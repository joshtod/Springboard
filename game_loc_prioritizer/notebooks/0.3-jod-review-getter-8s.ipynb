# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 8

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')

# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 112 users this round
# Got 194 reivews
# 306944 reviews are now in the bag, so to speak
# 2024-03-31 20:25:48
#
# Scraped 96 users this round
# Got 142 reivews
# 307086 reviews are now in the bag, so to speak
# 2024-03-31 20:29:13
#
# Scraped 97 users this round
# Got 191 reivews
# 307277 reviews are now in the bag, so to speak
# 2024-03-31 20:32:33
#
# Scraped 115 users this round
# Got 208 reivews
# 307485 reviews are now in the bag, so to speak
# 2024-03-31 20:36:30
#
# Scraped 114 users this round
# Got 181 reivews
# 307666 reviews are now in the bag, so to speak
# 2024-03-31 20:40:38
#
# Scraped 109 users this round
# Got 237 reivews
# 307903 reviews are now in the bag, so to speak
# 2024-03-31 20:44:28
#
# Scraped 130 users this round
# Got 156 reivews
# 308059 reviews are now in the bag, so to speak
# 2024-03-31 20:49:01
#
# Scraped 106 users this round
# Got 150 reivews
# 308209 reviews are now in the bag, so to speak
# 2024-03-31 20:52:41
#
# Scraped 97 users this round
# Got 196 reivews
# 308405 reviews are now in the bag, so to speak
# 2024-03-31 20:56:02
#
# Scraped 101 users this round
# Got 198 reivews
# 308603 reviews are now in the bag, so to speak
# 2024-03-31 20:59:38
#
# Scraped 122 users this round
# Got 163 reivews
# 308766 reviews are now in the bag, so to speak
# 2024-03-31 21:04:09
#
# Scraped 97 users this round
# Got 192 reivews
# 308958 reviews are now in the bag, so to speak
# 2024-03-31 21:07:16
#
# Scraped 105 users this round
# Got 206 reivews
# 309164 reviews are now in the bag, so to speak
# 2024-03-31 21:11:03
#
# Scraped 125 users this round
# Got 194 reivews
# 309358 reviews are now in the bag, so to speak
# 2024-03-31 21:15:42
#
# Scraped 87 users this round
# Got 156 reivews
# 309514 reviews are now in the bag, so to speak
# 2024-03-31 21:18:45
#
# Scraped 106 users this round
# Got 175 reivews
# 309689 reviews are now in the bag, so to speak
# 2024-03-31 21:22:35
#
# Scraped 116 users this round
# Got 161 reivews
# 309850 reviews are now in the bag, so to speak
# 2024-03-31 21:27:07
#
# Scraped 102 users this round
# Got 214 reivews
# 310064 reviews are now in the bag, so to speak
# 2024-03-31 21:31:02
#
# Scraped 102 users this round
# Got 165 reivews
# 310229 reviews are now in the bag, so to speak
# 2024-03-31 21:34:50
#
# Scraped 112 users this round
# Got 187 reivews
# 310416 reviews are now in the bag, so to speak
# 2024-03-31 21:39:17
#
# Scraped 123 users this round
# Got 185 reivews
# 310601 reviews are now in the bag, so to speak
# 2024-03-31 21:44:18
#
# Scraped 110 users this round
# Got 210 reivews
# 310811 reviews are now in the bag, so to speak
# 2024-03-31 21:48:41
#
# Scraped 107 users this round
# Got 205 reivews
# 311016 reviews are now in the bag, so to speak
# 2024-03-31 21:53:03
#
# Scraped 107 users this round
# Got 196 reivews
# 311212 reviews are now in the bag, so to speak
# 2024-03-31 21:56:59
#
# Scraped 110 users this round
# Got 195 reivews
# 311407 reviews are now in the bag, so to speak
# 2024-03-31 22:00:57
#
# Scraped 111 users this round
# Got 192 reivews
# 311599 reviews are now in the bag, so to speak
# 2024-03-31 22:05:10
#
# Scraped 91 users this round
# Got 204 reivews
# 311803 reviews are now in the bag, so to speak
# 2024-03-31 22:08:29
#
# Scraped 127 users this round
# Got 193 reivews
# 311996 reviews are now in the bag, so to speak
# 2024-03-31 22:14:55
#
# Scraped 109 users this round
# Got 167 reivews
# 312163 reviews are now in the bag, so to speak
# 2024-03-31 22:20:29
#
# Scraped 98 users this round
# Got 184 reivews
# 312347 reviews are now in the bag, so to speak
# 2024-03-31 22:25:34
#
# Scraped 103 users this round
# Got 232 reivews
# 312579 reviews are now in the bag, so to speak
# 2024-03-31 22:30:55
#
# Scraped 94 users this round
# Got 152 reivews
# 312731 reviews are now in the bag, so to speak
# 2024-03-31 22:36:02
#
# Scraped 108 users this round
# Got 185 reivews
# 312916 reviews are now in the bag, so to speak
# 2024-03-31 22:42:07
#
# Scraped 99 users this round
# Got 220 reivews
# 313136 reviews are now in the bag, so to speak
# 2024-03-31 22:47:39
#
# Scraped 101 users this round
# Got 170 reivews
# 313306 reviews are now in the bag, so to speak
# 2024-03-31 22:53:17
#
# Scraped 109 users this round
# Got 164 reivews
# 313470 reviews are now in the bag, so to speak
# 2024-03-31 22:59:59
#
# Scraped 111 users this round
# Got 189 reivews
# 313659 reviews are now in the bag, so to speak
# 2024-03-31 23:06:35
#
# Scraped 113 users this round
# Got 157 reivews
# 313816 reviews are now in the bag, so to speak
# 2024-03-31 23:12:50
#
# Scraped 87 users this round
# Got 215 reivews
# 314031 reviews are now in the bag, so to speak
# 2024-03-31 23:17:34
#
# Scraped 106 users this round
# Got 230 reivews
# 314261 reviews are now in the bag, so to speak
# 2024-03-31 23:23:06
#
# Scraped 104 users this round
# Got 201 reivews
# 314462 reviews are now in the bag, so to speak
# 2024-03-31 23:27:29
#
# Scraped 111 users this round
# Got 220 reivews
# 314682 reviews are now in the bag, so to speak
# 2024-03-31 23:31:23
#
# Scraped 127 users this round
# Got 156 reivews
# 314838 reviews are now in the bag, so to speak
# 2024-03-31 23:35:40
#
# Scraped 99 users this round
# Got 150 reivews
# 314988 reviews are now in the bag, so to speak
# 2024-03-31 23:38:46
#
# Scraped 129 users this round
# Got 170 reivews
# 315158 reviews are now in the bag, so to speak
# 2024-03-31 23:43:10
#
# Scraped 144 users this round
# Got 191 reivews
# 315349 reviews are now in the bag, so to speak
# 2024-03-31 23:48:05
#
# Scraped 102 users this round
# Got 169 reivews
# 315518 reviews are now in the bag, so to speak
# 2024-03-31 23:51:33
#
# Scraped 100 users this round
# Got 144 reivews
# 315662 reviews are now in the bag, so to speak
# 2024-03-31 23:54:47
#
# Scraped 112 users this round
# Got 202 reivews
# 315864 reviews are now in the bag, so to speak
# 2024-03-31 23:58:35
#
# Scraped 103 users this round
# Got 160 reivews
# 316024 reviews are now in the bag, so to speak
# 2024-04-01 00:01:44
#
# Scraped 90 users this round
# Got 189 reivews
# 316213 reviews are now in the bag, so to speak
# 2024-04-01 00:04:35
#
# Scraped 119 users this round
# Got 172 reivews
# 316385 reviews are now in the bag, so to speak
# 2024-04-01 00:08:32
#
# Scraped 100 users this round
# Got 203 reivews
# 316588 reviews are now in the bag, so to speak
# 2024-04-01 00:11:55
#
# Scraped 106 users this round
# Got 205 reivews
# 316793 reviews are now in the bag, so to speak
# 2024-04-01 00:15:38
#
# Scraped 123 users this round
# Got 178 reivews
# 316971 reviews are now in the bag, so to speak
# 2024-04-01 00:19:51
#
# Scraped 126 users this round
# Got 203 reivews
# 317174 reviews are now in the bag, so to speak
# 2024-04-01 00:24:04
#
# Scraped 95 users this round
# Got 209 reivews
# 317383 reviews are now in the bag, so to speak
# 2024-04-01 00:27:12
#
# Scraped 102 users this round
# Got 228 reivews
# 317611 reviews are now in the bag, so to speak
# 2024-04-01 00:30:34
#
# Scraped 97 users this round
# Got 164 reivews
# 317775 reviews are now in the bag, so to speak
# 2024-04-01 00:33:52
#
# Scraped 93 users this round
# Got 206 reivews
# 317981 reviews are now in the bag, so to speak
# 2024-04-01 00:36:49
#
# Unable to parse review blocks.
# Scraped 114 users this round
# Got 178 reivews
# 318159 reviews are now in the bag, so to speak
# 2024-04-01 00:46:44
#
# Scraped 103 users this round
# Got 191 reivews
# 318350 reviews are now in the bag, so to speak
# 2024-04-01 00:50:11
#
# Scraped 127 users this round
# Got 170 reivews
# 318520 reviews are now in the bag, so to speak
# 2024-04-01 00:54:39
#
# Scraped 96 users this round
# Got 191 reivews
# 318711 reviews are now in the bag, so to speak
# 2024-04-01 00:57:56
#
# Scraped 122 users this round
# Got 187 reivews
# 318898 reviews are now in the bag, so to speak
# 2024-04-01 01:02:13
#
# Scraped 101 users this round
# Got 198 reivews
# 319096 reviews are now in the bag, so to speak
# 2024-04-01 01:05:38
#
# Scraped 115 users this round
# Got 225 reivews
# 319321 reviews are now in the bag, so to speak
# 2024-04-01 01:09:39
#
# Scraped 121 users this round
# Got 201 reivews
# 319522 reviews are now in the bag, so to speak
# 2024-04-01 01:13:54
#
# Scraped 112 users this round
# Got 176 reivews
# 319698 reviews are now in the bag, so to speak
# 2024-04-01 01:17:47
#
# Scraped 109 users this round
# Got 154 reivews
# 319852 reviews are now in the bag, so to speak
# 2024-04-01 01:21:36
#
# Scraped 93 users this round
# Got 189 reivews
# 320041 reviews are now in the bag, so to speak
# 2024-04-01 01:24:48
#
# Scraped 97 users this round
# Got 221 reivews
# 320262 reviews are now in the bag, so to speak
# 2024-04-01 01:28:05
#
# Scraped 124 users this round
# Got 142 reivews
# 320404 reviews are now in the bag, so to speak
# 2024-04-01 01:32:16
#
# Scraped 108 users this round
# Got 176 reivews
# 320580 reviews are now in the bag, so to speak
# 2024-04-01 01:35:59
#
# Scraped 108 users this round
# Got 202 reivews
# 320782 reviews are now in the bag, so to speak
# 2024-04-01 01:39:41
#
# Scraped 114 users this round
# Got 181 reivews
# 320963 reviews are now in the bag, so to speak
# 2024-04-01 01:43:22
#
# Scraped 108 users this round
# Got 205 reivews
# 321168 reviews are now in the bag, so to speak
# 2024-04-01 01:46:55
#
# Scraped 100 users this round
# Got 158 reivews
# 321326 reviews are now in the bag, so to speak
# 2024-04-01 01:50:08
#
# Scraped 112 users this round
# Got 188 reivews
# 321514 reviews are now in the bag, so to speak
# 2024-04-01 01:53:56
#
# Scraped 113 users this round
# Got 204 reivews
# 321718 reviews are now in the bag, so to speak
# 2024-04-01 01:57:46
#
# Scraped 90 users this round
# Got 228 reivews
# 321946 reviews are now in the bag, so to speak
# 2024-04-01 02:00:52
#
# Scraped 113 users this round
# Got 199 reivews
# 322145 reviews are now in the bag, so to speak
# 2024-04-01 02:04:42
#
# Scraped 119 users this round
# Got 153 reivews
# 322298 reviews are now in the bag, so to speak
# 2024-04-01 02:08:44
#
# Scraped 108 users this round
# Got 189 reivews
# 322487 reviews are now in the bag, so to speak
# 2024-04-01 02:12:07
#
# Scraped 105 users this round
# Got 203 reivews
# 322690 reviews are now in the bag, so to speak
# 2024-04-01 02:15:27
#
# Scraped 112 users this round
# Got 207 reivews
# 322897 reviews are now in the bag, so to speak
# 2024-04-01 02:19:06
#
# Scraped 109 users this round
# Got 183 reivews
# 323080 reviews are now in the bag, so to speak
# 2024-04-01 02:22:49
#
# Scraped 110 users this round
# Got 200 reivews
# 323280 reviews are now in the bag, so to speak
# 2024-04-01 02:26:20
#
# Scraped 102 users this round
# Got 154 reivews
# 323434 reviews are now in the bag, so to speak
# 2024-04-01 02:29:24
#
# Scraped 111 users this round
# Got 197 reivews
# 323631 reviews are now in the bag, so to speak
# 2024-04-01 02:33:03
#
# Scraped 116 users this round
# Got 195 reivews
# 323826 reviews are now in the bag, so to speak
# 2024-04-01 02:36:57
#
# Scraped 104 users this round
# Got 139 reivews
# 323965 reviews are now in the bag, so to speak
# 2024-04-01 02:40:16
#
# Scraped 132 users this round
# Got 177 reivews
# 324142 reviews are now in the bag, so to speak
# 2024-04-01 02:44:37
#
# Scraped 122 users this round
# Got 190 reivews
# 324332 reviews are now in the bag, so to speak
# 2024-04-01 02:48:46
#
# Scraped 129 users this round
# Got 159 reivews
# 324491 reviews are now in the bag, so to speak
# 2024-04-01 02:53:02
#
# Scraped 120 users this round
# Got 201 reivews
# 324692 reviews are now in the bag, so to speak
# 2024-04-01 02:57:24
#
# Scraped 114 users this round
# Got 216 reivews
# 324908 reviews are now in the bag, so to speak
# 2024-04-01 03:01:05
#
# Scraped 109 users this round
# Got 182 reivews
# 325090 reviews are now in the bag, so to speak
# 2024-04-01 03:04:42
#
# Scraped 108 users this round
# Got 235 reivews
# 325325 reviews are now in the bag, so to speak
# 2024-04-01 03:08:04
#
# Scraped 114 users this round
# Got 177 reivews
# 325502 reviews are now in the bag, so to speak
# 2024-04-01 03:11:51
#
# Scraped 111 users this round
# Got 179 reivews
# 325681 reviews are now in the bag, so to speak
# 2024-04-01 03:15:37
#
# Scraped 107 users this round
# Got 194 reivews
# 325875 reviews are now in the bag, so to speak
# 2024-04-01 03:19:19
#
# Scraped 105 users this round
# Got 202 reivews
# 326077 reviews are now in the bag, so to speak
# 2024-04-01 03:22:49
#
# Scraped 97 users this round
# Got 217 reivews
# 326294 reviews are now in the bag, so to speak
# 2024-04-01 03:26:04
#
# Scraped 114 users this round
# Got 223 reivews
# 326517 reviews are now in the bag, so to speak
# 2024-04-01 03:29:48
#
# Scraped 103 users this round
# Got 198 reivews
# 326715 reviews are now in the bag, so to speak
# 2024-04-01 03:33:01
#
# Scraped 109 users this round
# Got 216 reivews
# 326931 reviews are now in the bag, so to speak
# 2024-04-01 03:36:40
#
# Scraped 117 users this round
# Got 178 reivews
# 327109 reviews are now in the bag, so to speak
# 2024-04-01 03:40:37
#
# Scraped 105 users this round
# Got 195 reivews
# 327304 reviews are now in the bag, so to speak
# 2024-04-01 03:43:48
#
# Scraped 106 users this round
# Got 165 reivews
# 327469 reviews are now in the bag, so to speak
# 2024-04-01 03:47:15
#
# Scraped 115 users this round
# Got 197 reivews
# 327666 reviews are now in the bag, so to speak
# 2024-04-01 03:50:55
#
# Scraped 87 users this round
# Got 188 reivews
# 327854 reviews are now in the bag, so to speak
# 2024-04-01 03:53:37
#
# Scraped 92 users this round
# Got 155 reivews
# 328009 reviews are now in the bag, so to speak
# 2024-04-01 03:56:26
#
# Scraped 115 users this round
# Got 153 reivews
# 328162 reviews are now in the bag, so to speak
# 2024-04-01 04:00:23
#
# Scraped 100 users this round
# Got 155 reivews
# 328317 reviews are now in the bag, so to speak
# 2024-04-01 04:03:29
#
# Scraped 114 users this round
# Got 155 reivews
# 328472 reviews are now in the bag, so to speak
# 2024-04-01 04:07:06
#
# Scraped 106 users this round
# Got 201 reivews
# 328673 reviews are now in the bag, so to speak
# 2024-04-01 04:10:44
#
# Scraped 102 users this round
# Got 206 reivews
# 328879 reviews are now in the bag, so to speak
# 2024-04-01 04:14:05
#
# Scraped 101 users this round
# Got 188 reivews
# 329067 reviews are now in the bag, so to speak
# 2024-04-01 04:17:22
#
# Scraped 108 users this round
# Got 178 reivews
# 329245 reviews are now in the bag, so to speak
# 2024-04-01 04:20:56
#
# Scraped 106 users this round
# Got 183 reivews
# 329428 reviews are now in the bag, so to speak
# 2024-04-01 04:24:22
#
# Scraped 100 users this round
# Got 180 reivews
# 329608 reviews are now in the bag, so to speak
# 2024-04-01 04:27:41
#
# Scraped 120 users this round
# Got 197 reivews
# 329805 reviews are now in the bag, so to speak
# 2024-04-01 04:31:34
#
# Scraped 88 users this round
# Got 183 reivews
# 329988 reviews are now in the bag, so to speak
# 2024-04-01 04:34:26
#
# Scraped 112 users this round
# Got 188 reivews
# 330176 reviews are now in the bag, so to speak
# 2024-04-01 04:38:21
#
# Scraped 110 users this round
# Got 199 reivews
# 330375 reviews are now in the bag, so to speak
# 2024-04-01 04:41:58
#
# Scraped 136 users this round
# Got 182 reivews
# 330557 reviews are now in the bag, so to speak
# 2024-04-01 04:46:33
#
# Scraped 131 users this round
# Got 225 reivews
# 330782 reviews are now in the bag, so to speak
# 2024-04-01 04:50:54
#
# Scraped 113 users this round
# Got 165 reivews
# 330947 reviews are now in the bag, so to speak
# 2024-04-01 04:54:29
#
# Scraped 103 users this round
# Got 149 reivews
# 331096 reviews are now in the bag, so to speak
# 2024-04-01 04:57:46
#
# Scraped 107 users this round
# Got 198 reivews
# 331294 reviews are now in the bag, so to speak
# 2024-04-01 05:01:26
#
# Scraped 106 users this round
# Got 230 reivews
# 331524 reviews are now in the bag, so to speak
# 2024-04-01 05:04:44
#
# Scraped 143 users this round
# Got 188 reivews
# 331712 reviews are now in the bag, so to speak
# 2024-04-01 05:09:41
#
# Scraped 141 users this round
# Got 174 reivews
# 331886 reviews are now in the bag, so to speak
# 2024-04-01 05:14:30
#
# Scraped 122 users this round
# Got 205 reivews
# 332091 reviews are now in the bag, so to speak
# 2024-04-01 05:18:29
#
# Scraped 126 users this round
# Got 195 reivews
# 332286 reviews are now in the bag, so to speak
# 2024-04-01 05:22:33
#
# Scraped 114 users this round
# Got 166 reivews
# 332452 reviews are now in the bag, so to speak
# 2024-04-01 05:26:17
#
# Scraped 116 users this round
# Got 215 reivews
# 332667 reviews are now in the bag, so to speak
# 2024-04-01 05:30:33
#
# Scraped 124 users this round
# Got 165 reivews
# 332832 reviews are now in the bag, so to speak
# 2024-04-01 05:34:47
#
# Scraped 125 users this round
# Got 174 reivews
# 333006 reviews are now in the bag, so to speak
# 2024-04-01 05:38:51
#
# Scraped 109 users this round
# Got 197 reivews
# 333203 reviews are now in the bag, so to speak
# 2024-04-01 05:42:25
#
# Scraped 113 users this round
# Got 230 reivews
# 333433 reviews are now in the bag, so to speak
# 2024-04-01 05:46:07
#
# Unable to parse review blocks.
# Scraped 110 users this round
# Got 155 reivews
# 333588 reviews are now in the bag, so to speak
# 2024-04-01 05:51:06
#
# Scraped 102 users this round
# Got 180 reivews
# 333768 reviews are now in the bag, so to speak
# 2024-04-01 05:54:18
#
# Scraped 91 users this round
# Got 227 reivews
# 333995 reviews are now in the bag, so to speak
# 2024-04-01 05:57:14
#
# Scraped 115 users this round
# Got 168 reivews
# 334163 reviews are now in the bag, so to speak
# 2024-04-01 06:00:59
#
# Scraped 117 users this round
# Got 192 reivews
# 334355 reviews are now in the bag, so to speak
# 2024-04-01 06:04:51
#
# Scraped 122 users this round
# Got 193 reivews
# 334548 reviews are now in the bag, so to speak
# 2024-04-01 06:08:47
#
# Scraped 127 users this round
# Got 213 reivews
# 334761 reviews are now in the bag, so to speak
# 2024-04-01 06:13:11
#
# Scraped 114 users this round
# Got 167 reivews
# 334928 reviews are now in the bag, so to speak
# 2024-04-01 06:16:54
#
# Scraped 105 users this round
# Got 174 reivews
# 335102 reviews are now in the bag, so to speak
# 2024-04-01 06:20:12
#
# Scraped 110 users this round
# Got 233 reivews
# 335335 reviews are now in the bag, so to speak
# 2024-04-01 06:23:59
#
# Scraped 91 users this round
# Got 196 reivews
# 335531 reviews are now in the bag, so to speak
# 2024-04-01 06:26:57
#
# Scraped 137 users this round
# Got 193 reivews
# 335724 reviews are now in the bag, so to speak
# 2024-04-01 06:31:45
#
# Scraped 110 users this round
# Got 179 reivews
# 335903 reviews are now in the bag, so to speak
# 2024-04-01 06:35:22
#
# Scraped 108 users this round
# Got 177 reivews
# 336080 reviews are now in the bag, so to speak
# 2024-04-01 06:39:00
#
# Scraped 112 users this round
# Got 136 reivews
# 336216 reviews are now in the bag, so to speak
# 2024-04-01 06:42:41
#
# Scraped 108 users this round
# Got 179 reivews
# 336395 reviews are now in the bag, so to speak
# 2024-04-01 06:46:09
#
# Scraped 110 users this round
# Got 197 reivews
# 336592 reviews are now in the bag, so to speak
# 2024-04-01 06:49:56
#
# Scraped 107 users this round
# Got 179 reivews
# 336771 reviews are now in the bag, so to speak
# 2024-04-01 06:53:37
#
# Scraped 110 users this round
# Got 223 reivews
# 336994 reviews are now in the bag, so to speak
# 2024-04-01 06:57:16
#
# Scraped 95 users this round
# Got 184 reivews
# 337178 reviews are now in the bag, so to speak
# 2024-04-01 07:00:39
#
# Scraped 107 users this round
# Got 194 reivews
# 337372 reviews are now in the bag, so to speak
# 2024-04-01 07:04:29
#
# Scraped 110 users this round
# Got 191 reivews
# 337563 reviews are now in the bag, so to speak
# 2024-04-01 07:08:16
#
# Scraped 119 users this round
# Got 202 reivews
# 337765 reviews are now in the bag, so to speak
# 2024-04-01 07:12:43
#
# Scraped 101 users this round
# Got 230 reivews
# 337995 reviews are now in the bag, so to speak
# 2024-04-01 07:16:02
#
# Scraped 110 users this round
# Got 167 reivews
# 338162 reviews are now in the bag, so to speak
# 2024-04-01 07:19:39
#
# Scraped 112 users this round
# Got 143 reivews
# 338305 reviews are now in the bag, so to speak
# 2024-04-01 07:23:17
#
# Scraped 126 users this round
# Got 214 reivews
# 338519 reviews are now in the bag, so to speak
# 2024-04-01 07:27:44
#
# Scraped 107 users this round
# Got 187 reivews
# 338706 reviews are now in the bag, so to speak
# 2024-04-01 07:31:25
#
# Scraped 104 users this round
# Got 148 reivews
# 338854 reviews are now in the bag, so to speak
# 2024-04-01 07:34:55
#
# Scraped 110 users this round
# Got 191 reivews
# 339045 reviews are now in the bag, so to speak
# 2024-04-01 07:38:50
#
# Scraped 110 users this round
# Got 204 reivews
# 339249 reviews are now in the bag, so to speak
# 2024-04-01 07:42:43
#
# Scraped 109 users this round
# Got 180 reivews
# 339429 reviews are now in the bag, so to speak
# 2024-04-01 07:46:15
#
# Scraped 127 users this round
# Got 176 reivews
# 339605 reviews are now in the bag, so to speak
# 2024-04-01 07:50:37
#
# Scraped 104 users this round
# Got 183 reivews
# 339788 reviews are now in the bag, so to speak
# 2024-04-01 07:53:56
#
# Scraped 111 users this round
# Got 171 reivews
# 339959 reviews are now in the bag, so to speak
# 2024-04-01 07:57:39
#
# Scraped 111 users this round
# Got 184 reivews
# 340143 reviews are now in the bag, so to speak
# 2024-04-01 08:01:33
#
# Scraped 131 users this round
# Got 164 reivews
# 340307 reviews are now in the bag, so to speak
# 2024-04-01 08:06:14
#
# Scraped 112 users this round
# Got 181 reivews
# 340488 reviews are now in the bag, so to speak
# 2024-04-01 08:10:07
#
# Scraped 114 users this round
# Got 252 reivews
# 340740 reviews are now in the bag, so to speak
# 2024-04-01 08:14:21
#
# Scraped 109 users this round
# Got 171 reivews
# 340911 reviews are now in the bag, so to speak
# 2024-04-01 08:18:06
#
# Scraped 104 users this round
# Got 199 reivews
# 341110 reviews are now in the bag, so to speak
# 2024-04-01 08:21:33
#
# Scraped 138 users this round
# Got 176 reivews
# 341286 reviews are now in the bag, so to speak
# 2024-04-01 08:26:28
#
# Scraped 127 users this round
# Got 173 reivews
# 341459 reviews are now in the bag, so to speak
# 2024-04-01 08:30:58
#
# Scraped 116 users this round
# Got 207 reivews
# 341666 reviews are now in the bag, so to speak
# 2024-04-01 08:34:58
#
# Scraped 109 users this round
# Got 194 reivews
# 341860 reviews are now in the bag, so to speak
# 2024-04-01 08:38:38
#
# Scraped 120 users this round
# Got 235 reivews
# 342095 reviews are now in the bag, so to speak
# 2024-04-01 08:42:55
#
# Scraped 118 users this round
# Got 164 reivews
# 342259 reviews are now in the bag, so to speak
# 2024-04-01 08:47:03
#
# Scraped 112 users this round
# Got 182 reivews
# 342441 reviews are now in the bag, so to speak
# 2024-04-01 08:50:57
#
# Scraped 111 users this round
# Got 164 reivews
# 342605 reviews are now in the bag, so to speak
# 2024-04-01 08:54:40
#
# Scraped 94 users this round
# Got 179 reivews
# 342784 reviews are now in the bag, so to speak
# 2024-04-01 08:57:50
#
# Scraped 113 users this round
# Got 258 reivews
# 343042 reviews are now in the bag, so to speak
# 2024-04-01 09:01:55
#
# Scraped 99 users this round
# Got 202 reivews
# 343244 reviews are now in the bag, so to speak
# 2024-04-01 09:05:21
#
# Scraped 101 users this round
# Got 199 reivews
# 343443 reviews are now in the bag, so to speak
# 2024-04-01 09:08:47
#
# Scraped 98 users this round
# Got 196 reivews
# 343639 reviews are now in the bag, so to speak
# 2024-04-01 09:12:09
#
# Scraped 104 users this round
# Got 156 reivews
# 343795 reviews are now in the bag, so to speak
# 2024-04-01 09:15:49
#
# Scraped 120 users this round
# Got 189 reivews
# 343984 reviews are now in the bag, so to speak
# 2024-04-01 09:20:17
#
# Scraped 78 users this round
# Got 187 reivews
# 344171 reviews are now in the bag, so to speak
# 2024-04-01 09:22:52
#
# Scraped 126 users this round
# Got 199 reivews
# 344370 reviews are now in the bag, so to speak
# 2024-04-01 09:27:16
#
# Scraped 100 users this round
# Got 162 reivews
# 344532 reviews are now in the bag, so to speak
# 2024-04-01 09:30:48
#
# Scraped 115 users this round
# Got 170 reivews
# 344702 reviews are now in the bag, so to speak
# 2024-04-01 09:35:00
#
# Scraped 94 users this round
# Got 158 reivews
# 344860 reviews are now in the bag, so to speak
# 2024-04-01 09:37:55
#
# Scraped 94 users this round
# Got 177 reivews
# 345037 reviews are now in the bag, so to speak
# 2024-04-01 09:41:13
#
# Scraped 123 users this round
# Got 191 reivews
# 345228 reviews are now in the bag, so to speak
# 2024-04-01 09:45:54
#
# Scraped 101 users this round
# Got 175 reivews
# 345403 reviews are now in the bag, so to speak
# 2024-04-01 09:49:34
#
# Scraped 116 users this round
# Got 159 reivews
# 345562 reviews are now in the bag, so to speak
# 2024-04-01 09:53:51
#
# Scraped 101 users this round
# Got 157 reivews
# 345719 reviews are now in the bag, so to speak
# 2024-04-01 09:57:29
#
# Scraped 103 users this round
# Got 199 reivews
# 345918 reviews are now in the bag, so to speak
# 2024-04-01 10:01:18
#
# Scraped 114 users this round
# Got 148 reivews
# 346066 reviews are now in the bag, so to speak
# 2024-04-01 10:05:22
#
# Scraped 115 users this round
# Got 155 reivews
# 346221 reviews are now in the bag, so to speak
# 2024-04-01 10:09:32
#
# Scraped 102 users this round
# Got 228 reivews
# 346449 reviews are now in the bag, so to speak
# 2024-04-01 10:13:13
#
# Scraped 119 users this round
# Got 185 reivews
# 346634 reviews are now in the bag, so to speak
# 2024-04-01 10:17:46
#
# Scraped 114 users this round
# Got 163 reivews
# 346797 reviews are now in the bag, so to speak
# 2024-04-01 10:22:00
#
# Scraped 126 users this round
# Got 193 reivews
# 346990 reviews are now in the bag, so to speak
# 2024-04-01 10:26:51
#
# Scraped 107 users this round
# Got 179 reivews
# 347169 reviews are now in the bag, so to speak
# 2024-04-01 10:31:14
#
# Scraped 105 users this round
# Got 230 reivews
# 347399 reviews are now in the bag, so to speak
# 2024-04-01 10:35:26
#
# Scraped 97 users this round
# Got 196 reivews
# 347595 reviews are now in the bag, so to speak
# 2024-04-01 10:39:19
#
# Scraped 129 users this round
# Got 205 reivews
# 347800 reviews are now in the bag, so to speak
# 2024-04-01 10:44:24
#
# Scraped 112 users this round
# Got 202 reivews
# 348002 reviews are now in the bag, so to speak
# 2024-04-01 10:48:27
#
# Scraped 129 users this round
# Got 134 reivews
# 348136 reviews are now in the bag, so to speak
# 2024-04-01 10:53:27
#
# Scraped 120 users this round
# Got 178 reivews
# 348314 reviews are now in the bag, so to speak
# 2024-04-01 10:58:11
#
# Scraped 108 users this round
# Got 210 reivews
# 348524 reviews are now in the bag, so to speak
# 2024-04-01 11:02:16
#
# Scraped 95 users this round
# Got 173 reivews
# 348697 reviews are now in the bag, so to speak
# 2024-04-01 11:05:56
#
# Scraped 114 users this round
# Got 165 reivews
# 348862 reviews are now in the bag, so to speak
# 2024-04-01 11:10:34
#
# Scraped 92 users this round
# Got 210 reivews
# 349072 reviews are now in the bag, so to speak
# 2024-04-01 11:13:58
#
# Scraped 93 users this round
# Got 212 reivews
# 349284 reviews are now in the bag, so to speak
# 2024-04-01 11:17:19
#
# Scraped 109 users this round
# Got 187 reivews
# 349471 reviews are now in the bag, so to speak
# 2024-04-01 11:21:24
#
# Scraped 109 users this round
# Got 222 reivews
# 349693 reviews are now in the bag, so to speak
# 2024-04-01 11:25:37
#
# Scraped 95 users this round
# Got 183 reivews
# 349876 reviews are now in the bag, so to speak
# 2024-04-01 11:29:04
#
# Scraped 121 users this round
# Got 163 reivews
# 350039 reviews are now in the bag, so to speak
# 2024-04-01 11:33:32
#
# Scraped 149 users this round
# Got 217 reivews
# 350256 reviews are now in the bag, so to speak
# 2024-04-01 11:39:16
#
# Scraped 109 users this round
# Got 199 reivews
# 350455 reviews are now in the bag, so to speak
# 2024-04-01 11:43:28
#
# Scraped 123 users this round
# Got 187 reivews
# 350642 reviews are now in the bag, so to speak
# 2024-04-01 11:48:16
#
# Scraped 89 users this round
# Got 153 reivews
# 350795 reviews are now in the bag, so to speak
# 2024-04-01 11:51:26
#
# Scraped 123 users this round
# Got 223 reivews
# 351018 reviews are now in the bag, so to speak
# 2024-04-01 11:56:10
#
# Scraped 95 users this round
# Got 201 reivews
# 351219 reviews are now in the bag, so to speak
# 2024-04-01 11:59:51
#
# Scraped 122 users this round
# Got 214 reivews
# 351433 reviews are now in the bag, so to speak
# 2024-04-01 12:04:37
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 94 users this round
# Got 209 reivews
# 351642 reviews are now in the bag, so to speak
# 2024-04-01 12:08:02
#
# Scraped 103 users this round
# Got 190 reivews
# 351832 reviews are now in the bag, so to speak
# 2024-04-01 12:12:01
#
# Scraped 132 users this round
# Got 150 reivews
# 351982 reviews are now in the bag, so to speak
# 2024-04-01 12:17:08
#
# Scraped 97 users this round
# Got 210 reivews
# 352192 reviews are now in the bag, so to speak
# 2024-04-01 12:20:53
#
# Scraped 101 users this round
# Got 188 reivews
# 352380 reviews are now in the bag, so to speak
# 2024-04-01 12:24:36
#
# Scraped 107 users this round
# Got 193 reivews
# 352573 reviews are now in the bag, so to speak
# 2024-04-01 12:28:42
#
# Scraped 109 users this round
# Got 169 reivews
# 352742 reviews are now in the bag, so to speak
# 2024-04-01 12:32:53
#
# Scraped 120 users this round
# Got 142 reivews
# 352884 reviews are now in the bag, so to speak
# 2024-04-01 12:37:11
#
# Scraped 110 users this round
# Got 187 reivews
# 353071 reviews are now in the bag, so to speak
# 2024-04-01 12:41:11
#
# Scraped 112 users this round
# Got 184 reivews
# 353255 reviews are now in the bag, so to speak
# 2024-04-01 12:45:19
#
# Unable to parse review blocks.
# Scraped 114 users this round
# Got 202 reivews
# 353457 reviews are now in the bag, so to speak
# 2024-04-01 12:49:25
#
# Scraped 124 users this round
# Got 137 reivews
# 353594 reviews are now in the bag, so to speak
# 2024-04-01 12:53:59
#
# Scraped 101 users this round
# Got 212 reivews
# 353806 reviews are now in the bag, so to speak
# 2024-04-01 12:57:38
#
# Scraped 117 users this round
# Got 215 reivews
# 354021 reviews are now in the bag, so to speak
# 2024-04-01 13:01:58
#
# Scraped 117 users this round
# Got 183 reivews
# 354204 reviews are now in the bag, so to speak
# 2024-04-01 13:06:18
#
# Scraped 109 users this round
# Got 172 reivews
# 354376 reviews are now in the bag, so to speak
# 2024-04-01 13:10:03
#
# Scraped 110 users this round
# Got 204 reivews
# 354580 reviews are now in the bag, so to speak
# 2024-04-01 13:14:02
#
# Scraped 135 users this round
# Got 223 reivews
# 354803 reviews are now in the bag, so to speak
# 2024-04-01 13:18:48
#
# Scraped 108 users this round
# Got 204 reivews
# 355007 reviews are now in the bag, so to speak
# 2024-04-01 13:22:31
#
# Scraped 95 users this round
# Got 185 reivews
# 355192 reviews are now in the bag, so to speak
# 2024-04-01 13:25:45
#
# Scraped 103 users this round
# Got 170 reivews
# 355362 reviews are now in the bag, so to speak
# 2024-04-01 13:29:23
#
# Scraped 103 users this round
# Got 189 reivews
# 355551 reviews are now in the bag, so to speak
# 2024-04-01 13:32:56
#
# Scraped 101 users this round
# Got 181 reivews
# 355732 reviews are now in the bag, so to speak
# 2024-04-01 13:36:24
#
# Scraped 123 users this round
# Got 208 reivews
# 355940 reviews are now in the bag, so to speak
# 2024-04-01 13:40:43
#
# Scraped 135 users this round
# Got 192 reivews
# 356132 reviews are now in the bag, so to speak
# 2024-04-01 13:45:27
#
# Scraped 113 users this round
# Got 205 reivews
# 356337 reviews are now in the bag, so to speak
# 2024-04-01 13:49:26
#
# Scraped 127 users this round
# Got 189 reivews
# 356526 reviews are now in the bag, so to speak
# 2024-04-01 13:54:04
#
# Scraped 108 users this round
# Got 167 reivews
# 356693 reviews are now in the bag, so to speak
# 2024-04-01 13:57:57
#
# Scraped 141 users this round
# Got 158 reivews
# 356851 reviews are now in the bag, so to speak
# 2024-04-01 14:03:00
#
# Scraped 99 users this round
# Got 203 reivews
# 357054 reviews are now in the bag, so to speak
# 2024-04-01 14:06:34
#
# Scraped 104 users this round
# Got 185 reivews
# 357239 reviews are now in the bag, so to speak
# 2024-04-01 14:10:19
#
# Scraped 106 users this round
# Got 202 reivews
# 357441 reviews are now in the bag, so to speak
# 2024-04-01 14:13:53
#
# Scraped 116 users this round
# Got 200 reivews
# 357641 reviews are now in the bag, so to speak
# 2024-04-01 14:17:53
#
# Scraped 109 users this round
# Got 225 reivews
# 357866 reviews are now in the bag, so to speak
# 2024-04-01 14:21:49
#
# Scraped 102 users this round
# Got 211 reivews
# 358077 reviews are now in the bag, so to speak
# 2024-04-01 14:26:25
#
# Scraped 106 users this round
# Got 170 reivews
# 358247 reviews are now in the bag, so to speak
# 2024-04-01 14:30:05
#
# Scraped 118 users this round
# Got 182 reivews
# 358429 reviews are now in the bag, so to speak
# 2024-04-01 14:34:23
#
# Scraped 115 users this round
# Got 162 reivews
# 358591 reviews are now in the bag, so to speak
# 2024-04-01 14:38:30
#
# Scraped 115 users this round
# Got 183 reivews
# 358774 reviews are now in the bag, so to speak
# 2024-04-01 14:42:31
#
# Scraped 103 users this round
# Got 209 reivews
# 358983 reviews are now in the bag, so to speak
# 2024-04-01 14:46:14
#
# Scraped 94 users this round
# Got 199 reivews
# 359182 reviews are now in the bag, so to speak
# 2024-04-01 14:49:25
#
# Scraped 127 users this round
# Got 183 reivews
# 359365 reviews are now in the bag, so to speak
# 2024-04-01 14:53:56
#
# Scraped 123 users this round
# Got 245 reivews
# 359610 reviews are now in the bag, so to speak
# 2024-04-01 14:58:28
#
# Scraped 109 users this round
# Got 190 reivews
# 359800 reviews are now in the bag, so to speak
# 2024-04-01 15:02:21
#
# Scraped 102 users this round
# Got 167 reivews
# 359967 reviews are now in the bag, so to speak
# 2024-04-01 15:05:58
#
# Scraped 104 users this round
# Got 144 reivews
# 360111 reviews are now in the bag, so to speak
# 2024-04-01 15:09:42
#
# Scraped 105 users this round
# Got 191 reivews
# 360302 reviews are now in the bag, so to speak
# 2024-04-01 15:13:17
#
# Scraped 98 users this round
# Got 161 reivews
# 360463 reviews are now in the bag, so to speak
# 2024-04-01 15:16:35
#
# Scraped 125 users this round
# Got 163 reivews
# 360626 reviews are now in the bag, so to speak
# 2024-04-01 15:21:00
#
# Scraped 102 users this round
# Got 196 reivews
# 360822 reviews are now in the bag, so to speak
# 2024-04-01 15:24:31
#
# Scraped 114 users this round
# Got 192 reivews
# 361014 reviews are now in the bag, so to speak
# 2024-04-01 15:28:30
#
# Scraped 97 users this round
# Got 170 reivews
# 361184 reviews are now in the bag, so to speak
# 2024-04-01 15:31:55
#
# Scraped 108 users this round
# Got 173 reivews
# 361357 reviews are now in the bag, so to speak
# 2024-04-01 15:35:33
#
# Scraped 108 users this round
# Got 195 reivews
# 361552 reviews are now in the bag, so to speak
# 2024-04-01 15:39:30
#
# Scraped 108 users this round
# Got 179 reivews
# 361731 reviews are now in the bag, so to speak
# 2024-04-01 15:43:24
#
# Scraped 129 users this round
# Got 194 reivews
# 361925 reviews are now in the bag, so to speak
# 2024-04-01 15:48:03
#
# Scraped 109 users this round
# Got 196 reivews
# 362121 reviews are now in the bag, so to speak
# 2024-04-01 15:51:49
#
# Scraped 119 users this round
# Got 181 reivews
# 362302 reviews are now in the bag, so to speak
# 2024-04-01 15:55:55
#
# Scraped 112 users this round
# Got 232 reivews
# 362534 reviews are now in the bag, so to speak
# 2024-04-01 15:59:54
#
# Scraped 105 users this round
# Got 163 reivews
# 362697 reviews are now in the bag, so to speak
# 2024-04-01 16:03:35
#
# Scraped 122 users this round
# Got 180 reivews
# 362877 reviews are now in the bag, so to speak
# 2024-04-01 16:08:00
#
# Scraped 131 users this round
# Got 210 reivews
# 363087 reviews are now in the bag, so to speak
# 2024-04-01 16:12:41
#
# Scraped 104 users this round
# Got 185 reivews
# 363272 reviews are now in the bag, so to speak
# 2024-04-01 16:16:16
#
# Scraped 112 users this round
# Got 194 reivews
# 363466 reviews are now in the bag, so to speak
# 2024-04-01 16:20:21
#
# Scraped 103 users this round
# Got 147 reivews
# 363613 reviews are now in the bag, so to speak
# 2024-04-01 16:23:38
#
# Scraped 111 users this round
# Got 201 reivews
# 363814 reviews are now in the bag, so to speak
# 2024-04-01 16:27:38
#
# Scraped 139 users this round
# Got 195 reivews
# 364009 reviews are now in the bag, so to speak
# 2024-04-01 16:32:48
#
# Scraped 102 users this round
# Got 171 reivews
# 364180 reviews are now in the bag, so to speak
# 2024-04-01 16:36:30
#
# Scraped 106 users this round
# Got 186 reivews
# 364366 reviews are now in the bag, so to speak
# 2024-04-01 16:40:05
#
# Scraped 113 users this round
# Got 151 reivews
# 364517 reviews are now in the bag, so to speak
# 2024-04-01 16:43:55
#
# Scraped 97 users this round
# Got 166 reivews
# 364683 reviews are now in the bag, so to speak
# 2024-04-01 16:47:24
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 112 users this round
# Got 148 reivews
# 364831 reviews are now in the bag, so to speak
# 2024-04-01 16:51:26
#
# Scraped 92 users this round
# Got 165 reivews
# 364996 reviews are now in the bag, so to speak
# 2024-04-01 16:54:28
#
# Scraped 121 users this round
# Got 180 reivews
# 365176 reviews are now in the bag, so to speak
# 2024-04-01 16:58:43
#
# Scraped 106 users this round
# Got 157 reivews
# 365333 reviews are now in the bag, so to speak
# 2024-04-01 17:02:31
#
# Scraped 104 users this round
# Got 226 reivews
# 365559 reviews are now in the bag, so to speak
# 2024-04-01 17:06:02
#
# Scraped 103 users this round
# Got 220 reivews
# 365779 reviews are now in the bag, so to speak
# 2024-04-01 17:09:27
#
# Scraped 118 users this round
# Got 170 reivews
# 365949 reviews are now in the bag, so to speak
# 2024-04-01 17:13:31
#
# Scraped 112 users this round
# Got 186 reivews
# 366135 reviews are now in the bag, so to speak
# 2024-04-01 17:17:24
#
# Scraped 122 users this round
# Got 185 reivews
# 366320 reviews are now in the bag, so to speak
# 2024-04-01 17:22:03
#
# Scraped 114 users this round
# Got 182 reivews
# 366502 reviews are now in the bag, so to speak
# 2024-04-01 17:26:12
#
# Scraped 96 users this round
# Got 167 reivews
# 366669 reviews are now in the bag, so to speak
# 2024-04-01 17:29:33
#
# Scraped 100 users this round
# Got 202 reivews
# 366871 reviews are now in the bag, so to speak
# 2024-04-01 17:32:56
#
# Scraped 88 users this round
# Got 165 reivews
# 367036 reviews are now in the bag, so to speak
# 2024-04-01 17:35:52
#
# Scraped 104 users this round
# Got 185 reivews
# 367221 reviews are now in the bag, so to speak
# 2024-04-01 17:39:27
#
# Scraped 106 users this round
# Got 231 reivews
# 367452 reviews are now in the bag, so to speak
# 2024-04-01 17:43:10
#
# Scraped 118 users this round
# Got 169 reivews
# 367621 reviews are now in the bag, so to speak
# 2024-04-01 17:47:18
#
# Scraped 123 users this round
# Got 184 reivews
# 367805 reviews are now in the bag, so to speak
# 2024-04-01 17:51:42
#
# Scraped 109 users this round
# Got 177 reivews
# 367982 reviews are now in the bag, so to speak
# 2024-04-01 17:55:34
#
# Scraped 102 users this round
# Got 227 reivews
# 368209 reviews are now in the bag, so to speak
# 2024-04-01 17:59:15
#
# Scraped 124 users this round
# Got 187 reivews
# 368396 reviews are now in the bag, so to speak
# 2024-04-01 18:03:29
#
# Scraped 96 users this round
# Got 160 reivews
# 368556 reviews are now in the bag, so to speak
# 2024-04-01 18:06:40
#
# Scraped 117 users this round
# Got 201 reivews
# 368757 reviews are now in the bag, so to speak
# 2024-04-01 18:10:49
#
# Scraped 96 users this round
# Got 188 reivews
# 368945 reviews are now in the bag, so to speak
# 2024-04-01 18:14:16
#
# Scraped 117 users this round
# Got 177 reivews
# 369122 reviews are now in the bag, so to speak
# 2024-04-01 18:18:20
#
# Scraped 135 users this round
# Got 216 reivews
# 369338 reviews are now in the bag, so to speak
# 2024-04-01 18:23:12
#
# Scraped 121 users this round
# Got 197 reivews
# 369535 reviews are now in the bag, so to speak
# 2024-04-01 18:27:25
#
# Scraped 89 users this round
# Got 177 reivews
# 369712 reviews are now in the bag, so to speak
# 2024-04-01 18:30:22
#
# Scraped 109 users this round
# Got 170 reivews
# 369882 reviews are now in the bag, so to speak
# 2024-04-01 18:34:04
#
# Scraped 96 users this round
# Got 205 reivews
# 370087 reviews are now in the bag, so to speak
# 2024-04-01 18:37:19
#
# Scraped 114 users this round
# Got 173 reivews
# 370260 reviews are now in the bag, so to speak
# 2024-04-01 18:41:16
#
# Scraped 115 users this round
# Got 177 reivews
# 370437 reviews are now in the bag, so to speak
# 2024-04-01 18:45:17
#
# Scraped 92 users this round
# Got 188 reivews
# 370625 reviews are now in the bag, so to speak
# 2024-04-01 18:48:27
#
# Scraped 98 users this round
# Got 166 reivews
# 370791 reviews are now in the bag, so to speak
# 2024-04-01 18:51:51
#
# Scraped 140 users this round
# Got 174 reivews
# 370965 reviews are now in the bag, so to speak
# 2024-04-01 18:56:59
#
# Scraped 100 users this round
# Got 150 reivews
# 371115 reviews are now in the bag, so to speak
# 2024-04-01 19:00:12
#
# Scraped 131 users this round
# Got 175 reivews
# 371290 reviews are now in the bag, so to speak
# 2024-04-01 19:04:53
#
# Scraped 119 users this round
# Got 215 reivews
# 371505 reviews are now in the bag, so to speak
# 2024-04-01 19:09:09
#
# Scraped 113 users this round
# Got 203 reivews
# 371708 reviews are now in the bag, so to speak
# 2024-04-01 19:13:09
#
# Scraped 103 users this round
# Got 172 reivews
# 371880 reviews are now in the bag, so to speak
# 2024-04-01 19:16:51
#
# Scraped 120 users this round
# Got 164 reivews
# 372044 reviews are now in the bag, so to speak
# 2024-04-01 19:21:00
#
# Scraped 111 users this round
# Got 171 reivews
# 372215 reviews are now in the bag, so to speak
# 2024-04-01 19:24:58
#
# Scraped 119 users this round
# Got 147 reivews
# 372362 reviews are now in the bag, so to speak
# 2024-04-01 19:29:06
#
# Scraped 113 users this round
# Got 187 reivews
# 372549 reviews are now in the bag, so to speak
# 2024-04-01 19:33:08
#
# Scraped 132 users this round
# Got 175 reivews
# 372724 reviews are now in the bag, so to speak
# 2024-04-01 19:37:49
#
# Scraped 125 users this round
# Got 131 reivews
# 372855 reviews are now in the bag, so to speak
# 2024-04-01 19:42:39
#
# Scraped 106 users this round
# Got 226 reivews
# 373081 reviews are now in the bag, so to speak
# 2024-04-01 19:46:17
#
# Scraped 109 users this round
# Got 175 reivews
# 373256 reviews are now in the bag, so to speak
# 2024-04-01 19:50:11
#
# Scraped 114 users this round
# Got 215 reivews
# 373471 reviews are now in the bag, so to speak
# 2024-04-01 19:54:06
#
# Scraped 106 users this round
# Got 184 reivews
# 373655 reviews are now in the bag, so to speak
# 2024-04-01 19:57:47
#
# Scraped 106 users this round
# Got 204 reivews
# 373859 reviews are now in the bag, so to speak
# 2024-04-01 20:01:32
#
# Scraped 96 users this round
# Got 168 reivews
# 374027 reviews are now in the bag, so to speak
# 2024-04-01 20:05:12
#
# Scraped 109 users this round
# Got 150 reivews
# 374177 reviews are now in the bag, so to speak
# 2024-04-01 20:10:18
#
# Scraped 109 users this round
# Got 194 reivews
# 374371 reviews are now in the bag, so to speak
# 2024-04-01 20:17:34
#
# Scraped 99 users this round
# Got 157 reivews
# 374528 reviews are now in the bag, so to speak
# 2024-04-01 20:24:07
#
# Scraped 109 users this round
# Got 207 reivews
# 374735 reviews are now in the bag, so to speak
# 2024-04-01 20:31:05
#
# Scraped 104 users this round
# Got 164 reivews
# 374899 reviews are now in the bag, so to speak
# 2024-04-01 20:36:55
#
# Scraped 97 users this round
# Got 221 reivews
# 375120 reviews are now in the bag, so to speak
# 2024-04-01 20:42:15
#
# Scraped 101 users this round
# Got 163 reivews
# 375283 reviews are now in the bag, so to speak
# 2024-04-01 20:47:22
#
# Scraped 105 users this round
# Got 219 reivews
# 375502 reviews are now in the bag, so to speak
# 2024-04-01 20:53:27
#
# Scraped 90 users this round
# Got 194 reivews
# 375696 reviews are now in the bag, so to speak
# 2024-04-01 20:59:01
#
# Scraped 107 users this round
# Got 195 reivews
# 375891 reviews are now in the bag, so to speak
# 2024-04-01 21:05:43
#
# Scraped 121 users this round
# Got 215 reivews
# 376106 reviews are now in the bag, so to speak
# 2024-04-01 21:13:06
#
# Scraped 115 users this round
# Got 169 reivews
# 376275 reviews are now in the bag, so to speak
# 2024-04-01 21:20:04
#
# Scraped 101 users this round
# Got 162 reivews
# 376437 reviews are now in the bag, so to speak
# 2024-04-01 21:26:09
#
# Scraped 111 users this round
# Got 161 reivews
# 376598 reviews are now in the bag, so to speak
# 2024-04-01 21:33:31
#
# Scraped 143 users this round
# Got 155 reivews
# 376753 reviews are now in the bag, so to speak
# 2024-04-01 21:42:29
#
# Scraped 105 users this round
# Got 159 reivews
# 376912 reviews are now in the bag, so to speak
# 2024-04-01 21:48:19
#
# Scraped 107 users this round
# Got 170 reivews
# 377082 reviews are now in the bag, so to speak
# 2024-04-01 21:54:37
#
# Scraped 123 users this round
# Got 164 reivews
# 377246 reviews are now in the bag, so to speak
# 2024-04-01 22:02:22
#
# Scraped 116 users this round
# Got 162 reivews
# 377408 reviews are now in the bag, so to speak
# 2024-04-01 22:10:02
#
# Scraped 127 users this round
# Got 183 reivews
# 377591 reviews are now in the bag, so to speak
# 2024-04-01 22:17:51
#
# Scraped 99 users this round
# Got 179 reivews
# 377770 reviews are now in the bag, so to speak
# 2024-04-01 22:23:52
#
# Scraped 103 users this round
# Got 166 reivews
# 377936 reviews are now in the bag, so to speak
# 2024-04-01 22:29:57
#
# Scraped 109 users this round
# Got 204 reivews
# 378140 reviews are now in the bag, so to speak
# 2024-04-01 22:36:14
#
# Scraped 133 users this round
# Got 198 reivews
# 378338 reviews are now in the bag, so to speak
# 2024-04-01 22:43:37
#
# Scraped 139 users this round
# Got 233 reivews
# 378571 reviews are now in the bag, so to speak
# 2024-04-01 22:50:59
#
# Scraped 106 users this round
# Got 183 reivews
# 378754 reviews are now in the bag, so to speak
# 2024-04-01 22:56:11
#
# Scraped 102 users this round
# Got 188 reivews
# 378942 reviews are now in the bag, so to speak
# 2024-04-01 23:01:29
#
# Scraped 111 users this round
# Got 245 reivews
# 379187 reviews are now in the bag, so to speak
# 2024-04-01 23:07:29
#
# Scraped 108 users this round
# Got 190 reivews
# 379377 reviews are now in the bag, so to speak
# 2024-04-01 23:12:14
#
# Scraped 112 users this round
# Got 164 reivews
# 379541 reviews are now in the bag, so to speak
# 2024-04-01 23:16:29
#
# Scraped 91 users this round
# Got 164 reivews
# 379705 reviews are now in the bag, so to speak
# 2024-04-01 23:19:42
#
# Scraped 113 users this round
# Got 203 reivews
# 379908 reviews are now in the bag, so to speak
# 2024-04-01 23:23:45
#
# Scraped 104 users this round
# Got 199 reivews
# 380107 reviews are now in the bag, so to speak
# 2024-04-01 23:27:33
#
# Scraped 117 users this round
# Got 201 reivews
# 380308 reviews are now in the bag, so to speak
# 2024-04-01 23:31:35
#
# Scraped 101 users this round
# Got 196 reivews
# 380504 reviews are now in the bag, so to speak
# 2024-04-01 23:35:07
#
# Scraped 110 users this round
# Got 244 reivews
# 380748 reviews are now in the bag, so to speak
# 2024-04-01 23:39:07
#
# Scraped 119 users this round
# Got 179 reivews
# 380927 reviews are now in the bag, so to speak
# 2024-04-01 23:43:21
#
# Scraped 116 users this round
# Got 169 reivews
# 381096 reviews are now in the bag, so to speak
# 2024-04-01 23:47:28
#
# Scraped 111 users this round
# Got 185 reivews
# 381281 reviews are now in the bag, so to speak
# 2024-04-01 23:51:52
#
# Scraped 109 users this round
# Got 196 reivews
# 381477 reviews are now in the bag, so to speak
# 2024-04-01 23:55:51
#
# Scraped 117 users this round
# Got 217 reivews
# 381694 reviews are now in the bag, so to speak
# 2024-04-02 00:00:07
#
# Scraped 127 users this round
# Got 195 reivews
# 381889 reviews are now in the bag, so to speak
# 2024-04-02 00:04:55
#
# Scraped 87 users this round
# Got 187 reivews
# 382076 reviews are now in the bag, so to speak
# 2024-04-02 00:07:54
#
# Scraped 105 users this round
# Got 178 reivews
# 382254 reviews are now in the bag, so to speak
# 2024-04-02 00:11:46
#
# Scraped 106 users this round
# Got 192 reivews
# 382446 reviews are now in the bag, so to speak
# 2024-04-02 00:15:56
#
# Scraped 100 users this round
# Got 204 reivews
# 382650 reviews are now in the bag, so to speak
# 2024-04-02 00:19:46
#
# Scraped 117 users this round
# Got 196 reivews
# 382846 reviews are now in the bag, so to speak
# 2024-04-02 00:24:01
#
# Scraped 106 users this round
# Got 199 reivews
# 383045 reviews are now in the bag, so to speak
# 2024-04-02 00:27:43
#
# Scraped 112 users this round
# Got 152 reivews
# 383197 reviews are now in the bag, so to speak
# 2024-04-02 00:31:42
#
# Scraped 110 users this round
# Got 207 reivews
# 383404 reviews are now in the bag, so to speak
# 2024-04-02 00:35:21
#
# Scraped 119 users this round
# Got 205 reivews
# 383609 reviews are now in the bag, so to speak
# 2024-04-02 00:39:29
#
# Scraped 108 users this round
# Got 245 reivews
# 383854 reviews are now in the bag, so to speak
# 2024-04-02 00:43:28
#
# Scraped 110 users this round
# Got 213 reivews
# 384067 reviews are now in the bag, so to speak
# 2024-04-02 00:47:22
#
# Scraped 108 users this round
# Got 198 reivews
# 384265 reviews are now in the bag, so to speak
# 2024-04-02 00:51:20
#
# Scraped 109 users this round
# Got 180 reivews
# 384445 reviews are now in the bag, so to speak
# 2024-04-02 00:55:26
#
# Scraped 83 users this round
# Got 218 reivews
# 384663 reviews are now in the bag, so to speak
# 2024-04-02 00:58:11
#
# Scraped 116 users this round
# Got 197 reivews
# 384860 reviews are now in the bag, so to speak
# 2024-04-02 01:02:27
#
# Scraped 105 users this round
# Got 169 reivews
# 385029 reviews are now in the bag, so to speak
# 2024-04-02 01:06:13
#
# Scraped 101 users this round
# Got 188 reivews
# 385217 reviews are now in the bag, so to speak
# 2024-04-02 01:09:44
#
# Scraped 86 users this round
# Got 195 reivews
# 385412 reviews are now in the bag, so to speak
# 2024-04-02 01:12:43
#
# Scraped 95 users this round
# Got 223 reivews
# 385635 reviews are now in the bag, so to speak
# 2024-04-02 01:16:03
#
# Scraped 113 users this round
# Got 167 reivews
# 385802 reviews are now in the bag, so to speak
# 2024-04-02 01:19:57
#
# Scraped 104 users this round
# Got 191 reivews
# 385993 reviews are now in the bag, so to speak
# 2024-04-02 01:23:32
#
# Scraped 86 users this round
# Got 175 reivews
# ...
# 2024-04-02 23:32:52
#
# Scraped 105 users this round
# Got 191 reivews
# 446636 reviews are now in the bag, so to speak
# 2024-04-02 23:39:46
#
# Scraped 111 users this round
# Got 145 reivews
# 446781 reviews are now in the bag, so to speak
# 2024-04-02 23:44:06
#
# Scraped 94 users this round
# Got 179 reivews
# 446960 reviews are now in the bag, so to speak
# 2024-04-02 23:47:01
#
# Scraped 124 users this round
# Got 217 reivews
# 447177 reviews are now in the bag, so to speak
# 2024-04-02 23:51:14
#
# Scraped 119 users this round
# Got 212 reivews
# 447389 reviews are now in the bag, so to speak
# 2024-04-02 23:55:27
#
# Scraped 105 users this round
# Got 159 reivews
# 447548 reviews are now in the bag, so to speak
# 2024-04-02 23:59:19
#
# Scraped 122 users this round
# Got 184 reivews
# 447732 reviews are now in the bag, so to speak
# 2024-04-03 00:03:44
#
# Scraped 105 users this round
# Got 195 reivews
# 447927 reviews are now in the bag, so to speak
# 2024-04-03 00:07:25
#
# Scraped 103 users this round
# Got 189 reivews
# 448116 reviews are now in the bag, so to speak
# 2024-04-03 00:10:58
#
# Scraped 119 users this round
# Got 168 reivews
# 448284 reviews are now in the bag, so to speak
# 2024-04-03 00:15:15
#
# Scraped 97 users this round
# Got 201 reivews
# 448485 reviews are now in the bag, so to speak
# 2024-04-03 00:18:30
#
# Scraped 97 users this round
# Got 143 reivews
# 448628 reviews are now in the bag, so to speak
# 2024-04-03 00:21:38
#
# Scraped 117 users this round
# Got 175 reivews
# 448803 reviews are now in the bag, so to speak
# 2024-04-03 00:25:43
#
# Scraped 123 users this round
# Got 156 reivews
# 448959 reviews are now in the bag, so to speak
# 2024-04-03 00:30:01
#
# Scraped 108 users this round
# Got 206 reivews
# 449165 reviews are now in the bag, so to speak
# 2024-04-03 00:33:58
#
# Scraped 90 users this round
# Got 186 reivews
# 449351 reviews are now in the bag, so to speak
# 2024-04-03 00:37:01
#
# Scraped 100 users this round
# Got 150 reivews
# 449501 reviews are now in the bag, so to speak
# 2024-04-03 00:40:28
#
# Scraped 108 users this round
# Got 175 reivews
# 449676 reviews are now in the bag, so to speak
# 2024-04-03 00:43:56
#
# Scraped 117 users this round
# Got 187 reivews
# 449863 reviews are now in the bag, so to speak
# 2024-04-03 00:48:08
#
# Scraped 113 users this round
# Got 178 reivews
# 450041 reviews are now in the bag, so to speak
# 2024-04-03 00:52:01
#
# Scraped 111 users this round
# Got 168 reivews
# 450209 reviews are now in the bag, so to speak
# 2024-04-03 00:55:40
#
# Scraped 117 users this round
# Got 170 reivews
# 450379 reviews are now in the bag, so to speak
# 2024-04-03 00:59:30
#
# Scraped 125 users this round
# Got 184 reivews
# 450563 reviews are now in the bag, so to speak
# 2024-04-03 01:03:45
#
# Scraped 130 users this round
# Got 205 reivews
# 450768 reviews are now in the bag, so to speak
# 2024-04-03 01:08:45
#
# Scraped 99 users this round
# Got 178 reivews
# 450946 reviews are now in the bag, so to speak
# 2024-04-03 01:11:59
#
# Scraped 118 users this round
# Got 213 reivews
# 451159 reviews are now in the bag, so to speak
# 2024-04-03 01:15:55
#
# Scraped 94 users this round
# Got 210 reivews
# 451369 reviews are now in the bag, so to speak
# 2024-04-03 01:19:05
#
# Scraped 98 users this round
# Got 176 reivews
# 451545 reviews are now in the bag, so to speak
# 2024-04-03 01:22:27
#
# Scraped 100 users this round
# Got 152 reivews
# 451697 reviews are now in the bag, so to speak
# 2024-04-03 01:25:35
#
# Scraped 116 users this round
# Got 226 reivews
# 451923 reviews are now in the bag, so to speak
# 2024-04-03 01:29:31
#
# Scraped 117 users this round
# Got 195 reivews
# 452118 reviews are now in the bag, so to speak
# 2024-04-03 01:33:27
#
# Scraped 105 users this round
# Got 163 reivews
# 452281 reviews are now in the bag, so to speak
# 2024-04-03 01:36:54
#
# Scraped 130 users this round
# Got 226 reivews
# 452507 reviews are now in the bag, so to speak
# 2024-04-03 01:41:29
#
# Scraped 109 users this round
# Got 204 reivews
# 452711 reviews are now in the bag, so to speak
# 2024-04-03 01:45:17
#
# Scraped 118 users this round
# Got 167 reivews
# 452878 reviews are now in the bag, so to speak
# 2024-04-03 01:49:05
#
# Scraped 103 users this round
# Got 169 reivews
# 453047 reviews are now in the bag, so to speak
# 2024-04-03 01:52:33
#
# Scraped 131 users this round
# Got 193 reivews
# 453240 reviews are now in the bag, so to speak
# 2024-04-03 01:57:01
#
# Scraped 106 users this round
# Got 165 reivews
# 453405 reviews are now in the bag, so to speak
# 2024-04-03 02:00:38
#
# Scraped 114 users this round
# Got 192 reivews
# 453597 reviews are now in the bag, so to speak
# 2024-04-03 02:04:25
#
# Scraped 124 users this round
# Got 168 reivews
# 453765 reviews are now in the bag, so to speak
# 2024-04-03 02:08:45
#
# Scraped 102 users this round
# Got 152 reivews
# 453917 reviews are now in the bag, so to speak
# 2024-04-03 02:11:59
#
# Scraped 113 users this round
# Got 190 reivews
# 454107 reviews are now in the bag, so to speak
# 2024-04-03 02:15:46
#
# Scraped 110 users this round
# Got 200 reivews
# 454307 reviews are now in the bag, so to speak
# 2024-04-03 02:19:25
#
# Scraped 116 users this round
# Got 177 reivews
# 454484 reviews are now in the bag, so to speak
# 2024-04-03 02:23:19
#
# Scraped 99 users this round
# Got 197 reivews
# 454681 reviews are now in the bag, so to speak
# 2024-04-03 02:26:26
#
# Scraped 105 users this round
# Got 207 reivews
# 454888 reviews are now in the bag, so to speak
# 2024-04-03 02:29:49
#
# Scraped 110 users this round
# Got 199 reivews
# 455087 reviews are now in the bag, so to speak
# 2024-04-03 02:33:30
#
# Scraped 109 users this round
# Got 183 reivews
# 455270 reviews are now in the bag, so to speak
# 2024-04-03 02:37:16
#
# Scraped 103 users this round
# Got 190 reivews
# 455460 reviews are now in the bag, so to speak
# 2024-04-03 02:40:38
#
# Scraped 102 users this round
# Got 158 reivews
# 455618 reviews are now in the bag, so to speak
# 2024-04-03 02:44:37
#
# Scraped 103 users this round
# Got 186 reivews
# 455804 reviews are now in the bag, so to speak
# 2024-04-03 02:48:06
#
# Scraped 107 users this round
# Got 181 reivews
# 455985 reviews are now in the bag, so to speak
# 2024-04-03 02:51:28
#
# Scraped 98 users this round
# Got 242 reivews
# 456227 reviews are now in the bag, so to speak
# 2024-04-03 02:54:39
#
# Scraped 89 users this round
# Got 204 reivews
# 456431 reviews are now in the bag, so to speak
# 2024-04-03 02:57:21
#
# Scraped 102 users this round
# Got 168 reivews
# 456599 reviews are now in the bag, so to speak
# 2024-04-03 03:00:40
#
# Scraped 96 users this round
# Got 209 reivews
# 456808 reviews are now in the bag, so to speak
# 2024-04-03 03:03:47
#
# Scraped 126 users this round
# Got 118 reivews
# 456926 reviews are now in the bag, so to speak
# 2024-04-03 03:07:44
#
# Scraped 117 users this round
# Got 179 reivews
# 457105 reviews are now in the bag, so to speak
# 2024-04-03 03:11:41
#
# Scraped 115 users this round
# Got 202 reivews
# 457307 reviews are now in the bag, so to speak
# 2024-04-03 03:15:39
#
# Scraped 84 users this round
# Got 152 reivews
# 457459 reviews are now in the bag, so to speak
# 2024-04-03 03:18:19
#
# Scraped 112 users this round
# Got 193 reivews
# 457652 reviews are now in the bag, so to speak
# 2024-04-03 03:22:00
#
# Scraped 122 users this round
# Got 249 reivews
# 457901 reviews are now in the bag, so to speak
# 2024-04-03 03:26:35
#
# Scraped 104 users this round
# Got 202 reivews
# 458103 reviews are now in the bag, so to speak
# 2024-04-03 03:30:09
#
# Scraped 115 users this round
# Got 239 reivews
# 458342 reviews are now in the bag, so to speak
# 2024-04-03 03:33:57
#
# Scraped 115 users this round
# Got 213 reivews
# 458555 reviews are now in the bag, so to speak
# 2024-04-03 03:37:51
#
# Scraped 121 users this round
# Got 187 reivews
# 458742 reviews are now in the bag, so to speak
# 2024-04-03 03:42:08
#
# Scraped 112 users this round
# Got 202 reivews
# 458944 reviews are now in the bag, so to speak
# 2024-04-03 03:45:47
#
# Scraped 93 users this round
# Got 194 reivews
# 459138 reviews are now in the bag, so to speak
# 2024-04-03 03:48:35
#
# Scraped 90 users this round
# Got 171 reivews
# 459309 reviews are now in the bag, so to speak
# 2024-04-03 03:51:22
#
# Scraped 115 users this round
# Got 153 reivews
# 459462 reviews are now in the bag, so to speak
# 2024-04-03 03:55:09
#
# Scraped 103 users this round
# Got 173 reivews
# 459635 reviews are now in the bag, so to speak
# 2024-04-03 03:58:23
#
# Scraped 103 users this round
# Got 167 reivews
# 459802 reviews are now in the bag, so to speak
# 2024-04-03 04:01:51
#
# Scraped 135 users this round
# Got 205 reivews
# 460007 reviews are now in the bag, so to speak
# 2024-04-03 04:06:28
#
# Scraped 127 users this round
# Got 178 reivews
# 460185 reviews are now in the bag, so to speak
# 2024-04-03 04:10:45
#
# Scraped 104 users this round
# Got 189 reivews
# 460374 reviews are now in the bag, so to speak
# 2024-04-03 04:14:33
#
# Scraped 98 users this round
# Got 217 reivews
# 460591 reviews are now in the bag, so to speak
# 2024-04-03 04:18:04
#
# Scraped 100 users this round
# Got 186 reivews
# 460777 reviews are now in the bag, so to speak
# 2024-04-03 04:21:14
#
# Scraped 119 users this round
# Got 185 reivews
# 460962 reviews are now in the bag, so to speak
# 2024-04-03 04:25:26
#
# Scraped 93 users this round
# Got 150 reivews
# 461112 reviews are now in the bag, so to speak
# 2024-04-03 04:28:17
#
# Scraped 105 users this round
# Got 185 reivews
# 461297 reviews are now in the bag, so to speak
# 2024-04-03 04:32:00
#
# Scraped 113 users this round
# Got 182 reivews
# 461479 reviews are now in the bag, so to speak
# 2024-04-03 04:35:43
#
# Scraped 102 users this round
# Got 152 reivews
# 461631 reviews are now in the bag, so to speak
# 2024-04-03 04:39:00
#
# Scraped 112 users this round
# Got 167 reivews
# 461798 reviews are now in the bag, so to speak
# 2024-04-03 04:42:44
#
# Scraped 105 users this round
# Got 188 reivews
# 461986 reviews are now in the bag, so to speak
# 2024-04-03 04:46:11
#
# Scraped 95 users this round
# Got 168 reivews
# 462154 reviews are now in the bag, so to speak
# 2024-04-03 04:49:05
#
# Scraped 106 users this round
# Got 153 reivews
# 462307 reviews are now in the bag, so to speak
# 2024-04-03 04:52:29
#
# Scraped 139 users this round
# Got 185 reivews
# 462492 reviews are now in the bag, so to speak
# 2024-04-03 04:57:08
#
# Scraped 98 users this round
# Got 147 reivews
# 462639 reviews are now in the bag, so to speak
# 2024-04-03 05:00:06
#
# Scraped 105 users this round
# Got 195 reivews
# 462834 reviews are now in the bag, so to speak
# 2024-04-03 05:03:25
#
# Scraped 106 users this round
# Got 145 reivews
# 462979 reviews are now in the bag, so to speak
# 2024-04-03 05:06:52
#
# Scraped 106 users this round
# Got 181 reivews
# 463160 reviews are now in the bag, so to speak
# 2024-04-03 05:10:15
#
# Scraped 113 users this round
# Got 216 reivews
# 463376 reviews are now in the bag, so to speak
# 2024-04-03 05:14:07
#
# Scraped 111 users this round
# Got 205 reivews
# 463581 reviews are now in the bag, so to speak
# 2024-04-03 05:17:40
#
# Scraped 122 users this round
# Got 207 reivews
# 463788 reviews are now in the bag, so to speak
# 2024-04-03 05:21:42
#
# Scraped 109 users this round
# Got 191 reivews
# 463979 reviews are now in the bag, so to speak
# 2024-04-03 05:25:23
#
# Scraped 113 users this round
# Got 190 reivews
# 464169 reviews are now in the bag, so to speak
# 2024-04-03 05:29:05
#
# Scraped 110 users this round
# Got 172 reivews
# 464341 reviews are now in the bag, so to speak
# 2024-04-03 05:32:45
#
# Scraped 113 users this round
# Got 203 reivews
# 464544 reviews are now in the bag, so to speak
# 2024-04-03 05:36:47
#
# Scraped 122 users this round
# Got 152 reivews
# 464696 reviews are now in the bag, so to speak
# 2024-04-03 05:40:48
#
# Scraped 98 users this round
# Got 161 reivews
# 464857 reviews are now in the bag, so to speak
# 2024-04-03 05:43:57
#
# Scraped 118 users this round
# Got 202 reivews
# 465059 reviews are now in the bag, so to speak
# 2024-04-03 05:47:52
#
# Scraped 97 users this round
# Got 208 reivews
# 465267 reviews are now in the bag, so to speak
# 2024-04-03 05:51:22
#
# Scraped 112 users this round
# Got 192 reivews
# 465459 reviews are now in the bag, so to speak
# 2024-04-03 05:54:58
#
# Scraped 114 users this round
# Got 130 reivews
# 465589 reviews are now in the bag, so to speak
# 2024-04-03 05:58:34
#
# Scraped 112 users this round
# Got 179 reivews
# 465768 reviews are now in the bag, so to speak
# 2024-04-03 06:02:42
#
# Scraped 104 users this round
# Got 153 reivews
# 465921 reviews are now in the bag, so to speak
# 2024-04-03 06:06:09
#
# Scraped 100 users this round
# Got 178 reivews
# 466099 reviews are now in the bag, so to speak
# 2024-04-03 06:09:26
#
# Scraped 103 users this round
# Got 158 reivews
# 466257 reviews are now in the bag, so to speak
# 2024-04-03 06:12:58
#
# Scraped 107 users this round
# Got 209 reivews
# 466466 reviews are now in the bag, so to speak
# 2024-04-03 06:16:26
#
# Scraped 103 users this round
# Got 159 reivews
# 466625 reviews are now in the bag, so to speak
# 2024-04-03 06:19:50
#
# Scraped 103 users this round
# Got 144 reivews
# 466769 reviews are now in the bag, so to speak
# 2024-04-03 06:23:09
#
# Scraped 96 users this round
# Got 203 reivews
# 466972 reviews are now in the bag, so to speak
# 2024-04-03 06:26:13
#
# Scraped 124 users this round
# Got 194 reivews
# 467166 reviews are now in the bag, so to speak
# 2024-04-03 06:30:31
#
# Scraped 90 users this round
# Got 173 reivews
# 467339 reviews are now in the bag, so to speak
# 2024-04-03 06:33:41
#
# Scraped 130 users this round
# Got 213 reivews
# 467552 reviews are now in the bag, so to speak
# 2024-04-03 06:38:25
#
# Scraped 94 users this round
# Got 192 reivews
# 467744 reviews are now in the bag, so to speak
# 2024-04-03 06:41:36
#
# Scraped 135 users this round
# Got 254 reivews
# 467998 reviews are now in the bag, so to speak
# 2024-04-03 06:46:30
#
# Scraped 117 users this round
# Got 200 reivews
# 468198 reviews are now in the bag, so to speak
# 2024-04-03 06:50:14
#
# Scraped 104 users this round
# Got 188 reivews
# 468386 reviews are now in the bag, so to speak
# 2024-04-03 06:53:43
#
# Scraped 99 users this round
# Got 216 reivews
# 468602 reviews are now in the bag, so to speak
# 2024-04-03 06:56:59
#
# Scraped 120 users this round
# Got 154 reivews
# 468756 reviews are now in the bag, so to speak
# 2024-04-03 07:01:42
#
# Scraped 128 users this round
# Got 191 reivews
# 468947 reviews are now in the bag, so to speak
# 2024-04-03 07:06:07
#
# Scraped 121 users this round
# Got 196 reivews
# 469143 reviews are now in the bag, so to speak
# 2024-04-03 07:10:15
#
# Scraped 114 users this round
# Got 162 reivews
# 469305 reviews are now in the bag, so to speak
# 2024-04-03 07:14:12
#
# Scraped 100 users this round
# Got 192 reivews
# 469497 reviews are now in the bag, so to speak
# 2024-04-03 07:17:31
#
# Scraped 112 users this round
# Got 236 reivews
# 469733 reviews are now in the bag, so to speak
# 2024-04-03 07:21:23
#
# Scraped 115 users this round
# Got 174 reivews
# 469907 reviews are now in the bag, so to speak
# 2024-04-03 07:25:36
#
# Scraped 98 users this round
# Got 197 reivews
# 470104 reviews are now in the bag, so to speak
# 2024-04-03 07:29:19
#
# Scraped 131 users this round
# Got 172 reivews
# 470276 reviews are now in the bag, so to speak
# 2024-04-03 07:34:23
#
# Scraped 91 users this round
# Got 176 reivews
# 470452 reviews are now in the bag, so to speak
# 2024-04-03 07:37:29
#
# Scraped 116 users this round
# Got 154 reivews
# 470606 reviews are now in the bag, so to speak
# 2024-04-03 07:41:15
#
# Scraped 102 users this round
# Got 179 reivews
# 470785 reviews are now in the bag, so to speak
# 2024-04-03 07:44:40
#
# Scraped 105 users this round
# Got 184 reivews
# 470969 reviews are now in the bag, so to speak
# 2024-04-03 07:48:38
#
# Scraped 100 users this round
# Got 234 reivews
# 471203 reviews are now in the bag, so to speak
# 2024-04-03 07:51:58
#
# Scraped 87 users this round
# Got 146 reivews
# 471349 reviews are now in the bag, so to speak
# 2024-04-03 07:54:50
#
# Scraped 112 users this round
# Got 168 reivews
# 471517 reviews are now in the bag, so to speak
# 2024-04-03 07:58:39
#
# Scraped 112 users this round
# Got 227 reivews
# 471744 reviews are now in the bag, so to speak
# 2024-04-03 08:02:44
#
# Scraped 98 users this round
# Got 199 reivews
# 471943 reviews are now in the bag, so to speak
# 2024-04-03 08:06:21
#
# Scraped 118 users this round
# Got 175 reivews
# 472118 reviews are now in the bag, so to speak
# 2024-04-03 08:10:47
#
# Scraped 109 users this round
# Got 166 reivews
# 472284 reviews are now in the bag, so to speak
# 2024-04-03 08:15:07
#
# Scraped 117 users this round
# Got 226 reivews
# 472510 reviews are now in the bag, so to speak
# 2024-04-03 08:20:37
#
# Unable to parse review blocks.
