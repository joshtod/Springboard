# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 3

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')


# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 100 users this round
# Got 185 reivews
# 158970 reviews are now in the bag, so to speak
# 2024-03-28 15:35:10
#
# Scraped 102 users this round
# Got 172 reivews
# 159142 reviews are now in the bag, so to speak
# 2024-03-28 15:38:27
#
# Scraped 100 users this round
# Got 165 reivews
# 159307 reviews are now in the bag, so to speak
# 2024-03-28 15:41:41
#
# Scraped 129 users this round
# Got 211 reivews
# 159518 reviews are now in the bag, so to speak
# 2024-03-28 15:45:49
#
# Scraped 110 users this round
# Got 165 reivews
# 159683 reviews are now in the bag, so to speak
# 2024-03-28 15:49:16
#
# Scraped 94 users this round
# Got 150 reivews
# 159833 reviews are now in the bag, so to speak
# 2024-03-28 15:52:07
#
# Scraped 96 users this round
# Got 203 reivews
# 160036 reviews are now in the bag, so to speak
# 2024-03-28 15:55:15
#
# Scraped 112 users this round
# Got 199 reivews
# 160235 reviews are now in the bag, so to speak
# 2024-03-28 15:58:54
#
# Scraped 109 users this round
# Got 174 reivews
# 160409 reviews are now in the bag, so to speak
# 2024-03-28 16:02:30
#
# Scraped 143 users this round
# Got 155 reivews
# 160564 reviews are now in the bag, so to speak
# 2024-03-28 16:07:22
#
# Scraped 107 users this round
# Got 175 reivews
# 160739 reviews are now in the bag, so to speak
# 2024-03-28 16:11:00
#
# Scraped 103 users this round
# Got 189 reivews
# 160928 reviews are now in the bag, so to speak
# 2024-03-28 16:14:19
#
# Scraped 104 users this round
# Got 192 reivews
# 161120 reviews are now in the bag, so to speak
# 2024-03-28 16:17:42
#
# Scraped 126 users this round
# Got 183 reivews
# 161303 reviews are now in the bag, so to speak
# 2024-03-28 16:21:40
#
# Scraped 107 users this round
# Got 204 reivews
# 161507 reviews are now in the bag, so to speak
# 2024-03-28 16:24:59
#
# Scraped 132 users this round
# Got 181 reivews
# 161688 reviews are now in the bag, so to speak
# 2024-03-28 16:29:15
#
# Scraped 96 users this round
# Got 213 reivews
# 161901 reviews are now in the bag, so to speak
# 2024-03-28 16:32:25
#
# Scraped 95 users this round
# Got 172 reivews
# 162073 reviews are now in the bag, so to speak
# 2024-03-28 16:35:27
#
# Scraped 108 users this round
# Got 166 reivews
# 162239 reviews are now in the bag, so to speak
# 2024-03-28 16:38:57
#
# Scraped 106 users this round
# Got 189 reivews
# 162428 reviews are now in the bag, so to speak
# 2024-03-28 16:42:19
#
# Scraped 111 users this round
# Got 251 reivews
# 162679 reviews are now in the bag, so to speak
# 2024-03-28 16:45:47
#
# Scraped 111 users this round
# Got 166 reivews
# 162845 reviews are now in the bag, so to speak
# 2024-03-28 16:49:19
#
# Scraped 105 users this round
# Got 196 reivews
# 163041 reviews are now in the bag, so to speak
# 2024-03-28 16:52:33
#
# Scraped 99 users this round
# Got 203 reivews
# 163244 reviews are now in the bag, so to speak
# 2024-03-28 16:55:43
#
# Scraped 82 users this round
# Got 188 reivews
# 163432 reviews are now in the bag, so to speak
# 2024-03-28 16:58:11
#
# Scraped 110 users this round
# Got 196 reivews
# 163628 reviews are now in the bag, so to speak
# 2024-03-28 17:01:36
#
# Scraped 102 users this round
# Got 234 reivews
# 163862 reviews are now in the bag, so to speak
# 2024-03-28 17:04:55
#
# Scraped 116 users this round
# Got 216 reivews
# 164078 reviews are now in the bag, so to speak
# 2024-03-28 17:08:34
#
# Scraped 110 users this round
# Got 185 reivews
# 164263 reviews are now in the bag, so to speak
# 2024-03-28 17:12:07
#
# Scraped 102 users this round
# Got 167 reivews
# 164430 reviews are now in the bag, so to speak
# 2024-03-28 17:15:24
#
# Scraped 134 users this round
# Got 197 reivews
# 164627 reviews are now in the bag, so to speak
# 2024-03-28 17:19:54
#
# Scraped 108 users this round
# Got 172 reivews
# 164799 reviews are now in the bag, so to speak
# 2024-03-28 17:23:15
#
# Scraped 113 users this round
# Got 209 reivews
# 165008 reviews are now in the bag, so to speak
# 2024-03-28 17:26:58
#
# Scraped 115 users this round
# Got 217 reivews
# 165225 reviews are now in the bag, so to speak
# 2024-03-28 17:30:43
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 127 users this round
# Got 227 reivews
# 165452 reviews are now in the bag, so to speak
# 2024-03-28 17:34:49
#
# Scraped 99 users this round
# Got 189 reivews
# 165641 reviews are now in the bag, so to speak
# 2024-03-28 17:37:54
#
# Scraped 112 users this round
# Got 191 reivews
# 165832 reviews are now in the bag, so to speak
# 2024-03-28 17:41:20
#
# Scraped 113 users this round
# Got 226 reivews
# 166058 reviews are now in the bag, so to speak
# 2024-03-28 17:44:55
#
# Scraped 100 users this round
# Got 173 reivews
# 166231 reviews are now in the bag, so to speak
# 2024-03-28 17:47:56
#
# Scraped 110 users this round
# Got 182 reivews
# 166413 reviews are now in the bag, so to speak
# 2024-03-28 17:51:29
#
# Scraped 104 users this round
# Got 206 reivews
# 166619 reviews are now in the bag, so to speak
# 2024-03-28 17:54:48
#
# Scraped 103 users this round
# Got 161 reivews
# 166780 reviews are now in the bag, so to speak
# 2024-03-28 17:58:06
#
# Scraped 137 users this round
# Got 193 reivews
# 166973 reviews are now in the bag, so to speak
# 2024-03-28 18:02:37
#
# Scraped 105 users this round
# Got 159 reivews
# 167132 reviews are now in the bag, so to speak
# 2024-03-28 18:05:53
#
# Scraped 110 users this round
# Got 172 reivews
# 167304 reviews are now in the bag, so to speak
# 2024-03-28 18:09:39
#
# Scraped 138 users this round
# Got 198 reivews
# 167502 reviews are now in the bag, so to speak
# 2024-03-28 18:14:21
#
# Scraped 103 users this round
# Got 196 reivews
# 167698 reviews are now in the bag, so to speak
# 2024-03-28 18:17:35
#
# Scraped 95 users this round
# Got 168 reivews
# 167866 reviews are now in the bag, so to speak
# 2024-03-28 18:20:29
#
# Scraped 105 users this round
# Got 190 reivews
# 168056 reviews are now in the bag, so to speak
# 2024-03-28 18:23:43
#
# Scraped 91 users this round
# Got 167 reivews
# 168223 reviews are now in the bag, so to speak
# 2024-03-28 18:26:25
#
# Scraped 103 users this round
# Got 200 reivews
# 168423 reviews are now in the bag, so to speak
# 2024-03-28 18:29:37
#
# Scraped 117 users this round
# Got 228 reivews
# 168651 reviews are now in the bag, so to speak
# 2024-03-28 18:33:22
#
# Scraped 99 users this round
# Got 176 reivews
# 168827 reviews are now in the bag, so to speak
# 2024-03-28 18:36:32
#
# Scraped 111 users this round
# Got 189 reivews
# 169016 reviews are now in the bag, so to speak
# 2024-03-28 18:40:03
#
# Scraped 113 users this round
# Got 154 reivews
# 169170 reviews are now in the bag, so to speak
# 2024-03-28 18:43:37
#
# Scraped 104 users this round
# Got 194 reivews
# 169364 reviews are now in the bag, so to speak
# 2024-03-28 18:46:41
#
# Scraped 128 users this round
# Got 235 reivews
# 169599 reviews are now in the bag, so to speak
# 2024-03-28 18:50:38
#
# Scraped 117 users this round
# Got 122 reivews
# 169721 reviews are now in the bag, so to speak
# 2024-03-28 18:54:04
#
# Scraped 121 users this round
# Got 197 reivews
# 169918 reviews are now in the bag, so to speak
# 2024-03-28 18:57:54
#
# Scraped 112 users this round
# Got 197 reivews
# 170115 reviews are now in the bag, so to speak
# 2024-03-28 19:01:20
#
# Scraped 106 users this round
# Got 193 reivews
# 170308 reviews are now in the bag, so to speak
# 2024-03-28 19:04:39
#
# Scraped 112 users this round
# Got 171 reivews
# 170479 reviews are now in the bag, so to speak
# 2024-03-28 19:08:17
#
# Scraped 119 users this round
# Got 186 reivews
# 170665 reviews are now in the bag, so to speak
# 2024-03-28 19:12:04
#
# Scraped 109 users this round
# Got 192 reivews
# 170857 reviews are now in the bag, so to speak
# 2024-03-28 19:15:42
#
# Scraped 110 users this round
# Got 222 reivews
# 171079 reviews are now in the bag, so to speak
# 2024-03-28 19:19:22
#
# Scraped 111 users this round
# Got 196 reivews
# 171275 reviews are now in the bag, so to speak
# 2024-03-28 19:23:03
#
# Scraped 110 users this round
# Got 175 reivews
# 171450 reviews are now in the bag, so to speak
# 2024-03-28 19:26:27
#
# Scraped 106 users this round
# Got 212 reivews
# 171662 reviews are now in the bag, so to speak
# 2024-03-28 19:29:49
#
# Scraped 93 users this round
# Got 200 reivews
# 171862 reviews are now in the bag, so to speak
# 2024-03-28 19:32:32
#
# Scraped 103 users this round
# Got 196 reivews
# 172058 reviews are now in the bag, so to speak
# 2024-03-28 19:35:56
#
# Scraped 108 users this round
# Got 232 reivews
# 172290 reviews are now in the bag, so to speak
# 2024-03-28 19:39:35
#
# Scraped 112 users this round
# Got 201 reivews
# 172491 reviews are now in the bag, so to speak
# 2024-03-28 19:43:09
#
# Scraped 108 users this round
# Got 197 reivews
# 172688 reviews are now in the bag, so to speak
# 2024-03-28 19:46:59
#
# Scraped 114 users this round
# Got 196 reivews
# 172884 reviews are now in the bag, so to speak
# 2024-03-28 19:50:43
#
# Scraped 114 users this round
# Got 174 reivews
# 173058 reviews are now in the bag, so to speak
# 2024-03-28 19:54:21
#
# Scraped 122 users this round
# Got 190 reivews
# 173248 reviews are now in the bag, so to speak
# 2024-03-28 19:58:31
#
# Scraped 118 users this round
# Got 175 reivews
# 173423 reviews are now in the bag, so to speak
# 2024-03-28 20:02:19
#
# Scraped 108 users this round
# Got 159 reivews
# 173582 reviews are now in the bag, so to speak
# 2024-03-28 20:05:40
#
# Scraped 119 users this round
# Got 160 reivews
# 173742 reviews are now in the bag, so to speak
# 2024-03-28 20:09:20
#
# Scraped 109 users this round
# Got 206 reivews
# 173948 reviews are now in the bag, so to speak
# 2024-03-28 20:12:40
#
# Scraped 92 users this round
# Got 192 reivews
# 174140 reviews are now in the bag, so to speak
# 2024-03-28 20:15:25
#
# Scraped 107 users this round
# Got 178 reivews
# 174318 reviews are now in the bag, so to speak
# 2024-03-28 20:18:48
#
# Scraped 124 users this round
# Got 235 reivews
# 174553 reviews are now in the bag, so to speak
# 2024-03-28 20:22:53
#
# Scraped 108 users this round
# Got 235 reivews
# 174788 reviews are now in the bag, so to speak
# 2024-03-28 20:26:18
#
# Scraped 125 users this round
# Got 174 reivews
# 174962 reviews are now in the bag, so to speak
# 2024-03-28 20:30:36
#
# Scraped 93 users this round
# Got 185 reivews
# 175147 reviews are now in the bag, so to speak
# 2024-03-28 20:33:38
#
# Scraped 110 users this round
# Got 221 reivews
# 175368 reviews are now in the bag, so to speak
# 2024-03-28 20:37:17
#
# Scraped 119 users this round
# Got 199 reivews
# 175567 reviews are now in the bag, so to speak
# 2024-03-28 20:41:23
#
# Scraped 80 users this round
# Got 163 reivews
# 175730 reviews are now in the bag, so to speak
# 2024-03-28 20:43:51
#
# Scraped 107 users this round
# Got 221 reivews
# 175951 reviews are now in the bag, so to speak
# 2024-03-28 20:47:18
#
# Scraped 123 users this round
# Got 196 reivews
# 176147 reviews are now in the bag, so to speak
# 2024-03-28 20:51:31
#
# Scraped 94 users this round
# Got 180 reivews
# 176327 reviews are now in the bag, so to speak
# 2024-03-28 20:54:32
#
# Scraped 110 users this round
# Got 229 reivews
# 176556 reviews are now in the bag, so to speak
# 2024-03-28 20:58:15
#
# Scraped 89 users this round
# Got 192 reivews
# 176748 reviews are now in the bag, so to speak
# 2024-03-28 21:00:57
#
# Scraped 91 users this round
# Got 208 reivews
# 176956 reviews are now in the bag, so to speak
# 2024-03-28 21:03:51
#
# Scraped 107 users this round
# Got 216 reivews
# 177172 reviews are now in the bag, so to speak
# 2024-03-28 21:07:18
#
# Scraped 105 users this round
# Got 197 reivews
# 177369 reviews are now in the bag, so to speak
# 2024-03-28 21:10:48
#
# Scraped 101 users this round
# Got 192 reivews
# 177561 reviews are now in the bag, so to speak
# 2024-03-28 21:13:56
#
# Scraped 124 users this round
# Got 233 reivews
# 177794 reviews are now in the bag, so to speak
# 2024-03-28 21:17:49
#
# Scraped 112 users this round
# Got 164 reivews
# 177958 reviews are now in the bag, so to speak
# 2024-03-28 21:21:24
#
# Scraped 113 users this round
# Got 212 reivews
# 178170 reviews are now in the bag, so to speak
# 2024-03-28 21:24:57
#
# Scraped 90 users this round
# Got 220 reivews
# 178390 reviews are now in the bag, so to speak
# 2024-03-28 21:27:59
#
# Scraped 112 users this round
# Got 183 reivews
# 178573 reviews are now in the bag, so to speak
# 2024-03-28 21:31:32
#
# Scraped 111 users this round
# Got 185 reivews
# 178758 reviews are now in the bag, so to speak
# 2024-03-28 21:35:00
#
# Scraped 117 users this round
# Got 180 reivews
# 178938 reviews are now in the bag, so to speak
# 2024-03-28 21:38:44
#
# Scraped 101 users this round
# Got 242 reivews
# 179180 reviews are now in the bag, so to speak
# 2024-03-28 21:42:04
#
# Scraped 122 users this round
# Got 190 reivews
# 179370 reviews are now in the bag, so to speak
# 2024-03-28 21:46:06
#
# Scraped 119 users this round
# Got 245 reivews
# 179615 reviews are now in the bag, so to speak
# 2024-03-28 21:50:00
#
# Scraped 96 users this round
# Got 202 reivews
# 179817 reviews are now in the bag, so to speak
# 2024-03-28 21:53:05
#
# Scraped 89 users this round
# Got 209 reivews
# 180026 reviews are now in the bag, so to speak
# 2024-03-28 21:55:54
#
# Scraped 112 users this round
# Got 207 reivews
# 180233 reviews are now in the bag, so to speak
# 2024-03-28 21:59:46
#
# Scraped 105 users this round
# Got 185 reivews
# 180418 reviews are now in the bag, so to speak
# 2024-03-28 22:03:42
#
# Scraped 114 users this round
# Got 181 reivews
# 180599 reviews are now in the bag, so to speak
# 2024-03-28 22:07:36
#
# Scraped 121 users this round
# Got 204 reivews
# 180803 reviews are now in the bag, so to speak
# 2024-03-28 22:12:18
#
# Scraped 109 users this round
# Got 181 reivews
# 180984 reviews are now in the bag, so to speak
# 2024-03-28 22:16:24
#
# Scraped 114 users this round
# Got 148 reivews
# 181132 reviews are now in the bag, so to speak
# 2024-03-28 22:20:38
#
# Scraped 116 users this round
# Got 218 reivews
# 181350 reviews are now in the bag, so to speak
# 2024-03-28 22:25:00
#
# Scraped 104 users this round
# Got 177 reivews
# 181527 reviews are now in the bag, so to speak
# 2024-03-28 22:28:55
#
# Scraped 99 users this round
# Got 197 reivews
# 181724 reviews are now in the bag, so to speak
# 2024-03-28 22:32:39
#
# Scraped 131 users this round
# Got 177 reivews
# 181901 reviews are now in the bag, so to speak
# 2024-03-28 22:38:20
#
# Scraped 120 users this round
# Got 180 reivews
# 182081 reviews are now in the bag, so to speak
# 2024-03-28 22:42:35
#
# Scraped 114 users this round
# Got 169 reivews
# 182250 reviews are now in the bag, so to speak
# 2024-03-28 22:51:14
#
# Scraped 97 users this round
# Got 174 reivews
# 182424 reviews are now in the bag, so to speak
# 2024-03-28 22:59:17
#
# Scraped 128 users this round
# Got 180 reivews
# 182604 reviews are now in the bag, so to speak
# 2024-03-28 23:10:50
#
# Scraped 107 users this round
# Got 195 reivews
# 182799 reviews are now in the bag, so to speak
# 2024-03-28 23:20:53
#
# Scraped 121 users this round
# Got 209 reivews
# 183008 reviews are now in the bag, so to speak
# 2024-03-28 23:25:18
#
# Scraped 112 users this round
# Got 188 reivews
# 183196 reviews are now in the bag, so to speak
# 2024-03-28 23:29:04
#
# Scraped 114 users this round
# Got 208 reivews
# 183404 reviews are now in the bag, so to speak
# 2024-03-28 23:32:35
#
# Scraped 102 users this round
# Got 202 reivews
# 183606 reviews are now in the bag, so to speak
# 2024-03-28 23:35:54
#
# Scraped 118 users this round
# Got 175 reivews
# 183781 reviews are now in the bag, so to speak
# 2024-03-28 23:39:45
#
# Scraped 106 users this round
# Got 141 reivews
# 183922 reviews are now in the bag, so to speak
# 2024-03-28 23:43:10
#
# Scraped 99 users this round
# Got 173 reivews
# 184095 reviews are now in the bag, so to speak
# 2024-03-28 23:46:37
#
# Scraped 103 users this round
# Got 196 reivews
# 184291 reviews are now in the bag, so to speak
# 2024-03-28 23:49:53
#
# Scraped 106 users this round
# Got 212 reivews
# 184503 reviews are now in the bag, so to speak
# 2024-03-28 23:53:13
#
# Scraped 87 users this round
# Got 189 reivews
# 184692 reviews are now in the bag, so to speak
# 2024-03-28 23:55:54
#
# Scraped 109 users this round
# Got 155 reivews
# 184847 reviews are now in the bag, so to speak
# 2024-03-28 23:59:26
#
# Scraped 129 users this round
# Got 186 reivews
# 185033 reviews are now in the bag, so to speak
# 2024-03-29 00:03:46
#
# Scraped 95 users this round
# Got 192 reivews
# 185225 reviews are now in the bag, so to speak
# 2024-03-29 00:06:41
#
# Scraped 125 users this round
# Got 152 reivews
# 185377 reviews are now in the bag, so to speak
# 2024-03-29 00:10:56
#
# Scraped 108 users this round
# Got 182 reivews
# 185559 reviews are now in the bag, so to speak
# 2024-03-29 00:14:42
#
# Scraped 92 users this round
# Got 176 reivews
# 185735 reviews are now in the bag, so to speak
# 2024-03-29 00:17:50
#
# Scraped 111 users this round
# Got 198 reivews
# 185933 reviews are now in the bag, so to speak
# 2024-03-29 00:21:31
#
# Scraped 115 users this round
# Got 212 reivews
# 186145 reviews are now in the bag, so to speak
# 2024-03-29 00:25:29
#
# Scraped 118 users this round
# Got 165 reivews
# 186310 reviews are now in the bag, so to speak
# 2024-03-29 00:29:20
#
# Scraped 125 users this round
# Got 186 reivews
# 186496 reviews are now in the bag, so to speak
# 2024-03-29 00:33:27
#
# Scraped 117 users this round
# Got 193 reivews
# 186689 reviews are now in the bag, so to speak
# 2024-03-29 00:37:22
#
# Scraped 98 users this round
# Got 232 reivews
# 186921 reviews are now in the bag, so to speak
# 2024-03-29 00:40:26
#
# Scraped 99 users this round
# Got 192 reivews
# 187113 reviews are now in the bag, so to speak
# 2024-03-29 00:43:39
#
# Scraped 88 users this round
# Got 172 reivews
# 187285 reviews are now in the bag, so to speak
# 2024-03-29 00:46:29
#
# Scraped 111 users this round
# Got 213 reivews
# 187498 reviews are now in the bag, so to speak
# 2024-03-29 00:50:12
#
# Scraped 127 users this round
# Got 211 reivews
# 187709 reviews are now in the bag, so to speak
# 2024-03-29 00:54:39
#
# Scraped 101 users this round
# Got 156 reivews
# 187865 reviews are now in the bag, so to speak
# 2024-03-29 00:57:47
#
# Scraped 110 users this round
# Got 182 reivews
# 188047 reviews are now in the bag, so to speak
# 2024-03-29 01:01:32
#
# Scraped 93 users this round
# Got 197 reivews
# 188244 reviews are now in the bag, so to speak
# 2024-03-29 01:04:42
#
# Scraped 120 users this round
# Got 172 reivews
# 188416 reviews are now in the bag, so to speak
# 2024-03-29 01:09:01
#
# Scraped 122 users this round
# Got 203 reivews
# 188619 reviews are now in the bag, so to speak
# 2024-03-29 01:13:06
#
# Scraped 127 users this round
# Got 141 reivews
# 188760 reviews are now in the bag, so to speak
# 2024-03-29 01:17:19
#
# Scraped 113 users this round
# Got 180 reivews
# 188940 reviews are now in the bag, so to speak
# 2024-03-29 01:20:58
#
# Scraped 97 users this round
# Got 174 reivews
# 189114 reviews are now in the bag, so to speak
# 2024-03-29 01:24:03
#
# Scraped 115 users this round
# Got 189 reivews
# 189303 reviews are now in the bag, so to speak
# 2024-03-29 01:27:58
#
# Scraped 141 users this round
# Got 183 reivews
# 189486 reviews are now in the bag, so to speak
# 2024-03-29 01:32:41
#
# Scraped 97 users this round
# Got 204 reivews
# 189690 reviews are now in the bag, so to speak
# 2024-03-29 01:35:56
#
# Scraped 122 users this round
# Got 191 reivews
# 189881 reviews are now in the bag, so to speak
# 2024-03-29 01:40:00
#
# Scraped 109 users this round
# Got 193 reivews
# 190074 reviews are now in the bag, so to speak
# 2024-03-29 01:43:37
#
# Scraped 118 users this round
# Got 176 reivews
# 190250 reviews are now in the bag, so to speak
# 2024-03-29 01:47:47
#
# Scraped 112 users this round
# Got 197 reivews
# 190447 reviews are now in the bag, so to speak
# 2024-03-29 01:51:28
#
# Scraped 89 users this round
# Got 203 reivews
# 190650 reviews are now in the bag, so to speak
# 2024-03-29 01:54:15
#
# Scraped 124 users this round
# Got 155 reivews
# 190805 reviews are now in the bag, so to speak
# 2024-03-29 01:58:23
#
# Scraped 106 users this round
# Got 188 reivews
# 190993 reviews are now in the bag, so to speak
# 2024-03-29 02:01:38
#
# Scraped 118 users this round
# Got 183 reivews
# 191176 reviews are now in the bag, so to speak
# 2024-03-29 02:05:29
#
# Scraped 109 users this round
# Got 208 reivews
# 191384 reviews are now in the bag, so to speak
# 2024-03-29 02:08:56
#
# Scraped 117 users this round
# Got 158 reivews
# 191542 reviews are now in the bag, so to speak
# 2024-03-29 02:12:46
#
# Scraped 106 users this round
# Got 194 reivews
# 191736 reviews are now in the bag, so to speak
# 2024-03-29 02:16:07
#
# Scraped 112 users this round
# Got 184 reivews
# 191920 reviews are now in the bag, so to speak
# 2024-03-29 02:19:46
#
# Scraped 111 users this round
# Got 192 reivews
# 192112 reviews are now in the bag, so to speak
# 2024-03-29 02:23:20
#
# Scraped 115 users this round
# Got 181 reivews
# 192293 reviews are now in the bag, so to speak
# 2024-03-29 02:27:08
#
# Scraped 106 users this round
# Got 199 reivews
# 192492 reviews are now in the bag, so to speak
# 2024-03-29 02:30:47
#
# Scraped 104 users this round
# Got 169 reivews
# 192661 reviews are now in the bag, so to speak
# 2024-03-29 02:34:14
#
# Scraped 114 users this round
# Got 170 reivews
# 192831 reviews are now in the bag, so to speak
# 2024-03-29 02:37:58
#
# Scraped 132 users this round
# Got 204 reivews
# 193035 reviews are now in the bag, so to speak
# 2024-03-29 02:42:29
#
# Scraped 123 users this round
# Got 237 reivews
# 193272 reviews are now in the bag, so to speak
# 2024-03-29 02:46:33
#
# Scraped 107 users this round
# Got 194 reivews
# 193466 reviews are now in the bag, so to speak
# 2024-03-29 02:49:57
#
# Scraped 112 users this round
# Got 215 reivews
# 193681 reviews are now in the bag, so to speak
# 2024-03-29 02:53:42
#
# Scraped 94 users this round
# Got 201 reivews
# 193882 reviews are now in the bag, so to speak
# 2024-03-29 02:56:34
#
# Scraped 122 users this round
# Got 173 reivews
# 194055 reviews are now in the bag, so to speak
# 2024-03-29 03:00:35
#
# Scraped 96 users this round
# Got 191 reivews
# 194246 reviews are now in the bag, so to speak
# 2024-03-29 03:03:40
#
# Scraped 114 users this round
# Got 172 reivews
# 194418 reviews are now in the bag, so to speak
# 2024-03-29 03:07:18
#
# Scraped 100 users this round
# Got 192 reivews
# 194610 reviews are now in the bag, so to speak
# 2024-03-29 03:10:23
#
# Scraped 103 users this round
# Got 220 reivews
# 194830 reviews are now in the bag, so to speak
# 2024-03-29 03:13:33
#
# Scraped 119 users this round
# Got 197 reivews
# 195027 reviews are now in the bag, so to speak
# 2024-03-29 03:17:25
#
# Scraped 108 users this round
# Got 187 reivews
# 195214 reviews are now in the bag, so to speak
# 2024-03-29 03:20:48
#
# Scraped 101 users this round
# Got 189 reivews
# 195403 reviews are now in the bag, so to speak
# 2024-03-29 03:23:54
#
# Scraped 100 users this round
# Got 199 reivews
# 195602 reviews are now in the bag, so to speak
# 2024-03-29 03:29:04
#
# Scraped 112 users this round
# Got 158 reivews
# 195760 reviews are now in the bag, so to speak
# 2024-03-29 03:32:38
#
# Scraped 108 users this round
# Got 234 reivews
# 195994 reviews are now in the bag, so to speak
# 2024-03-29 03:36:13
#
# Scraped 118 users this round
# Got 194 reivews
# 196188 reviews are now in the bag, so to speak
# 2024-03-29 03:40:08
#
# Scraped 124 users this round
# Got 207 reivews
# 196395 reviews are now in the bag, so to speak
# 2024-03-29 03:44:18
#
# Scraped 114 users this round
# Got 219 reivews
# 196614 reviews are now in the bag, so to speak
# 2024-03-29 03:47:55
#
# Scraped 106 users this round
# Got 158 reivews
# 196772 reviews are now in the bag, so to speak
# 2024-03-29 03:51:07
#
# Scraped 128 users this round
# Got 205 reivews
# 196977 reviews are now in the bag, so to speak
# 2024-03-29 03:55:21
#
# Scraped 122 users this round
# Got 207 reivews
# 197184 reviews are now in the bag, so to speak
# 2024-03-29 03:59:14
#
# Scraped 105 users this round
# Got 193 reivews
# 197377 reviews are now in the bag, so to speak
# 2024-03-29 04:02:45
#
# Scraped 97 users this round
# Got 198 reivews
# 197575 reviews are now in the bag, so to speak
# 2024-03-29 04:05:51
#
# Scraped 105 users this round
# Got 189 reivews
# 197764 reviews are now in the bag, so to speak
# 2024-03-29 04:09:07
#
# Scraped 125 users this round
# Got 211 reivews
# 197975 reviews are now in the bag, so to speak
# 2024-03-29 04:13:10
#
# Scraped 96 users this round
# Got 194 reivews
# 198169 reviews are now in the bag, so to speak
# 2024-03-29 04:16:17
#
# Scraped 105 users this round
# Got 132 reivews
# 198301 reviews are now in the bag, so to speak
# 2024-03-29 04:19:41
#
# Scraped 98 users this round
# Got 200 reivews
# 198501 reviews are now in the bag, so to speak
# 2024-03-29 04:22:43
#
# Scraped 121 users this round
# Got 160 reivews
# 198661 reviews are now in the bag, so to speak
# 2024-03-29 04:26:33
#
# Scraped 108 users this round
# Got 159 reivews
# 198820 reviews are now in the bag, so to speak
# 2024-03-29 04:30:10
#
# Scraped 108 users this round
# Got 195 reivews
# 199015 reviews are now in the bag, so to speak
# 2024-03-29 04:33:42
#
# Scraped 103 users this round
# Got 177 reivews
# 199192 reviews are now in the bag, so to speak
# 2024-03-29 04:37:03
#
# Scraped 120 users this round
# Got 225 reivews
# 199417 reviews are now in the bag, so to speak
# 2024-03-29 04:41:01
#
# Scraped 139 users this round
# Got 188 reivews
# 199605 reviews are now in the bag, so to speak
# 2024-03-29 04:45:19
#
# Scraped 117 users this round
# Got 177 reivews
# 199782 reviews are now in the bag, so to speak
# 2024-03-29 04:48:59
#
# Scraped 103 users this round
# Got 152 reivews
# 199934 reviews are now in the bag, so to speak
# 2024-03-29 04:52:17
#
# Scraped 137 users this round
# Got 169 reivews
# 200103 reviews are now in the bag, so to speak
# 2024-03-29 04:56:56
#
# Scraped 99 users this round
# Got 195 reivews
# 200298 reviews are now in the bag, so to speak
# 2024-03-29 05:00:06
#
# Scraped 119 users this round
# Got 201 reivews
# 200499 reviews are now in the bag, so to speak
# 2024-03-29 05:03:57
#
# Scraped 106 users this round
# Got 205 reivews
# 200704 reviews are now in the bag, so to speak
# 2024-03-29 05:07:16
#
# Scraped 100 users this round
# Got 172 reivews
# 200876 reviews are now in the bag, so to speak
# 2024-03-29 05:10:20
#
# Scraped 119 users this round
# Got 156 reivews
# 201032 reviews are now in the bag, so to speak
# 2024-03-29 05:14:01
#
# Scraped 99 users this round
# Got 176 reivews
# 201208 reviews are now in the bag, so to speak
# 2024-03-29 05:17:02
#
# Scraped 97 users this round
# Got 186 reivews
# 201394 reviews are now in the bag, so to speak
# 2024-03-29 05:20:16
#
# Scraped 117 users this round
# Got 184 reivews
# 201578 reviews are now in the bag, so to speak
# 2024-03-29 05:24:08
#
# Scraped 93 users this round
# Got 185 reivews
# 201763 reviews are now in the bag, so to speak
# 2024-03-29 05:27:07
#
# Scraped 113 users this round
# Got 208 reivews
# 201971 reviews are now in the bag, so to speak
# 2024-03-29 05:30:51
#
# Scraped 110 users this round
# Got 232 reivews
# 202203 reviews are now in the bag, so to speak
# 2024-03-29 05:34:43
#
# Scraped 104 users this round
# Got 196 reivews
# 202399 reviews are now in the bag, so to speak
# 2024-03-29 05:38:12
#
# Scraped 142 users this round
# Got 192 reivews
# 202591 reviews are now in the bag, so to speak
# 2024-03-29 05:42:46
#
# Scraped 119 users this round
# Got 161 reivews
# 202752 reviews are now in the bag, so to speak
# 2024-03-29 05:46:33
#
# Scraped 98 users this round
# Got 198 reivews
# 202950 reviews are now in the bag, so to speak
# 2024-03-29 05:49:51
#
# Scraped 129 users this round
# Got 161 reivews
# 203111 reviews are now in the bag, so to speak
# 2024-03-29 05:54:47
#
# Scraped 127 users this round
# Got 215 reivews
# 203326 reviews are now in the bag, so to speak
# 2024-03-29 05:59:16
#
# Scraped 140 users this round
# Got 231 reivews
# 203557 reviews are now in the bag, so to speak
# 2024-03-29 06:03:59
#
# Scraped 97 users this round
# Got 196 reivews
# 203753 reviews are now in the bag, so to speak
# 2024-03-29 06:06:59
#
# Scraped 105 users this round
# Got 161 reivews
# 203914 reviews are now in the bag, so to speak
# 2024-03-29 06:10:08
#
# Scraped 139 users this round
# Got 171 reivews
# 204085 reviews are now in the bag, so to speak
# 2024-03-29 06:14:52
#
# Scraped 114 users this round
# Got 199 reivews
# 204284 reviews are now in the bag, so to speak
# 2024-03-29 06:18:38
#
# Scraped 103 users this round
# Got 163 reivews
# 204447 reviews are now in the bag, so to speak
# 2024-03-29 06:22:01
#
# Scraped 122 users this round
# Got 164 reivews
# 204611 reviews are now in the bag, so to speak
# 2024-03-29 06:26:05
#
# Scraped 142 users this round
# Got 187 reivews
# 204798 reviews are now in the bag, so to speak
# 2024-03-29 06:31:08
#
# Scraped 114 users this round
# Got 214 reivews
# 205012 reviews are now in the bag, so to speak
# 2024-03-29 06:34:47
#
# Scraped 128 users this round
# Got 170 reivews
# 205182 reviews are now in the bag, so to speak
# 2024-03-29 06:38:59
#
# Scraped 115 users this round
# Got 149 reivews
# 205331 reviews are now in the bag, so to speak
# 2024-03-29 06:42:40
#
# Scraped 100 users this round
# Got 170 reivews
# 205501 reviews are now in the bag, so to speak
# 2024-03-29 06:46:03
#
# Scraped 108 users this round
# Got 218 reivews
# 205719 reviews are now in the bag, so to speak
# 2024-03-29 06:49:26
#
# Scraped 113 users this round
# Got 211 reivews
# 205930 reviews are now in the bag, so to speak
# 2024-03-29 06:52:59
#
# Scraped 108 users this round
# Got 202 reivews
# 206132 reviews are now in the bag, so to speak
# 2024-03-29 06:56:32
#
# Scraped 96 users this round
# Got 213 reivews
# 206345 reviews are now in the bag, so to speak
# 2024-03-29 06:59:37
#
# Scraped 120 users this round
# Got 211 reivews
# 206556 reviews are now in the bag, so to speak
# 2024-03-29 07:03:49
#
# Scraped 115 users this round
# Got 189 reivews
# 206745 reviews are now in the bag, so to speak
# 2024-03-29 07:07:53
#
# Scraped 96 users this round
# Got 144 reivews
# 206889 reviews are now in the bag, so to speak
# 2024-03-29 07:10:54
#
# Scraped 101 users this round
# Got 180 reivews
# 207069 reviews are now in the bag, so to speak
# 2024-03-29 07:14:15
#
# Scraped 109 users this round
# Got 130 reivews
# 207199 reviews are now in the bag, so to speak
# 2024-03-29 07:18:04
#
# Scraped 103 users this round
# Got 194 reivews
# 207393 reviews are now in the bag, so to speak
# 2024-03-29 07:21:45
#
# Scraped 115 users this round
# Got 173 reivews
# 207566 reviews are now in the bag, so to speak
# 2024-03-29 07:25:17
#
# Scraped 93 users this round
# Got 181 reivews
# 207747 reviews are now in the bag, so to speak
# 2024-03-29 07:28:03
#
# Scraped 108 users this round
# Got 184 reivews
# 207931 reviews are now in the bag, so to speak
# 2024-03-29 07:31:45
#
# Scraped 103 users this round
# Got 179 reivews
# 208110 reviews are now in the bag, so to speak
# 2024-03-29 07:34:57
#
# Scraped 119 users this round
# Got 214 reivews
# 208324 reviews are now in the bag, so to speak
# 2024-03-29 07:38:56
#
# Scraped 121 users this round
# Got 144 reivews
# 208468 reviews are now in the bag, so to speak
# 2024-03-29 07:42:48
#
# Scraped 119 users this round
# Got 156 reivews
# 208624 reviews are now in the bag, so to speak
# 2024-03-29 07:46:43
#
# Scraped 103 users this round
# Got 142 reivews
# 208766 reviews are now in the bag, so to speak
# 2024-03-29 07:49:53
#
# Scraped 112 users this round
# Got 175 reivews
# 208941 reviews are now in the bag, so to speak
# 2024-03-29 07:53:28
#
# Scraped 111 users this round
# Got 154 reivews
# 209095 reviews are now in the bag, so to speak
# 2024-03-29 07:57:02
#
# Scraped 132 users this round
# Got 161 reivews
# 209256 reviews are now in the bag, so to speak
# 2024-03-29 08:01:28
#
# Scraped 132 users this round
# Got 218 reivews
# 209474 reviews are now in the bag, so to speak
# 2024-03-29 08:06:15
#
# Scraped 117 users this round
# Got 158 reivews
# 209632 reviews are now in the bag, so to speak
# 2024-03-29 08:10:19
#
# Scraped 95 users this round
# Got 169 reivews
# 209801 reviews are now in the bag, so to speak
# 2024-03-29 08:13:39
#
# Scraped 122 users this round
# Got 200 reivews
# 210001 reviews are now in the bag, so to speak
# 2024-03-29 08:17:47
#
# Scraped 125 users this round
# Got 200 reivews
# 210201 reviews are now in the bag, so to speak
# 2024-03-29 08:21:54
#
# Scraped 92 users this round
# Got 205 reivews
# 210406 reviews are now in the bag, so to speak
# 2024-03-29 08:24:51
#
# Scraped 125 users this round
# Got 234 reivews
# 210640 reviews are now in the bag, so to speak
# 2024-03-29 08:29:05
#
# Scraped 111 users this round
# Got 212 reivews
# 210852 reviews are now in the bag, so to speak
# 2024-03-29 08:33:04
#
# Scraped 125 users this round
# Got 173 reivews
# 211025 reviews are now in the bag, so to speak
# 2024-03-29 08:37:09
#
# Scraped 105 users this round
# Got 214 reivews
# 211239 reviews are now in the bag, so to speak
# 2024-03-29 08:41:16
#
# Scraped 102 users this round
# Got 191 reivews
# 211430 reviews are now in the bag, so to speak
# 2024-03-29 08:44:34
#
# Scraped 103 users this round
# Got 169 reivews
# 211599 reviews are now in the bag, so to speak
# 2024-03-29 08:47:54
#
# Scraped 88 users this round
# Got 217 reivews
# 211816 reviews are now in the bag, so to speak
# 2024-03-29 08:50:50
#
# Scraped 102 users this round
# Got 153 reivews
# 211969 reviews are now in the bag, so to speak
# 2024-03-29 08:54:30
#
# Scraped 120 users this round
# Got 166 reivews
# 212135 reviews are now in the bag, so to speak
# 2024-03-29 08:58:12
#
# Scraped 125 users this round
# Got 196 reivews
# 212331 reviews are now in the bag, so to speak
# 2024-03-29 09:03:02
#
# Scraped 108 users this round
# Got 196 reivews
# 212527 reviews are now in the bag, so to speak
# 2024-03-29 09:06:53
#
# Scraped 121 users this round
# Got 183 reivews
# 212710 reviews are now in the bag, so to speak
# 2024-03-29 09:10:54
#
# Scraped 121 users this round
# Got 198 reivews
# 212908 reviews are now in the bag, so to speak
# 2024-03-29 09:14:53
#
# Scraped 109 users this round
# Got 206 reivews
# 213114 reviews are now in the bag, so to speak
# 2024-03-29 09:18:25
#
# Scraped 117 users this round
# Got 138 reivews
# 213252 reviews are now in the bag, so to speak
# 2024-03-29 09:22:26
#
# Scraped 109 users this round
# Got 205 reivews
# 213457 reviews are now in the bag, so to speak
# 2024-03-29 09:26:04
#
# Scraped 104 users this round
# Got 198 reivews
# 213655 reviews are now in the bag, so to speak
# 2024-03-29 09:29:57
#
# Scraped 97 users this round
# Got 148 reivews
# 213803 reviews are now in the bag, so to speak
# 2024-03-29 09:32:56
#
# Scraped 110 users this round
# Got 186 reivews
# 213989 reviews are now in the bag, so to speak
# 2024-03-29 09:36:34
#
# Scraped 126 users this round
# Got 215 reivews
# 214204 reviews are now in the bag, so to speak
# 2024-03-29 09:40:42
#
# Scraped 113 users this round
# Got 184 reivews
# 214388 reviews are now in the bag, so to speak
# 2024-03-29 09:44:30
#
# Scraped 120 users this round
# Got 239 reivews
# 214627 reviews are now in the bag, so to speak
# 2024-03-29 09:48:33
#
# Scraped 98 users this round
# Got 168 reivews
# 214795 reviews are now in the bag, so to speak
# 2024-03-29 09:51:49
#
# Scraped 111 users this round
# Got 178 reivews
# 214973 reviews are now in the bag, so to speak
# 2024-03-29 09:55:35
#
# Scraped 121 users this round
# Got 198 reivews
# 215171 reviews are now in the bag, so to speak
# 2024-03-29 09:59:33
#
# Scraped 111 users this round
# Got 175 reivews
# 215346 reviews are now in the bag, so to speak
# 2024-03-29 10:03:09
#
# Scraped 108 users this round
# Got 174 reivews
# 215520 reviews are now in the bag, so to speak
# 2024-03-29 10:06:31
#
# Scraped 115 users this round
# Got 177 reivews
# 215697 reviews are now in the bag, so to speak
# 2024-03-29 10:10:45
#
# Scraped 118 users this round
# Got 159 reivews
# 215856 reviews are now in the bag, so to speak
# 2024-03-29 10:14:50
#
# Scraped 108 users this round
# Got 187 reivews
# 216043 reviews are now in the bag, so to speak
# 2024-03-29 10:18:16
#
# Scraped 94 users this round
# Got 143 reivews
# 216186 reviews are now in the bag, so to speak
# 2024-03-29 10:21:24
#
# Scraped 100 users this round
# Got 174 reivews
# 216360 reviews are now in the bag, so to speak
# 2024-03-29 10:24:38
#
# Scraped 131 users this round
# Got 174 reivews
# 216534 reviews are now in the bag, so to speak
# 2024-03-29 10:28:54
#
# Scraped 99 users this round
# Got 195 reivews
# 216729 reviews are now in the bag, so to speak
# 2024-03-29 10:32:13
#
# Scraped 108 users this round
# Got 202 reivews
# 216931 reviews are now in the bag, so to speak
# 2024-03-29 10:35:40
#
# Scraped 108 users this round
# Got 244 reivews
# 217175 reviews are now in the bag, so to speak
# 2024-03-29 10:39:33
#
# Scraped 128 users this round
# Got 160 reivews
# 217335 reviews are now in the bag, so to speak
# 2024-03-29 10:43:34
#
# Scraped 96 users this round
# Got 210 reivews
# 217545 reviews are now in the bag, so to speak
# 2024-03-29 10:46:31
#
# Scraped 103 users this round
# Got 184 reivews
# 217729 reviews are now in the bag, so to speak
# 2024-03-29 10:49:41
#
# Scraped 108 users this round
# Got 181 reivews
# 217910 reviews are now in the bag, so to speak
# 2024-03-29 10:53:05
#
# Scraped 112 users this round
# Got 172 reivews
# 218082 reviews are now in the bag, so to speak
# 2024-03-29 10:56:34
#
# Scraped 131 users this round
# Got 218 reivews
# 218300 reviews are now in the bag, so to speak
# 2024-03-29 11:01:13
#
# Scraped 113 users this round
# Got 163 reivews
# 218463 reviews are now in the bag, so to speak
# 2024-03-29 11:04:44
#
# Scraped 112 users this round
# Got 174 reivews
# 218637 reviews are now in the bag, so to speak
# 2024-03-29 11:08:13
#
# Scraped 116 users this round
# Got 194 reivews
# 218831 reviews are now in the bag, so to speak
# 2024-03-29 11:12:04
#
# Scraped 126 users this round
# Got 151 reivews
# 218982 reviews are now in the bag, so to speak
# 2024-03-29 11:16:16
#
# Scraped 113 users this round
# Got 172 reivews
# 219154 reviews are now in the bag, so to speak
# 2024-03-29 11:19:53
#
# Scraped 109 users this round
# Got 205 reivews
# 219359 reviews are now in the bag, so to speak
# 2024-03-29 11:23:25
#
# Scraped 99 users this round
# Got 173 reivews
# 219532 reviews are now in the bag, so to speak
# 2024-03-29 11:26:37
#
# Scraped 111 users this round
# Got 202 reivews
# 219734 reviews are now in the bag, so to speak
# 2024-03-29 11:30:32
#
# Scraped 110 users this round
# Got 199 reivews
# 219933 reviews are now in the bag, so to speak
# 2024-03-29 11:34:12
#
# Scraped 104 users this round
# Got 151 reivews
# 220084 reviews are now in the bag, so to speak
# 2024-03-29 11:37:43
#
# Scraped 97 users this round
# Got 185 reivews
# 220269 reviews are now in the bag, so to speak
# 2024-03-29 11:40:51
#
# Scraped 112 users this round
# Got 189 reivews
# 220458 reviews are now in the bag, so to speak
# 2024-03-29 11:45:00
#
# Scraped 113 users this round
# Got 233 reivews
# 220691 reviews are now in the bag, so to speak
# 2024-03-29 11:48:57
#
# Scraped 106 users this round
# Got 183 reivews
# 220874 reviews are now in the bag, so to speak
# 2024-03-29 11:52:36
#
# Scraped 111 users this round
# Got 160 reivews
# 221034 reviews are now in the bag, so to speak
# 2024-03-29 11:56:26
#
# Scraped 111 users this round
# Got 182 reivews
# 221216 reviews are now in the bag, so to speak
# 2024-03-29 12:00:35
#
# Scraped 96 users this round
# Got 216 reivews
# 221432 reviews are now in the bag, so to speak
# 2024-03-29 12:04:06
#
# Scraped 106 users this round
# Got 193 reivews
# 221625 reviews are now in the bag, so to speak
# 2024-03-29 12:08:06
#
# Scraped 100 users this round
# Got 145 reivews
# 221770 reviews are now in the bag, so to speak
# 2024-03-29 12:11:59
#
# Scraped 114 users this round
# Got 214 reivews
# 221984 reviews are now in the bag, so to speak
# 2024-03-29 12:16:23
#
# Scraped 127 users this round
# Got 197 reivews
# 222181 reviews are now in the bag, so to speak
# 2024-03-29 12:21:11
#
# Scraped 106 users this round
# Got 187 reivews
# 222368 reviews are now in the bag, so to speak
# 2024-03-29 12:25:09
#
# Scraped 108 users this round
# Got 187 reivews
# 222555 reviews are now in the bag, so to speak
# 2024-03-29 12:29:10
#
# Scraped 106 users this round
# Got 165 reivews
# 222720 reviews are now in the bag, so to speak
# 2024-03-29 12:33:11
#
# Scraped 103 users this round
# Got 191 reivews
# 222911 reviews are now in the bag, so to speak
# 2024-03-29 12:37:14
#
# Scraped 108 users this round
# Got 217 reivews
# 223128 reviews are now in the bag, so to speak
# 2024-03-29 12:41:24
#
# Scraped 93 users this round
# Got 209 reivews
# 223337 reviews are now in the bag, so to speak
# 2024-03-29 12:44:55
#
# Scraped 124 users this round
# Got 179 reivews
# 223516 reviews are now in the bag, so to speak
# 2024-03-29 12:49:38
#
# Scraped 109 users this round
# Got 159 reivews
# 223675 reviews are now in the bag, so to speak
# 2024-03-29 12:53:45
#
# Scraped 114 users this round
# Got 230 reivews
# 223905 reviews are now in the bag, so to speak
# 2024-03-29 12:57:47
#
# Scraped 105 users this round
# Got 240 reivews
# 224145 reviews are now in the bag, so to speak
# 2024-03-29 13:01:30
#
# Scraped 111 users this round
# Got 229 reivews
# 224374 reviews are now in the bag, so to speak
# 2024-03-29 13:05:23
#
# Scraped 101 users this round
# Got 173 reivews
# 224547 reviews are now in the bag, so to speak
# 2024-03-29 13:08:46
#
# Scraped 103 users this round
# Got 203 reivews
# 224750 reviews are now in the bag, so to speak
# 2024-03-29 13:12:16
#
# Scraped 110 users this round
# Got 186 reivews
# 224936 reviews are now in the bag, so to speak
# 2024-03-29 13:15:53
#
# Scraped 88 users this round
# Got 166 reivews
# 225102 reviews are now in the bag, so to speak
# 2024-03-29 13:18:45
#
# Scraped 106 users this round
# Got 168 reivews
# 225270 reviews are now in the bag, so to speak
# 2024-03-29 13:22:08
#
# Scraped 121 users this round
# Got 171 reivews
# 225441 reviews are now in the bag, so to speak
# 2024-03-29 13:26:08
#
# Scraped 96 users this round
# Got 170 reivews
# 225611 reviews are now in the bag, so to speak
# 2024-03-29 13:29:14
#
# Scraped 119 users this round
# Got 200 reivews
# 225811 reviews are now in the bag, so to speak
# 2024-03-29 13:33:17
#
# Scraped 103 users this round
# Got 175 reivews
# 225986 reviews are now in the bag, so to speak
# 2024-03-29 13:36:44
#
# Scraped 110 users this round
# Got 203 reivews
# 226189 reviews are now in the bag, so to speak
# 2024-03-29 13:40:27
#
# Scraped 142 users this round
# Got 204 reivews
# 226393 reviews are now in the bag, so to speak
# 2024-03-29 13:45:17
#
# Scraped 94 users this round
# Got 185 reivews
# 226578 reviews are now in the bag, so to speak
# 2024-03-29 13:48:23
#
# Scraped 108 users this round
# Got 189 reivews
# 226767 reviews are now in the bag, so to speak
# 2024-03-29 13:51:52
#
# Scraped 122 users this round
# Got 168 reivews
# 226935 reviews are now in the bag, so to speak
# 2024-03-29 13:55:58
#
# Scraped 105 users this round
# Got 205 reivews
# 227140 reviews are now in the bag, so to speak
# 2024-03-29 13:59:29
#
# Scraped 99 users this round
# Got 204 reivews
# 227344 reviews are now in the bag, so to speak
# 2024-03-29 14:02:55
#
# Scraped 101 users this round
# Got 227 reivews
# 227571 reviews are now in the bag, so to speak
# 2024-03-29 14:06:08
#
# Scraped 135 users this round
# Got 191 reivews
# 227762 reviews are now in the bag, so to speak
# 2024-03-29 14:10:54
#
# Scraped 138 users this round
# Got 252 reivews
# 228014 reviews are now in the bag, so to speak
# 2024-03-29 14:15:50
#
# Scraped 102 users this round
# Got 198 reivews
# 228212 reviews are now in the bag, so to speak
# 2024-03-29 14:19:17
#
# Scraped 89 users this round
# Got 207 reivews
# 228419 reviews are now in the bag, so to speak
# 2024-03-29 14:22:10
#
# Scraped 108 users this round
# Got 200 reivews
# 228619 reviews are now in the bag, so to speak
# 2024-03-29 14:26:03
#
# Scraped 101 users this round
# Got 180 reivews
# 228799 reviews are now in the bag, so to speak
# 2024-03-29 14:29:49
#
# Scraped 127 users this round
# Got 163 reivews
# 228962 reviews are now in the bag, so to speak
# 2024-03-29 14:34:09
#
# Scraped 115 users this round
# Got 209 reivews
# 229171 reviews are now in the bag, so to speak
# 2024-03-29 14:38:22
#
# Scraped 114 users this round
# Got 221 reivews
# 229392 reviews are now in the bag, so to speak
# 2024-03-29 14:42:25
#
# Scraped 119 users this round
# Got 200 reivews
# 229592 reviews are now in the bag, so to speak
# 2024-03-29 14:46:51
#
# Scraped 105 users this round
# Got 187 reivews
# 229779 reviews are now in the bag, so to speak
# 2024-03-29 14:50:28
#
# Scraped 137 users this round
# Got 134 reivews
# 229913 reviews are now in the bag, so to speak
# 2024-03-29 14:55:03
#
# Scraped 121 users this round
# Got 204 reivews
# 230117 reviews are now in the bag, so to speak
# 2024-03-29 14:59:23
#
# Scraped 89 users this round
# Got 189 reivews
# 230306 reviews are now in the bag, so to speak
# 2024-03-29 15:02:25
#
# Scraped 125 users this round
# Got 182 reivews
# 230488 reviews are now in the bag, so to speak
# 2024-03-29 15:06:58
#
# Scraped 98 users this round
# Got 252 reivews
# 230740 reviews are now in the bag, so to speak
# 2024-03-29 15:10:23
#
# Scraped 118 users this round
# Got 137 reivews
# 230877 reviews are now in the bag, so to speak
# 2024-03-29 15:14:23
#
# Scraped 103 users this round
# Got 222 reivews
# 231099 reviews are now in the bag, so to speak
# 2024-03-29 15:18:03
#
# Scraped 102 users this round
# Got 188 reivews
# 231287 reviews are now in the bag, so to speak
# 2024-03-29 15:21:45
#
# Scraped 121 users this round
# Got 193 reivews
# 231480 reviews are now in the bag, so to speak
# 2024-03-29 15:25:56
#
# Scraped 105 users this round
# Got 239 reivews
# 231719 reviews are now in the bag, so to speak
# 2024-03-29 15:29:32
#
# Scraped 121 users this round
# Got 163 reivews
# 231882 reviews are now in the bag, so to speak
# 2024-03-29 15:33:47
#
# Scraped 100 users this round
# Got 187 reivews
# 232069 reviews are now in the bag, so to speak
# 2024-03-29 15:37:05
#
# Scraped 102 users this round
# Got 158 reivews
# 232227 reviews are now in the bag, so to speak
# 2024-03-29 15:40:17
#
# Scraped 104 users this round
# Got 205 reivews
# 232432 reviews are now in the bag, so to speak
# 2024-03-29 15:43:43
#
# Scraped 125 users this round
# Got 187 reivews
# 232619 reviews are now in the bag, so to speak
# 2024-03-29 15:47:56
#
# Scraped 94 users this round
# Got 230 reivews
# 232849 reviews are now in the bag, so to speak
# 2024-03-29 15:50:52
#
# Scraped 105 users this round
# Got 153 reivews
# 233002 reviews are now in the bag, so to speak
# 2024-03-29 15:54:22
#
# Scraped 93 users this round
# Got 188 reivews
# 233190 reviews are now in the bag, so to speak
# 2024-03-29 15:57:32
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 107 users this round
# Got 194 reivews
# 233384 reviews are now in the bag, so to speak
# 2024-03-29 16:01:14
#
# Scraped 104 users this round
# Got 194 reivews
# 233578 reviews are now in the bag, so to speak
# 2024-03-29 16:04:44
#
# Scraped 105 users this round
# Got 179 reivews
# 233757 reviews are now in the bag, so to speak
# 2024-03-29 16:08:00
#
# Scraped 94 users this round
# Got 206 reivews
# 233963 reviews are now in the bag, so to speak
# 2024-03-29 16:10:55
#
# Scraped 105 users this round
# Got 151 reivews
# 234114 reviews are now in the bag, so to speak
# 2024-03-29 16:14:10
#
# Scraped 116 users this round
# Got 225 reivews
# 234339 reviews are now in the bag, so to speak
# 2024-03-29 16:18:06
#
# Scraped 113 users this round
# Got 188 reivews
# 234527 reviews are now in the bag, so to speak
# 2024-03-29 16:21:33
#
# Scraped 129 users this round
# Got 190 reivews
# 234717 reviews are now in the bag, so to speak
# 2024-03-29 16:25:36
#
# Scraped 108 users this round
# Got 187 reivews
# 234904 reviews are now in the bag, so to speak
# 2024-03-29 16:29:04
#
# Scraped 115 users this round
# Got 227 reivews
# 235131 reviews are now in the bag, so to speak
# 2024-03-29 16:32:38
#
# Scraped 110 users this round
# Got 189 reivews
# 235320 reviews are now in the bag, so to speak
# 2024-03-29 16:36:05
#
# Scraped 114 users this round
# Got 183 reivews
# 235503 reviews are now in the bag, so to speak
# 2024-03-29 16:39:40
#
# Scraped 113 users this round
# Got 148 reivews
# 235651 reviews are now in the bag, so to speak
# 2024-03-29 16:43:11
#
# Scraped 95 users this round
# Got 199 reivews
# 235850 reviews are now in the bag, so to speak
# 2024-03-29 16:45:58
#
# Scraped 123 users this round
# Got 187 reivews
# 236037 reviews are now in the bag, so to speak
# 2024-03-29 16:50:38
#
# Scraped 98 users this round
# Got 221 reivews
# 236258 reviews are now in the bag, so to speak
# 2024-03-29 16:54:50
#
# Scraped 113 users this round
# Got 187 reivews
# 236445 reviews are now in the bag, so to speak
# 2024-03-29 16:58:42
#
# Scraped 97 users this round
# Got 158 reivews
# 236603 reviews are now in the bag, so to speak
# 2024-03-29 17:01:45
#
# Scraped 121 users this round
# Got 212 reivews
# 236815 reviews are now in the bag, so to speak
# 2024-03-29 17:05:49
#
# Scraped 126 users this round
# Got 190 reivews
# 237005 reviews are now in the bag, so to speak
# 2024-03-29 17:10:08
#
# Scraped 121 users this round
# Got 182 reivews
# 237187 reviews are now in the bag, so to speak
# 2024-03-29 17:14:07
#
# Scraped 125 users this round
# Got 206 reivews
# 237393 reviews are now in the bag, so to speak
# 2024-03-29 17:18:27
#
# Scraped 111 users this round
# Got 192 reivews
# 237585 reviews are now in the bag, so to speak
# 2024-03-29 17:21:58
#
# Scraped 101 users this round
# Got 179 reivews
# 237764 reviews are now in the bag, so to speak
# 2024-03-29 17:25:13
#
# Scraped 115 users this round
# Got 176 reivews
# 237940 reviews are now in the bag, so to speak
# 2024-03-29 17:29:10
#
# Scraped 108 users this round
# Got 167 reivews
# 238107 reviews are now in the bag, so to speak
# 2024-03-29 17:32:46
#
# Scraped 133 users this round
# Got 198 reivews
# 238305 reviews are now in the bag, so to speak
# 2024-03-29 17:37:20
#
# Scraped 105 users this round
# Got 170 reivews
# 238475 reviews are now in the bag, so to speak
# 2024-03-29 17:40:54
#
# Scraped 112 users this round
# Got 189 reivews
# 238664 reviews are now in the bag, so to speak
# 2024-03-29 17:44:40
#
# Scraped 102 users this round
# Got 210 reivews
# 238874 reviews are now in the bag, so to speak
# 2024-03-29 17:48:04
#
# Scraped 92 users this round
# Got 204 reivews
# 239078 reviews are now in the bag, so to speak
# 2024-03-29 17:50:54
#
# ...
# 2024-04-02 23:41:39
#
# Scraped 99 users this round
# Got 182 reivews
# 534752 reviews are now in the bag, so to speak
# 2024-04-02 23:45:14
#
# Scraped 89 users this round
# Got 188 reivews
# 534940 reviews are now in the bag, so to speak
# 2024-04-02 23:48:04
#
# Scraped 100 users this round
# Got 196 reivews
# 535136 reviews are now in the bag, so to speak
# 2024-04-02 23:51:27
#
# Scraped 92 users this round
# Got 188 reivews
# 535324 reviews are now in the bag, so to speak
# 2024-04-02 23:54:35
#
# Scraped 123 users this round
# Got 212 reivews
# 535536 reviews are now in the bag, so to speak
# 2024-04-02 23:59:02
#
# Scraped 99 users this round
# Got 190 reivews
# 535726 reviews are now in the bag, so to speak
# 2024-04-03 00:02:27
#
# Scraped 105 users this round
# Got 139 reivews
# 535865 reviews are now in the bag, so to speak
# 2024-04-03 00:05:59
#
# Scraped 102 users this round
# Got 230 reivews
# 536095 reviews are now in the bag, so to speak
# 2024-04-03 00:09:46
#
# Scraped 116 users this round
# Got 190 reivews
# 536285 reviews are now in the bag, so to speak
# 2024-04-03 00:13:48
#
# Scraped 103 users this round
# Got 156 reivews
# 536441 reviews are now in the bag, so to speak
# 2024-04-03 00:17:18
#
# Scraped 104 users this round
# Got 188 reivews
# 536629 reviews are now in the bag, so to speak
# 2024-04-03 00:20:48
#
# Scraped 95 users this round
# Got 184 reivews
# 536813 reviews are now in the bag, so to speak
# 2024-04-03 00:24:00
#
# Scraped 111 users this round
# Got 157 reivews
# 536970 reviews are now in the bag, so to speak
# 2024-04-03 00:27:54
#
# Scraped 111 users this round
# Got 171 reivews
# 537141 reviews are now in the bag, so to speak
# 2024-04-03 00:31:42
#
# Scraped 101 users this round
# Got 146 reivews
# 537287 reviews are now in the bag, so to speak
# 2024-04-03 00:35:01
#
# Scraped 112 users this round
# Got 174 reivews
# 537461 reviews are now in the bag, so to speak
# 2024-04-03 00:38:47
#
# Scraped 116 users this round
# Got 192 reivews
# 537653 reviews are now in the bag, so to speak
# 2024-04-03 00:43:03
#
# Scraped 112 users this round
# Got 168 reivews
# 537821 reviews are now in the bag, so to speak
# 2024-04-03 00:46:46
#
# Scraped 109 users this round
# Got 186 reivews
# 538007 reviews are now in the bag, so to speak
# 2024-04-03 00:50:20
#
# Scraped 103 users this round
# Got 177 reivews
# 538184 reviews are now in the bag, so to speak
# 2024-04-03 00:53:37
#
# Scraped 112 users this round
# Got 189 reivews
# 538373 reviews are now in the bag, so to speak
# 2024-04-03 00:57:24
#
# Scraped 111 users this round
# Got 172 reivews
# 538545 reviews are now in the bag, so to speak
# 2024-04-03 01:01:14
#
# Scraped 102 users this round
# Got 159 reivews
# 538704 reviews are now in the bag, so to speak
# 2024-04-03 01:04:45
#
# Scraped 119 users this round
# Got 185 reivews
# 538889 reviews are now in the bag, so to speak
# 2024-04-03 01:08:36
#
# Scraped 107 users this round
# Got 202 reivews
# 539091 reviews are now in the bag, so to speak
# 2024-04-03 01:12:24
#
# Scraped 94 users this round
# Got 198 reivews
# 539289 reviews are now in the bag, so to speak
# 2024-04-03 01:15:35
#
# Scraped 108 users this round
# Got 186 reivews
# 539475 reviews are now in the bag, so to speak
# 2024-04-03 01:19:17
#
# Scraped 112 users this round
# Got 170 reivews
# 539645 reviews are now in the bag, so to speak
# 2024-04-03 01:23:00
#
# Scraped 103 users this round
# Got 152 reivews
# 539797 reviews are now in the bag, so to speak
# 2024-04-03 01:26:19
#
# Scraped 120 users this round
# Got 174 reivews
# 539971 reviews are now in the bag, so to speak
# 2024-04-03 01:30:25
#
# Scraped 107 users this round
# Got 214 reivews
# 540185 reviews are now in the bag, so to speak
# 2024-04-03 01:34:14
#
# Scraped 105 users this round
# Got 205 reivews
# 540390 reviews are now in the bag, so to speak
# 2024-04-03 01:37:35
#
# Scraped 106 users this round
# Got 206 reivews
# 540596 reviews are now in the bag, so to speak
# 2024-04-03 01:41:03
#
# Scraped 88 users this round
# Got 200 reivews
# 540796 reviews are now in the bag, so to speak
# 2024-04-03 01:43:47
#
# Scraped 114 users this round
# Got 170 reivews
# 540966 reviews are now in the bag, so to speak
# 2024-04-03 01:47:37
#
# Scraped 132 users this round
# Got 190 reivews
# 541156 reviews are now in the bag, so to speak
# 2024-04-03 01:51:57
#
# Scraped 94 users this round
# Got 164 reivews
# 541320 reviews are now in the bag, so to speak
# 2024-04-03 01:55:03
#
# Scraped 98 users this round
# Got 157 reivews
# 541477 reviews are now in the bag, so to speak
# 2024-04-03 01:58:22
#
# Scraped 120 users this round
# Got 159 reivews
# 541636 reviews are now in the bag, so to speak
# 2024-04-03 02:02:26
#
# Scraped 107 users this round
# Got 171 reivews
# 541807 reviews are now in the bag, so to speak
# 2024-04-03 02:06:05
#
# Scraped 104 users this round
# Got 188 reivews
# 541995 reviews are now in the bag, so to speak
# 2024-04-03 02:09:35
#
# Scraped 115 users this round
# Got 165 reivews
# 542160 reviews are now in the bag, so to speak
# 2024-04-03 02:13:20
#
# Scraped 110 users this round
# Got 240 reivews
# 542400 reviews are now in the bag, so to speak
# 2024-04-03 02:17:01
#
# Scraped 116 users this round
# Got 219 reivews
# 542619 reviews are now in the bag, so to speak
# 2024-04-03 02:20:51
#
# Scraped 120 users this round
# Got 206 reivews
# 542825 reviews are now in the bag, so to speak
# 2024-04-03 02:24:46
#
# Scraped 110 users this round
# Got 194 reivews
# 543019 reviews are now in the bag, so to speak
# 2024-04-03 02:28:17
#
# Scraped 102 users this round
# Got 166 reivews
# 543185 reviews are now in the bag, so to speak
# 2024-04-03 02:31:33
#
# Scraped 98 users this round
# Got 164 reivews
# 543349 reviews are now in the bag, so to speak
# 2024-04-03 02:34:41
#
# Scraped 89 users this round
# Got 187 reivews
# 543536 reviews are now in the bag, so to speak
# 2024-04-03 02:37:41
#
# Scraped 112 users this round
# Got 221 reivews
# 543757 reviews are now in the bag, so to speak
# 2024-04-03 02:41:09
#
# Scraped 111 users this round
# Got 213 reivews
# 543970 reviews are now in the bag, so to speak
# 2024-04-03 02:45:00
#
# Scraped 109 users this round
# Got 184 reivews
# 544154 reviews are now in the bag, so to speak
# 2024-04-03 02:48:48
#
# Scraped 100 users this round
# Got 226 reivews
# 544380 reviews are now in the bag, so to speak
# 2024-04-03 02:51:58
#
# Scraped 105 users this round
# Got 168 reivews
# 544548 reviews are now in the bag, so to speak
# 2024-04-03 02:55:25
#
# Scraped 107 users this round
# Got 210 reivews
# 544758 reviews are now in the bag, so to speak
# 2024-04-03 02:59:05
#
# Scraped 103 users this round
# Got 174 reivews
# 544932 reviews are now in the bag, so to speak
# 2024-04-03 03:02:22
#
# Scraped 88 users this round
# Got 191 reivews
# 545123 reviews are now in the bag, so to speak
# 2024-04-03 03:05:11
#
# Scraped 137 users this round
# Got 204 reivews
# 545327 reviews are now in the bag, so to speak
# 2024-04-03 03:09:45
#
# Scraped 114 users this round
# Got 197 reivews
# 545524 reviews are now in the bag, so to speak
# 2024-04-03 03:13:23
#
# Scraped 101 users this round
# Got 226 reivews
# 545750 reviews are now in the bag, so to speak
# 2024-04-03 03:16:30
#
# Scraped 96 users this round
# Got 171 reivews
# 545921 reviews are now in the bag, so to speak
# 2024-04-03 03:19:42
#
# Scraped 92 users this round
# Got 210 reivews
# 546131 reviews are now in the bag, so to speak
# 2024-04-03 03:22:32
#
# Scraped 108 users this round
# Got 189 reivews
# 546320 reviews are now in the bag, so to speak
# 2024-04-03 03:26:14
#
# Scraped 98 users this round
# Got 214 reivews
# 546534 reviews are now in the bag, so to speak
# 2024-04-03 03:29:24
#
# Scraped 138 users this round
# Got 203 reivews
# 546737 reviews are now in the bag, so to speak
# 2024-04-03 03:34:11
#
# Scraped 103 users this round
# Got 169 reivews
# 546906 reviews are now in the bag, so to speak
# 2024-04-03 03:37:35
#
# Scraped 111 users this round
# Got 178 reivews
# 547084 reviews are now in the bag, so to speak
# 2024-04-03 03:41:13
#
# Scraped 117 users this round
# Got 187 reivews
# 547271 reviews are now in the bag, so to speak
# 2024-04-03 03:45:05
#
# Scraped 98 users this round
# Got 203 reivews
# 547474 reviews are now in the bag, so to speak
# 2024-04-03 03:48:17
#
# Scraped 107 users this round
# Got 210 reivews
# 547684 reviews are now in the bag, so to speak
# 2024-04-03 03:52:01
#
# Scraped 107 users this round
# Got 165 reivews
# 547849 reviews are now in the bag, so to speak
# 2024-04-03 03:55:29
#
# Scraped 119 users this round
# Got 199 reivews
# 548048 reviews are now in the bag, so to speak
# 2024-04-03 03:59:39
#
# Scraped 110 users this round
# Got 190 reivews
# 548238 reviews are now in the bag, so to speak
# 2024-04-03 04:03:26
#
# Scraped 103 users this round
# Got 185 reivews
# 548423 reviews are now in the bag, so to speak
# 2024-04-03 04:06:59
#
# Scraped 101 users this round
# Got 169 reivews
# 548592 reviews are now in the bag, so to speak
# 2024-04-03 04:10:22
#
# Scraped 102 users this round
# Got 196 reivews
# 548788 reviews are now in the bag, so to speak
# 2024-04-03 04:13:36
#
# Scraped 115 users this round
# Got 202 reivews
# 548990 reviews are now in the bag, so to speak
# 2024-04-03 04:17:26
#
# Scraped 111 users this round
# Got 209 reivews
# 549199 reviews are now in the bag, so to speak
# 2024-04-03 04:20:59
#
# Scraped 98 users this round
# Got 200 reivews
# 549399 reviews are now in the bag, so to speak
# 2024-04-03 04:24:22
#
# Scraped 110 users this round
# Got 181 reivews
# 549580 reviews are now in the bag, so to speak
# 2024-04-03 04:28:05
#
# Scraped 105 users this round
# Got 186 reivews
# 549766 reviews are now in the bag, so to speak
# 2024-04-03 04:31:37
#
# Scraped 112 users this round
# Got 209 reivews
# 549975 reviews are now in the bag, so to speak
# 2024-04-03 04:35:21
#
# Scraped 98 users this round
# Got 239 reivews
# 550214 reviews are now in the bag, so to speak
# 2024-04-03 04:38:41
#
# Scraped 125 users this round
# Got 195 reivews
# 550409 reviews are now in the bag, so to speak
# 2024-04-03 04:42:54
#
# Scraped 108 users this round
# Got 198 reivews
# 550607 reviews are now in the bag, so to speak
# 2024-04-03 04:46:36
#
# Scraped 105 users this round
# Got 203 reivews
# 550810 reviews are now in the bag, so to speak
# 2024-04-03 04:50:10
#
# Scraped 115 users this round
# Got 194 reivews
# 551004 reviews are now in the bag, so to speak
# 2024-04-03 04:54:00
#
# Scraped 109 users this round
# Got 149 reivews
# 551153 reviews are now in the bag, so to speak
# 2024-04-03 04:57:40
#
# Scraped 106 users this round
# Got 181 reivews
# 551334 reviews are now in the bag, so to speak
# 2024-04-03 05:01:17
#
# Scraped 101 users this round
# Got 190 reivews
# 551524 reviews are now in the bag, so to speak
# 2024-04-03 05:04:32
#
# Scraped 102 users this round
# Got 181 reivews
# 551705 reviews are now in the bag, so to speak
# 2024-04-03 05:07:57
#
# Scraped 101 users this round
# Got 201 reivews
# 551906 reviews are now in the bag, so to speak
# 2024-04-03 05:11:04
#
# Scraped 104 users this round
# Got 162 reivews
# 552068 reviews are now in the bag, so to speak
# 2024-04-03 05:14:27
#
# Scraped 106 users this round
# Got 198 reivews
# 552266 reviews are now in the bag, so to speak
# 2024-04-03 05:17:50
#
# Scraped 91 users this round
# Got 218 reivews
# 552484 reviews are now in the bag, so to speak
# 2024-04-03 05:20:47
#
# Scraped 116 users this round
# Got 197 reivews
# 552681 reviews are now in the bag, so to speak
# 2024-04-03 05:24:33
#
# Scraped 117 users this round
# Got 168 reivews
# 552849 reviews are now in the bag, so to speak
# 2024-04-03 05:28:37
#
# Scraped 94 users this round
# Got 191 reivews
# 553040 reviews are now in the bag, so to speak
# 2024-04-03 05:31:49
#
# Scraped 104 users this round
# Got 212 reivews
# 553252 reviews are now in the bag, so to speak
# 2024-04-03 05:35:09
#
# Scraped 121 users this round
# Got 223 reivews
# 553475 reviews are now in the bag, so to speak
# 2024-04-03 05:39:12
#
# Scraped 120 users this round
# Got 181 reivews
# 553656 reviews are now in the bag, so to speak
# 2024-04-03 05:43:15
#
# Scraped 107 users this round
# Got 149 reivews
# 553805 reviews are now in the bag, so to speak
# 2024-04-03 05:46:49
#
# Scraped 114 users this round
# Got 204 reivews
# 554009 reviews are now in the bag, so to speak
# 2024-04-03 05:50:53
#
# Scraped 102 users this round
# Got 166 reivews
# 554175 reviews are now in the bag, so to speak
# 2024-04-03 05:54:04
#
# Scraped 108 users this round
# Got 179 reivews
# 554354 reviews are now in the bag, so to speak
# 2024-04-03 05:57:38
#
# Scraped 124 users this round
# Got 162 reivews
# 554516 reviews are now in the bag, so to speak
# 2024-04-03 06:01:49
#
# Scraped 101 users this round
# Got 200 reivews
# 554716 reviews are now in the bag, so to speak
# 2024-04-03 06:05:09
#
# Scraped 122 users this round
# Got 184 reivews
# 554900 reviews are now in the bag, so to speak
# 2024-04-03 06:09:13
#
# Scraped 99 users this round
# Got 165 reivews
# 555065 reviews are now in the bag, so to speak
# 2024-04-03 06:12:37
#
# Scraped 98 users this round
# Got 193 reivews
# 555258 reviews are now in the bag, so to speak
# 2024-04-03 06:15:53
#
# Scraped 107 users this round
# Got 145 reivews
# 555403 reviews are now in the bag, so to speak
# 2024-04-03 06:19:20
#
# Scraped 113 users this round
# Got 227 reivews
# 555630 reviews are now in the bag, so to speak
# 2024-04-03 06:23:18
#
# Scraped 111 users this round
# Got 188 reivews
# 555818 reviews are now in the bag, so to speak
# 2024-04-03 06:27:08
#
# Scraped 105 users this round
# Got 185 reivews
# 556003 reviews are now in the bag, so to speak
# 2024-04-03 06:30:51
#
# Scraped 111 users this round
# Got 193 reivews
# 556196 reviews are now in the bag, so to speak
# 2024-04-03 06:34:58
#
# Scraped 115 users this round
# Got 197 reivews
# 556393 reviews are now in the bag, so to speak
# 2024-04-03 06:39:23
#
# Scraped 123 users this round
# Got 179 reivews
# 556572 reviews are now in the bag, so to speak
# 2024-04-03 06:43:27
#
# Scraped 139 users this round
# Got 196 reivews
# 556768 reviews are now in the bag, so to speak
# 2024-04-03 06:48:15
#
# Scraped 96 users this round
# Got 183 reivews
# 556951 reviews are now in the bag, so to speak
# 2024-04-03 06:51:20
#
# Scraped 111 users this round
# Got 164 reivews
# 557115 reviews are now in the bag, so to speak
# 2024-04-03 06:55:13
#
# Scraped 119 users this round
# Got 171 reivews
# 557286 reviews are now in the bag, so to speak
# 2024-04-03 06:59:13
#
# Scraped 120 users this round
# Got 178 reivews
# 557464 reviews are now in the bag, so to speak
# 2024-04-03 07:03:15
#
# Scraped 108 users this round
# Got 204 reivews
# 557668 reviews are now in the bag, so to speak
# 2024-04-03 07:07:01
#
# Scraped 116 users this round
# Got 178 reivews
# 557846 reviews are now in the bag, so to speak
# 2024-04-03 07:10:54
#
# Scraped 117 users this round
# Got 197 reivews
# 558043 reviews are now in the bag, so to speak
# 2024-04-03 07:14:57
#
# Scraped 103 users this round
# Got 172 reivews
# 558215 reviews are now in the bag, so to speak
# 2024-04-03 07:18:23
#
# Scraped 103 users this round
# Got 208 reivews
# 558423 reviews are now in the bag, so to speak
# 2024-04-03 07:21:47
#
# Scraped 96 users this round
# Got 178 reivews
# 558601 reviews are now in the bag, so to speak
# 2024-04-03 07:25:05
#
# Scraped 115 users this round
# Got 200 reivews
# 558801 reviews are now in the bag, so to speak
# 2024-04-03 07:29:26
#
# Scraped 133 users this round
# Got 174 reivews
# 558975 reviews are now in the bag, so to speak
# 2024-04-03 07:34:25
#
# Scraped 108 users this round
# Got 164 reivews
# 559139 reviews are now in the bag, so to speak
# 2024-04-03 07:38:01
#
# Scraped 108 users this round
# Got 189 reivews
# 559328 reviews are now in the bag, so to speak
# 2024-04-03 07:41:43
#
# Scraped 112 users this round
# Got 167 reivews
# 559495 reviews are now in the bag, so to speak
# 2024-04-03 07:45:34
#
# Scraped 118 users this round
# Got 161 reivews
# 559656 reviews are now in the bag, so to speak
# 2024-04-03 07:49:29
#
# Scraped 114 users this round
# Got 202 reivews
# 559858 reviews are now in the bag, so to speak
# 2024-04-03 07:53:24
#
# Scraped 111 users this round
# Got 188 reivews
# 560046 reviews are now in the bag, so to speak
# 2024-04-03 07:57:23
#
# Scraped 100 users this round
# Got 183 reivews
# 560229 reviews are now in the bag, so to speak
# 2024-04-03 08:01:05
#
# Scraped 118 users this round
# Got 176 reivews
# 560405 reviews are now in the bag, so to speak
# 2024-04-03 08:05:29
#
# Scraped 110 users this round
# Got 181 reivews
# 560586 reviews are now in the bag, so to speak
# 2024-04-03 08:09:29
#
# Scraped 129 users this round
# Got 217 reivews
# 560803 reviews are now in the bag, so to speak
# 2024-04-03 08:14:15
#
# Scraped 106 users this round
# Got 192 reivews
# 560995 reviews are now in the bag, so to speak
# 2024-04-03 08:18:40
#
# Unable to parse review blocks.
