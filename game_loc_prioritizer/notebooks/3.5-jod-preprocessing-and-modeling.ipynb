# %% [markdown]
# ### Preprocessing
#
# Uses the following data:
# 1. games_df, a table of general information about (almost) all Steam games
# 2. review_table, a table of 6+million reviews scraped from the Steam store, listing the user, game, etc
# 3. recently_played_df, a table of users' recently played games with playtimes
#
# Accomplishes the following:
# 1. Generate tables containing vectors for every game and every user. Our inputs will be limited to items in this table.
# 2. Generate reduced tables containing vectors of only the games and users that have rich enough info to be useful for prediction.

# %%
import pandas as pd
import numpy as np

from bidict import bidict

import pickle
import pyarrow as pa
import pyarrow.parquet as pq


import scipy.sparse as sp
from scipy.sparse import coo_matrix, csr_matrix, lil_matrix, save_npz

# %store -r tags_dict

# %%
# Load

with open('../data/interim/1 - Games DF - Wrangled.pkl', 'rb') as file :
    games_df = pickle.load(file)

review_table = pq.read_table('../data/interim/cleaned_reviews.parquet')

with open('../data/interim/recently_played_cleaned.pkl', 'rb') as file :
    recently_played_df = pickle.load(file)

# %% [markdown]
# ### Make games vectors/matrices
#
# We'll produce one matrix with all known games. This will be used to vectorize input.
#
# Then we'll produce a matrix that contains only those games with sufficient information to be subjects of recommendation.

# %%
# Isolate the info we'll use for the vectors
games_df_tags_only = games_df[['app_id', 'tags', 'tag_list']]
games_df_tags_only.head()
# Out:
#     app_id                                               tags  \
# 0      730  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1   553850  [Action, Online Co-Op, Multiplayer, Third-Pers...
# 2  1086940  [RPG, Choices Matter, Story Rich, Character Cu...
# 3  1245620  [Souls-like, Dark Fantasy, Open World, RPG, Di...
# 4  1623730  [Multiplayer, Open World, Survival, Creature C...
#
#                                             tag_list
# 0  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1  [Action, Online Co-Op, Third-Person Shooter, M...
# 2  [RPG, Choices Matter, Story Rich, Character Cu...
# 3  [Souls-like, Dark Fantasy, Open World, RPG, Di...
# 4  [Multiplayer, Open World, Survival, Creature C...

# %%
# Make a handy dict for the app_ids and their new indexes
game_to_full_index = bidict()
for index, row in games_df_tags_only.iterrows() :
    game_to_full_index[index] = row['app_id']
game_to_full_index = game_to_full_index.inverse

# %%
# Get our list of columns
used_tags = set(tags_dict.values())

# %%
# Prepare our sparse matrix
# NOTE: We will weight PRIMARY tags more strongly than non-primary tags.
# A lower weight_ratio favors primary tags more.

weight_ratio = 0.8

matrix_values = []

for index, row in games_df_tags_only.iterrows() :
    skips = set()
    for tag in row['tags'] :
        skips.add(tag)
        tup = (index, tag, 1)
        matrix_values.append(tup)
    for tag in row['tag_list'] :
        if tag not in skips :
                    tup = (index, tag, weight_ratio)
                    matrix_values.append(tup)

matrix_values[0]
# Out:
# (0, 'FPS', 1)

# %%
# To make the matrix, we must index our tags.
tag_to_col_index = bidict()
i = 0
for value in tags_dict.values() :
    tag_to_col_index[value] = i
    i += 1

# %%
# Make the matrix

rows = [row[0] for row in matrix_values]
columns = [tag_to_col_index[row[1]] for row in matrix_values]
values = [row[2] for row in matrix_values]

matrix_row_count = max(rows)+1
matrix_col_count = max(columns)+1

game_tags_matrix = coo_matrix((values, (rows, columns)), shape=(matrix_row_count, matrix_col_count))
game_tags_matrix = csr_matrix(game_tags_matrix)

# %%
# Good job, everybody! Let's save it and move on.
save_npz('../data/processed/full_game_tag_matrix.npz', game_tags_matrix)

# And also the index dicts.
with open('../data/processed/tag_to_col_index.pkl', "wb") as file :
    pickle.dump(tag_to_col_index, file)

with open('../data/processed/game_to_full_index.pkl', "wb") as file :
    pickle.dump(game_to_full_index, file)

# %% [markdown]
# Now we subset this matrix to include only games with 10+ tags.
#
# This index will be smaller, but we must be careful to note the original index values. That's the only way we can relate the rows in this matrix to any other matrix.

# %%
nonzero_counts = pd.Series(game_tags_matrix.getnnz(axis=1))
can_keep = nonzero_counts >= 10
game_tags_matrix_reduced = game_tags_matrix[can_keep]

## This creates a dict with:
##  KEYS == reduced matrix index
##  VALUES == corresponding full matrix index
game_reduced_index_to_full_index = bidict()
i=0
for index, value in can_keep.items() :
    if value==True :
        game_reduced_index_to_full_index[i]=index
        i += 1

# %%
# Save! That! Matrix!
save_npz('../data/processed/reduced_game_tag_matrix.npz', game_tags_matrix_reduced)

# And the dict, of course.
with open('../data/processed/game_reduced_index_to_full_index.pkl', 'wb') as file :
    pickle.dump(game_reduced_index_to_full_index, file)

# %% [markdown]
# ### Now we make the users matrices...

# %%
recently_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4181501 entries, 0 to 4181500
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user         object
#  1   app_id       int64
#  2   playtime_2w  int64
#  3   playtime_f   int64
# dtypes: int64(3), object(1)
# memory usage: 127.6+ MB

# %%
review_table.shape
# Out:
# (6747619, 11)

# %%
# Because our games_df does not contain every single game on Steam, it's possible
# that a game will be touched in a review or recently_played about which we cannot
# make inference.
# Let's make a set of all usable games to help limit our tables to legal values.
usable_app_ids = set(games_df['app_id'].values)
len(usable_app_ids)
# Out:
# 100894

# %%
# Now let's reduce the above datasets to only those which touch usable games.
recently_played_df = recently_played_df[recently_played_df['app_id'].isin(usable_app_ids)].reset_index(drop=True)
recently_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3593525 entries, 0 to 3593524
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user         object
#  1   app_id       int64
#  2   playtime_2w  int64
#  3   playtime_f   int64
# dtypes: int64(3), object(1)
# memory usage: 109.7+ MB

# %%
# To subset the review_talbe, we'll have to pandacize it first.

review_df = review_table.to_pandas()
review_df = review_df[review_df['app_id'].isin(usable_app_ids)].reset_index(drop=True)
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5726093 entries, 0 to 5726092
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user             object
#  1   app_id           int64
#  2   positive         int64
#  3   total_playtime   float64
#  4   review_playtime  float64
#  5   text             object
#  6   helpful_count    int64
#  7   review_date      object
#  8   edit_date        object
#  9   date_scraped     object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 436.9+ MB

# %%
# We should save processed versions of these for use in the modeling notebook.
usable_review_table = pa.Table.from_pandas(review_df)
pq.write_table(usable_review_table, '../data/processed/usable_review_table.parquet')

with open('../data/processed/usable_recently_played.pkl', 'wb') as file :
    pickle.dump(recently_played_df, file)

# %%
# The two tables above contain different but overlapping sets of users.
# In order to combine them into a single users matrix, we must first create
# a unified index for all touched users.

recently_users = set(recently_played_df['user'].values)
review_users = set(review_table['user'].to_pylist())
touched_users = recently_users | review_users

user_to_full_index = bidict()
i=0
for user in touched_users :
    user_to_full_index[user] = i
    i+=1

# %%
# We also need a unified index for games.

recently_games =set(recently_played_df['app_id'].values)
review_games = set(review_table['app_id'].to_pylist())
touched_games = recently_games | review_games

game_to_col_index = bidict()
i=0
for game in touched_games :
    game_to_col_index[game] = i
    i+=1

# %%
# Now let's prepare our points.

recently_played_points = recently_played_df.apply( \
                                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], 0.2), axis=1) \
                                .tolist()

# %%
# Since we'll have to update this matrix in a sec, let's make it a lil_matrix first.

user_info_matrix = lil_matrix((len(touched_users), len(touched_games)), dtype=float)

for point in recently_played_points :
    user_info_matrix[point[0], point[1]] = point[2]

# %%
# Now let's prepare the review data to update that matrix.

positive_reviews = review_df[review_df['positive']==1][['user', 'app_id']]
negative_reviews = review_df[review_df['positive']==0][['user', 'app_id']]

positive_points = positive_reviews.apply( \
                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], 1), axis=1) \
                .tolist()
                                
negative_points = negative_reviews.apply( \
                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], -1), axis=1) \
                .tolist()

# %%
## Now, we update the matrix.

for point in positive_points :
    user_info_matrix[point[0], point[1]] = point[2]

for point in negative_points :
    user_info_matrix[point[0], point[1]] = point[2]

# %%
## Just for funsies, make it the same format as our games matrix.
user_info_matrix = user_info_matrix.tocsr()

# %%
# Save! That! Matrix!
save_npz('../data/processed/user_info_matrix.npz', user_info_matrix)

# And the dicts, of course.
with open('../data/processed/user_to_full_index.pkl', 'wb') as file :
    pickle.dump(user_to_full_index, file)

with open('../data/processed/game_to_col_index.pkl', 'wb') as file :
    pickle.dump(game_to_col_index, file)

# %%
# Now we create a subset of the matrix that contains only users with enough info for prediction.
# Where should we put the threshold?

nonzero_counts = pd.Series(user_info_matrix.getnnz(axis=1))
nonzero_counts.describe()
# Out:
# count    1.887354e+06
# mean     4.779766e+00
# std      7.041132e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      6.000000e+00
# max      5.517000e+03
# dtype: float64

# %%
# I'll arbitrarily choose 5. Sue me! I dare you.

can_keep = nonzero_counts >= 5
user_info_matrix_reduced = user_info_matrix[can_keep]

## This creates a dict with:
##  KEYS == reduced matrix index
##  VALUES == corresponding full matrix index

user_reduced_index_to_full_index = bidict()
i=0
for index, value in can_keep.items() :
    if value==True :
        user_reduced_index_to_full_index[i]=index
        i += 1

# %%
# Save! That! Matrix!
save_npz('../data/processed/user_info_matrix_reduced.npz', user_info_matrix_reduced)

# etc etc
with open('../data/processed/user_reduced_index_to_full_index.pkl', 'wb') as file :
    pickle.dump(user_reduced_index_to_full_index, file)

# %% [markdown]
# At time of inference, the top X consine similarity users' rows will be called up, and the most common games not already played by the user will be recommended.

# %% [markdown]
# # Modeling
#
# Describes a system for taking a single user_id as an input and generating game recommendations.

# %%
from scipy import stats

from scipy.sparse import load_npz
from sklearn.metrics.pairwise import cosine_similarity

from bayes_opt import BayesianOptimization

import time
import random

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
# Load the dfs to display the rec results in a human-readable way
with open('../data/interim/1 - Games DF - Wrangled.pkl', 'rb') as file :
    games_df = pickle.load(file)
with open('../data/processed/usable_recently_played.pkl', 'rb') as file :
    recently_played_df = pickle.load(file)
review_table = pq.read_table('../data/processed/usable_review_table.parquet')
with open('../data/raw/all_users', 'rb') as file :
    all_users = pickle.load(file)

# Load the tables used to define input
game_tags_matrix = load_npz('../data/processed/full_game_tag_matrix.npz')
user_info_matrix = load_npz('../data/processed/user_info_matrix.npz')

# Load the tables used for inference
game_tags_matrix_reduced = load_npz('../data/processed/reduced_game_tag_matrix.npz')
user_info_matrix_reduced = load_npz('../data/processed/user_info_matrix_reduced.npz')

# Load the index converters for the games/tags matrix
with open('../data/processed/tag_to_col_index.pkl', "rb") as file :
    tag_to_col_index = pickle.load(file)
with open('../data/processed/game_reduced_index_to_full_index.pkl', 'rb') as file :
    game_reduced_index_to_full_index = pickle.load(file)
with open('../data/processed/game_to_full_index.pkl', 'rb') as file :
    game_to_full_index = pickle.load(file)

# Load the index converters for the users/games matrix
with open('../data/processed/user_to_full_index.pkl', 'rb') as file :
    user_to_full_index = pickle.load(file)
with open('../data/processed/game_to_col_index.pkl', 'rb') as file :
    game_to_col_index = pickle.load(file)
with open('../data/processed/user_reduced_index_to_full_index.pkl', 'rb') as file :
    user_reduced_index_to_full_index = pickle.load(file)

# %% [markdown]
# ## Define the functions

# %% [markdown]
# ### Collaborative recommendations, step 1: find similar users

# %%
# Get an arbitrary number of similar users
def get_similar_users(target_user_row, similar_user_limit=50, test_user_indices=[], testing=False, verbose=False) :
    """
    Takes a user id and returns a sorted descending series of the X most similar users:
        keys = user index (in the reduced matrix)
        values = cosine similarity
    Rows that have played no games that the target user hasn't also played are removed,*
    as they have no novel info for prediction.
    """

    # Establish the indices of users that can be considered
    # (they must have played at least one game that the target user has not)
    # All users in the reduced table have played at least 5 games, so 
    # if len(target_user_touched_games) < 5 :
    #     usable_indices = [index for index in range(user_info_matrix_reduced.shape[0]) if len(set(user_info_matrix_reduced[index].indices) - target_user_touched_games) > 0]
    # else :
    #     usable_indices = range(0, user_info_matrix_reduced.shape[0])
    # NOTE: PROBABLY NEED TO TIGHTEN THIS UP A BIT!
    # I NEED TO FILTER THE MATRIX OR ASCERTAIN THE INDICES FOR USERS THAT HAVE PLAYED
    # AT LEAST ONE GAME THAT THE TARGET HAS NOT.
    # THIS MAY BE A NONISSUE, SINCE ALL USERS IN THE PREDICITON SET HAVE PLAYED AT
    # LEAST 5 GAMES, AND WE ARE REMOVING COSINE SIM SCORES OF 1
    # SO SOMEONE WHO HAS PLAYED 1 FEWER GAME MIGHT SCORE HIGHER THAN SOMEONE PLAYING 2 MORE
    # BUT ALL THE OPERATIONS I CAN THINK OF TO DO THIS ON A CSR ARE WAAAAY TOO SLOW

    # Go ahead and run cosine similarity now, so that the scores can be associated with the correct index.
    row_cosine_similarities = pd.Series(cosine_similarity(target_user_row, user_info_matrix_reduced)[0], name="similarity_score")

    # If we're testing, remove all test users from this step
    if testing==True :
        for index in row_cosine_similarities.index :
            if index in test_user_indices :
                row_cosine_similarities = row_cosine_similarities.drop(index)

    # Remove the 1s
    row_cosine_similarities = row_cosine_similarities[row_cosine_similarities < 1]

    row_cosine_similarities.sort_values(ascending=False, inplace=True)
    most_similar_users = row_cosine_similarities[:similar_user_limit]

    if verbose==True :
        print(f"Top {similar_user_limit} most similar users:")
        for index, value in most_similar_users.items() :
            print(f"{round(value, 9)} -- {index}")
            
    return(most_similar_users)

# %% [markdown]
# ### Collaborative recommendations, step 2: generate scores

# %%
# Generate suggestions based on that.
# First, find out all the games these "similar users" have played.
# Then, weight those playes by the similarity score, then sum them across users.

# NOTE：I could speed all this up by just using arrays instead of rows/columns


def get_collab_scores(similar_users, collab_filter_limit=50, target_user_touched_games=[], verbose=False) :
    
    # Convert to df for easier row/column-wise computation
    similar_users_df = pd.DataFrame(similar_users)

    # We need to make a column in the df for each game, so we grab all games
    # here (indexed by game col index).
    # We remove any games already touched by the target user along the way.
    relevant_games = set()
    for user in similar_users.keys() :
        for game in user_info_matrix[user].indices :
            if game not in target_user_touched_games :
                relevant_games.add(game)
    
    # Create a column for each game
    for game in relevant_games :
        similar_users_df[game] = 0

    # Now fill those columns with the scores
    for user in similar_users.keys() :
        for game in user_info_matrix[user].indices :
            similar_users_df.loc[user, game] = user_info_matrix[user, game]

    # Now multiply the scores by the normalized similarity score
    for user, row in similar_users_df.iterrows() :
        for game in relevant_games :
            if row[game] != 0 :
                similar_users_df.loc[user, game] = row['similarity_score'] * row[game]

    # Now collect those scores
    # NOTE: CONVERTS GAME COL INDEX BACK TO APP_ID AT THIS STEP
    collab_filt_rec_scores = {}
    for game in relevant_games:
        collab_filt_rec_scores[game_to_col_index.inverse[game]] = similar_users_df[game].sum()

    collab_filt_scores = pd.Series(collab_filt_rec_scores, name="collab_rec_score").sort_values(ascending=False)

    # Limit the output
    collab_filt_scores = collab_filt_scores[:collab_filter_limit]

    # To make them interactible with later scores, let's standardize them
    # scaler = MinMaxScaler()
    # collab_filt_scores = pd.Series(scaler.fit_transform(collab_filt_rec_scores.values.reshape(-1,1)).flatten(), index=collab_filt_rec_scores.index)
    # if verbose==True :
    #     for app_id, score in collab_filt_scores.items() :
    #         print(f"{round(score, 3)} -- {games_df[games_df['app_id']==app_id]['title'].values[0]}")
    
    return collab_filt_scores

# %% [markdown]
# ### Content-based recommendations

# %%
# NOTE: STRETCH GOAL: Determine multimodality, generate different lists of scores

# %%
# Determine most similar games for each, multiply by user preference, MinMaxScale.

def get_content_scores(target_user_row, content_filter_limit, verbose=False) :

    """
    Takes a row from the users/games table, then does the following:
        1. Finds recs for each from the reduced game/tags matrix
        2. Creates a descending-sorted 10-row Series:
            keys = game's index (relative to main games_df)
            values = queried game's cosine similarity score to the queried game
        3. Weights all values in the series by the user's preference for the game
        4. Combines all resulting series into a single series with sim scores summed
        5. Returns the series
    """

    # Get the most recent games.
    # I already have the games in terms of col indices in the users matrix.
    # I need the indices for the games matrix, to do cos similarity.

    # Go from game col index to app_id
    # played_game_app_ids = [game_to_col_index.inverse[game] for game in target_user_row.indices]
    # # Go from app_id to full game row index
    # played_game_full_matrix_row_indices = [game_to_full_index[game] for game in played_game_app_ids]

    # Find the sim scores for each game, adding them to the main list
    similarity_series_list = []
    full_row_indexes = []

    for query_index in target_user_row.indices :

        # Get the reduced game/tags matrix index
        current_app_id = game_to_col_index.inverse[query_index] 
        current_full_row_index = game_to_full_index[current_app_id]
        try :
            reduced_row_index = game_reduced_index_to_full_index.inverse[current_full_row_index]
        except :
            ####
            continue 

        # Let's grab the full row index. We will later use this to remove
        # already-touched games from the recommendations.
        full_row_indexes.append(current_full_row_index)

        # Find the similarity score between games
        # The resulting series is indexed by the reduced games matrix
        row_cosine_similarities = pd.Series(cosine_similarity(game_tags_matrix[current_full_row_index], game_tags_matrix_reduced)[0])
        # Reindex the predictions back to the full game matrix index
        row_cosine_similarities.index = [game_reduced_index_to_full_index[index] for index in row_cosine_similarities.index]
        row_cosine_similarities.sort_values(ascending=False, inplace=True)
        # Since we cannot know ahead of time how many games the user has touched,
        # and the user may have only touched one game,
        # we can safely limit the results here to the overall content filter limit.
        # This will ensure that the full number of scores are returned no matter 
        # how many games were touched. 
        # This is still indexed by the full game matrix.
        top_similar = row_cosine_similarities[:content_filter_limit]

        # Now, get a coefficient to represent the user's preference for the game in question.
        # All games similar to this game will be modified by this coefficient.
        # First we find the game's column in the full user matrix
        preference_coefficient = target_user_row[0, query_index]
        # Then we just multiply.
        top_similar = top_similar * preference_coefficient

        # That's all we need for the score! Let's append.
        similarity_series_list.append(top_similar)

        # if verbose == True :
        #     print(f"Recs for {games_df.loc[current_full_row_index]['title']}:")
        #     for rec in top_similar.items() :
        #         print(f"{round(rec[1], 3)} -- {games_df.loc[rec[0]]['title']}")

    # Combine the serieses into the main series.
    # Here it's still indexed by full game matrix index.
    final_scores = pd.Series()
    for similarity_series in similarity_series_list :
        final_scores = final_scores.add(similarity_series, fill_value=0)
    final_scores = final_scores.sort_values(ascending=False)

    # Remove already-played games from the main series
    for game in full_row_indexes :
        try :
            final_scores = final_scores.drop(labels=game)
        except :
            continue

    # Normalize the series to make it similar to the collaborative score series
    # I suppose the original values were some wonky kind of float that didn't work
    # with scipy, so we coerce them here.
    content_filt_scores = stats.zscore(final_scores.astype(float))

    # Return the desired number of values
    if len(content_filt_scores) < content_filter_limit :
        content_filter_limit = len(content_filt_scores)
    content_filt_scores = content_filt_scores[:content_filter_limit]

    # Set index to app_id
    content_filt_scores.index = [game_to_full_index.inverse[game] for game in content_filt_scores.index]

    # if verbose == True :
    #     print('------------------')
    #     for game, score in content_filt_scores.items() :
    #         print(f"{round(score, 3)} -- {games_df[games_df['app_id']==game]['title'].values[0]}")     
    
    return(content_filt_scores)

# %% [markdown]
# ### Combine the recs for final set of recs

# %%
# NOTE: Is it worth checking the scale discrepancy between the two and tweaking the ratio
# programmatically for each distribution?

# It may be that tweaking the relative weights of the collaborative and content-based filter results
# can improve accuracy. Let's define this as a function so we can play with that programmatically
# later, if need be.

def combine_scores(collaborative, content_based, double_bonus=0, popular_bias=0, ratio=0.5, recs=10) :
    """
    Takes a series of collaborative filtering scores (key=app_id, value=score)
    And a series of content based filtering scores with the same schema
    And a 0-1 ratio of importance between the two (higher ratio favors collaborative scores)
    And the "double_bonus", which is multiplied/summed to the score of each game that appears in both lists
    And a "popular_bias" which is multiplied to the pos_review_percent and added to the score
    And the number of recommendations to be returned

    Returns a series of game app_ids and recommendation scores
    """

    # Define the ratio-modified scores
    collaborative = collaborative * ratio
    content_based = content_based * (1-ratio)

    # Add them into the base final scores series
    final_recs = collaborative.add(content_based, fill_value=0)

    # Apply doubles bonus, if any
    doubles = []
    for game in collaborative.index :
        if game in content_based.index :
            doubles.append(game)
    for game in doubles :
        final_recs[game] += (final_recs[game] * double_bonus)

    # Apply popularity bonus, if any
    for index in final_recs.index :
        positive_review_percent = games_df[games_df['app_id']==index]['positive_review_percent'].values[0]
        final_recs[index] += (positive_review_percent * popular_bias)

    # Sort descending
    final_recs = final_recs.sort_values(ascending=False)

    # Determine length
    if len(final_recs) < recs :
        recs = len(final_recs)
    
    # Determine final recs
    final_recs = final_recs[:recs]

    return final_recs

# %% [markdown]
# ### Create unified function

# %%
def get_recs(user, similar_user_limit=50, collab_filter_limit=50, content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, recs=10, test_user_indices=[], test_user_rows=[], testing=False, verbose=False, show_result=False) :

    """
    Takes a user via full user matrix index
    Generates a series of recommendations
    
    """

    # Let's-a-go!
    begin = time.time()

    # Grab some useful info about the target user
    if testing==True :
        # target_user_id = user_reduced_index_to_full_index.inverse[game_reduced_index_to_full_index[user]]
        target_user_row = test_user_rows[test_user_indices.index(user)]
        # print(target_user_row)
    else :
        # target_user_id = user_to_full_index.inverse[user]
        target_user_row = user_info_matrix[user]

    target_user_touched_games = set(target_user_row.indices)

    # Display some stuff
    if show_result==True or verbose==True :
        print("------ User profile:")
        for game in target_user_touched_games :
            app_id = game_to_col_index.inverse[game]
            score = target_user_row[0, game]
            print(f"{score} - {games_df[games_df['app_id']==app_id]['title'].values[0]}")
        print("--------------------")

    # Get similar users
    most_similar_users = get_similar_users(target_user_row, similar_user_limit=similar_user_limit, test_user_indices=test_user_indices, testing=testing, verbose=False)
    if verbose==True :
        print("\nTop 5 most similar users\n")
        print(most_similar_users.head())
        print("--------------------------")

    # Print the params here to make it easier to intuit what's happening in the results
    if verbose==True :
        print(f"similar_user_limit: {similar_user_limit}")
        print(f"collab_filter_limit: {collab_filter_limit}")
        print(f"content_filter_limit: {content_filter_limit}")
        print(f"double_bonus: {round(double_bonus, 3)}")
        print(f"popular_bias: {round(popular_bias, 3)}")
        print(f"ratio col/con: {round(ratio, 3)}")
        print(f"num of recs: {recs}\n")

    # Get scores from them
    collab_filt_scores = get_collab_scores(most_similar_users, collab_filter_limit=collab_filter_limit, target_user_touched_games=target_user_touched_games, verbose=False)
    if verbose==True :
        print("Top 8 collab filt scores")
        for index, item in collab_filt_scores.head(8).items() :
            print(f"{round(item, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------------")

    # Get content filtering scores
    content_filt_scores = get_content_scores(target_user_row, content_filter_limit=content_filter_limit,  verbose=False)
    if verbose==True :
        print("Top 8 content filt scores")
        for index, item in content_filt_scores.head(8).items() :
            print(f"{round(item, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------------")
    
    # Calculate final scores
    final_recs = combine_scores(collab_filt_scores, content_filt_scores, double_bonus=double_bonus, popular_bias=popular_bias, ratio=ratio, recs=recs)

    if show_result==True or verbose==True:
        print('')
        print('------ Recommendations')
        for index, score in final_recs.items() :
            print(f"{round(score, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------")
        print(f"\nRuntime: {round(time.time()-begin, 2)}s\n")

    return final_recs

# %% [markdown]
# ## Execution!

# %%
# NOTE: Commented out so that running the notebook skips directly to testing/evaluation

# params = {
#     "similar_user_limit":50,
#     "collab_filter_limit":50,
#     "content_filter_limit":50,
#     "double_bonus":2,
#     "popular_bias":3,
#     "ratio":0.2,
#     "recs":20,
#     "verbose":False,
#     "show_result": True
# }

# recs = get_recs(50, **params)

# %% [markdown]
# ### Testing
#
# The basic idea is to remove a game or games from a user's profile (preferably a user with a significant number of touched games) and see if the engine recommends that game for the modified user profile.

# %%
# Programmatically assemble a set of usable user profiles (10+ touched games)

def get_test_users(user_count=50, minimum_games=10) :
    """
    Returns user_count number of test users (reduced user matrix index) as a list
    Each user must have at least minimum_games number of touched games and disliked at least one game
    """
    
    # VARS
    test_user_indices = []
    checked_indices = set()
    total_users = user_info_matrix_reduced.shape[0]

    while len(test_user_indices) < user_count :
        # Find a user at random
        index = random.randint(1, total_users)
        # Make sure you haven't done this one before
        if index not in checked_indices :
            # Make sure the user has enough games
            if len(user_info_matrix_reduced[index].indices) >= minimum_games :
                # Make sure they dislike at least one game
                if -1 in user_info_matrix_reduced[index].data :
                    # Log 'em!
                    test_user_indices.append(index)
        # Log 'em!
        checked_indices.add(index)
    
    return test_user_indices

# %%
# Randomly remove one or more game(s) from each, and save as a list of rows.

def create_test_rows(test_user_indices) :
    """
    Takes a list of reduced user matrix indices (test users)
    Returns 3 items:
    1. A list of those users' rows with the most- and least- liked games removed
    2. A list of those users' most-liked games (in matching index order)
    3. A list of those users' least-liked games (in matching index order)
    """

    test_rows = []
    liked_games = []
    disliked_games = []

    for test_user in test_user_indices :
        current_row = user_info_matrix_reduced[test_user]

        # Pick a game they LIKED VERY MUCH to remove
        liked_game = np.argmax(current_row.data)

        # Pick a game they HATED to remove.
        # It's possible that all values are positive, in which case this variable will
        # have no meaning. We will check that at the evaluation phase.
        # For now, we'll pull the value no matter what to perserve index relationships.
        disliked_game = np.argmin(current_row.data)

        # Save the values for evaluation
        liked = (test_user, current_row.indices[liked_game], current_row.data[liked_game])
        liked_games.append(liked)
        disliked = (test_user, current_row.indices[disliked_game], current_row.data[disliked_game])
        disliked_games.append(disliked)

        # Remove the values

        lil_row = current_row.tolil()
        lil_row[0, liked[1]] = 0
        lil_row[0, disliked[1]] = 0
        current_row = lil_row.tocsr()
        current_row.eliminate_zeros()

        # Add it to the list
        test_rows.append(current_row)
        
    return test_rows, liked_games, disliked_games

# %%
# Evaluation function

# Checks to see if POSITIVE game is in top X recs: +
# Checks to see if NEGATIVE game is in recs at all: -

def binary_evaluator(results, verbose=False) :
    """"
    Takes a list of tuples with the schema:
        1. Series of recommendations (key=app_id, value=utility score)
        2. app_id of favorite game
        3. app_id of least favorite game

    Evaluates the recommendations in each tuple by:
        Adding 1 to the overall score if the favorite game is recommended
        Subtracting 1 from the overall score if the least favorite game is recommended
    
    Returns the score as an int
    """

    good = []
    bad = []

    for result in results :
        if result[1] in result[0].index :
            good.append(1)
        if (result[2] != result[1]) and (result[2] in result[0].index) :
            bad.append(1)
    
    validated = sum(good)
    disproved = sum(bad)
    score = validated - disproved

    print(f"Validated recommendations: {validated}")
    print(f"Disproved recommendations: {disproved}")

    return score

# %%
# Run inference on each modified profile


def run_a_test(test_users=50, evaluator=binary_evaluator, similar_user_limit=50, collab_filter_limit=50, \
               content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, recs=10, \
               testing=True, verbose=False, show_result=False) :
    
    # Generate X test user indices
    test_user_indices = get_test_users(test_users)

    test_rows, liked_games, disliked_games = create_test_rows(test_user_indices)

    # test_user_full_indices = [user_reduced_index_to_full_index[user] for user in test_user_indices]
    results = []

    params = {
        "test_user_indices":test_user_indices,
        "test_user_rows":test_rows,
        "similar_user_limit":similar_user_limit,
        "collab_filter_limit":collab_filter_limit,
        "content_filter_limit":content_filter_limit,
        "double_bonus":double_bonus,
        "popular_bias":popular_bias,
        "ratio":ratio,
        "recs":recs,
        "verbose":verbose,
        "show_result":show_result,
        "testing":testing
        }

    for i in range(len(test_user_indices)) :
        result = get_recs(test_user_indices[i], **params)
        results.append((result, \
                        game_to_col_index.inverse[liked_games[i][1]], \
                        game_to_col_index.inverse[disliked_games[i][1]]))
        
    score = evaluator(results)

    return score

# %%
# NOTE: Commented out so that running the notebook skips directly to testing/evaluation

# test_params = {
#     "test_users":50,
#     "evaluator":binary_evaluator,
#     "similar_user_limit":50,
#     "collab_filter_limit":50,
#     "content_filter_limit":50,
#     "double_bonus":2,
#     "popular_bias":3,
#     "ratio":0.2,
#     "recs":20,
#     "testing":True,
#     "verbose":False,
#     "show_result":True
# }

# run_a_test(**test_params)

# %% [markdown]
# ### O   P   T   I   M   I   Z   E

# %%
def boptimize(test_users=50, evaluator=binary_evaluator, n_iter=4, init_points=10, verbose=False, show_result=False) :
    
    # We'll define our test set here, so the Bayesian bit below will
    # execute on the same subset each time.

    # Generate X test user indices
    test_user_indices = get_test_users(test_users)

    # Generate test rows
    test_rows, liked_games, disliked_games = create_test_rows(test_user_indices)


    # Define the scoring function within the main function so that it has native access to variables
    def bayes_test(test_user_indices=test_user_indices, liked_games=liked_games, \
               disliked_games=disliked_games, test_rows=test_rows, evaluator=evaluator, \
               similar_user_limit=50, collab_filter_limit=50, \
               content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, \
               recs=10, testing=True, verbose=verbose, show_result=show_result) :
    
        params = {
        "test_user_indices":test_user_indices,
        "test_user_rows":test_rows,
        "similar_user_limit":int(similar_user_limit),
        "collab_filter_limit":int(collab_filter_limit),
        "content_filter_limit":int(content_filter_limit),
        "double_bonus":double_bonus,
        "popular_bias":popular_bias,
        "ratio":ratio,
        "recs":int(recs),
        "verbose":verbose,
        "show_result":show_result,
        "testing":testing
        }
        
        results = []

        for i in range(len(test_user_indices)) :
            result = get_recs(test_user_indices[i], **params)
            results.append((result, \
                            game_to_col_index.inverse[liked_games[i][1]], \
                            game_to_col_index.inverse[disliked_games[i][1]]))
            
        score = evaluator(results)
        print(score)

        return score


    # Prepare params for Bayes
    param_bounds = {
        "similar_user_limit":(250, 250),
        "collab_filter_limit":(100, 125),
        "content_filter_limit":(30, 40),
        "double_bonus":(1.5, 2.3),
        "popular_bias":(1.3, 2.5),
        "ratio":(0.4, 0.8),
        "recs":(20, 20),
        }
    
    # Execute
    optimizer = BayesianOptimization(f=bayes_test, pbounds=param_bounds, random_state=42)
    optimizer.maximize(init_points=init_points, n_iter=n_iter)
    best_params = optimizer.max
    print(best_params)

    return best_params

# %% [markdown]
# I ran the following cell many times, recording the result each time.
#
# This final iteration represents a honing-in on the most optimal parameters.
#
# A fuller discussion will be the forthcoming project report.

# %%
boptimize(test_users=100, n_iter=15, init_points=8, show_result=True)
# Out:
# |   iter    |  target   | collab... | conten... | double... | popula... |   ratio   |   recs    | simila... |
# -------------------------------------------------------------------------------------------------------------
# ------ User profile:
# 1.0 - Against the Storm
# 1.0 - Stacklands
# 1.0 - Apex Legends™
# 0.2 - Don't Starve Together
# 0.2 - Frostpunk
# 1.0 - Lethal Company
# 1.0 - Among Us
# 1.0 - Oxygen Not Included
# 1.0 - Sea of Thieves 2023 Edition
# 0.2 - Noita
# 1.0 - Deceive Inc.
# 1.0 - 7 Days to Die
# 1.0 - Metal: Hellsinger
# -1.0 - Cossacks 3
# 0.2 - Crypt of the NecroDancer
# -1.0 - The Elder Scrolls V: Skyrim Special Edition
# 0.2 - Don't Starve
# 1.0 - Omega Strikers
# 1.0 - Industries of Titan
# 0.2 - Songs of Conquest
# --------------------
# ------ Recommendations
# 5.726 -- Counter-Strike 2
# 4.698 -- PUBG: BATTLEGROUNDS
# 4.205 -- Dota 2
# 3.734 -- Judgment: Apocalypse Survival Simulation
# 3.429 -- Team Fortress 2
# 3.297 -- Empires of the Undergrowth
# 3.239 -- RimWorld
# 3.175 -- Paladins®
# 3.042 -- The Final Earth 2
# 2.949 -- Space Haven
# 2.848 -- Garry's Mod
# 2.816 -- IXION
# 2.808 -- Surviving Mars
# 2.789 -- Grand Theft Auto V
# 2.767 -- First Feudal
# 2.741 -- Terraria
# 2.724 -- Baldur's Gate 3
# 2.72 -- Deducto
# 2.717 -- Blazing Sails
# 2.656 -- Aquatico
# --------------------
#
# Runtime: 10.05s
#
# ------ User profile:
# 1.0 - ARMA: Cold War Assault
# 1.0 - Terraria
# 1.0 - Risk of Rain 2
# 1.0 - Vampire Survivors
# 1.0 - No More Room in Hell
# 1.0 - Helltaker
# 1.0 - Stellaris
# 1.0 - Trove
# --------------------
#
# ------ Recommendations
# 8.179 -- Counter-Strike 2
# 5.476 -- Arma 3
# 4.801 -- Force of Nature
# 4.596 -- Planet Explorers
# 4.284 -- Team Fortress 2
# 4.066 -- Dota 2
# 3.696 -- Rust
# 3.594 -- Lethal Company
# 3.451 -- Baldur's Gate 3
# 3.424 -- ELDEN RING
# 3.414 -- Left 4 Dead 2
# 3.241 -- Garry's Mod
# 3.121 -- Necesse
# 2.901 -- Halo: The Master Chief Collection
# 2.824 -- Cyberpunk 2077
# 2.795 -- Don't Starve Together
# 2.791 -- DARK SOULS™ III
# 2.786 -- Apex Legends™
# 2.778 -- Phasmophobia
# 2.758 -- Starbound
# --------------------
#
# Runtime: 9.0s
#
# ------ User profile:
# 0.2 - Resident Evil 4 (2005)
# 0.2 - NARUTO: Ultimate Ninja STORM
# 0.2 - Persona 3 Reload
# 1.0 - The Legend of Heroes: Trails in the Sky the 3rd
# 1.0 - TEKKEN 8
# 1.0 - The Legend of Heroes: Trails in the Sky SC
# 0.2 - Tom Clancy's Rainbow Six® Siege
# 0.2 - NARUTO SHIPPUDEN: Ultimate Ninja STORM 2
# 1.0 - Battlerite
# 1.0 - Lethal Company
# 1.0 - GUILTY GEAR Xrd -SIGN-
# 1.0 - TEKKEN 7
# 1.0 - The Legend of Heroes: Trails in the Sky
# 0.2 - Pummel Party
# --------------------
#
# ------ Recommendations
# 7.731 -- Counter-Strike 2
# 4.326 -- Dota 2
# 3.607 -- The Legend of Heroes: Trails of Cold Steel IV
# 3.57 -- The Legend of Heroes: Trails of Cold Steel III
# 3.539 -- The Legend of Heroes: Trails of Cold Steel II
# 3.53 -- Team Fortress 2
# 3.507 -- GUILTY GEAR Xrd REV 2
# 3.432 -- GRANDIA HD Remaster
# 3.423 -- BlazBlue: Chronophantasma Extend
# 3.416 -- BlazBlue Centralfiction
# 3.4 -- Melty Blood Actress Again Current Code
# 3.386 -- FINAL FANTASY X/X-2 HD Remaster
# 3.361 -- UNDER NIGHT IN-BIRTH Exe:Late
# 3.351 -- Garry's Mod
# 3.343 -- The Legend of Heroes: Trails of Cold Steel
# 3.291 -- GRANDIA II HD Remaster
# 3.279 -- Atelier Lydie & Suelle ~The Alchemists and the Mysterious Paintings~
# 3.241 -- Ruined King: A League of Legends Story™
# 3.228 -- Hyperdimension Neptunia Re;Birth2: Sisters Generation
# 3.203 -- THE KING OF FIGHTERS XIII STEAM EDITION
# --------------------
#
# Runtime: 8.51s
#
# ------ User profile:
# 1.0 - LIBRARY
# 1.0 - Gorogoa
# 1.0 - Live Adventure
# 1.0 - NaissanceE
# 1.0 - Beyond The Edge Of Owlsgard
# 1.0 - Lume
# 1.0 - Zniw Adventure
# -1.0 - Maize
# 1.0 - Terraria
# 1.0 - Superflight
# -1.0 - Samorost 2
# 1.0 - Golf With Your Friends
# 1.0 - Crescent Cauldron Cafe
# 1.0 - Wuppo: Definitive Edition
# 1.0 - Marble Skies
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 7.36 -- Counter-Strike 2
# 4.596 -- Starbound
# 4.007 -- Team Fortress 2
# 3.068 -- Lethal Company
# 3.005 -- GRIS
# 2.904 -- Left 4 Dead 2
# 2.852 -- Pierre's Adventures in French [Learn French]
# 2.805 -- Baldur's Gate 3
# 2.788 -- ELDEN RING
# 2.713 -- Garry's Mod
# 2.7 -- Reversion - The Return (Last Chapter)
# 2.673 -- Stardew Valley
# 2.654 -- Dota 2
# 2.59 -- Destiny 2
# 2.565 -- Tom Clancy's Rainbow Six® Siege
# 2.526 -- Phasmophobia
# 2.512 -- CHUCHEL
# 2.506 -- Rust
# 2.441 -- DARK SOULS™ III
# 2.419 -- Necesse
# --------------------
#
# Runtime: 9.03s
#
# ------ User profile:
# 0.2 - Bejeweled® 3
# 0.2 - Counter-Strike 2
# 1.0 - Don't Starve Together
# 1.0 - Plants vs. Zombies GOTY Edition
# 1.0 - Foxhole
# 1.0 - AdVenture Capitalist
# 1.0 - The Wild Eight
# 0.2 - Overwatch® 2
# 0.2 - NGU IDLE
# 0.2 - Terraria
# 1.0 - Tricky Towers
# 1.0 - Human Fall Flat
# 1.0 - Tabletop Simulator
# 1.0 - Trove
# 1.0 - Brawlhalla
# 1.0 - Goat Simulator
# 1.0 - Stardew Valley
# 1.0 - Enter the Gungeon
# 1.0 - Don't Starve
# 0.2 - The Binding of Isaac: Rebirth
# 1.0 - Duck Game
# --------------------
#
# ------ Recommendations
# 7.925 -- Raft
# 7.505 -- Subnautica
# 4.628 -- Necesse
# 4.586 -- Team Fortress 2
# 4.281 -- The Long Dark
# 4.084 -- ELDEN RING
# 3.851 -- Ethereal Estate
# 3.65 -- Dota 2
# 3.577 -- Planet Explorers
# 3.386 -- Left 4 Dead 2
# 3.337 -- The Witcher® 3: Wild Hunt
# 3.278 -- Baldur's Gate 3
# 3.27 -- Forager
# 3.134 -- Green Hell
# 3.083 -- Grounded
# 3.066 -- Voidtrain
# 3.017 -- Totally Reliable Delivery Service
# 3.013 -- PlayForm: Human Dynamics
# 2.995 -- Fighties
# 2.98 -- Dead Rising 3 Apocalypse Edition
# --------------------
#
# Runtime: 9.16s
#
# ------ User profile:
# 0.2 - STAR WARS™ Republic Commando™
# 0.2 - STAR WARS™ Empire at War - Gold Pack
# -1.0 - SpongeBob SquarePants: Battle for Bikini Bottom - Rehydrated
# 0.2 - Dota 2
# -1.0 - Stronghold Crusader 2
# 0.2 - MARVEL SNAP
# 0.2 - Apex Legends™
# 0.2 - Street Fighter™ 6
# 1.0 - Pacify
# 0.2 - STAR WARS Jedi: Fallen Order™
# --------------------
#
# ------ Recommendations
# 7.12 -- Lethal Company
# 5.927 -- Counter-Strike 2
# 3.73 -- Team Fortress 2
# 3.64 -- Terraria
# 2.943 -- Garry's Mod
# 2.911 -- Left 4 Dead 2
# 2.796 -- FOREWARNED
# 2.748 -- The Witcher® 3: Wild Hunt
# 2.73 -- Lunch Lady
# 2.711 -- Phasmophobia
# 2.693 -- Inside the Backrooms
# 2.672 -- Remnant Records
# 2.647 -- Stardew Valley
# 2.637 -- Dark Fracture: Prologue
# 2.617 -- Sekiro™: Shadows Die Twice - GOTY Edition
# 2.579 -- Among Us
# 2.555 -- Warframe
# 2.554 -- Tom Clancy's Rainbow Six® Siege
# 2.542 -- Dying Light
# 2.514 -- Vampire Survivors
# --------------------
#
# Runtime: 8.92s
#
# ------ User profile:
# 1.0 - THE KING OF FIGHTERS XV
# 1.0 - Mortal Kombat 1
# 1.0 - Retrowave
# 1.0 - Resident Evil 2
# 1.0 - Forza Horizon 4
# 1.0 - Injustice: Gods Among Us Ultimate Edition
# 1.0 - Pretty Neko
# 1.0 - Resident Evil 7 Biohazard
# 1.0 - RetroArch
# --------------------
#
# ------ Recommendations
# 5.058 -- Counter-Strike 2
# 4.372 -- Mortal Kombat 11
# 4.28 -- Killer Instinct
# 4.242 -- Injustice™ 2
# 4.009 -- GUILTY GEAR Xrd REV 2
# 3.998 -- GUILTY GEAR Xrd -SIGN-
# 3.659 -- TEKKEN 7
# 3.389 -- Terraria
# 3.35 -- Team Fortress 2
# 3.336 -- Resident Evil 0
# 3.195 -- EBOLA 3
# 3.173 -- EBOLA 2
# 3.122 -- The Evil Within 2
# 3.058 -- ULTIMATE MARVEL VS. CAPCOM 3
# 2.939 -- THE KING OF FIGHTERS XIII STEAM EDITION
# 2.892 -- Garry's Mod
# 2.876 -- Guilty Gear X2 #Reload
# 2.868 -- Mortal Kombat X
# 2.8 -- THE KING OF FIGHTERS 2002 UNLIMITED MATCH
# 2.797 -- BlazBlue: Chronophantasma Extend
# --------------------
#
# Runtime: 7.95s
#
# ------ User profile:
# 1.0 - ARMORED CORE™ VI FIRES OF RUBICON™
# 1.0 - ACE COMBAT™ 7: SKIES UNKNOWN
# 0.2 - TT Isle of Man: Ride on the Edge
# 1.0 - Genital Jousting
# 1.0 - Project Wingman
# 1.0 - Palworld
# 1.0 - Muse Dash
# 1.0 - Swarmlake
# 1.0 - Fate/EXTELLA LINK
# 1.0 - Doki Doki Literature Club!
# 0.2 - SCARLET NEXUS
# 0.2 - SteamVR
# 1.0 - VRChat
# -1.0 - Fate/Samurai Remnant
# 0.2 - War Thunder
# 1.0 - The Exit 8
# 0.2 - Windowkill
# -1.0 - Groove Coaster
# 1.0 - MissileDancer
# --------------------
#
# ------ Recommendations
# 5.312 -- Counter-Strike 2
# 3.67 -- Team Fortress 2
# 3.314 -- Bit Blaster XL
# 3.303 -- Dota 2
# 3.07 -- Geometry Wars: Retro Evolved
# 3.041 -- LUFTRAUSERS
# 2.995 -- Trap Legend
# 2.994 -- Garry's Mod
# 2.934 -- Trap Shrine
# 2.919 -- Hyperdimension Neptunia U: Action Unleashed
# 2.913 -- IL-2 Sturmovik: Battle of Stalingrad
# 2.877 -- ELDEN RING
# 2.875 -- Vincemus - Air Combat
# 2.775 -- Vampire Survivors
# 2.744 -- Left 4 Dead 2
# 2.686 -- Terraria
# 2.59 -- Resident Evil 4
# 2.582 -- Hades
# 2.581 -- Baldur's Gate 3
# 2.556 -- Portal 2
# --------------------
#
# Runtime: 8.99s
#
# ------ User profile:
# 0.2 - Unnamed Space Idle
# 0.2 - Yu-Gi-Oh! Master Duel
# 0.2 - Mortal Kombat X
# 0.2 - Cyberpunk 2077
# 0.2 - Mr.Mine
# 0.2 - Idle Slayer
# 1.0 - To the Moon
# 0.2 - Don't Starve Together
# 0.2 - Firestone: Online Idle RPG
# 1.0 - Clicker Heroes
# --------------------
#
# ------ Recommendations
# 11.377 -- Counter-Strike 2
# 3.958 -- Team Fortress 2
# 3.539 -- Wizard And Minion Idle
# 3.534 -- Dead by Daylight
# 3.484 -- Soda Dungeon
# 3.382 -- Fastest Hands In The WASD
# 3.358 -- Crusaders of the Lost Idols
# 3.292 -- HELLDIVERS™ 2
# 3.289 -- Sid Meier's Civilization® V
# 3.26 -- Tom Clancy's Rainbow Six® Siege
# 3.23 -- Garry's Mod
# 3.177 -- ELDEN RING
# 3.145 -- Guild Quest
# 3.121 -- Zombidle : REMONSTERED
# 3.087 -- Arma 3
# 3.08 -- PAYDAY 2
# 3.079 -- Left 4 Dead 2
# 3.075 -- AdVenture Capitalist
# 3.062 -- Terraria
# 3.047 -- Dragon Cliff
# --------------------
#
# Runtime: 7.92s
#
# ------ User profile:
# 1.0 - Bloodshore
# 1.0 - Chernobylite Enhanced Edition
# 1.0 - theHunter: Call of the Wild™
# -1.0 - Battlefield™ 1
# 1.0 - Last Train Home
# 1.0 - The Dark Pictures Anthology: Little Hope
# 1.0 - Holdfast: Nations At War
# 1.0 - Resident Evil Village
# 1.0 - UNCHARTED™: Legacy of Thieves Collection
# 1.0 - Dead Space
# 1.0 - Horizon Zero Dawn™ Complete Edition
# 1.0 - Titanfall® 2
# 1.0 - Days Gone
# 1.0 - The Dark Pictures Anthology: House of Ashes
# 1.0 - Who Pressed Mute on Uncle Marcus?
# 1.0 - Resident Evil 7 Biohazard
# 1.0 - The Light Remake
# --------------------
#
# ------ Recommendations
# 5.746 -- Resident Evil 4
# 4.905 -- The Evil Within 2
# 4.599 -- Counter-Strike 2
# 3.876 -- Dota 2
# 3.23 -- Resident Evil 7 Teaser: Beginning Hour
# 3.174 -- Outlast 2
# 3.127 -- Team Fortress 2
# 3.069 -- Eternal Evil
# 3.067 -- Left 4 Dead 2
# 3.029 -- Rise of the Tomb Raider™
# 3.028 -- EBOLA 3
# 3.004 -- Terraria
# 2.986 -- EBOLA 2
# 2.954 -- Metro Exodus
# 2.948 -- The Walking Dead: Saints & Sinners
# 2.923 -- Marvel’s Spider-Man Remastered
# 2.913 -- FROSTBITE: Deadly Climate
# 2.857 -- Garry's Mod
# 2.839 -- El Paso, Elsewhere
# 2.836 -- The Beast Inside
# --------------------
#
# Runtime: 9.06s
#
# ------ User profile:
# 1.0 - Rust
# 1.0 - Realm Royale Reforged
# 1.0 - Crab Game
# 1.0 - Arma 3
# -1.0 - BattleBit Remastered
# 1.0 - DayZ
# 1.0 - Planet Zoo
# 1.0 - Plants vs. Zombies GOTY Edition
# 0.2 - THE FINALS
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 5.566 -- Counter-Strike 2
# 4.111 -- Team Fortress 2
# 3.16 -- Warframe
# 3.038 -- Baldur's Gate 3
# 3.033 -- Garry's Mod
# 2.951 -- Unturned
# 2.923 -- Dota 2
# 2.905 -- Undertale
# 2.893 -- Don't Starve Together
# 2.834 -- Left 4 Dead 2
# 2.812 -- Stardew Valley
# 2.788 -- HELLDIVERS™ 2
# 2.77 -- CastleMiner Z
# 2.738 -- Red Dead Redemption 2
# 2.722 -- Helltaker
# 2.711 -- Hurtworld
# 2.7 -- INSIDE
# 2.642 -- Grand Theft Auto V
# 2.591 -- Terraria
# 2.591 -- Phasmophobia
# --------------------
#
# Runtime: 8.71s
#
# ------ User profile:
# 1.0 - Company of Heroes 3
# 1.0 - Prison Architect
# 1.0 - Arma 3
# 1.0 - Six Days in Fallujah
# 1.0 - Squad
# 1.0 - Project Wingman
# -1.0 - Call to Arms
# 1.0 - Fallout 4
# -1.0 - EmergeNYC
# --------------------
#
# ------ Recommendations
# 7.273 -- Counter-Strike 2
# 5.506 -- Insurgency: Sandstorm
# 5.487 -- Counter-Strike: Source
# 4.521 -- Fallout: New Vegas
# 3.863 -- Dota 2
# 3.655 -- Team Fortress 2
# 3.504 -- Stardew Valley
# 3.135 -- Garry's Mod
# 3.112 -- ELDEN RING
# 3.063 -- Grand Theft Auto V
# 3.047 -- Zero Hour
# 2.993 -- Baldur's Gate 3
# 2.991 -- Rust
# 2.973 -- Terraria
# 2.894 -- Rising Storm Game of the Year Edition
# 2.836 -- Red Dead Redemption 2
# 2.767 -- Left 4 Dead 2
# 2.75 -- The Witcher® 3: Wild Hunt
# 2.741 -- HELLDIVERS™ 2
# 2.68 -- Tom Clancy's Ghost Recon®
# --------------------
#
# Runtime: 8.77s
#
# ------ User profile:
# 0.2 - Deep Rock Galactic
# 0.2 - Persona 4 Golden
# 0.2 - Sons Of The Forest
# 0.2 - Penny’s Big Breakaway
# 0.2 - Stardew Valley
# 1.0 - Sonic Frontiers
# 0.2 - PowerWash Simulator
# 0.2 - Exoprimal
# 0.2 - DOOM Eternal
# 0.2 - Street Fighter™ 6
# 0.2 - Pizza Tower
# --------------------
#
# ------ Recommendations
# 9.405 -- Counter-Strike 2
# 4.957 -- Team Fortress 2
# 4.283 -- Dota 2
# 3.727 -- Terraria
# 3.633 -- Phasmophobia
# 3.583 -- Orbo's Odyssey
# 3.562 -- Solar Ash
# 3.47 -- IndependANT
# 3.45 -- Minute
# 3.421 -- Garry's Mod
# 3.399 -- Crash Bandicoot™ 4: It’s About Time
# 3.359 -- Hob
# 3.329 -- Prince of Persia®
# 3.264 -- ELDEN RING
# 3.232 -- Baldur's Gate 3
# 3.14 -- The Witcher® 3: Wild Hunt
# 3.067 -- Rust
# 3.04 -- Sonic Lost World
# 3.032 -- Immortals Fenyx Rising
# 3.006 -- DARK SOULS™ III
# --------------------
#
# Runtime: 8.39s
#
# ------ User profile:
# 1.0 - Killing Floor 2
# 1.0 - Dying Light 2 Stay Human: Reloaded Edition
# 1.0 - Bloons TD 6
# 1.0 - Dishonored 2
# 1.0 - Left 4 Dead 2
# 1.0 - Fallout 4
# 1.0 - Starfield
# 1.0 - Halo: The Master Chief Collection
# 1.0 - Dishonored
# 1.0 - Epic Battle Fantasy 5
# 1.0 - Epic Battle Fantasy 4
# --------------------
#
# ------ Recommendations
# 8.398 -- Fallout: New Vegas
# 6.866 -- Cyberpunk 2077
# 6.584 -- Counter-Strike 2
# 5.377 -- Call of Duty: World at War
# 5.231 -- Call of Duty®: Black Ops II
# 3.899 -- Stay Home
# 3.696 -- Garry's Mod
# 3.575 -- Arizona Sunshine®
# 3.499 -- Death Horizon: Reloaded
# 3.253 -- Gothic® 3
# 3.127 -- Left 4 Dead
# 3.117 -- REQUISITION VR
# 3.043 -- Tom Clancy's Rainbow Six® Siege
# 2.991 -- Killing Floor
# 2.924 -- Terraria
# 2.92 -- HELLDIVERS™ 2
# 2.914 -- Dota 2
# 2.89 -- Team Fortress 2
# 2.888 -- Dishonored®: Death of the Outsider™
# 2.85 -- Lethal Company
# --------------------
#
# Runtime: 9.37s
#
# ------ User profile:
# 1.0 - Stray
# 1.0 - What Remains of Edith Finch
# 1.0 - The Outlast Trials
# 1.0 - Fallout 3: Game of the Year Edition
# 1.0 - Tell Me Why
# -1.0 - Grand Theft Auto: San Andreas – The Definitive Edition
# 1.0 - Half-Life 2: Episode Two
# 1.0 - Cat Cafe Manager
# 1.0 - Fallout: New Vegas
# 1.0 - Stardew Valley
# 1.0 - Marvel’s Spider-Man: Miles Morales
# 1.0 - Marvel’s Spider-Man Remastered
# 1.0 - Black Mesa
# 1.0 - Phasmophobia
# 1.0 - Half-Life 2: Episode One
# 1.0 - ELDEN RING
# 1.0 - Red Dead Redemption 2
# 1.0 - Borderlands 2
# --------------------
#
# ------ Recommendations
# 7.812 -- Fallout 4
# 7.589 -- Counter-Strike 2
# 6.989 -- Halo: The Master Chief Collection
# 6.927 -- Half-Life: Alyx
# 4.353 -- Far Cry®
# 3.847 -- Half-Life 2
# 3.631 -- Horizon Zero Dawn™ Complete Edition
# 3.524 -- Half-Life: Blue Shift
# 3.463 -- Half-Life: Opposing Force
# 3.407 -- Half-Life 2: Lost Coast
# 3.298 -- S.T.A.L.K.E.R.: Call of Pripyat
# 3.294 -- Half-Life
# 3.106 -- Metro Exodus
# 3.081 -- Red Faction
# 3.068 -- Dota 2
# 3.057 -- Team Fortress 2
# 3.036 -- Metro 2033 Redux
# 2.996 -- BioShock™ Remastered
# 2.953 -- Far Cry® 4
# 2.952 -- Call of Juarez: Bound in Blood
# --------------------
#
# Runtime: 8.93s
#
# ------ User profile:
# 1.0 - Call of Duty®: Modern Warfare®
# 1.0 - Prison Architect
# 1.0 - Call of Duty®: Black Ops Cold War
# 1.0 - VTOL VR
# 1.0 - Kerbal Space Program
# 0.2 - Depraved
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - POSTAL 4: No Regerts
# 1.0 - Operation: Harsh Doorstop
# 0.2 - Arma 3
# 1.0 - Gas Station Simulator
# 0.2 - BeamNG.drive
# 1.0 - Teardown
# 1.0 - Stormworks: Build and Rescue
# 1.0 - Call of Duty®
# -1.0 - Battlefield™ 2042
# 1.0 - Phasmophobia
# -1.0 - Drug Dealer Simulator
# --------------------
#
# ------ Recommendations
# 6.965 -- Counter-Strike 2
# 5.627 -- Ready or Not
# 3.448 -- Call of Duty®: Modern Warfare® 2 (2009)
# 3.389 -- Battlefield 4™
# 3.323 -- Tom Clancy's Rainbow Six® Siege
# 3.281 -- Zero Caliber VR
# 3.218 -- Dota 2
# 3.098 -- Baldur's Gate 3
# 3.009 -- Battlefield™ Hardline
# 2.952 -- Call of Duty®: Modern Warfare® Remastered (2017)
# 2.948 -- Onward
# 2.94 -- GROUND BRANCH
# 2.877 -- The Witcher® 3: Wild Hunt
# 2.861 -- Team Fortress 2
# 2.806 -- PAYDAY 2
# 2.759 -- Brothers in Arms: Hell's Highway™
# 2.747 -- Arma 2
# 2.746 -- Call of Duty®: Black Ops
# 2.745 -- Stardew Valley
# 2.738 -- Garry's Mod
# --------------------
#
# Runtime: 8.78s
#
# ------ User profile:
# -1.0 - Halo Infinite
# -1.0 - Split or Steal
# 1.0 - PAYDAY 2
# 1.0 - War Thunder
# 0.2 - Wingspan
# 0.2 - Baldur's Gate 3
# 0.2 - Counter-Strike 2
# 1.0 - Battlerite
# --------------------
#
# ------ Recommendations
# 5.316 -- Arma 3
# 3.947 -- PUBG: BATTLEGROUNDS
# 3.596 -- Dota 2
# 3.427 -- HELLDIVERS™ 2
# 3.409 -- Dead by Daylight
# 3.356 -- Team Fortress 2
# 3.102 -- Lethal Company
# 3.039 -- Terraria
# 3.005 -- Left 4 Dead 2
# 2.996 -- Tom Clancy's Rainbow Six® Siege
# 2.861 -- ELDEN RING
# 2.813 -- Garry's Mod
# 2.78 -- Portal 2
# 2.776 -- Risk of Rain 2
# 2.755 -- Deep Rock Galactic
# 2.729 -- Doki Doki Literature Club!
# 2.714 -- Undertale
# 2.693 -- The Witcher® 3: Wild Hunt
# 2.677 -- No Man's Sky
# 2.676 -- Hades
# --------------------
#
# Runtime: 8.49s
#
# ------ User profile:
# 1.0 - ASTRONEER
# 1.0 - No Man's Sky
# 1.0 - The Binding of Isaac
# 1.0 - Kerbal Space Program
# 1.0 - Murderous Pursuits
# -1.0 - Mushroom Wars 2
# 1.0 - FTL: Faster Than Light
# 1.0 - Papers, Please
# 1.0 - Autonauts
# -1.0 - Dead by Daylight
# 1.0 - Rogue Legacy
# -1.0 - Spacebase DF-9
# --------------------
#
# ------ Recommendations
# 6.452 -- Starbound
# 4.987 -- Counter-Strike 2
# 4.31 -- Satisfactory
# 3.136 -- Dota 2
# 2.996 -- Terraria
# 2.922 -- Team Fortress 2
# 2.911 -- Garry's Mod
# 2.833 -- Space Trash Scavenger
# 2.73 -- Risk of Rain (2013)
# 2.713 -- Borderlands 2
# 2.556 -- Grand Theft Auto V
# 2.52 -- DayZ
# 2.496 -- Euro Truck Simulator 2
# 2.486 -- Drift
# 2.481 -- Left 4 Dead 2
# 2.46 -- Doki Doki Literature Club!
# 2.442 -- Voidtrain
# 2.437 -- Portal 2
# 2.431 -- Space Pirates And Zombies 2
# 2.422 -- Risk of Rain 2
# --------------------
#
# Runtime: 8.93s
#
# ------ User profile:
# 1.0 - Tomb Raider
# -1.0 - Rust
# 1.0 - Europa Universalis IV
# 1.0 - Imperator: Rome
# 0.2 - The Elder Scrolls V: Skyrim Special Edition
# 0.2 - Enter the Gungeon
# 0.2 - Don't Starve
# 0.2 - Dead Cells
# 0.2 - Team Fortress 2
# -1.0 - Hearts of Iron IV
# -1.0 - Fallout 4
# 0.2 - Don't Starve Together
# 1.0 - Dota Underlords
# -1.0 - Dying Light
# -1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 7.128 -- Counter-Strike 2
# 6.801 -- Crusader Kings III
# 6.599 -- Crusader Kings II
# 2.981 -- Terraria
# 2.955 -- Dota 2
# 2.854 -- Victoria 3
# 2.842 -- Supreme Ruler 2020 Gold
# 2.68 -- Victoria II
# 2.63 -- UNCHARTED™: Legacy of Thieves Collection
# 2.553 -- Arma 3
# 2.539 -- Left 4 Dead 2
# 2.532 -- Supreme Ruler 2030
# 2.499 -- HELLDIVERS™ 2
# 2.495 -- Tomb Raider: Legend
# 2.494 -- Sid Meier's Civilization® V
# 2.456 -- Risk of Rain 2
# 2.438 -- Tomb Raider IV: The Last Revelation
# 2.43 -- Destiny 2
# 2.418 -- Stellaris
# 2.416 -- The Forest
# --------------------
#
# Runtime: 8.33s
#
# ------ User profile:
# 1.0 - Planet Lander
# 1.0 - Lucius
# 1.0 - Deceive Inc.
# -1.0 - Unpacking
# -1.0 - Monsti
# 0.2 - Nimbus
# -1.0 - Skullgirls 2nd Encore
# -1.0 - Life is Strange 2
# -1.0 - Marvel's Midnight Suns
# 0.2 - Counter-Strike: Source
# 1.0 - Batman: Arkham City - Game of the Year Edition
# 1.0 - Grounded
# --------------------
#
# ------ Recommendations
# 5.299 -- Valheim
# 4.83 -- Counter-Strike 2
# 4.787 -- Batman: Arkham Asylum Game of the Year Edition
# 4.397 -- ARK: Survival Evolved
# 3.227 -- Baldur's Gate 3
# 3.16 -- Team Fortress 2
# 2.754 -- Garry's Mod
# 2.737 -- Dota 2
# 2.662 -- ELDEN RING
# 2.583 -- Stardew Valley
# 2.544 -- Necesse
# 2.503 -- Batman™: Arkham Origins
# 2.477 -- Raft
# 2.471 -- Scrap Mechanic
# 2.463 -- Factorio
# 2.43 -- Batman™: Arkham Knight
# 2.42 -- Warframe
# 2.391 -- DOOM
# 2.39 -- Starbound
# 2.388 -- Sid Meier's Civilization® V
# --------------------
#
# Runtime: 8.82s
#
# ------ User profile:
# 1.0 - Tower Unite
# 1.0 - Batman: The Enemy Within - The Telltale Series
# 1.0 - Higurashi When They Cry Hou - Ch.2 Watanagashi
# 1.0 - Emily is Away Too
# 1.0 - Stardew Valley
# 1.0 - Headliner: NoviNews
# 1.0 - Higurashi When They Cry Hou - Ch.6 Tsumihoroboshi
# -1.0 - Puzzle Agent
# 1.0 - The Great Ace Attorney Chronicles
# 1.0 - Cibele
# 1.0 - Crush Crush
# 1.0 - one night, hot springs
# 1.0 - Dead by Daylight
# 1.0 - Root
# --------------------
#
# ------ Recommendations
# 5.598 -- Counter-Strike 2
# 3.902 -- Tiny Bunny
# 3.454 -- Higurashi When They Cry Hou - Ch.7 Minagoroshi
# 3.454 -- Higurashi When They Cry Hou - Ch.4 Himatsubushi
# 3.346 -- Higurashi When They Cry Hou+
# 3.189 -- Higurashi When They Cry Hou - Ch.8 Matsuribayashi
# 3.14 -- Raging Loop
# 3.106 -- Nightmare Zapping
# 3.065 -- Higurashi When They Cry Hou - Rei
# 3.033 -- Sound of Drop - fall into poison -
# 3.01 -- Terraria
# 2.991 -- Baldur's Gate 3
# 2.936 -- CHAOS;HEAD NOAH
# 2.91 -- a new life.
# 2.9 -- Amelie
# 2.9 -- We Know the Devil
# 2.888 -- Viviette
# 2.887 -- Phasmophobia
# 2.857 -- The Silver Case
# 2.839 -- Tokyo Dark
# --------------------
#
# Runtime: 9.33s
#
# ------ User profile:
# 1.0 - SpongeBob SquarePants: Battle for Bikini Bottom - Rehydrated
# 1.0 - What Remains of Edith Finch
# 1.0 - Untitled Goose Game
# 1.0 - Super Meat Boy
# 1.0 - The Stanley Parable
# 1.0 - Super Monkey Ball Banana Mania
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Pumpkin Jack
# 1.0 - Resident Evil Village
# 1.0 - Visage
# 1.0 - Return of the Obra Dinn
# 0.2 - LEGO® 2K Drive
# 0.2 - Axiom Verge
# 1.0 - Tomb Raider
# 1.0 - Super Monkey Ball: Banana Blitz HD
# -1.0 - Little Nightmares II
# 1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 5.19 -- A Hat in Time
# 5.037 -- Counter-Strike 2
# 3.636 -- Spyro™ Reignited Trilogy
# 3.53 -- Crash Bandicoot™ N. Sane Trilogy
# 3.384 -- Katamari Damacy REROLL
# 3.188 -- Inner Ashes
# 3.069 -- Layers of Fear (2016)
# 3.063 -- The Ring of Truth
# 2.909 -- INFRA
# 2.842 -- The Beast Inside
# 2.839 -- Phasmophobia
# 2.827 -- The Vanishing of Ethan Carter
# 2.769 -- Aporia: Beyond The Valley
# 2.751 -- Baldur's Gate 3
# 2.727 -- de Blob
# 2.721 -- Pikuniku
# 2.63 -- The Fidelio Incident
# 2.605 -- Terraria
# 2.601 -- Draugen
# 2.568 -- Conarium
# --------------------
#
# Runtime: 8.26s
#
# ------ User profile:
# -1.0 - Survive the Nights
# -1.0 - Hell Let Loose
# -1.0 - Mist Survival
# -1.0 - Swordsman VR
# -1.0 - World War 2 Winter Gun Range VR Simulator
# -1.0 - Cities: Skylines II
# -1.0 - Bootstrap Island
# -1.0 - Lethal Company
# -1.0 - The Break-In
# -1.0 - Fighting Clans
# -1.0 - Onward
# -1.0 - Starfield
# -1.0 - Death Horizon: Reloaded
# -1.0 - Medieval Dynasty
# -1.0 - Zero Hour
# -1.0 - Grimlord
# -1.0 - The Walking Dead: Saints & Sinners - Chapter 2: Retribution
# 1.0 - RimWorld
# --------------------
#
# ------ Recommendations
# 4.757 -- Counter-Strike 2
# 3.634 -- Empires of the Undergrowth
# 3.566 -- The Final Earth 2
# 3.562 -- Oxygen Not Included
# 3.555 -- Against the Storm
# 3.487 -- Dwarf Fortress
# 3.426 -- Farlanders
# 3.373 -- Space Haven
# 3.345 -- Prison Architect
# 3.337 -- Surviving Mars
# 3.304 -- Paleon
# 3.3 -- Ratopia
# 3.289 -- Judgment: Apocalypse Survival Simulation
# 3.275 -- Sapiens
# 3.251 -- Project Highrise
# 3.243 -- Founders' Fortune
# 3.202 -- After the Collapse
# 3.162 -- The Universim
# 3.125 -- Dota 2
# 3.072 -- First Feudal
# --------------------
#
# Runtime: 9.73s
#
# ------ User profile:
# 0.2 - No Man's Sky
# 0.2 - Kerbal Space Program
# -1.0 - Crysis 2 Remastered
# 1.0 - Aperture Desk Job
# -1.0 - Blackwake
# 0.2 - Counter-Strike 2
# 1.0 - Doki Doki Literature Club!
# 0.2 - Darkwood
# -1.0 - Crysis Remastered
# 0.2 - Palworld
# -1.0 - STAR WARS Jedi: Fallen Order™
# 0.2 - Outer Wilds
# 0.2 - Intruder
# 1.0 - Borderlands Game of the Year Enhanced
# 1.0 - missed messages.
# --------------------
#
# ------ Recommendations
# 5.271 -- Borderlands 2
# 3.336 -- Trick and Treat - Visual Novel
# 3.239 -- How To Date A Magical Girl!
# 3.044 -- Team Fortress 2
# 2.908 -- Left 4 Dead 2
# 2.782 -- Rust
# 2.78 -- Cyberpunk 2077
# 2.729 -- HELLDIVERS™ 2
# 2.663 -- Lethal Company
# 2.66 -- YOU and ME and HER: A Love Story
# 2.656 -- Her World
# 2.631 -- a new life.
# 2.621 -- Your Dry Delight
# 2.61 -- Phasmophobia
# 2.609 -- Lake of Voices
# 2.607 -- Doki Doki Literature Club Plus!
# 2.602 -- memories
# 2.602 -- Trap Legend
# 2.592 -- SCP: Doki Doki Anomaly
# 2.579 -- Higurashi When They Cry Hou+
# --------------------
#
# Runtime: 8.54s
#
# ------ User profile:
# 1.0 - Mafia III: Definitive Edition
# 0.2 - Yakuza 5 Remastered
# 1.0 - DAVE THE DIVER
# 1.0 - Dying Light
# 0.2 - Last Epoch
# 1.0 - Cyberpunk 2077
# 1.0 - Far Cry 3 - Blood Dragon
# 1.0 - Finding Paradise
# 1.0 - Insurgency: Sandstorm
# 1.0 - Battlefield™ V
# 1.0 - Resident Evil 3
# 1.0 - Mafia: Definitive Edition
# 0.2 - Kingdom Come: Deliverance
# 0.2 - Afterimage
# 0.2 - Dragon's Dogma: Dark Arisen
# 0.2 - Trepang2
# 1.0 - Titanfall® 2
# 1.0 - Days Gone
# 0.2 - Balatro
# -1.0 - Battlefield™ 2042
# 1.0 - Red Dead Redemption 2
# --------------------
#
# ------ Recommendations
# 7.784 -- Grand Theft Auto V
# 7.132 -- Wolfenstein II: The New Colossus
# 6.358 -- Counter-Strike 2
# 6.209 -- Watch_Dogs® 2
# 5.814 -- Resident Evil 4
# 5.676 -- Hell Let Loose
# 5.225 -- Deus Ex: Mankind Divided
# 4.686 -- The Evil Within 2
# 4.682 -- Call of Duty®
# 4.049 -- Mafia II: Definitive Edition
# 3.929 -- Baldur's Gate 3
# 3.913 -- Call of Juarez
# 3.891 -- Metro 2033 Redux
# 3.874 -- Dota 2
# 3.816 -- Team Fortress 2
# 3.774 -- Sleeping Dogs: Definitive Edition
# 3.604 -- Mafia II (Classic)
# 3.534 -- Resident Evil 3: Raccoon City Demo
# 3.476 -- Sleeping Dogs
# 3.179 -- METAL GEAR SOLID V: GROUND ZEROES
# --------------------
#
# Runtime: 9.52s
#
# ------ User profile:
# 1.0 - Castle Crashers®
# 1.0 - DOOM
# 0.2 - The Sims™ 4
# 1.0 - Divinity: Original Sin 2 - Definitive Edition
# 1.0 - Injustice™ 2
# 1.0 - Sid Meier's Civilization® V
# 1.0 - Horizon Zero Dawn™ Complete Edition
# 1.0 - DOOM Eternal
# 0.2 - Divinity: Original Sin - Enhanced Edition
# 1.0 - STAR WARS Jedi: Fallen Order™
# --------------------
#
# ------ Recommendations
# 8.8 -- Counter-Strike 2
# 3.522 -- Team Fortress 2
# 3.476 -- Trepang2
# 3.392 -- Black Mesa
# 3.377 -- DOOM 64
# 3.374 -- DOOM (1993)
# 3.36 -- Bulletstorm: Full Clip Edition
# 3.271 -- Painkiller: Black Edition
# 3.214 -- DOOM Eternal: The Ancient Gods - Part One
# 3.197 -- Serious Sam 4
# 3.186 -- Painkiller Hell & Damnation
# 3.159 -- CARNAGE OFFERING
# 3.132 -- Garry's Mod
# 3.068 -- Half-Life Deathmatch: Source
# 3.054 -- Far Cry®
# 2.925 -- PERISH
# 2.924 -- Painkiller Overdose
# 2.858 -- Left 4 Dead 2
# 2.853 -- Forbidden Ingress
# 2.828 -- Rust
# --------------------
#
# Runtime: 8.02s
#
# ------ User profile:
# 1.0 - 鬼谷八荒 Tale of Immortal
# 1.0 - Devil May Cry 5
# 0.2 - Kenshi
# 1.0 - Saints Row IV: Re-Elected
# 1.0 - PAYDAY 2
# 1.0 - 7 Days to Die
# 0.2 - ONE PIECE: PIRATE WARRIORS 4
# 0.2 - The Forest
# 1.0 - People Playground
# 0.2 - Pummel Party
# 1.0 - Total War: SHOGUN 2
# 0.2 - Red Dead Redemption 2
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 9.249 -- Counter-Strike 2
# 7.95 -- Arma 3
# 4.351 -- Total War: EMPIRE – Definitive Edition
# 4.28 -- Grand Theft Auto V
# 3.635 -- Viscera Cleanup Detail: Santa's Rampage
# 3.607 -- Left 4 Dead 2
# 3.606 -- Dota 2
# 3.522 -- Stardew Valley
# 3.444 -- Tom Clancy's Rainbow Six® Siege
# 3.344 -- Rust
# 3.342 -- Fun with Ragdolls: The Game
# 3.251 -- The Witcher® 3: Wild Hunt
# 3.226 -- Risk of Rain 2
# 3.156 -- Viscera Cleanup Detail: Shadow Warrior
# 3.079 -- ELDEN RING
# 3.078 -- Baldur's Gate 3
# 3.019 -- Borderlands 2
# 2.868 -- Team Fortress 2
# 2.777 -- Don't Starve Together
# 2.636 -- Devil May Cry HD Collection
# --------------------
#
# Runtime: 8.64s
#
# ------ User profile:
# 1.0 - Castle Crashers®
# 1.0 - Cry of Fear
# 1.0 - BattleBlock Theater®
# 1.0 - Cuphead
# 1.0 - Baldur's Gate 3
# 1.0 - The Binding of Isaac: Rebirth
# 0.2 - HELLDIVERS™ 2
# 1.0 - DARK SOULS™ II
# 1.0 - DayZ
# 1.0 - Skul: The Hero Slayer
# --------------------
#
# ------ Recommendations
# 9.502 -- Unturned
# 7.313 -- Counter-Strike 2
# 4.323 -- No More Room in Hell
# 3.783 -- Dungreed
# 3.514 -- Arizona Sunshine®
# 3.446 -- Terraria
# 3.323 -- Stardew Valley
# 3.288 -- Move or Die
# 3.153 -- Dota 2
# 3.13 -- Trollhunters: Defenders of Arcadia
# 3.119 -- Team Fortress 2
# 3.059 -- Rust
# 3.009 -- DUMB FIGHT
# 2.942 -- ELDEN RING
# 2.889 -- Undertale
# 2.723 -- Euro Truck Simulator 2
# 2.705 -- Quiet Sleep
# 2.649 -- Lethal Company
# 2.617 -- Valheim
# 2.614 -- Garry's Mod
# --------------------
#
# Runtime: 8.67s
#
# ------ User profile:
# 1.0 - Hogwarts Legacy
# 1.0 - FINAL FANTASY XIV Online
# 1.0 - Baldur's Gate 3
# 1.0 - Cyberpunk 2077
# 1.0 - Counter-Strike 2
# 1.0 - Blockstorm
# 1.0 - Life is Strange - Episode 1
# 1.0 - Grand Theft Auto V
# 1.0 - Borderlands 3
# 1.0 - DOOM Eternal
# 1.0 - Helltaker
# 1.0 - Lost Ark
# 1.0 - Don't Starve Together
# 1.0 - ELDEN RING
# 1.0 - Path of Exile
# --------------------
#
# ------ Recommendations
# 12.868 -- Dragon's Dogma: Dark Arisen
# 8.769 -- Monster Hunter: World
# 7.948 -- The Elder Scrolls® Online
# 5.51 -- FINAL FANTASY XV WINDOWS EDITION
# 5.299 -- Dota 2
# 4.457 -- Two Worlds Epic Edition
# 4.418 -- The Lord of the Rings Online™
# 4.349 -- Neverwinter
# 4.252 -- Guild Wars 2
# 3.34 -- Team Fortress 2
# 3.323 -- Kingdoms of Amalur: Reckoning™
# 3.266 -- Drakensang Online
# 3.181 -- Risen
# 3.11 -- Bulletstorm: Full Clip Edition
# 3.044 -- Continent of the Ninth Seal
# 3.031 -- HELLDIVERS™ 2
# 3.016 -- Serious Sam 2
# 3.014 -- Serious Sam 4
# 2.99 -- Vindictus
# 2.91 -- Dragon Age™ Inquisition
# --------------------
#
# Runtime: 8.81s
#
# ------ User profile:
# 0.2 - Hogwarts Legacy
# 1.0 - Yu-Gi-Oh! Master Duel
# 0.2 - Beyond: Two Souls
# 0.2 - Cyberpunk 2077
# 0.2 - Marvel’s Spider-Man: Miles Morales
# 0.2 - Counter-Strike 2
# 0.2 - HELLDIVERS™ 2
# 0.2 - The Last of Us™ Part I
# 0.2 - Marvel’s Spider-Man Remastered
# 1.0 - Borderlands 3
# -1.0 - Escape the Backrooms
# 1.0 - Phasmophobia
# -1.0 - Borderlands Game of the Year Enhanced
# 1.0 - Trine 4: The Nightmare Prince
# --------------------
#
# ------ Recommendations
# 3.33 -- Stardew Valley
# 3.163 -- Baldur's Gate 3
# 3.095 -- Dota 2
# 3.093 -- Terraria
# 3.016 -- Garry's Mod
# 2.923 -- Team Fortress 2
# 2.793 -- This is a Ghost
# 2.766 -- Trine Enchanted Edition
# 2.747 -- The Witcher® 3: Wild Hunt
# 2.734 -- Total War: WARHAMMER II
# 2.675 -- The Binding of Isaac: Rebirth
# 2.657 -- Dying Light
# 2.654 -- Among Us
# 2.653 -- Satisfactory
# 2.64 -- Monster Hunter: World
# 2.635 -- Risk of Rain 2
# 2.62 -- Undertale
# 2.608 -- Demonologist
# 2.602 -- Remnant Records
# 2.6 -- Tom Clancy's Rainbow Six® Siege
# --------------------
#
# Runtime: 9.89s
#
# ------ User profile:
# 1.0 - Red Faction Guerrilla Steam Edition
# 1.0 - Beat Saber
# 1.0 - Plug & Play
# 1.0 - Doodle Date
# 1.0 - Tiny Town VR
# 1.0 - Job Simulator
# 1.0 - Chivalry: Medieval Warfare
# 1.0 - Hotline Miami
# 1.0 - Rising Storm 2: Vietnam
# 1.0 - DEAD RISING®
# 1.0 - Blade and Sorcery
# 1.0 - STAR WARS™ Battlefront II (Classic, 2005)
# 1.0 - Dead by Daylight
# 1.0 - METAL GEAR SOLID V: THE PHANTOM PAIN
# 1.0 - GORN
# 1.0 - Call of Juarez: Gunslinger
# --------------------
#
# ------ Recommendations
# 4.952 -- Tom Clancy's Ghost Recon® Wildlands
# 4.864 -- Far Cry®
# 4.789 -- Tom Clancy's Ghost Recon: Future Soldier™
# 4.669 -- Just Cause
# 4.554 -- Counter-Strike 2
# 4.219 -- Mace and Grace: action fight blood fitness arcade
# 3.998 -- STAR WARS™ Battlefront (Classic, 2004)
# 3.53 -- Tom Clancy's Splinter Cell Chaos Theory®
# 3.503 -- Verdun
# 3.482 -- Red Faction
# 3.443 -- Dead Rising 2: Off the Record
# 3.325 -- Tannenberg
# 3.303 -- Red Faction®: Armageddon™
# 3.298 -- Tom Clancy's Splinter Cell®
# 3.281 -- Ninja Legends
# 3.262 -- Hellsplit: Arena
# 3.261 -- The Evil Within 2
# 3.187 -- Chivalry 2
# 3.157 -- Fallout 4
# 3.15 -- Bionic Commando
# --------------------
#
# Runtime: 9.73s
#
# ------ User profile:
# 1.0 - Rock 'N' Roll Defense
# 1.0 - POSTAL 4: No Regerts
# 1.0 - Kingdom Come: Deliverance
# 1.0 - Mount & Blade: Warband
# 1.0 - cyberpunkdreams
# 1.0 - The Witcher: Enhanced Edition Director's Cut
# 1.0 - Albion Online
# 1.0 - A Night In Berlin
# 1.0 - Mount & Blade II: Bannerlord
# -1.0 - Battlefield™ 2042
# 1.0 - Assassin’s Creed® Rogue
# 0.2 - Travellers Rest
# --------------------
#
# ------ Recommendations
# 8.295 -- The Witcher® 3: Wild Hunt
# 6.083 -- Counter-Strike 2
# 3.868 -- Mount & Blade: With Fire & Sword
# 3.632 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 3.556 -- Medieval Dynasty
# 3.25 -- Dota 2
# 3.236 -- Mount & Blade
# 3.147 -- PAYDAY 2
# 3.124 -- Phasmophobia
# 2.921 -- Lethal Company
# 2.88 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 2.814 -- Garry's Mod
# 2.778 -- Rust
# 2.743 -- Tom Clancy's Rainbow Six® Siege
# 2.729 -- Middle-earth™: Shadow of Mordor™
# 2.715 -- ARMA: Cold War Assault
# 2.707 -- Battle Brothers
# 2.695 -- ELDEN RING
# 2.684 -- Valheim
# 2.638 -- Microsoft Flight Simulator X: Steam Edition
# --------------------
#
# Runtime: 9.05s
#
# ------ User profile:
# 1.0 - Turbo Overkill
# 1.0 - The Evil Within
# -1.0 - Florence
# 1.0 - Riders Republic
# 1.0 - RUINER
# -1.0 - BATTALION: Legacy
# -1.0 - Quake Champions
# 1.0 - Titanfall® 2
# 1.0 - To the Moon
# 1.0 - Grand Theft Auto V
# 1.0 - Sunset Overdrive
# 1.0 - ULTRAKILL
# 1.0 - Helltaker
# -1.0 - Call of Duty®
# -1.0 - BRINK
# -1.0 - Road 96 🛣️
# --------------------
#
# ------ Recommendations
# 5.748 -- Saints Row: The Third
# 4.145 -- Counter-Strike 2
# 3.179 -- Team Fortress 2
# 3.115 -- Baldur's Gate 3
# 2.809 -- ELDEN RING
# 2.738 -- Sleeping Dogs
# 2.733 -- Garry's Mod
# 2.697 -- Just Cause 2
# 2.667 -- Just Cause™ 3
# 2.624 -- Just Cause 2: Multiplayer Mod
# 2.6 -- Left 4 Dead 2
# 2.547 -- Stardew Valley
# 2.54 -- The Witcher® 3: Wild Hunt
# 2.534 -- Saints Row 2
# 2.506 -- Dota 2
# 2.48 -- The Crew™ 2
# 2.479 -- HELLDIVERS™ 2
# 2.46 -- Terraria
# 2.451 -- Finding Paradise
# 2.439 -- Factorio
# --------------------
#
# Runtime: 10.39s
#
# ------ User profile:
# 1.0 - We Were Here Expeditions: The FriendShip
# 1.0 - MALWARE Rewritten
# 0.2 - Stacklands
# 1.0 - Assetto Corsa
# 1.0 - Phasmophobia
# 1.0 - Neon White
# 1.0 - BattleBit Remastered
# 1.0 - Battlefield™ V
# 1.0 - Beat Saber
# 0.2 - Time Warpers
# 1.0 - Lost Ark
# 1.0 - War Thunder
# 0.2 - Assetto Corsa Competizione
# 1.0 - Hardbass Clicker
# 1.0 - DEVOUR
# 1.0 - Geometry Dash
# 0.2 - Balatro
# 0.2 - Melvor Idle
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 6.941 -- Counter-Strike 2
# 4.386 -- Occult
# 4.297 -- Team Fortress 2
# 3.053 -- Garry's Mod
# 2.96 -- ELDEN RING
# 2.953 -- Unturned
# 2.853 -- Silent Rain
# 2.78 -- Rust
# 2.743 -- Dota 2
# 2.698 -- Square
# 2.688 -- Stardew Valley
# 2.665 -- Terraria
# 2.653 -- Tom Clancy's Rainbow Six® Siege
# 2.652 -- Baldur's Gate 3
# 2.652 -- Valheim
# 2.65 -- World War Next
# 2.592 -- PAYDAY 2
# 2.577 -- DiRT Rally 2.0
# 2.556 -- Arma 3
# 2.553 -- Half-Life: Alyx
# --------------------
#
# Runtime: 9.4s
#
# ------ User profile:
# 1.0 - Portal
# 1.0 - Sven Co-op
# 1.0 - Half-Life
# 1.0 - Nuclear Dawn
# 1.0 - Ratchet & Clank: Rift Apart
# 1.0 - Portal 2
# 1.0 - Hunt Down The Freeman
# -1.0 - Counter-Strike 2
# -1.0 - SCP: Secret Laboratory
# -1.0 - No More Room in Hell
# 1.0 - Wild Warfare
# 1.0 - Don't Starve Together
# 1.0 - AXYOS
# -1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 3.29 -- Dota 2
# 3.139 -- HELLDIVERS™ 2
# 2.874 -- Suicide Guy
# 2.812 -- Son Of Killwa
# 2.81 -- Suicide Guy: The Lost Dreams
# 2.802 -- Baldur's Gate 3
# 2.778 -- Gravitas
# 2.769 -- Team Fortress 2
# 2.727 -- PAYDAY 2
# 2.707 -- ELDEN RING
# 2.597 -- Rust
# 2.569 -- Risk of Rain 2
# 2.529 -- Deep Rock Galactic
# 2.483 -- Unturned
# 2.469 -- Suicide Guy Deluxe Plus
# 2.462 -- The Witcher® 3: Wild Hunt
# 2.457 -- Fragsurf
# 2.454 -- Halo: The Master Chief Collection
# 2.427 -- Quantum Conundrum
# 2.424 -- DEPLOYMENT
# --------------------
#
# Runtime: 8.4s
#
# ------ User profile:
# 0.2 - Overwatch® 2
# 0.2 - Halo Infinite
# 0.2 - Total War: WARHAMMER III
# 0.2 - Monster Hunter: World
# 0.2 - War Thunder
# 0.2 - Cyberpunk 2077
# 0.2 - Hell Let Loose
# 0.2 - Halls of Torment
# 0.2 - STAR WARS Jedi: Survivor™
# 0.2 - Death Must Die
# 0.2 - HELLDIVERS™ 2
# 0.2 - Mount & Blade II: Bannerlord
# 0.2 - ELDEN RING
# --------------------
#
# ------ Recommendations
# 13.962 -- DARK SOULS™ III
# 8.113 -- Fallout 4
# 7.01 -- Destiny 2
# 6.031 -- Counter-Strike 2
# 4.804 -- Dragon's Dogma: Dark Arisen
# 4.349 -- Lords of the Fallen
# 4.298 -- FINAL FANTASY XV WINDOWS EDITION
# 4.105 -- Team Fortress 2
# 4.054 -- Bound By Flame
# 3.926 -- Dota 2
# 3.524 -- Left 4 Dead 2
# 3.312 -- DARK SOULS™: REMASTERED
# 3.211 -- DARK SOULS™ II
# 3.178 -- DARK SOULS™ II: Scholar of the First Sin
# 3.169 -- Terraria
# 3.162 -- Dead by Daylight
# 3.138 -- Sea of Thieves 2023 Edition
# 3.059 -- Keeper's Toll
# 3.035 -- CODE VEIN
# 3.026 -- Nioh: Complete Edition
# --------------------
#
# Runtime: 8.41s
#
# ------ User profile:
# 0.2 - It Takes Two
# 1.0 - Fluffy Horde
# 0.2 - NosTale - Anime MMORPG
# 1.0 - Fallout 4
# 0.2 - Just Act Natural
# 0.2 - Hogwarts Legacy
# 1.0 - Monster Hunter: World
# 0.2 - Lethal Company
# -1.0 - AereA
# 1.0 - Forager
# 0.2 - Among Us
# 0.2 - Diablo® IV
# 0.2 - Bloons TD 6
# 1.0 - Kynseed
# 1.0 - Crashlands
# 1.0 - Little Nightmares II
# 0.2 - Stray
# 1.0 - Stardew Valley
# -1.0 - Cladun Returns: This Is Sengoku!
# 1.0 - IdleOn - The Idle MMO
# 1.0 - One Hour One Life
# --------------------
#
# ------ Recommendations
# 10.12 -- Terraria
# 7.572 -- Counter-Strike 2
# 4.325 -- My Time at Portia
# 3.451 -- Team Fortress 2
# 3.254 -- The Witcher® 3: Wild Hunt
# 3.241 -- Necesse
# 3.212 -- Clanfolk
# 3.168 -- Cornucopia®
# 3.112 -- Keplerth
# 3.1 -- Risen
# 3.087 -- Kingdoms of Amalur: Reckoning™
# 3.052 -- Dig or Die
# 2.998 -- Garry's Mod
# 2.804 -- Signs of Life
# 2.746 -- Force of Nature
# 2.726 -- Baldur's Gate 3
# 2.649 -- FortressCraft Evolved!
# 2.631 -- Halo: The Master Chief Collection
# 2.608 -- Borderlands 2
# 2.587 -- Windforge
# --------------------
#
# Runtime: 9.28s
#
# ------ User profile:
# -1.0 - Minds Eyes
# 1.0 - Crab Game
# 1.0 - SCP: Secret Laboratory
# 0.2 - Left 4 Dead 2
# 1.0 - Unturned
# 1.0 - Escape the Backrooms
# 1.0 - Helltaker
# 1.0 - Outlast
# --------------------
#
# ------ Recommendations
# 8.072 -- Counter-Strike 2
# 3.413 -- Team Fortress 2
# 3.179 -- Garry's Mod
# 3.04 -- Killing Floor - Toy Master
# 3.031 -- Transmissions: Element 120
# 2.884 -- Dota 2
# 2.872 -- Grand Theft Auto V
# 2.872 -- Tom Clancy's Rainbow Six® Siege
# 2.831 -- HELLDIVERS™ 2
# 2.823 -- Rust
# 2.809 -- ELDEN RING
# 2.779 -- Undertale
# 2.778 -- Stray
# 2.692 -- Cyberpunk 2077
# 2.686 -- RimWorld
# 2.642 -- The Witcher® 3: Wild Hunt
# 2.626 -- Red Dead Redemption 2
# 2.607 -- Lethal Company
# 2.594 -- Frightened
# 2.581 -- DARK SOULS™ III
# --------------------
#
# Runtime: 8.86s
#
# ------ User profile:
# 0.2 - Momodora: Moonlit Farewell
# 1.0 - Rising Dusk
# -1.0 - Titan Souls
# 0.2 - HELLDIVERS™ 2
# 1.0 - Elite Dangerous
# 0.2 - Project Zomboid
# 0.2 - Dyson Sphere Program
# 0.2 - 100% Orange Juice
# 1.0 - One Step From Eden
# -1.0 - Robocraft
# --------------------
#
# ------ Recommendations
# 5.74 -- Counter-Strike 2
# 5.031 -- No Man's Sky
# 3.226 -- Terraria
# 3.176 -- Garry's Mod
# 3.136 -- Team Fortress 2
# 2.919 -- Left 4 Dead 2
# 2.858 -- The Witcher® 3: Wild Hunt
# 2.845 -- Rust
# 2.839 -- Slay the Spire
# 2.771 -- Dota 2
# 2.762 -- Stardew Valley
# 2.743 -- Hector The Cat - Treasure Hunter
# 2.712 -- Tom Clancy's Rainbow Six® Siege
# 2.645 -- Deep Rock Galactic
# 2.606 -- EndCycle VS
# 2.605 -- RimWorld
# 2.594 -- Baldur's Gate 3
# 2.59 -- Skelly Selest
# 2.579 -- Tabletop Simulator
# 2.57 -- Interstellar Pilot 2
# --------------------
#
# Runtime: 8.64s
#
# ------ User profile:
# 1.0 - Quake II RTX
# 0.2 - Deep Rock Galactic: Survivor
# 1.0 - Fallout 3: Game of the Year Edition
# 1.0 - Saints Row IV: Re-Elected
# 0.2 - The Ascent
# 0.2 - Fallout: New Vegas
# 1.0 - Turok 3: Shadow of Oblivion Remastered
# 0.2 - Horizon Forbidden West™ Complete Edition
# 0.2 - Keeper's Toll
# 1.0 - Grim Dawn
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Sniper Elite 5
# 0.2 - Fallout 4
# 1.0 - Halo: The Master Chief Collection
# 1.0 - FINAL FANTASY IX
# --------------------
#
# ------ Recommendations
# 8.058 -- Counter-Strike 2
# 4.786 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 4.096 -- STAR WARS™ Knights of the Old Republic™
# 3.917 -- Dota 2
# 3.758 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 3.743 -- Fallout 3
# 3.631 -- Team Fortress 2
# 3.334 -- FINAL FANTASY XII THE ZODIAC AGE
# 3.287 -- Stardew Valley
# 3.234 -- Gothic® 3
# 3.209 -- Garry's Mod
# 3.113 -- Tom Clancy's Rainbow Six® Siege
# 3.06 -- Quake
# 3.051 -- Starfield
# 3.018 -- FINAL FANTASY X/X-2 HD Remaster
# 3.015 -- Quake II
# 2.998 -- Wolfenstein: Enemy Territory
# 2.969 -- Okami HD
# 2.958 -- Trials of Mana
# 2.946 -- Sudeki
# --------------------
#
# Runtime: 8.66s
#
# ------ User profile:
# -1.0 - Rust
# 1.0 - Streets of Rogue
# 1.0 - Metro Exodus
# 1.0 - EVERSPACE™
# 1.0 - 7 Days to Die
# 1.0 - Katana ZERO
# 1.0 - Cities: Skylines
# 1.0 - FEZ
# 1.0 - Assassin's Creed® Odyssey
# 1.0 - Overload
# 1.0 - Dyson Sphere Program
# 1.0 - Oxygen Not Included
# 1.0 - RimWorld
# 1.0 - Dying Light
# --------------------
#
# ------ Recommendations
# 6.981 -- Counter-Strike 2
# 4.308 -- Team Fortress 2
# 4.075 -- Empires of the Undergrowth
# 3.814 -- Space Haven
# 3.581 -- Surviving Mars
# 3.243 -- Left 4 Dead 2
# 3.112 -- Dota 2
# 2.99 -- Stable Orbit - Build your own space station
# 2.97 -- The Final Earth 2
# 2.935 -- ELDEN RING
# 2.933 -- Lethal Company
# 2.92 -- Garry's Mod
# 2.904 -- Against the Storm
# 2.889 -- Terraria
# 2.785 -- Tom Clancy's Rainbow Six® Siege
# 2.729 -- Metro 2033 Redux
# 2.718 -- Resident Evil Village
# 2.702 -- Vampire Survivors
# 2.692 -- Judgment: Apocalypse Survival Simulation
# 2.684 -- Prison Architect
# --------------------
#
# Runtime: 10.73s
#
# ------ User profile:
# 1.0 - GROUND BRANCH
# 0.2 - Ready or Not
# 0.2 - YUME 3
# 0.2 - Snowbreak: Containment Zone
# 1.0 - Warframe
# 1.0 - Unturned
# 0.2 - Grand Theft Auto V
# 1.0 - Warface: Clutch
# 1.0 - NEKOPARA Vol. 1
# 0.2 - Joy Life
# --------------------
#
# ------ Recommendations
# 9.894 -- Arma 3
# 9.222 -- Counter-Strike 2
# 4.51 -- Team Fortress 2
# 4.013 -- Dota 2
# 3.322 -- Verdun
# 3.26 -- Terraria
# 3.21 -- America's Army: Proving Grounds
# 3.205 -- Lethal Company
# 3.19 -- Squad
# 3.175 -- Stardew Valley
# 3.149 -- Zero Hour
# 2.896 -- Contain
# 2.846 -- Mount & Blade: Warband
# 2.818 -- Among Us
# 2.782 -- Baldur's Gate 3
# 2.768 -- Deep Rock Galactic
# 2.762 -- Dead by Daylight
# 2.728 -- Garry's Mod
# 2.722 -- Project Zomboid
# 2.72 -- Risk of Rain 2
# --------------------
#
# Runtime: 10.23s
#
# ------ User profile:
# 1.0 - Motorsport Manager
# 1.0 - Football Coach: College Dynasty
# 1.0 - Total War: THREE KINGDOMS
# 1.0 - Rising Storm 2: Vietnam
# 1.0 - Car Mechanic Simulator 2018
# 1.0 - Car Mechanic Simulator 2015
# 1.0 - Tank Mechanic Simulator
# 1.0 - Insurgency: Sandstorm
# 1.0 - Total War: SHOGUN 2
# --------------------
#
# ------ Recommendations
# 6.554 -- Total War: MEDIEVAL II – Definitive Edition
# 5.947 -- Counter-Strike 2
# 5.685 -- Squad
# 3.641 -- Team Fortress 2
# 3.39 -- Car Mechanic Simulator 2014
# 3.13 -- DRIFT CE
# 3.11 -- Total War: NAPOLEON – Definitive Edition
# 3.098 -- Left 4 Dead 2
# 3.073 -- Garry's Mod
# 2.923 -- ELDEN RING
# 2.852 -- Rising Storm Game of the Year Edition
# 2.824 -- Total War: EMPIRE – Definitive Edition
# 2.792 -- Verdun
# 2.791 -- Car Mechanic Simulator 2021
# 2.788 -- Rome: Total War™ - Collection
# 2.759 -- Stardew Valley
# 2.758 -- Medieval II: Total War™ Kingdoms
# 2.722 -- Total War: ROME II - Emperor Edition
# 2.697 -- Total War: WARHAMMER II
# 2.631 -- Baldur's Gate 3
# --------------------
#
# Runtime: 9.25s
#
# ------ User profile:
# 0.2 - Against the Storm
# 0.2 - HELLDIVERS™ 2
# -1.0 - Fallout 4
# -1.0 - Warhammer 40,000: Darktide
# 1.0 - DOOM
# 1.0 - Divinity: Original Sin 2 - Definitive Edition
# 1.0 - Terraria
# 0.2 - Squad
# -1.0 - Starfield
# -1.0 - State of Decay 2: Juggernaut Edition
# -1.0 - Judgment
# -1.0 - Fallout 3: Game of the Year Edition
# 1.0 - Saints Row IV: Re-Elected
# 1.0 - Fallout: New Vegas
# 0.2 - Hero's Adventure: Road to Passion
# -1.0 - Deus Ex: Mankind Divided
# 1.0 - ELDEN RING
# 0.2 - Kenshi
# -1.0 - Killing Floor 2
# 0.2 - Days Gone
# 1.0 - Resident Evil 4
# --------------------
#
# ------ Recommendations
# 5.232 -- Counter-Strike 2
# 4.882 -- Starbound
# 3.133 -- Baldur's Gate 3
# 2.85 -- Dota 2
# 2.835 -- Left 4 Dead 2
# 2.738 -- Grand Theft Auto V
# 2.685 -- El Paso, Elsewhere
# 2.654 -- Saints Row: The Third
# 2.651 -- Necesse
# 2.61 -- Team Fortress 2
# 2.585 -- DARK SOULS™ III
# 2.575 -- BattleBit Remastered
# 2.55 -- The Evil Within 2
# 2.519 -- DOOM Eternal
# 2.504 -- PAYDAY 2
# 2.5 -- Undertale
# 2.46 -- Borderlands 2
# 2.459 -- Garry's Mod
# 2.456 -- Serious Sam 2
# 2.452 -- Tom Clancy's Rainbow Six® Siege
# --------------------
#
# Runtime: 9.33s
#
# ------ User profile:
# 1.0 - Cookie Clicker
# 1.0 - BattleBlock Theater®
# 1.0 - Bloons TD 6
# 0.2 - Need for Speed™ Heat
# 1.0 - Kairo
# 1.0 - The Binding of Isaac: Rebirth
# 1.0 - Starbound
# 1.0 - Lethal Company
# 1.0 - Risk of Rain 2
# 1.0 - The Room
# 1.0 - DayZ
# 1.0 - Vampire Survivors
# 1.0 - Risk of Rain (2013)
# -1.0 - Path of Exile
# 1.0 - DARK SOULS™ III
# --------------------
#
# ------ Recommendations
# 7.144 -- Counter-Strike 2
# 6.541 -- Terraria
# 4.034 -- DARK SOULS™: REMASTERED
# 3.744 -- Dota 2
# 3.396 -- Team Fortress 2
# 3.138 -- ELDEN RING
# 3.11 -- Stardew Valley
# 3.093 -- Spirits Abyss
# 3.044 -- The Binding of Isaac
# 3.007 -- Dungreed
# 2.996 -- Crawl
# 2.913 -- Baldur's Gate 3
# 2.89 -- Wizard of Legend
# 2.869 -- TowerClimb
# 2.851 -- Enter the Gungeon
# 2.815 -- Dungeon Survivors
# 2.775 -- Fallout: New Vegas
# 2.743 -- Rust
# 2.7 -- Never Split the Party
# 2.674 -- The Guest
# --------------------
#
# Runtime: 8.6s
#
# ------ User profile:
# 1.0 - Fire Pro Wrestling World
# 1.0 - Conan Exiles
# 1.0 - Resident Evil 2
# 1.0 - Chivalry: Medieval Warfare
# 1.0 - Tom Clancy's Rainbow Six® Siege
# 1.0 - Torchlight II
# 1.0 - The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 1.0 - MechWarrior Online™ Legends
# --------------------
#
# ------ Recommendations
# 22.671 -- Counter-Strike 2
# 11.498 -- Counter-Strike: Source
# 4.371 -- Dota 2
# 4.214 -- Tom Clancy's Ghost Recon®
# 4.202 -- Resident Evil 7 Biohazard
# 4.046 -- Battlefield 4™
# 3.858 -- Team Fortress 2
# 3.797 -- Verdun
# 3.78 -- The Elder Scrolls V: Skyrim Special Edition
# 3.514 -- Task Force
# 3.232 -- Garry's Mod
# 3.149 -- HELLDIVERS™ 2
# 3.098 -- ELDEN RING
# 3.023 -- The Witcher® 3: Wild Hunt
# 2.974 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 2.853 -- Borderlands 2
# 2.837 -- Lethal Company
# 2.709 -- Dying Light
# 2.702 -- Baldur's Gate 3
# 2.674 -- The Forest
# --------------------
#
# Runtime: 8.35s
#
# ------ User profile:
# 1.0 - Raft
# 1.0 - Dirty Bomb®
# 1.0 - Five Nights at Freddy's
# -1.0 - BATTALION: Legacy
# 1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Terraria
# 1.0 - New World
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 9.622 -- Counter-Strike 2
# 7.206 -- Valheim
# 4.016 -- Dota 2
# 3.955 -- Team Fortress 2
# 3.655 -- ARK: Survival Evolved
# 3.225 -- Necesse
# 3.135 -- ELDEN RING
# 3.046 -- Stardew Valley
# 2.98 -- Dig or Die
# 2.969 -- HELLDIVERS™ 2
# 2.944 -- Rust
# 2.914 -- Scrap Mechanic
# 2.877 -- Arma 3
# 2.816 -- PAYDAY 2
# 2.806 -- Destiny 2
# 2.732 -- Deep Rock Galactic
# 2.731 -- Junk Jack
# 2.726 -- DOOM
# 2.725 -- Half-Life 2
# 2.717 -- Dead by Daylight
# --------------------
#
# Runtime: 8.86s
#
# ------ User profile:
# 1.0 - Euro Truck Simulator 2
# 0.2 - Far Cry® 5
# 1.0 - PAYDAY 2
# 1.0 - Russian Fishing 4
# 1.0 - Syberia II
# -1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Wind Child
# 1.0 - DESOLATE
# 1.0 - Thorne - Death Merchants
# 1.0 - Fated Souls
# 0.2 - Don't Starve Together
# -1.0 - CRSED: F.O.A.D.
# 1.0 - Moonchild
# 1.0 - Path of Exile
# 1.0 - Overcast - Walden and the Werewolf
# --------------------
#
# ------ Recommendations
# 5.618 -- Counter-Strike 2
# 3.399 -- Lost Ark
# 3.291 -- Dota 2
# 3.121 -- Team Fortress 2
# 3.072 -- Terraria
# 3.019 -- Garry's Mod
# 2.955 -- Baldur's Gate 3
# 2.819 -- The Witcher® 3: Wild Hunt
# 2.799 -- Stardew Valley
# 2.789 -- HELLDIVERS™ 2
# 2.615 -- The Forest
# 2.571 -- Arma 3
# 2.55 -- Hearts of Iron IV
# 2.511 -- Rust
# 2.462 -- Deep Rock Galactic
# 2.454 -- American Truck Simulator
# 2.454 -- Dead by Daylight
# 2.454 -- Palworld
# 2.434 -- Left 4 Dead 2
# 2.424 -- Monster Hunter: World
# --------------------
#
# Runtime: 9.82s
#
# ------ User profile:
# 1.0 - Long Live The Queen
# 1.0 - Divinity: Dragon Commander
# 0.2 - Lethal League
# 1.0 - Baldur's Gate 3
# 1.0 - Mini Motorways
# 1.0 - Wolfenstein: The New Order
# 1.0 - Call of Duty®: Black Ops III
# 1.0 - Call of Duty®: Modern Warfare® 2 (2009)
# 1.0 - Pizza Tower
# 1.0 - Indie Game: The Movie
# 1.0 - A Hat in Time
# 1.0 - DOOM Eternal
# 0.2 - Rogue Tower
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 10.427 -- Black Mesa
# 8.25 -- DOOM
# 4.919 -- Counter-Strike 2
# 4.391 -- Half-Life 2: Episode Two
# 4.354 -- Bulletstorm: Full Clip Edition
# 3.474 -- Call of Duty® 4: Modern Warfare® (2007)
# 3.379 -- Garry's Mod
# 3.372 -- Wolfenstein: Youngblood
# 3.365 -- Call of Duty® 2
# 3.349 -- Wolfenstein: The Old Blood
# 3.329 -- Call of Duty®: Black Ops
# 3.29 -- Team Fortress 2
# 3.265 -- Dota 2
# 3.246 -- STAR WARS™ Republic Commando™
# 3.242 -- Wolfenstein II: The New Colossus
# 3.227 -- Brothers in Arms: Road to Hill 30™
# 3.213 -- Brothers in Arms: Hell's Highway™
# 3.199 -- Metro Exodus
# 3.194 -- Call of Duty®: Black Ops II
# 3.053 -- Call of Juarez: Bound in Blood
# --------------------
#
# Runtime: 8.97s
#
# ------ User profile:
# 0.2 - RISK: Global Domination
# 0.2 - Brawlhalla
# 0.2 - Battlefield™ 1
# 0.2 - PUBG: BATTLEGROUNDS
# 0.2 - Europa Universalis IV
# 0.2 - Hearts of Iron IV
# 0.2 - Grand Theft Auto V
# 0.2 - Mount & Blade: Warband
# 0.2 - Mount & Blade II: Bannerlord
# 0.2 - Pacify
# 0.2 - NARAKA: BLADEPOINT
# 0.2 - Phasmophobia
# 0.2 - Red Dead Redemption 2
# 0.2 - EA SPORTS FC™ 24
# 0.2 - Sea of Thieves 2023 Edition
# --------------------
#
# ------ Recommendations
# 7.648 -- Counter-Strike 2
# 4.775 -- Team Fortress 2
# 4.154 -- Tom Clancy's Ghost Recon® Wildlands
# 4.131 -- Call of Juarez: Bound in Blood
# 3.925 -- Garry's Mod
# 3.866 -- Mount & Blade
# 3.855 -- Mount & Blade: With Fire & Sword
# ...
# --------------------
#
# Runtime: 9.19s
#
# ------ User profile:
# -1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Elite Dangerous
# 1.0 - Orbital Gear
# 1.0 - Tabletop Simulator
# 1.0 - Warframe
# 1.0 - System Shock
# 1.0 - Brothers - A Tale of Two Sons
# 1.0 - Deus Ex: Human Revolution - Director's Cut
# 1.0 - METAL GEAR RISING: REVENGEANCE
# --------------------
#
# ------ Recommendations
# 9.964 -- Counter-Strike 2
# 4.239 -- Dota 2
# 4.073 -- Cyberpunk 2077
# 3.571 -- Terraria
# 3.435 -- Stardew Valley
# 3.374 -- Among Us
# 3.314 -- ELDEN RING
# 3.313 -- Baldur's Gate 3
# 3.233 -- Rust
# 3.21 -- Garry's Mod
# 3.116 -- Starbound
# 3.106 -- Lethal Company
# 3.049 -- Deep Rock Galactic
# 3.018 -- Team Fortress 2
# 3.0 -- Left 4 Dead 2
# 2.975 -- Killing Floor
# 2.943 -- Grand Theft Auto V
# 2.86 -- Dying Light
# 2.856 -- Euro Truck Simulator 2
# 2.855 -- Hogwarts Legacy
# --------------------
#
# Runtime: 8.68s
#
# ------ User profile:
# 1.0 - Five Nights at Freddy's: Security Breach
# 1.0 - F1® 23
# 0.2 - HELLDIVERS™ 2
# 1.0 - Tom Clancy's Rainbow Six® Siege
# 0.2 - Cruelty Squad
# 1.0 - Cats Hidden in Paris
# -1.0 - Fallout 76
# -1.0 - Overwatch® 2
# 0.2 - God of War
# 0.2 - Danganronpa: Trigger Happy Havoc
# -1.0 - Call of Duty®: Modern Warfare® II
# 1.0 - Call of Duty®: Black Ops III
# -1.0 - Poppy Playtime
# 0.2 - Grand Theft Auto IV: Complete Edition
# 0.2 - Forza Horizon 5
# 0.2 - The Binding of Isaac: Rebirth
# 0.2 - Geometry Dash
# 1.0 - ULTRAKILL
# -1.0 - Call of Duty®
# 0.2 - My Friend Pedro
# --------------------
#
# ------ Recommendations
# 19.278 -- Counter-Strike 2
# 4.394 -- Dota 2
# 4.256 -- The Witcher® 3: Wild Hunt
# 3.885 -- Team Fortress 2
# 3.8 -- Baldur's Gate 3
# 3.501 -- ELDEN RING
# 3.049 -- Stardew Valley
# 2.98 -- Project Zomboid
# 2.97 -- Halo: The Master Chief Collection
# 2.951 -- Garry's Mod
# 2.938 -- Terraria
# 2.886 -- BattleBit Remastered
# 2.882 -- Plants vs. Zombies GOTY Edition
# 2.877 -- RimWorld
# 2.845 -- Portal 2
# 2.819 -- Counter-Strike
# 2.818 -- PAYDAY 2
# 2.805 -- Cyberpunk 2077
# 2.795 -- Phasmophobia
# 2.78 -- Vampire Survivors
# --------------------
#
# Runtime: 9.25s
#
# ------ User profile:
# 1.0 - Ruined King: A League of Legends Story™
# 1.0 - Phasmophobia
# 1.0 - DOOM
# 1.0 - Total War: WARHAMMER III
# 1.0 - Tyranny
# 0.2 - Team Fortress 2
# 0.2 - No Man's Sky
# 0.2 - Left 4 Dead 2
# 1.0 - Resident Evil 7 Biohazard
# 1.0 - ENDLESS™ Space 2
# 1.0 - ELDEN RING
# -1.0 - Path of Exile
# 1.0 - Total War: WARHAMMER
# 1.0 - CHRONO TRIGGER®
# 1.0 - Persona 3 Portable
# 0.2 - Days Gone
# 1.0 - The Last of Us™ Part I
# -1.0 - Warhammer: End Times - Vermintide
# 1.0 - Total War: ATTILA
# 1.0 - Project Warlock
# --------------------
#
# ------ Recommendations
# 8.876 -- Counter-Strike 2
# 3.657 -- Deep Rock Galactic
# 3.638 -- FINAL FANTASY IX
# 3.505 -- Terraria
# 3.232 -- HELLDIVERS™ 2
# 3.228 -- Dota 2
# 3.151 -- The Witcher® 3: Wild Hunt
# 3.097 -- Total War: WARHAMMER II
# 3.077 -- Warframe
# 3.028 -- Grand Theft Auto V
# 2.992 -- RimWorld
# 2.851 -- Arma 3
# 2.824 -- Red Dead Redemption 2
# 2.8 -- Total War: NAPOLEON – Definitive Edition
# 2.759 -- Satisfactory
# 2.741 -- Portal 2
# 2.735 -- Baldur's Gate 3
# 2.728 -- The Legend of Heroes: Trails in the Sky SC
# 2.705 -- DARK SOULS™ III
# 2.696 -- Monster Hunter: World
# --------------------
#
# Runtime: 8.95s
#
# ------ User profile:
# -1.0 - Potion Craft: Alchemist Simulator
# 1.0 - Cyberpunk 2077
# -1.0 - STAR WARS Jedi: Survivor™
# 1.0 - Stardew Valley
# 1.0 - Roots of Pacha
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# -1.0 - Sun Haven
# 1.0 - Graveyard Keeper
# 1.0 - ELDEN RING
# 1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 9.864 -- Counter-Strike 2
# 5.436 -- Team Fortress 2
# 5.257 -- Dota 2
# 4.207 -- Baldur's Gate 3
# 3.952 -- Lethal Company
# 3.893 -- Valheim
# 3.607 -- Risk of Rain 2
# 3.425 -- Left 4 Dead 2
# 3.42 -- Garry's Mod
# 3.412 -- Euro Truck Simulator 2
# 3.394 -- HELLDIVERS™ 2
# 3.384 -- Terraria
# 3.349 -- Phasmophobia
# 3.174 -- Deep Rock Galactic
# 3.143 -- Counter-Strike
# 3.132 -- Palworld
# 3.018 -- Apex Legends™
# 2.994 -- Dying Light
# 2.99 -- Tabletop Simulator
# 2.98 -- Fallout 4
# --------------------
#
# Runtime: 9.02s
#
# ------ User profile:
# 1.0 - HELLDIVERS™ 2
# 1.0 - Fallout 4
# 1.0 - Palworld
# 1.0 - Hogwarts Legacy
# 1.0 - Mortal Kombat 1
# 1.0 - Arma 3
# 1.0 - Lethal Company
# 0.2 - BioShock™ Remastered
# 1.0 - Squad
# 0.2 - Batman™: Arkham Knight
# 1.0 - Starfield
# 1.0 - Sons Of The Forest
# 1.0 - Baldur's Gate 3
# 1.0 - Sid Meier's Civilization® V
# 0.2 - Grand Theft Auto IV: Complete Edition
# 0.2 - Sid Meier’s Civilization® VI
# 1.0 - Starship Troopers: Extermination
# 1.0 - Hell Let Loose
# 0.2 - The Witcher® 3: Wild Hunt
# 1.0 - Rising Storm 2: Vietnam
# 1.0 - The Last of Us™ Part I
# --------------------
#
# ------ Recommendations
# 12.486 -- Counter-Strike 2
# 5.339 -- Dota 2
# 4.864 -- Fallout: New Vegas
# 3.687 -- Team Fortress 2
# 3.631 -- Terraria
# 3.588 -- Garry's Mod
# 3.395 -- Risk of Rain 2
# 3.298 -- Stardew Valley
# 3.291 -- Path of Exile
# 3.271 -- Rising Storm Game of the Year Edition
# 3.259 -- Destiny 2
# 3.142 -- ELDEN RING
# 3.122 -- Hades
# 3.083 -- Rust
# 3.082 -- Don't Starve Together
# 3.079 -- Borderlands 2
# 3.065 -- Euro Truck Simulator 2
# 3.046 -- Among Us
# 3.042 -- Isonzo
# 2.981 -- Deep Rock Galactic
# --------------------
#
# Runtime: 8.59s
#
# ------ User profile:
# 1.0 - Monster Hunter: World
# 1.0 - DRAGON BALL XENOVERSE 2
# 1.0 - Need for Speed™ Unbound
# -1.0 - FINAL FANTASY XV WINDOWS EDITION
# 0.2 - Snowbreak: Containment Zone
# 0.2 - Apex Legends™
# -1.0 - Battle Teams 2
# -1.0 - MONSTER HUNTER RISE
# -1.0 - Path of Exile
# --------------------
#
# ------ Recommendations
# 10.651 -- Counter-Strike 2
# 4.524 -- The Witcher® 3: Wild Hunt
# 4.353 -- Team Fortress 2
# 3.889 -- Tom Clancy's Rainbow Six® Siege
# 3.532 -- HELLDIVERS™ 2
# 3.49 -- Dota 2
# 3.218 -- ELDEN RING
# 3.211 -- Baldur's Gate 3
# 3.046 -- Subnautica
# 2.962 -- Valheim
# 2.884 -- Terraria
# 2.783 -- Factorio
# 2.756 -- Borderlands 2
# 2.75 -- Left 4 Dead 2
# 2.731 -- Total War: WARHAMMER II
# 2.73 -- The Stanley Parable
# 2.725 -- Fallout: New Vegas
# 2.717 -- Warframe
# 2.699 -- Among Us
# 2.692 -- Dwarf Fortress
# --------------------
#
# Runtime: 8.72s
#
# ------ User profile:
# -1.0 - The Fifth Day
# 1.0 - Warhammer® 40,000: Dawn of War® - Game of the Year Edition
# -1.0 - Counter-Strike 2
# 1.0 - Red Faction
# 0.2 - HELLDIVERS™ 2
# 1.0 - Project Zomboid
# -1.0 - Fallout 4
# 1.0 - Lethe - Episode One
# 1.0 - Phasmophobia
# -1.0 - Total War: ROME II - Emperor Edition
# 1.0 - Alcatraz: VR Escape Room
# 0.2 - Lethal Company
# 1.0 - Call of Duty®: Ghosts
# 0.2 - ARK: Survival Ascended
# -1.0 - No Man's Sky
# 0.2 - Baldur's Gate 3
# -1.0 - PUBG: BATTLEGROUNDS
# -1.0 - 7 Days to Die
# 1.0 - NieR:Automata™
# 0.2 - Ready or Not
# 0.2 - Killing Floor 2
# -1.0 - The Walking Dead: A New Frontier
# 1.0 - Battlefield™ 2042
# --------------------
#
# ------ Recommendations
# 5.538 -- Team Fortress 2
# 4.068 -- Dota 2
# 3.409 -- Garry's Mod
# 3.33 -- Left 4 Dead 2
# 3.251 -- Terraria
# 3.21 -- ELDEN RING
# 3.098 -- Valheim
# 3.01 -- Stardew Valley
# 2.989 -- Dead by Daylight
# 2.986 -- Unturned
# 2.92 -- Vampire Survivors
# 2.663 -- Rust
# 2.653 -- The Forest
# 2.649 -- Horizon Zero Dawn™ Complete Edition
# 2.641 -- Risk of Rain 2
# 2.637 -- Factorio
# 2.632 -- Borderlands 2
# 2.585 -- Tom Clancy's Rainbow Six® Siege
# 2.573 -- Arma 3
# 2.547 -- Golf With Your Friends
# --------------------
#
# Runtime: 8.86s
#
# ------ User profile:
# 1.0 - Suicide Squad: Kill the Justice League
# 1.0 - Deep Rock Galactic: Survivor
# 1.0 - Last Epoch
# 1.0 - Ready or Not
# 1.0 - Enshrouded
# 1.0 - Pacific Drive
# 1.0 - Pioneers of Pagonia
# 1.0 - SteamWorld Build
# 1.0 - Dragon's Dogma 2
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - FatalZone
# 1.0 - Death Must Die
# 1.0 - Cities: Skylines II
# 1.0 - Wizardry: Proving Grounds of the Mad Overlord
# 1.0 - The Lamplighters League
# 1.0 - Sovereign Syndicate
# 1.0 - ENDLESS™ Dungeon
# 1.0 - Nightingale
# --------------------
#
# ------ Recommendations
# 7.965 -- Valheim
# 6.699 -- Counter-Strike 2
# 4.052 -- Team Fortress 2
# 3.844 -- Garry's Mod
# 3.703 -- Dota 2
# 3.638 -- Stardew Valley
# 3.585 -- Terraria
# 3.177 -- Deep Rock Galactic
# 3.018 -- Risk of Rain 2
# 3.001 -- ELDEN RING
# 2.957 -- Necesse
# 2.942 -- Counter-Strike: Source
# 2.907 -- The Binding of Isaac: Rebirth
# 2.869 -- Vampire Survivors
# 2.804 -- The Forest
# 2.804 -- Resident Evil 2
# 2.794 -- Black Mesa
# 2.793 -- Slay the Spire
# 2.788 -- Red Dead Redemption 2
# 2.742 -- Lethal Company
# --------------------
#
# Runtime: 8.57s
#
# ------ User profile:
# 1.0 - Hades
# 1.0 - Death's Door
# 1.0 - Kaze and the Wild Masks
# 1.0 - FAR: Lone Sails
# 1.0 - The Last Campfire
# 1.0 - Grim Dawn
# 1.0 - GRIS
# -1.0 - BattleBit Remastered
# 1.0 - Mark of the Ninja: Remastered
# 1.0 - Vampire Survivors
# 1.0 - Dorfromantik
# 1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 8.156 -- Counter-Strike 2
# 4.263 -- Team Fortress 2
# 4.159 -- Baldur's Gate 3
# 3.63 -- Dota 2
# 3.498 -- Valheim
# 3.393 -- Terraria
# 3.313 -- Rust
# 3.237 -- Garry's Mod
# 3.09 -- HELLDIVERS™ 2
# 3.05 -- The Witcher® 3: Wild Hunt
# 2.933 -- Left 4 Dead 2
# 2.879 -- Divinity: Original Sin 2 - Definitive Edition
# 2.873 -- Lethal Company
# 2.872 -- Stray
# 2.87 -- Phasmophobia
# 2.867 -- Portal 2
# 2.826 -- DARK SOULS™ III
# 2.804 -- Subnautica
# 2.798 -- Red Dead Redemption 2
# 2.758 -- Slay the Spire
# --------------------
#
# Runtime: 8.6s
#
# ------ User profile:
# -1.0 - NARAKA: BLADEPOINT
# 1.0 - Monster Hunter: World
# 1.0 - Rise of the Tomb Raider™
# 1.0 - Beholder
# 1.0 - Shadow of the Tomb Raider: Definitive Edition
# -1.0 - PUBG: BATTLEGROUNDS
# 1.0 - DARK SOULS™ III
# 1.0 - Chivalry: Medieval Warfare
# 1.0 - Gremlins, Inc.
# -1.0 - Bright Memory
# 1.0 - WILL: A Wonderful World / WILL：美好世界
# -1.0 - Z1 Battle Royale
# -1.0 - NieR:Automata™
# 1.0 - HUMANKIND™
# -1.0 - Assassin's Creed® Origins
# 1.0 - Sid Meier’s Civilization® VI
# 1.0 - A Plague Tale: Innocence
# --------------------
#
# ------ Recommendations
# 7.471 -- Counter-Strike 2
# 7.389 -- ELDEN RING
# 4.525 -- DARK SOULS™: REMASTERED
# 3.905 -- Dota 2
# 3.868 -- HELLDIVERS™ 2
# 3.8 -- DARK SOULS™ II
# 3.673 -- Garry's Mod
# 3.649 -- Team Fortress 2
# 3.537 -- Baldur's Gate 3
# 3.314 -- Lords of the Fallen
# 3.165 -- Don't Starve Together
# 3.139 -- Grand Theft Auto V
# 3.041 -- The Witcher® 3: Wild Hunt
# 3.033 -- Phasmophobia
# 2.946 -- Valheim
# 2.819 -- Red Dead Redemption 2
# 2.809 -- Vampire Survivors
# 2.798 -- Left 4 Dead 2
# 2.797 -- Lethal Company
# 2.757 -- Rust
# --------------------
#
# Runtime: 9.37s
#
# ------ User profile:
# 0.2 - Forza Horizon 5
# 1.0 - Hunted: The Demon’s Forge™
# 1.0 - VVVVVV
# 1.0 - BattleBlock Theater®
# 0.2 - Need for Speed™ Unbound
# 0.2 - Need for Speed™ Heat
# 0.2 - EZ2ON REBOOT : R
# 1.0 - Ghost Town Mine Ride & Shootin' Gallery
# 1.0 - A.R.E.S.: Extinction Agenda
# 1.0 - APB Reloaded
# 1.0 - Assassin's Creed® Revelations
# 0.2 - SteamVR
# 0.2 - CarX Drift Racing Online
# 1.0 - Octodad: Dadliest Catch
# 0.2 - THE FINALS
# 0.2 - DJMAX RESPECT V
# -1.0 - New Retro Arcade: Neon
# --------------------
#
# ------ Recommendations
# 9.432 -- Counter-Strike 2
# 4.456 -- Team Fortress 2
# 3.789 -- Dota 2
# 3.014 -- ELDEN RING
# 2.85 -- Phasmophobia
# 2.84 -- Warframe
# 2.799 -- Garry's Mod
# 2.798 -- Portal 2
# 2.767 -- Baldur's Gate 3
# 2.71 -- Tom Clancy's Rainbow Six® Siege
# 2.691 -- Deep Rock Galactic
# 2.686 -- Rust
# 2.64 -- RimWorld
# 2.64 -- Terraria
# 2.632 -- Stardew Valley
# 2.605 -- Out There Somewhere
# 2.559 -- DARK SOULS™ III
# 2.544 -- Pikuniku
# 2.542 -- Vampire Survivors
# 2.449 -- Left 4 Dead 2
# --------------------
#
# Runtime: 9.57s
#
# ------ User profile:
# 1.0 - Euro Truck Simulator 2
# 1.0 - Sniper Elite 4
# 1.0 - The Uncertain: Light At The End
# 1.0 - Ranch Simulator - Build, Farm, Hunt
# 1.0 - Lucius
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Dishonored 2
# 1.0 - The Evil Within 2
# 1.0 - Apex Legends™
# 1.0 - Grand Theft Auto V
# 1.0 - Fallout 4
# 1.0 - Liber Prologue
# 1.0 - The Crew™ 2
# 1.0 - Batman: Arkham City - Game of the Year Edition
# 1.0 - METAL GEAR SOLID V: THE PHANTOM PAIN
# 1.0 - Assassin’s Creed® Rogue
# 1.0 - Call of Juarez: Gunslinger
# --------------------
#
# ------ Recommendations
# 6.607 -- Counter-Strike 2
# 5.647 -- Dota 2
# 3.979 -- Team Fortress 2
# 3.675 -- Rise of the Tomb Raider™
# 3.638 -- Terraria
# 3.566 -- HELLDIVERS™ 2
# 3.359 -- Garry's Mod
# 3.222 -- Lethal Company
# 3.199 -- Stardew Valley
# 3.195 -- Baldur's Gate 3
# 3.194 -- Metro Exodus
# 3.153 -- Life is Strange - Episode 1
# 3.118 -- ELDEN RING
# 3.068 -- Tom Clancy's Rainbow Six® Siege
# 3.026 -- Factorio
# 3.0 -- Assassin's Creed 2
# 2.917 -- Assassin's Creed® Revelations
# 2.899 -- Euro Truck Simulator
# 2.854 -- Kenshi
# 2.845 -- Shadow of the Tomb Raider: Definitive Edition
# --------------------
#
# Runtime: 8.9s
#
# ------ User profile:
# 0.2 - HELLDIVERS™ 2
# 1.0 - Apex Legends™
# 1.0 - Street Fighter™ 6
# 0.2 - Last Epoch
# -1.0 - Overwatch® 2
# 1.0 - Valheim
# 0.2 - Mortal Kombat 1
# 1.0 - Nickelodeon All-Star Brawl 2
# 0.2 - Team Fortress 2
# 1.0 - A Hat in Time
# 1.0 - Baldur's Gate 3
# 1.0 - PUBG: BATTLEGROUNDS
# 0.2 - The Forest
# -1.0 - DNF Duel
# 1.0 - Hades
# 1.0 - Enter the Gungeon
# 1.0 - Risk of Rain 2
# 1.0 - Getting Over It with Bennett Foddy
# 1.0 - The Walking Dead
# --------------------
#
# ------ Recommendations
# 12.869 -- Counter-Strike 2
# 5.09 -- Monster Hunter: World
# 4.61 -- Garry's Mod
# 4.59 -- Dota 2
# 4.277 -- Lethal Company
# 4.182 -- Stardew Valley
# 4.153 -- Left 4 Dead 2
# 4.147 -- Terraria
# 3.987 -- ELDEN RING
# 3.844 -- Deep Rock Galactic
# 3.768 -- Don't Starve Together
# 3.595 -- Portal 2
# 3.458 -- Grand Theft Auto V
# 3.43 -- Tom Clancy's Rainbow Six® Siege
# 3.364 -- Rust
# 3.325 -- The Witcher® 3: Wild Hunt
# 3.199 -- PAYDAY 2
# 3.131 -- Phasmophobia
# 2.96 -- The Binding of Isaac: Rebirth
# 2.913 -- DayZ
# --------------------
#
# Runtime: 9.82s
#
# ------ User profile:
# 1.0 - Total War: WARHAMMER III
# 1.0 - DRAGON BALL XENOVERSE 2
# 1.0 - Stardew Valley
# 1.0 - HELLDIVERS™ 2
# 1.0 - Terraria
# 1.0 - EARTH DEFENSE FORCE 5
# 1.0 - Mount & Blade II: Bannerlord
# 1.0 - Graveyard Keeper
# 1.0 - Slay the Spire
# 1.0 - SUNLESS SEA
# 1.0 - Minion Masters
# 1.0 - Total War: WARHAMMER II
# 1.0 - Total War: WARHAMMER
# --------------------
#
# ------ Recommendations
# 12.345 -- Counter-Strike 2
# 6.374 -- Team Fortress 2
# 4.956 -- Left 4 Dead 2
# 4.897 -- Baldur's Gate 3
# 4.547 -- Forager
# 4.416 -- Dota 2
# 4.187 -- ELDEN RING
# 3.547 -- Rust
# 3.494 -- Risk of Rain 2
# 3.407 -- Cyberpunk 2077
# 3.352 -- Red Dead Redemption 2
# 3.348 -- FTL: Faster Than Light
# 3.306 -- Arma 3
# 3.214 -- Euro Truck Simulator 2
# 3.21 -- Garry's Mod
# 3.171 -- Deep Rock Galactic
# 3.16 -- Half-Life: Alyx
# 3.119 -- Fallout: New Vegas
# 3.084 -- RimWorld
# 3.077 -- Monster Hunter: World
# --------------------
#
# Runtime: 9.06s
#
# ------ User profile:
# 1.0 - Cats Hidden in Jingle Jam
# 1.0 - Hades
# -1.0 - Halo Infinite
# 1.0 - ACE COMBAT™ 7: SKIES UNKNOWN
# -1.0 - Shadow of the Tomb Raider: Definitive Edition
# 1.0 - Baldur's Gate 3
# -1.0 - Marvel’s Spider-Man: Miles Morales
# -1.0 - Hearts of Iron IV
# 1.0 - Project Zomboid
# 1.0 - Marvel’s Spider-Man Remastered
# -1.0 - Apex Legends™
# -1.0 - Tales of Arise
# -1.0 - Mount & Blade II: Bannerlord
# 1.0 - Medieval Dynasty
# -1.0 - Call of Duty®
# -1.0 - The Guild 3
# -1.0 - Wartales
# 1.0 - Persona 5 Royal
# --------------------
#
# ------ Recommendations
# 8.79 -- Counter-Strike 2
# 4.04 -- Team Fortress 2
# 3.9 -- Terraria
# 3.464 -- The Witcher® 3: Wild Hunt
# 3.408 -- Phasmophobia
# 3.355 -- HELLDIVERS™ 2
# 3.127 -- Garry's Mod
# 3.054 -- Call of Duty®: Black Ops III
# 3.048 -- Left 4 Dead 2
# 3.021 -- PAYDAY 2
# 3.02 -- Rust
# 2.995 -- Lethal Company
# 2.99 -- Don't Starve Together
# 2.894 -- Destiny 2
# 2.885 -- Tom Clancy's Rainbow Six® Siege
# 2.88 -- Risk of Rain 2
# 2.852 -- The Binding of Isaac: Rebirth
# 2.849 -- Hell Let Loose
# 2.829 -- Crab Game
# 2.808 -- Sea of Thieves 2023 Edition
# --------------------
#
# Runtime: 9.97s
#
# Validated recommendations: 28
# Disproved recommendations: 17
# 11
# | 23        | 11.0      | 103.4     | 32.9      | 1.728     | 2.062     | 0.7403    | 20.0      | 250.0     |
# =============================================================================================================
# {'target': 13.0, 'params': {'collab_filter_limit': 103.48734651630105, 'content_filter_limit': 32.921446485352185, 'double_bonus': 1.7930894746349533, 'popular_bias': 1.8472839810604431, 'ratio': 0.7140703845572055, 'recs': 20.0, 'similar_user_limit': 250.0}}
# {'target': 13.0,
#  'params': {'collab_filter_limit': 103.48734651630105,
#   'content_filter_limit': 32.921446485352185,
#   'double_bonus': 1.7930894746349533,
#   'popular_bias': 1.8472839810604431,
#   'ratio': 0.7140703845572055,
#   'recs': 20.0,
#   'similar_user_limit': 250.0}}

# %% [markdown]
# ### Conclusion
#
# While the bulk of the conclusions and analysis will be in the forthcoming presentation step, we can see by the 'target' score that we are able to games that the user will enjoy much more frequently than games the user will not enjoy, and that the optimal parameters for our evaluation function are as above.
