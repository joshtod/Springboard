# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# String manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
# # # NOTE: Only use once. Instantiates holder files.

# scraped_users = set([0])
# with open('../data/raw/review_scraped_users.pkl', 'wb+') as file :
#     pickle.dump(scraped_users, file)

# skipped_users = {0:'hello world'}
# with open('../data/raw/review_skipped_users.pkl', 'wb+') as file :
#     pickle.dump(skipped_users, file)

# users_with_no_reviews = set([0])
# with open('../data/raw/users_with_no_reviews.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open('../data/raw/review_scraped_users.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open('../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

unscraped_users = all_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open('../data/raw/review_skipped_users.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open('../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open('../data/raw/users_with_no_reviews.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table('../data/raw/review_table.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, '../data/raw/review_table.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open('../data/raw/review_scraped_users.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open('../data/raw/review_scraped_users.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 114 users this round
# Got 230 reivews
# 7989 reviews are now in the bag, so to speak
# 2024-03-22 15:14:59
#
# Scraped 104 users this round
# Got 155 reivews
# 8144 reviews are now in the bag, so to speak
# 2024-03-22 15:17:25
#
# Scraped 103 users this round
# Got 166 reivews
# 8310 reviews are now in the bag, so to speak
# 2024-03-22 15:19:45
#
# Scraped 112 users this round
# Got 203 reivews
# 8513 reviews are now in the bag, so to speak
# 2024-03-22 15:22:19
#
# Scraped 120 users this round
# Got 248 reivews
# 8761 reviews are now in the bag, so to speak
# 2024-03-22 15:25:08
#
# Scraped 110 users this round
# Got 201 reivews
# 8962 reviews are now in the bag, so to speak
# 2024-03-22 15:27:51
#
# Scraped 117 users this round
# Got 142 reivews
# 9104 reviews are now in the bag, so to speak
# 2024-03-22 15:30:34
#
# Scraped 101 users this round
# Got 195 reivews
# 9299 reviews are now in the bag, so to speak
# 2024-03-22 15:32:53
#
# Scraped 102 users this round
# Got 182 reivews
# 9481 reviews are now in the bag, so to speak
# 2024-03-22 15:35:30
#
# Scraped 128 users this round
# Got 185 reivews
# 9666 reviews are now in the bag, so to speak
# 2024-03-22 15:38:30
#
# Scraped 119 users this round
# Got 189 reivews
# 9855 reviews are now in the bag, so to speak
# 2024-03-22 15:41:29
#
# Scraped 107 users this round
# Got 154 reivews
# 10009 reviews are now in the bag, so to speak
# 2024-03-22 15:43:52
#
# Scraped 109 users this round
# Got 172 reivews
# 10181 reviews are now in the bag, so to speak
# 2024-03-22 15:46:51
#
# Scraped 110 users this round
# Got 157 reivews
# 10338 reviews are now in the bag, so to speak
# 2024-03-22 15:49:25
#
# Scraped 134 users this round
# Got 192 reivews
# 10530 reviews are now in the bag, so to speak
# 2024-03-22 15:52:42
#
# Scraped 133 users this round
# Got 173 reivews
# 10703 reviews are now in the bag, so to speak
# 2024-03-22 15:55:47
#
# Scraped 105 users this round
# Got 195 reivews
# 10898 reviews are now in the bag, so to speak
# 2024-03-22 15:58:09
#
# Scraped 104 users this round
# Got 205 reivews
# 11103 reviews are now in the bag, so to speak
# 2024-03-22 16:00:38
#
# Scraped 104 users this round
# Got 186 reivews
# 11289 reviews are now in the bag, so to speak
# 2024-03-22 16:03:05
#
# Scraped 122 users this round
# Got 180 reivews
# 11469 reviews are now in the bag, so to speak
# 2024-03-22 16:06:18
#
# Scraped 102 users this round
# Got 209 reivews
# 11678 reviews are now in the bag, so to speak
# 2024-03-22 16:08:30
#
# Scraped 133 users this round
# Got 173 reivews
# 11851 reviews are now in the bag, so to speak
# 2024-03-22 16:11:34
#
# Scraped 105 users this round
# Got 168 reivews
# 12019 reviews are now in the bag, so to speak
# 2024-03-22 16:14:00
#
# Scraped 112 users this round
# Got 146 reivews
# 12165 reviews are now in the bag, so to speak
# 2024-03-22 16:16:35
#
# Scraped 113 users this round
# Got 218 reivews
# 12383 reviews are now in the bag, so to speak
# 2024-03-22 16:19:18
#
# Scraped 115 users this round
# Got 209 reivews
# 12592 reviews are now in the bag, so to speak
# 2024-03-22 16:21:49
#
# Scraped 107 users this round
# Got 164 reivews
# 12756 reviews are now in the bag, so to speak
# 2024-03-22 16:24:17
#
# Scraped 88 users this round
# Got 184 reivews
# 12940 reviews are now in the bag, so to speak
# 2024-03-22 16:26:13
#
# Scraped 93 users this round
# Got 199 reivews
# 13139 reviews are now in the bag, so to speak
# 2024-03-22 16:28:16
#
# Scraped 129 users this round
# Got 157 reivews
# 13296 reviews are now in the bag, so to speak
# 2024-03-22 16:31:16
#
# Scraped 106 users this round
# Got 198 reivews
# 13494 reviews are now in the bag, so to speak
# 2024-03-22 16:33:51
#
# Scraped 123 users this round
# Got 207 reivews
# 13701 reviews are now in the bag, so to speak
# 2024-03-22 16:36:41
#
# Scraped 97 users this round
# Got 190 reivews
# 13891 reviews are now in the bag, so to speak
# 2024-03-22 16:38:57
#
# Scraped 110 users this round
# Got 207 reivews
# 14098 reviews are now in the bag, so to speak
# 2024-03-22 16:41:37
#
# Scraped 109 users this round
# Got 205 reivews
# 14303 reviews are now in the bag, so to speak
# 2024-03-22 16:44:04
#
# Scraped 117 users this round
# Got 214 reivews
# 14517 reviews are now in the bag, so to speak
# 2024-03-22 16:46:43
#
# Scraped 125 users this round
# Got 232 reivews
# 14749 reviews are now in the bag, so to speak
# 2024-03-22 16:49:45
#
# Scraped 135 users this round
# Got 172 reivews
# 14921 reviews are now in the bag, so to speak
# 2024-03-22 16:52:46
#
# Scraped 102 users this round
# Got 175 reivews
# 15096 reviews are now in the bag, so to speak
# 2024-03-22 16:55:02
#
# Scraped 114 users this round
# Got 200 reivews
# 15296 reviews are now in the bag, so to speak
# 2024-03-22 16:57:33
#
# Scraped 126 users this round
# Got 163 reivews
# 15459 reviews are now in the bag, so to speak
# 2024-03-22 17:00:29
#
# Scraped 112 users this round
# Got 174 reivews
# 15633 reviews are now in the bag, so to speak
# 2024-03-22 17:03:04
#
# Scraped 102 users this round
# Got 206 reivews
# 15839 reviews are now in the bag, so to speak
# 2024-03-22 17:05:18
#
# Scraped 103 users this round
# Got 179 reivews
# 16018 reviews are now in the bag, so to speak
# 2024-03-22 17:07:37
#
# Scraped 91 users this round
# Got 205 reivews
# 16223 reviews are now in the bag, so to speak
# 2024-03-22 17:09:46
#
# Scraped 112 users this round
# Got 189 reivews
# 16412 reviews are now in the bag, so to speak
# 2024-03-22 17:12:50
#
# Scraped 95 users this round
# Got 181 reivews
# 16593 reviews are now in the bag, so to speak
# 2024-03-22 17:14:54
#
# Scraped 116 users this round
# Got 203 reivews
# 16796 reviews are now in the bag, so to speak
# 2024-03-22 17:17:31
#
# Scraped 120 users this round
# Got 195 reivews
# 16991 reviews are now in the bag, so to speak
# 2024-03-22 17:20:06
#
# Scraped 106 users this round
# Got 195 reivews
# 17186 reviews are now in the bag, so to speak
# 2024-03-22 17:22:33
#
# Scraped 102 users this round
# Got 156 reivews
# 17342 reviews are now in the bag, so to speak
# 2024-03-22 17:24:38
#
# Scraped 118 users this round
# Got 172 reivews
# 17514 reviews are now in the bag, so to speak
# 2024-03-22 17:27:21
#
# Scraped 101 users this round
# Got 172 reivews
# 17686 reviews are now in the bag, so to speak
# 2024-03-22 17:29:42
#
# Scraped 101 users this round
# Got 180 reivews
# 17866 reviews are now in the bag, so to speak
# 2024-03-22 17:31:58
#
# Scraped 120 users this round
# Got 189 reivews
# 18055 reviews are now in the bag, so to speak
# 2024-03-22 17:34:37
#
# Scraped 115 users this round
# Got 161 reivews
# 18216 reviews are now in the bag, so to speak
# 2024-03-22 17:37:12
#
# Scraped 107 users this round
# Got 176 reivews
# 18392 reviews are now in the bag, so to speak
# 2024-03-22 17:39:34
#
# Scraped 100 users this round
# Got 204 reivews
# 18596 reviews are now in the bag, so to speak
# 2024-03-22 17:41:54
#
# Scraped 112 users this round
# Got 177 reivews
# 18773 reviews are now in the bag, so to speak
# 2024-03-22 17:44:25
#
# Scraped 118 users this round
# Got 161 reivews
# 18934 reviews are now in the bag, so to speak
# 2024-03-22 17:47:05
#
# Scraped 103 users this round
# Got 190 reivews
# 19124 reviews are now in the bag, so to speak
# 2024-03-22 17:49:37
#
# Scraped 93 users this round
# Got 183 reivews
# 19307 reviews are now in the bag, so to speak
# 2024-03-22 17:51:48
#
# Scraped 113 users this round
# Got 237 reivews
# 19544 reviews are now in the bag, so to speak
# 2024-03-22 17:54:25
#
# Scraped 95 users this round
# Got 211 reivews
# 19755 reviews are now in the bag, so to speak
# 2024-03-22 17:56:43
#
# Scraped 105 users this round
# Got 186 reivews
# 19941 reviews are now in the bag, so to speak
# 2024-03-22 17:58:59
#
# Scraped 94 users this round
# Got 166 reivews
# 20107 reviews are now in the bag, so to speak
# 2024-03-22 18:01:15
#
# Scraped 105 users this round
# Got 171 reivews
# 20278 reviews are now in the bag, so to speak
# 2024-03-22 18:03:38
#
# Scraped 99 users this round
# Got 211 reivews
# 20489 reviews are now in the bag, so to speak
# 2024-03-22 18:05:55
#
# Scraped 118 users this round
# Got 174 reivews
# 20663 reviews are now in the bag, so to speak
# 2024-03-22 18:08:29
#
# Scraped 125 users this round
# Got 154 reivews
# 20817 reviews are now in the bag, so to speak
# 2024-03-22 18:11:17
#
# Scraped 93 users this round
# Got 151 reivews
# 20968 reviews are now in the bag, so to speak
# 2024-03-22 18:13:18
#
# Scraped 104 users this round
# Got 162 reivews
# 21130 reviews are now in the bag, so to speak
# 2024-03-22 18:15:38
