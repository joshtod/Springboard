# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 3
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 54 users this round
# Got 339 reivews
# 339 reviews are now in the bag, so to speak
# 2024-04-03 18:08:38
#
# Scraped 60 users this round
# Got 310 reivews
# 649 reviews are now in the bag, so to speak
# 2024-04-03 18:10:20
#
# Scraped 56 users this round
# Got 368 reivews
# 1017 reviews are now in the bag, so to speak
# 2024-04-03 18:12:10
#
# Scraped 59 users this round
# Got 333 reivews
# 1350 reviews are now in the bag, so to speak
# 2024-04-03 18:13:56
#
# Scraped 58 users this round
# Got 356 reivews
# 1706 reviews are now in the bag, so to speak
# 2024-04-03 18:15:36
#
# Scraped 54 users this round
# Got 349 reivews
# 2055 reviews are now in the bag, so to speak
# 2024-04-03 18:17:13
#
# Scraped 53 users this round
# Got 339 reivews
# 2394 reviews are now in the bag, so to speak
# 2024-04-03 18:18:41
#
# Scraped 59 users this round
# Got 319 reivews
# 2713 reviews are now in the bag, so to speak
# 2024-04-03 18:20:19
#
# Scraped 58 users this round
# Got 340 reivews
# 3053 reviews are now in the bag, so to speak
# 2024-04-03 18:22:05
#
# Scraped 55 users this round
# Got 305 reivews
# 3358 reviews are now in the bag, so to speak
# 2024-04-03 18:23:43
#
# Scraped 55 users this round
# Got 323 reivews
# 3681 reviews are now in the bag, so to speak
# 2024-04-03 18:25:19
#
# Scraped 57 users this round
# Got 331 reivews
# 4012 reviews are now in the bag, so to speak
# 2024-04-03 18:26:53
#
# Scraped 55 users this round
# Got 359 reivews
# 4371 reviews are now in the bag, so to speak
# 2024-04-03 18:28:29
#
# Scraped 56 users this round
# Got 357 reivews
# 4728 reviews are now in the bag, so to speak
# 2024-04-03 18:30:18
#
# Scraped 54 users this round
# Got 302 reivews
# 5030 reviews are now in the bag, so to speak
# 2024-04-03 18:31:55
#
# Scraped 57 users this round
# Got 343 reivews
# 5373 reviews are now in the bag, so to speak
# 2024-04-03 18:33:33
#
# Scraped 60 users this round
# Got 333 reivews
# 5706 reviews are now in the bag, so to speak
# 2024-04-03 18:35:18
#
# Scraped 56 users this round
# Got 358 reivews
# 6064 reviews are now in the bag, so to speak
# 2024-04-03 18:37:01
#
# Scraped 62 users this round
# Got 345 reivews
# 6409 reviews are now in the bag, so to speak
# 2024-04-03 18:38:50
#
# Scraped 60 users this round
# Got 337 reivews
# 6746 reviews are now in the bag, so to speak
# 2024-04-03 18:40:33
#
# Scraped 56 users this round
# Got 297 reivews
# 7043 reviews are now in the bag, so to speak
# 2024-04-03 18:42:14
#
# Scraped 53 users this round
# Got 379 reivews
# 7422 reviews are now in the bag, so to speak
# 2024-04-03 18:43:55
#
# Scraped 57 users this round
# Got 365 reivews
# 7787 reviews are now in the bag, so to speak
# 2024-04-03 18:45:31
#
# Scraped 54 users this round
# Got 360 reivews
# 8147 reviews are now in the bag, so to speak
# 2024-04-03 18:47:12
#
# Scraped 57 users this round
# Got 375 reivews
# 8522 reviews are now in the bag, so to speak
# 2024-04-03 18:48:55
#
# Scraped 59 users this round
# Got 365 reivews
# 8887 reviews are now in the bag, so to speak
# 2024-04-03 18:50:40
#
# Scraped 56 users this round
# Got 352 reivews
# 9239 reviews are now in the bag, so to speak
# 2024-04-03 18:52:11
#
# Scraped 60 users this round
# Got 324 reivews
# 9563 reviews are now in the bag, so to speak
# 2024-04-03 18:53:42
#
# Scraped 59 users this round
# Got 343 reivews
# 9906 reviews are now in the bag, so to speak
# 2024-04-03 18:55:29
#
# Scraped 60 users this round
# Got 346 reivews
# 10252 reviews are now in the bag, so to speak
# 2024-04-03 18:57:16
#
# Scraped 56 users this round
# Got 318 reivews
# 10570 reviews are now in the bag, so to speak
# 2024-04-03 18:58:46
#
# Scraped 56 users this round
# Got 323 reivews
# 10893 reviews are now in the bag, so to speak
# 2024-04-03 19:00:28
#
# Scraped 54 users this round
# Got 338 reivews
# 11231 reviews are now in the bag, so to speak
# 2024-04-03 19:01:58
#
# Scraped 54 users this round
# Got 326 reivews
# 11557 reviews are now in the bag, so to speak
# 2024-04-03 19:03:33
#
# Scraped 62 users this round
# Got 335 reivews
# 11892 reviews are now in the bag, so to speak
# 2024-04-03 19:05:16
#
# Scraped 56 users this round
# Got 317 reivews
# 12209 reviews are now in the bag, so to speak
# 2024-04-03 19:06:54
#
# Scraped 58 users this round
# Got 374 reivews
# 12583 reviews are now in the bag, so to speak
# 2024-04-03 19:08:33
#
# Scraped 58 users this round
# Got 309 reivews
# 12892 reviews are now in the bag, so to speak
# 2024-04-03 19:10:20
#
# Scraped 58 users this round
# Got 348 reivews
# 13240 reviews are now in the bag, so to speak
# 2024-04-03 19:12:08
#
# Scraped 57 users this round
# Got 357 reivews
# 13597 reviews are now in the bag, so to speak
# 2024-04-03 19:13:50
#
# Scraped 55 users this round
# Got 325 reivews
# 13922 reviews are now in the bag, so to speak
# 2024-04-03 19:18:18
#
# Scraped 67 users this round
# Got 327 reivews
# 14249 reviews are now in the bag, so to speak
# 2024-04-03 19:20:13
#
# Scraped 52 users this round
# Got 330 reivews
# 14579 reviews are now in the bag, so to speak
# 2024-04-03 19:21:37
#
# Scraped 59 users this round
# Got 324 reivews
# 14903 reviews are now in the bag, so to speak
# 2024-04-03 19:23:24
#
# Scraped 52 users this round
# Got 293 reivews
# 15196 reviews are now in the bag, so to speak
# 2024-04-03 19:24:47
#
# Scraped 53 users this round
# Got 353 reivews
# 15549 reviews are now in the bag, so to speak
# 2024-04-03 19:26:19
#
# Scraped 54 users this round
# Got 363 reivews
# 15912 reviews are now in the bag, so to speak
# 2024-04-03 19:27:52
#
# Scraped 57 users this round
# Got 340 reivews
# 16252 reviews are now in the bag, so to speak
# 2024-04-03 19:29:41
#
# Scraped 57 users this round
# Got 336 reivews
# 16588 reviews are now in the bag, so to speak
# 2024-04-03 19:31:18
#
# Scraped 54 users this round
# Got 345 reivews
# 16933 reviews are now in the bag, so to speak
# 2024-04-03 19:32:47
#
# Scraped 62 users this round
# Got 372 reivews
# 17305 reviews are now in the bag, so to speak
# 2024-04-03 19:34:34
#
# Scraped 56 users this round
# Got 319 reivews
# 17624 reviews are now in the bag, so to speak
# 2024-04-03 19:36:08
#
# Scraped 57 users this round
# Got 335 reivews
# 17959 reviews are now in the bag, so to speak
# 2024-04-03 19:37:48
#
# Scraped 57 users this round
# Got 347 reivews
# 18306 reviews are now in the bag, so to speak
# 2024-04-03 19:39:26
#
# Scraped 56 users this round
# Got 340 reivews
# 18646 reviews are now in the bag, so to speak
# 2024-04-03 19:40:58
#
# Scraped 59 users this round
# Got 362 reivews
# 19008 reviews are now in the bag, so to speak
# 2024-04-03 19:42:31
#
# Scraped 54 users this round
# Got 297 reivews
# 19305 reviews are now in the bag, so to speak
# 2024-04-03 19:44:06
#
# Scraped 57 users this round
# Got 312 reivews
# 19617 reviews are now in the bag, so to speak
# 2024-04-03 19:45:42
#
# Scraped 55 users this round
# Got 357 reivews
# 19974 reviews are now in the bag, so to speak
# 2024-04-03 19:47:18
#
# Scraped 51 users this round
# Got 371 reivews
# 20345 reviews are now in the bag, so to speak
# 2024-04-03 19:48:44
#
# Scraped 54 users this round
# Got 380 reivews
# 20725 reviews are now in the bag, so to speak
# 2024-04-03 19:50:31
#
# Scraped 51 users this round
# Got 341 reivews
# 21066 reviews are now in the bag, so to speak
# 2024-04-03 19:51:56
#
# Scraped 53 users this round
# Got 369 reivews
# 21435 reviews are now in the bag, so to speak
# 2024-04-03 19:53:26
#
# Scraped 56 users this round
# Got 335 reivews
# 21770 reviews are now in the bag, so to speak
# 2024-04-03 19:54:56
#
# Scraped 64 users this round
# Got 352 reivews
# 22122 reviews are now in the bag, so to speak
# 2024-04-03 19:56:51
#
# Scraped 54 users this round
# Got 311 reivews
# 22433 reviews are now in the bag, so to speak
# 2024-04-03 19:58:22
#
# Scraped 53 users this round
# Got 344 reivews
# 22777 reviews are now in the bag, so to speak
# 2024-04-03 19:59:54
#
# Scraped 58 users this round
# Got 336 reivews
# 23113 reviews are now in the bag, so to speak
# 2024-04-03 20:01:38
#
# Scraped 61 users this round
# Got 341 reivews
# 23454 reviews are now in the bag, so to speak
# 2024-04-03 20:03:20
#
# Scraped 57 users this round
# Got 365 reivews
# 23819 reviews are now in the bag, so to speak
# 2024-04-03 20:05:02
#
# Scraped 56 users this round
# Got 367 reivews
# 24186 reviews are now in the bag, so to speak
# 2024-04-03 20:06:44
#
# Scraped 54 users this round
# Got 350 reivews
# 24536 reviews are now in the bag, so to speak
# 2024-04-03 20:08:26
#
# Scraped 52 users this round
# Got 349 reivews
# 24885 reviews are now in the bag, so to speak
# 2024-04-03 20:09:57
#
# Scraped 61 users this round
# Got 329 reivews
# 25214 reviews are now in the bag, so to speak
# 2024-04-03 20:11:37
#
# Scraped 53 users this round
# Got 372 reivews
# 25586 reviews are now in the bag, so to speak
# 2024-04-03 20:13:13
#
# Scraped 55 users this round
# Got 338 reivews
# 25924 reviews are now in the bag, so to speak
# 2024-04-03 20:14:54
#
# Scraped 55 users this round
# Got 321 reivews
# 26245 reviews are now in the bag, so to speak
# 2024-04-03 20:16:31
#
# Scraped 54 users this round
# Got 363 reivews
# 26608 reviews are now in the bag, so to speak
# 2024-04-03 20:18:10
#
# Scraped 55 users this round
# Got 341 reivews
# 26949 reviews are now in the bag, so to speak
# 2024-04-03 20:19:44
#
# Scraped 51 users this round
# Got 326 reivews
# 27275 reviews are now in the bag, so to speak
# 2024-04-03 20:21:09
#
# Scraped 52 users this round
# Got 349 reivews
# 27624 reviews are now in the bag, so to speak
# 2024-04-03 20:22:39
#
# Scraped 58 users this round
# Got 358 reivews
# 27982 reviews are now in the bag, so to speak
# 2024-04-03 20:24:26
#
# Scraped 55 users this round
# Got 337 reivews
# 28319 reviews are now in the bag, so to speak
# 2024-04-03 20:25:58
#
# Scraped 59 users this round
# Got 325 reivews
# 28644 reviews are now in the bag, so to speak
# 2024-04-03 20:27:49
#
# Scraped 55 users this round
# Got 347 reivews
# 28991 reviews are now in the bag, so to speak
# 2024-04-03 20:29:23
#
# Scraped 59 users this round
# Got 338 reivews
# 29329 reviews are now in the bag, so to speak
# 2024-04-03 20:31:03
#
# Scraped 56 users this round
# Got 295 reivews
# 29624 reviews are now in the bag, so to speak
# 2024-04-03 20:32:30
#
# Scraped 59 users this round
# Got 370 reivews
# 29994 reviews are now in the bag, so to speak
# 2024-04-03 20:34:15
#
# Scraped 56 users this round
# Got 389 reivews
# 30383 reviews are now in the bag, so to speak
# 2024-04-03 20:35:50
#
# Scraped 61 users this round
# Got 302 reivews
# 30685 reviews are now in the bag, so to speak
# 2024-04-03 20:37:32
#
# Scraped 53 users this round
# Got 400 reivews
# 31085 reviews are now in the bag, so to speak
# 2024-04-03 20:39:06
#
# Scraped 53 users this round
# Got 353 reivews
# 31438 reviews are now in the bag, so to speak
# 2024-04-03 20:40:35
#
# Scraped 54 users this round
# Got 362 reivews
# 31800 reviews are now in the bag, so to speak
# 2024-04-03 20:42:14
#
# Scraped 55 users this round
# Got 344 reivews
# 32144 reviews are now in the bag, so to speak
# 2024-04-03 20:43:47
#
# Scraped 55 users this round
# Got 360 reivews
# 32504 reviews are now in the bag, so to speak
# 2024-04-03 20:45:20
#
# Scraped 55 users this round
# Got 327 reivews
# 32831 reviews are now in the bag, so to speak
# 2024-04-03 20:46:50
#
# Scraped 53 users this round
# Got 300 reivews
# 33131 reviews are now in the bag, so to speak
# 2024-04-03 20:48:19
#
# Scraped 54 users this round
# Got 356 reivews
# 33487 reviews are now in the bag, so to speak
# 2024-04-03 20:49:59
#
# Scraped 57 users this round
# Got 354 reivews
# 33841 reviews are now in the bag, so to speak
# 2024-04-03 20:51:39
#
# Scraped 56 users this round
# Got 368 reivews
# 34209 reviews are now in the bag, so to speak
# 2024-04-03 20:53:15
#
# Scraped 61 users this round
# Got 350 reivews
# 34559 reviews are now in the bag, so to speak
# 2024-04-03 20:55:05
#
# Scraped 60 users this round
# Got 328 reivews
# 34887 reviews are now in the bag, so to speak
# 2024-04-03 20:57:05
#
# Scraped 57 users this round
# Got 308 reivews
# 35195 reviews are now in the bag, so to speak
# 2024-04-03 20:58:45
#
# Scraped 54 users this round
# Got 315 reivews
# 35510 reviews are now in the bag, so to speak
# 2024-04-03 21:00:16
#
# Scraped 54 users this round
# Got 316 reivews
# 35826 reviews are now in the bag, so to speak
# 2024-04-03 21:01:50
#
# Scraped 58 users this round
# Got 361 reivews
# 36187 reviews are now in the bag, so to speak
# 2024-04-03 21:03:38
#
# Scraped 53 users this round
# Got 319 reivews
# 36506 reviews are now in the bag, so to speak
# 2024-04-03 21:05:13
#
# Scraped 54 users this round
# Got 348 reivews
# 36854 reviews are now in the bag, so to speak
# 2024-04-03 21:06:54
#
# Scraped 58 users this round
# Got 372 reivews
# 37226 reviews are now in the bag, so to speak
# 2024-04-03 21:08:41
#
# Scraped 54 users this round
# Got 297 reivews
# 37523 reviews are now in the bag, so to speak
# 2024-04-03 21:10:17
#
# Scraped 56 users this round
# Got 338 reivews
# 37861 reviews are now in the bag, so to speak
# 2024-04-03 21:12:09
#
# Scraped 56 users this round
# Got 349 reivews
# 38210 reviews are now in the bag, so to speak
# 2024-04-03 21:13:46
#
# Scraped 56 users this round
# Got 371 reivews
# 38581 reviews are now in the bag, so to speak
# 2024-04-03 21:15:26
#
# Scraped 54 users this round
# Got 307 reivews
# 38888 reviews are now in the bag, so to speak
# 2024-04-03 21:17:13
#
# Scraped 57 users this round
# Got 384 reivews
# 39272 reviews are now in the bag, so to speak
# 2024-04-03 21:18:59
#
# Scraped 59 users this round
# Got 359 reivews
# 39631 reviews are now in the bag, so to speak
# 2024-04-03 21:20:41
#
# Scraped 53 users this round
# Got 335 reivews
# 39966 reviews are now in the bag, so to speak
# 2024-04-03 21:22:11
#
# Scraped 58 users this round
# Got 399 reivews
# 40365 reviews are now in the bag, so to speak
# 2024-04-03 21:24:00
#
# Scraped 55 users this round
# Got 320 reivews
# 40685 reviews are now in the bag, so to speak
# 2024-04-03 21:25:37
#
# Scraped 56 users this round
# Got 306 reivews
# 40991 reviews are now in the bag, so to speak
# 2024-04-03 21:27:10
#
# Scraped 60 users this round
# Got 400 reivews
# 41391 reviews are now in the bag, so to speak
# 2024-04-03 21:28:52
#
# Scraped 56 users this round
# Got 308 reivews
# 41699 reviews are now in the bag, so to speak
# 2024-04-03 21:30:32
#
# Scraped 55 users this round
# Got 351 reivews
# 42050 reviews are now in the bag, so to speak
# 2024-04-03 21:32:13
#
# Scraped 55 users this round
# Got 321 reivews
# 42371 reviews are now in the bag, so to speak
# 2024-04-03 21:33:41
#
# Scraped 55 users this round
# Got 329 reivews
# 42700 reviews are now in the bag, so to speak
# 2024-04-03 21:35:23
#
# Scraped 55 users this round
# Got 338 reivews
# 43038 reviews are now in the bag, so to speak
# 2024-04-03 21:36:59
#
# Scraped 56 users this round
# Got 374 reivews
# 43412 reviews are now in the bag, so to speak
# 2024-04-03 21:38:40
#
# Scraped 56 users this round
# Got 344 reivews
# 43756 reviews are now in the bag, so to speak
# 2024-04-03 21:40:10
#
# Scraped 58 users this round
# Got 331 reivews
# 44087 reviews are now in the bag, so to speak
# 2024-04-03 21:41:46
#
# Scraped 57 users this round
# Got 304 reivews
# 44391 reviews are now in the bag, so to speak
# 2024-04-03 21:43:16
#
# Scraped 57 users this round
# Got 343 reivews
# 44734 reviews are now in the bag, so to speak
# 2024-04-03 21:44:55
#
# Scraped 64 users this round
# Got 341 reivews
# 45075 reviews are now in the bag, so to speak
# 2024-04-03 21:46:48
#
# Scraped 58 users this round
# Got 390 reivews
# 45465 reviews are now in the bag, so to speak
# 2024-04-03 21:48:33
#
# Scraped 54 users this round
# Got 304 reivews
# 45769 reviews are now in the bag, so to speak
# 2024-04-03 21:50:02
#
# Scraped 54 users this round
# Got 329 reivews
# 46098 reviews are now in the bag, so to speak
# 2024-04-03 21:51:39
#
# Scraped 53 users this round
# Got 361 reivews
# 46459 reviews are now in the bag, so to speak
# 2024-04-03 21:53:09
#
# Scraped 51 users this round
# Got 292 reivews
# 46751 reviews are now in the bag, so to speak
# 2024-04-03 21:54:36
#
# Scraped 61 users this round
# Got 370 reivews
# 47121 reviews are now in the bag, so to speak
# 2024-04-03 21:56:14
#
# Scraped 54 users this round
# Got 334 reivews
# 47455 reviews are now in the bag, so to speak
# 2024-04-03 21:57:43
#
# Scraped 61 users this round
# Got 325 reivews
# 47780 reviews are now in the bag, so to speak
# 2024-04-03 21:59:24
#
# Scraped 63 users this round
# Got 362 reivews
# 48142 reviews are now in the bag, so to speak
# 2024-04-03 22:01:02
#
# Scraped 52 users this round
# Got 327 reivews
# 48469 reviews are now in the bag, so to speak
# 2024-04-03 22:02:26
#
# Scraped 57 users this round
# Got 356 reivews
# 48825 reviews are now in the bag, so to speak
# 2024-04-03 22:04:06
#
# Scraped 58 users this round
# Got 288 reivews
# 49113 reviews are now in the bag, so to speak
# 2024-04-03 22:05:53
#
# Scraped 52 users this round
# Got 307 reivews
# 49420 reviews are now in the bag, so to speak
# 2024-04-03 22:07:18
#
# Scraped 53 users this round
# Got 366 reivews
# 49786 reviews are now in the bag, so to speak
# 2024-04-03 22:09:01
#
# Scraped 55 users this round
# Got 337 reivews
# 50123 reviews are now in the bag, so to speak
# 2024-04-03 22:10:35
#
# Scraped 59 users this round
# Got 353 reivews
# 50476 reviews are now in the bag, so to speak
# 2024-04-03 22:12:13
#
# Scraped 61 users this round
# Got 318 reivews
# 50794 reviews are now in the bag, so to speak
# 2024-04-03 22:13:59
#
# Scraped 57 users this round
# Got 361 reivews
# 51155 reviews are now in the bag, so to speak
# 2024-04-03 22:15:53
#
# Scraped 56 users this round
# Got 377 reivews
# 51532 reviews are now in the bag, so to speak
# 2024-04-03 22:17:29
#
# Scraped 58 users this round
# Got 376 reivews
# 51908 reviews are now in the bag, so to speak
# 2024-04-03 22:19:12
#
# Scraped 58 users this round
# Got 306 reivews
# 52214 reviews are now in the bag, so to speak
# 2024-04-03 22:21:02
#
# Scraped 55 users this round
# Got 328 reivews
# 52542 reviews are now in the bag, so to speak
# 2024-04-03 22:22:37
#
# Scraped 53 users this round
# Got 347 reivews
# 52889 reviews are now in the bag, so to speak
# 2024-04-03 22:24:32
#
# Scraped 53 users this round
# Got 339 reivews
# 53228 reviews are now in the bag, so to speak
# 2024-04-03 22:26:48
#
# Scraped 57 users this round
# Got 347 reivews
# 53575 reviews are now in the bag, so to speak
# 2024-04-03 22:29:39
#
# Scraped 55 users this round
# Got 331 reivews
# 53906 reviews are now in the bag, so to speak
# 2024-04-03 22:32:31
#
# Scraped 54 users this round
# Got 377 reivews
# 54283 reviews are now in the bag, so to speak
# 2024-04-03 22:35:24
#
# Scraped 56 users this round
# Got 304 reivews
# 54587 reviews are now in the bag, so to speak
# 2024-04-03 22:38:23
#
# Scraped 57 users this round
# Got 325 reivews
# 54912 reviews are now in the bag, so to speak
# 2024-04-03 22:41:28
#
# Scraped 56 users this round
# Got 341 reivews
# 55253 reviews are now in the bag, so to speak
# 2024-04-03 22:44:32
#
# Scraped 62 users this round
# Got 363 reivews
# 55616 reviews are now in the bag, so to speak
# 2024-04-03 22:47:57
#
# Scraped 54 users this round
# Got 357 reivews
# 55973 reviews are now in the bag, so to speak
# 2024-04-03 22:50:55
#
# Scraped 53 users this round
# Got 369 reivews
# 56342 reviews are now in the bag, so to speak
# 2024-04-03 22:53:44
#
# Scraped 59 users this round
# Got 316 reivews
# 56658 reviews are now in the bag, so to speak
# 2024-04-03 22:56:59
#
# Scraped 57 users this round
# Got 321 reivews
# 56979 reviews are now in the bag, so to speak
# 2024-04-03 23:00:05
#
# Scraped 54 users this round
# Got 359 reivews
# 57338 reviews are now in the bag, so to speak
# 2024-04-03 23:02:39
#
# Scraped 52 users this round
# Got 310 reivews
# 57648 reviews are now in the bag, so to speak
# 2024-04-03 23:05:14
#
# Scraped 59 users this round
# Got 348 reivews
# 57996 reviews are now in the bag, so to speak
# 2024-04-03 23:08:30
#
# Scraped 56 users this round
# Got 334 reivews
# 58330 reviews are now in the bag, so to speak
# 2024-04-03 23:11:56
#
# Scraped 57 users this round
# Got 325 reivews
# 58655 reviews are now in the bag, so to speak
# 2024-04-03 23:14:34
#
# Scraped 54 users this round
# Got 369 reivews
# 59024 reviews are now in the bag, so to speak
# 2024-04-03 23:16:09
#
# Scraped 59 users this round
# Got 344 reivews
# 59368 reviews are now in the bag, so to speak
# 2024-04-03 23:17:55
#
# Scraped 56 users this round
# Got 342 reivews
# 59710 reviews are now in the bag, so to speak
# 2024-04-03 23:19:30
#
# Scraped 54 users this round
# Got 349 reivews
# 60059 reviews are now in the bag, so to speak
# 2024-04-03 23:21:02
#
# Scraped 54 users this round
# Got 383 reivews
# 60442 reviews are now in the bag, so to speak
# 2024-04-03 23:22:39
#
# Scraped 55 users this round
# Got 354 reivews
# 60796 reviews are now in the bag, so to speak
# 2024-04-03 23:24:17
#
# Scraped 57 users this round
# Got 334 reivews
# 61130 reviews are now in the bag, so to speak
# 2024-04-03 23:25:52
#
# Scraped 56 users this round
# Got 331 reivews
# 61461 reviews are now in the bag, so to speak
# 2024-04-03 23:27:20
#
# Scraped 58 users this round
# Got 351 reivews
# 61812 reviews are now in the bag, so to speak
# 2024-04-03 23:29:01
#
# Scraped 61 users this round
# Got 296 reivews
# 62108 reviews are now in the bag, so to speak
# 2024-04-03 23:30:48
#
# Scraped 55 users this round
# Got 358 reivews
# 62466 reviews are now in the bag, so to speak
# 2024-04-03 23:32:28
#
# Scraped 55 users this round
# Got 325 reivews
# 62791 reviews are now in the bag, so to speak
# 2024-04-03 23:34:10
#
# Scraped 52 users this round
# Got 347 reivews
# 63138 reviews are now in the bag, so to speak
# 2024-04-03 23:35:39
#
# Scraped 55 users this round
# Got 342 reivews
# 63480 reviews are now in the bag, so to speak
# 2024-04-03 23:37:11
#
# Scraped 59 users this round
# Got 351 reivews
# 63831 reviews are now in the bag, so to speak
# 2024-04-03 23:38:47
#
# Scraped 60 users this round
# Got 312 reivews
# 64143 reviews are now in the bag, so to speak
# 2024-04-03 23:40:28
#
# Scraped 56 users this round
# Got 339 reivews
# 64482 reviews are now in the bag, so to speak
# 2024-04-03 23:42:02
#
# Scraped 54 users this round
# Got 313 reivews
# 64795 reviews are now in the bag, so to speak
# 2024-04-03 23:43:38
#
# Scraped 56 users this round
# Got 338 reivews
# 65133 reviews are now in the bag, so to speak
# 2024-04-03 23:45:20
#
# Scraped 60 users this round
# Got 338 reivews
# 65471 reviews are now in the bag, so to speak
# 2024-04-03 23:47:09
#
# Scraped 60 users this round
# Got 354 reivews
# 65825 reviews are now in the bag, so to speak
# 2024-04-03 23:49:13
#
# Scraped 62 users this round
# Got 357 reivews
# 66182 reviews are now in the bag, so to speak
# 2024-04-03 23:50:52
#
# Scraped 53 users this round
# Got 350 reivews
# 66532 reviews are now in the bag, so to speak
# 2024-04-03 23:52:21
#
# Scraped 55 users this round
# Got 365 reivews
# 66897 reviews are now in the bag, so to speak
# 2024-04-03 23:53:51
#
# Scraped 55 users this round
# Got 321 reivews
# 67218 reviews are now in the bag, so to speak
# 2024-04-03 23:55:23
#
# Scraped 59 users this round
# Got 321 reivews
# 67539 reviews are now in the bag, so to speak
# 2024-04-03 23:57:03
#
# Scraped 55 users this round
# Got 309 reivews
# 67848 reviews are now in the bag, so to speak
# 2024-04-03 23:58:38
#
# Scraped 61 users this round
# Got 355 reivews
# 68203 reviews are now in the bag, so to speak
# 2024-04-04 00:00:30
#
# Scraped 58 users this round
# Got 327 reivews
# 68530 reviews are now in the bag, so to speak
# 2024-04-04 00:02:12
#
# Scraped 60 users this round
# Got 343 reivews
# 68873 reviews are now in the bag, so to speak
# 2024-04-04 00:03:51
#
# Scraped 55 users this round
# Got 310 reivews
# 69183 reviews are now in the bag, so to speak
# 2024-04-04 00:05:23
#
# Scraped 56 users this round
# Got 354 reivews
# 69537 reviews are now in the bag, so to speak
# 2024-04-04 00:07:04
#
# Scraped 54 users this round
# Got 377 reivews
# 69914 reviews are now in the bag, so to speak
# 2024-04-04 00:08:37
#
# Scraped 55 users this round
# Got 339 reivews
# 70253 reviews are now in the bag, so to speak
# 2024-04-04 00:10:35
#
# Scraped 57 users this round
# Got 301 reivews
# 70554 reviews are now in the bag, so to speak
# 2024-04-04 00:12:27
#
# Scraped 59 users this round
# Got 335 reivews
# 70889 reviews are now in the bag, so to speak
# 2024-04-04 00:14:10
#
# Scraped 53 users this round
# Got 312 reivews
# 71201 reviews are now in the bag, so to speak
# 2024-04-04 00:15:33
#
# Scraped 53 users this round
# Got 351 reivews
# 71552 reviews are now in the bag, so to speak
# 2024-04-04 00:16:54
#
# Scraped 56 users this round
# Got 324 reivews
# 71876 reviews are now in the bag, so to speak
# 2024-04-04 00:18:30
#
# Scraped 59 users this round
# Got 311 reivews
# 72187 reviews are now in the bag, so to speak
# 2024-04-04 00:20:12
#
# Scraped 51 users this round
# Got 305 reivews
# 72492 reviews are now in the bag, so to speak
# 2024-04-04 00:21:34
#
# Scraped 57 users this round
# Got 371 reivews
# 72863 reviews are now in the bag, so to speak
# 2024-04-04 00:23:26
#
# Scraped 57 users this round
# Got 353 reivews
# 73216 reviews are now in the bag, so to speak
# 2024-04-04 00:25:00
#
# Scraped 52 users this round
# Got 355 reivews
# 73571 reviews are now in the bag, so to speak
# 2024-04-04 00:26:37
#
# Scraped 54 users this round
# Got 328 reivews
# 73899 reviews are now in the bag, so to speak
# 2024-04-04 00:28:16
#
# Scraped 53 users this round
# Got 356 reivews
# 74255 reviews are now in the bag, so to speak
# 2024-04-04 00:29:47
#
# Scraped 61 users this round
# Got 351 reivews
# 74606 reviews are now in the bag, so to speak
# 2024-04-04 00:31:33
#
# Scraped 56 users this round
# Got 346 reivews
# 74952 reviews are now in the bag, so to speak
# 2024-04-04 00:33:09
#
# Scraped 51 users this round
# Got 320 reivews
# 75272 reviews are now in the bag, so to speak
# 2024-04-04 00:34:33
#
# Scraped 57 users this round
# Got 362 reivews
# 75634 reviews are now in the bag, so to speak
# 2024-04-04 00:36:13
#
# Scraped 55 users this round
# Got 364 reivews
# 75998 reviews are now in the bag, so to speak
# 2024-04-04 00:37:46
#
# Scraped 56 users this round
# Got 340 reivews
# 76338 reviews are now in the bag, so to speak
# 2024-04-04 00:39:20
#
# Scraped 54 users this round
# Got 349 reivews
# 76687 reviews are now in the bag, so to speak
# 2024-04-04 00:40:45
#
# Scraped 57 users this round
# Got 337 reivews
# 77024 reviews are now in the bag, so to speak
# 2024-04-04 00:42:20
#
# Scraped 54 users this round
# Got 350 reivews
# 77374 reviews are now in the bag, so to speak
# 2024-04-04 00:43:49
#
# Scraped 54 users this round
# Got 366 reivews
# 77740 reviews are now in the bag, so to speak
# 2024-04-04 00:45:21
#
# Scraped 52 users this round
# Got 299 reivews
# 78039 reviews are now in the bag, so to speak
# 2024-04-04 00:46:50
#
# Scraped 55 users this round
# Got 349 reivews
# 78388 reviews are now in the bag, so to speak
# 2024-04-04 00:48:28
#
# Scraped 55 users this round
# Got 356 reivews
# 78744 reviews are now in the bag, so to speak
# 2024-04-04 00:49:56
#
# Scraped 54 users this round
# Got 314 reivews
# 79058 reviews are now in the bag, so to speak
# 2024-04-04 00:51:34
#
# Scraped 61 users this round
# Got 313 reivews
# 79371 reviews are now in the bag, so to speak
# 2024-04-04 00:53:15
#
# Scraped 54 users this round
# Got 374 reivews
# 79745 reviews are now in the bag, so to speak
# 2024-04-04 00:54:37
#
# Scraped 55 users this round
# Got 342 reivews
# 80087 reviews are now in the bag, so to speak
# 2024-04-04 00:56:09
#
# Scraped 56 users this round
# Got 325 reivews
# 80412 reviews are now in the bag, so to speak
# 2024-04-04 00:57:38
#
# Scraped 54 users this round
# Got 321 reivews
# 80733 reviews are now in the bag, so to speak
# 2024-04-04 00:59:06
#
# Scraped 54 users this round
# Got 324 reivews
# 81057 reviews are now in the bag, so to speak
# 2024-04-04 01:00:48
#
# Scraped 54 users this round
# Got 308 reivews
# 81365 reviews are now in the bag, so to speak
# 2024-04-04 01:02:34
#
# Scraped 57 users this round
# Got 326 reivews
# 81691 reviews are now in the bag, so to speak
# 2024-04-04 01:04:09
#
# Scraped 56 users this round
# Got 333 reivews
# 82024 reviews are now in the bag, so to speak
# 2024-04-04 01:05:51
#
# Scraped 63 users this round
# Got 333 reivews
# 82357 reviews are now in the bag, so to speak
# 2024-04-04 01:07:42
#
# Scraped 55 users this round
# Got 341 reivews
# 82698 reviews are now in the bag, so to speak
# 2024-04-04 01:09:11
#
# Scraped 57 users this round
# Got 343 reivews
# 83041 reviews are now in the bag, so to speak
# 2024-04-04 01:10:52
#
# Scraped 52 users this round
# Got 351 reivews
# 83392 reviews are now in the bag, so to speak
# 2024-04-04 01:12:17
#
# Scraped 57 users this round
# Got 297 reivews
# 83689 reviews are now in the bag, so to speak
# 2024-04-04 01:13:59
#
# Scraped 60 users this round
# Got 270 reivews
# 83959 reviews are now in the bag, so to speak
# 2024-04-04 01:15:40
#
# Scraped 57 users this round
# Got 398 reivews
# 84357 reviews are now in the bag, so to speak
# 2024-04-04 01:17:07
#
# Scraped 58 users this round
# Got 372 reivews
# 84729 reviews are now in the bag, so to speak
# 2024-04-04 01:18:48
#
# Scraped 60 users this round
# Got 364 reivews
# 85093 reviews are now in the bag, so to speak
# 2024-04-04 01:20:23
#
# Scraped 55 users this round
# Got 349 reivews
# 85442 reviews are now in the bag, so to speak
# 2024-04-04 01:21:52
#
# Scraped 54 users this round
# Got 317 reivews
# 85759 reviews are now in the bag, so to speak
# 2024-04-04 01:23:24
#
# Scraped 58 users this round
# Got 313 reivews
# 86072 reviews are now in the bag, so to speak
# 2024-04-04 01:25:06
#
# Scraped 51 users this round
# Got 319 reivews
# 86391 reviews are now in the bag, so to speak
# 2024-04-04 01:26:27
#
# Scraped 56 users this round
# Got 322 reivews
# 86713 reviews are now in the bag, so to speak
# 2024-04-04 01:28:02
#
# Scraped 61 users this round
# Got 332 reivews
# 87045 reviews are now in the bag, so to speak
# 2024-04-04 01:29:42
#
# Scraped 56 users this round
# Got 352 reivews
# 87397 reviews are now in the bag, so to speak
# 2024-04-04 01:31:16
#
# Scraped 58 users this round
# Got 336 reivews
# 87733 reviews are now in the bag, so to speak
# 2024-04-04 01:32:56
#
# Scraped 54 users this round
# Got 329 reivews
# 88062 reviews are now in the bag, so to speak
# 2024-04-04 01:34:26
#
# Scraped 59 users this round
# Got 308 reivews
# 88370 reviews are now in the bag, so to speak
# 2024-04-04 01:36:03
#
# Scraped 53 users this round
# Got 348 reivews
# 88718 reviews are now in the bag, so to speak
# 2024-04-04 01:37:35
#
# Scraped 57 users this round
# Got 319 reivews
# 89037 reviews are now in the bag, so to speak
# 2024-04-04 01:39:22
#
# Scraped 56 users this round
# Got 368 reivews
# 89405 reviews are now in the bag, so to speak
# 2024-04-04 01:40:57
#
# Scraped 55 users this round
# Got 328 reivews
# 89733 reviews are now in the bag, so to speak
# 2024-04-04 01:42:45
#
# Scraped 55 users this round
# Got 319 reivews
# 90052 reviews are now in the bag, so to speak
# 2024-04-04 01:44:34
#
# Scraped 54 users this round
# Got 338 reivews
# 90390 reviews are now in the bag, so to speak
# 2024-04-04 01:46:10
#
# Scraped 57 users this round
# Got 311 reivews
# 90701 reviews are now in the bag, so to speak
# 2024-04-04 01:47:46
#
# Scraped 62 users this round
# Got 348 reivews
# 91049 reviews are now in the bag, so to speak
# 2024-04-04 01:49:36
#
# Scraped 58 users this round
# Got 320 reivews
# 91369 reviews are now in the bag, so to speak
# 2024-04-04 01:51:15
#
# Scraped 58 users this round
# Got 372 reivews
# 91741 reviews are now in the bag, so to speak
# 2024-04-04 01:52:54
#
# Scraped 54 users this round
# Got 344 reivews
# 92085 reviews are now in the bag, so to speak
# 2024-04-04 01:54:31
#
# Scraped 56 users this round
# Got 336 reivews
# 92421 reviews are now in the bag, so to speak
# 2024-04-04 01:55:59
#
# Scraped 56 users this round
# Got 350 reivews
# 92771 reviews are now in the bag, so to speak
# 2024-04-04 01:57:54
#
# Scraped 53 users this round
# Got 344 reivews
# 93115 reviews are now in the bag, so to speak
# 2024-04-04 01:59:22
#
# Scraped 53 users this round
# Got 346 reivews
# 93461 reviews are now in the bag, so to speak
# 2024-04-04 02:00:58
#
# Scraped 56 users this round
# Got 326 reivews
# 93787 reviews are now in the bag, so to speak
# 2024-04-04 02:02:29
#
# Scraped 57 users this round
# Got 336 reivews
# 94123 reviews are now in the bag, so to speak
# 2024-04-04 02:04:07
#
# Scraped 55 users this round
# Got 349 reivews
# 94472 reviews are now in the bag, so to speak
# 2024-04-04 02:05:45
#
# Scraped 53 users this round
# Got 357 reivews
# 94829 reviews are now in the bag, so to speak
# 2024-04-04 02:07:13
#
# Scraped 57 users this round
# Got 365 reivews
# 95194 reviews are now in the bag, so to speak
# 2024-04-04 02:09:00
#
# Scraped 54 users this round
# Got 358 reivews
# 95552 reviews are now in the bag, so to speak
# 2024-04-04 02:10:28
#
# Scraped 56 users this round
# Got 372 reivews
# 95924 reviews are now in the bag, so to speak
# 2024-04-04 02:12:02
#
# Scraped 57 users this round
# Got 356 reivews
# 96280 reviews are now in the bag, so to speak
# 2024-04-04 02:13:36
#
# Scraped 53 users this round
# Got 326 reivews
# 96606 reviews are now in the bag, so to speak
# 2024-04-04 02:15:05
#
# Scraped 55 users this round
# Got 342 reivews
# 96948 reviews are now in the bag, so to speak
# 2024-04-04 02:16:34
#
# Scraped 61 users this round
# Got 315 reivews
# 97263 reviews are now in the bag, so to speak
# 2024-04-04 02:18:18
#
# Scraped 55 users this round
# Got 305 reivews
# 97568 reviews are now in the bag, so to speak
# 2024-04-04 02:20:08
#
# Scraped 59 users this round
# Got 334 reivews
# 97902 reviews are now in the bag, so to speak
# 2024-04-04 02:21:45
#
# Scraped 52 users this round
# Got 350 reivews
# 98252 reviews are now in the bag, so to speak
# 2024-04-04 02:23:11
#
# Scraped 57 users this round
# Got 331 reivews
# 98583 reviews are now in the bag, so to speak
# 2024-04-04 02:24:45
#
# Scraped 60 users this round
# Got 263 reivews
# 98846 reviews are now in the bag, so to speak
# 2024-04-04 02:26:20
#
# Scraped 56 users this round
# Got 341 reivews
# 99187 reviews are now in the bag, so to speak
# 2024-04-04 02:27:56
#
# Scraped 59 users this round
# Got 351 reivews
# 99538 reviews are now in the bag, so to speak
# 2024-04-04 02:29:39
#
# Scraped 54 users this round
# Got 357 reivews
# 99895 reviews are now in the bag, so to speak
# 2024-04-04 02:31:20
#
# Scraped 55 users this round
# Got 312 reivews
# 100207 reviews are now in the bag, so to speak
# 2024-04-04 02:32:51
#
# Scraped 62 users this round
# Got 333 reivews
# 100540 reviews are now in the bag, so to speak
# 2024-04-04 02:34:44
#
# Scraped 56 users this round
# Got 359 reivews
# 100899 reviews are now in the bag, so to speak
# 2024-04-04 02:36:17
#
# Scraped 55 users this round
# Got 306 reivews
# 101205 reviews are now in the bag, so to speak
# 2024-04-04 02:37:44
#
# Scraped 57 users this round
# Got 376 reivews
# 101581 reviews are now in the bag, so to speak
# 2024-04-04 02:39:15
#
# Scraped 58 users this round
# Got 358 reivews
# 101939 reviews are now in the bag, so to speak
# 2024-04-04 02:40:51
#
# Scraped 54 users this round
# Got 302 reivews
# 102241 reviews are now in the bag, so to speak
# 2024-04-04 02:42:27
#
# Scraped 54 users this round
# Got 339 reivews
# 102580 reviews are now in the bag, so to speak
# 2024-04-04 02:44:04
#
# Scraped 57 users this round
# Got 354 reivews
# 102934 reviews are now in the bag, so to speak
# 2024-04-04 02:45:41
#
# Scraped 52 users this round
# Got 319 reivews
# 103253 reviews are now in the bag, so to speak
# 2024-04-04 02:47:10
#
# Scraped 57 users this round
# Got 317 reivews
# 103570 reviews are now in the bag, so to speak
# 2024-04-04 02:48:39
#
# Scraped 52 users this round
# Got 356 reivews
# 103926 reviews are now in the bag, so to speak
# 2024-04-04 02:50:12
#
# Scraped 56 users this round
# Got 367 reivews
# 104293 reviews are now in the bag, so to speak
# 2024-04-04 02:51:56
#
# Scraped 52 users this round
# Got 345 reivews
# 104638 reviews are now in the bag, so to speak
# 2024-04-04 02:53:21
#
# Scraped 57 users this round
# Got 361 reivews
# 104999 reviews are now in the bag, so to speak
# 2024-04-04 02:54:57
#
# Scraped 58 users this round
# Got 337 reivews
# 105336 reviews are now in the bag, so to speak
# 2024-04-04 02:56:30
#
# Scraped 55 users this round
# Got 302 reivews
# 105638 reviews are now in the bag, so to speak
# 2024-04-04 02:57:56
#
# Scraped 55 users this round
# Got 341 reivews
# 105979 reviews are now in the bag, so to speak
# 2024-04-04 02:59:31
#
# Scraped 57 users this round
# Got 343 reivews
# 106322 reviews are now in the bag, so to speak
# 2024-04-04 03:01:03
#
# Scraped 53 users this round
# Got 323 reivews
# 106645 reviews are now in the bag, so to speak
# 2024-04-04 03:02:31
#
# Scraped 57 users this round
# Got 291 reivews
# 106936 reviews are now in the bag, so to speak
# 2024-04-04 03:03:56
#
# Scraped 63 users this round
# Got 342 reivews
# 107278 reviews are now in the bag, so to speak
# 2024-04-04 03:05:46
#
# Scraped 56 users this round
# Got 354 reivews
# 107632 reviews are now in the bag, so to speak
# 2024-04-04 03:07:28
#
# Scraped 55 users this round
# Got 349 reivews
# 107981 reviews are now in the bag, so to speak
# 2024-04-04 03:08:59
#
# Scraped 57 users this round
# Got 320 reivews
# 108301 reviews are now in the bag, so to speak
# 2024-04-04 03:10:35
#
# Scraped 60 users this round
# Got 364 reivews
# 108665 reviews are now in the bag, so to speak
# 2024-04-04 03:12:19
#
# Scraped 57 users this round
# Got 384 reivews
# 109049 reviews are now in the bag, so to speak
# 2024-04-04 03:13:58
#
# Scraped 52 users this round
# Got 350 reivews
# 109399 reviews are now in the bag, so to speak
# 2024-04-04 03:15:31
#
# Scraped 62 users this round
# Got 356 reivews
# 109755 reviews are now in the bag, so to speak
# 2024-04-04 03:17:05
#
# Scraped 54 users this round
# Got 364 reivews
# 110119 reviews are now in the bag, so to speak
# 2024-04-04 03:18:40
#
# Scraped 57 users this round
# Got 338 reivews
# 110457 reviews are now in the bag, so to speak
# 2024-04-04 03:20:13
#
# Scraped 55 users this round
# Got 376 reivews
# 110833 reviews are now in the bag, so to speak
# 2024-04-04 03:21:43
#
# Scraped 54 users this round
# Got 342 reivews
# 111175 reviews are now in the bag, so to speak
# 2024-04-04 03:23:10
#
# Scraped 59 users this round
# Got 302 reivews
# 111477 reviews are now in the bag, so to speak
# 2024-04-04 03:24:53
#
# Scraped 53 users this round
# Got 326 reivews
# 111803 reviews are now in the bag, so to speak
# 2024-04-04 03:26:14
#
# Scraped 55 users this round
# Got 350 reivews
# 112153 reviews are now in the bag, so to speak
# 2024-04-04 03:27:45
#
# Scraped 60 users this round
# Got 327 reivews
# 112480 reviews are now in the bag, so to speak
# 2024-04-04 03:29:23
#
# Scraped 54 users this round
# Got 349 reivews
# 112829 reviews are now in the bag, so to speak
# 2024-04-04 03:30:51
#
# Scraped 56 users this round
# Got 342 reivews
# 113171 reviews are now in the bag, so to speak
# 2024-04-04 03:32:23
#
# Scraped 65 users this round
# Got 319 reivews
# 113490 reviews are now in the bag, so to speak
# 2024-04-04 03:34:07
#
# Scraped 57 users this round
# Got 348 reivews
# 113838 reviews are now in the bag, so to speak
# 2024-04-04 03:35:41
#
# Scraped 52 users this round
# Got 394 reivews
# 114232 reviews are now in the bag, so to speak
# 2024-04-04 03:37:08
#
# Scraped 54 users this round
# Got 344 reivews
# 114576 reviews are now in the bag, so to speak
# 2024-04-04 03:38:37
#
# Scraped 56 users this round
# Got 338 reivews
# 114914 reviews are now in the bag, so to speak
# 2024-04-04 03:40:23
#
# Scraped 55 users this round
# Got 337 reivews
# 115251 reviews are now in the bag, so to speak
# 2024-04-04 03:42:00
#
# Scraped 54 users this round
# Got 342 reivews
# 115593 reviews are now in the bag, so to speak
# 2024-04-04 03:43:35
#
# Scraped 52 users this round
# Got 318 reivews
# 115911 reviews are now in the bag, so to speak
# 2024-04-04 03:45:06
#
# Scraped 58 users this round
# Got 325 reivews
# 116236 reviews are now in the bag, so to speak
# 2024-04-04 03:46:49
#
# Scraped 57 users this round
# Got 392 reivews
# 116628 reviews are now in the bag, so to speak
# 2024-04-04 03:48:20
#
# Scraped 54 users this round
# Got 326 reivews
# 116954 reviews are now in the bag, so to speak
# 2024-04-04 03:49:48
#
# Scraped 53 users this round
# Got 345 reivews
# 117299 reviews are now in the bag, so to speak
# 2024-04-04 03:51:02
#
# Scraped 55 users this round
# Got 370 reivews
# 117669 reviews are now in the bag, so to speak
# 2024-04-04 03:52:24
#
# Scraped 53 users this round
# Got 330 reivews
# 117999 reviews are now in the bag, so to speak
# 2024-04-04 03:53:47
#
# Scraped 55 users this round
# Got 315 reivews
# 118314 reviews are now in the bag, so to speak
# 2024-04-04 03:55:09
#
# Scraped 57 users this round
# Got 354 reivews
# 118668 reviews are now in the bag, so to speak
# 2024-04-04 03:56:45
#
# Scraped 53 users this round
# Got 298 reivews
# 118966 reviews are now in the bag, so to speak
# 2024-04-04 03:58:06
#
# Scraped 53 users this round
# Got 337 reivews
# 119303 reviews are now in the bag, so to speak
# 2024-04-04 03:59:23
#
# Scraped 54 users this round
# Got 365 reivews
# 119668 reviews are now in the bag, so to speak
# 2024-04-04 04:00:54
#
# Scraped 58 users this round
# Got 335 reivews
# 120003 reviews are now in the bag, so to speak
# 2024-04-04 04:02:19
#
# Scraped 54 users this round
# Got 306 reivews
# 120309 reviews are now in the bag, so to speak
# 2024-04-04 04:03:45
#
# Scraped 51 users this round
# Got 340 reivews
# 120649 reviews are now in the bag, so to speak
# 2024-04-04 04:05:06
#
# Scraped 54 users this round
# Got 358 reivews
# 121007 reviews are now in the bag, so to speak
# 2024-04-04 04:06:29
#
# Scraped 54 users this round
# Got 374 reivews
# 121381 reviews are now in the bag, so to speak
# 2024-04-04 04:07:55
#
# Scraped 58 users this round
# Got 335 reivews
# 121716 reviews are now in the bag, so to speak
# 2024-04-04 04:09:19
#
# Scraped 58 users this round
# Got 322 reivews
# 122038 reviews are now in the bag, so to speak
# 2024-04-04 04:10:47
#
# Scraped 60 users this round
# Got 369 reivews
# 122407 reviews are now in the bag, so to speak
# 2024-04-04 04:12:13
#
# Scraped 58 users this round
# Got 301 reivews
# 122708 reviews are now in the bag, so to speak
# 2024-04-04 04:13:50
#
# Scraped 56 users this round
# Got 319 reivews
# 123027 reviews are now in the bag, so to speak
# 2024-04-04 04:15:15
#
# Scraped 58 users this round
# Got 297 reivews
# 123324 reviews are now in the bag, so to speak
# 2024-04-04 04:16:39
#
# Scraped 51 users this round
# Got 374 reivews
# 123698 reviews are now in the bag, so to speak
# 2024-04-04 04:17:51
#
# Scraped 59 users this round
# Got 342 reivews
# 124040 reviews are now in the bag, so to speak
# 2024-04-04 04:19:16
#
# Scraped 57 users this round
# Got 320 reivews
# 124360 reviews are now in the bag, so to speak
# 2024-04-04 04:20:41
#
# Scraped 58 users this round
# Got 376 reivews
# 124736 reviews are now in the bag, so to speak
# 2024-04-04 04:22:02
#
# Scraped 53 users this round
# Got 369 reivews
# 125105 reviews are now in the bag, so to speak
# 2024-04-04 04:23:19
#
# Scraped 52 users this round
# Got 367 reivews
# 125472 reviews are now in the bag, so to speak
# 2024-04-04 04:24:30
#
# Scraped 51 users this round
# Got 338 reivews
# 125810 reviews are now in the bag, so to speak
# 2024-04-04 04:25:43
#
# Scraped 57 users this round
# Got 313 reivews
# 126123 reviews are now in the bag, so to speak
# 2024-04-04 04:27:00
#
# Scraped 56 users this round
# Got 338 reivews
# 126461 reviews are now in the bag, so to speak
# 2024-04-04 04:28:16
#
# Scraped 56 users this round
# Got 355 reivews
# 126816 reviews are now in the bag, so to speak
# 2024-04-04 04:29:28
#
# Scraped 59 users this round
# Got 309 reivews
# 127125 reviews are now in the bag, so to speak
# 2024-04-04 04:30:48
#
# Scraped 57 users this round
# Got 391 reivews
# 127516 reviews are now in the bag, so to speak
# 2024-04-04 04:32:07
#
# Scraped 58 users this round
# Got 344 reivews
# 127860 reviews are now in the bag, so to speak
# 2024-04-04 04:33:23
#
# Scraped 53 users this round
# Got 349 reivews
# 128209 reviews are now in the bag, so to speak
# 2024-04-04 04:34:38
#
# Scraped 55 users this round
# Got 329 reivews
# 128538 reviews are now in the bag, so to speak
# 2024-04-04 04:36:00
#
# Scraped 56 users this round
# Got 331 reivews
# 128869 reviews are now in the bag, so to speak
# 2024-04-04 04:37:09
#
# Scraped 57 users this round
# Got 340 reivews
# 129209 reviews are now in the bag, so to speak
# 2024-04-04 04:38:17
#
# Scraped 59 users this round
# Got 334 reivews
# 129543 reviews are now in the bag, so to speak
# 2024-04-04 04:39:32
#
# Scraped 59 users this round
# Got 380 reivews
# 129923 reviews are now in the bag, so to speak
# 2024-04-04 04:40:48
#
# Scraped 54 users this round
# Got 390 reivews
# 130313 reviews are now in the bag, so to speak
# 2024-04-04 04:41:52
#
# Scraped 54 users this round
# Got 352 reivews
# 130665 reviews are now in the bag, so to speak
# 2024-04-04 04:43:03
#
# Scraped 55 users this round
# Got 306 reivews
# 130971 reviews are now in the bag, so to speak
# 2024-04-04 04:44:08
#
# Scraped 56 users this round
# Got 352 reivews
# 131323 reviews are now in the bag, so to speak
# 2024-04-04 04:45:21
#
# Scraped 53 users this round
# Got 323 reivews
# 131646 reviews are now in the bag, so to speak
# 2024-04-04 04:46:18
#
# Scraped 59 users this round
# Got 372 reivews
# 132018 reviews are now in the bag, so to speak
# 2024-04-04 04:47:40
#
# Scraped 59 users this round
# Got 325 reivews
# 132343 reviews are now in the bag, so to speak
# 2024-04-04 04:48:54
#
# Scraped 56 users this round
# Got 311 reivews
# 132654 reviews are now in the bag, so to speak
# 2024-04-04 04:50:05
#
# Scraped 54 users this round
# Got 311 reivews
# 132965 reviews are now in the bag, so to speak
# 2024-04-04 04:51:14
#
# Scraped 60 users this round
# Got 331 reivews
# 133296 reviews are now in the bag, so to speak
# 2024-04-04 04:52:29
#
# Scraped 56 users this round
# Got 324 reivews
# 133620 reviews are now in the bag, so to speak
# 2024-04-04 04:53:31
#
# Scraped 55 users this round
# Got 349 reivews
# 133969 reviews are now in the bag, so to speak
# 2024-04-04 04:54:40
#
# Scraped 59 users this round
# Got 353 reivews
# 134322 reviews are now in the bag, so to speak
# 2024-04-04 04:55:54
#
# Scraped 53 users this round
# Got 286 reivews
# 134608 reviews are now in the bag, so to speak
# 2024-04-04 04:57:00
#
# Scraped 53 users this round
# Got 339 reivews
# 134947 reviews are now in the bag, so to speak
# 2024-04-04 04:58:09
#
# Scraped 57 users this round
# Got 369 reivews
# 135316 reviews are now in the bag, so to speak
# 2024-04-04 04:59:23
#
# Scraped 56 users this round
# Got 351 reivews
# 135667 reviews are now in the bag, so to speak
# 2024-04-04 05:00:30
#
# Scraped 53 users this round
# Got 368 reivews
# 136035 reviews are now in the bag, so to speak
# 2024-04-04 05:01:41
#
# Scraped 53 users this round
# Got 309 reivews
# 136344 reviews are now in the bag, so to speak
# 2024-04-04 05:02:44
#
# Scraped 62 users this round
# Got 376 reivews
# 136720 reviews are now in the bag, so to speak
# 2024-04-04 05:03:56

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
