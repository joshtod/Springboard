# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
# # # NOTE: Only use once. Instantiates holder files.

# scraped_users = set([0])
# with open('../data/raw/review_scraped_users.pkl', 'wb+') as file :
#     pickle.dump(scraped_users, file)

# skipped_users = {0:'hello world'}
# with open('../data/raw/review_skipped_users.pkl', 'wb+') as file :
#     pickle.dump(skipped_users, file)

# users_with_no_reviews = set([0])
# with open('../data/raw/users_with_no_reviews.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
last_digit = 0

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')


# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

# try :
#     with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
#         users_with_no_reviews = pickle.load(file)
# except :
#     users_with_no_reviews = set()
#     print('Empty set')

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            # with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
            #     users_with_no_reviews = pickle.load(file)
            # users_with_no_reviews.add(user)
            # with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
            #     pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 112 users this round
# Got 239 reivews
# 199603 reviews are now in the bag, so to speak
# 2024-03-29 19:21:59
#
# Scraped 105 users this round
# Got 177 reivews
# 199780 reviews are now in the bag, so to speak
# 2024-03-29 19:25:54
#
# Scraped 116 users this round
# Got 191 reivews
# 199971 reviews are now in the bag, so to speak
# 2024-03-29 19:30:34
#
# Scraped 113 users this round
# Got 202 reivews
# 200173 reviews are now in the bag, so to speak
# 2024-03-29 19:34:35
#
# Scraped 99 users this round
# Got 185 reivews
# 200358 reviews are now in the bag, so to speak
# 2024-03-29 19:38:13
#
# Scraped 115 users this round
# Got 176 reivews
# 200534 reviews are now in the bag, so to speak
# 2024-03-29 19:42:31
#
# Scraped 118 users this round
# Got 185 reivews
# 200719 reviews are now in the bag, so to speak
# 2024-03-29 19:46:41
#
# Scraped 88 users this round
# Got 132 reivews
# 200851 reviews are now in the bag, so to speak
# 2024-03-29 19:49:36
#
# Scraped 88 users this round
# Got 195 reivews
# 201046 reviews are now in the bag, so to speak
# 2024-03-29 19:52:34
#
# Scraped 108 users this round
# Got 177 reivews
# 201223 reviews are now in the bag, so to speak
# 2024-03-29 19:56:16
#
# Scraped 130 users this round
# Got 164 reivews
# 201387 reviews are now in the bag, so to speak
# 2024-03-29 20:01:00
#
# Scraped 109 users this round
# Got 201 reivews
# 201588 reviews are now in the bag, so to speak
# 2024-03-29 20:05:00
#
# Scraped 110 users this round
# Got 182 reivews
# 201770 reviews are now in the bag, so to speak
# 2024-03-29 20:09:04
#
# Scraped 134 users this round
# Got 157 reivews
# 201927 reviews are now in the bag, so to speak
# 2024-03-29 20:13:54
#
# Scraped 113 users this round
# Got 185 reivews
# 202112 reviews are now in the bag, so to speak
# 2024-03-29 20:18:12
#
# Scraped 115 users this round
# Got 175 reivews
# 202287 reviews are now in the bag, so to speak
# 2024-03-29 20:22:49
#
# Scraped 102 users this round
# Got 171 reivews
# 202458 reviews are now in the bag, so to speak
# 2024-03-29 20:27:00
#
# Scraped 108 users this round
# Got 204 reivews
# 202662 reviews are now in the bag, so to speak
# 2024-03-29 20:31:07
#
# Scraped 115 users this round
# Got 162 reivews
# 202824 reviews are now in the bag, so to speak
# 2024-03-29 20:35:28
#
# Scraped 86 users this round
# Got 173 reivews
# 202997 reviews are now in the bag, so to speak
# 2024-03-29 20:38:24
#
# Scraped 126 users this round
# Got 181 reivews
# 203178 reviews are now in the bag, so to speak
# 2024-03-29 20:42:49
#
# Scraped 101 users this round
# Got 176 reivews
# 203354 reviews are now in the bag, so to speak
# 2024-03-29 20:46:41
#
# Scraped 105 users this round
# Got 161 reivews
# 203515 reviews are now in the bag, so to speak
# 2024-03-29 20:50:43
#
# Scraped 116 users this round
# Got 180 reivews
# 203695 reviews are now in the bag, so to speak
# 2024-03-29 20:55:11
#
# Scraped 96 users this round
# Got 188 reivews
# 203883 reviews are now in the bag, so to speak
# 2024-03-29 20:58:44
#
# Scraped 108 users this round
# Got 227 reivews
# 204110 reviews are now in the bag, so to speak
# 2024-03-29 21:02:50
#
# Scraped 107 users this round
# Got 201 reivews
# 204311 reviews are now in the bag, so to speak
# 2024-03-29 21:06:55
#
# Scraped 114 users this round
# Got 176 reivews
# 204487 reviews are now in the bag, so to speak
# 2024-03-29 21:11:18
#
# Scraped 111 users this round
# Got 212 reivews
# 204699 reviews are now in the bag, so to speak
# 2024-03-29 21:15:42
#
# Scraped 98 users this round
# Got 187 reivews
# 204886 reviews are now in the bag, so to speak
# 2024-03-29 21:19:17
#
# Scraped 99 users this round
# Got 165 reivews
# 205051 reviews are now in the bag, so to speak
# 2024-03-29 21:23:21
#
# Scraped 109 users this round
# Got 177 reivews
# 205228 reviews are now in the bag, so to speak
# 2024-03-29 21:27:50
#
# Scraped 113 users this round
# Got 167 reivews
# 205395 reviews are now in the bag, so to speak
# 2024-03-29 21:32:06
#
# Scraped 104 users this round
# Got 187 reivews
# 205582 reviews are now in the bag, so to speak
# 2024-03-29 21:36:02
#
# Scraped 117 users this round
# Got 156 reivews
# 205738 reviews are now in the bag, so to speak
# 2024-03-29 21:40:41
#
# Scraped 99 users this round
# Got 216 reivews
# 205954 reviews are now in the bag, so to speak
# 2024-03-29 21:44:32
#
# Scraped 90 users this round
# Got 181 reivews
# 206135 reviews are now in the bag, so to speak
# 2024-03-29 21:47:52
#
# Scraped 104 users this round
# Got 180 reivews
# 206315 reviews are now in the bag, so to speak
# 2024-03-29 21:51:24
#
# Scraped 111 users this round
# Got 198 reivews
# 206513 reviews are now in the bag, so to speak
# 2024-03-29 21:55:46
#
# Scraped 118 users this round
# Got 181 reivews
# 206694 reviews are now in the bag, so to speak
# 2024-03-29 22:00:25
#
# Scraped 108 users this round
# Got 164 reivews
# 206858 reviews are now in the bag, so to speak
# 2024-03-29 22:04:24
#
# Scraped 97 users this round
# Got 204 reivews
# 207062 reviews are now in the bag, so to speak
# 2024-03-29 22:08:00
#
# Scraped 128 users this round
# Got 179 reivews
# 207241 reviews are now in the bag, so to speak
# 2024-03-29 22:12:45
#
# Scraped 118 users this round
# Got 202 reivews
# 207443 reviews are now in the bag, so to speak
# 2024-03-29 22:17:21
#
# Scraped 110 users this round
# Got 183 reivews
# 207626 reviews are now in the bag, so to speak
# 2024-03-29 22:21:06
#
# Scraped 102 users this round
# Got 207 reivews
# 207833 reviews are now in the bag, so to speak
# 2024-03-29 22:24:38
#
# Scraped 96 users this round
# Got 143 reivews
# 207976 reviews are now in the bag, so to speak
# 2024-03-29 22:27:59
#
# Scraped 124 users this round
# Got 169 reivews
# 208145 reviews are now in the bag, so to speak
# 2024-03-29 22:32:32
#
# Scraped 122 users this round
# Got 198 reivews
# 208343 reviews are now in the bag, so to speak
# 2024-03-29 22:36:51
#
# Scraped 97 users this round
# Got 202 reivews
# 208545 reviews are now in the bag, so to speak
# 2024-03-29 22:40:05
#
# Scraped 107 users this round
# Got 180 reivews
# 208725 reviews are now in the bag, so to speak
# 2024-03-29 22:43:51
#
# Scraped 105 users this round
# Got 178 reivews
# 208903 reviews are now in the bag, so to speak
# 2024-03-29 22:47:36
#
# Scraped 122 users this round
# Got 187 reivews
# 209090 reviews are now in the bag, so to speak
# 2024-03-29 22:52:10
#
# Scraped 105 users this round
# Got 183 reivews
# 209273 reviews are now in the bag, so to speak
# 2024-03-29 22:55:54
#
# Scraped 102 users this round
# Got 163 reivews
# 209436 reviews are now in the bag, so to speak
# 2024-03-29 22:59:31
#
# Scraped 127 users this round
# Got 221 reivews
# 209657 reviews are now in the bag, so to speak
# 2024-03-29 23:04:00
#
# Scraped 118 users this round
# Got 190 reivews
# 209847 reviews are now in the bag, so to speak
# 2024-03-29 23:07:58
#
# Scraped 126 users this round
# Got 205 reivews
# 210052 reviews are now in the bag, so to speak
# 2024-03-29 23:12:21
#
# Scraped 113 users this round
# Got 184 reivews
# 210236 reviews are now in the bag, so to speak
# 2024-03-29 23:16:02
#
# Scraped 110 users this round
# Got 178 reivews
# 210414 reviews are now in the bag, so to speak
# 2024-03-29 23:19:46
#
# Scraped 104 users this round
# Got 179 reivews
# 210593 reviews are now in the bag, so to speak
# 2024-03-29 23:23:11
#
# Scraped 99 users this round
# Got 174 reivews
# 210767 reviews are now in the bag, so to speak
# 2024-03-29 23:26:31
#
# Scraped 98 users this round
# Got 176 reivews
# 210943 reviews are now in the bag, so to speak
# 2024-03-29 23:29:42
#
# Scraped 100 users this round
# Got 171 reivews
# 211114 reviews are now in the bag, so to speak
# 2024-03-29 23:33:08
#
# Scraped 125 users this round
# Got 174 reivews
# 211288 reviews are now in the bag, so to speak
# 2024-03-29 23:37:29
#
# Scraped 128 users this round
# Got 201 reivews
# 211489 reviews are now in the bag, so to speak
# 2024-03-29 23:41:44
#
# Scraped 121 users this round
# Got 163 reivews
# 211652 reviews are now in the bag, so to speak
# 2024-03-29 23:45:41
#
# Scraped 106 users this round
# Got 186 reivews
# 211838 reviews are now in the bag, so to speak
# 2024-03-29 23:49:22
#
# Scraped 89 users this round
# Got 184 reivews
# 212022 reviews are now in the bag, so to speak
# 2024-03-29 23:52:12
#
# Scraped 110 users this round
# Got 167 reivews
# 212189 reviews are now in the bag, so to speak
# 2024-03-29 23:56:02
#
# Scraped 104 users this round
# Got 174 reivews
# 212363 reviews are now in the bag, so to speak
# 2024-03-29 23:59:34
#
# Scraped 104 users this round
# Got 210 reivews
# 212573 reviews are now in the bag, so to speak
# 2024-03-30 00:03:08
#
# Scraped 102 users this round
# Got 242 reivews
# 212815 reviews are now in the bag, so to speak
# 2024-03-30 00:06:30
#
# Scraped 99 users this round
# Got 217 reivews
# 213032 reviews are now in the bag, so to speak
# 2024-03-30 00:10:09
#
# Scraped 98 users this round
# Got 197 reivews
# 213229 reviews are now in the bag, so to speak
# 2024-03-30 00:13:25
#
# Scraped 110 users this round
# Got 149 reivews
# 213378 reviews are now in the bag, so to speak
# 2024-03-30 00:17:28
#
# Scraped 123 users this round
# Got 201 reivews
# 213579 reviews are now in the bag, so to speak
# 2024-03-30 00:21:50
#
# Scraped 123 users this round
# Got 208 reivews
# 213787 reviews are now in the bag, so to speak
# 2024-03-30 00:26:08
#
# Scraped 110 users this round
# Got 226 reivews
# 214013 reviews are now in the bag, so to speak
# 2024-03-30 00:29:37
#
# Scraped 107 users this round
# Got 190 reivews
# 214203 reviews are now in the bag, so to speak
# 2024-03-30 00:33:02
#
# Scraped 94 users this round
# Got 168 reivews
# 214371 reviews are now in the bag, so to speak
# 2024-03-30 00:35:58
#
# Scraped 97 users this round
# Got 175 reivews
# 214546 reviews are now in the bag, so to speak
# 2024-03-30 00:39:01
#
# Scraped 143 users this round
# Got 185 reivews
# 214731 reviews are now in the bag, so to speak
# 2024-03-30 00:43:50
#
# Scraped 103 users this round
# Got 197 reivews
# 214928 reviews are now in the bag, so to speak
# 2024-03-30 00:47:10
#
# Scraped 117 users this round
# Got 157 reivews
# 215085 reviews are now in the bag, so to speak
# 2024-03-30 00:51:07
#
# Scraped 99 users this round
# Got 149 reivews
# 215234 reviews are now in the bag, so to speak
# 2024-03-30 00:54:29
#
# Scraped 120 users this round
# Got 187 reivews
# 215421 reviews are now in the bag, so to speak
# 2024-03-30 00:58:37
#
# Scraped 126 users this round
# Got 169 reivews
# 215590 reviews are now in the bag, so to speak
# 2024-03-30 01:02:32
#
# Scraped 106 users this round
# Got 183 reivews
# 215773 reviews are now in the bag, so to speak
# 2024-03-30 01:06:04
#
# Scraped 109 users this round
# Got 166 reivews
# 215939 reviews are now in the bag, so to speak
# 2024-03-30 01:09:26
#
# Scraped 99 users this round
# Got 173 reivews
# 216112 reviews are now in the bag, so to speak
# 2024-03-30 01:12:24
#
# Scraped 111 users this round
# Got 185 reivews
# 216297 reviews are now in the bag, so to speak
# 2024-03-30 01:15:57
#
# Scraped 104 users this round
# Got 197 reivews
# 216494 reviews are now in the bag, so to speak
# 2024-03-30 01:18:56
#
# Scraped 110 users this round
# Got 139 reivews
# 216633 reviews are now in the bag, so to speak
# 2024-03-30 01:22:25
#
# Scraped 109 users this round
# Got 210 reivews
# 216843 reviews are now in the bag, so to speak
# 2024-03-30 01:25:43
#
# Scraped 100 users this round
# Got 189 reivews
# 217032 reviews are now in the bag, so to speak
# 2024-03-30 01:28:35
#
# Scraped 111 users this round
# Got 179 reivews
# 217211 reviews are now in the bag, so to speak
# 2024-03-30 01:31:43
#
# Scraped 116 users this round
# Got 170 reivews
# 217381 reviews are now in the bag, so to speak
# 2024-03-30 01:35:24
#
# Scraped 101 users this round
# Got 190 reivews
# 217571 reviews are now in the bag, so to speak
# 2024-03-30 01:38:33
#
# Scraped 101 users this round
# Got 219 reivews
# 217790 reviews are now in the bag, so to speak
# 2024-03-30 01:41:41
#
# Scraped 102 users this round
# Got 212 reivews
# 218002 reviews are now in the bag, so to speak
# 2024-03-30 01:44:42
#
# Scraped 121 users this round
# Got 174 reivews
# 218176 reviews are now in the bag, so to speak
# 2024-03-30 01:48:26
#
# Scraped 115 users this round
# Got 140 reivews
# 218316 reviews are now in the bag, so to speak
# 2024-03-30 01:51:54
#
# Scraped 89 users this round
# Got 170 reivews
# 218486 reviews are now in the bag, so to speak
# 2024-03-30 01:54:25
#
# Scraped 119 users this round
# Got 179 reivews
# 218665 reviews are now in the bag, so to speak
# 2024-03-30 01:58:08
#
# Scraped 132 users this round
# Got 229 reivews
# 218894 reviews are now in the bag, so to speak
# 2024-03-30 02:02:03
#
# Scraped 115 users this round
# Got 165 reivews
# 219059 reviews are now in the bag, so to speak
# 2024-03-30 02:05:45
#
# Scraped 118 users this round
# Got 177 reivews
# 219236 reviews are now in the bag, so to speak
# 2024-03-30 02:09:28
#
# Scraped 90 users this round
# Got 173 reivews
# 219409 reviews are now in the bag, so to speak
# 2024-03-30 02:12:08
#
# Scraped 122 users this round
# Got 199 reivews
# 219608 reviews are now in the bag, so to speak
# 2024-03-30 02:15:55
#
# Scraped 118 users this round
# Got 158 reivews
# 219766 reviews are now in the bag, so to speak
# 2024-03-30 02:19:38
#
# Scraped 114 users this round
# Got 175 reivews
# 219941 reviews are now in the bag, so to speak
# 2024-03-30 02:23:07
#
# Scraped 98 users this round
# Got 214 reivews
# 220155 reviews are now in the bag, so to speak
# 2024-03-30 02:26:11
#
# Scraped 102 users this round
# Got 236 reivews
# 220391 reviews are now in the bag, so to speak
# 2024-03-30 02:29:19
#
# Scraped 107 users this round
# Got 241 reivews
# 220632 reviews are now in the bag, so to speak
# 2024-03-30 02:32:29
#
# Scraped 126 users this round
# Got 194 reivews
# 220826 reviews are now in the bag, so to speak
# 2024-03-30 02:36:32
#
# Scraped 104 users this round
# Got 197 reivews
# 221023 reviews are now in the bag, so to speak
# 2024-03-30 02:39:31
#
# Scraped 93 users this round
# Got 200 reivews
# 221223 reviews are now in the bag, so to speak
# 2024-03-30 02:42:05
#
# Scraped 126 users this round
# Got 180 reivews
# 221403 reviews are now in the bag, so to speak
# 2024-03-30 02:45:33
#
# Scraped 125 users this round
# Got 203 reivews
# 221606 reviews are now in the bag, so to speak
# 2024-03-30 02:49:29
#
# Scraped 111 users this round
# Got 187 reivews
# 221793 reviews are now in the bag, so to speak
# 2024-03-30 02:52:48
#
# Scraped 123 users this round
# Got 192 reivews
# 221985 reviews are now in the bag, so to speak
# 2024-03-30 02:56:25
#
# Scraped 83 users this round
# Got 191 reivews
# 222176 reviews are now in the bag, so to speak
# 2024-03-30 02:58:49
#
# Scraped 101 users this round
# Got 176 reivews
# 222352 reviews are now in the bag, so to speak
# 2024-03-30 03:01:47
#
# Scraped 108 users this round
# Got 183 reivews
# 222535 reviews are now in the bag, so to speak
# 2024-03-30 03:04:53
#
# Scraped 114 users this round
# Got 180 reivews
# 222715 reviews are now in the bag, so to speak
# 2024-03-30 03:08:27
#
# Scraped 115 users this round
# Got 192 reivews
# 222907 reviews are now in the bag, so to speak
# 2024-03-30 03:11:49
#
# Scraped 94 users this round
# Got 160 reivews
# 223067 reviews are now in the bag, so to speak
# 2024-03-30 03:14:31
#
# Scraped 106 users this round
# Got 192 reivews
# 223259 reviews are now in the bag, so to speak
# 2024-03-30 03:17:52
#
# Scraped 112 users this round
# Got 156 reivews
# 223415 reviews are now in the bag, so to speak
# 2024-03-30 03:21:04
#
# Scraped 100 users this round
# Got 183 reivews
# 223598 reviews are now in the bag, so to speak
# 2024-03-30 03:24:10
#
# Scraped 110 users this round
# Got 199 reivews
# 223797 reviews are now in the bag, so to speak
# 2024-03-30 03:27:18
#
# Scraped 95 users this round
# Got 200 reivews
# 223997 reviews are now in the bag, so to speak
# 2024-03-30 03:30:01
#
# Scraped 108 users this round
# Got 171 reivews
# 224168 reviews are now in the bag, so to speak
# 2024-03-30 03:33:06
#
# Scraped 94 users this round
# Got 176 reivews
# 224344 reviews are now in the bag, so to speak
# 2024-03-30 03:35:44
#
# Scraped 92 users this round
# Got 183 reivews
# 224527 reviews are now in the bag, so to speak
# 2024-03-30 03:38:20
#
# Scraped 101 users this round
# Got 188 reivews
# 224715 reviews are now in the bag, so to speak
# 2024-03-30 03:41:20
#
# Scraped 104 users this round
# Got 218 reivews
# 224933 reviews are now in the bag, so to speak
# 2024-03-30 03:44:34
#
# Scraped 86 users this round
# Got 186 reivews
# 225119 reviews are now in the bag, so to speak
# 2024-03-30 03:47:00
#
# Scraped 137 users this round
# Got 167 reivews
# 225286 reviews are now in the bag, so to speak
# 2024-03-30 03:50:53
#
# Scraped 113 users this round
# Got 177 reivews
# 225463 reviews are now in the bag, so to speak
# 2024-03-30 03:54:28
#
# Scraped 99 users this round
# Got 176 reivews
# 225639 reviews are now in the bag, so to speak
# 2024-03-30 03:57:23
#
# Scraped 120 users this round
# Got 188 reivews
# 225827 reviews are now in the bag, so to speak
# 2024-03-30 04:01:05
#
# Scraped 119 users this round
# Got 194 reivews
# 226021 reviews are now in the bag, so to speak
# 2024-03-30 04:04:33
#
# Scraped 108 users this round
# Got 191 reivews
# 226212 reviews are now in the bag, so to speak
# 2024-03-30 04:07:40
#
# Scraped 100 users this round
# Got 215 reivews
# 226427 reviews are now in the bag, so to speak
# 2024-03-30 04:10:38
#
# Scraped 102 users this round
# Got 165 reivews
# 226592 reviews are now in the bag, so to speak
# 2024-03-30 04:13:37
#
# Scraped 131 users this round
# Got 216 reivews
# 226808 reviews are now in the bag, so to speak
# 2024-03-30 04:17:50
#
# Scraped 114 users this round
# Got 195 reivews
# 227003 reviews are now in the bag, so to speak
# 2024-03-30 04:21:20
#
# Scraped 120 users this round
# Got 204 reivews
# 227207 reviews are now in the bag, so to speak
# 2024-03-30 04:24:56
#
# Scraped 104 users this round
# Got 170 reivews
# 227377 reviews are now in the bag, so to speak
# 2024-03-30 04:28:00
#
# Scraped 105 users this round
# Got 216 reivews
# 227593 reviews are now in the bag, so to speak
# 2024-03-30 04:31:07
#
# Scraped 86 users this round
# Got 204 reivews
# 227797 reviews are now in the bag, so to speak
# 2024-03-30 04:33:33
#
# Scraped 89 users this round
# Got 195 reivews
# 227992 reviews are now in the bag, so to speak
# 2024-03-30 04:36:17
#
# Scraped 118 users this round
# Got 165 reivews
# 228157 reviews are now in the bag, so to speak
# 2024-03-30 04:39:38
#
# Scraped 97 users this round
# Got 174 reivews
# 228331 reviews are now in the bag, so to speak
# 2024-03-30 04:42:24
#
# Scraped 120 users this round
# Got 157 reivews
# 228488 reviews are now in the bag, so to speak
# 2024-03-30 04:45:50
#
# Scraped 114 users this round
# Got 173 reivews
# 228661 reviews are now in the bag, so to speak
# 2024-03-30 04:49:06
#
# Scraped 94 users this round
# Got 222 reivews
# 228883 reviews are now in the bag, so to speak
# 2024-03-30 04:51:45
#
# Scraped 105 users this round
# Got 216 reivews
# 229099 reviews are now in the bag, so to speak
# 2024-03-30 04:54:52
#
# Scraped 124 users this round
# Got 170 reivews
# 229269 reviews are now in the bag, so to speak
# 2024-03-30 04:58:29
#
# Scraped 102 users this round
# Got 217 reivews
# 229486 reviews are now in the bag, so to speak
# 2024-03-30 05:01:23
#
# Scraped 108 users this round
# Got 202 reivews
# 229688 reviews are now in the bag, so to speak
# 2024-03-30 05:04:51
#
# Scraped 119 users this round
# Got 206 reivews
# 229894 reviews are now in the bag, so to speak
# 2024-03-30 05:08:18
#
# Scraped 129 users this round
# Got 191 reivews
# 230085 reviews are now in the bag, so to speak
# 2024-03-30 05:12:06
#
# Scraped 101 users this round
# Got 181 reivews
# 230266 reviews are now in the bag, so to speak
# 2024-03-30 05:15:09
#
# Scraped 106 users this round
# Got 221 reivews
# 230487 reviews are now in the bag, so to speak
# 2024-03-30 05:18:32
#
# Scraped 135 users this round
# Got 191 reivews
# 230678 reviews are now in the bag, so to speak
# 2024-03-30 05:23:10
#
# Scraped 111 users this round
# Got 220 reivews
# 230898 reviews are now in the bag, so to speak
# 2024-03-30 05:26:16
#
# Scraped 120 users this round
# Got 208 reivews
# 231106 reviews are now in the bag, so to speak
# 2024-03-30 05:29:58
#
# Scraped 98 users this round
# Got 178 reivews
# 231284 reviews are now in the bag, so to speak
# 2024-03-30 05:32:50
#
# Scraped 115 users this round
# Got 202 reivews
# 231486 reviews are now in the bag, so to speak
# 2024-03-30 05:36:18
#
# Scraped 127 users this round
# Got 173 reivews
# 231659 reviews are now in the bag, so to speak
# 2024-03-30 05:39:58
#
# Scraped 104 users this round
# Got 193 reivews
# 231852 reviews are now in the bag, so to speak
# 2024-03-30 05:42:59
#
# Scraped 101 users this round
# Got 188 reivews
# 232040 reviews are now in the bag, so to speak
# 2024-03-30 05:45:56
#
# Scraped 99 users this round
# Got 184 reivews
# 232224 reviews are now in the bag, so to speak
# 2024-03-30 05:49:00
#
# Scraped 131 users this round
# Got 174 reivews
# 232398 reviews are now in the bag, so to speak
# 2024-03-30 05:53:10
#
# Scraped 121 users this round
# Got 194 reivews
# 232592 reviews are now in the bag, so to speak
# 2024-03-30 05:56:49
#
# Scraped 103 users this round
# Got 206 reivews
# 232798 reviews are now in the bag, so to speak
# 2024-03-30 05:59:59
#
# Scraped 119 users this round
# Got 210 reivews
# 233008 reviews are now in the bag, so to speak
# 2024-03-30 06:03:37
#
# Scraped 110 users this round
# Got 182 reivews
# 233190 reviews are now in the bag, so to speak
# 2024-03-30 06:07:04
#
# Scraped 114 users this round
# Got 161 reivews
# 233351 reviews are now in the bag, so to speak
# 2024-03-30 06:10:28
#
# Scraped 99 users this round
# Got 166 reivews
# 233517 reviews are now in the bag, so to speak
# 2024-03-30 06:13:19
#
# Scraped 97 users this round
# Got 166 reivews
# 233683 reviews are now in the bag, so to speak
# 2024-03-30 06:16:06
#
# Scraped 122 users this round
# Got 161 reivews
# 233844 reviews are now in the bag, so to speak
# 2024-03-30 06:19:38
#
# Scraped 112 users this round
# Got 221 reivews
# 234065 reviews are now in the bag, so to speak
# 2024-03-30 06:23:08
#
# Scraped 99 users this round
# Got 172 reivews
# 234237 reviews are now in the bag, so to speak
# 2024-03-30 06:25:55
#
# Scraped 123 users this round
# Got 208 reivews
# 234445 reviews are now in the bag, so to speak
# 2024-03-30 06:29:41
#
# Scraped 116 users this round
# Got 185 reivews
# 234630 reviews are now in the bag, so to speak
# 2024-03-30 06:33:16
#
# Scraped 104 users this round
# Got 139 reivews
# 234769 reviews are now in the bag, so to speak
# 2024-03-30 06:36:21
#
# Scraped 110 users this round
# Got 198 reivews
# 234967 reviews are now in the bag, so to speak
# 2024-03-30 06:39:31
#
# Scraped 112 users this round
# Got 213 reivews
# 235180 reviews are now in the bag, so to speak
# 2024-03-30 06:42:54
#
# Scraped 123 users this round
# Got 186 reivews
# 235366 reviews are now in the bag, so to speak
# 2024-03-30 06:46:40
#
# Scraped 95 users this round
# Got 184 reivews
# 235550 reviews are now in the bag, so to speak
# 2024-03-30 06:49:28
#
# Scraped 97 users this round
# Got 193 reivews
# 235743 reviews are now in the bag, so to speak
# 2024-03-30 06:52:10
#
# Scraped 106 users this round
# Got 209 reivews
# 235952 reviews are now in the bag, so to speak
# 2024-03-30 06:55:19
#
# Scraped 104 users this round
# Got 195 reivews
# 236147 reviews are now in the bag, so to speak
# 2024-03-30 06:58:28
#
# Scraped 104 users this round
# Got 204 reivews
# 236351 reviews are now in the bag, so to speak
# 2024-03-30 07:01:39
#
# Scraped 117 users this round
# Got 195 reivews
# 236546 reviews are now in the bag, so to speak
# 2024-03-30 07:05:14
#
# Scraped 99 users this round
# Got 167 reivews
# 236713 reviews are now in the bag, so to speak
# 2024-03-30 07:08:04
#
# Scraped 122 users this round
# Got 215 reivews
# 236928 reviews are now in the bag, so to speak
# 2024-03-30 07:11:41
#
# Scraped 102 users this round
# Got 245 reivews
# 237173 reviews are now in the bag, so to speak
# 2024-03-30 07:14:36
#
# Scraped 112 users this round
# Got 218 reivews
# 237391 reviews are now in the bag, so to speak
# 2024-03-30 07:17:58
#
# Scraped 123 users this round
# Got 238 reivews
# 237629 reviews are now in the bag, so to speak
# 2024-03-30 07:21:41
#
# Scraped 96 users this round
# Got 219 reivews
# 237848 reviews are now in the bag, so to speak
# 2024-03-30 07:24:29
#
# Scraped 95 users this round
# Got 221 reivews
# 238069 reviews are now in the bag, so to speak
# 2024-03-30 07:27:15
#
# Scraped 124 users this round
# Got 194 reivews
# 238263 reviews are now in the bag, so to speak
# 2024-03-30 07:31:06
#
# Scraped 106 users this round
# Got 152 reivews
# 238415 reviews are now in the bag, so to speak
# 2024-03-30 07:34:15
#
# Scraped 112 users this round
# Got 207 reivews
# 238622 reviews are now in the bag, so to speak
# 2024-03-30 07:37:33
#
# Scraped 118 users this round
# Got 191 reivews
# 238813 reviews are now in the bag, so to speak
# 2024-03-30 07:41:08
#
# Scraped 108 users this round
# Got 182 reivews
# 238995 reviews are now in the bag, so to speak
# 2024-03-30 07:44:28
#
# Scraped 88 users this round
# Got 170 reivews
# 239165 reviews are now in the bag, so to speak
# 2024-03-30 07:47:04
#
# Scraped 139 users this round
# Got 194 reivews
# 239359 reviews are now in the bag, so to speak
# 2024-03-30 07:51:15
#
# Scraped 130 users this round
# Got 195 reivews
# 239554 reviews are now in the bag, so to speak
# 2024-03-30 07:55:12
#
# Scraped 104 users this round
# Got 190 reivews
# 239744 reviews are now in the bag, so to speak
# 2024-03-30 07:58:14
#
# Scraped 101 users this round
# Got 185 reivews
# 239929 reviews are now in the bag, so to speak
# 2024-03-30 08:01:00
#
# Scraped 111 users this round
# Got 173 reivews
# 240102 reviews are now in the bag, so to speak
# 2024-03-30 08:03:53
#
# Scraped 115 users this round
# Got 205 reivews
# 240307 reviews are now in the bag, so to speak
# 2024-03-30 08:06:49
#
# Scraped 126 users this round
# Got 179 reivews
# 240486 reviews are now in the bag, so to speak
# 2024-03-30 08:10:08
#
# Scraped 91 users this round
# Got 176 reivews
# 240662 reviews are now in the bag, so to speak
# 2024-03-30 08:12:25
#
# Scraped 89 users this round
# Got 180 reivews
# 240842 reviews are now in the bag, so to speak
# 2024-03-30 08:14:45
#
# Scraped 117 users this round
# Got 171 reivews
# 241013 reviews are now in the bag, so to speak
# 2024-03-30 08:18:02
#
# Scraped 124 users this round
# Got 212 reivews
# 241225 reviews are now in the bag, so to speak
# 2024-03-30 08:21:38
#
# Scraped 120 users this round
# Got 210 reivews
# 241435 reviews are now in the bag, so to speak
# 2024-03-30 08:25:05
#
# Scraped 85 users this round
# Got 162 reivews
# 241597 reviews are now in the bag, so to speak
# 2024-03-30 08:27:09
#
# Scraped 113 users this round
# Got 202 reivews
# 241799 reviews are now in the bag, so to speak
# 2024-03-30 08:30:20
#
# Scraped 104 users this round
# Got 252 reivews
# 242051 reviews are now in the bag, so to speak
# 2024-03-30 08:33:09
#
# Scraped 106 users this round
# Got 189 reivews
# 242240 reviews are now in the bag, so to speak
# 2024-03-30 08:35:50
#
# Scraped 112 users this round
# Got 219 reivews
# 242459 reviews are now in the bag, so to speak
# 2024-03-30 08:38:54
#
# Scraped 100 users this round
# Got 212 reivews
# 242671 reviews are now in the bag, so to speak
# 2024-03-30 08:41:32
#
# Scraped 123 users this round
# Got 186 reivews
# 242857 reviews are now in the bag, so to speak
# 2024-03-30 08:45:02
#
# Scraped 94 users this round
# Got 170 reivews
# 243027 reviews are now in the bag, so to speak
# 2024-03-30 08:47:24
#
# Scraped 107 users this round
# Got 210 reivews
# 243237 reviews are now in the bag, so to speak
# 2024-03-30 08:50:17
#
# Scraped 99 users this round
# Got 185 reivews
# 243422 reviews are now in the bag, so to speak
# 2024-03-30 08:52:54
#
# Scraped 111 users this round
# Got 208 reivews
# 243630 reviews are now in the bag, so to speak
# 2024-03-30 08:55:58
#
# Scraped 101 users this round
# Got 193 reivews
# 243823 reviews are now in the bag, so to speak
# 2024-03-30 08:58:37
#
# Scraped 112 users this round
# Got 162 reivews
# 243985 reviews are now in the bag, so to speak
# 2024-03-30 09:01:30
#
# Scraped 102 users this round
# Got 166 reivews
# 244151 reviews are now in the bag, so to speak
# 2024-03-30 09:04:05
#
# Scraped 140 users this round
# Got 174 reivews
# 244325 reviews are now in the bag, so to speak
# 2024-03-30 09:08:15
#
# Scraped 124 users this round
# Got 169 reivews
# 244494 reviews are now in the bag, so to speak
# 2024-03-30 09:11:44
#
# Scraped 112 users this round
# Got 186 reivews
# 244680 reviews are now in the bag, so to speak
# 2024-03-30 09:14:48
#
# Scraped 130 users this round
# Got 179 reivews
# 244859 reviews are now in the bag, so to speak
# 2024-03-30 09:18:42
#
# Scraped 108 users this round
# Got 189 reivews
# 245048 reviews are now in the bag, so to speak
# 2024-03-30 09:21:34
#
# Scraped 108 users this round
# Got 187 reivews
# 245235 reviews are now in the bag, so to speak
# 2024-03-30 09:24:30
#
# Scraped 102 users this round
# Got 229 reivews
# 245464 reviews are now in the bag, so to speak
# 2024-03-30 09:27:13
#
# Scraped 105 users this round
# Got 192 reivews
# 245656 reviews are now in the bag, so to speak
# 2024-03-30 09:30:11
#
# Scraped 119 users this round
# Got 202 reivews
# 245858 reviews are now in the bag, so to speak
# 2024-03-30 09:33:38
#
# Scraped 121 users this round
# Got 206 reivews
# 246064 reviews are now in the bag, so to speak
# 2024-03-30 09:37:00
#
# Scraped 105 users this round
# Got 244 reivews
# 246308 reviews are now in the bag, so to speak
# 2024-03-30 09:39:58
#
# Scraped 109 users this round
# Got 217 reivews
# 246525 reviews are now in the bag, so to speak
# 2024-03-30 09:42:50
#
# Scraped 111 users this round
# Got 224 reivews
# 246749 reviews are now in the bag, so to speak
# 2024-03-30 09:45:58
#
# Scraped 109 users this round
# Got 193 reivews
# 246942 reviews are now in the bag, so to speak
# 2024-03-30 09:48:57
#
# Scraped 134 users this round
# Got 137 reivews
# 247079 reviews are now in the bag, so to speak
# 2024-03-30 09:52:39
#
# Scraped 127 users this round
# Got 178 reivews
# 247257 reviews are now in the bag, so to speak
# 2024-03-30 09:56:22
#
# Scraped 107 users this round
# Got 215 reivews
# 247472 reviews are now in the bag, so to speak
# 2024-03-30 09:59:17
#
# Scraped 105 users this round
# Got 164 reivews
# 247636 reviews are now in the bag, so to speak
# 2024-03-30 10:02:08
#
# Scraped 112 users this round
# Got 234 reivews
# 247870 reviews are now in the bag, so to speak
# 2024-03-30 10:05:04
#
# Scraped 88 users this round
# Got 174 reivews
# 248044 reviews are now in the bag, so to speak
# 2024-03-30 10:07:18
#
# Scraped 75 users this round
# Got 248 reivews
# 248292 reviews are now in the bag, so to speak
# 2024-03-30 10:09:09
#
# Scraped 96 users this round
# Got 153 reivews
# 248445 reviews are now in the bag, so to speak
# 2024-03-30 10:11:31
#
# Scraped 120 users this round
# Got 206 reivews
# 248651 reviews are now in the bag, so to speak
# 2024-03-30 10:14:59
#
# Scraped 95 users this round
# Got 190 reivews
# 248841 reviews are now in the bag, so to speak
# 2024-03-30 10:17:31
#
# Scraped 104 users this round
# Got 185 reivews
# 249026 reviews are now in the bag, so to speak
# 2024-03-30 10:20:13
#
# Scraped 125 users this round
# Got 208 reivews
# 249234 reviews are now in the bag, so to speak
# 2024-03-30 10:24:01
#
# Scraped 111 users this round
# Got 169 reivews
# 249403 reviews are now in the bag, so to speak
# 2024-03-30 10:27:05
#
# Scraped 107 users this round
# Got 174 reivews
# 249577 reviews are now in the bag, so to speak
# 2024-03-30 10:30:01
#
# Scraped 107 users this round
# Got 160 reivews
# 249737 reviews are now in the bag, so to speak
# 2024-03-30 10:33:19
#
# Scraped 110 users this round
# Got 145 reivews
# 249882 reviews are now in the bag, so to speak
# 2024-03-30 10:36:14
#
# Scraped 116 users this round
# Got 170 reivews
# 250052 reviews are now in the bag, so to speak
# 2024-03-30 10:39:20
#
# Scraped 119 users this round
# Got 179 reivews
# 250231 reviews are now in the bag, so to speak
# 2024-03-30 10:42:42
#
# Scraped 113 users this round
# Got 184 reivews
# 250415 reviews are now in the bag, so to speak
# 2024-03-30 10:45:42
#
# Scraped 97 users this round
# Got 252 reivews
# 250667 reviews are now in the bag, so to speak
# 2024-03-30 10:48:26
#
# Scraped 105 users this round
# Got 202 reivews
# 250869 reviews are now in the bag, so to speak
# 2024-03-30 10:51:18
#
# Scraped 116 users this round
# Got 174 reivews
# 251043 reviews are now in the bag, so to speak
# 2024-03-30 10:54:37
#
# Scraped 102 users this round
# Got 234 reivews
# 251277 reviews are now in the bag, so to speak
# 2024-03-30 10:57:23
#
# Scraped 112 users this round
# Got 177 reivews
# 251454 reviews are now in the bag, so to speak
# 2024-03-30 11:00:39
#
# Scraped 99 users this round
# Got 203 reivews
# 251657 reviews are now in the bag, so to speak
# 2024-03-30 11:03:11
#
# Scraped 101 users this round
# Got 181 reivews
# 251838 reviews are now in the bag, so to speak
# 2024-03-30 11:06:01
#
# Scraped 118 users this round
# Got 179 reivews
# 252017 reviews are now in the bag, so to speak
# 2024-03-30 11:09:40
#
# Scraped 99 users this round
# Got 111 reivews
# 252128 reviews are now in the bag, so to speak
# 2024-03-30 11:12:51
#
# Scraped 105 users this round
# Got 205 reivews
# 252333 reviews are now in the bag, so to speak
# 2024-03-30 11:16:35
#
# Scraped 109 users this round
# Got 224 reivews
# 252557 reviews are now in the bag, so to speak
# 2024-03-30 11:20:27
#
# Scraped 114 users this round
# Got 161 reivews
# 252718 reviews are now in the bag, so to speak
# 2024-03-30 11:24:17
#
# Scraped 140 users this round
# Got 185 reivews
# 252903 reviews are now in the bag, so to speak
# 2024-03-30 11:29:11
#
# Scraped 129 users this round
# Got 205 reivews
# 253108 reviews are now in the bag, so to speak
# 2024-03-30 11:33:33
#
# Scraped 117 users this round
# Got 220 reivews
# 253328 reviews are now in the bag, so to speak
# 2024-03-30 11:37:26
#
# Scraped 86 users this round
# Got 184 reivews
# 253512 reviews are now in the bag, so to speak
# 2024-03-30 11:40:15
#
# Scraped 112 users this round
# Got 195 reivews
# 253707 reviews are now in the bag, so to speak
# 2024-03-30 11:44:01
#
# Scraped 117 users this round
# Got 171 reivews
# 253878 reviews are now in the bag, so to speak
# 2024-03-30 11:48:02
#
# Scraped 102 users this round
# Got 180 reivews
# 254058 reviews are now in the bag, so to speak
# 2024-03-30 11:51:30
#
# Scraped 126 users this round
# Got 144 reivews
# 254202 reviews are now in the bag, so to speak
# 2024-03-30 11:56:05
#
# Scraped 135 users this round
# Got 167 reivews
# 254369 reviews are now in the bag, so to speak
# 2024-03-30 12:00:39
#
# Scraped 115 users this round
# Got 177 reivews
# 254546 reviews are now in the bag, so to speak
# 2024-03-30 12:04:49
#
# Scraped 113 users this round
# Got 195 reivews
# 254741 reviews are now in the bag, so to speak
# 2024-03-30 12:08:49
#
# Scraped 112 users this round
# Got 211 reivews
# 254952 reviews are now in the bag, so to speak
# 2024-03-30 12:12:38
#
# Scraped 110 users this round
# Got 176 reivews
# 255128 reviews are now in the bag, so to speak
# 2024-03-30 12:16:30
#
# Scraped 102 users this round
# Got 187 reivews
# 255315 reviews are now in the bag, so to speak
# 2024-03-30 12:19:48
#
# Scraped 99 users this round
# Got 167 reivews
# 255482 reviews are now in the bag, so to speak
# 2024-03-30 12:23:01
#
# Scraped 112 users this round
# Got 168 reivews
# 255650 reviews are now in the bag, so to speak
# 2024-03-30 12:26:48
#
# Scraped 116 users this round
# Got 179 reivews
# 255829 reviews are now in the bag, so to speak
# 2024-03-30 12:30:40
#
# Scraped 109 users this round
# Got 176 reivews
# 256005 reviews are now in the bag, so to speak
# 2024-03-30 12:34:19
#
# Scraped 114 users this round
# Got 198 reivews
# 256203 reviews are now in the bag, so to speak
# 2024-03-30 12:38:04
#
# Scraped 114 users this round
# Got 176 reivews
# 256379 reviews are now in the bag, so to speak
# 2024-03-30 12:42:09
#
# Scraped 90 users this round
# Got 144 reivews
# 256523 reviews are now in the bag, so to speak
# 2024-03-30 12:44:54
#
# Scraped 119 users this round
# Got 208 reivews
# 256731 reviews are now in the bag, so to speak
# 2024-03-30 12:48:53
#
# Scraped 104 users this round
# Got 208 reivews
# 256939 reviews are now in the bag, so to speak
# 2024-03-30 12:52:21
#
# Scraped 117 users this round
# Got 176 reivews
# 257115 reviews are now in the bag, so to speak
# 2024-03-30 12:56:11
#
# Scraped 108 users this round
# Got 206 reivews
# 257321 reviews are now in the bag, so to speak
# 2024-03-30 12:59:55
#
# Scraped 95 users this round
# Got 143 reivews
# 257464 reviews are now in the bag, so to speak
# 2024-03-30 13:02:55
#
# Scraped 112 users this round
# Got 248 reivews
# 257712 reviews are now in the bag, so to speak
# 2024-03-30 13:07:04
#
# Scraped 112 users this round
# Got 180 reivews
# 257892 reviews are now in the bag, so to speak
# 2024-03-30 13:10:55
#
# Scraped 109 users this round
# Got 171 reivews
# 258063 reviews are now in the bag, so to speak
# 2024-03-30 13:14:34
#
# Scraped 120 users this round
# Got 203 reivews
# 258266 reviews are now in the bag, so to speak
# 2024-03-30 13:18:37
#
# Scraped 117 users this round
# Got 150 reivews
# 258416 reviews are now in the bag, so to speak
# 2024-03-30 13:22:34
#
# Scraped 106 users this round
# Got 198 reivews
# 258614 reviews are now in the bag, so to speak
# 2024-03-30 13:26:16
#
# Scraped 123 users this round
# Got 193 reivews
# 258807 reviews are now in the bag, so to speak
# 2024-03-30 13:30:41
#
# Scraped 125 users this round
# Got 176 reivews
# 258983 reviews are now in the bag, so to speak
# 2024-03-30 13:35:00
#
# Scraped 98 users this round
# Got 151 reivews
# 259134 reviews are now in the bag, so to speak
# 2024-03-30 13:38:13
#
# Scraped 100 users this round
# Got 186 reivews
# 259320 reviews are now in the bag, so to speak
# 2024-03-30 13:41:29
#
# Scraped 126 users this round
# Got 185 reivews
# 259505 reviews are now in the bag, so to speak
# 2024-03-30 13:45:51
#
# Scraped 110 users this round
# Got 167 reivews
# 259672 reviews are now in the bag, so to speak
# 2024-03-30 13:49:20
#
# Scraped 135 users this round
# Got 167 reivews
# 259839 reviews are now in the bag, so to speak
# 2024-03-30 13:53:54
#
# Scraped 97 users this round
# Got 201 reivews
# 260040 reviews are now in the bag, so to speak
# 2024-03-30 13:57:05
#
# Scraped 114 users this round
# Got 144 reivews
# 260184 reviews are now in the bag, so to speak
# 2024-03-30 14:00:49
#
# Scraped 104 users this round
# Got 203 reivews
# 260387 reviews are now in the bag, so to speak
# 2024-03-30 14:04:15
#
# Scraped 106 users this round
# Got 160 reivews
# 260547 reviews are now in the bag, so to speak
# 2024-03-30 14:07:52
#
# Scraped 105 users this round
# Got 179 reivews
# 260726 reviews are now in the bag, so to speak
# 2024-03-30 14:11:21
#
# Scraped 102 users this round
# Got 197 reivews
# 260923 reviews are now in the bag, so to speak
# 2024-03-30 14:14:42
#
# Scraped 98 users this round
# Got 196 reivews
# 261119 reviews are now in the bag, so to speak
# 2024-03-30 14:18:03
#
# Scraped 112 users this round
# Got 243 reivews
# 261362 reviews are now in the bag, so to speak
# 2024-03-30 14:21:56
#
# Scraped 99 users this round
# Got 200 reivews
# 261562 reviews are now in the bag, so to speak
# 2024-03-30 14:25:19
#
# Scraped 116 users this round
# Got 198 reivews
# 261760 reviews are now in the bag, so to speak
# 2024-03-30 14:29:13
#
# Scraped 98 users this round
# Got 188 reivews
# 261948 reviews are now in the bag, so to speak
# 2024-03-30 14:32:23
#
# Scraped 118 users this round
# Got 230 reivews
# 262178 reviews are now in the bag, so to speak
# 2024-03-30 14:36:19
#
# Scraped 108 users this round
# Got 197 reivews
# 262375 reviews are now in the bag, so to speak
# 2024-03-30 14:40:04
#
# Scraped 111 users this round
# Got 184 reivews
# 262559 reviews are now in the bag, so to speak
# 2024-03-30 14:43:52
#
# Scraped 102 users this round
# Got 219 reivews
# 262778 reviews are now in the bag, so to speak
# 2024-03-30 14:47:14
#
# Scraped 103 users this round
# Got 174 reivews
# 262952 reviews are now in the bag, so to speak
# 2024-03-30 14:50:37
#
# Scraped 132 users this round
# Got 199 reivews
# 263151 reviews are now in the bag, so to speak
# 2024-03-30 14:55:00
#
# Scraped 105 users this round
# Got 213 reivews
# 263364 reviews are now in the bag, so to speak
# 2024-03-30 14:58:33
#
# Scraped 98 users this round
# Got 153 reivews
# 263517 reviews are now in the bag, so to speak
# 2024-03-30 15:01:42
#
# Scraped 118 users this round
# Got 152 reivews
# 263669 reviews are now in the bag, so to speak
# 2024-03-30 15:05:35
#
# Scraped 117 users this round
# Got 162 reivews
# 263831 reviews are now in the bag, so to speak
# 2024-03-30 15:09:42
#
# Scraped 121 users this round
# Got 170 reivews
# 264001 reviews are now in the bag, so to speak
# 2024-03-30 15:13:45
#
# Scraped 96 users this round
# Got 189 reivews
# 264190 reviews are now in the bag, so to speak
# 2024-03-30 15:16:55
#
# Scraped 101 users this round
# Got 173 reivews
# 264363 reviews are now in the bag, so to speak
# 2024-03-30 15:20:18
#
# Scraped 115 users this round
# Got 183 reivews
# 264546 reviews are now in the bag, so to speak
# 2024-03-30 15:24:15
#
# Scraped 96 users this round
# Got 183 reivews
# 264729 reviews are now in the bag, so to speak
# 2024-03-30 15:27:24
#
# Scraped 93 users this round
# Got 186 reivews
# 264915 reviews are now in the bag, so to speak
# 2024-03-30 15:30:30
#
# Scraped 129 users this round
# Got 202 reivews
# 265117 reviews are now in the bag, so to speak
# 2024-03-30 15:34:54
#
# Scraped 100 users this round
# Got 173 reivews
# 265290 reviews are now in the bag, so to speak
# 2024-03-30 15:38:06
#
# Scraped 125 users this round
# Got 197 reivews
# 265487 reviews are now in the bag, so to speak
# 2024-03-30 15:42:17
#
# Scraped 93 users this round
# Got 162 reivews
# 265649 reviews are now in the bag, so to speak
# 2024-03-30 15:45:15
#
# Scraped 139 users this round
# Got 207 reivews
# 265856 reviews are now in the bag, so to speak
# 2024-03-30 15:50:03
#
# Scraped 123 users this round
# Got 206 reivews
# 266062 reviews are now in the bag, so to speak
# 2024-03-30 15:54:13
#
# Scraped 82 users this round
# Got 161 reivews
# 266223 reviews are now in the bag, so to speak
# 2024-03-30 15:56:45
#
# Scraped 106 users this round
# Got 184 reivews
# 266407 reviews are now in the bag, so to speak
# 2024-03-30 16:00:20
#
# Scraped 105 users this round
# Got 203 reivews
# 266610 reviews are now in the bag, so to speak
# 2024-03-30 16:04:03
#
# Scraped 147 users this round
# Got 217 reivews
# 266827 reviews are now in the bag, so to speak
# 2024-03-30 16:09:28
#
# Scraped 104 users this round
# Got 156 reivews
# 266983 reviews are now in the bag, so to speak
# 2024-03-30 16:12:52
#
# Scraped 123 users this round
# Got 170 reivews
# 267153 reviews are now in the bag, so to speak
# 2024-03-30 16:17:03
#
# Scraped 127 users this round
# Got 218 reivews
# 267371 reviews are now in the bag, so to speak
# 2024-03-30 16:21:30
#
# Scraped 113 users this round
# Got 207 reivews
# 267578 reviews are now in the bag, so to speak
# 2024-03-30 16:25:08
#
# Scraped 102 users this round
# Got 209 reivews
# 267787 reviews are now in the bag, so to speak
# 2024-03-30 16:28:44
#
# Scraped 122 users this round
# Got 166 reivews
# 267953 reviews are now in the bag, so to speak
# 2024-03-30 16:32:54
#
# Scraped 104 users this round
# Got 211 reivews
# 268164 reviews are now in the bag, so to speak
# 2024-03-30 16:36:32
#
# Scraped 100 users this round
# Got 202 reivews
# 268366 reviews are now in the bag, so to speak
# 2024-03-30 16:39:53
#
# Scraped 119 users this round
# Got 197 reivews
# 268563 reviews are now in the bag, so to speak
# 2024-03-30 16:44:11
#
# Scraped 112 users this round
# Got 231 reivews
# 268794 reviews are now in the bag, so to speak
# 2024-03-30 16:48:01
#
# Scraped 104 users this round
# Got 190 reivews
# 268984 reviews are now in the bag, so to speak
# 2024-03-30 16:51:14
#
# Scraped 114 users this round
# Got 173 reivews
# 269157 reviews are now in the bag, so to speak
# 2024-03-30 16:54:59
#
# Scraped 106 users this round
# Got 208 reivews
# 269365 reviews are now in the bag, so to speak
# 2024-03-30 16:58:37
#
# Scraped 103 users this round
# Got 193 reivews
# 269558 reviews are now in the bag, so to speak
# 2024-03-30 17:02:16
#
# Scraped 114 users this round
# Got 170 reivews
# 269728 reviews are now in the bag, so to speak
# 2024-03-30 17:06:01
#
# Scraped 103 users this round
# Got 200 reivews
# 269928 reviews are now in the bag, so to speak
# 2024-03-30 17:09:27
#
# Scraped 128 users this round
# Got 206 reivews
# 270134 reviews are now in the bag, so to speak
# 2024-03-30 17:14:10
#
# Scraped 106 users this round
# Got 174 reivews
# 270308 reviews are now in the bag, so to speak
# 2024-03-30 17:17:43
#
# Scraped 122 users this round
# Got 215 reivews
# 270523 reviews are now in the bag, so to speak
# 2024-03-30 17:22:06
#
# Scraped 112 users this round
# Got 194 reivews
# 270717 reviews are now in the bag, so to speak
# 2024-03-30 17:25:58
#
# Scraped 110 users this round
# Got 186 reivews
# 270903 reviews are now in the bag, so to speak
# 2024-03-30 17:29:44
#
# Scraped 109 users this round
# Got 130 reivews
# 271033 reviews are now in the bag, so to speak
# 2024-03-30 17:33:19
#
# Scraped 111 users this round
# Got 260 reivews
# 271293 reviews are now in the bag, so to speak
# 2024-03-30 17:37:06
#
# Scraped 93 users this round
# Got 168 reivews
# 271461 reviews are now in the bag, so to speak
# 2024-03-30 17:40:04
#
# Scraped 130 users this round
# Got 169 reivews
# 271630 reviews are now in the bag, so to speak
# 2024-03-30 17:44:19
#
# Scraped 104 users this round
# Got 164 reivews
# 271794 reviews are now in the bag, so to speak
# 2024-03-30 17:47:42
#
# Scraped 113 users this round
# Got 197 reivews
# 271991 reviews are now in the bag, so to speak
# 2024-03-30 17:51:25
#
# Scraped 127 users this round
# Got 166 reivews
# 272157 reviews are now in the bag, so to speak
# 2024-03-30 17:55:39
#
# Scraped 98 users this round
# Got 218 reivews
# 272375 reviews are now in the bag, so to speak
# 2024-03-30 17:59:00
#
# Scraped 105 users this round
# Got 216 reivews
# 272591 reviews are now in the bag, so to speak
# 2024-03-30 18:02:33
#
# Scraped 108 users this round
# Got 194 reivews
# 272785 reviews are now in the bag, so to speak
# 2024-03-30 18:06:15
#
# Scraped 110 users this round
# Got 207 reivews
# 272992 reviews are now in the bag, so to speak
# 2024-03-30 18:10:00
#
# Scraped 128 users this round
# Got 171 reivews
# 273163 reviews are now in the bag, so to speak
# 2024-03-30 18:14:26
#
# Scraped 114 users this round
# Got 165 reivews
# 273328 reviews are now in the bag, so to speak
# 2024-03-30 18:18:23
#
# Scraped 116 users this round
# Got 164 reivews
# 273492 reviews are now in the bag, so to speak
# 2024-03-30 18:22:18
#
# Scraped 118 users this round
# Got 170 reivews
# 273662 reviews are now in the bag, so to speak
# 2024-03-30 18:26:25
#
# Scraped 120 users this round
# Got 193 reivews
# 273855 reviews are now in the bag, so to speak
# 2024-03-30 18:30:37
#
# Scraped 100 users this round
# Got 161 reivews
# 274016 reviews are now in the bag, so to speak
# 2024-03-30 18:34:02
#
# Scraped 120 users this round
# Got 162 reivews
# 274178 reviews are now in the bag, so to speak
# 2024-03-30 18:38:11
#
# Scraped 119 users this round
# Got 155 reivews
# 274333 reviews are now in the bag, so to speak
# 2024-03-30 18:42:15
#
# Scraped 124 users this round
# Got 162 reivews
# 274495 reviews are now in the bag, so to speak
# 2024-03-30 18:46:39
#
# Scraped 131 users this round
# Got 211 reivews
# 274706 reviews are now in the bag, so to speak
# 2024-03-30 18:51:09
#
# Scraped 109 users this round
# Got 185 reivews
# 274891 reviews are now in the bag, so to speak
# 2024-03-30 18:55:01
#
# Scraped 123 users this round
# Got 173 reivews
# 275064 reviews are now in the bag, so to speak
# 2024-03-30 18:59:16
#
# Scraped 122 users this round
# Got 203 reivews
# 275267 reviews are now in the bag, so to speak
# 2024-03-30 19:03:22
#
# Scraped 118 users this round
# Got 197 reivews
# 275464 reviews are now in the bag, so to speak
# 2024-03-30 19:07:23
#
# Scraped 129 users this round
# Got 208 reivews
# 275672 reviews are now in the bag, so to speak
# 2024-03-30 19:11:46
#
# Scraped 126 users this round
# Got 176 reivews
# 275848 reviews are now in the bag, so to speak
# 2024-03-30 19:15:59
#
# Scraped 93 users this round
# Got 210 reivews
# 276058 reviews are now in the bag, so to speak
# 2024-03-30 19:18:55
#
# Scraped 107 users this round
# Got 185 reivews
# 276243 reviews are now in the bag, so to speak
# 2024-03-30 19:22:46
#
# Scraped 124 users this round
# Got 153 reivews
# 276396 reviews are now in the bag, so to speak
# 2024-03-30 19:27:02
#
# Scraped 102 users this round
# Got 192 reivews
# 276588 reviews are now in the bag, so to speak
# 2024-03-30 19:30:34
#
# Scraped 124 users this round
# Got 179 reivews
# 276767 reviews are now in the bag, so to speak
# 2024-03-30 19:34:51
#
# Scraped 106 users this round
# Got 217 reivews
# 276984 reviews are now in the bag, so to speak
# 2024-03-30 19:38:37
#
# Scraped 114 users this round
# Got 194 reivews
# 277178 reviews are now in the bag, so to speak
# 2024-03-30 19:42:34
#
# Scraped 110 users this round
# Got 205 reivews
# 277383 reviews are now in the bag, so to speak
# 2024-03-30 19:46:05
#
# Scraped 130 users this round
# Got 157 reivews
# 277540 reviews are now in the bag, so to speak
# 2024-03-30 19:50:43
#
# Scraped 116 users this round
# Got 219 reivews
# 277759 reviews are now in the bag, so to speak
# 2024-03-30 19:54:31
#
# Scraped 131 users this round
# Got 201 reivews
# 277960 reviews are now in the bag, so to speak
# 2024-03-30 19:59:10
#
# Scraped 113 users this round
# Got 205 reivews
# 278165 reviews are now in the bag, so to speak
# 2024-03-30 20:02:42
#
# Scraped 121 users this round
# Got 194 reivews
# 278359 reviews are now in the bag, so to speak
# 2024-03-30 20:06:52
#
# Scraped 108 users this round
# Got 157 reivews
# 278516 reviews are now in the bag, so to speak
# 2024-03-30 20:10:42
#
# Scraped 111 users this round
# Got 190 reivews
# 278706 reviews are now in the bag, so to speak
# 2024-03-30 20:14:24
#
# Scraped 91 users this round
# Got 204 reivews
# 278910 reviews are now in the bag, so to speak
# 2024-03-30 20:17:31
#
# Scraped 104 users this round
# Got 221 reivews
# 279131 reviews are now in the bag, so to speak
# 2024-03-30 20:21:04
#
# Scraped 117 users this round
# Got 221 reivews
# 279352 reviews are now in the bag, so to speak
# 2024-03-30 20:25:06
#
# Scraped 126 users this round
# Got 173 reivews
# ...
# 2024-04-03 00:00:43
#
# Scraped 117 users this round
# Got 173 reivews
# 505750 reviews are now in the bag, so to speak
# 2024-04-03 00:04:28
#
# Scraped 124 users this round
# Got 193 reivews
# 505943 reviews are now in the bag, so to speak
# 2024-04-03 00:08:39
#
# Scraped 114 users this round
# Got 205 reivews
# 506148 reviews are now in the bag, so to speak
# 2024-04-03 00:12:20
#
# Scraped 126 users this round
# Got 158 reivews
# 506306 reviews are now in the bag, so to speak
# 2024-04-03 00:16:21
#
# Scraped 103 users this round
# Got 200 reivews
# 506506 reviews are now in the bag, so to speak
# 2024-04-03 00:19:41
#
# Scraped 105 users this round
# Got 191 reivews
# 506697 reviews are now in the bag, so to speak
# 2024-04-03 00:23:14
#
# Scraped 95 users this round
# Got 188 reivews
# 506885 reviews are now in the bag, so to speak
# 2024-04-03 00:26:25
#
# Scraped 117 users this round
# Got 203 reivews
# 507088 reviews are now in the bag, so to speak
# 2024-04-03 00:30:27
#
# Scraped 99 users this round
# Got 172 reivews
# 507260 reviews are now in the bag, so to speak
# 2024-04-03 00:33:43
#
# Scraped 107 users this round
# Got 237 reivews
# 507497 reviews are now in the bag, so to speak
# 2024-04-03 00:37:13
#
# Scraped 118 users this round
# Got 166 reivews
# 507663 reviews are now in the bag, so to speak
# 2024-04-03 00:41:10
#
# Scraped 109 users this round
# Got 197 reivews
# 507860 reviews are now in the bag, so to speak
# 2024-04-03 00:44:38
#
# Scraped 86 users this round
# Got 168 reivews
# 508028 reviews are now in the bag, so to speak
# 2024-04-03 00:47:28
#
# Scraped 97 users this round
# Got 205 reivews
# 508233 reviews are now in the bag, so to speak
# 2024-04-03 00:50:38
#
# Scraped 132 users this round
# Got 203 reivews
# 508436 reviews are now in the bag, so to speak
# 2024-04-03 00:55:18
#
# Scraped 106 users this round
# Got 138 reivews
# 508574 reviews are now in the bag, so to speak
# 2024-04-03 00:58:56
#
# Scraped 112 users this round
# Got 202 reivews
# 508776 reviews are now in the bag, so to speak
# 2024-04-03 01:02:38
#
# Scraped 106 users this round
# Got 178 reivews
# 508954 reviews are now in the bag, so to speak
# 2024-04-03 01:06:12
#
# Scraped 105 users this round
# Got 189 reivews
# 509143 reviews are now in the bag, so to speak
# 2024-04-03 01:09:28
#
# Scraped 103 users this round
# Got 226 reivews
# 509369 reviews are now in the bag, so to speak
# 2024-04-03 01:12:37
#
# Scraped 103 users this round
# Got 157 reivews
# 509526 reviews are now in the bag, so to speak
# 2024-04-03 01:16:05
#
# Scraped 111 users this round
# Got 200 reivews
# 509726 reviews are now in the bag, so to speak
# 2024-04-03 01:19:48
#
# Scraped 103 users this round
# Got 208 reivews
# 509934 reviews are now in the bag, so to speak
# 2024-04-03 01:23:03
#
# Scraped 97 users this round
# Got 185 reivews
# 510119 reviews are now in the bag, so to speak
# 2024-04-03 01:26:14
#
# Scraped 110 users this round
# Got 234 reivews
# 510353 reviews are now in the bag, so to speak
# 2024-04-03 01:29:36
#
# Scraped 127 users this round
# Got 162 reivews
# 510515 reviews are now in the bag, so to speak
# 2024-04-03 01:33:31
#
# Scraped 118 users this round
# Got 146 reivews
# 510661 reviews are now in the bag, so to speak
# 2024-04-03 01:37:14
#
# Scraped 114 users this round
# Got 172 reivews
# 510833 reviews are now in the bag, so to speak
# 2024-04-03 01:40:50
#
# Scraped 103 users this round
# Got 173 reivews
# 511006 reviews are now in the bag, so to speak
# 2024-04-03 01:43:57
#
# Scraped 112 users this round
# Got 196 reivews
# 511202 reviews are now in the bag, so to speak
# 2024-04-03 01:47:31
#
# Scraped 125 users this round
# Got 203 reivews
# 511405 reviews are now in the bag, so to speak
# 2024-04-03 01:51:34
#
# Scraped 92 users this round
# Got 191 reivews
# 511596 reviews are now in the bag, so to speak
# 2024-04-03 01:54:31
#
# Scraped 111 users this round
# Got 192 reivews
# 511788 reviews are now in the bag, so to speak
# 2024-04-03 01:57:52
#
# Scraped 115 users this round
# Got 190 reivews
# 511978 reviews are now in the bag, so to speak
# 2024-04-03 02:01:25
#
# Scraped 108 users this round
# Got 164 reivews
# 512142 reviews are now in the bag, so to speak
# 2024-04-03 02:04:43
#
# Scraped 116 users this round
# Got 176 reivews
# 512318 reviews are now in the bag, so to speak
# 2024-04-03 02:08:24
#
# Scraped 128 users this round
# Got 165 reivews
# 512483 reviews are now in the bag, so to speak
# 2024-04-03 02:12:29
#
# Scraped 96 users this round
# Got 198 reivews
# 512681 reviews are now in the bag, so to speak
# 2024-04-03 02:15:41
#
# Scraped 115 users this round
# Got 197 reivews
# 512878 reviews are now in the bag, so to speak
# 2024-04-03 02:19:29
#
# Scraped 97 users this round
# Got 179 reivews
# 513057 reviews are now in the bag, so to speak
# 2024-04-03 02:22:16
#
# Scraped 111 users this round
# Got 150 reivews
# 513207 reviews are now in the bag, so to speak
# 2024-04-03 02:25:37
#
# Scraped 117 users this round
# Got 193 reivews
# 513400 reviews are now in the bag, so to speak
# 2024-04-03 02:29:33
#
# Scraped 101 users this round
# Got 204 reivews
# 513604 reviews are now in the bag, so to speak
# 2024-04-03 02:32:46
#
# Scraped 111 users this round
# Got 191 reivews
# 513795 reviews are now in the bag, so to speak
# 2024-04-03 02:36:14
#
# Scraped 107 users this round
# Got 206 reivews
# 514001 reviews are now in the bag, so to speak
# 2024-04-03 02:39:33
#
# Scraped 123 users this round
# Got 193 reivews
# 514194 reviews are now in the bag, so to speak
# 2024-04-03 02:43:42
#
# Scraped 112 users this round
# Got 169 reivews
# 514363 reviews are now in the bag, so to speak
# 2024-04-03 02:47:15
#
# Scraped 115 users this round
# Got 226 reivews
# 514589 reviews are now in the bag, so to speak
# 2024-04-03 02:50:44
#
# Scraped 128 users this round
# Got 210 reivews
# 514799 reviews are now in the bag, so to speak
# 2024-04-03 02:54:40
#
# Scraped 102 users this round
# Got 194 reivews
# 514993 reviews are now in the bag, so to speak
# 2024-04-03 02:57:46
#
# Scraped 93 users this round
# Got 183 reivews
# 515176 reviews are now in the bag, so to speak
# 2024-04-03 03:00:34
#
# Scraped 111 users this round
# Got 218 reivews
# 515394 reviews are now in the bag, so to speak
# 2024-04-03 03:04:09
#
# Scraped 103 users this round
# Got 180 reivews
# 515574 reviews are now in the bag, so to speak
# 2024-04-03 03:07:21
#
# Scraped 97 users this round
# Got 245 reivews
# 515819 reviews are now in the bag, so to speak
# 2024-04-03 03:10:21
#
# Scraped 93 users this round
# Got 202 reivews
# 516021 reviews are now in the bag, so to speak
# 2024-04-03 03:13:04
#
# Scraped 117 users this round
# Got 219 reivews
# 516240 reviews are now in the bag, so to speak
# 2024-04-03 03:16:39
#
# Scraped 94 users this round
# Got 204 reivews
# 516444 reviews are now in the bag, so to speak
# 2024-04-03 03:19:26
#
# Scraped 118 users this round
# Got 205 reivews
# 516649 reviews are now in the bag, so to speak
# 2024-04-03 03:23:28
#
# Scraped 104 users this round
# Got 201 reivews
# 516850 reviews are now in the bag, so to speak
# 2024-04-03 03:26:51
#
# Scraped 108 users this round
# Got 172 reivews
# 517022 reviews are now in the bag, so to speak
# 2024-04-03 03:30:06
#
# Scraped 127 users this round
# Got 209 reivews
# 517231 reviews are now in the bag, so to speak
# 2024-04-03 03:34:33
#
# Scraped 125 users this round
# Got 193 reivews
# 517424 reviews are now in the bag, so to speak
# 2024-04-03 03:38:39
#
# Scraped 119 users this round
# Got 213 reivews
# 517637 reviews are now in the bag, so to speak
# 2024-04-03 03:42:31
#
# Scraped 108 users this round
# Got 208 reivews
# 517845 reviews are now in the bag, so to speak
# 2024-04-03 03:45:53
#
# Scraped 110 users this round
# Got 176 reivews
# 518021 reviews are now in the bag, so to speak
# 2024-04-03 03:49:19
#
# Scraped 114 users this round
# Got 223 reivews
# 518244 reviews are now in the bag, so to speak
# 2024-04-03 03:52:54
#
# Scraped 120 users this round
# Got 212 reivews
# 518456 reviews are now in the bag, so to speak
# 2024-04-03 03:56:41
#
# Scraped 118 users this round
# Got 214 reivews
# 518670 reviews are now in the bag, so to speak
# 2024-04-03 04:00:13
#
# Scraped 113 users this round
# Got 167 reivews
# 518837 reviews are now in the bag, so to speak
# 2024-04-03 04:03:52
#
# Scraped 102 users this round
# Got 136 reivews
# 518973 reviews are now in the bag, so to speak
# 2024-04-03 04:07:15
#
# Scraped 106 users this round
# Got 159 reivews
# 519132 reviews are now in the bag, so to speak
# 2024-04-03 04:10:44
#
# Scraped 113 users this round
# Got 178 reivews
# 519310 reviews are now in the bag, so to speak
# 2024-04-03 04:14:14
#
# Scraped 101 users this round
# Got 177 reivews
# 519487 reviews are now in the bag, so to speak
# 2024-04-03 04:17:10
#
# Scraped 126 users this round
# Got 188 reivews
# 519675 reviews are now in the bag, so to speak
# 2024-04-03 04:21:15
#
# Scraped 102 users this round
# Got 164 reivews
# 519839 reviews are now in the bag, so to speak
# 2024-04-03 04:24:31
#
# Scraped 125 users this round
# Got 181 reivews
# 520020 reviews are now in the bag, so to speak
# 2024-04-03 04:28:30
#
# Scraped 120 users this round
# Got 201 reivews
# 520221 reviews are now in the bag, so to speak
# 2024-04-03 04:32:23
#
# Scraped 107 users this round
# Got 175 reivews
# 520396 reviews are now in the bag, so to speak
# 2024-04-03 04:35:40
#
# Scraped 96 users this round
# Got 188 reivews
# 520584 reviews are now in the bag, so to speak
# 2024-04-03 04:38:43
#
# Scraped 109 users this round
# Got 193 reivews
# 520777 reviews are now in the bag, so to speak
# 2024-04-03 04:42:06
#
# Scraped 117 users this round
# Got 183 reivews
# 520960 reviews are now in the bag, so to speak
# 2024-04-03 04:45:45
#
# Scraped 98 users this round
# Got 165 reivews
# 521125 reviews are now in the bag, so to speak
# 2024-04-03 04:48:51
#
# Scraped 119 users this round
# Got 151 reivews
# 521276 reviews are now in the bag, so to speak
# 2024-04-03 04:52:36
#
# Scraped 122 users this round
# Got 173 reivews
# 521449 reviews are now in the bag, so to speak
# 2024-04-03 04:56:28
#
# Scraped 107 users this round
# Got 196 reivews
# 521645 reviews are now in the bag, so to speak
# 2024-04-03 04:59:52
#
# Scraped 117 users this round
# Got 190 reivews
# 521835 reviews are now in the bag, so to speak
# 2024-04-03 05:03:49
#
# Scraped 95 users this round
# Got 236 reivews
# 522071 reviews are now in the bag, so to speak
# 2024-04-03 05:07:10
#
# Scraped 107 users this round
# Got 193 reivews
# 522264 reviews are now in the bag, so to speak
# 2024-04-03 05:10:32
#
# Scraped 96 users this round
# Got 190 reivews
# 522454 reviews are now in the bag, so to speak
# 2024-04-03 05:13:30
#
# Scraped 127 users this round
# Got 173 reivews
# 522627 reviews are now in the bag, so to speak
# 2024-04-03 05:17:36
#
# Scraped 110 users this round
# Got 127 reivews
# 522754 reviews are now in the bag, so to speak
# 2024-04-03 05:21:05
#
# Scraped 128 users this round
# Got 140 reivews
# 522894 reviews are now in the bag, so to speak
# 2024-04-03 05:25:20
#
# Scraped 129 users this round
# Got 237 reivews
# 523131 reviews are now in the bag, so to speak
# 2024-04-03 05:29:42
#
# Scraped 106 users this round
# Got 145 reivews
# 523276 reviews are now in the bag, so to speak
# 2024-04-03 05:33:04
#
# Scraped 96 users this round
# Got 163 reivews
# 523439 reviews are now in the bag, so to speak
# 2024-04-03 05:36:45
#
# Scraped 105 users this round
# Got 190 reivews
# 523629 reviews are now in the bag, so to speak
# 2024-04-03 05:39:57
#
# Scraped 110 users this round
# Got 193 reivews
# 523822 reviews are now in the bag, so to speak
# 2024-04-03 05:43:37
#
# Scraped 88 users this round
# Got 161 reivews
# 523983 reviews are now in the bag, so to speak
# 2024-04-03 05:46:36
#
# Scraped 92 users this round
# Got 183 reivews
# 524166 reviews are now in the bag, so to speak
# 2024-04-03 05:49:21
#
# Scraped 126 users this round
# Got 180 reivews
# 524346 reviews are now in the bag, so to speak
# 2024-04-03 05:54:01
#
# Scraped 106 users this round
# Got 190 reivews
# 524536 reviews are now in the bag, so to speak
# 2024-04-03 05:57:38
#
# Scraped 117 users this round
# Got 203 reivews
# 524739 reviews are now in the bag, so to speak
# 2024-04-03 06:01:26
#
# Scraped 109 users this round
# Got 202 reivews
# 524941 reviews are now in the bag, so to speak
# 2024-04-03 06:04:46
#
# Scraped 112 users this round
# Got 151 reivews
# 525092 reviews are now in the bag, so to speak
# 2024-04-03 06:08:24
#
# Scraped 117 users this round
# Got 214 reivews
# 525306 reviews are now in the bag, so to speak
# 2024-04-03 06:12:09
#
# Scraped 98 users this round
# Got 190 reivews
# 525496 reviews are now in the bag, so to speak
# 2024-04-03 06:15:20
#
# Scraped 105 users this round
# Got 190 reivews
# 525686 reviews are now in the bag, so to speak
# 2024-04-03 06:18:28
#
# Scraped 116 users this round
# Got 240 reivews
# 525926 reviews are now in the bag, so to speak
# 2024-04-03 06:22:24
#
# Scraped 107 users this round
# Got 147 reivews
# 526073 reviews are now in the bag, so to speak
# 2024-04-03 06:25:56
#
# Scraped 86 users this round
# Got 179 reivews
# 526252 reviews are now in the bag, so to speak
# 2024-04-03 06:28:28
#
# Scraped 123 users this round
# Got 130 reivews
# 526382 reviews are now in the bag, so to speak
# 2024-04-03 06:33:05
#
# Scraped 128 users this round
# Got 210 reivews
# 526592 reviews are now in the bag, so to speak
# 2024-04-03 06:37:27
#
# Scraped 107 users this round
# Got 147 reivews
# 526739 reviews are now in the bag, so to speak
# 2024-04-03 06:40:53
#
# Scraped 107 users this round
# Got 211 reivews
# 526950 reviews are now in the bag, so to speak
# 2024-04-03 06:44:16
#
# Scraped 110 users this round
# Got 195 reivews
# 527145 reviews are now in the bag, so to speak
# 2024-04-03 06:47:46
#
# Scraped 102 users this round
# Got 208 reivews
# 527353 reviews are now in the bag, so to speak
# 2024-04-03 06:51:03
#
# Scraped 89 users this round
# Got 230 reivews
# 527583 reviews are now in the bag, so to speak
# 2024-04-03 06:53:55
#
# Scraped 88 users this round
# Got 201 reivews
# 527784 reviews are now in the bag, so to speak
# 2024-04-03 06:56:52
#
# Scraped 92 users this round
# Got 179 reivews
# 527963 reviews are now in the bag, so to speak
# 2024-04-03 06:59:33
#
# Scraped 113 users this round
# Got 177 reivews
# 528140 reviews are now in the bag, so to speak
# 2024-04-03 07:03:03
#
# Scraped 101 users this round
# Got 161 reivews
# 528301 reviews are now in the bag, so to speak
# 2024-04-03 07:06:20
#
# Scraped 138 users this round
# Got 183 reivews
# 528484 reviews are now in the bag, so to speak
# 2024-04-03 07:11:00
#
# Scraped 125 users this round
# Got 171 reivews
# 528655 reviews are now in the bag, so to speak
# 2024-04-03 07:14:59
#
# Scraped 112 users this round
# Got 156 reivews
# 528811 reviews are now in the bag, so to speak
# 2024-04-03 07:18:30
#
# Scraped 115 users this round
# Got 168 reivews
# 528979 reviews are now in the bag, so to speak
# 2024-04-03 07:22:08
#
# Scraped 107 users this round
# Got 186 reivews
# 529165 reviews are now in the bag, so to speak
# 2024-04-03 07:25:28
#
# Scraped 123 users this round
# Got 184 reivews
# 529349 reviews are now in the bag, so to speak
# 2024-04-03 07:29:48
#
# Scraped 96 users this round
# Got 181 reivews
# 529530 reviews are now in the bag, so to speak
# 2024-04-03 07:33:04
#
# Scraped 124 users this round
# Got 181 reivews
# 529711 reviews are now in the bag, so to speak
# 2024-04-03 07:37:16
#
# Scraped 107 users this round
# Got 178 reivews
# 529889 reviews are now in the bag, so to speak
# 2024-04-03 07:40:43
#
# Scraped 111 users this round
# Got 190 reivews
# 530079 reviews are now in the bag, so to speak
# 2024-04-03 07:44:30
#
# Scraped 106 users this round
# Got 216 reivews
# 530295 reviews are now in the bag, so to speak
# 2024-04-03 07:47:48
#
# Scraped 98 users this round
# Got 197 reivews
# 530492 reviews are now in the bag, so to speak
# 2024-04-03 07:50:56
#
# Scraped 77 users this round
# Got 182 reivews
# 530674 reviews are now in the bag, so to speak
# 2024-04-03 07:53:18
#
# Scraped 84 users this round
# Got 187 reivews
# 530861 reviews are now in the bag, so to speak
# 2024-04-03 07:56:21
#
# Scraped 114 users this round
# Got 196 reivews
# 531057 reviews are now in the bag, so to speak
# 2024-04-03 08:00:07
#
# Scraped 100 users this round
# Got 171 reivews
# 531228 reviews are now in the bag, so to speak
# 2024-04-03 08:03:44
#
# Scraped 122 users this round
# Got 189 reivews
# 531417 reviews are now in the bag, so to speak
# 2024-04-03 08:08:08
#
# Scraped 103 users this round
# Got 192 reivews
# 531609 reviews are now in the bag, so to speak
# 2024-04-03 08:11:29
#
# Scraped 130 users this round
# Got 123 reivews
# 531732 reviews are now in the bag, so to speak
# 2024-04-03 08:16:40
#
# Scraped 121 users this round
# Got 223 reivews
# 531955 reviews are now in the bag, so to speak
# 2024-04-03 08:21:38
#
# Unable to parse review blocks.
