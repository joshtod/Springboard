# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 9

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')

# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 124 users this round
# Got 171 reivews
# 340215 reviews are now in the bag, so to speak
# 2024-03-31 20:26:21
#
# Scraped 89 users this round
# Got 161 reivews
# 340376 reviews are now in the bag, so to speak
# 2024-03-31 20:29:20
#
# Scraped 136 users this round
# Got 177 reivews
# 340553 reviews are now in the bag, so to speak
# 2024-03-31 20:34:07
#
# Scraped 89 users this round
# Got 199 reivews
# 340752 reviews are now in the bag, so to speak
# 2024-03-31 20:37:21
#
# Scraped 123 users this round
# Got 203 reivews
# 340955 reviews are now in the bag, so to speak
# 2024-03-31 20:41:38
#
# Scraped 112 users this round
# Got 198 reivews
# 341153 reviews are now in the bag, so to speak
# 2024-03-31 20:45:35
#
# Scraped 113 users this round
# Got 210 reivews
# 341363 reviews are now in the bag, so to speak
# 2024-03-31 20:49:42
#
# Scraped 126 users this round
# Got 209 reivews
# 341572 reviews are now in the bag, so to speak
# 2024-03-31 20:53:55
#
# Scraped 98 users this round
# Got 169 reivews
# 341741 reviews are now in the bag, so to speak
# 2024-03-31 20:57:25
#
# Scraped 117 users this round
# Got 186 reivews
# 341927 reviews are now in the bag, so to speak
# 2024-03-31 21:01:40
#
# Scraped 104 users this round
# Got 175 reivews
# 342102 reviews are now in the bag, so to speak
# 2024-03-31 21:05:09
#
# Scraped 97 users this round
# Got 191 reivews
# 342293 reviews are now in the bag, so to speak
# 2024-03-31 21:08:38
#
# Scraped 99 users this round
# Got 172 reivews
# 342465 reviews are now in the bag, so to speak
# 2024-03-31 21:12:03
#
# Scraped 95 users this round
# Got 212 reivews
# 342677 reviews are now in the bag, so to speak
# 2024-03-31 21:15:21
#
# Scraped 123 users this round
# Got 180 reivews
# 342857 reviews are now in the bag, so to speak
# 2024-03-31 21:19:48
#
# Scraped 111 users this round
# Got 155 reivews
# 343012 reviews are now in the bag, so to speak
# 2024-03-31 21:23:59
#
# Scraped 92 users this round
# Got 159 reivews
# 343171 reviews are now in the bag, so to speak
# 2024-03-31 21:27:22
#
# Scraped 119 users this round
# Got 201 reivews
# 343372 reviews are now in the bag, so to speak
# 2024-03-31 21:32:22
#
# Scraped 107 users this round
# Got 149 reivews
# 343521 reviews are now in the bag, so to speak
# 2024-03-31 21:36:34
#
# Scraped 96 users this round
# Got 149 reivews
# 343670 reviews are now in the bag, so to speak
# 2024-03-31 21:40:22
#
# Scraped 101 users this round
# Got 214 reivews
# 343884 reviews are now in the bag, so to speak
# 2024-03-31 21:44:18
#
# Scraped 94 users this round
# Got 167 reivews
# 344051 reviews are now in the bag, so to speak
# 2024-03-31 21:47:49
#
# Scraped 94 users this round
# Got 169 reivews
# 344220 reviews are now in the bag, so to speak
# 2024-03-31 21:51:18
#
# Scraped 132 users this round
# Got 170 reivews
# 344390 reviews are now in the bag, so to speak
# 2024-03-31 21:56:22
#
# Scraped 124 users this round
# Got 206 reivews
# 344596 reviews are now in the bag, so to speak
# 2024-03-31 22:00:58
#
# Scraped 106 users this round
# Got 209 reivews
# 344805 reviews are now in the bag, so to speak
# 2024-03-31 22:04:51
#
# Scraped 103 users this round
# Got 176 reivews
# 344981 reviews are now in the bag, so to speak
# 2024-03-31 22:08:40
#
# Scraped 106 users this round
# Got 183 reivews
# 345164 reviews are now in the bag, so to speak
# 2024-03-31 22:13:41
#
# Scraped 111 users this round
# Got 152 reivews
# 345316 reviews are now in the bag, so to speak
# 2024-03-31 22:19:05
#
# Scraped 113 users this round
# Got 176 reivews
# 345492 reviews are now in the bag, so to speak
# 2024-03-31 22:24:52
#
# Scraped 104 users this round
# Got 206 reivews
# 345698 reviews are now in the bag, so to speak
# 2024-03-31 22:30:29
#
# Scraped 94 users this round
# Got 202 reivews
# 345900 reviews are now in the bag, so to speak
# 2024-03-31 22:35:42
#
# Scraped 96 users this round
# Got 212 reivews
# 346112 reviews are now in the bag, so to speak
# 2024-03-31 22:40:44
#
# Scraped 102 users this round
# Got 168 reivews
# 346280 reviews are now in the bag, so to speak
# 2024-03-31 22:46:21
#
# Scraped 118 users this round
# Got 175 reivews
# 346455 reviews are now in the bag, so to speak
# 2024-03-31 22:52:44
#
# Scraped 127 users this round
# Got 141 reivews
# 346596 reviews are now in the bag, so to speak
# 2024-03-31 23:00:09
#
# Scraped 116 users this round
# Got 185 reivews
# 346781 reviews are now in the bag, so to speak
# 2024-03-31 23:06:48
#
# Scraped 127 users this round
# Got 232 reivews
# 347013 reviews are now in the bag, so to speak
# 2024-03-31 23:13:47
#
# Scraped 101 users this round
# Got 201 reivews
# 347214 reviews are now in the bag, so to speak
# 2024-03-31 23:19:28
#
# Scraped 129 users this round
# Got 160 reivews
# 347374 reviews are now in the bag, so to speak
# 2024-03-31 23:26:16
#
# Scraped 96 users this round
# Got 177 reivews
# 347551 reviews are now in the bag, so to speak
# 2024-03-31 23:29:45
#
# Scraped 110 users this round
# Got 156 reivews
# 347707 reviews are now in the bag, so to speak
# 2024-03-31 23:33:15
#
# Scraped 129 users this round
# Got 213 reivews
# 347920 reviews are now in the bag, so to speak
# 2024-03-31 23:37:49
#
# Scraped 110 users this round
# Got 152 reivews
# 348072 reviews are now in the bag, so to speak
# 2024-03-31 23:41:47
#
# Scraped 106 users this round
# Got 169 reivews
# 348241 reviews are now in the bag, so to speak
# 2024-03-31 23:45:29
#
# Scraped 114 users this round
# Got 156 reivews
# 348397 reviews are now in the bag, so to speak
# 2024-03-31 23:49:34
#
# Scraped 114 users this round
# Got 180 reivews
# 348577 reviews are now in the bag, so to speak
# 2024-03-31 23:53:28
#
# Scraped 132 users this round
# Got 226 reivews
# 348803 reviews are now in the bag, so to speak
# 2024-03-31 23:58:00
#
# Scraped 101 users this round
# Got 160 reivews
# 348963 reviews are now in the bag, so to speak
# 2024-04-01 00:01:13
#
# Scraped 100 users this round
# Got 179 reivews
# 349142 reviews are now in the bag, so to speak
# 2024-04-01 00:04:28
#
# Scraped 101 users this round
# Got 192 reivews
# 349334 reviews are now in the bag, so to speak
# 2024-04-01 00:08:00
#
# Scraped 112 users this round
# Got 205 reivews
# 349539 reviews are now in the bag, so to speak
# 2024-04-01 00:11:50
#
# Scraped 99 users this round
# Got 168 reivews
# 349707 reviews are now in the bag, so to speak
# 2024-04-01 00:15:04
#
# Scraped 118 users this round
# Got 207 reivews
# 349914 reviews are now in the bag, so to speak
# 2024-04-01 00:19:13
#
# Scraped 109 users this round
# Got 189 reivews
# 350103 reviews are now in the bag, so to speak
# 2024-04-01 00:22:54
#
# Scraped 112 users this round
# Got 194 reivews
# 350297 reviews are now in the bag, so to speak
# 2024-04-01 00:26:47
#
# Scraped 111 users this round
# Got 170 reivews
# 350467 reviews are now in the bag, so to speak
# 2024-04-01 00:30:39
#
# Scraped 97 users this round
# Got 183 reivews
# 350650 reviews are now in the bag, so to speak
# 2024-04-01 00:33:44
#
# Scraped 97 users this round
# Got 197 reivews
# 350847 reviews are now in the bag, so to speak
# 2024-04-01 00:36:45
#
# Unable to parse review blocks.
# Scraped 103 users this round
# Got 172 reivews
# 351019 reviews are now in the bag, so to speak
# 2024-04-01 00:46:19
#
# Scraped 94 users this round
# Got 209 reivews
# 351228 reviews are now in the bag, so to speak
# 2024-04-01 00:49:35
#
# Scraped 117 users this round
# Got 192 reivews
# 351420 reviews are now in the bag, so to speak
# 2024-04-01 00:53:39
#
# Scraped 125 users this round
# Got 202 reivews
# 351622 reviews are now in the bag, so to speak
# 2024-04-01 00:58:09
#
# Scraped 100 users this round
# Got 166 reivews
# 351788 reviews are now in the bag, so to speak
# 2024-04-01 01:01:26
#
# Scraped 106 users this round
# Got 172 reivews
# 351960 reviews are now in the bag, so to speak
# 2024-04-01 01:05:02
#
# Scraped 111 users this round
# Got 183 reivews
# 352143 reviews are now in the bag, so to speak
# 2024-04-01 01:08:54
#
# Scraped 112 users this round
# Got 227 reivews
# 352370 reviews are now in the bag, so to speak
# 2024-04-01 01:12:45
#
# Scraped 125 users this round
# Got 164 reivews
# 352534 reviews are now in the bag, so to speak
# 2024-04-01 01:17:05
#
# Scraped 126 users this round
# Got 187 reivews
# 352721 reviews are now in the bag, so to speak
# 2024-04-01 01:21:37
#
# Scraped 115 users this round
# Got 163 reivews
# 352884 reviews are now in the bag, so to speak
# 2024-04-01 01:25:32
#
# Scraped 125 users this round
# Got 176 reivews
# 353060 reviews are now in the bag, so to speak
# 2024-04-01 01:29:44
#
# Scraped 136 users this round
# Got 201 reivews
# 353261 reviews are now in the bag, so to speak
# 2024-04-01 01:34:32
#
# Scraped 127 users this round
# Got 186 reivews
# 353447 reviews are now in the bag, so to speak
# 2024-04-01 01:38:44
#
# Scraped 88 users this round
# Got 196 reivews
# 353643 reviews are now in the bag, so to speak
# 2024-04-01 01:41:39
#
# Scraped 110 users this round
# Got 196 reivews
# 353839 reviews are now in the bag, so to speak
# 2024-04-01 01:45:23
#
# Scraped 121 users this round
# Got 177 reivews
# 354016 reviews are now in the bag, so to speak
# 2024-04-01 01:49:13
#
# Scraped 132 users this round
# Got 188 reivews
# 354204 reviews are now in the bag, so to speak
# 2024-04-01 01:53:49
#
# Scraped 110 users this round
# Got 226 reivews
# 354430 reviews are now in the bag, so to speak
# 2024-04-01 01:57:23
#
# Scraped 99 users this round
# Got 210 reivews
# 354640 reviews are now in the bag, so to speak
# 2024-04-01 02:00:52
#
# Scraped 95 users this round
# Got 166 reivews
# 354806 reviews are now in the bag, so to speak
# 2024-04-01 02:04:00
#
# Scraped 106 users this round
# Got 167 reivews
# 354973 reviews are now in the bag, so to speak
# 2024-04-01 02:07:48
#
# Scraped 124 users this round
# Got 216 reivews
# 355189 reviews are now in the bag, so to speak
# 2024-04-01 02:12:11
#
# Scraped 100 users this round
# Got 219 reivews
# 355408 reviews are now in the bag, so to speak
# 2024-04-01 02:15:26
#
# Scraped 106 users this round
# Got 190 reivews
# 355598 reviews are now in the bag, so to speak
# 2024-04-01 02:19:01
#
# Scraped 91 users this round
# Got 198 reivews
# 355796 reviews are now in the bag, so to speak
# 2024-04-01 02:22:09
#
# Scraped 103 users this round
# Got 199 reivews
# 355995 reviews are now in the bag, so to speak
# 2024-04-01 02:25:24
#
# Scraped 104 users this round
# Got 204 reivews
# 356199 reviews are now in the bag, so to speak
# 2024-04-01 02:28:55
#
# Scraped 103 users this round
# Got 190 reivews
# 356389 reviews are now in the bag, so to speak
# 2024-04-01 02:32:17
#
# Scraped 100 users this round
# Got 229 reivews
# 356618 reviews are now in the bag, so to speak
# 2024-04-01 02:35:44
#
# Scraped 101 users this round
# Got 193 reivews
# 356811 reviews are now in the bag, so to speak
# 2024-04-01 02:39:01
#
# Scraped 92 users this round
# Got 184 reivews
# 356995 reviews are now in the bag, so to speak
# 2024-04-01 02:41:49
#
# Scraped 98 users this round
# Got 164 reivews
# 357159 reviews are now in the bag, so to speak
# 2024-04-01 02:44:55
#
# Scraped 118 users this round
# Got 177 reivews
# 357336 reviews are now in the bag, so to speak
# 2024-04-01 02:48:44
#
# Scraped 113 users this round
# Got 163 reivews
# 357499 reviews are now in the bag, so to speak
# 2024-04-01 02:52:26
#
# Scraped 112 users this round
# Got 215 reivews
# 357714 reviews are now in the bag, so to speak
# 2024-04-01 02:56:11
#
# Scraped 122 users this round
# Got 203 reivews
# 357917 reviews are now in the bag, so to speak
# 2024-04-01 03:00:25
#
# Scraped 92 users this round
# Got 178 reivews
# 358095 reviews are now in the bag, so to speak
# 2024-04-01 03:03:18
#
# Scraped 106 users this round
# Got 163 reivews
# 358258 reviews are now in the bag, so to speak
# 2024-04-01 03:06:38
#
# Scraped 119 users this round
# Got 195 reivews
# 358453 reviews are now in the bag, so to speak
# 2024-04-01 03:10:37
#
# Scraped 109 users this round
# Got 144 reivews
# 358597 reviews are now in the bag, so to speak
# 2024-04-01 03:14:16
#
# Scraped 98 users this round
# Got 186 reivews
# 358783 reviews are now in the bag, so to speak
# 2024-04-01 03:17:25
#
# Scraped 108 users this round
# Got 200 reivews
# 358983 reviews are now in the bag, so to speak
# 2024-04-01 03:21:08
#
# Scraped 109 users this round
# Got 158 reivews
# 359141 reviews are now in the bag, so to speak
# 2024-04-01 03:24:36
#
# Scraped 92 users this round
# Got 177 reivews
# 359318 reviews are now in the bag, so to speak
# 2024-04-01 03:27:36
#
# Scraped 111 users this round
# Got 212 reivews
# 359530 reviews are now in the bag, so to speak
# 2024-04-01 03:31:16
#
# Scraped 111 users this round
# Got 173 reivews
# 359703 reviews are now in the bag, so to speak
# 2024-04-01 03:34:49
#
# Scraped 110 users this round
# Got 162 reivews
# 359865 reviews are now in the bag, so to speak
# 2024-04-01 03:38:26
#
# Scraped 138 users this round
# Got 183 reivews
# 360048 reviews are now in the bag, so to speak
# 2024-04-01 03:43:02
#
# Scraped 126 users this round
# Got 183 reivews
# 360231 reviews are now in the bag, so to speak
# 2024-04-01 03:47:12
#
# Scraped 107 users this round
# Got 166 reivews
# 360397 reviews are now in the bag, so to speak
# 2024-04-01 03:50:24
#
# Scraped 103 users this round
# Got 173 reivews
# 360570 reviews are now in the bag, so to speak
# 2024-04-01 03:53:37
#
# Scraped 119 users this round
# Got 205 reivews
# 360775 reviews are now in the bag, so to speak
# 2024-04-01 03:57:46
#
# Scraped 105 users this round
# Got 195 reivews
# 360970 reviews are now in the bag, so to speak
# 2024-04-01 04:00:56
#
# Scraped 129 users this round
# Got 192 reivews
# 361162 reviews are now in the bag, so to speak
# 2024-04-01 04:05:22
#
# Scraped 101 users this round
# Got 204 reivews
# 361366 reviews are now in the bag, so to speak
# 2024-04-01 04:08:44
#
# Scraped 114 users this round
# Got 178 reivews
# 361544 reviews are now in the bag, so to speak
# 2024-04-01 04:12:28
#
# Scraped 106 users this round
# Got 232 reivews
# 361776 reviews are now in the bag, so to speak
# 2024-04-01 04:16:04
#
# Scraped 112 users this round
# Got 164 reivews
# 361940 reviews are now in the bag, so to speak
# 2024-04-01 04:20:01
#
# Scraped 122 users this round
# Got 174 reivews
# 362114 reviews are now in the bag, so to speak
# 2024-04-01 04:24:04
#
# Scraped 110 users this round
# Got 168 reivews
# 362282 reviews are now in the bag, so to speak
# 2024-04-01 04:27:47
#
# Scraped 103 users this round
# Got 159 reivews
# 362441 reviews are now in the bag, so to speak
# 2024-04-01 04:31:05
#
# Scraped 103 users this round
# Got 199 reivews
# 362640 reviews are now in the bag, so to speak
# 2024-04-01 04:34:43
#
# Scraped 99 users this round
# Got 171 reivews
# 362811 reviews are now in the bag, so to speak
# 2024-04-01 04:37:53
#
# Scraped 100 users this round
# Got 151 reivews
# 362962 reviews are now in the bag, so to speak
# 2024-04-01 04:41:06
#
# Scraped 81 users this round
# Got 175 reivews
# 363137 reviews are now in the bag, so to speak
# 2024-04-01 04:43:34
#
# Scraped 136 users this round
# Got 211 reivews
# 363348 reviews are now in the bag, so to speak
# 2024-04-01 04:48:02
#
# Scraped 105 users this round
# Got 219 reivews
# 363567 reviews are now in the bag, so to speak
# 2024-04-01 04:51:28
#
# Scraped 108 users this round
# Got 228 reivews
# 363795 reviews are now in the bag, so to speak
# 2024-04-01 04:54:57
#
# Scraped 121 users this round
# Got 173 reivews
# 363968 reviews are now in the bag, so to speak
# 2024-04-01 04:59:06
#
# Scraped 99 users this round
# Got 199 reivews
# 364167 reviews are now in the bag, so to speak
# 2024-04-01 05:02:25
#
# Scraped 101 users this round
# Got 166 reivews
# 364333 reviews are now in the bag, so to speak
# 2024-04-01 05:05:40
#
# Scraped 120 users this round
# Got 180 reivews
# 364513 reviews are now in the bag, so to speak
# 2024-04-01 05:09:45
#
# Scraped 123 users this round
# Got 187 reivews
# 364700 reviews are now in the bag, so to speak
# 2024-04-01 05:13:55
#
# Scraped 122 users this round
# Got 212 reivews
# 364912 reviews are now in the bag, so to speak
# 2024-04-01 05:17:59
#
# Scraped 90 users this round
# Got 208 reivews
# 365120 reviews are now in the bag, so to speak
# 2024-04-01 05:20:55
#
# Scraped 101 users this round
# Got 198 reivews
# 365318 reviews are now in the bag, so to speak
# 2024-04-01 05:24:19
#
# Scraped 106 users this round
# Got 137 reivews
# 365455 reviews are now in the bag, so to speak
# 2024-04-01 05:27:41
#
# Scraped 102 users this round
# Got 192 reivews
# 365647 reviews are now in the bag, so to speak
# 2024-04-01 05:31:05
#
# Scraped 108 users this round
# Got 205 reivews
# 365852 reviews are now in the bag, so to speak
# 2024-04-01 05:34:38
#
# Scraped 103 users this round
# Got 190 reivews
# 366042 reviews are now in the bag, so to speak
# 2024-04-01 05:38:02
#
# Scraped 123 users this round
# Got 169 reivews
# 366211 reviews are now in the bag, so to speak
# 2024-04-01 05:42:23
#
# Scraped 116 users this round
# Got 213 reivews
# 366424 reviews are now in the bag, so to speak
# 2024-04-01 05:46:08
#
# Unable to parse review blocks.
# Scraped 114 users this round
# Got 199 reivews
# 366623 reviews are now in the bag, so to speak
# 2024-04-01 05:51:23
#
# Scraped 125 users this round
# Got 176 reivews
# 366799 reviews are now in the bag, so to speak
# 2024-04-01 05:55:35
#
# Scraped 113 users this round
# Got 156 reivews
# 366955 reviews are now in the bag, so to speak
# 2024-04-01 05:59:08
#
# Scraped 126 users this round
# Got 180 reivews
# 367135 reviews are now in the bag, so to speak
# 2024-04-01 06:03:26
#
# Scraped 112 users this round
# Got 211 reivews
# 367346 reviews are now in the bag, so to speak
# 2024-04-01 06:07:20
#
# Scraped 106 users this round
# Got 184 reivews
# 367530 reviews are now in the bag, so to speak
# 2024-04-01 06:10:44
#
# Scraped 114 users this round
# Got 192 reivews
# 367722 reviews are now in the bag, so to speak
# 2024-04-01 06:14:34
#
# Scraped 108 users this round
# Got 226 reivews
# 367948 reviews are now in the bag, so to speak
# 2024-04-01 06:18:03
#
# Scraped 114 users this round
# Got 208 reivews
# 368156 reviews are now in the bag, so to speak
# 2024-04-01 06:21:47
#
# Scraped 112 users this round
# Got 227 reivews
# 368383 reviews are now in the bag, so to speak
# 2024-04-01 06:25:34
#
# Scraped 124 users this round
# Got 200 reivews
# 368583 reviews are now in the bag, so to speak
# 2024-04-01 06:29:48
#
# Scraped 113 users this round
# Got 178 reivews
# 368761 reviews are now in the bag, so to speak
# 2024-04-01 06:33:38
#
# Scraped 131 users this round
# Got 201 reivews
# 368962 reviews are now in the bag, so to speak
# 2024-04-01 06:38:17
#
# Scraped 122 users this round
# Got 189 reivews
# 369151 reviews are now in the bag, so to speak
# 2024-04-01 06:42:18
#
# Scraped 97 users this round
# Got 171 reivews
# 369322 reviews are now in the bag, so to speak
# 2024-04-01 06:45:35
#
# Scraped 138 users this round
# Got 200 reivews
# 369522 reviews are now in the bag, so to speak
# 2024-04-01 06:50:26
#
# Scraped 113 users this round
# Got 229 reivews
# 369751 reviews are now in the bag, so to speak
# 2024-04-01 06:54:15
#
# Scraped 95 users this round
# Got 187 reivews
# 369938 reviews are now in the bag, so to speak
# 2024-04-01 06:57:13
#
# Scraped 108 users this round
# Got 180 reivews
# 370118 reviews are now in the bag, so to speak
# 2024-04-01 07:00:43
#
# Scraped 114 users this round
# Got 196 reivews
# 370314 reviews are now in the bag, so to speak
# 2024-04-01 07:04:40
#
# Scraped 114 users this round
# Got 171 reivews
# 370485 reviews are now in the bag, so to speak
# 2024-04-01 07:08:41
#
# Scraped 115 users this round
# Got 245 reivews
# 370730 reviews are now in the bag, so to speak
# 2024-04-01 07:12:36
#
# Scraped 90 users this round
# Got 192 reivews
# 370922 reviews are now in the bag, so to speak
# 2024-04-01 07:15:40
#
# Scraped 103 users this round
# Got 231 reivews
# 371153 reviews are now in the bag, so to speak
# 2024-04-01 07:18:56
#
# Scraped 114 users this round
# Got 164 reivews
# 371317 reviews are now in the bag, so to speak
# 2024-04-01 07:22:46
#
# Scraped 120 users this round
# Got 181 reivews
# 371498 reviews are now in the bag, so to speak
# 2024-04-01 07:27:10
#
# Scraped 115 users this round
# Got 176 reivews
# 371674 reviews are now in the bag, so to speak
# 2024-04-01 07:30:56
#
# Scraped 96 users this round
# Got 195 reivews
# 371869 reviews are now in the bag, so to speak
# 2024-04-01 07:34:01
#
# Scraped 114 users this round
# Got 192 reivews
# 372061 reviews are now in the bag, so to speak
# 2024-04-01 07:37:52
#
# Scraped 124 users this round
# Got 173 reivews
# 372234 reviews are now in the bag, so to speak
# 2024-04-01 07:42:04
#
# Scraped 113 users this round
# Got 223 reivews
# 372457 reviews are now in the bag, so to speak
# 2024-04-01 07:46:05
#
# Scraped 93 users this round
# Got 174 reivews
# 372631 reviews are now in the bag, so to speak
# 2024-04-01 07:48:57
#
# Scraped 106 users this round
# Got 176 reivews
# 372807 reviews are now in the bag, so to speak
# 2024-04-01 07:52:27
#
# Scraped 99 users this round
# Got 192 reivews
# 372999 reviews are now in the bag, so to speak
# 2024-04-01 07:55:41
#
# Scraped 113 users this round
# Got 184 reivews
# 373183 reviews are now in the bag, so to speak
# 2024-04-01 07:59:32
#
# Scraped 87 users this round
# Got 180 reivews
# 373363 reviews are now in the bag, so to speak
# 2024-04-01 08:02:25
#
# Scraped 110 users this round
# Got 196 reivews
# 373559 reviews are now in the bag, so to speak
# 2024-04-01 08:06:07
#
# Scraped 116 users this round
# Got 176 reivews
# 373735 reviews are now in the bag, so to speak
# 2024-04-01 08:10:18
#
# Scraped 110 users this round
# Got 226 reivews
# 373961 reviews are now in the bag, so to speak
# 2024-04-01 08:14:10
#
# Scraped 101 users this round
# Got 206 reivews
# 374167 reviews are now in the bag, so to speak
# 2024-04-01 08:17:40
#
# Scraped 101 users this round
# Got 208 reivews
# 374375 reviews are now in the bag, so to speak
# 2024-04-01 08:20:58
#
# Scraped 110 users this round
# Got 192 reivews
# 374567 reviews are now in the bag, so to speak
# 2024-04-01 08:24:54
#
# Scraped 115 users this round
# Got 156 reivews
# 374723 reviews are now in the bag, so to speak
# 2024-04-01 08:28:46
#
# Scraped 102 users this round
# Got 173 reivews
# 374896 reviews are now in the bag, so to speak
# 2024-04-01 08:32:24
#
# Scraped 127 users this round
# Got 177 reivews
# 375073 reviews are now in the bag, so to speak
# 2024-04-01 08:36:53
#
# Scraped 109 users this round
# Got 194 reivews
# 375267 reviews are now in the bag, so to speak
# 2024-04-01 08:40:41
#
# Scraped 110 users this round
# Got 185 reivews
# 375452 reviews are now in the bag, so to speak
# 2024-04-01 08:44:27
#
# Scraped 95 users this round
# Got 213 reivews
# 375665 reviews are now in the bag, so to speak
# 2024-04-01 08:47:39
#
# Scraped 124 users this round
# Got 193 reivews
# 375858 reviews are now in the bag, so to speak
# 2024-04-01 08:52:06
#
# Scraped 91 users this round
# Got 146 reivews
# 376004 reviews are now in the bag, so to speak
# 2024-04-01 08:55:08
#
# Scraped 98 users this round
# Got 185 reivews
# 376189 reviews are now in the bag, so to speak
# 2024-04-01 08:58:35
#
# Scraped 127 users this round
# Got 139 reivews
# 376328 reviews are now in the bag, so to speak
# 2024-04-01 09:02:50
#
# Scraped 106 users this round
# Got 199 reivews
# 376527 reviews are now in the bag, so to speak
# 2024-04-01 09:06:26
#
# Scraped 112 users this round
# Got 163 reivews
# 376690 reviews are now in the bag, so to speak
# 2024-04-01 09:10:29
#
# Scraped 94 users this round
# Got 171 reivews
# 376861 reviews are now in the bag, so to speak
# 2024-04-01 09:13:36
#
# Scraped 122 users this round
# Got 172 reivews
# 377033 reviews are now in the bag, so to speak
# 2024-04-01 09:18:04
#
# Scraped 109 users this round
# Got 189 reivews
# 377222 reviews are now in the bag, so to speak
# 2024-04-01 09:22:04
#
# Scraped 98 users this round
# Got 222 reivews
# 377444 reviews are now in the bag, so to speak
# 2024-04-01 09:25:25
#
# Scraped 114 users this round
# Got 202 reivews
# 377646 reviews are now in the bag, so to speak
# 2024-04-01 09:29:32
#
# Scraped 132 users this round
# Got 235 reivews
# 377881 reviews are now in the bag, so to speak
# 2024-04-01 09:34:14
#
# Scraped 114 users this round
# Got 157 reivews
# 378038 reviews are now in the bag, so to speak
# 2024-04-01 09:38:06
#
# Scraped 123 users this round
# Got 210 reivews
# 378248 reviews are now in the bag, so to speak
# 2024-04-01 09:42:47
#
# Scraped 105 users this round
# Got 200 reivews
# 378448 reviews are now in the bag, so to speak
# 2024-04-01 09:46:34
#
# Scraped 112 users this round
# Got 202 reivews
# 378650 reviews are now in the bag, so to speak
# 2024-04-01 09:50:31
#
# Scraped 120 users this round
# Got 184 reivews
# 378834 reviews are now in the bag, so to speak
# 2024-04-01 09:55:32
#
# Scraped 112 users this round
# Got 207 reivews
# 379041 reviews are now in the bag, so to speak
# 2024-04-01 09:59:13
#
# Scraped 141 users this round
# Got 153 reivews
# 379194 reviews are now in the bag, so to speak
# 2024-04-01 10:04:49
#
# Scraped 120 users this round
# Got 189 reivews
# 379383 reviews are now in the bag, so to speak
# 2024-04-01 10:09:12
#
# Scraped 103 users this round
# Got 209 reivews
# 379592 reviews are now in the bag, so to speak
# 2024-04-01 10:12:53
#
# Scraped 119 users this round
# Got 167 reivews
# 379759 reviews are now in the bag, so to speak
# 2024-04-01 10:17:26
#
# Scraped 109 users this round
# Got 187 reivews
# 379946 reviews are now in the bag, so to speak
# 2024-04-01 10:21:27
#
# Scraped 110 users this round
# Got 213 reivews
# 380159 reviews are now in the bag, so to speak
# 2024-04-01 10:25:32
#
# Scraped 115 users this round
# Got 206 reivews
# 380365 reviews are now in the bag, so to speak
# 2024-04-01 10:30:16
#
# Scraped 123 users this round
# Got 174 reivews
# 380539 reviews are now in the bag, so to speak
# 2024-04-01 10:35:19
#
# Scraped 100 users this round
# Got 200 reivews
# 380739 reviews are now in the bag, so to speak
# 2024-04-01 10:39:09
#
# Scraped 105 users this round
# Got 224 reivews
# 380963 reviews are now in the bag, so to speak
# 2024-04-01 10:43:03
#
# Scraped 105 users this round
# Got 218 reivews
# 381181 reviews are now in the bag, so to speak
# 2024-04-01 10:47:03
#
# Scraped 110 users this round
# Got 197 reivews
# 381378 reviews are now in the bag, so to speak
# 2024-04-01 10:51:22
#
# Scraped 109 users this round
# Got 179 reivews
# 381557 reviews are now in the bag, so to speak
# 2024-04-01 10:55:23
#
# Scraped 106 users this round
# Got 178 reivews
# 381735 reviews are now in the bag, so to speak
# 2024-04-01 10:59:29
#
# Scraped 112 users this round
# Got 207 reivews
# 381942 reviews are now in the bag, so to speak
# 2024-04-01 11:04:04
#
# Scraped 111 users this round
# Got 150 reivews
# 382092 reviews are now in the bag, so to speak
# 2024-04-01 11:08:15
#
# Scraped 98 users this round
# Got 156 reivews
# 382248 reviews are now in the bag, so to speak
# 2024-04-01 11:12:08
#
# Scraped 105 users this round
# Got 165 reivews
# 382413 reviews are now in the bag, so to speak
# 2024-04-01 11:15:57
#
# Scraped 86 users this round
# Got 165 reivews
# 382578 reviews are now in the bag, so to speak
# 2024-04-01 11:18:58
#
# Scraped 110 users this round
# Got 211 reivews
# 382789 reviews are now in the bag, so to speak
# 2024-04-01 11:23:09
#
# Scraped 94 users this round
# Got 203 reivews
# 382992 reviews are now in the bag, so to speak
# 2024-04-01 11:26:36
#
# Scraped 108 users this round
# Got 212 reivews
# 383204 reviews are now in the bag, so to speak
# 2024-04-01 11:30:50
#
# Scraped 90 users this round
# Got 212 reivews
# 383416 reviews are now in the bag, so to speak
# 2024-04-01 11:34:09
#
# Scraped 107 users this round
# Got 209 reivews
# 383625 reviews are now in the bag, so to speak
# 2024-04-01 11:38:03
#
# Scraped 99 users this round
# Got 228 reivews
# 383853 reviews are now in the bag, so to speak
# 2024-04-01 11:41:54
#
# Scraped 99 users this round
# Got 152 reivews
# 384005 reviews are now in the bag, so to speak
# 2024-04-01 11:45:26
#
# Scraped 97 users this round
# Got 191 reivews
# 384196 reviews are now in the bag, so to speak
# 2024-04-01 11:49:00
#
# Scraped 110 users this round
# Got 172 reivews
# 384368 reviews are now in the bag, so to speak
# 2024-04-01 11:53:03
#
# Scraped 113 users this round
# Got 188 reivews
# 384556 reviews are now in the bag, so to speak
# 2024-04-01 11:57:16
#
# Scraped 101 users this round
# Got 170 reivews
# 384726 reviews are now in the bag, so to speak
# 2024-04-01 12:01:10
#
# Scraped 94 users this round
# Got 180 reivews
# 384906 reviews are now in the bag, so to speak
# 2024-04-01 12:04:43
#
# Scraped 130 users this round
# Got 189 reivews
# 385095 reviews are now in the bag, so to speak
# 2024-04-01 12:09:48
#
# Scraped 119 users this round
# Got 162 reivews
# 385257 reviews are now in the bag, so to speak
# 2024-04-01 12:14:35
#
# Scraped 110 users this round
# Got 181 reivews
# 385438 reviews are now in the bag, so to speak
# 2024-04-01 12:18:45
#
# Scraped 120 users this round
# Got 195 reivews
# 385633 reviews are now in the bag, so to speak
# 2024-04-01 12:23:21
#
# Scraped 125 users this round
# Got 184 reivews
# 385817 reviews are now in the bag, so to speak
# 2024-04-01 12:28:28
#
# Scraped 118 users this round
# Got 196 reivews
# 386013 reviews are now in the bag, so to speak
# 2024-04-01 12:33:05
#
# Scraped 105 users this round
# Got 154 reivews
# 386167 reviews are now in the bag, so to speak
# 2024-04-01 12:37:08
#
# Scraped 101 users this round
# Got 212 reivews
# 386379 reviews are now in the bag, so to speak
# 2024-04-01 12:40:39
#
# Scraped 115 users this round
# Got 175 reivews
# 386554 reviews are now in the bag, so to speak
# 2024-04-01 12:44:56
#
# Unable to parse review blocks.
# Scraped 109 users this round
# Got 203 reivews
# 386757 reviews are now in the bag, so to speak
# 2024-04-01 12:48:51
#
# Scraped 121 users this round
# Got 173 reivews
# 386930 reviews are now in the bag, so to speak
# 2024-04-01 12:53:03
#
# Scraped 127 users this round
# Got 215 reivews
# 387145 reviews are now in the bag, so to speak
# 2024-04-01 12:57:41
#
# Scraped 118 users this round
# Got 192 reivews
# 387337 reviews are now in the bag, so to speak
# 2024-04-01 13:01:59
#
# Scraped 126 users this round
# Got 169 reivews
# 387506 reviews are now in the bag, so to speak
# 2024-04-01 13:06:29
#
# Scraped 129 users this round
# Got 244 reivews
# 387750 reviews are now in the bag, so to speak
# 2024-04-01 13:11:16
#
# Unable to parse review blocks.
# Scraped 111 users this round
# Got 152 reivews
# 387902 reviews are now in the bag, so to speak
# 2024-04-01 13:15:11
#
# Scraped 106 users this round
# Got 186 reivews
# 388088 reviews are now in the bag, so to speak
# 2024-04-01 13:18:53
#
# Scraped 112 users this round
# Got 187 reivews
# 388275 reviews are now in the bag, so to speak
# 2024-04-01 13:22:53
#
# Scraped 101 users this round
# Got 144 reivews
# 388419 reviews are now in the bag, so to speak
# 2024-04-01 13:26:21
#
# Scraped 113 users this round
# Got 183 reivews
# 388602 reviews are now in the bag, so to speak
# 2024-04-01 13:30:17
#
# Scraped 120 users this round
# Got 216 reivews
# 388818 reviews are now in the bag, so to speak
# 2024-04-01 13:34:48
#
# Scraped 89 users this round
# Got 169 reivews
# 388987 reviews are now in the bag, so to speak
# 2024-04-01 13:37:44
#
# Scraped 98 users this round
# Got 167 reivews
# 389154 reviews are now in the bag, so to speak
# 2024-04-01 13:41:00
#
# Scraped 118 users this round
# Got 185 reivews
# 389339 reviews are now in the bag, so to speak
# 2024-04-01 13:45:09
#
# Scraped 112 users this round
# Got 230 reivews
# 389569 reviews are now in the bag, so to speak
# 2024-04-01 13:49:03
#
# Scraped 112 users this round
# Got 206 reivews
# 389775 reviews are now in the bag, so to speak
# 2024-04-01 13:53:08
#
# Scraped 109 users this round
# Got 201 reivews
# 389976 reviews are now in the bag, so to speak
# 2024-04-01 13:56:43
#
# Scraped 112 users this round
# Got 149 reivews
# 390125 reviews are now in the bag, so to speak
# 2024-04-01 14:00:41
#
# Scraped 102 users this round
# Got 181 reivews
# 390306 reviews are now in the bag, so to speak
# 2024-04-01 14:04:18
#
# Scraped 112 users this round
# Got 189 reivews
# 390495 reviews are now in the bag, so to speak
# 2024-04-01 14:08:25
#
# Scraped 107 users this round
# Got 163 reivews
# 390658 reviews are now in the bag, so to speak
# 2024-04-01 14:12:14
#
# Scraped 113 users this round
# Got 166 reivews
# 390824 reviews are now in the bag, so to speak
# 2024-04-01 14:16:17
#
# Scraped 102 users this round
# Got 189 reivews
# 391013 reviews are now in the bag, so to speak
# 2024-04-01 14:19:56
#
# Scraped 116 users this round
# Got 211 reivews
# 391224 reviews are now in the bag, so to speak
# 2024-04-01 14:24:04
#
# Scraped 117 users this round
# Got 189 reivews
# 391413 reviews are now in the bag, so to speak
# 2024-04-01 14:28:12
#
# Scraped 115 users this round
# Got 179 reivews
# 391592 reviews are now in the bag, so to speak
# 2024-04-01 14:32:11
#
# Scraped 107 users this round
# Got 194 reivews
# 391786 reviews are now in the bag, so to speak
# 2024-04-01 14:35:59
#
# Scraped 130 users this round
# Got 196 reivews
# 391982 reviews are now in the bag, so to speak
# 2024-04-01 14:40:35
#
# Scraped 107 users this round
# Got 164 reivews
# 392146 reviews are now in the bag, so to speak
# 2024-04-01 14:44:29
#
# Scraped 94 users this round
# Got 179 reivews
# 392325 reviews are now in the bag, so to speak
# 2024-04-01 14:47:44
#
# Scraped 102 users this round
# Got 170 reivews
# 392495 reviews are now in the bag, so to speak
# 2024-04-01 14:51:20
#
# Scraped 97 users this round
# Got 173 reivews
# 392668 reviews are now in the bag, so to speak
# 2024-04-01 14:54:42
#
# Scraped 121 users this round
# Got 164 reivews
# 392832 reviews are now in the bag, so to speak
# 2024-04-01 14:59:04
#
# Scraped 118 users this round
# Got 180 reivews
# 393012 reviews are now in the bag, so to speak
# 2024-04-01 15:03:12
#
# Scraped 118 users this round
# Got 209 reivews
# 393221 reviews are now in the bag, so to speak
# 2024-04-01 15:08:06
#
# Scraped 124 users this round
# Got 217 reivews
# 393438 reviews are now in the bag, so to speak
# 2024-04-01 15:12:34
#
# Scraped 106 users this round
# Got 188 reivews
# 393626 reviews are now in the bag, so to speak
# 2024-04-01 15:16:16
#
# Scraped 103 users this round
# Got 196 reivews
# 393822 reviews are now in the bag, so to speak
# 2024-04-01 15:19:46
#
# Scraped 107 users this round
# Got 140 reivews
# 393962 reviews are now in the bag, so to speak
# 2024-04-01 15:23:32
#
# Scraped 97 users this round
# Got 167 reivews
# 394129 reviews are now in the bag, so to speak
# 2024-04-01 15:26:45
#
# Scraped 111 users this round
# Got 192 reivews
# 394321 reviews are now in the bag, so to speak
# 2024-04-01 15:30:41
#
# Scraped 100 users this round
# Got 206 reivews
# 394527 reviews are now in the bag, so to speak
# 2024-04-01 15:34:08
#
# Scraped 126 users this round
# Got 186 reivews
# 394713 reviews are now in the bag, so to speak
# 2024-04-01 15:38:36
#
# Scraped 87 users this round
# Got 203 reivews
# 394916 reviews are now in the bag, so to speak
# 2024-04-01 15:41:34
#
# Scraped 110 users this round
# Got 194 reivews
# 395110 reviews are now in the bag, so to speak
# 2024-04-01 15:45:30
#
# Scraped 101 users this round
# Got 185 reivews
# 395295 reviews are now in the bag, so to speak
# 2024-04-01 15:49:07
#
# Scraped 98 users this round
# Got 169 reivews
# 395464 reviews are now in the bag, so to speak
# 2024-04-01 15:52:29
#
# Scraped 126 users this round
# Got 201 reivews
# 395665 reviews are now in the bag, so to speak
# 2024-04-01 15:56:53
#
# Scraped 108 users this round
# Got 221 reivews
# 395886 reviews are now in the bag, so to speak
# 2024-04-01 16:00:35
#
# Scraped 109 users this round
# Got 193 reivews
# 396079 reviews are now in the bag, so to speak
# 2024-04-01 16:04:18
#
# Scraped 130 users this round
# Got 205 reivews
# 396284 reviews are now in the bag, so to speak
# 2024-04-01 16:09:10
#
# Scraped 104 users this round
# Got 178 reivews
# 396462 reviews are now in the bag, so to speak
# 2024-04-01 16:12:58
#
# Scraped 112 users this round
# Got 219 reivews
# 396681 reviews are now in the bag, so to speak
# 2024-04-01 16:17:02
#
# Scraped 114 users this round
# Got 205 reivews
# 396886 reviews are now in the bag, so to speak
# 2024-04-01 16:21:03
#
# Scraped 106 users this round
# Got 193 reivews
# 397079 reviews are now in the bag, so to speak
# 2024-04-01 16:24:42
#
# Scraped 121 users this round
# Got 177 reivews
# 397256 reviews are now in the bag, so to speak
# 2024-04-01 16:29:11
#
# Scraped 110 users this round
# Got 155 reivews
# 397411 reviews are now in the bag, so to speak
# 2024-04-01 16:32:59
#
# Scraped 124 users this round
# Got 200 reivews
# 397611 reviews are now in the bag, so to speak
# 2024-04-01 16:37:20
#
# Scraped 117 users this round
# Got 194 reivews
# 397805 reviews are now in the bag, so to speak
# 2024-04-01 16:41:31
#
# Scraped 86 users this round
# Got 226 reivews
# 398031 reviews are now in the bag, so to speak
# 2024-04-01 16:44:32
#
# Scraped 98 users this round
# Got 189 reivews
# 398220 reviews are now in the bag, so to speak
# 2024-04-01 16:47:52
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 119 users this round
# Got 190 reivews
# 398410 reviews are now in the bag, so to speak
# 2024-04-01 16:52:01
#
# Scraped 107 users this round
# Got 177 reivews
# 398587 reviews are now in the bag, so to speak
# 2024-04-01 16:55:41
#
# Scraped 119 users this round
# Got 168 reivews
# 398755 reviews are now in the bag, so to speak
# 2024-04-01 17:00:05
#
# Scraped 101 users this round
# Got 186 reivews
# 398941 reviews are now in the bag, so to speak
# 2024-04-01 17:03:43
#
# Scraped 92 users this round
# Got 229 reivews
# 399170 reviews are now in the bag, so to speak
# 2024-04-01 17:06:40
#
# Scraped 112 users this round
# Got 196 reivews
# 399366 reviews are now in the bag, so to speak
# 2024-04-01 17:10:30
#
# Scraped 107 users this round
# Got 192 reivews
# 399558 reviews are now in the bag, so to speak
# 2024-04-01 17:14:17
#
# Scraped 114 users this round
# Got 203 reivews
# 399761 reviews are now in the bag, so to speak
# 2024-04-01 17:18:16
#
# Scraped 141 users this round
# Got 186 reivews
# 399947 reviews are now in the bag, so to speak
# 2024-04-01 17:23:55
#
# Scraped 104 users this round
# Got 194 reivews
# 400141 reviews are now in the bag, so to speak
# 2024-04-01 17:27:46
#
# Scraped 112 users this round
# Got 249 reivews
# 400390 reviews are now in the bag, so to speak
# 2024-04-01 17:31:45
#
# Scraped 122 users this round
# Got 193 reivews
# 400583 reviews are now in the bag, so to speak
# 2024-04-01 17:36:05
#
# Scraped 93 users this round
# Got 183 reivews
# 400766 reviews are now in the bag, so to speak
# 2024-04-01 17:39:20
#
# Scraped 114 users this round
# Got 213 reivews
# 400979 reviews are now in the bag, so to speak
# 2024-04-01 17:43:21
#
# Scraped 117 users this round
# Got 213 reivews
# 401192 reviews are now in the bag, so to speak
# 2024-04-01 17:47:38
#
# Scraped 100 users this round
# Got 163 reivews
# 401355 reviews are now in the bag, so to speak
# 2024-04-01 17:50:53
#
# Scraped 112 users this round
# Got 179 reivews
# 401534 reviews are now in the bag, so to speak
# 2024-04-01 17:54:50
#
# Scraped 92 users this round
# Got 177 reivews
# 401711 reviews are now in the bag, so to speak
# 2024-04-01 17:58:03
#
# Scraped 94 users this round
# Got 189 reivews
# 401900 reviews are now in the bag, so to speak
# 2024-04-01 18:01:06
#
# Scraped 128 users this round
# Got 213 reivews
# 402113 reviews are now in the bag, so to speak
# 2024-04-01 18:05:39
#
# Scraped 106 users this round
# Got 143 reivews
# 402256 reviews are now in the bag, so to speak
# 2024-04-01 18:09:30
#
# Scraped 127 users this round
# Got 165 reivews
# 402421 reviews are now in the bag, so to speak
# 2024-04-01 18:14:05
#
# Scraped 82 users this round
# Got 161 reivews
# 402582 reviews are now in the bag, so to speak
# 2024-04-01 18:16:45
#
# Scraped 124 users this round
# Got 183 reivews
# 402765 reviews are now in the bag, so to speak
# 2024-04-01 18:21:16
#
# Scraped 109 users this round
# Got 204 reivews
# 402969 reviews are now in the bag, so to speak
# 2024-04-01 18:25:00
#
# Scraped 99 users this round
# Got 165 reivews
# 403134 reviews are now in the bag, so to speak
# 2024-04-01 18:28:25
#
# Scraped 109 users this round
# Got 204 reivews
# 403338 reviews are now in the bag, so to speak
# 2024-04-01 18:32:18
#
# Scraped 101 users this round
# Got 197 reivews
# 403535 reviews are now in the bag, so to speak
# 2024-04-01 18:35:48
#
# Scraped 103 users this round
# Got 195 reivews
# 403730 reviews are now in the bag, so to speak
# 2024-04-01 18:39:11
#
# Scraped 130 users this round
# Got 171 reivews
# 403901 reviews are now in the bag, so to speak
# 2024-04-01 18:43:47
#
# Scraped 108 users this round
# Got 202 reivews
# 404103 reviews are now in the bag, so to speak
# 2024-04-01 18:47:30
#
# Scraped 135 users this round
# Got 182 reivews
# 404285 reviews are now in the bag, so to speak
# 2024-04-01 18:52:22
#
# Scraped 134 users this round
# Got 188 reivews
# 404473 reviews are now in the bag, so to speak
# 2024-04-01 18:57:18
#
# Scraped 98 users this round
# Got 174 reivews
# 404647 reviews are now in the bag, so to speak
# 2024-04-01 19:00:43
#
# Scraped 116 users this round
# Got 186 reivews
# 404833 reviews are now in the bag, so to speak
# 2024-04-01 19:04:55
#
# Scraped 99 users this round
# Got 155 reivews
# 404988 reviews are now in the bag, so to speak
# 2024-04-01 19:08:16
#
# Scraped 100 users this round
# Got 190 reivews
# 405178 reviews are now in the bag, so to speak
# 2024-04-01 19:11:35
#
# Scraped 108 users this round
# Got 188 reivews
# 405366 reviews are now in the bag, so to speak
# 2024-04-01 19:15:07
#
# Scraped 105 users this round
# Got 151 reivews
# 405517 reviews are now in the bag, so to speak
# 2024-04-01 19:18:39
#
# Scraped 134 users this round
# Got 218 reivews
# 405735 reviews are now in the bag, so to speak
# 2024-04-01 19:23:40
#
# Scraped 115 users this round
# Got 165 reivews
# 405900 reviews are now in the bag, so to speak
# 2024-04-01 19:27:49
#
# Scraped 111 users this round
# Got 213 reivews
# 406113 reviews are now in the bag, so to speak
# 2024-04-01 19:31:53
#
# Scraped 111 users this round
# Got 162 reivews
# 406275 reviews are now in the bag, so to speak
# 2024-04-01 19:35:36
#
# Scraped 91 users this round
# Got 243 reivews
# 406518 reviews are now in the bag, so to speak
# 2024-04-01 19:38:33
#
# Scraped 114 users this round
# Got 241 reivews
# 406759 reviews are now in the bag, so to speak
# 2024-04-01 19:42:47
#
# Scraped 131 users this round
# Got 201 reivews
# 406960 reviews are now in the bag, so to speak
# 2024-04-01 19:47:26
#
# Scraped 108 users this round
# Got 187 reivews
# 407147 reviews are now in the bag, so to speak
# 2024-04-01 19:51:20
#
# Scraped 112 users this round
# Got 187 reivews
# 407334 reviews are now in the bag, so to speak
# 2024-04-01 19:55:12
#
# Scraped 114 users this round
# Got 202 reivews
# 407536 reviews are now in the bag, so to speak
# 2024-04-01 19:59:17
#
# Scraped 114 users this round
# Got 173 reivews
# 407709 reviews are now in the bag, so to speak
# 2024-04-01 20:03:47
#
# Scraped 106 users this round
# Got 217 reivews
# 407926 reviews are now in the bag, so to speak
# 2024-04-01 20:07:54
#
# Scraped 106 users this round
# Got 193 reivews
# 408119 reviews are now in the bag, so to speak
# 2024-04-01 20:14:16
#
# Scraped 110 users this round
# Got 199 reivews
# 408318 reviews are now in the bag, so to speak
# 2024-04-01 20:21:39
#
# Scraped 114 users this round
# Got 160 reivews
# 408478 reviews are now in the bag, so to speak
# 2024-04-01 20:29:30
#
# Scraped 107 users this round
# Got 160 reivews
# 408638 reviews are now in the bag, so to speak
# 2024-04-01 20:35:12
#
# Scraped 106 users this round
# Got 207 reivews
# 408845 reviews are now in the bag, so to speak
# 2024-04-01 20:41:14
#
# Scraped 83 users this round
# Got 198 reivews
# 409043 reviews are now in the bag, so to speak
# 2024-04-01 20:45:41
#
# Scraped 122 users this round
# Got 151 reivews
# 409194 reviews are now in the bag, so to speak
# 2024-04-01 20:52:41
#
# Scraped 118 users this round
# Got 176 reivews
# 409370 reviews are now in the bag, so to speak
# 2024-04-01 21:00:30
#
# Scraped 114 users this round
# Got 160 reivews
# 409530 reviews are now in the bag, so to speak
# 2024-04-01 21:07:29
#
# Scraped 110 users this round
# Got 204 reivews
# 409734 reviews are now in the bag, so to speak
# 2024-04-01 21:14:00
#
# Scraped 113 users this round
# Got 198 reivews
# 409932 reviews are now in the bag, so to speak
# 2024-04-01 21:21:02
#
# Scraped 114 users this round
# Got 165 reivews
# 410097 reviews are now in the bag, so to speak
# 2024-04-01 21:27:51
#
# Scraped 109 users this round
# Got 205 reivews
# 410302 reviews are now in the bag, so to speak
# 2024-04-01 21:34:29
#
# Scraped 103 users this round
# Got 238 reivews
# 410540 reviews are now in the bag, so to speak
# 2024-04-01 21:40:56
#
# Scraped 120 users this round
# Got 167 reivews
# 410707 reviews are now in the bag, so to speak
# 2024-04-01 21:48:20
#
# Scraped 117 users this round
# Got 224 reivews
# 410931 reviews are now in the bag, so to speak
# 2024-04-01 21:55:32
#
# Scraped 109 users this round
# Got 204 reivews
# 411135 reviews are now in the bag, so to speak
# 2024-04-01 22:02:20
#
# Scraped 129 users this round
# Got 170 reivews
# 411305 reviews are now in the bag, so to speak
# 2024-04-01 22:11:04
#
# Scraped 88 users this round
# Got 175 reivews
# 411480 reviews are now in the bag, so to speak
# 2024-04-01 22:16:01
#
# Scraped 107 users this round
# Got 182 reivews
# 411662 reviews are now in the bag, so to speak
# 2024-04-01 22:22:03
#
# Scraped 113 users this round
# Got 181 reivews
# 411843 reviews are now in the bag, so to speak
# 2024-04-01 22:29:13
#
# Scraped 96 users this round
# Got 154 reivews
# 411997 reviews are now in the bag, so to speak
# 2024-04-01 22:34:29
#
# Scraped 108 users this round
# Got 207 reivews
# 412204 reviews are now in the bag, so to speak
# 2024-04-01 22:40:35
#
# Scraped 99 users this round
# Got 191 reivews
# 412395 reviews are now in the bag, so to speak
# 2024-04-01 22:45:35
#
# Scraped 105 users this round
# Got 162 reivews
# 412557 reviews are now in the bag, so to speak
# 2024-04-01 22:51:04
#
# Scraped 121 users this round
# Got 188 reivews
# 412745 reviews are now in the bag, so to speak
# 2024-04-01 22:57:24
#
# Scraped 121 users this round
# Got 174 reivews
# 412919 reviews are now in the bag, so to speak
# 2024-04-01 23:03:45
#
# Scraped 97 users this round
# Got 253 reivews
# 413172 reviews are now in the bag, so to speak
# 2024-04-01 23:08:30
#
# Scraped 131 users this round
# Got 199 reivews
# 413371 reviews are now in the bag, so to speak
# 2024-04-01 23:14:14
#
# Scraped 124 users this round
# Got 172 reivews
# 413543 reviews are now in the bag, so to speak
# 2024-04-01 23:18:51
#
# Scraped 110 users this round
# Got 229 reivews
# 413772 reviews are now in the bag, so to speak
# 2024-04-01 23:23:04
#
# Scraped 96 users this round
# Got 181 reivews
# 413953 reviews are now in the bag, so to speak
# 2024-04-01 23:26:28
#
# Scraped 123 users this round
# Got 220 reivews
# 414173 reviews are now in the bag, so to speak
# 2024-04-01 23:31:08
#
# Scraped 88 users this round
# Got 197 reivews
# 414370 reviews are now in the bag, so to speak
# 2024-04-01 23:34:22
#
# Scraped 105 users this round
# Got 229 reivews
# 414599 reviews are now in the bag, so to speak
# 2024-04-01 23:38:17
#
# Scraped 112 users this round
# Got 189 reivews
# 414788 reviews are now in the bag, so to speak
# 2024-04-01 23:42:10
#
# Scraped 103 users this round
# Got 199 reivews
# 414987 reviews are now in the bag, so to speak
# 2024-04-01 23:45:46
#
# Scraped 113 users this round
# Got 174 reivews
# 415161 reviews are now in the bag, so to speak
# 2024-04-01 23:50:22
#
# Scraped 106 users this round
# Got 201 reivews
# 415362 reviews are now in the bag, so to speak
# 2024-04-01 23:54:13
#
# Scraped 139 users this round
# Got 234 reivews
# 415596 reviews are now in the bag, so to speak
# 2024-04-01 23:59:19
#
# Scraped 112 users this round
# Got 188 reivews
# 415784 reviews are now in the bag, so to speak
# 2024-04-02 00:03:27
#
# Scraped 108 users this round
# Got 177 reivews
# 415961 reviews are now in the bag, so to speak
# 2024-04-02 00:07:26
#
# Scraped 99 users this round
# Got 163 reivews
# 416124 reviews are now in the bag, so to speak
# 2024-04-02 00:10:55
#
# Scraped 104 users this round
# Got 218 reivews
# 416342 reviews are now in the bag, so to speak
# 2024-04-02 00:15:11
#
# Scraped 96 users this round
# Got 180 reivews
# 416522 reviews are now in the bag, so to speak
# 2024-04-02 00:18:52
#
# Scraped 95 users this round
# Got 191 reivews
# 416713 reviews are now in the bag, so to speak
# 2024-04-02 00:22:01
#
# Scraped 107 users this round
# Got 176 reivews
# 416889 reviews are now in the bag, so to speak
# 2024-04-02 00:25:42
#
# Scraped 109 users this round
# Got 180 reivews
# 417069 reviews are now in the bag, so to speak
# 2024-04-02 00:29:35
#
# Scraped 92 users this round
# Got 198 reivews
# 417267 reviews are now in the bag, so to speak
# 2024-04-02 00:32:38
#
# Scraped 106 users this round
# Got 195 reivews
# 417462 reviews are now in the bag, so to speak
# 2024-04-02 00:36:22
#
# Scraped 122 users this round
# Got 207 reivews
# 417669 reviews are now in the bag, so to speak
# 2024-04-02 00:40:54
#
# Scraped 108 users this round
# Got 221 reivews
# 417890 reviews are now in the bag, so to speak
# 2024-04-02 00:44:37
#
# Scraped 109 users this round
# Got 196 reivews
# 418086 reviews are now in the bag, so to speak
# 2024-04-02 00:48:34
#
# Scraped 104 users this round
# Got 224 reivews
# 418310 reviews are now in the bag, so to speak
# 2024-04-02 00:52:22
#
# Scraped 143 users this round
# Got 215 reivews
# 418525 reviews are now in the bag, so to speak
# 2024-04-02 00:58:06
#
# Scraped 98 users this round
# Got 175 reivews
# 418700 reviews are now in the bag, so to speak
# 2024-04-02 01:01:35
#
# Scraped 115 users this round
# Got 162 reivews
# 418862 reviews are now in the bag, so to speak
# 2024-04-02 01:05:40
#
# Scraped 106 users this round
# Got 220 reivews
# 419082 reviews are now in the bag, so to speak
# 2024-04-02 01:09:40
#
# Scraped 112 users this round
# Got 230 reivews
# 419312 reviews are now in the bag, so to speak
# 2024-04-02 01:14:03
#
# Scraped 115 users this round
# Got 170 reivews
# 419482 reviews are now in the bag, so to speak
# 2024-04-02 01:18:15
#
# Scraped 107 users this round
# Got 185 reivews
# 419667 reviews are now in the bag, so to speak
# 2024-04-02 01:22:06
#
# Scraped 98 users this round
# Got 169 reivews
# 419836 reviews are now in the bag, so to speak
# 2024-04-02 01:25:33
#
# Scraped 116 users this round
# Got 174 reivews
# ...
# 479502 reviews are now in the bag, so to speak
# 2024-04-02 23:20:06
#
# Scraped 140 users this round
# Got 173 reivews
# 479675 reviews are now in the bag, so to speak
# 2024-04-02 23:30:04
#
# Scraped 105 users this round
# Got 201 reivews
# 479876 reviews are now in the bag, so to speak
# 2024-04-02 23:37:15
#
# Scraped 128 users this round
# Got 187 reivews
# 480063 reviews are now in the bag, so to speak
# 2024-04-02 23:43:23
#
# Scraped 108 users this round
# Got 141 reivews
# 480204 reviews are now in the bag, so to speak
# 2024-04-02 23:47:27
#
# Scraped 123 users this round
# Got 196 reivews
# 480400 reviews are now in the bag, so to speak
# 2024-04-02 23:51:42
#
# Scraped 109 users this round
# Got 183 reivews
# 480583 reviews are now in the bag, so to speak
# 2024-04-02 23:55:34
#
# Scraped 126 users this round
# Got 194 reivews
# 480777 reviews are now in the bag, so to speak
# 2024-04-03 00:00:34
#
# Scraped 123 users this round
# Got 229 reivews
# 481006 reviews are now in the bag, so to speak
# 2024-04-03 00:05:00
#
# Scraped 120 users this round
# Got 207 reivews
# 481213 reviews are now in the bag, so to speak
# 2024-04-03 00:09:13
#
# Scraped 102 users this round
# Got 174 reivews
# 481387 reviews are now in the bag, so to speak
# 2024-04-03 00:12:55
#
# Scraped 91 users this round
# Got 197 reivews
# 481584 reviews are now in the bag, so to speak
# 2024-04-03 00:16:07
#
# Scraped 109 users this round
# Got 179 reivews
# 481763 reviews are now in the bag, so to speak
# 2024-04-03 00:19:49
#
# Scraped 95 users this round
# Got 238 reivews
# 482001 reviews are now in the bag, so to speak
# 2024-04-03 00:23:05
#
# Scraped 129 users this round
# Got 231 reivews
# 482232 reviews are now in the bag, so to speak
# 2024-04-03 00:27:34
#
# Scraped 102 users this round
# Got 184 reivews
# 482416 reviews are now in the bag, so to speak
# 2024-04-03 00:31:03
#
# Scraped 109 users this round
# Got 229 reivews
# 482645 reviews are now in the bag, so to speak
# 2024-04-03 00:34:50
#
# Scraped 121 users this round
# Got 158 reivews
# 482803 reviews are now in the bag, so to speak
# 2024-04-03 00:39:12
#
# Scraped 111 users this round
# Got 211 reivews
# 483014 reviews are now in the bag, so to speak
# 2024-04-03 00:42:55
#
# Scraped 111 users this round
# Got 218 reivews
# 483232 reviews are now in the bag, so to speak
# 2024-04-03 00:46:37
#
# Scraped 105 users this round
# Got 207 reivews
# 483439 reviews are now in the bag, so to speak
# 2024-04-03 00:50:32
#
# Scraped 105 users this round
# Got 160 reivews
# 483599 reviews are now in the bag, so to speak
# 2024-04-03 00:54:11
#
# Scraped 126 users this round
# Got 174 reivews
# 483773 reviews are now in the bag, so to speak
# 2024-04-03 00:58:56
#
# Scraped 115 users this round
# Got 182 reivews
# 483955 reviews are now in the bag, so to speak
# 2024-04-03 01:02:41
#
# Scraped 100 users this round
# Got 180 reivews
# 484135 reviews are now in the bag, so to speak
# 2024-04-03 01:05:55
#
# Scraped 110 users this round
# Got 193 reivews
# 484328 reviews are now in the bag, so to speak
# 2024-04-03 01:09:40
#
# Scraped 116 users this round
# Got 198 reivews
# 484526 reviews are now in the bag, so to speak
# 2024-04-03 01:13:40
#
# Scraped 119 users this round
# Got 164 reivews
# 484690 reviews are now in the bag, so to speak
# 2024-04-03 01:17:47
#
# Scraped 115 users this round
# Got 178 reivews
# 484868 reviews are now in the bag, so to speak
# 2024-04-03 01:21:33
#
# Scraped 97 users this round
# Got 202 reivews
# 485070 reviews are now in the bag, so to speak
# 2024-04-03 01:24:45
#
# Scraped 104 users this round
# Got 195 reivews
# 485265 reviews are now in the bag, so to speak
# 2024-04-03 01:28:17
#
# Scraped 93 users this round
# Got 178 reivews
# 485443 reviews are now in the bag, so to speak
# 2024-04-03 01:31:26
#
# Scraped 106 users this round
# Got 171 reivews
# 485614 reviews are now in the bag, so to speak
# 2024-04-03 01:34:53
#
# Scraped 132 users this round
# Got 157 reivews
# 485771 reviews are now in the bag, so to speak
# 2024-04-03 01:39:17
#
# Scraped 113 users this round
# Got 159 reivews
# 485930 reviews are now in the bag, so to speak
# 2024-04-03 01:42:50
#
# Scraped 109 users this round
# Got 167 reivews
# 486097 reviews are now in the bag, so to speak
# 2024-04-03 01:46:23
#
# Scraped 109 users this round
# Got 145 reivews
# 486242 reviews are now in the bag, so to speak
# 2024-04-03 01:49:52
#
# Scraped 111 users this round
# Got 152 reivews
# 486394 reviews are now in the bag, so to speak
# 2024-04-03 01:53:27
#
# Scraped 112 users this round
# Got 168 reivews
# 486562 reviews are now in the bag, so to speak
# 2024-04-03 01:57:04
#
# Scraped 120 users this round
# Got 164 reivews
# 486726 reviews are now in the bag, so to speak
# 2024-04-03 02:01:02
#
# Scraped 111 users this round
# Got 195 reivews
# 486921 reviews are now in the bag, so to speak
# 2024-04-03 02:04:48
#
# Scraped 111 users this round
# Got 167 reivews
# 487088 reviews are now in the bag, so to speak
# 2024-04-03 02:08:47
#
# Scraped 95 users this round
# Got 187 reivews
# 487275 reviews are now in the bag, so to speak
# 2024-04-03 02:11:53
#
# Scraped 103 users this round
# Got 195 reivews
# 487470 reviews are now in the bag, so to speak
# 2024-04-03 02:15:22
#
# Scraped 110 users this round
# Got 161 reivews
# 487631 reviews are now in the bag, so to speak
# 2024-04-03 02:19:13
#
# Scraped 144 users this round
# Got 159 reivews
# 487790 reviews are now in the bag, so to speak
# 2024-04-03 02:24:01
#
# Scraped 96 users this round
# Got 175 reivews
# 487965 reviews are now in the bag, so to speak
# 2024-04-03 02:26:54
#
# Scraped 96 users this round
# Got 227 reivews
# 488192 reviews are now in the bag, so to speak
# 2024-04-03 02:30:03
#
# Scraped 99 users this round
# Got 221 reivews
# 488413 reviews are now in the bag, so to speak
# 2024-04-03 02:33:22
#
# Scraped 110 users this round
# Got 169 reivews
# 488582 reviews are now in the bag, so to speak
# 2024-04-03 02:36:58
#
# Scraped 120 users this round
# Got 163 reivews
# 488745 reviews are now in the bag, so to speak
# 2024-04-03 02:40:58
#
# Scraped 108 users this round
# Got 207 reivews
# 488952 reviews are now in the bag, so to speak
# 2024-04-03 02:44:48
#
# Scraped 101 users this round
# Got 169 reivews
# 489121 reviews are now in the bag, so to speak
# 2024-04-03 02:47:58
#
# Scraped 121 users this round
# Got 177 reivews
# 489298 reviews are now in the bag, so to speak
# 2024-04-03 02:51:57
#
# Scraped 95 users this round
# Got 206 reivews
# 489504 reviews are now in the bag, so to speak
# 2024-04-03 02:54:53
#
# Scraped 139 users this round
# Got 156 reivews
# 489660 reviews are now in the bag, so to speak
# 2024-04-03 02:59:30
#
# Scraped 114 users this round
# Got 242 reivews
# 489902 reviews are now in the bag, so to speak
# 2024-04-03 03:03:13
#
# Scraped 103 users this round
# Got 184 reivews
# 490086 reviews are now in the bag, so to speak
# 2024-04-03 03:06:40
#
# Scraped 106 users this round
# Got 191 reivews
# 490277 reviews are now in the bag, so to speak
# 2024-04-03 03:10:03
#
# Scraped 118 users this round
# Got 187 reivews
# 490464 reviews are now in the bag, so to speak
# 2024-04-03 03:13:58
#
# Scraped 125 users this round
# Got 194 reivews
# 490658 reviews are now in the bag, so to speak
# 2024-04-03 03:18:08
#
# Scraped 112 users this round
# Got 195 reivews
# 490853 reviews are now in the bag, so to speak
# 2024-04-03 03:21:42
#
# Scraped 101 users this round
# Got 221 reivews
# 491074 reviews are now in the bag, so to speak
# 2024-04-03 03:24:58
#
# Scraped 100 users this round
# Got 173 reivews
# 491247 reviews are now in the bag, so to speak
# 2024-04-03 03:28:18
#
# Scraped 118 users this round
# Got 166 reivews
# 491413 reviews are now in the bag, so to speak
# 2024-04-03 03:32:44
#
# Scraped 97 users this round
# Got 175 reivews
# 491588 reviews are now in the bag, so to speak
# 2024-04-03 03:36:08
#
# Scraped 119 users this round
# Got 160 reivews
# 491748 reviews are now in the bag, so to speak
# 2024-04-03 03:40:00
#
# Scraped 112 users this round
# Got 177 reivews
# 491925 reviews are now in the bag, so to speak
# 2024-04-03 03:43:39
#
# Scraped 114 users this round
# Got 187 reivews
# 492112 reviews are now in the bag, so to speak
# 2024-04-03 03:47:27
#
# Scraped 108 users this round
# Got 165 reivews
# 492277 reviews are now in the bag, so to speak
# 2024-04-03 03:51:18
#
# Scraped 119 users this round
# Got 218 reivews
# 492495 reviews are now in the bag, so to speak
# 2024-04-03 03:55:17
#
# Scraped 93 users this round
# Got 195 reivews
# 492690 reviews are now in the bag, so to speak
# 2024-04-03 03:58:25
#
# Scraped 115 users this round
# Got 159 reivews
# 492849 reviews are now in the bag, so to speak
# 2024-04-03 04:02:15
#
# Scraped 111 users this round
# Got 157 reivews
# 493006 reviews are now in the bag, so to speak
# 2024-04-03 04:05:50
#
# Scraped 121 users this round
# Got 190 reivews
# 493196 reviews are now in the bag, so to speak
# 2024-04-03 04:10:07
#
# Scraped 112 users this round
# Got 187 reivews
# 493383 reviews are now in the bag, so to speak
# 2024-04-03 04:14:18
#
# Scraped 105 users this round
# Got 204 reivews
# 493587 reviews are now in the bag, so to speak
# 2024-04-03 04:17:51
#
# Scraped 109 users this round
# Got 166 reivews
# 493753 reviews are now in the bag, so to speak
# 2024-04-03 04:21:31
#
# Scraped 117 users this round
# Got 181 reivews
# 493934 reviews are now in the bag, so to speak
# 2024-04-03 04:25:24
#
# Scraped 118 users this round
# Got 201 reivews
# 494135 reviews are now in the bag, so to speak
# 2024-04-03 04:29:39
#
# Scraped 113 users this round
# Got 162 reivews
# 494297 reviews are now in the bag, so to speak
# 2024-04-03 04:33:32
#
# Scraped 104 users this round
# Got 179 reivews
# 494476 reviews are now in the bag, so to speak
# 2024-04-03 04:36:43
#
# Scraped 105 users this round
# Got 225 reivews
# 494701 reviews are now in the bag, so to speak
# 2024-04-03 04:40:24
#
# Scraped 89 users this round
# Got 164 reivews
# 494865 reviews are now in the bag, so to speak
# 2024-04-03 04:43:15
#
# Scraped 112 users this round
# Got 225 reivews
# 495090 reviews are now in the bag, so to speak
# 2024-04-03 04:47:17
#
# Scraped 108 users this round
# Got 188 reivews
# 495278 reviews are now in the bag, so to speak
# 2024-04-03 04:51:02
#
# Scraped 137 users this round
# Got 199 reivews
# 495477 reviews are now in the bag, so to speak
# 2024-04-03 04:55:38
#
# Scraped 100 users this round
# Got 249 reivews
# 495726 reviews are now in the bag, so to speak
# 2024-04-03 04:58:59
#
# Scraped 129 users this round
# Got 147 reivews
# 495873 reviews are now in the bag, so to speak
# 2024-04-03 05:03:26
#
# Scraped 94 users this round
# Got 207 reivews
# 496080 reviews are now in the bag, so to speak
# 2024-04-03 05:06:43
#
# Scraped 97 users this round
# Got 163 reivews
# 496243 reviews are now in the bag, so to speak
# 2024-04-03 05:09:41
#
# Scraped 116 users this round
# Got 199 reivews
# 496442 reviews are now in the bag, so to speak
# 2024-04-03 05:13:51
#
# Scraped 92 users this round
# Got 154 reivews
# 496596 reviews are now in the bag, so to speak
# 2024-04-03 05:16:47
#
# Scraped 101 users this round
# Got 199 reivews
# 496795 reviews are now in the bag, so to speak
# 2024-04-03 05:20:12
#
# Scraped 113 users this round
# Got 214 reivews
# 497009 reviews are now in the bag, so to speak
# 2024-04-03 05:23:49
#
# Scraped 123 users this round
# Got 176 reivews
# 497185 reviews are now in the bag, so to speak
# 2024-04-03 05:28:18
#
# Scraped 138 users this round
# Got 181 reivews
# 497366 reviews are now in the bag, so to speak
# 2024-04-03 05:33:31
#
# Scraped 100 users this round
# Got 140 reivews
# 497506 reviews are now in the bag, so to speak
# 2024-04-03 05:36:33
#
# Scraped 110 users this round
# Got 199 reivews
# 497705 reviews are now in the bag, so to speak
# 2024-04-03 05:40:16
#
# Scraped 98 users this round
# Got 199 reivews
# 497904 reviews are now in the bag, so to speak
# 2024-04-03 05:43:32
#
# Scraped 111 users this round
# Got 203 reivews
# 498107 reviews are now in the bag, so to speak
# 2024-04-03 05:47:19
#
# Scraped 109 users this round
# Got 207 reivews
# 498314 reviews are now in the bag, so to speak
# 2024-04-03 05:50:53
#
# Scraped 108 users this round
# Got 166 reivews
# 498480 reviews are now in the bag, so to speak
# 2024-04-03 05:54:25
#
# Scraped 99 users this round
# Got 179 reivews
# 498659 reviews are now in the bag, so to speak
# 2024-04-03 05:57:31
#
# Scraped 94 users this round
# Got 189 reivews
# 498848 reviews are now in the bag, so to speak
# 2024-04-03 06:00:46
#
# Scraped 132 users this round
# Got 152 reivews
# 499000 reviews are now in the bag, so to speak
# 2024-04-03 06:05:13
#
# Scraped 121 users this round
# Got 164 reivews
# 499164 reviews are now in the bag, so to speak
# 2024-04-03 06:09:25
#
# Scraped 98 users this round
# Got 205 reivews
# 499369 reviews are now in the bag, so to speak
# 2024-04-03 06:12:42
#
# Scraped 113 users this round
# Got 195 reivews
# 499564 reviews are now in the bag, so to speak
# 2024-04-03 06:16:26
#
# Scraped 95 users this round
# Got 164 reivews
# 499728 reviews are now in the bag, so to speak
# 2024-04-03 06:19:43
#
# Scraped 102 users this round
# Got 194 reivews
# 499922 reviews are now in the bag, so to speak
# 2024-04-03 06:23:25
#
# Scraped 116 users this round
# Got 190 reivews
# 500112 reviews are now in the bag, so to speak
# 2024-04-03 06:27:20
#
# Scraped 88 users this round
# Got 171 reivews
# 500283 reviews are now in the bag, so to speak
# 2024-04-03 06:30:08
#
# Scraped 132 users this round
# Got 163 reivews
# 500446 reviews are now in the bag, so to speak
# 2024-04-03 06:35:11
#
# Scraped 117 users this round
# Got 203 reivews
# 500649 reviews are now in the bag, so to speak
# 2024-04-03 06:39:22
#
# Scraped 88 users this round
# Got 149 reivews
# 500798 reviews are now in the bag, so to speak
# 2024-04-03 06:42:10
#
# Scraped 112 users this round
# Got 174 reivews
# 500972 reviews are now in the bag, so to speak
# 2024-04-03 06:45:57
#
# Scraped 105 users this round
# Got 191 reivews
# 501163 reviews are now in the bag, so to speak
# 2024-04-03 06:49:21
#
# Scraped 103 users this round
# Got 182 reivews
# 501345 reviews are now in the bag, so to speak
# 2024-04-03 06:52:39
#
# Scraped 95 users this round
# Got 217 reivews
# 501562 reviews are now in the bag, so to speak
# 2024-04-03 06:56:03
#
# Scraped 109 users this round
# Got 175 reivews
# 501737 reviews are now in the bag, so to speak
# 2024-04-03 06:59:23
#
# Scraped 126 users this round
# Got 194 reivews
# 501931 reviews are now in the bag, so to speak
# 2024-04-03 07:03:41
#
# Scraped 102 users this round
# Got 152 reivews
# 502083 reviews are now in the bag, so to speak
# 2024-04-03 07:07:08
#
# Scraped 120 users this round
# Got 208 reivews
# 502291 reviews are now in the bag, so to speak
# 2024-04-03 07:11:10
#
# Scraped 90 users this round
# Got 210 reivews
# 502501 reviews are now in the bag, so to speak
# 2024-04-03 07:14:10
#
# Scraped 129 users this round
# Got 168 reivews
# 502669 reviews are now in the bag, so to speak
# 2024-04-03 07:19:33
#
# Scraped 92 users this round
# Got 202 reivews
# 502871 reviews are now in the bag, so to speak
# 2024-04-03 07:22:44
#
# Scraped 115 users this round
# Got 196 reivews
# 503067 reviews are now in the bag, so to speak
# 2024-04-03 07:26:49
#
# Scraped 93 users this round
# Got 237 reivews
# 503304 reviews are now in the bag, so to speak
# 2024-04-03 07:30:28
#
# Scraped 93 users this round
# Got 150 reivews
# 503454 reviews are now in the bag, so to speak
# 2024-04-03 07:33:40
#
# Scraped 97 users this round
# Got 162 reivews
# 503616 reviews are now in the bag, so to speak
# 2024-04-03 07:37:05
#
# Scraped 91 users this round
# Got 216 reivews
# 503832 reviews are now in the bag, so to speak
# 2024-04-03 07:40:14
#
# Scraped 119 users this round
# Got 210 reivews
# 504042 reviews are now in the bag, so to speak
# 2024-04-03 07:44:37
#
# Scraped 108 users this round
# Got 189 reivews
# 504231 reviews are now in the bag, so to speak
# 2024-04-03 07:48:16
#
# Scraped 133 users this round
# Got 189 reivews
# 504420 reviews are now in the bag, so to speak
# 2024-04-03 07:53:05
#
# Scraped 87 users this round
# Got 182 reivews
# 504602 reviews are now in the bag, so to speak
# 2024-04-03 07:56:02
#
# Scraped 99 users this round
# Got 194 reivews
# 504796 reviews are now in the bag, so to speak
# 2024-04-03 07:59:34
#
# Scraped 123 users this round
# Got 166 reivews
# 504962 reviews are now in the bag, so to speak
# 2024-04-03 08:04:30
#
# Scraped 99 users this round
# Got 184 reivews
# 505146 reviews are now in the bag, so to speak
# 2024-04-03 08:08:04
#
# Scraped 108 users this round
# Got 169 reivews
# 505315 reviews are now in the bag, so to speak
# 2024-04-03 08:12:08
#
# Scraped 101 users this round
# Got 183 reivews
# 505498 reviews are now in the bag, so to speak
# 2024-04-03 08:16:06
#
# Scraped 104 users this round
# Got 238 reivews
# 505736 reviews are now in the bag, so to speak
# 2024-04-03 08:20:42
#
# Unable to parse review blocks.
