# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 8
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 57 users this round
# Got 339 reivews
# 339 reviews are now in the bag, so to speak
# 2024-04-03 18:11:53
#
# Scraped 54 users this round
# Got 321 reivews
# 660 reviews are now in the bag, so to speak
# 2024-04-03 18:13:25
#
# Scraped 60 users this round
# Got 345 reivews
# 1005 reviews are now in the bag, so to speak
# 2024-04-03 18:15:09
#
# Scraped 56 users this round
# Got 294 reivews
# 1299 reviews are now in the bag, so to speak
# 2024-04-03 18:16:47
#
# Scraped 54 users this round
# Got 329 reivews
# 1628 reviews are now in the bag, so to speak
# 2024-04-03 18:18:21
#
# Scraped 55 users this round
# Got 310 reivews
# 1938 reviews are now in the bag, so to speak
# 2024-04-03 18:19:52
#
# Scraped 60 users this round
# Got 353 reivews
# 2291 reviews are now in the bag, so to speak
# 2024-04-03 18:21:35
#
# Scraped 58 users this round
# Got 372 reivews
# 2663 reviews are now in the bag, so to speak
# 2024-04-03 18:23:14
#
# Scraped 53 users this round
# Got 314 reivews
# 2977 reviews are now in the bag, so to speak
# 2024-04-03 18:24:48
#
# Scraped 52 users this round
# Got 318 reivews
# 3295 reviews are now in the bag, so to speak
# 2024-04-03 18:26:16
#
# Scraped 54 users this round
# Got 362 reivews
# 3657 reviews are now in the bag, so to speak
# 2024-04-03 18:27:45
#
# Scraped 59 users this round
# Got 308 reivews
# 3965 reviews are now in the bag, so to speak
# 2024-04-03 18:29:28
#
# Scraped 54 users this round
# Got 308 reivews
# 4273 reviews are now in the bag, so to speak
# 2024-04-03 18:31:04
#
# Scraped 62 users this round
# Got 344 reivews
# 4617 reviews are now in the bag, so to speak
# 2024-04-03 18:32:49
#
# Scraped 52 users this round
# Got 320 reivews
# 4937 reviews are now in the bag, so to speak
# 2024-04-03 18:34:14
#
# Scraped 60 users this round
# Got 346 reivews
# 5283 reviews are now in the bag, so to speak
# 2024-04-03 18:36:02
#
# Scraped 54 users this round
# Got 332 reivews
# 5615 reviews are now in the bag, so to speak
# 2024-04-03 18:37:34
#
# Scraped 57 users this round
# Got 302 reivews
# 5917 reviews are now in the bag, so to speak
# 2024-04-03 18:39:21
#
# Scraped 57 users this round
# Got 359 reivews
# 6276 reviews are now in the bag, so to speak
# 2024-04-03 18:41:05
#
# Scraped 55 users this round
# Got 309 reivews
# 6585 reviews are now in the bag, so to speak
# 2024-04-03 18:42:47
#
# Scraped 59 users this round
# Got 390 reivews
# 6975 reviews are now in the bag, so to speak
# 2024-04-03 18:44:28
#
# Scraped 55 users this round
# Got 323 reivews
# 7298 reviews are now in the bag, so to speak
# 2024-04-03 18:46:14
#
# Scraped 53 users this round
# Got 349 reivews
# 7647 reviews are now in the bag, so to speak
# 2024-04-03 18:47:48
#
# Scraped 52 users this round
# Got 345 reivews
# 7992 reviews are now in the bag, so to speak
# 2024-04-03 18:49:20
#
# Scraped 58 users this round
# Got 351 reivews
# 8343 reviews are now in the bag, so to speak
# 2024-04-03 18:51:09
#
# Scraped 60 users this round
# Got 393 reivews
# 8736 reviews are now in the bag, so to speak
# 2024-04-03 18:52:57
#
# Scraped 55 users this round
# Got 351 reivews
# 9087 reviews are now in the bag, so to speak
# 2024-04-03 18:54:23
#
# Scraped 57 users this round
# Got 362 reivews
# 9449 reviews are now in the bag, so to speak
# 2024-04-03 18:56:01
#
# Scraped 59 users this round
# Got 315 reivews
# 9764 reviews are now in the bag, so to speak
# 2024-04-03 18:57:38
#
# Scraped 54 users this round
# Got 359 reivews
# 10123 reviews are now in the bag, so to speak
# 2024-04-03 18:59:09
#
# Scraped 56 users this round
# Got 371 reivews
# 10494 reviews are now in the bag, so to speak
# 2024-04-03 19:00:45
#
# Scraped 57 users this round
# Got 343 reivews
# 10837 reviews are now in the bag, so to speak
# 2024-04-03 19:02:22
#
# Scraped 55 users this round
# Got 314 reivews
# 11151 reviews are now in the bag, so to speak
# 2024-04-03 19:04:03
#
# Scraped 55 users this round
# Got 352 reivews
# 11503 reviews are now in the bag, so to speak
# 2024-04-03 19:05:32
#
# Scraped 57 users this round
# Got 300 reivews
# 11803 reviews are now in the bag, so to speak
# 2024-04-03 19:07:08
#
# Scraped 53 users this round
# Got 315 reivews
# 12118 reviews are now in the bag, so to speak
# 2024-04-03 19:08:39
#
# Scraped 55 users this round
# Got 341 reivews
# 12459 reviews are now in the bag, so to speak
# 2024-04-03 19:10:33
#
# Scraped 56 users this round
# Got 331 reivews
# 12790 reviews are now in the bag, so to speak
# 2024-04-03 19:12:14
#
# Scraped 58 users this round
# Got 372 reivews
# 13162 reviews are now in the bag, so to speak
# 2024-04-03 19:14:09
#
# Scraped 54 users this round
# Got 367 reivews
# 13529 reviews are now in the bag, so to speak
# 2024-04-03 19:15:47
#
# Scraped 60 users this round
# Got 345 reivews
# 13874 reviews are now in the bag, so to speak
# 2024-04-03 19:17:29
#
# Scraped 53 users this round
# Got 341 reivews
# 14215 reviews are now in the bag, so to speak
# 2024-04-03 19:18:47
#
# Scraped 60 users this round
# Got 296 reivews
# 14511 reviews are now in the bag, so to speak
# 2024-04-03 19:20:26
#
# Scraped 53 users this round
# Got 335 reivews
# 14846 reviews are now in the bag, so to speak
# 2024-04-03 19:21:52
#
# Scraped 55 users this round
# Got 375 reivews
# 15221 reviews are now in the bag, so to speak
# 2024-04-03 19:23:29
#
# Scraped 59 users this round
# Got 383 reivews
# 15604 reviews are now in the bag, so to speak
# 2024-04-03 19:25:13
#
# Scraped 51 users this round
# Got 349 reivews
# 15953 reviews are now in the bag, so to speak
# 2024-04-03 19:26:38
#
# Scraped 52 users this round
# Got 330 reivews
# 16283 reviews are now in the bag, so to speak
# 2024-04-03 19:28:12
#
# Scraped 60 users this round
# Got 356 reivews
# 16639 reviews are now in the bag, so to speak
# 2024-04-03 19:30:00
#
# Scraped 60 users this round
# Got 334 reivews
# 16973 reviews are now in the bag, so to speak
# 2024-04-03 19:31:42
#
# Scraped 58 users this round
# Got 325 reivews
# 17298 reviews are now in the bag, so to speak
# 2024-04-03 19:33:20
#
# Scraped 58 users this round
# Got 344 reivews
# 17642 reviews are now in the bag, so to speak
# 2024-04-03 19:35:03
#
# Scraped 54 users this round
# Got 357 reivews
# 17999 reviews are now in the bag, so to speak
# 2024-04-03 19:36:36
#
# Scraped 55 users this round
# Got 351 reivews
# 18350 reviews are now in the bag, so to speak
# 2024-04-03 19:38:15
#
# Scraped 58 users this round
# Got 296 reivews
# 18646 reviews are now in the bag, so to speak
# 2024-04-03 19:39:54
#
# Scraped 54 users this round
# Got 323 reivews
# 18969 reviews are now in the bag, so to speak
# 2024-04-03 19:41:26
#
# Scraped 59 users this round
# Got 308 reivews
# 19277 reviews are now in the bag, so to speak
# 2024-04-03 19:43:02
#
# Scraped 58 users this round
# Got 395 reivews
# 19672 reviews are now in the bag, so to speak
# 2024-04-03 19:44:46
#
# Scraped 52 users this round
# Got 369 reivews
# 20041 reviews are now in the bag, so to speak
# 2024-04-03 19:46:24
#
# Scraped 58 users this round
# Got 299 reivews
# 20340 reviews are now in the bag, so to speak
# 2024-04-03 19:47:59
#
# Scraped 57 users this round
# Got 340 reivews
# 20680 reviews are now in the bag, so to speak
# 2024-04-03 19:49:43
#
# Scraped 54 users this round
# Got 339 reivews
# 21019 reviews are now in the bag, so to speak
# 2024-04-03 19:51:24
#
# Scraped 57 users this round
# Got 349 reivews
# 21368 reviews are now in the bag, so to speak
# 2024-04-03 19:53:00
#
# Scraped 57 users this round
# Got 294 reivews
# 21662 reviews are now in the bag, so to speak
# 2024-04-03 19:54:45
#
# Scraped 60 users this round
# Got 385 reivews
# 22047 reviews are now in the bag, so to speak
# 2024-04-03 19:56:31
#
# Scraped 55 users this round
# Got 348 reivews
# 22395 reviews are now in the bag, so to speak
# 2024-04-03 19:58:05
#
# Scraped 57 users this round
# Got 310 reivews
# 22705 reviews are now in the bag, so to speak
# 2024-04-03 19:59:40
#
# Scraped 59 users this round
# Got 326 reivews
# 23031 reviews are now in the bag, so to speak
# 2024-04-03 20:01:17
#
# Scraped 56 users this round
# Got 365 reivews
# 23396 reviews are now in the bag, so to speak
# 2024-04-03 20:02:51
#
# Scraped 58 users this round
# Got 356 reivews
# 23752 reviews are now in the bag, so to speak
# 2024-04-03 20:04:33
#
# Scraped 56 users this round
# Got 343 reivews
# 24095 reviews are now in the bag, so to speak
# 2024-04-03 20:06:10
#
# Scraped 54 users this round
# Got 316 reivews
# 24411 reviews are now in the bag, so to speak
# 2024-04-03 20:07:47
#
# Scraped 57 users this round
# Got 342 reivews
# 24753 reviews are now in the bag, so to speak
# 2024-04-03 20:09:38
#
# Scraped 54 users this round
# Got 356 reivews
# 25109 reviews are now in the bag, so to speak
# 2024-04-03 20:11:09
#
# Scraped 54 users this round
# Got 328 reivews
# 25437 reviews are now in the bag, so to speak
# 2024-04-03 20:12:42
#
# Scraped 55 users this round
# Got 303 reivews
# 25740 reviews are now in the bag, so to speak
# 2024-04-03 20:14:17
#
# Scraped 62 users this round
# Got 298 reivews
# 26038 reviews are now in the bag, so to speak
# 2024-04-03 20:16:13
#
# Scraped 56 users this round
# Got 301 reivews
# 26339 reviews are now in the bag, so to speak
# 2024-04-03 20:17:53
#
# Scraped 53 users this round
# Got 382 reivews
# 26721 reviews are now in the bag, so to speak
# 2024-04-03 20:19:29
#
# Scraped 58 users this round
# Got 347 reivews
# 27068 reviews are now in the bag, so to speak
# 2024-04-03 20:21:10
#
# Scraped 64 users this round
# Got 368 reivews
# 27436 reviews are now in the bag, so to speak
# 2024-04-03 20:22:54
#
# Scraped 56 users this round
# Got 334 reivews
# 27770 reviews are now in the bag, so to speak
# 2024-04-03 20:24:30
#
# Scraped 59 users this round
# Got 337 reivews
# 28107 reviews are now in the bag, so to speak
# 2024-04-03 20:26:14
#
# Scraped 55 users this round
# Got 362 reivews
# 28469 reviews are now in the bag, so to speak
# 2024-04-03 20:27:52
#
# Scraped 55 users this round
# Got 341 reivews
# 28810 reviews are now in the bag, so to speak
# 2024-04-03 20:29:36
#
# Scraped 53 users this round
# Got 386 reivews
# 29196 reviews are now in the bag, so to speak
# 2024-04-03 20:31:13
#
# Scraped 58 users this round
# Got 349 reivews
# 29545 reviews are now in the bag, so to speak
# 2024-04-03 20:32:48
#
# Scraped 55 users this round
# Got 346 reivews
# 29891 reviews are now in the bag, so to speak
# 2024-04-03 20:34:26
#
# Scraped 55 users this round
# Got 368 reivews
# 30259 reviews are now in the bag, so to speak
# 2024-04-03 20:36:04
#
# Scraped 61 users this round
# Got 374 reivews
# 30633 reviews are now in the bag, so to speak
# 2024-04-03 20:37:50
#
# Scraped 59 users this round
# Got 316 reivews
# 30949 reviews are now in the bag, so to speak
# 2024-04-03 20:39:29
#
# Scraped 52 users this round
# Got 326 reivews
# 31275 reviews are now in the bag, so to speak
# 2024-04-03 20:40:56
#
# Scraped 55 users this round
# Got 369 reivews
# 31644 reviews are now in the bag, so to speak
# 2024-04-03 20:42:28
#
# Scraped 54 users this round
# Got 361 reivews
# 32005 reviews are now in the bag, so to speak
# 2024-04-03 20:44:02
#
# Scraped 54 users this round
# Got 310 reivews
# 32315 reviews are now in the bag, so to speak
# 2024-04-03 20:45:29
#
# Scraped 53 users this round
# Got 358 reivews
# 32673 reviews are now in the bag, so to speak
# 2024-04-03 20:46:58
#
# Scraped 56 users this round
# Got 317 reivews
# 32990 reviews are now in the bag, so to speak
# 2024-04-03 20:48:40
#
# Scraped 56 users this round
# Got 315 reivews
# 33305 reviews are now in the bag, so to speak
# 2024-04-03 20:50:26
#
# Scraped 54 users this round
# Got 339 reivews
# 33644 reviews are now in the bag, so to speak
# 2024-04-03 20:51:52
#
# Scraped 54 users this round
# Got 317 reivews
# 33961 reviews are now in the bag, so to speak
# 2024-04-03 20:53:27
#
# Scraped 56 users this round
# Got 361 reivews
# 34322 reviews are now in the bag, so to speak
# 2024-04-03 20:55:08
#
# Scraped 58 users this round
# Got 300 reivews
# 34622 reviews are now in the bag, so to speak
# 2024-04-03 20:56:45
#
# Scraped 57 users this round
# Got 380 reivews
# 35002 reviews are now in the bag, so to speak
# 2024-04-03 20:58:28
#
# Scraped 57 users this round
# Got 298 reivews
# 35300 reviews are now in the bag, so to speak
# 2024-04-03 21:00:04
#
# Scraped 57 users this round
# Got 340 reivews
# 35640 reviews are now in the bag, so to speak
# 2024-04-03 21:01:43
#
# Scraped 55 users this round
# Got 348 reivews
# 35988 reviews are now in the bag, so to speak
# 2024-04-03 21:03:32
#
# Scraped 56 users this round
# Got 310 reivews
# 36298 reviews are now in the bag, so to speak
# 2024-04-03 21:05:12
#
# Scraped 56 users this round
# Got 325 reivews
# 36623 reviews are now in the bag, so to speak
# 2024-04-03 21:06:58
#
# Scraped 57 users this round
# Got 336 reivews
# 36959 reviews are now in the bag, so to speak
# 2024-04-03 21:08:34
#
# Scraped 56 users this round
# Got 388 reivews
# 37347 reviews are now in the bag, so to speak
# 2024-04-03 21:10:23
#
# Scraped 53 users this round
# Got 324 reivews
# 37671 reviews are now in the bag, so to speak
# 2024-04-03 21:11:57
#
# Scraped 59 users this round
# Got 333 reivews
# 38004 reviews are now in the bag, so to speak
# 2024-04-03 21:13:49
#
# Scraped 57 users this round
# Got 324 reivews
# 38328 reviews are now in the bag, so to speak
# 2024-04-03 21:15:27
#
# Scraped 54 users this round
# Got 329 reivews
# 38657 reviews are now in the bag, so to speak
# 2024-04-03 21:17:06
#
# Scraped 53 users this round
# Got 350 reivews
# 39007 reviews are now in the bag, so to speak
# 2024-04-03 21:18:45
#
# Scraped 57 users this round
# Got 340 reivews
# 39347 reviews are now in the bag, so to speak
# 2024-04-03 21:20:27
#
# Scraped 54 users this round
# Got 355 reivews
# 39702 reviews are now in the bag, so to speak
# 2024-04-03 21:22:10
#
# Scraped 58 users this round
# Got 334 reivews
# 40036 reviews are now in the bag, so to speak
# 2024-04-03 21:23:48
#
# Scraped 62 users this round
# Got 323 reivews
# 40359 reviews are now in the bag, so to speak
# 2024-04-03 21:25:26
#
# Scraped 55 users this round
# Got 361 reivews
# 40720 reviews are now in the bag, so to speak
# 2024-04-03 21:27:05
#
# Scraped 56 users this round
# Got 383 reivews
# 41103 reviews are now in the bag, so to speak
# 2024-04-03 21:28:38
#
# Scraped 56 users this round
# Got 320 reivews
# 41423 reviews are now in the bag, so to speak
# 2024-04-03 21:30:15
#
# Scraped 55 users this round
# Got 334 reivews
# 41757 reviews are now in the bag, so to speak
# 2024-04-03 21:31:47
#
# Scraped 55 users this round
# Got 340 reivews
# 42097 reviews are now in the bag, so to speak
# 2024-04-03 21:33:19
#
# Scraped 57 users this round
# Got 346 reivews
# 42443 reviews are now in the bag, so to speak
# 2024-04-03 21:34:56
#
# Scraped 53 users this round
# Got 344 reivews
# 42787 reviews are now in the bag, so to speak
# 2024-04-03 21:36:24
#
# Scraped 58 users this round
# Got 353 reivews
# 43140 reviews are now in the bag, so to speak
# 2024-04-03 21:38:07
#
# Scraped 59 users this round
# Got 324 reivews
# 43464 reviews are now in the bag, so to speak
# 2024-04-03 21:39:47
#
# Scraped 57 users this round
# Got 340 reivews
# 43804 reviews are now in the bag, so to speak
# 2024-04-03 21:41:24
#
# Scraped 55 users this round
# Got 369 reivews
# 44173 reviews are now in the bag, so to speak
# 2024-04-03 21:42:52
#
# Scraped 53 users this round
# Got 326 reivews
# 44499 reviews are now in the bag, so to speak
# 2024-04-03 21:44:23
#
# Scraped 57 users this round
# Got 325 reivews
# 44824 reviews are now in the bag, so to speak
# 2024-04-03 21:45:56
#
# Scraped 57 users this round
# Got 341 reivews
# 45165 reviews are now in the bag, so to speak
# 2024-04-03 21:47:38
#
# Scraped 57 users this round
# Got 289 reivews
# 45454 reviews are now in the bag, so to speak
# 2024-04-03 21:49:16
#
# Scraped 58 users this round
# Got 314 reivews
# 45768 reviews are now in the bag, so to speak
# 2024-04-03 21:51:02
#
# Scraped 59 users this round
# Got 326 reivews
# 46094 reviews are now in the bag, so to speak
# 2024-04-03 21:52:42
#
# Scraped 57 users this round
# Got 311 reivews
# 46405 reviews are now in the bag, so to speak
# 2024-04-03 21:54:26
#
# Scraped 55 users this round
# Got 306 reivews
# 46711 reviews are now in the bag, so to speak
# 2024-04-03 21:55:54
#
# Scraped 52 users this round
# Got 356 reivews
# 47067 reviews are now in the bag, so to speak
# 2024-04-03 21:57:23
#
# Scraped 56 users this round
# Got 336 reivews
# 47403 reviews are now in the bag, so to speak
# 2024-04-03 21:58:59
#
# Scraped 56 users this round
# Got 358 reivews
# 47761 reviews are now in the bag, so to speak
# 2024-04-03 22:00:37
#
# Scraped 56 users this round
# Got 371 reivews
# 48132 reviews are now in the bag, so to speak
# 2024-04-03 22:02:13
#
# Scraped 57 users this round
# Got 338 reivews
# 48470 reviews are now in the bag, so to speak
# 2024-04-03 22:03:48
#
# Scraped 51 users this round
# Got 361 reivews
# 48831 reviews are now in the bag, so to speak
# 2024-04-03 22:05:21
#
# Scraped 53 users this round
# Got 354 reivews
# 49185 reviews are now in the bag, so to speak
# 2024-04-03 22:07:00
#
# Scraped 56 users this round
# Got 350 reivews
# 49535 reviews are now in the bag, so to speak
# 2024-04-03 22:08:38
#
# Scraped 55 users this round
# Got 296 reivews
# 49831 reviews are now in the bag, so to speak
# 2024-04-03 22:10:09
#
# Scraped 56 users this round
# Got 341 reivews
# 50172 reviews are now in the bag, so to speak
# 2024-04-03 22:11:56
#
# Scraped 57 users this round
# Got 336 reivews
# 50508 reviews are now in the bag, so to speak
# 2024-04-03 22:13:34
#
# Scraped 55 users this round
# Got 396 reivews
# 50904 reviews are now in the bag, so to speak
# 2024-04-03 22:15:10
#
# Scraped 59 users this round
# Got 324 reivews
# 51228 reviews are now in the bag, so to speak
# 2024-04-03 22:17:01
#
# Scraped 52 users this round
# Got 340 reivews
# 51568 reviews are now in the bag, so to speak
# 2024-04-03 22:18:41
#
# Scraped 55 users this round
# Got 352 reivews
# 51920 reviews are now in the bag, so to speak
# 2024-04-03 22:20:17
#
# Scraped 55 users this round
# Got 347 reivews
# 52267 reviews are now in the bag, so to speak
# 2024-04-03 22:21:54
#
# Scraped 53 users this round
# Got 310 reivews
# 52577 reviews are now in the bag, so to speak
# 2024-04-03 22:23:43
#
# Scraped 54 users this round
# Got 392 reivews
# 52969 reviews are now in the bag, so to speak
# 2024-04-03 22:25:52
#
# Scraped 53 users this round
# Got 353 reivews
# 53322 reviews are now in the bag, so to speak
# 2024-04-03 22:28:28
#
# Scraped 57 users this round
# Got 303 reivews
# 53625 reviews are now in the bag, so to speak
# 2024-04-03 22:31:17
#
# Scraped 59 users this round
# Got 370 reivews
# 53995 reviews are now in the bag, so to speak
# 2024-04-03 22:34:20
#
# Scraped 60 users this round
# Got 320 reivews
# 54315 reviews are now in the bag, so to speak
# 2024-04-03 22:37:30
#
# Scraped 56 users this round
# Got 336 reivews
# 54651 reviews are now in the bag, so to speak
# 2024-04-03 22:40:19
#
# Scraped 55 users this round
# Got 362 reivews
# 55013 reviews are now in the bag, so to speak
# 2024-04-03 22:43:23
#
# Scraped 52 users this round
# Got 341 reivews
# 55354 reviews are now in the bag, so to speak
# 2024-04-03 22:46:10
#
# Scraped 55 users this round
# Got 358 reivews
# 55712 reviews are now in the bag, so to speak
# 2024-04-03 22:48:48
#
# Scraped 56 users this round
# Got 339 reivews
# 56051 reviews are now in the bag, so to speak
# 2024-04-03 22:51:52
#
# Scraped 57 users this round
# Got 285 reivews
# 56336 reviews are now in the bag, so to speak
# 2024-04-03 22:54:42
#
# Scraped 56 users this round
# Got 370 reivews
# 56706 reviews are now in the bag, so to speak
# 2024-04-03 22:57:43
#
# Scraped 59 users this round
# Got 335 reivews
# 57041 reviews are now in the bag, so to speak
# 2024-04-03 23:00:54
#
# Scraped 60 users this round
# Got 331 reivews
# 57372 reviews are now in the bag, so to speak
# 2024-04-03 23:03:41
#
# Scraped 59 users this round
# Got 363 reivews
# 57735 reviews are now in the bag, so to speak
# 2024-04-03 23:06:50
#
# Scraped 52 users this round
# Got 360 reivews
# 58095 reviews are now in the bag, so to speak
# 2024-04-03 23:09:45
#
# Scraped 63 users this round
# Got 290 reivews
# 58385 reviews are now in the bag, so to speak
# 2024-04-03 23:13:08
#
# Scraped 56 users this round
# Got 309 reivews
# 58694 reviews are now in the bag, so to speak
# 2024-04-03 23:15:09
#
# Scraped 53 users this round
# Got 335 reivews
# 59029 reviews are now in the bag, so to speak
# 2024-04-03 23:16:46
#
# Scraped 51 users this round
# Got 331 reivews
# 59360 reviews are now in the bag, so to speak
# 2024-04-03 23:18:15
#
# Scraped 55 users this round
# Got 351 reivews
# 59711 reviews are now in the bag, so to speak
# 2024-04-03 23:19:44
#
# Scraped 52 users this round
# Got 347 reivews
# 60058 reviews are now in the bag, so to speak
# 2024-04-03 23:21:19
#
# Scraped 59 users this round
# Got 333 reivews
# 60391 reviews are now in the bag, so to speak
# 2024-04-03 23:22:54
#
# Scraped 57 users this round
# Got 337 reivews
# 60728 reviews are now in the bag, so to speak
# 2024-04-03 23:24:32
#
# Scraped 53 users this round
# Got 348 reivews
# 61076 reviews are now in the bag, so to speak
# 2024-04-03 23:26:07
#
# Scraped 57 users this round
# Got 325 reivews
# 61401 reviews are now in the bag, so to speak
# 2024-04-03 23:27:47
#
# Scraped 54 users this round
# Got 336 reivews
# 61737 reviews are now in the bag, so to speak
# 2024-04-03 23:29:18
#
# Scraped 56 users this round
# Got 351 reivews
# 62088 reviews are now in the bag, so to speak
# 2024-04-03 23:30:49
#
# Scraped 54 users this round
# Got 305 reivews
# 62393 reviews are now in the bag, so to speak
# 2024-04-03 23:32:24
#
# Scraped 55 users this round
# Got 343 reivews
# 62736 reviews are now in the bag, so to speak
# 2024-04-03 23:33:55
#
# Scraped 53 users this round
# Got 317 reivews
# 63053 reviews are now in the bag, so to speak
# 2024-04-03 23:35:19
#
# Scraped 58 users this round
# Got 304 reivews
# 63357 reviews are now in the bag, so to speak
# 2024-04-03 23:36:52
#
# Scraped 53 users this round
# Got 336 reivews
# 63693 reviews are now in the bag, so to speak
# 2024-04-03 23:38:28
#
# Scraped 60 users this round
# Got 332 reivews
# 64025 reviews are now in the bag, so to speak
# 2024-04-03 23:40:10
#
# Scraped 54 users this round
# Got 342 reivews
# 64367 reviews are now in the bag, so to speak
# 2024-04-03 23:41:41
#
# Scraped 54 users this round
# Got 350 reivews
# 64717 reviews are now in the bag, so to speak
# 2024-04-03 23:43:11
#
# Scraped 58 users this round
# Got 344 reivews
# 65061 reviews are now in the bag, so to speak
# 2024-04-03 23:45:12
#
# Scraped 58 users this round
# Got 294 reivews
# 65355 reviews are now in the bag, so to speak
# 2024-04-03 23:46:46
#
# Scraped 59 users this round
# Got 368 reivews
# 65723 reviews are now in the bag, so to speak
# 2024-04-03 23:48:29
#
# Scraped 57 users this round
# Got 342 reivews
# 66065 reviews are now in the bag, so to speak
# 2024-04-03 23:50:01
#
# Scraped 58 users this round
# Got 341 reivews
# 66406 reviews are now in the bag, so to speak
# 2024-04-03 23:51:48
#
# Scraped 57 users this round
# Got 361 reivews
# 66767 reviews are now in the bag, so to speak
# 2024-04-03 23:53:22
#
# Scraped 60 users this round
# Got 324 reivews
# 67091 reviews are now in the bag, so to speak
# 2024-04-03 23:55:05
#
# Scraped 57 users this round
# Got 332 reivews
# 67423 reviews are now in the bag, so to speak
# 2024-04-03 23:56:42
#
# Scraped 56 users this round
# Got 339 reivews
# 67762 reviews are now in the bag, so to speak
# 2024-04-03 23:58:17
#
# Scraped 55 users this round
# Got 330 reivews
# 68092 reviews are now in the bag, so to speak
# 2024-04-03 23:59:51
#
# Scraped 50 users this round
# Got 312 reivews
# 68404 reviews are now in the bag, so to speak
# 2024-04-04 00:01:17
#
# Scraped 55 users this round
# Got 342 reivews
# 68746 reviews are now in the bag, so to speak
# 2024-04-04 00:02:58
#
# Scraped 57 users this round
# Got 308 reivews
# 69054 reviews are now in the bag, so to speak
# 2024-04-04 00:04:41
#
# Scraped 58 users this round
# Got 355 reivews
# 69409 reviews are now in the bag, so to speak
# 2024-04-04 00:06:09
#
# Scraped 59 users this round
# Got 327 reivews
# 69736 reviews are now in the bag, so to speak
# 2024-04-04 00:07:55
#
# Scraped 59 users this round
# Got 329 reivews
# 70065 reviews are now in the bag, so to speak
# 2024-04-04 00:09:43
#
# Scraped 56 users this round
# Got 348 reivews
# 70413 reviews are now in the bag, so to speak
# 2024-04-04 00:11:19
#
# Scraped 63 users this round
# Got 356 reivews
# 70769 reviews are now in the bag, so to speak
# 2024-04-04 00:13:14
#
# Scraped 55 users this round
# Got 374 reivews
# 71143 reviews are now in the bag, so to speak
# 2024-04-04 00:14:49
#
# Scraped 56 users this round
# Got 368 reivews
# 71511 reviews are now in the bag, so to speak
# 2024-04-04 00:16:29
#
# Scraped 52 users this round
# Got 362 reivews
# 71873 reviews are now in the bag, so to speak
# 2024-04-04 00:18:00
#
# Scraped 55 users this round
# Got 314 reivews
# 72187 reviews are now in the bag, so to speak
# 2024-04-04 00:19:29
#
# Scraped 55 users this round
# Got 299 reivews
# 72486 reviews are now in the bag, so to speak
# 2024-04-04 00:21:00
#
# Scraped 59 users this round
# Got 325 reivews
# 72811 reviews are now in the bag, so to speak
# 2024-04-04 00:22:42
#
# Scraped 57 users this round
# Got 338 reivews
# 73149 reviews are now in the bag, so to speak
# 2024-04-04 00:24:17
#
# Scraped 57 users this round
# Got 330 reivews
# 73479 reviews are now in the bag, so to speak
# 2024-04-04 00:26:06
#
# Scraped 54 users this round
# Got 387 reivews
# 73866 reviews are now in the bag, so to speak
# 2024-04-04 00:27:38
#
# Scraped 60 users this round
# Got 336 reivews
# 74202 reviews are now in the bag, so to speak
# 2024-04-04 00:29:23
#
# Scraped 51 users this round
# Got 337 reivews
# 74539 reviews are now in the bag, so to speak
# 2024-04-04 00:30:46
#
# Scraped 60 users this round
# Got 353 reivews
# 74892 reviews are now in the bag, so to speak
# 2024-04-04 00:32:25
#
# Scraped 57 users this round
# Got 343 reivews
# 75235 reviews are now in the bag, so to speak
# 2024-04-04 00:33:55
#
# Scraped 57 users this round
# Got 339 reivews
# 75574 reviews are now in the bag, so to speak
# 2024-04-04 00:35:26
#
# Scraped 58 users this round
# Got 295 reivews
# 75869 reviews are now in the bag, so to speak
# 2024-04-04 00:37:05
#
# Scraped 56 users this round
# Got 364 reivews
# 76233 reviews are now in the bag, so to speak
# 2024-04-04 00:38:40
#
# Scraped 58 users this round
# Got 328 reivews
# 76561 reviews are now in the bag, so to speak
# 2024-04-04 00:40:13
#
# Scraped 52 users this round
# Got 313 reivews
# 76874 reviews are now in the bag, so to speak
# 2024-04-04 00:41:43
#
# Scraped 59 users this round
# Got 330 reivews
# 77204 reviews are now in the bag, so to speak
# 2024-04-04 00:43:29
#
# Scraped 56 users this round
# Got 354 reivews
# 77558 reviews are now in the bag, so to speak
# 2024-04-04 00:44:58
#
# Scraped 59 users this round
# Got 360 reivews
# 77918 reviews are now in the bag, so to speak
# 2024-04-04 00:46:46
#
# Scraped 60 users this round
# Got 336 reivews
# 78254 reviews are now in the bag, so to speak
# 2024-04-04 00:48:28
#
# Scraped 59 users this round
# Got 340 reivews
# 78594 reviews are now in the bag, so to speak
# 2024-04-04 00:50:12
#
# Scraped 56 users this round
# Got 329 reivews
# 78923 reviews are now in the bag, so to speak
# 2024-04-04 00:51:42
#
# Scraped 57 users this round
# Got 363 reivews
# 79286 reviews are now in the bag, so to speak
# 2024-04-04 00:53:22
#
# Scraped 53 users this round
# Got 320 reivews
# 79606 reviews are now in the bag, so to speak
# 2024-04-04 00:54:57
#
# Scraped 53 users this round
# Got 322 reivews
# 79928 reviews are now in the bag, so to speak
# 2024-04-04 00:56:24
#
# Scraped 57 users this round
# Got 355 reivews
# 80283 reviews are now in the bag, so to speak
# 2024-04-04 00:58:04
#
# Scraped 54 users this round
# Got 360 reivews
# 80643 reviews are now in the bag, so to speak
# 2024-04-04 00:59:49
#
# Scraped 56 users this round
# Got 328 reivews
# 80971 reviews are now in the bag, so to speak
# 2024-04-04 01:01:25
#
# Scraped 55 users this round
# Got 348 reivews
# 81319 reviews are now in the bag, so to speak
# 2024-04-04 01:02:52
#
# Scraped 55 users this round
# Got 363 reivews
# 81682 reviews are now in the bag, so to speak
# 2024-04-04 01:04:32
#
# Scraped 59 users this round
# Got 300 reivews
# 81982 reviews are now in the bag, so to speak
# 2024-04-04 01:06:08
#
# Scraped 54 users this round
# Got 334 reivews
# 82316 reviews are now in the bag, so to speak
# 2024-04-04 01:07:35
#
# Scraped 54 users this round
# Got 333 reivews
# 82649 reviews are now in the bag, so to speak
# 2024-04-04 01:09:16
#
# Scraped 55 users this round
# Got 313 reivews
# 82962 reviews are now in the bag, so to speak
# 2024-04-04 01:10:50
#
# Scraped 55 users this round
# Got 363 reivews
# 83325 reviews are now in the bag, so to speak
# 2024-04-04 01:12:23
#
# Scraped 58 users this round
# Got 374 reivews
# 83699 reviews are now in the bag, so to speak
# 2024-04-04 01:13:55
#
# Scraped 56 users this round
# Got 311 reivews
# 84010 reviews are now in the bag, so to speak
# 2024-04-04 01:15:32
#
# Scraped 56 users this round
# Got 296 reivews
# 84306 reviews are now in the bag, so to speak
# 2024-04-04 01:17:10
#
# Scraped 54 users this round
# Got 358 reivews
# 84664 reviews are now in the bag, so to speak
# 2024-04-04 01:18:30
#
# Scraped 54 users this round
# Got 318 reivews
# 84982 reviews are now in the bag, so to speak
# 2024-04-04 01:20:00
#
# Scraped 53 users this round
# Got 327 reivews
# 85309 reviews are now in the bag, so to speak
# 2024-04-04 01:21:24
#
# Scraped 60 users this round
# Got 301 reivews
# 85610 reviews are now in the bag, so to speak
# 2024-04-04 01:23:00
#
# Scraped 55 users this round
# Got 306 reivews
# 85916 reviews are now in the bag, so to speak
# 2024-04-04 01:24:31
#
# Scraped 52 users this round
# Got 386 reivews
# 86302 reviews are now in the bag, so to speak
# 2024-04-04 01:26:06
#
# Scraped 58 users this round
# Got 358 reivews
# 86660 reviews are now in the bag, so to speak
# 2024-04-04 01:27:31
#
# Scraped 56 users this round
# Got 357 reivews
# 87017 reviews are now in the bag, so to speak
# 2024-04-04 01:29:02
#
# Scraped 55 users this round
# Got 319 reivews
# 87336 reviews are now in the bag, so to speak
# 2024-04-04 01:30:26
#
# Scraped 56 users this round
# Got 348 reivews
# 87684 reviews are now in the bag, so to speak
# 2024-04-04 01:31:59
#
# Scraped 56 users this round
# Got 350 reivews
# 88034 reviews are now in the bag, so to speak
# 2024-04-04 01:33:38
#
# Scraped 55 users this round
# Got 351 reivews
# 88385 reviews are now in the bag, so to speak
# 2024-04-04 01:35:12
#
# Scraped 56 users this round
# Got 346 reivews
# 88731 reviews are now in the bag, so to speak
# 2024-04-04 01:36:48
#
# Scraped 51 users this round
# Got 398 reivews
# 89129 reviews are now in the bag, so to speak
# 2024-04-04 01:38:27
#
# Scraped 63 users this round
# Got 335 reivews
# 89464 reviews are now in the bag, so to speak
# 2024-04-04 01:40:12
#
# Scraped 65 users this round
# Got 346 reivews
# 89810 reviews are now in the bag, so to speak
# 2024-04-04 01:42:16
#
# Scraped 54 users this round
# Got 323 reivews
# 90133 reviews are now in the bag, so to speak
# 2024-04-04 01:43:53
#
# Scraped 60 users this round
# Got 320 reivews
# 90453 reviews are now in the bag, so to speak
# 2024-04-04 01:45:32
#
# Scraped 55 users this round
# Got 392 reivews
# 90845 reviews are now in the bag, so to speak
# 2024-04-04 01:47:11
#
# Scraped 53 users this round
# Got 364 reivews
# 91209 reviews are now in the bag, so to speak
# 2024-04-04 01:48:35
#
# Scraped 54 users this round
# Got 339 reivews
# 91548 reviews are now in the bag, so to speak
# 2024-04-04 01:50:03
#
# Scraped 60 users this round
# Got 286 reivews
# 91834 reviews are now in the bag, so to speak
# 2024-04-04 01:51:37
#
# Scraped 57 users this round
# Got 308 reivews
# 92142 reviews are now in the bag, so to speak
# 2024-04-04 01:53:21
#
# Scraped 56 users this round
# Got 336 reivews
# 92478 reviews are now in the bag, so to speak
# 2024-04-04 01:54:50
#
# Scraped 54 users this round
# Got 369 reivews
# 92847 reviews are now in the bag, so to speak
# 2024-04-04 01:56:25
#
# Scraped 55 users this round
# Got 341 reivews
# 93188 reviews are now in the bag, so to speak
# 2024-04-04 01:58:02
#
# Scraped 60 users this round
# Got 315 reivews
# 93503 reviews are now in the bag, so to speak
# 2024-04-04 01:59:40
#
# Scraped 52 users this round
# Got 355 reivews
# 93858 reviews are now in the bag, so to speak
# 2024-04-04 02:01:05
#
# Scraped 59 users this round
# Got 356 reivews
# 94214 reviews are now in the bag, so to speak
# 2024-04-04 02:02:47
#
# Scraped 59 users this round
# Got 330 reivews
# 94544 reviews are now in the bag, so to speak
# 2024-04-04 02:04:29
#
# Scraped 57 users this round
# Got 366 reivews
# 94910 reviews are now in the bag, so to speak
# 2024-04-04 02:06:04
#
# Scraped 54 users this round
# Got 355 reivews
# 95265 reviews are now in the bag, so to speak
# 2024-04-04 02:07:51
#
# Scraped 57 users this round
# Got 305 reivews
# 95570 reviews are now in the bag, so to speak
# 2024-04-04 02:09:19
#
# Scraped 57 users this round
# Got 288 reivews
# 95858 reviews are now in the bag, so to speak
# 2024-04-04 02:10:54
#
# Scraped 54 users this round
# Got 326 reivews
# 96184 reviews are now in the bag, so to speak
# 2024-04-04 02:12:25
#
# Scraped 59 users this round
# Got 328 reivews
# 96512 reviews are now in the bag, so to speak
# 2024-04-04 02:14:00
#
# Scraped 53 users this round
# Got 339 reivews
# 96851 reviews are now in the bag, so to speak
# 2024-04-04 02:15:34
#
# Scraped 58 users this round
# Got 304 reivews
# 97155 reviews are now in the bag, so to speak
# 2024-04-04 02:17:22
#
# Scraped 55 users this round
# Got 312 reivews
# 97467 reviews are now in the bag, so to speak
# 2024-04-04 02:18:51
#
# Scraped 55 users this round
# Got 364 reivews
# 97831 reviews are now in the bag, so to speak
# 2024-04-04 02:20:56
#
# Scraped 56 users this round
# Got 346 reivews
# 98177 reviews are now in the bag, so to speak
# 2024-04-04 02:22:24
#
# Scraped 56 users this round
# Got 333 reivews
# 98510 reviews are now in the bag, so to speak
# 2024-04-04 02:23:49
#
# Scraped 59 users this round
# Got 299 reivews
# 98809 reviews are now in the bag, so to speak
# 2024-04-04 02:25:23
#
# Scraped 60 users this round
# Got 331 reivews
# 99140 reviews are now in the bag, so to speak
# 2024-04-04 02:27:08
#
# Scraped 56 users this round
# Got 329 reivews
# 99469 reviews are now in the bag, so to speak
# 2024-04-04 02:28:35
#
# Scraped 56 users this round
# Got 353 reivews
# 99822 reviews are now in the bag, so to speak
# 2024-04-04 02:30:08
#
# Scraped 60 users this round
# Got 365 reivews
# 100187 reviews are now in the bag, so to speak
# 2024-04-04 02:31:48
#
# Scraped 58 users this round
# Got 310 reivews
# 100497 reviews are now in the bag, so to speak
# 2024-04-04 02:33:28
#
# Scraped 54 users this round
# Got 296 reivews
# 100793 reviews are now in the bag, so to speak
# 2024-04-04 02:34:58
#
# Scraped 56 users this round
# Got 357 reivews
# 101150 reviews are now in the bag, so to speak
# 2024-04-04 02:36:35
#
# Scraped 54 users this round
# Got 357 reivews
# 101507 reviews are now in the bag, so to speak
# 2024-04-04 02:38:03
#
# Scraped 55 users this round
# Got 338 reivews
# 101845 reviews are now in the bag, so to speak
# 2024-04-04 02:39:35
#
# Scraped 52 users this round
# Got 290 reivews
# 102135 reviews are now in the bag, so to speak
# 2024-04-04 02:41:06
#
# Scraped 57 users this round
# Got 354 reivews
# 102489 reviews are now in the bag, so to speak
# 2024-04-04 02:42:37
#
# Scraped 52 users this round
# Got 338 reivews
# 102827 reviews are now in the bag, so to speak
# 2024-04-04 02:44:02
#
# Scraped 56 users this round
# Got 370 reivews
# 103197 reviews are now in the bag, so to speak
# 2024-04-04 02:45:35
#
# Scraped 57 users this round
# Got 373 reivews
# 103570 reviews are now in the bag, so to speak
# 2024-04-04 02:47:18
#
# Scraped 62 users this round
# Got 330 reivews
# 103900 reviews are now in the bag, so to speak
# 2024-04-04 02:48:54
#
# Scraped 53 users this round
# Got 327 reivews
# 104227 reviews are now in the bag, so to speak
# 2024-04-04 02:50:29
#
# Scraped 57 users this round
# Got 327 reivews
# 104554 reviews are now in the bag, so to speak
# 2024-04-04 02:52:05
#
# Scraped 56 users this round
# Got 368 reivews
# 104922 reviews are now in the bag, so to speak
# 2024-04-04 02:53:45
#
# Scraped 59 users this round
# Got 341 reivews
# 105263 reviews are now in the bag, so to speak
# 2024-04-04 02:55:21
#
# Scraped 53 users this round
# Got 321 reivews
# 105584 reviews are now in the bag, so to speak
# 2024-04-04 02:56:53
#
# Scraped 58 users this round
# Got 326 reivews
# 105910 reviews are now in the bag, so to speak
# 2024-04-04 02:58:31
#
# Scraped 55 users this round
# Got 318 reivews
# 106228 reviews are now in the bag, so to speak
# 2024-04-04 03:00:08
#
# Scraped 55 users this round
# Got 318 reivews
# 106546 reviews are now in the bag, so to speak
# 2024-04-04 03:01:44
#
# Scraped 53 users this round
# Got 383 reivews
# 106929 reviews are now in the bag, so to speak
# 2024-04-04 03:03:12
#
# Scraped 58 users this round
# Got 305 reivews
# 107234 reviews are now in the bag, so to speak
# 2024-04-04 03:04:46
#
# Scraped 56 users this round
# Got 344 reivews
# 107578 reviews are now in the bag, so to speak
# 2024-04-04 03:06:26
#
# Scraped 55 users this round
# Got 343 reivews
# 107921 reviews are now in the bag, so to speak
# 2024-04-04 03:07:59
#
# Scraped 54 users this round
# Got 352 reivews
# 108273 reviews are now in the bag, so to speak
# 2024-04-04 03:09:30
#
# Scraped 54 users this round
# Got 358 reivews
# 108631 reviews are now in the bag, so to speak
# 2024-04-04 03:10:57
#
# Scraped 54 users this round
# Got 338 reivews
# 108969 reviews are now in the bag, so to speak
# 2024-04-04 03:12:26
#
# Scraped 60 users this round
# Got 344 reivews
# 109313 reviews are now in the bag, so to speak
# 2024-04-04 03:14:12
#
# Scraped 51 users this round
# Got 393 reivews
# 109706 reviews are now in the bag, so to speak
# 2024-04-04 03:15:42
#
# Scraped 52 users this round
# Got 319 reivews
# 110025 reviews are now in the bag, so to speak
# 2024-04-04 03:17:16
#
# Scraped 55 users this round
# Got 320 reivews
# 110345 reviews are now in the bag, so to speak
# 2024-04-04 03:18:48
#
# Scraped 56 users this round
# Got 356 reivews
# 110701 reviews are now in the bag, so to speak
# 2024-04-04 03:20:26
#
# Scraped 53 users this round
# Got 288 reivews
# 110989 reviews are now in the bag, so to speak
# 2024-04-04 03:21:52
#
# Scraped 60 users this round
# Got 336 reivews
# 111325 reviews are now in the bag, so to speak
# 2024-04-04 03:23:37
#
# Scraped 59 users this round
# Got 343 reivews
# 111668 reviews are now in the bag, so to speak
# 2024-04-04 03:25:07
#
# Scraped 60 users this round
# Got 342 reivews
# 112010 reviews are now in the bag, so to speak
# 2024-04-04 03:26:49
#
# Scraped 53 users this round
# Got 324 reivews
# 112334 reviews are now in the bag, so to speak
# 2024-04-04 03:28:30
#
# Scraped 59 users this round
# Got 317 reivews
# 112651 reviews are now in the bag, so to speak
# 2024-04-04 03:30:20
#
# Scraped 56 users this round
# Got 350 reivews
# 113001 reviews are now in the bag, so to speak
# 2024-04-04 03:31:54
#
# Scraped 51 users this round
# Got 339 reivews
# 113340 reviews are now in the bag, so to speak
# 2024-04-04 03:33:20
#
# Scraped 53 users this round
# Got 338 reivews
# 113678 reviews are now in the bag, so to speak
# 2024-04-04 03:34:48
#
# Scraped 58 users this round
# Got 357 reivews
# 114035 reviews are now in the bag, so to speak
# 2024-04-04 03:36:26
#
# Scraped 56 users this round
# Got 359 reivews
# 114394 reviews are now in the bag, so to speak
# 2024-04-04 03:38:04
#
# Scraped 55 users this round
# Got 338 reivews
# 114732 reviews are now in the bag, so to speak
# 2024-04-04 03:39:34
#
# Scraped 58 users this round
# Got 316 reivews
# 115048 reviews are now in the bag, so to speak
# 2024-04-04 03:41:04
#
# Scraped 55 users this round
# Got 335 reivews
# 115383 reviews are now in the bag, so to speak
# 2024-04-04 03:42:28
#
# Scraped 58 users this round
# Got 352 reivews
# 115735 reviews are now in the bag, so to speak
# 2024-04-04 03:43:59
#
# Scraped 54 users this round
# Got 367 reivews
# 116102 reviews are now in the bag, so to speak
# 2024-04-04 03:45:30
#
# Scraped 57 users this round
# Got 370 reivews
# 116472 reviews are now in the bag, so to speak
# 2024-04-04 03:47:04

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
