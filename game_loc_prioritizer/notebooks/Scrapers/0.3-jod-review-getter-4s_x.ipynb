# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 4
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 56 users this round
# Got 297 reivews
# 297 reviews are now in the bag, so to speak
# 2024-04-03 18:09:09
#
# Scraped 55 users this round
# Got 333 reivews
# 630 reviews are now in the bag, so to speak
# 2024-04-03 18:10:38
#
# Scraped 56 users this round
# Got 369 reivews
# 999 reviews are now in the bag, so to speak
# 2024-04-03 18:12:15
#
# Scraped 58 users this round
# Got 355 reivews
# 1354 reviews are now in the bag, so to speak
# 2024-04-03 18:14:08
#
# Scraped 52 users this round
# Got 365 reivews
# 1719 reviews are now in the bag, so to speak
# 2024-04-03 18:15:38
#
# Scraped 55 users this round
# Got 340 reivews
# 2059 reviews are now in the bag, so to speak
# 2024-04-03 18:17:14
#
# Scraped 57 users this round
# Got 323 reivews
# 2382 reviews are now in the bag, so to speak
# 2024-04-03 18:19:03
#
# Scraped 52 users this round
# Got 347 reivews
# 2729 reviews are now in the bag, so to speak
# 2024-04-03 18:20:29
#
# Scraped 56 users this round
# Got 321 reivews
# 3050 reviews are now in the bag, so to speak
# 2024-04-03 18:21:57
#
# Scraped 56 users this round
# Got 361 reivews
# 3411 reviews are now in the bag, so to speak
# 2024-04-03 18:23:30
#
# Scraped 54 users this round
# Got 339 reivews
# 3750 reviews are now in the bag, so to speak
# 2024-04-03 18:24:58
#
# Scraped 57 users this round
# Got 315 reivews
# 4065 reviews are now in the bag, so to speak
# 2024-04-03 18:26:39
#
# Scraped 55 users this round
# Got 315 reivews
# 4380 reviews are now in the bag, so to speak
# 2024-04-03 18:28:17
#
# Scraped 56 users this round
# Got 364 reivews
# 4744 reviews are now in the bag, so to speak
# 2024-04-03 18:29:58
#
# Scraped 56 users this round
# Got 345 reivews
# 5089 reviews are now in the bag, so to speak
# 2024-04-03 18:31:32
#
# Scraped 58 users this round
# Got 357 reivews
# 5446 reviews are now in the bag, so to speak
# 2024-04-03 18:33:13
#
# Scraped 57 users this round
# Got 323 reivews
# 5769 reviews are now in the bag, so to speak
# 2024-04-03 18:34:52
#
# Scraped 60 users this round
# Got 326 reivews
# 6095 reviews are now in the bag, so to speak
# 2024-04-03 18:36:39
#
# Scraped 55 users this round
# Got 329 reivews
# 6424 reviews are now in the bag, so to speak
# 2024-04-03 18:38:15
#
# Scraped 57 users this round
# Got 355 reivews
# 6779 reviews are now in the bag, so to speak
# 2024-04-03 18:39:58
#
# Scraped 58 users this round
# Got 358 reivews
# 7137 reviews are now in the bag, so to speak
# 2024-04-03 18:41:44
#
# Scraped 56 users this round
# Got 366 reivews
# 7503 reviews are now in the bag, so to speak
# 2024-04-03 18:43:21
#
# Scraped 62 users this round
# Got 363 reivews
# 7866 reviews are now in the bag, so to speak
# 2024-04-03 18:45:10
#
# Scraped 59 users this round
# Got 374 reivews
# 8240 reviews are now in the bag, so to speak
# 2024-04-03 18:46:52
#
# Scraped 56 users this round
# Got 360 reivews
# 8600 reviews are now in the bag, so to speak
# 2024-04-03 18:48:32
#
# Scraped 59 users this round
# Got 333 reivews
# 8933 reviews are now in the bag, so to speak
# 2024-04-03 18:50:17
#
# Scraped 57 users this round
# Got 348 reivews
# 9281 reviews are now in the bag, so to speak
# 2024-04-03 18:51:54
#
# Scraped 62 users this round
# Got 331 reivews
# 9612 reviews are now in the bag, so to speak
# 2024-04-03 18:53:36
#
# Scraped 57 users this round
# Got 375 reivews
# 9987 reviews are now in the bag, so to speak
# 2024-04-03 18:55:16
#
# Scraped 54 users this round
# Got 351 reivews
# 10338 reviews are now in the bag, so to speak
# 2024-04-03 18:56:51
#
# Scraped 54 users this round
# Got 328 reivews
# 10666 reviews are now in the bag, so to speak
# 2024-04-03 18:58:17
#
# Scraped 54 users this round
# Got 372 reivews
# 11038 reviews are now in the bag, so to speak
# 2024-04-03 18:59:44
#
# Scraped 58 users this round
# Got 274 reivews
# 11312 reviews are now in the bag, so to speak
# 2024-04-03 19:01:24
#
# Scraped 58 users this round
# Got 372 reivews
# 11684 reviews are now in the bag, so to speak
# 2024-04-03 19:03:09
#
# Scraped 53 users this round
# Got 321 reivews
# 12005 reviews are now in the bag, so to speak
# 2024-04-03 19:04:46
#
# Scraped 55 users this round
# Got 343 reivews
# 12348 reviews are now in the bag, so to speak
# 2024-04-03 19:06:21
#
# Scraped 57 users this round
# Got 371 reivews
# 12719 reviews are now in the bag, so to speak
# 2024-04-03 19:08:01
#
# Scraped 59 users this round
# Got 350 reivews
# 13069 reviews are now in the bag, so to speak
# 2024-04-03 19:09:53
#
# Scraped 56 users this round
# Got 300 reivews
# 13369 reviews are now in the bag, so to speak
# 2024-04-03 19:11:31
#
# Scraped 58 users this round
# Got 372 reivews
# 13741 reviews are now in the bag, so to speak
# 2024-04-03 19:13:14
#
# Scraped 56 users this round
# Got 342 reivews
# 14083 reviews are now in the bag, so to speak
# 2024-04-03 19:15:04
#
# Scraped 54 users this round
# Got 372 reivews
# 14455 reviews are now in the bag, so to speak
# 2024-04-03 19:16:32
#
# Scraped 57 users this round
# Got 310 reivews
# 14765 reviews are now in the bag, so to speak
# 2024-04-03 19:18:02
#
# Scraped 52 users this round
# Got 325 reivews
# 15090 reviews are now in the bag, so to speak
# 2024-04-03 19:19:30
#
# Scraped 56 users this round
# Got 334 reivews
# 15424 reviews are now in the bag, so to speak
# 2024-04-03 19:21:10
#
# Scraped 57 users this round
# Got 368 reivews
# 15792 reviews are now in the bag, so to speak
# 2024-04-03 19:22:53
#
# Scraped 60 users this round
# Got 357 reivews
# 16149 reviews are now in the bag, so to speak
# 2024-04-03 19:24:35
#
# Scraped 58 users this round
# Got 373 reivews
# 16522 reviews are now in the bag, so to speak
# 2024-04-03 19:26:10
#
# Scraped 59 users this round
# Got 316 reivews
# 16838 reviews are now in the bag, so to speak
# 2024-04-03 19:27:55
#
# Scraped 57 users this round
# Got 330 reivews
# 17168 reviews are now in the bag, so to speak
# 2024-04-03 19:29:29
#
# Scraped 54 users this round
# Got 292 reivews
# 17460 reviews are now in the bag, so to speak
# 2024-04-03 19:30:56
#
# Scraped 54 users this round
# Got 342 reivews
# 17802 reviews are now in the bag, so to speak
# 2024-04-03 19:32:32
#
# Scraped 54 users this round
# Got 359 reivews
# 18161 reviews are now in the bag, so to speak
# 2024-04-03 19:34:07
#
# Scraped 53 users this round
# Got 334 reivews
# 18495 reviews are now in the bag, so to speak
# 2024-04-03 19:35:39
#
# Scraped 55 users this round
# Got 347 reivews
# 18842 reviews are now in the bag, so to speak
# 2024-04-03 19:37:17
#
# Scraped 52 users this round
# Got 363 reivews
# 19205 reviews are now in the bag, so to speak
# 2024-04-03 19:38:48
#
# Scraped 56 users this round
# Got 376 reivews
# 19581 reviews are now in the bag, so to speak
# 2024-04-03 19:40:21
#
# Scraped 57 users this round
# Got 329 reivews
# 19910 reviews are now in the bag, so to speak
# 2024-04-03 19:41:55
#
# Scraped 55 users this round
# Got 336 reivews
# 20246 reviews are now in the bag, so to speak
# 2024-04-03 19:43:36
#
# Scraped 55 users this round
# Got 342 reivews
# 20588 reviews are now in the bag, so to speak
# 2024-04-03 19:45:23
#
# Scraped 55 users this round
# Got 354 reivews
# 20942 reviews are now in the bag, so to speak
# 2024-04-03 19:46:57
#
# Scraped 59 users this round
# Got 351 reivews
# 21293 reviews are now in the bag, so to speak
# 2024-04-03 19:48:34
#
# Scraped 55 users this round
# Got 340 reivews
# 21633 reviews are now in the bag, so to speak
# 2024-04-03 19:50:14
#
# Scraped 55 users this round
# Got 354 reivews
# 21987 reviews are now in the bag, so to speak
# 2024-04-03 19:52:02
#
# Scraped 59 users this round
# Got 319 reivews
# 22306 reviews are now in the bag, so to speak
# 2024-04-03 19:53:44
#
# Scraped 56 users this round
# Got 335 reivews
# 22641 reviews are now in the bag, so to speak
# 2024-04-03 19:55:38
#
# Scraped 57 users this round
# Got 320 reivews
# 22961 reviews are now in the bag, so to speak
# 2024-04-03 19:57:16
#
# Scraped 52 users this round
# Got 363 reivews
# 23324 reviews are now in the bag, so to speak
# 2024-04-03 19:58:41
#
# Scraped 54 users this round
# Got 321 reivews
# 23645 reviews are now in the bag, so to speak
# 2024-04-03 20:00:13
#
# Scraped 54 users this round
# Got 363 reivews
# 24008 reviews are now in the bag, so to speak
# 2024-04-03 20:01:50
#
# Scraped 57 users this round
# Got 348 reivews
# 24356 reviews are now in the bag, so to speak
# 2024-04-03 20:03:33
#
# Scraped 54 users this round
# Got 284 reivews
# 24640 reviews are now in the bag, so to speak
# 2024-04-03 20:05:04
#
# Scraped 53 users this round
# Got 290 reivews
# 24930 reviews are now in the bag, so to speak
# 2024-04-03 20:06:33
#
# Scraped 56 users this round
# Got 343 reivews
# 25273 reviews are now in the bag, so to speak
# 2024-04-03 20:08:14
#
# Scraped 57 users this round
# Got 371 reivews
# 25644 reviews are now in the bag, so to speak
# 2024-04-03 20:09:53
#
# Scraped 52 users this round
# Got 350 reivews
# 25994 reviews are now in the bag, so to speak
# 2024-04-03 20:11:26
#
# Scraped 57 users this round
# Got 296 reivews
# 26290 reviews are now in the bag, so to speak
# 2024-04-03 20:13:06
#
# Scraped 53 users this round
# Got 322 reivews
# 26612 reviews are now in the bag, so to speak
# 2024-04-03 20:14:34
#
# Scraped 58 users this round
# Got 341 reivews
# 26953 reviews are now in the bag, so to speak
# 2024-04-03 20:16:11
#
# Scraped 57 users this round
# Got 357 reivews
# 27310 reviews are now in the bag, so to speak
# 2024-04-03 20:17:59
#
# Scraped 55 users this round
# Got 304 reivews
# 27614 reviews are now in the bag, so to speak
# 2024-04-03 20:19:32
#
# Scraped 56 users this round
# Got 351 reivews
# 27965 reviews are now in the bag, so to speak
# 2024-04-03 20:21:04
#
# Scraped 53 users this round
# Got 373 reivews
# 28338 reviews are now in the bag, so to speak
# 2024-04-03 20:22:39
#
# Scraped 54 users this round
# Got 323 reivews
# 28661 reviews are now in the bag, so to speak
# 2024-04-03 20:24:23
#
# Scraped 57 users this round
# Got 329 reivews
# 28990 reviews are now in the bag, so to speak
# 2024-04-03 20:25:56
#
# Scraped 57 users this round
# Got 366 reivews
# 29356 reviews are now in the bag, so to speak
# 2024-04-03 20:27:34
#
# Scraped 54 users this round
# Got 340 reivews
# 29696 reviews are now in the bag, so to speak
# 2024-04-03 20:29:14
#
# Scraped 61 users this round
# Got 357 reivews
# 30053 reviews are now in the bag, so to speak
# 2024-04-03 20:30:50
#
# Scraped 58 users this round
# Got 339 reivews
# 30392 reviews are now in the bag, so to speak
# 2024-04-03 20:32:24
#
# Scraped 58 users this round
# Got 338 reivews
# 30730 reviews are now in the bag, so to speak
# 2024-04-03 20:34:05
#
# Scraped 60 users this round
# Got 329 reivews
# 31059 reviews are now in the bag, so to speak
# 2024-04-03 20:35:52
#
# Scraped 57 users this round
# Got 327 reivews
# 31386 reviews are now in the bag, so to speak
# 2024-04-03 20:37:27
#
# Scraped 56 users this round
# Got 338 reivews
# 31724 reviews are now in the bag, so to speak
# 2024-04-03 20:39:01
#
# Scraped 56 users this round
# Got 317 reivews
# 32041 reviews are now in the bag, so to speak
# 2024-04-03 20:40:37
#
# Scraped 59 users this round
# Got 301 reivews
# 32342 reviews are now in the bag, so to speak
# 2024-04-03 20:42:21
#
# Scraped 55 users this round
# Got 348 reivews
# 32690 reviews are now in the bag, so to speak
# 2024-04-03 20:43:58
#
# Scraped 56 users this round
# Got 368 reivews
# 33058 reviews are now in the bag, so to speak
# 2024-04-03 20:45:24
#
# Scraped 56 users this round
# Got 363 reivews
# 33421 reviews are now in the bag, so to speak
# 2024-04-03 20:47:00
#
# Scraped 58 users this round
# Got 332 reivews
# 33753 reviews are now in the bag, so to speak
# 2024-04-03 20:48:33
#
# Scraped 55 users this round
# Got 370 reivews
# 34123 reviews are now in the bag, so to speak
# 2024-04-03 20:50:13
#
# Scraped 63 users this round
# Got 367 reivews
# 34490 reviews are now in the bag, so to speak
# 2024-04-03 20:52:05
#
# Scraped 55 users this round
# Got 323 reivews
# 34813 reviews are now in the bag, so to speak
# 2024-04-03 20:53:42
#
# Scraped 57 users this round
# Got 364 reivews
# 35177 reviews are now in the bag, so to speak
# 2024-04-03 20:55:16
#
# Scraped 57 users this round
# Got 339 reivews
# 35516 reviews are now in the bag, so to speak
# 2024-04-03 20:56:59
#
# Scraped 57 users this round
# Got 329 reivews
# 35845 reviews are now in the bag, so to speak
# 2024-04-03 20:58:34
#
# Scraped 58 users this round
# Got 377 reivews
# 36222 reviews are now in the bag, so to speak
# 2024-04-03 21:00:15
#
# Scraped 51 users this round
# Got 367 reivews
# 36589 reviews are now in the bag, so to speak
# 2024-04-03 21:01:47
#
# Scraped 57 users this round
# Got 323 reivews
# 36912 reviews are now in the bag, so to speak
# 2024-04-03 21:03:30
#
# Scraped 58 users this round
# Got 344 reivews
# 37256 reviews are now in the bag, so to speak
# 2024-04-03 21:05:08
#
# Scraped 58 users this round
# Got 343 reivews
# 37599 reviews are now in the bag, so to speak
# 2024-04-03 21:06:51
#
# Scraped 56 users this round
# Got 315 reivews
# 37914 reviews are now in the bag, so to speak
# 2024-04-03 21:08:37
#
# Scraped 62 users this round
# Got 299 reivews
# 38213 reviews are now in the bag, so to speak
# 2024-04-03 21:10:33
#
# Scraped 56 users this round
# Got 339 reivews
# 38552 reviews are now in the bag, so to speak
# 2024-04-03 21:12:12
#
# Scraped 55 users this round
# Got 323 reivews
# 38875 reviews are now in the bag, so to speak
# 2024-04-03 21:13:52
#
# Scraped 56 users this round
# Got 323 reivews
# 39198 reviews are now in the bag, so to speak
# 2024-04-03 21:15:43
#
# Scraped 61 users this round
# Got 377 reivews
# 39575 reviews are now in the bag, so to speak
# 2024-04-03 21:17:31
#
# Scraped 56 users this round
# Got 359 reivews
# 39934 reviews are now in the bag, so to speak
# 2024-04-03 21:19:10
#
# Scraped 54 users this round
# Got 326 reivews
# 40260 reviews are now in the bag, so to speak
# 2024-04-03 21:20:47
#
# Scraped 56 users this round
# Got 348 reivews
# 40608 reviews are now in the bag, so to speak
# 2024-04-03 21:22:23
#
# Scraped 56 users this round
# Got 375 reivews
# 40983 reviews are now in the bag, so to speak
# 2024-04-03 21:24:04
#
# Scraped 56 users this round
# Got 384 reivews
# 41367 reviews are now in the bag, so to speak
# 2024-04-03 21:25:41
#
# Scraped 62 users this round
# Got 372 reivews
# 41739 reviews are now in the bag, so to speak
# 2024-04-03 21:27:27
#
# Scraped 54 users this round
# Got 362 reivews
# 42101 reviews are now in the bag, so to speak
# 2024-04-03 21:29:03
#
# Scraped 53 users this round
# Got 285 reivews
# 42386 reviews are now in the bag, so to speak
# 2024-04-03 21:30:29
#
# Scraped 56 users this round
# Got 313 reivews
# 42699 reviews are now in the bag, so to speak
# 2024-04-03 21:32:02
#
# Scraped 55 users this round
# Got 319 reivews
# 43018 reviews are now in the bag, so to speak
# 2024-04-03 21:33:31
#
# Scraped 56 users this round
# Got 322 reivews
# 43340 reviews are now in the bag, so to speak
# 2024-04-03 21:35:05
#
# Scraped 58 users this round
# Got 297 reivews
# 43637 reviews are now in the bag, so to speak
# 2024-04-03 21:36:47
#
# Scraped 57 users this round
# Got 357 reivews
# 43994 reviews are now in the bag, so to speak
# 2024-04-03 21:38:20
#
# Scraped 56 users this round
# Got 333 reivews
# 44327 reviews are now in the bag, so to speak
# 2024-04-03 21:39:58
#
# Scraped 59 users this round
# Got 364 reivews
# 44691 reviews are now in the bag, so to speak
# 2024-04-03 21:41:39
#
# Scraped 55 users this round
# Got 322 reivews
# 45013 reviews are now in the bag, so to speak
# 2024-04-03 21:43:18
#
# Scraped 53 users this round
# Got 321 reivews
# 45334 reviews are now in the bag, so to speak
# 2024-04-03 21:44:54
#
# Scraped 56 users this round
# Got 353 reivews
# 45687 reviews are now in the bag, so to speak
# 2024-04-03 21:46:33
#
# Scraped 51 users this round
# Got 347 reivews
# 46034 reviews are now in the bag, so to speak
# 2024-04-03 21:47:56
#
# Scraped 58 users this round
# Got 318 reivews
# 46352 reviews are now in the bag, so to speak
# 2024-04-03 21:49:35
#
# Scraped 53 users this round
# Got 356 reivews
# 46708 reviews are now in the bag, so to speak
# 2024-04-03 21:51:05
#
# Scraped 53 users this round
# Got 369 reivews
# 47077 reviews are now in the bag, so to speak
# 2024-04-03 21:52:42
#
# Scraped 57 users this round
# Got 402 reivews
# 47479 reviews are now in the bag, so to speak
# 2024-04-03 21:54:25
#
# Scraped 57 users this round
# Got 315 reivews
# 47794 reviews are now in the bag, so to speak
# 2024-04-03 21:56:12
#
# Scraped 58 users this round
# Got 319 reivews
# 48113 reviews are now in the bag, so to speak
# 2024-04-03 21:57:47
#
# Scraped 59 users this round
# Got 321 reivews
# 48434 reviews are now in the bag, so to speak
# 2024-04-03 21:59:31
#
# Scraped 57 users this round
# Got 331 reivews
# 48765 reviews are now in the bag, so to speak
# 2024-04-03 22:01:09
#
# Scraped 55 users this round
# Got 346 reivews
# 49111 reviews are now in the bag, so to speak
# 2024-04-03 22:02:47
#
# Scraped 55 users this round
# Got 355 reivews
# 49466 reviews are now in the bag, so to speak
# 2024-04-03 22:04:20
#
# Scraped 62 users this round
# Got 339 reivews
# 49805 reviews are now in the bag, so to speak
# 2024-04-03 22:06:12
#
# Scraped 60 users this round
# Got 315 reivews
# 50120 reviews are now in the bag, so to speak
# 2024-04-03 22:08:10
#
# Scraped 61 users this round
# Got 372 reivews
# 50492 reviews are now in the bag, so to speak
# 2024-04-03 22:09:59
#
# Scraped 57 users this round
# Got 352 reivews
# 50844 reviews are now in the bag, so to speak
# 2024-04-03 22:11:40
#
# Scraped 58 users this round
# Got 383 reivews
# 51227 reviews are now in the bag, so to speak
# 2024-04-03 22:13:20
#
# Scraped 53 users this round
# Got 319 reivews
# 51546 reviews are now in the bag, so to speak
# 2024-04-03 22:15:01
#
# Scraped 58 users this round
# Got 358 reivews
# 51904 reviews are now in the bag, so to speak
# 2024-04-03 22:16:39
#
# Scraped 59 users this round
# Got 383 reivews
# 52287 reviews are now in the bag, so to speak
# 2024-04-03 22:18:23
#
# Scraped 53 users this round
# Got 386 reivews
# 52673 reviews are now in the bag, so to speak
# 2024-04-03 22:19:59
#
# Scraped 53 users this round
# Got 346 reivews
# 53019 reviews are now in the bag, so to speak
# 2024-04-03 22:21:35
#
# Scraped 58 users this round
# Got 320 reivews
# 53339 reviews are now in the bag, so to speak
# 2024-04-03 22:23:33
#
# Scraped 57 users this round
# Got 367 reivews
# 53706 reviews are now in the bag, so to speak
# 2024-04-03 22:25:42
#
# Scraped 54 users this round
# Got 316 reivews
# 54022 reviews are now in the bag, so to speak
# 2024-04-03 22:28:23
#
# Scraped 58 users this round
# Got 348 reivews
# 54370 reviews are now in the bag, so to speak
# 2024-04-03 22:31:44
#
# Scraped 57 users this round
# Got 343 reivews
# 54713 reviews are now in the bag, so to speak
# 2024-04-03 22:34:43
#
# Scraped 58 users this round
# Got 351 reivews
# 55064 reviews are now in the bag, so to speak
# 2024-04-03 22:37:59
#
# Scraped 55 users this round
# Got 327 reivews
# 55391 reviews are now in the bag, so to speak
# 2024-04-03 22:40:49
#
# Scraped 53 users this round
# Got 317 reivews
# 55708 reviews are now in the bag, so to speak
# 2024-04-03 22:43:36
#
# Scraped 56 users this round
# Got 303 reivews
# 56011 reviews are now in the bag, so to speak
# 2024-04-03 22:46:37
#
# Scraped 52 users this round
# Got 323 reivews
# 56334 reviews are now in the bag, so to speak
# 2024-04-03 22:49:11
#
# Scraped 61 users this round
# Got 373 reivews
# 56707 reviews are now in the bag, so to speak
# 2024-04-03 22:52:28
#
# Scraped 58 users this round
# Got 359 reivews
# 57066 reviews are now in the bag, so to speak
# 2024-04-03 22:55:26
#
# Scraped 54 users this round
# Got 353 reivews
# 57419 reviews are now in the bag, so to speak
# 2024-04-03 22:58:21
#
# Scraped 53 users this round
# Got 383 reivews
# 57802 reviews are now in the bag, so to speak
# 2024-04-03 23:01:19
#
# Scraped 55 users this round
# Got 323 reivews
# 58125 reviews are now in the bag, so to speak
# 2024-04-03 23:03:47
#
# Scraped 58 users this round
# Got 351 reivews
# 58476 reviews are now in the bag, so to speak
# 2024-04-03 23:06:50
#
# Scraped 52 users this round
# Got 315 reivews
# 58791 reviews are now in the bag, so to speak
# 2024-04-03 23:09:41
#
# Scraped 59 users this round
# Got 329 reivews
# 59120 reviews are now in the bag, so to speak
# 2024-04-03 23:12:52
#
# Scraped 53 users this round
# Got 397 reivews
# 59517 reviews are now in the bag, so to speak
# 2024-04-03 23:15:11
#
# Scraped 55 users this round
# Got 336 reivews
# 59853 reviews are now in the bag, so to speak
# 2024-04-03 23:16:54
#
# Scraped 55 users this round
# Got 332 reivews
# 60185 reviews are now in the bag, so to speak
# 2024-04-03 23:18:38
#
# Scraped 57 users this round
# Got 372 reivews
# 60557 reviews are now in the bag, so to speak
# 2024-04-03 23:20:17
#
# Scraped 54 users this round
# Got 328 reivews
# 60885 reviews are now in the bag, so to speak
# 2024-04-03 23:21:45
#
# Scraped 57 users this round
# Got 397 reivews
# 61282 reviews are now in the bag, so to speak
# 2024-04-03 23:23:23
#
# Scraped 55 users this round
# Got 345 reivews
# 61627 reviews are now in the bag, so to speak
# 2024-04-03 23:24:57
#
# Scraped 55 users this round
# Got 295 reivews
# 61922 reviews are now in the bag, so to speak
# 2024-04-03 23:26:31
#
# Scraped 54 users this round
# Got 354 reivews
# 62276 reviews are now in the bag, so to speak
# 2024-04-03 23:28:01
#
# Scraped 58 users this round
# Got 317 reivews
# 62593 reviews are now in the bag, so to speak
# 2024-04-03 23:29:33
#
# Scraped 54 users this round
# Got 330 reivews
# 62923 reviews are now in the bag, so to speak
# 2024-04-03 23:31:06
#
# Scraped 59 users this round
# Got 347 reivews
# 63270 reviews are now in the bag, so to speak
# 2024-04-03 23:32:43
#
# Scraped 54 users this round
# Got 318 reivews
# 63588 reviews are now in the bag, so to speak
# 2024-04-03 23:34:17
#
# Scraped 53 users this round
# Got 367 reivews
# 63955 reviews are now in the bag, so to speak
# 2024-04-03 23:35:48
#
# Scraped 54 users this round
# Got 359 reivews
# 64314 reviews are now in the bag, so to speak
# 2024-04-03 23:37:23
#
# Scraped 58 users this round
# Got 364 reivews
# 64678 reviews are now in the bag, so to speak
# 2024-04-03 23:39:03
#
# Scraped 56 users this round
# Got 335 reivews
# 65013 reviews are now in the bag, so to speak
# 2024-04-03 23:40:50
#
# Scraped 55 users this round
# Got 368 reivews
# 65381 reviews are now in the bag, so to speak
# 2024-04-03 23:42:31
#
# Scraped 59 users this round
# Got 321 reivews
# 65702 reviews are now in the bag, so to speak
# 2024-04-03 23:44:11
#
# Scraped 58 users this round
# Got 332 reivews
# 66034 reviews are now in the bag, so to speak
# 2024-04-03 23:45:48
#
# Scraped 55 users this round
# Got 309 reivews
# 66343 reviews are now in the bag, so to speak
# 2024-04-03 23:47:21
#
# Scraped 52 users this round
# Got 377 reivews
# 66720 reviews are now in the bag, so to speak
# 2024-04-03 23:48:50
#
# Scraped 57 users this round
# Got 357 reivews
# 67077 reviews are now in the bag, so to speak
# 2024-04-03 23:50:33
#
# Scraped 56 users this round
# Got 328 reivews
# 67405 reviews are now in the bag, so to speak
# 2024-04-03 23:52:13
#
# Scraped 55 users this round
# Got 325 reivews
# 67730 reviews are now in the bag, so to speak
# 2024-04-03 23:53:46
#
# Scraped 56 users this round
# Got 347 reivews
# 68077 reviews are now in the bag, so to speak
# 2024-04-03 23:55:19
#
# Scraped 60 users this round
# Got 365 reivews
# 68442 reviews are now in the bag, so to speak
# 2024-04-03 23:57:05
#
# Scraped 58 users this round
# Got 342 reivews
# 68784 reviews are now in the bag, so to speak
# 2024-04-03 23:58:51
#
# Scraped 54 users this round
# Got 328 reivews
# 69112 reviews are now in the bag, so to speak
# 2024-04-04 00:00:27
#
# Scraped 62 users this round
# Got 352 reivews
# 69464 reviews are now in the bag, so to speak
# 2024-04-04 00:02:04
#
# Scraped 53 users this round
# Got 384 reivews
# 69848 reviews are now in the bag, so to speak
# 2024-04-04 00:03:36
#
# Scraped 56 users this round
# Got 341 reivews
# 70189 reviews are now in the bag, so to speak
# 2024-04-04 00:05:07
#
# Scraped 56 users this round
# Got 315 reivews
# 70504 reviews are now in the bag, so to speak
# 2024-04-04 00:06:35
#
# Scraped 56 users this round
# Got 337 reivews
# 70841 reviews are now in the bag, so to speak
# 2024-04-04 00:08:12
#
# Scraped 62 users this round
# Got 351 reivews
# 71192 reviews are now in the bag, so to speak
# 2024-04-04 00:10:06
#
# Scraped 54 users this round
# Got 350 reivews
# 71542 reviews are now in the bag, so to speak
# 2024-04-04 00:11:44
#
# Scraped 54 users this round
# Got 380 reivews
# 71922 reviews are now in the bag, so to speak
# 2024-04-04 00:13:24
#
# Scraped 56 users this round
# Got 319 reivews
# 72241 reviews are now in the bag, so to speak
# 2024-04-04 00:15:00
#
# Scraped 51 users this round
# Got 351 reivews
# 72592 reviews are now in the bag, so to speak
# 2024-04-04 00:16:25
#
# Scraped 60 users this round
# Got 375 reivews
# 72967 reviews are now in the bag, so to speak
# 2024-04-04 00:18:07
#
# Scraped 55 users this round
# Got 365 reivews
# 73332 reviews are now in the bag, so to speak
# 2024-04-04 00:19:48
#
# Scraped 57 users this round
# Got 346 reivews
# 73678 reviews are now in the bag, so to speak
# 2024-04-04 00:21:28
#
# Scraped 53 users this round
# Got 330 reivews
# 74008 reviews are now in the bag, so to speak
# 2024-04-04 00:23:03
#
# Scraped 54 users this round
# Got 355 reivews
# 74363 reviews are now in the bag, so to speak
# 2024-04-04 00:24:31
#
# Scraped 54 users this round
# Got 354 reivews
# 74717 reviews are now in the bag, so to speak
# 2024-04-04 00:26:04
#
# Scraped 57 users this round
# Got 333 reivews
# 75050 reviews are now in the bag, so to speak
# 2024-04-04 00:27:39
#
# Scraped 55 users this round
# Got 310 reivews
# 75360 reviews are now in the bag, so to speak
# 2024-04-04 00:29:07
#
# Scraped 55 users this round
# Got 355 reivews
# 75715 reviews are now in the bag, so to speak
# 2024-04-04 00:30:44
#
# Scraped 54 users this round
# Got 302 reivews
# 76017 reviews are now in the bag, so to speak
# 2024-04-04 00:32:25
#
# Scraped 52 users this round
# Got 371 reivews
# 76388 reviews are now in the bag, so to speak
# 2024-04-04 00:34:02
#
# Scraped 56 users this round
# Got 348 reivews
# 76736 reviews are now in the bag, so to speak
# 2024-04-04 00:35:37
#
# Scraped 59 users this round
# Got 308 reivews
# 77044 reviews are now in the bag, so to speak
# 2024-04-04 00:37:15
#
# Scraped 60 users this round
# Got 306 reivews
# 77350 reviews are now in the bag, so to speak
# 2024-04-04 00:38:52
#
# Scraped 52 users this round
# Got 340 reivews
# 77690 reviews are now in the bag, so to speak
# 2024-04-04 00:40:25
#
# Scraped 55 users this round
# Got 320 reivews
# 78010 reviews are now in the bag, so to speak
# 2024-04-04 00:42:00
#
# Scraped 56 users this round
# Got 323 reivews
# 78333 reviews are now in the bag, so to speak
# 2024-04-04 00:43:27
#
# Scraped 55 users this round
# Got 372 reivews
# 78705 reviews are now in the bag, so to speak
# 2024-04-04 00:45:08
#
# Scraped 53 users this round
# Got 328 reivews
# 79033 reviews are now in the bag, so to speak
# 2024-04-04 00:46:37
#
# Scraped 53 users this round
# Got 334 reivews
# 79367 reviews are now in the bag, so to speak
# 2024-04-04 00:48:03
#
# Scraped 55 users this round
# Got 331 reivews
# 79698 reviews are now in the bag, so to speak
# 2024-04-04 00:49:31
#
# Scraped 55 users this round
# Got 361 reivews
# 80059 reviews are now in the bag, so to speak
# 2024-04-04 00:50:58
#
# Scraped 58 users this round
# Got 330 reivews
# 80389 reviews are now in the bag, so to speak
# 2024-04-04 00:52:34
#
# Scraped 55 users this round
# Got 327 reivews
# 80716 reviews are now in the bag, so to speak
# 2024-04-04 00:54:07
#
# Scraped 60 users this round
# Got 340 reivews
# 81056 reviews are now in the bag, so to speak
# 2024-04-04 00:55:51
#
# Scraped 57 users this round
# Got 341 reivews
# 81397 reviews are now in the bag, so to speak
# 2024-04-04 00:57:32
#
# Scraped 58 users this round
# Got 332 reivews
# 81729 reviews are now in the bag, so to speak
# 2024-04-04 00:59:12
#
# Scraped 57 users this round
# Got 295 reivews
# 82024 reviews are now in the bag, so to speak
# 2024-04-04 01:00:46
#
# Scraped 60 users this round
# Got 326 reivews
# 82350 reviews are now in the bag, so to speak
# 2024-04-04 01:02:24
#
# Scraped 53 users this round
# Got 340 reivews
# 82690 reviews are now in the bag, so to speak
# 2024-04-04 01:03:52
#
# Scraped 57 users this round
# Got 316 reivews
# 83006 reviews are now in the bag, so to speak
# 2024-04-04 01:05:27
#
# Scraped 52 users this round
# Got 318 reivews
# 83324 reviews are now in the bag, so to speak
# 2024-04-04 01:07:03
#
# Scraped 59 users this round
# Got 383 reivews
# 83707 reviews are now in the bag, so to speak
# 2024-04-04 01:08:46
#
# Scraped 56 users this round
# Got 314 reivews
# 84021 reviews are now in the bag, so to speak
# 2024-04-04 01:10:18
#
# Scraped 58 users this round
# Got 358 reivews
# 84379 reviews are now in the bag, so to speak
# 2024-04-04 01:12:05
#
# Scraped 54 users this round
# Got 338 reivews
# 84717 reviews are now in the bag, so to speak
# 2024-04-04 01:13:36
#
# Scraped 56 users this round
# Got 338 reivews
# 85055 reviews are now in the bag, so to speak
# 2024-04-04 01:15:09
#
# Scraped 55 users this round
# Got 350 reivews
# 85405 reviews are now in the bag, so to speak
# 2024-04-04 01:16:46
#
# Scraped 53 users this round
# Got 322 reivews
# 85727 reviews are now in the bag, so to speak
# 2024-04-04 01:18:17
#
# Scraped 52 users this round
# Got 351 reivews
# 86078 reviews are now in the bag, so to speak
# 2024-04-04 01:19:47
#
# Scraped 54 users this round
# Got 330 reivews
# 86408 reviews are now in the bag, so to speak
# 2024-04-04 01:21:11
#
# Scraped 52 users this round
# Got 326 reivews
# 86734 reviews are now in the bag, so to speak
# 2024-04-04 01:22:34
#
# Scraped 56 users this round
# Got 348 reivews
# 87082 reviews are now in the bag, so to speak
# 2024-04-04 01:24:12
#
# Scraped 52 users this round
# Got 341 reivews
# 87423 reviews are now in the bag, so to speak
# 2024-04-04 01:25:36
#
# Scraped 57 users this round
# Got 369 reivews
# 87792 reviews are now in the bag, so to speak
# 2024-04-04 01:27:29
#
# Scraped 55 users this round
# Got 310 reivews
# 88102 reviews are now in the bag, so to speak
# 2024-04-04 01:28:55
#
# Scraped 58 users this round
# Got 316 reivews
# 88418 reviews are now in the bag, so to speak
# 2024-04-04 01:30:35
#
# Scraped 56 users this round
# Got 356 reivews
# 88774 reviews are now in the bag, so to speak
# 2024-04-04 01:32:14
#
# Scraped 58 users this round
# Got 371 reivews
# 89145 reviews are now in the bag, so to speak
# 2024-04-04 01:33:50
#
# Scraped 57 users this round
# Got 299 reivews
# 89444 reviews are now in the bag, so to speak
# 2024-04-04 01:35:24
#
# Scraped 62 users this round
# Got 345 reivews
# 89789 reviews are now in the bag, so to speak
# 2024-04-04 01:37:07
#
# Scraped 59 users this round
# Got 345 reivews
# 90134 reviews are now in the bag, so to speak
# 2024-04-04 01:38:46
#
# Scraped 57 users this round
# Got 331 reivews
# 90465 reviews are now in the bag, so to speak
# 2024-04-04 01:40:25
#
# Scraped 57 users this round
# Got 346 reivews
# 90811 reviews are now in the bag, so to speak
# 2024-04-04 01:41:53
#
# Scraped 56 users this round
# Got 378 reivews
# 91189 reviews are now in the bag, so to speak
# 2024-04-04 01:43:23
#
# Scraped 55 users this round
# Got 364 reivews
# 91553 reviews are now in the bag, so to speak
# 2024-04-04 01:44:53
#
# Scraped 54 users this round
# Got 333 reivews
# 91886 reviews are now in the bag, so to speak
# 2024-04-04 01:46:16
#
# Scraped 57 users this round
# Got 350 reivews
# 92236 reviews are now in the bag, so to speak
# 2024-04-04 01:47:53
#
# Scraped 59 users this round
# Got 345 reivews
# 92581 reviews are now in the bag, so to speak
# 2024-04-04 01:49:34
#
# Scraped 55 users this round
# Got 369 reivews
# 92950 reviews are now in the bag, so to speak
# 2024-04-04 01:51:05
#
# Scraped 53 users this round
# Got 354 reivews
# 93304 reviews are now in the bag, so to speak
# 2024-04-04 01:52:36
#
# Scraped 56 users this round
# Got 295 reivews
# 93599 reviews are now in the bag, so to speak
# 2024-04-04 01:54:06
#
# Scraped 56 users this round
# Got 372 reivews
# 93971 reviews are now in the bag, so to speak
# 2024-04-04 01:55:47
#
# Scraped 55 users this round
# Got 370 reivews
# 94341 reviews are now in the bag, so to speak
# 2024-04-04 01:57:17
#
# Scraped 54 users this round
# Got 351 reivews
# 94692 reviews are now in the bag, so to speak
# 2024-04-04 01:59:00
#
# Scraped 55 users this round
# Got 358 reivews
# 95050 reviews are now in the bag, so to speak
# 2024-04-04 02:00:28
#
# Scraped 55 users this round
# Got 324 reivews
# 95374 reviews are now in the bag, so to speak
# 2024-04-04 02:01:57
#
# Scraped 57 users this round
# Got 353 reivews
# 95727 reviews are now in the bag, so to speak
# 2024-04-04 02:03:36
#
# Scraped 54 users this round
# Got 359 reivews
# 96086 reviews are now in the bag, so to speak
# 2024-04-04 02:05:02
#
# Scraped 59 users this round
# Got 333 reivews
# 96419 reviews are now in the bag, so to speak
# 2024-04-04 02:06:58
#
# Scraped 52 users this round
# Got 310 reivews
# 96729 reviews are now in the bag, so to speak
# 2024-04-04 02:08:31
#
# Scraped 50 users this round
# Got 328 reivews
# 97057 reviews are now in the bag, so to speak
# 2024-04-04 02:10:08
#
# Scraped 61 users this round
# Got 321 reivews
# 97378 reviews are now in the bag, so to speak
# 2024-04-04 02:11:51
#
# Scraped 59 users this round
# Got 322 reivews
# 97700 reviews are now in the bag, so to speak
# 2024-04-04 02:13:33
#
# Scraped 59 users this round
# Got 341 reivews
# 98041 reviews are now in the bag, so to speak
# 2024-04-04 02:15:10
#
# Scraped 53 users this round
# Got 337 reivews
# 98378 reviews are now in the bag, so to speak
# 2024-04-04 02:16:37
#
# Scraped 52 users this round
# Got 318 reivews
# 98696 reviews are now in the bag, so to speak
# 2024-04-04 02:18:04
#
# Scraped 58 users this round
# Got 312 reivews
# 99008 reviews are now in the bag, so to speak
# 2024-04-04 02:19:53
#
# Scraped 54 users this round
# Got 350 reivews
# 99358 reviews are now in the bag, so to speak
# 2024-04-04 02:21:34
#
# Scraped 57 users this round
# Got 345 reivews
# 99703 reviews are now in the bag, so to speak
# 2024-04-04 02:23:11
#
# Scraped 58 users this round
# Got 380 reivews
# 100083 reviews are now in the bag, so to speak
# 2024-04-04 02:24:52
#
# Scraped 59 users this round
# Got 308 reivews
# 100391 reviews are now in the bag, so to speak
# 2024-04-04 02:26:31
#
# Scraped 56 users this round
# Got 332 reivews
# 100723 reviews are now in the bag, so to speak
# 2024-04-04 02:28:01
#
# Scraped 54 users this round
# Got 340 reivews
# 101063 reviews are now in the bag, so to speak
# 2024-04-04 02:29:27
#
# Scraped 56 users this round
# Got 312 reivews
# 101375 reviews are now in the bag, so to speak
# 2024-04-04 02:31:03
#
# Scraped 53 users this round
# Got 351 reivews
# 101726 reviews are now in the bag, so to speak
# 2024-04-04 02:32:39
#
# Scraped 57 users this round
# Got 355 reivews
# 102081 reviews are now in the bag, so to speak
# 2024-04-04 02:34:20
#
# Scraped 57 users this round
# Got 361 reivews
# 102442 reviews are now in the bag, so to speak
# 2024-04-04 02:35:56
#
# Scraped 58 users this round
# Got 363 reivews
# 102805 reviews are now in the bag, so to speak
# 2024-04-04 02:37:29
#
# Scraped 59 users this round
# Got 346 reivews
# 103151 reviews are now in the bag, so to speak
# 2024-04-04 02:39:05
#
# Scraped 54 users this round
# Got 347 reivews
# 103498 reviews are now in the bag, so to speak
# 2024-04-04 02:40:32
#
# Scraped 60 users this round
# Got 377 reivews
# 103875 reviews are now in the bag, so to speak
# 2024-04-04 02:42:11
#
# Scraped 55 users this round
# Got 320 reivews
# 104195 reviews are now in the bag, so to speak
# 2024-04-04 02:43:43
#
# Scraped 62 users this round
# Got 330 reivews
# 104525 reviews are now in the bag, so to speak
# 2024-04-04 02:45:25
#
# Scraped 55 users this round
# Got 339 reivews
# 104864 reviews are now in the bag, so to speak
# 2024-04-04 02:46:56
#
# Scraped 58 users this round
# Got 361 reivews
# 105225 reviews are now in the bag, so to speak
# 2024-04-04 02:48:33
#
# Scraped 55 users this round
# Got 337 reivews
# 105562 reviews are now in the bag, so to speak
# 2024-04-04 02:50:04
#
# Scraped 54 users this round
# Got 305 reivews
# 105867 reviews are now in the bag, so to speak
# 2024-04-04 02:51:29
#
# Scraped 60 users this round
# Got 323 reivews
# 106190 reviews are now in the bag, so to speak
# 2024-04-04 02:53:20
#
# Scraped 51 users this round
# Got 334 reivews
# 106524 reviews are now in the bag, so to speak
# 2024-04-04 02:54:40
#
# Scraped 61 users this round
# Got 373 reivews
# 106897 reviews are now in the bag, so to speak
# 2024-04-04 02:56:32
#
# Scraped 57 users this round
# Got 333 reivews
# 107230 reviews are now in the bag, so to speak
# 2024-04-04 02:58:02
#
# Scraped 55 users this round
# Got 321 reivews
# 107551 reviews are now in the bag, so to speak
# 2024-04-04 02:59:32
#
# Scraped 57 users this round
# Got 311 reivews
# 107862 reviews are now in the bag, so to speak
# 2024-04-04 03:01:08
#
# Scraped 53 users this round
# Got 300 reivews
# 108162 reviews are now in the bag, so to speak
# 2024-04-04 03:02:45
#
# Scraped 62 users this round
# Got 350 reivews
# 108512 reviews are now in the bag, so to speak
# 2024-04-04 03:04:23
#
# Scraped 55 users this round
# Got 341 reivews
# 108853 reviews are now in the bag, so to speak
# 2024-04-04 03:05:58
#
# Scraped 55 users this round
# Got 360 reivews
# 109213 reviews are now in the bag, so to speak
# 2024-04-04 03:07:31
#
# Scraped 52 users this round
# Got 316 reivews
# 109529 reviews are now in the bag, so to speak
# 2024-04-04 03:08:54
#
# Scraped 57 users this round
# Got 332 reivews
# 109861 reviews are now in the bag, so to speak
# 2024-04-04 03:10:32
#
# Scraped 60 users this round
# Got 358 reivews
# 110219 reviews are now in the bag, so to speak
# 2024-04-04 03:12:12
#
# Scraped 54 users this round
# Got 318 reivews
# 110537 reviews are now in the bag, so to speak
# 2024-04-04 03:13:45
#
# Scraped 56 users this round
# Got 398 reivews
# 110935 reviews are now in the bag, so to speak
# 2024-04-04 03:15:21
#
# Scraped 62 users this round
# Got 338 reivews
# 111273 reviews are now in the bag, so to speak
# 2024-04-04 03:17:13
#
# Scraped 56 users this round
# Got 317 reivews
# 111590 reviews are now in the bag, so to speak
# 2024-04-04 03:18:52
#
# Scraped 54 users this round
# Got 303 reivews
# 111893 reviews are now in the bag, so to speak
# 2024-04-04 03:20:22
#
# Scraped 56 users this round
# Got 345 reivews
# 112238 reviews are now in the bag, so to speak
# 2024-04-04 03:21:54
#
# Scraped 61 users this round
# Got 354 reivews
# 112592 reviews are now in the bag, so to speak
# 2024-04-04 03:23:55
#
# Scraped 53 users this round
# Got 359 reivews
# 112951 reviews are now in the bag, so to speak
# 2024-04-04 03:25:28
#
# Scraped 52 users this round
# Got 325 reivews
# 113276 reviews are now in the bag, so to speak
# 2024-04-04 03:26:54
#
# Scraped 56 users this round
# Got 366 reivews
# 113642 reviews are now in the bag, so to speak
# 2024-04-04 03:28:31
#
# Scraped 56 users this round
# Got 349 reivews
# 113991 reviews are now in the bag, so to speak
# 2024-04-04 03:30:14
#
# Scraped 57 users this round
# Got 346 reivews
# 114337 reviews are now in the bag, so to speak
# 2024-04-04 03:31:51
#
# Scraped 59 users this round
# Got 322 reivews
# 114659 reviews are now in the bag, so to speak
# 2024-04-04 03:33:38
#
# Scraped 56 users this round
# Got 328 reivews
# 114987 reviews are now in the bag, so to speak
# 2024-04-04 03:35:10
#
# Scraped 62 users this round
# Got 302 reivews
# 115289 reviews are now in the bag, so to speak
# 2024-04-04 03:36:55
#
# Scraped 56 users this round
# Got 342 reivews
# 115631 reviews are now in the bag, so to speak
# 2024-04-04 03:38:34
#
# Scraped 58 users this round
# Got 331 reivews
# 115962 reviews are now in the bag, so to speak
# 2024-04-04 03:40:16
#
# Scraped 53 users this round
# Got 329 reivews
# 116291 reviews are now in the bag, so to speak
# 2024-04-04 03:41:48
#
# Scraped 55 users this round
# Got 362 reivews
# 116653 reviews are now in the bag, so to speak
# 2024-04-04 03:43:20
#
# Scraped 63 users this round
# Got 375 reivews
# 117028 reviews are now in the bag, so to speak
# 2024-04-04 03:44:57
#
# Scraped 58 users this round
# Got 354 reivews
# 117382 reviews are now in the bag, so to speak
# 2024-04-04 03:46:33
#
# Scraped 55 users this round
# Got 340 reivews
# 117722 reviews are now in the bag, so to speak
# 2024-04-04 03:48:01
#
# Scraped 56 users this round
# Got 356 reivews
# 118078 reviews are now in the bag, so to speak
# 2024-04-04 03:49:37
#
# Scraped 57 users this round
# Got 392 reivews
# 118470 reviews are now in the bag, so to speak
# 2024-04-04 03:51:15
#
# Scraped 51 users this round
# Got 341 reivews
# 118811 reviews are now in the bag, so to speak
# 2024-04-04 03:52:28
#
# Scraped 61 users this round
# Got 348 reivews
# 119159 reviews are now in the bag, so to speak
# 2024-04-04 03:54:13
#
# Scraped 59 users this round
# Got 318 reivews
# 119477 reviews are now in the bag, so to speak
# 2024-04-04 03:55:40
#
# Scraped 58 users this round
# Got 282 reivews
# 119759 reviews are now in the bag, so to speak
# 2024-04-04 03:57:04
#
# Scraped 56 users this round
# Got 377 reivews
# 120136 reviews are now in the bag, so to speak
# 2024-04-04 03:58:35
#
# Scraped 55 users this round
# Got 305 reivews
# 120441 reviews are now in the bag, so to speak
# 2024-04-04 04:00:02
#
# Scraped 58 users this round
# Got 323 reivews
# 120764 reviews are now in the bag, so to speak
# 2024-04-04 04:01:38
#
# Scraped 54 users this round
# Got 362 reivews
# 121126 reviews are now in the bag, so to speak
# 2024-04-04 04:03:11
#
# Scraped 56 users this round
# Got 337 reivews
# 121463 reviews are now in the bag, so to speak
# 2024-04-04 04:04:35
#
# Scraped 59 users this round
# Got 373 reivews
# 121836 reviews are now in the bag, so to speak
# 2024-04-04 04:06:02
#
# Scraped 58 users this round
# Got 323 reivews
# 122159 reviews are now in the bag, so to speak
# 2024-04-04 04:07:28
#
# Scraped 62 users this round
# Got 329 reivews
# 122488 reviews are now in the bag, so to speak
# 2024-04-04 04:08:57
#
# Scraped 57 users this round
# Got 316 reivews
# 122804 reviews are now in the bag, so to speak
# 2024-04-04 04:10:17
#
# Scraped 58 users this round
# Got 341 reivews
# 123145 reviews are now in the bag, so to speak
# 2024-04-04 04:11:40
#
# Scraped 57 users this round
# Got 337 reivews
# 123482 reviews are now in the bag, so to speak
# 2024-04-04 04:13:00
#
# Scraped 56 users this round
# Got 336 reivews
# 123818 reviews are now in the bag, so to speak
# 2024-04-04 04:14:33
#
# Scraped 59 users this round
# Got 322 reivews
# 124140 reviews are now in the bag, so to speak
# 2024-04-04 04:16:08

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
