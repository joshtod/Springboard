# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 1

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')

# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 123 users this round
# Got 206 reivews
# 385355 reviews are now in the bag, so to speak
# 2024-04-01 09:43:32
#
# Scraped 113 users this round
# Got 182 reivews
# 385537 reviews are now in the bag, so to speak
# 2024-04-01 09:47:48
#
# Scraped 112 users this round
# Got 149 reivews
# 385686 reviews are now in the bag, so to speak
# 2024-04-01 09:51:53
#
# Scraped 110 users this round
# Got 181 reivews
# 385867 reviews are now in the bag, so to speak
# 2024-04-01 09:55:51
#
# Scraped 114 users this round
# Got 204 reivews
# 386071 reviews are now in the bag, so to speak
# 2024-04-01 09:59:58
#
# Scraped 116 users this round
# Got 182 reivews
# 386253 reviews are now in the bag, so to speak
# 2024-04-01 10:04:16
#
# Scraped 102 users this round
# Got 184 reivews
# 386437 reviews are now in the bag, so to speak
# 2024-04-01 10:07:48
#
# Scraped 107 users this round
# Got 240 reivews
# 386677 reviews are now in the bag, so to speak
# 2024-04-01 10:12:05
#
# Scraped 85 users this round
# Got 167 reivews
# 386844 reviews are now in the bag, so to speak
# 2024-04-01 10:14:59
#
# Scraped 130 users this round
# Got 163 reivews
# 387007 reviews are now in the bag, so to speak
# 2024-04-01 10:19:49
#
# Scraped 114 users this round
# Got 202 reivews
# 387209 reviews are now in the bag, so to speak
# 2024-04-01 10:24:10
#
# Scraped 113 users this round
# Got 197 reivews
# 387406 reviews are now in the bag, so to speak
# 2024-04-01 10:28:26
#
# Scraped 112 users this round
# Got 159 reivews
# 387565 reviews are now in the bag, so to speak
# 2024-04-01 10:33:12
#
# Scraped 130 users this round
# Got 184 reivews
# 387749 reviews are now in the bag, so to speak
# 2024-04-01 10:38:19
#
# Scraped 117 users this round
# Got 204 reivews
# 387953 reviews are now in the bag, so to speak
# 2024-04-01 10:42:40
#
# Scraped 102 users this round
# Got 173 reivews
# 388126 reviews are now in the bag, so to speak
# 2024-04-01 10:46:24
#
# Scraped 112 users this round
# Got 224 reivews
# 388350 reviews are now in the bag, so to speak
# 2024-04-01 10:50:39
#
# Scraped 115 users this round
# Got 204 reivews
# 388554 reviews are now in the bag, so to speak
# 2024-04-01 10:54:57
#
# Scraped 103 users this round
# Got 166 reivews
# 388720 reviews are now in the bag, so to speak
# 2024-04-01 10:58:44
#
# Scraped 126 users this round
# Got 197 reivews
# 388917 reviews are now in the bag, so to speak
# 2024-04-01 11:03:46
#
# Scraped 99 users this round
# Got 178 reivews
# 389095 reviews are now in the bag, so to speak
# 2024-04-01 11:07:28
#
# Scraped 112 users this round
# Got 205 reivews
# 389300 reviews are now in the bag, so to speak
# 2024-04-01 11:11:57
#
# Scraped 132 users this round
# Got 141 reivews
# 389441 reviews are now in the bag, so to speak
# 2024-04-01 11:17:22
#
# Scraped 106 users this round
# Got 212 reivews
# 389653 reviews are now in the bag, so to speak
# 2024-04-01 11:21:34
#
# Scraped 99 users this round
# Got 178 reivews
# 389831 reviews are now in the bag, so to speak
# 2024-04-01 11:25:32
#
# Scraped 84 users this round
# Got 191 reivews
# 390022 reviews are now in the bag, so to speak
# 2024-04-01 11:28:34
#
# Scraped 108 users this round
# Got 215 reivews
# 390237 reviews are now in the bag, so to speak
# 2024-04-01 11:32:40
#
# Scraped 112 users this round
# Got 201 reivews
# 390438 reviews are now in the bag, so to speak
# 2024-04-01 11:37:02
#
# Scraped 107 users this round
# Got 166 reivews
# 390604 reviews are now in the bag, so to speak
# 2024-04-01 11:40:55
#
# Scraped 113 users this round
# Got 243 reivews
# 390847 reviews are now in the bag, so to speak
# 2024-04-01 11:45:11
#
# Scraped 111 users this round
# Got 186 reivews
# 391033 reviews are now in the bag, so to speak
# 2024-04-01 11:49:33
#
# Scraped 116 users this round
# Got 158 reivews
# 391191 reviews are now in the bag, so to speak
# 2024-04-01 11:54:01
#
# Scraped 105 users this round
# Got 216 reivews
# 391407 reviews are now in the bag, so to speak
# 2024-04-01 11:57:49
#
# Scraped 120 users this round
# Got 208 reivews
# 391615 reviews are now in the bag, so to speak
# 2024-04-01 12:02:19
#
# Scraped 126 users this round
# Got 213 reivews
# 391828 reviews are now in the bag, so to speak
# 2024-04-01 12:07:20
#
# Scraped 106 users this round
# Got 199 reivews
# 392027 reviews are now in the bag, so to speak
# 2024-04-01 12:11:25
#
# Scraped 100 users this round
# Got 166 reivews
# 392193 reviews are now in the bag, so to speak
# 2024-04-01 12:15:12
#
# Scraped 102 users this round
# Got 190 reivews
# 392383 reviews are now in the bag, so to speak
# 2024-04-01 12:19:11
#
# Scraped 111 users this round
# Got 173 reivews
# 392556 reviews are now in the bag, so to speak
# 2024-04-01 12:23:09
#
# Scraped 109 users this round
# Got 200 reivews
# 392756 reviews are now in the bag, so to speak
# 2024-04-01 12:27:24
#
# Scraped 95 users this round
# Got 171 reivews
# 392927 reviews are now in the bag, so to speak
# 2024-04-01 12:30:48
#
# Scraped 91 users this round
# Got 220 reivews
# 393147 reviews are now in the bag, so to speak
# 2024-04-01 12:34:04
#
# Scraped 100 users this round
# Got 192 reivews
# 393339 reviews are now in the bag, so to speak
# 2024-04-01 12:37:41
#
# Scraped 112 users this round
# Got 171 reivews
# 393510 reviews are now in the bag, so to speak
# 2024-04-01 12:41:41
#
# Scraped 116 users this round
# Got 179 reivews
# 393689 reviews are now in the bag, so to speak
# 2024-04-01 12:45:57
#
# Scraped 100 users this round
# Got 195 reivews
# 393884 reviews are now in the bag, so to speak
# 2024-04-01 12:49:24
#
# Scraped 112 users this round
# Got 209 reivews
# 394093 reviews are now in the bag, so to speak
# 2024-04-01 12:53:29
#
# Scraped 92 users this round
# Got 180 reivews
# 394273 reviews are now in the bag, so to speak
# 2024-04-01 12:56:43
#
# Scraped 113 users this round
# Got 175 reivews
# 394448 reviews are now in the bag, so to speak
# 2024-04-01 13:00:43
#
# Scraped 117 users this round
# Got 162 reivews
# 394610 reviews are now in the bag, so to speak
# 2024-04-01 13:04:45
#
# Scraped 110 users this round
# Got 213 reivews
# 394823 reviews are now in the bag, so to speak
# 2024-04-01 13:08:42
#
# Scraped 118 users this round
# Got 204 reivews
# 395027 reviews are now in the bag, so to speak
# 2024-04-01 13:12:56
#
# Scraped 107 users this round
# Got 220 reivews
# 395247 reviews are now in the bag, so to speak
# 2024-04-01 13:16:37
#
# Scraped 112 users this round
# Got 198 reivews
# 395445 reviews are now in the bag, so to speak
# 2024-04-01 13:20:36
#
# Scraped 111 users this round
# Got 167 reivews
# 395612 reviews are now in the bag, so to speak
# 2024-04-01 13:24:34
#
# Scraped 102 users this round
# Got 214 reivews
# 395826 reviews are now in the bag, so to speak
# 2024-04-01 13:28:07
#
# Scraped 108 users this round
# Got 221 reivews
# 396047 reviews are now in the bag, so to speak
# 2024-04-01 13:31:58
#
# Scraped 109 users this round
# Got 179 reivews
# 396226 reviews are now in the bag, so to speak
# 2024-04-01 13:35:49
#
# Scraped 130 users this round
# Got 208 reivews
# 396434 reviews are now in the bag, so to speak
# 2024-04-01 13:40:35
#
# Scraped 128 users this round
# Got 177 reivews
# 396611 reviews are now in the bag, so to speak
# 2024-04-01 13:45:01
#
# Scraped 100 users this round
# Got 161 reivews
# 396772 reviews are now in the bag, so to speak
# 2024-04-01 13:48:27
#
# Scraped 110 users this round
# Got 213 reivews
# 396985 reviews are now in the bag, so to speak
# 2024-04-01 13:52:21
#
# Scraped 116 users this round
# Got 179 reivews
# 397164 reviews are now in the bag, so to speak
# 2024-04-01 13:56:24
#
# Scraped 101 users this round
# Got 217 reivews
# 397381 reviews are now in the bag, so to speak
# 2024-04-01 14:00:02
#
# Scraped 112 users this round
# Got 214 reivews
# 397595 reviews are now in the bag, so to speak
# 2024-04-01 14:03:52
#
# Scraped 110 users this round
# Got 175 reivews
# 397770 reviews are now in the bag, so to speak
# 2024-04-01 14:07:45
#
# Scraped 115 users this round
# Got 188 reivews
# 397958 reviews are now in the bag, so to speak
# 2024-04-01 14:11:50
#
# Scraped 118 users this round
# Got 173 reivews
# 398131 reviews are now in the bag, so to speak
# 2024-04-01 14:15:52
#
# Scraped 128 users this round
# Got 196 reivews
# 398327 reviews are now in the bag, so to speak
# 2024-04-01 14:20:29
#
# Scraped 114 users this round
# Got 183 reivews
# 398510 reviews are now in the bag, so to speak
# 2024-04-01 14:24:32
#
# Scraped 116 users this round
# Got 193 reivews
# 398703 reviews are now in the bag, so to speak
# 2024-04-01 14:28:34
#
# Scraped 110 users this round
# Got 198 reivews
# 398901 reviews are now in the bag, so to speak
# 2024-04-01 14:32:34
#
# Scraped 105 users this round
# Got 195 reivews
# 399096 reviews are now in the bag, so to speak
# 2024-04-01 14:36:12
#
# Scraped 86 users this round
# Got 174 reivews
# 399270 reviews are now in the bag, so to speak
# 2024-04-01 14:39:09
#
# Scraped 114 users this round
# Got 218 reivews
# 399488 reviews are now in the bag, so to speak
# 2024-04-01 14:43:21
#
# Scraped 117 users this round
# Got 178 reivews
# 399666 reviews are now in the bag, so to speak
# 2024-04-01 14:47:22
#
# Scraped 107 users this round
# Got 202 reivews
# 399868 reviews are now in the bag, so to speak
# 2024-04-01 14:51:16
#
# Scraped 86 users this round
# Got 200 reivews
# 400068 reviews are now in the bag, so to speak
# 2024-04-01 14:54:00
#
# Scraped 111 users this round
# Got 205 reivews
# 400273 reviews are now in the bag, so to speak
# 2024-04-01 14:57:59
#
# Scraped 99 users this round
# Got 181 reivews
# 400454 reviews are now in the bag, so to speak
# 2024-04-01 15:01:30
#
# Scraped 100 users this round
# Got 183 reivews
# 400637 reviews are now in the bag, so to speak
# 2024-04-01 15:05:07
#
# Scraped 121 users this round
# Got 162 reivews
# 400799 reviews are now in the bag, so to speak
# 2024-04-01 15:09:43
#
# Scraped 98 users this round
# Got 221 reivews
# 401020 reviews are now in the bag, so to speak
# 2024-04-01 15:12:55
#
# Scraped 96 users this round
# Got 182 reivews
# 401202 reviews are now in the bag, so to speak
# 2024-04-01 15:16:07
#
# Scraped 113 users this round
# Got 193 reivews
# 401395 reviews are now in the bag, so to speak
# 2024-04-01 15:20:12
#
# Scraped 95 users this round
# Got 194 reivews
# 401589 reviews are now in the bag, so to speak
# 2024-04-01 15:23:36
#
# Scraped 106 users this round
# Got 183 reivews
# 401772 reviews are now in the bag, so to speak
# 2024-04-01 15:27:26
#
# Scraped 112 users this round
# Got 200 reivews
# 401972 reviews are now in the bag, so to speak
# 2024-04-01 15:31:25
#
# Scraped 127 users this round
# Got 194 reivews
# 402166 reviews are now in the bag, so to speak
# 2024-04-01 15:35:59
#
# Scraped 122 users this round
# Got 237 reivews
# 402403 reviews are now in the bag, so to speak
# 2024-04-01 15:40:27
#
# Scraped 101 users this round
# Got 155 reivews
# 402558 reviews are now in the bag, so to speak
# 2024-04-01 15:43:54
#
# Scraped 109 users this round
# Got 157 reivews
# 402715 reviews are now in the bag, so to speak
# 2024-04-01 15:47:42
#
# Scraped 122 users this round
# Got 229 reivews
# 402944 reviews are now in the bag, so to speak
# 2024-04-01 15:52:07
#
# Scraped 105 users this round
# Got 146 reivews
# 403090 reviews are now in the bag, so to speak
# 2024-04-01 15:55:41
#
# Scraped 91 users this round
# Got 140 reivews
# 403230 reviews are now in the bag, so to speak
# 2024-04-01 15:58:47
#
# Scraped 115 users this round
# Got 156 reivews
# 403386 reviews are now in the bag, so to speak
# 2024-04-01 16:02:48
#
# Scraped 97 users this round
# Got 166 reivews
# 403552 reviews are now in the bag, so to speak
# 2024-04-01 16:06:06
#
# Scraped 108 users this round
# Got 187 reivews
# 403739 reviews are now in the bag, so to speak
# 2024-04-01 16:09:49
#
# Scraped 118 users this round
# Got 184 reivews
# 403923 reviews are now in the bag, so to speak
# 2024-04-01 16:14:04
#
# Scraped 104 users this round
# Got 199 reivews
# 404122 reviews are now in the bag, so to speak
# 2024-04-01 16:17:51
#
# Scraped 119 users this round
# Got 179 reivews
# 404301 reviews are now in the bag, so to speak
# 2024-04-01 16:22:09
#
# Scraped 128 users this round
# Got 196 reivews
# 404497 reviews are now in the bag, so to speak
# 2024-04-01 16:26:39
#
# Scraped 119 users this round
# Got 196 reivews
# 404693 reviews are now in the bag, so to speak
# 2024-04-01 16:30:47
#
# Scraped 112 users this round
# Got 167 reivews
# 404860 reviews are now in the bag, so to speak
# 2024-04-01 16:34:46
#
# Scraped 104 users this round
# Got 201 reivews
# 405061 reviews are now in the bag, so to speak
# 2024-04-01 16:38:25
#
# Scraped 110 users this round
# Got 172 reivews
# 405233 reviews are now in the bag, so to speak
# 2024-04-01 16:42:28
#
# Scraped 110 users this round
# Got 200 reivews
# 405433 reviews are now in the bag, so to speak
# 2024-04-01 16:46:24
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 135 users this round
# Got 148 reivews
# 405581 reviews are now in the bag, so to speak
# 2024-04-01 16:51:10
#
# Scraped 98 users this round
# Got 175 reivews
# 405756 reviews are now in the bag, so to speak
# 2024-04-01 16:54:24
#
# Scraped 130 users this round
# Got 191 reivews
# 405947 reviews are now in the bag, so to speak
# 2024-04-01 16:58:59
#
# Scraped 119 users this round
# Got 179 reivews
# 406126 reviews are now in the bag, so to speak
# 2024-04-01 17:03:23
#
# Scraped 117 users this round
# Got 192 reivews
# 406318 reviews are now in the bag, so to speak
# 2024-04-01 17:07:20
#
# Scraped 115 users this round
# Got 193 reivews
# 406511 reviews are now in the bag, so to speak
# 2024-04-01 17:11:17
#
# Scraped 119 users this round
# Got 191 reivews
# 406702 reviews are now in the bag, so to speak
# 2024-04-01 17:15:31
#
# Scraped 132 users this round
# Got 186 reivews
# 406888 reviews are now in the bag, so to speak
# 2024-04-01 17:20:16
#
# Scraped 122 users this round
# Got 184 reivews
# 407072 reviews are now in the bag, so to speak
# 2024-04-01 17:25:04
#
# Scraped 93 users this round
# Got 185 reivews
# 407257 reviews are now in the bag, so to speak
# 2024-04-01 17:28:31
#
# Scraped 108 users this round
# Got 160 reivews
# 407417 reviews are now in the bag, so to speak
# 2024-04-01 17:32:14
#
# Scraped 113 users this round
# Got 149 reivews
# 407566 reviews are now in the bag, so to speak
# 2024-04-01 17:36:09
#
# Scraped 114 users this round
# Got 196 reivews
# 407762 reviews are now in the bag, so to speak
# 2024-04-01 17:40:09
#
# Scraped 105 users this round
# Got 155 reivews
# 407917 reviews are now in the bag, so to speak
# 2024-04-01 17:43:39
#
# Scraped 107 users this round
# Got 218 reivews
# 408135 reviews are now in the bag, so to speak
# 2024-04-01 17:47:21
#
# Scraped 105 users this round
# Got 173 reivews
# 408308 reviews are now in the bag, so to speak
# 2024-04-01 17:50:57
#
# Scraped 103 users this round
# Got 216 reivews
# 408524 reviews are now in the bag, so to speak
# 2024-04-01 17:54:21
#
# Scraped 102 users this round
# Got 179 reivews
# 408703 reviews are now in the bag, so to speak
# 2024-04-01 17:57:57
#
# Scraped 105 users this round
# Got 223 reivews
# 408926 reviews are now in the bag, so to speak
# 2024-04-01 18:01:33
#
# Scraped 101 users this round
# Got 186 reivews
# 409112 reviews are now in the bag, so to speak
# 2024-04-01 18:05:01
#
# Scraped 118 users this round
# Got 213 reivews
# 409325 reviews are now in the bag, so to speak
# 2024-04-01 18:09:21
#
# Scraped 118 users this round
# Got 187 reivews
# 409512 reviews are now in the bag, so to speak
# 2024-04-01 18:13:36
#
# Scraped 99 users this round
# Got 168 reivews
# 409680 reviews are now in the bag, so to speak
# 2024-04-01 18:16:54
#
# Scraped 104 users this round
# Got 190 reivews
# 409870 reviews are now in the bag, so to speak
# 2024-04-01 18:20:33
#
# Scraped 106 users this round
# Got 156 reivews
# 410026 reviews are now in the bag, so to speak
# 2024-04-01 18:23:58
#
# Scraped 109 users this round
# Got 159 reivews
# 410185 reviews are now in the bag, so to speak
# 2024-04-01 18:27:45
#
# Scraped 133 users this round
# Got 188 reivews
# 410373 reviews are now in the bag, so to speak
# 2024-04-01 18:32:28
#
# Scraped 94 users this round
# Got 206 reivews
# 410579 reviews are now in the bag, so to speak
# 2024-04-01 18:35:50
#
# Scraped 106 users this round
# Got 199 reivews
# 410778 reviews are now in the bag, so to speak
# 2024-04-01 18:39:22
#
# Scraped 117 users this round
# Got 181 reivews
# 410959 reviews are now in the bag, so to speak
# 2024-04-01 18:43:20
#
# Scraped 96 users this round
# Got 169 reivews
# 411128 reviews are now in the bag, so to speak
# 2024-04-01 18:46:34
#
# Scraped 99 users this round
# Got 179 reivews
# 411307 reviews are now in the bag, so to speak
# 2024-04-01 18:49:59
#
# Scraped 113 users this round
# Got 209 reivews
# 411516 reviews are now in the bag, so to speak
# 2024-04-01 18:53:51
#
# Scraped 107 users this round
# Got 218 reivews
# 411734 reviews are now in the bag, so to speak
# 2024-04-01 18:57:30
#
# Scraped 99 users this round
# Got 173 reivews
# 411907 reviews are now in the bag, so to speak
# 2024-04-01 19:00:52
#
# Scraped 102 users this round
# Got 168 reivews
# 412075 reviews are now in the bag, so to speak
# 2024-04-01 19:04:18
#
# Scraped 102 users this round
# Got 205 reivews
# 412280 reviews are now in the bag, so to speak
# 2024-04-01 19:07:59
#
# Scraped 106 users this round
# Got 191 reivews
# 412471 reviews are now in the bag, so to speak
# 2024-04-01 19:11:31
#
# Scraped 99 users this round
# Got 196 reivews
# 412667 reviews are now in the bag, so to speak
# 2024-04-01 19:14:55
#
# Scraped 113 users this round
# Got 144 reivews
# 412811 reviews are now in the bag, so to speak
# 2024-04-01 19:18:56
#
# Scraped 119 users this round
# Got 164 reivews
# 412975 reviews are now in the bag, so to speak
# 2024-04-01 19:23:14
#
# Scraped 110 users this round
# Got 156 reivews
# 413131 reviews are now in the bag, so to speak
# 2024-04-01 19:26:49
#
# Scraped 101 users this round
# Got 199 reivews
# 413330 reviews are now in the bag, so to speak
# 2024-04-01 19:30:17
#
# Scraped 107 users this round
# Got 189 reivews
# 413519 reviews are now in the bag, so to speak
# 2024-04-01 19:33:59
#
# Scraped 139 users this round
# Got 177 reivews
# 413696 reviews are now in the bag, so to speak
# 2024-04-01 19:39:12
#
# Scraped 112 users this round
# Got 152 reivews
# 413848 reviews are now in the bag, so to speak
# 2024-04-01 19:43:01
#
# Scraped 109 users this round
# Got 189 reivews
# 414037 reviews are now in the bag, so to speak
# 2024-04-01 19:46:36
#
# Scraped 100 users this round
# Got 203 reivews
# 414240 reviews are now in the bag, so to speak
# 2024-04-01 19:50:09
#
# Scraped 116 users this round
# Got 197 reivews
# 414437 reviews are now in the bag, so to speak
# 2024-04-01 19:54:09
#
# Scraped 124 users this round
# Got 213 reivews
# 414650 reviews are now in the bag, so to speak
# 2024-04-01 19:58:42
#
# Scraped 104 users this round
# Got 174 reivews
# 414824 reviews are now in the bag, so to speak
# 2024-04-01 20:02:33
#
# Scraped 101 users this round
# Got 213 reivews
# 415037 reviews are now in the bag, so to speak
# 2024-04-01 20:06:19
#
# Scraped 101 users this round
# Got 197 reivews
# 415234 reviews are now in the bag, so to speak
# 2024-04-01 20:11:45
#
# Scraped 124 users this round
# Got 185 reivews
# 415419 reviews are now in the bag, so to speak
# 2024-04-01 20:20:23
#
# Scraped 94 users this round
# Got 179 reivews
# 415598 reviews are now in the bag, so to speak
# 2024-04-01 20:26:54
#
# Scraped 115 users this round
# Got 157 reivews
# 415755 reviews are now in the bag, so to speak
# 2024-04-01 20:33:37
#
# Scraped 106 users this round
# Got 197 reivews
# 415952 reviews are now in the bag, so to speak
# 2024-04-01 20:39:20
#
# Scraped 107 users this round
# Got 172 reivews
# 416124 reviews are now in the bag, so to speak
# 2024-04-01 20:45:24
#
# Scraped 108 users this round
# Got 201 reivews
# 416325 reviews are now in the bag, so to speak
# 2024-04-01 20:51:37
#
# Scraped 116 users this round
# Got 216 reivews
# 416541 reviews are now in the bag, so to speak
# 2024-04-01 20:59:01
#
# Scraped 106 users this round
# Got 172 reivews
# 416713 reviews are now in the bag, so to speak
# 2024-04-01 21:05:23
#
# Scraped 98 users this round
# Got 195 reivews
# 416908 reviews are now in the bag, so to speak
# 2024-04-01 21:11:14
#
# Scraped 91 users this round
# Got 177 reivews
# 417085 reviews are now in the bag, so to speak
# 2024-04-01 21:16:30
#
# Scraped 126 users this round
# Got 177 reivews
# 417262 reviews are now in the bag, so to speak
# 2024-04-01 21:24:22
#
# Scraped 115 users this round
# Got 172 reivews
# 417434 reviews are now in the bag, so to speak
# 2024-04-01 21:31:32
#
# Scraped 126 users this round
# Got 207 reivews
# 417641 reviews are now in the bag, so to speak
# 2024-04-01 21:39:31
#
# Scraped 97 users this round
# Got 188 reivews
# 417829 reviews are now in the bag, so to speak
# 2024-04-01 21:45:03
#
# Scraped 98 users this round
# Got 194 reivews
# 418023 reviews are now in the bag, so to speak
# 2024-04-01 21:50:49
#
# Scraped 107 users this round
# Got 177 reivews
# 418200 reviews are now in the bag, so to speak
# 2024-04-01 21:56:54
#
# Scraped 136 users this round
# Got 201 reivews
# 418401 reviews are now in the bag, so to speak
# 2024-04-01 22:06:40
#
# Scraped 123 users this round
# Got 187 reivews
# 418588 reviews are now in the bag, so to speak
# 2024-04-01 22:13:52
#
# Scraped 111 users this round
# Got 258 reivews
# 418846 reviews are now in the bag, so to speak
# 2024-04-01 22:20:32
#
# Scraped 109 users this round
# Got 187 reivews
# 419033 reviews are now in the bag, so to speak
# 2024-04-01 22:27:05
#
# Scraped 124 users this round
# Got 194 reivews
# 419227 reviews are now in the bag, so to speak
# 2024-04-01 22:34:47
#
# Scraped 130 users this round
# Got 122 reivews
# 419349 reviews are now in the bag, so to speak
# 2024-04-01 22:41:51
#
# Scraped 113 users this round
# Got 214 reivews
# 419563 reviews are now in the bag, so to speak
# 2024-04-01 22:47:46
#
# Scraped 96 users this round
# Got 213 reivews
# 419776 reviews are now in the bag, so to speak
# 2024-04-01 22:52:39
#
# Scraped 116 users this round
# Got 200 reivews
# 419976 reviews are now in the bag, so to speak
# 2024-04-01 22:58:39
#
# Scraped 115 users this round
# Got 193 reivews
# 420169 reviews are now in the bag, so to speak
# 2024-04-01 23:04:55
#
# Scraped 115 users this round
# Got 192 reivews
# 420361 reviews are now in the bag, so to speak
# 2024-04-01 23:10:35
#
# Scraped 110 users this round
# Got 192 reivews
# 420553 reviews are now in the bag, so to speak
# 2024-04-01 23:14:44
#
# Scraped 89 users this round
# Got 267 reivews
# 420820 reviews are now in the bag, so to speak
# 2024-04-01 23:17:39
#
# Scraped 120 users this round
# Got 218 reivews
# 421038 reviews are now in the bag, so to speak
# 2024-04-01 23:22:10
#
# Scraped 90 users this round
# Got 200 reivews
# 421238 reviews are now in the bag, so to speak
# 2024-04-01 23:25:23
#
# Scraped 101 users this round
# Got 171 reivews
# 421409 reviews are now in the bag, so to speak
# 2024-04-01 23:28:58
#
# Scraped 106 users this round
# Got 209 reivews
# 421618 reviews are now in the bag, so to speak
# 2024-04-01 23:32:49
#
# Scraped 121 users this round
# Got 164 reivews
# 421782 reviews are now in the bag, so to speak
# 2024-04-01 23:37:17
#
# Scraped 112 users this round
# Got 165 reivews
# 421947 reviews are now in the bag, so to speak
# 2024-04-01 23:41:20
#
# Scraped 119 users this round
# Got 201 reivews
# 422148 reviews are now in the bag, so to speak
# 2024-04-01 23:45:55
#
# Scraped 122 users this round
# Got 210 reivews
# 422358 reviews are now in the bag, so to speak
# 2024-04-01 23:50:38
#
# Scraped 99 users this round
# Got 192 reivews
# 422550 reviews are now in the bag, so to speak
# 2024-04-01 23:54:04
#
# Scraped 115 users this round
# Got 191 reivews
# 422741 reviews are now in the bag, so to speak
# 2024-04-01 23:58:08
#
# Scraped 111 users this round
# Got 205 reivews
# 422946 reviews are now in the bag, so to speak
# 2024-04-02 00:02:10
#
# Scraped 128 users this round
# Got 174 reivews
# 423120 reviews are now in the bag, so to speak
# 2024-04-02 00:06:48
#
# Scraped 124 users this round
# Got 151 reivews
# 423271 reviews are now in the bag, so to speak
# 2024-04-02 00:11:22
#
# Scraped 121 users this round
# Got 206 reivews
# 423477 reviews are now in the bag, so to speak
# 2024-04-02 00:16:08
#
# Scraped 116 users this round
# Got 213 reivews
# 423690 reviews are now in the bag, so to speak
# 2024-04-02 00:20:23
#
# Scraped 107 users this round
# Got 238 reivews
# 423928 reviews are now in the bag, so to speak
# 2024-04-02 00:24:08
#
# Scraped 97 users this round
# Got 168 reivews
# 424096 reviews are now in the bag, so to speak
# 2024-04-02 00:27:50
#
# Scraped 93 users this round
# Got 206 reivews
# 424302 reviews are now in the bag, so to speak
# 2024-04-02 00:31:20
#
# Scraped 98 users this round
# Got 193 reivews
# 424495 reviews are now in the bag, so to speak
# 2024-04-02 00:34:47
#
# Scraped 124 users this round
# Got 148 reivews
# 424643 reviews are now in the bag, so to speak
# 2024-04-02 00:39:19
#
# Scraped 105 users this round
# Got 190 reivews
# 424833 reviews are now in the bag, so to speak
# 2024-04-02 00:43:02
#
# Scraped 114 users this round
# Got 185 reivews
# 425018 reviews are now in the bag, so to speak
# 2024-04-02 00:47:06
#
# Scraped 112 users this round
# Got 190 reivews
# 425208 reviews are now in the bag, so to speak
# 2024-04-02 00:50:58
#
# Scraped 123 users this round
# Got 170 reivews
# 425378 reviews are now in the bag, so to speak
# 2024-04-02 00:55:24
#
# Scraped 106 users this round
# Got 174 reivews
# 425552 reviews are now in the bag, so to speak
# 2024-04-02 00:59:29
#
# Scraped 106 users this round
# Got 210 reivews
# 425762 reviews are now in the bag, so to speak
# 2024-04-02 01:03:19
#
# Scraped 101 users this round
# Got 142 reivews
# 425904 reviews are now in the bag, so to speak
# 2024-04-02 01:06:49
#
# Scraped 126 users this round
# Got 162 reivews
# 426066 reviews are now in the bag, so to speak
# 2024-04-02 01:11:27
#
# Scraped 102 users this round
# Got 209 reivews
# 426275 reviews are now in the bag, so to speak
# 2024-04-02 01:15:04
#
# Scraped 100 users this round
# Got 186 reivews
# 426461 reviews are now in the bag, so to speak
# 2024-04-02 01:18:39
#
# Scraped 109 users this round
# Got 183 reivews
# 426644 reviews are now in the bag, so to speak
# 2024-04-02 01:22:33
#
# Scraped 107 users this round
# Got 194 reivews
# 426838 reviews are now in the bag, so to speak
# 2024-04-02 01:26:04
#
# Scraped 97 users this round
# Got 188 reivews
# 427026 reviews are now in the bag, so to speak
# 2024-04-02 01:29:21
#
# Scraped 115 users this round
# Got 168 reivews
# 427194 reviews are now in the bag, so to speak
# 2024-04-02 01:33:30
#
# Scraped 117 users this round
# Got 206 reivews
# 427400 reviews are now in the bag, so to speak
# 2024-04-02 01:37:39
#
# Scraped 112 users this round
# Got 192 reivews
# 427592 reviews are now in the bag, so to speak
# 2024-04-02 01:41:40
#
# Scraped 98 users this round
# Got 222 reivews
# 427814 reviews are now in the bag, so to speak
# 2024-04-02 01:45:12
#
# Scraped 95 users this round
# Got 157 reivews
# 427971 reviews are now in the bag, so to speak
# 2024-04-02 01:48:21
#
# Scraped 121 users this round
# Got 174 reivews
# 428145 reviews are now in the bag, so to speak
# 2024-04-02 01:52:33
#
# Scraped 113 users this round
# Got 226 reivews
# 428371 reviews are now in the bag, so to speak
# 2024-04-02 01:56:37
#
# Scraped 100 users this round
# Got 222 reivews
# 428593 reviews are now in the bag, so to speak
# 2024-04-02 02:00:05
#
# Scraped 125 users this round
# Got 181 reivews
# 428774 reviews are now in the bag, so to speak
# 2024-04-02 02:04:33
#
# Scraped 125 users this round
# Got 198 reivews
# 428972 reviews are now in the bag, so to speak
# 2024-04-02 02:09:01
#
# Scraped 115 users this round
# Got 186 reivews
# 429158 reviews are now in the bag, so to speak
# 2024-04-02 02:13:06
#
# Scraped 116 users this round
# Got 214 reivews
# 429372 reviews are now in the bag, so to speak
# 2024-04-02 02:17:18
#
# Scraped 104 users this round
# Got 201 reivews
# 429573 reviews are now in the bag, so to speak
# 2024-04-02 02:20:51
#
# Scraped 107 users this round
# Got 209 reivews
# 429782 reviews are now in the bag, so to speak
# 2024-04-02 02:24:35
#
# Scraped 107 users this round
# Got 222 reivews
# 430004 reviews are now in the bag, so to speak
# 2024-04-02 02:28:18
#
# Scraped 112 users this round
# Got 211 reivews
# 430215 reviews are now in the bag, so to speak
# 2024-04-02 02:32:20
#
# Scraped 111 users this round
# Got 193 reivews
# 430408 reviews are now in the bag, so to speak
# 2024-04-02 02:36:14
#
# Scraped 108 users this round
# Got 194 reivews
# 430602 reviews are now in the bag, so to speak
# 2024-04-02 02:39:57
#
# Scraped 83 users this round
# Got 162 reivews
# 430764 reviews are now in the bag, so to speak
# 2024-04-02 02:42:41
#
# Scraped 124 users this round
# Got 183 reivews
# 430947 reviews are now in the bag, so to speak
# 2024-04-02 02:47:04
#
# Scraped 108 users this round
# Got 179 reivews
# 431126 reviews are now in the bag, so to speak
# 2024-04-02 02:50:57
#
# Scraped 108 users this round
# Got 175 reivews
# 431301 reviews are now in the bag, so to speak
# 2024-04-02 02:54:49
#
# Scraped 97 users this round
# Got 200 reivews
# 431501 reviews are now in the bag, so to speak
# 2024-04-02 02:58:20
#
# Scraped 104 users this round
# Got 181 reivews
# 431682 reviews are now in the bag, so to speak
# 2024-04-02 03:01:54
#
# Scraped 92 users this round
# Got 187 reivews
# 431869 reviews are now in the bag, so to speak
# 2024-04-02 03:05:04
#
# Scraped 101 users this round
# Got 205 reivews
# 432074 reviews are now in the bag, so to speak
# 2024-04-02 03:08:25
#
# Scraped 109 users this round
# Got 148 reivews
# 432222 reviews are now in the bag, so to speak
# 2024-04-02 03:12:11
#
# Scraped 117 users this round
# Got 160 reivews
# 432382 reviews are now in the bag, so to speak
# 2024-04-02 03:16:14
#
# Scraped 111 users this round
# Got 179 reivews
# 432561 reviews are now in the bag, so to speak
# 2024-04-02 03:20:02
#
# Scraped 91 users this round
# Got 229 reivews
# 432790 reviews are now in the bag, so to speak
# 2024-04-02 03:23:08
#
# Scraped 126 users this round
# Got 182 reivews
# 432972 reviews are now in the bag, so to speak
# 2024-04-02 03:27:51
#
# Scraped 125 users this round
# Got 195 reivews
# 433167 reviews are now in the bag, so to speak
# 2024-04-02 03:32:20
#
# Scraped 121 users this round
# Got 194 reivews
# 433361 reviews are now in the bag, so to speak
# 2024-04-02 03:36:35
#
# Scraped 104 users this round
# Got 219 reivews
# 433580 reviews are now in the bag, so to speak
# 2024-04-02 03:40:02
#
# Scraped 96 users this round
# Got 202 reivews
# 433782 reviews are now in the bag, so to speak
# 2024-04-02 03:43:20
#
# Scraped 109 users this round
# Got 195 reivews
# 433977 reviews are now in the bag, so to speak
# 2024-04-02 03:46:58
#
# Scraped 112 users this round
# Got 217 reivews
# 434194 reviews are now in the bag, so to speak
# 2024-04-02 03:50:44
#
# Scraped 137 users this round
# Got 163 reivews
# 434357 reviews are now in the bag, so to speak
# 2024-04-02 03:55:35
#
# Scraped 131 users this round
# Got 212 reivews
# 434569 reviews are now in the bag, so to speak
# 2024-04-02 04:00:28
#
# Scraped 117 users this round
# Got 166 reivews
# 434735 reviews are now in the bag, so to speak
# 2024-04-02 04:04:35
#
# Scraped 111 users this round
# Got 202 reivews
# 434937 reviews are now in the bag, so to speak
# 2024-04-02 04:08:17
#
# Scraped 115 users this round
# Got 185 reivews
# 435122 reviews are now in the bag, so to speak
# 2024-04-02 04:12:19
#
# Scraped 97 users this round
# Got 146 reivews
# 435268 reviews are now in the bag, so to speak
# 2024-04-02 04:15:41
#
# Scraped 104 users this round
# Got 195 reivews
# 435463 reviews are now in the bag, so to speak
# 2024-04-02 04:19:17
#
# Scraped 113 users this round
# Got 179 reivews
# 435642 reviews are now in the bag, so to speak
# 2024-04-02 04:23:29
#
# Scraped 101 users this round
# Got 159 reivews
# 435801 reviews are now in the bag, so to speak
# 2024-04-02 04:27:06
#
# Scraped 121 users this round
# Got 201 reivews
# 436002 reviews are now in the bag, so to speak
# 2024-04-02 04:31:32
#
# Scraped 126 users this round
# Got 193 reivews
# 436195 reviews are now in the bag, so to speak
# 2024-04-02 04:36:20
#
# Scraped 125 users this round
# Got 160 reivews
# 436355 reviews are now in the bag, so to speak
# 2024-04-02 04:40:52
#
# Scraped 132 users this round
# Got 184 reivews
# 436539 reviews are now in the bag, so to speak
# 2024-04-02 04:45:35
#
# Scraped 104 users this round
# Got 168 reivews
# 436707 reviews are now in the bag, so to speak
# 2024-04-02 04:49:14
#
# Scraped 98 users this round
# Got 132 reivews
# 436839 reviews are now in the bag, so to speak
# 2024-04-02 04:52:39
#
# Scraped 119 users this round
# Got 203 reivews
# 437042 reviews are now in the bag, so to speak
# 2024-04-02 04:56:58
#
# Scraped 93 users this round
# Got 230 reivews
# 437272 reviews are now in the bag, so to speak
# 2024-04-02 05:00:14
#
# Scraped 110 users this round
# Got 195 reivews
# 437467 reviews are now in the bag, so to speak
# 2024-04-02 05:04:21
#
# Scraped 98 users this round
# Got 194 reivews
# 437661 reviews are now in the bag, so to speak
# 2024-04-02 05:07:43
#
# Scraped 105 users this round
# Got 172 reivews
# 437833 reviews are now in the bag, so to speak
# 2024-04-02 05:11:26
#
# Scraped 115 users this round
# Got 184 reivews
# 438017 reviews are now in the bag, so to speak
# 2024-04-02 05:15:29
#
# Scraped 111 users this round
# Got 172 reivews
# 438189 reviews are now in the bag, so to speak
# 2024-04-02 05:19:20
#
# Scraped 92 users this round
# Got 209 reivews
# 438398 reviews are now in the bag, so to speak
# 2024-04-02 05:22:27
#
# Scraped 114 users this round
# Got 169 reivews
# 438567 reviews are now in the bag, so to speak
# 2024-04-02 05:26:17
#
# Scraped 103 users this round
# Got 239 reivews
# 438806 reviews are now in the bag, so to speak
# 2024-04-02 05:29:49
#
# Scraped 114 users this round
# Got 197 reivews
# 439003 reviews are now in the bag, so to speak
# 2024-04-02 05:33:41
#
# Scraped 114 users this round
# Got 201 reivews
# 439204 reviews are now in the bag, so to speak
# 2024-04-02 05:37:41
#
# Scraped 101 users this round
# Got 166 reivews
# 439370 reviews are now in the bag, so to speak
# 2024-04-02 05:41:11
#
# Scraped 98 users this round
# Got 184 reivews
# 439554 reviews are now in the bag, so to speak
# 2024-04-02 05:44:33
#
# Scraped 117 users this round
# Got 194 reivews
# 439748 reviews are now in the bag, so to speak
# 2024-04-02 05:48:42
#
# Scraped 91 users this round
# Got 164 reivews
# 439912 reviews are now in the bag, so to speak
# 2024-04-02 05:51:40
#
# Scraped 121 users this round
# Got 191 reivews
# 440103 reviews are now in the bag, so to speak
# 2024-04-02 05:55:57
#
# Scraped 104 users this round
# Got 192 reivews
# 440295 reviews are now in the bag, so to speak
# 2024-04-02 05:59:35
#
# Scraped 101 users this round
# Got 243 reivews
# 440538 reviews are now in the bag, so to speak
# 2024-04-02 06:03:16
#
# Scraped 102 users this round
# Got 188 reivews
# 440726 reviews are now in the bag, so to speak
# 2024-04-02 06:06:49
#
# Scraped 146 users this round
# Got 186 reivews
# 440912 reviews are now in the bag, so to speak
# 2024-04-02 06:12:36
#
# Scraped 105 users this round
# Got 188 reivews
# 441100 reviews are now in the bag, so to speak
# 2024-04-02 06:16:19
#
# Scraped 94 users this round
# Got 182 reivews
# 441282 reviews are now in the bag, so to speak
# 2024-04-02 06:19:30
#
# Scraped 118 users this round
# Got 199 reivews
# 441481 reviews are now in the bag, so to speak
# 2024-04-02 06:23:37
#
# Scraped 105 users this round
# Got 171 reivews
# 441652 reviews are now in the bag, so to speak
# 2024-04-02 06:27:11
#
# Scraped 93 users this round
# Got 179 reivews
# 441831 reviews are now in the bag, so to speak
# 2024-04-02 06:30:29
#
# Scraped 107 users this round
# Got 145 reivews
# 441976 reviews are now in the bag, so to speak
# 2024-04-02 06:34:12
#
# Scraped 101 users this round
# Got 197 reivews
# 442173 reviews are now in the bag, so to speak
# 2024-04-02 06:37:47
#
# Scraped 124 users this round
# Got 169 reivews
# 442342 reviews are now in the bag, so to speak
# 2024-04-02 06:42:03
#
# Scraped 126 users this round
# Got 203 reivews
# 442545 reviews are now in the bag, so to speak
# 2024-04-02 06:46:35
#
# Scraped 80 users this round
# Got 193 reivews
# 442738 reviews are now in the bag, so to speak
# 2024-04-02 06:49:18
#
# Scraped 119 users this round
# Got 192 reivews
# 442930 reviews are now in the bag, so to speak
# 2024-04-02 06:53:29
#
# Scraped 99 users this round
# Got 200 reivews
# 443130 reviews are now in the bag, so to speak
# 2024-04-02 06:57:01
#
# Scraped 116 users this round
# Got 248 reivews
# 443378 reviews are now in the bag, so to speak
# 2024-04-02 07:01:19
#
# Scraped 106 users this round
# Got 164 reivews
# 443542 reviews are now in the bag, so to speak
# 2024-04-02 07:04:57
#
# Scraped 108 users this round
# Got 178 reivews
# 443720 reviews are now in the bag, so to speak
# 2024-04-02 07:08:43
#
# Scraped 103 users this round
# Got 194 reivews
# 443914 reviews are now in the bag, so to speak
# 2024-04-02 07:12:20
#
# Scraped 114 users this round
# Got 224 reivews
# 444138 reviews are now in the bag, so to speak
# 2024-04-02 07:16:27
#
# Scraped 119 users this round
# Got 160 reivews
# 444298 reviews are now in the bag, so to speak
# 2024-04-02 07:20:43
#
# Scraped 117 users this round
# Got 197 reivews
# 444495 reviews are now in the bag, so to speak
# 2024-04-02 07:25:02
#
# Scraped 131 users this round
# Got 202 reivews
# 444697 reviews are now in the bag, so to speak
# 2024-04-02 07:29:59
#
# Scraped 104 users this round
# Got 148 reivews
# 444845 reviews are now in the bag, so to speak
# 2024-04-02 07:33:39
#
# Scraped 104 users this round
# Got 189 reivews
# 445034 reviews are now in the bag, so to speak
# 2024-04-02 07:37:25
#
# Scraped 104 users this round
# Got 193 reivews
# 445227 reviews are now in the bag, so to speak
# 2024-04-02 07:41:00
#
# Scraped 94 users this round
# Got 187 reivews
# 445414 reviews are now in the bag, so to speak
# 2024-04-02 07:44:15
#
# Scraped 109 users this round
# Got 197 reivews
# 445611 reviews are now in the bag, so to speak
# 2024-04-02 07:48:05
#
# Scraped 95 users this round
# Got 199 reivews
# 445810 reviews are now in the bag, so to speak
# 2024-04-02 07:51:26
#
# Scraped 107 users this round
# Got 157 reivews
# 445967 reviews are now in the bag, so to speak
# 2024-04-02 07:55:16
#
# Scraped 126 users this round
# Got 183 reivews
# 446150 reviews are now in the bag, so to speak
# 2024-04-02 07:59:51
#
# Scraped 126 users this round
# Got 236 reivews
# 446386 reviews are now in the bag, so to speak
# 2024-04-02 08:04:31
#
# Scraped 116 users this round
# Got 185 reivews
# 446571 reviews are now in the bag, so to speak
# 2024-04-02 08:08:41
#
# Scraped 105 users this round
# Got 213 reivews
# 446784 reviews are now in the bag, so to speak
# 2024-04-02 08:12:31
#
# Scraped 124 users this round
# Got 201 reivews
# 446985 reviews are now in the bag, so to speak
# 2024-04-02 08:17:12
#
# Scraped 107 users this round
# Got 208 reivews
# 447193 reviews are now in the bag, so to speak
# 2024-04-02 08:21:02
#
# Scraped 101 users this round
# Got 223 reivews
# 447416 reviews are now in the bag, so to speak
# 2024-04-02 08:24:49
#
# Scraped 99 users this round
# Got 222 reivews
# 447638 reviews are now in the bag, so to speak
# 2024-04-02 08:28:15
#
# Scraped 135 users this round
# Got 207 reivews
# 447845 reviews are now in the bag, so to speak
# 2024-04-02 08:33:19
#
# Scraped 94 users this round
# Got 186 reivews
# 448031 reviews are now in the bag, so to speak
# 2024-04-02 08:36:38
#
# Scraped 117 users this round
# Got 176 reivews
# 448207 reviews are now in the bag, so to speak
# 2024-04-02 08:40:43
#
# Scraped 113 users this round
# Got 148 reivews
# 448355 reviews are now in the bag, so to speak
# 2024-04-02 08:44:31
#
# Scraped 85 users this round
# Got 180 reivews
# 448535 reviews are now in the bag, so to speak
# 2024-04-02 08:47:12
#
# Scraped 119 users this round
# Got 216 reivews
# 448751 reviews are now in the bag, so to speak
# 2024-04-02 08:51:41
#
# Scraped 129 users this round
# Got 210 reivews
# 448961 reviews are now in the bag, so to speak
# 2024-04-02 08:56:42
#
# Scraped 108 users this round
# Got 174 reivews
# 449135 reviews are now in the bag, so to speak
# 2024-04-02 09:00:38
#
# Scraped 104 users this round
# Got 214 reivews
# 449349 reviews are now in the bag, so to speak
# 2024-04-02 09:04:26
#
# Scraped 110 users this round
# Got 194 reivews
# 449543 reviews are now in the bag, so to speak
# 2024-04-02 09:08:29
#
# Scraped 103 users this round
# Got 172 reivews
# 449715 reviews are now in the bag, so to speak
# 2024-04-02 09:12:23
#
# Scraped 117 users this round
# Got 245 reivews
# 449960 reviews are now in the bag, so to speak
# 2024-04-02 09:17:34
#
# Scraped 124 users this round
# Got 177 reivews
# 450137 reviews are now in the bag, so to speak
# 2024-04-02 09:22:08
#
# Scraped 99 users this round
# Got 230 reivews
# 450367 reviews are now in the bag, so to speak
# 2024-04-02 09:25:46
#
# Scraped 110 users this round
# Got 200 reivews
# 450567 reviews are now in the bag, so to speak
# 2024-04-02 09:29:59
#
# Scraped 97 users this round
# Got 174 reivews
# 450741 reviews are now in the bag, so to speak
# 2024-04-02 09:33:34
#
# Scraped 95 users this round
# Got 234 reivews
# 450975 reviews are now in the bag, so to speak
# 2024-04-02 09:36:58
#
# Scraped 96 users this round
# Got 182 reivews
# 451157 reviews are now in the bag, so to speak
# 2024-04-02 09:40:26
#
# Scraped 110 users this round
# Got 200 reivews
# 451357 reviews are now in the bag, so to speak
# 2024-04-02 09:44:02
#
# Scraped 97 users this round
# Got 153 reivews
# 451510 reviews are now in the bag, so to speak
# 2024-04-02 09:47:10
#
# Scraped 113 users this round
# Got 155 reivews
# 451665 reviews are now in the bag, so to speak
# 2024-04-02 09:51:07
#
# Scraped 111 users this round
# Got 215 reivews
# 451880 reviews are now in the bag, so to speak
# 2024-04-02 09:54:51
#
# Scraped 105 users this round
# Got 190 reivews
# 452070 reviews are now in the bag, so to speak
# 2024-04-02 09:58:22
#
# Scraped 111 users this round
# Got 192 reivews
# 452262 reviews are now in the bag, so to speak
# 2024-04-02 10:02:13
#
# Scraped 114 users this round
# Got 198 reivews
# 452460 reviews are now in the bag, so to speak
# 2024-04-02 10:06:19
#
# Scraped 115 users this round
# Got 204 reivews
# 452664 reviews are now in the bag, so to speak
# 2024-04-02 10:10:21
#
# Scraped 104 users this round
# Got 161 reivews
# 452825 reviews are now in the bag, so to speak
# 2024-04-02 10:13:44
#
# Scraped 115 users this round
# Got 194 reivews
# 453019 reviews are now in the bag, so to speak
# 2024-04-02 10:20:05
#
# Scraped 110 users this round
# Got 178 reivews
# 453197 reviews are now in the bag, so to speak
# 2024-04-02 10:25:06
#
# Scraped 102 users this round
# Got 143 reivews
# 453340 reviews are now in the bag, so to speak
# 2024-04-02 10:29:11
#
# Scraped 120 users this round
# Got 199 reivews
# 453539 reviews are now in the bag, so to speak
# 2024-04-02 10:34:58
#
# Scraped 110 users this round
# Got 200 reivews
# 453739 reviews are now in the bag, so to speak
# 2024-04-02 10:39:27
#
# Scraped 87 users this round
# Got 189 reivews
# 453928 reviews are now in the bag, so to speak
# 2024-04-02 10:42:48
#
# Scraped 137 users this round
# Got 205 reivews
# 454133 reviews are now in the bag, so to speak
# 2024-04-02 10:48:13
#
# Scraped 120 users this round
# Got 186 reivews
# 454319 reviews are now in the bag, so to speak
# 2024-04-02 10:53:01
#
# Scraped 95 users this round
# Got 173 reivews
# 454492 reviews are now in the bag, so to speak
# 2024-04-02 10:56:12
#
# Scraped 119 users this round
# Got 173 reivews
# 454665 reviews are now in the bag, so to speak
# 2024-04-02 11:01:03
#
# Scraped 103 users this round
# Got 179 reivews
# 454844 reviews are now in the bag, so to speak
# 2024-04-02 11:05:17
#
# Scraped 116 users this round
# Got 180 reivews
# 455024 reviews are now in the bag, so to speak
# 2024-04-02 11:09:32
#
# Scraped 111 users this round
# Got 202 reivews
# 455226 reviews are now in the bag, so to speak
# 2024-04-02 11:13:43
#
# Scraped 120 users this round
# Got 198 reivews
# 455424 reviews are now in the bag, so to speak
# 2024-04-02 11:18:04
#
# Scraped 99 users this round
# Got 177 reivews
# 455601 reviews are now in the bag, so to speak
# 2024-04-02 11:21:49
#
# Scraped 116 users this round
# Got 210 reivews
# 455811 reviews are now in the bag, so to speak
# 2024-04-02 11:26:32
#
# Scraped 102 users this round
# Got 228 reivews
# 456039 reviews are now in the bag, so to speak
# 2024-04-02 11:30:18
#
# Scraped 102 users this round
# Got 210 reivews
# 456249 reviews are now in the bag, so to speak
# 2024-04-02 11:34:15
#
# Scraped 104 users this round
# Got 178 reivews
# 456427 reviews are now in the bag, so to speak
# 2024-04-02 11:38:13
#
# Scraped 108 users this round
# Got 173 reivews
# 456600 reviews are now in the bag, so to speak
# 2024-04-02 11:42:14
#
# Scraped 119 users this round
# Got 221 reivews
# 456821 reviews are now in the bag, so to speak
# 2024-04-02 11:46:29
#
# Scraped 108 users this round
# Got 203 reivews
# 457024 reviews are now in the bag, so to speak
# 2024-04-02 11:50:28
#
# Scraped 102 users this round
# Got 205 reivews
# 457229 reviews are now in the bag, so to speak
# 2024-04-02 11:54:27
#
# Scraped 108 users this round
# Got 198 reivews
# 457427 reviews are now in the bag, so to speak
# 2024-04-02 11:58:13
#
# Scraped 95 users this round
# Got 176 reivews
# 457603 reviews are now in the bag, so to speak
# 2024-04-02 12:01:33
#
# Scraped 102 users this round
# Got 180 reivews
# 457783 reviews are now in the bag, so to speak
# 2024-04-02 12:05:12
#
# Scraped 88 users this round
# Got 213 reivews
# 457996 reviews are now in the bag, so to speak
# 2024-04-02 12:07:59
#
# Scraped 102 users this round
# Got 174 reivews
# 458170 reviews are now in the bag, so to speak
# 2024-04-02 12:11:48
#
# Scraped 102 users this round
# Got 164 reivews
# 458334 reviews are now in the bag, so to speak
# 2024-04-02 12:15:15
#
# Scraped 99 users this round
# Got 187 reivews
# 458521 reviews are now in the bag, so to speak
# 2024-04-02 12:18:49
#
# Scraped 116 users this round
# Got 142 reivews
# 458663 reviews are now in the bag, so to speak
# 2024-04-02 12:22:58
#
# Scraped 99 users this round
# Got 179 reivews
# 458842 reviews are now in the bag, so to speak
# 2024-04-02 12:26:29
#
# Scraped 120 users this round
# Got 181 reivews
# 459023 reviews are now in the bag, so to speak
# 2024-04-02 12:30:45
#
# Scraped 113 users this round
# Got 153 reivews
# 459176 reviews are now in the bag, so to speak
# 2024-04-02 12:35:05
#
# Scraped 96 users this round
# Got 193 reivews
# 459369 reviews are now in the bag, so to speak
# 2024-04-02 12:38:28
#
# Scraped 99 users this round
# Got 183 reivews
# 459552 reviews are now in the bag, so to speak
# 2024-04-02 12:42:04
#
# Scraped 108 users this round
# Got 183 reivews
# 459735 reviews are now in the bag, so to speak
# 2024-04-02 12:46:06
#
# Scraped 129 users this round
# Got 171 reivews
# 459906 reviews are now in the bag, so to speak
# 2024-04-02 12:51:27
#
# Scraped 102 users this round
# Got 207 reivews
# 460113 reviews are now in the bag, so to speak
# 2024-04-02 12:54:59
#
# Scraped 94 users this round
# Got 214 reivews
# 460327 reviews are now in the bag, so to speak
# 2024-04-02 12:58:25
#
# Scraped 112 users this round
# Got 198 reivews
# 460525 reviews are now in the bag, so to speak
# 2024-04-02 13:02:35
#
# Scraped 96 users this round
# Got 231 reivews
# 460756 reviews are now in the bag, so to speak
# 2024-04-02 13:05:58
#
# Scraped 112 users this round
# Got 185 reivews
# 460941 reviews are now in the bag, so to speak
# 2024-04-02 13:10:03
#
# Scraped 127 users this round
# Got 140 reivews
# 461081 reviews are now in the bag, so to speak
# 2024-04-02 13:14:34
#
# Scraped 113 users this round
# Got 170 reivews
# 461251 reviews are now in the bag, so to speak
# 2024-04-02 13:18:52
#
# Scraped 115 users this round
# Got 218 reivews
# 461469 reviews are now in the bag, so to speak
# 2024-04-02 13:23:11
#
# Scraped 95 users this round
# Got 212 reivews
# 461681 reviews are now in the bag, so to speak
# 2024-04-02 13:26:35
#
# Scraped 106 users this round
# Got 157 reivews
# 461838 reviews are now in the bag, so to speak
# 2024-04-02 13:30:26
#
# Scraped 99 users this round
# Got 146 reivews
# 461984 reviews are now in the bag, so to speak
# 2024-04-02 13:34:11
#
# Scraped 118 users this round
# Got 180 reivews
# 462164 reviews are now in the bag, so to speak
# 2024-04-02 13:38:40
#
# Unable to parse review blocks.
# Scraped 111 users this round
# Got 188 reivews
# 462352 reviews are now in the bag, so to speak
# 2024-04-02 13:47:59
#
# Scraped 101 users this round
# Got 216 reivews
# 462568 reviews are now in the bag, so to speak
# 2024-04-02 13:51:43
#
# Scraped 115 users this round
# Got 167 reivews
# 462735 reviews are now in the bag, so to speak
# 2024-04-02 13:56:27
#
# Scraped 120 users this round
# Got 177 reivews
# 462912 reviews are now in the bag, so to speak
# 2024-04-02 14:01:23
#
# Scraped 89 users this round
# Got 190 reivews
# 463102 reviews are now in the bag, so to speak
# 2024-04-02 14:04:37
#
# Scraped 102 users this round
# Got 177 reivews
# 463279 reviews are now in the bag, so to speak
# 2024-04-02 14:08:11
#
# Scraped 98 users this round
# Got 169 reivews
# 463448 reviews are now in the bag, so to speak
# 2024-04-02 14:11:38
#
# Scraped 106 users this round
# Got 175 reivews
# 463623 reviews are now in the bag, so to speak
# 2024-04-02 14:15:44
#
# Scraped 95 users this round
# Got 202 reivews
# 463825 reviews are now in the bag, so to speak
# 2024-04-02 14:19:14
#
# Scraped 111 users this round
# Got 179 reivews
# 464004 reviews are now in the bag, so to speak
# 2024-04-02 14:23:35
#
# Scraped 97 users this round
# Got 178 reivews
# 464182 reviews are now in the bag, so to speak
# 2024-04-02 14:27:09
#
# Scraped 106 users this round
# Got 184 reivews
# 464366 reviews are now in the bag, so to speak
# 2024-04-02 14:31:04
#
# Scraped 98 users this round
# Got 191 reivews
# 464557 reviews are now in the bag, so to speak
# 2024-04-02 14:34:52
#
# Scraped 105 users this round
# Got 170 reivews
# 464727 reviews are now in the bag, so to speak
# 2024-04-02 14:38:47
#
# Scraped 106 users this round
# Got 137 reivews
# 464864 reviews are now in the bag, so to speak
# 2024-04-02 14:42:50
#
# Scraped 102 users this round
# Got 204 reivews
# 465068 reviews are now in the bag, so to speak
# 2024-04-02 14:46:34
#
# Scraped 118 users this round
# Got 192 reivews
# 465260 reviews are now in the bag, so to speak
# 2024-04-02 14:51:12
#
# Scraped 93 users this round
# Got 146 reivews
# ...
# 2024-04-02 23:22:08
#
# Scraped 127 users this round
# Got 170 reivews
# 488012 reviews are now in the bag, so to speak
# 2024-04-02 23:31:13
#
# Scraped 103 users this round
# Got 172 reivews
# 488184 reviews are now in the bag, so to speak
# 2024-04-02 23:38:26
#
# Scraped 100 users this round
# Got 175 reivews
# 488359 reviews are now in the bag, so to speak
# 2024-04-02 23:42:48
#
# Scraped 101 users this round
# Got 171 reivews
# 488530 reviews are now in the bag, so to speak
# 2024-04-02 23:46:28
#
# Scraped 107 users this round
# Got 202 reivews
# 488732 reviews are now in the bag, so to speak
# 2024-04-02 23:50:06
#
# Scraped 119 users this round
# Got 186 reivews
# 488918 reviews are now in the bag, so to speak
# 2024-04-02 23:54:15
#
# Scraped 122 users this round
# Got 175 reivews
# 489093 reviews are now in the bag, so to speak
# 2024-04-02 23:58:44
#
# Scraped 105 users this round
# Got 189 reivews
# 489282 reviews are now in the bag, so to speak
# 2024-04-03 00:02:19
#
# Scraped 118 users this round
# Got 169 reivews
# 489451 reviews are now in the bag, so to speak
# 2024-04-03 00:06:29
#
# Scraped 93 users this round
# Got 208 reivews
# 489659 reviews are now in the bag, so to speak
# 2024-04-03 00:09:43
#
# Scraped 110 users this round
# Got 171 reivews
# 489830 reviews are now in the bag, so to speak
# 2024-04-03 00:13:51
#
# Scraped 122 users this round
# Got 173 reivews
# 490003 reviews are now in the bag, so to speak
# 2024-04-03 00:18:26
#
# Scraped 121 users this round
# Got 200 reivews
# 490203 reviews are now in the bag, so to speak
# 2024-04-03 00:22:41
#
# Scraped 114 users this round
# Got 207 reivews
# 490410 reviews are now in the bag, so to speak
# 2024-04-03 00:26:36
#
# Scraped 113 users this round
# Got 227 reivews
# 490637 reviews are now in the bag, so to speak
# 2024-04-03 00:30:17
#
# Scraped 95 users this round
# Got 163 reivews
# 490800 reviews are now in the bag, so to speak
# 2024-04-03 00:33:33
#
# Scraped 122 users this round
# Got 194 reivews
# 490994 reviews are now in the bag, so to speak
# 2024-04-03 00:37:56
#
# Scraped 110 users this round
# Got 159 reivews
# 491153 reviews are now in the bag, so to speak
# 2024-04-03 00:41:49
#
# Scraped 103 users this round
# Got 170 reivews
# 491323 reviews are now in the bag, so to speak
# 2024-04-03 00:45:14
#
# Scraped 107 users this round
# Got 242 reivews
# 491565 reviews are now in the bag, so to speak
# 2024-04-03 00:49:00
#
# Scraped 117 users this round
# Got 198 reivews
# 491763 reviews are now in the bag, so to speak
# 2024-04-03 00:53:16
#
# Scraped 110 users this round
# Got 207 reivews
# 491970 reviews are now in the bag, so to speak
# 2024-04-03 00:56:56
#
# Scraped 107 users this round
# Got 191 reivews
# 492161 reviews are now in the bag, so to speak
# 2024-04-03 01:00:20
#
# Scraped 105 users this round
# Got 176 reivews
# 492337 reviews are now in the bag, so to speak
# 2024-04-03 01:03:52
#
# Scraped 119 users this round
# Got 164 reivews
# 492501 reviews are now in the bag, so to speak
# 2024-04-03 01:07:55
#
# Scraped 134 users this round
# Got 208 reivews
# 492709 reviews are now in the bag, so to speak
# 2024-04-03 01:12:42
#
# Scraped 120 users this round
# Got 199 reivews
# 492908 reviews are now in the bag, so to speak
# 2024-04-03 01:16:49
#
# Scraped 98 users this round
# Got 212 reivews
# 493120 reviews are now in the bag, so to speak
# 2024-04-03 01:19:57
#
# Scraped 115 users this round
# Got 206 reivews
# 493326 reviews are now in the bag, so to speak
# 2024-04-03 01:23:51
#
# Scraped 111 users this round
# Got 186 reivews
# 493512 reviews are now in the bag, so to speak
# 2024-04-03 01:27:43
#
# Scraped 101 users this round
# Got 164 reivews
# 493676 reviews are now in the bag, so to speak
# 2024-04-03 01:31:09
#
# Scraped 114 users this round
# Got 215 reivews
# 493891 reviews are now in the bag, so to speak
# 2024-04-03 01:34:55
#
# Scraped 115 users this round
# Got 178 reivews
# 494069 reviews are now in the bag, so to speak
# 2024-04-03 01:38:39
#
# Scraped 116 users this round
# Got 158 reivews
# 494227 reviews are now in the bag, so to speak
# 2024-04-03 01:42:27
#
# Scraped 108 users this round
# Got 179 reivews
# 494406 reviews are now in the bag, so to speak
# 2024-04-03 01:46:01
#
# Scraped 115 users this round
# Got 185 reivews
# 494591 reviews are now in the bag, so to speak
# 2024-04-03 01:49:47
#
# Scraped 109 users this round
# Got 172 reivews
# 494763 reviews are now in the bag, so to speak
# 2024-04-03 01:53:16
#
# Scraped 112 users this round
# Got 168 reivews
# 494931 reviews are now in the bag, so to speak
# 2024-04-03 01:57:05
#
# Scraped 110 users this round
# Got 228 reivews
# 495159 reviews are now in the bag, so to speak
# 2024-04-03 02:00:46
#
# Scraped 116 users this round
# Got 168 reivews
# 495327 reviews are now in the bag, so to speak
# 2024-04-03 02:04:53
#
# Scraped 113 users this round
# Got 220 reivews
# 495547 reviews are now in the bag, so to speak
# 2024-04-03 02:08:42
#
# Scraped 107 users this round
# Got 220 reivews
# 495767 reviews are now in the bag, so to speak
# 2024-04-03 02:12:16
#
# Scraped 95 users this round
# Got 219 reivews
# 495986 reviews are now in the bag, so to speak
# 2024-04-03 02:15:13
#
# Scraped 110 users this round
# Got 210 reivews
# 496196 reviews are now in the bag, so to speak
# 2024-04-03 02:18:48
#
# Scraped 128 users this round
# Got 186 reivews
# 496382 reviews are now in the bag, so to speak
# 2024-04-03 02:23:42
#
# Scraped 93 users this round
# Got 224 reivews
# 496606 reviews are now in the bag, so to speak
# 2024-04-03 02:26:47
#
# Scraped 109 users this round
# Got 198 reivews
# 496804 reviews are now in the bag, so to speak
# 2024-04-03 02:30:28
#
# Scraped 127 users this round
# Got 230 reivews
# 497034 reviews are now in the bag, so to speak
# 2024-04-03 02:34:45
#
# Scraped 113 users this round
# Got 164 reivews
# 497198 reviews are now in the bag, so to speak
# 2024-04-03 02:38:40
#
# Scraped 107 users this round
# Got 204 reivews
# 497402 reviews are now in the bag, so to speak
# 2024-04-03 02:42:03
#
# Scraped 104 users this round
# Got 157 reivews
# 497559 reviews are now in the bag, so to speak
# 2024-04-03 02:45:18
#
# Scraped 107 users this round
# Got 211 reivews
# 497770 reviews are now in the bag, so to speak
# 2024-04-03 02:49:03
#
# Scraped 101 users this round
# Got 228 reivews
# 497998 reviews are now in the bag, so to speak
# 2024-04-03 02:52:15
#
# Scraped 129 users this round
# Got 202 reivews
# 498200 reviews are now in the bag, so to speak
# 2024-04-03 02:56:43
#
# Scraped 119 users this round
# Got 192 reivews
# 498392 reviews are now in the bag, so to speak
# 2024-04-03 03:01:09
#
# Scraped 104 users this round
# Got 194 reivews
# 498586 reviews are now in the bag, so to speak
# 2024-04-03 03:04:51
#
# Scraped 112 users this round
# Got 151 reivews
# 498737 reviews are now in the bag, so to speak
# 2024-04-03 03:08:56
#
# Scraped 111 users this round
# Got 201 reivews
# 498938 reviews are now in the bag, so to speak
# 2024-04-03 03:12:42
#
# Scraped 107 users this round
# Got 167 reivews
# 499105 reviews are now in the bag, so to speak
# 2024-04-03 03:16:29
#
# Scraped 107 users this round
# Got 148 reivews
# 499253 reviews are now in the bag, so to speak
# 2024-04-03 03:20:06
#
# Scraped 99 users this round
# Got 167 reivews
# 499420 reviews are now in the bag, so to speak
# 2024-04-03 03:23:09
#
# Scraped 104 users this round
# Got 200 reivews
# 499620 reviews are now in the bag, so to speak
# 2024-04-03 03:26:38
#
# Scraped 116 users this round
# Got 182 reivews
# 499802 reviews are now in the bag, so to speak
# 2024-04-03 03:30:23
#
# Scraped 111 users this round
# Got 234 reivews
# 500036 reviews are now in the bag, so to speak
# 2024-04-03 03:34:08
#
# Scraped 101 users this round
# Got 162 reivews
# 500198 reviews are now in the bag, so to speak
# 2024-04-03 03:37:16
#
# Scraped 116 users this round
# Got 159 reivews
# 500357 reviews are now in the bag, so to speak
# 2024-04-03 03:41:06
#
# Scraped 103 users this round
# Got 226 reivews
# 500583 reviews are now in the bag, so to speak
# 2024-04-03 03:44:29
#
# Scraped 106 users this round
# Got 209 reivews
# 500792 reviews are now in the bag, so to speak
# 2024-04-03 03:47:48
#
# Scraped 116 users this round
# Got 201 reivews
# 500993 reviews are now in the bag, so to speak
# 2024-04-03 03:51:37
#
# Scraped 100 users this round
# Got 203 reivews
# 501196 reviews are now in the bag, so to speak
# 2024-04-03 03:54:52
#
# Scraped 110 users this round
# Got 169 reivews
# 501365 reviews are now in the bag, so to speak
# 2024-04-03 03:58:17
#
# Scraped 95 users this round
# Got 177 reivews
# 501542 reviews are now in the bag, so to speak
# 2024-04-03 04:01:19
#
# Scraped 133 users this round
# Got 158 reivews
# 501700 reviews are now in the bag, so to speak
# 2024-04-03 04:05:58
#
# Scraped 133 users this round
# Got 200 reivews
# 501900 reviews are now in the bag, so to speak
# 2024-04-03 04:10:38
#
# Scraped 105 users this round
# Got 142 reivews
# 502042 reviews are now in the bag, so to speak
# 2024-04-03 04:14:04
#
# Scraped 105 users this round
# Got 153 reivews
# 502195 reviews are now in the bag, so to speak
# 2024-04-03 04:17:18
#
# Scraped 112 users this round
# Got 198 reivews
# 502393 reviews are now in the bag, so to speak
# 2024-04-03 04:21:25
#
# Scraped 83 users this round
# Got 173 reivews
# 502566 reviews are now in the bag, so to speak
# 2024-04-03 04:24:05
#
# Scraped 88 users this round
# Got 198 reivews
# 502764 reviews are now in the bag, so to speak
# 2024-04-03 04:27:02
#
# Scraped 108 users this round
# Got 192 reivews
# 502956 reviews are now in the bag, so to speak
# 2024-04-03 04:30:46
#
# Scraped 114 users this round
# Got 180 reivews
# 503136 reviews are now in the bag, so to speak
# 2024-04-03 04:34:40
#
# Scraped 98 users this round
# Got 229 reivews
# 503365 reviews are now in the bag, so to speak
# 2024-04-03 04:37:52
#
# Scraped 112 users this round
# Got 194 reivews
# 503559 reviews are now in the bag, so to speak
# 2024-04-03 04:41:32
#
# Scraped 94 users this round
# Got 196 reivews
# 503755 reviews are now in the bag, so to speak
# 2024-04-03 04:44:36
#
# Scraped 100 users this round
# Got 176 reivews
# 503931 reviews are now in the bag, so to speak
# 2024-04-03 04:48:13
#
# Scraped 103 users this round
# Got 171 reivews
# 504102 reviews are now in the bag, so to speak
# 2024-04-03 04:52:10
#
# Scraped 97 users this round
# Got 195 reivews
# 504297 reviews are now in the bag, so to speak
# 2024-04-03 04:55:29
#
# Scraped 127 users this round
# Got 187 reivews
# 504484 reviews are now in the bag, so to speak
# 2024-04-03 04:59:56
#
# Scraped 97 users this round
# Got 137 reivews
# 504621 reviews are now in the bag, so to speak
# 2024-04-03 05:02:59
#
# Scraped 86 users this round
# Got 160 reivews
# 504781 reviews are now in the bag, so to speak
# 2024-04-03 05:05:57
#
# Scraped 101 users this round
# Got 179 reivews
# 504960 reviews are now in the bag, so to speak
# 2024-04-03 05:09:14
#
# Scraped 123 users this round
# Got 193 reivews
# 505153 reviews are now in the bag, so to speak
# 2024-04-03 05:13:28
#
# Scraped 101 users this round
# Got 139 reivews
# 505292 reviews are now in the bag, so to speak
# 2024-04-03 05:16:41
#
# Scraped 93 users this round
# Got 173 reivews
# 505465 reviews are now in the bag, so to speak
# 2024-04-03 05:19:39
#
# Scraped 121 users this round
# Got 164 reivews
# 505629 reviews are now in the bag, so to speak
# 2024-04-03 05:23:41
#
# Scraped 109 users this round
# Got 185 reivews
# 505814 reviews are now in the bag, so to speak
# 2024-04-03 05:27:27
#
# Scraped 123 users this round
# Got 187 reivews
# 506001 reviews are now in the bag, so to speak
# 2024-04-03 05:32:31
#
# Scraped 115 users this round
# Got 224 reivews
# 506225 reviews are now in the bag, so to speak
# 2024-04-03 05:36:16
#
# Scraped 122 users this round
# Got 190 reivews
# 506415 reviews are now in the bag, so to speak
# 2024-04-03 05:40:27
#
# Scraped 111 users this round
# Got 241 reivews
# 506656 reviews are now in the bag, so to speak
# 2024-04-03 05:44:05
#
# Scraped 108 users this round
# Got 180 reivews
# 506836 reviews are now in the bag, so to speak
# 2024-04-03 05:47:52
#
# Scraped 117 users this round
# Got 187 reivews
# 507023 reviews are now in the bag, so to speak
# 2024-04-03 05:51:51
#
# Scraped 109 users this round
# Got 182 reivews
# 507205 reviews are now in the bag, so to speak
# 2024-04-03 05:55:25
#
# Scraped 103 users this round
# Got 159 reivews
# 507364 reviews are now in the bag, so to speak
# 2024-04-03 05:58:39
#
# Scraped 100 users this round
# Got 183 reivews
# 507547 reviews are now in the bag, so to speak
# 2024-04-03 06:02:08
#
# Scraped 97 users this round
# Got 258 reivews
# 507805 reviews are now in the bag, so to speak
# 2024-04-03 06:05:24
#
# Scraped 109 users this round
# Got 222 reivews
# 508027 reviews are now in the bag, so to speak
# 2024-04-03 06:09:11
#
# Scraped 114 users this round
# Got 211 reivews
# 508238 reviews are now in the bag, so to speak
# 2024-04-03 06:13:03
#
# Scraped 110 users this round
# Got 179 reivews
# 508417 reviews are now in the bag, so to speak
# 2024-04-03 06:16:45
#
# Scraped 97 users this round
# Got 183 reivews
# 508600 reviews are now in the bag, so to speak
# 2024-04-03 06:19:47
#
# Scraped 115 users this round
# Got 183 reivews
# 508783 reviews are now in the bag, so to speak
# 2024-04-03 06:23:35
#
# Scraped 113 users this round
# Got 164 reivews
# 508947 reviews are now in the bag, so to speak
# 2024-04-03 06:27:26
#
# Scraped 135 users this round
# Got 210 reivews
# 509157 reviews are now in the bag, so to speak
# 2024-04-03 06:32:41
#
# Scraped 110 users this round
# Got 194 reivews
# 509351 reviews are now in the bag, so to speak
# 2024-04-03 06:36:46
#
# Scraped 104 users this round
# Got 190 reivews
# 509541 reviews are now in the bag, so to speak
# 2024-04-03 06:40:24
#
# Scraped 111 users this round
# Got 205 reivews
# 509746 reviews are now in the bag, so to speak
# 2024-04-03 06:44:19
#
# Scraped 111 users this round
# Got 178 reivews
# 509924 reviews are now in the bag, so to speak
# 2024-04-03 06:48:01
#
# Scraped 99 users this round
# Got 196 reivews
# 510120 reviews are now in the bag, so to speak
# 2024-04-03 06:51:16
#
# Scraped 104 users this round
# Got 199 reivews
# 510319 reviews are now in the bag, so to speak
# 2024-04-03 06:54:38
#
# Scraped 106 users this round
# Got 219 reivews
# 510538 reviews are now in the bag, so to speak
# 2024-04-03 06:58:20
#
# Scraped 108 users this round
# Got 160 reivews
# 510698 reviews are now in the bag, so to speak
# 2024-04-03 07:01:54
#
# Scraped 113 users this round
# Got 192 reivews
# 510890 reviews are now in the bag, so to speak
# 2024-04-03 07:05:50
#
# Scraped 99 users this round
# Got 207 reivews
# 511097 reviews are now in the bag, so to speak
# 2024-04-03 07:09:07
#
# Scraped 115 users this round
# Got 162 reivews
# 511259 reviews are now in the bag, so to speak
# 2024-04-03 07:13:03
#
# Scraped 103 users this round
# Got 205 reivews
# 511464 reviews are now in the bag, so to speak
# 2024-04-03 07:16:40
#
# Scraped 101 users this round
# Got 177 reivews
# 511641 reviews are now in the bag, so to speak
# 2024-04-03 07:20:21
#
# Scraped 108 users this round
# Got 175 reivews
# 511816 reviews are now in the bag, so to speak
# 2024-04-03 07:23:58
#
# Scraped 97 users this round
# Got 198 reivews
# 512014 reviews are now in the bag, so to speak
# 2024-04-03 07:27:14
#
# Scraped 106 users this round
# Got 199 reivews
# 512213 reviews are now in the bag, so to speak
# 2024-04-03 07:31:32
#
# Scraped 121 users this round
# Got 183 reivews
# 512396 reviews are now in the bag, so to speak
# 2024-04-03 07:35:55
#
# Scraped 123 users this round
# Got 208 reivews
# 512604 reviews are now in the bag, so to speak
# 2024-04-03 07:40:15
#
# Scraped 99 users this round
# Got 189 reivews
# 512793 reviews are now in the bag, so to speak
# 2024-04-03 07:43:40
#
# Scraped 118 users this round
# Got 167 reivews
# 512960 reviews are now in the bag, so to speak
# 2024-04-03 07:47:58
#
# Scraped 97 users this round
# Got 165 reivews
# 513125 reviews are now in the bag, so to speak
# 2024-04-03 07:51:23
#
# Scraped 108 users this round
# Got 197 reivews
# 513322 reviews are now in the bag, so to speak
# 2024-04-03 07:55:03
#
# Scraped 110 users this round
# Got 202 reivews
# 513524 reviews are now in the bag, so to speak
# 2024-04-03 07:58:44
#
# Scraped 114 users this round
# Got 193 reivews
# 513717 reviews are now in the bag, so to speak
# 2024-04-03 08:02:51
#
# Scraped 105 users this round
# Got 206 reivews
# 513923 reviews are now in the bag, so to speak
# 2024-04-03 08:06:41
#
# Scraped 118 users this round
# Got 219 reivews
# 514142 reviews are now in the bag, so to speak
# 2024-04-03 08:11:14
#
# Scraped 108 users this round
# Got 190 reivews
# 514332 reviews are now in the bag, so to speak
# 2024-04-03 08:15:11
#
# Scraped 111 users this round
# Got 228 reivews
# 514560 reviews are now in the bag, so to speak
# 2024-04-03 08:20:06
#
# Unable to parse review blocks.
