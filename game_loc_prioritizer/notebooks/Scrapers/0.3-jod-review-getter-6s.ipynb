# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 6

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')


# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 83 users this round
# Got 198 reivews
# 329669 reviews are now in the bag, so to speak
# 2024-03-31 20:24:38
#
# Scraped 97 users this round
# Got 145 reivews
# 329814 reviews are now in the bag, so to speak
# 2024-03-31 20:28:02
#
# Scraped 96 users this round
# Got 212 reivews
# 330026 reviews are now in the bag, so to speak
# 2024-03-31 20:31:28
#
# Scraped 137 users this round
# Got 176 reivews
# 330202 reviews are now in the bag, so to speak
# 2024-03-31 20:36:32
#
# Scraped 94 users this round
# Got 167 reivews
# 330369 reviews are now in the bag, so to speak
# 2024-03-31 20:39:36
#
# Scraped 95 users this round
# Got 191 reivews
# 330560 reviews are now in the bag, so to speak
# 2024-03-31 20:42:53
#
# Scraped 120 users this round
# Got 201 reivews
# 330761 reviews are now in the bag, so to speak
# 2024-03-31 20:47:05
#
# Scraped 128 users this round
# Got 164 reivews
# 330925 reviews are now in the bag, so to speak
# 2024-03-31 20:51:48
#
# Scraped 109 users this round
# Got 209 reivews
# 331134 reviews are now in the bag, so to speak
# 2024-03-31 20:55:49
#
# Scraped 101 users this round
# Got 206 reivews
# 331340 reviews are now in the bag, so to speak
# 2024-03-31 20:59:29
#
# Scraped 119 users this round
# Got 206 reivews
# 331546 reviews are now in the bag, so to speak
# 2024-03-31 21:03:47
#
# Scraped 122 users this round
# Got 185 reivews
# 331731 reviews are now in the bag, so to speak
# 2024-03-31 21:08:04
#
# Scraped 126 users this round
# Got 179 reivews
# 331910 reviews are now in the bag, so to speak
# 2024-03-31 21:12:37
#
# Scraped 94 users this round
# Got 195 reivews
# 332105 reviews are now in the bag, so to speak
# 2024-03-31 21:16:04
#
# Scraped 129 users this round
# Got 234 reivews
# 332339 reviews are now in the bag, so to speak
# 2024-03-31 21:21:02
#
# Scraped 96 users this round
# Got 224 reivews
# 332563 reviews are now in the bag, so to speak
# 2024-03-31 21:24:40
#
# Scraped 125 users this round
# Got 184 reivews
# 332747 reviews are now in the bag, so to speak
# 2024-03-31 21:29:29
#
# Scraped 126 users this round
# Got 175 reivews
# 332922 reviews are now in the bag, so to speak
# 2024-03-31 21:34:30
#
# Scraped 94 users this round
# Got 191 reivews
# 333113 reviews are now in the bag, so to speak
# 2024-03-31 21:38:12
#
# Scraped 106 users this round
# Got 204 reivews
# 333317 reviews are now in the bag, so to speak
# 2024-03-31 21:42:28
#
# Scraped 118 users this round
# Got 171 reivews
# 333488 reviews are now in the bag, so to speak
# 2024-03-31 21:47:03
#
# Scraped 128 users this round
# Got 150 reivews
# 333638 reviews are now in the bag, so to speak
# 2024-03-31 21:52:07
#
# Scraped 99 users this round
# Got 175 reivews
# 333813 reviews are now in the bag, so to speak
# 2024-03-31 21:55:42
#
# Scraped 120 users this round
# Got 183 reivews
# 333996 reviews are now in the bag, so to speak
# 2024-03-31 22:00:11
#
# Scraped 110 users this round
# Got 181 reivews
# 334177 reviews are now in the bag, so to speak
# 2024-03-31 22:04:10
#
# Scraped 123 users this round
# Got 231 reivews
# 334408 reviews are now in the bag, so to speak
# 2024-03-31 22:09:07
#
# Scraped 132 users this round
# Got 212 reivews
# 334620 reviews are now in the bag, so to speak
# 2024-03-31 22:16:02
#
# Scraped 105 users this round
# Got 188 reivews
# 334808 reviews are now in the bag, so to speak
# 2024-03-31 22:21:22
#
# Scraped 123 users this round
# Got 176 reivews
# 334984 reviews are now in the bag, so to speak
# 2024-03-31 22:27:56
#
# Scraped 94 users this round
# Got 198 reivews
# 335182 reviews are now in the bag, so to speak
# 2024-03-31 22:33:15
#
# Scraped 117 users this round
# Got 174 reivews
# 335356 reviews are now in the bag, so to speak
# 2024-03-31 22:39:55
#
# Scraped 123 users this round
# Got 217 reivews
# 335573 reviews are now in the bag, so to speak
# 2024-03-31 22:46:59
#
# Scraped 104 users this round
# Got 224 reivews
# 335797 reviews are now in the bag, so to speak
# 2024-03-31 22:52:57
#
# Scraped 83 users this round
# Got 232 reivews
# 336029 reviews are now in the bag, so to speak
# 2024-03-31 22:57:57
#
# Scraped 113 users this round
# Got 174 reivews
# 336203 reviews are now in the bag, so to speak
# 2024-03-31 23:04:31
#
# Scraped 114 users this round
# Got 189 reivews
# 336392 reviews are now in the bag, so to speak
# 2024-03-31 23:10:54
#
# Scraped 105 users this round
# Got 197 reivews
# 336589 reviews are now in the bag, so to speak
# 2024-03-31 23:16:33
#
# Scraped 111 users this round
# Got 166 reivews
# 336755 reviews are now in the bag, so to speak
# 2024-03-31 23:22:51
#
# Scraped 122 users this round
# Got 176 reivews
# 336931 reviews are now in the bag, so to speak
# 2024-03-31 23:28:00
#
# Scraped 105 users this round
# Got 203 reivews
# 337134 reviews are now in the bag, so to speak
# 2024-03-31 23:31:40
#
# Scraped 105 users this round
# Got 182 reivews
# 337316 reviews are now in the bag, so to speak
# 2024-03-31 23:35:15
#
# Scraped 124 users this round
# Got 173 reivews
# 337489 reviews are now in the bag, so to speak
# 2024-03-31 23:39:49
#
# Scraped 113 users this round
# Got 195 reivews
# 337684 reviews are now in the bag, so to speak
# 2024-03-31 23:43:43
#
# Scraped 110 users this round
# Got 200 reivews
# 337884 reviews are now in the bag, so to speak
# 2024-03-31 23:47:36
#
# Scraped 114 users this round
# Got 177 reivews
# 338061 reviews are now in the bag, so to speak
# 2024-03-31 23:51:18
#
# Scraped 101 users this round
# Got 186 reivews
# 338247 reviews are now in the bag, so to speak
# 2024-03-31 23:54:30
#
# Scraped 112 users this round
# Got 173 reivews
# 338420 reviews are now in the bag, so to speak
# 2024-03-31 23:58:21
#
# Scraped 99 users this round
# Got 186 reivews
# 338606 reviews are now in the bag, so to speak
# 2024-04-01 00:01:35
#
# Scraped 106 users this round
# Got 218 reivews
# 338824 reviews are now in the bag, so to speak
# 2024-04-01 00:05:09
#
# Scraped 111 users this round
# Got 157 reivews
# 338981 reviews are now in the bag, so to speak
# 2024-04-01 00:08:53
#
# Scraped 104 users this round
# Got 169 reivews
# 339150 reviews are now in the bag, so to speak
# 2024-04-01 00:12:23
#
# Scraped 128 users this round
# Got 180 reivews
# 339330 reviews are now in the bag, so to speak
# 2024-04-01 00:16:45
#
# Scraped 97 users this round
# Got 144 reivews
# 339474 reviews are now in the bag, so to speak
# 2024-04-01 00:19:54
#
# Scraped 128 users this round
# Got 174 reivews
# 339648 reviews are now in the bag, so to speak
# 2024-04-01 00:24:14
#
# Scraped 106 users this round
# Got 206 reivews
# 339854 reviews are now in the bag, so to speak
# 2024-04-01 00:27:44
#
# Scraped 105 users this round
# Got 157 reivews
# 340011 reviews are now in the bag, so to speak
# 2024-04-01 00:31:06
#
# Scraped 104 users this round
# Got 168 reivews
# 340179 reviews are now in the bag, so to speak
# 2024-04-01 00:34:30
#
# Scraped 108 users this round
# Got 208 reivews
# 340387 reviews are now in the bag, so to speak
# 2024-04-01 00:38:05
#
# Unable to parse review blocks.
# Scraped 99 users this round
# Got 195 reivews
# 340582 reviews are now in the bag, so to speak
# 2024-04-01 00:47:32
#
# Scraped 89 users this round
# Got 241 reivews
# 340823 reviews are now in the bag, so to speak
# 2024-04-01 00:50:46
#
# Scraped 90 users this round
# Got 169 reivews
# 340992 reviews are now in the bag, so to speak
# 2024-04-01 00:53:32
#
# Scraped 108 users this round
# Got 214 reivews
# 341206 reviews are now in the bag, so to speak
# 2024-04-01 00:57:14
#
# Scraped 109 users this round
# Got 223 reivews
# 341429 reviews are now in the bag, so to speak
# 2024-04-01 01:00:54
#
# Scraped 125 users this round
# Got 181 reivews
# 341610 reviews are now in the bag, so to speak
# 2024-04-01 01:05:25
#
# Scraped 95 users this round
# Got 150 reivews
# 341760 reviews are now in the bag, so to speak
# 2024-04-01 01:08:32
#
# Scraped 106 users this round
# Got 222 reivews
# 341982 reviews are now in the bag, so to speak
# 2024-04-01 01:12:11
#
# Scraped 112 users this round
# Got 188 reivews
# 342170 reviews are now in the bag, so to speak
# 2024-04-01 01:16:03
#
# Scraped 102 users this round
# Got 187 reivews
# 342357 reviews are now in the bag, so to speak
# 2024-04-01 01:19:33
#
# Scraped 117 users this round
# Got 167 reivews
# 342524 reviews are now in the bag, so to speak
# 2024-04-01 01:23:38
#
# Scraped 103 users this round
# Got 184 reivews
# 342708 reviews are now in the bag, so to speak
# 2024-04-01 01:27:03
#
# Scraped 116 users this round
# Got 182 reivews
# 342890 reviews are now in the bag, so to speak
# 2024-04-01 01:30:54
#
# Scraped 106 users this round
# Got 136 reivews
# 343026 reviews are now in the bag, so to speak
# 2024-04-01 01:34:23
#
# Scraped 131 users this round
# Got 187 reivews
# 343213 reviews are now in the bag, so to speak
# 2024-04-01 01:38:45
#
# Scraped 112 users this round
# Got 160 reivews
# 343373 reviews are now in the bag, so to speak
# 2024-04-01 01:42:43
#
# Scraped 117 users this round
# Got 196 reivews
# 343569 reviews are now in the bag, so to speak
# 2024-04-01 01:46:43
#
# Scraped 118 users this round
# Got 159 reivews
# 343728 reviews are now in the bag, so to speak
# 2024-04-01 01:50:54
#
# Scraped 115 users this round
# Got 184 reivews
# 343912 reviews are now in the bag, so to speak
# 2024-04-01 01:54:52
#
# Scraped 116 users this round
# Got 195 reivews
# 344107 reviews are now in the bag, so to speak
# 2024-04-01 01:58:45
#
# Scraped 109 users this round
# Got 182 reivews
# 344289 reviews are now in the bag, so to speak
# 2024-04-01 02:02:38
#
# Scraped 123 users this round
# Got 262 reivews
# 344551 reviews are now in the bag, so to speak
# 2024-04-01 02:06:59
#
# Scraped 116 users this round
# Got 190 reivews
# 344741 reviews are now in the bag, so to speak
# 2024-04-01 02:11:08
#
# Scraped 105 users this round
# Got 180 reivews
# 344921 reviews are now in the bag, so to speak
# 2024-04-01 02:14:44
#
# Scraped 112 users this round
# Got 237 reivews
# 345158 reviews are now in the bag, so to speak
# 2024-04-01 02:18:32
#
# Scraped 118 users this round
# Got 209 reivews
# 345367 reviews are now in the bag, so to speak
# 2024-04-01 02:22:28
#
# Scraped 134 users this round
# Got 167 reivews
# 345534 reviews are now in the bag, so to speak
# 2024-04-01 02:27:05
#
# Scraped 113 users this round
# Got 175 reivews
# 345709 reviews are now in the bag, so to speak
# 2024-04-01 02:30:58
#
# Scraped 123 users this round
# Got 163 reivews
# 345872 reviews are now in the bag, so to speak
# 2024-04-01 02:35:08
#
# Scraped 116 users this round
# Got 200 reivews
# 346072 reviews are now in the bag, so to speak
# 2024-04-01 02:39:09
#
# Scraped 119 users this round
# Got 213 reivews
# 346285 reviews are now in the bag, so to speak
# 2024-04-01 02:43:18
#
# Scraped 116 users this round
# Got 184 reivews
# 346469 reviews are now in the bag, so to speak
# 2024-04-01 02:47:07
#
# Scraped 98 users this round
# Got 221 reivews
# 346690 reviews are now in the bag, so to speak
# 2024-04-01 02:50:12
#
# Scraped 108 users this round
# Got 231 reivews
# 346921 reviews are now in the bag, so to speak
# 2024-04-01 02:53:39
#
# Scraped 105 users this round
# Got 180 reivews
# 347101 reviews are now in the bag, so to speak
# 2024-04-01 02:57:07
#
# Scraped 133 users this round
# Got 233 reivews
# 347334 reviews are now in the bag, so to speak
# 2024-04-01 03:01:36
#
# Scraped 106 users this round
# Got 216 reivews
# 347550 reviews are now in the bag, so to speak
# 2024-04-01 03:05:01
#
# Scraped 108 users this round
# Got 183 reivews
# 347733 reviews are now in the bag, so to speak
# 2024-04-01 03:08:26
#
# Scraped 122 users this round
# Got 177 reivews
# 347910 reviews are now in the bag, so to speak
# 2024-04-01 03:12:39
#
# Scraped 108 users this round
# Got 175 reivews
# 348085 reviews are now in the bag, so to speak
# 2024-04-01 03:16:13
#
# Scraped 112 users this round
# Got 203 reivews
# 348288 reviews are now in the bag, so to speak
# 2024-04-01 03:19:57
#
# Scraped 109 users this round
# Got 218 reivews
# 348506 reviews are now in the bag, so to speak
# 2024-04-01 03:23:39
#
# Scraped 138 users this round
# Got 178 reivews
# 348684 reviews are now in the bag, so to speak
# 2024-04-01 03:28:18
#
# Scraped 98 users this round
# Got 170 reivews
# 348854 reviews are now in the bag, so to speak
# 2024-04-01 03:31:27
#
# Scraped 105 users this round
# Got 205 reivews
# 349059 reviews are now in the bag, so to speak
# 2024-04-01 03:34:48
#
# Scraped 106 users this round
# Got 160 reivews
# 349219 reviews are now in the bag, so to speak
# 2024-04-01 03:38:13
#
# Scraped 120 users this round
# Got 203 reivews
# 349422 reviews are now in the bag, so to speak
# 2024-04-01 03:42:17
#
# Scraped 115 users this round
# Got 159 reivews
# 349581 reviews are now in the bag, so to speak
# 2024-04-01 03:46:02
#
# Scraped 111 users this round
# Got 147 reivews
# 349728 reviews are now in the bag, so to speak
# 2024-04-01 03:49:45
#
# Scraped 127 users this round
# Got 204 reivews
# 349932 reviews are now in the bag, so to speak
# 2024-04-01 03:53:50
#
# Scraped 124 users this round
# Got 211 reivews
# 350143 reviews are now in the bag, so to speak
# 2024-04-01 03:58:03
#
# Scraped 117 users this round
# Got 162 reivews
# 350305 reviews are now in the bag, so to speak
# 2024-04-01 04:02:12
#
# Scraped 99 users this round
# Got 154 reivews
# 350459 reviews are now in the bag, so to speak
# 2024-04-01 04:05:17
#
# Scraped 114 users this round
# Got 197 reivews
# 350656 reviews are now in the bag, so to speak
# 2024-04-01 04:09:06
#
# Scraped 93 users this round
# Got 206 reivews
# 350862 reviews are now in the bag, so to speak
# 2024-04-01 04:11:55
#
# Scraped 103 users this round
# Got 219 reivews
# 351081 reviews are now in the bag, so to speak
# 2024-04-01 04:15:09
#
# Scraped 95 users this round
# Got 185 reivews
# 351266 reviews are now in the bag, so to speak
# 2024-04-01 04:18:19
#
# Scraped 118 users this round
# Got 214 reivews
# 351480 reviews are now in the bag, so to speak
# 2024-04-01 04:22:13
#
# Scraped 117 users this round
# Got 191 reivews
# 351671 reviews are now in the bag, so to speak
# 2024-04-01 04:26:12
#
# Scraped 89 users this round
# Got 159 reivews
# 351830 reviews are now in the bag, so to speak
# 2024-04-01 04:29:08
#
# Scraped 96 users this round
# Got 183 reivews
# 352013 reviews are now in the bag, so to speak
# 2024-04-01 04:32:15
#
# Scraped 119 users this round
# Got 204 reivews
# 352217 reviews are now in the bag, so to speak
# 2024-04-01 04:36:29
#
# Scraped 106 users this round
# Got 181 reivews
# 352398 reviews are now in the bag, so to speak
# 2024-04-01 04:40:12
#
# Scraped 117 users this round
# Got 183 reivews
# 352581 reviews are now in the bag, so to speak
# 2024-04-01 04:43:53
#
# Scraped 111 users this round
# Got 168 reivews
# 352749 reviews are now in the bag, so to speak
# 2024-04-01 04:47:30
#
# Scraped 102 users this round
# Got 154 reivews
# 352903 reviews are now in the bag, so to speak
# 2024-04-01 04:50:40
#
# Scraped 112 users this round
# Got 191 reivews
# 353094 reviews are now in the bag, so to speak
# 2024-04-01 04:54:12
#
# Scraped 102 users this round
# Got 227 reivews
# 353321 reviews are now in the bag, so to speak
# 2024-04-01 04:57:38
#
# Scraped 117 users this round
# Got 168 reivews
# 353489 reviews are now in the bag, so to speak
# 2024-04-01 05:01:13
#
# Scraped 117 users this round
# Got 191 reivews
# 353680 reviews are now in the bag, so to speak
# 2024-04-01 05:04:59
#
# Scraped 122 users this round
# Got 162 reivews
# 353842 reviews are now in the bag, so to speak
# 2024-04-01 05:08:56
#
# Scraped 112 users this round
# Got 190 reivews
# 354032 reviews are now in the bag, so to speak
# 2024-04-01 05:12:43
#
# Scraped 113 users this round
# Got 188 reivews
# 354220 reviews are now in the bag, so to speak
# 2024-04-01 05:16:24
#
# Scraped 102 users this round
# Got 177 reivews
# 354397 reviews are now in the bag, so to speak
# 2024-04-01 05:19:37
#
# Scraped 116 users this round
# Got 176 reivews
# 354573 reviews are now in the bag, so to speak
# 2024-04-01 05:23:24
#
# Scraped 106 users this round
# Got 176 reivews
# 354749 reviews are now in the bag, so to speak
# 2024-04-01 05:26:59
#
# Scraped 83 users this round
# Got 164 reivews
# 354913 reviews are now in the bag, so to speak
# 2024-04-01 05:29:21
#
# Scraped 98 users this round
# Got 181 reivews
# 355094 reviews are now in the bag, so to speak
# 2024-04-01 05:32:26
#
# Scraped 105 users this round
# Got 191 reivews
# 355285 reviews are now in the bag, so to speak
# 2024-04-01 05:35:48
#
# Scraped 91 users this round
# Got 135 reivews
# 355420 reviews are now in the bag, so to speak
# 2024-04-01 05:38:46
#
# Scraped 118 users this round
# Got 190 reivews
# 355610 reviews are now in the bag, so to speak
# 2024-04-01 05:42:42
#
# Scraped 114 users this round
# Got 190 reivews
# 355800 reviews are now in the bag, so to speak
# 2024-04-01 05:46:31
#
# Unable to parse review blocks.
# Scraped 107 users this round
# Got 202 reivews
# 356002 reviews are now in the bag, so to speak
# 2024-04-01 05:51:18
#
# Scraped 101 users this round
# Got 180 reivews
# 356182 reviews are now in the bag, so to speak
# 2024-04-01 05:54:30
#
# Scraped 109 users this round
# Got 176 reivews
# 356358 reviews are now in the bag, so to speak
# 2024-04-01 05:57:56
#
# Scraped 106 users this round
# Got 165 reivews
# 356523 reviews are now in the bag, so to speak
# 2024-04-01 06:01:37
#
# Scraped 135 users this round
# Got 224 reivews
# 356747 reviews are now in the bag, so to speak
# 2024-04-01 06:06:08
#
# Scraped 107 users this round
# Got 161 reivews
# 356908 reviews are now in the bag, so to speak
# 2024-04-01 06:09:52
#
# Scraped 108 users this round
# Got 176 reivews
# 357084 reviews are now in the bag, so to speak
# 2024-04-01 06:13:34
#
# Scraped 115 users this round
# Got 157 reivews
# 357241 reviews are now in the bag, so to speak
# 2024-04-01 06:17:36
#
# Scraped 100 users this round
# Got 192 reivews
# 357433 reviews are now in the bag, so to speak
# 2024-04-01 06:21:12
#
# Scraped 107 users this round
# Got 230 reivews
# 357663 reviews are now in the bag, so to speak
# 2024-04-01 06:24:49
#
# Scraped 144 users this round
# Got 182 reivews
# 357845 reviews are now in the bag, so to speak
# 2024-04-01 06:29:44
#
# Scraped 117 users this round
# Got 196 reivews
# 358041 reviews are now in the bag, so to speak
# 2024-04-01 06:33:40
#
# Scraped 112 users this round
# Got 197 reivews
# 358238 reviews are now in the bag, so to speak
# 2024-04-01 06:37:26
#
# Scraped 142 users this round
# Got 200 reivews
# 358438 reviews are now in the bag, so to speak
# 2024-04-01 06:42:07
#
# Scraped 134 users this round
# Got 176 reivews
# 358614 reviews are now in the bag, so to speak
# 2024-04-01 06:46:51
#
# Scraped 121 users this round
# Got 217 reivews
# 358831 reviews are now in the bag, so to speak
# 2024-04-01 06:50:53
#
# Scraped 112 users this round
# Got 214 reivews
# 359045 reviews are now in the bag, so to speak
# 2024-04-01 06:54:31
#
# Scraped 130 users this round
# Got 182 reivews
# 359227 reviews are now in the bag, so to speak
# 2024-04-01 06:58:49
#
# Scraped 110 users this round
# Got 213 reivews
# 359440 reviews are now in the bag, so to speak
# 2024-04-01 07:02:29
#
# Scraped 104 users this round
# Got 183 reivews
# 359623 reviews are now in the bag, so to speak
# 2024-04-01 07:05:52
#
# Scraped 120 users this round
# Got 168 reivews
# 359791 reviews are now in the bag, so to speak
# 2024-04-01 07:09:47
#
# Scraped 109 users this round
# Got 187 reivews
# 359978 reviews are now in the bag, so to speak
# 2024-04-01 07:13:32
#
# Scraped 111 users this round
# Got 202 reivews
# 360180 reviews are now in the bag, so to speak
# 2024-04-01 07:17:22
#
# Scraped 108 users this round
# Got 176 reivews
# 360356 reviews are now in the bag, so to speak
# 2024-04-01 07:20:54
#
# Scraped 118 users this round
# Got 157 reivews
# 360513 reviews are now in the bag, so to speak
# 2024-04-01 07:24:54
#
# Scraped 117 users this round
# Got 165 reivews
# 360678 reviews are now in the bag, so to speak
# 2024-04-01 07:29:09
#
# Scraped 101 users this round
# Got 173 reivews
# 360851 reviews are now in the bag, so to speak
# 2024-04-01 07:32:37
#
# Scraped 96 users this round
# Got 159 reivews
# 361010 reviews are now in the bag, so to speak
# 2024-04-01 07:36:09
#
# Scraped 116 users this round
# Got 162 reivews
# 361172 reviews are now in the bag, so to speak
# 2024-04-01 07:40:18
#
# Scraped 104 users this round
# Got 168 reivews
# 361340 reviews are now in the bag, so to speak
# 2024-04-01 07:43:48
#
# Scraped 90 users this round
# Got 192 reivews
# 361532 reviews are now in the bag, so to speak
# 2024-04-01 07:46:47
#
# Scraped 102 users this round
# Got 209 reivews
# 361741 reviews are now in the bag, so to speak
# 2024-04-01 07:50:13
#
# Scraped 110 users this round
# Got 208 reivews
# 361949 reviews are now in the bag, so to speak
# 2024-04-01 07:53:53
#
# Scraped 106 users this round
# Got 201 reivews
# 362150 reviews are now in the bag, so to speak
# 2024-04-01 07:57:32
#
# Scraped 104 users this round
# Got 199 reivews
# 362349 reviews are now in the bag, so to speak
# 2024-04-01 08:00:53
#
# Scraped 103 users this round
# Got 167 reivews
# 362516 reviews are now in the bag, so to speak
# 2024-04-01 08:04:22
#
# Scraped 102 users this round
# Got 191 reivews
# 362707 reviews are now in the bag, so to speak
# 2024-04-01 08:07:48
#
# Scraped 99 users this round
# Got 176 reivews
# 362883 reviews are now in the bag, so to speak
# 2024-04-01 08:11:09
#
# Scraped 120 users this round
# Got 170 reivews
# 363053 reviews are now in the bag, so to speak
# 2024-04-01 08:15:13
#
# Scraped 95 users this round
# Got 166 reivews
# 363219 reviews are now in the bag, so to speak
# 2024-04-01 08:18:24
#
# Scraped 110 users this round
# Got 196 reivews
# 363415 reviews are now in the bag, so to speak
# 2024-04-01 08:22:13
#
# Scraped 119 users this round
# Got 197 reivews
# 363612 reviews are now in the bag, so to speak
# 2024-04-01 08:26:22
#
# Scraped 100 users this round
# Got 208 reivews
# 363820 reviews are now in the bag, so to speak
# 2024-04-01 08:29:48
#
# Scraped 107 users this round
# Got 156 reivews
# 363976 reviews are now in the bag, so to speak
# 2024-04-01 08:33:29
#
# Scraped 116 users this round
# Got 156 reivews
# 364132 reviews are now in the bag, so to speak
# 2024-04-01 08:37:25
#
# Scraped 105 users this round
# Got 197 reivews
# 364329 reviews are now in the bag, so to speak
# 2024-04-01 08:40:58
#
# Scraped 116 users this round
# Got 157 reivews
# 364486 reviews are now in the bag, so to speak
# 2024-04-01 08:45:17
#
# Scraped 112 users this round
# Got 227 reivews
# 364713 reviews are now in the bag, so to speak
# 2024-04-01 08:49:03
#
# Scraped 120 users this round
# Got 180 reivews
# 364893 reviews are now in the bag, so to speak
# 2024-04-01 08:53:17
#
# Scraped 100 users this round
# Got 198 reivews
# 365091 reviews are now in the bag, so to speak
# 2024-04-01 08:56:36
#
# Scraped 103 users this round
# Got 140 reivews
# 365231 reviews are now in the bag, so to speak
# 2024-04-01 08:59:58
#
# Scraped 102 users this round
# Got 206 reivews
# 365437 reviews are now in the bag, so to speak
# 2024-04-01 09:03:30
#
# Scraped 100 users this round
# Got 188 reivews
# 365625 reviews are now in the bag, so to speak
# 2024-04-01 09:07:03
#
# Scraped 97 users this round
# Got 197 reivews
# 365822 reviews are now in the bag, so to speak
# 2024-04-01 09:10:36
#
# Scraped 106 users this round
# Got 205 reivews
# 366027 reviews are now in the bag, so to speak
# 2024-04-01 09:14:23
#
# Scraped 96 users this round
# Got 171 reivews
# 366198 reviews are now in the bag, so to speak
# 2024-04-01 09:17:46
#
# Scraped 104 users this round
# Got 191 reivews
# 366389 reviews are now in the bag, so to speak
# 2024-04-01 09:21:21
#
# Scraped 112 users this round
# Got 219 reivews
# 366608 reviews are now in the bag, so to speak
# 2024-04-01 09:25:11
#
# Scraped 101 users this round
# Got 236 reivews
# 366844 reviews are now in the bag, so to speak
# 2024-04-01 09:28:49
#
# Scraped 111 users this round
# Got 172 reivews
# 367016 reviews are now in the bag, so to speak
# 2024-04-01 09:32:49
#
# Scraped 95 users this round
# Got 122 reivews
# 367138 reviews are now in the bag, so to speak
# 2024-04-01 09:35:58
#
# Scraped 113 users this round
# Got 195 reivews
# 367333 reviews are now in the bag, so to speak
# 2024-04-01 09:40:10
#
# Scraped 118 users this round
# Got 141 reivews
# 367474 reviews are now in the bag, so to speak
# 2024-04-01 09:44:33
#
# Scraped 118 users this round
# Got 187 reivews
# 367661 reviews are now in the bag, so to speak
# 2024-04-01 09:48:54
#
# Scraped 115 users this round
# Got 172 reivews
# 367833 reviews are now in the bag, so to speak
# 2024-04-01 09:53:06
#
# Scraped 109 users this round
# Got 184 reivews
# 368017 reviews are now in the bag, so to speak
# 2024-04-01 09:57:08
#
# Scraped 122 users this round
# Got 187 reivews
# 368204 reviews are now in the bag, so to speak
# 2024-04-01 10:01:43
#
# Scraped 86 users this round
# Got 210 reivews
# 368414 reviews are now in the bag, so to speak
# 2024-04-01 10:05:00
#
# Scraped 107 users this round
# Got 149 reivews
# 368563 reviews are now in the bag, so to speak
# 2024-04-01 10:08:55
#
# Scraped 127 users this round
# Got 224 reivews
# 368787 reviews are now in the bag, so to speak
# 2024-04-01 10:13:37
#
# Scraped 99 users this round
# Got 182 reivews
# 368969 reviews are now in the bag, so to speak
# 2024-04-01 10:17:15
#
# Scraped 116 users this round
# Got 227 reivews
# 369196 reviews are now in the bag, so to speak
# 2024-04-01 10:21:40
#
# Scraped 112 users this round
# Got 220 reivews
# 369416 reviews are now in the bag, so to speak
# 2024-04-01 10:25:34
#
# Scraped 116 users this round
# Got 213 reivews
# 369629 reviews are now in the bag, so to speak
# 2024-04-01 10:30:23
#
# Scraped 91 users this round
# Got 154 reivews
# 369783 reviews are now in the bag, so to speak
# 2024-04-01 10:33:43
#
# Scraped 133 users this round
# Got 197 reivews
# 369980 reviews are now in the bag, so to speak
# 2024-04-01 10:39:04
#
# Scraped 128 users this round
# Got 202 reivews
# 370182 reviews are now in the bag, so to speak
# 2024-04-01 10:43:58
#
# Scraped 98 users this round
# Got 199 reivews
# 370381 reviews are now in the bag, so to speak
# 2024-04-01 10:47:38
#
# Scraped 114 users this round
# Got 185 reivews
# 370566 reviews are now in the bag, so to speak
# 2024-04-01 10:51:49
#
# Scraped 112 users this round
# Got 197 reivews
# 370763 reviews are now in the bag, so to speak
# 2024-04-01 10:56:16
#
# Scraped 104 users this round
# Got 166 reivews
# 370929 reviews are now in the bag, so to speak
# 2024-04-01 11:00:09
#
# Scraped 103 users this round
# Got 191 reivews
# 371120 reviews are now in the bag, so to speak
# 2024-04-01 11:03:57
#
# Scraped 99 users this round
# Got 197 reivews
# 371317 reviews are now in the bag, so to speak
# 2024-04-01 11:07:41
#
# Scraped 119 users this round
# Got 197 reivews
# 371514 reviews are now in the bag, so to speak
# 2024-04-01 11:12:30
#
# Scraped 96 users this round
# Got 177 reivews
# 371691 reviews are now in the bag, so to speak
# 2024-04-01 11:16:02
#
# Scraped 89 users this round
# Got 158 reivews
# 371849 reviews are now in the bag, so to speak
# 2024-04-01 11:19:19
#
# Scraped 89 users this round
# Got 188 reivews
# 372037 reviews are now in the bag, so to speak
# 2024-04-01 11:22:29
#
# Scraped 104 users this round
# Got 190 reivews
# 372227 reviews are now in the bag, so to speak
# 2024-04-01 11:26:14
#
# Scraped 123 users this round
# Got 191 reivews
# 372418 reviews are now in the bag, so to speak
# 2024-04-01 11:30:59
#
# Scraped 99 users this round
# Got 183 reivews
# 372601 reviews are now in the bag, so to speak
# 2024-04-01 11:34:49
#
# Scraped 93 users this round
# Got 181 reivews
# 372782 reviews are now in the bag, so to speak
# 2024-04-01 11:38:01
#
# Scraped 127 users this round
# Got 204 reivews
# 372986 reviews are now in the bag, so to speak
# 2024-04-01 11:42:47
#
# Scraped 114 users this round
# Got 189 reivews
# 373175 reviews are now in the bag, so to speak
# 2024-04-01 11:47:18
#
# Scraped 118 users this round
# Got 199 reivews
# 373374 reviews are now in the bag, so to speak
# 2024-04-01 11:51:49
#
# Scraped 105 users this round
# Got 191 reivews
# 373565 reviews are now in the bag, so to speak
# 2024-04-01 11:55:41
#
# Scraped 114 users this round
# Got 170 reivews
# 373735 reviews are now in the bag, so to speak
# 2024-04-01 12:00:04
#
# Scraped 103 users this round
# Got 178 reivews
# 373913 reviews are now in the bag, so to speak
# 2024-04-01 12:03:47
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 126 users this round
# Got 169 reivews
# 374082 reviews are now in the bag, so to speak
# 2024-04-01 12:08:38
#
# Scraped 103 users this round
# Got 201 reivews
# 374283 reviews are now in the bag, so to speak
# 2024-04-01 12:12:34
#
# Scraped 101 users this round
# Got 177 reivews
# 374460 reviews are now in the bag, so to speak
# 2024-04-01 12:16:12
#
# Scraped 106 users this round
# Got 154 reivews
# 374614 reviews are now in the bag, so to speak
# 2024-04-01 12:20:11
#
# Scraped 93 users this round
# Got 182 reivews
# 374796 reviews are now in the bag, so to speak
# 2024-04-01 12:23:28
#
# Scraped 117 users this round
# Got 189 reivews
# 374985 reviews are now in the bag, so to speak
# 2024-04-01 12:27:48
#
# Scraped 110 users this round
# Got 200 reivews
# 375185 reviews are now in the bag, so to speak
# 2024-04-01 12:32:00
#
# Scraped 109 users this round
# Got 176 reivews
# 375361 reviews are now in the bag, so to speak
# 2024-04-01 12:35:52
#
# Scraped 115 users this round
# Got 264 reivews
# 375625 reviews are now in the bag, so to speak
# 2024-04-01 12:40:11
#
# Scraped 117 users this round
# Got 222 reivews
# 375847 reviews are now in the bag, so to speak
# 2024-04-01 12:44:26
#
# Scraped 132 users this round
# Got 176 reivews
# 376023 reviews are now in the bag, so to speak
# 2024-04-01 12:49:17
#
# Scraped 116 users this round
# Got 141 reivews
# 376164 reviews are now in the bag, so to speak
# 2024-04-01 12:53:24
#
# Scraped 94 users this round
# Got 174 reivews
# 376338 reviews are now in the bag, so to speak
# 2024-04-01 12:56:42
#
# Scraped 98 users this round
# Got 163 reivews
# 376501 reviews are now in the bag, so to speak
# 2024-04-01 13:00:11
#
# Scraped 137 users this round
# Got 195 reivews
# 376696 reviews are now in the bag, so to speak
# 2024-04-01 13:05:17
#
# Scraped 125 users this round
# Got 211 reivews
# 376907 reviews are now in the bag, so to speak
# 2024-04-01 13:09:53
#
# Scraped 100 users this round
# Got 225 reivews
# 377132 reviews are now in the bag, so to speak
# 2024-04-01 13:13:25
#
# Scraped 110 users this round
# Got 211 reivews
# 377343 reviews are now in the bag, so to speak
# 2024-04-01 13:17:13
#
# Scraped 102 users this round
# Got 171 reivews
# 377514 reviews are now in the bag, so to speak
# 2024-04-01 13:20:41
#
# Scraped 108 users this round
# Got 168 reivews
# 377682 reviews are now in the bag, so to speak
# 2024-04-01 13:24:32
#
# Scraped 87 users this round
# Got 218 reivews
# 377900 reviews are now in the bag, so to speak
# 2024-04-01 13:27:32
#
# Scraped 119 users this round
# Got 210 reivews
# 378110 reviews are now in the bag, so to speak
# 2024-04-01 13:31:46
#
# Scraped 99 users this round
# Got 132 reivews
# 378242 reviews are now in the bag, so to speak
# 2024-04-01 13:35:11
#
# Scraped 117 users this round
# Got 175 reivews
# 378417 reviews are now in the bag, so to speak
# 2024-04-01 13:39:18
#
# Scraped 99 users this round
# Got 172 reivews
# 378589 reviews are now in the bag, so to speak
# 2024-04-01 13:42:45
#
# Scraped 106 users this round
# Got 196 reivews
# 378785 reviews are now in the bag, so to speak
# 2024-04-01 13:46:26
#
# Scraped 124 users this round
# Got 156 reivews
# 378941 reviews are now in the bag, so to speak
# 2024-04-01 13:50:51
#
# Scraped 93 users this round
# Got 185 reivews
# 379126 reviews are now in the bag, so to speak
# 2024-04-01 13:53:56
#
# Scraped 103 users this round
# Got 189 reivews
# 379315 reviews are now in the bag, so to speak
# 2024-04-01 13:57:26
#
# Scraped 99 users this round
# Got 189 reivews
# 379504 reviews are now in the bag, so to speak
# 2024-04-01 14:00:53
#
# Scraped 105 users this round
# Got 179 reivews
# 379683 reviews are now in the bag, so to speak
# 2024-04-01 14:04:35
#
# Scraped 128 users this round
# Got 164 reivews
# 379847 reviews are now in the bag, so to speak
# 2024-04-01 14:09:19
#
# Scraped 130 users this round
# Got 164 reivews
# 380011 reviews are now in the bag, so to speak
# 2024-04-01 14:13:52
#
# Scraped 111 users this round
# Got 185 reivews
# 380196 reviews are now in the bag, so to speak
# 2024-04-01 14:17:46
#
# Scraped 93 users this round
# Got 183 reivews
# 380379 reviews are now in the bag, so to speak
# 2024-04-01 14:20:59
#
# Scraped 102 users this round
# Got 186 reivews
# 380565 reviews are now in the bag, so to speak
# 2024-04-01 14:24:41
#
# Scraped 83 users this round
# Got 162 reivews
# 380727 reviews are now in the bag, so to speak
# 2024-04-01 14:27:30
#
# Scraped 106 users this round
# Got 171 reivews
# 380898 reviews are now in the bag, so to speak
# 2024-04-01 14:31:23
#
# Scraped 89 users this round
# Got 168 reivews
# 381066 reviews are now in the bag, so to speak
# 2024-04-01 14:34:14
#
# Scraped 124 users this round
# Got 154 reivews
# 381220 reviews are now in the bag, so to speak
# 2024-04-01 14:38:39
#
# Scraped 112 users this round
# Got 182 reivews
# 381402 reviews are now in the bag, so to speak
# 2024-04-01 14:42:24
#
# Scraped 117 users this round
# Got 167 reivews
# 381569 reviews are now in the bag, so to speak
# 2024-04-01 14:46:32
#
# Scraped 88 users this round
# Got 190 reivews
# 381759 reviews are now in the bag, so to speak
# 2024-04-01 14:49:26
#
# Scraped 99 users this round
# Got 166 reivews
# 381925 reviews are now in the bag, so to speak
# 2024-04-01 14:52:50
#
# Scraped 99 users this round
# Got 214 reivews
# 382139 reviews are now in the bag, so to speak
# 2024-04-01 14:56:15
#
# Scraped 105 users this round
# Got 177 reivews
# 382316 reviews are now in the bag, so to speak
# 2024-04-01 14:59:55
#
# Scraped 100 users this round
# Got 184 reivews
# 382500 reviews are now in the bag, so to speak
# 2024-04-01 15:03:31
#
# Scraped 115 users this round
# Got 205 reivews
# 382705 reviews are now in the bag, so to speak
# 2024-04-01 15:07:39
#
# Scraped 93 users this round
# Got 151 reivews
# 382856 reviews are now in the bag, so to speak
# 2024-04-01 15:10:49
#
# Scraped 123 users this round
# Got 212 reivews
# 383068 reviews are now in the bag, so to speak
# 2024-04-01 15:15:13
#
# Scraped 119 users this round
# Got 162 reivews
# 383230 reviews are now in the bag, so to speak
# 2024-04-01 15:19:23
#
# Scraped 113 users this round
# Got 174 reivews
# 383404 reviews are now in the bag, so to speak
# 2024-04-01 15:23:28
#
# Scraped 99 users this round
# Got 175 reivews
# 383579 reviews are now in the bag, so to speak
# 2024-04-01 15:26:57
#
# Scraped 99 users this round
# Got 189 reivews
# 383768 reviews are now in the bag, so to speak
# 2024-04-01 15:30:18
#
# Scraped 100 users this round
# Got 201 reivews
# 383969 reviews are now in the bag, so to speak
# 2024-04-01 15:33:45
#
# Scraped 105 users this round
# Got 180 reivews
# 384149 reviews are now in the bag, so to speak
# 2024-04-01 15:37:19
#
# Scraped 98 users this round
# Got 197 reivews
# 384346 reviews are now in the bag, so to speak
# 2024-04-01 15:40:38
#
# Scraped 112 users this round
# Got 150 reivews
# 384496 reviews are now in the bag, so to speak
# 2024-04-01 15:44:36
#
# Scraped 113 users this round
# Got 197 reivews
# 384693 reviews are now in the bag, so to speak
# 2024-04-01 15:49:24
#
# Scraped 116 users this round
# Got 165 reivews
# 384858 reviews are now in the bag, so to speak
# 2024-04-01 15:53:56
#
# Scraped 102 users this round
# Got 190 reivews
# 385048 reviews are now in the bag, so to speak
# 2024-04-01 15:57:18
#
# Scraped 103 users this round
# Got 207 reivews
# 385255 reviews are now in the bag, so to speak
# 2024-04-01 16:00:53
#
# Scraped 111 users this round
# Got 165 reivews
# 385420 reviews are now in the bag, so to speak
# 2024-04-01 16:05:00
#
# Scraped 114 users this round
# Got 207 reivews
# 385627 reviews are now in the bag, so to speak
# 2024-04-01 16:09:10
#
# Scraped 116 users this round
# Got 133 reivews
# 385760 reviews are now in the bag, so to speak
# 2024-04-01 16:13:15
#
# Scraped 101 users this round
# Got 199 reivews
# 385959 reviews are now in the bag, so to speak
# 2024-04-01 16:16:44
#
# Scraped 121 users this round
# Got 198 reivews
# 386157 reviews are now in the bag, so to speak
# 2024-04-01 16:21:06
#
# Scraped 82 users this round
# Got 158 reivews
# 386315 reviews are now in the bag, so to speak
# 2024-04-01 16:23:57
#
# Scraped 119 users this round
# Got 178 reivews
# 386493 reviews are now in the bag, so to speak
# 2024-04-01 16:28:02
#
# Scraped 118 users this round
# Got 224 reivews
# 386717 reviews are now in the bag, so to speak
# 2024-04-01 16:32:16
#
# Scraped 102 users this round
# Got 210 reivews
# 386927 reviews are now in the bag, so to speak
# 2024-04-01 16:35:54
#
# Scraped 103 users this round
# Got 187 reivews
# 387114 reviews are now in the bag, so to speak
# 2024-04-01 16:39:35
#
# Scraped 115 users this round
# Got 194 reivews
# 387308 reviews are now in the bag, so to speak
# 2024-04-01 16:43:41
#
# Scraped 111 users this round
# Got 178 reivews
# 387486 reviews are now in the bag, so to speak
# 2024-04-01 16:47:47
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 119 users this round
# Got 159 reivews
# 387645 reviews are now in the bag, so to speak
# 2024-04-01 16:51:57
#
# Scraped 92 users this round
# Got 150 reivews
# 387795 reviews are now in the bag, so to speak
# 2024-04-01 16:55:11
#
# Scraped 147 users this round
# Got 157 reivews
# 387952 reviews are now in the bag, so to speak
# 2024-04-01 17:00:45
#
# Scraped 94 users this round
# Got 224 reivews
# 388176 reviews are now in the bag, so to speak
# 2024-04-01 17:04:03
#
# Scraped 123 users this round
# Got 170 reivews
# 388346 reviews are now in the bag, so to speak
# 2024-04-01 17:08:28
#
# Scraped 104 users this round
# Got 162 reivews
# 388508 reviews are now in the bag, so to speak
# 2024-04-01 17:12:03
#
# Scraped 121 users this round
# Got 182 reivews
# 388690 reviews are now in the bag, so to speak
# 2024-04-01 17:16:22
#
# Scraped 120 users this round
# Got 189 reivews
# 388879 reviews are now in the bag, so to speak
# 2024-04-01 17:20:47
#
# Scraped 101 users this round
# Got 192 reivews
# 389071 reviews are now in the bag, so to speak
# 2024-04-01 17:24:32
#
# Scraped 138 users this round
# Got 187 reivews
# 389258 reviews are now in the bag, so to speak
# 2024-04-01 17:29:39
#
# Scraped 120 users this round
# Got 145 reivews
# 389403 reviews are now in the bag, so to speak
# 2024-04-01 17:33:55
#
# Scraped 104 users this round
# Got 180 reivews
# 389583 reviews are now in the bag, so to speak
# 2024-04-01 17:37:34
#
# Scraped 109 users this round
# Got 202 reivews
# 389785 reviews are now in the bag, so to speak
# 2024-04-01 17:41:20
#
# Scraped 110 users this round
# Got 179 reivews
# 389964 reviews are now in the bag, so to speak
# 2024-04-01 17:45:06
#
# Scraped 102 users this round
# Got 155 reivews
# 390119 reviews are now in the bag, so to speak
# 2024-04-01 17:48:33
#
# Scraped 127 users this round
# Got 219 reivews
# 390338 reviews are now in the bag, so to speak
# 2024-04-01 17:53:10
#
# Scraped 90 users this round
# Got 165 reivews
# 390503 reviews are now in the bag, so to speak
# 2024-04-01 17:56:08
#
# Scraped 95 users this round
# Got 236 reivews
# 390739 reviews are now in the bag, so to speak
# 2024-04-01 17:59:27
#
# Scraped 100 users this round
# Got 151 reivews
# 390890 reviews are now in the bag, so to speak
# 2024-04-01 18:02:53
#
# Scraped 110 users this round
# Got 189 reivews
# 391079 reviews are now in the bag, so to speak
# 2024-04-01 18:06:46
#
# Scraped 99 users this round
# Got 142 reivews
# 391221 reviews are now in the bag, so to speak
# 2024-04-01 18:10:09
#
# Scraped 92 users this round
# Got 185 reivews
# 391406 reviews are now in the bag, so to speak
# 2024-04-01 18:13:24
#
# Scraped 102 users this round
# Got 185 reivews
# 391591 reviews are now in the bag, so to speak
# 2024-04-01 18:16:56
#
# Scraped 132 users this round
# Got 172 reivews
# 391763 reviews are now in the bag, so to speak
# 2024-04-01 18:21:31
#
# Scraped 125 users this round
# Got 200 reivews
# 391963 reviews are now in the bag, so to speak
# 2024-04-01 18:25:56
#
# Scraped 133 users this round
# Got 161 reivews
# 392124 reviews are now in the bag, so to speak
# 2024-04-01 18:30:46
#
# Scraped 93 users this round
# Got 177 reivews
# 392301 reviews are now in the bag, so to speak
# 2024-04-01 18:33:54
#
# Scraped 119 users this round
# Got 207 reivews
# 392508 reviews are now in the bag, so to speak
# 2024-04-01 18:38:16
#
# Scraped 110 users this round
# Got 178 reivews
# 392686 reviews are now in the bag, so to speak
# 2024-04-01 18:42:09
#
# Scraped 123 users this round
# Got 181 reivews
# 392867 reviews are now in the bag, so to speak
# 2024-04-01 18:46:29
#
# Scraped 114 users this round
# Got 188 reivews
# 393055 reviews are now in the bag, so to speak
# 2024-04-01 18:50:26
#
# Scraped 115 users this round
# Got 234 reivews
# 393289 reviews are now in the bag, so to speak
# 2024-04-01 18:54:41
#
# Scraped 107 users this round
# Got 176 reivews
# 393465 reviews are now in the bag, so to speak
# 2024-04-01 18:58:22
#
# Scraped 114 users this round
# Got 217 reivews
# 393682 reviews are now in the bag, so to speak
# 2024-04-01 19:02:20
#
# Scraped 134 users this round
# Got 232 reivews
# 393914 reviews are now in the bag, so to speak
# 2024-04-01 19:07:05
#
# Scraped 99 users this round
# Got 190 reivews
# 394104 reviews are now in the bag, so to speak
# 2024-04-01 19:10:31
#
# Scraped 122 users this round
# Got 168 reivews
# 394272 reviews are now in the bag, so to speak
# 2024-04-01 19:14:50
#
# Scraped 128 users this round
# Got 179 reivews
# 394451 reviews are now in the bag, so to speak
# 2024-04-01 19:19:24
#
# Scraped 102 users this round
# Got 176 reivews
# 394627 reviews are now in the bag, so to speak
# 2024-04-01 19:22:58
#
# Scraped 116 users this round
# Got 160 reivews
# 394787 reviews are now in the bag, so to speak
# 2024-04-01 19:27:07
#
# Scraped 108 users this round
# Got 185 reivews
# 394972 reviews are now in the bag, so to speak
# 2024-04-01 19:30:54
#
# Scraped 121 users this round
# Got 164 reivews
# 395136 reviews are now in the bag, so to speak
# 2024-04-01 19:35:14
#
# Scraped 113 users this round
# Got 164 reivews
# 395300 reviews are now in the bag, so to speak
# 2024-04-01 19:39:23
#
# Scraped 100 users this round
# Got 187 reivews
# 395487 reviews are now in the bag, so to speak
# 2024-04-01 19:42:42
#
# Scraped 112 users this round
# Got 230 reivews
# 395717 reviews are now in the bag, so to speak
# 2024-04-01 19:46:30
#
# Scraped 118 users this round
# Got 250 reivews
# 395967 reviews are now in the bag, so to speak
# 2024-04-01 19:50:43
#
# Scraped 108 users this round
# Got 168 reivews
# 396135 reviews are now in the bag, so to speak
# 2024-04-01 19:54:30
#
# Scraped 106 users this round
# Got 192 reivews
# 396327 reviews are now in the bag, so to speak
# 2024-04-01 19:58:12
#
# Scraped 92 users this round
# Got 197 reivews
# 396524 reviews are now in the bag, so to speak
# 2024-04-01 20:01:23
#
# Scraped 119 users this round
# Got 156 reivews
# 396680 reviews are now in the bag, so to speak
# 2024-04-01 20:05:50
#
# Scraped 115 users this round
# Got 217 reivews
# 396897 reviews are now in the bag, so to speak
# 2024-04-01 20:11:49
#
# Scraped 112 users this round
# Got 156 reivews
# 397053 reviews are now in the bag, so to speak
# 2024-04-01 20:19:26
#
# Scraped 125 users this round
# Got 163 reivews
# 397216 reviews are now in the bag, so to speak
# 2024-04-01 20:28:11
#
# Scraped 116 users this round
# Got 196 reivews
# 397412 reviews are now in the bag, so to speak
# 2024-04-01 20:34:39
#
# Scraped 105 users this round
# Got 160 reivews
# 397572 reviews are now in the bag, so to speak
# 2024-04-01 20:40:22
#
# Scraped 104 users this round
# Got 173 reivews
# 397745 reviews are now in the bag, so to speak
# 2024-04-01 20:45:57
#
# Scraped 95 users this round
# Got 172 reivews
# 397917 reviews are now in the bag, so to speak
# 2024-04-01 20:51:06
#
# Scraped 116 users this round
# Got 192 reivews
# 398109 reviews are now in the bag, so to speak
# 2024-04-01 20:58:23
#
# Scraped 102 users this round
# Got 218 reivews
# 398327 reviews are now in the bag, so to speak
# 2024-04-01 21:04:38
#
# Scraped 116 users this round
# Got 192 reivews
# 398519 reviews are now in the bag, so to speak
# 2024-04-01 21:12:10
#
# Scraped 106 users this round
# Got 182 reivews
# 398701 reviews are now in the bag, so to speak
# 2024-04-01 21:18:32
#
# Scraped 105 users this round
# Got 187 reivews
# 398888 reviews are now in the bag, so to speak
# 2024-04-01 21:24:44
#
# Scraped 118 users this round
# Got 220 reivews
# 399108 reviews are now in the bag, so to speak
# 2024-04-01 21:32:11
#
# Scraped 113 users this round
# Got 216 reivews
# 399324 reviews are now in the bag, so to speak
# 2024-04-01 21:38:47
#
# Scraped 114 users this round
# Got 194 reivews
# 399518 reviews are now in the bag, so to speak
# 2024-04-01 21:45:51
#
# Scraped 103 users this round
# Got 201 reivews
# 399719 reviews are now in the bag, so to speak
# 2024-04-01 21:51:39
#
# Scraped 123 users this round
# Got 224 reivews
# 399943 reviews are now in the bag, so to speak
# 2024-04-01 21:59:31
#
# Scraped 102 users this round
# Got 203 reivews
# 400146 reviews are now in the bag, so to speak
# 2024-04-01 22:06:29
#
# Scraped 100 users this round
# Got 185 reivews
# 400331 reviews are now in the bag, so to speak
# 2024-04-01 22:12:23
#
# Scraped 112 users this round
# Got 198 reivews
# 400529 reviews are now in the bag, so to speak
# 2024-04-01 22:18:58
#
# Scraped 109 users this round
# Got 166 reivews
# 400695 reviews are now in the bag, so to speak
# 2024-04-01 22:25:20
#
# Scraped 119 users this round
# Got 196 reivews
# 400891 reviews are now in the bag, so to speak
# 2024-04-01 22:32:38
#
# Scraped 124 users this round
# Got 179 reivews
# 401070 reviews are now in the bag, so to speak
# 2024-04-01 22:39:26
#
# Scraped 98 users this round
# Got 199 reivews
# 401269 reviews are now in the bag, so to speak
# 2024-04-01 22:44:36
#
# Scraped 131 users this round
# Got 194 reivews
# 401463 reviews are now in the bag, so to speak
# 2024-04-01 22:51:37
#
# Scraped 114 users this round
# Got 157 reivews
# 401620 reviews are now in the bag, so to speak
# 2024-04-01 22:57:24
#
# Scraped 120 users this round
# Got 145 reivews
# 401765 reviews are now in the bag, so to speak
# 2024-04-01 23:03:37
#
# Scraped 104 users this round
# Got 156 reivews
# 401921 reviews are now in the bag, so to speak
# 2024-04-01 23:08:52
#
# Scraped 94 users this round
# Got 202 reivews
# 402123 reviews are now in the bag, so to speak
# 2024-04-01 23:12:50
#
# Scraped 127 users this round
# Got 214 reivews
# 402337 reviews are now in the bag, so to speak
# 2024-04-01 23:17:31
#
# Scraped 123 users this round
# Got 154 reivews
# 402491 reviews are now in the bag, so to speak
# 2024-04-01 23:21:57
#
# Scraped 85 users this round
# Got 167 reivews
# 402658 reviews are now in the bag, so to speak
# 2024-04-01 23:24:50
#
# Scraped 119 users this round
# Got 182 reivews
# 402840 reviews are now in the bag, so to speak
# 2024-04-01 23:29:08
#
# Scraped 95 users this round
# Got 199 reivews
# 403039 reviews are now in the bag, so to speak
# 2024-04-01 23:32:31
#
# Scraped 119 users this round
# Got 183 reivews
# 403222 reviews are now in the bag, so to speak
# 2024-04-01 23:36:59
#
# Scraped 112 users this round
# Got 154 reivews
# 403376 reviews are now in the bag, so to speak
# 2024-04-01 23:41:02
#
# Scraped 135 users this round
# Got 179 reivews
# 403555 reviews are now in the bag, so to speak
# 2024-04-01 23:45:53
#
# Scraped 121 users this round
# Got 213 reivews
# 403768 reviews are now in the bag, so to speak
# 2024-04-01 23:50:38
#
# Scraped 109 users this round
# Got 214 reivews
# 403982 reviews are now in the bag, so to speak
# 2024-04-01 23:54:32
#
# Scraped 104 users this round
# Got 178 reivews
# 404160 reviews are now in the bag, so to speak
# 2024-04-01 23:58:00
#
# Scraped 95 users this round
# Got 167 reivews
# 404327 reviews are now in the bag, so to speak
# 2024-04-02 00:01:20
#
# Scraped 123 users this round
# Got 186 reivews
# 404513 reviews are now in the bag, so to speak
# 2024-04-02 00:06:01
#
# Scraped 112 users this round
# Got 189 reivews
# 404702 reviews are now in the bag, so to speak
# 2024-04-02 00:10:14
#
# Scraped 97 users this round
# Got 166 reivews
# 404868 reviews are now in the bag, so to speak
# 2024-04-02 00:13:49
#
# Scraped 102 users this round
# Got 191 reivews
# 405059 reviews are now in the bag, so to speak
# 2024-04-02 00:17:39
#
# Scraped 94 users this round
# Got 199 reivews
# 405258 reviews are now in the bag, so to speak
# 2024-04-02 00:21:03
#
# Scraped 117 users this round
# Got 170 reivews
# 405428 reviews are now in the bag, so to speak
# 2024-04-02 00:25:15
#
# Scraped 111 users this round
# Got 174 reivews
# 405602 reviews are now in the bag, so to speak
# 2024-04-02 00:29:12
#
# Scraped 102 users this round
# Got 215 reivews
# 405817 reviews are now in the bag, so to speak
# 2024-04-02 00:32:55
#
# Scraped 101 users this round
# Got 199 reivews
# 406016 reviews are now in the bag, so to speak
# 2024-04-02 00:36:22
#
# Scraped 108 users this round
# Got 160 reivews
# 406176 reviews are now in the bag, so to speak
# 2024-04-02 00:40:13
#
# Scraped 95 users this round
# Got 167 reivews
# 406343 reviews are now in the bag, so to speak
# 2024-04-02 00:43:32
#
# Scraped 111 users this round
# Got 192 reivews
# 406535 reviews are now in the bag, so to speak
# 2024-04-02 00:47:29
#
# Scraped 100 users this round
# Got 222 reivews
# 406757 reviews are now in the bag, so to speak
# 2024-04-02 00:51:02
#
# Scraped 109 users this round
# Got 197 reivews
# 406954 reviews are now in the bag, so to speak
# 2024-04-02 00:54:49
#
# Scraped 118 users this round
# Got 206 reivews
# 407160 reviews are now in the bag, so to speak
# 2024-04-02 00:59:23
#
# Scraped 114 users this round
# Got 149 reivews
# 407309 reviews are now in the bag, so to speak
# 2024-04-02 01:03:31
#
# Scraped 108 users this round
# Got 245 reivews
# 407554 reviews are now in the bag, so to speak
# 2024-04-02 01:07:25
#
# Scraped 114 users this round
# Got 161 reivews
# 407715 reviews are now in the bag, so to speak
# 2024-04-02 01:11:18
#
# Scraped 110 users this round
# Got 194 reivews
# 407909 reviews are now in the bag, so to speak
# 2024-04-02 01:15:14
#
# Scraped 114 users this round
# Got 215 reivews
# 408124 reviews are now in the bag, so to speak
# 2024-04-02 01:19:23
#
# Scraped 112 users this round
# Got 205 reivews
# 408329 reviews are now in the bag, so to speak
# 2024-04-02 01:23:33
#
# Scraped 105 users this round
# Got 190 reivews
# 408519 reviews are now in the bag, so to speak
# ...
# 2024-04-02 23:16:34
#
# Scraped 117 users this round
# Got 173 reivews
# 468837 reviews are now in the bag, so to speak
# 2024-04-02 23:24:50
#
# Scraped 110 users this round
# Got 176 reivews
# 469013 reviews are now in the bag, so to speak
# 2024-04-02 23:32:43
#
# Scraped 102 users this round
# Got 212 reivews
# 469225 reviews are now in the bag, so to speak
# 2024-04-02 23:39:10
#
# Scraped 121 users this round
# Got 227 reivews
# 469452 reviews are now in the bag, so to speak
# 2024-04-02 23:44:20
#
# Scraped 114 users this round
# Got 235 reivews
# 469687 reviews are now in the bag, so to speak
# 2024-04-02 23:48:45
#
# Scraped 89 users this round
# Got 236 reivews
# 469923 reviews are now in the bag, so to speak
# 2024-04-02 23:51:41
#
# Scraped 119 users this round
# Got 201 reivews
# 470124 reviews are now in the bag, so to speak
# 2024-04-02 23:55:45
#
# Scraped 93 users this round
# Got 191 reivews
# 470315 reviews are now in the bag, so to speak
# 2024-04-02 23:58:50
#
# Scraped 104 users this round
# Got 161 reivews
# 470476 reviews are now in the bag, so to speak
# 2024-04-03 00:02:16
#
# Scraped 101 users this round
# Got 178 reivews
# 470654 reviews are now in the bag, so to speak
# 2024-04-03 00:05:46
#
# Scraped 114 users this round
# Got 185 reivews
# 470839 reviews are now in the bag, so to speak
# 2024-04-03 00:09:50
#
# Scraped 120 users this round
# Got 164 reivews
# 471003 reviews are now in the bag, so to speak
# 2024-04-03 00:14:08
#
# Scraped 100 users this round
# Got 197 reivews
# 471200 reviews are now in the bag, so to speak
# 2024-04-03 00:17:36
#
# Scraped 116 users this round
# Got 195 reivews
# 471395 reviews are now in the bag, so to speak
# 2024-04-03 00:21:48
#
# Scraped 93 users this round
# Got 201 reivews
# 471596 reviews are now in the bag, so to speak
# 2024-04-03 00:24:47
#
# Scraped 100 users this round
# Got 190 reivews
# 471786 reviews are now in the bag, so to speak
# 2024-04-03 00:28:09
#
# Scraped 122 users this round
# Got 163 reivews
# 471949 reviews are now in the bag, so to speak
# 2024-04-03 00:32:38
#
# Scraped 119 users this round
# Got 183 reivews
# 472132 reviews are now in the bag, so to speak
# 2024-04-03 00:36:41
#
# Scraped 84 users this round
# Got 184 reivews
# 472316 reviews are now in the bag, so to speak
# 2024-04-03 00:39:38
#
# Scraped 110 users this round
# Got 246 reivews
# 472562 reviews are now in the bag, so to speak
# 2024-04-03 00:43:16
#
# Scraped 113 users this round
# Got 174 reivews
# 472736 reviews are now in the bag, so to speak
# 2024-04-03 00:46:57
#
# Scraped 106 users this round
# Got 185 reivews
# 472921 reviews are now in the bag, so to speak
# 2024-04-03 00:50:53
#
# Scraped 93 users this round
# Got 193 reivews
# 473114 reviews are now in the bag, so to speak
# 2024-04-03 00:53:54
#
# Scraped 115 users this round
# Got 169 reivews
# 473283 reviews are now in the bag, so to speak
# 2024-04-03 00:57:34
#
# Scraped 123 users this round
# Got 192 reivews
# 473475 reviews are now in the bag, so to speak
# 2024-04-03 01:02:00
#
# Scraped 125 users this round
# Got 196 reivews
# 473671 reviews are now in the bag, so to speak
# 2024-04-03 01:06:27
#
# Scraped 106 users this round
# Got 198 reivews
# 473869 reviews are now in the bag, so to speak
# 2024-04-03 01:10:14
#
# Scraped 123 users this round
# Got 171 reivews
# 474040 reviews are now in the bag, so to speak
# 2024-04-03 01:14:31
#
# Scraped 102 users this round
# Got 206 reivews
# 474246 reviews are now in the bag, so to speak
# 2024-04-03 01:17:48
#
# Scraped 109 users this round
# Got 177 reivews
# 474423 reviews are now in the bag, so to speak
# 2024-04-03 01:21:23
#
# Scraped 113 users this round
# Got 169 reivews
# 474592 reviews are now in the bag, so to speak
# 2024-04-03 01:24:59
#
# Scraped 128 users this round
# Got 170 reivews
# 474762 reviews are now in the bag, so to speak
# 2024-04-03 01:29:31
#
# Scraped 110 users this round
# Got 255 reivews
# 475017 reviews are now in the bag, so to speak
# 2024-04-03 01:33:01
#
# Scraped 98 users this round
# Got 184 reivews
# 475201 reviews are now in the bag, so to speak
# 2024-04-03 01:36:07
#
# Scraped 109 users this round
# Got 208 reivews
# 475409 reviews are now in the bag, so to speak
# 2024-04-03 01:39:45
#
# Scraped 123 users this round
# Got 189 reivews
# 475598 reviews are now in the bag, so to speak
# 2024-04-03 01:43:59
#
# Scraped 116 users this round
# Got 187 reivews
# 475785 reviews are now in the bag, so to speak
# 2024-04-03 01:47:48
#
# Scraped 98 users this round
# Got 174 reivews
# 475959 reviews are now in the bag, so to speak
# 2024-04-03 01:50:54
#
# Scraped 104 users this round
# Got 171 reivews
# 476130 reviews are now in the bag, so to speak
# 2024-04-03 01:54:08
#
# Scraped 94 users this round
# Got 199 reivews
# 476329 reviews are now in the bag, so to speak
# 2024-04-03 01:57:07
#
# Scraped 116 users this round
# Got 214 reivews
# 476543 reviews are now in the bag, so to speak
# 2024-04-03 02:01:16
#
# Scraped 115 users this round
# Got 181 reivews
# 476724 reviews are now in the bag, so to speak
# 2024-04-03 02:05:01
#
# Scraped 135 users this round
# Got 205 reivews
# 476929 reviews are now in the bag, so to speak
# 2024-04-03 02:09:47
#
# Scraped 117 users this round
# Got 175 reivews
# 477104 reviews are now in the bag, so to speak
# 2024-04-03 02:13:45
#
# Scraped 104 users this round
# Got 194 reivews
# 477298 reviews are now in the bag, so to speak
# 2024-04-03 02:17:21
#
# Scraped 117 users this round
# Got 205 reivews
# 477503 reviews are now in the bag, so to speak
# 2024-04-03 02:21:20
#
# Scraped 115 users this round
# Got 153 reivews
# 477656 reviews are now in the bag, so to speak
# 2024-04-03 02:25:14
#
# Scraped 123 users this round
# Got 193 reivews
# 477849 reviews are now in the bag, so to speak
# 2024-04-03 02:29:13
#
# Scraped 123 users this round
# Got 176 reivews
# 478025 reviews are now in the bag, so to speak
# 2024-04-03 02:33:15
#
# Scraped 109 users this round
# Got 141 reivews
# 478166 reviews are now in the bag, so to speak
# 2024-04-03 02:36:53
#
# Scraped 116 users this round
# Got 182 reivews
# 478348 reviews are now in the bag, so to speak
# 2024-04-03 02:40:45
#
# Scraped 129 users this round
# Got 199 reivews
# 478547 reviews are now in the bag, so to speak
# 2024-04-03 02:45:16
#
# Scraped 128 users this round
# Got 190 reivews
# 478737 reviews are now in the bag, so to speak
# 2024-04-03 02:49:58
#
# Scraped 106 users this round
# Got 165 reivews
# 478902 reviews are now in the bag, so to speak
# 2024-04-03 02:53:38
#
# Scraped 122 users this round
# Got 179 reivews
# 479081 reviews are now in the bag, so to speak
# 2024-04-03 02:57:43
#
# Scraped 119 users this round
# Got 205 reivews
# 479286 reviews are now in the bag, so to speak
# 2024-04-03 03:01:41
#
# Scraped 104 users this round
# Got 159 reivews
# 479445 reviews are now in the bag, so to speak
# 2024-04-03 03:05:35
#
# Scraped 114 users this round
# Got 195 reivews
# 479640 reviews are now in the bag, so to speak
# 2024-04-03 03:09:14
#
# Scraped 108 users this round
# Got 146 reivews
# 479786 reviews are now in the bag, so to speak
# 2024-04-03 03:12:47
#
# Scraped 116 users this round
# Got 196 reivews
# 479982 reviews are now in the bag, so to speak
# 2024-04-03 03:16:44
#
# Scraped 109 users this round
# Got 185 reivews
# 480167 reviews are now in the bag, so to speak
# 2024-04-03 03:20:18
#
# Scraped 105 users this round
# Got 189 reivews
# 480356 reviews are now in the bag, so to speak
# 2024-04-03 03:23:52
#
# Scraped 112 users this round
# Got 187 reivews
# 480543 reviews are now in the bag, so to speak
# 2024-04-03 03:27:37
#
# Scraped 102 users this round
# Got 168 reivews
# 480711 reviews are now in the bag, so to speak
# 2024-04-03 03:31:17
#
# Scraped 113 users this round
# Got 167 reivews
# 480878 reviews are now in the bag, so to speak
# 2024-04-03 03:35:19
#
# Scraped 105 users this round
# Got 197 reivews
# 481075 reviews are now in the bag, so to speak
# 2024-04-03 03:38:56
#
# Scraped 100 users this round
# Got 183 reivews
# 481258 reviews are now in the bag, so to speak
# 2024-04-03 03:42:11
#
# Scraped 121 users this round
# Got 155 reivews
# 481413 reviews are now in the bag, so to speak
# 2024-04-03 03:46:05
#
# Scraped 110 users this round
# Got 194 reivews
# 481607 reviews are now in the bag, so to speak
# 2024-04-03 03:49:40
#
# Scraped 97 users this round
# Got 146 reivews
# 481753 reviews are now in the bag, so to speak
# 2024-04-03 03:52:42
#
# Scraped 126 users this round
# Got 179 reivews
# 481932 reviews are now in the bag, so to speak
# 2024-04-03 03:57:03
#
# Scraped 123 users this round
# Got 205 reivews
# 482137 reviews are now in the bag, so to speak
# 2024-04-03 04:01:08
#
# Scraped 104 users this round
# Got 177 reivews
# 482314 reviews are now in the bag, so to speak
# 2024-04-03 04:04:44
#
# Scraped 104 users this round
# Got 174 reivews
# 482488 reviews are now in the bag, so to speak
# 2024-04-03 04:08:02
#
# Scraped 118 users this round
# Got 198 reivews
# 482686 reviews are now in the bag, so to speak
# 2024-04-03 04:12:00
#
# Scraped 120 users this round
# Got 187 reivews
# 482873 reviews are now in the bag, so to speak
# 2024-04-03 04:16:23
#
# Scraped 112 users this round
# Got 208 reivews
# 483081 reviews are now in the bag, so to speak
# 2024-04-03 04:20:30
#
# Scraped 87 users this round
# Got 192 reivews
# 483273 reviews are now in the bag, so to speak
# 2024-04-03 04:23:39
#
# Scraped 97 users this round
# Got 170 reivews
# 483443 reviews are now in the bag, so to speak
# 2024-04-03 04:26:40
#
# Scraped 97 users this round
# Got 214 reivews
# 483657 reviews are now in the bag, so to speak
# 2024-04-03 04:29:46
#
# Scraped 110 users this round
# Got 198 reivews
# 483855 reviews are now in the bag, so to speak
# 2024-04-03 04:33:26
#
# Scraped 115 users this round
# Got 149 reivews
# 484004 reviews are now in the bag, so to speak
# 2024-04-03 04:37:10
#
# Scraped 113 users this round
# Got 159 reivews
# 484163 reviews are now in the bag, so to speak
# 2024-04-03 04:40:38
#
# Scraped 129 users this round
# Got 199 reivews
# 484362 reviews are now in the bag, so to speak
# 2024-04-03 04:45:02
#
# Scraped 110 users this round
# Got 182 reivews
# 484544 reviews are now in the bag, so to speak
# 2024-04-03 04:48:39
#
# Scraped 110 users this round
# Got 191 reivews
# 484735 reviews are now in the bag, so to speak
# 2024-04-03 04:52:10
#
# Scraped 120 users this round
# Got 192 reivews
# 484927 reviews are now in the bag, so to speak
# 2024-04-03 04:56:15
#
# Scraped 125 users this round
# Got 208 reivews
# 485135 reviews are now in the bag, so to speak
# 2024-04-03 05:00:21
#
# Scraped 128 users this round
# Got 199 reivews
# 485334 reviews are now in the bag, so to speak
# 2024-04-03 05:04:46
#
# Scraped 106 users this round
# Got 205 reivews
# 485539 reviews are now in the bag, so to speak
# 2024-04-03 05:08:15
#
# Scraped 119 users this round
# Got 188 reivews
# 485727 reviews are now in the bag, so to speak
# 2024-04-03 05:12:36
#
# Scraped 106 users this round
# Got 219 reivews
# 485946 reviews are now in the bag, so to speak
# 2024-04-03 05:16:09
#
# Scraped 116 users this round
# Got 147 reivews
# 486093 reviews are now in the bag, so to speak
# 2024-04-03 05:20:00
#
# Scraped 118 users this round
# Got 196 reivews
# 486289 reviews are now in the bag, so to speak
# 2024-04-03 05:24:09
#
# Scraped 124 users this round
# Got 195 reivews
# 486484 reviews are now in the bag, so to speak
# 2024-04-03 05:28:27
#
# Scraped 127 users this round
# Got 219 reivews
# 486703 reviews are now in the bag, so to speak
# 2024-04-03 05:32:51
#
# Scraped 116 users this round
# Got 170 reivews
# 486873 reviews are now in the bag, so to speak
# 2024-04-03 05:36:39
#
# Scraped 132 users this round
# Got 228 reivews
# 487101 reviews are now in the bag, so to speak
# 2024-04-03 05:41:12
#
# Scraped 110 users this round
# Got 193 reivews
# 487294 reviews are now in the bag, so to speak
# 2024-04-03 05:44:51
#
# Scraped 113 users this round
# Got 190 reivews
# 487484 reviews are now in the bag, so to speak
# 2024-04-03 05:48:39
#
# Scraped 125 users this round
# Got 176 reivews
# 487660 reviews are now in the bag, so to speak
# 2024-04-03 05:52:56
#
# Scraped 89 users this round
# Got 194 reivews
# 487854 reviews are now in the bag, so to speak
# 2024-04-03 05:55:48
#
# Scraped 91 users this round
# Got 169 reivews
# 488023 reviews are now in the bag, so to speak
# 2024-04-03 05:58:45
#
# Scraped 88 users this round
# Got 210 reivews
# 488233 reviews are now in the bag, so to speak
# 2024-04-03 06:01:40
#
# Scraped 112 users this round
# Got 156 reivews
# 488389 reviews are now in the bag, so to speak
# 2024-04-03 06:05:33
#
# Scraped 103 users this round
# Got 212 reivews
# 488601 reviews are now in the bag, so to speak
# 2024-04-03 06:08:57
#
# Scraped 104 users this round
# Got 143 reivews
# 488744 reviews are now in the bag, so to speak
# 2024-04-03 06:12:20
#
# Scraped 114 users this round
# Got 206 reivews
# 488950 reviews are now in the bag, so to speak
# 2024-04-03 06:16:24
#
# Scraped 93 users this round
# Got 214 reivews
# 489164 reviews are now in the bag, so to speak
# 2024-04-03 06:19:21
#
# Scraped 112 users this round
# Got 221 reivews
# 489385 reviews are now in the bag, so to speak
# 2024-04-03 06:23:02
#
# Scraped 123 users this round
# Got 197 reivews
# 489582 reviews are now in the bag, so to speak
# 2024-04-03 06:27:09
#
# Scraped 91 users this round
# Got 196 reivews
# 489778 reviews are now in the bag, so to speak
# 2024-04-03 06:30:05
#
# Scraped 122 users this round
# Got 191 reivews
# 489969 reviews are now in the bag, so to speak
# 2024-04-03 06:34:42
#
# Scraped 99 users this round
# Got 149 reivews
# 490118 reviews are now in the bag, so to speak
# 2024-04-03 06:38:09
#
# Scraped 114 users this round
# Got 149 reivews
# 490267 reviews are now in the bag, so to speak
# 2024-04-03 06:42:07
#
# Scraped 108 users this round
# Got 190 reivews
# 490457 reviews are now in the bag, so to speak
# 2024-04-03 06:45:59
#
# Scraped 118 users this round
# Got 204 reivews
# 490661 reviews are now in the bag, so to speak
# 2024-04-03 06:49:56
#
# Scraped 132 users this round
# Got 176 reivews
# 490837 reviews are now in the bag, so to speak
# 2024-04-03 06:54:44
#
# Scraped 92 users this round
# Got 200 reivews
# 491037 reviews are now in the bag, so to speak
# 2024-04-03 06:57:36
#
# Scraped 99 users this round
# Got 193 reivews
# 491230 reviews are now in the bag, so to speak
# 2024-04-03 07:01:17
#
# Scraped 89 users this round
# Got 165 reivews
# 491395 reviews are now in the bag, so to speak
# 2024-04-03 07:04:08
#
# Scraped 106 users this round
# Got 170 reivews
# 491565 reviews are now in the bag, so to speak
# 2024-04-03 07:07:44
#
# Scraped 100 users this round
# Got 200 reivews
# 491765 reviews are now in the bag, so to speak
# 2024-04-03 07:11:01
#
# Scraped 102 users this round
# Got 194 reivews
# 491959 reviews are now in the bag, so to speak
# 2024-04-03 07:14:27
#
# Scraped 114 users this round
# Got 142 reivews
# 492101 reviews are now in the bag, so to speak
# 2024-04-03 07:18:17
#
# Scraped 123 users this round
# Got 212 reivews
# 492313 reviews are now in the bag, so to speak
# 2024-04-03 07:22:38
#
# Scraped 115 users this round
# Got 173 reivews
# 492486 reviews are now in the bag, so to speak
# 2024-04-03 07:26:34
#
# Scraped 117 users this round
# Got 169 reivews
# 492655 reviews are now in the bag, so to speak
# 2024-04-03 07:31:15
#
# Scraped 98 users this round
# Got 166 reivews
# 492821 reviews are now in the bag, so to speak
# 2024-04-03 07:34:35
#
# Scraped 112 users this round
# Got 151 reivews
# 492972 reviews are now in the bag, so to speak
# 2024-04-03 07:38:18
#
# Scraped 94 users this round
# Got 232 reivews
# 493204 reviews are now in the bag, so to speak
# 2024-04-03 07:41:20
#
# Scraped 123 users this round
# Got 176 reivews
# 493380 reviews are now in the bag, so to speak
# 2024-04-03 07:45:53
#
# Scraped 129 users this round
# Got 217 reivews
# 493597 reviews are now in the bag, so to speak
# 2024-04-03 07:50:21
#
# Scraped 108 users this round
# Got 177 reivews
# 493774 reviews are now in the bag, so to speak
# 2024-04-03 07:54:06
#
# Scraped 98 users this round
# Got 196 reivews
# 493970 reviews are now in the bag, so to speak
# 2024-04-03 07:57:33
#
# Scraped 111 users this round
# Got 165 reivews
# 494135 reviews are now in the bag, so to speak
# 2024-04-03 08:01:19
#
# Scraped 93 users this round
# Got 210 reivews
# 494345 reviews are now in the bag, so to speak
# 2024-04-03 08:04:25
#
# Scraped 127 users this round
# Got 177 reivews
# 494522 reviews are now in the bag, so to speak
# 2024-04-03 08:09:33
#
# Scraped 103 users this round
# Got 186 reivews
# 494708 reviews are now in the bag, so to speak
# 2024-04-03 08:13:29
#
# Scraped 107 users this round
# Got 137 reivews
# 494845 reviews are now in the bag, so to speak
# 2024-04-03 08:17:54
#
# Scraped 104 users this round
# Got 237 reivews
# 495082 reviews are now in the bag, so to speak
# 2024-04-03 08:22:16
#
# Unable to parse review blocks.
