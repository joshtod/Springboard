# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 2
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 53 users this round
# Got 338 reivews
# 338 reviews are now in the bag, so to speak
# 2024-04-03 18:08:05
#
# Scraped 58 users this round
# Got 273 reivews
# 611 reviews are now in the bag, so to speak
# 2024-04-03 18:09:38
#
# Scraped 55 users this round
# Got 344 reivews
# 955 reviews are now in the bag, so to speak
# 2024-04-03 18:11:23
#
# Scraped 55 users this round
# Got 326 reivews
# 1281 reviews are now in the bag, so to speak
# 2024-04-03 18:13:00
#
# Scraped 52 users this round
# Got 347 reivews
# 1628 reviews are now in the bag, so to speak
# 2024-04-03 18:14:37
#
# Scraped 56 users this round
# Got 312 reivews
# 1940 reviews are now in the bag, so to speak
# 2024-04-03 18:16:12
#
# Scraped 57 users this round
# Got 350 reivews
# 2290 reviews are now in the bag, so to speak
# 2024-04-03 18:17:56
#
# Scraped 55 users this round
# Got 337 reivews
# 2627 reviews are now in the bag, so to speak
# 2024-04-03 18:19:27
#
# Scraped 56 users this round
# Got 334 reivews
# 2961 reviews are now in the bag, so to speak
# 2024-04-03 18:21:08
#
# Scraped 59 users this round
# Got 303 reivews
# 3264 reviews are now in the bag, so to speak
# 2024-04-03 18:22:51
#
# Scraped 56 users this round
# Got 326 reivews
# 3590 reviews are now in the bag, so to speak
# 2024-04-03 18:24:29
#
# Scraped 55 users this round
# Got 339 reivews
# 3929 reviews are now in the bag, so to speak
# 2024-04-03 18:26:04
#
# Scraped 58 users this round
# Got 339 reivews
# 4268 reviews are now in the bag, so to speak
# 2024-04-03 18:27:38
#
# Scraped 54 users this round
# Got 349 reivews
# 4617 reviews are now in the bag, so to speak
# 2024-04-03 18:29:18
#
# Scraped 56 users this round
# Got 336 reivews
# 4953 reviews are now in the bag, so to speak
# 2024-04-03 18:30:55
#
# Scraped 56 users this round
# Got 323 reivews
# 5276 reviews are now in the bag, so to speak
# 2024-04-03 18:32:31
#
# Scraped 60 users this round
# Got 365 reivews
# 5641 reviews are now in the bag, so to speak
# 2024-04-03 18:34:15
#
# Scraped 58 users this round
# Got 343 reivews
# 5984 reviews are now in the bag, so to speak
# 2024-04-03 18:35:56
#
# Scraped 53 users this round
# Got 335 reivews
# 6319 reviews are now in the bag, so to speak
# 2024-04-03 18:37:24
#
# Scraped 57 users this round
# Got 293 reivews
# 6612 reviews are now in the bag, so to speak
# 2024-04-03 18:39:05
#
# Scraped 53 users this round
# Got 370 reivews
# 6982 reviews are now in the bag, so to speak
# 2024-04-03 18:40:35
#
# Scraped 55 users this round
# Got 348 reivews
# 7330 reviews are now in the bag, so to speak
# 2024-04-03 18:42:08
#
# Scraped 57 users this round
# Got 331 reivews
# 7661 reviews are now in the bag, so to speak
# 2024-04-03 18:43:56
#
# Scraped 63 users this round
# Got 318 reivews
# 7979 reviews are now in the bag, so to speak
# 2024-04-03 18:45:45
#
# Scraped 56 users this round
# Got 320 reivews
# 8299 reviews are now in the bag, so to speak
# 2024-04-03 18:47:19
#
# Scraped 59 users this round
# Got 358 reivews
# 8657 reviews are now in the bag, so to speak
# 2024-04-03 18:49:06
#
# Scraped 55 users this round
# Got 331 reivews
# 8988 reviews are now in the bag, so to speak
# 2024-04-03 18:50:37
#
# Scraped 56 users this round
# Got 348 reivews
# 9336 reviews are now in the bag, so to speak
# 2024-04-03 18:52:13
#
# Scraped 53 users this round
# Got 346 reivews
# 9682 reviews are now in the bag, so to speak
# 2024-04-03 18:53:44
#
# Scraped 58 users this round
# Got 345 reivews
# 10027 reviews are now in the bag, so to speak
# 2024-04-03 18:55:30
#
# Scraped 55 users this round
# Got 304 reivews
# 10331 reviews are now in the bag, so to speak
# 2024-04-03 18:57:04
#
# Scraped 53 users this round
# Got 340 reivews
# 10671 reviews are now in the bag, so to speak
# 2024-04-03 18:58:32
#
# Scraped 56 users this round
# Got 333 reivews
# 11004 reviews are now in the bag, so to speak
# 2024-04-03 19:00:10
#
# Scraped 58 users this round
# Got 354 reivews
# 11358 reviews are now in the bag, so to speak
# 2024-04-03 19:01:50
#
# Scraped 57 users this round
# Got 318 reivews
# 11676 reviews are now in the bag, so to speak
# 2024-04-03 19:03:29
#
# Scraped 58 users this round
# Got 384 reivews
# 12060 reviews are now in the bag, so to speak
# 2024-04-03 19:05:04
#
# Scraped 56 users this round
# Got 330 reivews
# 12390 reviews are now in the bag, so to speak
# 2024-04-03 19:06:45
#
# Scraped 54 users this round
# Got 337 reivews
# 12727 reviews are now in the bag, so to speak
# 2024-04-03 19:08:17
#
# Scraped 59 users this round
# Got 359 reivews
# 13086 reviews are now in the bag, so to speak
# 2024-04-03 19:09:59
#
# Scraped 59 users this round
# Got 335 reivews
# 13421 reviews are now in the bag, so to speak
# 2024-04-03 19:11:45
#
# Scraped 61 users this round
# Got 342 reivews
# 13763 reviews are now in the bag, so to speak
# 2024-04-03 19:13:31
#
# Scraped 62 users this round
# Got 331 reivews
# 14094 reviews are now in the bag, so to speak
# 2024-04-03 19:15:27
#
# Scraped 56 users this round
# Got 321 reivews
# 14415 reviews are now in the bag, so to speak
# 2024-04-03 19:16:57
#
# Scraped 57 users this round
# Got 359 reivews
# 14774 reviews are now in the bag, so to speak
# 2024-04-03 19:18:27
#
# Scraped 53 users this round
# Got 315 reivews
# 15089 reviews are now in the bag, so to speak
# 2024-04-03 19:19:55
#
# Scraped 59 users this round
# Got 353 reivews
# 15442 reviews are now in the bag, so to speak
# 2024-04-03 19:21:40
#
# Scraped 56 users this round
# Got 343 reivews
# 15785 reviews are now in the bag, so to speak
# 2024-04-03 19:23:13
#
# Scraped 56 users this round
# Got 317 reivews
# 16102 reviews are now in the bag, so to speak
# 2024-04-03 19:24:48
#
# Scraped 53 users this round
# Got 309 reivews
# 16411 reviews are now in the bag, so to speak
# 2024-04-03 19:26:12
#
# Scraped 55 users this round
# Got 341 reivews
# 16752 reviews are now in the bag, so to speak
# 2024-04-03 19:27:46
#
# Scraped 55 users this round
# Got 399 reivews
# 17151 reviews are now in the bag, so to speak
# 2024-04-03 19:29:26
#
# Scraped 57 users this round
# Got 354 reivews
# 17505 reviews are now in the bag, so to speak
# 2024-04-03 19:31:04
#
# Scraped 52 users this round
# Got 322 reivews
# 17827 reviews are now in the bag, so to speak
# 2024-04-03 19:32:31
#
# Scraped 57 users this round
# Got 345 reivews
# 18172 reviews are now in the bag, so to speak
# 2024-04-03 19:34:09
#
# Scraped 55 users this round
# Got 353 reivews
# 18525 reviews are now in the bag, so to speak
# 2024-04-03 19:35:46
#
# Scraped 55 users this round
# Got 387 reivews
# 18912 reviews are now in the bag, so to speak
# 2024-04-03 19:37:20
#
# Scraped 54 users this round
# Got 309 reivews
# 19221 reviews are now in the bag, so to speak
# 2024-04-03 19:38:52
#
# Scraped 55 users this round
# Got 329 reivews
# 19550 reviews are now in the bag, so to speak
# 2024-04-03 19:40:24
#
# Scraped 64 users this round
# Got 318 reivews
# 19868 reviews are now in the bag, so to speak
# 2024-04-03 19:42:17
#
# Scraped 55 users this round
# Got 375 reivews
# 20243 reviews are now in the bag, so to speak
# 2024-04-03 19:43:56
#
# Scraped 58 users this round
# Got 314 reivews
# 20557 reviews are now in the bag, so to speak
# 2024-04-03 19:45:38
#
# Scraped 59 users this round
# Got 330 reivews
# 20887 reviews are now in the bag, so to speak
# 2024-04-03 19:47:11
#
# Scraped 61 users this round
# Got 343 reivews
# 21230 reviews are now in the bag, so to speak
# 2024-04-03 19:49:03
#
# Scraped 58 users this round
# Got 385 reivews
# 21615 reviews are now in the bag, so to speak
# 2024-04-03 19:50:53
#
# Scraped 56 users this round
# Got 353 reivews
# 21968 reviews are now in the bag, so to speak
# 2024-04-03 19:52:35
#
# Scraped 57 users this round
# Got 350 reivews
# 22318 reviews are now in the bag, so to speak
# 2024-04-03 19:54:18
#
# Scraped 56 users this round
# Got 382 reivews
# 22700 reviews are now in the bag, so to speak
# 2024-04-03 19:56:02
#
# Scraped 51 users this round
# Got 320 reivews
# 23020 reviews are now in the bag, so to speak
# 2024-04-03 19:57:32
#
# Scraped 56 users this round
# Got 335 reivews
# 23355 reviews are now in the bag, so to speak
# 2024-04-03 19:59:08
#
# Scraped 56 users this round
# Got 348 reivews
# 23703 reviews are now in the bag, so to speak
# 2024-04-03 20:00:46
#
# Scraped 55 users this round
# Got 313 reivews
# 24016 reviews are now in the bag, so to speak
# 2024-04-03 20:02:21
#
# Scraped 58 users this round
# Got 327 reivews
# 24343 reviews are now in the bag, so to speak
# 2024-04-03 20:03:53
#
# Scraped 53 users this round
# Got 337 reivews
# 24680 reviews are now in the bag, so to speak
# 2024-04-03 20:05:20
#
# Scraped 52 users this round
# Got 354 reivews
# 25034 reviews are now in the bag, so to speak
# 2024-04-03 20:07:04
#
# Scraped 64 users this round
# Got 284 reivews
# 25318 reviews are now in the bag, so to speak
# 2024-04-03 20:08:59
#
# Scraped 55 users this round
# Got 328 reivews
# 25646 reviews are now in the bag, so to speak
# 2024-04-03 20:10:31
#
# Scraped 57 users this round
# Got 354 reivews
# 26000 reviews are now in the bag, so to speak
# 2024-04-03 20:12:17
#
# Scraped 56 users this round
# Got 318 reivews
# 26318 reviews are now in the bag, so to speak
# 2024-04-03 20:13:55
#
# Scraped 55 users this round
# Got 321 reivews
# 26639 reviews are now in the bag, so to speak
# 2024-04-03 20:15:25
#
# Scraped 60 users this round
# Got 327 reivews
# 26966 reviews are now in the bag, so to speak
# 2024-04-03 20:17:09
#
# Scraped 62 users this round
# Got 364 reivews
# 27330 reviews are now in the bag, so to speak
# 2024-04-03 20:19:08
#
# Scraped 56 users this round
# Got 327 reivews
# 27657 reviews are now in the bag, so to speak
# 2024-04-03 20:20:54
#
# Scraped 57 users this round
# Got 317 reivews
# 27974 reviews are now in the bag, so to speak
# 2024-04-03 20:22:28
#
# Scraped 58 users this round
# Got 361 reivews
# 28335 reviews are now in the bag, so to speak
# 2024-04-03 20:24:09
#
# Scraped 59 users this round
# Got 322 reivews
# 28657 reviews are now in the bag, so to speak
# 2024-04-03 20:25:43
#
# Scraped 54 users this round
# Got 355 reivews
# 29012 reviews are now in the bag, so to speak
# 2024-04-03 20:27:10
#
# Scraped 54 users this round
# Got 341 reivews
# 29353 reviews are now in the bag, so to speak
# 2024-04-03 20:28:42
#
# Scraped 54 users this round
# Got 332 reivews
# 29685 reviews are now in the bag, so to speak
# 2024-04-03 20:30:14
#
# Scraped 56 users this round
# Got 349 reivews
# 30034 reviews are now in the bag, so to speak
# 2024-04-03 20:31:54
#
# Scraped 52 users this round
# Got 315 reivews
# 30349 reviews are now in the bag, so to speak
# 2024-04-03 20:33:19
#
# Scraped 57 users this round
# Got 357 reivews
# 30706 reviews are now in the bag, so to speak
# 2024-04-03 20:34:52
#
# Scraped 56 users this round
# Got 286 reivews
# 30992 reviews are now in the bag, so to speak
# 2024-04-03 20:36:30
#
# Scraped 62 users this round
# Got 347 reivews
# 31339 reviews are now in the bag, so to speak
# 2024-04-03 20:38:22
#
# Scraped 59 users this round
# Got 377 reivews
# 31716 reviews are now in the bag, so to speak
# 2024-04-03 20:40:05
#
# Scraped 56 users this round
# Got 388 reivews
# 32104 reviews are now in the bag, so to speak
# 2024-04-03 20:41:49
#
# Scraped 53 users this round
# Got 351 reivews
# 32455 reviews are now in the bag, so to speak
# 2024-04-03 20:43:20
#
# Scraped 61 users this round
# Got 318 reivews
# 32773 reviews are now in the bag, so to speak
# 2024-04-03 20:45:00
#
# Scraped 54 users this round
# Got 321 reivews
# 33094 reviews are now in the bag, so to speak
# 2024-04-03 20:46:30
#
# Scraped 60 users this round
# Got 398 reivews
# 33492 reviews are now in the bag, so to speak
# 2024-04-03 20:48:11
#
# Scraped 52 users this round
# Got 318 reivews
# 33810 reviews are now in the bag, so to speak
# 2024-04-03 20:49:45
#
# Scraped 57 users this round
# Got 323 reivews
# 34133 reviews are now in the bag, so to speak
# 2024-04-03 20:51:39
#
# Scraped 58 users this round
# Got 291 reivews
# 34424 reviews are now in the bag, so to speak
# 2024-04-03 20:53:15
#
# Scraped 57 users this round
# Got 313 reivews
# 34737 reviews are now in the bag, so to speak
# 2024-04-03 20:54:54
#
# Scraped 58 users this round
# Got 376 reivews
# 35113 reviews are now in the bag, so to speak
# 2024-04-03 20:56:37
#
# Scraped 57 users this round
# Got 359 reivews
# 35472 reviews are now in the bag, so to speak
# 2024-04-03 20:58:14
#
# Scraped 57 users this round
# Got 373 reivews
# 35845 reviews are now in the bag, so to speak
# 2024-04-03 20:59:50
#
# Scraped 58 users this round
# Got 328 reivews
# 36173 reviews are now in the bag, so to speak
# 2024-04-03 21:01:29
#
# Scraped 57 users this round
# Got 352 reivews
# 36525 reviews are now in the bag, so to speak
# 2024-04-03 21:03:14
#
# Scraped 59 users this round
# Got 337 reivews
# 36862 reviews are now in the bag, so to speak
# 2024-04-03 21:04:59
#
# Scraped 56 users this round
# Got 390 reivews
# 37252 reviews are now in the bag, so to speak
# 2024-04-03 21:06:43
#
# Scraped 55 users this round
# Got 336 reivews
# 37588 reviews are now in the bag, so to speak
# 2024-04-03 21:08:26
#
# Scraped 57 users this round
# Got 318 reivews
# 37906 reviews are now in the bag, so to speak
# 2024-04-03 21:10:11
#
# Scraped 56 users this round
# Got 310 reivews
# 38216 reviews are now in the bag, so to speak
# 2024-04-03 21:11:46
#
# Scraped 56 users this round
# Got 359 reivews
# 38575 reviews are now in the bag, so to speak
# 2024-04-03 21:13:23
#
# Scraped 56 users this round
# Got 376 reivews
# 38951 reviews are now in the bag, so to speak
# 2024-04-03 21:15:03
#
# Scraped 53 users this round
# Got 368 reivews
# 39319 reviews are now in the bag, so to speak
# 2024-04-03 21:16:29
#
# Scraped 56 users this round
# Got 328 reivews
# 39647 reviews are now in the bag, so to speak
# 2024-04-03 21:18:11
#
# Scraped 56 users this round
# Got 297 reivews
# 39944 reviews are now in the bag, so to speak
# 2024-04-03 21:19:50
#
# Scraped 52 users this round
# Got 328 reivews
# 40272 reviews are now in the bag, so to speak
# 2024-04-03 21:21:25
#
# Scraped 56 users this round
# Got 348 reivews
# 40620 reviews are now in the bag, so to speak
# 2024-04-03 21:23:10
#
# Scraped 56 users this round
# Got 352 reivews
# 40972 reviews are now in the bag, so to speak
# 2024-04-03 21:24:44
#
# Scraped 53 users this round
# Got 341 reivews
# 41313 reviews are now in the bag, so to speak
# 2024-04-03 21:26:14
#
# Scraped 56 users this round
# Got 286 reivews
# 41599 reviews are now in the bag, so to speak
# 2024-04-03 21:27:41
#
# Scraped 61 users this round
# Got 314 reivews
# 41913 reviews are now in the bag, so to speak
# 2024-04-03 21:29:19
#
# Scraped 53 users this round
# Got 366 reivews
# 42279 reviews are now in the bag, so to speak
# 2024-04-03 21:30:47
#
# Scraped 57 users this round
# Got 360 reivews
# 42639 reviews are now in the bag, so to speak
# 2024-04-03 21:32:23
#
# Scraped 57 users this round
# Got 340 reivews
# 42979 reviews are now in the bag, so to speak
# 2024-04-03 21:34:07
#
# Scraped 53 users this round
# Got 323 reivews
# 43302 reviews are now in the bag, so to speak
# 2024-04-03 21:35:29
#
# Scraped 58 users this round
# Got 362 reivews
# 43664 reviews are now in the bag, so to speak
# 2024-04-03 21:37:12
#
# Scraped 55 users this round
# Got 339 reivews
# 44003 reviews are now in the bag, so to speak
# 2024-04-03 21:38:33
#
# Scraped 56 users this round
# Got 319 reivews
# 44322 reviews are now in the bag, so to speak
# 2024-04-03 21:40:02
#
# Scraped 57 users this round
# Got 323 reivews
# 44645 reviews are now in the bag, so to speak
# 2024-04-03 21:41:32
#
# Scraped 52 users this round
# Got 315 reivews
# 44960 reviews are now in the bag, so to speak
# 2024-04-03 21:43:03
#
# Scraped 63 users this round
# Got 355 reivews
# 45315 reviews are now in the bag, so to speak
# 2024-04-03 21:44:57
#
# Scraped 57 users this round
# Got 359 reivews
# 45674 reviews are now in the bag, so to speak
# 2024-04-03 21:46:31
#
# Scraped 57 users this round
# Got 364 reivews
# 46038 reviews are now in the bag, so to speak
# 2024-04-03 21:48:03
#
# Scraped 57 users this round
# Got 354 reivews
# 46392 reviews are now in the bag, so to speak
# 2024-04-03 21:49:33
#
# Scraped 58 users this round
# Got 311 reivews
# 46703 reviews are now in the bag, so to speak
# 2024-04-03 21:51:16
#
# Scraped 52 users this round
# Got 353 reivews
# 47056 reviews are now in the bag, so to speak
# 2024-04-03 21:52:44
#
# Scraped 56 users this round
# Got 357 reivews
# 47413 reviews are now in the bag, so to speak
# 2024-04-03 21:54:33
#
# Scraped 56 users this round
# Got 378 reivews
# 47791 reviews are now in the bag, so to speak
# 2024-04-03 21:56:10
#
# Scraped 55 users this round
# Got 328 reivews
# 48119 reviews are now in the bag, so to speak
# 2024-04-03 21:57:47
#
# Scraped 59 users this round
# Got 357 reivews
# 48476 reviews are now in the bag, so to speak
# 2024-04-03 21:59:26
#
# Scraped 58 users this round
# Got 397 reivews
# 48873 reviews are now in the bag, so to speak
# 2024-04-03 22:01:08
#
# Scraped 60 users this round
# Got 343 reivews
# 49216 reviews are now in the bag, so to speak
# 2024-04-03 22:02:55
#
# Scraped 56 users this round
# Got 347 reivews
# 49563 reviews are now in the bag, so to speak
# 2024-04-03 22:04:38
#
# Scraped 55 users this round
# Got 355 reivews
# 49918 reviews are now in the bag, so to speak
# 2024-04-03 22:06:17
#
# Scraped 54 users this round
# Got 330 reivews
# 50248 reviews are now in the bag, so to speak
# 2024-04-03 22:07:54
#
# Scraped 57 users this round
# Got 349 reivews
# 50597 reviews are now in the bag, so to speak
# 2024-04-03 22:09:45
#
# Scraped 64 users this round
# Got 356 reivews
# 50953 reviews are now in the bag, so to speak
# 2024-04-03 22:11:46
#
# Scraped 53 users this round
# Got 336 reivews
# 51289 reviews are now in the bag, so to speak
# 2024-04-03 22:13:19
#
# Scraped 58 users this round
# Got 323 reivews
# 51612 reviews are now in the bag, so to speak
# 2024-04-03 22:15:04
#
# Scraped 54 users this round
# Got 326 reivews
# 51938 reviews are now in the bag, so to speak
# 2024-04-03 22:16:35
#
# Scraped 53 users this round
# Got 327 reivews
# 52265 reviews are now in the bag, so to speak
# 2024-04-03 22:18:06
#
# Scraped 58 users this round
# Got 354 reivews
# 52619 reviews are now in the bag, so to speak
# 2024-04-03 22:19:54
#
# Scraped 55 users this round
# Got 374 reivews
# 52993 reviews are now in the bag, so to speak
# 2024-04-03 22:21:40
#
# Scraped 58 users this round
# Got 336 reivews
# 53329 reviews are now in the bag, so to speak
# 2024-04-03 22:23:42
#
# Scraped 57 users this round
# Got 341 reivews
# 53670 reviews are now in the bag, so to speak
# 2024-04-03 22:25:54
#
# Scraped 60 users this round
# Got 317 reivews
# 53987 reviews are now in the bag, so to speak
# 2024-04-03 22:28:45
#
# Scraped 62 users this round
# Got 295 reivews
# 54282 reviews are now in the bag, so to speak
# 2024-04-03 22:32:03
#
# Scraped 54 users this round
# Got 361 reivews
# 54643 reviews are now in the bag, so to speak
# 2024-04-03 22:34:59
#
# Scraped 58 users this round
# Got 290 reivews
# 54933 reviews are now in the bag, so to speak
# 2024-04-03 22:38:07
#
# Scraped 55 users this round
# Got 341 reivews
# 55274 reviews are now in the bag, so to speak
# 2024-04-03 22:41:03
#
# Scraped 57 users this round
# Got 346 reivews
# 55620 reviews are now in the bag, so to speak
# 2024-04-03 22:44:13
#
# Scraped 55 users this round
# Got 367 reivews
# 55987 reviews are now in the bag, so to speak
# 2024-04-03 22:47:11
#
# Scraped 60 users this round
# Got 341 reivews
# 56328 reviews are now in the bag, so to speak
# 2024-04-03 22:50:20
#
# Scraped 56 users this round
# Got 353 reivews
# 56681 reviews are now in the bag, so to speak
# 2024-04-03 22:53:15
#
# Scraped 54 users this round
# Got 349 reivews
# 57030 reviews are now in the bag, so to speak
# 2024-04-03 22:56:04
#
# Scraped 55 users this round
# Got 320 reivews
# 57350 reviews are now in the bag, so to speak
# 2024-04-03 22:58:58
#
# Scraped 54 users this round
# Got 373 reivews
# 57723 reviews are now in the bag, so to speak
# 2024-04-03 23:01:50
#
# Scraped 52 users this round
# Got 371 reivews
# 58094 reviews are now in the bag, so to speak
# 2024-04-03 23:04:20
#
# Scraped 55 users this round
# Got 327 reivews
# 58421 reviews are now in the bag, so to speak
# 2024-04-03 23:07:11
#
# Scraped 54 users this round
# Got 386 reivews
# 58807 reviews are now in the bag, so to speak
# 2024-04-03 23:10:20
#
# Scraped 53 users this round
# Got 352 reivews
# 59159 reviews are now in the bag, so to speak
# 2024-04-03 23:13:25
#
# Scraped 56 users this round
# Got 344 reivews
# 59503 reviews are now in the bag, so to speak
# 2024-04-03 23:15:26
#
# Scraped 60 users this round
# Got 359 reivews
# 59862 reviews are now in the bag, so to speak
# 2024-04-03 23:17:19
#
# Scraped 56 users this round
# Got 346 reivews
# 60208 reviews are now in the bag, so to speak
# 2024-04-03 23:18:51
#
# Scraped 55 users this round
# Got 307 reivews
# 60515 reviews are now in the bag, so to speak
# 2024-04-03 23:20:21
#
# Scraped 54 users this round
# Got 354 reivews
# 60869 reviews are now in the bag, so to speak
# 2024-04-03 23:21:59
#
# Scraped 58 users this round
# Got 320 reivews
# 61189 reviews are now in the bag, so to speak
# 2024-04-03 23:23:38
#
# Scraped 60 users this round
# Got 372 reivews
# 61561 reviews are now in the bag, so to speak
# 2024-04-03 23:25:33
#
# Scraped 53 users this round
# Got 345 reivews
# 61906 reviews are now in the bag, so to speak
# 2024-04-03 23:27:03
#
# Scraped 54 users this round
# Got 368 reivews
# 62274 reviews are now in the bag, so to speak
# 2024-04-03 23:28:41
#
# Scraped 56 users this round
# Got 323 reivews
# 62597 reviews are now in the bag, so to speak
# 2024-04-03 23:30:19
#
# Scraped 59 users this round
# Got 389 reivews
# 62986 reviews are now in the bag, so to speak
# 2024-04-03 23:31:58
#
# Scraped 54 users this round
# Got 372 reivews
# 63358 reviews are now in the bag, so to speak
# 2024-04-03 23:33:25
#
# Scraped 54 users this round
# Got 303 reivews
# 63661 reviews are now in the bag, so to speak
# 2024-04-03 23:34:51
#
# Scraped 55 users this round
# Got 324 reivews
# 63985 reviews are now in the bag, so to speak
# 2024-04-03 23:36:33
#
# Scraped 54 users this round
# Got 319 reivews
# 64304 reviews are now in the bag, so to speak
# 2024-04-03 23:37:59
#
# Scraped 54 users this round
# Got 340 reivews
# 64644 reviews are now in the bag, so to speak
# 2024-04-03 23:39:31
#
# Scraped 59 users this round
# Got 326 reivews
# 64970 reviews are now in the bag, so to speak
# 2024-04-03 23:41:07
#
# Scraped 52 users this round
# Got 304 reivews
# 65274 reviews are now in the bag, so to speak
# 2024-04-03 23:42:39
#
# Scraped 53 users this round
# Got 334 reivews
# 65608 reviews are now in the bag, so to speak
# 2024-04-03 23:44:11
#
# Scraped 58 users this round
# Got 340 reivews
# 65948 reviews are now in the bag, so to speak
# 2024-04-03 23:45:46
#
# Scraped 51 users this round
# Got 370 reivews
# 66318 reviews are now in the bag, so to speak
# 2024-04-03 23:47:13
#
# Scraped 55 users this round
# Got 336 reivews
# 66654 reviews are now in the bag, so to speak
# 2024-04-03 23:48:47
#
# Scraped 54 users this round
# Got 365 reivews
# 67019 reviews are now in the bag, so to speak
# 2024-04-03 23:50:24
#
# Scraped 58 users this round
# Got 396 reivews
# 67415 reviews are now in the bag, so to speak
# 2024-04-03 23:52:07
#
# Scraped 57 users this round
# Got 329 reivews
# 67744 reviews are now in the bag, so to speak
# 2024-04-03 23:53:46
#
# Scraped 57 users this round
# Got 347 reivews
# 68091 reviews are now in the bag, so to speak
# 2024-04-03 23:55:36
#
# Scraped 53 users this round
# Got 360 reivews
# 68451 reviews are now in the bag, so to speak
# 2024-04-03 23:57:09
#
# Scraped 53 users this round
# Got 380 reivews
# 68831 reviews are now in the bag, so to speak
# 2024-04-03 23:58:30
#
# Scraped 57 users this round
# Got 322 reivews
# 69153 reviews are now in the bag, so to speak
# 2024-04-04 00:00:10
#
# Scraped 55 users this round
# Got 395 reivews
# 69548 reviews are now in the bag, so to speak
# 2024-04-04 00:01:41
#
# Scraped 56 users this round
# Got 346 reivews
# 69894 reviews are now in the bag, so to speak
# 2024-04-04 00:03:15
#
# Scraped 55 users this round
# Got 327 reivews
# 70221 reviews are now in the bag, so to speak
# 2024-04-04 00:04:51
#
# Scraped 57 users this round
# Got 360 reivews
# 70581 reviews are now in the bag, so to speak
# 2024-04-04 00:06:35
#
# Scraped 58 users this round
# Got 375 reivews
# 70956 reviews are now in the bag, so to speak
# 2024-04-04 00:08:13
#
# Scraped 51 users this round
# Got 307 reivews
# 71263 reviews are now in the bag, so to speak
# 2024-04-04 00:09:53
#
# Scraped 56 users this round
# Got 334 reivews
# 71597 reviews are now in the bag, so to speak
# 2024-04-04 00:11:38
#
# Scraped 53 users this round
# Got 355 reivews
# 71952 reviews are now in the bag, so to speak
# 2024-04-04 00:13:13
#
# Scraped 58 users this round
# Got 322 reivews
# 72274 reviews are now in the bag, so to speak
# 2024-04-04 00:14:58
#
# Scraped 55 users this round
# Got 317 reivews
# 72591 reviews are now in the bag, so to speak
# 2024-04-04 00:16:29
#
# Scraped 56 users this round
# Got 319 reivews
# 72910 reviews are now in the bag, so to speak
# 2024-04-04 00:18:02
#
# Scraped 56 users this round
# Got 338 reivews
# 73248 reviews are now in the bag, so to speak
# 2024-04-04 00:19:46
#
# Scraped 61 users this round
# Got 309 reivews
# 73557 reviews are now in the bag, so to speak
# 2024-04-04 00:21:24
#
# Scraped 54 users this round
# Got 367 reivews
# 73924 reviews are now in the bag, so to speak
# 2024-04-04 00:22:56
#
# Scraped 56 users this round
# Got 386 reivews
# 74310 reviews are now in the bag, so to speak
# 2024-04-04 00:24:31
#
# Scraped 54 users this round
# Got 346 reivews
# 74656 reviews are now in the bag, so to speak
# 2024-04-04 00:26:03
#
# Scraped 54 users this round
# Got 385 reivews
# 75041 reviews are now in the bag, so to speak
# 2024-04-04 00:27:41
#
# Scraped 54 users this round
# Got 327 reivews
# 75368 reviews are now in the bag, so to speak
# 2024-04-04 00:29:22
#
# Scraped 52 users this round
# Got 388 reivews
# 75756 reviews are now in the bag, so to speak
# 2024-04-04 00:30:54
#
# Scraped 56 users this round
# Got 363 reivews
# 76119 reviews are now in the bag, so to speak
# 2024-04-04 00:32:23
#
# Scraped 55 users this round
# Got 317 reivews
# 76436 reviews are now in the bag, so to speak
# 2024-04-04 00:33:51
#
# Scraped 58 users this round
# Got 343 reivews
# 76779 reviews are now in the bag, so to speak
# 2024-04-04 00:35:27
#
# Scraped 52 users this round
# Got 337 reivews
# 77116 reviews are now in the bag, so to speak
# 2024-04-04 00:36:57
#
# Scraped 52 users this round
# Got 351 reivews
# 77467 reviews are now in the bag, so to speak
# 2024-04-04 00:38:28
#
# Scraped 56 users this round
# Got 341 reivews
# 77808 reviews are now in the bag, so to speak
# 2024-04-04 00:39:55
#
# Scraped 57 users this round
# Got 338 reivews
# 78146 reviews are now in the bag, so to speak
# 2024-04-04 00:41:34
#
# Scraped 57 users this round
# Got 333 reivews
# 78479 reviews are now in the bag, so to speak
# 2024-04-04 00:43:20
#
# Scraped 56 users this round
# Got 357 reivews
# 78836 reviews are now in the bag, so to speak
# 2024-04-04 00:44:51
#
# Scraped 55 users this round
# Got 320 reivews
# 79156 reviews are now in the bag, so to speak
# 2024-04-04 00:46:19
#
# Scraped 54 users this round
# Got 357 reivews
# 79513 reviews are now in the bag, so to speak
# 2024-04-04 00:47:56
#
# Scraped 55 users this round
# Got 311 reivews
# 79824 reviews are now in the bag, so to speak
# 2024-04-04 00:49:27
#
# Scraped 58 users this round
# Got 316 reivews
# 80140 reviews are now in the bag, so to speak
# 2024-04-04 00:51:06
#
# Scraped 53 users this round
# Got 345 reivews
# 80485 reviews are now in the bag, so to speak
# 2024-04-04 00:52:36
#
# Scraped 59 users this round
# Got 381 reivews
# 80866 reviews are now in the bag, so to speak
# 2024-04-04 00:54:17
#
# Scraped 57 users this round
# Got 329 reivews
# 81195 reviews are now in the bag, so to speak
# 2024-04-04 00:55:53
#
# Scraped 55 users this round
# Got 324 reivews
# 81519 reviews are now in the bag, so to speak
# 2024-04-04 00:57:24
#
# Scraped 55 users this round
# Got 313 reivews
# 81832 reviews are now in the bag, so to speak
# 2024-04-04 00:58:46
#
# Scraped 52 users this round
# Got 309 reivews
# 82141 reviews are now in the bag, so to speak
# 2024-04-04 01:00:12
#
# Scraped 60 users this round
# Got 334 reivews
# 82475 reviews are now in the bag, so to speak
# 2024-04-04 01:01:50
#
# Scraped 55 users this round
# Got 304 reivews
# 82779 reviews are now in the bag, so to speak
# 2024-04-04 01:03:17
#
# Scraped 55 users this round
# Got 380 reivews
# 83159 reviews are now in the bag, so to speak
# 2024-04-04 01:04:52
#
# Scraped 55 users this round
# Got 298 reivews
# 83457 reviews are now in the bag, so to speak
# 2024-04-04 01:06:39
#
# Scraped 59 users this round
# Got 331 reivews
# 83788 reviews are now in the bag, so to speak
# 2024-04-04 01:08:14
#
# Scraped 55 users this round
# Got 313 reivews
# 84101 reviews are now in the bag, so to speak
# 2024-04-04 01:10:00
#
# Scraped 59 users this round
# Got 349 reivews
# 84450 reviews are now in the bag, so to speak
# 2024-04-04 01:11:52
#
# Scraped 53 users this round
# Got 338 reivews
# 84788 reviews are now in the bag, so to speak
# 2024-04-04 01:13:27
#
# Scraped 55 users this round
# Got 388 reivews
# 85176 reviews are now in the bag, so to speak
# 2024-04-04 01:15:03
#
# Scraped 56 users this round
# Got 371 reivews
# 85547 reviews are now in the bag, so to speak
# 2024-04-04 01:16:43
#
# Scraped 53 users this round
# Got 334 reivews
# 85881 reviews are now in the bag, so to speak
# 2024-04-04 01:18:20
#
# Scraped 56 users this round
# Got 349 reivews
# 86230 reviews are now in the bag, so to speak
# 2024-04-04 01:19:44
#
# Scraped 56 users this round
# Got 314 reivews
# 86544 reviews are now in the bag, so to speak
# 2024-04-04 01:21:22
#
# Scraped 55 users this round
# Got 327 reivews
# 86871 reviews are now in the bag, so to speak
# 2024-04-04 01:23:00
#
# Scraped 51 users this round
# Got 341 reivews
# 87212 reviews are now in the bag, so to speak
# 2024-04-04 01:24:26
#
# Scraped 57 users this round
# Got 356 reivews
# 87568 reviews are now in the bag, so to speak
# 2024-04-04 01:26:15
#
# Scraped 55 users this round
# Got 312 reivews
# 87880 reviews are now in the bag, so to speak
# 2024-04-04 01:27:48
#
# Scraped 55 users this round
# Got 315 reivews
# 88195 reviews are now in the bag, so to speak
# 2024-04-04 01:29:20
#
# Scraped 58 users this round
# Got 327 reivews
# 88522 reviews are now in the bag, so to speak
# 2024-04-04 01:30:50
#
# Scraped 59 users this round
# Got 342 reivews
# 88864 reviews are now in the bag, so to speak
# 2024-04-04 01:32:35
#
# Scraped 57 users this round
# Got 285 reivews
# 89149 reviews are now in the bag, so to speak
# 2024-04-04 01:34:04
#
# Scraped 55 users this round
# Got 324 reivews
# 89473 reviews are now in the bag, so to speak
# 2024-04-04 01:35:33
#
# Scraped 57 users this round
# Got 380 reivews
# 89853 reviews are now in the bag, so to speak
# 2024-04-04 01:37:07
#
# Scraped 55 users this round
# Got 300 reivews
# 90153 reviews are now in the bag, so to speak
# 2024-04-04 01:38:46
#
# Scraped 58 users this round
# Got 384 reivews
# 90537 reviews are now in the bag, so to speak
# 2024-04-04 01:40:27
#
# Scraped 59 users this round
# Got 336 reivews
# 90873 reviews are now in the bag, so to speak
# 2024-04-04 01:42:12
#
# Scraped 55 users this round
# Got 355 reivews
# 91228 reviews are now in the bag, so to speak
# 2024-04-04 01:43:56
#
# Scraped 56 users this round
# Got 337 reivews
# 91565 reviews are now in the bag, so to speak
# 2024-04-04 01:45:23
#
# Scraped 55 users this round
# Got 347 reivews
# 91912 reviews are now in the bag, so to speak
# 2024-04-04 01:47:01
#
# Scraped 56 users this round
# Got 355 reivews
# 92267 reviews are now in the bag, so to speak
# 2024-04-04 01:48:33
#
# Scraped 53 users this round
# Got 358 reivews
# 92625 reviews are now in the bag, so to speak
# 2024-04-04 01:50:11
#
# Scraped 56 users this round
# Got 334 reivews
# 92959 reviews are now in the bag, so to speak
# 2024-04-04 01:51:51
#
# Scraped 56 users this round
# Got 302 reivews
# 93261 reviews are now in the bag, so to speak
# 2024-04-04 01:53:23
#
# Scraped 59 users this round
# Got 364 reivews
# 93625 reviews are now in the bag, so to speak
# 2024-04-04 01:54:55
#
# Scraped 58 users this round
# Got 360 reivews
# 93985 reviews are now in the bag, so to speak
# 2024-04-04 01:56:28
#
# Scraped 56 users this round
# Got 322 reivews
# 94307 reviews are now in the bag, so to speak
# 2024-04-04 01:57:58
#
# Scraped 52 users this round
# Got 347 reivews
# 94654 reviews are now in the bag, so to speak
# 2024-04-04 01:59:21
#
# Scraped 54 users this round
# Got 390 reivews
# 95044 reviews are now in the bag, so to speak
# 2024-04-04 02:00:53
#
# Scraped 60 users this round
# Got 339 reivews
# 95383 reviews are now in the bag, so to speak
# 2024-04-04 02:02:33
#
# Scraped 54 users this round
# Got 337 reivews
# 95720 reviews are now in the bag, so to speak
# 2024-04-04 02:04:07
#
# Scraped 56 users this round
# Got 359 reivews
# 96079 reviews are now in the bag, so to speak
# 2024-04-04 02:05:37
#
# Scraped 60 users this round
# Got 336 reivews
# 96415 reviews are now in the bag, so to speak
# 2024-04-04 02:07:19
#
# Scraped 52 users this round
# Got 324 reivews
# 96739 reviews are now in the bag, so to speak
# 2024-04-04 02:09:01
#
# Scraped 59 users this round
# Got 304 reivews
# 97043 reviews are now in the bag, so to speak
# 2024-04-04 02:10:46
#
# Scraped 62 users this round
# Got 373 reivews
# 97416 reviews are now in the bag, so to speak
# 2024-04-04 02:12:28
#
# Scraped 61 users this round
# Got 334 reivews
# 97750 reviews are now in the bag, so to speak
# 2024-04-04 02:13:59
#
# Scraped 61 users this round
# Got 369 reivews
# 98119 reviews are now in the bag, so to speak
# 2024-04-04 02:15:53
#
# Scraped 58 users this round
# Got 347 reivews
# 98466 reviews are now in the bag, so to speak
# 2024-04-04 02:17:37
#
# Scraped 52 users this round
# Got 363 reivews
# 98829 reviews are now in the bag, so to speak
# 2024-04-04 02:19:00
#
# Scraped 57 users this round
# Got 327 reivews
# 99156 reviews are now in the bag, so to speak
# 2024-04-04 02:20:43
#
# Scraped 63 users this round
# Got 341 reivews
# 99497 reviews are now in the bag, so to speak
# 2024-04-04 02:22:18
#
# Scraped 58 users this round
# Got 344 reivews
# 99841 reviews are now in the bag, so to speak
# 2024-04-04 02:23:50
#
# Scraped 56 users this round
# Got 335 reivews
# 100176 reviews are now in the bag, so to speak
# 2024-04-04 02:25:27
#
# Scraped 58 users this round
# Got 320 reivews
# 100496 reviews are now in the bag, so to speak
# 2024-04-04 02:27:03
#
# Scraped 56 users this round
# Got 366 reivews
# 100862 reviews are now in the bag, so to speak
# 2024-04-04 02:28:33
#
# Scraped 54 users this round
# Got 341 reivews
# 101203 reviews are now in the bag, so to speak
# 2024-04-04 02:30:01
#
# Scraped 57 users this round
# Got 362 reivews
# 101565 reviews are now in the bag, so to speak
# 2024-04-04 02:31:44
#
# Scraped 60 users this round
# Got 347 reivews
# 101912 reviews are now in the bag, so to speak
# 2024-04-04 02:33:20
#
# Scraped 52 users this round
# Got 341 reivews
# 102253 reviews are now in the bag, so to speak
# 2024-04-04 02:34:43
#
# Scraped 54 users this round
# Got 368 reivews
# 102621 reviews are now in the bag, so to speak
# 2024-04-04 02:36:20
#
# Scraped 55 users this round
# Got 328 reivews
# 102949 reviews are now in the bag, so to speak
# 2024-04-04 02:37:56
#
# Scraped 55 users this round
# Got 312 reivews
# 103261 reviews are now in the bag, so to speak
# 2024-04-04 02:39:25
#
# Scraped 59 users this round
# Got 342 reivews
# 103603 reviews are now in the bag, so to speak
# 2024-04-04 02:41:03
#
# Scraped 56 users this round
# Got 313 reivews
# 103916 reviews are now in the bag, so to speak
# 2024-04-04 02:42:32
#
# Scraped 59 users this round
# Got 340 reivews
# 104256 reviews are now in the bag, so to speak
# 2024-04-04 02:44:05
#
# Scraped 53 users this round
# Got 324 reivews
# 104580 reviews are now in the bag, so to speak
# 2024-04-04 02:45:34
#
# Scraped 59 users this round
# Got 348 reivews
# 104928 reviews are now in the bag, so to speak
# 2024-04-04 02:47:18
#
# Scraped 57 users this round
# Got 302 reivews
# 105230 reviews are now in the bag, so to speak
# 2024-04-04 02:48:50
#
# Scraped 56 users this round
# Got 327 reivews
# 105557 reviews are now in the bag, so to speak
# 2024-04-04 02:50:22
#
# Scraped 66 users this round
# Got 357 reivews
# 105914 reviews are now in the bag, so to speak
# 2024-04-04 02:52:08
#
# Scraped 55 users this round
# Got 303 reivews
# 106217 reviews are now in the bag, so to speak
# 2024-04-04 02:53:40
#
# Scraped 54 users this round
# Got 372 reivews
# 106589 reviews are now in the bag, so to speak
# 2024-04-04 02:55:06
#
# Scraped 53 users this round
# Got 355 reivews
# 106944 reviews are now in the bag, so to speak
# 2024-04-04 02:56:43
#
# Scraped 58 users this round
# Got 340 reivews
# 107284 reviews are now in the bag, so to speak
# 2024-04-04 02:58:17
#
# Scraped 57 users this round
# Got 368 reivews
# 107652 reviews are now in the bag, so to speak
# 2024-04-04 02:59:58
#
# Scraped 56 users this round
# Got 309 reivews
# 107961 reviews are now in the bag, so to speak
# 2024-04-04 03:01:30
#
# Scraped 56 users this round
# Got 319 reivews
# 108280 reviews are now in the bag, so to speak
# 2024-04-04 03:03:01
#
# Scraped 55 users this round
# Got 357 reivews
# 108637 reviews are now in the bag, so to speak
# 2024-04-04 03:04:34
#
# Scraped 55 users this round
# Got 339 reivews
# 108976 reviews are now in the bag, so to speak
# 2024-04-04 03:06:07
#
# Scraped 53 users this round
# Got 303 reivews
# 109279 reviews are now in the bag, so to speak
# 2024-04-04 03:07:31
#
# Scraped 55 users this round
# Got 271 reivews
# 109550 reviews are now in the bag, so to speak
# 2024-04-04 03:09:03
#
# Scraped 53 users this round
# Got 359 reivews
# 109909 reviews are now in the bag, so to speak
# 2024-04-04 03:10:27
#
# Scraped 55 users this round
# Got 319 reivews
# 110228 reviews are now in the bag, so to speak
# 2024-04-04 03:11:57
#
# Scraped 58 users this round
# Got 327 reivews
# 110555 reviews are now in the bag, so to speak
# 2024-04-04 03:13:40
#
# Scraped 59 users this round
# Got 349 reivews
# 110904 reviews are now in the bag, so to speak
# 2024-04-04 03:15:16
#
# Scraped 61 users this round
# Got 350 reivews
# 111254 reviews are now in the bag, so to speak
# 2024-04-04 03:16:56
#
# Scraped 57 users this round
# Got 328 reivews
# 111582 reviews are now in the bag, so to speak
# 2024-04-04 03:18:31
#
# Scraped 57 users this round
# Got 336 reivews
# 111918 reviews are now in the bag, so to speak
# 2024-04-04 03:20:12
#
# Scraped 55 users this round
# Got 369 reivews
# 112287 reviews are now in the bag, so to speak
# 2024-04-04 03:21:58
#
# Scraped 57 users this round
# Got 356 reivews
# 112643 reviews are now in the bag, so to speak
# 2024-04-04 03:23:37
#
# Scraped 57 users this round
# Got 339 reivews
# 112982 reviews are now in the bag, so to speak
# 2024-04-04 03:25:10
#
# Scraped 59 users this round
# Got 333 reivews
# 113315 reviews are now in the bag, so to speak
# 2024-04-04 03:26:43
#
# Scraped 56 users this round
# Got 342 reivews
# 113657 reviews are now in the bag, so to speak
# 2024-04-04 03:28:15
#
# Scraped 54 users this round
# Got 355 reivews
# 114012 reviews are now in the bag, so to speak
# 2024-04-04 03:29:47
#
# Scraped 53 users this round
# Got 321 reivews
# 114333 reviews are now in the bag, so to speak
# 2024-04-04 03:31:19
#
# Scraped 57 users this round
# Got 316 reivews
# 114649 reviews are now in the bag, so to speak
# 2024-04-04 03:32:50
#
# Scraped 57 users this round
# Got 360 reivews
# 115009 reviews are now in the bag, so to speak
# 2024-04-04 03:34:20
#
# Scraped 54 users this round
# Got 320 reivews
# 115329 reviews are now in the bag, so to speak
# 2024-04-04 03:35:51
#
# Scraped 58 users this round
# Got 369 reivews
# 115698 reviews are now in the bag, so to speak
# 2024-04-04 03:37:31
#
# Scraped 58 users this round
# Got 351 reivews
# 116049 reviews are now in the bag, so to speak
# 2024-04-04 03:39:22
#
# Scraped 55 users this round
# Got 303 reivews
# 116352 reviews are now in the bag, so to speak
# 2024-04-04 03:40:54
#
# Scraped 54 users this round
# Got 310 reivews
# 116662 reviews are now in the bag, so to speak
# 2024-04-04 03:42:16
#
# Scraped 52 users this round
# Got 314 reivews
# 116976 reviews are now in the bag, so to speak
# 2024-04-04 03:43:47
#
# Scraped 54 users this round
# Got 341 reivews
# 117317 reviews are now in the bag, so to speak
# 2024-04-04 03:45:15
#
# Scraped 58 users this round
# Got 320 reivews
# 117637 reviews are now in the bag, so to speak
# 2024-04-04 03:46:54
#
# Scraped 58 users this round
# Got 344 reivews
# 117981 reviews are now in the bag, so to speak
# 2024-04-04 03:48:23
#
# Scraped 56 users this round
# Got 354 reivews
# 118335 reviews are now in the bag, so to speak
# 2024-04-04 03:49:57
#
# Scraped 55 users this round
# Got 334 reivews
# 118669 reviews are now in the bag, so to speak
# 2024-04-04 03:51:22
#
# Scraped 58 users this round
# Got 331 reivews
# 119000 reviews are now in the bag, so to speak
# 2024-04-04 03:52:54
#
# Scraped 55 users this round
# Got 315 reivews
# 119315 reviews are now in the bag, so to speak
# 2024-04-04 03:54:18
#
# Scraped 53 users this round
# Got 347 reivews
# 119662 reviews are now in the bag, so to speak
# 2024-04-04 03:55:38
#
# Scraped 58 users this round
# Got 323 reivews
# 119985 reviews are now in the bag, so to speak
# 2024-04-04 03:57:02
#
# Scraped 59 users this round
# Got 324 reivews
# 120309 reviews are now in the bag, so to speak
# 2024-04-04 03:58:32
#
# Scraped 55 users this round
# Got 327 reivews
# 120636 reviews are now in the bag, so to speak
# 2024-04-04 03:59:55
#
# Scraped 56 users this round
# Got 307 reivews
# 120943 reviews are now in the bag, so to speak
# 2024-04-04 04:01:23
#
# Scraped 54 users this round
# Got 326 reivews
# 121269 reviews are now in the bag, so to speak
# 2024-04-04 04:02:41
#
# Scraped 56 users this round
# Got 351 reivews
# 121620 reviews are now in the bag, so to speak
# 2024-04-04 04:04:05
#
# Scraped 55 users this round
# Got 328 reivews
# 121948 reviews are now in the bag, so to speak
# 2024-04-04 04:05:32
#
# Scraped 54 users this round
# Got 377 reivews
# 122325 reviews are now in the bag, so to speak
# 2024-04-04 04:06:53
#
# Scraped 58 users this round
# Got 323 reivews
# 122648 reviews are now in the bag, so to speak
# 2024-04-04 04:08:20
#
# Scraped 56 users this round
# Got 317 reivews
# 122965 reviews are now in the bag, so to speak
# 2024-04-04 04:09:38
#
# Scraped 56 users this round
# Got 344 reivews
# 123309 reviews are now in the bag, so to speak
# 2024-04-04 04:11:14
#
# Scraped 56 users this round
# Got 366 reivews
# 123675 reviews are now in the bag, so to speak
# 2024-04-04 04:12:36
#
# Scraped 55 users this round
# Got 365 reivews
# 124040 reviews are now in the bag, so to speak
# 2024-04-04 04:14:08
#
# Scraped 54 users this round
# Got 366 reivews
# 124406 reviews are now in the bag, so to speak
# 2024-04-04 04:15:31
#
# Scraped 56 users this round
# Got 359 reivews
# 124765 reviews are now in the bag, so to speak
# 2024-04-04 04:16:56
#
# Scraped 53 users this round
# Got 338 reivews
# 125103 reviews are now in the bag, so to speak
# 2024-04-04 04:18:16
#
# Scraped 55 users this round
# Got 333 reivews
# 125436 reviews are now in the bag, so to speak
# 2024-04-04 04:19:33
#
# Scraped 60 users this round
# Got 343 reivews
# 125779 reviews are now in the bag, so to speak
# 2024-04-04 04:21:08
#
# Scraped 56 users this round
# Got 357 reivews
# 126136 reviews are now in the bag, so to speak
# 2024-04-04 04:22:25
#
# Scraped 56 users this round
# Got 362 reivews
# 126498 reviews are now in the bag, so to speak
# 2024-04-04 04:23:45
#
# Scraped 53 users this round
# Got 386 reivews
# 126884 reviews are now in the bag, so to speak
# 2024-04-04 04:24:52
#
# Scraped 52 users this round
# Got 344 reivews
# 127228 reviews are now in the bag, so to speak
# 2024-04-04 04:26:03
#
# Scraped 55 users this round
# Got 348 reivews
# 127576 reviews are now in the bag, so to speak
# 2024-04-04 04:27:12
#
# Scraped 54 users this round
# Got 332 reivews
# 127908 reviews are now in the bag, so to speak
# 2024-04-04 04:28:28
#
# Scraped 54 users this round
# Got 348 reivews
# 128256 reviews are now in the bag, so to speak
# 2024-04-04 04:29:36
#
# Scraped 60 users this round
# Got 329 reivews
# 128585 reviews are now in the bag, so to speak
# 2024-04-04 04:30:54
#
# Scraped 59 users this round
# Got 329 reivews
# 128914 reviews are now in the bag, so to speak
# 2024-04-04 04:32:18
#
# Scraped 55 users this round
# Got 332 reivews
# 129246 reviews are now in the bag, so to speak
# 2024-04-04 04:33:35
#
# Scraped 55 users this round
# Got 306 reivews
# 129552 reviews are now in the bag, so to speak
# 2024-04-04 04:34:48
#
# Scraped 56 users this round
# Got 366 reivews
# 129918 reviews are now in the bag, so to speak
# 2024-04-04 04:35:55
#
# Scraped 58 users this round
# Got 324 reivews
# 130242 reviews are now in the bag, so to speak
# 2024-04-04 04:37:17
#
# Scraped 56 users this round
# Got 341 reivews
# 130583 reviews are now in the bag, so to speak
# 2024-04-04 04:38:35
#
# Scraped 55 users this round
# Got 330 reivews
# 130913 reviews are now in the bag, so to speak
# 2024-04-04 04:39:42
#
# Scraped 59 users this round
# Got 334 reivews
# 131247 reviews are now in the bag, so to speak
# 2024-04-04 04:41:01
#
# Scraped 57 users this round
# Got 349 reivews
# 131596 reviews are now in the bag, so to speak
# 2024-04-04 04:42:04
#
# Scraped 53 users this round
# Got 341 reivews
# 131937 reviews are now in the bag, so to speak
# 2024-04-04 04:43:08
#
# Scraped 56 users this round
# Got 359 reivews
# 132296 reviews are now in the bag, so to speak
# 2024-04-04 04:44:21
#
# Scraped 55 users this round
# Got 336 reivews
# 132632 reviews are now in the bag, so to speak
# 2024-04-04 04:45:28
#
# Scraped 52 users this round
# Got 323 reivews
# 132955 reviews are now in the bag, so to speak
# 2024-04-04 04:46:31
#
# Scraped 57 users this round
# Got 327 reivews
# 133282 reviews are now in the bag, so to speak
# 2024-04-04 04:47:33

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
