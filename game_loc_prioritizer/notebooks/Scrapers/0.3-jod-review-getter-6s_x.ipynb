# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 6
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 58 users this round
# Got 348 reivews
# 348 reviews are now in the bag, so to speak
# 2024-04-03 18:10:48
#
# Scraped 54 users this round
# Got 346 reivews
# 694 reviews are now in the bag, so to speak
# 2024-04-03 18:12:20
#
# Scraped 59 users this round
# Got 355 reivews
# 1049 reviews are now in the bag, so to speak
# 2024-04-03 18:14:00
#
# Scraped 55 users this round
# Got 338 reivews
# 1387 reviews are now in the bag, so to speak
# 2024-04-03 18:15:33
#
# Scraped 58 users this round
# Got 369 reivews
# 1756 reviews are now in the bag, so to speak
# 2024-04-03 18:17:09
#
# Scraped 56 users this round
# Got 374 reivews
# 2130 reviews are now in the bag, so to speak
# 2024-04-03 18:18:52
#
# Scraped 56 users this round
# Got 353 reivews
# 2483 reviews are now in the bag, so to speak
# 2024-04-03 18:20:27
#
# Scraped 57 users this round
# Got 366 reivews
# 2849 reviews are now in the bag, so to speak
# 2024-04-03 18:22:06
#
# Scraped 55 users this round
# Got 386 reivews
# 3235 reviews are now in the bag, so to speak
# 2024-04-03 18:23:58
#
# Scraped 56 users this round
# Got 314 reivews
# 3549 reviews are now in the bag, so to speak
# 2024-04-03 18:25:38
#
# Scraped 56 users this round
# Got 339 reivews
# 3888 reviews are now in the bag, so to speak
# 2024-04-03 18:27:10
#
# Scraped 56 users this round
# Got 355 reivews
# 4243 reviews are now in the bag, so to speak
# 2024-04-03 18:28:50
#
# Scraped 58 users this round
# Got 371 reivews
# 4614 reviews are now in the bag, so to speak
# 2024-04-03 18:30:32
#
# Scraped 55 users this round
# Got 328 reivews
# 4942 reviews are now in the bag, so to speak
# 2024-04-03 18:32:08
#
# Scraped 58 users this round
# Got 338 reivews
# 5280 reviews are now in the bag, so to speak
# 2024-04-03 18:33:53
#
# Scraped 58 users this round
# Got 339 reivews
# 5619 reviews are now in the bag, so to speak
# 2024-04-03 18:35:35
#
# Scraped 55 users this round
# Got 312 reivews
# 5931 reviews are now in the bag, so to speak
# 2024-04-03 18:37:02
#
# Scraped 57 users this round
# Got 354 reivews
# 6285 reviews are now in the bag, so to speak
# 2024-04-03 18:38:54
#
# Scraped 57 users this round
# Got 334 reivews
# 6619 reviews are now in the bag, so to speak
# 2024-04-03 18:40:30
#
# Scraped 57 users this round
# Got 342 reivews
# 6961 reviews are now in the bag, so to speak
# 2024-04-03 18:42:07
#
# Scraped 60 users this round
# Got 348 reivews
# 7309 reviews are now in the bag, so to speak
# 2024-04-03 18:44:12
#
# Scraped 55 users this round
# Got 370 reivews
# 7679 reviews are now in the bag, so to speak
# 2024-04-03 18:45:49
#
# Scraped 56 users this round
# Got 316 reivews
# 7995 reviews are now in the bag, so to speak
# 2024-04-03 18:47:22
#
# Scraped 54 users this round
# Got 308 reivews
# 8303 reviews are now in the bag, so to speak
# 2024-04-03 18:48:54
#
# Scraped 57 users this round
# Got 347 reivews
# 8650 reviews are now in the bag, so to speak
# 2024-04-03 18:50:34
#
# Scraped 52 users this round
# Got 368 reivews
# 9018 reviews are now in the bag, so to speak
# 2024-04-03 18:52:13
#
# Scraped 55 users this round
# Got 346 reivews
# 9364 reviews are now in the bag, so to speak
# 2024-04-03 18:53:48
#
# Scraped 58 users this round
# Got 366 reivews
# 9730 reviews are now in the bag, so to speak
# 2024-04-03 18:55:24
#
# Scraped 57 users this round
# Got 356 reivews
# 10086 reviews are now in the bag, so to speak
# 2024-04-03 18:57:05
#
# Scraped 56 users this round
# Got 307 reivews
# 10393 reviews are now in the bag, so to speak
# 2024-04-03 18:58:49
#
# Scraped 54 users this round
# Got 349 reivews
# 10742 reviews are now in the bag, so to speak
# 2024-04-03 19:00:23
#
# Scraped 54 users this round
# Got 324 reivews
# 11066 reviews are now in the bag, so to speak
# 2024-04-03 19:01:50
#
# Scraped 56 users this round
# Got 316 reivews
# 11382 reviews are now in the bag, so to speak
# 2024-04-03 19:03:31
#
# Scraped 57 users this round
# Got 305 reivews
# 11687 reviews are now in the bag, so to speak
# 2024-04-03 19:05:11
#
# Scraped 53 users this round
# Got 322 reivews
# 12009 reviews are now in the bag, so to speak
# 2024-04-03 19:06:38
#
# Scraped 56 users this round
# Got 312 reivews
# 12321 reviews are now in the bag, so to speak
# 2024-04-03 19:08:22
#
# Scraped 57 users this round
# Got 352 reivews
# 12673 reviews are now in the bag, so to speak
# 2024-04-03 19:10:00
#
# Scraped 58 users this round
# Got 356 reivews
# 13029 reviews are now in the bag, so to speak
# 2024-04-03 19:11:42
#
# Scraped 54 users this round
# Got 320 reivews
# 13349 reviews are now in the bag, so to speak
# 2024-04-03 19:13:15
#
# Scraped 58 users this round
# Got 360 reivews
# 13709 reviews are now in the bag, so to speak
# 2024-04-03 19:15:04
#
# Scraped 57 users this round
# Got 342 reivews
# 14051 reviews are now in the bag, so to speak
# 2024-04-03 19:16:45
#
# Scraped 55 users this round
# Got 344 reivews
# 14395 reviews are now in the bag, so to speak
# 2024-04-03 19:18:25
#
# Scraped 55 users this round
# Got 287 reivews
# 14682 reviews are now in the bag, so to speak
# 2024-04-03 19:19:56
#
# Scraped 56 users this round
# Got 369 reivews
# 15051 reviews are now in the bag, so to speak
# 2024-04-03 19:21:30
#
# Scraped 54 users this round
# Got 345 reivews
# 15396 reviews are now in the bag, so to speak
# 2024-04-03 19:23:01
#
# Scraped 52 users this round
# Got 302 reivews
# 15698 reviews are now in the bag, so to speak
# 2024-04-03 19:24:26
#
# Scraped 57 users this round
# Got 349 reivews
# 16047 reviews are now in the bag, so to speak
# 2024-04-03 19:25:59
#
# Scraped 60 users this round
# Got 293 reivews
# 16340 reviews are now in the bag, so to speak
# 2024-04-03 19:27:42
#
# Scraped 54 users this round
# Got 344 reivews
# 16684 reviews are now in the bag, so to speak
# 2024-04-03 19:29:15
#
# Scraped 59 users this round
# Got 364 reivews
# 17048 reviews are now in the bag, so to speak
# 2024-04-03 19:30:58
#
# Scraped 56 users this round
# Got 353 reivews
# 17401 reviews are now in the bag, so to speak
# 2024-04-03 19:32:29
#
# Scraped 58 users this round
# Got 292 reivews
# 17693 reviews are now in the bag, so to speak
# 2024-04-03 19:34:15
#
# Scraped 53 users this round
# Got 329 reivews
# 18022 reviews are now in the bag, so to speak
# 2024-04-03 19:35:48
#
# Scraped 59 users this round
# Got 343 reivews
# 18365 reviews are now in the bag, so to speak
# 2024-04-03 19:37:26
#
# Scraped 54 users this round
# Got 368 reivews
# 18733 reviews are now in the bag, so to speak
# 2024-04-03 19:39:12
#
# Scraped 55 users this round
# Got 345 reivews
# 19078 reviews are now in the bag, so to speak
# 2024-04-03 19:40:55
#
# Scraped 58 users this round
# Got 369 reivews
# 19447 reviews are now in the bag, so to speak
# 2024-04-03 19:42:28
#
# Scraped 56 users this round
# Got 337 reivews
# 19784 reviews are now in the bag, so to speak
# 2024-04-03 19:44:03
#
# Scraped 59 users this round
# Got 339 reivews
# 20123 reviews are now in the bag, so to speak
# 2024-04-03 19:45:49
#
# Scraped 55 users this round
# Got 358 reivews
# 20481 reviews are now in the bag, so to speak
# 2024-04-03 19:47:25
#
# Scraped 53 users this round
# Got 365 reivews
# 20846 reviews are now in the bag, so to speak
# 2024-04-03 19:49:03
#
# Scraped 61 users this round
# Got 323 reivews
# 21169 reviews are now in the bag, so to speak
# 2024-04-03 19:50:44
#
# Scraped 60 users this round
# Got 302 reivews
# 21471 reviews are now in the bag, so to speak
# 2024-04-03 19:52:34
#
# Scraped 58 users this round
# Got 322 reivews
# 21793 reviews are now in the bag, so to speak
# 2024-04-03 19:54:20
#
# Scraped 56 users this round
# Got 321 reivews
# 22114 reviews are now in the bag, so to speak
# 2024-04-03 19:56:00
#
# Scraped 58 users this round
# Got 347 reivews
# 22461 reviews are now in the bag, so to speak
# 2024-04-03 19:57:39
#
# Scraped 56 users this round
# Got 357 reivews
# 22818 reviews are now in the bag, so to speak
# 2024-04-03 19:59:31
#
# Scraped 57 users this round
# Got 290 reivews
# 23108 reviews are now in the bag, so to speak
# 2024-04-03 20:01:08
#
# Scraped 54 users this round
# Got 357 reivews
# 23465 reviews are now in the bag, so to speak
# 2024-04-03 20:02:48
#
# Scraped 60 users this round
# Got 296 reivews
# 23761 reviews are now in the bag, so to speak
# 2024-04-03 20:04:23
#
# Scraped 55 users this round
# Got 364 reivews
# 24125 reviews are now in the bag, so to speak
# 2024-04-03 20:06:01
#
# Scraped 57 users this round
# Got 354 reivews
# 24479 reviews are now in the bag, so to speak
# 2024-04-03 20:07:39
#
# Scraped 54 users this round
# Got 341 reivews
# 24820 reviews are now in the bag, so to speak
# 2024-04-03 20:09:28
#
# Scraped 52 users this round
# Got 348 reivews
# 25168 reviews are now in the bag, so to speak
# 2024-04-03 20:11:06
#
# Scraped 55 users this round
# Got 369 reivews
# 25537 reviews are now in the bag, so to speak
# 2024-04-03 20:12:43
#
# Scraped 58 users this round
# Got 349 reivews
# 25886 reviews are now in the bag, so to speak
# 2024-04-03 20:14:27
#
# Scraped 58 users this round
# Got 371 reivews
# 26257 reviews are now in the bag, so to speak
# 2024-04-03 20:16:11
#
# Scraped 57 users this round
# Got 319 reivews
# 26576 reviews are now in the bag, so to speak
# 2024-04-03 20:17:50
#
# Scraped 55 users this round
# Got 314 reivews
# 26890 reviews are now in the bag, so to speak
# 2024-04-03 20:19:33
#
# Scraped 55 users this round
# Got 303 reivews
# 27193 reviews are now in the bag, so to speak
# 2024-04-03 20:21:10
#
# Scraped 59 users this round
# Got 340 reivews
# 27533 reviews are now in the bag, so to speak
# 2024-04-03 20:22:53
#
# Scraped 56 users this round
# Got 382 reivews
# 27915 reviews are now in the bag, so to speak
# 2024-04-03 20:24:32
#
# Scraped 56 users this round
# Got 349 reivews
# 28264 reviews are now in the bag, so to speak
# 2024-04-03 20:26:01
#
# Scraped 55 users this round
# Got 334 reivews
# 28598 reviews are now in the bag, so to speak
# 2024-04-03 20:27:29
#
# Scraped 56 users this round
# Got 356 reivews
# 28954 reviews are now in the bag, so to speak
# 2024-04-03 20:29:01
#
# Scraped 61 users this round
# Got 296 reivews
# 29250 reviews are now in the bag, so to speak
# 2024-04-03 20:30:44
#
# Scraped 56 users this round
# Got 378 reivews
# 29628 reviews are now in the bag, so to speak
# 2024-04-03 20:32:20
#
# Scraped 51 users this round
# Got 367 reivews
# 29995 reviews are now in the bag, so to speak
# 2024-04-03 20:33:51
#
# Scraped 53 users this round
# Got 310 reivews
# 30305 reviews are now in the bag, so to speak
# 2024-04-03 20:35:24
#
# Scraped 56 users this round
# Got 324 reivews
# 30629 reviews are now in the bag, so to speak
# 2024-04-03 20:37:00
#
# Scraped 52 users this round
# Got 338 reivews
# 30967 reviews are now in the bag, so to speak
# 2024-04-03 20:38:23
#
# Scraped 53 users this round
# Got 328 reivews
# 31295 reviews are now in the bag, so to speak
# 2024-04-03 20:39:50
#
# Scraped 57 users this round
# Got 330 reivews
# 31625 reviews are now in the bag, so to speak
# 2024-04-03 20:41:22
#
# Scraped 58 users this round
# Got 357 reivews
# 31982 reviews are now in the bag, so to speak
# 2024-04-03 20:42:52
#
# Scraped 57 users this round
# Got 298 reivews
# 32280 reviews are now in the bag, so to speak
# 2024-04-03 20:44:23
#
# Scraped 57 users this round
# Got 407 reivews
# 32687 reviews are now in the bag, so to speak
# 2024-04-03 20:46:03
#
# Scraped 58 users this round
# Got 341 reivews
# 33028 reviews are now in the bag, so to speak
# 2024-04-03 20:47:44
#
# Scraped 54 users this round
# Got 316 reivews
# 33344 reviews are now in the bag, so to speak
# 2024-04-03 20:49:10
#
# Scraped 56 users this round
# Got 359 reivews
# 33703 reviews are now in the bag, so to speak
# 2024-04-03 20:50:45
#
# Scraped 52 users this round
# Got 365 reivews
# 34068 reviews are now in the bag, so to speak
# 2024-04-03 20:52:18
#
# Scraped 54 users this round
# Got 352 reivews
# 34420 reviews are now in the bag, so to speak
# 2024-04-03 20:53:55
#
# Scraped 53 users this round
# Got 294 reivews
# 34714 reviews are now in the bag, so to speak
# 2024-04-03 20:55:38
#
# Scraped 58 users this round
# Got 343 reivews
# 35057 reviews are now in the bag, so to speak
# 2024-04-03 20:57:23
#
# Scraped 56 users this round
# Got 365 reivews
# 35422 reviews are now in the bag, so to speak
# 2024-04-03 20:59:04
#
# Scraped 60 users this round
# Got 320 reivews
# 35742 reviews are now in the bag, so to speak
# 2024-04-03 21:00:51
#
# Scraped 57 users this round
# Got 358 reivews
# 36100 reviews are now in the bag, so to speak
# 2024-04-03 21:02:38
#
# Scraped 55 users this round
# Got 343 reivews
# 36443 reviews are now in the bag, so to speak
# 2024-04-03 21:04:17
#
# Scraped 59 users this round
# Got 357 reivews
# 36800 reviews are now in the bag, so to speak
# 2024-04-03 21:05:56
#
# Scraped 58 users this round
# Got 329 reivews
# 37129 reviews are now in the bag, so to speak
# 2024-04-03 21:07:42
#
# Scraped 60 users this round
# Got 331 reivews
# 37460 reviews are now in the bag, so to speak
# 2024-04-03 21:09:28
#
# Scraped 54 users this round
# Got 365 reivews
# 37825 reviews are now in the bag, so to speak
# 2024-04-03 21:11:14
#
# Scraped 57 users this round
# Got 361 reivews
# 38186 reviews are now in the bag, so to speak
# 2024-04-03 21:12:48
#
# Scraped 57 users this round
# Got 329 reivews
# 38515 reviews are now in the bag, so to speak
# 2024-04-03 21:14:33
#
# Scraped 57 users this round
# Got 361 reivews
# 38876 reviews are now in the bag, so to speak
# 2024-04-03 21:16:13
#
# Scraped 54 users this round
# Got 331 reivews
# 39207 reviews are now in the bag, so to speak
# 2024-04-03 21:17:49
#
# Scraped 57 users this round
# Got 344 reivews
# 39551 reviews are now in the bag, so to speak
# 2024-04-03 21:19:30
#
# Scraped 51 users this round
# Got 361 reivews
# 39912 reviews are now in the bag, so to speak
# 2024-04-03 21:20:59
#
# Scraped 55 users this round
# Got 356 reivews
# 40268 reviews are now in the bag, so to speak
# 2024-04-03 21:22:39
#
# Scraped 57 users this round
# Got 357 reivews
# 40625 reviews are now in the bag, so to speak
# 2024-04-03 21:24:26
#
# Scraped 54 users this round
# Got 334 reivews
# 40959 reviews are now in the bag, so to speak
# 2024-04-03 21:25:58
#
# Scraped 56 users this round
# Got 347 reivews
# 41306 reviews are now in the bag, so to speak
# 2024-04-03 21:27:31
#
# Scraped 60 users this round
# Got 336 reivews
# 41642 reviews are now in the bag, so to speak
# 2024-04-03 21:29:20
#
# Scraped 56 users this round
# Got 335 reivews
# 41977 reviews are now in the bag, so to speak
# 2024-04-03 21:30:52
#
# Scraped 58 users this round
# Got 384 reivews
# 42361 reviews are now in the bag, so to speak
# 2024-04-03 21:32:31
#
# Scraped 54 users this round
# Got 323 reivews
# 42684 reviews are now in the bag, so to speak
# 2024-04-03 21:34:04
#
# Scraped 56 users this round
# Got 362 reivews
# 43046 reviews are now in the bag, so to speak
# 2024-04-03 21:35:39
#
# Scraped 58 users this round
# Got 330 reivews
# 43376 reviews are now in the bag, so to speak
# 2024-04-03 21:37:20
#
# Scraped 57 users this round
# Got 349 reivews
# 43725 reviews are now in the bag, so to speak
# 2024-04-03 21:38:54
#
# Scraped 56 users this round
# Got 328 reivews
# 44053 reviews are now in the bag, so to speak
# 2024-04-03 21:40:28
#
# Scraped 57 users this round
# Got 303 reivews
# 44356 reviews are now in the bag, so to speak
# 2024-04-03 21:42:08
#
# Scraped 60 users this round
# Got 378 reivews
# 44734 reviews are now in the bag, so to speak
# 2024-04-03 21:43:51
#
# Scraped 54 users this round
# Got 321 reivews
# 45055 reviews are now in the bag, so to speak
# 2024-04-03 21:45:18
#
# Scraped 56 users this round
# Got 349 reivews
# 45404 reviews are now in the bag, so to speak
# 2024-04-03 21:47:00
#
# Scraped 58 users this round
# Got 344 reivews
# 45748 reviews are now in the bag, so to speak
# 2024-04-03 21:48:33
#
# Scraped 56 users this round
# Got 303 reivews
# 46051 reviews are now in the bag, so to speak
# 2024-04-03 21:50:05
#
# Scraped 59 users this round
# Got 346 reivews
# 46397 reviews are now in the bag, so to speak
# 2024-04-03 21:51:49
#
# Scraped 57 users this round
# Got 305 reivews
# 46702 reviews are now in the bag, so to speak
# 2024-04-03 21:53:27
#
# Scraped 52 users this round
# Got 350 reivews
# 47052 reviews are now in the bag, so to speak
# 2024-04-03 21:54:55
#
# Scraped 52 users this round
# Got 340 reivews
# 47392 reviews are now in the bag, so to speak
# 2024-04-03 21:56:15
#
# Scraped 53 users this round
# Got 334 reivews
# 47726 reviews are now in the bag, so to speak
# 2024-04-03 21:57:36
#
# Scraped 55 users this round
# Got 320 reivews
# 48046 reviews are now in the bag, so to speak
# 2024-04-03 21:59:01
#
# Scraped 56 users this round
# Got 364 reivews
# 48410 reviews are now in the bag, so to speak
# 2024-04-03 22:00:38
#
# Scraped 58 users this round
# Got 374 reivews
# 48784 reviews are now in the bag, so to speak
# 2024-04-03 22:02:22
#
# Scraped 56 users this round
# Got 340 reivews
# 49124 reviews are now in the bag, so to speak
# 2024-04-03 22:03:57
#
# Scraped 55 users this round
# Got 359 reivews
# 49483 reviews are now in the bag, so to speak
# 2024-04-03 22:05:36
#
# Scraped 57 users this round
# Got 332 reivews
# 49815 reviews are now in the bag, so to speak
# 2024-04-03 22:07:07
#
# Scraped 54 users this round
# Got 364 reivews
# 50179 reviews are now in the bag, so to speak
# 2024-04-03 22:08:41
#
# Scraped 55 users this round
# Got 369 reivews
# 50548 reviews are now in the bag, so to speak
# 2024-04-03 22:10:10
#
# Scraped 60 users this round
# Got 364 reivews
# 50912 reviews are now in the bag, so to speak
# 2024-04-03 22:11:59
#
# Scraped 58 users this round
# Got 335 reivews
# 51247 reviews are now in the bag, so to speak
# 2024-04-03 22:13:36
#
# Scraped 54 users this round
# Got 353 reivews
# 51600 reviews are now in the bag, so to speak
# 2024-04-03 22:15:10
#
# Scraped 56 users this round
# Got 344 reivews
# 51944 reviews are now in the bag, so to speak
# 2024-04-03 22:16:48
#
# Scraped 60 users this round
# Got 376 reivews
# 52320 reviews are now in the bag, so to speak
# 2024-04-03 22:18:42
#
# Scraped 56 users this round
# Got 376 reivews
# 52696 reviews are now in the bag, so to speak
# 2024-04-03 22:20:22
#
# Scraped 60 users this round
# Got 360 reivews
# 53056 reviews are now in the bag, so to speak
# 2024-04-03 22:22:04
#
# Scraped 55 users this round
# Got 382 reivews
# 53438 reviews are now in the bag, so to speak
# 2024-04-03 22:24:01
#
# Scraped 61 users this round
# Got 392 reivews
# 53830 reviews are now in the bag, so to speak
# 2024-04-03 22:26:33
#
# Scraped 60 users this round
# Got 330 reivews
# 54160 reviews are now in the bag, so to speak
# 2024-04-03 22:29:39
#
# Scraped 56 users this round
# Got 298 reivews
# 54458 reviews are now in the bag, so to speak
# 2024-04-03 22:32:43
#
# Scraped 58 users this round
# Got 331 reivews
# 54789 reviews are now in the bag, so to speak
# 2024-04-03 22:35:46
#
# Scraped 56 users this round
# Got 353 reivews
# 55142 reviews are now in the bag, so to speak
# 2024-04-03 22:38:36
#
# Scraped 54 users this round
# Got 292 reivews
# 55434 reviews are now in the bag, so to speak
# 2024-04-03 22:41:27
#
# Scraped 58 users this round
# Got 336 reivews
# 55770 reviews are now in the bag, so to speak
# 2024-04-03 22:44:50
#
# Scraped 57 users this round
# Got 377 reivews
# 56147 reviews are now in the bag, so to speak
# 2024-04-03 22:47:48
#
# Scraped 55 users this round
# Got 341 reivews
# 56488 reviews are now in the bag, so to speak
# 2024-04-03 22:50:34
#
# Scraped 57 users this round
# Got 376 reivews
# 56864 reviews are now in the bag, so to speak
# 2024-04-03 22:53:58
#
# Scraped 59 users this round
# Got 338 reivews
# 57202 reviews are now in the bag, so to speak
# 2024-04-03 22:57:07
#
# Scraped 55 users this round
# Got 385 reivews
# 57587 reviews are now in the bag, so to speak
# 2024-04-03 23:00:21
#
# Scraped 62 users this round
# Got 349 reivews
# 57936 reviews are now in the bag, so to speak
# 2024-04-03 23:03:18
#
# Scraped 58 users this round
# Got 326 reivews
# 58262 reviews are now in the bag, so to speak
# 2024-04-03 23:06:19
#
# Scraped 53 users this round
# Got 318 reivews
# 58580 reviews are now in the bag, so to speak
# 2024-04-03 23:09:18
#
# Scraped 55 users this round
# Got 308 reivews
# 58888 reviews are now in the bag, so to speak
# 2024-04-03 23:12:01
#
# Scraped 51 users this round
# Got 330 reivews
# 59218 reviews are now in the bag, so to speak
# 2024-04-03 23:14:29
#
# Scraped 58 users this round
# Got 367 reivews
# 59585 reviews are now in the bag, so to speak
# 2024-04-03 23:16:26
#
# Scraped 55 users this round
# Got 276 reivews
# 59861 reviews are now in the bag, so to speak
# 2024-04-03 23:18:08
#
# Scraped 57 users this round
# Got 314 reivews
# 60175 reviews are now in the bag, so to speak
# 2024-04-03 23:19:37
#
# Scraped 54 users this round
# Got 330 reivews
# 60505 reviews are now in the bag, so to speak
# 2024-04-03 23:21:18
#
# Scraped 56 users this round
# Got 348 reivews
# 60853 reviews are now in the bag, so to speak
# 2024-04-03 23:22:55
#
# Scraped 62 users this round
# Got 343 reivews
# 61196 reviews are now in the bag, so to speak
# 2024-04-03 23:24:44
#
# Scraped 56 users this round
# Got 336 reivews
# 61532 reviews are now in the bag, so to speak
# 2024-04-03 23:26:20
#
# Scraped 56 users this round
# Got 425 reivews
# 61957 reviews are now in the bag, so to speak
# 2024-04-03 23:28:02
#
# Scraped 60 users this round
# Got 321 reivews
# 62278 reviews are now in the bag, so to speak
# 2024-04-03 23:29:56
#
# Scraped 56 users this round
# Got 329 reivews
# 62607 reviews are now in the bag, so to speak
# 2024-04-03 23:31:28
#
# Scraped 57 users this round
# Got 359 reivews
# 62966 reviews are now in the bag, so to speak
# 2024-04-03 23:33:03
#
# Scraped 60 users this round
# Got 344 reivews
# 63310 reviews are now in the bag, so to speak
# 2024-04-03 23:34:39
#
# Scraped 60 users this round
# Got 336 reivews
# 63646 reviews are now in the bag, so to speak
# 2024-04-03 23:36:25
#
# Scraped 54 users this round
# Got 354 reivews
# 64000 reviews are now in the bag, so to speak
# 2024-04-03 23:37:52
#
# Scraped 56 users this round
# Got 356 reivews
# 64356 reviews are now in the bag, so to speak
# 2024-04-03 23:39:28
#
# Scraped 56 users this round
# Got 354 reivews
# 64710 reviews are now in the bag, so to speak
# 2024-04-03 23:41:05
#
# Scraped 54 users this round
# Got 340 reivews
# 65050 reviews are now in the bag, so to speak
# 2024-04-03 23:42:35
#
# Scraped 58 users this round
# Got 345 reivews
# 65395 reviews are now in the bag, so to speak
# 2024-04-03 23:44:14
#
# Scraped 53 users this round
# Got 263 reivews
# 65658 reviews are now in the bag, so to speak
# 2024-04-03 23:45:45
#
# Scraped 53 users this round
# Got 373 reivews
# 66031 reviews are now in the bag, so to speak
# 2024-04-03 23:47:12
#
# Scraped 58 users this round
# Got 332 reivews
# 66363 reviews are now in the bag, so to speak
# 2024-04-03 23:48:51
#
# Scraped 53 users this round
# Got 355 reivews
# 66718 reviews are now in the bag, so to speak
# 2024-04-03 23:50:22
#
# Scraped 58 users this round
# Got 311 reivews
# 67029 reviews are now in the bag, so to speak
# 2024-04-03 23:52:00
#
# Scraped 55 users this round
# Got 352 reivews
# 67381 reviews are now in the bag, so to speak
# 2024-04-03 23:53:37
#
# Scraped 55 users this round
# Got 364 reivews
# 67745 reviews are now in the bag, so to speak
# 2024-04-03 23:55:11
#
# Scraped 55 users this round
# Got 352 reivews
# 68097 reviews are now in the bag, so to speak
# 2024-04-03 23:56:43
#
# Scraped 57 users this round
# Got 335 reivews
# 68432 reviews are now in the bag, so to speak
# 2024-04-03 23:58:16
#
# Scraped 54 users this round
# Got 327 reivews
# 68759 reviews are now in the bag, so to speak
# 2024-04-03 23:59:42
#
# Scraped 54 users this round
# Got 340 reivews
# 69099 reviews are now in the bag, so to speak
# 2024-04-04 00:01:14
#
# Scraped 62 users this round
# Got 356 reivews
# 69455 reviews are now in the bag, so to speak
# 2024-04-04 00:03:08
#
# Scraped 53 users this round
# Got 352 reivews
# 69807 reviews are now in the bag, so to speak
# 2024-04-04 00:04:42
#
# Scraped 59 users this round
# Got 371 reivews
# 70178 reviews are now in the bag, so to speak
# 2024-04-04 00:06:28
#
# Scraped 52 users this round
# Got 360 reivews
# 70538 reviews are now in the bag, so to speak
# 2024-04-04 00:07:58
#
# Scraped 59 users this round
# Got 322 reivews
# 70860 reviews are now in the bag, so to speak
# 2024-04-04 00:09:42
#
# Scraped 54 users this round
# Got 380 reivews
# 71240 reviews are now in the bag, so to speak
# 2024-04-04 00:11:26
#
# Scraped 59 users this round
# Got 340 reivews
# 71580 reviews are now in the bag, so to speak
# 2024-04-04 00:13:08
#
# Scraped 53 users this round
# Got 369 reivews
# 71949 reviews are now in the bag, so to speak
# 2024-04-04 00:14:34
#
# Scraped 55 users this round
# Got 381 reivews
# 72330 reviews are now in the bag, so to speak
# 2024-04-04 00:16:09
#
# Scraped 53 users this round
# Got 319 reivews
# 72649 reviews are now in the bag, so to speak
# 2024-04-04 00:17:37
#
# Scraped 54 users this round
# Got 331 reivews
# 72980 reviews are now in the bag, so to speak
# 2024-04-04 00:19:08
#
# Scraped 60 users this round
# Got 326 reivews
# 73306 reviews are now in the bag, so to speak
# 2024-04-04 00:20:52
#
# Scraped 56 users this round
# Got 326 reivews
# 73632 reviews are now in the bag, so to speak
# 2024-04-04 00:22:22
#
# Scraped 56 users this round
# Got 345 reivews
# 73977 reviews are now in the bag, so to speak
# 2024-04-04 00:24:08
#
# Scraped 54 users this round
# Got 330 reivews
# 74307 reviews are now in the bag, so to speak
# 2024-04-04 00:25:35
#
# Scraped 55 users this round
# Got 355 reivews
# 74662 reviews are now in the bag, so to speak
# 2024-04-04 00:27:24
#
# Scraped 59 users this round
# Got 336 reivews
# 74998 reviews are now in the bag, so to speak
# 2024-04-04 00:29:10
#
# Scraped 54 users this round
# Got 351 reivews
# 75349 reviews are now in the bag, so to speak
# 2024-04-04 00:30:32
#
# Scraped 52 users this round
# Got 329 reivews
# 75678 reviews are now in the bag, so to speak
# 2024-04-04 00:32:00
#
# Scraped 56 users this round
# Got 315 reivews
# 75993 reviews are now in the bag, so to speak
# 2024-04-04 00:33:46
#
# Scraped 51 users this round
# Got 298 reivews
# 76291 reviews are now in the bag, so to speak
# 2024-04-04 00:35:12
#
# Scraped 56 users this round
# Got 339 reivews
# 76630 reviews are now in the bag, so to speak
# 2024-04-04 00:36:46
#
# Scraped 57 users this round
# Got 335 reivews
# 76965 reviews are now in the bag, so to speak
# 2024-04-04 00:38:16
#
# Scraped 55 users this round
# Got 342 reivews
# 77307 reviews are now in the bag, so to speak
# 2024-04-04 00:39:52
#
# Scraped 52 users this round
# Got 331 reivews
# 77638 reviews are now in the bag, so to speak
# 2024-04-04 00:41:13
#
# Scraped 54 users this round
# Got 327 reivews
# 77965 reviews are now in the bag, so to speak
# 2024-04-04 00:42:46
#
# Scraped 54 users this round
# Got 386 reivews
# 78351 reviews are now in the bag, so to speak
# 2024-04-04 00:44:13
#
# Scraped 60 users this round
# Got 359 reivews
# 78710 reviews are now in the bag, so to speak
# 2024-04-04 00:46:00
#
# Scraped 55 users this round
# Got 338 reivews
# 79048 reviews are now in the bag, so to speak
# 2024-04-04 00:47:34
#
# Scraped 54 users this round
# Got 340 reivews
# 79388 reviews are now in the bag, so to speak
# 2024-04-04 00:49:05
#
# Scraped 54 users this round
# Got 330 reivews
# 79718 reviews are now in the bag, so to speak
# 2024-04-04 00:50:49
#
# Scraped 55 users this round
# Got 336 reivews
# 80054 reviews are now in the bag, so to speak
# 2024-04-04 00:52:25
#
# Scraped 57 users this round
# Got 321 reivews
# 80375 reviews are now in the bag, so to speak
# 2024-04-04 00:53:53
#
# Scraped 54 users this round
# Got 345 reivews
# 80720 reviews are now in the bag, so to speak
# 2024-04-04 00:55:23
#
# Scraped 54 users this round
# Got 346 reivews
# 81066 reviews are now in the bag, so to speak
# 2024-04-04 00:56:59
#
# Scraped 54 users this round
# Got 277 reivews
# 81343 reviews are now in the bag, so to speak
# 2024-04-04 00:58:31
#
# Scraped 52 users this round
# Got 380 reivews
# 81723 reviews are now in the bag, so to speak
# 2024-04-04 00:59:54
#
# Scraped 61 users this round
# Got 350 reivews
# 82073 reviews are now in the bag, so to speak
# 2024-04-04 01:01:36
#
# Scraped 54 users this round
# Got 324 reivews
# 82397 reviews are now in the bag, so to speak
# 2024-04-04 01:03:10
#
# Scraped 56 users this round
# Got 361 reivews
# 82758 reviews are now in the bag, so to speak
# 2024-04-04 01:04:46
#
# Scraped 62 users this round
# Got 321 reivews
# 83079 reviews are now in the bag, so to speak
# 2024-04-04 01:06:26
#
# Scraped 55 users this round
# Got 318 reivews
# 83397 reviews are now in the bag, so to speak
# 2024-04-04 01:07:51
#
# Scraped 60 users this round
# Got 295 reivews
# 83692 reviews are now in the bag, so to speak
# 2024-04-04 01:09:28
#
# Scraped 56 users this round
# Got 319 reivews
# 84011 reviews are now in the bag, so to speak
# 2024-04-04 01:11:09
#
# Scraped 57 users this round
# Got 354 reivews
# 84365 reviews are now in the bag, so to speak
# 2024-04-04 01:12:45
#
# Scraped 58 users this round
# Got 359 reivews
# 84724 reviews are now in the bag, so to speak
# 2024-04-04 01:14:24
#
# Scraped 56 users this round
# Got 347 reivews
# 85071 reviews are now in the bag, so to speak
# 2024-04-04 01:15:53
#
# Scraped 55 users this round
# Got 370 reivews
# 85441 reviews are now in the bag, so to speak
# 2024-04-04 01:17:21
#
# Scraped 53 users this round
# Got 347 reivews
# 85788 reviews are now in the bag, so to speak
# 2024-04-04 01:18:51
#
# Scraped 55 users this round
# Got 386 reivews
# 86174 reviews are now in the bag, so to speak
# 2024-04-04 01:20:35
#
# Scraped 58 users this round
# Got 352 reivews
# 86526 reviews are now in the bag, so to speak
# 2024-04-04 01:22:10
#
# Scraped 61 users this round
# Got 344 reivews
# 86870 reviews are now in the bag, so to speak
# 2024-04-04 01:23:53
#
# Scraped 65 users this round
# Got 337 reivews
# 87207 reviews are now in the bag, so to speak
# 2024-04-04 01:25:45
#
# Scraped 55 users this round
# Got 334 reivews
# 87541 reviews are now in the bag, so to speak
# 2024-04-04 01:27:17
#
# Scraped 58 users this round
# Got 354 reivews
# 87895 reviews are now in the bag, so to speak
# 2024-04-04 01:28:57
#
# Scraped 56 users this round
# Got 361 reivews
# 88256 reviews are now in the bag, so to speak
# 2024-04-04 01:30:39
#
# Scraped 55 users this round
# Got 353 reivews
# 88609 reviews are now in the bag, so to speak
# 2024-04-04 01:32:28
#
# Scraped 54 users this round
# Got 357 reivews
# 88966 reviews are now in the bag, so to speak
# 2024-04-04 01:33:58
#
# Scraped 53 users this round
# Got 350 reivews
# 89316 reviews are now in the bag, so to speak
# 2024-04-04 01:35:30
#
# Scraped 59 users this round
# Got 304 reivews
# 89620 reviews are now in the bag, so to speak
# 2024-04-04 01:37:13
#
# Scraped 58 users this round
# Got 342 reivews
# 89962 reviews are now in the bag, so to speak
# 2024-04-04 01:38:48
#
# Scraped 58 users this round
# Got 334 reivews
# 90296 reviews are now in the bag, so to speak
# 2024-04-04 01:40:29
#
# Scraped 53 users this round
# Got 314 reivews
# 90610 reviews are now in the bag, so to speak
# 2024-04-04 01:42:01
#
# Scraped 56 users this round
# Got 301 reivews
# 90911 reviews are now in the bag, so to speak
# 2024-04-04 01:43:30
#
# Scraped 58 users this round
# Got 332 reivews
# 91243 reviews are now in the bag, so to speak
# 2024-04-04 01:45:27
#
# Scraped 61 users this round
# Got 301 reivews
# 91544 reviews are now in the bag, so to speak
# 2024-04-04 01:47:22
#
# Scraped 53 users this round
# Got 298 reivews
# 91842 reviews are now in the bag, so to speak
# 2024-04-04 01:48:47
#
# Scraped 53 users this round
# Got 352 reivews
# 92194 reviews are now in the bag, so to speak
# 2024-04-04 01:50:36
#
# Scraped 59 users this round
# Got 361 reivews
# 92555 reviews are now in the bag, so to speak
# 2024-04-04 01:52:14
#
# Scraped 53 users this round
# Got 322 reivews
# 92877 reviews are now in the bag, so to speak
# 2024-04-04 01:53:43
#
# Scraped 55 users this round
# Got 309 reivews
# 93186 reviews are now in the bag, so to speak
# 2024-04-04 01:55:14
#
# Scraped 56 users this round
# Got 350 reivews
# 93536 reviews are now in the bag, so to speak
# 2024-04-04 01:56:55
#
# Scraped 55 users this round
# Got 351 reivews
# 93887 reviews are now in the bag, so to speak
# 2024-04-04 01:58:26
#
# Scraped 56 users this round
# Got 373 reivews
# 94260 reviews are now in the bag, so to speak
# 2024-04-04 01:59:55
#
# Scraped 53 users this round
# Got 349 reivews
# 94609 reviews are now in the bag, so to speak
# 2024-04-04 02:01:28
#
# Scraped 52 users this round
# Got 370 reivews
# 94979 reviews are now in the bag, so to speak
# 2024-04-04 02:02:53
#
# Scraped 55 users this round
# Got 350 reivews
# 95329 reviews are now in the bag, so to speak
# 2024-04-04 02:04:32
#
# Scraped 55 users this round
# Got 330 reivews
# 95659 reviews are now in the bag, so to speak
# 2024-04-04 02:05:59
#
# Scraped 53 users this round
# Got 281 reivews
# 95940 reviews are now in the bag, so to speak
# 2024-04-04 02:07:25
#
# Scraped 60 users this round
# Got 364 reivews
# 96304 reviews are now in the bag, so to speak
# 2024-04-04 02:09:09
#
# Scraped 62 users this round
# Got 314 reivews
# 96618 reviews are now in the bag, so to speak
# 2024-04-04 02:10:58
#
# Scraped 54 users this round
# Got 328 reivews
# 96946 reviews are now in the bag, so to speak
# 2024-04-04 02:12:27
#
# Scraped 53 users this round
# Got 350 reivews
# 97296 reviews are now in the bag, so to speak
# 2024-04-04 02:13:56
#
# Scraped 55 users this round
# Got 398 reivews
# 97694 reviews are now in the bag, so to speak
# 2024-04-04 02:15:29
#
# Scraped 56 users this round
# Got 350 reivews
# 98044 reviews are now in the bag, so to speak
# 2024-04-04 02:16:57
#
# Scraped 54 users this round
# Got 328 reivews
# 98372 reviews are now in the bag, so to speak
# 2024-04-04 02:18:25
#
# Scraped 58 users this round
# Got 356 reivews
# 98728 reviews are now in the bag, so to speak
# 2024-04-04 02:20:10
#
# Scraped 52 users this round
# Got 333 reivews
# 99061 reviews are now in the bag, so to speak
# 2024-04-04 02:21:34
#
# Scraped 54 users this round
# Got 382 reivews
# 99443 reviews are now in the bag, so to speak
# 2024-04-04 02:23:29
#
# Scraped 60 users this round
# Got 355 reivews
# 99798 reviews are now in the bag, so to speak
# 2024-04-04 02:25:16
#
# Scraped 60 users this round
# Got 320 reivews
# 100118 reviews are now in the bag, so to speak
# 2024-04-04 02:26:53
#
# Scraped 57 users this round
# Got 350 reivews
# 100468 reviews are now in the bag, so to speak
# 2024-04-04 02:28:34
#
# Scraped 57 users this round
# Got 328 reivews
# 100796 reviews are now in the bag, so to speak
# 2024-04-04 02:30:09
#
# Scraped 53 users this round
# Got 372 reivews
# 101168 reviews are now in the bag, so to speak
# 2024-04-04 02:31:36
#
# Scraped 62 users this round
# Got 376 reivews
# 101544 reviews are now in the bag, so to speak
# 2024-04-04 02:33:16
#
# Scraped 64 users this round
# Got 382 reivews
# 101926 reviews are now in the bag, so to speak
# 2024-04-04 02:35:15
#
# Scraped 56 users this round
# Got 352 reivews
# 102278 reviews are now in the bag, so to speak
# 2024-04-04 02:36:46
#
# Scraped 55 users this round
# Got 330 reivews
# 102608 reviews are now in the bag, so to speak
# 2024-04-04 02:38:17
#
# Scraped 51 users this round
# Got 327 reivews
# 102935 reviews are now in the bag, so to speak
# 2024-04-04 02:39:45
#
# Scraped 56 users this round
# Got 322 reivews
# 103257 reviews are now in the bag, so to speak
# 2024-04-04 02:41:20
#
# Scraped 54 users this round
# Got 309 reivews
# 103566 reviews are now in the bag, so to speak
# 2024-04-04 02:42:51
#
# Scraped 56 users this round
# Got 326 reivews
# 103892 reviews are now in the bag, so to speak
# 2024-04-04 02:44:33
#
# Scraped 61 users this round
# Got 358 reivews
# 104250 reviews are now in the bag, so to speak
# 2024-04-04 02:46:13
#
# Scraped 54 users this round
# Got 358 reivews
# 104608 reviews are now in the bag, so to speak
# 2024-04-04 02:47:40
#
# Scraped 56 users this round
# Got 364 reivews
# 104972 reviews are now in the bag, so to speak
# 2024-04-04 02:49:14
#
# Scraped 57 users this round
# Got 394 reivews
# 105366 reviews are now in the bag, so to speak
# 2024-04-04 02:50:53
#
# Scraped 56 users this round
# Got 304 reivews
# 105670 reviews are now in the bag, so to speak
# 2024-04-04 02:52:23
#
# Scraped 54 users this round
# Got 320 reivews
# 105990 reviews are now in the bag, so to speak
# 2024-04-04 02:54:00
#
# Scraped 60 users this round
# Got 353 reivews
# 106343 reviews are now in the bag, so to speak
# 2024-04-04 02:55:36
#
# Scraped 52 users this round
# Got 352 reivews
# 106695 reviews are now in the bag, so to speak
# 2024-04-04 02:56:57
#
# Scraped 55 users this round
# Got 336 reivews
# 107031 reviews are now in the bag, so to speak
# 2024-04-04 02:58:27
#
# Scraped 52 users this round
# Got 385 reivews
# 107416 reviews are now in the bag, so to speak
# 2024-04-04 02:59:52
#
# Scraped 54 users this round
# Got 374 reivews
# 107790 reviews are now in the bag, so to speak
# 2024-04-04 03:01:20
#
# Scraped 57 users this round
# Got 336 reivews
# 108126 reviews are now in the bag, so to speak
# 2024-04-04 03:03:02
#
# Scraped 55 users this round
# Got 354 reivews
# 108480 reviews are now in the bag, so to speak
# 2024-04-04 03:04:37
#
# Scraped 53 users this round
# Got 294 reivews
# 108774 reviews are now in the bag, so to speak
# 2024-04-04 03:06:03
#
# Scraped 56 users this round
# Got 323 reivews
# 109097 reviews are now in the bag, so to speak
# 2024-04-04 03:07:39
#
# Scraped 57 users this round
# Got 287 reivews
# 109384 reviews are now in the bag, so to speak
# 2024-04-04 03:09:12
#
# Scraped 55 users this round
# Got 326 reivews
# 109710 reviews are now in the bag, so to speak
# 2024-04-04 03:10:51
#
# Scraped 58 users this round
# Got 323 reivews
# 110033 reviews are now in the bag, so to speak
# 2024-04-04 03:12:33
#
# Scraped 59 users this round
# Got 315 reivews
# 110348 reviews are now in the bag, so to speak
# 2024-04-04 03:14:16
#
# Scraped 53 users this round
# Got 326 reivews
# 110674 reviews are now in the bag, so to speak
# 2024-04-04 03:15:45
#
# Scraped 54 users this round
# Got 365 reivews
# 111039 reviews are now in the bag, so to speak
# 2024-04-04 03:17:15
#
# Scraped 54 users this round
# Got 306 reivews
# 111345 reviews are now in the bag, so to speak
# 2024-04-04 03:18:48
#
# Scraped 59 users this round
# Got 365 reivews
# 111710 reviews are now in the bag, so to speak
# 2024-04-04 03:20:23
#
# Scraped 53 users this round
# Got 344 reivews
# 112054 reviews are now in the bag, so to speak
# 2024-04-04 03:21:46
#
# Scraped 58 users this round
# Got 340 reivews
# 112394 reviews are now in the bag, so to speak
# 2024-04-04 03:23:27
#
# Scraped 52 users this round
# Got 337 reivews
# 112731 reviews are now in the bag, so to speak
# 2024-04-04 03:24:47
#
# Scraped 55 users this round
# Got 333 reivews
# 113064 reviews are now in the bag, so to speak
# 2024-04-04 03:26:17
#
# Scraped 59 users this round
# Got 317 reivews
# 113381 reviews are now in the bag, so to speak
# 2024-04-04 03:27:55
#
# Scraped 55 users this round
# Got 337 reivews
# 113718 reviews are now in the bag, so to speak
# 2024-04-04 03:29:24
#
# Scraped 55 users this round
# Got 380 reivews
# 114098 reviews are now in the bag, so to speak
# 2024-04-04 03:31:03
#
# Scraped 53 users this round
# Got 384 reivews
# 114482 reviews are now in the bag, so to speak
# 2024-04-04 03:32:34
#
# Scraped 58 users this round
# Got 329 reivews
# 114811 reviews are now in the bag, so to speak
# 2024-04-04 03:34:22
#
# Scraped 54 users this round
# Got 363 reivews
# 115174 reviews are now in the bag, so to speak
# 2024-04-04 03:35:54
#
# Scraped 56 users this round
# Got 316 reivews
# 115490 reviews are now in the bag, so to speak
# 2024-04-04 03:37:26
#
# Scraped 55 users this round
# Got 358 reivews
# 115848 reviews are now in the bag, so to speak
# 2024-04-04 03:39:11
#
# Scraped 53 users this round
# Got 321 reivews
# 116169 reviews are now in the bag, so to speak
# 2024-04-04 03:40:46
#
# Scraped 52 users this round
# Got 356 reivews
# 116525 reviews are now in the bag, so to speak
# 2024-04-04 03:42:11
#
# Scraped 58 users this round
# Got 329 reivews
# 116854 reviews are now in the bag, so to speak
# 2024-04-04 03:43:38
#
# Scraped 58 users this round
# Got 332 reivews
# 117186 reviews are now in the bag, so to speak
# 2024-04-04 03:45:23
#
# Scraped 57 users this round
# Got 376 reivews
# 117562 reviews are now in the bag, so to speak
# 2024-04-04 03:46:49
#
# Scraped 55 users this round
# Got 344 reivews
# 117906 reviews are now in the bag, so to speak
# 2024-04-04 03:48:09
#
# Scraped 60 users this round
# Got 342 reivews
# 118248 reviews are now in the bag, so to speak
# 2024-04-04 03:49:43
#
# Scraped 56 users this round
# Got 327 reivews
# 118575 reviews are now in the bag, so to speak
# 2024-04-04 03:51:08
#
# Scraped 62 users this round
# Got 354 reivews
# 118929 reviews are now in the bag, so to speak
# 2024-04-04 03:52:41
#
# Scraped 60 users this round
# Got 373 reivews
# 119302 reviews are now in the bag, so to speak
# 2024-04-04 03:54:17
#
# Scraped 56 users this round
# Got 306 reivews
# 119608 reviews are now in the bag, so to speak
# 2024-04-04 03:55:40
#
# Scraped 53 users this round
# Got 320 reivews
# 119928 reviews are now in the bag, so to speak
# 2024-04-04 03:57:02
#
# Scraped 53 users this round
# Got 308 reivews
# 120236 reviews are now in the bag, so to speak
# 2024-04-04 03:58:24
#
# Scraped 62 users this round
# Got 341 reivews
# 120577 reviews are now in the bag, so to speak
# 2024-04-04 04:00:08
#
# Scraped 60 users this round
# Got 334 reivews
# 120911 reviews are now in the bag, so to speak
# 2024-04-04 04:01:36
#
# Scraped 54 users this round
# Got 343 reivews
# 121254 reviews are now in the bag, so to speak
# 2024-04-04 04:03:03
#
# Scraped 62 users this round
# Got 332 reivews
# 121586 reviews are now in the bag, so to speak
# 2024-04-04 04:04:36
#
# Scraped 61 users this round
# Got 320 reivews
# 121906 reviews are now in the bag, so to speak
# 2024-04-04 04:06:10

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
