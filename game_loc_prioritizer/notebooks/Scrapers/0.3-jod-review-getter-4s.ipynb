# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 4

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')


# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 101 users this round
# Got 198 reivews
# 342123 reviews are now in the bag, so to speak
# 2024-03-31 20:25:24
#
# Scraped 98 users this round
# Got 152 reivews
# 342275 reviews are now in the bag, so to speak
# 2024-03-31 20:28:39
#
# Scraped 110 users this round
# Got 205 reivews
# 342480 reviews are now in the bag, so to speak
# 2024-03-31 20:32:35
#
# Scraped 114 users this round
# Got 182 reivews
# 342662 reviews are now in the bag, so to speak
# 2024-03-31 20:36:39
#
# Scraped 101 users this round
# Got 174 reivews
# 342836 reviews are now in the bag, so to speak
# 2024-03-31 20:40:12
#
# Scraped 122 users this round
# Got 206 reivews
# 343042 reviews are now in the bag, so to speak
# 2024-03-31 20:44:34
#
# Scraped 110 users this round
# Got 184 reivews
# 343226 reviews are now in the bag, so to speak
# 2024-03-31 20:48:20
#
# Scraped 116 users this round
# Got 182 reivews
# 343408 reviews are now in the bag, so to speak
# 2024-03-31 20:52:23
#
# Scraped 116 users this round
# Got 169 reivews
# 343577 reviews are now in the bag, so to speak
# 2024-03-31 20:56:28
#
# Scraped 136 users this round
# Got 168 reivews
# 343745 reviews are now in the bag, so to speak
# 2024-03-31 21:01:33
#
# Scraped 97 users this round
# Got 185 reivews
# 343930 reviews are now in the bag, so to speak
# 2024-03-31 21:04:53
#
# Scraped 128 users this round
# Got 208 reivews
# 344138 reviews are now in the bag, so to speak
# 2024-03-31 21:09:36
#
# Scraped 110 users this round
# Got 216 reivews
# 344354 reviews are now in the bag, so to speak
# 2024-03-31 21:13:37
#
# Scraped 119 users this round
# Got 162 reivews
# 344516 reviews are now in the bag, so to speak
# 2024-03-31 21:18:05
#
# Scraped 103 users this round
# Got 188 reivews
# 344704 reviews are now in the bag, so to speak
# 2024-03-31 21:21:57
#
# Scraped 106 users this round
# Got 210 reivews
# 344914 reviews are now in the bag, so to speak
# 2024-03-31 21:25:49
#
# Scraped 116 users this round
# Got 173 reivews
# 345087 reviews are now in the bag, so to speak
# 2024-03-31 21:30:05
#
# Scraped 128 users this round
# Got 229 reivews
# 345316 reviews are now in the bag, so to speak
# 2024-03-31 21:35:03
#
# Scraped 130 users this round
# Got 155 reivews
# 345471 reviews are now in the bag, so to speak
# 2024-03-31 21:40:27
#
# Scraped 107 users this round
# Got 160 reivews
# 345631 reviews are now in the bag, so to speak
# 2024-03-31 21:44:40
#
# Scraped 107 users this round
# Got 167 reivews
# 345798 reviews are now in the bag, so to speak
# 2024-03-31 21:48:54
#
# Scraped 110 users this round
# Got 161 reivews
# 345959 reviews are now in the bag, so to speak
# 2024-03-31 21:53:18
#
# Scraped 103 users this round
# Got 186 reivews
# 346145 reviews are now in the bag, so to speak
# 2024-03-31 21:56:59
#
# Scraped 99 users this round
# Got 210 reivews
# 346355 reviews are now in the bag, so to speak
# 2024-03-31 22:00:33
#
# Scraped 111 users this round
# Got 175 reivews
# 346530 reviews are now in the bag, so to speak
# 2024-03-31 22:04:39
#
# Scraped 106 users this round
# Got 188 reivews
# 346718 reviews are now in the bag, so to speak
# 2024-03-31 22:08:46
#
# Scraped 110 users this round
# Got 208 reivews
# 346926 reviews are now in the bag, so to speak
# 2024-03-31 22:14:09
#
# Scraped 109 users this round
# Got 182 reivews
# 347108 reviews are now in the bag, so to speak
# 2024-03-31 22:19:26
#
# Scraped 118 users this round
# Got 211 reivews
# 347319 reviews are now in the bag, so to speak
# 2024-03-31 22:25:37
#
# Scraped 113 users this round
# Got 204 reivews
# 347523 reviews are now in the bag, so to speak
# 2024-03-31 22:32:02
#
# Scraped 110 users this round
# Got 214 reivews
# 347737 reviews are now in the bag, so to speak
# 2024-03-31 22:38:11
#
# Scraped 109 users this round
# Got 189 reivews
# 347926 reviews are now in the bag, so to speak
# 2024-03-31 22:44:34
#
# Scraped 108 users this round
# Got 191 reivews
# 348117 reviews are now in the bag, so to speak
# 2024-03-31 22:51:01
#
# Scraped 88 users this round
# Got 231 reivews
# 348348 reviews are now in the bag, so to speak
# 2024-03-31 22:56:02
#
# Scraped 111 users this round
# Got 179 reivews
# 348527 reviews are now in the bag, so to speak
# 2024-03-31 23:02:55
#
# Scraped 110 users this round
# Got 163 reivews
# 348690 reviews are now in the bag, so to speak
# 2024-03-31 23:08:42
#
# Scraped 98 users this round
# Got 173 reivews
# 348863 reviews are now in the bag, so to speak
# 2024-03-31 23:14:08
#
# Scraped 125 users this round
# Got 183 reivews
# 349046 reviews are now in the bag, so to speak
# 2024-03-31 23:21:17
#
# Scraped 115 users this round
# Got 176 reivews
# 349222 reviews are now in the bag, so to speak
# 2024-03-31 23:26:50
#
# Scraped 96 users this round
# Got 203 reivews
# 349425 reviews are now in the bag, so to speak
# 2024-03-31 23:30:12
#
# Scraped 92 users this round
# Got 158 reivews
# 349583 reviews are now in the bag, so to speak
# 2024-03-31 23:33:04
#
# Scraped 90 users this round
# Got 184 reivews
# 349767 reviews are now in the bag, so to speak
# 2024-03-31 23:35:56
#
# Scraped 97 users this round
# Got 190 reivews
# 349957 reviews are now in the bag, so to speak
# 2024-03-31 23:39:10
#
# Scraped 92 users this round
# Got 157 reivews
# 350114 reviews are now in the bag, so to speak
# 2024-03-31 23:42:09
#
# Scraped 118 users this round
# Got 174 reivews
# 350288 reviews are now in the bag, so to speak
# 2024-03-31 23:46:07
#
# Scraped 104 users this round
# Got 196 reivews
# 350484 reviews are now in the bag, so to speak
# 2024-03-31 23:49:30
#
# Scraped 106 users this round
# Got 203 reivews
# 350687 reviews are now in the bag, so to speak
# 2024-03-31 23:52:56
#
# Scraped 104 users this round
# Got 147 reivews
# 350834 reviews are now in the bag, so to speak
# 2024-03-31 23:56:08
#
# Scraped 118 users this round
# Got 189 reivews
# 351023 reviews are now in the bag, so to speak
# 2024-03-31 23:59:57
#
# Scraped 129 users this round
# Got 160 reivews
# 351183 reviews are now in the bag, so to speak
# 2024-04-01 00:04:25
#
# Scraped 131 users this round
# Got 219 reivews
# 351402 reviews are now in the bag, so to speak
# 2024-04-01 00:08:52
#
# Scraped 104 users this round
# Got 149 reivews
# 351551 reviews are now in the bag, so to speak
# 2024-04-01 00:12:15
#
# Scraped 110 users this round
# Got 203 reivews
# 351754 reviews are now in the bag, so to speak
# 2024-04-01 00:16:15
#
# Scraped 101 users this round
# Got 176 reivews
# 351930 reviews are now in the bag, so to speak
# 2024-04-01 00:19:30
#
# Scraped 101 users this round
# Got 165 reivews
# 352095 reviews are now in the bag, so to speak
# 2024-04-01 00:22:55
#
# Scraped 116 users this round
# Got 164 reivews
# 352259 reviews are now in the bag, so to speak
# 2024-04-01 00:26:53
#
# Scraped 110 users this round
# Got 203 reivews
# 352462 reviews are now in the bag, so to speak
# 2024-04-01 00:30:31
#
# Scraped 125 users this round
# Got 143 reivews
# 352605 reviews are now in the bag, so to speak
# 2024-04-01 00:34:44
#
# Scraped 92 users this round
# Got 167 reivews
# 352772 reviews are now in the bag, so to speak
# 2024-04-01 00:37:39
#
# Unable to parse review blocks.
# Scraped 112 users this round
# Got 189 reivews
# 352961 reviews are now in the bag, so to speak
# 2024-04-01 00:47:45
#
# Scraped 109 users this round
# Got 162 reivews
# 353123 reviews are now in the bag, so to speak
# 2024-04-01 00:51:17
#
# Scraped 96 users this round
# Got 181 reivews
# 353304 reviews are now in the bag, so to speak
# 2024-04-01 00:54:28
#
# Scraped 111 users this round
# Got 190 reivews
# 353494 reviews are now in the bag, so to speak
# 2024-04-01 00:58:11
#
# Scraped 138 users this round
# Got 176 reivews
# 353670 reviews are now in the bag, so to speak
# 2024-04-01 01:03:02
#
# Scraped 103 users this round
# Got 181 reivews
# 353851 reviews are now in the bag, so to speak
# 2024-04-01 01:06:26
#
# Scraped 99 users this round
# Got 190 reivews
# 354041 reviews are now in the bag, so to speak
# 2024-04-01 01:09:51
#
# Scraped 111 users this round
# Got 165 reivews
# 354206 reviews are now in the bag, so to speak
# 2024-04-01 01:13:21
#
# Scraped 123 users this round
# Got 211 reivews
# 354417 reviews are now in the bag, so to speak
# 2024-04-01 01:17:33
#
# Scraped 112 users this round
# Got 185 reivews
# 354602 reviews are now in the bag, so to speak
# 2024-04-01 01:21:38
#
# Scraped 109 users this round
# Got 180 reivews
# 354782 reviews are now in the bag, so to speak
# 2024-04-01 01:25:31
#
# Scraped 94 users this round
# Got 187 reivews
# 354969 reviews are now in the bag, so to speak
# 2024-04-01 01:28:44
#
# Scraped 127 users this round
# Got 166 reivews
# 355135 reviews are now in the bag, so to speak
# 2024-04-01 01:33:07
#
# Scraped 97 users this round
# Got 140 reivews
# 355275 reviews are now in the bag, so to speak
# 2024-04-01 01:36:22
#
# Scraped 111 users this round
# Got 190 reivews
# 355465 reviews are now in the bag, so to speak
# 2024-04-01 01:40:00
#
# Scraped 121 users this round
# Got 190 reivews
# 355655 reviews are now in the bag, so to speak
# 2024-04-01 01:44:07
#
# Scraped 115 users this round
# Got 147 reivews
# 355802 reviews are now in the bag, so to speak
# 2024-04-01 01:48:02
#
# Scraped 113 users this round
# Got 186 reivews
# 355988 reviews are now in the bag, so to speak
# 2024-04-01 01:51:48
#
# Scraped 103 users this round
# Got 188 reivews
# 356176 reviews are now in the bag, so to speak
# 2024-04-01 01:55:05
#
# Scraped 97 users this round
# Got 162 reivews
# 356338 reviews are now in the bag, so to speak
# 2024-04-01 01:58:34
#
# Scraped 106 users this round
# Got 198 reivews
# 356536 reviews are now in the bag, so to speak
# 2024-04-01 02:02:04
#
# Scraped 97 users this round
# Got 192 reivews
# 356728 reviews are now in the bag, so to speak
# 2024-04-01 02:05:19
#
# Scraped 99 users this round
# Got 175 reivews
# 356903 reviews are now in the bag, so to speak
# 2024-04-01 02:08:49
#
# Scraped 105 users this round
# Got 188 reivews
# 357091 reviews are now in the bag, so to speak
# 2024-04-01 02:12:25
#
# Scraped 90 users this round
# Got 216 reivews
# 357307 reviews are now in the bag, so to speak
# 2024-04-01 02:15:21
#
# Scraped 121 users this round
# Got 175 reivews
# 357482 reviews are now in the bag, so to speak
# 2024-04-01 02:19:21
#
# Scraped 106 users this round
# Got 203 reivews
# 357685 reviews are now in the bag, so to speak
# 2024-04-01 02:22:42
#
# Scraped 110 users this round
# Got 184 reivews
# 357869 reviews are now in the bag, so to speak
# 2024-04-01 02:26:20
#
# Scraped 95 users this round
# Got 177 reivews
# 358046 reviews are now in the bag, so to speak
# 2024-04-01 02:29:38
#
# Scraped 106 users this round
# Got 181 reivews
# 358227 reviews are now in the bag, so to speak
# 2024-04-01 02:33:02
#
# Scraped 104 users this round
# Got 170 reivews
# 358397 reviews are now in the bag, so to speak
# 2024-04-01 02:36:19
#
# Scraped 129 users this round
# Got 227 reivews
# 358624 reviews are now in the bag, so to speak
# 2024-04-01 02:40:34
#
# Scraped 115 users this round
# Got 141 reivews
# 358765 reviews are now in the bag, so to speak
# 2024-04-01 02:44:32
#
# Scraped 119 users this round
# Got 192 reivews
# 358957 reviews are now in the bag, so to speak
# 2024-04-01 02:48:24
#
# Scraped 80 users this round
# Got 196 reivews
# 359153 reviews are now in the bag, so to speak
# 2024-04-01 02:50:58
#
# Scraped 113 users this round
# Got 185 reivews
# 359338 reviews are now in the bag, so to speak
# 2024-04-01 02:54:40
#
# Scraped 93 users this round
# Got 166 reivews
# 359504 reviews are now in the bag, so to speak
# 2024-04-01 02:57:34
#
# Scraped 92 users this round
# Got 205 reivews
# 359709 reviews are now in the bag, so to speak
# 2024-04-01 03:00:30
#
# Scraped 107 users this round
# Got 190 reivews
# 359899 reviews are now in the bag, so to speak
# 2024-04-01 03:03:50
#
# Scraped 112 users this round
# Got 200 reivews
# 360099 reviews are now in the bag, so to speak
# 2024-04-01 03:07:37
#
# Scraped 126 users this round
# Got 183 reivews
# 360282 reviews are now in the bag, so to speak
# 2024-04-01 03:11:49
#
# Scraped 115 users this round
# Got 199 reivews
# 360481 reviews are now in the bag, so to speak
# 2024-04-01 03:15:43
#
# Scraped 107 users this round
# Got 157 reivews
# 360638 reviews are now in the bag, so to speak
# 2024-04-01 03:19:01
#
# Scraped 111 users this round
# Got 165 reivews
# 360803 reviews are now in the bag, so to speak
# 2024-04-01 03:22:45
#
# Scraped 123 users this round
# Got 155 reivews
# 360958 reviews are now in the bag, so to speak
# 2024-04-01 03:26:47
#
# Scraped 118 users this round
# Got 170 reivews
# 361128 reviews are now in the bag, so to speak
# 2024-04-01 03:30:36
#
# Scraped 106 users this round
# Got 207 reivews
# 361335 reviews are now in the bag, so to speak
# 2024-04-01 03:34:06
#
# Scraped 117 users this round
# Got 171 reivews
# 361506 reviews are now in the bag, so to speak
# 2024-04-01 03:38:03
#
# Scraped 88 users this round
# Got 193 reivews
# 361699 reviews are now in the bag, so to speak
# 2024-04-01 03:40:49
#
# Scraped 91 users this round
# Got 197 reivews
# 361896 reviews are now in the bag, so to speak
# 2024-04-01 03:43:54
#
# Scraped 109 users this round
# Got 205 reivews
# 362101 reviews are now in the bag, so to speak
# 2024-04-01 03:47:40
#
# Scraped 98 users this round
# Got 200 reivews
# 362301 reviews are now in the bag, so to speak
# 2024-04-01 03:50:42
#
# Scraped 109 users this round
# Got 180 reivews
# 362481 reviews are now in the bag, so to speak
# 2024-04-01 03:54:28
#
# Scraped 117 users this round
# Got 158 reivews
# 362639 reviews are now in the bag, so to speak
# 2024-04-01 03:58:16
#
# Scraped 107 users this round
# Got 244 reivews
# 362883 reviews are now in the bag, so to speak
# 2024-04-01 04:01:58
#
# Scraped 122 users this round
# Got 206 reivews
# 363089 reviews are now in the bag, so to speak
# 2024-04-01 04:05:57
#
# Scraped 123 users this round
# Got 167 reivews
# 363256 reviews are now in the bag, so to speak
# 2024-04-01 04:10:18
#
# Scraped 104 users this round
# Got 218 reivews
# 363474 reviews are now in the bag, so to speak
# 2024-04-01 04:13:41
#
# Scraped 112 users this round
# Got 217 reivews
# 363691 reviews are now in the bag, so to speak
# 2024-04-01 04:17:13
#
# Scraped 103 users this round
# Got 185 reivews
# 363876 reviews are now in the bag, so to speak
# 2024-04-01 04:20:33
#
# Scraped 99 users this round
# Got 176 reivews
# 364052 reviews are now in the bag, so to speak
# 2024-04-01 04:23:55
#
# Scraped 121 users this round
# Got 214 reivews
# 364266 reviews are now in the bag, so to speak
# 2024-04-01 04:27:55
#
# Scraped 127 users this round
# Got 160 reivews
# 364426 reviews are now in the bag, so to speak
# 2024-04-01 04:32:07
#
# Scraped 109 users this round
# Got 187 reivews
# 364613 reviews are now in the bag, so to speak
# 2024-04-01 04:36:01
#
# Scraped 121 users this round
# Got 169 reivews
# 364782 reviews are now in the bag, so to speak
# 2024-04-01 04:40:09
#
# Scraped 105 users this round
# Got 156 reivews
# 364938 reviews are now in the bag, so to speak
# 2024-04-01 04:43:30
#
# Scraped 107 users this round
# Got 172 reivews
# 365110 reviews are now in the bag, so to speak
# 2024-04-01 04:46:53
#
# Scraped 121 users this round
# Got 211 reivews
# 365321 reviews are now in the bag, so to speak
# 2024-04-01 04:51:03
#
# Scraped 93 users this round
# Got 135 reivews
# 365456 reviews are now in the bag, so to speak
# 2024-04-01 04:54:01
#
# Scraped 113 users this round
# Got 182 reivews
# 365638 reviews are now in the bag, so to speak
# 2024-04-01 04:57:56
#
# Scraped 104 users this round
# Got 217 reivews
# 365855 reviews are now in the bag, so to speak
# 2024-04-01 05:01:31
#
# Scraped 104 users this round
# Got 186 reivews
# 366041 reviews are now in the bag, so to speak
# 2024-04-01 05:04:54
#
# Scraped 90 users this round
# Got 190 reivews
# 366231 reviews are now in the bag, so to speak
# 2024-04-01 05:07:55
#
# Scraped 108 users this round
# Got 203 reivews
# 366434 reviews are now in the bag, so to speak
# 2024-04-01 05:11:32
#
# Scraped 122 users this round
# Got 252 reivews
# 366686 reviews are now in the bag, so to speak
# 2024-04-01 05:15:44
#
# Scraped 136 users this round
# Got 167 reivews
# 366853 reviews are now in the bag, so to speak
# 2024-04-01 05:20:22
#
# Scraped 106 users this round
# Got 177 reivews
# 367030 reviews are now in the bag, so to speak
# 2024-04-01 05:23:50
#
# Scraped 113 users this round
# Got 190 reivews
# 367220 reviews are now in the bag, so to speak
# 2024-04-01 05:27:23
#
# Scraped 126 users this round
# Got 190 reivews
# 367410 reviews are now in the bag, so to speak
# 2024-04-01 05:31:35
#
# Scraped 132 users this round
# Got 238 reivews
# 367648 reviews are now in the bag, so to speak
# 2024-04-01 05:36:02
#
# Scraped 108 users this round
# Got 143 reivews
# 367791 reviews are now in the bag, so to speak
# 2024-04-01 05:39:44
#
# Scraped 115 users this round
# Got 190 reivews
# 367981 reviews are now in the bag, so to speak
# 2024-04-01 05:43:31
#
# Unable to parse review blocks.
# Scraped 110 users this round
# Got 132 reivews
# 368113 reviews are now in the bag, so to speak
# 2024-04-01 05:48:33
#
# Scraped 105 users this round
# Got 196 reivews
# 368309 reviews are now in the bag, so to speak
# 2024-04-01 05:51:48
#
# Scraped 98 users this round
# Got 203 reivews
# 368512 reviews are now in the bag, so to speak
# 2024-04-01 05:55:02
#
# Scraped 132 users this round
# Got 198 reivews
# 368710 reviews are now in the bag, so to speak
# 2024-04-01 05:59:34
#
# Scraped 111 users this round
# Got 178 reivews
# 368888 reviews are now in the bag, so to speak
# 2024-04-01 06:03:15
#
# Scraped 101 users this round
# Got 179 reivews
# 369067 reviews are now in the bag, so to speak
# 2024-04-01 06:06:30
#
# Scraped 115 users this round
# Got 181 reivews
# 369248 reviews are now in the bag, so to speak
# 2024-04-01 06:10:18
#
# Scraped 119 users this round
# Got 172 reivews
# 369420 reviews are now in the bag, so to speak
# 2024-04-01 06:14:25
#
# Scraped 108 users this round
# Got 178 reivews
# 369598 reviews are now in the bag, so to speak
# 2024-04-01 06:18:07
#
# Scraped 104 users this round
# Got 157 reivews
# 369755 reviews are now in the bag, so to speak
# 2024-04-01 06:21:40
#
# Scraped 122 users this round
# Got 193 reivews
# 369948 reviews are now in the bag, so to speak
# 2024-04-01 06:25:51
#
# Scraped 110 users this round
# Got 203 reivews
# 370151 reviews are now in the bag, so to speak
# 2024-04-01 06:29:34
#
# Scraped 118 users this round
# Got 211 reivews
# 370362 reviews are now in the bag, so to speak
# 2024-04-01 06:33:32
#
# Scraped 118 users this round
# Got 134 reivews
# 370496 reviews are now in the bag, so to speak
# 2024-04-01 06:37:25
#
# Scraped 96 users this round
# Got 171 reivews
# 370667 reviews are now in the bag, so to speak
# 2024-04-01 06:40:31
#
# Scraped 103 users this round
# Got 197 reivews
# 370864 reviews are now in the bag, so to speak
# 2024-04-01 06:43:57
#
# Scraped 94 users this round
# Got 176 reivews
# 371040 reviews are now in the bag, so to speak
# 2024-04-01 06:47:07
#
# Scraped 109 users this round
# Got 192 reivews
# 371232 reviews are now in the bag, so to speak
# 2024-04-01 06:50:44
#
# Scraped 107 users this round
# Got 211 reivews
# 371443 reviews are now in the bag, so to speak
# 2024-04-01 06:54:18
#
# Scraped 122 users this round
# Got 184 reivews
# 371627 reviews are now in the bag, so to speak
# 2024-04-01 06:58:48
#
# Scraped 102 users this round
# Got 193 reivews
# 371820 reviews are now in the bag, so to speak
# 2024-04-01 07:02:34
#
# Scraped 119 users this round
# Got 193 reivews
# 372013 reviews are now in the bag, so to speak
# 2024-04-01 07:07:08
#
# Scraped 96 users this round
# Got 133 reivews
# 372146 reviews are now in the bag, so to speak
# 2024-04-01 07:10:17
#
# Scraped 109 users this round
# Got 194 reivews
# 372340 reviews are now in the bag, so to speak
# 2024-04-01 07:13:58
#
# Scraped 87 users this round
# Got 188 reivews
# 372528 reviews are now in the bag, so to speak
# 2024-04-01 07:16:48
#
# Scraped 102 users this round
# Got 190 reivews
# 372718 reviews are now in the bag, so to speak
# 2024-04-01 07:20:05
#
# Scraped 107 users this round
# Got 188 reivews
# 372906 reviews are now in the bag, so to speak
# 2024-04-01 07:23:41
#
# Scraped 107 users this round
# Got 189 reivews
# 373095 reviews are now in the bag, so to speak
# 2024-04-01 07:27:11
#
# Scraped 108 users this round
# Got 219 reivews
# 373314 reviews are now in the bag, so to speak
# 2024-04-01 07:30:55
#
# Scraped 133 users this round
# Got 238 reivews
# 373552 reviews are now in the bag, so to speak
# 2024-04-01 07:35:24
#
# Scraped 116 users this round
# Got 204 reivews
# 373756 reviews are now in the bag, so to speak
# 2024-04-01 07:39:12
#
# Scraped 115 users this round
# Got 194 reivews
# 373950 reviews are now in the bag, so to speak
# 2024-04-01 07:43:00
#
# Scraped 117 users this round
# Got 200 reivews
# 374150 reviews are now in the bag, so to speak
# 2024-04-01 07:46:48
#
# Scraped 111 users this round
# Got 191 reivews
# 374341 reviews are now in the bag, so to speak
# 2024-04-01 07:50:34
#
# Scraped 107 users this round
# Got 179 reivews
# 374520 reviews are now in the bag, so to speak
# 2024-04-01 07:54:04
#
# Scraped 86 users this round
# Got 192 reivews
# 374712 reviews are now in the bag, so to speak
# 2024-04-01 07:56:49
#
# Scraped 130 users this round
# Got 186 reivews
# 374898 reviews are now in the bag, so to speak
# 2024-04-01 08:01:12
#
# Scraped 104 users this round
# Got 191 reivews
# 375089 reviews are now in the bag, so to speak
# 2024-04-01 08:04:56
#
# Scraped 100 users this round
# Got 230 reivews
# 375319 reviews are now in the bag, so to speak
# 2024-04-01 08:08:33
#
# Scraped 103 users this round
# Got 174 reivews
# 375493 reviews are now in the bag, so to speak
# 2024-04-01 08:11:50
#
# Scraped 100 users this round
# Got 197 reivews
# 375690 reviews are now in the bag, so to speak
# 2024-04-01 08:15:20
#
# Scraped 117 users this round
# Got 185 reivews
# 375875 reviews are now in the bag, so to speak
# 2024-04-01 08:19:27
#
# Scraped 134 users this round
# Got 162 reivews
# 376037 reviews are now in the bag, so to speak
# 2024-04-01 08:24:08
#
# Scraped 104 users this round
# Got 177 reivews
# 376214 reviews are now in the bag, so to speak
# 2024-04-01 08:27:33
#
# Scraped 113 users this round
# Got 168 reivews
# 376382 reviews are now in the bag, so to speak
# 2024-04-01 08:31:30
#
# Scraped 96 users this round
# Got 191 reivews
# 376573 reviews are now in the bag, so to speak
# 2024-04-01 08:35:04
#
# Scraped 104 users this round
# Got 157 reivews
# 376730 reviews are now in the bag, so to speak
# 2024-04-01 08:38:33
#
# Scraped 99 users this round
# Got 193 reivews
# 376923 reviews are now in the bag, so to speak
# 2024-04-01 08:41:56
#
# Scraped 93 users this round
# Got 188 reivews
# 377111 reviews are now in the bag, so to speak
# 2024-04-01 08:44:57
#
# Scraped 100 users this round
# Got 181 reivews
# 377292 reviews are now in the bag, so to speak
# 2024-04-01 08:48:06
#
# Scraped 126 users this round
# Got 156 reivews
# 377448 reviews are now in the bag, so to speak
# 2024-04-01 08:52:23
#
# Scraped 121 users this round
# Got 217 reivews
# 377665 reviews are now in the bag, so to speak
# 2024-04-01 08:56:30
#
# Scraped 97 users this round
# Got 217 reivews
# 377882 reviews are now in the bag, so to speak
# 2024-04-01 08:59:48
#
# Scraped 116 users this round
# Got 144 reivews
# 378026 reviews are now in the bag, so to speak
# 2024-04-01 09:03:54
#
# Scraped 99 users this round
# Got 147 reivews
# 378173 reviews are now in the bag, so to speak
# 2024-04-01 09:07:22
#
# Scraped 104 users this round
# Got 195 reivews
# 378368 reviews are now in the bag, so to speak
# 2024-04-01 09:11:05
#
# Scraped 109 users this round
# Got 226 reivews
# 378594 reviews are now in the bag, so to speak
# 2024-04-01 09:14:47
#
# Scraped 98 users this round
# Got 192 reivews
# 378786 reviews are now in the bag, so to speak
# 2024-04-01 09:17:59
#
# Scraped 86 users this round
# Got 230 reivews
# 379016 reviews are now in the bag, so to speak
# 2024-04-01 09:20:56
#
# Scraped 104 users this round
# Got 180 reivews
# 379196 reviews are now in the bag, so to speak
# 2024-04-01 09:24:38
#
# Scraped 106 users this round
# Got 191 reivews
# 379387 reviews are now in the bag, so to speak
# 2024-04-01 09:28:17
#
# Scraped 103 users this round
# Got 174 reivews
# 379561 reviews are now in the bag, so to speak
# 2024-04-01 09:31:57
#
# Scraped 105 users this round
# Got 182 reivews
# 379743 reviews are now in the bag, so to speak
# 2024-04-01 09:35:31
#
# Scraped 113 users this round
# Got 197 reivews
# 379940 reviews are now in the bag, so to speak
# 2024-04-01 09:39:23
#
# Scraped 116 users this round
# Got 209 reivews
# 380149 reviews are now in the bag, so to speak
# 2024-04-01 09:44:15
#
# Scraped 93 users this round
# Got 192 reivews
# 380341 reviews are now in the bag, so to speak
# 2024-04-01 09:47:32
#
# Scraped 96 users this round
# Got 199 reivews
# 380540 reviews are now in the bag, so to speak
# 2024-04-01 09:51:14
#
# Scraped 106 users this round
# Got 190 reivews
# 380730 reviews are now in the bag, so to speak
# 2024-04-01 09:55:06
#
# Scraped 96 users this round
# Got 192 reivews
# 380922 reviews are now in the bag, so to speak
# 2024-04-01 09:58:32
#
# Scraped 116 users this round
# Got 174 reivews
# 381096 reviews are now in the bag, so to speak
# 2024-04-01 10:02:48
#
# Scraped 117 users this round
# Got 206 reivews
# 381302 reviews are now in the bag, so to speak
# 2024-04-01 10:07:09
#
# Scraped 107 users this round
# Got 217 reivews
# 381519 reviews are now in the bag, so to speak
# 2024-04-01 10:10:54
#
# Scraped 106 users this round
# Got 205 reivews
# 381724 reviews are now in the bag, so to speak
# 2024-04-01 10:14:52
#
# Scraped 114 users this round
# Got 155 reivews
# 381879 reviews are now in the bag, so to speak
# 2024-04-01 10:19:21
#
# Scraped 118 users this round
# Got 212 reivews
# 382091 reviews are now in the bag, so to speak
# 2024-04-01 10:23:33
#
# Scraped 97 users this round
# Got 180 reivews
# 382271 reviews are now in the bag, so to speak
# 2024-04-01 10:27:14
#
# Scraped 116 users this round
# Got 176 reivews
# 382447 reviews are now in the bag, so to speak
# 2024-04-01 10:32:12
#
# Scraped 110 users this round
# Got 178 reivews
# 382625 reviews are now in the bag, so to speak
# 2024-04-01 10:36:41
#
# Scraped 102 users this round
# Got 191 reivews
# 382816 reviews are now in the bag, so to speak
# 2024-04-01 10:40:28
#
# Scraped 99 users this round
# Got 186 reivews
# 383002 reviews are now in the bag, so to speak
# 2024-04-01 10:44:04
#
# Scraped 96 users this round
# Got 199 reivews
# 383201 reviews are now in the bag, so to speak
# 2024-04-01 10:47:40
#
# Scraped 91 users this round
# Got 177 reivews
# 383378 reviews are now in the bag, so to speak
# 2024-04-01 10:50:55
#
# Scraped 104 users this round
# Got 207 reivews
# 383585 reviews are now in the bag, so to speak
# 2024-04-01 10:54:58
#
# Scraped 117 users this round
# Got 197 reivews
# 383782 reviews are now in the bag, so to speak
# 2024-04-01 10:59:24
#
# Scraped 102 users this round
# Got 206 reivews
# 383988 reviews are now in the bag, so to speak
# 2024-04-01 11:03:15
#
# Scraped 111 users this round
# Got 195 reivews
# 384183 reviews are now in the bag, so to speak
# 2024-04-01 11:07:47
#
# Scraped 92 users this round
# Got 237 reivews
# 384420 reviews are now in the bag, so to speak
# 2024-04-01 11:11:24
#
# Scraped 99 users this round
# Got 156 reivews
# 384576 reviews are now in the bag, so to speak
# 2024-04-01 11:15:01
#
# Scraped 101 users this round
# Got 148 reivews
# 384724 reviews are now in the bag, so to speak
# 2024-04-01 11:18:39
#
# Scraped 114 users this round
# Got 208 reivews
# 384932 reviews are now in the bag, so to speak
# 2024-04-01 11:22:52
#
# Scraped 119 users this round
# Got 173 reivews
# 385105 reviews are now in the bag, so to speak
# 2024-04-01 11:27:19
#
# Scraped 96 users this round
# Got 193 reivews
# 385298 reviews are now in the bag, so to speak
# 2024-04-01 11:30:55
#
# Scraped 111 users this round
# Got 187 reivews
# 385485 reviews are now in the bag, so to speak
# 2024-04-01 11:35:23
#
# Scraped 110 users this round
# Got 216 reivews
# 385701 reviews are now in the bag, so to speak
# 2024-04-01 11:39:52
#
# Scraped 109 users this round
# Got 199 reivews
# 385900 reviews are now in the bag, so to speak
# 2024-04-01 11:43:48
#
# Scraped 143 users this round
# Got 161 reivews
# 386061 reviews are now in the bag, so to speak
# 2024-04-01 11:49:23
#
# Scraped 116 users this round
# Got 170 reivews
# 386231 reviews are now in the bag, so to speak
# 2024-04-01 11:53:46
#
# Scraped 107 users this round
# Got 160 reivews
# 386391 reviews are now in the bag, so to speak
# 2024-04-01 11:57:57
#
# Scraped 99 users this round
# Got 208 reivews
# 386599 reviews are now in the bag, so to speak
# 2024-04-01 12:01:30
#
# Scraped 112 users this round
# Got 223 reivews
# 386822 reviews are now in the bag, so to speak
# 2024-04-01 12:05:50
#
# Scraped 116 users this round
# Got 158 reivews
# 386980 reviews are now in the bag, so to speak
# 2024-04-01 12:10:16
#
# Scraped 118 users this round
# Got 178 reivews
# 387158 reviews are now in the bag, so to speak
# 2024-04-01 12:14:52
#
# Scraped 134 users this round
# Got 185 reivews
# 387343 reviews are now in the bag, so to speak
# 2024-04-01 12:20:04
#
# Scraped 112 users this round
# Got 172 reivews
# 387515 reviews are now in the bag, so to speak
# 2024-04-01 12:24:18
#
# Scraped 121 users this round
# Got 188 reivews
# 387703 reviews are now in the bag, so to speak
# 2024-04-01 12:28:57
#
# Scraped 114 users this round
# Got 213 reivews
# 387916 reviews are now in the bag, so to speak
# 2024-04-01 12:33:19
#
# Scraped 110 users this round
# Got 158 reivews
# 388074 reviews are now in the bag, so to speak
# 2024-04-01 12:37:14
#
# Scraped 102 users this round
# Got 209 reivews
# 388283 reviews are now in the bag, so to speak
# 2024-04-01 12:40:50
#
# Scraped 92 users this round
# Got 183 reivews
# 388466 reviews are now in the bag, so to speak
# 2024-04-01 12:44:00
#
# Scraped 96 users this round
# Got 209 reivews
# 388675 reviews are now in the bag, so to speak
# 2024-04-01 12:47:33
#
# Scraped 117 users this round
# Got 190 reivews
# 388865 reviews are now in the bag, so to speak
# 2024-04-01 12:51:41
#
# Scraped 99 users this round
# Got 156 reivews
# 389021 reviews are now in the bag, so to speak
# 2024-04-01 12:55:07
#
# Scraped 109 users this round
# Got 246 reivews
# 389267 reviews are now in the bag, so to speak
# 2024-04-01 12:59:05
#
# Scraped 120 users this round
# Got 191 reivews
# 389458 reviews are now in the bag, so to speak
# 2024-04-01 13:03:26
#
# Scraped 101 users this round
# Got 190 reivews
# 389648 reviews are now in the bag, so to speak
# 2024-04-01 13:06:56
#
# Scraped 121 users this round
# Got 203 reivews
# 389851 reviews are now in the bag, so to speak
# 2024-04-01 13:11:25
#
# Unable to parse review blocks.
# Scraped 130 users this round
# Got 220 reivews
# 390071 reviews are now in the bag, so to speak
# 2024-04-01 13:16:00
#
# Scraped 116 users this round
# Got 182 reivews
# 390253 reviews are now in the bag, so to speak
# 2024-04-01 13:20:07
#
# Scraped 96 users this round
# Got 123 reivews
# 390376 reviews are now in the bag, so to speak
# 2024-04-01 13:23:19
#
# Scraped 110 users this round
# Got 177 reivews
# 390553 reviews are now in the bag, so to speak
# 2024-04-01 13:27:16
#
# Scraped 120 users this round
# Got 152 reivews
# 390705 reviews are now in the bag, so to speak
# 2024-04-01 13:31:31
#
# Scraped 118 users this round
# Got 151 reivews
# 390856 reviews are now in the bag, so to speak
# 2024-04-01 13:35:44
#
# Scraped 108 users this round
# Got 201 reivews
# 391057 reviews are now in the bag, so to speak
# 2024-04-01 13:39:32
#
# Scraped 101 users this round
# Got 179 reivews
# 391236 reviews are now in the bag, so to speak
# 2024-04-01 13:43:10
#
# Scraped 83 users this round
# Got 204 reivews
# 391440 reviews are now in the bag, so to speak
# 2024-04-01 13:45:54
#
# Scraped 124 users this round
# Got 187 reivews
# 391627 reviews are now in the bag, so to speak
# 2024-04-01 13:50:22
#
# Scraped 118 users this round
# Got 195 reivews
# 391822 reviews are now in the bag, so to speak
# 2024-04-01 13:54:30
#
# Scraped 127 users this round
# Got 176 reivews
# 391998 reviews are now in the bag, so to speak
# 2024-04-01 13:58:52
#
# Scraped 102 users this round
# Got 200 reivews
# 392198 reviews are now in the bag, so to speak
# 2024-04-01 14:02:28
#
# Scraped 104 users this round
# Got 191 reivews
# 392389 reviews are now in the bag, so to speak
# 2024-04-01 14:06:07
#
# Scraped 98 users this round
# Got 172 reivews
# 392561 reviews are now in the bag, so to speak
# 2024-04-01 14:09:31
#
# Scraped 101 users this round
# Got 165 reivews
# 392726 reviews are now in the bag, so to speak
# 2024-04-01 14:12:54
#
# Scraped 111 users this round
# Got 202 reivews
# 392928 reviews are now in the bag, so to speak
# 2024-04-01 14:16:58
#
# Scraped 95 users this round
# Got 202 reivews
# 393130 reviews are now in the bag, so to speak
# 2024-04-01 14:20:10
#
# Scraped 105 users this round
# Got 223 reivews
# 393353 reviews are now in the bag, so to speak
# 2024-04-01 14:23:54
#
# Scraped 100 users this round
# Got 200 reivews
# 393553 reviews are now in the bag, so to speak
# 2024-04-01 14:27:23
#
# Scraped 118 users this round
# Got 176 reivews
# 393729 reviews are now in the bag, so to speak
# 2024-04-01 14:31:42
#
# Scraped 94 users this round
# Got 193 reivews
# 393922 reviews are now in the bag, so to speak
# 2024-04-01 14:34:57
#
# Scraped 102 users this round
# Got 195 reivews
# 394117 reviews are now in the bag, so to speak
# 2024-04-01 14:38:33
#
# Scraped 119 users this round
# Got 185 reivews
# 394302 reviews are now in the bag, so to speak
# 2024-04-01 14:42:54
#
# Scraped 102 users this round
# Got 182 reivews
# 394484 reviews are now in the bag, so to speak
# 2024-04-01 14:46:27
#
# Scraped 111 users this round
# Got 172 reivews
# 394656 reviews are now in the bag, so to speak
# 2024-04-01 14:50:32
#
# Scraped 125 users this round
# Got 168 reivews
# 394824 reviews are now in the bag, so to speak
# 2024-04-01 14:55:02
#
# Scraped 104 users this round
# Got 179 reivews
# 395003 reviews are now in the bag, so to speak
# 2024-04-01 14:59:02
#
# Scraped 127 users this round
# Got 169 reivews
# 395172 reviews are now in the bag, so to speak
# 2024-04-01 15:04:02
#
# Scraped 123 users this round
# Got 140 reivews
# 395312 reviews are now in the bag, so to speak
# 2024-04-01 15:08:23
#
# Scraped 120 users this round
# Got 229 reivews
# 395541 reviews are now in the bag, so to speak
# 2024-04-01 15:12:41
#
# Scraped 125 users this round
# Got 181 reivews
# 395722 reviews are now in the bag, so to speak
# 2024-04-01 15:17:00
#
# Scraped 111 users this round
# Got 206 reivews
# 395928 reviews are now in the bag, so to speak
# 2024-04-01 15:20:55
#
# Scraped 101 users this round
# Got 175 reivews
# 396103 reviews are now in the bag, so to speak
# 2024-04-01 15:24:29
#
# Scraped 111 users this round
# Got 158 reivews
# 396261 reviews are now in the bag, so to speak
# 2024-04-01 15:28:28
#
# Scraped 129 users this round
# Got 202 reivews
# 396463 reviews are now in the bag, so to speak
# 2024-04-01 15:33:28
#
# Scraped 108 users this round
# Got 214 reivews
# 396677 reviews are now in the bag, so to speak
# 2024-04-01 15:37:04
#
# Scraped 119 users this round
# Got 185 reivews
# 396862 reviews are now in the bag, so to speak
# 2024-04-01 15:41:07
#
# Scraped 122 users this round
# Got 214 reivews
# 397076 reviews are now in the bag, so to speak
# 2024-04-01 15:45:13
#
# Scraped 123 users this round
# Got 169 reivews
# 397245 reviews are now in the bag, so to speak
# 2024-04-01 15:49:27
#
# Scraped 123 users this round
# Got 154 reivews
# 397399 reviews are now in the bag, so to speak
# 2024-04-01 15:53:42
#
# Scraped 100 users this round
# Got 153 reivews
# 397552 reviews are now in the bag, so to speak
# 2024-04-01 15:57:03
#
# Scraped 105 users this round
# Got 167 reivews
# 397719 reviews are now in the bag, so to speak
# 2024-04-01 16:00:48
#
# Scraped 101 users this round
# Got 239 reivews
# 397958 reviews are now in the bag, so to speak
# 2024-04-01 16:04:15
#
# Scraped 98 users this round
# Got 162 reivews
# 398120 reviews are now in the bag, so to speak
# 2024-04-01 16:07:37
#
# Scraped 107 users this round
# Got 221 reivews
# 398341 reviews are now in the bag, so to speak
# 2024-04-01 16:11:19
#
# Scraped 87 users this round
# Got 187 reivews
# 398528 reviews are now in the bag, so to speak
# 2024-04-01 16:14:15
#
# Scraped 110 users this round
# Got 185 reivews
# 398713 reviews are now in the bag, so to speak
# 2024-04-01 16:18:00
#
# Scraped 99 users this round
# Got 226 reivews
# 398939 reviews are now in the bag, so to speak
# 2024-04-01 16:21:33
#
# Scraped 122 users this round
# Got 169 reivews
# 399108 reviews are now in the bag, so to speak
# 2024-04-01 16:25:53
#
# Scraped 100 users this round
# Got 178 reivews
# 399286 reviews are now in the bag, so to speak
# 2024-04-01 16:29:29
#
# Scraped 98 users this round
# Got 196 reivews
# 399482 reviews are now in the bag, so to speak
# 2024-04-01 16:33:00
#
# Scraped 100 users this round
# Got 222 reivews
# 399704 reviews are now in the bag, so to speak
# 2024-04-01 16:36:27
#
# Scraped 122 users this round
# Got 211 reivews
# 399915 reviews are now in the bag, so to speak
# 2024-04-01 16:40:45
#
# Scraped 96 users this round
# Got 206 reivews
# 400121 reviews are now in the bag, so to speak
# 2024-04-01 16:44:07
#
# Scraped 103 users this round
# Got 176 reivews
# 400297 reviews are now in the bag, so to speak
# 2024-04-01 16:47:42
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 96 users this round
# Got 191 reivews
# 400488 reviews are now in the bag, so to speak
# 2024-04-01 16:50:56
#
# Scraped 101 users this round
# Got 213 reivews
# 400701 reviews are now in the bag, so to speak
# 2024-04-01 16:54:20
#
# Scraped 113 users this round
# Got 193 reivews
# 400894 reviews are now in the bag, so to speak
# 2024-04-01 16:58:19
#
# Scraped 115 users this round
# Got 160 reivews
# 401054 reviews are now in the bag, so to speak
# 2024-04-01 17:02:31
#
# Scraped 100 users this round
# Got 204 reivews
# 401258 reviews are now in the bag, so to speak
# 2024-04-01 17:05:51
#
# Scraped 118 users this round
# Got 191 reivews
# 401449 reviews are now in the bag, so to speak
# 2024-04-01 17:09:51
#
# Scraped 121 users this round
# Got 163 reivews
# 401612 reviews are now in the bag, so to speak
# 2024-04-01 17:14:02
#
# Scraped 92 users this round
# Got 170 reivews
# 401782 reviews are now in the bag, so to speak
# 2024-04-01 17:17:02
#
# Scraped 102 users this round
# Got 202 reivews
# 401984 reviews are now in the bag, so to speak
# 2024-04-01 17:20:34
#
# Scraped 96 users this round
# Got 198 reivews
# 402182 reviews are now in the bag, so to speak
# 2024-04-01 17:24:05
#
# Scraped 107 users this round
# Got 206 reivews
# 402388 reviews are now in the bag, so to speak
# 2024-04-01 17:28:06
#
# Scraped 114 users this round
# Got 168 reivews
# 402556 reviews are now in the bag, so to speak
# 2024-04-01 17:32:11
#
# Scraped 114 users this round
# Got 234 reivews
# 402790 reviews are now in the bag, so to speak
# 2024-04-01 17:36:15
#
# Scraped 119 users this round
# Got 179 reivews
# 402969 reviews are now in the bag, so to speak
# 2024-04-01 17:40:25
#
# Scraped 103 users this round
# Got 175 reivews
# 403144 reviews are now in the bag, so to speak
# 2024-04-01 17:43:54
#
# Scraped 108 users this round
# Got 184 reivews
# 403328 reviews are now in the bag, so to speak
# 2024-04-01 17:47:38
#
# Scraped 112 users this round
# Got 133 reivews
# 403461 reviews are now in the bag, so to speak
# 2024-04-01 17:51:30
#
# Scraped 114 users this round
# Got 211 reivews
# 403672 reviews are now in the bag, so to speak
# 2024-04-01 17:55:31
#
# Scraped 98 users this round
# Got 181 reivews
# 403853 reviews are now in the bag, so to speak
# 2024-04-01 17:58:46
#
# Scraped 121 users this round
# Got 192 reivews
# 404045 reviews are now in the bag, so to speak
# 2024-04-01 18:02:59
#
# Scraped 132 users this round
# Got 197 reivews
# 404242 reviews are now in the bag, so to speak
# 2024-04-01 18:07:47
#
# Scraped 89 users this round
# Got 208 reivews
# 404450 reviews are now in the bag, so to speak
# 2024-04-01 18:10:39
#
# Scraped 110 users this round
# Got 182 reivews
# 404632 reviews are now in the bag, so to speak
# 2024-04-01 18:14:24
#
# Scraped 110 users this round
# Got 213 reivews
# 404845 reviews are now in the bag, so to speak
# 2024-04-01 18:18:17
#
# Scraped 100 users this round
# Got 188 reivews
# 405033 reviews are now in the bag, so to speak
# 2024-04-01 18:21:30
#
# Scraped 100 users this round
# Got 175 reivews
# 405208 reviews are now in the bag, so to speak
# 2024-04-01 18:24:52
#
# Scraped 115 users this round
# Got 195 reivews
# 405403 reviews are now in the bag, so to speak
# 2024-04-01 18:29:03
#
# Scraped 106 users this round
# Got 206 reivews
# 405609 reviews are now in the bag, so to speak
# 2024-04-01 18:32:40
#
# Scraped 135 users this round
# Got 197 reivews
# 405806 reviews are now in the bag, so to speak
# 2024-04-01 18:37:35
#
# Scraped 97 users this round
# Got 141 reivews
# 405947 reviews are now in the bag, so to speak
# 2024-04-01 18:40:52
#
# Scraped 120 users this round
# Got 170 reivews
# 406117 reviews are now in the bag, so to speak
# 2024-04-01 18:45:10
#
# Scraped 89 users this round
# Got 193 reivews
# 406310 reviews are now in the bag, so to speak
# 2024-04-01 18:48:14
#
# Scraped 88 users this round
# Got 195 reivews
# 406505 reviews are now in the bag, so to speak
# 2024-04-01 18:51:05
#
# Scraped 83 users this round
# Got 211 reivews
# 406716 reviews are now in the bag, so to speak
# 2024-04-01 18:53:45
#
# Scraped 127 users this round
# Got 158 reivews
# 406874 reviews are now in the bag, so to speak
# 2024-04-01 18:58:21
#
# Scraped 114 users this round
# Got 180 reivews
# 407054 reviews are now in the bag, so to speak
# 2024-04-01 19:02:13
#
# Scraped 105 users this round
# Got 216 reivews
# 407270 reviews are now in the bag, so to speak
# 2024-04-01 19:05:43
#
# Scraped 106 users this round
# Got 179 reivews
# 407449 reviews are now in the bag, so to speak
# 2024-04-01 19:09:26
#
# Scraped 105 users this round
# Got 160 reivews
# 407609 reviews are now in the bag, so to speak
# 2024-04-01 19:12:49
#
# Scraped 114 users this round
# Got 217 reivews
# 407826 reviews are now in the bag, so to speak
# 2024-04-01 19:16:55
#
# Scraped 101 users this round
# Got 171 reivews
# 407997 reviews are now in the bag, so to speak
# 2024-04-01 19:20:17
#
# Scraped 113 users this round
# Got 164 reivews
# 408161 reviews are now in the bag, so to speak
# 2024-04-01 19:24:22
#
# Scraped 101 users this round
# Got 197 reivews
# 408358 reviews are now in the bag, so to speak
# 2024-04-01 19:28:07
#
# Scraped 117 users this round
# Got 226 reivews
# 408584 reviews are now in the bag, so to speak
# 2024-04-01 19:32:19
#
# Scraped 133 users this round
# Got 190 reivews
# 408774 reviews are now in the bag, so to speak
# 2024-04-01 19:37:02
#
# Scraped 123 users this round
# Got 182 reivews
# 408956 reviews are now in the bag, so to speak
# 2024-04-01 19:41:45
#
# Scraped 120 users this round
# Got 161 reivews
# 409117 reviews are now in the bag, so to speak
# 2024-04-01 19:45:57
#
# Scraped 107 users this round
# Got 207 reivews
# 409324 reviews are now in the bag, so to speak
# 2024-04-01 19:49:29
#
# Scraped 95 users this round
# Got 172 reivews
# 409496 reviews are now in the bag, so to speak
# 2024-04-01 19:52:31
#
# Scraped 119 users this round
# Got 199 reivews
# 409695 reviews are now in the bag, so to speak
# 2024-04-01 19:56:41
#
# Scraped 100 users this round
# Got 155 reivews
# 409850 reviews are now in the bag, so to speak
# 2024-04-01 20:00:05
#
# Scraped 92 users this round
# Got 191 reivews
# 410041 reviews are now in the bag, so to speak
# 2024-04-01 20:03:28
#
# Scraped 109 users this round
# Got 189 reivews
# 410230 reviews are now in the bag, so to speak
# 2024-04-01 20:07:34
#
# Scraped 128 users this round
# Got 202 reivews
# 410432 reviews are now in the bag, so to speak
# 2024-04-01 20:15:27
#
# Scraped 97 users this round
# Got 172 reivews
# 410604 reviews are now in the bag, so to speak
# 2024-04-01 20:21:52
#
# Scraped 116 users this round
# Got 183 reivews
# 410787 reviews are now in the bag, so to speak
# 2024-04-01 20:29:44
#
# Scraped 119 users this round
# Got 232 reivews
# 411019 reviews are now in the bag, so to speak
# 2024-04-01 20:36:37
#
# Scraped 116 users this round
# Got 166 reivews
# 411185 reviews are now in the bag, so to speak
# 2024-04-01 20:43:03
#
# Scraped 122 users this round
# Got 182 reivews
# 411367 reviews are now in the bag, so to speak
# 2024-04-01 20:49:56
#
# Scraped 97 users this round
# Got 210 reivews
# 411577 reviews are now in the bag, so to speak
# 2024-04-01 20:56:05
#
# Scraped 114 users this round
# Got 205 reivews
# 411782 reviews are now in the bag, so to speak
# 2024-04-01 21:03:24
#
# Scraped 104 users this round
# Got 191 reivews
# 411973 reviews are now in the bag, so to speak
# 2024-04-01 21:09:25
#
# Scraped 114 users this round
# Got 181 reivews
# 412154 reviews are now in the bag, so to speak
# 2024-04-01 21:16:04
#
# Scraped 92 users this round
# Got 172 reivews
# 412326 reviews are now in the bag, so to speak
# 2024-04-01 21:21:36
#
# Scraped 89 users this round
# Got 140 reivews
# 412466 reviews are now in the bag, so to speak
# 2024-04-01 21:26:37
#
# Scraped 95 users this round
# Got 170 reivews
# 412636 reviews are now in the bag, so to speak
# 2024-04-01 21:32:53
#
# Scraped 115 users this round
# Got 224 reivews
# 412860 reviews are now in the bag, so to speak
# 2024-04-01 21:39:56
#
# Scraped 123 users this round
# Got 167 reivews
# 413027 reviews are now in the bag, so to speak
# 2024-04-01 21:47:23
#
# Scraped 115 users this round
# Got 181 reivews
# 413208 reviews are now in the bag, so to speak
# 2024-04-01 21:53:58
#
# Scraped 100 users this round
# Got 175 reivews
# 413383 reviews are now in the bag, so to speak
# 2024-04-01 22:00:07
#
# Unable to parse review blocks.
# Scraped 104 users this round
# Got 168 reivews
# 413551 reviews are now in the bag, so to speak
# 2024-04-01 22:07:29
#
# Scraped 135 users this round
# Got 214 reivews
# 413765 reviews are now in the bag, so to speak
# 2024-04-01 22:15:48
#
# Scraped 120 users this round
# Got 203 reivews
# 413968 reviews are now in the bag, so to speak
# 2024-04-01 22:22:59
#
# Scraped 127 users this round
# Got 176 reivews
# 414144 reviews are now in the bag, so to speak
# 2024-04-01 22:30:44
#
# Scraped 120 users this round
# Got 223 reivews
# 414367 reviews are now in the bag, so to speak
# 2024-04-01 22:37:39
#
# Scraped 105 users this round
# Got 191 reivews
# 414558 reviews are now in the bag, so to speak
# 2024-04-01 22:43:22
#
# Scraped 122 users this round
# Got 216 reivews
# 414774 reviews are now in the bag, so to speak
# 2024-04-01 22:49:35
#
# Scraped 111 users this round
# Got 201 reivews
# 414975 reviews are now in the bag, so to speak
# 2024-04-01 22:55:40
#
# Scraped 110 users this round
# Got 169 reivews
# 415144 reviews are now in the bag, so to speak
# 2024-04-01 23:01:32
#
# Scraped 95 users this round
# Got 179 reivews
# 415323 reviews are now in the bag, so to speak
# 2024-04-01 23:06:23
#
# Scraped 94 users this round
# Got 183 reivews
# 415506 reviews are now in the bag, so to speak
# 2024-04-01 23:10:48
#
# Scraped 119 users this round
# Got 195 reivews
# 415701 reviews are now in the bag, so to speak
# 2024-04-01 23:15:16
#
# Scraped 113 users this round
# Got 164 reivews
# 415865 reviews are now in the bag, so to speak
# 2024-04-01 23:19:21
#
# Scraped 109 users this round
# Got 176 reivews
# 416041 reviews are now in the bag, so to speak
# 2024-04-01 23:23:11
#
# Scraped 97 users this round
# Got 194 reivews
# 416235 reviews are now in the bag, so to speak
# 2024-04-01 23:26:28
#
# Scraped 118 users this round
# Got 149 reivews
# 416384 reviews are now in the bag, so to speak
# 2024-04-01 23:30:45
#
# Scraped 129 users this round
# Got 200 reivews
# 416584 reviews are now in the bag, so to speak
# 2024-04-01 23:35:32
#
# Scraped 105 users this round
# Got 230 reivews
# 416814 reviews are now in the bag, so to speak
# 2024-04-01 23:39:20
#
# Scraped 114 users this round
# Got 190 reivews
# 417004 reviews are now in the bag, so to speak
# 2024-04-01 23:43:19
#
# Scraped 117 users this round
# Got 181 reivews
# 417185 reviews are now in the bag, so to speak
# 2024-04-01 23:47:40
#
# Scraped 145 users this round
# Got 185 reivews
# 417370 reviews are now in the bag, so to speak
# 2024-04-01 23:53:32
#
# Scraped 103 users this round
# Got 210 reivews
# 417580 reviews are now in the bag, so to speak
# 2024-04-01 23:56:58
#
# Scraped 108 users this round
# Got 188 reivews
# 417768 reviews are now in the bag, so to speak
# 2024-04-02 00:00:42
#
# Scraped 98 users this round
# Got 203 reivews
# 417971 reviews are now in the bag, so to speak
# 2024-04-02 00:04:06
#
# Scraped 103 users this round
# Got 209 reivews
# 418180 reviews are now in the bag, so to speak
# 2024-04-02 00:07:41
#
# Scraped 116 users this round
# Got 227 reivews
# 418407 reviews are now in the bag, so to speak
# 2024-04-02 00:11:55
#
# Scraped 101 users this round
# Got 186 reivews
# 418593 reviews are now in the bag, so to speak
# 2024-04-02 00:15:36
#
# Scraped 106 users this round
# Got 169 reivews
# 418762 reviews are now in the bag, so to speak
# 2024-04-02 00:19:21
#
# Scraped 113 users this round
# Got 168 reivews
# 418930 reviews are now in the bag, so to speak
# 2024-04-02 00:23:26
#
# Scraped 114 users this round
# Got 164 reivews
# 419094 reviews are now in the bag, so to speak
# 2024-04-02 00:27:41
#
# Scraped 114 users this round
# Got 190 reivews
# 419284 reviews are now in the bag, so to speak
# 2024-04-02 00:31:47
#
# Scraped 102 users this round
# Got 190 reivews
# 419474 reviews are now in the bag, so to speak
# 2024-04-02 00:35:27
#
# Scraped 78 users this round
# Got 178 reivews
# 419652 reviews are now in the bag, so to speak
# 2024-04-02 00:37:56
#
# Scraped 126 users this round
# Got 171 reivews
# 419823 reviews are now in the bag, so to speak
# 2024-04-02 00:42:32
#
# Scraped 132 users this round
# Got 207 reivews
# 420030 reviews are now in the bag, so to speak
# 2024-04-02 00:47:29
#
# Scraped 102 users this round
# Got 230 reivews
# 420260 reviews are now in the bag, so to speak
# 2024-04-02 00:51:20
#
# Scraped 109 users this round
# Got 185 reivews
# 420445 reviews are now in the bag, so to speak
# 2024-04-02 00:55:13
#
# Scraped 93 users this round
# Got 213 reivews
# 420658 reviews are now in the bag, so to speak
# 2024-04-02 00:58:54
#
# Scraped 111 users this round
# Got 190 reivews
# 420848 reviews are now in the bag, so to speak
# 2024-04-02 01:02:59
#
# Scraped 110 users this round
# Got 140 reivews
# 420988 reviews are now in the bag, so to speak
# 2024-04-02 01:06:56
#
# Scraped 114 users this round
# Got 211 reivews
# 421199 reviews are now in the bag, so to speak
# ...
# 2024-04-02 23:04:29
#
# Scraped 138 users this round
# Got 174 reivews
# 482547 reviews are now in the bag, so to speak
# 2024-04-02 23:14:03
#
# Scraped 128 users this round
# Got 216 reivews
# 482763 reviews are now in the bag, so to speak
# 2024-04-02 23:23:07
#
# Scraped 123 users this round
# Got 196 reivews
# 482959 reviews are now in the bag, so to speak
# 2024-04-02 23:32:13
#
# Scraped 108 users this round
# Got 139 reivews
# 483098 reviews are now in the bag, so to speak
# 2024-04-02 23:39:26
#
# Scraped 126 users this round
# Got 165 reivews
# 483263 reviews are now in the bag, so to speak
# 2024-04-02 23:44:32
#
# Scraped 101 users this round
# Got 191 reivews
# 483454 reviews are now in the bag, so to speak
# 2024-04-02 23:48:03
#
# Scraped 125 users this round
# Got 213 reivews
# 483667 reviews are now in the bag, so to speak
# 2024-04-02 23:52:32
#
# Scraped 112 users this round
# Got 202 reivews
# 483869 reviews are now in the bag, so to speak
# 2024-04-02 23:56:40
#
# Scraped 112 users this round
# Got 161 reivews
# 484030 reviews are now in the bag, so to speak
# 2024-04-03 00:00:41
#
# Scraped 108 users this round
# Got 231 reivews
# 484261 reviews are now in the bag, so to speak
# 2024-04-03 00:04:35
#
# Scraped 122 users this round
# Got 220 reivews
# 484481 reviews are now in the bag, so to speak
# 2024-04-03 00:08:52
#
# Scraped 104 users this round
# Got 164 reivews
# 484645 reviews are now in the bag, so to speak
# 2024-04-03 00:12:31
#
# Scraped 110 users this round
# Got 213 reivews
# 484858 reviews are now in the bag, so to speak
# 2024-04-03 00:16:37
#
# Scraped 93 users this round
# Got 162 reivews
# 485020 reviews are now in the bag, so to speak
# 2024-04-03 00:19:36
#
# Scraped 128 users this round
# Got 172 reivews
# 485192 reviews are now in the bag, so to speak
# 2024-04-03 00:23:51
#
# Scraped 114 users this round
# Got 148 reivews
# 485340 reviews are now in the bag, so to speak
# 2024-04-03 00:27:34
#
# Scraped 114 users this round
# Got 186 reivews
# 485526 reviews are now in the bag, so to speak
# 2024-04-03 00:31:24
#
# Scraped 120 users this round
# Got 208 reivews
# 485734 reviews are now in the bag, so to speak
# 2024-04-03 00:35:25
#
# Scraped 112 users this round
# Got 152 reivews
# 485886 reviews are now in the bag, so to speak
# 2024-04-03 00:39:09
#
# Scraped 106 users this round
# Got 180 reivews
# 486066 reviews are now in the bag, so to speak
# 2024-04-03 00:42:37
#
# Scraped 106 users this round
# Got 205 reivews
# 486271 reviews are now in the bag, so to speak
# 2024-04-03 00:46:10
#
# Scraped 116 users this round
# Got 145 reivews
# 486416 reviews are now in the bag, so to speak
# 2024-04-03 00:50:07
#
# Scraped 104 users this round
# Got 175 reivews
# 486591 reviews are now in the bag, so to speak
# 2024-04-03 00:53:32
#
# Scraped 113 users this round
# Got 173 reivews
# 486764 reviews are now in the bag, so to speak
# 2024-04-03 00:57:21
#
# Scraped 121 users this round
# Got 217 reivews
# 486981 reviews are now in the bag, so to speak
# 2024-04-03 01:01:52
#
# Scraped 112 users this round
# Got 189 reivews
# 487170 reviews are now in the bag, so to speak
# 2024-04-03 01:05:58
#
# Scraped 104 users this round
# Got 204 reivews
# 487374 reviews are now in the bag, so to speak
# 2024-04-03 01:09:20
#
# Scraped 111 users this round
# Got 153 reivews
# 487527 reviews are now in the bag, so to speak
# 2024-04-03 01:13:00
#
# Scraped 141 users this round
# Got 189 reivews
# 487716 reviews are now in the bag, so to speak
# 2024-04-03 01:17:56
#
# Scraped 108 users this round
# Got 182 reivews
# 487898 reviews are now in the bag, so to speak
# 2024-04-03 01:21:36
#
# Scraped 115 users this round
# Got 181 reivews
# 488079 reviews are now in the bag, so to speak
# 2024-04-03 01:25:48
#
# Scraped 120 users this round
# Got 184 reivews
# 488263 reviews are now in the bag, so to speak
# 2024-04-03 01:30:01
#
# Scraped 108 users this round
# Got 212 reivews
# 488475 reviews are now in the bag, so to speak
# 2024-04-03 01:33:33
#
# Scraped 108 users this round
# Got 215 reivews
# 488690 reviews are now in the bag, so to speak
# 2024-04-03 01:37:10
#
# Scraped 133 users this round
# Got 209 reivews
# 488899 reviews are now in the bag, so to speak
# 2024-04-03 01:41:47
#
# Scraped 98 users this round
# Got 154 reivews
# 489053 reviews are now in the bag, so to speak
# 2024-04-03 01:45:08
#
# Scraped 92 users this round
# Got 174 reivews
# 489227 reviews are now in the bag, so to speak
# 2024-04-03 01:48:08
#
# Scraped 104 users this round
# Got 188 reivews
# 489415 reviews are now in the bag, so to speak
# 2024-04-03 01:51:50
#
# Scraped 100 users this round
# Got 235 reivews
# 489650 reviews are now in the bag, so to speak
# 2024-04-03 01:55:13
#
# Scraped 122 users this round
# Got 178 reivews
# 489828 reviews are now in the bag, so to speak
# 2024-04-03 01:59:19
#
# Scraped 111 users this round
# Got 171 reivews
# 489999 reviews are now in the bag, so to speak
# 2024-04-03 02:02:54
#
# Scraped 98 users this round
# Got 171 reivews
# 490170 reviews are now in the bag, so to speak
# 2024-04-03 02:05:53
#
# Scraped 111 users this round
# Got 186 reivews
# 490356 reviews are now in the bag, so to speak
# 2024-04-03 02:09:24
#
# Scraped 119 users this round
# Got 194 reivews
# 490550 reviews are now in the bag, so to speak
# 2024-04-03 02:13:31
#
# Scraped 113 users this round
# Got 193 reivews
# 490743 reviews are now in the bag, so to speak
# 2024-04-03 02:17:11
#
# Scraped 110 users this round
# Got 180 reivews
# 490923 reviews are now in the bag, so to speak
# 2024-04-03 02:21:03
#
# Scraped 129 users this round
# Got 251 reivews
# 491174 reviews are now in the bag, so to speak
# 2024-04-03 02:25:21
#
# Scraped 125 users this round
# Got 202 reivews
# 491376 reviews are now in the bag, so to speak
# 2024-04-03 02:29:29
#
# Scraped 116 users this round
# Got 208 reivews
# 491584 reviews are now in the bag, so to speak
# 2024-04-03 02:33:18
#
# Scraped 116 users this round
# Got 196 reivews
# 491780 reviews are now in the bag, so to speak
# 2024-04-03 02:37:23
#
# Scraped 102 users this round
# Got 185 reivews
# 491965 reviews are now in the bag, so to speak
# 2024-04-03 02:40:51
#
# Scraped 126 users this round
# Got 210 reivews
# 492175 reviews are now in the bag, so to speak
# 2024-04-03 02:44:56
#
# Scraped 114 users this round
# Got 200 reivews
# 492375 reviews are now in the bag, so to speak
# 2024-04-03 02:48:41
#
# Scraped 93 users this round
# Got 231 reivews
# 492606 reviews are now in the bag, so to speak
# 2024-04-03 02:51:37
#
# Scraped 134 users this round
# Got 158 reivews
# 492764 reviews are now in the bag, so to speak
# 2024-04-03 02:55:57
#
# Scraped 97 users this round
# Got 178 reivews
# 492942 reviews are now in the bag, so to speak
# 2024-04-03 02:58:54
#
# Scraped 103 users this round
# Got 159 reivews
# 493101 reviews are now in the bag, so to speak
# 2024-04-03 03:02:15
#
# Scraped 109 users this round
# Got 134 reivews
# 493235 reviews are now in the bag, so to speak
# 2024-04-03 03:05:46
#
# Scraped 105 users this round
# Got 166 reivews
# 493401 reviews are now in the bag, so to speak
# 2024-04-03 03:09:13
#
# Scraped 104 users this round
# Got 182 reivews
# 493583 reviews are now in the bag, so to speak
# 2024-04-03 03:12:31
#
# Scraped 88 users this round
# Got 179 reivews
# 493762 reviews are now in the bag, so to speak
# 2024-04-03 03:15:23
#
# Scraped 110 users this round
# Got 175 reivews
# 493937 reviews are now in the bag, so to speak
# 2024-04-03 03:19:20
#
# Scraped 107 users this round
# Got 182 reivews
# 494119 reviews are now in the bag, so to speak
# 2024-04-03 03:22:40
#
# Scraped 106 users this round
# Got 179 reivews
# 494298 reviews are now in the bag, so to speak
# 2024-04-03 03:26:12
#
# Scraped 97 users this round
# Got 187 reivews
# 494485 reviews are now in the bag, so to speak
# 2024-04-03 03:29:26
#
# Scraped 127 users this round
# Got 160 reivews
# 494645 reviews are now in the bag, so to speak
# 2024-04-03 03:33:47
#
# Scraped 94 users this round
# Got 206 reivews
# 494851 reviews are now in the bag, so to speak
# 2024-04-03 03:36:39
#
# Scraped 131 users this round
# Got 156 reivews
# 495007 reviews are now in the bag, so to speak
# 2024-04-03 03:41:14
#
# Scraped 134 users this round
# Got 191 reivews
# 495198 reviews are now in the bag, so to speak
# 2024-04-03 03:45:51
#
# Scraped 122 users this round
# Got 169 reivews
# 495367 reviews are now in the bag, so to speak
# 2024-04-03 03:50:03
#
# Scraped 102 users this round
# Got 230 reivews
# 495597 reviews are now in the bag, so to speak
# 2024-04-03 03:53:26
#
# Scraped 95 users this round
# Got 159 reivews
# 495756 reviews are now in the bag, so to speak
# 2024-04-03 03:56:45
#
# Scraped 113 users this round
# Got 198 reivews
# 495954 reviews are now in the bag, so to speak
# 2024-04-03 04:00:20
#
# Scraped 131 users this round
# Got 163 reivews
# 496117 reviews are now in the bag, so to speak
# 2024-04-03 04:04:33
#
# Scraped 114 users this round
# Got 197 reivews
# 496314 reviews are now in the bag, so to speak
# 2024-04-03 04:08:27
#
# Scraped 102 users this round
# Got 218 reivews
# 496532 reviews are now in the bag, so to speak
# 2024-04-03 04:11:53
#
# Scraped 96 users this round
# Got 152 reivews
# 496684 reviews are now in the bag, so to speak
# 2024-04-03 04:15:10
#
# Scraped 125 users this round
# Got 161 reivews
# 496845 reviews are now in the bag, so to speak
# 2024-04-03 04:19:11
#
# Scraped 106 users this round
# Got 205 reivews
# 497050 reviews are now in the bag, so to speak
# 2024-04-03 04:22:39
#
# Scraped 108 users this round
# Got 181 reivews
# 497231 reviews are now in the bag, so to speak
# 2024-04-03 04:26:15
#
# Scraped 114 users this round
# Got 164 reivews
# 497395 reviews are now in the bag, so to speak
# 2024-04-03 04:29:53
#
# Scraped 119 users this round
# Got 149 reivews
# 497544 reviews are now in the bag, so to speak
# 2024-04-03 04:33:45
#
# Scraped 88 users this round
# Got 169 reivews
# 497713 reviews are now in the bag, so to speak
# 2024-04-03 04:36:39
#
# Scraped 113 users this round
# Got 212 reivews
# 497925 reviews are now in the bag, so to speak
# 2024-04-03 04:40:28
#
# Scraped 132 users this round
# Got 204 reivews
# 498129 reviews are now in the bag, so to speak
# 2024-04-03 04:45:14
#
# Scraped 98 users this round
# Got 172 reivews
# 498301 reviews are now in the bag, so to speak
# 2024-04-03 04:48:19
#
# Scraped 120 users this round
# Got 179 reivews
# 498480 reviews are now in the bag, so to speak
# 2024-04-03 04:52:22
#
# Scraped 100 users this round
# Got 143 reivews
# 498623 reviews are now in the bag, so to speak
# 2024-04-03 04:55:22
#
# Scraped 104 users this round
# Got 179 reivews
# 498802 reviews are now in the bag, so to speak
# 2024-04-03 04:58:44
#
# Scraped 124 users this round
# Got 184 reivews
# 498986 reviews are now in the bag, so to speak
# 2024-04-03 05:03:09
#
# Scraped 127 users this round
# Got 177 reivews
# 499163 reviews are now in the bag, so to speak
# 2024-04-03 05:07:22
#
# Scraped 101 users this round
# Got 197 reivews
# 499360 reviews are now in the bag, so to speak
# 2024-04-03 05:10:38
#
# Scraped 100 users this round
# Got 189 reivews
# 499549 reviews are now in the bag, so to speak
# 2024-04-03 05:13:49
#
# Scraped 112 users this round
# Got 184 reivews
# 499733 reviews are now in the bag, so to speak
# 2024-04-03 05:17:35
#
# Scraped 108 users this round
# Got 185 reivews
# 499918 reviews are now in the bag, so to speak
# 2024-04-03 05:21:07
#
# Scraped 115 users this round
# Got 182 reivews
# 500100 reviews are now in the bag, so to speak
# 2024-04-03 05:24:53
#
# Scraped 110 users this round
# Got 169 reivews
# 500269 reviews are now in the bag, so to speak
# 2024-04-03 05:28:37
#
# Scraped 115 users this round
# Got 170 reivews
# 500439 reviews are now in the bag, so to speak
# 2024-04-03 05:32:31
#
# Scraped 115 users this round
# Got 217 reivews
# 500656 reviews are now in the bag, so to speak
# 2024-04-03 05:36:20
#
# Scraped 123 users this round
# Got 198 reivews
# 500854 reviews are now in the bag, so to speak
# 2024-04-03 05:40:41
#
# Scraped 120 users this round
# Got 199 reivews
# 501053 reviews are now in the bag, so to speak
# 2024-04-03 05:44:44
#
# Scraped 101 users this round
# Got 160 reivews
# 501213 reviews are now in the bag, so to speak
# 2024-04-03 05:48:07
#
# Scraped 104 users this round
# Got 193 reivews
# 501406 reviews are now in the bag, so to speak
# 2024-04-03 05:51:33
#
# Scraped 121 users this round
# Got 136 reivews
# 501542 reviews are now in the bag, so to speak
# 2024-04-03 05:55:25
#
# Scraped 99 users this round
# Got 180 reivews
# 501722 reviews are now in the bag, so to speak
# 2024-04-03 05:58:47
#
# Scraped 111 users this round
# Got 167 reivews
# 501889 reviews are now in the bag, so to speak
# 2024-04-03 06:02:24
#
# Scraped 124 users this round
# Got 208 reivews
# 502097 reviews are now in the bag, so to speak
# 2024-04-03 06:06:28
#
# Scraped 132 users this round
# Got 170 reivews
# 502267 reviews are now in the bag, so to speak
# 2024-04-03 06:10:57
#
# Scraped 121 users this round
# Got 183 reivews
# 502450 reviews are now in the bag, so to speak
# 2024-04-03 06:15:03
#
# Scraped 119 users this round
# Got 183 reivews
# 502633 reviews are now in the bag, so to speak
# 2024-04-03 06:19:10
#
# Scraped 95 users this round
# Got 150 reivews
# 502783 reviews are now in the bag, so to speak
# 2024-04-03 06:22:12
#
# Scraped 100 users this round
# Got 177 reivews
# 502960 reviews are now in the bag, so to speak
# 2024-04-03 06:25:18
#
# Scraped 102 users this round
# Got 139 reivews
# 503099 reviews are now in the bag, so to speak
# 2024-04-03 06:28:36
#
# Scraped 102 users this round
# Got 219 reivews
# 503318 reviews are now in the bag, so to speak
# 2024-04-03 06:32:41
#
# Scraped 113 users this round
# Got 215 reivews
# 503533 reviews are now in the bag, so to speak
# 2024-04-03 06:36:52
#
# Scraped 107 users this round
# Got 193 reivews
# 503726 reviews are now in the bag, so to speak
# 2024-04-03 06:40:58
#
# Scraped 151 users this round
# Got 201 reivews
# 503927 reviews are now in the bag, so to speak
# 2024-04-03 06:46:17
#
# Scraped 103 users this round
# Got 143 reivews
# 504070 reviews are now in the bag, so to speak
# 2024-04-03 06:49:33
#
# Scraped 113 users this round
# Got 122 reivews
# 504192 reviews are now in the bag, so to speak
# 2024-04-03 06:53:17
#
# Scraped 96 users this round
# Got 220 reivews
# 504412 reviews are now in the bag, so to speak
# 2024-04-03 06:56:18
#
# Scraped 107 users this round
# Got 174 reivews
# 504586 reviews are now in the bag, so to speak
# 2024-04-03 06:59:51
#
# Scraped 112 users this round
# Got 161 reivews
# 504747 reviews are now in the bag, so to speak
# 2024-04-03 07:03:34
#
# Scraped 108 users this round
# Got 178 reivews
# 504925 reviews are now in the bag, so to speak
# 2024-04-03 07:07:27
#
# Scraped 99 users this round
# Got 188 reivews
# 505113 reviews are now in the bag, so to speak
# 2024-04-03 07:10:51
#
# Scraped 110 users this round
# Got 212 reivews
# 505325 reviews are now in the bag, so to speak
# 2024-04-03 07:14:40
#
# Scraped 99 users this round
# Got 153 reivews
# 505478 reviews are now in the bag, so to speak
# 2024-04-03 07:17:50
#
# Scraped 124 users this round
# Got 168 reivews
# 505646 reviews are now in the bag, so to speak
# 2024-04-03 07:22:50
#
# Scraped 122 users this round
# Got 192 reivews
# 505838 reviews are now in the bag, so to speak
# 2024-04-03 07:26:55
#
# Scraped 111 users this round
# Got 187 reivews
# 506025 reviews are now in the bag, so to speak
# 2024-04-03 07:31:24
#
# Scraped 100 users this round
# Got 184 reivews
# 506209 reviews are now in the bag, so to speak
# 2024-04-03 07:34:42
#
# Scraped 110 users this round
# Got 213 reivews
# 506422 reviews are now in the bag, so to speak
# 2024-04-03 07:38:37
#
# Scraped 100 users this round
# Got 207 reivews
# 506629 reviews are now in the bag, so to speak
# 2024-04-03 07:41:51
#
# Scraped 86 users this round
# Got 173 reivews
# 506802 reviews are now in the bag, so to speak
# 2024-04-03 07:44:44
#
# Scraped 121 users this round
# Got 163 reivews
# 506965 reviews are now in the bag, so to speak
# 2024-04-03 07:49:03
#
# Scraped 104 users this round
# Got 172 reivews
# 507137 reviews are now in the bag, so to speak
# 2024-04-03 07:52:35
#
# Scraped 128 users this round
# Got 172 reivews
# 507309 reviews are now in the bag, so to speak
# 2024-04-03 07:57:07
#
# Scraped 115 users this round
# Got 181 reivews
# 507490 reviews are now in the bag, so to speak
# 2024-04-03 08:00:59
#
# Scraped 111 users this round
# Got 186 reivews
# 507676 reviews are now in the bag, so to speak
# 2024-04-03 08:04:58
#
# Scraped 105 users this round
# Got 208 reivews
# 507884 reviews are now in the bag, so to speak
# 2024-04-03 08:08:42
#
# Scraped 105 users this round
# Got 206 reivews
# 508090 reviews are now in the bag, so to speak
# 2024-04-03 08:12:22
#
# Scraped 127 users this round
# Got 217 reivews
# 508307 reviews are now in the bag, so to speak
# 2024-04-03 08:18:08
#
# Unable to parse review blocks.
