# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')


# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 122 users this round
# Got 186 reivews
# 272356 reviews are now in the bag, so to speak
# 2024-03-30 11:11:53
#
# Scraped 105 users this round
# Got 188 reivews
# 272544 reviews are now in the bag, so to speak
# 2024-03-30 11:15:31
#
# Scraped 104 users this round
# Got 187 reivews
# 272731 reviews are now in the bag, so to speak
# 2024-03-30 11:19:08
#
# Scraped 109 users this round
# Got 200 reivews
# 272931 reviews are now in the bag, so to speak
# 2024-03-30 11:22:50
#
# Scraped 100 users this round
# Got 180 reivews
# 273111 reviews are now in the bag, so to speak
# 2024-03-30 11:26:13
#
# Scraped 86 users this round
# Got 187 reivews
# 273298 reviews are now in the bag, so to speak
# 2024-03-30 11:28:57
#
# Scraped 129 users this round
# Got 163 reivews
# 273461 reviews are now in the bag, so to speak
# 2024-03-30 11:33:40
#
# Scraped 114 users this round
# Got 178 reivews
# 273639 reviews are now in the bag, so to speak
# 2024-03-30 11:37:32
#
# Scraped 107 users this round
# Got 152 reivews
# 273791 reviews are now in the bag, so to speak
# 2024-03-30 11:41:11
#
# Scraped 97 users this round
# Got 177 reivews
# 273968 reviews are now in the bag, so to speak
# 2024-03-30 11:44:15
#
# Scraped 132 users this round
# Got 154 reivews
# 274122 reviews are now in the bag, so to speak
# 2024-03-30 11:48:56
#
# Scraped 99 users this round
# Got 189 reivews
# 274311 reviews are now in the bag, so to speak
# 2024-03-30 11:52:26
#
# Scraped 112 users this round
# Got 236 reivews
# 274547 reviews are now in the bag, so to speak
# 2024-03-30 11:56:19
#
# Scraped 105 users this round
# Got 163 reivews
# 274710 reviews are now in the bag, so to speak
# 2024-03-30 11:59:56
#
# Scraped 95 users this round
# Got 192 reivews
# 274902 reviews are now in the bag, so to speak
# 2024-03-30 12:03:13
#
# Scraped 113 users this round
# Got 202 reivews
# 275104 reviews are now in the bag, so to speak
# 2024-03-30 12:07:09
#
# Scraped 109 users this round
# Got 143 reivews
# 275247 reviews are now in the bag, so to speak
# 2024-03-30 12:10:51
#
# Scraped 114 users this round
# Got 160 reivews
# 275407 reviews are now in the bag, so to speak
# 2024-03-30 12:14:43
#
# Scraped 121 users this round
# Got 166 reivews
# 275573 reviews are now in the bag, so to speak
# 2024-03-30 12:19:07
#
# Scraped 102 users this round
# Got 184 reivews
# 275757 reviews are now in the bag, so to speak
# 2024-03-30 12:22:41
#
# Scraped 108 users this round
# Got 219 reivews
# 275976 reviews are now in the bag, so to speak
# 2024-03-30 12:26:30
#
# Scraped 112 users this round
# Got 205 reivews
# 276181 reviews are now in the bag, so to speak
# 2024-03-30 12:30:31
#
# Scraped 103 users this round
# Got 228 reivews
# 276409 reviews are now in the bag, so to speak
# 2024-03-30 12:34:04
#
# Scraped 119 users this round
# Got 206 reivews
# 276615 reviews are now in the bag, so to speak
# 2024-03-30 12:38:28
#
# Scraped 112 users this round
# Got 179 reivews
# 276794 reviews are now in the bag, so to speak
# 2024-03-30 12:42:31
#
# Scraped 123 users this round
# Got 198 reivews
# 276992 reviews are now in the bag, so to speak
# 2024-03-30 12:46:47
#
# Scraped 96 users this round
# Got 187 reivews
# 277179 reviews are now in the bag, so to speak
# 2024-03-30 12:50:12
#
# Scraped 133 users this round
# Got 204 reivews
# 277383 reviews are now in the bag, so to speak
# 2024-03-30 12:55:05
#
# Scraped 112 users this round
# Got 148 reivews
# 277531 reviews are now in the bag, so to speak
# 2024-03-30 12:58:57
#
# Scraped 122 users this round
# Got 170 reivews
# 277701 reviews are now in the bag, so to speak
# 2024-03-30 13:03:28
#
# Scraped 97 users this round
# Got 227 reivews
# 277928 reviews are now in the bag, so to speak
# 2024-03-30 13:06:50
#
# Scraped 107 users this round
# Got 231 reivews
# 278159 reviews are now in the bag, so to speak
# 2024-03-30 13:10:35
#
# Scraped 113 users this round
# Got 196 reivews
# 278355 reviews are now in the bag, so to speak
# 2024-03-30 13:14:30
#
# Scraped 103 users this round
# Got 233 reivews
# 278588 reviews are now in the bag, so to speak
# 2024-03-30 13:17:59
#
# Scraped 106 users this round
# Got 209 reivews
# 278797 reviews are now in the bag, so to speak
# 2024-03-30 13:21:50
#
# Scraped 91 users this round
# Got 161 reivews
# 278958 reviews are now in the bag, so to speak
# 2024-03-30 13:24:53
#
# Scraped 101 users this round
# Got 164 reivews
# 279122 reviews are now in the bag, so to speak
# 2024-03-30 13:28:08
#
# Scraped 108 users this round
# Got 141 reivews
# 279263 reviews are now in the bag, so to speak
# 2024-03-30 13:31:51
#
# Scraped 122 users this round
# Got 217 reivews
# 279480 reviews are now in the bag, so to speak
# 2024-03-30 13:36:17
#
# Scraped 122 users this round
# Got 148 reivews
# 279628 reviews are now in the bag, so to speak
# 2024-03-30 13:40:26
#
# Scraped 118 users this round
# Got 198 reivews
# 279826 reviews are now in the bag, so to speak
# 2024-03-30 13:44:44
#
# Scraped 96 users this round
# Got 189 reivews
# 280015 reviews are now in the bag, so to speak
# 2024-03-30 13:48:00
#
# Scraped 116 users this round
# Got 208 reivews
# 280223 reviews are now in the bag, so to speak
# 2024-03-30 13:52:04
#
# Scraped 107 users this round
# Got 202 reivews
# 280425 reviews are now in the bag, so to speak
# 2024-03-30 13:55:40
#
# Scraped 97 users this round
# Got 161 reivews
# 280586 reviews are now in the bag, so to speak
# 2024-03-30 13:59:08
#
# Scraped 106 users this round
# Got 150 reivews
# 280736 reviews are now in the bag, so to speak
# 2024-03-30 14:02:57
#
# Scraped 121 users this round
# Got 188 reivews
# 280924 reviews are now in the bag, so to speak
# 2024-03-30 14:07:11
#
# Scraped 90 users this round
# Got 203 reivews
# 281127 reviews are now in the bag, so to speak
# 2024-03-30 14:10:20
#
# Scraped 108 users this round
# Got 252 reivews
# 281379 reviews are now in the bag, so to speak
# 2024-03-30 14:14:05
#
# Scraped 93 users this round
# Got 175 reivews
# 281554 reviews are now in the bag, so to speak
# 2024-03-30 14:17:21
#
# Scraped 112 users this round
# Got 205 reivews
# 281759 reviews are now in the bag, so to speak
# 2024-03-30 14:21:13
#
# Scraped 120 users this round
# Got 139 reivews
# 281898 reviews are now in the bag, so to speak
# 2024-03-30 14:25:32
#
# Scraped 121 users this round
# Got 221 reivews
# 282119 reviews are now in the bag, so to speak
# 2024-03-30 14:30:00
#
# Scraped 110 users this round
# Got 198 reivews
# 282317 reviews are now in the bag, so to speak
# 2024-03-30 14:33:50
#
# Scraped 113 users this round
# Got 192 reivews
# 282509 reviews are now in the bag, so to speak
# 2024-03-30 14:38:04
#
# Scraped 131 users this round
# Got 157 reivews
# 282666 reviews are now in the bag, so to speak
# 2024-03-30 14:42:31
#
# Scraped 124 users this round
# Got 216 reivews
# 282882 reviews are now in the bag, so to speak
# 2024-03-30 14:46:51
#
# Scraped 107 users this round
# Got 193 reivews
# 283075 reviews are now in the bag, so to speak
# 2024-03-30 14:50:32
#
# Scraped 108 users this round
# Got 219 reivews
# 283294 reviews are now in the bag, so to speak
# 2024-03-30 14:54:15
#
# Scraped 107 users this round
# Got 207 reivews
# 283501 reviews are now in the bag, so to speak
# 2024-03-30 14:58:14
#
# Scraped 100 users this round
# Got 224 reivews
# 283725 reviews are now in the bag, so to speak
# 2024-03-30 15:02:05
#
# Scraped 103 users this round
# Got 187 reivews
# 283912 reviews are now in the bag, so to speak
# 2024-03-30 15:05:33
#
# Scraped 127 users this round
# Got 224 reivews
# 284136 reviews are now in the bag, so to speak
# 2024-03-30 15:09:56
#
# Scraped 136 users this round
# Got 179 reivews
# 284315 reviews are now in the bag, so to speak
# 2024-03-30 15:15:02
#
# Scraped 101 users this round
# Got 183 reivews
# 284498 reviews are now in the bag, so to speak
# 2024-03-30 15:18:34
#
# Scraped 105 users this round
# Got 203 reivews
# 284701 reviews are now in the bag, so to speak
# 2024-03-30 15:22:12
#
# Scraped 142 users this round
# Got 147 reivews
# 284848 reviews are now in the bag, so to speak
# 2024-03-30 15:27:15
#
# Scraped 121 users this round
# Got 156 reivews
# 285004 reviews are now in the bag, so to speak
# 2024-03-30 15:31:35
#
# Scraped 103 users this round
# Got 170 reivews
# 285174 reviews are now in the bag, so to speak
# 2024-03-30 15:35:22
#
# Scraped 105 users this round
# Got 156 reivews
# 285330 reviews are now in the bag, so to speak
# 2024-03-30 15:39:12
#
# Scraped 98 users this round
# Got 172 reivews
# 285502 reviews are now in the bag, so to speak
# 2024-03-30 15:42:26
#
# Scraped 108 users this round
# Got 184 reivews
# 285686 reviews are now in the bag, so to speak
# 2024-03-30 15:46:10
#
# Scraped 101 users this round
# Got 179 reivews
# 285865 reviews are now in the bag, so to speak
# 2024-03-30 15:49:37
#
# Scraped 102 users this round
# Got 174 reivews
# 286039 reviews are now in the bag, so to speak
# 2024-03-30 15:53:16
#
# Scraped 134 users this round
# Got 154 reivews
# 286193 reviews are now in the bag, so to speak
# 2024-03-30 15:58:15
#
# Scraped 128 users this round
# Got 177 reivews
# 286370 reviews are now in the bag, so to speak
# 2024-03-30 16:02:48
#
# Scraped 96 users this round
# Got 175 reivews
# 286545 reviews are now in the bag, so to speak
# 2024-03-30 16:06:09
#
# Scraped 117 users this round
# Got 171 reivews
# 286716 reviews are now in the bag, so to speak
# 2024-03-30 16:10:30
#
# Scraped 112 users this round
# Got 146 reivews
# 286862 reviews are now in the bag, so to speak
# 2024-03-30 16:14:24
#
# Scraped 116 users this round
# Got 185 reivews
# 287047 reviews are now in the bag, so to speak
# 2024-03-30 16:18:48
#
# Scraped 102 users this round
# Got 187 reivews
# 287234 reviews are now in the bag, so to speak
# 2024-03-30 16:22:16
#
# Scraped 112 users this round
# Got 207 reivews
# 287441 reviews are now in the bag, so to speak
# 2024-03-30 16:26:08
#
# Scraped 102 users this round
# Got 164 reivews
# 287605 reviews are now in the bag, so to speak
# 2024-03-30 16:29:51
#
# Scraped 113 users this round
# Got 192 reivews
# 287797 reviews are now in the bag, so to speak
# 2024-03-30 16:33:39
#
# Scraped 97 users this round
# Got 205 reivews
# 288002 reviews are now in the bag, so to speak
# 2024-03-30 16:36:59
#
# Scraped 105 users this round
# Got 202 reivews
# 288204 reviews are now in the bag, so to speak
# 2024-03-30 16:40:42
#
# Scraped 113 users this round
# Got 229 reivews
# 288433 reviews are now in the bag, so to speak
# 2024-03-30 16:44:41
#
# Scraped 108 users this round
# Got 154 reivews
# 288587 reviews are now in the bag, so to speak
# 2024-03-30 16:48:22
#
# Scraped 123 users this round
# Got 195 reivews
# 288782 reviews are now in the bag, so to speak
# 2024-03-30 16:52:37
#
# Scraped 120 users this round
# Got 184 reivews
# 288966 reviews are now in the bag, so to speak
# 2024-03-30 16:56:57
#
# Scraped 115 users this round
# Got 171 reivews
# 289137 reviews are now in the bag, so to speak
# 2024-03-30 17:01:09
#
# Scraped 124 users this round
# Got 166 reivews
# 289303 reviews are now in the bag, so to speak
# 2024-03-30 17:05:43
#
# Scraped 109 users this round
# Got 205 reivews
# 289508 reviews are now in the bag, so to speak
# 2024-03-30 17:09:34
#
# Scraped 105 users this round
# Got 171 reivews
# 289679 reviews are now in the bag, so to speak
# 2024-03-30 17:13:21
#
# Scraped 119 users this round
# Got 176 reivews
# 289855 reviews are now in the bag, so to speak
# 2024-03-30 17:17:39
#
# Scraped 99 users this round
# Got 187 reivews
# 290042 reviews are now in the bag, so to speak
# 2024-03-30 17:21:03
#
# Scraped 98 users this round
# Got 207 reivews
# 290249 reviews are now in the bag, so to speak
# 2024-03-30 17:24:32
#
# Scraped 97 users this round
# Got 196 reivews
# 290445 reviews are now in the bag, so to speak
# 2024-03-30 17:27:44
#
# Scraped 117 users this round
# Got 176 reivews
# 290621 reviews are now in the bag, so to speak
# 2024-03-30 17:32:08
#
# Scraped 111 users this round
# Got 195 reivews
# 290816 reviews are now in the bag, so to speak
# 2024-03-30 17:36:08
#
# Scraped 98 users this round
# Got 187 reivews
# 291003 reviews are now in the bag, so to speak
# 2024-03-30 17:39:21
#
# Scraped 125 users this round
# Got 172 reivews
# 291175 reviews are now in the bag, so to speak
# 2024-03-30 17:44:00
#
# Scraped 116 users this round
# Got 146 reivews
# 291321 reviews are now in the bag, so to speak
# 2024-03-30 17:48:16
#
# Scraped 121 users this round
# Got 165 reivews
# 291486 reviews are now in the bag, so to speak
# 2024-03-30 17:52:32
#
# Scraped 94 users this round
# Got 245 reivews
# 291731 reviews are now in the bag, so to speak
# 2024-03-30 17:55:53
#
# Scraped 94 users this round
# Got 194 reivews
# 291925 reviews are now in the bag, so to speak
# 2024-03-30 17:59:12
#
# Scraped 109 users this round
# Got 188 reivews
# 292113 reviews are now in the bag, so to speak
# 2024-03-30 18:03:04
#
# Scraped 119 users this round
# Got 158 reivews
# 292271 reviews are now in the bag, so to speak
# 2024-03-30 18:07:20
#
# Scraped 121 users this round
# Got 170 reivews
# 292441 reviews are now in the bag, so to speak
# 2024-03-30 18:11:43
#
# Scraped 100 users this round
# Got 174 reivews
# 292615 reviews are now in the bag, so to speak
# 2024-03-30 18:15:18
#
# Scraped 114 users this round
# Got 158 reivews
# 292773 reviews are now in the bag, so to speak
# 2024-03-30 18:19:18
#
# Scraped 99 users this round
# Got 211 reivews
# 292984 reviews are now in the bag, so to speak
# 2024-03-30 18:22:39
#
# Scraped 96 users this round
# Got 196 reivews
# 293180 reviews are now in the bag, so to speak
# 2024-03-30 18:25:58
#
# Scraped 112 users this round
# Got 182 reivews
# 293362 reviews are now in the bag, so to speak
# 2024-03-30 18:30:03
#
# Scraped 110 users this round
# Got 218 reivews
# 293580 reviews are now in the bag, so to speak
# 2024-03-30 18:33:48
#
# Scraped 107 users this round
# Got 186 reivews
# 293766 reviews are now in the bag, so to speak
# 2024-03-30 18:37:41
#
# Scraped 104 users this round
# Got 166 reivews
# 293932 reviews are now in the bag, so to speak
# 2024-03-30 18:41:27
#
# Scraped 90 users this round
# Got 224 reivews
# 294156 reviews are now in the bag, so to speak
# 2024-03-30 18:44:46
#
# Scraped 117 users this round
# Got 182 reivews
# 294338 reviews are now in the bag, so to speak
# 2024-03-30 18:49:02
#
# Scraped 107 users this round
# Got 175 reivews
# 294513 reviews are now in the bag, so to speak
# 2024-03-30 18:52:47
#
# Scraped 97 users this round
# Got 205 reivews
# 294718 reviews are now in the bag, so to speak
# 2024-03-30 18:56:05
#
# Scraped 102 users this round
# Got 191 reivews
# 294909 reviews are now in the bag, so to speak
# 2024-03-30 18:59:40
#
# Scraped 101 users this round
# Got 166 reivews
# 295075 reviews are now in the bag, so to speak
# 2024-03-30 19:03:11
#
# Scraped 112 users this round
# Got 178 reivews
# 295253 reviews are now in the bag, so to speak
# 2024-03-30 19:07:03
#
# Scraped 84 users this round
# Got 208 reivews
# 295461 reviews are now in the bag, so to speak
# 2024-03-30 19:09:50
#
# Scraped 123 users this round
# Got 188 reivews
# 295649 reviews are now in the bag, so to speak
# 2024-03-30 19:14:25
#
# Scraped 100 users this round
# Got 204 reivews
# 295853 reviews are now in the bag, so to speak
# 2024-03-30 19:17:43
#
# Scraped 104 users this round
# Got 207 reivews
# 296060 reviews are now in the bag, so to speak
# 2024-03-30 19:21:25
#
# Scraped 104 users this round
# Got 194 reivews
# 296254 reviews are now in the bag, so to speak
# 2024-03-30 19:25:01
#
# Scraped 119 users this round
# Got 215 reivews
# 296469 reviews are now in the bag, so to speak
# 2024-03-30 19:29:29
#
# Scraped 119 users this round
# Got 207 reivews
# 296676 reviews are now in the bag, so to speak
# 2024-03-30 19:33:41
#
# Scraped 133 users this round
# Got 175 reivews
# 296851 reviews are now in the bag, so to speak
# 2024-03-30 19:38:18
#
# Scraped 124 users this round
# Got 201 reivews
# 297052 reviews are now in the bag, so to speak
# 2024-03-30 19:42:49
#
# Scraped 132 users this round
# Got 173 reivews
# 297225 reviews are now in the bag, so to speak
# 2024-03-30 19:47:26
#
# Scraped 109 users this round
# Got 174 reivews
# 297399 reviews are now in the bag, so to speak
# 2024-03-30 19:51:15
#
# Scraped 106 users this round
# Got 187 reivews
# 297586 reviews are now in the bag, so to speak
# 2024-03-30 19:54:56
#
# Scraped 102 users this round
# Got 172 reivews
# 297758 reviews are now in the bag, so to speak
# 2024-03-30 19:58:43
#
# Scraped 117 users this round
# Got 174 reivews
# 297932 reviews are now in the bag, so to speak
# 2024-03-30 20:02:47
#
# Scraped 123 users this round
# Got 196 reivews
# 298128 reviews are now in the bag, so to speak
# 2024-03-30 20:07:11
#
# Scraped 101 users this round
# Got 216 reivews
# 298344 reviews are now in the bag, so to speak
# 2024-03-30 20:11:03
#
# Scraped 93 users this round
# Got 211 reivews
# 298555 reviews are now in the bag, so to speak
# 2024-03-30 20:14:12
#
# Scraped 105 users this round
# Got 160 reivews
# 298715 reviews are now in the bag, so to speak
# 2024-03-30 20:17:55
#
# Scraped 98 users this round
# Got 185 reivews
# 298900 reviews are now in the bag, so to speak
# 2024-03-30 20:21:11
#
# Scraped 122 users this round
# Got 212 reivews
# 299112 reviews are now in the bag, so to speak
# 2024-03-30 20:25:50
#
# Scraped 91 users this round
# Got 210 reivews
# 299322 reviews are now in the bag, so to speak
# 2024-03-30 20:28:55
#
# Scraped 101 users this round
# Got 195 reivews
# 299517 reviews are now in the bag, so to speak
# 2024-03-30 20:32:34
#
# Scraped 99 users this round
# Got 153 reivews
# 299670 reviews are now in the bag, so to speak
# 2024-03-30 20:35:50
#
# Scraped 111 users this round
# Got 163 reivews
# 299833 reviews are now in the bag, so to speak
# 2024-03-30 20:39:43
#
# Scraped 124 users this round
# Got 173 reivews
# 300006 reviews are now in the bag, so to speak
# 2024-03-30 20:44:19
#
# Scraped 102 users this round
# Got 174 reivews
# 300180 reviews are now in the bag, so to speak
# 2024-03-30 20:47:44
#
# Scraped 110 users this round
# Got 176 reivews
# 300356 reviews are now in the bag, so to speak
# 2024-03-30 20:51:51
#
# Scraped 97 users this round
# Got 214 reivews
# 300570 reviews are now in the bag, so to speak
# 2024-03-30 20:55:17
#
# Scraped 105 users this round
# Got 217 reivews
# 300787 reviews are now in the bag, so to speak
# 2024-03-30 20:59:05
#
# Scraped 119 users this round
# Got 201 reivews
# 300988 reviews are now in the bag, so to speak
# 2024-03-30 21:03:20
#
# Scraped 108 users this round
# Got 169 reivews
# 301157 reviews are now in the bag, so to speak
# 2024-03-30 21:06:59
#
# Scraped 99 users this round
# Got 177 reivews
# 301334 reviews are now in the bag, so to speak
# 2024-03-30 21:10:33
#
# Scraped 110 users this round
# Got 173 reivews
# 301507 reviews are now in the bag, so to speak
# 2024-03-30 21:14:51
#
# Scraped 101 users this round
# Got 224 reivews
# 301731 reviews are now in the bag, so to speak
# 2024-03-30 21:18:34
#
# Scraped 114 users this round
# Got 173 reivews
# 301904 reviews are now in the bag, so to speak
# 2024-03-30 21:22:56
#
# Scraped 125 users this round
# Got 185 reivews
# 302089 reviews are now in the bag, so to speak
# 2024-03-30 21:27:23
#
# Scraped 113 users this round
# Got 218 reivews
# 302307 reviews are now in the bag, so to speak
# 2024-03-30 21:31:37
#
# Scraped 107 users this round
# Got 185 reivews
# 302492 reviews are now in the bag, so to speak
# 2024-03-30 21:35:38
#
# Scraped 111 users this round
# Got 176 reivews
# 302668 reviews are now in the bag, so to speak
# 2024-03-30 21:39:53
#
# Scraped 104 users this round
# Got 224 reivews
# 302892 reviews are now in the bag, so to speak
# 2024-03-30 21:43:37
#
# Scraped 141 users this round
# Got 208 reivews
# 303100 reviews are now in the bag, so to speak
# 2024-03-30 21:49:01
#
# Scraped 115 users this round
# Got 158 reivews
# 303258 reviews are now in the bag, so to speak
# 2024-03-30 21:53:20
#
# Scraped 106 users this round
# Got 187 reivews
# 303445 reviews are now in the bag, so to speak
# 2024-03-30 21:57:23
#
# Scraped 92 users this round
# Got 209 reivews
# 303654 reviews are now in the bag, so to speak
# 2024-03-30 22:00:37
#
# Scraped 102 users this round
# Got 170 reivews
# 303824 reviews are now in the bag, so to speak
# 2024-03-30 22:04:18
#
# Scraped 111 users this round
# Got 160 reivews
# 303984 reviews are now in the bag, so to speak
# 2024-03-30 22:08:17
#
# Scraped 112 users this round
# Got 177 reivews
# 304161 reviews are now in the bag, so to speak
# 2024-03-30 22:12:19
#
# Scraped 103 users this round
# Got 188 reivews
# 304349 reviews are now in the bag, so to speak
# 2024-03-30 22:16:00
#
# Scraped 103 users this round
# Got 162 reivews
# 304511 reviews are now in the bag, so to speak
# 2024-03-30 22:19:52
#
# Scraped 112 users this round
# Got 148 reivews
# 304659 reviews are now in the bag, so to speak
# 2024-03-30 22:23:50
#
# Scraped 107 users this round
# Got 182 reivews
# 304841 reviews are now in the bag, so to speak
# 2024-03-30 22:27:26
#
# Scraped 95 users this round
# Got 172 reivews
# 305013 reviews are now in the bag, so to speak
# 2024-03-30 22:30:56
#
# Scraped 95 users this round
# Got 177 reivews
# 305190 reviews are now in the bag, so to speak
# 2024-03-30 22:34:30
#
# Scraped 105 users this round
# Got 187 reivews
# 305377 reviews are now in the bag, so to speak
# 2024-03-30 22:38:07
#
# Scraped 114 users this round
# Got 163 reivews
# 305540 reviews are now in the bag, so to speak
# 2024-03-30 22:42:16
#
# Scraped 100 users this round
# Got 185 reivews
# 305725 reviews are now in the bag, so to speak
# 2024-03-30 22:45:46
#
# Scraped 98 users this round
# Got 188 reivews
# 305913 reviews are now in the bag, so to speak
# 2024-03-30 22:49:12
#
# Scraped 117 users this round
# Got 186 reivews
# 306099 reviews are now in the bag, so to speak
# 2024-03-30 22:53:53
#
# Scraped 119 users this round
# Got 182 reivews
# 306281 reviews are now in the bag, so to speak
# 2024-03-30 22:58:05
#
# Scraped 111 users this round
# Got 198 reivews
# 306479 reviews are now in the bag, so to speak
# 2024-03-30 23:02:14
#
# Scraped 89 users this round
# Got 179 reivews
# 306658 reviews are now in the bag, so to speak
# 2024-03-30 23:05:25
#
# Scraped 96 users this round
# Got 167 reivews
# 306825 reviews are now in the bag, so to speak
# 2024-03-30 23:08:48
#
# Scraped 116 users this round
# Got 121 reivews
# 306946 reviews are now in the bag, so to speak
# 2024-03-30 23:13:04
#
# Scraped 111 users this round
# Got 181 reivews
# 307127 reviews are now in the bag, so to speak
# 2024-03-30 23:17:11
#
# Scraped 104 users this round
# Got 166 reivews
# 307293 reviews are now in the bag, so to speak
# 2024-03-30 23:20:49
#
# Scraped 110 users this round
# Got 164 reivews
# 307457 reviews are now in the bag, so to speak
# 2024-03-30 23:24:56
#
# Scraped 112 users this round
# Got 162 reivews
# 307619 reviews are now in the bag, so to speak
# 2024-03-30 23:29:11
#
# Scraped 122 users this round
# Got 176 reivews
# 307795 reviews are now in the bag, so to speak
# 2024-03-30 23:33:25
#
# Scraped 131 users this round
# Got 206 reivews
# 308001 reviews are now in the bag, so to speak
# 2024-03-30 23:37:58
#
# Scraped 100 users this round
# Got 160 reivews
# 308161 reviews are now in the bag, so to speak
# 2024-03-30 23:41:25
#
# Scraped 121 users this round
# Got 169 reivews
# 308330 reviews are now in the bag, so to speak
# 2024-03-30 23:45:50
#
# Scraped 124 users this round
# Got 184 reivews
# 308514 reviews are now in the bag, so to speak
# 2024-03-30 23:50:15
#
# Scraped 95 users this round
# Got 163 reivews
# 308677 reviews are now in the bag, so to speak
# 2024-03-30 23:53:40
#
# Scraped 107 users this round
# Got 172 reivews
# 308849 reviews are now in the bag, so to speak
# 2024-03-30 23:57:32
#
# Scraped 123 users this round
# Got 224 reivews
# 309073 reviews are now in the bag, so to speak
# 2024-03-31 00:01:44
#
# Scraped 115 users this round
# Got 166 reivews
# 309239 reviews are now in the bag, so to speak
# 2024-03-31 00:05:44
#
# Scraped 106 users this round
# Got 207 reivews
# 309446 reviews are now in the bag, so to speak
# 2024-03-31 00:09:34
#
# Scraped 98 users this round
# Got 192 reivews
# 309638 reviews are now in the bag, so to speak
# 2024-03-31 00:13:02
#
# Scraped 109 users this round
# Got 187 reivews
# 309825 reviews are now in the bag, so to speak
# 2024-03-31 00:17:06
#
# Scraped 102 users this round
# Got 168 reivews
# 309993 reviews are now in the bag, so to speak
# 2024-03-31 00:20:41
#
# Scraped 106 users this round
# Got 212 reivews
# 310205 reviews are now in the bag, so to speak
# 2024-03-31 00:24:20
#
# Scraped 132 users this round
# Got 215 reivews
# 310420 reviews are now in the bag, so to speak
# 2024-03-31 00:28:55
#
# Scraped 100 users this round
# Got 192 reivews
# 310612 reviews are now in the bag, so to speak
# 2024-03-31 00:32:19
#
# Scraped 94 users this round
# Got 199 reivews
# 310811 reviews are now in the bag, so to speak
# 2024-03-31 00:35:24
#
# Scraped 115 users this round
# Got 201 reivews
# 311012 reviews are now in the bag, so to speak
# 2024-03-31 00:39:19
#
# Scraped 108 users this round
# Got 206 reivews
# 311218 reviews are now in the bag, so to speak
# 2024-03-31 00:42:59
#
# Scraped 107 users this round
# Got 164 reivews
# 311382 reviews are now in the bag, so to speak
# 2024-03-31 00:46:41
#
# Scraped 112 users this round
# Got 184 reivews
# 311566 reviews are now in the bag, so to speak
# 2024-03-31 00:50:40
#
# Scraped 102 users this round
# Got 182 reivews
# 311748 reviews are now in the bag, so to speak
# 2024-03-31 00:54:12
#
# Scraped 113 users this round
# Got 173 reivews
# 311921 reviews are now in the bag, so to speak
# 2024-03-31 00:58:13
#
# Scraped 112 users this round
# Got 190 reivews
# 312111 reviews are now in the bag, so to speak
# 2024-03-31 01:01:58
#
# Scraped 114 users this round
# Got 197 reivews
# 312308 reviews are now in the bag, so to speak
# 2024-03-31 01:05:54
#
# Scraped 122 users this round
# Got 186 reivews
# 312494 reviews are now in the bag, so to speak
# 2024-03-31 01:10:15
#
# Scraped 112 users this round
# Got 191 reivews
# 312685 reviews are now in the bag, so to speak
# 2024-03-31 01:14:02
#
# Scraped 117 users this round
# Got 229 reivews
# 312914 reviews are now in the bag, so to speak
# 2024-03-31 01:18:25
#
# Scraped 125 users this round
# Got 179 reivews
# 313093 reviews are now in the bag, so to speak
# 2024-03-31 01:22:49
#
# Scraped 95 users this round
# Got 180 reivews
# 313273 reviews are now in the bag, so to speak
# 2024-03-31 01:26:04
#
# Scraped 115 users this round
# Got 184 reivews
# 313457 reviews are now in the bag, so to speak
# 2024-03-31 01:30:03
#
# Scraped 121 users this round
# Got 166 reivews
# 313623 reviews are now in the bag, so to speak
# 2024-03-31 01:34:13
#
# Scraped 102 users this round
# Got 199 reivews
# 313822 reviews are now in the bag, so to speak
# 2024-03-31 01:37:44
#
# Scraped 111 users this round
# Got 195 reivews
# 314017 reviews are now in the bag, so to speak
# 2024-03-31 01:41:33
#
# Scraped 101 users this round
# Got 190 reivews
# 314207 reviews are now in the bag, so to speak
# 2024-03-31 01:44:59
#
# Scraped 104 users this round
# Got 199 reivews
# 314406 reviews are now in the bag, so to speak
# 2024-03-31 01:48:26
#
# Scraped 103 users this round
# Got 184 reivews
# 314590 reviews are now in the bag, so to speak
# 2024-03-31 01:52:08
#
# Scraped 125 users this round
# Got 167 reivews
# 314757 reviews are now in the bag, so to speak
# 2024-03-31 01:56:39
#
# Scraped 107 users this round
# Got 158 reivews
# 314915 reviews are now in the bag, so to speak
# 2024-03-31 02:00:15
#
# Scraped 89 users this round
# Got 215 reivews
# 315130 reviews are now in the bag, so to speak
# 2024-03-31 02:03:24
#
# Scraped 124 users this round
# Got 211 reivews
# 315341 reviews are now in the bag, so to speak
# 2024-03-31 02:07:50
#
# Scraped 109 users this round
# Got 187 reivews
# 315528 reviews are now in the bag, so to speak
# 2024-03-31 02:11:27
#
# Scraped 117 users this round
# Got 207 reivews
# 315735 reviews are now in the bag, so to speak
# 2024-03-31 02:15:31
#
# Scraped 103 users this round
# Got 187 reivews
# 315922 reviews are now in the bag, so to speak
# 2024-03-31 02:19:02
#
# Scraped 102 users this round
# Got 152 reivews
# 316074 reviews are now in the bag, so to speak
# 2024-03-31 02:22:34
#
# Scraped 116 users this round
# Got 191 reivews
# 316265 reviews are now in the bag, so to speak
# 2024-03-31 02:26:52
#
# Scraped 103 users this round
# Got 215 reivews
# 316480 reviews are now in the bag, so to speak
# 2024-03-31 02:30:31
#
# Scraped 114 users this round
# Got 185 reivews
# 316665 reviews are now in the bag, so to speak
# 2024-03-31 02:34:33
#
# Scraped 96 users this round
# Got 175 reivews
# 316840 reviews are now in the bag, so to speak
# 2024-03-31 02:37:51
#
# Scraped 92 users this round
# Got 192 reivews
# 317032 reviews are now in the bag, so to speak
# 2024-03-31 02:40:57
#
# Scraped 117 users this round
# Got 213 reivews
# 317245 reviews are now in the bag, so to speak
# 2024-03-31 02:45:02
#
# Scraped 126 users this round
# Got 220 reivews
# 317465 reviews are now in the bag, so to speak
# 2024-03-31 02:49:25
#
# Scraped 115 users this round
# Got 188 reivews
# 317653 reviews are now in the bag, so to speak
# 2024-03-31 02:53:49
#
# Scraped 107 users this round
# Got 174 reivews
# 317827 reviews are now in the bag, so to speak
# 2024-03-31 02:57:34
#
# Scraped 98 users this round
# Got 226 reivews
# 318053 reviews are now in the bag, so to speak
# 2024-03-31 03:00:45
#
# Scraped 107 users this round
# Got 204 reivews
# 318257 reviews are now in the bag, so to speak
# 2024-03-31 03:04:21
#
# Scraped 116 users this round
# Got 173 reivews
# 318430 reviews are now in the bag, so to speak
# 2024-03-31 03:08:36
#
# Scraped 122 users this round
# Got 192 reivews
# 318622 reviews are now in the bag, so to speak
# 2024-03-31 03:12:46
#
# Scraped 123 users this round
# Got 167 reivews
# 318789 reviews are now in the bag, so to speak
# 2024-03-31 03:16:59
#
# Scraped 112 users this round
# Got 202 reivews
# 318991 reviews are now in the bag, so to speak
# 2024-03-31 03:21:07
#
# Scraped 106 users this round
# Got 190 reivews
# 319181 reviews are now in the bag, so to speak
# 2024-03-31 03:24:32
#
# Scraped 102 users this round
# Got 185 reivews
# 319366 reviews are now in the bag, so to speak
# 2024-03-31 03:27:56
#
# Scraped 92 users this round
# Got 209 reivews
# 319575 reviews are now in the bag, so to speak
# 2024-03-31 03:30:55
#
# Scraped 137 users this round
# Got 200 reivews
# 319775 reviews are now in the bag, so to speak
# 2024-03-31 03:36:00
#
# Scraped 126 users this round
# Got 195 reivews
# 319970 reviews are now in the bag, so to speak
# 2024-03-31 03:40:16
#
# Scraped 97 users this round
# Got 194 reivews
# 320164 reviews are now in the bag, so to speak
# 2024-03-31 03:43:15
#
# Scraped 121 users this round
# Got 158 reivews
# 320322 reviews are now in the bag, so to speak
# 2024-03-31 03:47:25
#
# Scraped 102 users this round
# Got 209 reivews
# 320531 reviews are now in the bag, so to speak
# 2024-03-31 03:50:51
#
# Scraped 106 users this round
# Got 197 reivews
# 320728 reviews are now in the bag, so to speak
# 2024-03-31 03:54:48
#
# Scraped 110 users this round
# Got 197 reivews
# 320925 reviews are now in the bag, so to speak
# 2024-03-31 03:58:29
#
# Scraped 116 users this round
# Got 163 reivews
# 321088 reviews are now in the bag, so to speak
# 2024-03-31 04:02:33
#
# Scraped 109 users this round
# Got 154 reivews
# 321242 reviews are now in the bag, so to speak
# 2024-03-31 04:05:58
#
# Scraped 104 users this round
# Got 182 reivews
# 321424 reviews are now in the bag, so to speak
# 2024-03-31 04:09:36
#
# Scraped 106 users this round
# Got 204 reivews
# 321628 reviews are now in the bag, so to speak
# 2024-03-31 04:13:29
#
# Scraped 95 users this round
# Got 189 reivews
# 321817 reviews are now in the bag, so to speak
# 2024-03-31 04:16:40
#
# Scraped 100 users this round
# Got 196 reivews
# 322013 reviews are now in the bag, so to speak
# 2024-03-31 04:20:02
#
# Scraped 107 users this round
# Got 166 reivews
# 322179 reviews are now in the bag, so to speak
# 2024-03-31 04:23:42
#
# Scraped 106 users this round
# Got 143 reivews
# 322322 reviews are now in the bag, so to speak
# 2024-03-31 04:27:15
#
# Scraped 101 users this round
# Got 214 reivews
# 322536 reviews are now in the bag, so to speak
# 2024-03-31 04:30:45
#
# Scraped 106 users this round
# Got 186 reivews
# 322722 reviews are now in the bag, so to speak
# 2024-03-31 04:34:23
#
# Scraped 108 users this round
# Got 202 reivews
# 322924 reviews are now in the bag, so to speak
# 2024-03-31 04:37:57
#
# Scraped 116 users this round
# Got 211 reivews
# 323135 reviews are now in the bag, so to speak
# 2024-03-31 04:41:54
#
# Scraped 106 users this round
# Got 215 reivews
# 323350 reviews are now in the bag, so to speak
# 2024-03-31 04:45:25
#
# Scraped 107 users this round
# Got 171 reivews
# 323521 reviews are now in the bag, so to speak
# 2024-03-31 04:49:49
#
# Scraped 109 users this round
# Got 197 reivews
# 323718 reviews are now in the bag, so to speak
# 2024-03-31 04:53:12
#
# Scraped 119 users this round
# Got 194 reivews
# 323912 reviews are now in the bag, so to speak
# 2024-03-31 04:57:31
#
# Scraped 103 users this round
# Got 205 reivews
# 324117 reviews are now in the bag, so to speak
# 2024-03-31 05:00:51
#
# Scraped 90 users this round
# Got 192 reivews
# 324309 reviews are now in the bag, so to speak
# 2024-03-31 05:03:49
#
# Scraped 109 users this round
# Got 225 reivews
# 324534 reviews are now in the bag, so to speak
# 2024-03-31 05:07:32
#
# Scraped 91 users this round
# Got 213 reivews
# 324747 reviews are now in the bag, so to speak
# 2024-03-31 05:10:25
#
# Scraped 118 users this round
# Got 157 reivews
# 324904 reviews are now in the bag, so to speak
# 2024-03-31 05:14:21
#
# Scraped 106 users this round
# Got 241 reivews
# 325145 reviews are now in the bag, so to speak
# 2024-03-31 05:18:03
#
# Scraped 127 users this round
# Got 193 reivews
# 325338 reviews are now in the bag, so to speak
# 2024-03-31 05:22:37
#
# Scraped 100 users this round
# Got 180 reivews
# 325518 reviews are now in the bag, so to speak
# 2024-03-31 05:26:08
#
# Scraped 129 users this round
# Got 199 reivews
# 325717 reviews are now in the bag, so to speak
# 2024-03-31 05:30:42
#
# Scraped 109 users this round
# Got 191 reivews
# 325908 reviews are now in the bag, so to speak
# 2024-03-31 05:34:21
#
# Scraped 109 users this round
# Got 187 reivews
# 326095 reviews are now in the bag, so to speak
# 2024-03-31 05:38:01
#
# Scraped 123 users this round
# Got 183 reivews
# 326278 reviews are now in the bag, so to speak
# 2024-03-31 05:42:25
#
# Scraped 128 users this round
# Got 212 reivews
# 326490 reviews are now in the bag, so to speak
# 2024-03-31 05:46:59
#
# Scraped 115 users this round
# Got 176 reivews
# 326666 reviews are now in the bag, so to speak
# 2024-03-31 05:51:02
#
# Scraped 102 users this round
# Got 158 reivews
# 326824 reviews are now in the bag, so to speak
# 2024-03-31 05:54:17
#
# Scraped 109 users this round
# Got 202 reivews
# 327026 reviews are now in the bag, so to speak
# 2024-03-31 05:58:04
#
# Scraped 98 users this round
# Got 175 reivews
# 327201 reviews are now in the bag, so to speak
# 2024-03-31 06:01:09
#
# Scraped 121 users this round
# Got 180 reivews
# 327381 reviews are now in the bag, so to speak
# 2024-03-31 06:05:29
#
# Scraped 111 users this round
# Got 226 reivews
# 327607 reviews are now in the bag, so to speak
# 2024-03-31 06:09:20
#
# Scraped 119 users this round
# Got 204 reivews
# 327811 reviews are now in the bag, so to speak
# 2024-03-31 06:13:35
#
# Scraped 108 users this round
# Got 219 reivews
# 328030 reviews are now in the bag, so to speak
# 2024-03-31 06:17:18
#
# Unable to parse review blocks.
# Scraped 116 users this round
# Got 159 reivews
# 328189 reviews are now in the bag, so to speak
# 2024-03-31 06:23:52
#
# Scraped 111 users this round
# Got 171 reivews
# 328360 reviews are now in the bag, so to speak
# 2024-03-31 06:27:38
#
# Scraped 100 users this round
# Got 179 reivews
# 328539 reviews are now in the bag, so to speak
# 2024-03-31 06:30:56
#
# Scraped 129 users this round
# Got 267 reivews
# 328806 reviews are now in the bag, so to speak
# 2024-03-31 06:35:28
#
# Scraped 108 users this round
# Got 165 reivews
# 328971 reviews are now in the bag, so to speak
# 2024-03-31 06:39:05
#
# Scraped 104 users this round
# Got 187 reivews
# 329158 reviews are now in the bag, so to speak
# 2024-03-31 06:43:30
#
# Scraped 89 users this round
# Got 203 reivews
# 329361 reviews are now in the bag, so to speak
# 2024-03-31 06:46:26
#
# Scraped 104 users this round
# Got 165 reivews
# 329526 reviews are now in the bag, so to speak
# 2024-03-31 06:49:45
#
# Scraped 118 users this round
# Got 182 reivews
# 329708 reviews are now in the bag, so to speak
# 2024-03-31 06:53:54
#
# Scraped 109 users this round
# Got 188 reivews
# 329896 reviews are now in the bag, so to speak
# 2024-03-31 06:57:32
#
# Scraped 125 users this round
# Got 182 reivews
# 330078 reviews are now in the bag, so to speak
# 2024-03-31 07:01:47
#
# Scraped 123 users this round
# Got 158 reivews
# 330236 reviews are now in the bag, so to speak
# 2024-03-31 07:05:50
#
# Scraped 122 users this round
# Got 186 reivews
# 330422 reviews are now in the bag, so to speak
# 2024-03-31 07:10:00
#
# Scraped 125 users this round
# Got 168 reivews
# 330590 reviews are now in the bag, so to speak
# 2024-03-31 07:14:34
#
# Scraped 119 users this round
# Got 164 reivews
# 330754 reviews are now in the bag, so to speak
# 2024-03-31 07:18:42
#
# Scraped 98 users this round
# Got 161 reivews
# 330915 reviews are now in the bag, so to speak
# 2024-03-31 07:21:56
#
# Scraped 110 users this round
# Got 221 reivews
# 331136 reviews are now in the bag, so to speak
# 2024-03-31 07:25:41
#
# Scraped 113 users this round
# Got 197 reivews
# 331333 reviews are now in the bag, so to speak
# 2024-03-31 07:30:20
#
# Scraped 122 users this round
# Got 201 reivews
# 331534 reviews are now in the bag, so to speak
# 2024-03-31 07:35:01
#
# Scraped 111 users this round
# Got 181 reivews
# 331715 reviews are now in the bag, so to speak
# 2024-03-31 07:38:43
#
# Scraped 110 users this round
# Got 189 reivews
# 331904 reviews are now in the bag, so to speak
# 2024-03-31 07:42:32
#
# Scraped 110 users this round
# Got 133 reivews
# 332037 reviews are now in the bag, so to speak
# 2024-03-31 07:46:11
#
# Scraped 121 users this round
# Got 202 reivews
# 332239 reviews are now in the bag, so to speak
# 2024-03-31 07:50:27
#
# Scraped 95 users this round
# Got 176 reivews
# 332415 reviews are now in the bag, so to speak
# 2024-03-31 07:53:52
#
# Scraped 82 users this round
# Got 180 reivews
# 332595 reviews are now in the bag, so to speak
# 2024-03-31 07:56:52
#
# Scraped 126 users this round
# Got 171 reivews
# 332766 reviews are now in the bag, so to speak
# 2024-03-31 08:01:25
#
# Scraped 129 users this round
# Got 224 reivews
# 332990 reviews are now in the bag, so to speak
# 2024-03-31 08:05:35
#
# Scraped 126 users this round
# Got 200 reivews
# 333190 reviews are now in the bag, so to speak
# 2024-03-31 08:10:05
#
# Scraped 96 users this round
# Got 193 reivews
# 333383 reviews are now in the bag, so to speak
# 2024-03-31 08:13:11
#
# Scraped 98 users this round
# Got 180 reivews
# 333563 reviews are now in the bag, so to speak
# 2024-03-31 08:16:27
#
# Scraped 120 users this round
# Got 203 reivews
# 333766 reviews are now in the bag, so to speak
# 2024-03-31 08:20:54
#
# Scraped 102 users this round
# Got 207 reivews
# 333973 reviews are now in the bag, so to speak
# 2024-03-31 08:24:28
#
# Scraped 123 users this round
# Got 203 reivews
# 334176 reviews are now in the bag, so to speak
# 2024-03-31 08:29:00
#
# Scraped 120 users this round
# Got 178 reivews
# 334354 reviews are now in the bag, so to speak
# 2024-03-31 08:33:16
#
# Scraped 116 users this round
# Got 148 reivews
# 334502 reviews are now in the bag, so to speak
# 2024-03-31 08:37:16
#
# Scraped 109 users this round
# Got 219 reivews
# 334721 reviews are now in the bag, so to speak
# 2024-03-31 08:41:13
#
# Scraped 115 users this round
# Got 154 reivews
# 334875 reviews are now in the bag, so to speak
# 2024-03-31 08:45:14
#
# Scraped 115 users this round
# Got 204 reivews
# 335079 reviews are now in the bag, so to speak
# 2024-03-31 08:49:09
#
# Scraped 108 users this round
# Got 150 reivews
# 335229 reviews are now in the bag, so to speak
# 2024-03-31 08:52:39
#
# Scraped 117 users this round
# Got 189 reivews
# 335418 reviews are now in the bag, so to speak
# 2024-03-31 08:56:54
#
# Scraped 120 users this round
# Got 194 reivews
# 335612 reviews are now in the bag, so to speak
# 2024-03-31 09:01:08
#
# Scraped 118 users this round
# Got 175 reivews
# 335787 reviews are now in the bag, so to speak
# 2024-03-31 09:05:22
#
# Scraped 98 users this round
# Got 193 reivews
# 335980 reviews are now in the bag, so to speak
# 2024-03-31 09:08:38
#
# Scraped 101 users this round
# Got 157 reivews
# 336137 reviews are now in the bag, so to speak
# 2024-03-31 09:12:03
#
# Scraped 105 users this round
# Got 174 reivews
# 336311 reviews are now in the bag, so to speak
# 2024-03-31 09:16:19
#
# Scraped 108 users this round
# Got 172 reivews
# 336483 reviews are now in the bag, so to speak
# 2024-03-31 09:20:33
#
# Scraped 92 users this round
# Got 158 reivews
# 336641 reviews are now in the bag, so to speak
# 2024-03-31 09:23:28
#
# Scraped 95 users this round
# Got 170 reivews
# 336811 reviews are now in the bag, so to speak
# 2024-03-31 09:26:39
#
# Scraped 125 users this round
# Got 184 reivews
# 336995 reviews are now in the bag, so to speak
# 2024-03-31 09:31:10
#
# Scraped 102 users this round
# Got 173 reivews
# 337168 reviews are now in the bag, so to speak
# 2024-03-31 09:34:31
#
# Scraped 120 users this round
# Got 139 reivews
# 337307 reviews are now in the bag, so to speak
# 2024-03-31 09:38:35
#
# Scraped 105 users this round
# Got 204 reivews
# 337511 reviews are now in the bag, so to speak
# 2024-03-31 09:42:09
#
# Scraped 109 users this round
# Got 188 reivews
# 337699 reviews are now in the bag, so to speak
# 2024-03-31 09:46:06
#
# Scraped 147 users this round
# Got 186 reivews
# 337885 reviews are now in the bag, so to speak
# 2024-03-31 09:51:18
#
# Scraped 114 users this round
# Got 211 reivews
# 338096 reviews are now in the bag, so to speak
# 2024-03-31 09:55:36
#
# Scraped 127 users this round
# Got 180 reivews
# 338276 reviews are now in the bag, so to speak
# 2024-03-31 10:00:13
#
# Scraped 93 users this round
# Got 201 reivews
# 338477 reviews are now in the bag, so to speak
# 2024-03-31 10:03:17
#
# Scraped 102 users this round
# Got 156 reivews
# 338633 reviews are now in the bag, so to speak
# 2024-03-31 10:06:43
#
# Scraped 111 users this round
# Got 199 reivews
# 338832 reviews are now in the bag, so to speak
# 2024-03-31 10:10:25
#
# Scraped 117 users this round
# Got 168 reivews
# 339000 reviews are now in the bag, so to speak
# 2024-03-31 10:14:37
#
# Scraped 109 users this round
# Got 201 reivews
# 339201 reviews are now in the bag, so to speak
# 2024-03-31 10:18:27
#
# Scraped 101 users this round
# Got 176 reivews
# 339377 reviews are now in the bag, so to speak
# 2024-03-31 10:21:58
#
# Scraped 111 users this round
# Got 171 reivews
# 339548 reviews are now in the bag, so to speak
# 2024-03-31 10:25:49
#
# Scraped 101 users this round
# Got 201 reivews
# 339749 reviews are now in the bag, so to speak
# 2024-03-31 10:29:28
#
# Scraped 94 users this round
# Got 179 reivews
# 339928 reviews are now in the bag, so to speak
# 2024-03-31 10:32:45
#
# Scraped 111 users this round
# Got 171 reivews
# 340099 reviews are now in the bag, so to speak
# 2024-03-31 10:36:36
#
# Scraped 114 users this round
# Got 184 reivews
# 340283 reviews are now in the bag, so to speak
# 2024-03-31 10:40:50
#
# Scraped 114 users this round
# Got 237 reivews
# 340520 reviews are now in the bag, so to speak
# 2024-03-31 10:45:11
#
# Scraped 107 users this round
# Got 132 reivews
# 340652 reviews are now in the bag, so to speak
# 2024-03-31 10:49:09
#
# Scraped 99 users this round
# Got 175 reivews
# 340827 reviews are now in the bag, so to speak
# 2024-03-31 10:52:54
#
# Scraped 94 users this round
# Got 158 reivews
# 340985 reviews are now in the bag, so to speak
# 2024-03-31 10:56:14
#
# Scraped 108 users this round
# Got 176 reivews
# 341161 reviews are now in the bag, so to speak
# 2024-03-31 11:00:51
#
# Scraped 94 users this round
# Got 192 reivews
# 341353 reviews are now in the bag, so to speak
# 2024-03-31 11:04:24
#
# Scraped 112 users this round
# Got 210 reivews
# 341563 reviews are now in the bag, so to speak
# 2024-03-31 11:08:31
#
# Scraped 99 users this round
# Got 174 reivews
# 341737 reviews are now in the bag, so to speak
# 2024-03-31 11:11:58
#
# Scraped 122 users this round
# Got 177 reivews
# 341914 reviews are now in the bag, so to speak
# 2024-03-31 11:16:13
#
# Scraped 88 users this round
# Got 196 reivews
# 342110 reviews are now in the bag, so to speak
# 2024-03-31 11:19:16
#
# Scraped 137 users this round
# Got 169 reivews
# 342279 reviews are now in the bag, so to speak
# 2024-03-31 11:24:05
#
# Scraped 116 users this round
# Got 206 reivews
# 342485 reviews are now in the bag, so to speak
# 2024-03-31 11:28:43
#
# Scraped 111 users this round
# Got 175 reivews
# 342660 reviews are now in the bag, so to speak
# 2024-03-31 11:32:47
#
# Scraped 98 users this round
# Got 190 reivews
# 342850 reviews are now in the bag, so to speak
# 2024-03-31 11:36:25
#
# Scraped 117 users this round
# Got 216 reivews
# 343066 reviews are now in the bag, so to speak
# 2024-03-31 11:40:45
#
# Scraped 102 users this round
# Got 221 reivews
# 343287 reviews are now in the bag, so to speak
# 2024-03-31 11:44:29
#
# Scraped 124 users this round
# Got 190 reivews
# 343477 reviews are now in the bag, so to speak
# 2024-03-31 11:48:50
#
# Scraped 111 users this round
# Got 243 reivews
# 343720 reviews are now in the bag, so to speak
# 2024-03-31 11:52:54
#
# Scraped 106 users this round
# Got 210 reivews
# 343930 reviews are now in the bag, so to speak
# 2024-03-31 11:56:35
#
# Scraped 85 users this round
# Got 148 reivews
# 344078 reviews are now in the bag, so to speak
# 2024-03-31 11:59:21
#
# Scraped 95 users this round
# Got 192 reivews
# 344270 reviews are now in the bag, so to speak
# 2024-03-31 12:02:36
#
# Scraped 114 users this round
# Got 219 reivews
# 344489 reviews are now in the bag, so to speak
# 2024-03-31 12:06:46
#
# Scraped 102 users this round
# Got 204 reivews
# 344693 reviews are now in the bag, so to speak
# 2024-03-31 12:10:20
#
# Scraped 93 users this round
# Got 186 reivews
# 344879 reviews are now in the bag, so to speak
# 2024-03-31 12:13:21
#
# Scraped 116 users this round
# Got 184 reivews
# 345063 reviews are now in the bag, so to speak
# 2024-03-31 12:17:11
#
# Scraped 111 users this round
# Got 195 reivews
# 345258 reviews are now in the bag, so to speak
# 2024-03-31 12:21:03
#
# Scraped 103 users this round
# Got 188 reivews
# 345446 reviews are now in the bag, so to speak
# 2024-03-31 12:24:35
#
# Scraped 122 users this round
# Got 205 reivews
# 345651 reviews are now in the bag, so to speak
# 2024-03-31 12:29:06
#
# Scraped 134 users this round
# Got 215 reivews
# 345866 reviews are now in the bag, so to speak
# 2024-03-31 12:33:55
#
# Scraped 102 users this round
# Got 181 reivews
# 346047 reviews are now in the bag, so to speak
# 2024-03-31 12:37:31
#
# Scraped 100 users this round
# Got 186 reivews
# 346233 reviews are now in the bag, so to speak
# 2024-03-31 12:40:49
#
# Scraped 101 users this round
# Got 198 reivews
# 346431 reviews are now in the bag, so to speak
# 2024-03-31 12:44:30
#
# Scraped 116 users this round
# Got 201 reivews
# 346632 reviews are now in the bag, so to speak
# 2024-03-31 12:48:51
#
# Scraped 123 users this round
# Got 161 reivews
# 346793 reviews are now in the bag, so to speak
# 2024-03-31 12:53:07
#
# Scraped 125 users this round
# Got 191 reivews
# 346984 reviews are now in the bag, so to speak
# 2024-03-31 12:57:38
#
# Scraped 108 users this round
# Got 170 reivews
# 347154 reviews are now in the bag, so to speak
# 2024-03-31 13:01:26
#
# Scraped 108 users this round
# Got 204 reivews
# 347358 reviews are now in the bag, so to speak
# 2024-03-31 13:05:11
#
# Scraped 98 users this round
# Got 162 reivews
# 347520 reviews are now in the bag, so to speak
# 2024-03-31 13:08:38
#
# Scraped 132 users this round
# Got 236 reivews
# 347756 reviews are now in the bag, so to speak
# 2024-03-31 13:13:44
#
# Scraped 103 users this round
# Got 192 reivews
# 347948 reviews are now in the bag, so to speak
# 2024-03-31 13:17:31
#
# Scraped 101 users this round
# Got 223 reivews
# 348171 reviews are now in the bag, so to speak
# 2024-03-31 13:21:02
#
# Scraped 126 users this round
# Got 226 reivews
# 348397 reviews are now in the bag, so to speak
# 2024-03-31 13:25:32
#
# Scraped 95 users this round
# Got 149 reivews
# 348546 reviews are now in the bag, so to speak
# 2024-03-31 13:28:20
#
# Scraped 105 users this round
# Got 177 reivews
# 348723 reviews are now in the bag, so to speak
# 2024-03-31 13:32:04
#
# Scraped 111 users this round
# Got 207 reivews
# 348930 reviews are now in the bag, so to speak
# 2024-03-31 13:35:54
#
# Scraped 89 users this round
# Got 166 reivews
# 349096 reviews are now in the bag, so to speak
# 2024-03-31 13:38:57
#
# Scraped 112 users this round
# Got 197 reivews
# 349293 reviews are now in the bag, so to speak
# 2024-03-31 13:43:05
#
# Scraped 99 users this round
# Got 227 reivews
# 349520 reviews are now in the bag, so to speak
# 2024-03-31 13:46:42
#
# Scraped 118 users this round
# Got 234 reivews
# 349754 reviews are now in the bag, so to speak
# 2024-03-31 13:50:54
#
# Scraped 106 users this round
# Got 192 reivews
# 349946 reviews are now in the bag, so to speak
# 2024-03-31 13:54:35
#
# Scraped 102 users this round
# Got 219 reivews
# 350165 reviews are now in the bag, so to speak
# 2024-03-31 13:58:09
#
# Scraped 100 users this round
# Got 216 reivews
# 350381 reviews are now in the bag, so to speak
# 2024-03-31 14:01:25
#
# Scraped 120 users this round
# Got 172 reivews
# 350553 reviews are now in the bag, so to speak
# 2024-03-31 14:05:39
#
# Scraped 145 users this round
# Got 158 reivews
# 350711 reviews are now in the bag, so to speak
# 2024-03-31 14:10:55
#
# Scraped 108 users this round
# Got 218 reivews
# 350929 reviews are now in the bag, so to speak
# 2024-03-31 14:14:36
#
# Scraped 104 users this round
# Got 195 reivews
# 351124 reviews are now in the bag, so to speak
# 2024-03-31 14:17:43
#
# Scraped 123 users this round
# Got 232 reivews
# 351356 reviews are now in the bag, so to speak
# 2024-03-31 14:21:38
#
# Scraped 110 users this round
# Got 187 reivews
# 351543 reviews are now in the bag, so to speak
# 2024-03-31 14:25:09
#
# Scraped 117 users this round
# Got 218 reivews
# 351761 reviews are now in the bag, so to speak
# 2024-03-31 14:28:52
#
# Scraped 120 users this round
# Got 183 reivews
# 351944 reviews are now in the bag, so to speak
# 2024-03-31 14:32:43
#
# ...
# 516468 reviews are now in the bag, so to speak
# 2024-04-02 23:45:03
#
# Scraped 98 users this round
# Got 186 reivews
# 516654 reviews are now in the bag, so to speak
# 2024-04-02 23:48:14
#
# Scraped 99 users this round
# Got 193 reivews
# 516847 reviews are now in the bag, so to speak
# 2024-04-02 23:51:36
#
# Scraped 98 users this round
# Got 155 reivews
# 517002 reviews are now in the bag, so to speak
# 2024-04-02 23:54:58
#
# Scraped 127 users this round
# Got 213 reivews
# 517215 reviews are now in the bag, so to speak
# 2024-04-02 23:59:29
#
# Scraped 84 users this round
# Got 170 reivews
# 517385 reviews are now in the bag, so to speak
# 2024-04-03 00:02:08
#
# Scraped 118 users this round
# Got 167 reivews
# 517552 reviews are now in the bag, so to speak
# 2024-04-03 00:06:09
#
# Scraped 111 users this round
# Got 169 reivews
# 517721 reviews are now in the bag, so to speak
# 2024-04-03 00:10:09
#
# Scraped 111 users this round
# Got 218 reivews
# 517939 reviews are now in the bag, so to speak
# 2024-04-03 00:14:01
#
# Scraped 104 users this round
# Got 166 reivews
# 518105 reviews are now in the bag, so to speak
# 2024-04-03 00:17:40
#
# Scraped 98 users this round
# Got 189 reivews
# 518294 reviews are now in the bag, so to speak
# 2024-04-03 00:20:58
#
# Scraped 125 users this round
# Got 188 reivews
# 518482 reviews are now in the bag, so to speak
# 2024-04-03 00:25:17
#
# Scraped 98 users this round
# Got 150 reivews
# 518632 reviews are now in the bag, so to speak
# 2024-04-03 00:28:33
#
# Scraped 130 users this round
# Got 199 reivews
# 518831 reviews are now in the bag, so to speak
# 2024-04-03 00:32:59
#
# Scraped 99 users this round
# Got 179 reivews
# 519010 reviews are now in the bag, so to speak
# 2024-04-03 00:36:23
#
# Scraped 108 users this round
# Got 171 reivews
# 519181 reviews are now in the bag, so to speak
# 2024-04-03 00:40:14
#
# Scraped 105 users this round
# Got 179 reivews
# 519360 reviews are now in the bag, so to speak
# 2024-04-03 00:43:55
#
# Scraped 108 users this round
# Got 204 reivews
# 519564 reviews are now in the bag, so to speak
# 2024-04-03 00:47:45
#
# Scraped 96 users this round
# Got 177 reivews
# 519741 reviews are now in the bag, so to speak
# 2024-04-03 00:50:51
#
# Scraped 100 users this round
# Got 231 reivews
# 519972 reviews are now in the bag, so to speak
# 2024-04-03 00:54:40
#
# Scraped 136 users this round
# Got 240 reivews
# 520212 reviews are now in the bag, so to speak
# 2024-04-03 00:59:52
#
# Scraped 115 users this round
# Got 218 reivews
# 520430 reviews are now in the bag, so to speak
# 2024-04-03 01:03:57
#
# Scraped 120 users this round
# Got 144 reivews
# 520574 reviews are now in the bag, so to speak
# 2024-04-03 01:07:57
#
# Scraped 103 users this round
# Got 255 reivews
# 520829 reviews are now in the bag, so to speak
# 2024-04-03 01:11:19
#
# Scraped 116 users this round
# Got 180 reivews
# 521009 reviews are now in the bag, so to speak
# 2024-04-03 01:15:07
#
# Scraped 112 users this round
# Got 193 reivews
# 521202 reviews are now in the bag, so to speak
# 2024-04-03 01:18:47
#
# Scraped 106 users this round
# Got 226 reivews
# 521428 reviews are now in the bag, so to speak
# 2024-04-03 01:22:16
#
# Scraped 97 users this round
# Got 141 reivews
# 521569 reviews are now in the bag, so to speak
# 2024-04-03 01:25:26
#
# Scraped 122 users this round
# Got 184 reivews
# 521753 reviews are now in the bag, so to speak
# 2024-04-03 01:29:44
#
# Scraped 128 users this round
# Got 196 reivews
# 521949 reviews are now in the bag, so to speak
# 2024-04-03 01:33:59
#
# Scraped 103 users this round
# Got 209 reivews
# 522158 reviews are now in the bag, so to speak
# 2024-04-03 01:37:19
#
# Scraped 117 users this round
# Got 192 reivews
# 522350 reviews are now in the bag, so to speak
# 2024-04-03 01:41:13
#
# Scraped 90 users this round
# Got 180 reivews
# 522530 reviews are now in the bag, so to speak
# 2024-04-03 01:44:09
#
# Scraped 111 users this round
# Got 165 reivews
# 522695 reviews are now in the bag, so to speak
# 2024-04-03 01:47:48
#
# Scraped 96 users this round
# Got 166 reivews
# 522861 reviews are now in the bag, so to speak
# 2024-04-03 01:50:50
#
# Scraped 108 users this round
# Got 206 reivews
# 523067 reviews are now in the bag, so to speak
# 2024-04-03 01:54:24
#
# Scraped 107 users this round
# Got 192 reivews
# 523259 reviews are now in the bag, so to speak
# 2024-04-03 01:57:51
#
# Scraped 110 users this round
# Got 183 reivews
# 523442 reviews are now in the bag, so to speak
# 2024-04-03 02:01:34
#
# Scraped 96 users this round
# Got 203 reivews
# 523645 reviews are now in the bag, so to speak
# 2024-04-03 02:04:53
#
# Scraped 130 users this round
# Got 248 reivews
# 523893 reviews are now in the bag, so to speak
# 2024-04-03 02:09:33
#
# Scraped 117 users this round
# Got 177 reivews
# 524070 reviews are now in the bag, so to speak
# 2024-04-03 02:13:58
#
# Scraped 110 users this round
# Got 233 reivews
# 524303 reviews are now in the bag, so to speak
# 2024-04-03 02:17:39
#
# Scraped 100 users this round
# Got 176 reivews
# 524479 reviews are now in the bag, so to speak
# 2024-04-03 02:20:56
#
# Scraped 108 users this round
# Got 188 reivews
# 524667 reviews are now in the bag, so to speak
# 2024-04-03 02:24:40
#
# Scraped 105 users this round
# Got 183 reivews
# 524850 reviews are now in the bag, so to speak
# 2024-04-03 02:28:16
#
# Scraped 108 users this round
# Got 177 reivews
# 525027 reviews are now in the bag, so to speak
# 2024-04-03 02:31:43
#
# Scraped 102 users this round
# Got 189 reivews
# 525216 reviews are now in the bag, so to speak
# 2024-04-03 02:35:04
#
# Scraped 113 users this round
# Got 195 reivews
# 525411 reviews are now in the bag, so to speak
# 2024-04-03 02:38:49
#
# Scraped 114 users this round
# Got 153 reivews
# 525564 reviews are now in the bag, so to speak
# 2024-04-03 02:42:29
#
# Scraped 104 users this round
# Got 196 reivews
# 525760 reviews are now in the bag, so to speak
# 2024-04-03 02:45:46
#
# Scraped 120 users this round
# Got 172 reivews
# 525932 reviews are now in the bag, so to speak
# 2024-04-03 02:49:51
#
# Scraped 111 users this round
# Got 204 reivews
# 526136 reviews are now in the bag, so to speak
# 2024-04-03 02:53:37
#
# Scraped 96 users this round
# Got 205 reivews
# 526341 reviews are now in the bag, so to speak
# 2024-04-03 02:56:40
#
# Scraped 109 users this round
# Got 162 reivews
# 526503 reviews are now in the bag, so to speak
# 2024-04-03 03:00:13
#
# Scraped 94 users this round
# Got 199 reivews
# 526702 reviews are now in the bag, so to speak
# 2024-04-03 03:03:06
#
# Scraped 117 users this round
# Got 199 reivews
# 526901 reviews are now in the bag, so to speak
# 2024-04-03 03:07:03
#
# Scraped 100 users this round
# Got 192 reivews
# 527093 reviews are now in the bag, so to speak
# 2024-04-03 03:10:22
#
# Scraped 103 users this round
# Got 238 reivews
# 527331 reviews are now in the bag, so to speak
# 2024-04-03 03:13:57
#
# Scraped 103 users this round
# Got 189 reivews
# 527520 reviews are now in the bag, so to speak
# 2024-04-03 03:17:20
#
# Scraped 115 users this round
# Got 207 reivews
# 527727 reviews are now in the bag, so to speak
# 2024-04-03 03:21:07
#
# Scraped 104 users this round
# Got 186 reivews
# 527913 reviews are now in the bag, so to speak
# 2024-04-03 03:24:48
#
# Scraped 106 users this round
# Got 201 reivews
# 528114 reviews are now in the bag, so to speak
# 2024-04-03 03:28:08
#
# Scraped 107 users this round
# Got 164 reivews
# 528278 reviews are now in the bag, so to speak
# 2024-04-03 03:31:39
#
# Scraped 116 users this round
# Got 206 reivews
# 528484 reviews are now in the bag, so to speak
# 2024-04-03 03:35:30
#
# Scraped 89 users this round
# Got 191 reivews
# 528675 reviews are now in the bag, so to speak
# 2024-04-03 03:38:23
#
# Scraped 113 users this round
# Got 158 reivews
# 528833 reviews are now in the bag, so to speak
# 2024-04-03 03:42:07
#
# Scraped 108 users this round
# Got 182 reivews
# 529015 reviews are now in the bag, so to speak
# 2024-04-03 03:45:43
#
# Scraped 122 users this round
# Got 212 reivews
# 529227 reviews are now in the bag, so to speak
# 2024-04-03 03:50:00
#
# Scraped 111 users this round
# Got 162 reivews
# 529389 reviews are now in the bag, so to speak
# 2024-04-03 03:53:43
#
# Scraped 123 users this round
# Got 222 reivews
# 529611 reviews are now in the bag, so to speak
# 2024-04-03 03:58:11
#
# Scraped 93 users this round
# Got 190 reivews
# 529801 reviews are now in the bag, so to speak
# 2024-04-03 04:01:13
#
# Scraped 95 users this round
# Got 174 reivews
# 529975 reviews are now in the bag, so to speak
# 2024-04-03 04:04:52
#
# Scraped 100 users this round
# Got 183 reivews
# 530158 reviews are now in the bag, so to speak
# 2024-04-03 04:08:09
#
# Scraped 104 users this round
# Got 215 reivews
# 530373 reviews are now in the bag, so to speak
# 2024-04-03 04:11:36
#
# Scraped 115 users this round
# Got 182 reivews
# 530555 reviews are now in the bag, so to speak
# 2024-04-03 04:15:30
#
# Scraped 96 users this round
# Got 177 reivews
# 530732 reviews are now in the bag, so to speak
# 2024-04-03 04:18:24
#
# Scraped 117 users this round
# Got 179 reivews
# 530911 reviews are now in the bag, so to speak
# 2024-04-03 04:22:14
#
# Scraped 120 users this round
# Got 201 reivews
# 531112 reviews are now in the bag, so to speak
# 2024-04-03 04:26:24
#
# Scraped 132 users this round
# Got 167 reivews
# 531279 reviews are now in the bag, so to speak
# 2024-04-03 04:31:00
#
# Scraped 109 users this round
# Got 215 reivews
# 531494 reviews are now in the bag, so to speak
# 2024-04-03 04:34:33
#
# Scraped 101 users this round
# Got 205 reivews
# 531699 reviews are now in the bag, so to speak
# 2024-04-03 04:37:58
#
# Scraped 94 users this round
# Got 182 reivews
# 531881 reviews are now in the bag, so to speak
# 2024-04-03 04:41:10
#
# Scraped 100 users this round
# Got 212 reivews
# 532093 reviews are now in the bag, so to speak
# 2024-04-03 04:44:37
#
# Scraped 119 users this round
# Got 229 reivews
# 532322 reviews are now in the bag, so to speak
# 2024-04-03 04:48:36
#
# Scraped 106 users this round
# Got 206 reivews
# 532528 reviews are now in the bag, so to speak
# 2024-04-03 04:52:16
#
# Scraped 106 users this round
# Got 198 reivews
# 532726 reviews are now in the bag, so to speak
# 2024-04-03 04:55:36
#
# Scraped 105 users this round
# Got 170 reivews
# 532896 reviews are now in the bag, so to speak
# 2024-04-03 04:59:03
#
# Scraped 95 users this round
# Got 154 reivews
# 533050 reviews are now in the bag, so to speak
# 2024-04-03 05:02:01
#
# Scraped 104 users this round
# Got 162 reivews
# 533212 reviews are now in the bag, so to speak
# 2024-04-03 05:05:29
#
# Scraped 102 users this round
# Got 178 reivews
# 533390 reviews are now in the bag, so to speak
# 2024-04-03 05:08:52
#
# Scraped 99 users this round
# Got 192 reivews
# 533582 reviews are now in the bag, so to speak
# 2024-04-03 05:12:03
#
# Scraped 94 users this round
# Got 170 reivews
# 533752 reviews are now in the bag, so to speak
# 2024-04-03 05:15:06
#
# Scraped 124 users this round
# Got 182 reivews
# 533934 reviews are now in the bag, so to speak
# 2024-04-03 05:19:35
#
# Scraped 89 users this round
# Got 187 reivews
# 534121 reviews are now in the bag, so to speak
# 2024-04-03 05:22:21
#
# Scraped 114 users this round
# Got 159 reivews
# 534280 reviews are now in the bag, so to speak
# 2024-04-03 05:26:01
#
# Scraped 105 users this round
# Got 184 reivews
# 534464 reviews are now in the bag, so to speak
# 2024-04-03 05:29:32
#
# Scraped 110 users this round
# Got 212 reivews
# 534676 reviews are now in the bag, so to speak
# 2024-04-03 05:33:12
#
# Scraped 111 users this round
# Got 180 reivews
# 534856 reviews are now in the bag, so to speak
# 2024-04-03 05:36:48
#
# Scraped 123 users this round
# Got 147 reivews
# 535003 reviews are now in the bag, so to speak
# 2024-04-03 05:41:12
#
# Scraped 111 users this round
# Got 169 reivews
# 535172 reviews are now in the bag, so to speak
# 2024-04-03 05:45:03
#
# Scraped 103 users this round
# Got 195 reivews
# 535367 reviews are now in the bag, so to speak
# 2024-04-03 05:48:34
#
# Scraped 109 users this round
# Got 185 reivews
# 535552 reviews are now in the bag, so to speak
# 2024-04-03 05:52:04
#
# Scraped 111 users this round
# Got 178 reivews
# 535730 reviews are now in the bag, so to speak
# 2024-04-03 05:55:48
#
# Scraped 108 users this round
# Got 170 reivews
# 535900 reviews are now in the bag, so to speak
# 2024-04-03 05:59:36
#
# Scraped 102 users this round
# Got 183 reivews
# 536083 reviews are now in the bag, so to speak
# 2024-04-03 06:03:09
#
# Scraped 106 users this round
# Got 166 reivews
# 536249 reviews are now in the bag, so to speak
# 2024-04-03 06:06:23
#
# Scraped 105 users this round
# Got 172 reivews
# 536421 reviews are now in the bag, so to speak
# 2024-04-03 06:09:41
#
# Scraped 127 users this round
# Got 182 reivews
# 536603 reviews are now in the bag, so to speak
# 2024-04-03 06:14:01
#
# Scraped 93 users this round
# Got 205 reivews
# 536808 reviews are now in the bag, so to speak
# 2024-04-03 06:17:01
#
# Scraped 108 users this round
# Got 197 reivews
# 537005 reviews are now in the bag, so to speak
# 2024-04-03 06:20:31
#
# Scraped 110 users this round
# Got 164 reivews
# 537169 reviews are now in the bag, so to speak
# 2024-04-03 06:24:03
#
# Scraped 103 users this round
# Got 220 reivews
# 537389 reviews are now in the bag, so to speak
# 2024-04-03 06:27:28
#
# Scraped 121 users this round
# Got 176 reivews
# 537565 reviews are now in the bag, so to speak
# 2024-04-03 06:32:13
#
# Scraped 126 users this round
# Got 227 reivews
# 537792 reviews are now in the bag, so to speak
# 2024-04-03 06:36:41
#
# Scraped 97 users this round
# Got 197 reivews
# 537989 reviews are now in the bag, so to speak
# 2024-04-03 06:39:55
#
# Scraped 111 users this round
# Got 180 reivews
# 538169 reviews are now in the bag, so to speak
# 2024-04-03 06:43:56
#
# Scraped 93 users this round
# Got 198 reivews
# 538367 reviews are now in the bag, so to speak
# 2024-04-03 06:47:04
#
# Scraped 98 users this round
# Got 198 reivews
# 538565 reviews are now in the bag, so to speak
# 2024-04-03 06:50:26
#
# Scraped 99 users this round
# Got 225 reivews
# 538790 reviews are now in the bag, so to speak
# 2024-04-03 06:53:45
#
# Scraped 105 users this round
# Got 211 reivews
# 539001 reviews are now in the bag, so to speak
# 2024-04-03 06:57:17
#
# Scraped 130 users this round
# Got 206 reivews
# 539207 reviews are now in the bag, so to speak
# 2024-04-03 07:01:54
#
# Scraped 101 users this round
# Got 191 reivews
# 539398 reviews are now in the bag, so to speak
# 2024-04-03 07:05:10
#
# Scraped 114 users this round
# Got 145 reivews
# 539543 reviews are now in the bag, so to speak
# 2024-04-03 07:09:04
#
# Scraped 106 users this round
# Got 183 reivews
# 539726 reviews are now in the bag, so to speak
# 2024-04-03 07:12:36
#
# Scraped 126 users this round
# Got 165 reivews
# 539891 reviews are now in the bag, so to speak
# 2024-04-03 07:16:50
#
# Scraped 114 users this round
# Got 204 reivews
# 540095 reviews are now in the bag, so to speak
# 2024-04-03 07:20:33
#
# Scraped 92 users this round
# Got 180 reivews
# 540275 reviews are now in the bag, so to speak
# 2024-04-03 07:23:36
#
# Scraped 111 users this round
# Got 196 reivews
# 540471 reviews are now in the bag, so to speak
# 2024-04-03 07:27:24
#
# Scraped 105 users this round
# Got 184 reivews
# 540655 reviews are now in the bag, so to speak
# 2024-04-03 07:31:40
#
# Scraped 110 users this round
# Got 195 reivews
# 540850 reviews are now in the bag, so to speak
# 2024-04-03 07:35:25
#
# Scraped 99 users this round
# Got 227 reivews
# 541077 reviews are now in the bag, so to speak
# 2024-04-03 07:38:43
#
# Scraped 115 users this round
# Got 193 reivews
# 541270 reviews are now in the bag, so to speak
# 2024-04-03 07:43:01
#
# Scraped 94 users this round
# Got 192 reivews
# 541462 reviews are now in the bag, so to speak
# 2024-04-03 07:46:06
#
# Scraped 115 users this round
# Got 232 reivews
# 541694 reviews are now in the bag, so to speak
# 2024-04-03 07:49:55
#
# Scraped 101 users this round
# Got 194 reivews
# 541888 reviews are now in the bag, so to speak
# 2024-04-03 07:53:26
#
# Scraped 110 users this round
# Got 156 reivews
# 542044 reviews are now in the bag, so to speak
# 2024-04-03 07:57:05
#
# Scraped 105 users this round
# Got 180 reivews
# 542224 reviews are now in the bag, so to speak
# 2024-04-03 08:00:52
#
# Scraped 88 users this round
# Got 202 reivews
# 542426 reviews are now in the bag, so to speak
# 2024-04-03 08:03:45
#
# Scraped 108 users this round
# Got 158 reivews
# 542584 reviews are now in the bag, so to speak
# 2024-04-03 08:07:40
#
# Scraped 113 users this round
# Got 177 reivews
# 542761 reviews are now in the bag, so to speak
# 2024-04-03 08:11:54
#
# Scraped 111 users this round
# Got 210 reivews
# 542971 reviews are now in the bag, so to speak
# 2024-04-03 08:16:50
#
# Scraped 132 users this round
# Got 194 reivews
# 543165 reviews are now in the bag, so to speak
# 2024-04-03 08:22:40
#
# Unable to parse review blocks.
