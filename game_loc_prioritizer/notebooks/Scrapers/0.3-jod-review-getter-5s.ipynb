# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 5

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')


# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 116 users this round
# Got 194 reivews
# 303362 reviews are now in the bag, so to speak
# 2024-03-31 20:25:59
#
# Scraped 102 users this round
# Got 182 reivews
# 303544 reviews are now in the bag, so to speak
# 2024-03-31 20:29:22
#
# Scraped 115 users this round
# Got 159 reivews
# 303703 reviews are now in the bag, so to speak
# 2024-03-31 20:33:20
#
# Scraped 112 users this round
# Got 190 reivews
# 303893 reviews are now in the bag, so to speak
# 2024-03-31 20:37:35
#
# Scraped 108 users this round
# Got 206 reivews
# 304099 reviews are now in the bag, so to speak
# 2024-03-31 20:41:14
#
# Scraped 90 users this round
# Got 197 reivews
# 304296 reviews are now in the bag, so to speak
# 2024-03-31 20:44:21
#
# Scraped 121 users this round
# Got 178 reivews
# 304474 reviews are now in the bag, so to speak
# 2024-03-31 20:48:38
#
# Scraped 103 users this round
# Got 205 reivews
# 304679 reviews are now in the bag, so to speak
# 2024-03-31 20:51:54
#
# Scraped 122 users this round
# Got 197 reivews
# 304876 reviews are now in the bag, so to speak
# 2024-03-31 20:56:03
#
# Scraped 115 users this round
# Got 143 reivews
# 305019 reviews are now in the bag, so to speak
# 2024-03-31 21:00:17
#
# Scraped 86 users this round
# Got 162 reivews
# 305181 reviews are now in the bag, so to speak
# 2024-03-31 21:03:16
#
# Scraped 102 users this round
# Got 194 reivews
# 305375 reviews are now in the bag, so to speak
# 2024-03-31 21:06:52
#
# Scraped 112 users this round
# Got 243 reivews
# 305618 reviews are now in the bag, so to speak
# 2024-03-31 21:10:44
#
# Scraped 99 users this round
# Got 186 reivews
# 305804 reviews are now in the bag, so to speak
# 2024-03-31 21:14:11
#
# Scraped 101 users this round
# Got 172 reivews
# 305976 reviews are now in the bag, so to speak
# 2024-03-31 21:17:49
#
# Scraped 106 users this round
# Got 228 reivews
# 306204 reviews are now in the bag, so to speak
# 2024-03-31 21:21:41
#
# Scraped 87 users this round
# Got 153 reivews
# 306357 reviews are now in the bag, so to speak
# 2024-03-31 21:24:38
#
# Scraped 112 users this round
# Got 214 reivews
# 306571 reviews are now in the bag, so to speak
# 2024-03-31 21:28:57
#
# Scraped 117 users this round
# Got 205 reivews
# 306776 reviews are now in the bag, so to speak
# 2024-03-31 21:33:44
#
# Scraped 109 users this round
# Got 193 reivews
# 306969 reviews are now in the bag, so to speak
# 2024-03-31 21:38:14
#
# Scraped 104 users this round
# Got 197 reivews
# 307166 reviews are now in the bag, so to speak
# 2024-03-31 21:42:23
#
# Scraped 105 users this round
# Got 174 reivews
# 307340 reviews are now in the bag, so to speak
# 2024-03-31 21:46:16
#
# Scraped 93 users this round
# Got 230 reivews
# 307570 reviews are now in the bag, so to speak
# 2024-03-31 21:49:37
#
# Scraped 107 users this round
# Got 182 reivews
# 307752 reviews are now in the bag, so to speak
# 2024-03-31 21:53:51
#
# Scraped 125 users this round
# Got 205 reivews
# 307957 reviews are now in the bag, so to speak
# 2024-03-31 21:58:40
#
# Scraped 95 users this round
# Got 163 reivews
# 308120 reviews are now in the bag, so to speak
# 2024-03-31 22:01:57
#
# Scraped 86 users this round
# Got 188 reivews
# 308308 reviews are now in the bag, so to speak
# 2024-03-31 22:05:05
#
# Scraped 120 users this round
# Got 184 reivews
# 308492 reviews are now in the bag, so to speak
# 2024-03-31 22:10:06
#
# Scraped 117 users this round
# Got 179 reivews
# 308671 reviews are now in the bag, so to speak
# 2024-03-31 22:16:21
#
# Scraped 102 users this round
# Got 206 reivews
# 308877 reviews are now in the bag, so to speak
# 2024-03-31 22:21:46
#
# Scraped 102 users this round
# Got 208 reivews
# 309085 reviews are now in the bag, so to speak
# 2024-03-31 22:27:11
#
# Scraped 107 users this round
# Got 202 reivews
# 309287 reviews are now in the bag, so to speak
# 2024-03-31 22:33:10
#
# Scraped 104 users this round
# Got 175 reivews
# 309462 reviews are now in the bag, so to speak
# 2024-03-31 22:38:54
#
# Scraped 119 users this round
# Got 158 reivews
# 309620 reviews are now in the bag, so to speak
# 2024-03-31 22:45:27
#
# Scraped 104 users this round
# Got 177 reivews
# 309797 reviews are now in the bag, so to speak
# 2024-03-31 22:51:23
#
# Scraped 100 users this round
# Got 196 reivews
# 309993 reviews are now in the bag, so to speak
# 2024-03-31 22:57:27
#
# Scraped 99 users this round
# Got 193 reivews
# 310186 reviews are now in the bag, so to speak
# 2024-03-31 23:03:02
#
# Scraped 101 users this round
# Got 223 reivews
# 310409 reviews are now in the bag, so to speak
# 2024-03-31 23:08:43
#
# Scraped 102 users this round
# Got 215 reivews
# 310624 reviews are now in the bag, so to speak
# 2024-03-31 23:14:28
#
# Scraped 107 users this round
# Got 218 reivews
# 310842 reviews are now in the bag, so to speak
# 2024-03-31 23:20:43
#
# Scraped 96 users this round
# Got 203 reivews
# 311045 reviews are now in the bag, so to speak
# 2024-03-31 23:25:42
#
# Scraped 109 users this round
# Got 198 reivews
# 311243 reviews are now in the bag, so to speak
# 2024-03-31 23:29:26
#
# Scraped 97 users this round
# Got 166 reivews
# 311409 reviews are now in the bag, so to speak
# 2024-03-31 23:32:46
#
# Scraped 117 users this round
# Got 193 reivews
# 311602 reviews are now in the bag, so to speak
# 2024-03-31 23:36:44
#
# Scraped 106 users this round
# Got 178 reivews
# 311780 reviews are now in the bag, so to speak
# 2024-03-31 23:40:11
#
# Scraped 106 users this round
# Got 138 reivews
# 311918 reviews are now in the bag, so to speak
# 2024-03-31 23:43:55
#
# Scraped 121 users this round
# Got 187 reivews
# 312105 reviews are now in the bag, so to speak
# 2024-03-31 23:47:55
#
# Scraped 98 users this round
# Got 163 reivews
# 312268 reviews are now in the bag, so to speak
# 2024-03-31 23:51:04
#
# Scraped 103 users this round
# Got 219 reivews
# 312487 reviews are now in the bag, so to speak
# 2024-03-31 23:54:29
#
# Scraped 97 users this round
# Got 151 reivews
# 312638 reviews are now in the bag, so to speak
# 2024-03-31 23:57:32
#
# Scraped 122 users this round
# Got 178 reivews
# 312816 reviews are now in the bag, so to speak
# 2024-04-01 00:01:49
#
# Scraped 115 users this round
# Got 197 reivews
# 313013 reviews are now in the bag, so to speak
# 2024-04-01 00:05:40
#
# Scraped 112 users this round
# Got 163 reivews
# 313176 reviews are now in the bag, so to speak
# 2024-04-01 00:09:34
#
# Scraped 105 users this round
# Got 222 reivews
# 313398 reviews are now in the bag, so to speak
# 2024-04-01 00:13:08
#
# Scraped 119 users this round
# Got 174 reivews
# 313572 reviews are now in the bag, so to speak
# 2024-04-01 00:17:21
#
# Scraped 116 users this round
# Got 216 reivews
# 313788 reviews are now in the bag, so to speak
# 2024-04-01 00:21:16
#
# Scraped 122 users this round
# Got 159 reivews
# 313947 reviews are now in the bag, so to speak
# 2024-04-01 00:25:32
#
# Scraped 130 users this round
# Got 208 reivews
# 314155 reviews are now in the bag, so to speak
# 2024-04-01 00:30:12
#
# Scraped 118 users this round
# Got 189 reivews
# 314344 reviews are now in the bag, so to speak
# 2024-04-01 00:34:10
#
# Scraped 98 users this round
# Got 213 reivews
# 314557 reviews are now in the bag, so to speak
# 2024-04-01 00:37:24
#
# Unable to parse review blocks.
# Scraped 102 users this round
# Got 192 reivews
# 314749 reviews are now in the bag, so to speak
# 2024-04-01 00:47:01
#
# Scraped 121 users this round
# Got 169 reivews
# 314918 reviews are now in the bag, so to speak
# 2024-04-01 00:51:07
#
# Scraped 105 users this round
# Got 180 reivews
# 315098 reviews are now in the bag, so to speak
# 2024-04-01 00:54:37
#
# Scraped 93 users this round
# Got 218 reivews
# 315316 reviews are now in the bag, so to speak
# 2024-04-01 00:57:56
#
# Scraped 108 users this round
# Got 223 reivews
# 315539 reviews are now in the bag, so to speak
# 2024-04-01 01:01:41
#
# Scraped 102 users this round
# Got 213 reivews
# 315752 reviews are now in the bag, so to speak
# 2024-04-01 01:05:16
#
# Scraped 119 users this round
# Got 199 reivews
# 315951 reviews are now in the bag, so to speak
# 2024-04-01 01:09:16
#
# Scraped 98 users this round
# Got 178 reivews
# 316129 reviews are now in the bag, so to speak
# 2024-04-01 01:12:45
#
# Scraped 104 users this round
# Got 166 reivews
# 316295 reviews are now in the bag, so to speak
# 2024-04-01 01:16:09
#
# Scraped 120 users this round
# Got 213 reivews
# 316508 reviews are now in the bag, so to speak
# 2024-04-01 01:20:14
#
# Scraped 113 users this round
# Got 192 reivews
# 316700 reviews are now in the bag, so to speak
# 2024-04-01 01:24:05
#
# Scraped 111 users this round
# Got 207 reivews
# 316907 reviews are now in the bag, so to speak
# 2024-04-01 01:27:55
#
# Scraped 97 users this round
# Got 192 reivews
# 317099 reviews are now in the bag, so to speak
# 2024-04-01 01:31:07
#
# Scraped 107 users this round
# Got 161 reivews
# 317260 reviews are now in the bag, so to speak
# 2024-04-01 01:34:46
#
# Scraped 112 users this round
# Got 203 reivews
# 317463 reviews are now in the bag, so to speak
# 2024-04-01 01:38:32
#
# Scraped 110 users this round
# Got 182 reivews
# 317645 reviews are now in the bag, so to speak
# 2024-04-01 01:41:59
#
# Scraped 119 users this round
# Got 165 reivews
# 317810 reviews are now in the bag, so to speak
# 2024-04-01 01:46:17
#
# Scraped 115 users this round
# Got 162 reivews
# 317972 reviews are now in the bag, so to speak
# 2024-04-01 01:50:00
#
# Scraped 107 users this round
# Got 171 reivews
# 318143 reviews are now in the bag, so to speak
# 2024-04-01 01:53:35
#
# Scraped 124 users this round
# Got 190 reivews
# 318333 reviews are now in the bag, so to speak
# 2024-04-01 01:58:07
#
# Scraped 121 users this round
# Got 184 reivews
# 318517 reviews are now in the bag, so to speak
# 2024-04-01 02:02:20
#
# Scraped 114 users this round
# Got 186 reivews
# 318703 reviews are now in the bag, so to speak
# 2024-04-01 02:06:07
#
# Scraped 121 users this round
# Got 184 reivews
# 318887 reviews are now in the bag, so to speak
# 2024-04-01 02:10:18
#
# Scraped 114 users this round
# Got 201 reivews
# 319088 reviews are now in the bag, so to speak
# 2024-04-01 02:14:02
#
# Scraped 90 users this round
# Got 166 reivews
# 319254 reviews are now in the bag, so to speak
# 2024-04-01 02:16:45
#
# Scraped 102 users this round
# Got 173 reivews
# 319427 reviews are now in the bag, so to speak
# 2024-04-01 02:19:55
#
# Scraped 113 users this round
# Got 215 reivews
# 319642 reviews are now in the bag, so to speak
# 2024-04-01 02:23:40
#
# Scraped 92 users this round
# Got 145 reivews
# 319787 reviews are now in the bag, so to speak
# 2024-04-01 02:26:27
#
# Scraped 108 users this round
# Got 199 reivews
# 319986 reviews are now in the bag, so to speak
# 2024-04-01 02:29:58
#
# Scraped 98 users this round
# Got 183 reivews
# 320169 reviews are now in the bag, so to speak
# 2024-04-01 02:33:06
#
# Scraped 119 users this round
# Got 192 reivews
# 320361 reviews are now in the bag, so to speak
# 2024-04-01 02:36:53
#
# Scraped 107 users this round
# Got 227 reivews
# 320588 reviews are now in the bag, so to speak
# 2024-04-01 02:40:21
#
# Scraped 98 users this round
# Got 213 reivews
# 320801 reviews are now in the bag, so to speak
# 2024-04-01 02:43:32
#
# Scraped 128 users this round
# Got 170 reivews
# 320971 reviews are now in the bag, so to speak
# 2024-04-01 02:47:47
#
# Scraped 123 users this round
# Got 201 reivews
# 321172 reviews are now in the bag, so to speak
# 2024-04-01 02:51:58
#
# Scraped 128 users this round
# Got 156 reivews
# 321328 reviews are now in the bag, so to speak
# 2024-04-01 02:56:25
#
# Scraped 122 users this round
# Got 229 reivews
# 321557 reviews are now in the bag, so to speak
# 2024-04-01 03:00:29
#
# Scraped 123 users this round
# Got 235 reivews
# 321792 reviews are now in the bag, so to speak
# 2024-04-01 03:04:46
#
# Scraped 99 users this round
# Got 176 reivews
# 321968 reviews are now in the bag, so to speak
# 2024-04-01 03:08:00
#
# Scraped 93 users this round
# Got 176 reivews
# 322144 reviews are now in the bag, so to speak
# 2024-04-01 03:10:48
#
# Scraped 101 users this round
# Got 185 reivews
# 322329 reviews are now in the bag, so to speak
# 2024-04-01 03:14:00
#
# Scraped 112 users this round
# Got 230 reivews
# 322559 reviews are now in the bag, so to speak
# 2024-04-01 03:17:59
#
# Scraped 116 users this round
# Got 207 reivews
# 322766 reviews are now in the bag, so to speak
# 2024-04-01 03:21:51
#
# Scraped 105 users this round
# Got 173 reivews
# 322939 reviews are now in the bag, so to speak
# 2024-04-01 03:25:15
#
# Scraped 99 users this round
# Got 166 reivews
# 323105 reviews are now in the bag, so to speak
# 2024-04-01 03:28:17
#
# Scraped 132 users this round
# Got 165 reivews
# 323270 reviews are now in the bag, so to speak
# 2024-04-01 03:32:37
#
# Scraped 112 users this round
# Got 189 reivews
# 323459 reviews are now in the bag, so to speak
# 2024-04-01 03:36:12
#
# Scraped 111 users this round
# Got 216 reivews
# 323675 reviews are now in the bag, so to speak
# 2024-04-01 03:39:51
#
# Scraped 132 users this round
# Got 191 reivews
# 323866 reviews are now in the bag, so to speak
# 2024-04-01 03:44:22
#
# Scraped 112 users this round
# Got 183 reivews
# 324049 reviews are now in the bag, so to speak
# 2024-04-01 03:48:13
#
# Scraped 104 users this round
# Got 202 reivews
# 324251 reviews are now in the bag, so to speak
# 2024-04-01 03:51:34
#
# Scraped 116 users this round
# Got 238 reivews
# 324489 reviews are now in the bag, so to speak
# 2024-04-01 03:55:26
#
# Scraped 126 users this round
# Got 147 reivews
# 324636 reviews are now in the bag, so to speak
# 2024-04-01 03:59:27
#
# Scraped 97 users this round
# Got 202 reivews
# 324838 reviews are now in the bag, so to speak
# 2024-04-01 04:02:34
#
# Scraped 106 users this round
# Got 190 reivews
# 325028 reviews are now in the bag, so to speak
# 2024-04-01 04:06:09
#
# Scraped 145 users this round
# Got 152 reivews
# 325180 reviews are now in the bag, so to speak
# 2024-04-01 04:11:12
#
# Scraped 112 users this round
# Got 179 reivews
# 325359 reviews are now in the bag, so to speak
# 2024-04-01 04:14:47
#
# Scraped 99 users this round
# Got 190 reivews
# 325549 reviews are now in the bag, so to speak
# 2024-04-01 04:17:56
#
# Scraped 93 users this round
# Got 175 reivews
# 325724 reviews are now in the bag, so to speak
# 2024-04-01 04:20:46
#
# Scraped 116 users this round
# Got 203 reivews
# 325927 reviews are now in the bag, so to speak
# 2024-04-01 04:24:35
#
# Scraped 97 users this round
# Got 181 reivews
# 326108 reviews are now in the bag, so to speak
# 2024-04-01 04:27:50
#
# Scraped 99 users this round
# Got 197 reivews
# 326305 reviews are now in the bag, so to speak
# 2024-04-01 04:31:02
#
# Scraped 120 users this round
# Got 179 reivews
# 326484 reviews are now in the bag, so to speak
# 2024-04-01 04:35:12
#
# Scraped 108 users this round
# Got 171 reivews
# 326655 reviews are now in the bag, so to speak
# 2024-04-01 04:38:54
#
# Scraped 118 users this round
# Got 218 reivews
# 326873 reviews are now in the bag, so to speak
# 2024-04-01 04:42:53
#
# Scraped 132 users this round
# Got 183 reivews
# 327056 reviews are now in the bag, so to speak
# 2024-04-01 04:47:03
#
# Scraped 109 users this round
# Got 179 reivews
# 327235 reviews are now in the bag, so to speak
# 2024-04-01 04:50:32
#
# Scraped 109 users this round
# Got 231 reivews
# 327466 reviews are now in the bag, so to speak
# 2024-04-01 04:54:13
#
# Scraped 107 users this round
# Got 184 reivews
# 327650 reviews are now in the bag, so to speak
# 2024-04-01 04:57:34
#
# Scraped 114 users this round
# Got 184 reivews
# 327834 reviews are now in the bag, so to speak
# 2024-04-01 05:01:18
#
# Scraped 121 users this round
# Got 198 reivews
# 328032 reviews are now in the bag, so to speak
# 2024-04-01 05:05:21
#
# Scraped 113 users this round
# Got 223 reivews
# 328255 reviews are now in the bag, so to speak
# 2024-04-01 05:09:14
#
# Scraped 119 users this round
# Got 181 reivews
# 328436 reviews are now in the bag, so to speak
# 2024-04-01 05:13:10
#
# Scraped 109 users this round
# Got 185 reivews
# 328621 reviews are now in the bag, so to speak
# 2024-04-01 05:16:36
#
# Scraped 118 users this round
# Got 194 reivews
# 328815 reviews are now in the bag, so to speak
# 2024-04-01 05:20:25
#
# Scraped 114 users this round
# Got 190 reivews
# 329005 reviews are now in the bag, so to speak
# 2024-04-01 05:23:57
#
# Scraped 130 users this round
# Got 199 reivews
# 329204 reviews are now in the bag, so to speak
# 2024-04-01 05:28:06
#
# Scraped 92 users this round
# Got 214 reivews
# 329418 reviews are now in the bag, so to speak
# 2024-04-01 05:31:00
#
# Scraped 152 users this round
# Got 166 reivews
# 329584 reviews are now in the bag, so to speak
# 2024-04-01 05:36:13
#
# Scraped 99 users this round
# Got 212 reivews
# 329796 reviews are now in the bag, so to speak
# 2024-04-01 05:39:20
#
# Scraped 116 users this round
# Got 195 reivews
# 329991 reviews are now in the bag, so to speak
# 2024-04-01 05:43:02
#
# Scraped 103 users this round
# Got 202 reivews
# 330193 reviews are now in the bag, so to speak
# 2024-04-01 05:46:20
#
# Scraped 96 users this round
# Got 188 reivews
# 330381 reviews are now in the bag, so to speak
# 2024-04-01 05:48:48
#
# Scraped 105 users this round
# Got 164 reivews
# 330545 reviews are now in the bag, so to speak
# 2024-04-01 05:52:12
#
# Scraped 96 users this round
# Got 184 reivews
# 330729 reviews are now in the bag, so to speak
# 2024-04-01 05:55:15
#
# Scraped 110 users this round
# Got 211 reivews
# 330940 reviews are now in the bag, so to speak
# 2024-04-01 05:58:50
#
# Scraped 113 users this round
# Got 196 reivews
# 331136 reviews are now in the bag, so to speak
# 2024-04-01 06:02:42
#
# Scraped 113 users this round
# Got 203 reivews
# 331339 reviews are now in the bag, so to speak
# 2024-04-01 06:06:26
#
# Scraped 128 users this round
# Got 162 reivews
# 331501 reviews are now in the bag, so to speak
# 2024-04-01 06:10:55
#
# Scraped 113 users this round
# Got 218 reivews
# 331719 reviews are now in the bag, so to speak
# 2024-04-01 06:14:30
#
# Scraped 107 users this round
# Got 154 reivews
# 331873 reviews are now in the bag, so to speak
# 2024-04-01 06:18:13
#
# Scraped 98 users this round
# Got 143 reivews
# 332016 reviews are now in the bag, so to speak
# 2024-04-01 06:21:26
#
# Scraped 99 users this round
# Got 182 reivews
# 332198 reviews are now in the bag, so to speak
# 2024-04-01 06:24:40
#
# Scraped 105 users this round
# Got 189 reivews
# 332387 reviews are now in the bag, so to speak
# 2024-04-01 06:28:06
#
# Scraped 97 users this round
# Got 227 reivews
# 332614 reviews are now in the bag, so to speak
# 2024-04-01 06:31:15
#
# Scraped 120 users this round
# Got 197 reivews
# 332811 reviews are now in the bag, so to speak
# 2024-04-01 06:35:34
#
# Scraped 110 users this round
# Got 206 reivews
# 333017 reviews are now in the bag, so to speak
# 2024-04-01 06:39:12
#
# Scraped 104 users this round
# Got 159 reivews
# 333176 reviews are now in the bag, so to speak
# 2024-04-01 06:42:39
#
# Scraped 122 users this round
# Got 188 reivews
# 333364 reviews are now in the bag, so to speak
# 2024-04-01 06:46:44
#
# Scraped 120 users this round
# Got 123 reivews
# 333487 reviews are now in the bag, so to speak
# 2024-04-01 06:50:58
#
# Scraped 117 users this round
# Got 165 reivews
# 333652 reviews are now in the bag, so to speak
# 2024-04-01 06:54:58
#
# Scraped 133 users this round
# Got 203 reivews
# 333855 reviews are now in the bag, so to speak
# 2024-04-01 06:59:41
#
# Scraped 121 users this round
# Got 167 reivews
# 334022 reviews are now in the bag, so to speak
# 2024-04-01 07:04:02
#
# Scraped 89 users this round
# Got 148 reivews
# 334170 reviews are now in the bag, so to speak
# 2024-04-01 07:06:49
#
# Scraped 117 users this round
# Got 178 reivews
# 334348 reviews are now in the bag, so to speak
# 2024-04-01 07:10:52
#
# Scraped 111 users this round
# Got 174 reivews
# 334522 reviews are now in the bag, so to speak
# 2024-04-01 07:14:35
#
# Scraped 97 users this round
# Got 152 reivews
# 334674 reviews are now in the bag, so to speak
# 2024-04-01 07:17:43
#
# Scraped 99 users this round
# Got 152 reivews
# 334826 reviews are now in the bag, so to speak
# 2024-04-01 07:20:55
#
# Scraped 105 users this round
# Got 207 reivews
# 335033 reviews are now in the bag, so to speak
# 2024-04-01 07:24:31
#
# Scraped 127 users this round
# Got 235 reivews
# 335268 reviews are now in the bag, so to speak
# 2024-04-01 07:28:43
#
# Scraped 114 users this round
# Got 180 reivews
# 335448 reviews are now in the bag, so to speak
# 2024-04-01 07:32:37
#
# Scraped 111 users this round
# Got 199 reivews
# 335647 reviews are now in the bag, so to speak
# 2024-04-01 07:36:28
#
# Scraped 115 users this round
# Got 195 reivews
# 335842 reviews are now in the bag, so to speak
# 2024-04-01 07:40:12
#
# Scraped 105 users this round
# Got 172 reivews
# 336014 reviews are now in the bag, so to speak
# 2024-04-01 07:43:54
#
# Scraped 119 users this round
# Got 203 reivews
# 336217 reviews are now in the bag, so to speak
# 2024-04-01 07:47:53
#
# Scraped 100 users this round
# Got 188 reivews
# 336405 reviews are now in the bag, so to speak
# 2024-04-01 07:51:18
#
# Scraped 111 users this round
# Got 175 reivews
# 336580 reviews are now in the bag, so to speak
# 2024-04-01 07:55:16
#
# Scraped 129 users this round
# Got 205 reivews
# 336785 reviews are now in the bag, so to speak
# 2024-04-01 07:59:45
#
# Scraped 97 users this round
# Got 170 reivews
# 336955 reviews are now in the bag, so to speak
# 2024-04-01 08:03:01
#
# Scraped 120 users this round
# Got 167 reivews
# 337122 reviews are now in the bag, so to speak
# 2024-04-01 08:07:20
#
# Scraped 113 users this round
# Got 164 reivews
# 337286 reviews are now in the bag, so to speak
# 2024-04-01 08:11:14
#
# Scraped 100 users this round
# Got 156 reivews
# 337442 reviews are now in the bag, so to speak
# 2024-04-01 08:14:54
#
# Scraped 118 users this round
# Got 196 reivews
# 337638 reviews are now in the bag, so to speak
# 2024-04-01 08:18:59
#
# Scraped 105 users this round
# Got 189 reivews
# 337827 reviews are now in the bag, so to speak
# 2024-04-01 08:22:35
#
# Scraped 108 users this round
# Got 163 reivews
# 337990 reviews are now in the bag, so to speak
# 2024-04-01 08:26:26
#
# Scraped 96 users this round
# Got 198 reivews
# 338188 reviews are now in the bag, so to speak
# 2024-04-01 08:30:03
#
# Scraped 111 users this round
# Got 211 reivews
# 338399 reviews are now in the bag, so to speak
# 2024-04-01 08:33:46
#
# Scraped 104 users this round
# Got 208 reivews
# 338607 reviews are now in the bag, so to speak
# 2024-04-01 08:37:21
#
# Scraped 100 users this round
# Got 179 reivews
# 338786 reviews are now in the bag, so to speak
# 2024-04-01 08:40:46
#
# Scraped 128 users this round
# Got 195 reivews
# 338981 reviews are now in the bag, so to speak
# 2024-04-01 08:45:11
#
# Scraped 104 users this round
# Got 217 reivews
# 339198 reviews are now in the bag, so to speak
# 2024-04-01 08:48:43
#
# Scraped 112 users this round
# Got 190 reivews
# 339388 reviews are now in the bag, so to speak
# 2024-04-01 08:52:49
#
# Scraped 113 users this round
# Got 211 reivews
# 339599 reviews are now in the bag, so to speak
# 2024-04-01 08:56:48
#
# Scraped 106 users this round
# Got 196 reivews
# 339795 reviews are now in the bag, so to speak
# 2024-04-01 09:00:22
#
# Scraped 95 users this round
# Got 206 reivews
# 340001 reviews are now in the bag, so to speak
# 2024-04-01 09:03:36
#
# Scraped 90 users this round
# Got 166 reivews
# 340167 reviews are now in the bag, so to speak
# 2024-04-01 09:06:16
#
# Scraped 112 users this round
# Got 238 reivews
# 340405 reviews are now in the bag, so to speak
# 2024-04-01 09:10:01
#
# Scraped 106 users this round
# Got 189 reivews
# 340594 reviews are now in the bag, so to speak
# 2024-04-01 09:13:34
#
# Scraped 128 users this round
# Got 175 reivews
# 340769 reviews are now in the bag, so to speak
# 2024-04-01 09:18:05
#
# Scraped 132 users this round
# Got 199 reivews
# 340968 reviews are now in the bag, so to speak
# 2024-04-01 09:23:12
#
# Scraped 118 users this round
# Got 167 reivews
# 341135 reviews are now in the bag, so to speak
# 2024-04-01 09:27:34
#
# Scraped 129 users this round
# Got 169 reivews
# 341304 reviews are now in the bag, so to speak
# 2024-04-01 09:32:07
#
# Scraped 96 users this round
# Got 149 reivews
# 341453 reviews are now in the bag, so to speak
# 2024-04-01 09:35:16
#
# Scraped 85 users this round
# Got 171 reivews
# 341624 reviews are now in the bag, so to speak
# 2024-04-01 09:38:03
#
# Scraped 112 users this round
# Got 184 reivews
# 341808 reviews are now in the bag, so to speak
# 2024-04-01 09:42:20
#
# Scraped 113 users this round
# Got 232 reivews
# 342040 reviews are now in the bag, so to speak
# 2024-04-01 09:46:29
#
# Scraped 112 users this round
# Got 181 reivews
# 342221 reviews are now in the bag, so to speak
# 2024-04-01 09:50:38
#
# Scraped 96 users this round
# Got 179 reivews
# 342400 reviews are now in the bag, so to speak
# 2024-04-01 09:54:02
#
# Scraped 107 users this round
# Got 140 reivews
# 342540 reviews are now in the bag, so to speak
# 2024-04-01 09:58:05
#
# Scraped 101 users this round
# Got 173 reivews
# 342713 reviews are now in the bag, so to speak
# 2024-04-01 10:01:42
#
# Scraped 130 users this round
# Got 136 reivews
# 342849 reviews are now in the bag, so to speak
# 2024-04-01 10:06:29
#
# Scraped 109 users this round
# Got 212 reivews
# 343061 reviews are now in the bag, so to speak
# 2024-04-01 10:10:34
#
# Scraped 94 users this round
# Got 203 reivews
# 343264 reviews are now in the bag, so to speak
# 2024-04-01 10:14:03
#
# Scraped 114 users this round
# Got 231 reivews
# 343495 reviews are now in the bag, so to speak
# 2024-04-01 10:18:25
#
# Scraped 105 users this round
# Got 199 reivews
# 343694 reviews are now in the bag, so to speak
# 2024-04-01 10:22:07
#
# Scraped 107 users this round
# Got 179 reivews
# 343873 reviews are now in the bag, so to speak
# 2024-04-01 10:26:07
#
# Scraped 125 users this round
# Got 187 reivews
# 344060 reviews are now in the bag, so to speak
# 2024-04-01 10:31:11
#
# Scraped 117 users this round
# Got 198 reivews
# 344258 reviews are now in the bag, so to speak
# 2024-04-01 10:35:46
#
# Scraped 107 users this round
# Got 226 reivews
# 344484 reviews are now in the bag, so to speak
# 2024-04-01 10:39:45
#
# Scraped 112 users this round
# Got 166 reivews
# 344650 reviews are now in the bag, so to speak
# 2024-04-01 10:43:57
#
# Scraped 126 users this round
# Got 159 reivews
# 344809 reviews are now in the bag, so to speak
# 2024-04-01 10:48:52
#
# Scraped 97 users this round
# Got 157 reivews
# 344966 reviews are now in the bag, so to speak
# 2024-04-01 10:52:18
#
# Scraped 94 users this round
# Got 150 reivews
# 345116 reviews are now in the bag, so to speak
# 2024-04-01 10:55:39
#
# Scraped 125 users this round
# Got 187 reivews
# 345303 reviews are now in the bag, so to speak
# 2024-04-01 11:00:27
#
# Scraped 100 users this round
# Got 204 reivews
# 345507 reviews are now in the bag, so to speak
# 2024-04-01 11:04:20
#
# Scraped 108 users this round
# Got 174 reivews
# 345681 reviews are now in the bag, so to speak
# 2024-04-01 11:08:31
#
# Scraped 118 users this round
# Got 149 reivews
# 345830 reviews are now in the bag, so to speak
# 2024-04-01 11:13:08
#
# Scraped 117 users this round
# Got 174 reivews
# 346004 reviews are now in the bag, so to speak
# 2024-04-01 11:17:31
#
# Scraped 113 users this round
# Got 183 reivews
# 346187 reviews are now in the bag, so to speak
# 2024-04-01 11:21:46
#
# Scraped 104 users this round
# Got 193 reivews
# 346380 reviews are now in the bag, so to speak
# 2024-04-01 11:25:32
#
# Scraped 110 users this round
# Got 273 reivews
# 346653 reviews are now in the bag, so to speak
# 2024-04-01 11:30:06
#
# Scraped 121 users this round
# Got 175 reivews
# 346828 reviews are now in the bag, so to speak
# 2024-04-01 11:34:47
#
# Scraped 127 users this round
# Got 157 reivews
# 346985 reviews are now in the bag, so to speak
# 2024-04-01 11:39:26
#
# Scraped 100 users this round
# Got 175 reivews
# 347160 reviews are now in the bag, so to speak
# 2024-04-01 11:43:05
#
# Scraped 124 users this round
# Got 204 reivews
# 347364 reviews are now in the bag, so to speak
# 2024-04-01 11:47:42
#
# Scraped 117 users this round
# Got 189 reivews
# 347553 reviews are now in the bag, so to speak
# 2024-04-01 11:52:14
#
# Scraped 107 users this round
# Got 189 reivews
# 347742 reviews are now in the bag, so to speak
# 2024-04-01 11:56:21
#
# Scraped 92 users this round
# Got 217 reivews
# 347959 reviews are now in the bag, so to speak
# 2024-04-01 11:59:51
#
# Scraped 127 users this round
# Got 203 reivews
# 348162 reviews are now in the bag, so to speak
# 2024-04-01 12:04:55
#
# Scraped 107 users this round
# Got 180 reivews
# 348342 reviews are now in the bag, so to speak
# 2024-04-01 12:08:52
#
# Scraped 114 users this round
# Got 233 reivews
# 348575 reviews are now in the bag, so to speak
# 2024-04-01 12:13:12
#
# Scraped 101 users this round
# Got 145 reivews
# 348720 reviews are now in the bag, so to speak
# 2024-04-01 12:16:47
#
# Scraped 90 users this round
# Got 153 reivews
# 348873 reviews are now in the bag, so to speak
# 2024-04-01 12:20:01
#
# Scraped 103 users this round
# Got 170 reivews
# 349043 reviews are now in the bag, so to speak
# 2024-04-01 12:24:02
#
# Scraped 106 users this round
# Got 217 reivews
# 349260 reviews are now in the bag, so to speak
# 2024-04-01 12:28:10
#
# Scraped 117 users this round
# Got 155 reivews
# 349415 reviews are now in the bag, so to speak
# 2024-04-01 12:32:45
#
# Scraped 100 users this round
# Got 182 reivews
# 349597 reviews are now in the bag, so to speak
# 2024-04-01 12:36:18
#
# Scraped 88 users this round
# Got 219 reivews
# 349816 reviews are now in the bag, so to speak
# 2024-04-01 12:39:03
#
# Scraped 92 users this round
# Got 194 reivews
# 350010 reviews are now in the bag, so to speak
# 2024-04-01 12:42:15
#
# Scraped 101 users this round
# Got 173 reivews
# 350183 reviews are now in the bag, so to speak
# 2024-04-01 12:45:53
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 112 users this round
# Got 217 reivews
# 350400 reviews are now in the bag, so to speak
# 2024-04-01 12:50:08
#
# Scraped 109 users this round
# Got 168 reivews
# 350568 reviews are now in the bag, so to speak
# 2024-04-01 12:54:01
#
# Scraped 123 users this round
# Got 197 reivews
# 350765 reviews are now in the bag, so to speak
# 2024-04-01 12:58:28
#
# Scraped 114 users this round
# Got 222 reivews
# 350987 reviews are now in the bag, so to speak
# 2024-04-01 13:02:34
#
# Scraped 101 users this round
# Got 177 reivews
# 351164 reviews are now in the bag, so to speak
# 2024-04-01 13:06:05
#
# Scraped 134 users this round
# Got 170 reivews
# 351334 reviews are now in the bag, so to speak
# 2024-04-01 13:10:53
#
# Scraped 96 users this round
# Got 177 reivews
# 351511 reviews are now in the bag, so to speak
# 2024-04-01 13:14:21
#
# Scraped 117 users this round
# Got 201 reivews
# 351712 reviews are now in the bag, so to speak
# 2024-04-01 13:18:37
#
# Scraped 110 users this round
# Got 168 reivews
# 351880 reviews are now in the bag, so to speak
# 2024-04-01 13:22:31
#
# Scraped 114 users this round
# Got 190 reivews
# 352070 reviews are now in the bag, so to speak
# 2024-04-01 13:26:37
#
# Scraped 102 users this round
# Got 177 reivews
# 352247 reviews are now in the bag, so to speak
# 2024-04-01 13:30:07
#
# Scraped 125 users this round
# Got 204 reivews
# 352451 reviews are now in the bag, so to speak
# 2024-04-01 13:34:31
#
# Scraped 110 users this round
# Got 180 reivews
# 352631 reviews are now in the bag, so to speak
# 2024-04-01 13:38:22
#
# Scraped 106 users this round
# Got 216 reivews
# 352847 reviews are now in the bag, so to speak
# 2024-04-01 13:42:14
#
# Scraped 122 users this round
# Got 199 reivews
# 353046 reviews are now in the bag, so to speak
# 2024-04-01 13:46:47
#
# Scraped 113 users this round
# Got 177 reivews
# 353223 reviews are now in the bag, so to speak
# 2024-04-01 13:50:45
#
# Scraped 117 users this round
# Got 172 reivews
# 353395 reviews are now in the bag, so to speak
# 2024-04-01 13:55:04
#
# Scraped 103 users this round
# Got 176 reivews
# 353571 reviews are now in the bag, so to speak
# 2024-04-01 13:58:59
#
# Scraped 88 users this round
# Got 199 reivews
# 353770 reviews are now in the bag, so to speak
# 2024-04-01 14:01:55
#
# Scraped 131 users this round
# Got 187 reivews
# 353957 reviews are now in the bag, so to speak
# 2024-04-01 14:06:42
#
# Scraped 116 users this round
# Got 225 reivews
# 354182 reviews are now in the bag, so to speak
# 2024-04-01 14:10:57
#
# Scraped 95 users this round
# Got 187 reivews
# 354369 reviews are now in the bag, so to speak
# 2024-04-01 14:14:15
#
# Scraped 111 users this round
# Got 186 reivews
# 354555 reviews are now in the bag, so to speak
# 2024-04-01 14:18:13
#
# Scraped 97 users this round
# Got 220 reivews
# 354775 reviews are now in the bag, so to speak
# 2024-04-01 14:21:40
#
# Scraped 105 users this round
# Got 219 reivews
# 354994 reviews are now in the bag, so to speak
# 2024-04-01 14:25:24
#
# Scraped 114 users this round
# Got 171 reivews
# 355165 reviews are now in the bag, so to speak
# 2024-04-01 14:29:31
#
# Scraped 125 users this round
# Got 199 reivews
# 355364 reviews are now in the bag, so to speak
# 2024-04-01 14:33:57
#
# Scraped 103 users this round
# Got 210 reivews
# 355574 reviews are now in the bag, so to speak
# 2024-04-01 14:37:33
#
# Scraped 115 users this round
# Got 164 reivews
# 355738 reviews are now in the bag, so to speak
# 2024-04-01 14:41:32
#
# Scraped 95 users this round
# Got 181 reivews
# 355919 reviews are now in the bag, so to speak
# 2024-04-01 14:44:32
#
# Scraped 132 users this round
# Got 185 reivews
# 356104 reviews are now in the bag, so to speak
# 2024-04-01 14:49:15
#
# Scraped 107 users this round
# Got 208 reivews
# 356312 reviews are now in the bag, so to speak
# 2024-04-01 14:53:04
#
# Scraped 107 users this round
# Got 178 reivews
# 356490 reviews are now in the bag, so to speak
# 2024-04-01 14:56:48
#
# Scraped 108 users this round
# Got 209 reivews
# 356699 reviews are now in the bag, so to speak
# 2024-04-01 15:00:37
#
# Scraped 121 users this round
# Got 165 reivews
# 356864 reviews are now in the bag, so to speak
# 2024-04-01 15:05:06
#
# Scraped 117 users this round
# Got 164 reivews
# 357028 reviews are now in the bag, so to speak
# 2024-04-01 15:09:12
#
# Scraped 103 users this round
# Got 198 reivews
# 357226 reviews are now in the bag, so to speak
# 2024-04-01 15:12:44
#
# Scraped 126 users this round
# Got 246 reivews
# 357472 reviews are now in the bag, so to speak
# 2024-04-01 15:17:17
#
# Scraped 104 users this round
# Got 142 reivews
# 357614 reviews are now in the bag, so to speak
# 2024-04-01 15:20:51
#
# Scraped 120 users this round
# Got 174 reivews
# 357788 reviews are now in the bag, so to speak
# 2024-04-01 15:25:08
#
# Scraped 120 users this round
# Got 183 reivews
# 357971 reviews are now in the bag, so to speak
# 2024-04-01 15:29:26
#
# Scraped 98 users this round
# Got 195 reivews
# 358166 reviews are now in the bag, so to speak
# 2024-04-01 15:32:50
#
# Scraped 98 users this round
# Got 169 reivews
# 358335 reviews are now in the bag, so to speak
# 2024-04-01 15:36:01
#
# Scraped 119 users this round
# Got 222 reivews
# 358557 reviews are now in the bag, so to speak
# 2024-04-01 15:40:10
#
# Scraped 102 users this round
# Got 198 reivews
# 358755 reviews are now in the bag, so to speak
# 2024-04-01 15:43:47
#
# Scraped 97 users this round
# Got 187 reivews
# 358942 reviews are now in the bag, so to speak
# 2024-04-01 15:47:05
#
# Scraped 110 users this round
# Got 181 reivews
# 359123 reviews are now in the bag, so to speak
# 2024-04-01 15:50:50
#
# Scraped 118 users this round
# Got 145 reivews
# 359268 reviews are now in the bag, so to speak
# 2024-04-01 15:54:50
#
# Scraped 121 users this round
# Got 180 reivews
# 359448 reviews are now in the bag, so to speak
# 2024-04-01 15:59:08
#
# Scraped 92 users this round
# Got 204 reivews
# 359652 reviews are now in the bag, so to speak
# 2024-04-01 16:02:24
#
# Scraped 106 users this round
# Got 166 reivews
# 359818 reviews are now in the bag, so to speak
# 2024-04-01 16:06:07
#
# Scraped 100 users this round
# Got 195 reivews
# 360013 reviews are now in the bag, so to speak
# 2024-04-01 16:09:39
#
# Scraped 120 users this round
# Got 167 reivews
# 360180 reviews are now in the bag, so to speak
# 2024-04-01 16:14:02
#
# Scraped 117 users this round
# Got 192 reivews
# 360372 reviews are now in the bag, so to speak
# 2024-04-01 16:18:11
#
# Scraped 88 users this round
# Got 148 reivews
# 360520 reviews are now in the bag, so to speak
# 2024-04-01 16:21:01
#
# Scraped 127 users this round
# Got 165 reivews
# 360685 reviews are now in the bag, so to speak
# 2024-04-01 16:25:40
#
# Scraped 96 users this round
# Got 169 reivews
# 360854 reviews are now in the bag, so to speak
# 2024-04-01 16:28:46
#
# Scraped 105 users this round
# Got 216 reivews
# 361070 reviews are now in the bag, so to speak
# 2024-04-01 16:32:29
#
# Scraped 102 users this round
# Got 150 reivews
# 361220 reviews are now in the bag, so to speak
# 2024-04-01 16:35:50
#
# Scraped 118 users this round
# Got 227 reivews
# 361447 reviews are now in the bag, so to speak
# 2024-04-01 16:40:00
#
# Scraped 115 users this round
# Got 143 reivews
# 361590 reviews are now in the bag, so to speak
# 2024-04-01 16:43:58
#
# Scraped 119 users this round
# Got 224 reivews
# 361814 reviews are now in the bag, so to speak
# 2024-04-01 16:48:08
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 110 users this round
# Got 194 reivews
# 362008 reviews are now in the bag, so to speak
# 2024-04-01 16:52:09
#
# Scraped 111 users this round
# Got 182 reivews
# 362190 reviews are now in the bag, so to speak
# 2024-04-01 16:56:11
#
# Scraped 105 users this round
# Got 218 reivews
# 362408 reviews are now in the bag, so to speak
# 2024-04-01 16:59:54
#
# Scraped 139 users this round
# Got 177 reivews
# 362585 reviews are now in the bag, so to speak
# 2024-04-01 17:05:00
#
# Scraped 103 users this round
# Got 156 reivews
# 362741 reviews are now in the bag, so to speak
# 2024-04-01 17:08:34
#
# Scraped 108 users this round
# Got 197 reivews
# 362938 reviews are now in the bag, so to speak
# 2024-04-01 17:12:21
#
# Scraped 108 users this round
# Got 199 reivews
# 363137 reviews are now in the bag, so to speak
# 2024-04-01 17:16:04
#
# Scraped 120 users this round
# Got 212 reivews
# 363349 reviews are now in the bag, so to speak
# 2024-04-01 17:20:33
#
# Scraped 108 users this round
# Got 198 reivews
# 363547 reviews are now in the bag, so to speak
# 2024-04-01 17:24:45
#
# Scraped 102 users this round
# Got 165 reivews
# 363712 reviews are now in the bag, so to speak
# 2024-04-01 17:28:35
#
# Scraped 107 users this round
# Got 223 reivews
# 363935 reviews are now in the bag, so to speak
# 2024-04-01 17:32:28
#
# Scraped 101 users this round
# Got 208 reivews
# 364143 reviews are now in the bag, so to speak
# 2024-04-01 17:35:58
#
# Scraped 127 users this round
# Got 194 reivews
# 364337 reviews are now in the bag, so to speak
# 2024-04-01 17:40:35
#
# Scraped 95 users this round
# Got 172 reivews
# 364509 reviews are now in the bag, so to speak
# 2024-04-01 17:43:49
#
# Scraped 93 users this round
# Got 188 reivews
# 364697 reviews are now in the bag, so to speak
# 2024-04-01 17:46:57
#
# Scraped 104 users this round
# Got 175 reivews
# 364872 reviews are now in the bag, so to speak
# 2024-04-01 17:50:37
#
# Scraped 103 users this round
# Got 205 reivews
# 365077 reviews are now in the bag, so to speak
# 2024-04-01 17:54:05
#
# Scraped 87 users this round
# Got 205 reivews
# 365282 reviews are now in the bag, so to speak
# 2024-04-01 17:56:54
#
# Scraped 105 users this round
# Got 199 reivews
# 365481 reviews are now in the bag, so to speak
# 2024-04-01 18:00:25
#
# Scraped 104 users this round
# Got 185 reivews
# 365666 reviews are now in the bag, so to speak
# 2024-04-01 18:03:56
#
# Scraped 118 users this round
# Got 164 reivews
# 365830 reviews are now in the bag, so to speak
# 2024-04-01 18:08:06
#
# Scraped 111 users this round
# Got 167 reivews
# 365997 reviews are now in the bag, so to speak
# 2024-04-01 18:11:52
#
# Scraped 107 users this round
# Got 179 reivews
# 366176 reviews are now in the bag, so to speak
# 2024-04-01 18:15:29
#
# Scraped 108 users this round
# Got 191 reivews
# 366367 reviews are now in the bag, so to speak
# 2024-04-01 18:19:06
#
# Scraped 156 users this round
# Got 190 reivews
# 366557 reviews are now in the bag, so to speak
# 2024-04-01 18:24:45
#
# Scraped 106 users this round
# Got 196 reivews
# 366753 reviews are now in the bag, so to speak
# 2024-04-01 18:28:20
#
# Scraped 112 users this round
# Got 155 reivews
# 366908 reviews are now in the bag, so to speak
# 2024-04-01 18:32:14
#
# Scraped 104 users this round
# Got 231 reivews
# 367139 reviews are now in the bag, so to speak
# 2024-04-01 18:35:52
#
# Scraped 121 users this round
# Got 203 reivews
# 367342 reviews are now in the bag, so to speak
# 2024-04-01 18:40:15
#
# Scraped 119 users this round
# Got 225 reivews
# 367567 reviews are now in the bag, so to speak
# 2024-04-01 18:44:30
#
# Scraped 104 users this round
# Got 190 reivews
# 367757 reviews are now in the bag, so to speak
# 2024-04-01 18:48:01
#
# Scraped 112 users this round
# Got 224 reivews
# 367981 reviews are now in the bag, so to speak
# 2024-04-01 18:51:56
#
# Scraped 105 users this round
# Got 196 reivews
# 368177 reviews are now in the bag, so to speak
# 2024-04-01 18:55:21
#
# Scraped 121 users this round
# Got 178 reivews
# 368355 reviews are now in the bag, so to speak
# 2024-04-01 18:59:44
#
# Scraped 108 users this round
# Got 238 reivews
# 368593 reviews are now in the bag, so to speak
# 2024-04-01 19:03:44
#
# Scraped 108 users this round
# Got 165 reivews
# 368758 reviews are now in the bag, so to speak
# 2024-04-01 19:07:23
#
# Scraped 99 users this round
# Got 199 reivews
# 368957 reviews are now in the bag, so to speak
# 2024-04-01 19:10:43
#
# Scraped 131 users this round
# Got 184 reivews
# 369141 reviews are now in the bag, so to speak
# 2024-04-01 19:15:21
#
# Scraped 90 users this round
# Got 198 reivews
# 369339 reviews are now in the bag, so to speak
# 2024-04-01 19:18:15
#
# Scraped 108 users this round
# Got 189 reivews
# 369528 reviews are now in the bag, so to speak
# 2024-04-01 19:21:59
#
# Scraped 101 users this round
# Got 182 reivews
# 369710 reviews are now in the bag, so to speak
# 2024-04-01 19:25:37
#
# Scraped 90 users this round
# Got 183 reivews
# 369893 reviews are now in the bag, so to speak
# 2024-04-01 19:28:40
#
# Scraped 113 users this round
# Got 174 reivews
# 370067 reviews are now in the bag, so to speak
# 2024-04-01 19:32:36
#
# Scraped 124 users this round
# Got 152 reivews
# 370219 reviews are now in the bag, so to speak
# 2024-04-01 19:37:02
#
# Scraped 114 users this round
# Got 160 reivews
# 370379 reviews are now in the bag, so to speak
# 2024-04-01 19:41:07
#
# Scraped 89 users this round
# Got 172 reivews
# 370551 reviews are now in the bag, so to speak
# 2024-04-01 19:43:55
#
# Scraped 111 users this round
# Got 179 reivews
# 370730 reviews are now in the bag, so to speak
# 2024-04-01 19:47:57
#
# Scraped 111 users this round
# Got 165 reivews
# 370895 reviews are now in the bag, so to speak
# 2024-04-01 19:51:37
#
# Scraped 96 users this round
# Got 222 reivews
# 371117 reviews are now in the bag, so to speak
# 2024-04-01 19:55:01
#
# Scraped 90 users this round
# Got 179 reivews
# 371296 reviews are now in the bag, so to speak
# 2024-04-01 19:57:57
#
# Scraped 121 users this round
# Got 152 reivews
# 371448 reviews are now in the bag, so to speak
# 2024-04-01 20:02:09
#
# Scraped 127 users this round
# Got 221 reivews
# 371669 reviews are now in the bag, so to speak
# 2024-04-01 20:07:23
#
# Scraped 103 users this round
# Got 183 reivews
# 371852 reviews are now in the bag, so to speak
# 2024-04-01 20:13:16
#
# Scraped 106 users this round
# Got 197 reivews
# 372049 reviews are now in the bag, so to speak
# 2024-04-01 20:20:32
#
# Scraped 116 users this round
# Got 199 reivews
# 372248 reviews are now in the bag, so to speak
# 2024-04-01 20:28:35
#
# Scraped 106 users this round
# Got 180 reivews
# 372428 reviews are now in the bag, so to speak
# 2024-04-01 20:34:30
#
# Scraped 117 users this round
# Got 177 reivews
# 372605 reviews are now in the bag, so to speak
# 2024-04-01 20:41:03
#
# Scraped 119 users this round
# Got 172 reivews
# 372777 reviews are now in the bag, so to speak
# 2024-04-01 20:47:25
#
# Scraped 112 users this round
# Got 207 reivews
# 372984 reviews are now in the bag, so to speak
# 2024-04-01 20:53:54
#
# Scraped 117 users this round
# Got 180 reivews
# 373164 reviews are now in the bag, so to speak
# 2024-04-01 21:00:59
#
# Scraped 102 users this round
# Got 182 reivews
# 373346 reviews are now in the bag, so to speak
# 2024-04-01 21:07:13
#
# Scraped 108 users this round
# Got 168 reivews
# 373514 reviews are now in the bag, so to speak
# 2024-04-01 21:13:58
#
# Scraped 108 users this round
# Got 212 reivews
# 373726 reviews are now in the bag, so to speak
# 2024-04-01 21:20:59
#
# Scraped 103 users this round
# Got 224 reivews
# 373950 reviews are now in the bag, so to speak
# 2024-04-01 21:27:02
#
# Scraped 100 users this round
# Got 183 reivews
# 374133 reviews are now in the bag, so to speak
# 2024-04-01 21:33:29
#
# Scraped 104 users this round
# Got 201 reivews
# 374334 reviews are now in the bag, so to speak
# 2024-04-01 21:39:53
#
# Scraped 114 users this round
# Got 161 reivews
# 374495 reviews are now in the bag, so to speak
# 2024-04-01 21:46:45
#
# Scraped 140 users this round
# Got 197 reivews
# 374692 reviews are now in the bag, so to speak
# 2024-04-01 21:55:36
#
# Scraped 95 users this round
# Got 145 reivews
# 374837 reviews are now in the bag, so to speak
# 2024-04-01 22:01:29
#
# Unable to parse review blocks.
# Scraped 121 users this round
# Got 193 reivews
# 375030 reviews are now in the bag, so to speak
# 2024-04-01 22:09:45
#
# Scraped 130 users this round
# Got 154 reivews
# 375184 reviews are now in the bag, so to speak
# 2024-04-01 22:17:40
#
# Scraped 115 users this round
# Got 182 reivews
# 375366 reviews are now in the bag, so to speak
# 2024-04-01 22:24:41
#
# Scraped 108 users this round
# Got 163 reivews
# 375529 reviews are now in the bag, so to speak
# 2024-04-01 22:31:08
#
# Scraped 112 users this round
# Got 177 reivews
# 375706 reviews are now in the bag, so to speak
# 2024-04-01 22:37:15
#
# Scraped 122 users this round
# Got 169 reivews
# 375875 reviews are now in the bag, so to speak
# 2024-04-01 22:43:56
#
# Scraped 95 users this round
# Got 195 reivews
# 376070 reviews are now in the bag, so to speak
# 2024-04-01 22:48:51
#
# Scraped 102 users this round
# Got 183 reivews
# 376253 reviews are now in the bag, so to speak
# 2024-04-01 22:53:52
#
# Scraped 115 users this round
# Got 166 reivews
# 376419 reviews are now in the bag, so to speak
# 2024-04-01 22:59:38
#
# Scraped 88 users this round
# Got 214 reivews
# 376633 reviews are now in the bag, so to speak
# 2024-04-01 23:04:07
#
# Scraped 91 users this round
# Got 202 reivews
# 376835 reviews are now in the bag, so to speak
# 2024-04-01 23:08:35
#
# Scraped 105 users this round
# Got 155 reivews
# 376990 reviews are now in the bag, so to speak
# 2024-04-01 23:12:59
#
# Scraped 105 users this round
# Got 160 reivews
# 377150 reviews are now in the bag, so to speak
# 2024-04-01 23:16:59
#
# Scraped 131 users this round
# Got 226 reivews
# 377376 reviews are now in the bag, so to speak
# 2024-04-01 23:21:50
#
# Scraped 114 users this round
# Got 152 reivews
# 377528 reviews are now in the bag, so to speak
# 2024-04-01 23:26:07
#
# Scraped 117 users this round
# Got 170 reivews
# 377698 reviews are now in the bag, so to speak
# 2024-04-01 23:30:13
#
# Scraped 109 users this round
# Got 149 reivews
# 377847 reviews are now in the bag, so to speak
# 2024-04-01 23:34:08
#
# Scraped 89 users this round
# Got 217 reivews
# 378064 reviews are now in the bag, so to speak
# 2024-04-01 23:37:05
#
# Scraped 113 users this round
# Got 198 reivews
# 378262 reviews are now in the bag, so to speak
# 2024-04-01 23:41:11
#
# Scraped 100 users this round
# Got 187 reivews
# 378449 reviews are now in the bag, so to speak
# 2024-04-01 23:44:43
#
# Scraped 133 users this round
# Got 141 reivews
# 378590 reviews are now in the bag, so to speak
# 2024-04-01 23:50:11
#
# Scraped 111 users this round
# Got 214 reivews
# 378804 reviews are now in the bag, so to speak
# 2024-04-01 23:54:11
#
# Scraped 114 users this round
# Got 182 reivews
# 378986 reviews are now in the bag, so to speak
# 2024-04-01 23:58:07
#
# Scraped 108 users this round
# Got 206 reivews
# 379192 reviews are now in the bag, so to speak
# 2024-04-02 00:01:52
#
# Scraped 114 users this round
# Got 162 reivews
# 379354 reviews are now in the bag, so to speak
# 2024-04-02 00:05:58
#
# Scraped 107 users this round
# Got 160 reivews
# 379514 reviews are now in the bag, so to speak
# 2024-04-02 00:10:01
#
# Scraped 106 users this round
# Got 165 reivews
# 379679 reviews are now in the bag, so to speak
# 2024-04-02 00:13:52
#
# Scraped 133 users this round
# Got 176 reivews
# 379855 reviews are now in the bag, so to speak
# 2024-04-02 00:18:44
#
# Scraped 109 users this round
# Got 179 reivews
# 380034 reviews are now in the bag, so to speak
# 2024-04-02 00:22:30
#
# Scraped 131 users this round
# Got 197 reivews
# 380231 reviews are now in the bag, so to speak
# 2024-04-02 00:27:14
#
# Scraped 109 users this round
# Got 253 reivews
# 380484 reviews are now in the bag, so to speak
# 2024-04-02 00:31:14
#
# Scraped 113 users this round
# Got 156 reivews
# 380640 reviews are now in the bag, so to speak
# 2024-04-02 00:35:24
#
# Scraped 112 users this round
# Got 205 reivews
# 380845 reviews are now in the bag, so to speak
# 2024-04-02 00:39:28
#
# Scraped 101 users this round
# Got 198 reivews
# 381043 reviews are now in the bag, so to speak
# 2024-04-02 00:42:51
#
# Scraped 101 users this round
# Got 174 reivews
# 381217 reviews are now in the bag, so to speak
# 2024-04-02 00:46:17
#
# Scraped 111 users this round
# Got 186 reivews
# 381403 reviews are now in the bag, so to speak
# 2024-04-02 00:50:04
#
# Scraped 107 users this round
# Got 192 reivews
# 381595 reviews are now in the bag, so to speak
# 2024-04-02 00:53:52
#
# Scraped 104 users this round
# Got 224 reivews
# 381819 reviews are now in the bag, so to speak
# 2024-04-02 00:57:44
#
# Scraped 98 users this round
# Got 161 reivews
# 381980 reviews are now in the bag, so to speak
# 2024-04-02 01:01:03
#
# Scraped 105 users this round
# Got 200 reivews
# 382180 reviews are now in the bag, so to speak
# 2024-04-02 01:04:51
#
# Scraped 126 users this round
# Got 189 reivews
# 382369 reviews are now in the bag, so to speak
# 2024-04-02 01:09:25
#
# Scraped 121 users this round
# Got 177 reivews
# 382546 reviews are now in the bag, so to speak
# 2024-04-02 01:13:37
#
# Scraped 124 users this round
# Got 213 reivews
# ...
# 2024-04-02 23:20:34
#
# Scraped 124 users this round
# Got 186 reivews
# 443043 reviews are now in the bag, so to speak
# 2024-04-02 23:29:21
#
# Scraped 94 users this round
# Got 189 reivews
# 443232 reviews are now in the bag, so to speak
# 2024-04-02 23:35:25
#
# Scraped 115 users this round
# Got 168 reivews
# 443400 reviews are now in the bag, so to speak
# 2024-04-02 23:41:56
#
# Scraped 105 users this round
# Got 183 reivews
# 443583 reviews are now in the bag, so to speak
# 2024-04-02 23:45:31
#
# Scraped 96 users this round
# Got 171 reivews
# 443754 reviews are now in the bag, so to speak
# 2024-04-02 23:48:52
#
# Scraped 129 users this round
# Got 186 reivews
# 443940 reviews are now in the bag, so to speak
# 2024-04-02 23:53:32
#
# Scraped 106 users this round
# Got 222 reivews
# 444162 reviews are now in the bag, so to speak
# 2024-04-02 23:57:26
#
# Scraped 101 users this round
# Got 198 reivews
# 444360 reviews are now in the bag, so to speak
# 2024-04-03 00:00:50
#
# Scraped 112 users this round
# Got 182 reivews
# 444542 reviews are now in the bag, so to speak
# 2024-04-03 00:04:42
#
# Scraped 120 users this round
# Got 154 reivews
# 444696 reviews are now in the bag, so to speak
# 2024-04-03 00:08:53
#
# Scraped 111 users this round
# Got 212 reivews
# 444908 reviews are now in the bag, so to speak
# 2024-04-03 00:12:55
#
# Scraped 97 users this round
# Got 187 reivews
# 445095 reviews are now in the bag, so to speak
# 2024-04-03 00:16:18
#
# Scraped 99 users this round
# Got 193 reivews
# 445288 reviews are now in the bag, so to speak
# 2024-04-03 00:19:36
#
# Scraped 103 users this round
# Got 180 reivews
# 445468 reviews are now in the bag, so to speak
# 2024-04-03 00:23:14
#
# Scraped 109 users this round
# Got 173 reivews
# 445641 reviews are now in the bag, so to speak
# 2024-04-03 00:26:47
#
# Scraped 106 users this round
# Got 195 reivews
# 445836 reviews are now in the bag, so to speak
# 2024-04-03 00:30:12
#
# Scraped 114 users this round
# Got 178 reivews
# 446014 reviews are now in the bag, so to speak
# 2024-04-03 00:34:11
#
# Scraped 103 users this round
# Got 204 reivews
# 446218 reviews are now in the bag, so to speak
# 2024-04-03 00:37:40
#
# Scraped 116 users this round
# Got 221 reivews
# 446439 reviews are now in the bag, so to speak
# 2024-04-03 00:41:28
#
# Scraped 88 users this round
# Got 198 reivews
# 446637 reviews are now in the bag, so to speak
# 2024-04-03 00:44:16
#
# Scraped 83 users this round
# Got 203 reivews
# 446840 reviews are now in the bag, so to speak
# 2024-04-03 00:46:52
#
# Scraped 101 users this round
# Got 149 reivews
# 446989 reviews are now in the bag, so to speak
# 2024-04-03 00:50:09
#
# Scraped 105 users this round
# Got 226 reivews
# 447215 reviews are now in the bag, so to speak
# 2024-04-03 00:54:11
#
# Scraped 117 users this round
# Got 220 reivews
# 447435 reviews are now in the bag, so to speak
# 2024-04-03 00:58:53
#
# Scraped 114 users this round
# Got 193 reivews
# 447628 reviews are now in the bag, so to speak
# 2024-04-03 01:02:53
#
# Scraped 108 users this round
# Got 191 reivews
# 447819 reviews are now in the bag, so to speak
# 2024-04-03 01:06:32
#
# Scraped 95 users this round
# Got 133 reivews
# 447952 reviews are now in the bag, so to speak
# 2024-04-03 01:09:33
#
# Scraped 85 users this round
# Got 154 reivews
# 448106 reviews are now in the bag, so to speak
# 2024-04-03 01:12:27
#
# Scraped 127 users this round
# Got 203 reivews
# 448309 reviews are now in the bag, so to speak
# 2024-04-03 01:17:13
#
# Scraped 121 users this round
# Got 185 reivews
# 448494 reviews are now in the bag, so to speak
# 2024-04-03 01:21:33
#
# Scraped 105 users this round
# Got 162 reivews
# 448656 reviews are now in the bag, so to speak
# 2024-04-03 01:25:04
#
# Scraped 104 users this round
# Got 228 reivews
# 448884 reviews are now in the bag, so to speak
# 2024-04-03 01:28:31
#
# Scraped 137 users this round
# Got 187 reivews
# 449071 reviews are now in the bag, so to speak
# 2024-04-03 01:33:46
#
# Scraped 127 users this round
# Got 205 reivews
# 449276 reviews are now in the bag, so to speak
# 2024-04-03 01:38:07
#
# Scraped 105 users this round
# Got 196 reivews
# 449472 reviews are now in the bag, so to speak
# 2024-04-03 01:41:51
#
# Scraped 135 users this round
# Got 175 reivews
# 449647 reviews are now in the bag, so to speak
# 2024-04-03 01:46:34
#
# Scraped 111 users this round
# Got 212 reivews
# 449859 reviews are now in the bag, so to speak
# 2024-04-03 01:50:00
#
# Scraped 122 users this round
# Got 197 reivews
# 450056 reviews are now in the bag, so to speak
# 2024-04-03 01:54:15
#
# Scraped 104 users this round
# Got 199 reivews
# 450255 reviews are now in the bag, so to speak
# 2024-04-03 01:57:37
#
# Scraped 98 users this round
# Got 183 reivews
# 450438 reviews are now in the bag, so to speak
# 2024-04-03 02:00:44
#
# Scraped 118 users this round
# Got 192 reivews
# 450630 reviews are now in the bag, so to speak
# 2024-04-03 02:04:34
#
# Scraped 116 users this round
# Got 174 reivews
# 450804 reviews are now in the bag, so to speak
# 2024-04-03 02:08:36
#
# Scraped 109 users this round
# Got 218 reivews
# 451022 reviews are now in the bag, so to speak
# 2024-04-03 02:12:20
#
# Scraped 110 users this round
# Got 213 reivews
# 451235 reviews are now in the bag, so to speak
# 2024-04-03 02:16:05
#
# Scraped 103 users this round
# Got 160 reivews
# 451395 reviews are now in the bag, so to speak
# 2024-04-03 02:19:17
#
# Scraped 110 users this round
# Got 186 reivews
# 451581 reviews are now in the bag, so to speak
# 2024-04-03 02:23:02
#
# Scraped 100 users this round
# Got 182 reivews
# 451763 reviews are now in the bag, so to speak
# 2024-04-03 02:26:18
#
# Scraped 114 users this round
# Got 165 reivews
# 451928 reviews are now in the bag, so to speak
# 2024-04-03 02:30:11
#
# Scraped 111 users this round
# Got 177 reivews
# 452105 reviews are now in the bag, so to speak
# 2024-04-03 02:33:51
#
# Scraped 102 users this round
# Got 196 reivews
# 452301 reviews are now in the bag, so to speak
# 2024-04-03 02:37:10
#
# Scraped 120 users this round
# Got 193 reivews
# 452494 reviews are now in the bag, so to speak
# 2024-04-03 02:41:12
#
# Scraped 110 users this round
# Got 185 reivews
# 452679 reviews are now in the bag, so to speak
# 2024-04-03 02:44:48
#
# Scraped 100 users this round
# Got 195 reivews
# 452874 reviews are now in the bag, so to speak
# 2024-04-03 02:47:59
#
# Scraped 98 users this round
# Got 191 reivews
# 453065 reviews are now in the bag, so to speak
# 2024-04-03 02:51:05
#
# Scraped 111 users this round
# Got 137 reivews
# 453202 reviews are now in the bag, so to speak
# 2024-04-03 02:54:44
#
# Scraped 95 users this round
# Got 151 reivews
# 453353 reviews are now in the bag, so to speak
# 2024-04-03 02:58:09
#
# Scraped 121 users this round
# Got 205 reivews
# 453558 reviews are now in the bag, so to speak
# 2024-04-03 03:02:14
#
# Scraped 127 users this round
# Got 170 reivews
# 453728 reviews are now in the bag, so to speak
# 2024-04-03 03:06:24
#
# Scraped 93 users this round
# Got 179 reivews
# 453907 reviews are now in the bag, so to speak
# 2024-04-03 03:09:26
#
# Scraped 90 users this round
# Got 170 reivews
# 454077 reviews are now in the bag, so to speak
# 2024-04-03 03:12:18
#
# Scraped 77 users this round
# Got 210 reivews
# 454287 reviews are now in the bag, so to speak
# 2024-04-03 03:14:44
#
# Scraped 108 users this round
# Got 196 reivews
# 454483 reviews are now in the bag, so to speak
# 2024-04-03 03:18:10
#
# Scraped 98 users this round
# Got 160 reivews
# 454643 reviews are now in the bag, so to speak
# 2024-04-03 03:21:28
#
# Scraped 121 users this round
# Got 201 reivews
# 454844 reviews are now in the bag, so to speak
# 2024-04-03 03:25:33
#
# Scraped 115 users this round
# Got 154 reivews
# 454998 reviews are now in the bag, so to speak
# 2024-04-03 03:29:19
#
# Scraped 125 users this round
# Got 193 reivews
# 455191 reviews are now in the bag, so to speak
# 2024-04-03 03:33:35
#
# Scraped 100 users this round
# Got 147 reivews
# 455338 reviews are now in the bag, so to speak
# 2024-04-03 03:36:39
#
# Scraped 92 users this round
# Got 189 reivews
# 455527 reviews are now in the bag, so to speak
# 2024-04-03 03:39:33
#
# Scraped 124 users this round
# Got 156 reivews
# 455683 reviews are now in the bag, so to speak
# 2024-04-03 03:43:31
#
# Scraped 106 users this round
# Got 176 reivews
# 455859 reviews are now in the bag, so to speak
# 2024-04-03 03:46:57
#
# Scraped 109 users this round
# Got 191 reivews
# 456050 reviews are now in the bag, so to speak
# 2024-04-03 03:50:24
#
# Scraped 108 users this round
# Got 159 reivews
# 456209 reviews are now in the bag, so to speak
# 2024-04-03 03:54:00
#
# Scraped 103 users this round
# Got 162 reivews
# 456371 reviews are now in the bag, so to speak
# 2024-04-03 03:57:19
#
# Scraped 122 users this round
# Got 180 reivews
# 456551 reviews are now in the bag, so to speak
# 2024-04-03 04:01:31
#
# Scraped 132 users this round
# Got 218 reivews
# 456769 reviews are now in the bag, so to speak
# 2024-04-03 04:06:10
#
# Scraped 110 users this round
# Got 178 reivews
# 456947 reviews are now in the bag, so to speak
# 2024-04-03 04:09:59
#
# Scraped 100 users this round
# Got 219 reivews
# 457166 reviews are now in the bag, so to speak
# 2024-04-03 04:13:11
#
# Scraped 92 users this round
# Got 175 reivews
# 457341 reviews are now in the bag, so to speak
# 2024-04-03 04:15:59
#
# Scraped 112 users this round
# Got 204 reivews
# 457545 reviews are now in the bag, so to speak
# 2024-04-03 04:19:46
#
# Scraped 119 users this round
# Got 155 reivews
# 457700 reviews are now in the bag, so to speak
# 2024-04-03 04:23:34
#
# Scraped 136 users this round
# Got 224 reivews
# 457924 reviews are now in the bag, so to speak
# 2024-04-03 04:28:22
#
# Scraped 117 users this round
# Got 175 reivews
# 458099 reviews are now in the bag, so to speak
# 2024-04-03 04:32:26
#
# Scraped 91 users this round
# Got 183 reivews
# 458282 reviews are now in the bag, so to speak
# 2024-04-03 04:35:25
#
# Scraped 108 users this round
# Got 166 reivews
# 458448 reviews are now in the bag, so to speak
# 2024-04-03 04:38:53
#
# Scraped 115 users this round
# Got 176 reivews
# 458624 reviews are now in the bag, so to speak
# 2024-04-03 04:42:43
#
# Scraped 105 users this round
# Got 201 reivews
# 458825 reviews are now in the bag, so to speak
# 2024-04-03 04:46:24
#
# Scraped 119 users this round
# Got 183 reivews
# 459008 reviews are now in the bag, so to speak
# 2024-04-03 04:50:14
#
# Scraped 104 users this round
# Got 166 reivews
# 459174 reviews are now in the bag, so to speak
# 2024-04-03 04:53:28
#
# Scraped 81 users this round
# Got 213 reivews
# 459387 reviews are now in the bag, so to speak
# 2024-04-03 04:56:04
#
# Scraped 99 users this round
# Got 173 reivews
# 459560 reviews are now in the bag, so to speak
# 2024-04-03 04:59:19
#
# Scraped 109 users this round
# Got 161 reivews
# 459721 reviews are now in the bag, so to speak
# 2024-04-03 05:02:58
#
# Scraped 118 users this round
# Got 204 reivews
# 459925 reviews are now in the bag, so to speak
# 2024-04-03 05:06:56
#
# Scraped 128 users this round
# Got 151 reivews
# 460076 reviews are now in the bag, so to speak
# 2024-04-03 05:11:30
#
# Scraped 89 users this round
# Got 177 reivews
# 460253 reviews are now in the bag, so to speak
# 2024-04-03 05:14:23
#
# Scraped 102 users this round
# Got 196 reivews
# 460449 reviews are now in the bag, so to speak
# 2024-04-03 05:17:35
#
# Scraped 95 users this round
# Got 194 reivews
# 460643 reviews are now in the bag, so to speak
# 2024-04-03 05:20:46
#
# Scraped 135 users this round
# Got 174 reivews
# 460817 reviews are now in the bag, so to speak
# 2024-04-03 05:25:16
#
# Scraped 101 users this round
# Got 158 reivews
# 460975 reviews are now in the bag, so to speak
# 2024-04-03 05:28:48
#
# Scraped 135 users this round
# Got 160 reivews
# 461135 reviews are now in the bag, so to speak
# 2024-04-03 05:33:21
#
# Scraped 130 users this round
# Got 193 reivews
# 461328 reviews are now in the bag, so to speak
# 2024-04-03 05:37:44
#
# Scraped 116 users this round
# Got 167 reivews
# 461495 reviews are now in the bag, so to speak
# 2024-04-03 05:41:37
#
# Scraped 116 users this round
# Got 175 reivews
# 461670 reviews are now in the bag, so to speak
# 2024-04-03 05:45:16
#
# Scraped 109 users this round
# Got 216 reivews
# 461886 reviews are now in the bag, so to speak
# 2024-04-03 05:49:03
#
# Scraped 103 users this round
# Got 151 reivews
# 462037 reviews are now in the bag, so to speak
# 2024-04-03 05:52:17
#
# Scraped 104 users this round
# Got 178 reivews
# 462215 reviews are now in the bag, so to speak
# 2024-04-03 05:55:55
#
# Scraped 118 users this round
# Got 183 reivews
# 462398 reviews are now in the bag, so to speak
# 2024-04-03 05:59:58
#
# Scraped 126 users this round
# Got 176 reivews
# 462574 reviews are now in the bag, so to speak
# 2024-04-03 06:04:22
#
# Scraped 104 users this round
# Got 205 reivews
# 462779 reviews are now in the bag, so to speak
# 2024-04-03 06:07:47
#
# Scraped 117 users this round
# Got 167 reivews
# 462946 reviews are now in the bag, so to speak
# 2024-04-03 06:11:54
#
# Scraped 94 users this round
# Got 215 reivews
# 463161 reviews are now in the bag, so to speak
# 2024-04-03 06:15:10
#
# Scraped 114 users this round
# Got 258 reivews
# 463419 reviews are now in the bag, so to speak
# 2024-04-03 06:18:54
#
# Scraped 130 users this round
# Got 213 reivews
# 463632 reviews are now in the bag, so to speak
# 2024-04-03 06:23:24
#
# Scraped 121 users this round
# Got 189 reivews
# 463821 reviews are now in the bag, so to speak
# 2024-04-03 06:27:36
#
# Scraped 124 users this round
# Got 182 reivews
# 464003 reviews are now in the bag, so to speak
# 2024-04-03 06:32:38
#
# Scraped 118 users this round
# Got 171 reivews
# 464174 reviews are now in the bag, so to speak
# 2024-04-03 06:36:34
#
# Scraped 111 users this round
# Got 170 reivews
# 464344 reviews are now in the bag, so to speak
# 2024-04-03 06:40:38
#
# Scraped 124 users this round
# Got 187 reivews
# 464531 reviews are now in the bag, so to speak
# 2024-04-03 06:44:56
#
# Scraped 115 users this round
# Got 228 reivews
# 464759 reviews are now in the bag, so to speak
# 2024-04-03 06:48:45
#
# Scraped 125 users this round
# Got 161 reivews
# 464920 reviews are now in the bag, so to speak
# 2024-04-03 06:53:09
#
# Scraped 124 users this round
# Got 197 reivews
# 465117 reviews are now in the bag, so to speak
# 2024-04-03 06:57:13
#
# Scraped 119 users this round
# Got 184 reivews
# 465301 reviews are now in the bag, so to speak
# 2024-04-03 07:01:18
#
# Scraped 112 users this round
# Got 154 reivews
# 465455 reviews are now in the bag, so to speak
# 2024-04-03 07:05:03
#
# Scraped 98 users this round
# Got 180 reivews
# 465635 reviews are now in the bag, so to speak
# 2024-04-03 07:08:25
#
# Scraped 102 users this round
# Got 148 reivews
# 465783 reviews are now in the bag, so to speak
# 2024-04-03 07:11:50
#
# Scraped 117 users this round
# Got 166 reivews
# 465949 reviews are now in the bag, so to speak
# 2024-04-03 07:16:04
#
# Scraped 107 users this round
# Got 132 reivews
# 466081 reviews are now in the bag, so to speak
# 2024-04-03 07:19:39
#
# Scraped 110 users this round
# Got 180 reivews
# 466261 reviews are now in the bag, so to speak
# 2024-04-03 07:23:49
#
# Scraped 107 users this round
# Got 167 reivews
# 466428 reviews are now in the bag, so to speak
# 2024-04-03 07:27:25
#
# Scraped 120 users this round
# Got 210 reivews
# 466638 reviews are now in the bag, so to speak
# 2024-04-03 07:32:11
#
# Scraped 110 users this round
# Got 184 reivews
# 466822 reviews are now in the bag, so to speak
# 2024-04-03 07:35:58
#
# Scraped 109 users this round
# Got 195 reivews
# 467017 reviews are now in the bag, so to speak
# 2024-04-03 07:39:56
#
# Scraped 110 users this round
# Got 204 reivews
# 467221 reviews are now in the bag, so to speak
# 2024-04-03 07:43:35
#
# Scraped 104 users this round
# Got 170 reivews
# 467391 reviews are now in the bag, so to speak
# 2024-04-03 07:46:58
#
# Scraped 101 users this round
# Got 201 reivews
# 467592 reviews are now in the bag, so to speak
# 2024-04-03 07:50:27
#
# Scraped 78 users this round
# Got 173 reivews
# 467765 reviews are now in the bag, so to speak
# 2024-04-03 07:52:54
#
# Scraped 135 users this round
# Got 166 reivews
# 467931 reviews are now in the bag, so to speak
# 2024-04-03 07:58:04
#
# Scraped 117 users this round
# Got 207 reivews
# 468138 reviews are now in the bag, so to speak
# 2024-04-03 08:02:30
#
# Scraped 116 users this round
# Got 229 reivews
# 468367 reviews are now in the bag, so to speak
# 2024-04-03 08:06:40
#
# Scraped 98 users this round
# Got 209 reivews
# 468576 reviews are now in the bag, so to speak
# 2024-04-03 08:10:14
#
# Scraped 120 users this round
# Got 189 reivews
# 468765 reviews are now in the bag, so to speak
# 2024-04-03 08:14:53
#
# Scraped 104 users this round
# Got 185 reivews
# 468950 reviews are now in the bag, so to speak
# 2024-04-03 08:19:31
#
# Unable to parse review blocks.
