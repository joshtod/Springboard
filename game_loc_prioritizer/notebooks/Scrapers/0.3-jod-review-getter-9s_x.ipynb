# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 9
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 62 users this round
# Got 329 reivews
# 329 reviews are now in the bag, so to speak
# 2024-04-03 18:12:29
#
# Scraped 56 users this round
# Got 353 reivews
# 682 reviews are now in the bag, so to speak
# 2024-04-03 18:14:05
#
# Scraped 54 users this round
# Got 346 reivews
# 1028 reviews are now in the bag, so to speak
# 2024-04-03 18:15:44
#
# Scraped 56 users this round
# Got 338 reivews
# 1366 reviews are now in the bag, so to speak
# 2024-04-03 18:17:23
#
# Scraped 55 users this round
# Got 378 reivews
# 1744 reviews are now in the bag, so to speak
# 2024-04-03 18:19:02
#
# Scraped 56 users this round
# Got 343 reivews
# 2087 reviews are now in the bag, so to speak
# 2024-04-03 18:20:32
#
# Scraped 57 users this round
# Got 323 reivews
# 2410 reviews are now in the bag, so to speak
# 2024-04-03 18:22:09
#
# Scraped 58 users this round
# Got 324 reivews
# 2734 reviews are now in the bag, so to speak
# 2024-04-03 18:23:54
#
# Scraped 54 users this round
# Got 336 reivews
# 3070 reviews are now in the bag, so to speak
# 2024-04-03 18:25:20
#
# Scraped 51 users this round
# Got 369 reivews
# 3439 reviews are now in the bag, so to speak
# 2024-04-03 18:26:49
#
# Scraped 57 users this round
# Got 347 reivews
# 3786 reviews are now in the bag, so to speak
# 2024-04-03 18:28:29
#
# Scraped 53 users this round
# Got 343 reivews
# 4129 reviews are now in the bag, so to speak
# 2024-04-03 18:30:00
#
# Scraped 56 users this round
# Got 356 reivews
# 4485 reviews are now in the bag, so to speak
# 2024-04-03 18:31:37
#
# Scraped 53 users this round
# Got 349 reivews
# 4834 reviews are now in the bag, so to speak
# 2024-04-03 18:33:02
#
# Scraped 60 users this round
# Got 350 reivews
# 5184 reviews are now in the bag, so to speak
# 2024-04-03 18:34:44
#
# Scraped 53 users this round
# Got 380 reivews
# 5564 reviews are now in the bag, so to speak
# 2024-04-03 18:36:14
#
# Scraped 57 users this round
# Got 318 reivews
# 5882 reviews are now in the bag, so to speak
# 2024-04-03 18:37:52
#
# Scraped 60 users this round
# Got 375 reivews
# 6257 reviews are now in the bag, so to speak
# 2024-04-03 18:39:39
#
# Scraped 55 users this round
# Got 365 reivews
# 6622 reviews are now in the bag, so to speak
# 2024-04-03 18:41:10
#
# Scraped 53 users this round
# Got 368 reivews
# 6990 reviews are now in the bag, so to speak
# 2024-04-03 18:42:41
#
# Scraped 59 users this round
# Got 357 reivews
# 7347 reviews are now in the bag, so to speak
# 2024-04-03 18:44:29
#
# Scraped 55 users this round
# Got 299 reivews
# 7646 reviews are now in the bag, so to speak
# 2024-04-03 18:46:02
#
# Scraped 52 users this round
# Got 341 reivews
# 7987 reviews are now in the bag, so to speak
# 2024-04-03 18:47:34
#
# Scraped 58 users this round
# Got 312 reivews
# 8299 reviews are now in the bag, so to speak
# 2024-04-03 18:49:30
#
# Scraped 52 users this round
# Got 344 reivews
# 8643 reviews are now in the bag, so to speak
# 2024-04-03 18:50:59
#
# Scraped 52 users this round
# Got 331 reivews
# 8974 reviews are now in the bag, so to speak
# 2024-04-03 18:52:33
#
# Scraped 59 users this round
# Got 362 reivews
# 9336 reviews are now in the bag, so to speak
# 2024-04-03 18:54:13
#
# Scraped 57 users this round
# Got 361 reivews
# 9697 reviews are now in the bag, so to speak
# 2024-04-03 18:55:43
#
# Scraped 54 users this round
# Got 335 reivews
# 10032 reviews are now in the bag, so to speak
# 2024-04-03 18:57:17
#
# Scraped 53 users this round
# Got 314 reivews
# 10346 reviews are now in the bag, so to speak
# 2024-04-03 18:58:48
#
# Scraped 57 users this round
# Got 317 reivews
# 10663 reviews are now in the bag, so to speak
# 2024-04-03 19:00:34
#
# Scraped 57 users this round
# Got 311 reivews
# 10974 reviews are now in the bag, so to speak
# 2024-04-03 19:02:05
#
# Scraped 52 users this round
# Got 365 reivews
# 11339 reviews are now in the bag, so to speak
# 2024-04-03 19:03:48
#
# Scraped 59 users this round
# Got 332 reivews
# 11671 reviews are now in the bag, so to speak
# 2024-04-03 19:05:24
#
# Scraped 56 users this round
# Got 338 reivews
# 12009 reviews are now in the bag, so to speak
# 2024-04-03 19:07:00
#
# Scraped 60 users this round
# Got 328 reivews
# 12337 reviews are now in the bag, so to speak
# 2024-04-03 19:08:44
#
# Scraped 53 users this round
# Got 346 reivews
# 12683 reviews are now in the bag, so to speak
# 2024-04-03 19:10:22
#
# Scraped 59 users this round
# Got 331 reivews
# 13014 reviews are now in the bag, so to speak
# 2024-04-03 19:12:02
#
# Scraped 57 users this round
# Got 366 reivews
# 13380 reviews are now in the bag, so to speak
# 2024-04-03 19:13:45
#
# Scraped 58 users this round
# Got 365 reivews
# 13745 reviews are now in the bag, so to speak
# 2024-04-03 19:15:31
#
# Scraped 60 users this round
# Got 378 reivews
# 14123 reviews are now in the bag, so to speak
# 2024-04-03 19:17:05
#
# Scraped 55 users this round
# Got 320 reivews
# 14443 reviews are now in the bag, so to speak
# 2024-04-03 19:18:39
#
# Scraped 59 users this round
# Got 300 reivews
# 14743 reviews are now in the bag, so to speak
# 2024-04-03 19:20:17
#
# Scraped 59 users this round
# Got 321 reivews
# 15064 reviews are now in the bag, so to speak
# 2024-04-03 19:21:49
#
# Scraped 59 users this round
# Got 311 reivews
# 15375 reviews are now in the bag, so to speak
# 2024-04-03 19:23:24
#
# Scraped 65 users this round
# Got 371 reivews
# 15746 reviews are now in the bag, so to speak
# 2024-04-03 19:25:21
#
# Scraped 56 users this round
# Got 306 reivews
# 16052 reviews are now in the bag, so to speak
# 2024-04-03 19:26:58
#
# Scraped 59 users this round
# Got 339 reivews
# 16391 reviews are now in the bag, so to speak
# 2024-04-03 19:28:39
#
# Scraped 57 users this round
# Got 358 reivews
# 16749 reviews are now in the bag, so to speak
# 2024-04-03 19:30:21
#
# Scraped 54 users this round
# Got 318 reivews
# 17067 reviews are now in the bag, so to speak
# 2024-04-03 19:31:51
#
# Scraped 54 users this round
# Got 376 reivews
# 17443 reviews are now in the bag, so to speak
# 2024-04-03 19:33:27
#
# Scraped 51 users this round
# Got 337 reivews
# 17780 reviews are now in the bag, so to speak
# 2024-04-03 19:34:55
#
# Scraped 57 users this round
# Got 316 reivews
# 18096 reviews are now in the bag, so to speak
# 2024-04-03 19:36:37
#
# Scraped 57 users this round
# Got 335 reivews
# 18431 reviews are now in the bag, so to speak
# 2024-04-03 19:38:16
#
# Scraped 55 users this round
# Got 359 reivews
# 18790 reviews are now in the bag, so to speak
# 2024-04-03 19:39:45
#
# Scraped 56 users this round
# Got 346 reivews
# 19136 reviews are now in the bag, so to speak
# 2024-04-03 19:41:27
#
# Scraped 57 users this round
# Got 300 reivews
# 19436 reviews are now in the bag, so to speak
# 2024-04-03 19:43:04
#
# Scraped 59 users this round
# Got 343 reivews
# 19779 reviews are now in the bag, so to speak
# 2024-04-03 19:44:43
#
# Scraped 56 users this round
# Got 320 reivews
# 20099 reviews are now in the bag, so to speak
# 2024-04-03 19:46:26
#
# Scraped 55 users this round
# Got 323 reivews
# 20422 reviews are now in the bag, so to speak
# 2024-04-03 19:48:09
#
# Scraped 54 users this round
# Got 350 reivews
# 20772 reviews are now in the bag, so to speak
# 2024-04-03 19:49:46
#
# Scraped 57 users this round
# Got 358 reivews
# 21130 reviews are now in the bag, so to speak
# 2024-04-03 19:51:30
#
# Scraped 56 users this round
# Got 312 reivews
# 21442 reviews are now in the bag, so to speak
# 2024-04-03 19:53:19
#
# Scraped 56 users this round
# Got 327 reivews
# 21769 reviews are now in the bag, so to speak
# 2024-04-03 19:54:56
#
# Scraped 55 users this round
# Got 329 reivews
# 22098 reviews are now in the bag, so to speak
# 2024-04-03 19:56:35
#
# Scraped 55 users this round
# Got 357 reivews
# 22455 reviews are now in the bag, so to speak
# 2024-04-03 19:58:10
#
# Scraped 59 users this round
# Got 342 reivews
# 22797 reviews are now in the bag, so to speak
# 2024-04-03 19:59:48
#
# Scraped 58 users this round
# Got 322 reivews
# 23119 reviews are now in the bag, so to speak
# 2024-04-03 20:01:28
#
# Scraped 56 users this round
# Got 385 reivews
# 23504 reviews are now in the bag, so to speak
# 2024-04-03 20:03:07
#
# Scraped 59 users this round
# Got 301 reivews
# 23805 reviews are now in the bag, so to speak
# 2024-04-03 20:04:46
#
# Scraped 54 users this round
# Got 296 reivews
# 24101 reviews are now in the bag, so to speak
# 2024-04-03 20:06:13
#
# Scraped 56 users this round
# Got 340 reivews
# 24441 reviews are now in the bag, so to speak
# 2024-04-03 20:07:53
#
# Scraped 61 users this round
# Got 325 reivews
# 24766 reviews are now in the bag, so to speak
# 2024-04-03 20:09:40
#
# Scraped 55 users this round
# Got 372 reivews
# 25138 reviews are now in the bag, so to speak
# 2024-04-03 20:11:21
#
# Scraped 58 users this round
# Got 377 reivews
# 25515 reviews are now in the bag, so to speak
# 2024-04-03 20:13:03
#
# Scraped 54 users this round
# Got 313 reivews
# 25828 reviews are now in the bag, so to speak
# 2024-04-03 20:14:33
#
# Scraped 54 users this round
# Got 326 reivews
# 26154 reviews are now in the bag, so to speak
# 2024-04-03 20:16:10
#
# Scraped 54 users this round
# Got 409 reivews
# 26563 reviews are now in the bag, so to speak
# 2024-04-03 20:17:53
#
# Scraped 54 users this round
# Got 329 reivews
# 26892 reviews are now in the bag, so to speak
# 2024-04-03 20:19:31
#
# Scraped 56 users this round
# Got 326 reivews
# 27218 reviews are now in the bag, so to speak
# 2024-04-03 20:21:10
#
# Scraped 55 users this round
# Got 359 reivews
# 27577 reviews are now in the bag, so to speak
# 2024-04-03 20:22:48
#
# Scraped 65 users this round
# Got 326 reivews
# 27903 reviews are now in the bag, so to speak
# 2024-04-03 20:24:48
#
# Scraped 57 users this round
# Got 328 reivews
# 28231 reviews are now in the bag, so to speak
# 2024-04-03 20:26:22
#
# Scraped 56 users this round
# Got 344 reivews
# 28575 reviews are now in the bag, so to speak
# 2024-04-03 20:27:55
#
# Scraped 59 users this round
# Got 366 reivews
# 28941 reviews are now in the bag, so to speak
# 2024-04-03 20:29:35
#
# Scraped 57 users this round
# Got 312 reivews
# 29253 reviews are now in the bag, so to speak
# 2024-04-03 20:31:20
#
# Scraped 55 users this round
# Got 291 reivews
# 29544 reviews are now in the bag, so to speak
# 2024-04-03 20:32:53
#
# Scraped 54 users this round
# Got 383 reivews
# 29927 reviews are now in the bag, so to speak
# 2024-04-03 20:34:24
#
# Scraped 60 users this round
# Got 292 reivews
# 30219 reviews are now in the bag, so to speak
# 2024-04-03 20:36:12
#
# Scraped 56 users this round
# Got 322 reivews
# 30541 reviews are now in the bag, so to speak
# 2024-04-03 20:37:48
#
# Scraped 55 users this round
# Got 351 reivews
# 30892 reviews are now in the bag, so to speak
# 2024-04-03 20:39:28
#
# Scraped 56 users this round
# Got 339 reivews
# 31231 reviews are now in the bag, so to speak
# 2024-04-03 20:41:10
#
# Scraped 55 users this round
# Got 330 reivews
# 31561 reviews are now in the bag, so to speak
# 2024-04-03 20:42:44
#
# Scraped 58 users this round
# Got 345 reivews
# 31906 reviews are now in the bag, so to speak
# 2024-04-03 20:44:30
#
# Scraped 56 users this round
# Got 363 reivews
# 32269 reviews are now in the bag, so to speak
# 2024-04-03 20:46:11
#
# Scraped 61 users this round
# Got 267 reivews
# 32536 reviews are now in the bag, so to speak
# 2024-04-03 20:48:02
#
# Scraped 55 users this round
# Got 330 reivews
# 32866 reviews are now in the bag, so to speak
# 2024-04-03 20:49:35
#
# Scraped 54 users this round
# Got 325 reivews
# 33191 reviews are now in the bag, so to speak
# 2024-04-03 20:51:15
#
# Scraped 54 users this round
# Got 348 reivews
# 33539 reviews are now in the bag, so to speak
# 2024-04-03 20:52:51
#
# Scraped 57 users this round
# Got 380 reivews
# 33919 reviews are now in the bag, so to speak
# 2024-04-03 20:54:31
#
# Scraped 60 users this round
# Got 323 reivews
# 34242 reviews are now in the bag, so to speak
# 2024-04-03 20:56:21
#
# Scraped 59 users this round
# Got 385 reivews
# 34627 reviews are now in the bag, so to speak
# 2024-04-03 20:58:03
#
# Scraped 53 users this round
# Got 352 reivews
# 34979 reviews are now in the bag, so to speak
# 2024-04-03 20:59:32
#
# Scraped 57 users this round
# Got 307 reivews
# 35286 reviews are now in the bag, so to speak
# 2024-04-03 21:01:15
#
# Scraped 60 users this round
# Got 337 reivews
# 35623 reviews are now in the bag, so to speak
# 2024-04-03 21:03:06
#
# Scraped 56 users this round
# Got 316 reivews
# 35939 reviews are now in the bag, so to speak
# 2024-04-03 21:04:54
#
# Scraped 52 users this round
# Got 361 reivews
# 36300 reviews are now in the bag, so to speak
# 2024-04-03 21:06:35
#
# Scraped 57 users this round
# Got 352 reivews
# 36652 reviews are now in the bag, so to speak
# 2024-04-03 21:08:11
#
# Scraped 56 users this round
# Got 307 reivews
# 36959 reviews are now in the bag, so to speak
# 2024-04-03 21:09:54
#
# Scraped 55 users this round
# Got 368 reivews
# 37327 reviews are now in the bag, so to speak
# 2024-04-03 21:11:33
#
# Scraped 61 users this round
# Got 380 reivews
# 37707 reviews are now in the bag, so to speak
# 2024-04-03 21:13:21
#
# Scraped 56 users this round
# Got 326 reivews
# 38033 reviews are now in the bag, so to speak
# 2024-04-03 21:14:58
#
# Scraped 57 users this round
# Got 366 reivews
# 38399 reviews are now in the bag, so to speak
# 2024-04-03 21:16:32
#
# Scraped 56 users this round
# Got 328 reivews
# 38727 reviews are now in the bag, so to speak
# 2024-04-03 21:18:14
#
# Scraped 56 users this round
# Got 376 reivews
# 39103 reviews are now in the bag, so to speak
# 2024-04-03 21:19:53
#
# Scraped 60 users this round
# Got 352 reivews
# 39455 reviews are now in the bag, so to speak
# 2024-04-03 21:21:38
#
# Scraped 52 users this round
# Got 333 reivews
# 39788 reviews are now in the bag, so to speak
# 2024-04-03 21:23:07
#
# Scraped 56 users this round
# Got 359 reivews
# 40147 reviews are now in the bag, so to speak
# 2024-04-03 21:24:43
#
# Scraped 54 users this round
# Got 346 reivews
# 40493 reviews are now in the bag, so to speak
# 2024-04-03 21:26:15
#
# Scraped 54 users this round
# Got 317 reivews
# 40810 reviews are now in the bag, so to speak
# 2024-04-03 21:27:41
#
# Scraped 57 users this round
# Got 332 reivews
# 41142 reviews are now in the bag, so to speak
# 2024-04-03 21:29:14
#
# Scraped 57 users this round
# Got 328 reivews
# 41470 reviews are now in the bag, so to speak
# 2024-04-03 21:30:49
#
# Scraped 55 users this round
# Got 305 reivews
# 41775 reviews are now in the bag, so to speak
# 2024-04-03 21:32:23
#
# Scraped 55 users this round
# Got 283 reivews
# 42058 reviews are now in the bag, so to speak
# 2024-04-03 21:33:58
#
# Scraped 55 users this round
# Got 338 reivews
# 42396 reviews are now in the bag, so to speak
# 2024-04-03 21:35:28
#
# Scraped 56 users this round
# Got 386 reivews
# 42782 reviews are now in the bag, so to speak
# 2024-04-03 21:37:05
#
# Scraped 55 users this round
# Got 309 reivews
# 43091 reviews are now in the bag, so to speak
# 2024-04-03 21:38:40
#
# Scraped 63 users this round
# Got 350 reivews
# 43441 reviews are now in the bag, so to speak
# 2024-04-03 21:40:28
#
# Scraped 60 users this round
# Got 325 reivews
# 43766 reviews are now in the bag, so to speak
# 2024-04-03 21:42:06
#
# Scraped 54 users this round
# Got 341 reivews
# 44107 reviews are now in the bag, so to speak
# 2024-04-03 21:43:30
#
# Scraped 56 users this round
# Got 300 reivews
# 44407 reviews are now in the bag, so to speak
# 2024-04-03 21:45:09
#
# Scraped 61 users this round
# Got 322 reivews
# 44729 reviews are now in the bag, so to speak
# 2024-04-03 21:46:52
#
# Scraped 60 users this round
# Got 283 reivews
# 45012 reviews are now in the bag, so to speak
# 2024-04-03 21:48:28
#
# Scraped 54 users this round
# Got 318 reivews
# 45330 reviews are now in the bag, so to speak
# 2024-04-03 21:49:58
#
# Scraped 52 users this round
# Got 357 reivews
# 45687 reviews are now in the bag, so to speak
# 2024-04-03 21:51:31
#
# Scraped 58 users this round
# Got 291 reivews
# 45978 reviews are now in the bag, so to speak
# 2024-04-03 21:53:09
#
# Scraped 57 users this round
# Got 346 reivews
# 46324 reviews are now in the bag, so to speak
# 2024-04-03 21:54:52
#
# Scraped 58 users this round
# Got 344 reivews
# 46668 reviews are now in the bag, so to speak
# 2024-04-03 21:56:33
#
# Scraped 57 users this round
# Got 324 reivews
# 46992 reviews are now in the bag, so to speak
# 2024-04-03 21:58:16
#
# Scraped 55 users this round
# Got 303 reivews
# 47295 reviews are now in the bag, so to speak
# 2024-04-03 21:59:51
#
# Scraped 58 users this round
# Got 377 reivews
# 47672 reviews are now in the bag, so to speak
# 2024-04-03 22:01:39
#
# Scraped 54 users this round
# Got 323 reivews
# 47995 reviews are now in the bag, so to speak
# 2024-04-03 22:03:12
#
# Scraped 55 users this round
# Got 320 reivews
# 48315 reviews are now in the bag, so to speak
# 2024-04-03 22:04:48
#
# Scraped 58 users this round
# Got 383 reivews
# 48698 reviews are now in the bag, so to speak
# 2024-04-03 22:06:28
#
# Scraped 60 users this round
# Got 336 reivews
# 49034 reviews are now in the bag, so to speak
# 2024-04-03 22:08:09
#
# Scraped 54 users this round
# Got 337 reivews
# 49371 reviews are now in the bag, so to speak
# 2024-04-03 22:09:47
#
# Scraped 57 users this round
# Got 329 reivews
# 49700 reviews are now in the bag, so to speak
# 2024-04-03 22:11:42
#
# Scraped 56 users this round
# Got 363 reivews
# 50063 reviews are now in the bag, so to speak
# 2024-04-03 22:13:20
#
# Scraped 56 users this round
# Got 353 reivews
# 50416 reviews are now in the bag, so to speak
# 2024-04-03 22:14:58
#
# Scraped 55 users this round
# Got 301 reivews
# 50717 reviews are now in the bag, so to speak
# 2024-04-03 22:16:41
#
# Scraped 57 users this round
# Got 346 reivews
# 51063 reviews are now in the bag, so to speak
# 2024-04-03 22:18:19
#
# Scraped 58 users this round
# Got 335 reivews
# 51398 reviews are now in the bag, so to speak
# 2024-04-03 22:20:16
#
# Scraped 59 users this round
# Got 330 reivews
# 51728 reviews are now in the bag, so to speak
# 2024-04-03 22:21:59
#
# Scraped 53 users this round
# Got 342 reivews
# 52070 reviews are now in the bag, so to speak
# 2024-04-03 22:23:58
#
# Scraped 54 users this round
# Got 308 reivews
# 52378 reviews are now in the bag, so to speak
# 2024-04-03 22:26:08
#
# Scraped 51 users this round
# Got 329 reivews
# 52707 reviews are now in the bag, so to speak
# 2024-04-03 22:28:41
#
# Scraped 61 users this round
# Got 328 reivews
# 53035 reviews are now in the bag, so to speak
# 2024-04-03 22:31:54
#
# Scraped 59 users this round
# Got 341 reivews
# 53376 reviews are now in the bag, so to speak
# 2024-04-03 22:35:05
#
# Scraped 54 users this round
# Got 351 reivews
# 53727 reviews are now in the bag, so to speak
# 2024-04-03 22:37:57
#
# Scraped 53 users this round
# Got 313 reivews
# 54040 reviews are now in the bag, so to speak
# 2024-04-03 22:40:45
#
# Scraped 54 users this round
# Got 308 reivews
# 54348 reviews are now in the bag, so to speak
# 2024-04-03 22:43:49
#
# Scraped 55 users this round
# Got 309 reivews
# 54657 reviews are now in the bag, so to speak
# 2024-04-03 22:46:31
#
# Scraped 53 users this round
# Got 349 reivews
# 55006 reviews are now in the bag, so to speak
# 2024-04-03 22:49:10
#
# Scraped 55 users this round
# Got 378 reivews
# 55384 reviews are now in the bag, so to speak
# 2024-04-03 22:52:10
#
# Scraped 57 users this round
# Got 334 reivews
# 55718 reviews are now in the bag, so to speak
# 2024-04-03 22:55:09
#
# Scraped 55 users this round
# Got 330 reivews
# 56048 reviews are now in the bag, so to speak
# 2024-04-03 22:57:54
#
# Scraped 55 users this round
# Got 362 reivews
# 56410 reviews are now in the bag, so to speak
# 2024-04-03 23:01:02
#
# Scraped 60 users this round
# Got 376 reivews
# 56786 reviews are now in the bag, so to speak
# 2024-04-03 23:04:08
#
# Scraped 54 users this round
# Got 382 reivews
# 57168 reviews are now in the bag, so to speak
# 2024-04-03 23:06:58
#
# Scraped 56 users this round
# Got 325 reivews
# 57493 reviews are now in the bag, so to speak
# 2024-04-03 23:10:20
#
# Scraped 59 users this round
# Got 356 reivews
# 57849 reviews are now in the bag, so to speak
# 2024-04-03 23:13:32
#
# Scraped 57 users this round
# Got 318 reivews
# 58167 reviews are now in the bag, so to speak
# 2024-04-03 23:15:33
#
# Scraped 58 users this round
# Got 345 reivews
# 58512 reviews are now in the bag, so to speak
# 2024-04-03 23:17:20
#
# Scraped 60 users this round
# Got 331 reivews
# 58843 reviews are now in the bag, so to speak
# 2024-04-03 23:19:06
#
# Scraped 56 users this round
# Got 338 reivews
# 59181 reviews are now in the bag, so to speak
# 2024-04-03 23:20:46
#
# Scraped 55 users this round
# Got 333 reivews
# 59514 reviews are now in the bag, so to speak
# 2024-04-03 23:22:17
#
# Scraped 57 users this round
# Got 341 reivews
# 59855 reviews are now in the bag, so to speak
# 2024-04-03 23:23:52
#
# Scraped 52 users this round
# Got 334 reivews
# 60189 reviews are now in the bag, so to speak
# 2024-04-03 23:25:14
#
# Scraped 55 users this round
# Got 326 reivews
# 60515 reviews are now in the bag, so to speak
# 2024-04-03 23:26:48
#
# Scraped 55 users this round
# Got 347 reivews
# 60862 reviews are now in the bag, so to speak
# 2024-04-03 23:28:35
#
# Scraped 58 users this round
# Got 349 reivews
# 61211 reviews are now in the bag, so to speak
# 2024-04-03 23:30:17
#
# Scraped 56 users this round
# Got 334 reivews
# 61545 reviews are now in the bag, so to speak
# 2024-04-03 23:31:45
#
# Scraped 55 users this round
# Got 319 reivews
# 61864 reviews are now in the bag, so to speak
# 2024-04-03 23:33:14
#
# Scraped 55 users this round
# Got 353 reivews
# 62217 reviews are now in the bag, so to speak
# 2024-04-03 23:34:52
#
# Scraped 57 users this round
# Got 378 reivews
# 62595 reviews are now in the bag, so to speak
# 2024-04-03 23:36:34
#
# Scraped 57 users this round
# Got 323 reivews
# 62918 reviews are now in the bag, so to speak
# 2024-04-03 23:38:09
#
# Scraped 56 users this round
# Got 311 reivews
# 63229 reviews are now in the bag, so to speak
# 2024-04-03 23:39:47
#
# Scraped 54 users this round
# Got 326 reivews
# 63555 reviews are now in the bag, so to speak
# 2024-04-03 23:41:23
#
# Scraped 53 users this round
# Got 325 reivews
# 63880 reviews are now in the bag, so to speak
# 2024-04-03 23:43:05
#
# Scraped 62 users this round
# Got 338 reivews
# 64218 reviews are now in the bag, so to speak
# 2024-04-03 23:44:52
#
# Scraped 60 users this round
# Got 353 reivews
# 64571 reviews are now in the bag, so to speak
# 2024-04-03 23:46:33
#
# Scraped 56 users this round
# Got 304 reivews
# 64875 reviews are now in the bag, so to speak
# 2024-04-03 23:47:58
#
# Scraped 54 users this round
# Got 349 reivews
# 65224 reviews are now in the bag, so to speak
# 2024-04-03 23:49:31
#
# Scraped 55 users this round
# Got 297 reivews
# 65521 reviews are now in the bag, so to speak
# 2024-04-03 23:51:09
#
# Scraped 54 users this round
# Got 314 reivews
# 65835 reviews are now in the bag, so to speak
# 2024-04-03 23:52:50
#
# Scraped 57 users this round
# Got 334 reivews
# 66169 reviews are now in the bag, so to speak
# 2024-04-03 23:54:19
#
# Scraped 56 users this round
# Got 320 reivews
# 66489 reviews are now in the bag, so to speak
# 2024-04-03 23:55:53
#
# Scraped 53 users this round
# Got 326 reivews
# 66815 reviews are now in the bag, so to speak
# 2024-04-03 23:57:19
#
# Scraped 55 users this round
# Got 283 reivews
# 67098 reviews are now in the bag, so to speak
# 2024-04-03 23:58:46
#
# Scraped 58 users this round
# Got 352 reivews
# 67450 reviews are now in the bag, so to speak
# 2024-04-04 00:00:17
#
# Scraped 58 users this round
# Got 342 reivews
# 67792 reviews are now in the bag, so to speak
# 2024-04-04 00:02:00
#
# Scraped 55 users this round
# Got 331 reivews
# 68123 reviews are now in the bag, so to speak
# 2024-04-04 00:03:42
#
# Scraped 54 users this round
# Got 345 reivews
# 68468 reviews are now in the bag, so to speak
# 2024-04-04 00:05:17
#
# Scraped 55 users this round
# Got 363 reivews
# 68831 reviews are now in the bag, so to speak
# 2024-04-04 00:06:52
#
# Scraped 55 users this round
# Got 402 reivews
# 69233 reviews are now in the bag, so to speak
# 2024-04-04 00:08:32
#
# Scraped 55 users this round
# Got 314 reivews
# 69547 reviews are now in the bag, so to speak
# 2024-04-04 00:10:09
#
# Scraped 57 users this round
# Got 387 reivews
# 69934 reviews are now in the bag, so to speak
# 2024-04-04 00:11:53
#
# Scraped 51 users this round
# Got 354 reivews
# 70288 reviews are now in the bag, so to speak
# 2024-04-04 00:13:22
#
# Scraped 55 users this round
# Got 315 reivews
# 70603 reviews are now in the bag, so to speak
# 2024-04-04 00:15:01
#
# Scraped 55 users this round
# Got 360 reivews
# 70963 reviews are now in the bag, so to speak
# 2024-04-04 00:16:30
#
# Scraped 57 users this round
# Got 328 reivews
# 71291 reviews are now in the bag, so to speak
# 2024-04-04 00:18:05
#
# Scraped 58 users this round
# Got 288 reivews
# 71579 reviews are now in the bag, so to speak
# 2024-04-04 00:19:39
#
# Scraped 54 users this round
# Got 304 reivews
# 71883 reviews are now in the bag, so to speak
# 2024-04-04 00:21:13
#
# Scraped 58 users this round
# Got 349 reivews
# 72232 reviews are now in the bag, so to speak
# 2024-04-04 00:22:52
#
# Scraped 62 users this round
# Got 352 reivews
# 72584 reviews are now in the bag, so to speak
# 2024-04-04 00:24:41
#
# Scraped 52 users this round
# Got 330 reivews
# 72914 reviews are now in the bag, so to speak
# 2024-04-04 00:26:15
#
# Scraped 57 users this round
# Got 369 reivews
# 73283 reviews are now in the bag, so to speak
# 2024-04-04 00:28:03
#
# Scraped 57 users this round
# Got 385 reivews
# 73668 reviews are now in the bag, so to speak
# 2024-04-04 00:30:00
#
# Scraped 60 users this round
# Got 351 reivews
# 74019 reviews are now in the bag, so to speak
# 2024-04-04 00:31:38
#
# Scraped 56 users this round
# Got 330 reivews
# 74349 reviews are now in the bag, so to speak
# 2024-04-04 00:33:20
#
# Scraped 54 users this round
# Got 359 reivews
# 74708 reviews are now in the bag, so to speak
# 2024-04-04 00:34:52
#
# Scraped 53 users this round
# Got 341 reivews
# 75049 reviews are now in the bag, so to speak
# 2024-04-04 00:36:19
#
# Scraped 52 users this round
# Got 365 reivews
# 75414 reviews are now in the bag, so to speak
# 2024-04-04 00:37:50
#
# Scraped 55 users this round
# Got 343 reivews
# 75757 reviews are now in the bag, so to speak
# 2024-04-04 00:39:31
#
# Scraped 54 users this round
# Got 371 reivews
# 76128 reviews are now in the bag, so to speak
# 2024-04-04 00:41:08
#
# Scraped 56 users this round
# Got 361 reivews
# 76489 reviews are now in the bag, so to speak
# 2024-04-04 00:42:46
#
# Scraped 54 users this round
# Got 375 reivews
# 76864 reviews are now in the bag, so to speak
# 2024-04-04 00:44:31
#
# Scraped 53 users this round
# Got 334 reivews
# 77198 reviews are now in the bag, so to speak
# 2024-04-04 00:45:56
#
# Scraped 56 users this round
# Got 340 reivews
# 77538 reviews are now in the bag, so to speak
# 2024-04-04 00:47:31
#
# Scraped 58 users this round
# Got 352 reivews
# 77890 reviews are now in the bag, so to speak
# 2024-04-04 00:49:11
#
# Scraped 57 users this round
# Got 367 reivews
# 78257 reviews are now in the bag, so to speak
# 2024-04-04 00:50:56
#
# Scraped 59 users this round
# Got 326 reivews
# 78583 reviews are now in the bag, so to speak
# 2024-04-04 00:52:33
#
# Scraped 53 users this round
# Got 341 reivews
# 78924 reviews are now in the bag, so to speak
# 2024-04-04 00:54:02
#
# Scraped 58 users this round
# Got 318 reivews
# 79242 reviews are now in the bag, so to speak
# 2024-04-04 00:55:32
#
# Scraped 54 users this round
# Got 347 reivews
# 79589 reviews are now in the bag, so to speak
# 2024-04-04 00:57:09
#
# Scraped 60 users this round
# Got 319 reivews
# 79908 reviews are now in the bag, so to speak
# 2024-04-04 00:58:50
#
# Scraped 54 users this round
# Got 378 reivews
# 80286 reviews are now in the bag, so to speak
# 2024-04-04 01:00:29
#
# Scraped 58 users this round
# Got 321 reivews
# 80607 reviews are now in the bag, so to speak
# 2024-04-04 01:02:14
#
# Scraped 54 users this round
# Got 365 reivews
# 80972 reviews are now in the bag, so to speak
# 2024-04-04 01:03:56
#
# Scraped 56 users this round
# Got 340 reivews
# 81312 reviews are now in the bag, so to speak
# 2024-04-04 01:05:30
#
# Scraped 53 users this round
# Got 315 reivews
# 81627 reviews are now in the bag, so to speak
# 2024-04-04 01:06:58
#
# Scraped 56 users this round
# Got 350 reivews
# 81977 reviews are now in the bag, so to speak
# 2024-04-04 01:08:40
#
# Scraped 56 users this round
# Got 326 reivews
# 82303 reviews are now in the bag, so to speak
# 2024-04-04 01:10:16
#
# Scraped 57 users this round
# Got 320 reivews
# 82623 reviews are now in the bag, so to speak
# 2024-04-04 01:11:50
#
# Scraped 53 users this round
# Got 284 reivews
# 82907 reviews are now in the bag, so to speak
# 2024-04-04 01:13:18
#
# Scraped 55 users this round
# Got 359 reivews
# 83266 reviews are now in the bag, so to speak
# 2024-04-04 01:14:49
#
# Scraped 55 users this round
# Got 333 reivews
# 83599 reviews are now in the bag, so to speak
# 2024-04-04 01:16:18
#
# Scraped 58 users this round
# Got 316 reivews
# 83915 reviews are now in the bag, so to speak
# 2024-04-04 01:17:48
#
# Scraped 57 users this round
# Got 349 reivews
# 84264 reviews are now in the bag, so to speak
# 2024-04-04 01:19:24
#
# Scraped 58 users this round
# Got 360 reivews
# 84624 reviews are now in the bag, so to speak
# 2024-04-04 01:21:00
#
# Scraped 54 users this round
# Got 358 reivews
# 84982 reviews are now in the bag, so to speak
# 2024-04-04 01:22:35
#
# Scraped 57 users this round
# Got 344 reivews
# 85326 reviews are now in the bag, so to speak
# 2024-04-04 01:24:18
#
# Scraped 57 users this round
# Got 279 reivews
# 85605 reviews are now in the bag, so to speak
# 2024-04-04 01:25:47
#
# Scraped 60 users this round
# Got 322 reivews
# 85927 reviews are now in the bag, so to speak
# 2024-04-04 01:27:33
#
# Scraped 53 users this round
# Got 315 reivews
# 86242 reviews are now in the bag, so to speak
# 2024-04-04 01:29:02
#
# Scraped 53 users this round
# Got 391 reivews
# 86633 reviews are now in the bag, so to speak
# 2024-04-04 01:30:44
#
# Scraped 57 users this round
# Got 338 reivews
# 86971 reviews are now in the bag, so to speak
# 2024-04-04 01:32:10
#
# Scraped 54 users this round
# Got 305 reivews
# 87276 reviews are now in the bag, so to speak
# 2024-04-04 01:33:38
#
# Scraped 60 users this round
# Got 303 reivews
# 87579 reviews are now in the bag, so to speak
# 2024-04-04 01:35:35
#
# Scraped 55 users this round
# Got 343 reivews
# 87922 reviews are now in the bag, so to speak
# 2024-04-04 01:37:02
#
# Scraped 56 users this round
# Got 363 reivews
# 88285 reviews are now in the bag, so to speak
# 2024-04-04 01:38:42
#
# Scraped 64 users this round
# Got 362 reivews
# 88647 reviews are now in the bag, so to speak
# 2024-04-04 01:40:36
#
# Scraped 54 users this round
# Got 347 reivews
# 88994 reviews are now in the bag, so to speak
# 2024-04-04 01:42:09
#
# Scraped 57 users this round
# Got 393 reivews
# 89387 reviews are now in the bag, so to speak
# 2024-04-04 01:43:45
#
# Scraped 58 users this round
# Got 378 reivews
# 89765 reviews are now in the bag, so to speak
# 2024-04-04 01:45:15
#
# Scraped 62 users this round
# Got 328 reivews
# 90093 reviews are now in the bag, so to speak
# 2024-04-04 01:47:01
#
# Scraped 60 users this round
# Got 359 reivews
# 90452 reviews are now in the bag, so to speak
# 2024-04-04 01:48:53
#
# Scraped 58 users this round
# Got 308 reivews
# 90760 reviews are now in the bag, so to speak
# 2024-04-04 01:50:24
#
# Scraped 55 users this round
# Got 330 reivews
# 91090 reviews are now in the bag, so to speak
# 2024-04-04 01:51:51
#
# Scraped 59 users this round
# Got 369 reivews
# 91459 reviews are now in the bag, so to speak
# 2024-04-04 01:53:38
#
# Scraped 60 users this round
# Got 313 reivews
# 91772 reviews are now in the bag, so to speak
# 2024-04-04 01:55:14
#
# Scraped 51 users this round
# Got 329 reivews
# 92101 reviews are now in the bag, so to speak
# 2024-04-04 01:56:37
#
# Scraped 54 users this round
# Got 345 reivews
# 92446 reviews are now in the bag, so to speak
# 2024-04-04 01:58:17
#
# Scraped 57 users this round
# Got 320 reivews
# 92766 reviews are now in the bag, so to speak
# 2024-04-04 01:59:57
#
# Scraped 51 users this round
# Got 318 reivews
# 93084 reviews are now in the bag, so to speak
# 2024-04-04 02:01:15
#
# Scraped 56 users this round
# Got 322 reivews
# 93406 reviews are now in the bag, so to speak
# 2024-04-04 02:02:47
#
# Scraped 55 users this round
# Got 355 reivews
# 93761 reviews are now in the bag, so to speak
# 2024-04-04 02:04:20
#
# Scraped 55 users this round
# Got 314 reivews
# 94075 reviews are now in the bag, so to speak
# 2024-04-04 02:05:59
#
# Scraped 63 users this round
# Got 324 reivews
# 94399 reviews are now in the bag, so to speak
# 2024-04-04 02:07:55
#
# Scraped 56 users this round
# Got 362 reivews
# 94761 reviews are now in the bag, so to speak
# 2024-04-04 02:09:29
#
# Scraped 55 users this round
# Got 357 reivews
# 95118 reviews are now in the bag, so to speak
# 2024-04-04 02:11:00
#
# Scraped 55 users this round
# Got 400 reivews
# 95518 reviews are now in the bag, so to speak
# 2024-04-04 02:12:36
#
# Scraped 54 users this round
# Got 344 reivews
# 95862 reviews are now in the bag, so to speak
# 2024-04-04 02:14:07
#
# Scraped 54 users this round
# Got 311 reivews
# 96173 reviews are now in the bag, so to speak
# 2024-04-04 02:15:34
#
# Scraped 52 users this round
# Got 347 reivews
# 96520 reviews are now in the bag, so to speak
# 2024-04-04 02:17:08
#
# Scraped 55 users this round
# Got 326 reivews
# 96846 reviews are now in the bag, so to speak
# 2024-04-04 02:18:44
#
# Scraped 56 users this round
# Got 338 reivews
# 97184 reviews are now in the bag, so to speak
# 2024-04-04 02:20:27
#
# Scraped 55 users this round
# Got 362 reivews
# 97546 reviews are now in the bag, so to speak
# 2024-04-04 02:22:03
#
# Scraped 55 users this round
# Got 353 reivews
# 97899 reviews are now in the bag, so to speak
# 2024-04-04 02:23:32
#
# Scraped 54 users this round
# Got 361 reivews
# 98260 reviews are now in the bag, so to speak
# 2024-04-04 02:25:05
#
# Scraped 56 users this round
# Got 331 reivews
# 98591 reviews are now in the bag, so to speak
# 2024-04-04 02:26:40
#
# Scraped 54 users this round
# Got 285 reivews
# 98876 reviews are now in the bag, so to speak
# 2024-04-04 02:28:07
#
# Scraped 58 users this round
# Got 358 reivews
# 99234 reviews are now in the bag, so to speak
# 2024-04-04 02:29:47
#
# Scraped 55 users this round
# Got 372 reivews
# 99606 reviews are now in the bag, so to speak
# 2024-04-04 02:31:16
#
# Scraped 54 users this round
# Got 339 reivews
# 99945 reviews are now in the bag, so to speak
# 2024-04-04 02:32:47
#
# Scraped 54 users this round
# Got 347 reivews
# 100292 reviews are now in the bag, so to speak
# 2024-04-04 02:34:23
#
# Scraped 55 users this round
# Got 341 reivews
# 100633 reviews are now in the bag, so to speak
# 2024-04-04 02:35:51
#
# Scraped 55 users this round
# Got 363 reivews
# 100996 reviews are now in the bag, so to speak
# 2024-04-04 02:37:24
#
# Scraped 59 users this round
# Got 321 reivews
# 101317 reviews are now in the bag, so to speak
# 2024-04-04 02:39:05
#
# Scraped 56 users this round
# Got 307 reivews
# 101624 reviews are now in the bag, so to speak
# 2024-04-04 02:40:32
#
# Scraped 55 users this round
# Got 382 reivews
# 102006 reviews are now in the bag, so to speak
# 2024-04-04 02:42:25
#
# Scraped 58 users this round
# Got 323 reivews
# 102329 reviews are now in the bag, so to speak
# 2024-04-04 02:43:58
#
# Scraped 56 users this round
# Got 344 reivews
# 102673 reviews are now in the bag, so to speak
# 2024-04-04 02:45:44
#
# Scraped 58 users this round
# Got 351 reivews
# 103024 reviews are now in the bag, so to speak
# 2024-04-04 02:47:23
#
# Scraped 53 users this round
# Got 337 reivews
# 103361 reviews are now in the bag, so to speak
# 2024-04-04 02:48:55
#
# Scraped 53 users this round
# Got 375 reivews
# 103736 reviews are now in the bag, so to speak
# 2024-04-04 02:50:24
#
# Scraped 56 users this round
# Got 330 reivews
# 104066 reviews are now in the bag, so to speak
# 2024-04-04 02:51:52
#
# Scraped 53 users this round
# Got 348 reivews
# 104414 reviews are now in the bag, so to speak
# 2024-04-04 02:53:40
#
# Scraped 54 users this round
# Got 381 reivews
# 104795 reviews are now in the bag, so to speak
# 2024-04-04 02:55:17
#
# Scraped 51 users this round
# Got 363 reivews
# 105158 reviews are now in the bag, so to speak
# 2024-04-04 02:56:49
#
# Scraped 60 users this round
# Got 305 reivews
# 105463 reviews are now in the bag, so to speak
# 2024-04-04 02:58:27
#
# Scraped 58 users this round
# Got 322 reivews
# 105785 reviews are now in the bag, so to speak
# 2024-04-04 03:00:05
#
# Scraped 53 users this round
# Got 363 reivews
# 106148 reviews are now in the bag, so to speak
# 2024-04-04 03:01:32
#
# Scraped 58 users this round
# Got 371 reivews
# 106519 reviews are now in the bag, so to speak
# 2024-04-04 03:03:04
#
# Scraped 62 users this round
# Got 336 reivews
# 106855 reviews are now in the bag, so to speak
# 2024-04-04 03:04:44
#
# Scraped 56 users this round
# Got 342 reivews
# 107197 reviews are now in the bag, so to speak
# 2024-04-04 03:06:15
#
# Scraped 55 users this round
# Got 379 reivews
# 107576 reviews are now in the bag, so to speak
# 2024-04-04 03:07:49
#
# Scraped 57 users this round
# Got 333 reivews
# 107909 reviews are now in the bag, so to speak
# 2024-04-04 03:09:30
#
# Scraped 55 users this round
# Got 373 reivews
# 108282 reviews are now in the bag, so to speak
# 2024-04-04 03:11:00
#
# Scraped 59 users this round
# Got 365 reivews
# 108647 reviews are now in the bag, so to speak
# 2024-04-04 03:12:42
#
# Scraped 53 users this round
# Got 363 reivews
# 109010 reviews are now in the bag, so to speak
# 2024-04-04 03:14:06
#
# Scraped 58 users this round
# Got 366 reivews
# 109376 reviews are now in the bag, so to speak
# 2024-04-04 03:15:40
#
# Scraped 57 users this round
# Got 353 reivews
# 109729 reviews are now in the bag, so to speak
# 2024-04-04 03:17:18
#
# Scraped 55 users this round
# Got 372 reivews
# 110101 reviews are now in the bag, so to speak
# 2024-04-04 03:18:54
#
# Scraped 54 users this round
# Got 333 reivews
# 110434 reviews are now in the bag, so to speak
# 2024-04-04 03:20:48
#
# Scraped 57 users this round
# Got 340 reivews
# 110774 reviews are now in the bag, so to speak
# 2024-04-04 03:22:34
#
# Scraped 57 users this round
# Got 312 reivews
# 111086 reviews are now in the bag, so to speak
# 2024-04-04 03:24:07
#
# Scraped 55 users this round
# Got 343 reivews
# 111429 reviews are now in the bag, so to speak
# 2024-04-04 03:25:38
#
# Scraped 52 users this round
# Got 361 reivews
# 111790 reviews are now in the bag, so to speak
# 2024-04-04 03:27:09
#
# Scraped 53 users this round
# Got 355 reivews
# 112145 reviews are now in the bag, so to speak
# 2024-04-04 03:28:42
#
# Scraped 54 users this round
# Got 333 reivews
# 112478 reviews are now in the bag, so to speak
# 2024-04-04 03:30:18
#
# Scraped 55 users this round
# Got 274 reivews
# 112752 reviews are now in the bag, so to speak
# 2024-04-04 03:31:56
#
# Scraped 57 users this round
# Got 339 reivews
# 113091 reviews are now in the bag, so to speak
# 2024-04-04 03:33:31
#
# Scraped 55 users this round
# Got 327 reivews
# 113418 reviews are now in the bag, so to speak
# 2024-04-04 03:34:59
#
# Scraped 54 users this round
# Got 348 reivews
# 113766 reviews are now in the bag, so to speak
# 2024-04-04 03:36:35
#
# Scraped 56 users this round
# Got 361 reivews
# 114127 reviews are now in the bag, so to speak
# 2024-04-04 03:38:06
#
# Scraped 52 users this round
# Got 304 reivews
# 114431 reviews are now in the bag, so to speak
# 2024-04-04 03:39:31
#
# Scraped 57 users this round
# Got 342 reivews
# 114773 reviews are now in the bag, so to speak
# 2024-04-04 03:41:14
#
# Scraped 57 users this round
# Got 326 reivews
# 115099 reviews are now in the bag, so to speak
# 2024-04-04 03:42:50
#
# Scraped 57 users this round
# Got 338 reivews
# 115437 reviews are now in the bag, so to speak
# 2024-04-04 03:44:11
#
# Scraped 56 users this round
# Got 376 reivews
# 115813 reviews are now in the bag, so to speak
# 2024-04-04 03:45:45
#
# Scraped 55 users this round
# Got 391 reivews
# 116204 reviews are now in the bag, so to speak
# 2024-04-04 03:47:09
#
# Scraped 57 users this round
# Got 360 reivews
# 116564 reviews are now in the bag, so to speak
# 2024-04-04 03:48:32
#
# Scraped 59 users this round
# Got 354 reivews
# 116918 reviews are now in the bag, so to speak
# 2024-04-04 03:49:56
#
# Scraped 54 users this round
# Got 358 reivews
# 117276 reviews are now in the bag, so to speak
# 2024-04-04 03:51:21
#
# Scraped 56 users this round
# Got 355 reivews
# 117631 reviews are now in the bag, so to speak
# 2024-04-04 03:52:54
#
# Scraped 55 users this round
# Got 346 reivews
# 117977 reviews are now in the bag, so to speak
# 2024-04-04 03:54:22
#
# Scraped 55 users this round
# Got 356 reivews
# 118333 reviews are now in the bag, so to speak
# 2024-04-04 03:55:57
#
# Scraped 60 users this round
# Got 342 reivews
# 118675 reviews are now in the bag, so to speak
# 2024-04-04 03:57:28
#
# Scraped 55 users this round
# Got 352 reivews
# 119027 reviews are now in the bag, so to speak
# 2024-04-04 03:58:51
#
# Scraped 55 users this round
# Got 315 reivews
# 119342 reviews are now in the bag, so to speak
# 2024-04-04 04:00:15
#
# Scraped 61 users this round
# Got 328 reivews
# 119670 reviews are now in the bag, so to speak
# 2024-04-04 04:01:54
#
# Scraped 54 users this round
# Got 365 reivews
# 120035 reviews are now in the bag, so to speak
# 2024-04-04 04:03:14
#
# Scraped 57 users this round
# Got 353 reivews
# 120388 reviews are now in the bag, so to speak
# 2024-04-04 04:04:52
#
# Scraped 57 users this round
# Got 341 reivews
# 120729 reviews are now in the bag, so to speak
# 2024-04-04 04:06:40
#
# Scraped 56 users this round
# Got 342 reivews
# 121071 reviews are now in the bag, so to speak
# 2024-04-04 04:08:01
#
# Scraped 55 users this round
# Got 284 reivews
# 121355 reviews are now in the bag, so to speak
# 2024-04-04 04:09:24
#
# Scraped 57 users this round
# Got 302 reivews
# 121657 reviews are now in the bag, so to speak
# 2024-04-04 04:10:49
#
# Scraped 55 users this round
# Got 363 reivews
# 122020 reviews are now in the bag, so to speak
# 2024-04-04 04:12:12
#
# Scraped 57 users this round
# Got 355 reivews
# 122375 reviews are now in the bag, so to speak
# 2024-04-04 04:13:46
#
# Scraped 56 users this round
# Got 334 reivews
# 122709 reviews are now in the bag, so to speak
# 2024-04-04 04:15:08
#
# Scraped 55 users this round
# Got 340 reivews
# 123049 reviews are now in the bag, so to speak
# 2024-04-04 04:16:28
#
# Scraped 57 users this round
# Got 302 reivews
# 123351 reviews are now in the bag, so to speak
# 2024-04-04 04:17:57
#
# Scraped 57 users this round
# Got 323 reivews
# 123674 reviews are now in the bag, so to speak
# 2024-04-04 04:19:16
#
# Scraped 56 users this round
# Got 347 reivews
# 124021 reviews are now in the bag, so to speak
# 2024-04-04 04:20:39
#
# Scraped 57 users this round
# Got 296 reivews
# 124317 reviews are now in the bag, so to speak
# 2024-04-04 04:22:07
#
# Scraped 57 users this round
# Got 310 reivews
# 124627 reviews are now in the bag, so to speak
# 2024-04-04 04:23:28

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
