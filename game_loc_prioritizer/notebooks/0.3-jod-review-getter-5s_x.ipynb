# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 5
page = 2

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}_x.parquet')

# review_scraped_users = set()
# with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/tens_users.pkl', 'rb+') as file :
    tens_users = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/?p={}'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

relevant_users = {user for user in digit_users if user in tens_users}

unscraped_users = relevant_users - review_scraped_users

skipped_users = set()

# %%
# Useful functions

def log_failure(user, message) :
    # print(message)
    skipped_users.add(user)
    with open(f'../data/raw/review_skipped_users_{last_digit}_x.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user, page))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}_x.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}_x.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}_x.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 60 users this round
# Got 349 reivews
# 349 reviews are now in the bag, so to speak
# 2024-04-03 18:10:15
#
# Scraped 56 users this round
# Got 400 reivews
# 749 reviews are now in the bag, so to speak
# 2024-04-03 18:11:58
#
# Scraped 62 users this round
# Got 309 reivews
# 1058 reviews are now in the bag, so to speak
# 2024-04-03 18:13:43
#
# Scraped 55 users this round
# Got 352 reivews
# 1410 reviews are now in the bag, so to speak
# 2024-04-03 18:15:10
#
# Scraped 56 users this round
# Got 295 reivews
# 1705 reviews are now in the bag, so to speak
# 2024-04-03 18:16:40
#
# Scraped 56 users this round
# Got 322 reivews
# 2027 reviews are now in the bag, so to speak
# 2024-04-03 18:18:17
#
# Scraped 55 users this round
# Got 369 reivews
# 2396 reviews are now in the bag, so to speak
# 2024-04-03 18:19:55
#
# Scraped 57 users this round
# Got 312 reivews
# 2708 reviews are now in the bag, so to speak
# 2024-04-03 18:21:33
#
# Scraped 57 users this round
# Got 364 reivews
# 3072 reviews are now in the bag, so to speak
# 2024-04-03 18:23:08
#
# Scraped 54 users this round
# Got 353 reivews
# 3425 reviews are now in the bag, so to speak
# 2024-04-03 18:24:44
#
# Scraped 56 users this round
# Got 344 reivews
# 3769 reviews are now in the bag, so to speak
# 2024-04-03 18:26:20
#
# Scraped 55 users this round
# Got 374 reivews
# 4143 reviews are now in the bag, so to speak
# 2024-04-03 18:27:57
#
# Scraped 51 users this round
# Got 335 reivews
# 4478 reviews are now in the bag, so to speak
# 2024-04-03 18:29:29
#
# Scraped 59 users this round
# Got 328 reivews
# 4806 reviews are now in the bag, so to speak
# 2024-04-03 18:31:06
#
# Scraped 59 users this round
# Got 310 reivews
# 5116 reviews are now in the bag, so to speak
# 2024-04-03 18:32:50
#
# Scraped 61 users this round
# Got 355 reivews
# 5471 reviews are now in the bag, so to speak
# 2024-04-03 18:34:32
#
# Scraped 60 users this round
# Got 318 reivews
# 5789 reviews are now in the bag, so to speak
# 2024-04-03 18:36:12
#
# Scraped 57 users this round
# Got 302 reivews
# 6091 reviews are now in the bag, so to speak
# 2024-04-03 18:37:46
#
# Scraped 59 users this round
# Got 330 reivews
# 6421 reviews are now in the bag, so to speak
# 2024-04-03 18:39:37
#
# Scraped 55 users this round
# Got 350 reivews
# 6771 reviews are now in the bag, so to speak
# 2024-04-03 18:41:04
#
# Scraped 54 users this round
# Got 292 reivews
# 7063 reviews are now in the bag, so to speak
# 2024-04-03 18:42:36
#
# Scraped 59 users this round
# Got 378 reivews
# 7441 reviews are now in the bag, so to speak
# 2024-04-03 18:44:22
#
# Scraped 61 users this round
# Got 380 reivews
# 7821 reviews are now in the bag, so to speak
# 2024-04-03 18:46:11
#
# Scraped 57 users this round
# Got 335 reivews
# 8156 reviews are now in the bag, so to speak
# 2024-04-03 18:47:46
#
# Scraped 60 users this round
# Got 354 reivews
# 8510 reviews are now in the bag, so to speak
# 2024-04-03 18:49:41
#
# Scraped 53 users this round
# Got 336 reivews
# 8846 reviews are now in the bag, so to speak
# 2024-04-03 18:51:08
#
# Scraped 53 users this round
# Got 338 reivews
# 9184 reviews are now in the bag, so to speak
# 2024-04-03 18:52:44
#
# Scraped 55 users this round
# Got 323 reivews
# 9507 reviews are now in the bag, so to speak
# 2024-04-03 18:54:18
#
# Scraped 56 users this round
# Got 348 reivews
# 9855 reviews are now in the bag, so to speak
# 2024-04-03 18:55:54
#
# Scraped 56 users this round
# Got 348 reivews
# 10203 reviews are now in the bag, so to speak
# 2024-04-03 18:57:49
#
# Scraped 57 users this round
# Got 397 reivews
# 10600 reviews are now in the bag, so to speak
# 2024-04-03 18:59:29
#
# Scraped 54 users this round
# Got 335 reivews
# 10935 reviews are now in the bag, so to speak
# 2024-04-03 19:00:56
#
# Scraped 51 users this round
# Got 382 reivews
# 11317 reviews are now in the bag, so to speak
# 2024-04-03 19:02:25
#
# Scraped 55 users this round
# Got 354 reivews
# 11671 reviews are now in the bag, so to speak
# 2024-04-03 19:04:06
#
# Scraped 51 users this round
# Got 306 reivews
# 11977 reviews are now in the bag, so to speak
# 2024-04-03 19:05:29
#
# Scraped 54 users this round
# Got 330 reivews
# 12307 reviews are now in the bag, so to speak
# 2024-04-03 19:07:09
#
# Scraped 54 users this round
# Got 343 reivews
# 12650 reviews are now in the bag, so to speak
# 2024-04-03 19:08:47
#
# Scraped 59 users this round
# Got 345 reivews
# 12995 reviews are now in the bag, so to speak
# 2024-04-03 19:10:32
#
# Scraped 53 users this round
# Got 331 reivews
# 13326 reviews are now in the bag, so to speak
# 2024-04-03 19:12:09
#
# Scraped 57 users this round
# Got 323 reivews
# 13649 reviews are now in the bag, so to speak
# 2024-04-03 19:13:56
#
# Scraped 59 users this round
# Got 300 reivews
# 13949 reviews are now in the bag, so to speak
# 2024-04-03 19:15:39
#
# Scraped 58 users this round
# Got 336 reivews
# 14285 reviews are now in the bag, so to speak
# 2024-04-03 19:17:12
#
# Scraped 51 users this round
# Got 347 reivews
# 14632 reviews are now in the bag, so to speak
# 2024-04-03 19:18:36
#
# Scraped 56 users this round
# Got 328 reivews
# 14960 reviews are now in the bag, so to speak
# 2024-04-03 19:20:17
#
# Scraped 57 users this round
# Got 360 reivews
# 15320 reviews are now in the bag, so to speak
# 2024-04-03 19:21:50
#
# Scraped 57 users this round
# Got 338 reivews
# 15658 reviews are now in the bag, so to speak
# 2024-04-03 19:23:25
#
# Scraped 54 users this round
# Got 346 reivews
# 16004 reviews are now in the bag, so to speak
# 2024-04-03 19:24:57
#
# Scraped 56 users this round
# Got 288 reivews
# 16292 reviews are now in the bag, so to speak
# 2024-04-03 19:26:35
#
# Scraped 53 users this round
# Got 309 reivews
# 16601 reviews are now in the bag, so to speak
# 2024-04-03 19:28:03
#
# Scraped 53 users this round
# Got 359 reivews
# 16960 reviews are now in the bag, so to speak
# 2024-04-03 19:29:37
#
# Scraped 55 users this round
# Got 360 reivews
# 17320 reviews are now in the bag, so to speak
# 2024-04-03 19:31:21
#
# Scraped 54 users this round
# Got 307 reivews
# 17627 reviews are now in the bag, so to speak
# 2024-04-03 19:32:59
#
# Scraped 62 users this round
# Got 365 reivews
# 17992 reviews are now in the bag, so to speak
# 2024-04-03 19:34:53
#
# Scraped 54 users this round
# Got 347 reivews
# 18339 reviews are now in the bag, so to speak
# 2024-04-03 19:36:28
#
# Scraped 58 users this round
# Got 326 reivews
# 18665 reviews are now in the bag, so to speak
# 2024-04-03 19:38:12
#
# Scraped 61 users this round
# Got 348 reivews
# 19013 reviews are now in the bag, so to speak
# 2024-04-03 19:39:52
#
# Scraped 56 users this round
# Got 332 reivews
# 19345 reviews are now in the bag, so to speak
# 2024-04-03 19:41:26
#
# Scraped 55 users this round
# Got 354 reivews
# 19699 reviews are now in the bag, so to speak
# 2024-04-03 19:42:56
#
# Scraped 53 users this round
# Got 341 reivews
# 20040 reviews are now in the bag, so to speak
# 2024-04-03 19:44:29
#
# Scraped 54 users this round
# Got 350 reivews
# 20390 reviews are now in the bag, so to speak
# 2024-04-03 19:46:00
#
# Scraped 57 users this round
# Got 373 reivews
# 20763 reviews are now in the bag, so to speak
# 2024-04-03 19:47:37
#
# Scraped 52 users this round
# Got 354 reivews
# 21117 reviews are now in the bag, so to speak
# 2024-04-03 19:49:05
#
# Scraped 55 users this round
# Got 341 reivews
# 21458 reviews are now in the bag, so to speak
# 2024-04-03 19:50:43
#
# Scraped 60 users this round
# Got 329 reivews
# 21787 reviews are now in the bag, so to speak
# 2024-04-03 19:52:27
#
# Scraped 53 users this round
# Got 351 reivews
# 22138 reviews are now in the bag, so to speak
# 2024-04-03 19:54:10
#
# Scraped 57 users this round
# Got 358 reivews
# 22496 reviews are now in the bag, so to speak
# 2024-04-03 19:55:52
#
# Scraped 52 users this round
# Got 310 reivews
# 22806 reviews are now in the bag, so to speak
# 2024-04-03 19:57:24
#
# Scraped 56 users this round
# Got 376 reivews
# 23182 reviews are now in the bag, so to speak
# 2024-04-03 19:58:58
#
# Scraped 52 users this round
# Got 369 reivews
# 23551 reviews are now in the bag, so to speak
# 2024-04-03 20:00:25
#
# Scraped 58 users this round
# Got 346 reivews
# 23897 reviews are now in the bag, so to speak
# 2024-04-03 20:02:07
#
# Scraped 59 users this round
# Got 364 reivews
# 24261 reviews are now in the bag, so to speak
# 2024-04-03 20:03:45
#
# Scraped 56 users this round
# Got 342 reivews
# 24603 reviews are now in the bag, so to speak
# 2024-04-03 20:05:24
#
# Scraped 57 users this round
# Got 369 reivews
# 24972 reviews are now in the bag, so to speak
# 2024-04-03 20:07:14
#
# Scraped 58 users this round
# Got 379 reivews
# 25351 reviews are now in the bag, so to speak
# 2024-04-03 20:09:01
#
# Scraped 57 users this round
# Got 316 reivews
# 25667 reviews are now in the bag, so to speak
# 2024-04-03 20:10:44
#
# Scraped 54 users this round
# Got 296 reivews
# 25963 reviews are now in the bag, so to speak
# 2024-04-03 20:12:13
#
# Scraped 56 users this round
# Got 335 reivews
# 26298 reviews are now in the bag, so to speak
# 2024-04-03 20:13:46
#
# Scraped 53 users this round
# Got 355 reivews
# 26653 reviews are now in the bag, so to speak
# 2024-04-03 20:15:11
#
# Scraped 55 users this round
# Got 353 reivews
# 27006 reviews are now in the bag, so to speak
# 2024-04-03 20:16:53
#
# Scraped 58 users this round
# Got 320 reivews
# 27326 reviews are now in the bag, so to speak
# 2024-04-03 20:18:36
#
# Scraped 55 users this round
# Got 343 reivews
# 27669 reviews are now in the bag, so to speak
# 2024-04-03 20:20:16
#
# Scraped 55 users this round
# Got 341 reivews
# 28010 reviews are now in the bag, so to speak
# 2024-04-03 20:21:45
#
# Scraped 57 users this round
# Got 312 reivews
# 28322 reviews are now in the bag, so to speak
# 2024-04-03 20:23:17
#
# Scraped 60 users this round
# Got 331 reivews
# 28653 reviews are now in the bag, so to speak
# 2024-04-03 20:25:09
#
# Scraped 58 users this round
# Got 315 reivews
# 28968 reviews are now in the bag, so to speak
# 2024-04-03 20:26:48
#
# Scraped 57 users this round
# Got 359 reivews
# 29327 reviews are now in the bag, so to speak
# 2024-04-03 20:28:20
#
# Scraped 56 users this round
# Got 351 reivews
# 29678 reviews are now in the bag, so to speak
# 2024-04-03 20:30:03
#
# Scraped 53 users this round
# Got 350 reivews
# 30028 reviews are now in the bag, so to speak
# 2024-04-03 20:31:30
#
# Scraped 58 users this round
# Got 371 reivews
# 30399 reviews are now in the bag, so to speak
# 2024-04-03 20:33:08
#
# Scraped 58 users this round
# Got 332 reivews
# 30731 reviews are now in the bag, so to speak
# 2024-04-03 20:34:50
#
# Scraped 53 users this round
# Got 310 reivews
# 31041 reviews are now in the bag, so to speak
# 2024-04-03 20:36:21
#
# Scraped 57 users this round
# Got 329 reivews
# 31370 reviews are now in the bag, so to speak
# 2024-04-03 20:38:08
#
# Scraped 56 users this round
# Got 363 reivews
# 31733 reviews are now in the bag, so to speak
# 2024-04-03 20:39:41
#
# Scraped 55 users this round
# Got 326 reivews
# 32059 reviews are now in the bag, so to speak
# 2024-04-03 20:41:14
#
# Scraped 54 users this round
# Got 313 reivews
# 32372 reviews are now in the bag, so to speak
# 2024-04-03 20:42:47
#
# Scraped 53 users this round
# Got 326 reivews
# 32698 reviews are now in the bag, so to speak
# 2024-04-03 20:44:21
#
# Scraped 54 users this round
# Got 376 reivews
# 33074 reviews are now in the bag, so to speak
# 2024-04-03 20:45:59
#
# Scraped 55 users this round
# Got 303 reivews
# 33377 reviews are now in the bag, so to speak
# 2024-04-03 20:47:26
#
# Scraped 60 users this round
# Got 366 reivews
# 33743 reviews are now in the bag, so to speak
# 2024-04-03 20:49:11
#
# Scraped 55 users this round
# Got 345 reivews
# 34088 reviews are now in the bag, so to speak
# 2024-04-03 20:50:46
#
# Scraped 62 users this round
# Got 350 reivews
# 34438 reviews are now in the bag, so to speak
# 2024-04-03 20:52:32
#
# Scraped 54 users this round
# Got 338 reivews
# 34776 reviews are now in the bag, so to speak
# 2024-04-03 20:54:11
#
# Scraped 63 users this round
# Got 302 reivews
# 35078 reviews are now in the bag, so to speak
# 2024-04-03 20:56:05
#
# Scraped 59 users this round
# Got 345 reivews
# 35423 reviews are now in the bag, so to speak
# 2024-04-03 20:57:48
#
# Scraped 57 users this round
# Got 323 reivews
# 35746 reviews are now in the bag, so to speak
# 2024-04-03 20:59:27
#
# Scraped 54 users this round
# Got 347 reivews
# 36093 reviews are now in the bag, so to speak
# 2024-04-03 21:00:54
#
# Scraped 53 users this round
# Got 342 reivews
# 36435 reviews are now in the bag, so to speak
# 2024-04-03 21:02:32
#
# Scraped 57 users this round
# Got 328 reivews
# 36763 reviews are now in the bag, so to speak
# 2024-04-03 21:04:22
#
# Scraped 56 users this round
# Got 357 reivews
# 37120 reviews are now in the bag, so to speak
# 2024-04-03 21:06:09
#
# Scraped 56 users this round
# Got 351 reivews
# 37471 reviews are now in the bag, so to speak
# 2024-04-03 21:07:40
#
# Scraped 54 users this round
# Got 333 reivews
# 37804 reviews are now in the bag, so to speak
# 2024-04-03 21:09:16
#
# Scraped 58 users this round
# Got 351 reivews
# 38155 reviews are now in the bag, so to speak
# 2024-04-03 21:10:59
#
# Scraped 54 users this round
# Got 287 reivews
# 38442 reviews are now in the bag, so to speak
# 2024-04-03 21:12:27
#
# Scraped 57 users this round
# Got 337 reivews
# 38779 reviews are now in the bag, so to speak
# 2024-04-03 21:14:05
#
# Scraped 61 users this round
# Got 324 reivews
# 39103 reviews are now in the bag, so to speak
# 2024-04-03 21:15:53
#
# Scraped 55 users this round
# Got 310 reivews
# 39413 reviews are now in the bag, so to speak
# 2024-04-03 21:17:33
#
# Scraped 54 users this round
# Got 359 reivews
# 39772 reviews are now in the bag, so to speak
# 2024-04-03 21:19:08
#
# Scraped 53 users this round
# Got 344 reivews
# 40116 reviews are now in the bag, so to speak
# 2024-04-03 21:20:41
#
# Scraped 55 users this round
# Got 316 reivews
# 40432 reviews are now in the bag, so to speak
# 2024-04-03 21:22:16
#
# Scraped 58 users this round
# Got 327 reivews
# 40759 reviews are now in the bag, so to speak
# 2024-04-03 21:24:02
#
# Scraped 55 users this round
# Got 334 reivews
# 41093 reviews are now in the bag, so to speak
# 2024-04-03 21:25:40
#
# Scraped 56 users this round
# Got 341 reivews
# 41434 reviews are now in the bag, so to speak
# 2024-04-03 21:27:12
#
# Scraped 59 users this round
# Got 340 reivews
# 41774 reviews are now in the bag, so to speak
# 2024-04-03 21:28:59
#
# Scraped 54 users this round
# Got 384 reivews
# 42158 reviews are now in the bag, so to speak
# 2024-04-03 21:30:44
#
# Scraped 57 users this round
# Got 323 reivews
# 42481 reviews are now in the bag, so to speak
# 2024-04-03 21:32:20
#
# Scraped 58 users this round
# Got 317 reivews
# 42798 reviews are now in the bag, so to speak
# 2024-04-03 21:33:56
#
# Scraped 60 users this round
# Got 353 reivews
# 43151 reviews are now in the bag, so to speak
# 2024-04-03 21:35:47
#
# Scraped 57 users this round
# Got 338 reivews
# 43489 reviews are now in the bag, so to speak
# 2024-04-03 21:37:25
#
# Scraped 58 users this round
# Got 315 reivews
# 43804 reviews are now in the bag, so to speak
# 2024-04-03 21:39:35
#
# Scraped 54 users this round
# Got 344 reivews
# 44148 reviews are now in the bag, so to speak
# 2024-04-03 21:41:12
#
# Scraped 54 users this round
# Got 352 reivews
# 44500 reviews are now in the bag, so to speak
# 2024-04-03 21:42:48
#
# Scraped 57 users this round
# Got 345 reivews
# 44845 reviews are now in the bag, so to speak
# 2024-04-03 21:44:29
#
# Scraped 55 users this round
# Got 391 reivews
# 45236 reviews are now in the bag, so to speak
# 2024-04-03 21:46:04
#
# Scraped 53 users this round
# Got 377 reivews
# 45613 reviews are now in the bag, so to speak
# 2024-04-03 21:47:39
#
# Scraped 54 users this round
# Got 370 reivews
# 45983 reviews are now in the bag, so to speak
# 2024-04-03 21:49:06
#
# Scraped 57 users this round
# Got 366 reivews
# 46349 reviews are now in the bag, so to speak
# 2024-04-03 21:50:46
#
# Scraped 59 users this round
# Got 334 reivews
# 46683 reviews are now in the bag, so to speak
# 2024-04-03 21:52:30
#
# Scraped 53 users this round
# Got 305 reivews
# 46988 reviews are now in the bag, so to speak
# 2024-04-03 21:53:59
#
# Scraped 56 users this round
# Got 358 reivews
# 47346 reviews are now in the bag, so to speak
# 2024-04-03 21:55:47
#
# Scraped 56 users this round
# Got 318 reivews
# 47664 reviews are now in the bag, so to speak
# 2024-04-03 21:57:24
#
# Scraped 62 users this round
# Got 353 reivews
# 48017 reviews are now in the bag, so to speak
# 2024-04-03 21:59:11
#
# Scraped 53 users this round
# Got 373 reivews
# 48390 reviews are now in the bag, so to speak
# 2024-04-03 22:00:48
#
# Scraped 55 users this round
# Got 339 reivews
# 48729 reviews are now in the bag, so to speak
# 2024-04-03 22:02:22
#
# Scraped 57 users this round
# Got 343 reivews
# 49072 reviews are now in the bag, so to speak
# 2024-04-03 22:03:58
#
# Scraped 59 users this round
# Got 338 reivews
# 49410 reviews are now in the bag, so to speak
# 2024-04-03 22:05:48
#
# Scraped 51 users this round
# Got 334 reivews
# 49744 reviews are now in the bag, so to speak
# 2024-04-03 22:07:17
#
# Scraped 58 users this round
# Got 345 reivews
# 50089 reviews are now in the bag, so to speak
# 2024-04-03 22:09:09
#
# Scraped 55 users this round
# Got 354 reivews
# 50443 reviews are now in the bag, so to speak
# 2024-04-03 22:10:44
#
# Scraped 58 users this round
# Got 359 reivews
# 50802 reviews are now in the bag, so to speak
# 2024-04-03 22:12:30
#
# Scraped 57 users this round
# Got 330 reivews
# 51132 reviews are now in the bag, so to speak
# 2024-04-03 22:14:05
#
# Scraped 57 users this round
# Got 331 reivews
# 51463 reviews are now in the bag, so to speak
# 2024-04-03 22:15:45
#
# Scraped 59 users this round
# Got 414 reivews
# 51877 reviews are now in the bag, so to speak
# 2024-04-03 22:17:26
#
# Scraped 53 users this round
# Got 370 reivews
# 52247 reviews are now in the bag, so to speak
# 2024-04-03 22:18:56
#
# Scraped 53 users this round
# Got 324 reivews
# 52571 reviews are now in the bag, so to speak
# 2024-04-03 22:20:25
#
# Scraped 61 users this round
# Got 311 reivews
# 52882 reviews are now in the bag, so to speak
# 2024-04-03 22:22:11
#
# Scraped 59 users this round
# Got 359 reivews
# 53241 reviews are now in the bag, so to speak
# 2024-04-03 22:24:26
#
# Scraped 56 users this round
# Got 352 reivews
# 53593 reviews are now in the bag, so to speak
# 2024-04-03 22:26:45
#
# Scraped 58 users this round
# Got 347 reivews
# 53940 reviews are now in the bag, so to speak
# 2024-04-03 22:29:44
#
# Scraped 52 users this round
# Got 303 reivews
# 54243 reviews are now in the bag, so to speak
# 2024-04-03 22:32:30
#
# Scraped 58 users this round
# Got 320 reivews
# 54563 reviews are now in the bag, so to speak
# 2024-04-03 22:35:35
#
# Scraped 60 users this round
# Got 339 reivews
# 54902 reviews are now in the bag, so to speak
# 2024-04-03 22:38:54
#
# Scraped 60 users this round
# Got 373 reivews
# 55275 reviews are now in the bag, so to speak
# 2024-04-03 22:42:08
#
# Scraped 56 users this round
# Got 341 reivews
# 55616 reviews are now in the bag, so to speak
# 2024-04-03 22:45:16
#
# Scraped 58 users this round
# Got 322 reivews
# 55938 reviews are now in the bag, so to speak
# 2024-04-03 22:48:11
#
# Scraped 55 users this round
# Got 362 reivews
# 56300 reviews are now in the bag, so to speak
# 2024-04-03 22:51:11
#
# Scraped 54 users this round
# Got 388 reivews
# 56688 reviews are now in the bag, so to speak
# 2024-04-03 22:54:00
#
# Scraped 56 users this round
# Got 346 reivews
# 57034 reviews are now in the bag, so to speak
# 2024-04-03 22:57:08
#
# Scraped 56 users this round
# Got 340 reivews
# 57374 reviews are now in the bag, so to speak
# 2024-04-03 23:00:15
#
# Scraped 54 users this round
# Got 317 reivews
# 57691 reviews are now in the bag, so to speak
# 2024-04-03 23:02:49
#
# Scraped 57 users this round
# Got 371 reivews
# 58062 reviews are now in the bag, so to speak
# 2024-04-03 23:05:25
#
# Scraped 58 users this round
# Got 357 reivews
# 58419 reviews are now in the bag, so to speak
# 2024-04-03 23:08:58
#
# Scraped 60 users this round
# Got 362 reivews
# 58781 reviews are now in the bag, so to speak
# 2024-04-03 23:12:32
#
# Scraped 52 users this round
# Got 334 reivews
# 59115 reviews are now in the bag, so to speak
# 2024-04-03 23:14:49
#
# Scraped 58 users this round
# Got 289 reivews
# 59404 reviews are now in the bag, so to speak
# 2024-04-03 23:16:39
#
# Scraped 55 users this round
# Got 335 reivews
# 59739 reviews are now in the bag, so to speak
# 2024-04-03 23:18:24
#
# Scraped 52 users this round
# Got 321 reivews
# 60060 reviews are now in the bag, so to speak
# 2024-04-03 23:19:49
#
# Scraped 54 users this round
# Got 372 reivews
# 60432 reviews are now in the bag, so to speak
# 2024-04-03 23:21:24
#
# Scraped 59 users this round
# Got 320 reivews
# 60752 reviews are now in the bag, so to speak
# 2024-04-03 23:23:08
#
# Scraped 52 users this round
# Got 352 reivews
# 61104 reviews are now in the bag, so to speak
# 2024-04-03 23:24:39
#
# Scraped 53 users this round
# Got 361 reivews
# 61465 reviews are now in the bag, so to speak
# 2024-04-03 23:26:10
#
# Scraped 53 users this round
# Got 356 reivews
# 61821 reviews are now in the bag, so to speak
# 2024-04-03 23:27:41
#
# Scraped 51 users this round
# Got 352 reivews
# 62173 reviews are now in the bag, so to speak
# 2024-04-03 23:29:16
#
# Scraped 54 users this round
# Got 374 reivews
# 62547 reviews are now in the bag, so to speak
# 2024-04-03 23:30:58
#
# Scraped 55 users this round
# Got 352 reivews
# 62899 reviews are now in the bag, so to speak
# 2024-04-03 23:32:33
#
# Scraped 55 users this round
# Got 330 reivews
# 63229 reviews are now in the bag, so to speak
# 2024-04-03 23:34:08
#
# Scraped 56 users this round
# Got 385 reivews
# 63614 reviews are now in the bag, so to speak
# 2024-04-03 23:35:53
#
# Scraped 57 users this round
# Got 327 reivews
# 63941 reviews are now in the bag, so to speak
# 2024-04-03 23:37:31
#
# Scraped 60 users this round
# Got 351 reivews
# 64292 reviews are now in the bag, so to speak
# 2024-04-03 23:39:21
#
# Scraped 57 users this round
# Got 338 reivews
# 64630 reviews are now in the bag, so to speak
# 2024-04-03 23:40:54
#
# Scraped 59 users this round
# Got 347 reivews
# 64977 reviews are now in the bag, so to speak
# 2024-04-03 23:42:37
#
# Scraped 55 users this round
# Got 317 reivews
# 65294 reviews are now in the bag, so to speak
# 2024-04-03 23:44:13
#
# Scraped 55 users this round
# Got 319 reivews
# 65613 reviews are now in the bag, so to speak
# 2024-04-03 23:46:03
#
# Scraped 54 users this round
# Got 342 reivews
# 65955 reviews are now in the bag, so to speak
# 2024-04-03 23:47:28
#
# Scraped 56 users this round
# Got 354 reivews
# 66309 reviews are now in the bag, so to speak
# 2024-04-03 23:49:08
#
# Scraped 55 users this round
# Got 294 reivews
# 66603 reviews are now in the bag, so to speak
# 2024-04-03 23:50:38
#
# Scraped 58 users this round
# Got 392 reivews
# 66995 reviews are now in the bag, so to speak
# 2024-04-03 23:52:22
#
# Scraped 55 users this round
# Got 319 reivews
# 67314 reviews are now in the bag, so to speak
# 2024-04-03 23:53:54
#
# Scraped 53 users this round
# Got 308 reivews
# 67622 reviews are now in the bag, so to speak
# 2024-04-03 23:55:34
#
# Scraped 56 users this round
# Got 304 reivews
# 67926 reviews are now in the bag, so to speak
# 2024-04-03 23:57:11
#
# Scraped 53 users this round
# Got 362 reivews
# 68288 reviews are now in the bag, so to speak
# 2024-04-03 23:58:45
#
# Scraped 54 users this round
# Got 336 reivews
# 68624 reviews are now in the bag, so to speak
# 2024-04-04 00:00:12
#
# Scraped 60 users this round
# Got 321 reivews
# 68945 reviews are now in the bag, so to speak
# 2024-04-04 00:01:55
#
# Scraped 57 users this round
# Got 331 reivews
# 69276 reviews are now in the bag, so to speak
# 2024-04-04 00:03:33
#
# Scraped 59 users this round
# Got 333 reivews
# 69609 reviews are now in the bag, so to speak
# 2024-04-04 00:05:15
#
# Scraped 51 users this round
# Got 357 reivews
# 69966 reviews are now in the bag, so to speak
# 2024-04-04 00:06:38
#
# Scraped 59 users this round
# Got 329 reivews
# 70295 reviews are now in the bag, so to speak
# 2024-04-04 00:08:18
#
# Scraped 63 users this round
# Got 347 reivews
# 70642 reviews are now in the bag, so to speak
# 2024-04-04 00:10:08
#
# Scraped 53 users this round
# Got 350 reivews
# 70992 reviews are now in the bag, so to speak
# 2024-04-04 00:11:44
#
# Scraped 55 users this round
# Got 353 reivews
# 71345 reviews are now in the bag, so to speak
# 2024-04-04 00:13:35
#
# Scraped 58 users this round
# Got 367 reivews
# 71712 reviews are now in the bag, so to speak
# 2024-04-04 00:15:13
#
# Scraped 53 users this round
# Got 351 reivews
# 72063 reviews are now in the bag, so to speak
# 2024-04-04 00:16:38
#
# Scraped 56 users this round
# Got 279 reivews
# 72342 reviews are now in the bag, so to speak
# 2024-04-04 00:18:15
#
# Scraped 57 users this round
# Got 329 reivews
# 72671 reviews are now in the bag, so to speak
# 2024-04-04 00:19:56
#
# Scraped 60 users this round
# Got 290 reivews
# 72961 reviews are now in the bag, so to speak
# 2024-04-04 00:21:36
#
# Scraped 59 users this round
# Got 343 reivews
# 73304 reviews are now in the bag, so to speak
# 2024-04-04 00:23:18
#
# Scraped 60 users this round
# Got 356 reivews
# 73660 reviews are now in the bag, so to speak
# 2024-04-04 00:24:56
#
# Scraped 54 users this round
# Got 379 reivews
# 74039 reviews are now in the bag, so to speak
# 2024-04-04 00:26:30
#
# Scraped 59 users this round
# Got 349 reivews
# 74388 reviews are now in the bag, so to speak
# 2024-04-04 00:28:02
#
# Scraped 57 users this round
# Got 355 reivews
# 74743 reviews are now in the bag, so to speak
# 2024-04-04 00:29:33
#
# Scraped 59 users this round
# Got 313 reivews
# 75056 reviews are now in the bag, so to speak
# 2024-04-04 00:31:02
#
# Scraped 53 users this round
# Got 356 reivews
# 75412 reviews are now in the bag, so to speak
# 2024-04-04 00:32:40
#
# Scraped 56 users this round
# Got 359 reivews
# 75771 reviews are now in the bag, so to speak
# 2024-04-04 00:34:21
#
# Scraped 57 users this round
# Got 362 reivews
# 76133 reviews are now in the bag, so to speak
# 2024-04-04 00:36:07
#
# Scraped 55 users this round
# Got 343 reivews
# 76476 reviews are now in the bag, so to speak
# 2024-04-04 00:37:37
#
# Scraped 59 users this round
# Got 316 reivews
# 76792 reviews are now in the bag, so to speak
# 2024-04-04 00:39:22
#
# Scraped 56 users this round
# Got 334 reivews
# 77126 reviews are now in the bag, so to speak
# 2024-04-04 00:40:55
#
# Scraped 55 users this round
# Got 325 reivews
# 77451 reviews are now in the bag, so to speak
# 2024-04-04 00:42:23
#
# Scraped 54 users this round
# Got 365 reivews
# 77816 reviews are now in the bag, so to speak
# 2024-04-04 00:43:59
#
# Scraped 55 users this round
# Got 361 reivews
# 78177 reviews are now in the bag, so to speak
# 2024-04-04 00:45:35
#
# Scraped 53 users this round
# Got 338 reivews
# 78515 reviews are now in the bag, so to speak
# 2024-04-04 00:47:10
#
# Scraped 55 users this round
# Got 352 reivews
# 78867 reviews are now in the bag, so to speak
# 2024-04-04 00:48:36
#
# Scraped 61 users this round
# Got 315 reivews
# 79182 reviews are now in the bag, so to speak
# 2024-04-04 00:50:12
#
# Scraped 58 users this round
# Got 320 reivews
# 79502 reviews are now in the bag, so to speak
# 2024-04-04 00:51:42
#
# Scraped 54 users this round
# Got 333 reivews
# 79835 reviews are now in the bag, so to speak
# 2024-04-04 00:53:08
#
# Scraped 55 users this round
# Got 365 reivews
# 80200 reviews are now in the bag, so to speak
# 2024-04-04 00:54:50
#
# Scraped 54 users this round
# Got 360 reivews
# 80560 reviews are now in the bag, so to speak
# 2024-04-04 00:56:22
#
# Scraped 53 users this round
# Got 307 reivews
# 80867 reviews are now in the bag, so to speak
# 2024-04-04 00:57:47
#
# Scraped 59 users this round
# Got 328 reivews
# 81195 reviews are now in the bag, so to speak
# 2024-04-04 00:59:25
#
# Scraped 60 users this round
# Got 353 reivews
# 81548 reviews are now in the bag, so to speak
# 2024-04-04 01:01:13
#
# Scraped 55 users this round
# Got 340 reivews
# 81888 reviews are now in the bag, so to speak
# 2024-04-04 01:02:40
#
# Scraped 55 users this round
# Got 336 reivews
# 82224 reviews are now in the bag, so to speak
# 2024-04-04 01:04:10
#
# Scraped 58 users this round
# Got 329 reivews
# 82553 reviews are now in the bag, so to speak
# 2024-04-04 01:05:49
#
# Scraped 57 users this round
# Got 357 reivews
# 82910 reviews are now in the bag, so to speak
# 2024-04-04 01:07:31
#
# Scraped 59 users this round
# Got 362 reivews
# 83272 reviews are now in the bag, so to speak
# 2024-04-04 01:09:11
#
# Scraped 59 users this round
# Got 340 reivews
# 83612 reviews are now in the bag, so to speak
# 2024-04-04 01:10:44
#
# Scraped 56 users this round
# Got 321 reivews
# 83933 reviews are now in the bag, so to speak
# 2024-04-04 01:12:23
#
# Scraped 61 users this round
# Got 323 reivews
# 84256 reviews are now in the bag, so to speak
# 2024-04-04 01:14:13
#
# Scraped 56 users this round
# Got 333 reivews
# 84589 reviews are now in the bag, so to speak
# 2024-04-04 01:15:56
#
# Scraped 57 users this round
# Got 354 reivews
# 84943 reviews are now in the bag, so to speak
# 2024-04-04 01:17:31
#
# Scraped 59 users this round
# Got 331 reivews
# 85274 reviews are now in the bag, so to speak
# 2024-04-04 01:19:26
#
# Scraped 57 users this round
# Got 295 reivews
# 85569 reviews are now in the bag, so to speak
# 2024-04-04 01:21:05
#
# Scraped 57 users this round
# Got 347 reivews
# 85916 reviews are now in the bag, so to speak
# 2024-04-04 01:22:41
#
# Scraped 57 users this round
# Got 286 reivews
# 86202 reviews are now in the bag, so to speak
# 2024-04-04 01:24:24
#
# Scraped 54 users this round
# Got 350 reivews
# 86552 reviews are now in the bag, so to speak
# 2024-04-04 01:25:54
#
# Scraped 55 users this round
# Got 296 reivews
# 86848 reviews are now in the bag, so to speak
# 2024-04-04 01:27:25
#
# Scraped 56 users this round
# Got 350 reivews
# 87198 reviews are now in the bag, so to speak
# 2024-04-04 01:29:04
#
# Scraped 53 users this round
# Got 356 reivews
# 87554 reviews are now in the bag, so to speak
# 2024-04-04 01:30:38
#
# Scraped 61 users this round
# Got 369 reivews
# 87923 reviews are now in the bag, so to speak
# 2024-04-04 01:32:21
#
# Scraped 54 users this round
# Got 376 reivews
# 88299 reviews are now in the bag, so to speak
# 2024-04-04 01:34:02
#
# Scraped 60 users this round
# Got 359 reivews
# 88658 reviews are now in the bag, so to speak
# 2024-04-04 01:35:46
#
# Scraped 54 users this round
# Got 331 reivews
# 88989 reviews are now in the bag, so to speak
# 2024-04-04 01:37:17
#
# Scraped 58 users this round
# Got 363 reivews
# 89352 reviews are now in the bag, so to speak
# 2024-04-04 01:38:58
#
# Scraped 52 users this round
# Got 359 reivews
# 89711 reviews are now in the bag, so to speak
# 2024-04-04 01:40:25
#
# Scraped 55 users this round
# Got 383 reivews
# 90094 reviews are now in the bag, so to speak
# 2024-04-04 01:41:56
#
# Scraped 51 users this round
# Got 324 reivews
# 90418 reviews are now in the bag, so to speak
# 2024-04-04 01:43:15
#
# Scraped 54 users this round
# Got 342 reivews
# 90760 reviews are now in the bag, so to speak
# 2024-04-04 01:45:04
#
# Scraped 55 users this round
# Got 298 reivews
# 91058 reviews are now in the bag, so to speak
# 2024-04-04 01:46:33
#
# Scraped 56 users this round
# Got 346 reivews
# 91404 reviews are now in the bag, so to speak
# 2024-04-04 01:48:00
#
# Scraped 56 users this round
# Got 346 reivews
# 91750 reviews are now in the bag, so to speak
# 2024-04-04 01:49:40
#
# Scraped 55 users this round
# Got 326 reivews
# 92076 reviews are now in the bag, so to speak
# 2024-04-04 01:51:13
#
# Scraped 54 users this round
# Got 368 reivews
# 92444 reviews are now in the bag, so to speak
# 2024-04-04 01:52:45
#
# Scraped 53 users this round
# Got 327 reivews
# 92771 reviews are now in the bag, so to speak
# 2024-04-04 01:54:21
#
# Scraped 57 users this round
# Got 269 reivews
# 93040 reviews are now in the bag, so to speak
# 2024-04-04 01:55:55
#
# Scraped 58 users this round
# Got 346 reivews
# 93386 reviews are now in the bag, so to speak
# 2024-04-04 01:57:32
#
# Scraped 57 users this round
# Got 334 reivews
# 93720 reviews are now in the bag, so to speak
# 2024-04-04 01:59:10
#
# Scraped 57 users this round
# Got 309 reivews
# 94029 reviews are now in the bag, so to speak
# 2024-04-04 02:00:48
#
# Scraped 54 users this round
# Got 288 reivews
# 94317 reviews are now in the bag, so to speak
# 2024-04-04 02:02:11
#
# Scraped 58 users this round
# Got 355 reivews
# 94672 reviews are now in the bag, so to speak
# 2024-04-04 02:03:47
#
# Scraped 59 users this round
# Got 338 reivews
# 95010 reviews are now in the bag, so to speak
# 2024-04-04 02:05:22
#
# Scraped 56 users this round
# Got 365 reivews
# 95375 reviews are now in the bag, so to speak
# 2024-04-04 02:06:47
#
# Scraped 61 users this round
# Got 332 reivews
# 95707 reviews are now in the bag, so to speak
# 2024-04-04 02:08:31
#
# Scraped 58 users this round
# Got 318 reivews
# 96025 reviews are now in the bag, so to speak
# 2024-04-04 02:10:09
#
# Scraped 58 users this round
# Got 359 reivews
# 96384 reviews are now in the bag, so to speak
# 2024-04-04 02:11:44
#
# Scraped 55 users this round
# Got 355 reivews
# 96739 reviews are now in the bag, so to speak
# 2024-04-04 02:13:20
#
# Scraped 54 users this round
# Got 387 reivews
# 97126 reviews are now in the bag, so to speak
# 2024-04-04 02:14:53
#
# Scraped 56 users this round
# Got 336 reivews
# 97462 reviews are now in the bag, so to speak
# 2024-04-04 02:16:25
#
# Scraped 59 users this round
# Got 367 reivews
# 97829 reviews are now in the bag, so to speak
# 2024-04-04 02:18:05
#
# Scraped 60 users this round
# Got 342 reivews
# 98171 reviews are now in the bag, so to speak
# 2024-04-04 02:20:00
#
# Scraped 58 users this round
# Got 302 reivews
# 98473 reviews are now in the bag, so to speak
# 2024-04-04 02:21:32
#
# Scraped 54 users this round
# Got 397 reivews
# 98870 reviews are now in the bag, so to speak
# 2024-04-04 02:23:00
#
# Scraped 54 users this round
# Got 349 reivews
# 99219 reviews are now in the bag, so to speak
# 2024-04-04 02:24:34
#
# Scraped 55 users this round
# Got 346 reivews
# 99565 reviews are now in the bag, so to speak
# 2024-04-04 02:26:10
#
# Scraped 58 users this round
# Got 316 reivews
# 99881 reviews are now in the bag, so to speak
# 2024-04-04 02:27:49
#
# Scraped 57 users this round
# Got 322 reivews
# 100203 reviews are now in the bag, so to speak
# 2024-04-04 02:29:25
#
# Scraped 58 users this round
# Got 354 reivews
# 100557 reviews are now in the bag, so to speak
# 2024-04-04 02:31:02
#
# Scraped 57 users this round
# Got 352 reivews
# 100909 reviews are now in the bag, so to speak
# 2024-04-04 02:32:50
#
# Scraped 54 users this round
# Got 324 reivews
# 101233 reviews are now in the bag, so to speak
# 2024-04-04 02:34:18
#
# Scraped 55 users this round
# Got 317 reivews
# 101550 reviews are now in the bag, so to speak
# 2024-04-04 02:35:57
#
# Scraped 60 users this round
# Got 300 reivews
# 101850 reviews are now in the bag, so to speak
# 2024-04-04 02:37:32
#
# Scraped 56 users this round
# Got 318 reivews
# 102168 reviews are now in the bag, so to speak
# 2024-04-04 02:39:11
#
# Scraped 57 users this round
# Got 359 reivews
# 102527 reviews are now in the bag, so to speak
# 2024-04-04 02:40:51
#
# Scraped 58 users this round
# Got 369 reivews
# 102896 reviews are now in the bag, so to speak
# 2024-04-04 02:42:47
#
# Scraped 55 users this round
# Got 293 reivews
# 103189 reviews are now in the bag, so to speak
# 2024-04-04 02:44:18
#
# Scraped 54 users this round
# Got 321 reivews
# 103510 reviews are now in the bag, so to speak
# 2024-04-04 02:45:43
#
# Scraped 58 users this round
# Got 336 reivews
# 103846 reviews are now in the bag, so to speak
# 2024-04-04 02:47:19
#
# Scraped 55 users this round
# Got 324 reivews
# 104170 reviews are now in the bag, so to speak
# 2024-04-04 02:48:53
#
# Scraped 59 users this round
# Got 364 reivews
# 104534 reviews are now in the bag, so to speak
# 2024-04-04 02:50:44
#
# Scraped 58 users this round
# Got 315 reivews
# 104849 reviews are now in the bag, so to speak
# 2024-04-04 02:52:22
#
# Scraped 56 users this round
# Got 347 reivews
# 105196 reviews are now in the bag, so to speak
# 2024-04-04 02:53:47
#
# Scraped 55 users this round
# Got 352 reivews
# 105548 reviews are now in the bag, so to speak
# 2024-04-04 02:55:20
#
# Scraped 58 users this round
# Got 353 reivews
# 105901 reviews are now in the bag, so to speak
# 2024-04-04 02:56:58
#
# Scraped 59 users this round
# Got 327 reivews
# 106228 reviews are now in the bag, so to speak
# 2024-04-04 02:58:43
#
# Scraped 54 users this round
# Got 353 reivews
# 106581 reviews are now in the bag, so to speak
# 2024-04-04 03:00:26
#
# Scraped 57 users this round
# Got 329 reivews
# 106910 reviews are now in the bag, so to speak
# 2024-04-04 03:01:58
#
# Scraped 58 users this round
# Got 304 reivews
# 107214 reviews are now in the bag, so to speak
# 2024-04-04 03:03:31
#
# Scraped 60 users this round
# Got 368 reivews
# 107582 reviews are now in the bag, so to speak
# 2024-04-04 03:05:20
#
# Scraped 58 users this round
# Got 349 reivews
# 107931 reviews are now in the bag, so to speak
# 2024-04-04 03:06:56
#
# Scraped 56 users this round
# Got 337 reivews
# 108268 reviews are now in the bag, so to speak
# 2024-04-04 03:08:36
#
# Scraped 60 users this round
# Got 313 reivews
# 108581 reviews are now in the bag, so to speak
# 2024-04-04 03:10:16
#
# Scraped 54 users this round
# Got 378 reivews
# 108959 reviews are now in the bag, so to speak
# 2024-04-04 03:11:51
#
# Scraped 54 users this round
# Got 341 reivews
# 109300 reviews are now in the bag, so to speak
# 2024-04-04 03:13:26
#
# Scraped 56 users this round
# Got 368 reivews
# 109668 reviews are now in the bag, so to speak
# 2024-04-04 03:14:59
#
# Scraped 63 users this round
# Got 347 reivews
# 110015 reviews are now in the bag, so to speak
# 2024-04-04 03:16:42
#
# Scraped 54 users this round
# Got 351 reivews
# 110366 reviews are now in the bag, so to speak
# 2024-04-04 03:18:11
#
# Scraped 59 users this round
# Got 321 reivews
# 110687 reviews are now in the bag, so to speak
# 2024-04-04 03:19:49
#
# Scraped 53 users this round
# Got 360 reivews
# 111047 reviews are now in the bag, so to speak
# 2024-04-04 03:21:15
#
# Scraped 57 users this round
# Got 356 reivews
# 111403 reviews are now in the bag, so to speak
# 2024-04-04 03:23:12
#
# Scraped 63 users this round
# Got 297 reivews
# 111700 reviews are now in the bag, so to speak
# 2024-04-04 03:24:47
#
# Scraped 56 users this round
# Got 365 reivews
# 112065 reviews are now in the bag, so to speak
# 2024-04-04 03:26:18
#
# Scraped 53 users this round
# Got 367 reivews
# 112432 reviews are now in the bag, so to speak
# 2024-04-04 03:27:49
#
# Scraped 56 users this round
# Got 311 reivews
# 112743 reviews are now in the bag, so to speak
# 2024-04-04 03:29:11
#
# Scraped 58 users this round
# Got 342 reivews
# 113085 reviews are now in the bag, so to speak
# 2024-04-04 03:30:53
#
# Scraped 58 users this round
# Got 290 reivews
# 113375 reviews are now in the bag, so to speak
# 2024-04-04 03:32:46
#
# Scraped 54 users this round
# Got 301 reivews
# 113676 reviews are now in the bag, so to speak
# 2024-04-04 03:34:18
#
# Scraped 53 users this round
# Got 357 reivews
# 114033 reviews are now in the bag, so to speak
# 2024-04-04 03:35:45
#
# Scraped 62 users this round
# Got 349 reivews
# 114382 reviews are now in the bag, so to speak
# 2024-04-04 03:37:27
#
# Scraped 60 users this round
# Got 300 reivews
# 114682 reviews are now in the bag, so to speak
# 2024-04-04 03:39:05

# %%
# NOTE: USE ONLY ONCE IN HISTORY. Creates the tens_users thingie from the MAIN table.
# NOTE: DELETE CELL BEFORE COPYING NOTEBOOK. 

# orig_table = pq.read_table(f'../data/raw/review_table_combined.parquet')

# users = orig_table.select(['user']).to_pandas()

# orig_table = None

# counts = users.value_counts()

# legits = counts[counts == 10]

# tens_users = set()

# for index, value in legits.items() :
#     tens_users.add(index[0])

# with open(f'../data/raw/tens_users.pkl', 'wb+') as file :
#     pickle.dump(tens_users, file)
