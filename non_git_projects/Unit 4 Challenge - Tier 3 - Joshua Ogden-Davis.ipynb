# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col=0)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# What it look like?
print(properties.shape)
print(properties.head())

# What it do?
print(properties.info())
# Out:
# (342, 48)
#            City of London Barking & Dagenham       Barnet       Bexley  \
# NaT             E09000001          E09000002    E09000003    E09000004
# 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#                   Brent      Bromley       Camden      Croydon       Ealing  \
# NaT           E09000005    E09000006    E09000007    E09000008    E09000009
# 1995-01-01  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 1995-02-01  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 1995-03-01  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 1995-04-01  72965.63094  81124.41227   120097.899  68610.04641  82188.90498
#
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Transpose the DataFrame with a simple expression.
properties_transposed = properties.T

# Check our work!
properties_transposed
# Out:
#                             NaT   1995-01-01   1995-02-01   1995-03-01  \
# City of London        E09000001  91448.98487  82202.77314  79120.70256
# Barking & Dagenham    E09000002   50460.2266  51085.77983  51268.96956
# Barnet                E09000003  93284.51832  93190.16963  92247.52435
# Bexley                E09000004  64958.09036  64787.92069  64367.49344
# Brent                 E09000005  71306.56698  72022.26197  72015.76274
# Bromley               E09000006  81671.47692  81657.55944  81449.31143
# Camden                E09000007  120932.8881  119508.8622  120282.2131
# Croydon               E09000008  69158.16225  68951.09542  68712.44341
# Ealing                E09000009  79885.89069  80897.06551  81379.86288
# Enfield               E09000010  72514.69096  73155.19746  72190.44144
# Greenwich             E09000011  62300.10169  60993.26863  61377.83464
# Hackney               E09000012  61296.52637  63187.08332  63593.29935
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# This seems clunkier than it should be, but it looks infinitely reproducable!
properties_transposed.rename(columns={properties_transposed.columns[0] : "borough_code"}, inplace=True)

# Check, check, check it out
properties_transposed.head()
# Out:
#                    borough_code 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# City of London        E09000001         91448.98487         82202.77314
# Barking & Dagenham    E09000002          50460.2266         51085.77983
# Barnet                E09000003         93284.51832         93190.16963
# Bexley                E09000004         64958.09036         64787.92069
# Brent                 E09000005         71306.56698         72022.26197
#
#                    1995-03-01 00:00:00 1995-04-01 00:00:00  \
# City of London             79120.70256         77101.20804
# Barking & Dagenham         51268.96956         53133.50526
# Barnet                     92247.52435         90762.87492
# Bexley                     64367.49344         64277.66881
# Brent                      72015.76274         72965.63094
#
#                    1995-05-01 00:00:00 1995-06-01 00:00:00  \
# City of London             84409.14932         94900.51244
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# Well I thought it was fine that the borough names were the index...
# But .melt() had other ideas! It drops the index after melting.
# So we'll have to Python a little harder...
properties_transposed.insert(loc=0, column='borough_name', value=properties_transposed.index)

# OK! Now, when we melt things, we can keep the borough names & codes.
properties_melted = properties_transposed.melt(id_vars=['borough_name', 'borough_code'], var_name='month', value_name='avg_house_price')

# Show me what you're working with...
properties_melted
# Out:
#              borough_name borough_code      month avg_house_price
# 0          City of London    E09000001 1995-01-01     91448.98487
# 1      Barking & Dagenham    E09000002 1995-01-01      50460.2266
# 2                  Barnet    E09000003 1995-01-01     93284.51832
# 3                  Bexley    E09000004 1995-01-01     64958.09036
# 4                   Brent    E09000005 1995-01-01     71306.56698
# ...                   ...          ...        ...             ...
# 16363              LONDON    E12000007 2023-05-01          525629
# 16364          SOUTH EAST    E12000008 2023-05-01          388873
# 16365          SOUTH WEST    E12000009 2023-05-01          323765
# 16366         Unnamed: 47          NaN 2023-05-01             NaN
# 16367             England    E92000001 2023-05-01          303557
#
# [16368 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# NOTE: The data set on data.london.gov.uk updated overnight before I finished working on this!
# The update introduced over 500 new instances of unexpected data types, and I had to rewrite this part.
# So I'll do what makes sense here...
# But I can't guarantee it'll still make sense when this is graded.

# Had to do some heavy Googling to find .apply(type).value_counts()...
# And then I did a loop, because who can resist a nice loop?
for col_name in properties_melted.columns :
    print("Data types in ", col_name, ":\n", \
        properties_melted[col_name].apply(type).value_counts(), "\n")
# Out:
# Data types in  borough_name :
#  <class 'str'>    16368
# Name: borough_name, dtype: int64
#
# Data types in  borough_code :
#  <class 'str'>      15345
# <class 'float'>     1023
# Name: borough_code, dtype: int64
#
# Data types in  month :
#  <class 'pandas._libs.tslibs.timestamps.Timestamp'>    16368
# Name: month, dtype: int64
#
# Data types in  avg_house_price :
#  <class 'float'>    15780
# <class 'int'>        588
# Name: avg_house_price, dtype: int64

# %%
# Whoopsie! borough_code and avg_house_price have a lot of off-brand values...
# Let's dig a little deeper!
# Let's start with those floaty values in borough_code...
# I suppose we could dump them all into a new df and take a massive peek.
# First we create the new df...
bad_rows = pd.DataFrame()

# ... then we add every row where "borough_code" is a float.
for index, row in properties_melted.iterrows() :
    if type(row["borough_code"]) == type(1.0) :
        bad_rows = bad_rows.append(row, ignore_index=True)

print(bad_rows)
# Out:
# C:\Users\Josh\AppData\Local\Temp\ipykernel_35212\3784056176.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bad_rows = bad_rows.append(row, ignore_index=True)
#      borough_name  borough_code      month  avg_house_price
# 0     Unnamed: 34           NaN 1995-01-01              NaN
# 1     Unnamed: 37           NaN 1995-01-01              NaN
# 2     Unnamed: 47           NaN 1995-01-01              NaN
# 3     Unnamed: 34           NaN 1995-02-01              NaN
# 4     Unnamed: 37           NaN 1995-02-01              NaN
# ...           ...           ...        ...              ...
# 1018  Unnamed: 37           NaN 2023-04-01              NaN
# 1019  Unnamed: 47           NaN 2023-04-01              NaN
# 1020  Unnamed: 34           NaN 2023-05-01              NaN
# 1021  Unnamed: 37           NaN 2023-05-01              NaN
# ...

# %%
# Ah! The floats are actually NaN values, and they seem to happen at regular intervals!
# What's up with that??? Let me use my human eyes to see...
print(properties_melted.iloc[30:50])
# Out:
#           borough_name borough_code      month avg_house_price
# 30      Waltham Forest    E09000031 1995-01-01     61319.44913
# 31          Wandsworth    E09000032 1995-01-01     88559.04381
# 32         Westminster    E09000033 1995-01-01     133025.2772
# 33         Unnamed: 34          NaN 1995-01-01             NaN
# 34        Inner London    E13000001 1995-01-01      78251.9765
# 35        Outer London    E13000002 1995-01-01     72958.79836
# 36         Unnamed: 37          NaN 1995-01-01             NaN
# 37          NORTH EAST    E12000001 1995-01-01     42076.35411
# 38          NORTH WEST    E12000002 1995-01-01     43958.48001
# 39  YORKS & THE HUMBER    E12000003 1995-01-01     44803.42878
# 40       EAST MIDLANDS    E12000004 1995-01-01     45544.52227
# 41       WEST MIDLANDS    E12000005 1995-01-01     48527.52339
# 42     EAST OF ENGLAND    E12000006 1995-01-01      56701.5961
# 43              LONDON    E12000007 1995-01-01     74435.76052
# ...

# %%
# It looks like there are 4 different kinds of data in this set:
# data by borough, data by inner/outer London, and data by larger region, and England.
# The rows between these kinds of data are left "blank,"
# which accounts for the NaN values, which are floats because Pandas.

# Now let's check on those rogue ints in the avg_house_price column...
# Yay! A loop! Hooray!
bad_rows = pd.DataFrame()

for index, row in properties_melted.iterrows() :
    if type(row["avg_house_price"]) == type(1) :
        bad_rows = bad_rows.append(row, ignore_index=True)

print(bad_rows)

# Huh. Looks like the numbers just ended up with no decimal sometimes.
# It's unlikely that this happened by chance. They must have collected/recorded data differently
# on some years. Anyway, this is the level of specificity we have, so it's the one we'll use!
# Onward!
# Out:
# C:\Users\Josh\AppData\Local\Temp\ipykernel_35212\4062468283.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bad_rows = bad_rows.append(row, ignore_index=True)
#              borough_name borough_code      month  avg_house_price
# 0    Richmond upon Thames    E09000027 1995-04-01           106875
# 1    Kensington & Chelsea    E09000020 2007-10-01           808270
# 2                  LONDON    E12000007 2010-01-01           279724
# 3          City of London    E09000001 2022-05-01           795936
# 4      Barking & Dagenham    E09000002 2022-05-01           336137
# ..                    ...          ...        ...              ...
# 583       EAST OF ENGLAND    E12000006 2023-05-01           345710
# 584                LONDON    E12000007 2023-05-01           525629
# 585            SOUTH EAST    E12000008 2023-05-01           388873
# ...

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# NOTE: WHILE THERE ARE TECHNICALLY ONLY 32 BOROUGHS IN LONDON, "CITY OF LONDON" IS
# AN ADMINISTRATIVE AREA WITHIN LONDON THAT IS EXTREMELY SIMILAR TO A BOROUGH.
# THUS I WILL TREAT IT LIKE A BOROUGH FOR THE REMAINDER OF THE EXERCISE, MAKING
# THE TOTAL NUMBER OF "BOROUGHS" TO BE 33.

# I already know that there's more than just borough data here,
# so we're going to see more than just the borough names & codes in those columns.
# But let's make sure that there are no unexpected values there anyway...
boroughs_column_basic_values_set = set(properties_melted.iloc[0:48, 0])

all_boroughs_column_values = set(properties_melted["borough_name"])

unusual_borough_values = set(all_boroughs_column_values)

for value in all_boroughs_column_values :
    if value in boroughs_column_basic_values_set :
        unusual_borough_values.remove(value)

print(unusual_borough_values)
# Out:
# set()

# %%
# A billion lines of code later, I can now confirm that there are no unexpected values.
# Might as well see if the number of empty-ish entries lines up across columns...
print(properties_melted.isna().sum())
# Out:
# borough_name          0
# borough_code       1023
# month                 0
# avg_house_price    1023
# dtype: int64

# %%
# It does. So if I wanted to make an ass of you and me, I'd assume that the values
# are missing on the same rows. But, having walked to the edge of such madness,
# I shall now retreat to safer and more pedantic waters.

# The problem, simply put:
# If any column has empty values for borough_name AND borough_code
# AND avg_house_price, then it's useless and can be dropped.
# First, let's make some bools...
bool_frame = properties_melted.isna()

# Second: safety!
properties_melted_cleaned = properties_melted.copy()

# Third: loooop!
for index, row in properties_melted_cleaned.iterrows() :
    if bool_frame.loc[index, "borough_code"] and bool_frame.loc[index, "avg_house_price"] \
        and "Unnamed" in properties_melted_cleaned.loc[index, "borough_name"]:
        properties_melted_cleaned.drop(index, inplace=True)

# Let's check...
print(properties_melted_cleaned.isna().sum())
# Out:
# borough_name       0
# borough_code       0
# month              0
# avg_house_price    0
# dtype: int64

# %%
# Hooray.

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# Let's look at one of the boroughs with one of those cool British names.
# In one "line", we can identify the set of rows we want to look at, then
# use .plot() to create the visual.
properties_melted_cleaned[properties_melted_cleaned["borough_name"] == "Richmond upon Thames"] \
    .plot(x="month", y="avg_house_price", \
          xlabel="Year", ylabel="Average House Price", \
          title="Housing Prices over Time in Richmond upon Thames")

plt.show()

# %%
# Absolutely shocked that I got it on the first try.

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# If we're only looking for the greatest increase on average over the last 2 decades,
# then we only need 2 data points per borough (20 years ago and right now), so I'm not
# sure what this step accomplishes. But hey, we're here to learn!

# ...Speaking of which...
#  Why did you suggest lambda when there's literally a built-in method for this exaaaact situation???
properties_melted_cleaned["year"] = properties_melted_cleaned["month"].dt.year

# Check...
properties_melted_cleaned.head()
# Out:
#          borough_name borough_code      month avg_house_price  year
# 0      City of London    E09000001 1995-01-01     91448.98487  1995
# 1  Barking & Dagenham    E09000002 1995-01-01      50460.2266  1995
# 2              Barnet    E09000003 1995-01-01     93284.51832  1995
# 3              Bexley    E09000004 1995-01-01     64958.09036  1995
# 4               Brent    E09000005 1995-01-01     71306.56698  1995

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def dfg(borough, show_values=False) :
    # Returns the ratio of average house price in "borough" between 1998 and 2018.
    # If "show_values" is True, the relevant values will also be printed.
    # 
    # First, calculate the average price in 1998.
    # We could do it all in one line, but for readability's sake, let's just segment first.
    # By which I mean, let's make a df with only the rows for that borough in that year.
    borough_1998_rows = properties_melted_cleaned[(properties_melted_cleaned["borough_name"] == borough) \
                                                 & (properties_melted_cleaned["year"] == 1998)]
    
    # Now we take the average of all the prices in that period and divide by the sample size...
    borough_1998_price_sum = borough_1998_rows["avg_house_price"].sum()
    price_1998 = borough_1998_price_sum / len(borough_1998_rows)

    # Once more, with more 2018 feeling:
    borough_2018_rows = properties_melted_cleaned[(properties_melted_cleaned["borough_name"] == borough) \
                                           & (properties_melted_cleaned["year"] == 2018)]
    borough_2018_price_sum = borough_2018_rows["avg_house_price"].sum()
    price_2018 = borough_2018_price_sum / len(borough_2018_rows)

    # Then, ratio them like it's Twitter.
    ratio = price_2018 / price_1998

    # Pentultimately, tell the people what you know! Optionally, of course.
    # By which I mean, this only prints if the show_values kwarg is set to True.
    if show_values :
        print("Borough: ", borough)
        print("Avg price in 1998: ", price_1998)
        print("Avg price in 2018: ", price_2018)
        print("Ratio: ", ratio)

    # Ultimately, tell the computer what you know.
    return ratio

# Test it, and...
dfg("England")
# Out:
# 3.8104529783974

# %%
# WTF??? It worked on the second try?????
# OK, let's do the whole dang thing, then...

# Am I really saving any time by making a set to keep from referencing the df on every iteration of the loop?
all_boroughs = set(properties_melted_cleaned["borough_name"])

# Now we LOOOOOOOOOOOP!
# By which I mean, for each borough, make a tuple consisting of the borough name and its ratio.
# Then put them in a list.
results_list = []
for borough in all_boroughs :
    results_list.append((borough, dfg(borough)))

# Now let's order the list by ratio so we can easily find the nth most ratio'd borough
results_list.sort(key=lambda x: x[1], reverse=True)

# Aaaand we can print it in a human-friendly way.
for item in results_list :
    print(item[0], "=", round(item[1], 2))
# Out:
# Hackney = 6.2
# Waltham Forest = 5.83
# Southwark = 5.52
# Lewisham = 5.45
# Westminster = 5.35
# Newham = 5.31
# City of London = 5.3
# Inner London = 5.17
# Haringey = 5.13
# Kensington & Chelsea = 5.08
# Lambeth = 4.96
# Camden = 4.94
# Barking & Dagenham = 4.9
# Brent = 4.89
# Islington = 4.84
# Greenwich = 4.76
# Wandsworth = 4.76
# Merton = 4.74
# LONDON = 4.68
# Tower Hamlets = 4.63
# Redbridge = 4.47
# Outer London = 4.42
# Barnet = 4.36
# Havering = 4.33
# Ealing = 4.31
# Kingston upon Thames = 4.27
# Enfield = 4.26
# Bexley = 4.25
# Croydon = 4.2
# Hillingdon = 4.2
# EAST OF ENGLAND = 4.17
# Hammersmith & Fulham = 4.14
# Sutton = 4.12
# Bromley = 4.09
# Harrow = 4.06
# Richmond upon Thames = 4.01
# Hounslow = 3.98
# SOUTH EAST = 3.83
# England = 3.81
# SOUTH WEST = 3.8
# EAST MIDLANDS = 3.63
# NORTH WEST = 3.36
# YORKS & THE HUMBER = 3.36
# WEST MIDLANDS = 3.31
# NORTH EAST = 2.83

# %%
# Now that I'm looking at the list, I'm realizing a couple things.

# FIRST, I don't like that the regional data is in there. The question
# was about boroughs, so let's clean up our df to have only that relevant
# information. I don't want to lose the info entirely, though, because
# it might be useful for an in-depth analysis of the problem behind the problem.

# The "codes" for boroughs all have 0 in the second slot, so let's filter based on that.
properties_regional = pd.DataFrame()

for index, row in properties_melted_cleaned.iterrows() :
    if row[1][1] != str(0):
        properties_regional = properties_regional.append(row, ignore_index=True)
        properties_melted_cleaned.drop(index, inplace=True)

# We've also already created a "results_list" that contains regional data, so
# we can clean up/separate that out as well.
# First we make a set of only borough names from our newly updated df...
boroughs_only = set(properties_melted_cleaned["borough_name"])

# Then we double-comprehend to make a new list and remove regional values from the old one.
results_list_regions = [item for item in results_list if (item[0] in boroughs_only) == False]
results_list = [item for item in results_list if item[0] in boroughs_only]

# Let's just check to make sure that all worked...

print(set(properties_melted_cleaned["borough_name"]))
print(results_list)
# Out:
# C:\Users\Josh\AppData\Local\Temp\ipykernel_35212\624327539.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   properties_regional = properties_regional.append(row, ignore_index=True)
# C:\Users\Josh\AppData\Local\Temp\ipykernel_35212\624327539.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   properties_regional = properties_regional.append(row, ignore_index=True)
# C:\Users\Josh\AppData\Local\Temp\ipykernel_35212\624327539.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   properties_regional = properties_regional.append(row, ignore_index=True)
# ...

# %%
# SECOND, the problem behind the problem：
# The result they wanted was to determine "desirability," but the
# only metric they asked for was the ratio of avg price from 1998-2018.
# This ratio alone doesn't actually tell me anything useful.

# For example, a super cheap place that went up A LOT might still be a cheap dump.
# Or, a borough may have much higher prices in 2018, but could potentially have
# peaked in 2015 and is entering an undesirable nosedive now.

# What does "desirable" mean, anyway?
# Desirable for whomst?
# Desirable in whatst way? 

# I think I'm overthinking this, but I will play with it a little bit,
# because education. And by "play with it," I mean I will make a new dataframe
# that includes more useful columns that could assist with more granular analyses.

# This dataframe, I shall call:
housing_analysis_1998_2018 = pd.DataFrame()

# First, obvs, let's get all our boroughs & ratios in there, since that's easy-peasy with our existing list.
unzipped_results_list = list(zip(*results_list))
housing_analysis_1998_2018["Borough"] = unzipped_results_list[0]
housing_analysis_1998_2018["1998-2019 Ratio"] = unzipped_results_list[1]

# Another thing that would be interesting to know is the starting & ending average prices.
# We calculated them before, of course, but I was still too blindly trusting of the
# instructions to save the values at that point. Foolish!
# Well, I shall be a fool no longer. I'm about to throw those vauge instructions... for a LOOP!
# This will produce a list of the average 1998 prices per borough, in the same order as our
# existing df. 
average_1998_prices = list()
for borough in unzipped_results_list[0] :
    borough_1998_rows = properties_melted_cleaned[(properties_melted_cleaned["borough_name"] == borough) \
                                                  & (properties_melted_cleaned["year"] == 1998)]
    borough_1998_price_sum = borough_1998_rows["avg_house_price"].sum()
    price_1998 = borough_1998_price_sum / len(borough_1998_rows)
    average_1998_prices.append(price_1998)

# Again! AGAIN!!!
average_2018_prices = list()
for borough in unzipped_results_list[0] :
    borough_2018_rows = properties_melted_cleaned[(properties_melted_cleaned["borough_name"] == borough) \
                                                  & (properties_melted_cleaned["year"] == 2018)]
    borough_2018_price_sum = borough_2018_rows["avg_house_price"].sum()
    price_2018 = borough_2018_price_sum / len(borough_2018_rows)
    average_2018_prices.append(price_2018)

# Now we add these lists into our df as columns.
housing_analysis_1998_2018["1998 Avg Price"] = average_1998_prices
housing_analysis_1998_2018["2018 Avg Price"] = average_2018_prices

# IMHO this dataframe is much better suited to our original question.
# Let's take another peek at the data as it now stands...
print(housing_analysis_1998_2018.describe(), "\n")
print(housing_analysis_1998_2018.corr())
# Out:
#        1998-2019 Ratio  1998 Avg Price  2018 Avg Price
# count        33.000000       33.000000    3.300000e+01
# mean          4.716235   113204.904504    5.334155e+05
# std           0.571489    41876.380765    2.159243e+05
# min           3.976409    60285.821083    2.951967e+05
# 25%           4.248977    88143.228830    3.966317e+05
# 50%           4.741273   100692.590417    4.800505e+05
# 75%           5.082465   122359.468033    5.515606e+05
# max           6.198286   268350.122142    1.363880e+06
#
#                  1998-2019 Ratio  1998 Avg Price  2018 Avg Price
# 1998-2019 Ratio         1.000000       -0.020918        0.258846
# 1998 Avg Price         -0.020918        1.000000        0.956565
# 2018 Avg Price          0.258846        0.956565        1.000000
# ...

# %%
# Now let's see how the top 5 ratio'd boroughs look in comparison to the
# rest of the market (specifically, we can judge them against the output
# from .describe(). For readability, I'll do that one again here.)
print(housing_analysis_1998_2018.describe(), "\n")

# Now we print the info for the top 5 boroughs for comparison.
for i in range(5):
    print(housing_analysis_1998_2018.iloc[i], "\n")
# Out:
#        1998-2019 Ratio  1998 Avg Price  2018 Avg Price
# count        33.000000       33.000000    3.300000e+01
# mean          4.716235   113204.904504    5.334155e+05
# std           0.571489    41876.380765    2.159243e+05
# min           3.976409    60285.821083    2.951967e+05
# 25%           4.248977    88143.228830    3.966317e+05
# 50%           4.741273   100692.590417    4.800505e+05
# 75%           5.082465   122359.468033    5.515606e+05
# max           6.198286   268350.122142    1.363880e+06
#
# Borough                  Hackney
# 1998-2019 Ratio         6.198286
# 1998 Avg Price      87869.535804
# 2018 Avg Price     544640.475027
# Name: 0, dtype: object
#
# Borough            Waltham Forest
# 1998-2019 Ratio          5.834756
# 1998 Avg Price       75557.474132
# 2018 Avg Price      440859.411128
# Name: 1, dtype: object
#
# Borough                Southwark
# 1998-2019 Ratio         5.516485
# 1998 Avg Price      91405.187779
# 2018 Avg Price     504235.374945
# ...

# %%
# We can even take a look at the trends ourselves, if we want!
# Let's look at charts for the top 5 ratios...

# Since we're going to have to pull the data in a loop, let's
# set up our list...
list_of_arrays = []

# Now we loop, adding the relevant values to our list of arrays.
for i in range(5) :
    borough = results_list[i][0]
    new_array = properties_melted_cleaned.loc[properties_melted_cleaned["borough_name"] == borough, "avg_house_price"].to_numpy()
    list_of_arrays.append(new_array)

# Now we start building our plot! Starting with the x axis.
date_range_for_plot = properties_melted_cleaned.loc[properties_melted_cleaned["borough_name"] == borough, "month"].to_numpy()

# Now we put in our y values, one at a time, from the list we created above.
for i in range(5) :
    plt.plot(date_range_for_plot, list_of_arrays[i], label=results_list[i][0])

# Then we pretty it up and show!
plt.xlabel("Year")
plt.ylabel("Average House Price (Million Pounds)")
plt.title("Housing Costs Over Time for the 5 Top Ratio Boroughs")
plt.legend()

# %%
list_of_arrays = []

# Now we loop, adding the relevant values to our list of arrays.
for i in range(33) :
    borough = results_list[i][0]
    new_array = properties_melted_cleaned.loc[properties_melted_cleaned["borough_name"] == borough, "avg_house_price"].to_numpy()
    list_of_arrays.append(new_array)

# Now we start building our plot! Starting with the x axis.
# We only want one set of the dates, so we can get that by taking
# all the dates from one borough. Elegant? Probably not.
date_range_for_plot = properties_melted_cleaned.loc[properties_melted_cleaned["borough_name"] == borough, "month"].to_numpy()

# Now we put in our y values, one borough at a time, from the list we created above.
for i in range(33) :
    plt.plot(date_range_for_plot, list_of_arrays[i], label=results_list[i][0])

# Then we pretty it up and show!
plt.xlabel("Year")
plt.ylabel("Average House Price (Million Pounds)")
plt.title("Housing Costs Over Time for the All Boroughs")
plt.show()

# %%
housing_analysis_1998_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Borough          33 non-null     object
#  1   1998-2019 Ratio  33 non-null     float64
#  2   1998 Avg Price   33 non-null     float64
#  3   2018 Avg Price   33 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.2+ KB

# %%
def line_chart_1998_2018(borough) :
    properties_melted_cleaned[properties_melted_cleaned["borough_name"] == borough] \
        .plot(x="month", y="avg_house_price", \
              xlabel="Year", ylabel="Average House Price (Million Pounds)")
    plt.title(f"Average House Price Over Time in {borough}")
    print(housing_analysis_1998_2018[housing_analysis_1998_2018["Borough"] == borough])
    plt.ylim(0, 1600000)
    plt.show()
    return

# %%
line_chart_1998_2018("Kensington & Chelsea")
# Out:
#                 Borough  1998-2019 Ratio  1998 Avg Price  2018 Avg Price
# 8  Kensington & Chelsea         5.082465   268350.122142    1.363880e+06

# %%
line_chart_1998_2018(housing_analysis_1998_2018_by_2018_cost.iloc[0, 0])
# Out:
#                 Borough  1998-2019 Ratio  1998 Avg Price  2018 Avg Price
# 8  Kensington & Chelsea         5.082465   268350.122142    1.363880e+06

# %%
housing_analysis_1998_2018_by_2018_cost = housing_analysis_1998_2018.sort_values("2018 Avg Price", ascending=False)
print(housing_analysis_1998_2018_by_2018_cost[0:5])
# Out:
#                  Borough  1998-2019 Ratio  1998 Avg Price  2018 Avg Price
# 8   Kensington & Chelsea         5.082465   268350.122142    1.363880e+06
# 4            Westminster         5.353565   190531.949942    1.020025e+06
# 10                Camden         4.935353   170688.973933    8.424104e+05
# 6         City of London         5.301620   148031.894542    7.848089e+05
# 27  Hammersmith & Fulham         4.137798   175340.921250    7.255253e+05

# %%
# Sweet heavens above, I'd better just submit this assignment before I spend
# the next 7 months on it alone...

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ANSWER:
#
# By finding a dataset online, cleaning it up, and re-formatting it for easier processing,
# we can rather easily find the borough with the highest 1998-2018 house price ratio.
#
# It's Hackney, btw.
#
# However, I'm not sure this means anything useful. The stated objective was to determine
# "desirability," but the only metric asked for was the ratio, and I don't think the ratio
# sufficiently determines desirability.
#
# For example, Hackney's mean price in 2018 is just barely above the mean for all boroughs,
# and the borough with the second-highest ratio (Waltham Forest) is roughtly two standard
# deviations below the mean house price. Only looking at the "ratio" will give a false
# sense of similarity between two clearly very different boroughs.
#
# In fact, the definition of desirability will change depending on the audience. With this
# in mind, I re-transformed the data into a new DataFrame that should make it easier to look
# at relevant metrics and create new metrics. Hopefully this DataFrame would help different
# groups of buyers find the borough that is right for them.
#
# It's also worth noting that the overall ratio from 1998-2018 does not account for more
# granular trends. As we can see from the line chart, the borough with the 5th highest
# ratio (Westminster) may be in a downslide since about 2016, which is something that's
# extremely relevant to investors but completely ignored by our 1998-2018 metric.
#
# Were I to continue the analysis, I would take the following steps:
#
# 1. Include data on inflation rates by year. A 5% price increase is a -1% gain if
#    inflation is at 6%. Talk about undesirable!
#
# 2. Expand the df to include columns w/ratios on smaller time intervals, so that we can
#    get a view of how the rate of change itself is changing, which can help us
#    estimate a near-future trend. This data would be most useful for investors
#    who are just looking for the best ROI over a certain time period.
#
# 3. Separate the boroughs into groups based on the current house price, so that
#    personal homebuyers looking for a primary residence (aka, not investors)
#    can identify the boroughs with the best potential ROI that are still within
#    their price range, OR identify boroughs with relatively stable cost over time
#    in the event that they are concerned with controlling their property taxes.
#
# 4. Look for correlations between housing prices and other data. Getting tunnel vision
#    on one statistic leaves you completely unprepared when something else that is not in
#    your dataset, like trends in zoning laws or planned future developments, stands to
#    exert significant influence on your data.
