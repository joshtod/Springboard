# %% [markdown]
# ### Preprocessing
#
# Uses the following data:
# 1. games_df, a table of general information about (almost) all Steam games
# 2. review_table, a table of 6+million reviews scraped from the Steam store, listing the user, game, etc
# 3. recently_played_df, a table of users' recently played games with playtimes
#
# Accomplishes the following:
# 1. Generate tables containing vectors for every game and every user. Our inputs will be limited to items in this table.
# 2. Generate reduced tables containing vectors of only the games and users that have rich enough info to be useful for prediction.

# %%
import pandas as pd
import numpy as np

from bidict import bidict

import pickle
import pyarrow as pa
import pyarrow.parquet as pq


import scipy.sparse as sp
from scipy.sparse import coo_matrix, csr_matrix, lil_matrix, save_npz

# %store -r tags_dict

# %%
# Load

with open('../data/interim/1 - Games DF - Wrangled.pkl', 'rb') as file :
    games_df = pickle.load(file)

review_table = pq.read_table('../data/interim/cleaned_reviews.parquet')

with open('../data/interim/recently_played_cleaned.pkl', 'rb') as file :
    recently_played_df = pickle.load(file)

# %% [markdown]
# ### Make games vectors/matrices
#
# We'll produce one matrix with all known games. This will be used to vectorize input.
#
# Then we'll produce a matrix that contains only those games with sufficient information to be subjects of recommendation.

# %%
# Isolate the info we'll use for the vectors
games_df_tags_only = games_df[['app_id', 'tags', 'tag_list']]
games_df_tags_only.head()
# Out:
#     app_id                                               tags  \
# 0      730  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1   553850  [Action, Online Co-Op, Multiplayer, Third-Pers...
# 2  1086940  [RPG, Choices Matter, Story Rich, Character Cu...
# 3  1245620  [Souls-like, Dark Fantasy, Open World, RPG, Di...
# 4  1623730  [Multiplayer, Open World, Survival, Creature C...
#
#                                             tag_list
# 0  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1  [Action, Online Co-Op, Third-Person Shooter, M...
# 2  [RPG, Choices Matter, Story Rich, Character Cu...
# 3  [Souls-like, Dark Fantasy, Open World, RPG, Di...
# 4  [Multiplayer, Open World, Survival, Creature C...

# %%
# Make a handy dict for the app_ids and their new indexes
game_to_full_index = bidict()
for index, row in games_df_tags_only.iterrows() :
    game_to_full_index[index] = row['app_id']
game_to_full_index = game_to_full_index.inverse

# %%
# Get our list of columns
used_tags = set(tags_dict.values())

# %%
# Prepare our sparse matrix
# NOTE: We will weight PRIMARY tags more strongly than non-primary tags.
# A lower weight_ratio favors primary tags more.

weight_ratio = 0.8

matrix_values = []

for index, row in games_df_tags_only.iterrows() :
    skips = set()
    for tag in row['tags'] :
        skips.add(tag)
        tup = (index, tag, 1)
        matrix_values.append(tup)
    for tag in row['tag_list'] :
        if tag not in skips :
                    tup = (index, tag, weight_ratio)
                    matrix_values.append(tup)

matrix_values[0]
# Out:
# (0, 'FPS', 1)

# %%
# To make the matrix, we must index our tags.
tag_to_col_index = bidict()
i = 0
for value in tags_dict.values() :
    tag_to_col_index[value] = i
    i += 1

# %%
# Make the matrix

rows = [row[0] for row in matrix_values]
columns = [tag_to_col_index[row[1]] for row in matrix_values]
values = [row[2] for row in matrix_values]

matrix_row_count = max(rows)+1
matrix_col_count = max(columns)+1

game_tags_matrix = coo_matrix((values, (rows, columns)), shape=(matrix_row_count, matrix_col_count))
game_tags_matrix = csr_matrix(game_tags_matrix)

# %%
# Good job, everybody! Let's save it and move on.
save_npz('../data/processed/full_game_tag_matrix.npz', game_tags_matrix)

# And also the index dicts.
with open('../data/processed/tag_to_col_index.pkl', "wb") as file :
    pickle.dump(tag_to_col_index, file)

with open('../data/processed/game_to_full_index.pkl', "wb") as file :
    pickle.dump(game_to_full_index, file)

# %% [markdown]
# Now we subset this matrix to include only games with 10+ tags.
#
# This index will be smaller, but we must be careful to note the original index values. That's the only way we can relate the rows in this matrix to any other matrix.

# %%
nonzero_counts = pd.Series(game_tags_matrix.getnnz(axis=1))
can_keep = nonzero_counts >= 10
game_tags_matrix_reduced = game_tags_matrix[can_keep]

## This creates a dict with:
##  KEYS == reduced matrix index
##  VALUES == corresponding full matrix index
game_reduced_index_to_full_index = bidict()
i=0
for index, value in can_keep.items() :
    if value==True :
        game_reduced_index_to_full_index[i]=index
        i += 1

# %%
# Save! That! Matrix!
save_npz('../data/processed/reduced_game_tag_matrix.npz', game_tags_matrix_reduced)

# And the dict, of course.
with open('../data/processed/game_reduced_index_to_full_index.pkl', 'wb') as file :
    pickle.dump(game_reduced_index_to_full_index, file)

# %% [markdown]
# ### Now we make the users matrices...

# %%
recently_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4181501 entries, 0 to 4181500
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user         object
#  1   app_id       int64
#  2   playtime_2w  int64
#  3   playtime_f   int64
# dtypes: int64(3), object(1)
# memory usage: 127.6+ MB

# %%
review_table.shape
# Out:
# (6747619, 11)

# %%
# Because our games_df does not contain every single game on Steam, it's possible
# that a game will be touched in a review or recently_played about which we cannot
# make inference.
# Let's make a set of all usable games to help limit our tables to legal values.
usable_app_ids = set(games_df['app_id'].values)
len(usable_app_ids)
# Out:
# 100892

# %%
# Now let's reduce the above datasets to only those which touch usable games.
recently_played_df = recently_played_df[recently_played_df['app_id'].isin(usable_app_ids)].reset_index(drop=True)
recently_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3593525 entries, 0 to 3593524
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user         object
#  1   app_id       int64
#  2   playtime_2w  int64
#  3   playtime_f   int64
# dtypes: int64(3), object(1)
# memory usage: 109.7+ MB

# %%
# To subset the review_talbe, we'll have to pandacize it first.

review_df = review_table.to_pandas()
review_df = review_df[review_df['app_id'].isin(usable_app_ids)].reset_index(drop=True)
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5726093 entries, 0 to 5726092
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user             object
#  1   app_id           int64
#  2   positive         int64
#  3   total_playtime   float64
#  4   review_playtime  float64
#  5   text             object
#  6   helpful_count    int64
#  7   review_date      object
#  8   edit_date        object
#  9   date_scraped     object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 436.9+ MB

# %%
# We should save processed versions of these for use in the modeling notebook.
usable_review_table = pa.Table.from_pandas(review_df)
pq.write_table(usable_review_table, '../data/processed/usable_review_table.parquet')

with open('../data/processed/usable_recently_played.pkl', 'wb') as file :
    pickle.dump(recently_played_df, file)

# %%
# The two tables above contain different but overlapping sets of users.
# In order to combine them into a single users matrix, we must first create
# a unified index for all touched users.

recently_users = set(recently_played_df['user'].values)
review_users = set(review_table['user'].to_pylist())
touched_users = recently_users | review_users

user_to_full_index = bidict()
i=0
for user in touched_users :
    user_to_full_index[user] = i
    i+=1

# %%
# We also need a unified index for games.

recently_games =set(recently_played_df['app_id'].values)
review_games = set(review_table['app_id'].to_pylist())
touched_games = recently_games | review_games

game_to_col_index = bidict()
i=0
for game in touched_games :
    game_to_col_index[game] = i
    i+=1

# %%
# Now let's prepare our points.

recently_played_points = recently_played_df.apply( \
                                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], 0.2), axis=1) \
                                .tolist()

# %%
# Since we'll have to update this matrix in a sec, let's make it a lil_matrix first.

user_info_matrix = lil_matrix((len(touched_users), len(touched_games)), dtype=float)

for point in recently_played_points :
    user_info_matrix[point[0], point[1]] = point[2]

# %%
# Now let's prepare the review data to update that matrix.

positive_reviews = review_df[review_df['positive']==1][['user', 'app_id']]
negative_reviews = review_df[review_df['positive']==0][['user', 'app_id']]

positive_points = positive_reviews.apply( \
                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], 1), axis=1) \
                .tolist()
                                
negative_points = negative_reviews.apply( \
                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], -1), axis=1) \
                .tolist()

# %%
## Now, we update the matrix.

for point in positive_points :
    user_info_matrix[point[0], point[1]] = point[2]

for point in negative_points :
    user_info_matrix[point[0], point[1]] = point[2]

# %%
## Just for funsies, make it the same format as our games matrix.
user_info_matrix = user_info_matrix.tocsr()

# %%
# Save! That! Matrix!
save_npz('../data/processed/user_info_matrix.npz', user_info_matrix)

# And the dicts, of course.
with open('../data/processed/user_to_full_index.pkl', 'wb') as file :
    pickle.dump(user_to_full_index, file)

with open('../data/processed/game_to_col_index.pkl', 'wb') as file :
    pickle.dump(game_to_col_index, file)

# %%
# Now we create a subset of the matrix that contains only users with enough info for prediction.
# Where should we put the threshold?

nonzero_counts = pd.Series(user_info_matrix.getnnz(axis=1))
nonzero_counts.describe()
# Out:
# count    1.887354e+06
# mean     4.779766e+00
# std      7.041132e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      6.000000e+00
# max      5.517000e+03
# dtype: float64

# %%
# I'll arbitrarily choose 5. Sue me! I dare you.

can_keep = nonzero_counts >= 5
user_info_matrix_reduced = user_info_matrix[can_keep]

## This creates a dict with:
##  KEYS == reduced matrix index
##  VALUES == corresponding full matrix index

user_reduced_index_to_full_index = bidict()
i=0
for index, value in can_keep.items() :
    if value==True :
        user_reduced_index_to_full_index[i]=index
        i += 1

# %%
# Save! That! Matrix!
save_npz('../data/processed/user_info_matrix_reduced.npz', user_info_matrix_reduced)

# etc etc
with open('../data/processed/user_reduced_index_to_full_index.pkl', 'wb') as file :
    pickle.dump(user_reduced_index_to_full_index, file)

# %% [markdown]
# At time of inference, the top X consine similarity users' rows will be called up, and the most common games not already played by the user will be recommended.

# %% [markdown]
# # Modeling
#
# Describes a system for taking a single user_id as an input and generating game recommendations.

# %%
from scipy import stats

from scipy.sparse import load_npz
from sklearn.metrics.pairwise import cosine_similarity

from bayes_opt import BayesianOptimization

import time
import random

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
# Load the dfs to display the rec results in a human-readable way
with open('../data/interim/1 - Games DF - Wrangled.pkl', 'rb') as file :
    games_df = pickle.load(file)
with open('../data/processed/usable_recently_played.pkl', 'rb') as file :
    recently_played_df = pickle.load(file)
review_table = pq.read_table('../data/processed/usable_review_table.parquet')
with open('../data/raw/all_users', 'rb') as file :
    all_users = pickle.load(file)

# Load the tables used to define input
game_tags_matrix = load_npz('../data/processed/full_game_tag_matrix.npz')
user_info_matrix = load_npz('../data/processed/user_info_matrix.npz')

# Load the tables used for inference
game_tags_matrix_reduced = load_npz('../data/processed/reduced_game_tag_matrix.npz')
user_info_matrix_reduced = load_npz('../data/processed/user_info_matrix_reduced.npz')

# Load the index converters for the games/tags matrix
with open('../data/processed/tag_to_col_index.pkl', "rb") as file :
    tag_to_col_index = pickle.load(file)
with open('../data/processed/game_reduced_index_to_full_index.pkl', 'rb') as file :
    game_reduced_index_to_full_index = pickle.load(file)
with open('../data/processed/game_to_full_index.pkl', 'rb') as file :
    game_to_full_index = pickle.load(file)

# Load the index converters for the users/games matrix
with open('../data/processed/user_to_full_index.pkl', 'rb') as file :
    user_to_full_index = pickle.load(file)
with open('../data/processed/game_to_col_index.pkl', 'rb') as file :
    game_to_col_index = pickle.load(file)
with open('../data/processed/user_reduced_index_to_full_index.pkl', 'rb') as file :
    user_reduced_index_to_full_index = pickle.load(file)

# %% [markdown]
# ## Define the functions

# %% [markdown]
# ### Collaborative recommendations, step 1: find similar users

# %%
# Get an arbitrary number of similar users
def get_similar_users(target_user_row, similar_user_limit=50, test_user_indices=[], testing=False, verbose=False) :
    """
    Takes a user id and returns a sorted descending series of the X most similar users:
        keys = user index (in the reduced matrix)
        values = cosine similarity
    Rows that have played no games that the target user hasn't also played are removed,*
    as they have no novel info for prediction.
    """

    # Go ahead and run cosine similarity now, so that the scores can be associated with the correct index (the reduced user matrix index).
    row_cosine_similarities = pd.Series(cosine_similarity(target_user_row, user_info_matrix_reduced)[0], name="similarity_score")

    # If we're testing, remove all test users from this step
    if testing==True :
        for index in row_cosine_similarities.index :
            if index in test_user_indices :
                row_cosine_similarities = row_cosine_similarities.drop(index)

    # Remove the 1s.
    # This eliminates any user whose play profile is identical to that of the target user,
    # meaning they would be useless for prediction.
    # Also removes the target user.
    row_cosine_similarities = row_cosine_similarities[row_cosine_similarities < 1]

    row_cosine_similarities.sort_values(ascending=False, inplace=True)
    most_similar_users = row_cosine_similarities[:similar_user_limit]

    if verbose==True :
        print(f"Top {similar_user_limit} most similar users:")
        for index, value in most_similar_users.items() :
            print(f"{round(value, 9)} -- {index}")
            
    return(most_similar_users)

# %% [markdown]
# ### Collaborative recommendations, step 2: generate scores

# %%
# Generate suggestions based on that.
# First, find out all the games these "similar users" have played.
# Then, weight those playes by the similarity score, then sum them across users.

# NOTE：I could speed all this up by just using arrays instead of rows/columns


def get_collab_scores(similar_users, collab_filter_limit=50, target_user_touched_games=[], verbose=False) :
    """
    Takes a series in the format:
        keys: user index (in the reduced matrix)
        values: similarity score to target user (float)

    Looks at all those users' games, calculates a utility score for their played games
    based on the group's collective utility score for those games.

    Returns a series of len {collab_filter_limit} in the format:
        keys: app_id
        values: collab filter score
    """

    # We need to make a column in a df for each game, so we grab all games
    # here (indexed by game col index).
    # We remove any games already touched by the target user along the way.
    relevant_games = set()
    for user in similar_users.keys() :
        for game in user_info_matrix[user].indices :
            if game not in target_user_touched_games :
                relevant_games.add(game)
    
    similar_users_df = pd.DataFrame(index=similar_users.index)

    # Create a column for each game
    for game in relevant_games :
        similar_users_df[game] = 0

    # Now fill those columns with the scores
    for user in similar_users.keys() :
        for game in user_info_matrix[user].indices :
            similar_users_df.loc[user, game] = user_info_matrix_reduced[user, game]

    # Some games have an outlier number of comments, which makes them ALWAYS appear
    # in the collab recs list.
    # This bit of code counteracts that by multiplying each value in each game's col
    # by the inverse log of the sum of the col.
    # Needlessly complex? Maybe. But the motivation behind nerfing the *individual*
    # values in the df instead of just nerfing the games at the end is because 
    # nerfing them at the end (using log) will also nerf the effect of the similarity
    # score, which I don't want.
    # So, finding a way to modify the individual game preference scores before applying
    # the similarity score to the column sums seems preferable.

    # To do this, we can't have negative values. Even zeroes are untrustworthy.
    # Increasing the values here does not skew the overall results, since the
    # results will be normalized.
    # minimum = np.nanmin(similar_users_df.values)

    # if minimum < 0 :
    #     similar_users_df = similar_users_df - (minimum - 1.0001)
    # else :
    #     similar_users_df = similar_users_df + 1.0001

    # for col in similar_users_df.columns :
    #     col_sum = similar_users_df[col].sum()
    #     col_coef = 1/np.log(col_sum ** 1.3)
    #     similar_users_df[col] = similar_users_df[col] * col_coef
    # NOTE: This code just isn't having the desired result! A new approach is needed.
    # Maybe just identify any outliers, and nerf that column iff they appear??? dxdx

    # TODO: Alternatively, consider applying this step while compiling the matrices...!

    # Now multiply the scores by the similarity score
    for user, row in similar_users_df.iterrows() :
        for game in relevant_games :
            if row[game] != 0 :
                similar_users_df.loc[user, game] = similar_users[user] * row[game]

    # Now collect those scores
    # NOTE: CONVERTS FROM GAME COL INDEX BACK TO APP_ID AT THIS STEP
    collab_filt_rec_scores = {}
    for game in relevant_games:
        collab_filt_rec_scores[game_to_col_index.inverse[game]] = similar_users_df[game].sum()

    collab_filt_scores = pd.Series(collab_filt_rec_scores, name="collab_rec_score").sort_values(ascending=False)

    # Limit the output
    collab_filt_scores = collab_filt_scores[:collab_filter_limit]
    
    # Normalize
    collab_filt_scores = stats.zscore(collab_filt_scores.astype(float))

    # To make them interactible with later scores, let's standardize them
    # scaler = MinMaxScaler()
    # collab_filt_scores = pd.Series(scaler.fit_transform(collab_filt_rec_scores.values.reshape(-1,1)).flatten(), index=collab_filt_rec_scores.index)
    # if verbose==True :
    #     for app_id, score in collab_filt_scores.items() :
    #         print(f"{round(score, 3)} -- {games_df[games_df['app_id']==app_id]['title'].values[0]}")
    
    return collab_filt_scores

# %% [markdown]
# ### Content-based recommendations

# %%
# NOTE: STRETCH GOAL: Determine multimodality, generate different lists of scores

# %%
# Determine most similar games for each, multiply by user preference, MinMaxScale.

def get_content_scores(target_user_row, content_filter_limit, verbose=False) :

    """
    Takes a row from the users/games table, then does the following:
        1. Finds recs for each from the reduced game/tags matrix
        2. Creates a descending-sorted 10-row Series:
            keys = game's index (relative to main games_df)
            values = queried game's cosine similarity score to the queried game
        3. Weights all values in the series by the user's preference for the game
        4. Combines all resulting series into a single series with sim scores summed
        5. Returns the series
    """

    # Get the most recent games.
    # I already have the games in terms of col indices in the users matrix.
    # I need the indices for the games matrix, to do cos similarity.

    # Go from game col index to app_id
    # played_game_app_ids = [game_to_col_index.inverse[game] for game in target_user_row.indices]
    # # Go from app_id to full game row index
    # played_game_full_matrix_row_indices = [game_to_full_index[game] for game in played_game_app_ids]

    # Find the sim scores for each game, adding them to the main list
    similarity_series_list = []
    full_row_indexes = []

    for query_index in target_user_row.indices :

        # Get the reduced game/tags matrix index
        current_app_id = game_to_col_index.inverse[query_index] 
        current_full_row_index = game_to_full_index[current_app_id]
        try :
            reduced_row_index = game_reduced_index_to_full_index.inverse[current_full_row_index]
        except :
            ####
            continue 

        # Let's grab the full row index. We will later use this to remove
        # already-touched games from the recommendations.
        full_row_indexes.append(current_full_row_index)

        # Find the similarity score between games
        # The resulting series is indexed by the reduced games matrix
        row_cosine_similarities = pd.Series(cosine_similarity(game_tags_matrix[current_full_row_index], game_tags_matrix_reduced)[0])
        # Reindex the predictions back to the full game matrix index
        row_cosine_similarities.index = [game_reduced_index_to_full_index[index] for index in row_cosine_similarities.index]
        row_cosine_similarities.sort_values(ascending=False, inplace=True)
        # Since we cannot know ahead of time how many games the user has touched,
        # and the user may have only touched one game,
        # we can safely limit the results here to the overall content filter limit.
        # This will ensure that the full number of scores are returned no matter 
        # how many games were touched. 
        # This is still indexed by the full game matrix.
        top_similar = row_cosine_similarities[:content_filter_limit]

        # Now, get a coefficient to represent the user's preference for the game in question.
        # All games similar to this game will be modified by this coefficient.
        # First we find the game's column in the full user matrix
        preference_coefficient = target_user_row[0, query_index]
        # Then we just multiply.
        top_similar = top_similar * preference_coefficient

        # That's all we need for the score! Let's append.
        similarity_series_list.append(top_similar)

        # if verbose == True :
        #     print(f"Recs for {games_df.loc[current_full_row_index]['title']}:")
        #     for rec in top_similar.items() :
        #         print(f"{round(rec[1], 3)} -- {games_df.loc[rec[0]]['title']}")

    # Combine the serieses into the main series.
    # Here it's still indexed by full game matrix index.
    final_scores = pd.Series()
    for similarity_series in similarity_series_list :
        final_scores = final_scores.add(similarity_series, fill_value=0)
    final_scores = final_scores.sort_values(ascending=False)

    # Remove already-played games from the main series
    for game in full_row_indexes :
        try :
            final_scores = final_scores.drop(labels=game)
        except :
            continue

    # Normalize the series to make it similar to the collaborative score series
    # I suppose the original values were some wonky kind of float that didn't work
    # with scipy, so we coerce them here.
    content_filt_scores = stats.zscore(final_scores.astype(float))

    # Return the desired number of values
    if len(content_filt_scores) < content_filter_limit :
        content_filter_limit = len(content_filt_scores)
    content_filt_scores = content_filt_scores[:content_filter_limit]

    # Set index to app_id
    content_filt_scores.index = [game_to_full_index.inverse[game] for game in content_filt_scores.index]

    # if verbose == True :
    #     print('------------------')
    #     for game, score in content_filt_scores.items() :
    #         print(f"{round(score, 3)} -- {games_df[games_df['app_id']==game]['title'].values[0]}")     
    
    return(content_filt_scores)

# %% [markdown]
# ### Combine the recs for final set of recs

# %%
# NOTE: Is it worth checking the scale discrepancy between the two and tweaking the ratio
# programmatically for each distribution?

# It may be that tweaking the relative weights of the collaborative and content-based filter results
# can improve accuracy. Let's define this as a function so we can play with that programmatically
# later, if need be.

def combine_scores(collaborative, content_based, double_bonus=0, popular_bias=0, ratio=0.5, recs=10) :
    """
    Takes a series of collaborative filtering scores (key=app_id, value=score)
    And a series of content based filtering scores with the same schema
    And a 0-1 ratio of importance between the two (higher ratio favors collaborative scores)
    And the "double_bonus", which is multiplied/summed to the score of each game that appears in both lists
    And a "popular_bias" which is multiplied to the pos_review_percent and added to the score
    And the number of recommendations to be returned

    Returns a series of game app_ids and recommendation scores
    """

    # Define the ratio-modified scores
    collaborative = collaborative * ratio
    content_based = content_based * (1-ratio)

    # Add them into the base final scores series
    final_recs = collaborative.add(content_based, fill_value=0)

    # Apply doubles bonus, if any
    doubles = []
    for game in collaborative.index :
        if game in content_based.index :
            doubles.append(game)
    for game in doubles :
        final_recs[game] += (final_recs[game] * double_bonus)

    # Apply popularity bonus, if any
    for index in final_recs.index :
        positive_review_percent = games_df[games_df['app_id']==index]['positive_review_percent'].values[0]
        final_recs[index] += (positive_review_percent * popular_bias)

    # Sort descending
    final_recs = final_recs.sort_values(ascending=False)

    # Determine length
    if len(final_recs) < recs :
        recs = len(final_recs)
    
    # Determine final recs
    final_recs = final_recs[:recs]

    return final_recs

# %% [markdown]
# ### Create unified function

# %%
def get_recs(user, similar_user_limit=50, collab_filter_limit=50, content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, recs=10, test_user_indices=[], test_user_rows=[], testing=False, verbose=False, show_result=False) :

    """
    Takes a user via full user matrix index
    Generates a series of recommendations
    
    """

    # Let's-a-go!
    begin = time.time()

    # Grab some useful info about the target user
    if testing==True :
        # target_user_id = user_reduced_index_to_full_index.inverse[game_reduced_index_to_full_index[user]]
        target_user_row = test_user_rows[test_user_indices.index(user)]
        # print(target_user_row)
    else :
        # target_user_id = user_to_full_index.inverse[user]
        target_user_row = user_info_matrix[user]

    target_user_touched_games = set(target_user_row.indices)

    # Display some stuff
    if show_result==True or verbose==True :
        print("------ User profile:")
        for game in target_user_touched_games :
            app_id = game_to_col_index.inverse[game]
            score = target_user_row[0, game]
            print(f"{score} - {games_df[games_df['app_id']==app_id]['title'].values[0]}")
        print("--------------------")

    # Get similar users
    most_similar_users = get_similar_users(target_user_row, similar_user_limit=similar_user_limit, test_user_indices=test_user_indices, testing=testing, verbose=False)
    if verbose==True :
        print("\nTop 5 most similar users\n")
        print(most_similar_users.head())
        print("--------------------------")

    # Print the params here to make it easier to intuit what's happening in the results
    if verbose==True :
        print(f"similar_user_limit: {similar_user_limit}")
        print(f"collab_filter_limit: {collab_filter_limit}")
        print(f"content_filter_limit: {content_filter_limit}")
        print(f"double_bonus: {round(double_bonus, 3)}")
        print(f"popular_bias: {round(popular_bias, 3)}")
        print(f"ratio col/con: {round(ratio, 3)}")
        print(f"num of recs: {recs}\n")

    # Get scores from them
    collab_filt_scores = get_collab_scores(most_similar_users, collab_filter_limit=collab_filter_limit, target_user_touched_games=target_user_touched_games, verbose=False)
    if verbose==True :
        print("Top 8 collab filt scores")
        for index, item in collab_filt_scores.head(8).items() :
            print(f"{round(item, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------------")

    # Get content filtering scores
    content_filt_scores = get_content_scores(target_user_row, content_filter_limit=content_filter_limit,  verbose=False)
    if verbose==True :
        print("Top 8 content filt scores")
        for index, item in content_filt_scores.head(8).items() :
            print(f"{round(item, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------------")
    
    # Calculate final scores
    final_recs = combine_scores(collab_filt_scores, content_filt_scores, double_bonus=double_bonus, popular_bias=popular_bias, ratio=ratio, recs=recs)

    if show_result==True or verbose==True:
        print('')
        print('------ Recommendations')
        for index, score in final_recs.items() :
            print(f"{round(score, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------")
        print(f"\nRuntime: {round(time.time()-begin, 2)}s\n")

    return final_recs

# %% [markdown]
# ## Execution!

# %%
# NOTE: Commented out so that running the notebook skips directly to testing/evaluation

# params = {
#     "similar_user_limit":50,
#     "collab_filter_limit":50,
#     "content_filter_limit":50,
#     "double_bonus":2,
#     "popular_bias":3,
#     "ratio":0.2,
#     "recs":20,
#     "verbose":False,
#     "show_result": True
# }

# recs = get_recs(50, **params)

# %% [markdown]
# ### Testing
#
# The basic idea is to remove a game or games from a user's profile (preferably a user with a significant number of touched games) and see if the engine recommends that game for the modified user profile.

# %%
# Programmatically assemble a set of usable user profiles (10+ touched games)

def get_test_users(user_count=50, minimum_games=10) :
    """
    Returns user_count number of test users (reduced user matrix index) as a list
    Each user must have at least minimum_games number of touched games and disliked at least one game
    """
    
    # VARS
    test_user_indices = []
    checked_indices = set()
    total_users = user_info_matrix_reduced.shape[0]

    while len(test_user_indices) < user_count :
        # Find a user at random
        index = random.randint(1, total_users)
        # Make sure you haven't done this one before
        if index not in checked_indices :
            # Make sure the user has enough games
            if len(user_info_matrix_reduced[index].indices) >= minimum_games :
                # Make sure they dislike at least one game
                if -1 in user_info_matrix_reduced[index].data :
                    # Log 'em!
                    test_user_indices.append(index)
        # Log 'em!
        checked_indices.add(index)
    
    return test_user_indices

# %%
# Randomly remove one or more game(s) from each, and save as a list of rows.

def create_test_rows(test_user_indices) :
    """
    Takes a list of reduced user matrix indices (test users)
    Returns 3 items:
    1. A list of those users' rows with the most- and least- liked games removed
    2. A list of those users' most-liked games (in matching index order)
    3. A list of those users' least-liked games (in matching index order)
    """

    test_rows = []
    liked_games = []
    disliked_games = []

    for test_user in test_user_indices :
        current_row = user_info_matrix_reduced[test_user]

        # Pick a game they LIKED VERY MUCH to remove
        liked_game = np.argmax(current_row.data)

        # Pick a game they HATED to remove.
        # It's possible that all values are positive, in which case this variable will
        # have no meaning. We will check that at the evaluation phase.
        # For now, we'll pull the value no matter what to perserve index relationships.
        disliked_game = np.argmin(current_row.data)

        # Save the values for evaluation
        liked = (test_user, current_row.indices[liked_game], current_row.data[liked_game])
        liked_games.append(liked)
        disliked = (test_user, current_row.indices[disliked_game], current_row.data[disliked_game])
        disliked_games.append(disliked)

        # Remove the values

        lil_row = current_row.tolil()
        lil_row[0, liked[1]] = 0
        lil_row[0, disliked[1]] = 0
        current_row = lil_row.tocsr()
        current_row.eliminate_zeros()

        # Add it to the list
        test_rows.append(current_row)
        
    return test_rows, liked_games, disliked_games

# %%
# Evaluation function

# Checks to see if POSITIVE game is in top X recs: +
# Checks to see if NEGATIVE game is in recs at all: -

# TODO: Reframe the holder lists as a series, where the game is the index, values are empty lists, 1 and -1 are added to the list where applicable
#   This will allow us to more easily see which users are best served, and how often we propose positive AND negative games to the same user

def binary_evaluator(results, verbose=False, show_result=False) :
    """"
    Takes a list of tuples with the schema:
        1. Series of recommendations (key=app_id, value=utility score)
        2. app_id of favorite game
        3. app_id of least favorite game

    Evaluates the recommendations in each tuple by:
        Adding 1 to the overall score if the favorite game is recommended
        Subtracting 1 from the overall score if the least favorite game is recommended
    
    Returns the score as an int
    """

    good = []
    bad = []

    for result in results :
        # Grab the series of recommendations
        recs = result[0].index
        # See if we recommended the liked game, and score accordingly
        if result[1] in recs :
            good.append(1)
        # See if we recommended the disliked game, and score accordingly
        if result[2] in recs :
            bad.append(1)
    
    validated = sum(good)
    disproved = sum(bad)
    score = validated - disproved

    print(f"Validated recommendations: {validated}")
    print(f"Disproved recommendations: {disproved}")

    return score

# %%
# Another evaluation function

# If a POSITIVE game is in the recs, add the utility score to the score (so higher ranking = higher score)
# If a NEGATIVE game is in the recs, subtract (same as above) (for same reason)

def ranked_evaluator(results, verbose=False, show_result=True) :
    """"
    Takes a list of tuples with the schema:
        1. Series of recommendations (key=app_id, value=utility score)
        2. app_id of favorite game
        3. app_id of least favorite game

    Evaluates the recommendations in each tuple by:
        Adding the inverse rank of the positive game if it's included in the recs
        Subtracting the inverse rank of the negative game if it's included in the recs
    
    Returns the score as an int
    """

    good = []
    bad = []

    score = 0
    user = 0

    for result in results :
        # Grab the series of recommendations
        recs = result[0].index
        # See if we recommended the liked game, and score accordingly
        if result[1] in recs :
            # Get the ranking (since it's as an index, it starts from 0 and needs a little boost to prevent 1/0)
            ranking = recs.get_loc(result[1]) + 1
            good.append((user, ranking))
            score += 1/ranking
        # See if we recommended the disliked game, and score accordingly
        if result[2] in recs :
            # Samesies, except we neg it
            ranking = recs.get_loc(result[2]) + 1
            bad.append((user, ranking))
            score -= 1/ranking
        user += 1 
    
    # validated = sum(good)
    # disproved = sum(bad)
    # score = validated - disproved

    if show_result == True :
        print(f"Positives: {len(good)}")
        print(f"Negatives: {len(bad)}")
        print(f"Score: {score}")
        print(f"\n---\nGood: \n{good}")
        print(f"\n---\nBad: \n{bad}")

    # print(f"Validated recommendations: {validated}")
    # print(f"Disproved recommendations: {disproved}")

    return score

# %%
# Run inference on each modified profile


def run_a_test(test_users=50, evaluator=ranked_evaluator, similar_user_limit=50, collab_filter_limit=50, \
               content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, recs=10, \
               testing=True, verbose=False, show_result=False) :
    
    global results

    # Generate X test user indices
    test_user_indices = get_test_users(test_users)

    test_rows, liked_games, disliked_games = create_test_rows(test_user_indices)

    # test_user_full_indices = [user_reduced_index_to_full_index[user] for user in test_user_indices]
    results = []

    params = {
        "test_user_indices":test_user_indices,
        "test_user_rows":test_rows,
        "similar_user_limit":similar_user_limit,
        "collab_filter_limit":collab_filter_limit,
        "content_filter_limit":content_filter_limit,
        "double_bonus":double_bonus,
        "popular_bias":popular_bias,
        "ratio":ratio,
        "recs":recs,
        "verbose":verbose,
        "show_result":show_result,
        "testing":testing
        }

    for i in range(len(test_user_indices)) :
        result = get_recs(test_user_indices[i], **params)
        results.append((result, \
                        game_to_col_index.inverse[liked_games[i][1]], \
                        game_to_col_index.inverse[disliked_games[i][1]]))
        
    score = evaluator(results, verbose=verbose, show_result=show_result)

    return score

# %%
# NOTE: Commented out so that running the notebook skips directly to testing/evaluation
minimums = []
col_sums=[]
test_params = {
    "test_users":1,
    "evaluator":ranked_evaluator,
    "similar_user_limit":50,
    "collab_filter_limit":20,
    "content_filter_limit":10,
    "double_bonus":1.79,
    "popular_bias":0,
    "ratio":0.71,
    "recs":20,
    "testing":True,
    "verbose":True,
    "show_result":True
}

run_a_test(**test_params)
# Out:
# ------ User profile:
# -1.0 - Overwatch® 2
# 1.0 - MORDHAU
# -1.0 - Brawlhalla
# 1.0 - Conan Exiles
# 1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Bean Battles
# -1.0 - PlanetSide 2
# 1.0 - HELLDIVERS™ 2
# 1.0 - Battlefield 4™
# -1.0 - Red Dead Online
# 1.0 - Max Payne 3
# 1.0 - Vampire Survivors
# 1.0 - Among Us
# 1.0 - CRSED: F.O.A.D.
# 1.0 - Garry's Mod
# --------------------
#
# Top 5 most similar users
#
# 97243     0.438529
# 138125    0.425596
# 155504    0.390360
# 221531    0.390130
# 344787    0.386501
# Name: similarity_score, dtype: float64
# --------------------------
# similar_user_limit: 50
# collab_filter_limit: 20
# content_filter_limit: 10
# double_bonus: 1.79
# popular_bias: 0
# ratio col/con: 0.71
# num of recs: 20
#
# Top 8 collab filt scores
# 3.136 -- Counter-Strike 2
# 2.799 -- Team Fortress 2
# 0.265 -- Dota 2
# -0.365 -- Caliber
# -0.365 -- Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# -0.365 -- Warface: Clutch
# -0.365 -- Bloons TD 6
# -0.365 -- PAYDAY 2
# --------------------------
# Top 8 content filt scores
# 1.784 -- Realm Royale Reforged
# 1.092 -- Polygon Bit Battle Royale
# 1.022 -- Super Fantasy Kingdom
# 0.848 -- Imposters: Countdown
# 0.818 -- Purrfect Survivors
# 0.817 -- SUS
# 0.814 -- Renfield: Bring Your Own Blood
# 0.814 -- Call of Duty®: Modern Warfare® 2 (2009)
# --------------------------
#
# ------ Recommendations
# 2.227 -- Counter-Strike 2
# 1.987 -- Team Fortress 2
# 0.517 -- Realm Royale Reforged
# 0.246 -- Imposters: Countdown
# 0.236 -- Renfield: Bring Your Own Blood
# 0.236 -- Call of Duty®: Modern Warfare® 2 (2009)
# 0.228 -- Witchcraft Survivors
# 0.188 -- Dota 2
# -0.066 -- Battlefield 3™
# -0.259 -- Caliber
# -0.259 -- Sea of Thieves 2023 Edition
# -0.259 -- Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# -0.259 -- Endless Dark
# -0.259 -- Starfield
# -0.259 -- PAYDAY 2
# -0.259 -- Halo Infinite
# -0.259 -- Apex Legends™
# -0.259 -- Undertale
# -0.259 -- Destiny 2
# -0.259 -- Bloons TD 6
# --------------------
#
# Runtime: 1.99s
#
# Positives: 0
# Negatives: 1
# Score: -1.0
#
# ---
# Good:
# []
#
# ---
# Bad:
# [(0, 1)]
# -1.0

# %% [markdown]
# ### O   P   T   I   M   I   Z   E

# %%
def boptimize(test_users=50, evaluator=ranked_evaluator, n_iter=4, init_points=10, verbose=False, show_result=False) :
    
    # We'll define our test set here, so the Bayesian bit below will
    # execute on the same subset each time.

    # Generate X test user indices
    test_user_indices = get_test_users(test_users)

    # Generate test rows
    test_rows, liked_games, disliked_games = create_test_rows(test_user_indices)


    # Define the scoring function within the main function so that it has native access to variables
    def bayes_test(test_user_indices=test_user_indices, liked_games=liked_games, \
               disliked_games=disliked_games, test_rows=test_rows, evaluator=evaluator, \
               similar_user_limit=50, collab_filter_limit=50, \
               content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, \
               recs=10, testing=True, verbose=verbose, show_result=show_result) :
    
        params = {
        "test_user_indices":test_user_indices,
        "test_user_rows":test_rows,
        "similar_user_limit":int(similar_user_limit),
        "collab_filter_limit":int(collab_filter_limit),
        "content_filter_limit":int(content_filter_limit),
        "double_bonus":double_bonus,
        "popular_bias":popular_bias,
        "ratio":ratio,
        "recs":int(recs),
        "verbose":verbose,
        "show_result":show_result,
        "testing":testing
        }
        
        results = []

        for i in range(len(test_user_indices)) :
            result = get_recs(test_user_indices[i], **params)
            results.append((result, \
                            game_to_col_index.inverse[liked_games[i][1]], \
                            game_to_col_index.inverse[disliked_games[i][1]]))
            
        score = evaluator(results)
        print(score)

        return score


    # Prepare params for Bayes
    param_bounds = {
        "similar_user_limit":(100, 140),
        "collab_filter_limit":(40, 100),
        "content_filter_limit":(10, 50),
        "double_bonus":(0, 3),
        "popular_bias":(2, 5),
        "ratio":(0.2, 0.95),
        "recs":(20, 20),
        }
    
    # Execute
    optimizer = BayesianOptimization(f=bayes_test, pbounds=param_bounds, random_state=42)
    optimizer.maximize(init_points=init_points, n_iter=n_iter)
    best_params = optimizer.max
    print(best_params)

    return best_params

# %% [markdown]
# I ran the following cell many times, recording the result each time.
#
# This final iteration represents a honing-in on the most optimal parameters.
#
# A fuller discussion will be the forthcoming project report.

# %%
boptimize(test_users=70, n_iter=15, init_points=8, show_result=True)
# Out:
# |   iter    |  target   | collab... | conten... | double... | popula... |   ratio   |   recs    | simila... |
# -------------------------------------------------------------------------------------------------------------
# ------ User profile:
# 1.0 - Castle Crashers®
# 1.0 - Session: Skate Sim
# 1.0 - Supraland
# 1.0 - FIGHTING EX LAYER
# 0.2 - Nioh: Complete Edition
# 0.2 - SMITE®
# 0.2 - NBA 2K Playgrounds 2
# 1.0 - Mafia III: Definitive Edition
# 1.0 - Mortal Kombat 11
# 0.2 - Animal Shelter
# 1.0 - SOULCALIBUR VI
# 1.0 - Risk of Rain 2
# 1.0 - Skater XL - The Ultimate Skateboarding Game
# 0.2 - WWE 2K BATTLEGROUNDS
# -1.0 - Borderlands Game of the Year Enhanced
# 0.2 - DARK SOULS™ III
# 1.0 - Borderlands 2
# --------------------
#
# ------ Recommendations
# 7.001 -- Street Fighter V
# 5.529 -- Counter-Strike 2
# 5.168 -- BlazBlue Centralfiction
# 5.101 -- Killer Instinct
# 5.06 -- GUILTY GEAR Xrd -SIGN-
# 5.028 -- Mafia: Definitive Edition
# 4.908 -- THE KING OF FIGHTERS XV
# 4.907 -- TEKKEN 8
# 4.882 -- Far Cry 3
# 4.876 -- BlazBlue: Chronophantasma Extend
# 4.834 -- Injustice™ 2
# 4.832 -- Pro Gymnast Simulator
# 4.818 -- THE KING OF FIGHTERS 2002 UNLIMITED MATCH
# 4.779 -- THE KING OF FIGHTERS XIII STEAM EDITION
# 4.763 -- TEKKEN 7
# 4.739 -- Guilty Gear X2 #Reload
# 4.613 -- DEAD OR ALIVE 6
# 4.564 -- Wreckfest
# 4.514 -- Arcana Heart 3 LOVE MAX!!!!!
# 4.511 -- Granblue Fantasy Versus: Rising
# --------------------
#
# Runtime: 5.24s
#
# ------ User profile:
# -1.0 - Night in the Woods
# 1.0 - Far Cry® 5
# 1.0 - Gunpoint
# 1.0 - Far Cry® New Dawn
# 1.0 - Terraria
# -1.0 - Bully: Scholarship Edition
# 1.0 - Stash
# -1.0 - Graveyard Keeper
# -1.0 - Genesis Online
# 1.0 - The Elder Scrolls® Online
# --------------------
#
# ------ Recommendations
# 5.486 -- Counter-Strike 2
# 4.382 -- Necesse
# 4.223 -- Don't Starve Together
# 4.216 -- Valheim
# 4.208 -- Starbound
# 4.2 -- Far Cry® 2
# 4.165 -- Summoners War: Chronicles
# 4.101 -- Far Cry 3
# 4.09 -- Dig or Die
# 3.992 -- Team Fortress 2
# 3.971 -- Feel The Snow
# 3.971 -- Far Cry® 6
# 3.97 -- Far Cry® 4
# 3.894 -- Garry's Mod
# 3.889 -- Continent of the Ninth Seal
# 3.835 -- Baldur's Gate 3
# 3.77 -- RuneScape ®
# 3.657 -- Realms of Magic
# 3.652 -- Homefront®: The Revolution
# 3.639 -- SuchArt: Creative Space
# --------------------
#
# Runtime: 5.29s
#
# ------ User profile:
# 1.0 - Deep Rock Galactic
# 1.0 - Subnautica
# 0.2 - Cyberpunk 2077
# 1.0 - Goat Simulator
# 1.0 - Among Us
# 0.2 - Slime Rancher
# 1.0 - Team Fortress 2
# 1.0 - SCP: Secret Laboratory
# 1.0 - Lethal Company
# 0.2 - BattleBit Remastered
# -1.0 - Starfield
# 1.0 - SnowRunner
# 1.0 - Don't Starve Together
# 1.0 - Space Engineers
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 6.164 -- Necesse
# 6.158 -- Raft
# 5.57 -- Stranded Deep
# 5.425 -- Counter-Strike 2
# 5.395 -- Voidtrain
# 5.327 -- Subnautica: Below Zero
# 5.131 -- Satisfactory
# 4.985 -- The Long Dark
# 4.915 -- Dig or Die
# 4.88 -- Scrap Mechanic
# 4.825 -- Starbound
# 4.819 -- Grounded
# 4.789 -- Fireworks Mania - An Explosive Simulator
# 4.743 -- Green Hell
# 4.644 -- Ethereal Estate
# 4.602 -- Fun with Ragdolls: The Game
# 4.592 -- Terraria
# 4.571 -- ARK: Survival Evolved
# 4.551 -- Volcanoids
# 4.481 -- Bum Simulator
# --------------------
#
# Runtime: 5.96s
#
# ------ User profile:
# 1.0 - Deep Rock Galactic
# 1.0 - EVERSPACE™ 2
# 1.0 - HELLDIVERS™ 2
# 1.0 - Vampire Survivors
# 1.0 - Warhammer 40,000: Darktide
# 1.0 - DOOM
# 1.0 - Soulstone Survivors
# 1.0 - Total War: WARHAMMER III
# 1.0 - Total War: WARHAMMER II
# 1.0 - No Man's Sky
# 1.0 - Hardspace: Shipbreaker
# 0.2 - Deep Rock Galactic: Survivor
# 1.0 - Baldur's Gate 3
# -1.0 - PUBG: BATTLEGROUNDS
# 0.2 - SteamVR
# 1.0 - Warhammer 40,000: Space Marine - Anniversary Edition
# -1.0 - Borderlands 2
# 1.0 - Risk of Rain 2
# -1.0 - Red Dead Redemption 2
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 5.754 -- Warframe
# 5.012 -- Warhammer 40,000: Dawn of War II
# 4.984 -- Warhammer 40,000: Dawn of War II: Retribution
# 4.917 -- Warhammer® 40,000: Dawn of War® II Chaos Rising
# 4.615 -- Rodina
# 4.607 -- NEBULOUS: Fleet Command
# 4.513 -- Rome: Total War™ - Collection
# 4.486 -- Total War: WARHAMMER
# 4.46 -- Space Engineers
# 4.428 -- PERISH
# 4.42 -- Total War: NAPOLEON – Definitive Edition
# 4.365 -- Witchcraft Survivors
# 4.346 -- Total War: EMPIRE – Definitive Edition
# 4.336 -- Total War: ROME II - Emperor Edition
# 4.306 -- Earth Defense Force: Insect Armageddon
# 4.264 -- Serious Sam 4
# 4.217 -- Total War: THREE KINGDOMS
# 4.131 -- World War Z
# 4.127 -- Total War: ATTILA
# 4.024 -- Resident Evil Revelations
# --------------------
#
# Runtime: 5.73s
#
# ------ User profile:
# 1.0 - Deep Rock Galactic
# 1.0 - Core Keeper
# 1.0 - Inscryption
# 1.0 - V Rising
# 1.0 - Slay the Spire
# 1.0 - Call of Duty®
# 1.0 - Dyson Sphere Program
# 1.0 - DREDGE
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 7.127 -- Empires of the Undergrowth
# 6.416 -- Factory Town
# 6.407 -- Space Haven
# 6.178 -- Necesse
# 6.086 -- Desynced: Autonomous Colony Simulator
# 5.925 -- RAILGRADE
# 5.92 -- Nova Lands
# 5.574 -- Volcanoids
# 5.555 -- Counter-Strike 2
# 5.029 -- Voidtrain
# 4.232 -- Die in the Dungeon: PROLOGUE
# 4.185 -- Blood Card
# 4.164 -- Dicey Dungeons
# 4.151 -- Blood Card 2: Dark Mist
# 4.129 -- Astrea: Six-Sided Oracles
# 4.099 -- Poker Quest: Swords and Spades
# 4.008 -- Balatro
# 4.008 -- Pizza Tower
# 4.004 -- Iris and the Giant
# 3.694 -- The Last Hex
# --------------------
#
# Runtime: 4.84s
#
# ------ User profile:
# 1.0 - Beyond: Two Souls
# 1.0 - LUNA The Shadow Dust
# 1.0 - Valheim
# 0.2 - Baldur's Gate 3
# 1.0 - Spiritfarer®: Farewell Edition
# 1.0 - Detroit: Become Human
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Stardew Valley
# 1.0 - Eastshade
# 1.0 - Slime Rancher
# 1.0 - House Flipper
# 1.0 - GRIS
# 1.0 - Project Zomboid
# 1.0 - Tavern Master
# 1.0 - Divinity: Original Sin - Enhanced Edition
# 1.0 - Fran Bow
# 1.0 - Kena: Bridge of Spirits
# 1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 5.76 -- Counter-Strike 2
# 5.723 -- Necesse
# 5.664 -- My Jigsaw Adventures - Roads of Life
# 5.471 -- Gorogoa
# 5.455 -- Eventide: Slavic Fable
# 5.412 -- The Secret Order 6: Bloodline
# 5.371 -- Raft
# 5.334 -- Persian Nights: Sands of Wonders
# 5.319 -- 9 Clues 2: The Ward
# 5.296 -- Dig or Die
# 5.265 -- Mind Snares: Alice's Journey
# 5.2 -- My Jigsaw Adventures - A Lost Story
# 5.2 -- Scarlett Mysteries: Cursed Child
# 5.198 -- Dark Arcana: The Carnival
# 5.189 -- The Emerald Maiden: Symphony of Dreams
# 5.177 -- Little Briar Rose
# 5.151 -- The Secret Order 3: Ancient Times
# 4.971 -- Left in the Dark: No One on Board
# 4.971 -- The Secret Order 2: Masked Intent
# 4.944 -- Craftopia
# --------------------
#
# Runtime: 6.33s
#
# ------ User profile:
# -1.0 - Beyond: Two Souls
# 1.0 - Clone Drone in the Danger Zone
# 1.0 - One Piece Pirate Warriors 3
# 1.0 - BATTLETECH
# -1.0 - FINAL FANTASY XV WINDOWS EDITION
# 1.0 - Hell Let Loose
# -1.0 - POSTAL 4: No Regerts
# -1.0 - Batman™: Arkham Origins
# 1.0 - Rising Storm 2: Vietnam
# -1.0 - Sniper Ghost Warrior Contracts
# 1.0 - The Forgotten City
# -1.0 - Days Gone
# -1.0 - Quantum Break
# 1.0 - Vampire Survivors
# 1.0 - Isonzo
# -1.0 - Call of Duty®: WWII
# 1.0 - DRAGON BALL Z: KAKAROT
# --------------------
#
# ------ Recommendations
# 7.402 -- Insurgency: Sandstorm
# 5.575 -- Rising Storm Game of the Year Edition
# 5.46 -- Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# 5.362 -- Verdun
# 5.334 -- War of Rights
# 5.255 -- Day of Defeat: Source
# 5.253 -- Counter-Strike 2
# 5.197 -- Tannenberg
# 5.068 -- Red Orchestra: Ostfront 41-45
# 4.789 -- Beyond The Wire
# 4.71 -- GROUND BRANCH
# 4.618 -- DRAGON BALL XENOVERSE
# 4.601 -- Brothers in Arms: Hell's Highway™
# 4.592 -- Holdfast: Nations At War
# 4.581 -- Easy Red 2
# 4.571 -- DRAGON BALL XENOVERSE 2
# 4.571 -- NARUTO SHIPPUDEN: Ultimate Ninja STORM 4
# 4.535 -- Yakuza 4 Remastered
# 4.483 -- Military Conflict: Vietnam
# 4.465 -- Squad
# --------------------
#
# Runtime: 6.77s
#
# ------ User profile:
# 0.2 - Last Epoch
# 0.2 - Pacific Drive
# 0.2 - Tiny Tina's Wonderlands
# 0.2 - Roboquest
# 0.2 - Halls of Torment
# 0.2 - Trackmania
# 0.2 - Grand Theft Auto V
# 0.2 - Path of Exile
# 0.2 - Factorio
# --------------------
#
# ------ Recommendations
# 7.081 -- Superfuse
# 6.624 -- Torchlight III
# 6.167 -- Torchlight II
# 5.94 -- Gunfire Reborn
# 5.902 -- Victor Vran ARPG
# 5.874 -- Grim Dawn
# 5.627 -- The Incredible Adventures of Van Helsing
# 5.412 -- Dungeon Siege II
# 5.249 -- Serious Sam 2
# 5.228 -- Torchlight: Infinite
# 5.156 -- Dota 2
# 5.133 -- The Incredible Adventures of Van Helsing II
# 5.068 -- Sacred 2 Gold
# 4.944 -- Diablo® IV
# 4.759 -- Major League Gladiators
# 4.124 -- Radio Silent
# 3.953 -- Satisfactory
# 3.934 -- Against the Storm
# 3.92 -- Baldur's Gate 3
# 3.887 -- shapez
# --------------------
#
# Runtime: 5.57s
#
# ------ User profile:
# 1.0 - Rust
# 1.0 - Subnautica
# 1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Counter-Strike 2
# 0.2 - SCP: Secret Laboratory
# 1.0 - THE FINALS
# 1.0 - Grand Theft Auto V
# 1.0 - Phasmophobia
# 1.0 - The Forest
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 10.272 -- Tom Clancy's Rainbow Six® Siege
# 6.172 -- Volcanoids
# 6.085 -- Stranded Deep
# 5.897 -- Voidtrain
# 5.341 -- Dota 2
# 5.271 -- Lightphobe
# 5.215 -- The Long Dark
# 5.186 -- Urge
# 5.161 -- Counter-Strike: Source
# 5.074 -- Raft
# 4.829 -- Sons Of The Forest
# 4.819 -- Scrap Mechanic
# 4.814 -- Green Hell
# 4.755 -- Tom Clancy's Ghost Recon®
# 4.679 -- Apex Armor Swap Trainer
# 4.67 -- Arma 3
# 4.578 -- Mist Survival
# 4.542 -- GROUND BRANCH
# 4.471 -- Odd Woods
# 4.42 -- Tom Clancy's Rainbow Six® Vegas 2
# --------------------
#
# Runtime: 5.8s
#
# ------ User profile:
# 0.2 - Chivalry 2
# 1.0 - Splitgate
# 0.2 - Automation - The Car Company Tycoon Game
# -1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Barotrauma
# 1.0 - Cities: Skylines
# 1.0 - Hook
# 0.2 - SteamVR
# 1.0 - Halo: The Master Chief Collection
# 0.2 - Two Point Campus
# 1.0 - Planet Coaster
# 1.0 - Insurgency: Sandstorm
# 0.2 - Red Dead Redemption 2
# --------------------
#
# ------ Recommendations
# 5.661 -- Counter-Strike 2
# 5.298 -- Workers & Resources: Soviet Republic
# 5.138 -- Planet Zoo
# 4.983 -- RollerCoaster Tycoon®: Deluxe
# 4.786 -- RollerCoaster Tycoon® 3: Complete Edition
# 4.532 -- Aliens vs. Predator™
# 4.473 -- Mini Pipes - A Logic Puzzle Pipes Game
# 4.43 -- Smart City Plan
# 4.385 -- Blokker: Orange
# 4.366 -- klocki
# 4.356 -- Farm Manager 2021
# 4.329 -- SimCity™ 4 Deluxe Edition
# 4.315 -- One Circle
# 4.311 -- Hexcells
# 4.179 -- Zenge
# 4.12 -- Yin Yang
# 4.115 -- Parkasaurus
# 4.085 -- RollerCoaster Tycoon® 3: Platinum
# 4.066 -- hocus
# 3.989 -- Lotus Bloom
# --------------------
#
# Runtime: 5.06s
#
# ------ User profile:
# 1.0 - Warhammer 40,000: Boltgun
# 1.0 - Undertale
# 1.0 - Transistor
# 1.0 - Left 4 Dead 2
# 1.0 - Dead Cells
# 1.0 - Terraria
# 1.0 - Hedon Bloodrite
# 1.0 - Mark of the Ninja: Remastered
# 1.0 - Vampire Survivors
# 1.0 - Quake
# 1.0 - DUSK
# --------------------
#
# ------ Recommendations
# 7.613 -- Ion Fury
# 7.284 -- Quake II
# 7.005 -- DOOM 64
# 6.83 -- DOOM II
# 6.79 -- Hexen: Deathkings of the Dark Citadel
# 6.761 -- DOOM (1993)
# 6.517 -- Prodeus
# 6.27 -- Heretic: Shadow of the Serpent Riders
# 6.154 -- STAR WARS™ Dark Forces (Classic, 1995)
# 5.625 -- Hellbound
# 5.616 -- Blake Stone: Planet Strike
# 5.233 -- Counter-Strike 2
# 5.141 -- Quake III Arena
# 4.992 -- Monument
# 4.954 -- Painkiller: Black Edition
# 4.933 -- Turbo Overkill
# 4.904 -- Turok
# 4.876 -- Aliens versus Predator Classic 2000
# 4.785 -- Outlaws + A Handful of Missions
# 4.644 -- Deathmatch Classic
# --------------------
#
# Runtime: 4.99s
#
# ------ User profile:
# 1.0 - FINAL FANTASY XIV Online
# 1.0 - Enshrouded
# 1.0 - Dwarf Fortress
# 1.0 - Baldur's Gate 3
# 1.0 - Orwell: Keeping an Eye On You
# 1.0 - ENDLESS™ Legend
# 1.0 - Hacknet
# 1.0 - Stellaris Nexus
# 1.0 - Dragon's Dogma: Dark Arisen
# 1.0 - RimWorld
# --------------------
#
# ------ Recommendations
# 6.588 -- Tales of Arise
# 5.592 -- Against the Storm
# 5.547 -- Empires of the Undergrowth
# 5.536 -- Monster Hunter: World
# 5.372 -- Kingdoms of Amalur: Reckoning™
# 5.232 -- Hogwarts Legacy
# 5.098 -- Two Worlds Epic Edition
# 5.045 -- The Elder Scrolls® Online
# 5.015 -- Judgment: Apocalypse Survival Simulation
# 4.94 -- FINAL FANTASY XV WINDOWS EDITION
# 4.921 -- LIGHTNING RETURNS™: FINAL FANTASY® XIII
# 4.904 -- Sword Art Online: Lost Song
# 4.902 -- Founders' Fortune
# 4.901 -- Banished
# 4.89 -- Lord of Dwarves
# 4.88 -- Orwell: Ignorance is Strength
# 4.802 -- Counter-Strike 2
# 4.749 -- Sapiens
# 4.73 -- Guild Wars 2
# 4.694 -- After the Collapse
# --------------------
#
# Runtime: 4.42s
#
# ------ User profile:
# 0.2 - Pineapple on pizza
# 0.2 - Dungeons 3
# 0.2 - Counter-Strike 2
# 0.2 - Project Kat - Paper Lily Prologue
# 0.2 - Drunken Wrestlers 2
# 0.2 - 100 hidden frogs
# 0.2 - Kidnapped Girl
# 0.2 - Iron Snout
# 1.0 - Don't Starve Together
# 1.0 - ARK: Survival Evolved
# 0.2 - Cats Hidden in Paris
# -1.0 - KurtzPel
# 0.2 - Little Nightmares
# 0.2 - The Looker
# 1.0 - If My Heart Had Wings
# 0.2 - Idle Slayer
# 1.0 - Terraria
# 1.0 - Eden Eternal-聖境伝説
# 0.2 - Asteroid Bounty Hunter
# 0.2 - Steam Engine Simulator
# 0.2 - Call to Arms
# 0.2 - APB Reloaded
# 0.2 - Battle of Frigates
# 0.2 - Dungeons 2
# 0.2 - The Murder of Sonic the Hedgehog
# 0.2 - Cube Escape: Paradox
# 0.2 - BABBDI
# 0.2 - Albion Online
# 0.2 - Sheepy: A Short Adventure
# 0.2 - Beer Bar
# 0.2 - The Sims™ 4
# 0.2 - Need for Speed™ Unbound
# 0.2 - Awesomenauts - the 2D moba
# 1.0 - 7 Days to Die
# 0.2 - Eternal Senia
# 0.2 - Doki Doki Literature Club!
# 1.0 - Life is Strange - Episode 1
# 0.2 - Virtual Cottage
# 0.2 - Layers of Fear (2016)
# 0.2 - HoloCure - Save the Fans!
# 0.2 - Juice Galaxy
# 0.2 - Grimm's Hollow
# 0.2 - SuchArt: Creative Space
# 1.0 - Path of Exile
# 0.2 - ARK: The Survival Of The Fittest
# 0.2 - Cats Hidden in Jingle Jam
# 1.0 - Deponia: The Complete Journey
# 0.2 - Arrow a Row
# 0.2 - The Supper
# 1.0 - StormEdge: Wind of Change
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Stardew Valley
# 1.0 - Don't Starve
# 0.2 - Warframe
# 1.0 - Grand Theft Auto V
# 0.2 - Life is Strange 2
# 0.2 - Gravitas
# 0.2 - Call of Duty®
# 0.2 - Battlefield™ 2042
# 0.2 - 20 Small Mazes
# --------------------
#
# ------ Recommendations
# 8.928 -- Necesse
# 8.366 -- Valheim
# 7.755 -- Force of Nature
# 7.711 -- Voidtrain
# 7.213 -- Dig or Die
# 7.104 -- Raft
# 7.035 -- Planet Explorers
# 6.864 -- Forager
# 6.693 -- Junk Jack
# 6.591 -- Blockscape
# 6.522 -- Craftopia
# 6.5 -- Volcanoids
# 6.493 -- Stranded Deep
# 6.244 -- The Survivalists
# 6.178 -- Subsistence
# 5.895 -- Starbound
# 5.562 -- The Long Dark
# 5.501 -- Green Hell
# 5.493 -- Feel The Snow
# 5.401 -- Team Fortress 2
# --------------------
#
# Runtime: 7.52s
#
# ------ User profile:
# 1.0 - Undawn
# 1.0 - Half-Life
# 1.0 - Cookie Clicker
# 1.0 - The Walking Dead: Season Two
# 0.2 - Stumble Guys
# -1.0 - The Walking Dead: A New Frontier
# -1.0 - The Walking Dead: Michonne - A Telltale Miniseries
# 0.2 - Counter-Strike 2
# 1.0 - Bit Blaster XL
# 1.0 - Half-Life 2
# 0.2 - Supermarket Simulator
# 1.0 - Shadow Warrior 2
# 1.0 - The Walking Dead: The Final Season
# 1.0 - Vampire Survivors
# 1.0 - The Walking Dead: The Telltale Definitive Series
# 0.2 - Sunset Overdrive
# 1.0 - The Walking Dead
# 1.0 - Black Mesa
# --------------------
#
# ------ Recommendations
# 7.385 -- Half-Life: Alyx
# 6.344 -- Half-Life 2: Episode Two
# 6.154 -- Half-Life: Opposing Force
# 6.076 -- Half-Life 2: Episode One
# 6.036 -- Half-Life: Blue Shift
# 5.719 -- Halo: The Master Chief Collection
# 5.697 -- Half-Life 2: Lost Coast
# 5.609 -- Singularity™
# 5.591 -- Serious Sam Classic: The Second Encounter
# 5.558 -- Serious Sam Classic: The First Encounter
# 5.526 -- Resident Evil 7 Biohazard
# 5.51 -- Serious Sam HD: The First Encounter
# 5.467 -- Aliens versus Predator Classic 2000
# 5.448 -- Red Faction
# 5.402 -- Serious Sam 2
# 5.369 -- Far Cry®
# 5.17 -- Downfall
# 5.152 -- Metro 2033 Redux
# 5.117 -- Half-Life Deathmatch: Source
# 5.033 -- 7Days Origins
# --------------------
#
# Runtime: 5.12s
#
# ------ User profile:
# 1.0 - Tales of Symphonia
# 1.0 - Marvel’s Spider-Man Remastered
# -1.0 - Halo Infinite
# 1.0 - Dragon's Dogma 2
# 1.0 - Marvel’s Spider-Man: Miles Morales
# -1.0 - Starfield
# 1.0 - FINAL FANTASY IX
# 1.0 - FINAL FANTASY VII REMAKE INTERGRADE
# 1.0 - TEKKEN 8
# 1.0 - Devil May Cry 5
# -1.0 - Redfall
# 0.2 - Outcast - Second Contact
# 1.0 - RetroArch
# 0.2 - FINAL FANTASY XIV Online
# 0.2 - Mass Effect™ Legendary Edition
# 1.0 - Persona 3 Reload
# 1.0 - Dead Space
# -1.0 - Days Gone
# 1.0 - Resident Evil 4
# 1.0 - System Shock
# --------------------
#
# ------ Recommendations
# 7.09 -- FINAL FANTASY X/X-2 HD Remaster
# 5.74 -- Counter-Strike 2
# 4.875 -- The Legend of Heroes: Trails in the Sky SC
# 4.87 -- DEATH STRANDING DIRECTOR'S CUT
# 4.861 -- Rise of the Tomb Raider™
# 4.818 -- Okami HD
# 4.817 -- FINAL FANTASY XII THE ZODIAC AGE
# 4.759 -- Batman: Arkham City - Game of the Year Edition
# 4.698 -- Batman: Arkham Asylum Game of the Year Edition
# 4.693 -- .hack//G.U. Last Recode
# 4.684 -- Trials of Mana
# 4.618 -- Sudeki
# 4.574 -- Ys VI: The Ark of Napishtim
# 4.569 -- GRANDIA HD Remaster
# 4.553 -- Alien: Isolation
# 4.543 -- Batman™: Arkham Origins
# 4.529 -- Eldervale
# 4.519 -- Assassin's Creed 2
# 4.486 -- Atelier Ryza 2: Lost Legends & the Secret Fairy
# 4.473 -- UNCHARTED™: Legacy of Thieves Collection
# --------------------
#
# Runtime: 4.94s
#
# ------ User profile:
# -1.0 - Pixsaw
# 0.2 - Tools Up! Ultimate Edition
# 1.0 - Tightrope Theatre
# 1.0 - Fifteen
# 1.0 - Sonic Mania
# 1.0 - River Town Factory
# -1.0 - UnMetal
# -1.0 - HoPiKo
# -1.0 - Dragon Fantasy: The Volumes of Westeria
# 0.2 - A Life of Logic
# -1.0 - Alex Kidd in Miracle World DX
# 1.0 - My Little Universe
# 0.2 - Hexcells Infinite
# -1.0 - Pixel of Memory
# -1.0 - Gearbits
# -1.0 - The Tiny Bang Story
# 1.0 - Faerie Solitaire Remastered
# -1.0 - HackyZack
# -1.0 - Buildest
# -1.0 - Indecision.
# --------------------
#
# ------ Recommendations
# 4.952 -- Doki Doki Literature Club!
# 4.895 -- A Hat in Time
# 4.732 -- Tiny Traffic
# 4.729 -- Barry the Bunny
# 4.724 -- Dungeon in a Bottle
# 4.721 -- Explosive Candy World
# 4.709 -- Garbanzo Quest
# 4.706 -- Stoney's Adventure
# 4.704 -- Sokolor
# 4.695 -- Cat Slide Tiles
# 4.625 -- Dadish 2
# 4.488 -- Lovux
# 4.396 -- Sly Slime
# 4.298 -- Mission in Snowdriftland - Snowlogue
# 4.212 -- Destiny 2
# 4.016 -- Counter-Strike 2
# 3.573 -- Slay the Spire
# 3.573 -- Cookie Clicker
# 3.573 -- STAR WARS™ Empire at War - Gold Pack
# 3.56 -- PAYDAY 2
# --------------------
#
# Runtime: 4.62s
#
# ------ User profile:
# 0.2 - Deep Rock Galactic
# 0.2 - Inscryption
# 1.0 - GRANDIA II HD Remaster
# -1.0 - Batman™: Arkham Origins
# 0.2 - Monster Train
# 1.0 - Max Payne 3
# 0.2 - Ginga Force
# 1.0 - Detention
# 0.2 - FIGHTING EX LAYER
# 1.0 - LEGO® The Lord of the Rings™
# 1.0 - Danganronpa: Trigger Happy Havoc
# 1.0 - Danganronpa 2: Goodbye Despair
# 1.0 - Brothers - A Tale of Two Sons
# 0.2 - Quake
# 1.0 - Mother Russia Bleeds
# 0.2 - Dead by Daylight
# 1.0 - GAROU: MARK OF THE WOLVES
# 0.2 - PAYDAY 2
# 0.2 - BLUE REFLECTION
# 1.0 - Red Faction®: Armageddon™
# 1.0 - Warhammer 40,000: Space Marine - Anniversary Edition
# 1.0 - Castle of Illusion
# 0.2 - Slay the Spire
# 0.2 - Path of Exile
# 1.0 - Life is Strange: Before the Storm
# 0.2 - Warframe
# 1.0 - Bright Memory
# 0.2 - Titanfall® 2
# 0.2 - METAL GEAR SOLID V: GROUND ZEROES
# 0.2 - Balatro
# --------------------
#
# ------ Recommendations
# 11.773 -- HELLDIVERS™ 2
# 8.099 -- Binary Domain
# 5.718 -- Tokyo Dark
# 5.664 -- Bionic Commando
# 5.517 -- Danganronpa V3: Killing Harmony
# 5.43 -- Ghost Trick: Phantom Detective
# 5.382 -- Phoenix Wright: Ace Attorney Trilogy
# 5.296 -- Higurashi When They Cry Hou - Ch.7 Minagoroshi
# 5.284 -- STAR WARS™ Battlefront (Classic, 2004)
# 5.281 -- Higurashi When They Cry Hou - Ch.6 Tsumihoroboshi
# 5.266 -- Gears 5
# 5.256 -- Counter-Strike 2
# 5.216 -- Tom Clancy's Splinter Cell Chaos Theory®
# 5.215 -- Dead Space™ 2
# 5.152 -- OUTRIDERS
# 5.144 -- What Remains of Edith Finch
# 5.139 -- LOST PLANET® 3
# 5.108 -- AI: The Somnium Files
# 5.095 -- Umineko When They Cry - Answer Arcs
# 5.084 -- Red Faction Guerrilla Steam Edition
# --------------------
#
# Runtime: 5.56s
#
# ------ User profile:
# 1.0 - Subnautica
# 1.0 - Assassin’s Creed® IV Black Flag™
# 0.2 - Counter-Strike 2
# 1.0 - HELLDIVERS™ 2
# 1.0 - Tom Clancy's Rainbow Six® Siege
# 1.0 - Destiny 2
# 1.0 - Overwatch® 2
# 1.0 - Cyberpunk 2077
# 1.0 - Wolfenstein: The New Order
# 1.0 - The Stanley Parable
# 0.2 - Team Fortress 2
# 1.0 - Terraria
# 1.0 - A Hat in Time
# 0.2 - THE FINALS
# 1.0 - Halo: The Master Chief Collection
# 0.2 - ELDEN RING
# 1.0 - Borderlands 2
# 0.2 - Forza Horizon 5
# 1.0 - XCOM® 2
# 1.0 - Stardew Valley
# 1.0 - Warframe
# 1.0 - Titanfall® 2
# 0.2 - Horizon Zero Dawn™ Complete Edition
# 1.0 - ULTRAKILL
# --------------------
#
# ------ Recommendations
# 9.728 -- Apex Legends™
# 6.2 -- Serious Sam 2
# 5.938 -- Dirty Bomb®
# 5.813 -- Crysis 2 - Maximum Edition
# 5.704 -- Halo Infinite
# 5.672 -- Necesse
# 5.331 -- Lethal Company
# 5.297 -- Splitgate
# 5.152 -- DOOM Eternal
# 5.144 -- Half-Life 2: Episode Two
# 5.122 -- Half-Life 2
# 5.117 -- Borderlands: The Pre-Sequel
# 5.086 -- Forager
# 5.04 -- Black Mesa
# 5.02 -- OUTRIDERS
# 5.018 -- STAR WARS™ Republic Commando™
# 5.009 -- RoboCop: Rogue City
# 4.991 -- Tom Clancy’s The Division™
# 4.98 -- Half-Life: Opposing Force
# 4.978 -- Green Hell
# --------------------
#
# Runtime: 5.39s
#
# ------ User profile:
# 1.0 - Fantastic Contraption
# 1.0 - Baldur's Gate 3
# 1.0 - Ultimate Chicken Horse
# 1.0 - Tiny Battles
# 1.0 - Frozen Synapse 2
# 1.0 - Invisible, Inc.
# 1.0 - Siege of Centauri
# 1.0 - Vanishing Realms™
# 1.0 - The Lab
# 1.0 - Deus Ex: Mankind Divided
# 1.0 - Phasmophobia
# 1.0 - Unseen Diplomacy
# --------------------
#
# ------ Recommendations
# 8.206 -- Into the Breach
# 6.918 -- Spirits of the Hellements - TD
# 5.547 -- This is a Ghost
# 5.425 -- Deus Ex: Human Revolution - Director's Cut
# 4.782 -- Remnant Records
# 4.741 -- Demonologist
# 4.61 -- Counter-Strike 2
# 4.607 -- Dota 2
# 4.435 -- Fantastic Contraption Classic 1 & 2
# 4.388 -- Crysis 2 - Maximum Edition
# 4.265 -- Land of the Mage Lords
# 4.077 -- Deus Ex: Invisible War
# 4.022 -- Ghost Exile
# 3.997 -- Phylakterion
# 3.902 -- Path of Exile
# 3.879 -- Cyberpunk 2077
# 3.826 -- Tom Clancy's Rainbow Six® Siege
# 3.688 -- The Mage's Tale
# 3.598 -- Dead by Daylight
# 3.579 -- Slay the Spire
# --------------------
#
# Runtime: 4.46s
#
# ------ User profile:
# 1.0 - Crusader Kings II
# -1.0 - Destroy All Humans!
# 1.0 - Kenshi
# 1.0 - Valheim
# -1.0 - Crusader Kings III
# 1.0 - Fantasy General II
# -1.0 - Microsoft Flight Simulator 40th Anniversary Edition
# 1.0 - We Who Are About To Die
# -1.0 - STAR WARS™: Squadrons
# -1.0 - Raft
# -1.0 - The Forest
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 5.207 -- Counter-Strike 2
# 5.022 -- Empires of the Undergrowth
# 4.858 -- Colony Survival
# 4.652 -- Space Haven
# 4.479 -- Judgment: Apocalypse Survival Simulation
# 4.477 -- Terraria
# 4.414 -- shapez
# 4.401 -- Against the Storm
# 4.357 -- Re.poly
# 4.327 -- Lord of Dwarves
# 4.292 -- TerraTech
# 4.278 -- Gnomoria
# 4.263 -- First Feudal
# 4.231 -- Grounded
# 4.227 -- HELLDIVERS™ 2
# 4.221 -- Factory Town
# 4.108 -- Enshrouded
# 3.983 -- Panzer Corps 2
# 3.981 -- Field of Glory: Empires
# 3.954 -- Life is Feudal: Forest Village
# --------------------
#
# Runtime: 4.82s
#
# ------ User profile:
# 0.2 - Overwatch® 2
# 0.2 - Koi-Koi Japan [Hanafuda playing cards]
# 0.2 - SpeedRunners
# 0.2 - Car Mechanic Simulator 2014
# 0.2 - Hatsune Miku: Project DIVA Mega Mix+
# 1.0 - Sakura Spirit
# 0.2 - Picross Touch
# 0.2 - Puyo Puyo™ Tetris® 2
# 0.2 - Persona 5 Royal
# --------------------
#
# ------ Recommendations
# 5.662 -- Counter-Strike 2
# 5.533 -- My So-called Future Girlfriend
# 5.524 -- Miracle Snack Shop
# 5.489 -- NEKO-NIN exHeart
# 5.477 -- Sakura Succubus 4
# 5.459 -- Fantasy Tavern Sextet -Vol.3 Postlude Days-
# 5.413 -- My Furry Stepmom 🐾
# 5.4 -- Slobbish Dragon Princess LOVE + PLUS
# 5.376 -- Cross Princess
# 5.369 -- Renai Karichaimashita: Koikari - Love For Hire
# 5.366 -- NEKO-NIN exHeart 2
# 5.353 -- The Ditzy Demons Are in Love With Me
# 5.344 -- Kinkoi: Golden Loveriche
# 5.318 -- DATE A LIVE: Rio Reincarnation
# 5.317 -- Some Some Convenience Store
# 5.28 -- LuGame: Lunchtime Games Club!
# 5.273 -- Ascendant Hearts
# 5.232 -- TSUNDERE MILFIN
# 5.204 -- Sakura Beach
# 5.199 -- Sunrider Academy
# --------------------
#
# Runtime: 4.52s
#
# ------ User profile:
# 0.2 - Pathfinder: Wrath of the Righteous - Enhanced Edition
# -1.0 - STAR WARS™: The Old Republic™
# 0.2 - HELLDIVERS™ 2
# -1.0 - Skullgirls 2nd Encore
# -1.0 - CounterSide
# -1.0 - Warhammer 40,000: Darktide
# 1.0 - Hogwarts Legacy
# 0.2 - Turnip Boy Robs a Bank
# 0.2 - Cyberpunk 2077
# 1.0 - Slay the Princess
# 1.0 - Lucifer Within Us
# 1.0 - ENDER LILIES: Quietus of the Knights
# -1.0 - PAYDAY 3
# -1.0 - How To Date A Magical Girl!
# 0.2 - SpongeBob SquarePants: Battle for Bikini Bottom - Rehydrated
# 1.0 - Blood Bowl 2
# 0.2 - Sniper Ghost Warrior Contracts
# 1.0 - MONSTER HUNTER RISE
# -1.0 - Warhammer 40,000: Rogue Trader
# 1.0 - HoloCure - Save the Fans!
# 0.2 - ENDLESS™ Space 2
# 1.0 - Lost Planet® 2
# 0.2 - Holo X Break
# -1.0 - Wizard with a Gun
# --------------------
#
# ------ Recommendations
# 6.271 -- The Witcher® 3: Wild Hunt
# 4.875 -- Counter-Strike 2
# 4.663 -- Scarlet Hollow
# 4.605 -- Alien Swarm
# 4.576 -- EARTH DEFENSE FORCE 5
# 4.573 -- EARTH DEFENSE FORCE 4.1 The Shadow of New Despair
# 4.569 -- Earth Defense Force: Insect Armageddon
# 4.531 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 4.527 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 4.499 -- Fable - The Lost Chapters
# 4.425 -- Warhammer 40,000: Space Marine - Anniversary Edition
# 4.335 -- Dragon's Dogma: Dark Arisen
# 4.327 -- Eternal Edge+ Prologue
# 4.317 -- Risen
# 4.312 -- Saints Row IV: Re-Elected
# 4.256 -- Kingdoms of Amalur: Reckoning™
# 4.223 -- Warframe
# 4.213 -- Recursive Hate - Spider Hell
# 4.153 -- Sea of Thieves 2023 Edition
# 4.151 -- Fable Anniversary
# --------------------
#
# Runtime: 5.26s
#
# ------ User profile:
# 1.0 - METAL SLUG 3
# 1.0 - Half-Life: Alyx
# 1.0 - Tacoma
# 1.0 - The Underground Man 2
# 1.0 - Life is Strange: Before the Storm
# 1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Baldur's Gate 3
# 0.2 - Persona 3 Reload
# 1.0 - Life is Strange: True Colors
# 1.0 - Ori and the Blind Forest
# 1.0 - Papers, Please
# 0.2 - Street Fighter™ 6
# 1.0 - Cube Escape: Paradox
# 1.0 - Red Dead Redemption 2
# 1.0 - METAL GEAR RISING: REVENGEANCE
# --------------------
#
# ------ Recommendations
# 7.641 -- Marie's Room
# 6.477 -- Last Stop
# 5.754 -- Life is Strange Remastered
# 5.662 -- Counter-Strike 2
# 5.441 -- The Wreck
# 5.395 -- The Walking Dead: Season Two
# 5.335 -- Tell Me Why
# 5.267 -- Heaven's Vault
# 5.236 -- The Evil Within 2
# 5.146 -- Tom Clancy's Ghost Recon® Wildlands
# 5.069 -- Last wish
# 5.046 -- Ghost on the Shore
# 5.008 -- Far Cry®
# 4.498 -- Samsara Room
# 4.452 -- Life is Strange - Episode 1
# 4.392 -- Raji: Prologue
# 4.354 -- Empathy: Path of Whispers
# 4.315 -- Ori and the Will of the Wisps
# 4.231 -- Rusty Lake: Roots
# 4.171 -- METAL SLUG X
# --------------------
#
# Runtime: 4.6s
#
# ------ User profile:
# 1.0 - Killing Floor 2
# 0.2 - DARK SOULS™ II: Scholar of the First Sin
# 1.0 - Laika: Aged Through Blood
# 1.0 - ENDER LILIES: Quietus of the Knights
# 1.0 - DayZ
# 1.0 - Magicians & Looters
# 0.2 - Save Room - The Merchant
# 1.0 - Phasmophobia
# 1.0 - DARK SOULS™ III
# 1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 5.905 -- 8Doors: Arum's Afterlife Adventure
# 5.236 -- No More Room in Hell
# 5.229 -- Dogworld
# 5.13 -- Unbound: Worlds Apart
# 4.931 -- Killing Floor - Toy Master
# 4.849 -- NO Logic
# 4.781 -- HELLDIVERS™ 2
# 4.708 -- Arizona Sunshine®
# 4.676 -- Death's Gambit: Afterlife
# 4.605 -- 3000th Duel
# 4.534 -- Counter-Strike 2
# 4.526 -- Lost Wish: In the desperate world
# 4.283 -- DARK SOULS™: REMASTERED
# 4.19 -- Void Memory
# 4.16 -- ELDEN RING
# 4.035 -- Monster Hunter: World
# 4.03 -- This is a Ghost
# 3.979 -- DARK SOULS™ II
# 3.949 -- Dragon's Dogma: Dark Arisen
# 3.867 -- WarriOrb: Prologue
# --------------------
#
# Runtime: 4.16s
#
# ------ User profile:
# 0.2 - Prison Architect
# 0.2 - Steel Division 2
# 0.2 - Imperator: Rome
# 0.2 - Crusader Kings III
# 0.2 - Hearts of Iron IV
# 1.0 - Mount & Blade: Warband
# 0.2 - WARNO
# 1.0 - Wargame: Red Dragon
# --------------------
#
# ------ Recommendations
# 8.938 -- Mount & Blade II: Bannerlord
# 5.032 -- Men of War™
# 5.025 -- Men of War: Assault Squad
# 4.939 -- Company of Heroes: Opposing Fronts
# 4.872 -- Mount & Blade
# 4.854 -- ARMA: Gold Edition
# 4.848 -- Total War: NAPOLEON – Definitive Edition
# 4.825 -- Men of War: Assault Squad 2
# 4.725 -- Counter-Strike 2
# 4.683 -- Mount & Blade: With Fire & Sword
# 4.678 -- Wargame: European Escalation
# 4.671 -- Graviteam Tactics: Mius-Front
# 4.656 -- Company of Heroes: Tales of Valor
# 4.647 -- Steel Division: Normandy 44
# 4.586 -- Stardew Valley
# 4.582 -- Ultimate General: Gettysburg
# 4.404 -- Company of Heroes - Legacy Edition
# 4.402 -- Graviteam Tactics: Operation Star
# 4.272 -- Regiments
# 4.219 -- Company of Heroes 2
# --------------------
#
# Runtime: 4.3s
#
# ------ User profile:
# 1.0 - Miscreated
# 1.0 - MORDHAU
# 1.0 - PAYDAY 2
# 1.0 - South Park™: The Stick of Truth™
# 1.0 - Goat Simulator
# 1.0 - SUPERHOT
# 1.0 - Rising Storm 2: Vietnam
# 1.0 - DayZ
# 1.0 - S.T.A.L.K.E.R.: Shadow of Chernobyl
# 1.0 - Fallout 4
# 1.0 - Dead by Daylight
# 1.0 - Dying Light
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 7.331 -- S.T.A.L.K.E.R.: Call of Pripyat
# 6.5 -- CastleMiner Z
# 6.361 -- Metro Exodus
# 5.886 -- GTFO
# 5.858 -- Shadows of Kurgansk
# 5.692 -- Fallout: New Vegas
# 5.623 -- Dead Effect 2
# 5.442 -- Counter-Strike 2
# 5.259 -- Unturned
# 5.195 -- I Am Alive
# 5.182 -- Rust
# 4.971 -- Fallout 3
# 4.939 -- No More Room in Hell
# 4.865 -- Fallout 3: Game of the Year Edition
# 4.826 -- Ethereal Estate
# 4.81 -- Terminator: Resistance
# 4.809 -- Metro 2033 Redux
# 4.809 -- Metro: Last Light Redux
# 4.728 -- Killing Floor - Toy Master
# 4.633 -- Hurtworld
# --------------------
#
# Runtime: 4.49s
#
# ------ User profile:
# 0.2 - Europa Universalis IV
# 0.2 - Granblue Fantasy: Relink
# 0.2 - Terraria
# 0.2 - Hearts of Iron IV
# 1.0 - DARK SOULS™: REMASTERED
# -1.0 - Remnant: From the Ashes
# -1.0 - HUMANKIND™
# -1.0 - ICARUS
# --------------------
#
# ------ Recommendations
# 7.03 -- Monster Hunter: World
# 6.562 -- Nioh 2 – The Complete Edition
# 5.229 -- Counter-Strike 2
# 4.639 -- DARK SOULS™ II
# 4.609 -- Blade of Darkness
# 4.602 -- DARK SOULS™ II: Scholar of the First Sin
# 4.598 -- Fable - The Lost Chapters
# 4.567 -- Lies of P
# 4.561 -- Dragon's Dogma: Dark Arisen
# 4.48 -- Risen
# 4.47 -- STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 4.252 -- Dark Cave
# 4.142 -- Requiem
# 4.139 -- Risen 2: Dark Waters
# 4.138 -- Death's Gambit: Afterlife
# 4.115 -- DARK SOULS™ III
# 4.105 -- Nioh: Complete Edition
# 4.081 -- Gothic® 3
# 4.047 -- Victoria II
# 4.025 -- Two Worlds Epic Edition
# --------------------
#
# Runtime: 4.2s
#
# ------ User profile:
# -1.0 - Company of Heroes 2
# 1.0 - Broforce
# -1.0 - Elite Dangerous
# -1.0 - Warhammer: Vermintide 2
# -1.0 - DayZ
# -1.0 - Darkest Dungeon®
# -1.0 - Insurgency: Sandstorm
# -1.0 - Hunt: Showdown
# --------------------
#
# ------ Recommendations
# 5.453 -- Duck Game
# 5.339 -- Guns, Gore and Cannoli 2
# 5.261 -- Putty Pals
# 5.259 -- TowerFall Ascension
# 5.221 -- Squeakers
# 5.168 -- PewDiePie: Legend of the Brofist
# 5.154 -- Zombie Kill of the Week - Reborn
# 5.149 -- METAL SLUG 2
# 5.149 -- Bass Monkey
# 5.138 -- Death's Hangover
# 5.13 -- Abathor - Atlantis Landing
# 5.129 -- Bud Spencer & Terence Hill - Slaps And Beans
# 5.127 -- Superfighters Deluxe
# 5.035 -- METAL SLUG X
# 4.977 -- 1001 Spikes
# 4.963 -- Dead Pixels
# 4.96 -- Deathwish Enforcers Special Edition
# 4.94 -- Worms W.M.D
# 4.915 -- Shootout on Cash Island
# 4.854 -- Rocketbirds: Hardboiled Chicken
# --------------------
#
# Runtime: 4.47s
#
# ------ User profile:
# 1.0 - Hogwarts Legacy
# 1.0 - Pineapple on pizza
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Terraria
# 1.0 - Geometry Dash
# 1.0 - The Witcher: Enhanced Edition Director's Cut
# 1.0 - Dragon's Dogma: Dark Arisen
# 1.0 - Smalland: Survive the Wilds
# 1.0 - The Forest
# 1.0 - The Witcher 2: Assassins of Kings Enhanced Edition
# --------------------
#
# ------ Recommendations
# 6.08 -- Fable - The Lost Chapters
# 5.969 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 5.868 -- Risen
# 5.542 -- Fable Anniversary
# 5.403 -- Divinity II: Developer's Cut
# 5.402 -- Gothic® 3
# 5.295 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 5.291 -- Requiem
# 5.231 -- Two Worlds Epic Edition
# 5.208 -- Counter-Strike 2
# 5.19 -- Gothic II: Gold Edition
# 5.0 -- Middle-earth™: Shadow of War™
# 4.993 -- Kingdoms of Amalur: Reckoning™
# 4.945 -- Bound By Flame
# 4.645 -- GreedFall
# 4.581 -- Dota 2
# 4.479 -- Green Hell
# 4.449 -- Kingdoms of Amalur: Re-Reckoning
# 4.433 -- Dragon Age™ Inquisition
# 4.4 -- ArcaniA
# --------------------
#
# Runtime: 4.49s
#
# ------ User profile:
# 0.2 - Ready or Not
# 1.0 - Sons Of The Forest
# 0.2 - Pacific Drive
# 0.2 - theHunter: Call of the Wild™
# 0.2 - Bloons TD 6
# 0.2 - BattleBit Remastered
# 0.2 - Vampire Survivors
# 0.2 - BeamNG.drive
# 1.0 - Call of Duty®
# --------------------
#
# ------ Recommendations
# 7.107 -- The Forest
# 6.632 -- Call of Duty®: Modern Warfare® II
# 6.074 -- Battlefield 3™
# 5.579 -- Counter-Strike 2
# 5.05 -- Green Hell
# 4.948 -- Urge
# 4.826 -- Subnautica
# 4.809 -- GROUND BRANCH
# 4.761 -- Arma 3
# 4.646 -- Raft
# 4.635 -- Brothers in Arms: Hell's Highway™
# 4.56 -- Call of Duty®: Modern Warfare®
# 4.515 -- Medal of Honor™
# 4.498 -- Sniper Ghost Warrior Contracts 2
# 4.497 -- Zero Caliber VR
# 4.483 -- Volcanoids
# 4.407 -- Insurgency: Sandstorm
# 4.302 -- Tom Clancy's Ghost Recon® Wildlands
# 4.202 -- Tom Clancy's Rainbow Six® Vegas
# 4.186 -- Call of Duty®: Black Ops Cold War
# --------------------
#
# Runtime: 4.31s
#
# ------ User profile:
# 1.0 - POSTAL: Brain Damaged
# 1.0 - HELLDIVERS™ 2
# 1.0 - Palworld
# 1.0 - Don't Starve Together
# 1.0 - Dishonored 2
# 0.2 - Team Fortress 2
# 0.2 - Dead Cells
# -1.0 - Lethal Company
# 0.2 - Garry's Mod
# -1.0 - Your Only Move Is HUSTLE
# -1.0 - The Outlast Trials
# 1.0 - The Walking Dead: Season Two
# 1.0 - Bloons TD 6
# -1.0 - Poppy Playtime
# 1.0 - Trepang2
# 1.0 - Hollow Knight
# 1.0 - Enter the Gungeon
# 1.0 - DEATH STRANDING DIRECTOR'S CUT
# 0.2 - Risk of Rain 2
# 0.2 - Bopl Battle
# 1.0 - Red Dead Redemption 2
# --------------------
#
# ------ Recommendations
# 6.774 -- Fallout 4
# 5.579 -- Counter-Strike 2
# 5.303 -- Metro Exodus
# 5.119 -- Shadow of the Tomb Raider: Definitive Edition
# 4.924 -- Necesse
# 4.831 -- Valheim
# 4.764 -- DOOM 64
# 4.761 -- Raft
# 4.752 -- HROT
# 4.738 -- Rise of the Tomb Raider™
# 4.704 -- METAL GEAR SOLID V: THE PHANTOM PAIN
# 4.703 -- Prodeus
# 4.701 -- DOOM Eternal
# 4.699 -- Dig or Die
# 4.568 -- Feel The Snow
# 4.547 -- Left 4 Dead 2
# 4.432 -- Assassin's Creed 2
# 4.431 -- The Walking Dead
# 4.412 -- Anomalous
# 4.39 -- Craftopia
# --------------------
#
# Runtime: 5.05s
#
# ------ User profile:
# 1.0 - UNBEATABLE [white label]
# -1.0 - Overwatch® 2
# 1.0 - PAYDAY 2
# 1.0 - Warframe
# 1.0 - GRIS
# 1.0 - Apex Legends™
# -1.0 - Spacelords
# 1.0 - Street Fighter™ 6
# -1.0 - TEKKEN 7
# --------------------
#
# ------ Recommendations
# 5.178 -- Counter-Strike 2
# 4.998 -- The Witness
# 4.944 -- Red Dead Redemption 2
# 4.448 -- My Jigsaw Adventures - Roads of Life
# 4.31 -- Gorogoa
# 4.102 -- My Jigsaw Adventures - A Lost Story
# 4.065 -- LUNA The Shadow Dust
# 4.048 -- Evan's Remains
# 4.012 -- RiME
# 3.978 -- One-armed robber
# 3.97 -- Aspire: Ina's Tale
# 3.904 -- Left 4 Dead 2
# 3.902 -- AER Memories of Old
# 3.859 -- Spirit of the North
# 3.823 -- Even the Ocean
# 3.785 -- NaissanceE
# 3.775 -- Munin
# 3.756 -- The Long Return
# 3.709 -- Little Briar Rose
# 3.661 -- Areia: Pathway to Dawn
# --------------------
#
# Runtime: 4.57s
#
# ------ User profile:
# 1.0 - Chivalry 2
# 1.0 - Painkiller: Black Edition
# 1.0 - Pavlov VR
# 1.0 - Sekiro™: Shadows Die Twice - GOTY Edition
# 1.0 - Bloons TD Battles
# 1.0 - Bloons TD Battles 2
# 1.0 - DARK SOULS™ II: Scholar of the First Sin
# 1.0 - DARK SOULS™: REMASTERED
# 1.0 - NieR:Automata™
# 1.0 - Cruelty Squad
# -1.0 - Halo: The Master Chief Collection
# 1.0 - Phasmophobia
# 1.0 - ELDEN RING
# 1.0 - DARK SOULS™ III
# --------------------
#
# ------ Recommendations
# 6.259 -- Dragon's Dogma: Dark Arisen
# 5.784 -- Nioh: Complete Edition
# 5.77 -- DARK SOULS™ II
# 5.756 -- Monster Hunter: World
# 5.635 -- Steelrising
# 5.57 -- Bloons TD 6
# 5.509 -- Counter-Strike 2
# 5.448 -- Risen
# 5.392 -- Bound By Flame
# 5.384 -- Pascal's Wager: Definitive Edition
# 5.369 -- Lords Of The Fallen™ 2014
# 5.36 -- Nioh 2 – The Complete Edition
# 5.112 -- Dark Cave
# 5.083 -- Two Worlds Epic Edition
# 5.017 -- Lords of the Fallen
# 4.857 -- Fable - The Lost Chapters
# 4.805 -- Lies of P
# 4.804 -- Blade of Darkness
# 4.63 -- STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 4.562 -- Ashen
# --------------------
#
# Runtime: 4.73s
#
# ------ User profile:
# 1.0 - Beat Saber
# 0.2 - Last Epoch
# 1.0 - Streets of Rage 4
# 0.2 - Total War: WARHAMMER III
# 0.2 - Baldur's Gate 3
# 1.0 - DARK SOULS™ II: Scholar of the First Sin
# 0.2 - HELLDIVERS™ 2
# -1.0 - Darkest Dungeon®
# 1.0 - MechWarrior Online™ Legends
# 0.2 - THE FINALS
# 1.0 - Warhammer 40,000: Darktide
# --------------------
#
# ------ Recommendations
# 7.544 -- ELDEN RING
# 5.0 -- Counter-Strike 2
# 4.522 -- DARK SOULS™ III
# 4.452 -- Synth Riders
# 4.427 -- Apex Armor Swap Trainer
# 4.389 -- Tom Clancy's Rainbow Six® Siege
# 4.366 -- DARK SOULS™: REMASTERED
# 4.352 -- Mayhem Brawler
# 4.124 -- DARK SOULS™ II
# 4.102 -- Killing Floor 2
# 4.101 -- Nioh 2 – The Complete Edition
# 4.101 -- Colossus Down
# 4.04 -- GTFO
# 4.038 -- Team Fortress 2
# 3.97 -- World War Z
# 3.941 -- STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 3.921 -- The TakeOver
# 3.878 -- OhShape
# 3.835 -- PlanetSide 2
# 3.763 -- Double Dragon: Neon
# --------------------
#
# Runtime: 4.84s
#
# ------ User profile:
# 1.0 - Block N Load
# 0.2 - Dragon's Dogma 2
# -1.0 - War Thunder
# 0.2 - Ultimate Admiral: Dreadnoughts
# 1.0 - Project Zomboid
# 0.2 - Songs of Syx
# 1.0 - Battlefield™ 2042
# 1.0 - RimWorld
# --------------------
#
# ------ Recommendations
# 4.742 -- BattleBit Remastered
# 4.663 -- Risk of Rain 2
# 4.581 -- Empires of the Undergrowth
# 4.494 -- HELLDIVERS™ 2
# 4.493 -- Against the Storm
# 4.455 -- Stellaris
# 4.295 -- The Final Earth 2
# 4.291 -- Oxygen Not Included
# 4.212 -- The Forest
# 4.199 -- Necesse
# 4.133 -- Prison Architect
# 4.128 -- Space Haven
# 4.043 -- Dig or Die
# 4.04 -- Ratopia
# 4.037 -- Paleon
# 3.988 -- Sapiens
# 3.952 -- Project Highrise
# 3.947 -- Judgment: Apocalypse Survival Simulation
# 3.946 -- Feel The Snow
# 3.869 -- Surviving Mars
# --------------------
#
# Runtime: 4.4s
#
# ------ User profile:
# 1.0 - Cloudpunk
# 0.2 - Kebab Chefs! - Restaurant Simulator
# 0.2 - Chillquarium
# 1.0 - Valheim
# 1.0 - SYNTHETIK: Legion Rising
# 1.0 - Counter-Strike 2
# 1.0 - Factorio
# 0.2 - The Long Drive
# 1.0 - Terraria
# 0.2 - Lethal Company
# 1.0 - No More Room in Hell
# 1.0 - Unturned
# 1.0 - ARK: Survival Evolved
# 1.0 - One-armed cook
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 6.655 -- Necesse
# 6.11 -- Dig or Die
# 5.651 -- Craftopia
# 5.535 -- Voidtrain
# 5.491 -- Force of Nature
# 5.115 -- Raft
# 5.085 -- Satisfactory
# 5.06 -- Planet Explorers
# 4.967 -- Transmissions: Element 120
# 4.887 -- TerraTech
# 4.784 -- Cry of Fear
# 4.773 -- Killing Floor - Toy Master
# 4.724 -- Smalland: Survive the Wilds
# 4.66 -- Green Hell
# 4.612 -- Volcanoids
# 4.611 -- Phasmophobia
# 4.603 -- Stardew Valley
# 4.595 -- Zombie Panic! Source
# 4.566 -- Codename CURE
# 4.533 -- DayZ
# --------------------
#
# Runtime: 5.16s
#
# ------ User profile:
# 1.0 - STAR WARS™ Empire at War - Gold Pack
# 1.0 - The Hat Man: Shadow Ward
# 1.0 - SMITE®
# 1.0 - Danganronpa: Trigger Happy Havoc
# 1.0 - Resident Evil Village
# 1.0 - Doki Doki Literature Club!
# 1.0 - Sid Meier's Civilization® V
# 1.0 - Dead Space
# 1.0 - The Secret of Monkey Island: Special Edition
# 1.0 - Danganronpa 2: Goodbye Despair
# 1.0 - Resident Evil 4
# 1.0 - Resident Evil 7 Biohazard
# 1.0 - Hunt: Showdown
# --------------------
#
# ------ Recommendations
# 7.736 -- The Evil Within 2
# 6.087 -- Higurashi When They Cry Hou - Ch.6 Tsumihoroboshi
# 6.045 -- FROSTBITE: Deadly Climate
# 5.686 -- CHAOS;HEAD NOAH
# 5.461 -- Counter-Strike 2
# 5.301 -- Gynophobia
# 5.149 -- REQUISITION VR
# 5.134 -- Resident Evil 7 Teaser: Beginning Hour
# 5.105 -- Danganronpa V3: Killing Harmony
# 5.078 -- Outlast 2
# 5.02 -- El Paso, Elsewhere
# 4.991 -- Resident Evil 2
# 4.924 -- Ghost Trick: Phantom Detective
# 4.874 -- Phoenix Wright: Ace Attorney Trilogy
# 4.834 -- Penumbra: Black Plague Gold Edition
# 4.813 -- Eternal Evil
# 4.774 -- Granny
# 4.741 -- Metro Exodus
# 4.737 -- EBOLA 3
# 4.724 -- The Walking Dead: Saints & Sinners
# --------------------
#
# Runtime: 4.82s
#
# ------ User profile:
# 0.2 - Hogwarts Legacy
# 0.2 - The Outlast Trials
# 0.2 - Pacific Drive
# 0.2 - Stardew Valley
# 0.2 - The Binding of Isaac: Rebirth
# 0.2 - HELLDIVERS™ 2
# 0.2 - Terraria
# 0.2 - Lethal Company
# 0.2 - Balatro
# 0.2 - ARK: Survival Ascended
# 0.2 - Summoners War
# 0.2 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 7.504 -- Necesse
# 6.953 -- Valheim
# 6.789 -- Forager
# 6.731 -- FOREWARNED
# 6.468 -- Keplerth
# 6.328 -- Green Hell
# 6.17 -- Signs of Life
# 5.667 -- Starbound
# 5.604 -- Counter-Strike 2
# 5.527 -- Psycho Reign
# 5.427 -- Planet Explorers
# 4.864 -- There Won't be Light
# 4.348 -- Clanfolk
# 4.067 -- ELDEN RING
# 4.055 -- Cornucopia®
# 3.915 -- Phasmophobia
# 3.915 -- Counter-Strike: Source
# 3.649 -- ULTRAKILL
# 3.649 -- KILLBUG
# 3.611 -- Cookie Clicker
# --------------------
#
# Runtime: 4.67s
#
# ------ User profile:
# 1.0 - No Straight Roads: Encore Edition
# 1.0 - STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 0.2 - HELLDIVERS™ 2
# 1.0 - Street Fighter™ 6
# 1.0 - Deadly Premonition: The Director's Cut
# 1.0 - Bomb Rush Cyberfunk
# 0.2 - GUILTY GEAR -STRIVE-
# 0.2 - Dishonored 2
# 1.0 - The Elder Scrolls III: Morrowind® Game of the Year Edition
# 0.2 - No More Heroes
# 1.0 - Hi-Fi RUSH
# 0.2 - No More Heroes 2: Desperate Struggle
# 1.0 - Pizza Tower
# 1.0 - TEKKEN 8
# 1.0 - Baldur's Gate 3
# 1.0 - Spyro™ Reignited Trilogy
# 0.2 - Hylics 2
# 1.0 - METAL GEAR SOLID - Master Collection Version
# 1.0 - METAL GEAR SOLID 2: Sons of Liberty - Master Collection Version
# 1.0 - GUILTY GEAR Xrd REV 2
# 1.0 - The 25th Ward: The Silver Case
# --------------------
#
# ------ Recommendations
# 10.874 -- DRAGON BALL FighterZ
# 6.461 -- BlazBlue Centralfiction
# 6.45 -- GUILTY GEAR Xrd -SIGN-
# 6.395 -- BlazBlue: Chronophantasma Extend
# 6.392 -- UNDER NIGHT IN-BIRTH Exe:Late
# 6.369 -- Melty Blood Actress Again Current Code
# 5.991 -- THE KING OF FIGHTERS XIII STEAM EDITION
# 5.966 -- Injustice™ 2
# 5.953 -- TEKKEN 7
# 5.94 -- BlazBlue: Cross Tag Battle
# 5.932 -- THE KING OF FIGHTERS XV
# 5.837 -- CHAOS CODE -NEW SIGN OF CATASTROPHE-
# 5.763 -- ULTIMATE MARVEL VS. CAPCOM 3
# 5.747 -- Guilty Gear X2 #Reload
# 5.704 -- Killer Instinct
# 5.636 -- Sclash
# 5.575 -- DEATH STRANDING DIRECTOR'S CUT
# 5.527 -- Arcana Heart 3 LOVE MAX!!!!!
# 5.296 -- Granblue Fantasy Versus: Rising
# 5.265 -- Street Fighter V
# --------------------
#
# Runtime: 4.89s
#
# ------ User profile:
# 1.0 - Sairento VR
# 1.0 - The Price of Freedom
# -1.0 - Rituals
# 1.0 - The Swapper
# 1.0 - Thumper
# 1.0 - High Hell
# 1.0 - Papo & Yo
# -1.0 - Violent killer VR
# -1.0 - Windlands
# -1.0 - The Brookhaven Experiment
# 1.0 - House of the Dying Sun
# 1.0 - Thirty Flights of Loving
# --------------------
#
# ------ Recommendations
# 4.941 -- Balatro
# 4.846 -- Phasmophobia
# 4.365 -- Necro Mutex
# 4.339 -- Dota 2
# 4.078 -- Immortal Legacy: The Jade Cipher[VR]
# 4.06 -- Gravity Bone
# 4.013 -- Dogworld
# 4.002 -- MO:Astray
# 3.92 -- Overloop
# 3.89 -- Waking Mars
# 3.857 -- Seen
# 3.843 -- BLACKHOLE
# 3.838 -- Axiom Verge
# 3.824 -- RiME
# 3.744 -- Raji: Prologue
# 3.738 -- Environmental Station Alpha
# 3.736 -- Nihilumbra
# 3.714 -- HELLDIVERS™ 2
# 3.681 -- Iconoclasts
# 3.681 -- Counter-Strike 2
# --------------------
#
# Runtime: 4.28s
#
# ------ User profile:
# 1.0 - Muse Dash
# 1.0 - Back 4 Blood
# 1.0 - Detroit: Become Human
# 1.0 - Resident Evil Village
# 1.0 - Middle-earth™: Shadow of War™
# 1.0 - Zombie Army 4: Dead War
# 1.0 - Warhammer 40,000: Darktide
# 1.0 - Red Dead Redemption 2
# --------------------
#
# ------ Recommendations
# 7.418 -- The Evil Within 2
# 7.319 -- Arizona Sunshine®
# 7.16 -- World War Z
# 6.732 -- REQUISITION VR
# 5.798 -- Left 4 Dead 2
# 5.631 -- GTFO
# 5.532 -- Aliens vs. Predator™
# 5.51 -- Killing Floor 2
# 5.503 -- Stay Home
# 5.501 -- Blood and Bacon
# 5.425 -- Dead Island Definitive Edition
# 5.151 -- Don't Starve Together
# 5.099 -- Dead Island: Riptide Definitive Edition
# 5.043 -- Zombie Panic! Source
# 5.0 -- UNLOVED
# 4.89 -- Counter-Strike 2
# 4.594 -- Bionic Commando
# 4.37 -- Earthfall
# 3.951 -- Outlast 2
# 3.942 -- Resident Evil 7 Biohazard
# --------------------
#
# Runtime: 4.35s
#
# ------ User profile:
# 0.2 - Lil' Guardsman
# 1.0 - Tell Me Why
# 1.0 - RoboCop: Rogue City
# 1.0 - Metro Exodus
# 0.2 - SanctuaryRPG: Black Edition
# 1.0 - Fallout: New Vegas
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Road 96 🛣️
# -1.0 - Blackwake
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Sleeping Dogs: Definitive Edition
# 1.0 - To Hell With It
# 1.0 - Maneater
# 1.0 - Starfield
# 1.0 - VRChat
# 1.0 - Red Dead Redemption 2
# 1.0 - RimWorld
# -1.0 - Sea of Thieves 2023 Edition
# --------------------
#
# ------ Recommendations
# 12.295 -- Fallout 4
# 6.552 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 6.484 -- Kingdoms of Amalur: Reckoning™
# 6.454 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 5.655 -- Gothic® 3
# 5.535 -- Team Fortress 2
# 5.289 -- Hogwarts Legacy
# 5.179 -- The Evil Within 2
# 5.138 -- Dragon's Dogma: Dark Arisen
# 5.125 -- DOOM Eternal
# 5.076 -- Fallout 3
# 5.056 -- Middle-earth™: Shadow of War™
# 4.894 -- Cyberpunk 2077
# 4.78 -- Wolfenstein II: The New Colossus
# 4.674 -- Shadow of the Tomb Raider: Definitive Edition
# 4.619 -- Sleeping Dogs
# 4.603 -- Fable - The Lost Chapters
# 4.577 -- The Witcher: Enhanced Edition Director's Cut
# 4.556 -- Humanity Lost
# 4.518 -- Gothic II: Gold Edition
# --------------------
#
# Runtime: 4.98s
#
# ------ User profile:
# -1.0 - Overwatch® 2
# -1.0 - Ready or Not
# 1.0 - Pathologic 2
# 1.0 - Blue Estate The Game
# 1.0 - Barony
# 1.0 - Knock-knock
# -1.0 - Dead by Daylight
# 1.0 - G String
# -1.0 - 7 Days to Die
# 1.0 - Lethal Company
# 1.0 - Dead Rising 2: Off the Record
# -1.0 - PAYDAY 3
# -1.0 - Borderlands 3
# 1.0 - Serious Sam Fusion 2017 (beta)
# 1.0 - Zombie Army 4: Dead War
# 1.0 - Condemned: Criminal Origins
# --------------------
#
# ------ Recommendations
# 5.646 -- Counter-Strike 2
# 4.868 -- Serious Sam Classic: The Second Encounter
# 4.865 -- Serious Sam Classic: The First Encounter
# 4.658 -- Sniper Elite: Nazi Zombie Army
# 4.63 -- Serious Sam HD: The Second Encounter
# 4.622 -- Resident Evil 3: Raccoon City Demo
# 4.606 -- The Evil Within 2
# 4.595 -- Screencheat
# 4.567 -- Strange Brigade
# 4.47 -- Penumbra Overture
# 4.428 -- Resident Evil 5
# 4.266 -- Resident Evil Revelations
# 4.219 -- The Horror Story: Remastered
# 4.131 -- Bloody Good Time
# 4.076 -- Viscera Cleanup Detail: Shadow Warrior
# 4.033 -- Immortal Legacy: The Jade Cipher[VR]
# 3.976 -- DEAD RISING®
# 3.946 -- Pacify
# 3.895 -- Serious Sam 3: BFE
# 3.755 -- Team Fortress 2
# --------------------
#
# Runtime: 4.98s
#
# ------ User profile:
# 1.0 - Sword Art Online: Fatal Bullet
# 1.0 - Far Cry® 5
# 1.0 - CODE VEIN
# 1.0 - Monster Hunter: World
# 1.0 - Trials of Mana
# 1.0 - Cyberdimension Neptunia: 4 Goddesses Online
# 1.0 - Hellblade: Senua's Sacrifice
# -1.0 - Attack on Titan / A.O.T. Wings of Freedom
# 1.0 - Assassin's Creed® Odyssey
# 1.0 - The Vagrant
# 1.0 - Quantum Break
# 1.0 - Megadimension Neptunia VII
# --------------------
#
# ------ Recommendations
# 11.03 -- ELDEN RING
# 5.936 -- Sword Art Online: Lost Song
# 5.835 -- LIGHTNING RETURNS™: FINAL FANTASY® XIII
# 5.774 -- GOD EATER 3
# 5.74 -- FINAL FANTASY XV WINDOWS EDITION
# 5.614 -- Sword Art Online Re: Hollow Fragment
# 5.479 -- Tales of Berseria™
# 5.265 -- Fate/EXTELLA
# 5.175 -- Sudeki
# 5.174 -- Dragon's Dogma: Dark Arisen
# 5.095 -- Tales of Arise
# 5.06 -- Sekiro™: Shadows Die Twice - GOTY Edition
# 5.053 -- Attack on Titan 2 - A.O.T.2
# 4.918 -- Crystar
# 4.838 -- Atelier Firis: The Alchemist and the Mysterious Journey / フィリスのアトリエ ～不思議な旅の錬金術士～
# 4.673 -- Superdimension Neptune VS Sega Hard Girls
# 4.65 -- Hyperdimension Neptunia Re;Birth2: Sisters Generation
# 4.581 -- The Legend of Heroes: Trails in the Sky SC
# 4.57 -- Ys SEVEN
# 4.533 -- Hyperdimension Neptunia U: Action Unleashed
# --------------------
#
# Runtime: 4.58s
#
# ------ User profile:
# 1.0 - Battlefield™ V
# 1.0 - Halo Infinite
# -1.0 - BATTALION: Legacy
# -1.0 - PUBG: BATTLEGROUNDS
# -1.0 - Quake Champions
# 1.0 - Counter-Strike 2
# 1.0 - The Planet Crafter
# -1.0 - Arma 3
# -1.0 - Batman™: Arkham Knight
# 1.0 - Z1 Battle Royale
# 1.0 - Golf With Your Friends
# 0.2 - Call of Duty®
# -1.0 - Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# 1.0 - Kreedz Climbing
# --------------------
#
# ------ Recommendations
# 5.049 -- DayZ
# 4.728 -- Overload Playable Teaser 3.0
# 4.728 -- Double Action: Boogaloo
# 4.405 -- The Planet Crafter: Prologue
# 4.375 -- Satisfactory
# 4.247 -- Call of Duty® 2
# 4.206 -- Call of Duty®: Modern Warfare® 2 (2009)
# 4.197 -- Golf It!
# 4.182 -- Space Trash Scavenger
# 4.166 -- ASTRONEER
# 4.158 -- Subnautica: Below Zero
# 4.079 -- Bowling Hills
# 3.932 -- Battlefield™ 1
# 3.906 -- Codename CURE
# 3.828 -- HELLDIVERS™ 2
# 3.743 -- Destiny 2
# 3.672 -- Remains
# 3.637 -- CRSED: F.O.A.D.
# 3.634 -- Deadside
# 3.627 -- Slay the Spire
# --------------------
#
# Runtime: 4.71s
#
# ------ User profile:
# 1.0 - Five Nights at Freddy's 2
# 1.0 - PAYDAY 2
# 1.0 - Call of Duty®: Black Ops II
# 1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Portal 2
# 1.0 - Catan Universe
# 1.0 - Call of Duty®: Black Ops III
# 1.0 - Sinister City
# 0.2 - Resident Evil 4
# 1.0 - Z1 Battle Royale
# 1.0 - Destiny 2
# 1.0 - Borderlands 3
# 1.0 - Dead Island Definitive Edition
# -1.0 - Hunt: Showdown
# 1.0 - Borderlands 2
# --------------------
#
# ------ Recommendations
# ...
# 4.04 -- GROUND BRANCH
# 4.017 -- Pavlov VR
# 3.935 -- Metro Exodus
# 3.841 -- GTFO
# 3.766 -- Meltdown
# 3.687 -- Stardew Valley
# 3.661 -- Zero Hour
# 3.647 -- Slay the Spire
# 3.647 -- Papers, Please
# 3.647 -- Persona 5 Royal
# 3.647 -- American Truck Simulator
# --------------------
#
# Runtime: 4.61s
#
# ------ User profile:
# 1.0 - It Lurks Below
# 1.0 - Cookie Clicker
# 0.2 - Sons Of The Forest
# 1.0 - Baldur's Gate 3
# 1.0 - Bloons TD Battles 2
# 0.2 - Blood West
# 1.0 - Tricky Towers
# 1.0 - Vampire Survivors
# 0.2 - DAVE THE DIVER
# -1.0 - Mineirinho Director's Cut
# 1.0 - Path of Exile
# 0.2 - An Ankou
# --------------------
#
# ------ Recommendations
# 7.652 -- Dota 2
# 6.164 -- HELLDIVERS™ 2
# 5.379 -- Counter-Strike 2
# 4.453 -- Balatro
# 4.43 -- Portal 2
# 4.22 -- Kiwi Clicker - Juiced Up
# 4.045 -- Deep Rock Galactic: Survivor
# 4.019 -- GunSuit Guardians
# 3.732 -- A Hat in Time
# 3.732 -- Half-Life: Alyx
# 3.732 -- Stardew Valley
# 3.693 -- Bloons TD 6
# 3.693 -- Slay the Spire
# 3.693 -- Like a Dragon Gaiden: The Man Who Erased His Name
# 3.693 -- Plants vs. Zombies GOTY Edition
# 3.693 -- Factorio
# 3.693 -- BeamNG.drive
# 3.653 -- Halls of Torment
# 3.653 -- Your Only Move Is HUSTLE
# 3.653 -- Oxygen Not Included
# --------------------
#
# Runtime: 4.4s
#
# ------ User profile:
# 1.0 - Technobabylon
# 1.0 - Into the Breach
# 1.0 - Strangeland
# 0.2 - PlateUp!
# -1.0 - Thief
# 1.0 - Caves of Qud
# -1.0 - Outer Wilds
# -1.0 - DEATHLOOP
# -1.0 - You Will (Not) Remain
# 0.2 - The Escapists 2
# 1.0 - Lunacid
# 1.0 - The Case of the Golden Idol
# 1.0 - Thief™ II: The Metal Age
# -1.0 - The Test
# 1.0 - Filcher
# 0.2 - FAITH: The Unholy Trinity
# 0.2 - Europa Universalis IV
# 1.0 - The Eternal Castle [REMASTERED]
# 1.0 - Zero Hour
# --------------------
#
# ------ Recommendations
# 8.096 -- Counter-Strike 2
# 6.288 -- HELLDIVERS™ 2
# 4.46 -- Raft
# 4.381 -- BeamNG.drive
# 4.329 -- Garry's Mod
# 4.328 -- Team Fortress 2
# 4.317 -- Baldur's Gate 3
# 4.077 -- The Red Strings Club
# 4.072 -- Blood Nova
# 4.034 -- Whispers of a Machine
# 3.892 -- Resonance
# 3.842 -- Detective Di: The Silk Rose Murders
# 3.803 -- Gemini Rue
# 3.728 -- Dota 2
# 3.727 -- ULTRAKILL
# 3.727 -- Half-Life: Alyx
# 3.727 -- Stardew Valley
# 3.688 -- Mount & Blade: Warband
# 3.688 -- Bloons TD 6
# 3.688 -- Cookie Clicker
# --------------------
#
# Runtime: 4.71s
#
# ------ User profile:
# 1.0 - Defense Grid: The Awakening
# 1.0 - Natural Selection 2
# 1.0 - Hotline Miami 2: Wrong Number
# 1.0 - Half-Life 2: Episode Two
# 0.2 - Halo Infinite
# 1.0 - Portal 2
# 1.0 - Team Fortress 2
# 1.0 - FTL: Faster Than Light
# -1.0 - BioShock™ 2 Remastered
# 1.0 - Vampire Survivors
# 1.0 - Dystopia
# 1.0 - E.Y.E: Divine Cybermancy
# 1.0 - Blade Symphony
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 19.036 -- Counter-Strike 2
# 4.805 -- Sanctum
# 4.777 -- Sanctum 2
# 4.457 -- STAR WARS™ Republic Commando™
# 4.44 -- Half-Life 2: Lost Coast
# 4.229 -- People Playground
# 4.208 -- Guns of Icarus Online
# 4.206 -- Splitgate
# 4.2 -- Lethal Company
# 4.145 -- Crysis 2 - Maximum Edition
# 4.122 -- Portal
# 4.092 -- Call of Duty®: Black Ops II
# 4.023 -- Half-Life 2: Episode One
# 3.994 -- ELDEN RING
# 3.899 -- Halo: The Master Chief Collection
# 3.795 -- Half-Life: Alyx
# 3.795 -- Underground Blossom
# 3.795 -- Stardew Valley
# 3.755 -- Cookie Clicker
# 3.755 -- The Last Campfire
# --------------------
#
# Runtime: 4.54s
#
# ------ User profile:
# 1.0 - Halo Infinite
# 0.2 - DRAGON QUEST® XI S: Echoes of an Elusive Age™ - Definitive Edition
# -1.0 - SYNTHETIK: Legion Rising
# 1.0 - Cyberpunk 2077
# 1.0 - Enter the Gungeon
# 1.0 - Risk of Rain Returns
# -1.0 - Dead Cells
# 1.0 - UNDEFEATED
# 1.0 - Resident Evil 4
# 1.0 - Risk of Rain (2013)
# 1.0 - Songs of Syx
# 1.0 - Pit People®
# 1.0 - Voidigo
# --------------------
#
# ------ Recommendations
# 8.336 -- HELLDIVERS™ 2
# 4.766 -- Balatro
# 4.726 -- Left 4 Dead 2
# 4.568 -- Team Fortress 2
# 4.485 -- Star of Providence
# 4.449 -- Nuclear Throne
# 4.376 -- Dungreed
# 4.33 -- Warframe
# 4.29 -- Sid Meier’s Civilization® VI
# 4.097 -- Doomed to Hell
# 4.092 -- Dota 2
# 4.021 -- Cavity Busters
# 3.932 -- Crysis 2 - Maximum Edition
# 3.93 -- El Paso, Elsewhere
# 3.902 -- Death Road to Canada
# 3.848 -- Counter-Strike 2
# 3.727 -- A Hat in Time
# 3.727 -- Half-Life: Alyx
# 3.688 -- BeamNG.drive
# 3.688 -- Totally Accurate Battle Simulator
# --------------------
#
# Runtime: 4.64s
#
# ------ User profile:
# 1.0 - LARA CROFT AND THE TEMPLE OF OSIRIS™
# 1.0 - Persona 4 Golden
# 0.2 - Forza Horizon 5
# 1.0 - Ys I & II Chronicles+
# 1.0 - Valheim
# 1.0 - Sherlock Holmes: The Devil's Daughter
# 1.0 - Ys VIII: Lacrimosa of DANA
# 1.0 - Wolfenstein: The New Order
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Mafia: Definitive Edition
# 1.0 - Kingdom Come: Deliverance
# 1.0 - GreedFall
# 1.0 - Assassin's Creed® Odyssey
# 1.0 - State of Decay 2: Juggernaut Edition
# 1.0 - FIFA 22
# --------------------
#
# ------ Recommendations
# 7.699 -- Stardew Valley
# 6.616 -- Tomb Raider
# 6.338 -- Path of Exile
# 5.313 -- Trials of Mana
# 5.133 -- Counter-Strike 2
# 4.787 -- Ys: The Oath in Felghana
# 4.717 -- Ys Origin
# 4.676 -- ELDEN RING
# 4.671 -- Ys SEVEN
# 4.561 -- Ys VI: The Ark of Napishtim
# 4.513 -- The Witcher® 3: Wild Hunt
# 4.465 -- Hogwarts Legacy
# 4.446 -- Fable - The Lost Chapters
# 4.379 -- .hack//G.U. Last Recode
# 4.327 -- Tales of Arise
# 4.309 -- Sudeki
# 4.242 -- GRANDIA HD Remaster
# 4.238 -- The Witcher: Enhanced Edition Director's Cut
# 4.236 -- Kingdoms of Amalur: Reckoning™
# 4.153 -- Divinity II: Developer's Cut
# --------------------
#
# Runtime: 4.79s
#
# ------ User profile:
# 1.0 - No Man's Sky
# 1.0 - Battle Islands: Commanders
# 1.0 - Europa Universalis IV
# -1.0 - PUBG: BATTLEGROUNDS
# 1.0 - The Walking Dead: A New Frontier
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Tom Clancy's Rainbow Six® Siege
# -1.0 - Hearts of Iron IV
# 1.0 - The Walking Dead: The Final Season
# 1.0 - American Truck Simulator
# 1.0 - Hitman: Absolution™
# 1.0 - Grand Theft Auto IV: Complete Edition
# 1.0 - Tales from the Borderlands
# 1.0 - Mushroom Wars
# 1.0 - The Forest
# 1.0 - The Witcher 2: Assassins of Kings Enhanced Edition
# --------------------
#
# ------ Recommendations
# 9.221 -- Counter-Strike 2
# 4.795 -- The Walking Dead: Season Two
# 4.715 -- Portal 2
# 4.531 -- The Wolf Among Us
# 4.519 -- Team Fortress 2
# 4.482 -- The Walking Dead
# 4.455 -- Apex Legends™
# 4.405 -- Life is Strange: Before the Storm
# 4.39 -- Batman: The Enemy Within - The Telltale Series
# 4.313 -- Subnautica
# 4.219 -- The Witcher: Enhanced Edition Director's Cut
# 4.153 -- Fable - The Lost Chapters
# 4.138 -- Batman - The Telltale Series
# 4.098 -- The Walking Dead: Michonne - A Telltale Miniseries
# 4.016 -- Risen
# 3.939 -- Middle-earth™: Shadow of War™
# 3.825 -- Fable Anniversary
# 3.771 -- A Hat in Time
# 3.771 -- Half-Life: Alyx
# 3.732 -- Persona 5 Royal
# --------------------
#
# Runtime: 4.66s
#
# ------ User profile:
# 0.2 - Deep Rock Galactic
# 1.0 - Idle Champions of the Forgotten Realms
# 1.0 - Cyberpunk 2077
# 1.0 - Metro Exodus
# 1.0 - Warframe
# 1.0 - Car Detailing Simulator: Prologue
# 1.0 - LIZARDS MUST DIE
# 1.0 - Titanfall® 2
# -1.0 - This War of Mine
# -1.0 - SUCCUBUS: Prologue
# -1.0 - Gladiator Guild Manager
# -1.0 - Ajax’s Trial
# -1.0 - Hellpoint: The Thespian Feast
# 1.0 - Chill Corner
# -1.0 - Crossout
# 0.2 - IdleOn - The Idle MMO
# --------------------
#
# ------ Recommendations
# 7.122 -- Phasmophobia
# 6.939 -- HELLDIVERS™ 2
# 6.01 -- Counter-Strike 2
# 4.62 -- Fallout 4
# 4.459 -- Just Shapes & Beats
# 4.307 -- Prey
# 4.221 -- Team Fortress 2
# 4.082 -- Resident Evil 7 Biohazard
# 3.993 -- The Evil Within 2
# 3.974 -- Potion Commotion
# 3.942 -- Rust
# 3.906 -- Metro: Last Light Redux
# 3.906 -- Metro 2033 Redux
# 3.903 -- Sid Meier’s Civilization® VI
# 3.723 -- OneShot
# 3.723 -- Half-Life: Alyx
# 3.684 -- Factorio
# 3.684 -- Brotato
# 3.684 -- Bloons TD 6
# 3.684 -- Fluffy Store
# --------------------
#
# Runtime: 4.71s
#
# ------ User profile:
# 1.0 - Cry of Fear
# 0.2 - Dead Space™ 3
# 1.0 - Portal Knights
# 1.0 - Dying Light
# 1.0 - Destiny 2
# 1.0 - Terraria
# 1.0 - The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 1.0 - Raft
# -1.0 - The Elder Scrolls® Online
# 1.0 - Garry's Mod
# 0.2 - Left 4 Dead
# 1.0 - PAYDAY 2
# -1.0 - PUBG: BATTLEGROUNDS
# 1.0 - Left 4 Dead 2
# 0.2 - Call of Duty®: Black Ops III
# 1.0 - Halo: The Master Chief Collection
# 1.0 - The Forest
# 1.0 - Rust
# 1.0 - Warframe
# -1.0 - Geometry Dash
# --------------------
#
# ------ Recommendations
# 9.425 -- Counter-Strike 2
# 4.981 -- Killing Floor 2
# 4.698 -- Necesse
# 4.635 -- Valheim
# 4.463 -- No More Room in Hell
# 4.405 -- Killing Floor - Toy Master
# 4.303 -- Team Fortress 2
# 4.162 -- Scrap Mechanic
# 4.02 -- Tom Clancy's Rainbow Six® Siege
# 4.014 -- Call of Duty®: Black Ops II
# 4.002 -- Green Hell
# 3.964 -- Stardew Valley
# 3.958 -- Zombie Panic! Source
# 3.906 -- Volcanoids
# 3.902 -- Stay Home
# 3.849 -- Dota 2
# 3.826 -- Frog Detective 3: Corruption at Cowboy County
# 3.826 -- I Frog-ot
# 3.787 -- The Henry Stickmin Collection
# 3.747 -- Slay the Spire
# --------------------
#
# Runtime: 4.88s
#
# ------ User profile:
# 1.0 - Sekiro™: Shadows Die Twice - GOTY Edition
# -1.0 - Call of Duty®: Warzone™
# 1.0 - Oxygen Not Included
# -1.0 - Z1 Battle Royale
# 1.0 - Tactics Ogre: Reborn
# 1.0 - The Wolf Among Us
# 1.0 - FINAL FANTASY VII REMAKE INTERGRADE
# 1.0 - Hood: Outlaws & Legends
# --------------------
#
# ------ Recommendations
# 8.146 -- Counter-Strike 2
# 6.287 -- HELLDIVERS™ 2
# 4.093 -- ELDEN RING
# 4.088 -- RimWorld
# 4.014 -- Batman™: Arkham Knight
# 4.007 -- The Final Earth 2
# 3.948 -- Empires of the Undergrowth
# 3.905 -- CRISIS CORE –FINAL FANTASY VII– REUNION
# 3.875 -- Grand Theft Auto V
# 3.865 -- Tom Clancy's Rainbow Six® Siege
# 3.83 -- Batman: The Enemy Within - The Telltale Series
# 3.744 -- A Hat in Time
# 3.744 -- The Henry Stickmin Collection
# 3.704 -- Mount & Blade: Warband
# 3.704 -- Kingdom Rush  - Tower Defense
# 3.704 -- The Looker
# 3.704 -- Slay the Spire
# 3.704 -- Bloons TD 6
# 3.665 -- Tomb Raider
# 3.665 -- GRIS
# --------------------
#
# Runtime: 4.48s
#
# ------ User profile:
# 1.0 - Hotline Miami 2: Wrong Number
# 1.0 - The Binding of Isaac: Rebirth
# 0.2 - Warframe
# 1.0 - Doki Doki Literature Club!
# 1.0 - Terraria
# 1.0 - Risk of Rain 2
# 1.0 - World War Z
# 1.0 - Vampire Survivors
# 1.0 - Montaro
# 1.0 - Don't Starve Together
# 0.2 - Predecessor
# --------------------
#
# ------ Recommendations
# 9.351 -- Counter-Strike 2
# 4.955 -- Necesse
# 4.701 -- Starbound
# 4.586 -- Dig or Die
# 4.222 -- Stardew Valley
# 4.194 -- Portal 2
# 4.09 -- Team Fortress 2
# 4.07 -- Hotline Miami
# 4.042 -- Geometry Dash
# 4.003 -- ELDEN RING
# 3.761 -- Half-Life: Alyx
# 3.761 -- Pineapple on pizza
# 3.761 -- A Hat in Time
# 3.721 -- Hot Dogs, Horseshoes & Hand Grenades
# 3.721 -- Kingdom Rush  - Tower Defense
# 3.721 -- STEINS;GATE
# 3.721 -- Meg's Monster
# 3.721 -- BeamNG.drive
# 3.721 -- Factorio
# 3.721 -- BattleBlock Theater®
# --------------------
#
# Runtime: 4.49s
#
# ------ User profile:
# 1.0 - Half-Life: Alyx
# 1.0 - FINAL FANTASY VII
# 1.0 - POSTAL 2
# 1.0 - Murder Miners
# 1.0 - Half-Life 2
# 1.0 - BattleBit Remastered
# 1.0 - Yume Nikki
# 1.0 - OneShot
# 1.0 - Pirates, Vikings, and Knights II
# 1.0 - Call of Duty®: Black Ops
# 1.0 - Halo: The Master Chief Collection
# 1.0 - Call of Duty®
# 1.0 - Half-Life 2: Episode One
# --------------------
#
# ------ Recommendations
# 8.159 -- Counter-Strike 2
# 6.062 -- Team Fortress 2
# 5.878 -- Half-Life 2: Episode Two
# 5.543 -- Black Mesa
# 5.269 -- Halo Infinite
# 5.011 -- Half-Life: Opposing Force
# 4.751 -- Half-Life 2: Lost Coast
# 4.452 -- Red Faction
# 4.416 -- Half-Life: Blue Shift
# 4.366 -- Far Cry®
# 4.333 -- Half-Life
# 4.262 -- Call of Duty®: Modern Warfare® 2 (2009)
# 4.213 -- Call of Duty®: Black Ops II
# 4.192 -- Stardew Valley
# 4.187 -- Resident Evil 7 Biohazard
# 4.113 -- Fallout: New Vegas
# 3.949 -- Battlefield 4™
# 3.903 -- The Hanged Man
# 3.9 -- Arma 3
# 3.812 -- STAR WARS Jedi: Fallen Order™
# --------------------
#
# Runtime: 4.54s
#
# ------ User profile:
# 0.2 - Barony
# 0.2 - Halo 3 Mod Tools - MCC
# 0.2 - Project Zomboid
# 0.2 - DRAGON QUEST® XI S: Echoes of an Elusive Age™ - Definitive Edition
# 0.2 - Dungeon Defenders
# 0.2 - Yakuza: Like a Dragon
# 0.2 - Terraria
# 0.2 - FINAL FANTASY VII REMAKE INTERGRADE
# 0.2 - Tower Unite
# 0.2 - Streets of Rogue
# 0.2 - The Escapists 2
# 0.2 - EARTH DEFENSE FORCE 5
# 0.2 - Super Auto Pets
# 0.2 - Halo: The Master Chief Collection
# 0.2 - Graveyard Keeper
# 0.2 - VRChat
# 0.2 - Juice Galaxy
# 0.2 - Oh Deer
# 0.2 - Crab Champions
# --------------------
#
# ------ Recommendations
# 7.649 -- Counter-Strike 2
# 6.403 -- HELLDIVERS™ 2
# 5.955 -- Dig or Die
# 5.36 -- Necesse
# 4.752 -- The Legend of Heroes: Trails of Cold Steel
# 4.734 -- Crawl
# 4.729 -- Stardew Valley
# 4.666 -- Team Fortress 2
# 4.488 -- Wizard of Legend
# 4.478 -- Junk Jack
# 4.476 -- Phasmophobia
# 4.421 -- Heroes of Hammerwatch
# 4.324 -- Magicite
# 4.246 -- Ready or Not
# 4.129 -- CRISIS CORE –FINAL FANTASY VII– REUNION
# 4.08 -- Tom Clancy's Rainbow Six® Siege
# 4.047 -- STAR WARS™ Battlefront
# 3.953 -- FAIRY TAIL
# 3.845 -- Apex Legends™
# 3.816 -- Crossout
# --------------------
#
# Runtime: 4.8s
#
# ------ User profile:
# 1.0 - Dead by Daylight
# 1.0 - Horizon Forbidden West™ Complete Edition
# 0.2 - Battlefield 4™
# 1.0 - DARK SOULS™: REMASTERED
# 1.0 - Life is Strange - Episode 1
# 0.2 - Lethal Company
# 0.2 - SteamVR
# 0.2 - FOR HONOR™
# 0.2 - Don't Starve Together
# 1.0 - Raft
# 1.0 - DARK SOULS™ III
# --------------------
#
# ------ Recommendations
# 7.645 -- Counter-Strike 2
# 6.887 -- Baldur's Gate 3
# 6.473 -- ELDEN RING
# 6.165 -- Golf It!
# 4.385 -- DARK SOULS™ II: Scholar of the First Sin
# 4.319 -- Monster Hunter: World
# 4.312 -- DARK SOULS™ II
# 4.298 -- Fable - The Lost Chapters
# 4.272 -- Dragon's Dogma: Dark Arisen
# 4.135 -- Team Fortress 2
# 4.052 -- Necesse
# 4.02 -- HELLDIVERS™ 2
# 3.952 -- Life is Strange: Before the Storm
# 3.802 -- Two Worlds Epic Edition
# 3.791 -- Tom Clancy's Rainbow Six® Siege
# 3.767 -- Green Hell
# 3.729 -- ULTRAKILL
# 3.689 -- Slay the Spire
# 3.689 -- BeamNG.drive
# 3.689 -- Mount & Blade: Warband
# --------------------
#
# Runtime: 4.54s
#
# ------ User profile:
# -1.0 - STALCRAFT
# 0.2 - Counter-Strike 2
# 0.2 - Project Zomboid
# 0.2 - Apex Legends™
# 0.2 - BONEWORKS
# 1.0 - Hunt: Showdown
# 1.0 - Frostpunk
# 1.0 - Detroit: Become Human
# 0.2 - GoreBox
# 1.0 - BattleBit Remastered
# 1.0 - Squad
# 0.2 - People Playground
# 1.0 - RimWorld
# 0.2 - THE FINALS
# 0.2 - Resident Evil 4 (2005)
# 1.0 - Noita
# 0.2 - Battlefield™ 1
# 0.2 - PUBG: BATTLEGROUNDS
# 1.0 - 7 Days to Die
# 1.0 - The Walking Dead Onslaught
# 1.0 - Hearts of Iron IV
# 0.2 - BeamNG.drive
# 0.2 - Mount & Blade: Warband
# 0.2 - SteamVR
# 0.2 - Resident Evil 7 Biohazard
# 1.0 - METAL GEAR RISING: REVENGEANCE
# 0.2 - Into the Radius VR
# 1.0 - Kenshi
# 0.2 - War Thunder
# 0.2 - Cities: Skylines
# 1.0 - The Walking Dead
# 1.0 - Blade and Sorcery
# 1.0 - Brick Rigs
# 0.2 - Red Dead Redemption 2
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 7.032 -- Left 4 Dead 2
# 6.962 -- Rust
# 6.79 -- Hogwarts Legacy
# 5.331 -- Empires of the Undergrowth
# 4.741 -- Against the Storm
# 4.704 -- Judgment: Apocalypse Survival Simulation
# 4.419 -- First Feudal
# 4.381 -- Lethal Company
# 4.32 -- Team Fortress 2
# 4.31 -- Quake II
# 4.249 -- The Walking Dead: Season Two
# 4.186 -- The Elder Scrolls V: Skyrim Special Edition
# 4.006 -- HELLDIVERS™ 2
# 3.953 -- The Walking Dead: Saints & Sinners
# 3.937 -- Oxygen
# 3.912 -- Verdun
# 3.903 -- Grand Theft Auto V
# 3.847 -- Battlerace
# 3.8 -- Isonzo
# 3.706 -- Half-Life: Alyx
# --------------------
#
# Runtime: 5.79s
#
# Positives: 16
# Negatives: 6
# Score: 1.6692704354469061
#
# ---
# Good:
# [(0, 1), (6, 11), (10, 17), (11, 3), (13, 7), (24, 8), (25, 5), (29, 1), (38, 17), (42, 1), (46, 2), (49, 6), (63, 7), (65, 1), (66, 9), (69, 20)]
#
# ---
# Bad:
# [(2, 1), (23, 9), (28, 1), (45, 1), (63, 1), (66, 5)]
# 1.6692704354469061
# | 23        | 1.669     | 84.78     | 23.54     | 1.36      | 3.968     | 0.6694    | 20.0      | 129.9     |
# =============================================================================================================
# {'target': 3.5095959595959596, 'params': {'collab_filter_limit': 75.54487413172255, 'content_filter_limit': 11.85801650879991, 'double_bonus': 1.822634555704315, 'popular_bias': 2.5115723710618747, 'ratio': 0.24878869473895965, 'recs': 20.0, 'similar_user_limit': 138.62528132298237}}
# {'target': 3.5095959595959596,
#  'params': {'collab_filter_limit': 75.54487413172255,
#   'content_filter_limit': 11.85801650879991,
#   'double_bonus': 1.822634555704315,
#   'popular_bias': 2.5115723710618747,
#   'ratio': 0.24878869473895965,
#   'recs': 20.0,
#   'similar_user_limit': 138.62528132298237}}

# %% [markdown]
# ### Conclusion
#
# While the bulk of the conclusions and analysis will be in the forthcoming presentation step, we can see by the 'target' score that we are able to games that the user will enjoy much more frequently than games the user will not enjoy, and that the optimal parameters for our evaluation function are as follows (I had to remove the outputs to make the notebook readable):
#
# {'target': 13.0,
#  'params': {'collab_filter_limit': 103.48734651630105,
#   'content_filter_limit': 32.921446485352185,
#   'double_bonus': 1.7930894746349533,
#   'popular_bias': 1.8472839810604431,
#   'ratio': 0.7140703845572055,
#   'recs': 20.0,
#   'similar_user_limit': 250.0}}
