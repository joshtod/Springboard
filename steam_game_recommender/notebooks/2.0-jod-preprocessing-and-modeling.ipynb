# %% [markdown]
# ### Preprocessing
#
# Uses the following data:
# 1. games_df, a table of general information about (almost) all Steam games
# 2. review_table, a table of 6+million reviews scraped from the Steam store, listing the user, game, etc
# 3. recently_played_df, a table of users' recently played games with playtimes
#
# Accomplishes the following:
# 1. Generate tables containing vectors for every game and every user. Our inputs will be limited to items in this table.
# 2. Generate reduced tables containing vectors of only the games and users that have rich enough info to be useful for prediction.

# %%
import pandas as pd
import numpy as np

from bidict import bidict

import pickle
import pyarrow as pa
import pyarrow.parquet as pq


import scipy.sparse as sp
from scipy.sparse import coo_matrix, csr_matrix, lil_matrix, save_npz

# %store -r tags_dict

# %%
# Load

with open('../data/interim/1 - Games DF - Wrangled.pkl', 'rb') as file :
    games_df = pickle.load(file)

review_table = pq.read_table('../data/interim/cleaned_reviews.parquet')

with open('../data/interim/recently_played_cleaned.pkl', 'rb') as file :
    recently_played_df = pickle.load(file)

# %% [markdown]
# ### Make games vectors/matrices
#
# We'll produce one matrix with all known games. This will be used to vectorize input.
#
# Then we'll produce a matrix that contains only those games with sufficient information to be subjects of recommendation.

# %%
# Isolate the info we'll use for the vectors
games_df_tags_only = games_df[['app_id', 'tags', 'tag_list']]
games_df_tags_only.head()
# Out:
#     app_id                                               tags  \
# 0      730  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1   553850  [Action, Online Co-Op, Multiplayer, Third-Pers...
# 2  1086940  [RPG, Choices Matter, Story Rich, Character Cu...
# 3  1245620  [Souls-like, Dark Fantasy, Open World, RPG, Di...
# 4  1623730  [Multiplayer, Open World, Survival, Creature C...
#
#                                             tag_list
# 0  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1  [Action, Online Co-Op, Third-Person Shooter, M...
# 2  [RPG, Choices Matter, Story Rich, Character Cu...
# 3  [Souls-like, Dark Fantasy, Open World, RPG, Di...
# 4  [Multiplayer, Open World, Survival, Creature C...

# %%
# Make a handy dict for the app_ids and their new indexes
game_to_full_index = bidict()
for index, row in games_df_tags_only.iterrows() :
    game_to_full_index[index] = row['app_id']
game_to_full_index = game_to_full_index.inverse

# %%
# Get our list of columns
used_tags = set(tags_dict.values())

# %%
# Prepare our sparse matrix
# NOTE: We will weight PRIMARY tags more strongly than non-primary tags.
# A lower weight_ratio favors primary tags more.

weight_ratio = 0.8

matrix_values = []

for index, row in games_df_tags_only.iterrows() :
    skips = set()
    for tag in row['tags'] :
        skips.add(tag)
        tup = (index, tag, 1)
        matrix_values.append(tup)
    for tag in row['tag_list'] :
        if tag not in skips :
                    tup = (index, tag, weight_ratio)
                    matrix_values.append(tup)

matrix_values[0]
# Out:
# (0, 'FPS', 1)

# %%
# To make the matrix, we must index our tags.
tag_to_col_index = bidict()
i = 0
for value in tags_dict.values() :
    tag_to_col_index[value] = i
    i += 1

# %%
# Make the matrix

rows = [row[0] for row in matrix_values]
columns = [tag_to_col_index[row[1]] for row in matrix_values]
values = [row[2] for row in matrix_values]

matrix_row_count = max(rows)+1
matrix_col_count = max(columns)+1

game_tags_matrix = coo_matrix((values, (rows, columns)), shape=(matrix_row_count, matrix_col_count))
game_tags_matrix = csr_matrix(game_tags_matrix)

# %%
# Good job, everybody! Let's save it and move on.
save_npz('../data/processed/full_game_tag_matrix.npz', game_tags_matrix)

# And also the index dicts.
with open('../data/processed/tag_to_col_index.pkl', "wb") as file :
    pickle.dump(tag_to_col_index, file)

with open('../data/processed/game_to_full_index.pkl', "wb") as file :
    pickle.dump(game_to_full_index, file)

# %% [markdown]
# Now we subset this matrix to include only games with 10+ tags.
#
# This index will be smaller, but we must be careful to note the original index values. That's the only way we can relate the rows in this matrix to any other matrix.

# %%
nonzero_counts = pd.Series(game_tags_matrix.getnnz(axis=1))
can_keep = nonzero_counts >= 10
game_tags_matrix_reduced = game_tags_matrix[can_keep]

## This creates a dict with:
##  KEYS == reduced matrix index
##  VALUES == corresponding full matrix index
game_reduced_index_to_full_index = bidict()
i=0
for index, value in can_keep.items() :
    if value==True :
        game_reduced_index_to_full_index[i]=index
        i += 1

# %%
# Save! That! Matrix!
save_npz('../data/processed/reduced_game_tag_matrix.npz', game_tags_matrix_reduced)

# And the dict, of course.
with open('../data/processed/game_reduced_index_to_full_index.pkl', 'wb') as file :
    pickle.dump(game_reduced_index_to_full_index, file)

# %% [markdown]
# ### Now we make the users matrices...

# %%
recently_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4181501 entries, 0 to 4181500
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user         object
#  1   app_id       int64
#  2   playtime_2w  int64
#  3   playtime_f   int64
# dtypes: int64(3), object(1)
# memory usage: 127.6+ MB

# %%
review_table.shape
# Out:
# (6747619, 11)

# %%
# Because our games_df does not contain every single game on Steam, it's possible
# that a game will be touched in a review or recently_played about which we cannot
# make inference.
# Let's make a set of all usable games to help limit our tables to legal values.
usable_app_ids = set(games_df['app_id'].values)
len(usable_app_ids)
# Out:
# 100894

# %%
# Now let's reduce the above datasets to only those which touch usable games.
recently_played_df = recently_played_df[recently_played_df['app_id'].isin(usable_app_ids)].reset_index(drop=True)
recently_played_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3593525 entries, 0 to 3593524
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user         object
#  1   app_id       int64
#  2   playtime_2w  int64
#  3   playtime_f   int64
# dtypes: int64(3), object(1)
# memory usage: 109.7+ MB

# %%
# To subset the review_talbe, we'll have to pandacize it first.

review_df = review_table.to_pandas()
review_df = review_df[review_df['app_id'].isin(usable_app_ids)].reset_index(drop=True)
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5726093 entries, 0 to 5726092
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user             object
#  1   app_id           int64
#  2   positive         int64
#  3   total_playtime   float64
#  4   review_playtime  float64
#  5   text             object
#  6   helpful_count    int64
#  7   review_date      object
#  8   edit_date        object
#  9   date_scraped     object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 436.9+ MB

# %%
# We should save processed versions of these for use in the modeling notebook.
usable_review_table = pa.Table.from_pandas(review_df)
pq.write_table(usable_review_table, '../data/processed/usable_review_table.parquet')

with open('../data/processed/usable_recently_played.pkl', 'wb') as file :
    pickle.dump(recently_played_df, file)

# %%
# The two tables above contain different but overlapping sets of users.
# In order to combine them into a single users matrix, we must first create
# a unified index for all touched users.

recently_users = set(recently_played_df['user'].values)
review_users = set(review_table['user'].to_pylist())
touched_users = recently_users | review_users

user_to_full_index = bidict()
i=0
for user in touched_users :
    user_to_full_index[user] = i
    i+=1

# %%
# We also need a unified index for games.

recently_games =set(recently_played_df['app_id'].values)
review_games = set(review_table['app_id'].to_pylist())
touched_games = recently_games | review_games

game_to_col_index = bidict()
i=0
for game in touched_games :
    game_to_col_index[game] = i
    i+=1

# %%
# Now let's prepare our points.

recently_played_points = recently_played_df.apply( \
                                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], 0.2), axis=1) \
                                .tolist()

# %%
# Since we'll have to update this matrix in a sec, let's make it a lil_matrix first.

user_info_matrix = lil_matrix((len(touched_users), len(touched_games)), dtype=float)

for point in recently_played_points :
    user_info_matrix[point[0], point[1]] = point[2]

# %%
# Now let's prepare the review data to update that matrix.

positive_reviews = review_df[review_df['positive']==1][['user', 'app_id']]
negative_reviews = review_df[review_df['positive']==0][['user', 'app_id']]

positive_points = positive_reviews.apply( \
                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], 1), axis=1) \
                .tolist()
                                
negative_points = negative_reviews.apply( \
                lambda row: (user_to_full_index[row['user']], game_to_col_index[row['app_id']], -1), axis=1) \
                .tolist()

# %%
## Now, we update the matrix.

for point in positive_points :
    user_info_matrix[point[0], point[1]] = point[2]

for point in negative_points :
    user_info_matrix[point[0], point[1]] = point[2]

# %%
## Just for funsies, make it the same format as our games matrix.
user_info_matrix = user_info_matrix.tocsr()

# %%
# Save! That! Matrix!
save_npz('../data/processed/user_info_matrix.npz', user_info_matrix)

# And the dicts, of course.
with open('../data/processed/user_to_full_index.pkl', 'wb') as file :
    pickle.dump(user_to_full_index, file)

with open('../data/processed/game_to_col_index.pkl', 'wb') as file :
    pickle.dump(game_to_col_index, file)

# %%
# Now we create a subset of the matrix that contains only users with enough info for prediction.
# Where should we put the threshold?

nonzero_counts = pd.Series(user_info_matrix.getnnz(axis=1))
nonzero_counts.describe()
# Out:
# count    1.887354e+06
# mean     4.779766e+00
# std      7.041132e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      6.000000e+00
# max      5.517000e+03
# dtype: float64

# %%
# I'll arbitrarily choose 5. Sue me! I dare you.

can_keep = nonzero_counts >= 5
user_info_matrix_reduced = user_info_matrix[can_keep]

## This creates a dict with:
##  KEYS == reduced matrix index
##  VALUES == corresponding full matrix index

user_reduced_index_to_full_index = bidict()
i=0
for index, value in can_keep.items() :
    if value==True :
        user_reduced_index_to_full_index[i]=index
        i += 1

# %%
# Save! That! Matrix!
save_npz('../data/processed/user_info_matrix_reduced.npz', user_info_matrix_reduced)

# etc etc
with open('../data/processed/user_reduced_index_to_full_index.pkl', 'wb') as file :
    pickle.dump(user_reduced_index_to_full_index, file)

# %% [markdown]
# At time of inference, the top X consine similarity users' rows will be called up, and the most common games not already played by the user will be recommended.

# %% [markdown]
# # Modeling
#
# Describes a system for taking a single user_id as an input and generating game recommendations.

# %%
from scipy import stats

from scipy.sparse import load_npz
from sklearn.metrics.pairwise import cosine_similarity

from bayes_opt import BayesianOptimization

import time
import random

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
# Load the dfs to display the rec results in a human-readable way
with open('../data/interim/1 - Games DF - Wrangled.pkl', 'rb') as file :
    games_df = pickle.load(file)
with open('../data/processed/usable_recently_played.pkl', 'rb') as file :
    recently_played_df = pickle.load(file)
review_table = pq.read_table('../data/processed/usable_review_table.parquet')
with open('../data/raw/all_users', 'rb') as file :
    all_users = pickle.load(file)

# Load the tables used to define input
game_tags_matrix = load_npz('../data/processed/full_game_tag_matrix.npz')
user_info_matrix = load_npz('../data/processed/user_info_matrix.npz')

# Load the tables used for inference
game_tags_matrix_reduced = load_npz('../data/processed/reduced_game_tag_matrix.npz')
user_info_matrix_reduced = load_npz('../data/processed/user_info_matrix_reduced.npz')

# Load the index converters for the games/tags matrix
with open('../data/processed/tag_to_col_index.pkl', "rb") as file :
    tag_to_col_index = pickle.load(file)
with open('../data/processed/game_reduced_index_to_full_index.pkl', 'rb') as file :
    game_reduced_index_to_full_index = pickle.load(file)
with open('../data/processed/game_to_full_index.pkl', 'rb') as file :
    game_to_full_index = pickle.load(file)

# Load the index converters for the users/games matrix
with open('../data/processed/user_to_full_index.pkl', 'rb') as file :
    user_to_full_index = pickle.load(file)
with open('../data/processed/game_to_col_index.pkl', 'rb') as file :
    game_to_col_index = pickle.load(file)
with open('../data/processed/user_reduced_index_to_full_index.pkl', 'rb') as file :
    user_reduced_index_to_full_index = pickle.load(file)

# %% [markdown]
# ## Define the functions

# %% [markdown]
# ### Collaborative recommendations, step 1: find similar users

# %%
# Get an arbitrary number of similar users
def get_similar_users(target_user_row, similar_user_limit=50, test_user_indices=[], testing=False, verbose=False) :
    """
    Takes a user id and returns a sorted descending series of the X most similar users:
        keys = user index (in the reduced matrix)
        values = cosine similarity
    Rows that have played no games that the target user hasn't also played are removed,*
    as they have no novel info for prediction.
    """

    # Go ahead and run cosine similarity now, so that the scores can be associated with the correct index (the reduced user matrix index).
    row_cosine_similarities = pd.Series(cosine_similarity(target_user_row, user_info_matrix_reduced)[0], name="similarity_score")

    # If we're testing, remove all test users from this step
    if testing==True :
        for index in row_cosine_similarities.index :
            if index in test_user_indices :
                row_cosine_similarities = row_cosine_similarities.drop(index)

    # Remove the 1s.
    # This eliminates any user whose play profile is identical to that of the target user,
    # meaning they would be useless for prediction.
    # Also removes the target user.
    row_cosine_similarities = row_cosine_similarities[row_cosine_similarities < 1]

    row_cosine_similarities.sort_values(ascending=False, inplace=True)
    most_similar_users = row_cosine_similarities[:similar_user_limit]

    if verbose==True :
        print(f"Top {similar_user_limit} most similar users:")
        for index, value in most_similar_users.items() :
            print(f"{round(value, 9)} -- {index}")
            
    return(most_similar_users)

# %% [markdown]
# ### Collaborative recommendations, step 2: generate scores

# %%
# Generate suggestions based on that.
# First, find out all the games these "similar users" have played.
# Then, weight those playes by the similarity score, then sum them across users.

# NOTE：I could speed all this up by just using arrays instead of rows/columns


def get_collab_scores(similar_users, collab_filter_limit=50, target_user_touched_games=[], verbose=False) :
    """
    Takes a series in the format:
        keys: user index (in the reduced matrix)
        values: similarity score to target user (float)

    Looks at all those users' games, calculates a utility score for their played games
    based on the group's collective utility score for those games.

    Returns a series of len {collab_filter_limit} in the format:
        keys: app_id
        values: collab filter score
    """

    # We need to make a column in a df for each game, so we grab all games
    # here (indexed by game col index).
    # We remove any games already touched by the target user along the way.
    relevant_games = set()
    for user in similar_users.keys() :
        for game in user_info_matrix[user].indices :
            if game not in target_user_touched_games :
                relevant_games.add(game)
    
    similar_users_df = pd.DataFrame(index=similar_users.index)

    # Create a column for each game
    for game in relevant_games :
        similar_users_df[game] = 0

    # Now fill those columns with the scores
    for user in similar_users.keys() :
        for game in user_info_matrix[user].indices :
            similar_users_df.loc[user, game] = user_info_matrix_reduced[user, game]

    # Some games have an outlier number of comments, which makes them ALWAYS appear
    # in the collab recs list.
    # This bit of code counteracts that by multiplying each value in each game's col
    # by the inverse log of the sum of the col.
    # Needlessly complex? Maybe. But the motivation behind nerfing the *individual*
    # values in the df instead of just nerfing the games at the end is because 
    # nerfing them at the end (using log) will also nerf the effect of the similarity
    # score, which I don't want.
    # So, finding a way to modify the individual game preference scores before applying
    # the similarity score to the column sums seems preferable.

    # To do this, we can't have negative values. Even zeroes are untrustworthy.
    # Increasing the values here does not skew the overall results, since the
    # results will be normalized.
    # minimum = np.nanmin(similar_users_df.values)

    # if minimum < 0 :
    #     similar_users_df = similar_users_df - (minimum - 1.0001)
    # else :
    #     similar_users_df = similar_users_df + 1.0001

    # for col in similar_users_df.columns :
    #     col_sum = similar_users_df[col].sum()
    #     col_coef = 1/np.log(col_sum ** 1.3)
    #     similar_users_df[col] = similar_users_df[col] * col_coef
    # NOTE: This code just isn't having the desired result! A new approach is needed.
    # Maybe just identify any outliers, and nerf that column iff they appear??? dxdx

    # TODO: Alternatively, consider applying this step while compiling the matrices...!

    # Now multiply the scores by the similarity score
    for user, row in similar_users_df.iterrows() :
        for game in relevant_games :
            if row[game] != 0 :
                similar_users_df.loc[user, game] = similar_users[user] * row[game]

    # Now collect those scores
    # NOTE: CONVERTS FROM GAME COL INDEX BACK TO APP_ID AT THIS STEP
    collab_filt_rec_scores = {}
    for game in relevant_games:
        collab_filt_rec_scores[game_to_col_index.inverse[game]] = similar_users_df[game].sum()

    collab_filt_scores = pd.Series(collab_filt_rec_scores, name="collab_rec_score").sort_values(ascending=False)

    # Limit the output
    collab_filt_scores = collab_filt_scores[:collab_filter_limit]
    
    # Normalize
    collab_filt_scores = stats.zscore(collab_filt_scores.astype(float))

    # To make them interactible with later scores, let's standardize them
    # scaler = MinMaxScaler()
    # collab_filt_scores = pd.Series(scaler.fit_transform(collab_filt_rec_scores.values.reshape(-1,1)).flatten(), index=collab_filt_rec_scores.index)
    # if verbose==True :
    #     for app_id, score in collab_filt_scores.items() :
    #         print(f"{round(score, 3)} -- {games_df[games_df['app_id']==app_id]['title'].values[0]}")
    
    return collab_filt_scores

# %% [markdown]
# ### Content-based recommendations

# %%
# NOTE: STRETCH GOAL: Determine multimodality, generate different lists of scores

# %%
# Determine most similar games for each, multiply by user preference, MinMaxScale.

def get_content_scores(target_user_row, content_filter_limit, verbose=False) :

    """
    Takes a row from the users/games table, then does the following:
        1. Finds recs for each from the reduced game/tags matrix
        2. Creates a descending-sorted 10-row Series:
            keys = game's index (relative to main games_df)
            values = queried game's cosine similarity score to the queried game
        3. Weights all values in the series by the user's preference for the game
        4. Combines all resulting series into a single series with sim scores summed
        5. Returns the series
    """

    # Get the most recent games.
    # I already have the games in terms of col indices in the users matrix.
    # I need the indices for the games matrix, to do cos similarity.

    # Go from game col index to app_id
    # played_game_app_ids = [game_to_col_index.inverse[game] for game in target_user_row.indices]
    # # Go from app_id to full game row index
    # played_game_full_matrix_row_indices = [game_to_full_index[game] for game in played_game_app_ids]

    # Find the sim scores for each game, adding them to the main list
    similarity_series_list = []
    full_row_indexes = []

    for query_index in target_user_row.indices :

        # Get the reduced game/tags matrix index
        current_app_id = game_to_col_index.inverse[query_index] 
        current_full_row_index = game_to_full_index[current_app_id]
        try :
            reduced_row_index = game_reduced_index_to_full_index.inverse[current_full_row_index]
        except :
            ####
            continue 

        # Let's grab the full row index. We will later use this to remove
        # already-touched games from the recommendations.
        full_row_indexes.append(current_full_row_index)

        # Find the similarity score between games
        # The resulting series is indexed by the reduced games matrix
        row_cosine_similarities = pd.Series(cosine_similarity(game_tags_matrix[current_full_row_index], game_tags_matrix_reduced)[0])
        # Reindex the predictions back to the full game matrix index
        row_cosine_similarities.index = [game_reduced_index_to_full_index[index] for index in row_cosine_similarities.index]
        row_cosine_similarities.sort_values(ascending=False, inplace=True)
        # Since we cannot know ahead of time how many games the user has touched,
        # and the user may have only touched one game,
        # we can safely limit the results here to the overall content filter limit.
        # This will ensure that the full number of scores are returned no matter 
        # how many games were touched. 
        # This is still indexed by the full game matrix.
        top_similar = row_cosine_similarities[:content_filter_limit]

        # Now, get a coefficient to represent the user's preference for the game in question.
        # All games similar to this game will be modified by this coefficient.
        # First we find the game's column in the full user matrix
        preference_coefficient = target_user_row[0, query_index]
        # Then we just multiply.
        top_similar = top_similar * preference_coefficient

        # That's all we need for the score! Let's append.
        similarity_series_list.append(top_similar)

        # if verbose == True :
        #     print(f"Recs for {games_df.loc[current_full_row_index]['title']}:")
        #     for rec in top_similar.items() :
        #         print(f"{round(rec[1], 3)} -- {games_df.loc[rec[0]]['title']}")

    # Combine the serieses into the main series.
    # Here it's still indexed by full game matrix index.
    final_scores = pd.Series()
    for similarity_series in similarity_series_list :
        final_scores = final_scores.add(similarity_series, fill_value=0)
    final_scores = final_scores.sort_values(ascending=False)

    # Remove already-played games from the main series
    for game in full_row_indexes :
        try :
            final_scores = final_scores.drop(labels=game)
        except :
            continue

    # Normalize the series to make it similar to the collaborative score series
    # I suppose the original values were some wonky kind of float that didn't work
    # with scipy, so we coerce them here.
    content_filt_scores = stats.zscore(final_scores.astype(float))

    # Return the desired number of values
    if len(content_filt_scores) < content_filter_limit :
        content_filter_limit = len(content_filt_scores)
    content_filt_scores = content_filt_scores[:content_filter_limit]

    # Set index to app_id
    content_filt_scores.index = [game_to_full_index.inverse[game] for game in content_filt_scores.index]

    # if verbose == True :
    #     print('------------------')
    #     for game, score in content_filt_scores.items() :
    #         print(f"{round(score, 3)} -- {games_df[games_df['app_id']==game]['title'].values[0]}")     
    
    return(content_filt_scores)

# %% [markdown]
# ### Combine the recs for final set of recs

# %%
# NOTE: Is it worth checking the scale discrepancy between the two and tweaking the ratio
# programmatically for each distribution?

# It may be that tweaking the relative weights of the collaborative and content-based filter results
# can improve accuracy. Let's define this as a function so we can play with that programmatically
# later, if need be.

def combine_scores(collaborative, content_based, double_bonus=0, popular_bias=0, ratio=0.5, recs=10) :
    """
    Takes a series of collaborative filtering scores (key=app_id, value=score)
    And a series of content based filtering scores with the same schema
    And a 0-1 ratio of importance between the two (higher ratio favors collaborative scores)
    And the "double_bonus", which is multiplied/summed to the score of each game that appears in both lists
    And a "popular_bias" which is multiplied to the pos_review_percent and added to the score
    And the number of recommendations to be returned

    Returns a series of game app_ids and recommendation scores
    """

    # Define the ratio-modified scores
    collaborative = collaborative * ratio
    content_based = content_based * (1-ratio)

    # Add them into the base final scores series
    final_recs = collaborative.add(content_based, fill_value=0)

    # Apply doubles bonus, if any
    doubles = []
    for game in collaborative.index :
        if game in content_based.index :
            doubles.append(game)
    for game in doubles :
        final_recs[game] += (final_recs[game] * double_bonus)

    # Apply popularity bonus, if any
    for index in final_recs.index :
        positive_review_percent = games_df[games_df['app_id']==index]['positive_review_percent'].values[0]
        final_recs[index] += (positive_review_percent * popular_bias)

    # Sort descending
    final_recs = final_recs.sort_values(ascending=False)

    # Determine length
    if len(final_recs) < recs :
        recs = len(final_recs)
    
    # Determine final recs
    final_recs = final_recs[:recs]

    return final_recs

# %% [markdown]
# ### Create unified function

# %%
def get_recs(user, similar_user_limit=50, collab_filter_limit=50, content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, recs=10, test_user_indices=[], test_user_rows=[], testing=False, verbose=False, show_result=False) :

    """
    Takes a user via full user matrix index
    Generates a series of recommendations
    
    """

    # Let's-a-go!
    begin = time.time()

    # Grab some useful info about the target user
    if testing==True :
        # target_user_id = user_reduced_index_to_full_index.inverse[game_reduced_index_to_full_index[user]]
        target_user_row = test_user_rows[test_user_indices.index(user)]
        # print(target_user_row)
    else :
        # target_user_id = user_to_full_index.inverse[user]
        target_user_row = user_info_matrix[user]

    target_user_touched_games = set(target_user_row.indices)

    # Display some stuff
    if show_result==True or verbose==True :
        print("------ User profile:")
        for game in target_user_touched_games :
            app_id = game_to_col_index.inverse[game]
            score = target_user_row[0, game]
            print(f"{score} - {games_df[games_df['app_id']==app_id]['title'].values[0]}")
        print("--------------------")

    # Get similar users
    most_similar_users = get_similar_users(target_user_row, similar_user_limit=similar_user_limit, test_user_indices=test_user_indices, testing=testing, verbose=False)
    if verbose==True :
        print("\nTop 5 most similar users\n")
        print(most_similar_users.head())
        print("--------------------------")

    # Print the params here to make it easier to intuit what's happening in the results
    if verbose==True :
        print(f"similar_user_limit: {similar_user_limit}")
        print(f"collab_filter_limit: {collab_filter_limit}")
        print(f"content_filter_limit: {content_filter_limit}")
        print(f"double_bonus: {round(double_bonus, 3)}")
        print(f"popular_bias: {round(popular_bias, 3)}")
        print(f"ratio col/con: {round(ratio, 3)}")
        print(f"num of recs: {recs}\n")

    # Get scores from them
    collab_filt_scores = get_collab_scores(most_similar_users, collab_filter_limit=collab_filter_limit, target_user_touched_games=target_user_touched_games, verbose=False)
    if verbose==True :
        print("Top 8 collab filt scores")
        for index, item in collab_filt_scores.head(8).items() :
            print(f"{round(item, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------------")

    # Get content filtering scores
    content_filt_scores = get_content_scores(target_user_row, content_filter_limit=content_filter_limit,  verbose=False)
    if verbose==True :
        print("Top 8 content filt scores")
        for index, item in content_filt_scores.head(8).items() :
            print(f"{round(item, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------------")
    
    # Calculate final scores
    final_recs = combine_scores(collab_filt_scores, content_filt_scores, double_bonus=double_bonus, popular_bias=popular_bias, ratio=ratio, recs=recs)

    if show_result==True or verbose==True:
        print('')
        print('------ Recommendations')
        for index, score in final_recs.items() :
            print(f"{round(score, 3)} -- {games_df[games_df['app_id']==index]['title'].values[0]}")
        print("--------------------")
        print(f"\nRuntime: {round(time.time()-begin, 2)}s\n")

    return final_recs

# %% [markdown]
# ## Execution!

# %%
# NOTE: Commented out so that running the notebook skips directly to testing/evaluation

# params = {
#     "similar_user_limit":50,
#     "collab_filter_limit":50,
#     "content_filter_limit":50,
#     "double_bonus":2,
#     "popular_bias":3,
#     "ratio":0.2,
#     "recs":20,
#     "verbose":False,
#     "show_result": True
# }

# recs = get_recs(50, **params)

# %% [markdown]
# ### Testing
#
# The basic idea is to remove a game or games from a user's profile (preferably a user with a significant number of touched games) and see if the engine recommends that game for the modified user profile.

# %%
# Programmatically assemble a set of usable user profiles (10+ touched games)

def get_test_users(user_count=50, minimum_games=10) :
    """
    Returns user_count number of test users (reduced user matrix index) as a list
    Each user must have at least minimum_games number of touched games and disliked at least one game
    """
    
    # VARS
    test_user_indices = []
    checked_indices = set()
    total_users = user_info_matrix_reduced.shape[0]

    while len(test_user_indices) < user_count :
        # Find a user at random
        index = random.randint(1, total_users)
        # Make sure you haven't done this one before
        if index not in checked_indices :
            # Make sure the user has enough games
            if len(user_info_matrix_reduced[index].indices) >= minimum_games :
                # Make sure they dislike at least one game
                if -1 in user_info_matrix_reduced[index].data :
                    # Log 'em!
                    test_user_indices.append(index)
        # Log 'em!
        checked_indices.add(index)
    
    return test_user_indices

# %%
# Randomly remove one or more game(s) from each, and save as a list of rows.

def create_test_rows(test_user_indices) :
    """
    Takes a list of reduced user matrix indices (test users)
    Returns 3 items:
    1. A list of those users' rows with the most- and least- liked games removed
    2. A list of those users' most-liked games (in matching index order)
    3. A list of those users' least-liked games (in matching index order)
    """

    test_rows = []
    liked_games = []
    disliked_games = []

    for test_user in test_user_indices :
        current_row = user_info_matrix_reduced[test_user]

        # Pick a game they LIKED VERY MUCH to remove
        liked_game = np.argmax(current_row.data)

        # Pick a game they HATED to remove.
        # It's possible that all values are positive, in which case this variable will
        # have no meaning. We will check that at the evaluation phase.
        # For now, we'll pull the value no matter what to perserve index relationships.
        disliked_game = np.argmin(current_row.data)

        # Save the values for evaluation
        liked = (test_user, current_row.indices[liked_game], current_row.data[liked_game])
        liked_games.append(liked)
        disliked = (test_user, current_row.indices[disliked_game], current_row.data[disliked_game])
        disliked_games.append(disliked)

        # Remove the values

        lil_row = current_row.tolil()
        lil_row[0, liked[1]] = 0
        lil_row[0, disliked[1]] = 0
        current_row = lil_row.tocsr()
        current_row.eliminate_zeros()

        # Add it to the list
        test_rows.append(current_row)
        
    return test_rows, liked_games, disliked_games

# %%
# Evaluation function

# Checks to see if POSITIVE game is in top X recs: +
# Checks to see if NEGATIVE game is in recs at all: -

# TODO: Reframe the holder lists as a series, where the game is the index, values are empty lists, 1 and -1 are added to the list where applicable
#   This will allow us to more easily see which users are best served, and how often we propose positive AND negative games to the same user

def binary_evaluator(results, verbose=False, show_result=False) :
    """"
    Takes a list of tuples with the schema:
        1. Series of recommendations (key=app_id, value=utility score)
        2. app_id of favorite game
        3. app_id of least favorite game

    Evaluates the recommendations in each tuple by:
        Adding 1 to the overall score if the favorite game is recommended
        Subtracting 1 from the overall score if the least favorite game is recommended
    
    Returns the score as an int
    """

    good = []
    bad = []

    for result in results :
        # Grab the series of recommendations
        recs = result[0].index
        # See if we recommended the liked game, and score accordingly
        if result[1] in recs :
            good.append(1)
        # See if we recommended the disliked game, and score accordingly
        if result[2] in recs :
            bad.append(1)
    
    validated = sum(good)
    disproved = sum(bad)
    score = validated - disproved

    print(f"Validated recommendations: {validated}")
    print(f"Disproved recommendations: {disproved}")

    return score

# %%
# Another evaluation function

# If a POSITIVE game is in the recs, add the utility score to the score (so higher ranking = higher score)
# If a NEGATIVE game is in the recs, subtract (same as above) (for same reason)

def ranked_evaluator(results, verbose=False, show_result=True) :
    """"
    Takes a list of tuples with the schema:
        1. Series of recommendations (key=app_id, value=utility score)
        2. app_id of favorite game
        3. app_id of least favorite game

    Evaluates the recommendations in each tuple by:
        Adding the inverse rank of the positive game if it's included in the recs
        Subtracting the inverse rank of the negative game if it's included in the recs
    
    Returns the score as an int
    """

    good = []
    bad = []

    score = 0
    user = 0

    for result in results :
        # Grab the series of recommendations
        recs = result[0].index
        # See if we recommended the liked game, and score accordingly
        if result[1] in recs :
            # Get the ranking (since it's as an index, it starts from 0 and needs a little boost to prevent 1/0)
            ranking = recs.get_loc(result[1]) + 1
            good.append((user, ranking))
            score += 1/ranking
        # See if we recommended the disliked game, and score accordingly
        if result[2] in recs :
            # Samesies, except we neg it
            ranking = recs.get_loc(result[2]) + 1
            bad.append((user, ranking))
            score -= 1/ranking
        user += 1 
    
    # validated = sum(good)
    # disproved = sum(bad)
    # score = validated - disproved

    if show_result == True :
        print(f"Positives: {len(good)}")
        print(f"Negatives: {len(bad)}")
        print(f"Score: {score}")
        print(f"\n---\nGood: \n{good}")
        print(f"\n---\nBad: \n{bad}")

    # print(f"Validated recommendations: {validated}")
    # print(f"Disproved recommendations: {disproved}")

    return score

# %%
# Run inference on each modified profile


def run_a_test(test_users=50, evaluator=ranked_evaluator, similar_user_limit=50, collab_filter_limit=50, \
               content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, recs=10, \
               testing=True, verbose=False, show_result=False) :
    
    global results

    # Generate X test user indices
    test_user_indices = get_test_users(test_users)

    test_rows, liked_games, disliked_games = create_test_rows(test_user_indices)

    # test_user_full_indices = [user_reduced_index_to_full_index[user] for user in test_user_indices]
    results = []

    params = {
        "test_user_indices":test_user_indices,
        "test_user_rows":test_rows,
        "similar_user_limit":similar_user_limit,
        "collab_filter_limit":collab_filter_limit,
        "content_filter_limit":content_filter_limit,
        "double_bonus":double_bonus,
        "popular_bias":popular_bias,
        "ratio":ratio,
        "recs":recs,
        "verbose":verbose,
        "show_result":show_result,
        "testing":testing
        }

    for i in range(len(test_user_indices)) :
        result = get_recs(test_user_indices[i], **params)
        results.append((result, \
                        game_to_col_index.inverse[liked_games[i][1]], \
                        game_to_col_index.inverse[disliked_games[i][1]]))
        
    score = evaluator(results, verbose=verbose, show_result=show_result)

    return score

# %%
# NOTE: Commented out so that running the notebook skips directly to testing/evaluation
minimums = []
col_sums=[]
test_params = {
    "test_users":1,
    "evaluator":ranked_evaluator,
    "similar_user_limit":50,
    "collab_filter_limit":20,
    "content_filter_limit":10,
    "double_bonus":1.79,
    "popular_bias":0,
    "ratio":0.71,
    "recs":20,
    "testing":True,
    "verbose":True,
    "show_result":True
}

run_a_test(**test_params)
# Out:
# ------ User profile:
# 0.2 - Digimon Story Cyber Sleuth: Complete Edition
# 1.0 - Cookie Clicker
# 0.2 - Digimon Survive
# 0.2 - 9-nine-:Episode 1
# 1.0 - Book of Yog Idle RPG
# 0.2 - Digimon World: Next Order
# 1.0 - Patrick's Parabox
# 0.2 - Touhou Mystia's Izakaya
# 0.2 - Ghost Trick: Phantom Detective
# 0.2 - Ys IX: Monstrum Nox
# 0.2 - Victoria 3
# 0.2 - BLUE REFLECTION: Second Light
# 0.2 - DRAGON QUEST® XI S: Echoes of an Elusive Age™ - Definitive Edition
# 1.0 - OCTOPATH TRAVELER™
# 0.2 - FINAL FANTASY XV WINDOWS EDITION
# 1.0 - Sonic Frontiers
# 0.2 - BlazBlue Entropy Effect
# 0.2 - EXIT KUN
# 0.2 - Evil Genius 2: World Domination
# 0.2 - Utawarerumono: Prelude to the Fallen
# 1.0 - Lost Judgment
# 0.2 - Persona® 5 Strikers
# 0.2 - FINAL FANTASY XII THE ZODIAC AGE
# 0.2 - SCARLET NEXUS
# 1.0 - LIVE A LIVE
# 0.2 - HUMANKIND™
# 1.0 - OCTOPATH TRAVELER II
# 0.2 - 鬼谷八荒 Tale of Immortal
# 0.2 - Fate/Samurai Remnant
# 0.2 - Football Manager 2024
# 0.2 - Tales of Berseria™
# 1.0 - Desktop Girlfriend
# 0.2 - Hatsune Miku: Project DIVA Mega Mix+
# 0.2 - Tactics Ogre: Reborn
# 0.2 - Terraformers
# 0.2 - FINAL FANTASY X/X-2 HD Remaster
# 0.2 - VPet-Simulator
# --------------------
#
# Top 5 most similar users
#
# 163778    0.355928
# 510658    0.298216
# 302104    0.291864
# 163707    0.291864
# 86578     0.291864
# Name: similarity_score, dtype: float64
# --------------------------
# similar_user_limit: 50
# collab_filter_limit: 20
# content_filter_limit: 10
# double_bonus: 1.79
# popular_bias: 0
# ratio col/con: 0.71
# num of recs: 20
#
# Top 8 collab filt scores
# 4.2 -- Destiny 2
# 0.52 -- Dead by Daylight
# 0.384 -- STAR WARS™ Battlefront II (Classic, 2005)
# 0.318 -- Counter-Strike 2
# -0.339 -- Vampire: The Masquerade - Bloodhunt
# -0.339 -- Battlefield™ 1
# -0.339 -- Bloons TD 6
# -0.339 -- Aokana - Four Rhythms Across the Blue
# --------------------------
# Top 8 content filt scores
# 5.354 -- OCTOPATH TRAVELER II Prologue Demo
# 3.33 -- FAIRY TAIL
# 3.24 -- Beyond Galaxyland
# 2.543 -- Book of Yog Idle RPG Demo
# 2.488 -- FINAL FANTASY VIII - REMASTERED
# 2.363 -- Judgment
# 2.335 -- Goblins Factory
# 2.195 -- Sokosignal
# --------------------------
#
# ------ Recommendations
# 2.982 -- Destiny 2
# 0.966 -- FAIRY TAIL
# 0.721 -- FINAL FANTASY VIII - REMASTERED
# 0.685 -- Judgment
# 0.612 -- SOK MIN
# 0.606 -- Pretty Angel
# 0.369 -- Dead by Daylight
# 0.273 -- STAR WARS™ Battlefront II (Classic, 2005)
# 0.226 -- Counter-Strike 2
# -0.241 -- Bloons TD 6
# -0.241 -- TRAIL OUT
# -0.241 -- Battlefield™ 1
# -0.241 -- Crusader Kings III
# -0.241 -- Aokana - Four Rhythms Across the Blue
# -0.241 -- Counter-Strike
# -0.241 -- Noita
# -0.241 -- Risk of Rain 2
# -0.241 -- Human Fall Flat
# -0.241 -- SMITE®
# -0.241 -- Double Action: Boogaloo
# --------------------
#
# Runtime: 3.39s
#
# Positives: 0
# Negatives: 0
# Score: 0
#
# ---
# Good:
# []
#
# ---
# Bad:
# []
# 0

# %% [markdown]
# ### O   P   T   I   M   I   Z   E

# %%
def boptimize(test_users=50, evaluator=ranked_evaluator, n_iter=4, init_points=10, verbose=False, show_result=False) :
    
    # We'll define our test set here, so the Bayesian bit below will
    # execute on the same subset each time.

    # Generate X test user indices
    test_user_indices = get_test_users(test_users)

    # Generate test rows
    test_rows, liked_games, disliked_games = create_test_rows(test_user_indices)


    # Define the scoring function within the main function so that it has native access to variables
    def bayes_test(test_user_indices=test_user_indices, liked_games=liked_games, \
               disliked_games=disliked_games, test_rows=test_rows, evaluator=evaluator, \
               similar_user_limit=50, collab_filter_limit=50, \
               content_filter_limit=50, double_bonus=0, popular_bias=0, ratio=0.5, \
               recs=10, testing=True, verbose=verbose, show_result=show_result) :
    
        params = {
        "test_user_indices":test_user_indices,
        "test_user_rows":test_rows,
        "similar_user_limit":int(similar_user_limit),
        "collab_filter_limit":int(collab_filter_limit),
        "content_filter_limit":int(content_filter_limit),
        "double_bonus":double_bonus,
        "popular_bias":popular_bias,
        "ratio":ratio,
        "recs":int(recs),
        "verbose":verbose,
        "show_result":show_result,
        "testing":testing
        }
        
        results = []

        for i in range(len(test_user_indices)) :
            result = get_recs(test_user_indices[i], **params)
            results.append((result, \
                            game_to_col_index.inverse[liked_games[i][1]], \
                            game_to_col_index.inverse[disliked_games[i][1]]))
            
        score = evaluator(results)
        print(score)

        return score


    # Prepare params for Bayes
    param_bounds = {
        "similar_user_limit":(100, 140),
        "collab_filter_limit":(40, 100),
        "content_filter_limit":(10, 50),
        "double_bonus":(0, 3),
        "popular_bias":(2, 5),
        "ratio":(0.2, 0.95),
        "recs":(20, 20),
        }
    
    # Execute
    optimizer = BayesianOptimization(f=bayes_test, pbounds=param_bounds, random_state=42)
    optimizer.maximize(init_points=init_points, n_iter=n_iter)
    best_params = optimizer.max
    print(best_params)

    return best_params

# %% [markdown]
# I ran the following cell many times, recording the result each time.
#
# This final iteration represents a honing-in on the most optimal parameters.
#
# A fuller discussion will be the forthcoming project report.

# %%
boptimize(test_users=70, n_iter=15, init_points=8, show_result=True)
# Out:
# |   iter    |  target   | collab... | conten... | double... | popula... |   ratio   |   recs    | simila... |
# -------------------------------------------------------------------------------------------------------------
# ------ User profile:
# 1.0 - Deep Rock Galactic
# 1.0 - STAR WARS™ Empire at War - Gold Pack
# 1.0 - STAR WARS™ Jedi Knight - Jedi Academy™
# 1.0 - HELLDIVERS™ 2
# 1.0 - Rise of Nations: Extended Edition
# 1.0 - Mount & Blade: Warband
# 1.0 - Halo: The Master Chief Collection
# 1.0 - STAR WARS™ Knights of the Old Republic™ II - The Sith Lords™
# 1.0 - Insurgency: Sandstorm
# 1.0 - Due Process
# --------------------
#
# ------ Recommendations
# 6.736 -- STAR WARS™ Battlefront II (Classic, 2005)
# 6.627 -- STAR WARS™ Battlefront (Classic, 2004)
# 6.304 -- Homeworld Remastered Collection
# 6.232 -- Arma 3
# 5.401 -- Mass Effect™: Andromeda Deluxe Edition
# 5.254 -- STAR WARS™ Republic Commando™
# 5.253 -- Half-Life 2
# 5.229 -- Age of Mythology: Extended Edition
# 5.192 -- STAR WARS™ Knights of the Old Republic™
# 5.138 -- Half-Life 2: Episode Two
# 5.064 -- GROUND BRANCH
# 5.036 -- Supreme Commander: Forged Alliance
# 5.018 -- Mass Effect (2007)
# 5.011 -- Warhammer® 40,000: Dawn of War® - Dark Crusade
# 5.005 -- Black Mesa
# 4.999 -- Rome: Total War™ - Collection
# 4.941 -- Half-Life: Opposing Force
# 4.898 -- Command & Conquer 3: Kane's Wrath
# 4.859 -- Company of Heroes - Legacy Edition
# 4.847 -- Halo Wars: Definitive Edition
# --------------------
#
# Runtime: 5.33s
#
# ------ User profile:
# 0.2 - Sunkenland
# 1.0 - PUBG: BATTLEGROUNDS
# 0.2 - Crusader Kings III
# 1.0 - Among Us
# 0.2 - Divinity: Original Sin 2 - Definitive Edition
# 0.2 - HELLDIVERS™ 2
# 0.2 - ARK: Survival Ascended
# 1.0 - ELDEN RING
# --------------------
#
# ------ Recommendations
# 14.022 -- Counter-Strike 2
# 4.794 -- DARK SOULS™ III
# 4.724 -- Lightphobe
# 4.601 -- Counter-Strike: Source
# 4.439 -- Monster Hunter: World
# 4.418 -- Intruder
# 4.38 -- DARK SOULS™: REMASTERED
# 4.379 -- am i the baddie?
# 4.34 -- DARK SOULS™ II
# 4.339 -- DARK SOULS™ II: Scholar of the First Sin
# 4.328 -- Dragon's Dogma: Dark Arisen
# 4.205 -- STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 4.202 -- Tom Clancy's Rainbow Six® Vegas 2
# 4.202 -- Imposters: Countdown
# 4.172 -- Tom Clancy's Rainbow Six® Siege
# 4.159 -- The Last Hero of Nostalgaia
# 4.155 -- CODE VEIN
# 4.1 -- Tom Clancy's Ghost Recon® Wildlands
# 3.975 -- Zero Hour
# 3.959 -- Realm Royale Reforged
# --------------------
#
# Runtime: 5.12s
#
# ------ User profile:
# 1.0 - Paladins®
# 1.0 - Monster Hunter: World
# 0.2 - War Thunder
# 0.2 - Middle-earth™: Shadow of Mordor™
# 1.0 - Counter-Strike 2
# 1.0 - TEKKEN 7
# 0.2 - Farlight 84
# 1.0 - Command & Conquer: Red Alert 3
# --------------------
#
# ------ Recommendations
# 7.37 -- Tom Clancy's Rainbow Six® Siege
# 7.081 -- TEKKEN 8
# 5.65 -- DRAGON BALL Z: KAKAROT
# 5.109 -- Dota 2
# 4.867 -- World of Tanks Blitz
# 4.814 -- Warface: Clutch
# 4.785 -- The Undisputables : Online Multiplayer Shooter
# 4.525 -- Lightphobe
# 4.524 -- Dragon's Dogma: Dark Arisen
# 4.443 -- Command & Conquer 3: Kane's Wrath
# 4.399 -- Counter-Strike: Source
# 4.348 -- DARK SOULS™ III
# 4.259 -- Fable - The Lost Chapters
# 4.178 -- GUILTY GEAR Xrd REV 2
# 4.172 -- BlazBlue Centralfiction
# 4.158 -- Risen
# 4.146 -- Melty Blood Actress Again Current Code
# 4.133 -- BlazBlue: Chronophantasma Extend
# 4.12 -- Kingdoms of Amalur: Reckoning™
# 4.112 -- Command & Conquer: Red Alert 3 - Uprising
# --------------------
#
# Runtime: 4.92s
#
# ------ User profile:
# 1.0 - Euro Truck Simulator 2
# 0.2 - Stunt Paradise Demo
# 0.2 - Company of Heroes
# 1.0 - Bomber Crew
# 0.2 - Parkitect
# 0.2 - Dorfromantik
# 0.2 - F1® Manager 2023
# 1.0 - Mafia II (Classic)
# 0.2 - GROUND BRANCH
# -1.0 - Emergency 2014
# 0.2 - Wreckfest
# 1.0 - Raft
# -1.0 - WRC 4 FIA World Rally Championship
# 0.2 - Motor Town: Behind The Wheel
# 1.0 - Fireworks Mania - An Explosive Simulator
# 0.2 - Hearts of Iron IV
# 0.2 - Sid Meier’s Civilization® VI
# 1.0 - PC Building Simulator
# -1.0 - Fireworks Simulator
# 1.0 - Prison Architect
# 1.0 - Just Cause™ 3
# 0.2 - Ready or Not
# 1.0 - Hell Let Loose
# 0.2 - Supermarket Simulator
# 1.0 - Rising Storm 2: Vietnam
# 1.0 - Grand Theft Auto V
# --------------------
#
# ------ Recommendations
# 6.395 -- Just Cause 2
# 6.359 -- Sleeping Dogs
# 6.222 -- Sleeping Dogs: Definitive Edition
# 6.062 -- Grand Theft Auto IV: Complete Edition
# 5.869 -- Mad Max
# 5.691 -- Watch_Dogs® 2
# 5.69 -- Bully: Scholarship Edition
# 5.63 -- Counter-Strike 2
# 5.516 -- Bionic Commando
# 5.436 -- War of Rights
# 5.432 -- Army Troop
# 5.416 -- Rising Storm Game of the Year Edition
# 5.385 -- Verdun
# 5.333 -- Just Cause
# 5.32 -- Day of Defeat: Source
# 5.316 -- Saints Row: The Third
# 5.291 -- Isonzo
# 5.281 -- Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# 5.224 -- BeamNG.drive
# 5.061 -- Insurgency: Sandstorm
# --------------------
#
# Runtime: 6.33s
#
# ------ User profile:
# 1.0 - Sakura Gamer
# 0.2 - HELLCARD
# 1.0 - The Room 4: Old Sins
# 1.0 - Sword Art Online Re: Hollow Fragment
# 1.0 - Prey: Typhon Hunter
# 1.0 - Don't Starve
# 1.0 - Sakura Shrine Girls
# 1.0 - Dagon: by H. P. Lovecraft
# 1.0 - Quantum Break
# 1.0 - Mount & Blade II: Bannerlord
# 1.0 - XenoShyft
# 1.0 - Dark Future: Blood Red States
# --------------------
#
# ------ Recommendations
# 5.801 -- Dead Secret
# 5.408 -- The Whisperer | Le murmureur
# 4.915 -- HELLDIVERS™ 2
# 4.632 -- The Room Three
# 4.614 -- NEKO-NIN exHeart
# 4.525 -- Mount & Blade: Warband
# 4.509 -- The Room
# 4.477 -- Cross Princess
# 4.407 -- The Room Two
# 4.405 -- Love's Sweet Garnish
# 4.362 -- Mount & Blade
# 4.356 -- EmergeNYC
# 4.341 -- KARAKARA
# 4.319 -- Mount & Blade: With Fire & Sword
# 4.284 -- Sakura Beach 2
# 4.281 -- Fantasy Tavern Sextet -Vol.1 New World Days-
# 4.248 -- The Afterglow of Grisaia
# 4.235 -- KARAKARA2
# 4.233 -- NEKOPARA Vol. 1
# 4.153 -- TSUNDERE MILFIN
# --------------------
#
# Runtime: 5.06s
#
# ------ User profile:
# 1.0 - Just Act Natural
# 1.0 - BattleBlock Theater®
# 1.0 - Ready or Not
# 1.0 - PAYDAY 2
# 1.0 - DISTRAINT 2
# 1.0 - Friends vs Friends
# 1.0 - HELLDIVERS™ 2
# 1.0 - Life is Strange - Episode 1
# 1.0 - Trine Enchanted Edition
# 1.0 - Move or Die
# 1.0 - Zero Hour
# 1.0 - Don't Starve Together
# 1.0 - Insurgency: Sandstorm
# 1.0 - Pony Island
# 1.0 - Warhammer: Vermintide 2
# --------------------
#
# ------ Recommendations
# 8.583 -- GROUND BRANCH
# 6.75 -- Arma 3
# 5.957 -- Zero Caliber VR
# 5.266 -- Lightphobe
# 5.178 -- DISTRAINT: Deluxe Edition
# 5.173 -- Robotry!
# 5.146 -- Contain
# 5.122 -- Pikuniku
# 5.106 -- Tom Clancy's Ghost Recon®
# 5.092 -- Putty Pals
# 5.066 -- BADLAND: Game of the Year Edition
# 4.998 -- Adventures of Shuggy
# 4.991 -- Left 4 Dead 2
# 4.884 -- Squad
# 4.866 -- Bulb Boy
# 4.818 -- The Cave
# 4.761 -- Call of Duty®: Modern Warfare® III
# 4.654 -- Hood Warfare
# 4.64 -- Apex Legends™
# 4.635 -- Battlefield 4™
# --------------------
#
# Runtime: 5.7s
#
# ------ User profile:
# 1.0 - Euro Truck Simulator 2
# 1.0 - Forza Horizon 5
# 1.0 - Rust
# 1.0 - Plague Inc: Evolved
# 1.0 - Bloons TD 6
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Tom Clancy's Rainbow Six® Siege
# 1.0 - Hotline Miami
# 1.0 - The Crew™ 2
# 1.0 - Black Mesa
# 1.0 - Dead by Daylight
# -1.0 - Battlefield™ 2042
# -1.0 - DRIFT CE
# 1.0 - Zup! Z
# --------------------
#
# ------ Recommendations
# 6.828 -- Counter-Strike 2
# 5.807 -- Garry's Mod
# 4.887 -- Forza Horizon 4
# 4.868 -- Bloons TD 5
# 4.819 -- BeamNG.drive
# 4.717 -- MudRunner
# 4.647 -- Need For Speed: Hot Pursuit
# 4.592 -- Assetto Corsa Competizione
# 4.545 -- Need for Speed™ Heat
# 4.466 -- DiRT Rally 2.0
# 4.442 -- Need for Speed™ Payback
# 4.424 -- GROUND BRANCH
# 4.421 -- Euro Truck Simulator
# 4.414 -- Bounty: Drag Racing
# 4.264 -- Steep™
# 4.21 -- Firefighting Simulator - The Squad
# 4.203 -- Race for Tuning
# 4.189 -- Need for Speed™ Rivals
# 4.146 -- American Truck Simulator
# 4.113 -- Need for Speed: Shift
# --------------------
#
# Runtime: 5.38s
#
# ------ User profile:
# 0.2 - Phoenix Wright: Ace Attorney Trilogy
# 1.0 - Yakuza Kiwami 2
# 0.2 - Persona 4 Arena Ultimax
# 1.0 - Persona 5 Royal
# 1.0 - Neon White
# 0.2 - GUILTY GEAR -STRIVE-
# 0.2 - Undertale
# 0.2 - BlazBlue Centralfiction
# 1.0 - Yakuza Kiwami
# 1.0 - Hi-Fi RUSH
# 1.0 - TEKKEN 7
# 1.0 - FINAL FANTASY VII REMAKE INTERGRADE
# 0.2 - TEKKEN 8
# 1.0 - Bloodstained: Curse of the Moon 2
# 1.0 - Persona 5 Tactica
# 0.2 - DJMAX RESPECT V
# 0.2 - RetroArch
# 0.2 - Capcom Arcade Stadium
# 0.2 - Granblue Fantasy Versus: Rising
# 1.0 - Persona 3 Portable
# 1.0 - Persona 3 Reload
# 1.0 - GUILTY GEAR Xrd REV 2
# 1.0 - Hatsune Miku: Project DIVA Mega Mix+
# 1.0 - Resident Evil 4
# 1.0 - Bloodstained: Curse of the Moon
# --------------------
#
# ------ Recommendations
# 9.133 -- Yakuza 0
# 6.674 -- Persona 4 Golden
# 6.333 -- BlazBlue: Chronophantasma Extend
# 6.197 -- UNDER NIGHT IN-BIRTH Exe:Late
# 6.164 -- GUILTY GEAR Xrd -SIGN-
# 6.103 -- Melty Blood Actress Again Current Code
# 6.04 -- Yakuza: Like a Dragon
# 5.771 -- THE KING OF FIGHTERS XIII STEAM EDITION
# 5.737 -- Guilty Gear X2 #Reload
# 5.596 -- BlazBlue: Cross Tag Battle
# 5.552 -- CHAOS CODE -NEW SIGN OF CATASTROPHE-
# 5.534 -- DRAGON BALL Z: KAKAROT
# 5.461 -- THE KING OF FIGHTERS 2002 UNLIMITED MATCH
# 5.422 -- ULTIMATE MARVEL VS. CAPCOM 3
# 5.313 -- DRAGON BALL FighterZ
# 5.282 -- Tales Of Aravorn: An Elven Marriage
# 5.281 -- Yakuza 6: The Song of Life
# 5.266 -- THE KING OF FIGHTERS XV
# 5.259 -- Yakuza 4 Remastered
# 5.221 -- Arcana Heart 3 LOVE MAX!!!!!
# --------------------
#
# Runtime: 6.45s
#
# ------ User profile:
# 1.0 - Battlefield™ V
# 1.0 - Forza Horizon 5
# 1.0 - DOOM
# 1.0 - CODE VEIN
# 1.0 - Brawlhalla
# -1.0 - PAYDAY 2
# 1.0 - theHunter: Call of the Wild™
# 1.0 - Portal 2
# 1.0 - Ultimate Chicken Horse
# 1.0 - Counter-Strike 2
# 1.0 - DiRT Rally 2.0
# 1.0 - Apex Legends™
# 1.0 - Assetto Corsa
# 1.0 - Super Animal Royale
# 1.0 - NEEDY STREAMER OVERLOAD
# --------------------
#
# ------ Recommendations
# 6.684 -- Splitgate
# 5.998 -- Assetto Corsa Competizione
# 5.906 -- Forza Horizon 4
# 5.464 -- TT Isle of Man: Ride on the Edge 2
# 5.425 -- Bounty: Drag Racing
# 5.375 -- Need for Speed: Shift
# 5.367 -- Dakar 18
# 4.936 -- TT Isle of Man: Ride on the Edge
# 4.857 -- F1® 22
# 4.835 -- Color Breakers
# 4.789 -- CarX Drift Racing Online
# 4.785 -- BeamNG.drive
# 4.738 -- HELLDIVERS™ 2
# 4.638 -- MudRunner
# 4.573 -- Dorfs: Hammers for Hire
# 4.567 -- Tom Clancy's Rainbow Six® Siege
# 4.523 -- iRacing
# 4.5 -- Need For Speed: Hot Pursuit
# 4.462 -- The Crew™ 2
# 4.46 -- Wreckfest
# --------------------
#
# Runtime: 5.76s
#
# ------ User profile:
# -1.0 - Sid Meier's Civilization®: Beyond Earth™
# -1.0 - Peglin
# 1.0 - MORDHAU
# 1.0 - Mechabellum
# 1.0 - War Thunder
# 1.0 - Cuphead
# 1.0 - Bloons TD 6
# 1.0 - Alien Swarm
# -1.0 - BioShock™ Remastered
# 1.0 - Unturned
# -1.0 - Age of Wonders: Planetfall
# 1.0 - Revenge of the Titans
# 1.0 - Insurgency: Sandstorm
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 5.521 -- Counter-Strike 2
# 4.667 -- Shovel Knight: Shovel of Hope
# 4.618 -- Arma 3
# 4.316 -- Ultimate Zombie Defense
# 4.255 -- Bloons TD 5
# 4.24 -- Mago
# 4.233 -- Rising Storm Game of the Year Edition
# 4.159 -- Call of Duty®
# 4.136 -- Who's Your Daddy?!
# 4.086 -- Infested Planet
# 3.982 -- GROUND BRANCH
# 3.915 -- No More Room in Hell
# 3.89 -- Dota 2
# 3.85 -- War of Rights
# 3.786 -- Super Sanctum TD
# 3.763 -- Army Troop
# 3.718 -- Titanfall® 2
# 3.701 -- Hell Let Loose
# 3.667 -- Team Fortress 2
# 3.652 -- Chivalry: Medieval Warfare
# --------------------
#
# Runtime: 5.69s
#
# ------ User profile:
# 0.2 - Brotato
# 1.0 - Total War: WARHAMMER III
# 0.2 - Total War: ROME II - Emperor Edition
# 0.2 - Baldur's Gate 3
# 0.2 - Cyberpunk 2077
# 0.2 - PUBG: BATTLEGROUNDS
# 0.2 - Marvel’s Spider-Man: Miles Morales
# 0.2 - Rise of Nations: Extended Edition
# 0.2 - STAR WARS™: Battlefront Classic Collection
# 0.2 - Disco Elysium - The Final Cut
# 0.2 - Warhammer Age of Sigmar: Realms of Ruin
# 0.2 - Total War: SHOGUN 2
# 0.2 - Solar 2
# --------------------
#
# ------ Recommendations
# 7.677 -- Sid Meier’s Civilization® VI
# 7.166 -- Total War: WARHAMMER II
# 6.67 -- Total War: NAPOLEON – Definitive Edition
# 6.67 -- Rome: Total War™ - Collection
# 6.532 -- NEBULOUS: Fleet Command
# 6.306 -- SHOGUN: Total War™ - Collection
# 6.258 -- Company of Heroes: Opposing Fronts
# 6.105 -- Total War: MEDIEVAL II – Definitive Edition
# 5.998 -- Total War: EMPIRE – Definitive Edition
# 5.954 -- Total War: ATTILA
# 5.94 -- Total War: THREE KINGDOMS
# 5.901 -- A Total War Saga: FALL OF THE SAMURAI
# 5.874 -- Total War: WARHAMMER
# 5.823 -- A Total War Saga: THRONES OF BRITANNIA
# 5.528 -- Ancient Warfare: The Han Dynasty
# 5.487 -- Warhammer® 40,000: Dawn of War® - Dark Crusade
# 5.305 -- Halo Wars: Definitive Edition
# 5.253 -- Faces of War
# 5.248 -- Total War: ROME REMASTERED
# 5.103 -- Total War: PHARAOH
# --------------------
#
# Runtime: 5.45s
#
# ------ User profile:
# 1.0 - Halo Infinite
# 1.0 - The Witcher® 3: Wild Hunt
# 0.2 - HELLDIVERS™ 2
# 0.2 - Risk of Rain 2
# 1.0 - Apex Legends™
# 1.0 - The Walking Dead
# 1.0 - Rec Room
# 1.0 - Warhammer 40,000: Space Marine - Anniversary Edition
# 1.0 - Don't Starve Together
# 0.2 - THE FINALS
# 1.0 - Hollow Knight
# --------------------
#
# ------ Recommendations
# 6.921 -- Overwatch® 2
# 5.602 -- Counter-Strike 2
# 5.054 -- STAR WARS™ Battlefront™ II
# 5.033 -- Apex Armor Swap Trainer
# 4.861 -- PlanetSide 2
# 4.621 -- LOST PLANET® 3
# 4.608 -- Space Hulk: Deathwing Enhanced Edition
# 4.576 -- The Walking Dead: Season Two
# 4.451 -- BRINK
# 4.401 -- Galactic Force
# 4.382 -- The Walking Dead: The Final Season
# 4.368 -- Colorless World
# 4.324 -- The Witcher: Enhanced Edition Director's Cut
# 4.251 -- The Witcher 2: Assassins of Kings Enhanced Edition
# 4.222 -- Ori and the Will of the Wisps
# 4.215 -- Dogworld
# 4.18 -- Unbound: Worlds Apart
# 4.154 -- WarriOrb: Prologue
# 4.07 -- Fable - The Lost Chapters
# 3.998 -- Team Fortress 2
# --------------------
#
# Runtime: 5.34s
#
# ------ User profile:
# 0.2 - Cookie Clicker
# 1.0 - Inscryption
# 0.2 - HELLDIVERS™ 2
# 0.2 - Fallout 4
# -1.0 - Skullgirls 2nd Encore
# 1.0 - Hunt: Showdown
# 0.2 - Magicka
# 0.2 - L.A. Noire
# 1.0 - Monster Hunter: World
# 0.2 - Quake Champions
# 1.0 - Risk of Rain Returns
# 1.0 - Outer Wilds
# 1.0 - Ori and the Will of the Wisps
# 1.0 - Darkest Dungeon®
# 1.0 - Halo: The Master Chief Collection
# 1.0 - Killing Floor 2
# 1.0 - Stardew Valley
# 1.0 - Risk of Rain 2
# 1.0 - Voidigo
# --------------------
#
# ------ Recommendations
# 9.993 -- Left 4 Dead 2
# 5.725 -- Counter-Strike 2
# 5.216 -- Left 4 Dead
# 5.16 -- GTFO
# 5.159 -- Killing Floor
# 5.136 -- Enter the Gungeon
# 4.837 -- Zombie Panic! Source
# 4.832 -- Gatekeeper: Infinity
# 4.813 -- No More Room in Hell
# 4.78 -- Stay Home
# 4.76 -- Killing Floor - Toy Master
# 4.612 -- Returnal™
# 4.606 -- UNLOVED
# 4.428 -- Arizona Sunshine®
# 4.261 -- Ori and the Blind Forest
# 4.252 -- Clanfolk
# 4.232 -- DARK SOULS™ III
# 4.204 -- Cornucopia®
# 4.093 -- Dead Effect
# 4.082 -- Masked Forces: Zombie Survival
# --------------------
#
# Runtime: 5.65s
#
# ------ User profile:
# -1.0 - Cyberpunk 2077
# 1.0 - Contraption Maker
# -1.0 - Signal Simulator
# -1.0 - Viridi
# -1.0 - Oddworld: Abe's Oddysee®
# -1.0 - Bastard Bonds
# 1.0 - The Vanishing of Ethan Carter
# -1.0 - Broken Reality
# --------------------
#
# ------ Recommendations
# 5.629 -- Counter-Strike 2
# 4.991 -- What Remains of Edith Finch
# 4.984 -- The Room Two
# 4.982 -- Stack Masters
# 4.955 -- Hellgineers
# 4.929 -- Drilbert
# 4.917 -- Marie's Room
# 4.905 -- Outer Wilds
# 4.806 -- The White Door
# 4.767 -- Warp Factory
# 4.732 -- The Whispering Valley | La vallée qui murmure
# 4.594 -- Save the Dodos
# 4.564 -- Metamorphosis
# 4.488 -- When Ski Lifts Go Wrong
# 4.457 -- Classified Stories: The Tome of Myrkah
# 4.453 -- Gray Dawn
# 4.43 -- Now You See - A Hand Painted Horror Adventure
# 4.325 -- Ouija Rumours
# 4.321 -- Dead Secret
# 4.3 -- The Imagined Leviathan: Prologue
# --------------------
#
# Runtime: 5.03s
#
# ------ User profile:
# 1.0 - Acron: Attack of the Squirrels!
# 1.0 - Titans of Space PLUS
# 1.0 - Demeo
# 1.0 - After the Fall®
# 1.0 - 100 hidden frogs
# 1.0 - Spark & Kling
# 1.0 - Increment
# 1.0 - Dorfromantik
# 1.0 - Flock of the Low God
# 1.0 - The Forest
# 1.0 - Sam & Dan: Floaty Flatmates
# --------------------
#
# ------ Recommendations
# 6.0 -- The Walking Dead: Saints & Sinners
# 5.789 -- Resident Evil 7 Teaser: Beginning Hour
# 5.73 -- Immortal Legacy: The Jade Cipher[VR]
# 5.729 -- Necro Mutex
# 5.596 -- The Survivor
# 5.369 -- The Walking Dead: Saints & Sinners - Chapter 2: Retribution
# 5.074 -- Counter-Strike 2
# 4.964 -- Dead GroundZ
# 4.678 -- 100 hidden mice
# 4.557 -- 100 hidden rams
# 4.502 -- 100 hidden fish
# 4.497 -- 100 hidden cats
# 4.427 -- 100 hidden birds
# 4.328 -- 100 hidden cats 2
# 4.327 -- Urge
# 4.326 -- 100 hidden snails 2
# 4.288 -- 100 hidden mushrooms
# 4.278 -- The Long Dark
# 4.233 -- Subnautica
# 4.136 -- 100 hidden aliens
# --------------------
#
# Runtime: 5.09s
#
# ------ User profile:
# -1.0 - MORDHAU
# -1.0 - Crusader Kings III
# -1.0 - DARK SOULS™ II: Scholar of the First Sin
# -1.0 - Moonlighter
# -1.0 - Kingdom Come: Deliverance
# -1.0 - Squad 44
# -1.0 - Fallout 4
# -1.0 - Tactical Assault VR
# -1.0 - Hunt: Showdown
# --------------------
#
# ------ Recommendations
# 5.055 -- Valheim
# 4.501 -- HELLDIVERS™ 2
# 4.497 -- Lightphobe
# 4.121 -- Snapshot VR
# 4.058 -- Breachers
# 4.056 -- Sniper Elite V2
# 4.018 -- Stardew Valley
# 4.006 -- Pirates, Vikings, and Knights II
# 3.986 -- Terraria
# 3.974 -- Baldur's Gate 3
# 3.918 -- Guardians Frontline
# 3.761 -- Zero Hour
# 3.754 -- Sniper Elite 3
# 3.695 -- Sniper Elite
# 3.633 -- Steam Engine Simulator
# 3.633 -- Half-Life: Alyx
# 3.615 -- M.E.A.T. Veterans
# 3.595 -- Bloons TD 6
# 3.595 -- BABBDI
# 3.595 -- Slay the Spire
# --------------------
#
# Runtime: 5.08s
#
# ------ User profile:
# 0.2 - Apex Legends™
# 1.0 - The Pale Beyond
# 1.0 - Palworld
# 0.2 - Overwatch® 2
# 0.2 - Team Fortress 2
# -1.0 - Crown and Council
# 0.2 - Baldur's Gate 3
# 0.2 - Hearts of Iron IV
# 0.2 - METAL GEAR SOLID - Master Collection Version
# 1.0 - ELDEN RING
# 1.0 - I Can't Believe It's Not Gambling
# 0.2 - DARK SOULS™ III
# 1.0 - FINAL FANTASY XIV Online
# -1.0 - War Thunder
# 0.2 - Crusader Kings III
# 0.2 - Portal 2
# 1.0 - Stormworks: Build and Rescue
# 1.0 - Stories: The Path of Destinies
# 0.2 - Factorio
# --------------------
#
# ------ Recommendations
# 6.167 -- Risen
# 6.002 -- Monster Hunter: World
# 5.89 -- Dragon's Dogma: Dark Arisen
# 5.371 -- Two Worlds Epic Edition
# 5.172 -- FINAL FANTASY XV WINDOWS EDITION
# 5.038 -- HELLDIVERS™ 2
# 4.536 -- DARK SOULS™: REMASTERED
# 4.453 -- DARK SOULS™ II
# 4.452 -- DARK SOULS™ II: Scholar of the First Sin
# 4.428 -- DRAGON BALL Z: KAKAROT
# 4.34 -- Guild Wars 2
# 4.334 -- Voidtrain
# 4.286 -- Tales of Arise
# 4.283 -- The Elder Scrolls® Online
# 4.283 -- Neverwinter Nights: Enhanced Edition
# 4.24 -- Omensight: Definitive Edition
# 4.172 -- Don't open the doors!
# 4.109 -- Kingdoms of Amalur: Reckoning™
# 4.02 -- Counter-Strike: Source
# 4.012 -- STRANGER OF PARADISE FINAL FANTASY ORIGIN
# --------------------
#
# Runtime: 5.7s
#
# ------ User profile:
# 1.0 - Red Faction Guerrilla Steam Edition
# -1.0 - SURVIVAL: Postapocalypse Now
# 1.0 - Killing Floor
# 1.0 - Portal 2
# 1.0 - Counter-Strike 2
# 1.0 - Realm of the Mad God Exalt
# 1.0 - Tom Clancy's Rainbow Six® Siege
# 1.0 - Z1 Battle Royale
# 1.0 - Red Orchestra 2: Heroes of Stalingrad with Rising Storm
# --------------------
#
# ------ Recommendations
# 5.553 -- Counter-Strike: Source
# 5.249 -- Tom Clancy's Ghost Recon®
# 5.138 -- GROUND BRANCH
# 5.039 -- Verdun
# 4.892 -- Lightphobe
# 4.891 -- Squad
# 4.835 -- Bloons TD 6
# 4.702 -- Zero Hour
# 4.635 -- Rising Storm Game of the Year Edition
# 4.522 -- Counter-Strike
# 4.473 -- ARMA: Gold Edition
# 4.404 -- Splitgate
# 4.373 -- Arma 3
# 4.372 -- Cyberpunk 2077
# 4.322 -- Killing Floor - Toy Master
# 4.285 -- Day of Defeat: Source
# 4.255 -- Double Action: Boogaloo
# 4.186 -- Battlefield 3™
# 4.166 -- Codename CURE
# 4.032 -- Portal
# --------------------
#
# Runtime: 5.18s
#
# ------ User profile:
# 1.0 - Company of Heroes 2
# -1.0 - Halo Infinite
# 1.0 - Middle-earth™: Shadow of Mordor™
# 1.0 - Cyberpunk 2077
# -1.0 - Warhammer 40,000: Dawn of War II
# 1.0 - Old School RuneScape
# 1.0 - Tabletop Simulator
# 1.0 - Rising Storm 2: Vietnam
# -1.0 - Fallout 4
# 1.0 - SteamVR
# 1.0 - Starship Troopers: Terran Command
# 1.0 - Mount & Blade II: Bannerlord
# 1.0 - VRChat
# 1.0 - The Forest
# 1.0 - Generation Zero®
# 1.0 - Destiny 2
# --------------------
#
# ------ Recommendations
# 5.015 -- Subnautica
# 4.968 -- Urge
# 4.65 -- Sons Of The Forest
# 4.616 -- Green Hell
# 4.598 -- Unturned
# 4.576 -- Counter-Strike 2
# 4.521 -- Graviteam Tactics: Mius-Front
# 4.444 -- Volcanoids
# 4.412 -- Garry's Mod
# 4.369 -- Rec Room
# 4.259 -- Graviteam Tactics: Operation Star
# 4.244 -- ELDEN RING
# 4.242 -- Mount & Blade: Warband
# 4.187 -- 3dSen VR
# 4.185 -- HELLDIVERS™ 2
# 4.126 -- Steel Division: Normandy 44
# 4.063 -- Mount & Blade
# 4.043 -- Company of Heroes - Legacy Edition
# 4.034 -- Company of Heroes: Tales of Valor
# 4.03 -- Voidtrain
# --------------------
#
# Runtime: 5.67s
#
# ------ User profile:
# 0.2 - Counter-Strike 2
# 0.2 - Superflight
# 0.2 - Tom Clancy's Rainbow Six® Siege
# 0.2 - Neon Drive
# 1.0 - DOOM
# 0.2 - Cyberpunk 2077
# 0.2 - Sekiro™: Shadows Die Twice - GOTY Edition
# -1.0 - Arma 3
# 1.0 - No More Room in Hell
# 1.0 - Zombie Army Trilogy
# 1.0 - BioShock Infinite
# 1.0 - Garry's Mod
# 0.2 - Wolfenstein II: The New Colossus
# 1.0 - Bound By Flame
# 1.0 - Call of Duty®: Black Ops III
# 0.2 - Hotline Miami
# 0.2 - Dragon's Dogma: Dark Arisen
# 0.2 - ELDEN RING
# 0.2 - Mortal Sin
# 0.2 - Just Cause™ 3
# 1.0 - Call of Duty®: Modern Warfare® 2 (2009)
# 0.2 - Geometry Dash
# --------------------
#
# ------ Recommendations
# 7.732 -- Half-Life: Alyx
# 6.301 -- Black Mesa
# 6.016 -- Bulletstorm: Full Clip Edition
# 5.261 -- RoboCop: Rogue City
# 5.259 -- DOOM Eternal
# 5.25 -- Painkiller Overdose
# 5.217 -- Left 4 Dead 2
# 5.217 -- Dead Effect
# 5.209 -- Half-Life 2: Episode Two
# 5.182 -- Call of Duty®: Modern Warfare® Remastered (2017)
# 5.179 -- Call of Duty® 4: Modern Warfare® (2007)
# 5.134 -- Left 4 Dead
# 5.102 -- Killing Floor - Toy Master
# 5.098 -- Quake
# 5.068 -- Wolfenstein: The New Order
# 5.064 -- Enemy Front
# 5.035 -- STAR WARS™ Republic Commando™
# 5.02 -- Team Fortress 2
# 5.018 -- Call of Duty®: Black Ops
# 5.012 -- Call of Duty® 2
# --------------------
#
# Runtime: 6.21s
#
# ------ User profile:
# -1.0 - Overwatch® 2
# 1.0 - Core Keeper
# -1.0 - Resident Evil Revelations
# 1.0 - ARK: Survival Evolved
# 1.0 - The End of Dyeus
# 1.0 - Card Shark
# 1.0 - Boundary
# 1.0 - Cassette Beasts
# 1.0 - Lethal Company
# 1.0 - BattleBit Remastered
# 1.0 - DON'T SCREAM
# -1.0 - SONIC SUPERSTARS
# 1.0 - Balatro
# 1.0 - Palworld
# 1.0 - I Wanna Maker
# 1.0 - Mosa Lina
# 1.0 - Pseudoregalia
# --------------------
#
# ------ Recommendations
# 11.535 -- Valheim
# 5.631 -- Necesse
# 4.845 -- Junk Jack
# 4.784 -- Raft
# 4.673 -- Voidtrain
# 4.644 -- Dig or Die
# 4.61 -- Counter-Strike 2
# 4.364 -- Craftopia
# 4.222 -- HELLDIVERS™ 2
# 4.195 -- Hood Warfare
# 4.163 -- Signs of Life
# 4.052 -- Baldur's Gate 3
# 4.045 -- Boundless
# 3.992 -- Force of Nature
# 3.989 -- Stranded Deep
# 3.85 -- Garry's Mod
# 3.839 -- Terraria
# 3.716 -- CardLife: Creative Survival
# 3.621 -- Pineapple on pizza
# 3.614 -- Planet Explorers
# --------------------
#
# Runtime: 5.83s
#
# ------ User profile:
# 1.0 - BATTALION: Legacy
# 1.0 - Fallout: New Vegas
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 1.0 - Counter-Strike 2
# 1.0 - Forza Horizon 4
# 1.0 - Left on Read
# 1.0 - Car Mechanic Simulator 2018
# 1.0 - The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 1.0 - Papers, Please
# 1.0 - Tech Support: Error Unknown
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 15.45 -- Starfield
# 7.74 -- The Elder Scrolls III: Morrowind® Game of the Year Edition
# 7.635 -- Arma 3
# 6.636 -- Fallout 3
# 6.591 -- Gothic® 3
# 6.538 -- Kingdoms of Amalur: Reckoning™
# 5.504 -- Lightphobe
# 5.373 -- Risen
# 5.372 -- Fable - The Lost Chapters
# 5.282 -- Counter-Strike: Source
# 5.266 -- Fallout 4
# 5.144 -- Fable Anniversary
# 5.143 -- Gothic II: Gold Edition
# 5.124 -- Dragon's Dogma: Dark Arisen
# 5.123 -- Car Mechanic Simulator 2015
# 5.052 -- BeamNG.drive
# 5.044 -- Fallout 3: Game of the Year Edition
# 5.034 -- Hogwarts Legacy
# 4.945 -- Splitgate
# 4.92 -- Sudeki
# --------------------
#
# Runtime: 5.34s
#
# ------ User profile:
# 0.2 - Bloons TD 6
# 1.0 - Loop Hero
# 1.0 - Owlboy
# 1.0 - Prey
# 1.0 - Tangledeep
# 1.0 - Crypt of the NecroDancer
# 1.0 - Red Dead Redemption 2
# 1.0 - Epic Battle Fantasy 5
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 5.59 -- Fallout 4
# 5.513 -- Far Cry®
# 5.393 -- Against the Storm
# 5.283 -- Counter-Strike 2
# 4.928 -- Torgar's Quest
# 4.589 -- Epic Battle Fantasy 4
# 4.387 -- Super Panda Adventures
# 4.288 -- Balatro
# 4.27 -- Satisfactory
# 4.262 -- Ori and the Blind Forest
# 4.202 -- shapez
# 4.175 -- Empires of the Undergrowth
# 4.144 -- Ori and the Will of the Wisps
# 4.126 -- Mindustry
# 4.022 -- Alien: Isolation
# 4.003 -- Factory Town
# 3.985 -- Metro Exodus
# 3.975 -- Horace
# 3.908 -- Evoland 2
# 3.841 -- Iconoclasts
# --------------------
#
# Runtime: 5.4s
#
# ------ User profile:
# 1.0 - The Binding of Isaac
# 1.0 - Aliens vs. Predator™
# -1.0 - Blaster Shooter GunGuy!
# 1.0 - Mitos.is: The Game
# 1.0 - Counter-Strike 2
# -1.0 - 12 Labours of Hercules II: The Cretan Bull
# 1.0 - Terraria
# 1.0 - BioShock™
# 1.0 - Don't Starve Together
# 1.0 - BioShock Infinite
# -1.0 - 12 Labours of Hercules III: Girl Power
# 1.0 - BEEP
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 5.623 -- Euro Truck Simulator 2
# 4.828 -- Halo: The Master Chief Collection
# 4.718 -- Necesse
# 4.499 -- Starbound
# 4.495 -- Half-Life 2: Episode Two
# 4.486 -- Valheim
# 4.485 -- Half-Life 2
# 4.463 -- Dishonored
# 4.456 -- The Binding of Isaac: Rebirth
# 4.444 -- BioShock® 2
# 4.403 -- Dig or Die
# 4.327 -- Deus Ex: Human Revolution - Director's Cut
# 4.302 -- Singularity™
# 4.284 -- Arma 3
# 4.246 -- Feel The Snow
# 4.244 -- Wolfenstein: The New Order
# 4.23 -- Green Hell
# 4.215 -- BioShock™ Remastered
# 4.11 -- Magicite
# 4.067 -- Volcanoids
# --------------------
#
# Runtime: 5.78s
#
# ------ User profile:
# 1.0 - Cry of Fear
# -1.0 - Overwatch® 2
# 1.0 - DRAGON BALL XENOVERSE 2
# -1.0 - PUBG: BATTLEGROUNDS
# -1.0 - Battlefield™ 2042
# 1.0 - Crab Game
# 1.0 - Team Fortress 2
# 1.0 - Deceit
# 1.0 - Unturned
# 1.0 - Palworld
# 1.0 - Dota 2
# 1.0 - Emily is Away
# 1.0 - Red Dead Redemption 2
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 6.506 -- BIGFOOT
# 5.637 -- No More Room in Hell
# 5.623 -- Transmissions: Element 120
# 5.544 -- Counter-Strike 2
# 5.477 -- Killing Floor - Toy Master
# 5.301 -- Zombie Panic! Source
# 5.198 -- Codename CURE
# 4.895 -- DayZ
# 4.755 -- SCP: Secret Laboratory
# 4.651 -- Passing Pineview Forest
# 4.495 -- Resident Evil 7 Teaser: Beginning Hour
# 4.416 -- FROSTBITE: Deadly Climate
# 4.215 -- Far Cry® 4
# 4.111 -- White Noise 2
# 3.937 -- DRAGON BALL Z: KAKAROT
# 3.91 -- SlapBR
# 3.833 -- Dead Effect
# 3.792 -- DRAGON BALL XENOVERSE
# 3.789 -- float: champions
# 3.786 -- Baldur's Gate 3
# --------------------
#
# Runtime: 7.03s
#
# ------ User profile:
# 1.0 - Batman: Arkham Asylum Game of the Year Edition
# -1.0 - Rust
# 1.0 - MORDHAU
# 1.0 - STAR WARS™: The Old Republic™
# 1.0 - Assassin’s Creed® IV Black Flag™
# 1.0 - PUBG: BATTLEGROUNDS
# 0.2 - HELLDIVERS™ 2
# 1.0 - SCP: Secret Laboratory
# 1.0 - Conqueror's Blade
# 1.0 - Hearts of Iron IV
# 1.0 - Deceit
# 1.0 - Apex Legends™
# 1.0 - Unturned
# -1.0 - No More Room in Hell
# 1.0 - Phasmophobia
# 1.0 - Total War: SHOGUN 2
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 5.643 -- Counter-Strike 2
# 5.581 -- Total War: MEDIEVAL II – Definitive Edition
# 5.211 -- Company of Heroes: Opposing Fronts
# 5.193 -- Apex Armor Swap Trainer
# 4.932 -- Total War: ATTILA
# 4.725 -- Marvel’s Spider-Man Remastered
# 4.699 -- Total War: NAPOLEON – Definitive Edition
# 4.631 -- Batman™: Arkham Origins
# 4.615 -- Marvel’s Spider-Man: Miles Morales
# 4.574 -- Rise of the Tomb Raider™
# 4.57 -- Transmissions: Element 120
# 4.569 -- Company of Heroes: Tales of Valor
# 4.471 -- Cry of Fear
# 4.448 -- Assassin’s Creed® Brotherhood
# 4.426 -- Deducto
# 4.426 -- Assassin's Creed 2
# 4.342 -- Men of War: Assault Squad
# 4.339 -- Total War: THREE KINGDOMS
# 4.335 -- Assassin's Creed® Revelations
# 4.315 -- FROSTBITE: Deadly Climate
# --------------------
#
# Runtime: 6.22s
#
# ------ User profile:
# 1.0 - Company of Heroes 2
# -1.0 - HITMAN 3
# 1.0 - Cyberpunk 2077
# -1.0 - Heavy Rain
# -1.0 - Battlefield™ 1
# 1.0 - PowerWash Simulator
# 1.0 - Marvel's Guardians of the Galaxy
# 1.0 - Dagon: by H. P. Lovecraft
# -1.0 - Hardland
# -1.0 - Gunfire Reborn
# 1.0 - Starfield
# -1.0 - Wo Long: Fallen Dynasty
# -1.0 - Call of Duty®
# 1.0 - Pentiment
# 1.0 - Xuan-Yuan Sword VII
# 1.0 - The Elder Scrolls® Online
# --------------------
#
# ------ Recommendations
# 8.894 -- Hogwarts Legacy
# 8.744 -- Fallout 4
# 8.608 -- Prey
# 5.071 -- ELDEN RING
# 5.05 -- Kingdoms of Amalur: Reckoning™
# 4.982 -- The Outer Worlds
# 4.862 -- Fallout: New Vegas
# 4.731 -- Mass Effect (2007)
# 4.638 -- 3030 Deathwar Redux - A Space Odyssey
# 4.632 -- Terminator: Resistance
# 4.632 -- Counter-Strike 2
# 4.575 -- Spirits of Xanadu
# 4.539 -- STAR WARS™ Knights of the Old Republic™
# 4.526 -- Cloudpunk
# 4.525 -- Dragon's Dogma: Dark Arisen
# 4.348 -- SuchArt: Genius Artist Simulator
# 4.328 -- SuchArt: Creative Space
# 4.262 -- FINAL FANTASY XV WINDOWS EDITION
# 4.234 -- Fallout 3
# 4.222 -- Fallout 3: Game of the Year Edition
# --------------------
#
# Runtime: 6.28s
#
# ------ User profile:
# 1.0 - A Plague Tale: Requiem
# 1.0 - Ghostwire: Tokyo
# 1.0 - The Outlast Trials
# 1.0 - DRAGON BALL Z: KAKAROT
# 1.0 - Dying Light 2 Stay Human: Reloaded Edition
# 1.0 - Scorn
# -1.0 - Call of Duty®: Modern Warfare® III
# 1.0 - Starship Troopers: Extermination
# -1.0 - Lords of the Fallen
# 1.0 - Metal: Hellsinger
# -1.0 - Amnesia: The Bunker
# -1.0 - Terminator: Resistance
# 1.0 - Marvel’s Spider-Man Remastered
# 1.0 - CRISIS CORE –FINAL FANTASY VII– REUNION
# -1.0 - Starfield
# -1.0 - PAYDAY 3
# 1.0 - ELDEN RING
# 1.0 - Lies of P
# --------------------
#
# ------ Recommendations
# 5.419 -- Resident Evil 4
# 5.343 -- Baldur's Gate 3
# 5.151 -- Risen
# 4.874 -- Risen 2: Dark Waters
# 4.658 -- DARK SOULS™ III
# 4.352 -- Devil Inside Us: Roots of Evil
# 4.35 -- FINAL FANTASY XV WINDOWS EDITION
# 4.286 -- STRANGER OF PARADISE FINAL FANTASY ORIGIN
# 4.236 -- Assassin's Creed™: Director's Cut Edition
# 4.212 -- Amnesia: The Dark Descent
# 4.195 -- Marvel’s Spider-Man: Miles Morales
# 4.175 -- FINAL FANTASY VII REMAKE INTERGRADE
# 4.14 -- SOMA
# 4.086 -- The Chant
# 4.01 -- Outlast 2
# 3.96 -- FOREWARNED
# 3.937 -- DRAGON BALL XENOVERSE
# 3.93 -- DRAGON BALL XENOVERSE 2
# 3.892 -- NARUTO SHIPPUDEN: Ultimate Ninja STORM 3 Full Burst HD
# 3.854 -- Tales of Arise
# --------------------
#
# Runtime: 5.8s
#
# ------ User profile:
# 1.0 - Cry of Fear
# 1.0 - DOOM
# 1.0 - Mortal Kombat 11
# 0.2 - Lethal Company
# -1.0 - Fingerbones
# -1.0 - DOOM Eternal
# 0.2 - ELDEN RING
# 1.0 - DARK SOULS™ III
# --------------------
#
# ------ Recommendations
# 5.742 -- Counter-Strike 2
# 4.379 -- DARK SOULS™: REMASTERED
# 4.272 -- Quake
# 4.256 -- Monster Hunter: World
# 4.249 -- Transmissions: Element 120
# 4.237 -- DOOM II
# 4.213 -- DRAGON BALL Z: KAKAROT
# 4.21 -- Dragon's Dogma: Dark Arisen
# 4.2 -- DARK SOULS™ II
# 4.196 -- Quake II
# 4.185 -- Dead Effect
# 4.183 -- DARK SOULS™ II: Scholar of the First Sin
# 4.182 -- No More Room in Hell
# 4.168 -- SCP: Secret Laboratory
# 4.134 -- Risen
# 4.097 -- Killing Floor - Toy Master
# 4.073 -- Mortal Kombat X
# 4.009 -- Wick
# 3.971 -- Resident Evil 7 Teaser: Beginning Hour
# 3.941 -- FROSTBITE: Deadly Climate
# --------------------
#
# Runtime: 4.86s
#
# ------ User profile:
# 1.0 - Persona® 5 Strikers
# 1.0 - Tales of Berseria™
# 1.0 - Cyberpunk 2077
# 1.0 - PUBG: BATTLEGROUNDS
# 1.0 - OCTOPATH TRAVELER™
# 1.0 - Edna & Harvey: The Breakout - Anniversary Edition
# 1.0 - Mafia: Definitive Edition
# 1.0 - Sonic Forces
# 1.0 - PowerWash Simulator
# 1.0 - The Stanley Parable: Ultra Deluxe
# 1.0 - Neptunia Virtual Stars
# 1.0 - Ghost Trick: Phantom Detective
# 1.0 - DATE A LIVE: Rio Reincarnation
# 1.0 - Red Dead Redemption 2
# --------------------
#
# ------ Recommendations
# 8.214 -- Fallout 4
# 8.076 -- Grand Theft Auto V
# 7.217 -- Ys SEVEN
# 6.811 -- LIGHTNING RETURNS™: FINAL FANTASY® XIII
# 6.722 -- Crystar
# 6.69 -- FINAL FANTASY XV WINDOWS EDITION
# 6.439 -- Shining Resonance Refrain
# 6.159 -- Nights of Azure
# 5.687 -- Cyberdimension Neptunia: 4 Goddesses Online
# 5.671 -- Sleeping Dogs: Definitive Edition
# 5.578 -- Trials of Mana
# 5.411 -- Hyperdimension Neptunia U: Action Unleashed
# 5.331 -- Tales of Arise
# 5.274 -- Ys IX: Monstrum Nox
# 5.265 -- Counter-Strike 2
# 5.193 -- Mafia II (Classic)
# 5.184 -- Atelier Ryza 2: Lost Legends & the Secret Fairy
# 5.159 -- Ys Origin
# 5.094 -- .hack//G.U. Last Recode
# 5.046 -- Fallout: New Vegas
# --------------------
#
# Runtime: 5.51s
#
# ------ User profile:
# 1.0 - Hades
# -1.0 - Overwatch® 2
# 0.2 - Brawlhalla
# 1.0 - Terraria
# -1.0 - NARAKA: BLADEPOINT
# -1.0 - Dead by Daylight
# 0.2 - ELDEN RING
# 0.2 - Hunt: Showdown
# 0.2 - Path of Exile
# --------------------
#
# ------ Recommendations
# 6.917 -- Don't Starve Together
# 5.751 -- Craftopia
# 5.418 -- Team Fortress 2
# 4.778 -- Necesse
# 4.59 -- Starbound
# 4.573 -- Valheim
# 4.538 -- God of War
# 4.453 -- Dig or Die
# 4.404 -- Counter-Strike 2
# 4.386 -- Dreamscaper
# 4.382 -- Forager
# 4.324 -- Feel The Snow
# 4.323 -- Dandy Ace
# 4.229 -- Asura: Vengeance Edition
# 4.178 -- Magicite
# 4.007 -- Realms of Magic
# 4.003 -- Junk Jack
# 3.986 -- Signs of Life
# 3.905 -- Crea
# 3.902 -- The Survivalists
# --------------------
#
# Runtime: 5.38s
#
# ------ User profile:
# 1.0 - Warhammer 40,000: Dawn of War II: Retribution
# 1.0 - Dirty Bomb®
# 1.0 - Paladins®
# 1.0 - Middle-earth™: Shadow of Mordor™
# 1.0 - Warframe
# 1.0 - Left 4 Dead 2
# 1.0 - Sid Meier's Civilization® V
# 1.0 - Fallout 4
# 1.0 - Tom Clancy’s The Division™
# 1.0 - Far Cry® 4
# --------------------
#
# ------ Recommendations
# 10.06 -- Team Fortress 2
# 6.82 -- Far Cry® New Dawn
# 6.032 -- Fallout: New Vegas
# 5.766 -- Far Cry 3
# 5.53 -- Counter-Strike 2
# 5.403 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 5.194 -- Tom Clancy's Ghost Recon® Wildlands
# 5.122 -- Unturned
# 5.097 -- Risen
# 5.078 -- Kingdoms of Amalur: Reckoning™
# 5.07 -- Aliens vs. Predator™
# 4.994 -- Sniper Elite: Nazi Zombie Army
# 4.96 -- Mass Effect (2007)
# 4.93 -- Tom Clancy’s Splinter Cell Blacklist
# 4.882 -- Family Man: Prologue
# 4.877 -- Far Cry® 2
# 4.868 -- Call of Duty®: Black Ops II
# 4.812 -- Gothic® 3
# 4.784 -- Codename CURE
# 4.718 -- Risen 2: Dark Waters
# --------------------
#
# Runtime: 4.99s
#
# ------ User profile:
# 1.0 - Necrobarista
# 1.0 - Sins of a Solar Empire®: Rebellion
# 1.0 - Guns of Icarus Online
# 1.0 - MORDHAU
# -1.0 - Saints Row IV: Re-Elected
# 1.0 - Kerbal Space Program 2
# 1.0 - Retrowave
# 1.0 - SMITE®
# 1.0 - LYNE
# -1.0 - Assassin's Creed® Origins
# -1.0 - Microsoft Flight Simulator 40th Anniversary Edition
# 1.0 - Assassin's Creed® Unity
# 1.0 - Halo: The Master Chief Collection
# 1.0 - STAR WARS™ Knights of the Old Republic™ II - The Sith Lords™
# 1.0 - SUNLESS SEA
# 1.0 - Book of Travels
# 1.0 - Call of Juarez: Gunslinger
# --------------------
#
# ------ Recommendations
# 4.822 -- Baldur's Gate 3
# 4.821 -- Counter-Strike 2
# 4.771 -- Singularity™
# 4.716 -- Call of Juarez: Bound in Blood
# 4.501 -- Call of Juarez
# 4.351 -- Blokker: Orange
# 4.347 -- Mini Pipes - A Logic Puzzle Pipes Game
# 4.298 -- Re-Nullum
# 4.281 -- yarne
# 4.27 -- Hook
# 4.255 -- Kerbal Space Program
# 4.251 -- Spaceflight Simulator
# 4.251 -- Hexcells
# 4.185 -- klocki
# 4.176 -- Half-Life 2
# 4.172 -- Half-Life 2: Episode Two
# 4.17 -- Hexcells Infinite
# 4.133 -- STAR WARS™ Knights of the Old Republic™
# 4.127 -- Hexcells Plus
# 4.117 -- HELLDIVERS™ 2
# --------------------
#
# Runtime: 5.82s
#
# ------ User profile:
# -1.0 - Dragon's Dogma 2
# 0.2 - HELLDIVERS™ 2
# 1.0 - Terraria
# 0.2 - Project Zomboid
# 0.2 - Risk of Rain 2
# 0.2 - BattleBit Remastered
# 0.2 - Low Magic Age
# 0.2 - Darkest Dungeon®
# 1.0 - Dark Deity
# 0.2 - RimWorld
# --------------------
#
# ------ Recommendations
# 5.104 -- Necesse
# 4.728 -- Dig or Die
# 4.642 -- Starbound
# 4.587 -- Valheim
# 4.579 -- Feel The Snow
# 4.531 -- Factorio
# 4.515 -- Lethal Company
# 4.424 -- Kerbal Space Program
# 4.385 -- Forager
# 4.282 -- Junk Jack
# 4.236 -- Signs of Life
# 4.2 -- Age of Fear: The Free World
# 4.187 -- Craftopia
# 4.183 -- Crea
# 4.083 -- Tom Clancy's Rainbow Six® Siege
# 4.035 -- Force of Nature
# 4.011 -- Realms of Magic
# 3.942 -- PUBG: BATTLEGROUNDS
# 3.939 -- FLAMBERGE
# 3.91 -- The Survivalists
# --------------------
#
# Runtime: 5.21s
#
# ------ User profile:
# 0.2 - Forza Horizon 5
# 0.2 - Halo Infinite
# 0.2 - HELLDIVERS™ 2
# 0.2 - Tom Clancy's Rainbow Six® Siege
# 0.2 - Apex Legends™
# 0.2 - Destiny 2
# 0.2 - Pizza Tower
# 0.2 - Halo: The Master Chief Collection
# 0.2 - NARAKA: BLADEPOINT
# 0.2 - Call of Duty®
# 0.2 - VRChat
# 0.2 - Persona 5 Royal
# --------------------
#
# ------ Recommendations
# 12.906 -- PlanetSide 2
# 5.818 -- Call of Duty®: Warzone™
# 5.346 -- Half-Life 2: Episode Two
# 5.338 -- Counter-Strike 2
# 5.298 -- LOST PLANET® 3
# 5.229 -- BRINK
# 5.145 -- GROUND BRANCH
# 5.138 -- Arma 3
# 5.111 -- Call of Duty®: Modern Warfare® 2 (2009)
# 5.087 -- Half-Life
# 5.034 -- STAR WARS™ Battlefront (Classic, 2004)
# 5.018 -- Battlefield 4™
# 5.007 -- Half-Life 2: Lost Coast
# 4.973 -- Call of Duty® 4: Modern Warfare® (2007)
# 4.925 -- Serious Sam 2
# 4.891 -- Splitgate
# 4.887 -- Half-Life 2: Deathmatch
# 4.878 -- Call of Juarez: Bound in Blood
# 4.852 -- Far Cry®
# 4.697 -- Crysis 2 - Maximum Edition
# --------------------
#
# Runtime: 5.43s
#
# ------ User profile:
# 1.0 - Batman: The Enemy Within - The Telltale Series
# 1.0 - Chicken Police - Paint it RED!
# 1.0 - Resident Evil 3
# -1.0 - Mafia II: Definitive Edition
# 1.0 - Rise of the Tomb Raider™
# 1.0 - Ys VIII: Lacrimosa of DANA
# 1.0 - Sonic Frontiers
# 1.0 - Atomic Heart
# 1.0 - Scanner Sombre
# -1.0 - Sonic Mania
# -1.0 - One Piece Burning Blood
# 1.0 - CRISIS CORE –FINAL FANTASY VII– REUNION
# 1.0 - TEKKEN 7
# -1.0 - Killer Instinct
# 1.0 - Phasmophobia
# -1.0 - Yu-Gi-Oh! Legacy of the Duelist : Link Evolution
# --------------------
#
# ------ Recommendations
# 5.416 -- Tomb Raider
# 5.101 -- Lethal Company
# 4.304 -- Resident Evil 2
# 4.292 -- Blacksad: Under the Skin
# 4.278 -- The Wolf Among Us
# 4.255 -- Counter-Strike 2
# 4.244 -- FINAL FANTASY VII REMAKE INTERGRADE
# 4.173 -- Tales of Berseria™
# 4.165 -- This is a Ghost
# 4.163 -- The Walking Dead: Michonne - A Telltale Miniseries
# 4.143 -- DRAGON BALL Z: KAKAROT
# 4.13 -- Ys SEVEN
# 4.126 -- Ys Origin
# 4.101 -- Resident Evil
# 4.1 -- Trials of Mana
# 4.045 -- Batman - The Telltale Series
# 3.974 -- UNCHARTED™: Legacy of Thieves Collection
# 3.94 -- Demonologist
# 3.914 -- Remnant Records
# 3.889 -- Resident Evil 0
# --------------------
#
# Runtime: 5.67s
#
# ------ User profile:
# -1.0 - Overwatch® 2
# 1.0 - REQUISITION VR
# 1.0 - Valheim
# 0.2 - HELLDIVERS™ 2
# 1.0 - Darkwood
# 1.0 - Don't Starve Together
# 1.0 - Dota Underlords
# 1.0 - THE FINALS
# --------------------
#
# ------ Recommendations
# 9.053 -- Terraria
# 5.679 -- Counter-Strike 2
# 5.168 -- Necesse
# 4.943 -- Raft
# 4.828 -- Grounded
# 4.799 -- Dig or Die
# 4.667 -- Green Hell
# 4.539 -- Volcanoids
# 4.404 -- Craftopia
# 4.241 -- Force of Nature
# 4.239 -- Voidtrain
# 4.165 -- Subsistence
# 4.164 -- Dead Rising 3 Apocalypse Edition
# 3.958 -- Stardew Valley
# 3.727 -- Enshrouded
# 3.722 -- Smalland: Survive the Wilds
# 3.711 -- Passing Pineview Forest
# 3.654 -- Pineapple on pizza
# 3.642 -- Death Horizon: Reloaded
# 3.616 -- Plants vs. Zombies GOTY Edition
# --------------------
#
# Runtime: 5.13s
#
# ------ User profile:
# 1.0 - The Outer Worlds
# 1.0 - Cookie Clicker
# 1.0 - Age of Empires IV: Anniversary Edition
# 1.0 - Potion Craft: Alchemist Simulator
# 1.0 - Tick Tock: A Tale for Two
# 1.0 - Brigador: Up-Armored Edition
# -1.0 - Cyberpunk 2077
# 1.0 - Inscryption
# 1.0 - Elite Dangerous
# 1.0 - The Forgotten City
# 1.0 - For The King
# 1.0 - For The King II
# 1.0 - Age of Empires II: Definitive Edition
# 1.0 - Warhammer 40,000: Darktide
# --------------------
#
# ------ Recommendations
# 5.496 -- Counter-Strike 2
# 5.462 -- Age of Empires II (Retired)
# 4.9 -- Age of Empires® III (2007)
# 4.879 -- Age of Empires: Definitive Edition
# 4.749 -- Divinity: Original Sin - Enhanced Edition
# 4.736 -- Cossacks 3
# 4.73 -- Predictors
# 4.66 -- Company of Heroes: Tales of Valor
# 4.605 -- Majesty Gold HD
# 4.536 -- Age of Empires III: Definitive Edition
# 4.208 -- Kiwi Clicker - Juiced Up
# 4.173 -- Stronghold Crusader 2
# 4.044 -- The Past Within
# 3.802 -- Tabletop Simulator
# 3.779 -- HELLDIVERS™ 2
# 3.693 -- Aimlabs
# 3.617 -- Bloons TD 6
# 3.617 -- The Jackbox Party Pack 3
# 3.617 -- Hypnospace Outlaw
# 3.617 -- Euro Truck Simulator 2
# --------------------
#
# Runtime: 5.35s
#
# ------ User profile:
# -1.0 - Crusader Kings II
# -1.0 - Zero Caliber VR
# 1.0 - Hot Dogs, Horseshoes & Hand Grenades
# 1.0 - MORDHAU
# -1.0 - Total War: WARHAMMER III
# 1.0 - PAYDAY 2
# 1.0 - Warframe
# 1.0 - Assassin's Creed® Odyssey
# 1.0 - Unturned
# 1.0 - Destiny 2
# 1.0 - World War 3
# 1.0 - Insurgency: Sandstorm
# -1.0 - Red Dead Redemption 2
# -1.0 - Reign Of Kings
# -1.0 - Borderlands 2
# --------------------
#
# ------ Recommendations
# 5.429 -- GROUND BRANCH
# 5.361 -- Counter-Strike 2
# 5.245 -- BattleBit Remastered
# 4.78 -- Transmissions: Element 120
# 4.516 -- Isonzo
# 4.479 -- Squad
# 4.47 -- Halo Infinite
# 4.441 -- Battlefield 4™
# 4.303 -- Zero Hour
# 4.25 -- Tom Clancy's Rainbow Six® Vegas
# 4.195 -- America's Army: Proving Grounds
# 4.162 -- Star Trek Online
# 4.027 -- No More Room in Hell
# 4.005 -- Assassin’s Creed® IV Black Flag™
# 3.97 -- Combat Master: Season 1
# 3.899 -- Assassin's Creed® Origins
# 3.896 -- Dota 2
# 3.88 -- Battlerace
# 3.764 -- Risk of Rain 2
# 3.741 -- Champions Online
# --------------------
#
# Runtime: 5.38s
#
# ------ User profile:
# 1.0 - ARK: The Survival Of The Fittest
# -1.0 - Orcs Must Die! 2
# 1.0 - Company of Heroes 2
# -1.0 - Hell Let Loose
# -1.0 - SMITE®
# 1.0 - Blackwake
# 1.0 - Handy Dandy
# -1.0 - The Crew™ 2
# -1.0 - Mount & Blade II: Bannerlord
# 1.0 - 270 | Two Seventy US Election
# 1.0 - FOR HONOR™
# 1.0 - Barro
# -1.0 - The Dream Machine: Chapter 1 & 2
# 1.0 - Total War: SHOGUN 2
# 0.2 - Rust
# --------------------
#
# ------ Recommendations
# 4.939 -- Company of Heroes: Tales of Valor
# 4.923 -- Company of Heroes
# 4.91 -- Company of Heroes: Opposing Fronts
# 4.906 -- Total War: NAPOLEON – Definitive Edition
# 4.764 -- HELLDIVERS™ 2
# 4.69 -- Men of War™
# 4.655 -- Men of War: Assault Squad
# 4.437 -- Total War: ATTILA
# 4.404 -- Total War: MEDIEVAL II – Definitive Edition
# 4.339 -- Counter-Strike 2
# 4.339 -- Company of Heroes - Legacy Edition
# 4.316 -- Ancestors Legacy
# 4.306 -- Darwin Project
# 4.275 -- Steel Division 2
# 4.263 -- Men of War: Assault Squad 2
# 4.244 -- Chivalry: Medieval Warfare
# 4.186 -- Primal Carnage
# 4.164 -- Barro F22
# 4.124 -- A Total War Saga: FALL OF THE SAMURAI
# 4.121 -- Salt
# --------------------
#
# Runtime: 5.37s
#
# ------ User profile:
# 0.2 - HELLDIVERS™ 2
# 0.2 - Project Zomboid
# 1.0 - Cruelty Squad
# 1.0 - Subway Midnight
# 1.0 - Wildfrost
# 0.2 - Batman: Arkham Asylum Game of the Year Edition
# 1.0 - Overcooked! 2
# 1.0 - Sonic Frontiers
# 1.0 - Lethal Company
# 1.0 - Pizza Tower
# 1.0 - CULTIC
# 1.0 - Everhood
# 1.0 - The Stanley Parable: Ultra Deluxe
# 1.0 - SIGNALIS
# 1.0 - ELDEN RING
# 1.0 - FINAL FANTASY XIV Online
# 1.0 - Warframe
# 1.0 - Resident Evil 4
# 1.0 - ULTRAKILL
# --------------------
#
# ------ Recommendations
# 6.111 -- El Paso, Elsewhere
# 6.024 -- Monster Hunter: World
# 5.868 -- Dragon's Dogma: Dark Arisen
# 5.559 -- Eldervale
# 5.358 -- FINAL FANTASY XV WINDOWS EDITION
# 5.348 -- Two Worlds Epic Edition
# 5.305 -- Counter-Strike 2
# 4.919 -- MONSTER HUNTER RISE
# 4.892 -- Hellbound
# 4.857 -- Baldur's Gate 3
# 4.377 -- Vindictus
# 4.27 -- The Evil Within 2
# 4.194 -- SpellRogue
# 4.193 -- Godfall Ultimate Edition
# 4.187 -- DARK SOULS™ III
# 4.156 -- Overcooked
# 4.063 -- Anomalous
# 3.958 -- Limitless Hunger
# 3.797 -- UNDECEMBER
# 3.712 -- Team Fortress 2
# --------------------
#
# Runtime: 5.63s
#
# ------ User profile:
# 0.2 - STAR WARS™ Republic Commando™
# 0.2 - Bloons TD 6
# 0.2 - HELLDIVERS™ 2
# 0.2 - Call of Duty®: Black Ops III
# 0.2 - Risk of Rain 2
# 0.2 - Apex Legends™
# 0.2 - Call of Duty®: Black Ops
# 0.2 - Borderlands 3
# 1.0 - Borderlands: The Pre-Sequel
# 0.2 - Hunt: Showdown
# --------------------
#
# ------ Recommendations
# 6.529 -- Serious Sam 2
# 6.269 -- Borderlands 2
# 5.711 -- Counter-Strike 2
# 5.652 -- Borderlands Game of the Year Enhanced
# 5.644 -- Gunfire Reborn
# 5.458 -- Halo: The Master Chief Collection
# 5.329 -- Bulletstorm: Full Clip Edition
# 5.278 -- Shadow Warrior 2
# 5.26 -- Serious Sam Classic: The First Encounter
# 5.153 -- Serious Sam HD: The First Encounter
# 5.125 -- Call of Duty®: Black Ops II
# 5.092 -- PlanetSide 2
# 5.062 -- Dead Effect 2
# 5.011 -- Far Cry 3
# 4.937 -- Far Cry® 4
# 4.927 -- Serious Sam 3: BFE
# 4.662 -- Double Action: Boogaloo
# 4.652 -- Tiny Tina's Wonderlands
# 4.619 -- Half-Life 2: Deathmatch
# 4.614 -- OUTRIDERS
# --------------------
#
# Runtime: 5.04s
#
# ------ User profile:
# 1.0 - Potion Craft: Alchemist Simulator
# 0.2 - Maximum Action
# 0.2 - Thief™ Gold
# 0.2 - Dying Light 2 Stay Human: Reloaded Edition
# 0.2 - Left 4 Dead 2
# 0.2 - Resident Evil Village
# 0.2 - Wizard101
# 0.2 - Half Sword Demo
# 0.2 - Halo: The Master Chief Collection
# --------------------
#
# ------ Recommendations
# 5.443 -- Final Profit: A Shop RPG
# 5.38 -- Dynopunk: Welcome to Synth-City
# 5.358 -- News Tower
# 5.261 -- Kasi
# 5.112 -- Stardew Valley
# 5.056 -- Please Subscribe
# 4.981 -- Baker Business 3
# 4.949 -- Menu Please!
# 4.854 -- Team Fortress 2
# 4.784 -- Kynseed
# 4.732 -- SAELIG
# 4.687 -- Counter-Strike 2
# 4.516 -- Pixel Shopkeeper
# 4.515 -- Mini Transport
# 4.268 -- The Gorcs' Forge
# 4.049 -- Silk Roads: Caravan Kings
# 4.046 -- Arizona Sunshine®
# 4.003 -- Happy Empire - A Bouquet for the Princess
# 3.942 -- Little Merchant Legend
# 3.859 -- Lethal Company
# --------------------
#
# Runtime: 5.11s
#
# ------ User profile:
# 1.0 - Offworld Trading Company
# 1.0 - Undertale
# 0.2 - Chillquarium
# 1.0 - My Singing Monsters
# 1.0 - Tiny Bird Garden Deluxe
# 1.0 - Slime Rancher
# 1.0 - Viridi
# 0.2 - Risk of Rain 2
# 1.0 - Oxygen Not Included
# --------------------
#
# ------ Recommendations
# 5.533 -- Space Haven
# 5.42 -- Farlanders
# 5.343 -- Koi Farm
# 5.129 -- Garry's Mod
# 4.938 -- IXION
# 4.887 -- Bunny Park
# 4.706 -- Counter-Strike 2
# 4.626 -- Surviving the Aftermath
# 4.218 -- RimWorld
# 4.16 -- Empires of the Undergrowth
# 4.153 -- The Hex
# 4.135 -- The Final Earth 2
# 4.099 -- Stable Orbit - Build your own space station
# 4.063 -- Make Your Kingdom
# 4.039 -- Slime Rancher 2
# 4.02 -- Equilinox
# 4.01 -- Faith of Fate
# 3.982 -- ELDEN RING
# 3.84 -- HELLDIVERS™ 2
# 3.74 -- Ratopia
# --------------------
#
# Runtime: 5.22s
#
# ------ User profile:
# 1.0 - The Binding of Isaac
# 1.0 - Hot Dogs, Horseshoes & Hand Grenades
# 1.0 - Undertale
# 1.0 - Broforce
# 1.0 - Webbed
# 1.0 - CrossCode
# 1.0 - DARK SOULS™ II: Scholar of the First Sin
# 1.0 - The Stanley Parable
# 1.0 - POSTAL 2
# 1.0 - Tower of Guns
# 1.0 - LISA: The Painful
# 1.0 - Chants of Sennaar
# --------------------
#
# ------ Recommendations
# 6.564 -- The Hex
# 6.548 -- Lost Potato
# 6.454 -- Star of Providence
# 6.385 -- Straimium Immortaly
# 6.321 -- Heartbound
# 6.275 -- Kindergarten 2
# 6.12 -- Ogre Chambers DX
# 6.112 -- Jimmy and the Pulsating Mass
# 5.75 -- Stardew Valley
# 5.428 -- Killing Room
# 5.173 -- Unlucky Seven
# 4.438 -- Baldur's Gate 3
# 4.138 -- DARK SOULS™ III
# 4.01 -- Counter-Strike 2
# 4.009 -- Immortal Redneck
# 3.976 -- DARK SOULS™: REMASTERED
# 3.958 -- Unexplored
# 3.83 -- ELDEN RING
# 3.64 -- A Hat in Time
# 3.602 -- Brotato
# --------------------
#
# Runtime: 5.6s
#
# ------ User profile:
# 1.0 - ACE COMBAT™ 7: SKIES UNKNOWN
# 1.0 - War Thunder
# 1.0 - Realm Royale Reforged
# 1.0 - HELLDIVERS™ 2
# 1.0 - Microsoft Flight Simulator 40th Anniversary Edition
# 1.0 - THE FINALS
# 1.0 - Starfield
# 1.0 - Palworld
# 1.0 - Phasmophobia
# 1.0 - Factorio
# --------------------
#
# ------ Recommendations
# 8.787 -- IL-2 Sturmovik: Battle of Stalingrad
# 6.315 -- P.A.I.N.T.
# 6.176 -- Vincemus - Air Combat
# 5.693 -- Predator: Hunting Grounds
# 5.568 -- IL-2 Sturmovik: 1946
# 4.84 -- This is a Ghost
# 4.802 -- World War Next
# 4.705 -- Counter-Strike 2
# 4.602 -- Tom Clancy's Rainbow Six® Siege
# 4.483 -- Project Wingman
# 4.26 -- Against the Storm
# 4.248 -- Satisfactory
# 4.238 -- Remnant Records
# 4.218 -- Demonologist
# 4.167 -- shapez
# 4.163 -- Empires of the Undergrowth
# 4.053 -- War Gun: Shooting Games Online
# 3.989 -- PAYDAY 2
# 3.962 -- Factory Town
# 3.951 -- FINAL FANTASY XIV Online
# --------------------
#
# Runtime: 5.26s
#
# ------ User profile:
# 1.0 - ACE COMBAT™ 7: SKIES UNKNOWN
# 1.0 - Yakuza Kiwami 2
# 1.0 - HELLDIVERS™ 2
# 0.2 - Ginga Force
# 0.2 - Citizen Sleeper
# 0.2 - Pseudoregalia
# 1.0 - Monster Hunter: World
# 1.0 - Whisker Squadron: Survivor
# 0.2 - Natsuki Chronicles
# 0.2 - LISA: The Painful
# 1.0 - Persona® 5 Strikers
# 0.2 - Mega Man X Legacy Collection
# 0.2 - Mega Man X Legacy Collection 2
# 0.2 - WHAT THE GOLF?
# 1.0 - Wings of Vi
# 1.0 - OCTOPATH TRAVELER II
# 1.0 - BPM: BULLETS PER MINUTE
# 0.2 - SPRAWL
# 1.0 - The Witcher® 3: Wild Hunt
# 1.0 - Warframe
# 1.0 - DRAINUS
# 1.0 - Titanfall® 2
# 1.0 - Helltaker
# --------------------
#
# ------ Recommendations
# 7.749 -- FINAL FANTASY XV WINDOWS EDITION
# 6.221 -- LIGHTNING RETURNS™: FINAL FANTASY® XIII
# 5.908 -- Hollow Knight
# 5.613 -- Yakuza 4 Remastered
# 5.578 -- Dragon's Dogma: Dark Arisen
# 5.565 -- Fable - The Lost Chapters
# 5.433 -- Risen
# 5.376 -- DRAGON BALL Z: KAKAROT
# 5.231 -- Yakuza 3 Remastered
# 5.218 -- Kingdoms of Amalur: Reckoning™
# 5.21 -- Ys IX: Monstrum Nox
# 5.142 -- Fable Anniversary
# 5.053 -- Two Worlds Epic Edition
# 4.98 -- Risen 2: Dark Waters
# 4.975 -- .hack//G.U. Last Recode
# 4.871 -- Alien Swarm
# 4.866 -- Military Conflict: Vietnam
# 4.837 -- Divinity II: Developer's Cut
# 4.829 -- Cyberdimension Neptunia: 4 Goddesses Online
# 4.795 -- Earth Defense Force: Insect Armageddon
# --------------------
#
# Runtime: 6.56s
#
# ...
# 1.751 -- ULTRAKILL
# 1.731 -- Wobbly Life
# 1.731 -- Day of the Tentacle Remastered
# --------------------
#
# Runtime: 5.09s
#
# ------ User profile:
# 1.0 - Limbus Company
# 1.0 - Hot Dogs, Horseshoes & Hand Grenades
# 1.0 - Besiege
# 1.0 - Florence
# 1.0 - Terraria
# 1.0 - Lethal Company
# 1.0 - Lobotomy Corporation | Monster Management Simulation
# 1.0 - Cruelty Squad
# 1.0 - SIGNALIS
# 1.0 - ELDEN RING
# 1.0 - Sea of Thieves 2023 Edition
# --------------------
#
# ------ Recommendations
# 7.607 -- Tom Clancy's Rainbow Six® Siege
# 6.586 -- Counter-Strike 2
# 3.024 -- Deep Rock Galactic
# 2.918 -- Stardew Valley
# 2.878 -- Baldur's Gate 3
# 2.716 -- Brawlhalla
# 2.335 -- HELLDIVERS™ 2
# 1.953 -- DARK SOULS™ III
# 1.935 -- Starbound
# 1.877 -- Dig or Die
# 1.706 -- The Walking Dead
# 1.706 -- Euro Truck Simulator 2
# 1.706 -- Bloons TD 6
# 1.706 -- Satisfactory
# 1.686 -- Subnautica
# 1.686 -- Phasmophobia
# 1.686 -- Cuphead
# 1.686 -- Risk of Rain 2
# 1.686 -- Hexcells
# 1.666 -- Mount Your Friends
# --------------------
#
# Runtime: 4.94s
#
# ------ User profile:
# 1.0 - Red Faction Guerrilla Steam Edition
# 0.2 - SYNTHETIK 2
# 0.2 - Tiny Rogues
# 0.2 - Into the Breach
# 0.2 - Crying Suns
# 0.2 - HELLDIVERS™ 2
# 1.0 - Dying Light
# 1.0 - Sekiro™: Shadows Die Twice - GOTY Edition
# 1.0 - Metro Exodus
# 0.2 - Baldur's Gate 3
# 1.0 - RUINER
# 1.0 - FTL: Faster Than Light
# 1.0 - Hylics 2
# 1.0 - Resident Evil 7 Biohazard
# 0.2 - Dota 2
# 1.0 - INSIDE
# 1.0 - Enter the Gungeon
# 1.0 - The Binding of Isaac: Rebirth
# 1.0 - Titanfall® 2
# --------------------
#
# ------ Recommendations
# 8.7 -- Counter-Strike 2
# 5.445 -- Team Fortress 2
# 2.556 -- RimWorld
# 2.523 -- Stardew Valley
# 2.463 -- DARK SOULS™ III
# 2.354 -- ARMORED CORE™ VI FIRES OF RUBICON™
# 2.344 -- Hardspace: Shipbreaker
# 2.099 -- Apex Legends™
# 2.044 -- THE FINALS
# 2.039 -- Resident Evil Village
# 1.918 -- Metro 2033 Redux
# 1.824 -- Toroom
# 1.815 -- Resident Evil 7 Teaser: Beginning Hour
# 1.773 -- Far Cry®
# 1.737 -- OneShot
# 1.737 -- WITCH ON THE HOLY NIGHT
# 1.719 -- Eternal Evil
# 1.717 -- Slay the Spire
# 1.717 -- Peggle Deluxe
# 1.717 -- I Was a Teenage Exocolonist
# --------------------
#
# Runtime: 5.69s
#
# ------ User profile:
# 0.2 - VTOL VR
# 0.2 - Star Trek™: Bridge Crew
# 1.0 - Heroes Rise: The Prodigy
# 0.2 - DiRT Rally 2.0
# 1.0 - Tabletop Simulator
# 0.2 - Universe Sandbox
# -1.0 - Magic: The Gathering Arena
# 1.0 - The Walking Dead
# 0.2 - SteamVR
# 1.0 - Emily is Away Too
# 1.0 - The Hero Project: Redemption Season
# --------------------
#
# ------ Recommendations
# 6.714 -- HELLDIVERS™ 2
# 5.129 -- Counter-Strike 2
# 3.444 -- Lethal Company
# 3.427 -- Valheim
# 3.426 -- Stardew Valley
# 3.424 -- Baldur's Gate 3
# 3.384 -- Palworld
# 3.314 -- ELDEN RING
# 3.158 -- Rust
# 3.111 -- Tom Clancy's Rainbow Six® Siege
# 2.676 -- Call of Duty®
# 1.992 -- The Walking Dead: Season Two
# 1.984 -- Fallen Hero: Rebirth
# 1.984 -- Choice of Robots
# 1.977 -- 180 Files: The Aegis Project
# 1.947 -- The Walking Dead: The Final Season
# 1.897 -- 3dSen VR
# 1.858 -- Heroes Rise: HeroFall
# 1.776 -- Champion of the Gods
# 1.766 -- A Midsummer Night's Choice
# --------------------
#
# Runtime: 4.97s
#
# ------ User profile:
# -1.0 - MORDHAU
# 1.0 - Tom Clancy's Rainbow Six® Siege
# 1.0 - 100 hidden snails 2
# -1.0 - Just Cause 4 Reloaded
# 1.0 - We. The Revolution
# 1.0 - NGU IDLE
# 1.0 - Bit Blaster XL
# 0.2 - Dead Cells
# 1.0 - Teardown
# 1.0 - Dishonored
# 0.2 - HITMAN 3
# 0.2 - Bloons TD 6
# 1.0 - Chivalry: Medieval Warfare
# 1.0 - Path of Exile
# 1.0 - Just Cause 2
# 0.2 - Anno 1800
# 1.0 - The Elder Scrolls V: Skyrim Special Edition
# 0.2 - Stardew Valley
# 0.2 - Coloring Game 4
# 0.2 - The Binding of Isaac: Rebirth
# 1.0 - Hook
# 1.0 - Verdun
# 0.2 - Red Dead Redemption 2
# 0.2 - Factorio
# --------------------
#
# ------ Recommendations
# 27.969 -- Counter-Strike 2
# 5.327 -- Left 4 Dead 2
# 4.42 -- HELLDIVERS™ 2
# 2.451 -- Baldur's Gate 3
# 2.215 -- ELDEN RING
# 2.066 -- Mini Pipes - A Logic Puzzle Pipes Game
# 2.012 -- Destiny 2
# 2.002 -- One Circle
# 1.995 -- Dota 2
# 1.994 -- Dead by Daylight
# 1.99 -- klocki
# 1.985 -- Hexcells
# 1.974 -- Zenge
# 1.88 -- hocus
# 1.838 -- Insurgency: Sandstorm
# 1.78 -- Grand Theft Auto V
# 1.761 -- Bars and Balance
# 1.76 -- 100 hidden aliens
# 1.76 -- Isonzo
# 1.734 -- dogpet
# --------------------
#
# Runtime: 5.87s
#
# ------ User profile:
# -1.0 - DRAMA
# 1.0 - Gamedec - Definitive Edition
# 1.0 - Death Trash
# 1.0 - Sockventure
# 1.0 - Monument
# 1.0 - Legend of Keepers: Career of a Dungeon Manager
# 1.0 - AEW: Fight Forever
# 0.2 - Warframe
# 1.0 - Dorfromantik
# 1.0 - Mayhem in Single Valley
# 1.0 - Hellpoint
# 1.0 - UnMetal
# 1.0 - Phoenix Point
# 1.0 - The Hand of Merlin
# 1.0 - Songs of Conquest
# --------------------
#
# ------ Recommendations
# 9.672 -- ELDEN RING
# 2.546 -- RimWorld
# 2.523 -- Dead Cells
# 2.513 -- Stardew Valley
# 2.478 -- Garry's Mod
# 2.47 -- Counter-Strike 2
# 2.458 -- The Elder Scrolls IV: Oblivion® Game of the Year Edition
# 2.278 -- Grand Theft Auto V
# 2.162 -- HELLDIVERS™ 2
# 2.037 -- Adventurer Farmer: Save my son!
# 1.998 -- DUSK
# 1.954 -- Quake
# 1.923 -- Super Meat Boy
# 1.914 -- Quake II
# 1.897 -- Dr. oil
# 1.873 -- Space Wreck
# 1.773 -- Never Give Up
# 1.765 -- Half-Life: Alyx
# 1.753 -- Land Above Sea Below Prologue
# 1.745 -- Kingdom Rush  - Tower Defense
# --------------------
#
# Runtime: 5.56s
#
# ------ User profile:
# 1.0 - Kenshi
# -1.0 - MOBILE SUIT GUNDAM BATTLE OPERATION 2
# 1.0 - Project Zomboid
# 1.0 - We Who Are About To Die
# -1.0 - Blackguards 2
# 1.0 - Mount & Blade II: Bannerlord
# 1.0 - ARK: Survival Evolved
# -1.0 - No One Survived
# --------------------
#
# ------ Recommendations
# 7.668 -- Counter-Strike 2
# 4.813 -- Team Fortress 2
# 4.805 -- Red Dead Redemption 2
# 4.318 -- BONELAB
# 2.457 -- HELLDIVERS™ 2
# 2.278 -- Terraria
# 2.166 -- Paladins®
# 2.155 -- Tom Clancy's Rainbow Six® Siege
# 2.138 -- 7 Days to Die
# 2.022 -- Mount & Blade: Warband
# 1.974 -- Necesse
# 1.924 -- Mount & Blade
# 1.906 -- Raft
# 1.893 -- Dig or Die
# 1.79 -- Mount & Blade: With Fire & Sword
# 1.694 -- ULTRAKILL
# 1.694 -- A Hat in Time
# 1.674 -- Slay the Spire
# 1.674 -- Bloons TD 6
# 1.674 -- Counter-Strike
# --------------------
#
# Runtime: 5.19s
#
# ------ User profile:
# 1.0 - Euro Truck Simulator 2
# 1.0 - Beachhead: DESERT WAR
# 1.0 - Call of Duty® 2
# 1.0 - ArcaniA
# 1.0 - Call of Duty: United Offensive
# 1.0 - Call of Duty: World at War
# 1.0 - Half-Life 2: Lost Coast
# 1.0 - Five Dates
# 0.2 - Counter-Strike 2
# -1.0 - GRIS
# 1.0 - Call of Duty®: Ghosts
# 1.0 - Call of Duty®: Advanced Warfare - Gold Edition
# 1.0 - Counter-Strike: Source
# 1.0 - Call of Duty®: WWII
# 1.0 - Call of Duty® 4: Modern Warfare® (2007)
# 1.0 - Call of Duty® (2003)
# --------------------
#
# ------ Recommendations
# 16.318 -- Tom Clancy's Rainbow Six® Siege
# 5.895 -- Grand Theft Auto V
# 5.709 -- Dota 2
# 5.503 -- Yu-Gi-Oh! Master Duel
# 2.053 -- Call of Duty®: Modern Warfare® 2 (2009)
# 1.938 -- Tom Clancy's Ghost Recon®
# 1.937 -- Call of Duty®: Black Ops
# 1.908 -- Brothers in Arms: Road to Hill 30™
# 1.892 -- Call of Duty®: Modern Warfare® 3 (2011)
# 1.883 -- Brothers in Arms: Hell's Highway™
# 1.825 -- Red Orchestra: Ostfront 41-45
# 1.792 -- Call of Juarez: Bound in Blood
# 1.786 -- Call of Duty®: Black Ops II
# 1.753 -- HoloCure - Save the Fans!
# 1.733 -- Stardew Valley
# 1.733 -- ULTRAKILL
# 1.727 -- Medal of Honor™
# 1.713 -- Papers, Please
# 1.713 -- American Truck Simulator
# 1.713 -- Bloons TD 6
# --------------------
#
# Runtime: 5.82s
#
# ------ User profile:
# 1.0 - Nine Parchments
# -1.0 - Beholder
# 1.0 - Pathologic 2
# -1.0 - Hollow Knight
# 1.0 - Dead Cells
# 1.0 - Lumberhill
# -1.0 - Surviving Mars
# 1.0 - The Beginner's Guide
# 1.0 - Path of Exile
# 1.0 - Slay the Spire
# 1.0 - Convoy
# 1.0 - DARK SOULS™ III
# 1.0 - Yes, Your Grace
# --------------------
#
# ------ Recommendations
# 7.457 -- Dead by Daylight
# 5.116 -- HELLDIVERS™ 2
# 4.31 -- Counter-Strike 2
# 2.972 -- Deep Rock Galactic
# 2.936 -- Balatro
# 2.841 -- Baldur's Gate 3
# 2.776 -- Dota 2
# 2.761 -- ELDEN RING
# 2.741 -- Core Keeper
# 1.84 -- DARK SOULS™: REMASTERED
# 1.822 -- Dicey Dungeons
# 1.82 -- Summum Aeterna
# 1.8 -- Folk Hero
# 1.783 -- Poker Quest: Swords and Spades
# 1.775 -- Victor Vran ARPG
# 1.745 -- Blood Card 2: Dark Mist
# 1.664 -- Stardew Valley
# 1.65 -- Blood Card
# 1.644 -- Cookie Clicker
# 1.644 -- Sayonara Wild Hearts
# --------------------
#
# Runtime: 5.31s
#
# ------ User profile:
# 0.2 - God of War
# 0.2 - HELLDIVERS™ 2
# 0.2 - Destiny 2
# -1.0 - UNO
# 0.2 - Planet Zoo
# 1.0 - Sunkenland
# 0.2 - House Flipper 2
# 1.0 - House Flipper
# --------------------
#
# ------ Recommendations
# 9.095 -- Counter-Strike 2
# 4.655 -- Valheim
# 2.486 -- Baldur's Gate 3
# 2.485 -- Balatro
# 2.438 -- The Elder Scrolls V: Skyrim Special Edition
# 2.347 -- Sea of Thieves 2023 Edition
# 2.305 -- TEKKEN 8
# 2.084 -- Tom Clancy's Rainbow Six® Siege
# 2.0 -- Dota 2
# 1.721 -- Hotline Miami
# 1.721 -- Brotato
# 1.721 -- Cookie Clicker
# 1.721 -- Slay the Spire
# 1.721 -- Totally Accurate Battle Simulator
# 1.721 -- Factorio
# 1.721 -- Counter-Strike
# 1.721 -- Mount & Blade: Warband
# 1.701 -- Castle Crashers®
# 1.701 -- Your Only Move Is HUSTLE
# 1.701 -- Risk of Rain 2
# --------------------
#
# Runtime: 5.18s
#
# ------ User profile:
# 0.2 - Warhammer 40,000: Chaos Gate - Daemonhunters
# 1.0 - Aliens: Dark Descent
# 1.0 - Baldur's Gate 3
# 1.0 - BATTLETECH
# 1.0 - Dune: Spice Wars
# 1.0 - Shop Heroes
# 1.0 - Volleyball Unbound - Pro Beach Volleyball
# 1.0 - Frostpunk
# --------------------
#
# ------ Recommendations
# 9.014 -- Workers & Resources: Soviet Republic
# 4.35 -- Counter-Strike 2
# 2.956 -- ELDEN RING
# 2.925 -- Dota 2
# 2.836 -- Europa Universalis IV
# 2.756 -- Cyberpunk 2077
# 1.913 -- XCOM: Enemy Unknown
# 1.791 -- Northgard
# 1.779 -- Foundation
# 1.748 -- Half-Life: Alyx
# 1.748 -- Stardew Valley
# 1.743 -- They Are Billions
# 1.728 -- Papers, Please
# 1.728 -- BattleBlock Theater®
# 1.728 -- Lethal League Blaze
# 1.728 -- Bloons TD 6
# 1.728 -- Slay the Spire
# 1.725 -- XCOM® 2
# 1.724 -- Planetary Annihilation: TITANS
# 1.708 -- VVVVVV
# --------------------
#
# Runtime: 4.89s
#
# ------ User profile:
# -1.0 - Back 4 Blood
# 1.0 - Monster Hunter: World
# -1.0 - Conan Exiles
# 1.0 - Crusader Kings III
# -1.0 - BONELAB
# -1.0 - World War Z
# -1.0 - Apex Legends™
# -1.0 - Borderlands 3
# -1.0 - HARD BULLET
# -1.0 - NARUTO TO BORUTO: SHINOBI STRIKER
# 1.0 - Mount & Blade II: Bannerlord
# -1.0 - DEATHLOOP
# -1.0 - Warhammer 40,000: Darktide
# -1.0 - Zero Caliber VR
# --------------------
#
# ------ Recommendations
# 13.11 -- ELDEN RING
# 8.62 -- Counter-Strike 2
# 4.643 -- Euro Truck Simulator 2
# 2.371 -- HELLDIVERS™ 2
# 2.363 -- Stardew Valley
# 2.07 -- Grand Theft Auto V
# 2.008 -- Cyberpunk 2077
# 1.973 -- DARK SOULS™ III
# 1.97 -- Dota 2
# 1.946 -- DRAGON BALL Z: KAKAROT
# 1.935 -- Mount & Blade
# 1.889 -- DARK SOULS™: REMASTERED
# 1.888 -- Crusader Kings II
# 1.874 -- Dragon's Dogma: Dark Arisen
# 1.847 -- FINAL FANTASY XIV Online
# 1.846 -- DARK SOULS™ II
# 1.839 -- Mount & Blade: With Fire & Sword
# 1.757 -- 20 Small Mazes
# 1.747 -- FINAL FANTASY XV WINDOWS EDITION
# 1.737 -- CLANNAD
# --------------------
#
# Runtime: 5.58s
#
# ------ User profile:
# 1.0 - DARIUSBURST Chronicle Saviours
# 1.0 - DOOM 64
# 1.0 - MELTY BLOOD: TYPE LUMINA
# 1.0 - BlazBlue Centralfiction
# 1.0 - Savant - Ascent REMIX
# 1.0 - UNDER NIGHT IN-BIRTH II Sys:Celes
# 1.0 - Idol Showdown
# 1.0 - Among Us
# 1.0 - HoloCure - Save the Fans!
# 1.0 - Shooting Game KARI
# --------------------
#
# ------ Recommendations
# 7.313 -- Stardew Valley
# 6.384 -- Baldur's Gate 3
# 4.796 -- HELLDIVERS™ 2
# 2.583 -- Hollow Knight
# 2.582 -- Phasmophobia
# 2.403 -- 7 Days to Die
# 2.383 -- Counter-Strike 2
# 2.26 -- Dota 2
# 2.07 -- GUILTY GEAR Xrd REV 2
# 2.046 -- Melty Blood Actress Again Current Code
# 2.014 -- FOOTSIES Rollback Edition
# 1.998 -- GUILTY GEAR Xrd -SIGN-
# 1.984 -- UNDER NIGHT IN-BIRTH Exe:Late
# 1.977 -- DRAGON BALL FighterZ
# 1.96 -- THE KING OF FIGHTERS 2002 UNLIMITED MATCH
# 1.955 -- THE KING OF FIGHTERS XIII STEAM EDITION
# 1.854 -- THE KING OF FIGHTERS '98 ULTIMATE MATCH FINAL EDITION
# 1.849 -- Umineko: Golden Fantasia
# 1.838 -- Guilty Gear X2 #Reload
# 1.835 -- CHAOS CODE -NEW SIGN OF CATASTROPHE-
# --------------------
#
# Runtime: 5.24s
#
# ------ User profile:
# 1.0 - Sins of a Solar Empire®: Rebellion
# 1.0 - Company of Heroes 2
# 1.0 - Ready or Not
# 1.0 - South Park™: The Stick of Truth™
# 1.0 - X4: Foundations
# 1.0 - Hell Let Loose
# -1.0 - Ultimate General: Civil War
# 1.0 - Elite Dangerous
# 1.0 - HELLDIVERS™ 2
# 1.0 - Age of Empires II (Retired)
# 1.0 - Door Kickers 2: Task Force North
# 1.0 - Subnautica: Below Zero
# 1.0 - Axis & Allies 1942 Online
# 1.0 - Total War: SHOGUN 2
# -1.0 - ELDEN RING
# --------------------
#
# ------ Recommendations
# 6.381 -- Tom Clancy's Rainbow Six® Siege
# 4.552 -- Counter-Strike 2
# 4.514 -- Valheim
# 4.339 -- RimWorld
# 4.294 -- Squad
# 4.14 -- Balatro
# 4.134 -- DayZ
# 1.977 -- Company of Heroes: Tales of Valor
# 1.952 -- Company of Heroes
# 1.944 -- Company of Heroes: Opposing Fronts
# 1.937 -- Company of Heroes - Legacy Edition
# 1.883 -- Age of Empires® III (2007)
# 1.856 -- Men of War™
# 1.837 -- Men of War: Assault Squad
# 1.834 -- Faces of War
# 1.758 -- X3: Terran Conflict
# 1.701 -- Evochron Legacy SE
# 1.662 -- OneShot
# 1.662 -- Half-Life: Alyx
# 1.662 -- A Hat in Time
# --------------------
#
# Runtime: 5.8s
#
# ------ User profile:
# 1.0 - Ultimate Chicken Horse
# 1.0 - Counter-Strike 2
# 1.0 - Banished
# 1.0 - A Plague Tale: Innocence
# 1.0 - Shadow of the Tomb Raider: Definitive Edition
# 0.2 - Aperture Desk Job
# 1.0 - Edna & Harvey: The Breakout - Anniversary Edition
# 1.0 - Team Fortress 2
# 1.0 - Terraria
# 1.0 - Age of Mythology: Extended Edition
# 1.0 - Left 4 Dead 2
# 0.2 - Sid Meier's Civilization® V
# 1.0 - Dota 2
# 1.0 - Path of Exile
# 1.0 - Command & Conquer 3: Tiberium Wars
# 1.0 - Portal 2
# 1.0 - The Binding of Isaac: Rebirth
# 1.0 - Trials Fusion™
# 1.0 - Lethal League Blaze
# --------------------
#
# ------ Recommendations
# 10.037 -- Garry's Mod
# 2.056 -- Command & Conquer 3: Kane's Wrath
# 2.042 -- Resident Evil 2
# 2.036 -- Warhammer® 40,000: Dawn of War® - Dark Crusade
# 2.022 -- Warhammer® 40,000: Dawn of War® - Game of the Year Edition
# 2.022 -- Rise of Nations: Extended Edition
# 2.014 -- Warhammer® 40,000: Dawn of War® - Soulstorm
# 1.948 -- The Evil Within 2
# 1.947 -- Halo Wars: Definitive Edition
# 1.927 -- Move or Die
# 1.892 -- Homeworld Remastered Collection
# 1.885 -- Splitgate
# 1.876 -- Tom Clancy's Rainbow Six® Siege
# 1.835 -- SpellForce - Platinum Edition
# 1.829 -- Totally Accurate Battle Simulator
# 1.829 -- Euro Truck Simulator 2
# 1.829 -- Stray
# 1.829 -- Slay the Spire
# 1.829 -- Thronefall
# 1.809 -- Risk of Rain 2
# --------------------
#
# Runtime: 6.05s
#
# ------ User profile:
# 1.0 - Paladins®
# 1.0 - DmC: Devil May Cry
# 1.0 - Titan Souls
# 1.0 - Counter-Strike 2
# 1.0 - The Binding of Isaac: Rebirth
# 1.0 - Freedom Planet
# 1.0 - Jet Set Radio
# 1.0 - Castle of Illusion
# 1.0 - Mega Man Legacy Collection
# 1.0 - Garry's Mod
# --------------------
#
# ------ Recommendations
# 6.537 -- Outer Wilds
# 6.212 -- Dota 2
# 6.077 -- HELLDIVERS™ 2
# 2.04 -- Crash Bandicoot™ N. Sane Trilogy
# 2.031 -- Lightphobe
# 1.955 -- Counter-Strike: Source
# 1.944 -- Marc Eckō's Getting Up: Contents Under Pressure
# 1.88 -- Prince of Persia®: The Sands of Time
# 1.844 -- Devil May Cry HD Collection
# 1.843 -- Prince of Persia: Warrior Within™
# 1.826 -- Mega Man X Legacy Collection 2
# 1.826 -- Mega Man 11
# 1.784 -- Tom Clancy's Rainbow Six® Siege
# 1.767 -- Shantae: Risky's Revenge - Director's Cut
# 1.765 -- VTOL VR
# 1.765 -- A Hat in Time
# 1.758 -- Mega Man Legacy Collection 2
# 1.745 -- Mount & Blade: Warband
# 1.745 -- Hot Dogs, Horseshoes & Hand Grenades
# 1.745 -- Slay the Spire
# --------------------
#
# Runtime: 5.22s
#
# Positives: 13
# Negatives: 11
# Score: 2.438313586997797
#
# ---
# Good:
# [(1, 11), (2, 1), (3, 1), (9, 4), (13, 5), (17, 8), (19, 1), (21, 14), (25, 1), (31, 3), (47, 11), (52, 1), (53, 1)]
#
# ---
# Bad:
# [(4, 19), (5, 3), (9, 1), (12, 4), (15, 2), (24, 3), (28, 1), (31, 18), (32, 18), (39, 7), (48, 1)]
# 2.438313586997797
# | 23        | 2.438     | 74.59     | 25.87     | 3.0       | 2.0       | 0.95      | 20.0      | 100.0     |
# =============================================================================================================
# {'target': 3.059981684981685, 'params': {'collab_filter_limit': 86.99048980515778, 'content_filter_limit': 35.624591945359406, 'double_bonus': 3.0, 'popular_bias': 2.0, 'ratio': 0.95, 'recs': 20.0, 'similar_user_limit': 100.0}}
# {'target': 3.059981684981685,
#  'params': {'collab_filter_limit': 86.99048980515778,
#   'content_filter_limit': 35.624591945359406,
#   'double_bonus': 3.0,
#   'popular_bias': 2.0,
#   'ratio': 0.95,
#   'recs': 20.0,
#   'similar_user_limit': 100.0}}

# %% [markdown]
# ### Conclusion
#
# While the bulk of the conclusions and analysis will be in the forthcoming presentation step, we can see by the 'target' score that we are able to games that the user will enjoy much more frequently than games the user will not enjoy, and that the optimal parameters for our evaluation function are as follows (I had to remove the outputs to make the notebook readable):
#
# {'target': 13.0,
#  'params': {'collab_filter_limit': 103.48734651630105,
#   'content_filter_limit': 32.921446485352185,
#   'double_bonus': 1.7930894746349533,
#   'popular_bias': 1.8472839810604431,
#   'ratio': 0.7140703845572055,
#   'recs': 20.0,
#   'similar_user_limit': 250.0}}
