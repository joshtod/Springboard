# %% [markdown]
# Visits the 'recommendations' page of each user's profile and logs records with the following:
# 1. 'user' ---- user's id
# 2. 'app_id' ---- game's appid
# 3. 'positive' ---- 1 if review is positive, 0 if negative
# 4. 'total_playtime' ---- user's playtime in the game
# 5. 'review_playtime' ---- in the game at the time of review, if different
# 6. 'text' ---- text of review, if any
# 7. 'helpful_count' ---- how many people found the review helpful
# 8. 'review_date' ---- date of the review
# 9. 'edit_date' ---- date the review was last edited, if any
# 10. 'date_scraped' ---- date scraped

# %%
# Basic DS stuff
import numpy as np
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq

# Data manipulation
import re

# Web scraping
from bs4 import BeautifulSoup
from urllib.request import urlopen

# For labeling records, tracking files, and formatting
from datetime import datetime
import time

# For Rick
import pickle

# %%
last_digit = 7

# %%
# ### NOTE: Only use once. Instantiates digit table & varaibles.

# orig_table = pq.read_table(f'../data/raw/review_table.parquet')
# seed_table = pa.Table.from_batches([], schema=orig_table.schema)
# pq.write_table(seed_table, f'../data/raw/review_table_{last_digit}.parquet')

# with open(f'../data/raw/review_scraped_users.pkl', 'rb+') as file :
#     review_scraped_users = pickle.load(file)
# with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(review_scraped_users, file)

# with open(f'../data/raw/users_with_no_reviews.pkl', 'rb+') as file :
#     users_with_no_reviews = pickle.load(file)
# with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
#     pickle.dump(users_with_no_reviews, file)

# %%
# Load data

with open('../data/raw/all_users', 'rb+') as file :
    all_users = set(pickle.load(file))

with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
    review_scraped_users = pickle.load(file)

with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
    users_with_no_reviews = pickle.load(file)

# %%
# Establish vars

# Use as url.format(userid)
url = 'https://steamcommunity.com/profiles/{}/recommended/'

digit_users = {user for user in all_users if int(user[-1]) == last_digit}

unscraped_users = digit_users - review_scraped_users

skipped_users = {}

# %%
# Useful functions

def log_failure(user, message) :
    print(message)
    skipped_users[user] = message
    with open(f'../data/raw/review_skipped_users_{last_digit}.pkl', 'wb+') as file :
        pickle.dump(skipped_users, file)

# %%
# Main loop

counter = 0
holding_list = []
temp_scraped_users = set()

for user in unscraped_users :

    # Yes soup for you!
    try :
        html = urlopen(url.format(user))
        soup = BeautifulSoup(html, 'lxml')
        review_blocks = soup.find_all('div', class_='review_box')
        if len(review_blocks) == 0 :
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'rb+') as file :
                users_with_no_reviews = pickle.load(file)
            users_with_no_reviews.add(user)
            with open(f'../data/raw/users_with_no_reviews_{last_digit}.pkl', 'wb+') as file :
                pickle.dump(users_with_no_reviews, file)
            temp_scraped_users.add(user)
            continue
    except :
        log_failure(user, 'Unable to parse review blocks.')
        continue

    for review_block in review_blocks :

        holding_dict = {}

        # Specify user
        holding_dict['user'] = user

        # Get appid
        try :
            app_link = review_block.find('a').get('href')
            app_id = re.findall(r'\d+', app_link)
            holding_dict['app_id'] = int(app_id[0])
        except :
            holding_dict['app_id'] = 'Failed'
        
        # Get 'positive'
        try :
            r_or_n = review_block.find('div', class_='title').find('a').get_text()
            if r_or_n[0] == 'R' :
                holding_dict['positive'] = 1
            else :
                holding_dict['positive'] = 0
        except :
            holding_dict['positive'] = 'Failed'

        # Get playtimes
        try :
            playtimes = review_block.find('div', class_='hours').get_text().replace(',', '')
            pruned_playtimes = re.findall(r'[-+]?\d*\.?\d+|\d+', playtimes)
            for i in range(len(pruned_playtimes)) :
                pruned_playtimes[i] = float(pruned_playtimes[i])
            holding_dict['total_playtime'] = pruned_playtimes[0]
            if len(pruned_playtimes) > 1 :
                holding_dict['review_playtime'] = pruned_playtimes[1]
            else :
                holding_dict['review_playtime'] = pruned_playtimes[0]
        except :
            holding_dict['total_playtime'] = 'Failed'
            holding_dict['review_playtime'] = 'Failed'

        # Get review text
        try :
            review_text = review_block.find('div', class_='content').get_text().strip()
            holding_dict['text'] = review_text
        except :
            holding_dict['text'] = 'Failed'

        # Get 'helpful' counts
        try :
            helpful_str = review_block.find('div', class_='header').get_text()
            helpful_str = helpful_str.split('found')[0]
            helpful_count = re.findall(r'\d+', helpful_str)
            if len(helpful_count) != 0 :
                holding_dict['helpful_count'] = int(helpful_count[0])
            else :
                holding_dict['helpful_count'] = 0
        except :
            holding_dict['helpful_count'] = 'Failed'

        # Get review date
        try :
            posted_text = review_block.find('div', class_='posted').get_text().strip().replace('.', '')
            review_date_text = posted_text[7:]
            # If the review was edited, this str will contain the original date,
            # then a bunch of weird, un-strip()-able whitespace, then the edited date.
            # Let's split these two dates.
            if len(review_date_text) > 20 :
                date_texts = review_date_text.split('Last edited')
                date_texts[0] = date_texts[0][:-9]
                date_texts[1] = date_texts[1][1:]
            else :
                date_texts = [review_date_text, review_date_text]
            # Dates for reviews made in the current year do not include the year.
            # For consistency, we can add it manually.
            for i in range(2) :
                if ',' not in date_texts[i] :
                    year = datetime.now().year
                    date_texts[i] = date_texts[i] + f", {year}"
                date_texts[i] = datetime.strptime(date_texts[i], '%B %d, %Y')
            holding_dict['review_date'] = date_texts[0].date()
            holding_dict['edit_date'] = date_texts[1].date()
        except :
            holding_dict['review_date'] = 'Failed'
            holding_dict['edit_date'] = 'Failed'

        # Log the scraped date
        holding_dict['date_scraped'] = datetime.now().date()

        # Append the holding dict to the df at this level
        holding_list.append(holding_dict.copy())
    
    temp_scraped_users.add(user)

    counter += 1

    if counter % 50 == 0 :
        # Save to disk
        this_round_df = pd.DataFrame(holding_list)
        this_round_table = pa.Table.from_pandas(this_round_df)
        extant_table = pq.read_table(f'../data/raw/review_table_{last_digit}.parquet')
        total_table = pa.concat_tables([extant_table, this_round_table])
        # Release the memory
        extant_table = None
        pq.write_table(total_table, f'../data/raw/review_table_{last_digit}.parquet')
        # Store len and release memory
        all_records = len(total_table)
        total_table = None

        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'rb+') as file :
            review_scraped_users = pickle.load(file)
        review_scraped_users.update(temp_scraped_users)
        with open(f'../data/raw/review_scraped_users_{last_digit}.pkl', 'wb+') as file :
            pickle.dump(review_scraped_users, file)

        # Report
        print(f'Scraped {len(temp_scraped_users)} users this round')
        print(f'Got {len(holding_list)} reivews')
        print(f'{all_records} reviews are now in the bag, so to speak')
        print(datetime.now().replace(microsecond=0))
        print('')

        # Reset
        temp_scraped_users = set()
        holding_list = []
# Out:
# Scraped 110 users this round
# Got 195 reivews
# 360262 reviews are now in the bag, so to speak
# 2024-03-31 20:25:41
#
# Scraped 105 users this round
# Got 164 reivews
# 360426 reviews are now in the bag, so to speak
# 2024-03-31 20:29:30
#
# Scraped 113 users this round
# Got 191 reivews
# 360617 reviews are now in the bag, so to speak
# 2024-03-31 20:33:26
#
# Scraped 86 users this round
# Got 195 reivews
# 360812 reviews are now in the bag, so to speak
# 2024-03-31 20:36:26
#
# Scraped 114 users this round
# Got 202 reivews
# 361014 reviews are now in the bag, so to speak
# 2024-03-31 20:40:40
#
# Scraped 131 users this round
# Got 189 reivews
# 361203 reviews are now in the bag, so to speak
# 2024-03-31 20:45:22
#
# Scraped 96 users this round
# Got 169 reivews
# 361372 reviews are now in the bag, so to speak
# 2024-03-31 20:48:25
#
# Scraped 123 users this round
# Got 157 reivews
# 361529 reviews are now in the bag, so to speak
# 2024-03-31 20:52:40
#
# Scraped 132 users this round
# Got 169 reivews
# 361698 reviews are now in the bag, so to speak
# 2024-03-31 20:57:30
#
# Scraped 106 users this round
# Got 166 reivews
# 361864 reviews are now in the bag, so to speak
# 2024-03-31 21:01:27
#
# Scraped 126 users this round
# Got 161 reivews
# 362025 reviews are now in the bag, so to speak
# 2024-03-31 21:06:14
#
# Scraped 109 users this round
# Got 223 reivews
# 362248 reviews are now in the bag, so to speak
# 2024-03-31 21:10:03
#
# Scraped 92 users this round
# Got 159 reivews
# 362407 reviews are now in the bag, so to speak
# 2024-03-31 21:13:19
#
# Scraped 107 users this round
# Got 207 reivews
# 362614 reviews are now in the bag, so to speak
# 2024-03-31 21:17:13
#
# Scraped 134 users this round
# Got 168 reivews
# 362782 reviews are now in the bag, so to speak
# 2024-03-31 21:22:17
#
# Scraped 102 users this round
# Got 171 reivews
# 362953 reviews are now in the bag, so to speak
# 2024-03-31 21:26:25
#
# Scraped 114 users this round
# Got 192 reivews
# 363145 reviews are now in the bag, so to speak
# 2024-03-31 21:30:47
#
# Scraped 92 users this round
# Got 206 reivews
# 363351 reviews are now in the bag, so to speak
# 2024-03-31 21:34:21
#
# Scraped 138 users this round
# Got 220 reivews
# 363571 reviews are now in the bag, so to speak
# 2024-03-31 21:40:11
#
# Scraped 134 users this round
# Got 148 reivews
# 363719 reviews are now in the bag, so to speak
# 2024-03-31 21:45:39
#
# Scraped 123 users this round
# Got 144 reivews
# 363863 reviews are now in the bag, so to speak
# 2024-03-31 21:50:38
#
# Scraped 143 users this round
# Got 200 reivews
# 364063 reviews are now in the bag, so to speak
# 2024-03-31 21:56:12
#
# Scraped 112 users this round
# Got 113 reivews
# 364176 reviews are now in the bag, so to speak
# 2024-03-31 22:00:21
#
# Scraped 98 users this round
# Got 179 reivews
# 364355 reviews are now in the bag, so to speak
# 2024-03-31 22:04:00
#
# Scraped 117 users this round
# Got 164 reivews
# 364519 reviews are now in the bag, so to speak
# 2024-03-31 22:08:47
#
# Scraped 125 users this round
# Got 202 reivews
# 364721 reviews are now in the bag, so to speak
# 2024-03-31 22:15:08
#
# Scraped 103 users this round
# Got 222 reivews
# 364943 reviews are now in the bag, so to speak
# 2024-03-31 22:20:12
#
# Scraped 90 users this round
# Got 192 reivews
# 365135 reviews are now in the bag, so to speak
# 2024-03-31 22:24:54
#
# Scraped 88 users this round
# Got 161 reivews
# 365296 reviews are now in the bag, so to speak
# 2024-03-31 22:29:38
#
# Scraped 133 users this round
# Got 159 reivews
# 365455 reviews are now in the bag, so to speak
# 2024-03-31 22:37:37
#
# Scraped 105 users this round
# Got 203 reivews
# 365658 reviews are now in the bag, so to speak
# 2024-03-31 22:43:29
#
# Scraped 100 users this round
# Got 180 reivews
# 365838 reviews are now in the bag, so to speak
# 2024-03-31 22:49:37
#
# Scraped 113 users this round
# Got 168 reivews
# 366006 reviews are now in the bag, so to speak
# 2024-03-31 22:56:14
#
# Scraped 106 users this round
# Got 201 reivews
# 366207 reviews are now in the bag, so to speak
# 2024-03-31 23:02:26
#
# Scraped 98 users this round
# Got 172 reivews
# 366379 reviews are now in the bag, so to speak
# 2024-03-31 23:07:51
#
# Scraped 116 users this round
# Got 191 reivews
# 366570 reviews are now in the bag, so to speak
# 2024-03-31 23:14:06
#
# Scraped 97 users this round
# Got 141 reivews
# 366711 reviews are now in the bag, so to speak
# 2024-03-31 23:19:16
#
# Scraped 92 users this round
# Got 162 reivews
# 366873 reviews are now in the bag, so to speak
# 2024-03-31 23:24:07
#
# Scraped 90 users this round
# Got 206 reivews
# 367079 reviews are now in the bag, so to speak
# 2024-03-31 23:27:34
#
# Scraped 98 users this round
# Got 206 reivews
# 367285 reviews are now in the bag, so to speak
# 2024-03-31 23:30:53
#
# Scraped 131 users this round
# Got 194 reivews
# 367479 reviews are now in the bag, so to speak
# 2024-03-31 23:35:39
#
# Scraped 131 users this round
# Got 158 reivews
# 367637 reviews are now in the bag, so to speak
# 2024-03-31 23:40:04
#
# Scraped 118 users this round
# Got 156 reivews
# 367793 reviews are now in the bag, so to speak
# 2024-03-31 23:44:07
#
# Scraped 104 users this round
# Got 217 reivews
# 368010 reviews are now in the bag, so to speak
# 2024-03-31 23:47:35
#
# Scraped 92 users this round
# Got 169 reivews
# 368179 reviews are now in the bag, so to speak
# 2024-03-31 23:50:33
#
# Scraped 115 users this round
# Got 189 reivews
# 368368 reviews are now in the bag, so to speak
# 2024-03-31 23:54:14
#
# Scraped 95 users this round
# Got 187 reivews
# 368555 reviews are now in the bag, so to speak
# 2024-03-31 23:57:27
#
# Scraped 122 users this round
# Got 183 reivews
# 368738 reviews are now in the bag, so to speak
# 2024-04-01 00:01:37
#
# Scraped 96 users this round
# Got 165 reivews
# 368903 reviews are now in the bag, so to speak
# 2024-04-01 00:04:46
#
# Scraped 126 users this round
# Got 215 reivews
# 369118 reviews are now in the bag, so to speak
# 2024-04-01 00:09:12
#
# Scraped 98 users this round
# Got 178 reivews
# 369296 reviews are now in the bag, so to speak
# 2024-04-01 00:12:24
#
# Scraped 107 users this round
# Got 219 reivews
# 369515 reviews are now in the bag, so to speak
# 2024-04-01 00:16:04
#
# Scraped 136 users this round
# Got 191 reivews
# 369706 reviews are now in the bag, so to speak
# 2024-04-01 00:21:00
#
# Scraped 129 users this round
# Got 182 reivews
# 369888 reviews are now in the bag, so to speak
# 2024-04-01 00:25:17
#
# Scraped 110 users this round
# Got 162 reivews
# 370050 reviews are now in the bag, so to speak
# 2024-04-01 00:29:02
#
# Scraped 121 users this round
# Got 149 reivews
# 370199 reviews are now in the bag, so to speak
# 2024-04-01 00:32:57
#
# Scraped 108 users this round
# Got 187 reivews
# 370386 reviews are now in the bag, so to speak
# 2024-04-01 00:36:30
#
# Scraped 97 users this round
# Got 222 reivews
# 370608 reviews are now in the bag, so to speak
# 2024-04-01 00:39:43
#
# Unable to parse review blocks.
# Scraped 92 users this round
# Got 205 reivews
# 370813 reviews are now in the bag, so to speak
# 2024-04-01 00:43:00
#
# Scraped 114 users this round
# Got 185 reivews
# 370998 reviews are now in the bag, so to speak
# 2024-04-01 00:45:49
#
# Scraped 121 users this round
# Got 179 reivews
# 371177 reviews are now in the bag, so to speak
# 2024-04-01 00:49:48
#
# Scraped 89 users this round
# Got 147 reivews
# 371324 reviews are now in the bag, so to speak
# 2024-04-01 00:52:37
#
# Scraped 109 users this round
# Got 165 reivews
# 371489 reviews are now in the bag, so to speak
# 2024-04-01 00:56:27
#
# Scraped 96 users this round
# Got 191 reivews
# 371680 reviews are now in the bag, so to speak
# 2024-04-01 00:59:41
#
# Scraped 97 users this round
# Got 171 reivews
# 371851 reviews are now in the bag, so to speak
# 2024-04-01 01:03:04
#
# Scraped 109 users this round
# Got 191 reivews
# 372042 reviews are now in the bag, so to speak
# 2024-04-01 01:06:55
#
# Scraped 107 users this round
# Got 176 reivews
# 372218 reviews are now in the bag, so to speak
# 2024-04-01 01:10:32
#
# Scraped 116 users this round
# Got 208 reivews
# 372426 reviews are now in the bag, so to speak
# 2024-04-01 01:14:31
#
# Scraped 106 users this round
# Got 193 reivews
# 372619 reviews are now in the bag, so to speak
# 2024-04-01 01:18:09
#
# Scraped 110 users this round
# Got 215 reivews
# 372834 reviews are now in the bag, so to speak
# 2024-04-01 01:21:55
#
# Scraped 118 users this round
# Got 218 reivews
# 373052 reviews are now in the bag, so to speak
# 2024-04-01 01:25:51
#
# Scraped 115 users this round
# Got 189 reivews
# 373241 reviews are now in the bag, so to speak
# 2024-04-01 01:29:52
#
# Scraped 133 users this round
# Got 195 reivews
# 373436 reviews are now in the bag, so to speak
# 2024-04-01 01:34:36
#
# Scraped 94 users this round
# Got 176 reivews
# 373612 reviews are now in the bag, so to speak
# 2024-04-01 01:37:33
#
# Scraped 99 users this round
# Got 178 reivews
# 373790 reviews are now in the bag, so to speak
# 2024-04-01 01:40:58
#
# Scraped 108 users this round
# Got 177 reivews
# 373967 reviews are now in the bag, so to speak
# 2024-04-01 01:44:36
#
# Scraped 117 users this round
# Got 191 reivews
# 374158 reviews are now in the bag, so to speak
# 2024-04-01 01:48:36
#
# Scraped 89 users this round
# Got 158 reivews
# 374316 reviews are now in the bag, so to speak
# 2024-04-01 01:51:19
#
# Scraped 108 users this round
# Got 205 reivews
# 374521 reviews are now in the bag, so to speak
# 2024-04-01 01:54:54
#
# Scraped 104 users this round
# Got 212 reivews
# 374733 reviews are now in the bag, so to speak
# 2024-04-01 01:58:14
#
# Scraped 112 users this round
# Got 195 reivews
# 374928 reviews are now in the bag, so to speak
# 2024-04-01 02:01:58
#
# Scraped 105 users this round
# Got 184 reivews
# 375112 reviews are now in the bag, so to speak
# 2024-04-01 02:05:31
#
# Scraped 94 users this round
# Got 214 reivews
# 375326 reviews are now in the bag, so to speak
# 2024-04-01 02:08:38
#
# Scraped 122 users this round
# Got 174 reivews
# 375500 reviews are now in the bag, so to speak
# 2024-04-01 02:12:35
#
# Scraped 110 users this round
# Got 166 reivews
# 375666 reviews are now in the bag, so to speak
# 2024-04-01 02:16:17
#
# Scraped 102 users this round
# Got 198 reivews
# 375864 reviews are now in the bag, so to speak
# 2024-04-01 02:19:37
#
# Scraped 94 users this round
# Got 173 reivews
# 376037 reviews are now in the bag, so to speak
# 2024-04-01 02:22:38
#
# Scraped 113 users this round
# Got 191 reivews
# 376228 reviews are now in the bag, so to speak
# 2024-04-01 02:26:15
#
# Scraped 126 users this round
# Got 202 reivews
# 376430 reviews are now in the bag, so to speak
# 2024-04-01 02:30:39
#
# Scraped 127 users this round
# Got 141 reivews
# 376571 reviews are now in the bag, so to speak
# 2024-04-01 02:35:01
#
# Scraped 134 users this round
# Got 216 reivews
# 376787 reviews are now in the bag, so to speak
# 2024-04-01 02:39:48
#
# Scraped 126 users this round
# Got 185 reivews
# 376972 reviews are now in the bag, so to speak
# 2024-04-01 02:44:02
#
# Scraped 88 users this round
# Got 170 reivews
# 377142 reviews are now in the bag, so to speak
# 2024-04-01 02:46:56
#
# Scraped 103 users this round
# Got 199 reivews
# 377341 reviews are now in the bag, so to speak
# 2024-04-01 02:50:18
#
# Scraped 118 users this round
# Got 194 reivews
# 377535 reviews are now in the bag, so to speak
# 2024-04-01 02:54:07
#
# Scraped 114 users this round
# Got 186 reivews
# 377721 reviews are now in the bag, so to speak
# 2024-04-01 02:57:49
#
# Scraped 85 users this round
# Got 204 reivews
# 377925 reviews are now in the bag, so to speak
# 2024-04-01 03:00:20
#
# Scraped 103 users this round
# Got 229 reivews
# 378154 reviews are now in the bag, so to speak
# 2024-04-01 03:03:45
#
# Scraped 127 users this round
# Got 230 reivews
# 378384 reviews are now in the bag, so to speak
# 2024-04-01 03:08:14
#
# Scraped 99 users this round
# Got 175 reivews
# 378559 reviews are now in the bag, so to speak
# 2024-04-01 03:11:26
#
# Scraped 128 users this round
# Got 240 reivews
# 378799 reviews are now in the bag, so to speak
# 2024-04-01 03:15:50
#
# Scraped 116 users this round
# Got 163 reivews
# 378962 reviews are now in the bag, so to speak
# 2024-04-01 03:19:41
#
# Scraped 118 users this round
# Got 201 reivews
# 379163 reviews are now in the bag, so to speak
# 2024-04-01 03:24:02
#
# Scraped 106 users this round
# Got 189 reivews
# 379352 reviews are now in the bag, so to speak
# 2024-04-01 03:27:21
#
# Scraped 111 users this round
# Got 208 reivews
# 379560 reviews are now in the bag, so to speak
# 2024-04-01 03:31:10
#
# Scraped 109 users this round
# Got 195 reivews
# 379755 reviews are now in the bag, so to speak
# 2024-04-01 03:34:49
#
# Scraped 123 users this round
# Got 163 reivews
# 379918 reviews are now in the bag, so to speak
# 2024-04-01 03:38:48
#
# Scraped 84 users this round
# Got 158 reivews
# 380076 reviews are now in the bag, so to speak
# 2024-04-01 03:41:19
#
# Scraped 99 users this round
# Got 162 reivews
# 380238 reviews are now in the bag, so to speak
# 2024-04-01 03:44:27
#
# Scraped 88 users this round
# Got 200 reivews
# 380438 reviews are now in the bag, so to speak
# 2024-04-01 03:47:07
#
# Scraped 110 users this round
# Got 194 reivews
# 380632 reviews are now in the bag, so to speak
# 2024-04-01 03:50:42
#
# Scraped 101 users this round
# Got 174 reivews
# 380806 reviews are now in the bag, so to speak
# 2024-04-01 03:54:06
#
# Scraped 96 users this round
# Got 174 reivews
# 380980 reviews are now in the bag, so to speak
# 2024-04-01 03:57:10
#
# Scraped 101 users this round
# Got 181 reivews
# 381161 reviews are now in the bag, so to speak
# 2024-04-01 04:00:22
#
# Scraped 123 users this round
# Got 204 reivews
# 381365 reviews are now in the bag, so to speak
# 2024-04-01 04:04:33
#
# Scraped 123 users this round
# Got 175 reivews
# 381540 reviews are now in the bag, so to speak
# 2024-04-01 04:08:44
#
# Scraped 114 users this round
# Got 181 reivews
# 381721 reviews are now in the bag, so to speak
# 2024-04-01 04:12:22
#
# Scraped 96 users this round
# Got 175 reivews
# 381896 reviews are now in the bag, so to speak
# 2024-04-01 04:15:14
#
# Scraped 106 users this round
# Got 189 reivews
# 382085 reviews are now in the bag, so to speak
# 2024-04-01 04:18:39
#
# Scraped 102 users this round
# Got 184 reivews
# 382269 reviews are now in the bag, so to speak
# 2024-04-01 04:22:05
#
# Scraped 120 users this round
# Got 189 reivews
# 382458 reviews are now in the bag, so to speak
# 2024-04-01 04:25:56
#
# Scraped 109 users this round
# Got 161 reivews
# 382619 reviews are now in the bag, so to speak
# 2024-04-01 04:29:38
#
# Scraped 95 users this round
# Got 132 reivews
# 382751 reviews are now in the bag, so to speak
# 2024-04-01 04:32:41
#
# Scraped 105 users this round
# Got 154 reivews
# 382905 reviews are now in the bag, so to speak
# 2024-04-01 04:36:27
#
# Scraped 117 users this round
# Got 153 reivews
# 383058 reviews are now in the bag, so to speak
# 2024-04-01 04:40:11
#
# Scraped 109 users this round
# Got 166 reivews
# 383224 reviews are now in the bag, so to speak
# 2024-04-01 04:43:53
#
# Scraped 107 users this round
# Got 174 reivews
# 383398 reviews are now in the bag, so to speak
# 2024-04-01 04:47:20
#
# Scraped 124 users this round
# Got 180 reivews
# 383578 reviews are now in the bag, so to speak
# 2024-04-01 04:51:35
#
# Scraped 101 users this round
# Got 180 reivews
# 383758 reviews are now in the bag, so to speak
# 2024-04-01 04:54:48
#
# Scraped 100 users this round
# Got 179 reivews
# 383937 reviews are now in the bag, so to speak
# 2024-04-01 04:58:01
#
# Scraped 92 users this round
# Got 202 reivews
# 384139 reviews are now in the bag, so to speak
# 2024-04-01 05:00:55
#
# Scraped 120 users this round
# Got 188 reivews
# 384327 reviews are now in the bag, so to speak
# 2024-04-01 05:04:48
#
# Scraped 112 users this round
# Got 185 reivews
# 384512 reviews are now in the bag, so to speak
# 2024-04-01 05:08:27
#
# Scraped 99 users this round
# Got 191 reivews
# 384703 reviews are now in the bag, so to speak
# 2024-04-01 05:11:36
#
# Scraped 122 users this round
# Got 183 reivews
# 384886 reviews are now in the bag, so to speak
# 2024-04-01 05:15:33
#
# Scraped 101 users this round
# Got 202 reivews
# 385088 reviews are now in the bag, so to speak
# 2024-04-01 05:18:56
#
# Scraped 96 users this round
# Got 174 reivews
# 385262 reviews are now in the bag, so to speak
# 2024-04-01 05:22:04
#
# Scraped 108 users this round
# Got 180 reivews
# 385442 reviews are now in the bag, so to speak
# 2024-04-01 05:25:32
#
# Scraped 113 users this round
# Got 141 reivews
# 385583 reviews are now in the bag, so to speak
# 2024-04-01 05:29:14
#
# Scraped 115 users this round
# Got 173 reivews
# 385756 reviews are now in the bag, so to speak
# 2024-04-01 05:32:59
#
# Scraped 120 users this round
# Got 188 reivews
# 385944 reviews are now in the bag, so to speak
# 2024-04-01 05:36:46
#
# Scraped 114 users this round
# Got 167 reivews
# 386111 reviews are now in the bag, so to speak
# 2024-04-01 05:40:29
#
# Scraped 107 users this round
# Got 185 reivews
# 386296 reviews are now in the bag, so to speak
# 2024-04-01 05:44:11
#
# Unable to parse review blocks.
# Scraped 122 users this round
# Got 218 reivews
# 386514 reviews are now in the bag, so to speak
# 2024-04-01 05:49:22
#
# Scraped 113 users this round
# Got 192 reivews
# 386706 reviews are now in the bag, so to speak
# 2024-04-01 05:53:12
#
# Scraped 118 users this round
# Got 189 reivews
# 386895 reviews are now in the bag, so to speak
# 2024-04-01 05:57:01
#
# Scraped 129 users this round
# Got 192 reivews
# 387087 reviews are now in the bag, so to speak
# 2024-04-01 06:01:15
#
# Scraped 110 users this round
# Got 175 reivews
# 387262 reviews are now in the bag, so to speak
# 2024-04-01 06:04:57
#
# Scraped 101 users this round
# Got 188 reivews
# 387450 reviews are now in the bag, so to speak
# 2024-04-01 06:08:22
#
# Scraped 107 users this round
# Got 177 reivews
# 387627 reviews are now in the bag, so to speak
# 2024-04-01 06:11:51
#
# Scraped 106 users this round
# Got 179 reivews
# 387806 reviews are now in the bag, so to speak
# 2024-04-01 06:15:13
#
# Scraped 100 users this round
# Got 187 reivews
# 387993 reviews are now in the bag, so to speak
# 2024-04-01 06:18:33
#
# Scraped 95 users this round
# Got 136 reivews
# 388129 reviews are now in the bag, so to speak
# 2024-04-01 06:21:39
#
# Scraped 97 users this round
# Got 193 reivews
# 388322 reviews are now in the bag, so to speak
# 2024-04-01 06:24:56
#
# Scraped 115 users this round
# Got 170 reivews
# 388492 reviews are now in the bag, so to speak
# 2024-04-01 06:28:50
#
# Scraped 101 users this round
# Got 217 reivews
# 388709 reviews are now in the bag, so to speak
# 2024-04-01 06:32:17
#
# Scraped 112 users this round
# Got 169 reivews
# 388878 reviews are now in the bag, so to speak
# 2024-04-01 06:36:06
#
# Scraped 149 users this round
# Got 210 reivews
# 389088 reviews are now in the bag, so to speak
# 2024-04-01 06:41:13
#
# Scraped 92 users this round
# Got 177 reivews
# 389265 reviews are now in the bag, so to speak
# 2024-04-01 06:44:24
#
# Scraped 107 users this round
# Got 185 reivews
# 389450 reviews are now in the bag, so to speak
# 2024-04-01 06:47:54
#
# Scraped 139 users this round
# Got 167 reivews
# 389617 reviews are now in the bag, so to speak
# 2024-04-01 06:52:41
#
# Scraped 100 users this round
# Got 181 reivews
# 389798 reviews are now in the bag, so to speak
# 2024-04-01 06:56:00
#
# Scraped 107 users this round
# Got 166 reivews
# 389964 reviews are now in the bag, so to speak
# 2024-04-01 06:59:39
#
# Scraped 126 users this round
# Got 153 reivews
# 390117 reviews are now in the bag, so to speak
# 2024-04-01 07:04:06
#
# Scraped 115 users this round
# Got 189 reivews
# 390306 reviews are now in the bag, so to speak
# 2024-04-01 07:08:15
#
# Scraped 104 users this round
# Got 197 reivews
# 390503 reviews are now in the bag, so to speak
# 2024-04-01 07:11:53
#
# Scraped 109 users this round
# Got 143 reivews
# 390646 reviews are now in the bag, so to speak
# 2024-04-01 07:15:18
#
# Scraped 104 users this round
# Got 254 reivews
# 390900 reviews are now in the bag, so to speak
# 2024-04-01 07:18:53
#
# Scraped 108 users this round
# Got 193 reivews
# 391093 reviews are now in the bag, so to speak
# 2024-04-01 07:22:22
#
# Scraped 100 users this round
# Got 167 reivews
# 391260 reviews are now in the bag, so to speak
# 2024-04-01 07:25:42
#
# Scraped 131 users this round
# Got 204 reivews
# 391464 reviews are now in the bag, so to speak
# 2024-04-01 07:30:18
#
# Scraped 105 users this round
# Got 170 reivews
# 391634 reviews are now in the bag, so to speak
# 2024-04-01 07:33:48
#
# Scraped 110 users this round
# Got 207 reivews
# 391841 reviews are now in the bag, so to speak
# 2024-04-01 07:37:28
#
# Scraped 133 users this round
# Got 142 reivews
# 391983 reviews are now in the bag, so to speak
# 2024-04-01 07:42:19
#
# Scraped 109 users this round
# Got 215 reivews
# 392198 reviews are now in the bag, so to speak
# 2024-04-01 07:46:12
#
# Scraped 113 users this round
# Got 195 reivews
# 392393 reviews are now in the bag, so to speak
# 2024-04-01 07:50:25
#
# Scraped 98 users this round
# Got 153 reivews
# 392546 reviews are now in the bag, so to speak
# 2024-04-01 07:53:45
#
# Scraped 112 users this round
# Got 192 reivews
# 392738 reviews are now in the bag, so to speak
# 2024-04-01 07:57:23
#
# Scraped 113 users this round
# Got 204 reivews
# 392942 reviews are now in the bag, so to speak
# 2024-04-01 08:01:07
#
# Scraped 113 users this round
# Got 172 reivews
# 393114 reviews are now in the bag, so to speak
# 2024-04-01 08:04:52
#
# Scraped 99 users this round
# Got 189 reivews
# 393303 reviews are now in the bag, so to speak
# 2024-04-01 08:08:30
#
# Scraped 130 users this round
# Got 206 reivews
# 393509 reviews are now in the bag, so to speak
# 2024-04-01 08:12:57
#
# Scraped 107 users this round
# Got 206 reivews
# 393715 reviews are now in the bag, so to speak
# 2024-04-01 08:16:49
#
# Scraped 114 users this round
# Got 185 reivews
# 393900 reviews are now in the bag, so to speak
# 2024-04-01 08:20:47
#
# Scraped 104 users this round
# Got 226 reivews
# 394126 reviews are now in the bag, so to speak
# 2024-04-01 08:24:23
#
# Scraped 130 users this round
# Got 201 reivews
# 394327 reviews are now in the bag, so to speak
# 2024-04-01 08:29:11
#
# Scraped 112 users this round
# Got 202 reivews
# 394529 reviews are now in the bag, so to speak
# 2024-04-01 08:32:58
#
# Scraped 96 users this round
# Got 183 reivews
# 394712 reviews are now in the bag, so to speak
# 2024-04-01 08:36:20
#
# Scraped 125 users this round
# Got 201 reivews
# 394913 reviews are now in the bag, so to speak
# 2024-04-01 08:40:29
#
# Scraped 101 users this round
# Got 211 reivews
# 395124 reviews are now in the bag, so to speak
# 2024-04-01 08:43:53
#
# Scraped 92 users this round
# Got 145 reivews
# 395269 reviews are now in the bag, so to speak
# 2024-04-01 08:47:16
#
# Scraped 103 users this round
# Got 211 reivews
# 395480 reviews are now in the bag, so to speak
# 2024-04-01 08:50:47
#
# Scraped 109 users this round
# Got 175 reivews
# 395655 reviews are now in the bag, so to speak
# 2024-04-01 08:54:53
#
# Scraped 96 users this round
# Got 170 reivews
# 395825 reviews are now in the bag, so to speak
# 2024-04-01 08:58:07
#
# Scraped 109 users this round
# Got 198 reivews
# 396023 reviews are now in the bag, so to speak
# 2024-04-01 09:01:48
#
# Scraped 106 users this round
# Got 175 reivews
# 396198 reviews are now in the bag, so to speak
# 2024-04-01 09:05:29
#
# Scraped 131 users this round
# Got 147 reivews
# 396345 reviews are now in the bag, so to speak
# 2024-04-01 09:09:53
#
# Scraped 119 users this round
# Got 174 reivews
# 396519 reviews are now in the bag, so to speak
# 2024-04-01 09:14:14
#
# Scraped 121 users this round
# Got 172 reivews
# 396691 reviews are now in the bag, so to speak
# 2024-04-01 09:18:33
#
# Scraped 110 users this round
# Got 197 reivews
# 396888 reviews are now in the bag, so to speak
# 2024-04-01 09:22:27
#
# Scraped 103 users this round
# Got 170 reivews
# 397058 reviews are now in the bag, so to speak
# 2024-04-01 09:25:59
#
# Scraped 124 users this round
# Got 172 reivews
# 397230 reviews are now in the bag, so to speak
# 2024-04-01 09:30:50
#
# Scraped 113 users this round
# Got 141 reivews
# 397371 reviews are now in the bag, so to speak
# 2024-04-01 09:34:45
#
# Scraped 102 users this round
# Got 192 reivews
# 397563 reviews are now in the bag, so to speak
# 2024-04-01 09:38:25
#
# Scraped 106 users this round
# Got 172 reivews
# 397735 reviews are now in the bag, so to speak
# 2024-04-01 09:42:17
#
# Scraped 130 users this round
# Got 208 reivews
# 397943 reviews are now in the bag, so to speak
# 2024-04-01 09:47:13
#
# Scraped 108 users this round
# Got 239 reivews
# 398182 reviews are now in the bag, so to speak
# 2024-04-01 09:51:16
#
# Scraped 101 users this round
# Got 213 reivews
# 398395 reviews are now in the bag, so to speak
# 2024-04-01 09:54:53
#
# Scraped 130 users this round
# Got 179 reivews
# 398574 reviews are now in the bag, so to speak
# 2024-04-01 10:00:09
#
# Scraped 109 users this round
# Got 169 reivews
# 398743 reviews are now in the bag, so to speak
# 2024-04-01 10:04:16
#
# Scraped 109 users this round
# Got 195 reivews
# 398938 reviews are now in the bag, so to speak
# 2024-04-01 10:08:13
#
# Scraped 100 users this round
# Got 192 reivews
# 399130 reviews are now in the bag, so to speak
# 2024-04-01 10:11:58
#
# Scraped 98 users this round
# Got 219 reivews
# 399349 reviews are now in the bag, so to speak
# 2024-04-01 10:15:36
#
# Scraped 122 users this round
# Got 186 reivews
# 399535 reviews are now in the bag, so to speak
# 2024-04-01 10:20:04
#
# Scraped 101 users this round
# Got 188 reivews
# 399723 reviews are now in the bag, so to speak
# 2024-04-01 10:23:43
#
# Scraped 133 users this round
# Got 197 reivews
# 399920 reviews are now in the bag, so to speak
# 2024-04-01 10:29:18
#
# Scraped 97 users this round
# Got 175 reivews
# 400095 reviews are now in the bag, so to speak
# 2024-04-01 10:32:49
#
# Scraped 135 users this round
# Got 198 reivews
# 400293 reviews are now in the bag, so to speak
# 2024-04-01 10:38:03
#
# Scraped 118 users this round
# Got 170 reivews
# 400463 reviews are now in the bag, so to speak
# 2024-04-01 10:42:49
#
# Scraped 102 users this round
# Got 194 reivews
# 400657 reviews are now in the bag, so to speak
# 2024-04-01 10:46:42
#
# Scraped 103 users this round
# Got 189 reivews
# 400846 reviews are now in the bag, so to speak
# 2024-04-01 10:50:38
#
# Scraped 115 users this round
# Got 189 reivews
# 401035 reviews are now in the bag, so to speak
# 2024-04-01 10:55:09
#
# Scraped 104 users this round
# Got 185 reivews
# 401220 reviews are now in the bag, so to speak
# 2024-04-01 10:59:11
#
# Scraped 113 users this round
# Got 194 reivews
# 401414 reviews are now in the bag, so to speak
# 2024-04-01 11:03:29
#
# Scraped 106 users this round
# Got 161 reivews
# 401575 reviews are now in the bag, so to speak
# 2024-04-01 11:07:26
#
# Scraped 116 users this round
# Got 158 reivews
# 401733 reviews are now in the bag, so to speak
# 2024-04-01 11:12:19
#
# Scraped 122 users this round
# Got 171 reivews
# 401904 reviews are now in the bag, so to speak
# 2024-04-01 11:17:05
#
# Scraped 122 users this round
# Got 215 reivews
# 402119 reviews are now in the bag, so to speak
# 2024-04-01 11:21:50
#
# Scraped 104 users this round
# Got 224 reivews
# 402343 reviews are now in the bag, so to speak
# 2024-04-01 11:25:55
#
# Scraped 103 users this round
# Got 199 reivews
# 402542 reviews are now in the bag, so to speak
# 2024-04-01 11:29:45
#
# Scraped 107 users this round
# Got 177 reivews
# 402719 reviews are now in the bag, so to speak
# 2024-04-01 11:33:52
#
# Scraped 102 users this round
# Got 196 reivews
# 402915 reviews are now in the bag, so to speak
# 2024-04-01 11:37:41
#
# Scraped 101 users this round
# Got 171 reivews
# 403086 reviews are now in the bag, so to speak
# 2024-04-01 11:41:23
#
# Scraped 120 users this round
# Got 181 reivews
# 403267 reviews are now in the bag, so to speak
# 2024-04-01 11:45:55
#
# Scraped 109 users this round
# Got 195 reivews
# 403462 reviews are now in the bag, so to speak
# 2024-04-01 11:50:09
#
# Scraped 117 users this round
# Got 175 reivews
# 403637 reviews are now in the bag, so to speak
# 2024-04-01 11:54:32
#
# Scraped 92 users this round
# Got 182 reivews
# 403819 reviews are now in the bag, so to speak
# 2024-04-01 11:57:51
#
# Scraped 147 users this round
# Got 165 reivews
# 403984 reviews are now in the bag, so to speak
# 2024-04-01 12:03:25
#
# Scraped 101 users this round
# Got 213 reivews
# 404197 reviews are now in the bag, so to speak
# 2024-04-01 12:07:09
#
# Scraped 109 users this round
# Got 161 reivews
# 404358 reviews are now in the bag, so to speak
# 2024-04-01 12:11:18
#
# Scraped 116 users this round
# Got 196 reivews
# 404554 reviews are now in the bag, so to speak
# 2024-04-01 12:15:36
#
# Scraped 104 users this round
# Got 186 reivews
# 404740 reviews are now in the bag, so to speak
# 2024-04-01 12:19:29
#
# Scraped 103 users this round
# Got 209 reivews
# 404949 reviews are now in the bag, so to speak
# 2024-04-01 12:23:29
#
# Scraped 114 users this round
# Got 183 reivews
# 405132 reviews are now in the bag, so to speak
# 2024-04-01 12:27:42
#
# Scraped 107 users this round
# Got 177 reivews
# 405309 reviews are now in the bag, so to speak
# 2024-04-01 12:31:54
#
# Scraped 97 users this round
# Got 179 reivews
# 405488 reviews are now in the bag, so to speak
# 2024-04-01 12:35:13
#
# Scraped 79 users this round
# Got 205 reivews
# 405693 reviews are now in the bag, so to speak
# 2024-04-01 12:37:54
#
# Scraped 112 users this round
# Got 221 reivews
# 405914 reviews are now in the bag, so to speak
# 2024-04-01 12:42:02
#
# Scraped 122 users this round
# Got 192 reivews
# 406106 reviews are now in the bag, so to speak
# 2024-04-01 12:46:31
#
# Unable to parse review blocks.
# Scraped 111 users this round
# Got 173 reivews
# 406279 reviews are now in the bag, so to speak
# 2024-04-01 12:50:22
#
# Scraped 111 users this round
# Got 198 reivews
# 406477 reviews are now in the bag, so to speak
# 2024-04-01 12:54:22
#
# Scraped 108 users this round
# Got 208 reivews
# 406685 reviews are now in the bag, so to speak
# 2024-04-01 12:58:15
#
# Scraped 106 users this round
# Got 172 reivews
# 406857 reviews are now in the bag, so to speak
# 2024-04-01 13:02:10
#
# Scraped 112 users this round
# Got 177 reivews
# 407034 reviews are now in the bag, so to speak
# 2024-04-01 13:06:16
#
# Scraped 113 users this round
# Got 185 reivews
# 407219 reviews are now in the bag, so to speak
# 2024-04-01 13:10:04
#
# Scraped 102 users this round
# Got 245 reivews
# 407464 reviews are now in the bag, so to speak
# 2024-04-01 13:13:44
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 94 users this round
# Got 182 reivews
# 407646 reviews are now in the bag, so to speak
# 2024-04-01 13:17:05
#
# Scraped 96 users this round
# Got 217 reivews
# 407863 reviews are now in the bag, so to speak
# 2024-04-01 13:20:29
#
# Scraped 100 users this round
# Got 191 reivews
# 408054 reviews are now in the bag, so to speak
# 2024-04-01 13:24:03
#
# Scraped 130 users this round
# Got 199 reivews
# 408253 reviews are now in the bag, so to speak
# 2024-04-01 13:28:43
#
# Scraped 119 users this round
# Got 194 reivews
# 408447 reviews are now in the bag, so to speak
# 2024-04-01 13:32:54
#
# Scraped 111 users this round
# Got 187 reivews
# 408634 reviews are now in the bag, so to speak
# 2024-04-01 13:36:38
#
# Scraped 119 users this round
# Got 159 reivews
# 408793 reviews are now in the bag, so to speak
# 2024-04-01 13:40:54
#
# Scraped 124 users this round
# Got 179 reivews
# 408972 reviews are now in the bag, so to speak
# 2024-04-01 13:45:23
#
# Scraped 119 users this round
# Got 146 reivews
# 409118 reviews are now in the bag, so to speak
# 2024-04-01 13:49:40
#
# Scraped 122 users this round
# Got 174 reivews
# 409292 reviews are now in the bag, so to speak
# 2024-04-01 13:54:00
#
# Scraped 115 users this round
# Got 220 reivews
# 409512 reviews are now in the bag, so to speak
# 2024-04-01 13:58:12
#
# Scraped 112 users this round
# Got 170 reivews
# 409682 reviews are now in the bag, so to speak
# 2024-04-01 14:02:10
#
# Scraped 123 users this round
# Got 188 reivews
# 409870 reviews are now in the bag, so to speak
# 2024-04-01 14:06:42
#
# Scraped 111 users this round
# Got 192 reivews
# 410062 reviews are now in the bag, so to speak
# 2024-04-01 14:10:32
#
# Scraped 110 users this round
# Got 209 reivews
# 410271 reviews are now in the bag, so to speak
# 2024-04-01 14:14:24
#
# Scraped 95 users this round
# Got 183 reivews
# 410454 reviews are now in the bag, so to speak
# 2024-04-01 14:17:39
#
# Scraped 111 users this round
# Got 232 reivews
# 410686 reviews are now in the bag, so to speak
# 2024-04-01 14:21:36
#
# Scraped 100 users this round
# Got 163 reivews
# 410849 reviews are now in the bag, so to speak
# 2024-04-01 14:24:57
#
# Scraped 98 users this round
# Got 172 reivews
# 411021 reviews are now in the bag, so to speak
# 2024-04-01 14:28:32
#
# Scraped 124 users this round
# Got 187 reivews
# 411208 reviews are now in the bag, so to speak
# 2024-04-01 14:33:02
#
# Scraped 126 users this round
# Got 194 reivews
# 411402 reviews are now in the bag, so to speak
# 2024-04-01 14:37:34
#
# Scraped 125 users this round
# Got 220 reivews
# 411622 reviews are now in the bag, so to speak
# 2024-04-01 14:41:55
#
# Scraped 109 users this round
# Got 230 reivews
# 411852 reviews are now in the bag, so to speak
# 2024-04-01 14:45:48
#
# Scraped 131 users this round
# Got 156 reivews
# 412008 reviews are now in the bag, so to speak
# 2024-04-01 14:50:26
#
# Scraped 117 users this round
# Got 193 reivews
# 412201 reviews are now in the bag, so to speak
# 2024-04-01 14:54:47
#
# Scraped 109 users this round
# Got 191 reivews
# 412392 reviews are now in the bag, so to speak
# 2024-04-01 14:58:40
#
# Scraped 97 users this round
# Got 172 reivews
# 412564 reviews are now in the bag, so to speak
# 2024-04-01 15:01:56
#
# Scraped 95 users this round
# Got 164 reivews
# 412728 reviews are now in the bag, so to speak
# 2024-04-01 15:05:09
#
# Scraped 109 users this round
# Got 168 reivews
# 412896 reviews are now in the bag, so to speak
# 2024-04-01 15:08:47
#
# Scraped 91 users this round
# Got 152 reivews
# 413048 reviews are now in the bag, so to speak
# 2024-04-01 15:11:58
#
# Scraped 99 users this round
# Got 216 reivews
# 413264 reviews are now in the bag, so to speak
# 2024-04-01 15:15:19
#
# Scraped 106 users this round
# Got 207 reivews
# 413471 reviews are now in the bag, so to speak
# 2024-04-01 15:19:14
#
# Scraped 111 users this round
# Got 216 reivews
# 413687 reviews are now in the bag, so to speak
# 2024-04-01 15:23:11
#
# Scraped 117 users this round
# Got 201 reivews
# 413888 reviews are now in the bag, so to speak
# 2024-04-01 15:27:24
#
# Scraped 130 users this round
# Got 171 reivews
# 414059 reviews are now in the bag, so to speak
# 2024-04-01 15:31:58
#
# Scraped 94 users this round
# Got 182 reivews
# 414241 reviews are now in the bag, so to speak
# 2024-04-01 15:35:13
#
# Scraped 110 users this round
# Got 167 reivews
# 414408 reviews are now in the bag, so to speak
# 2024-04-01 15:38:55
#
# Scraped 122 users this round
# Got 209 reivews
# 414617 reviews are now in the bag, so to speak
# 2024-04-01 15:43:13
#
# Scraped 111 users this round
# Got 201 reivews
# 414818 reviews are now in the bag, so to speak
# 2024-04-01 15:46:58
#
# Scraped 96 users this round
# Got 181 reivews
# 414999 reviews are now in the bag, so to speak
# 2024-04-01 15:50:11
#
# Scraped 105 users this round
# Got 184 reivews
# 415183 reviews are now in the bag, so to speak
# 2024-04-01 15:54:11
#
# Scraped 106 users this round
# Got 241 reivews
# 415424 reviews are now in the bag, so to speak
# 2024-04-01 15:58:00
#
# Scraped 105 users this round
# Got 185 reivews
# 415609 reviews are now in the bag, so to speak
# 2024-04-01 16:01:28
#
# Scraped 117 users this round
# Got 184 reivews
# 415793 reviews are now in the bag, so to speak
# 2024-04-01 16:05:37
#
# Scraped 102 users this round
# Got 173 reivews
# 415966 reviews are now in the bag, so to speak
# 2024-04-01 16:09:10
#
# Scraped 95 users this round
# Got 184 reivews
# 416150 reviews are now in the bag, so to speak
# 2024-04-01 16:12:40
#
# Scraped 93 users this round
# Got 170 reivews
# 416320 reviews are now in the bag, so to speak
# 2024-04-01 16:15:45
#
# Scraped 85 users this round
# Got 146 reivews
# 416466 reviews are now in the bag, so to speak
# 2024-04-01 16:18:41
#
# Scraped 104 users this round
# Got 191 reivews
# 416657 reviews are now in the bag, so to speak
# 2024-04-01 16:22:21
#
# Scraped 115 users this round
# Got 177 reivews
# 416834 reviews are now in the bag, so to speak
# 2024-04-01 16:26:24
#
# Scraped 96 users this round
# Got 183 reivews
# 417017 reviews are now in the bag, so to speak
# 2024-04-01 16:29:49
#
# Scraped 105 users this round
# Got 184 reivews
# 417201 reviews are now in the bag, so to speak
# 2024-04-01 16:33:30
#
# Scraped 126 users this round
# Got 153 reivews
# 417354 reviews are now in the bag, so to speak
# 2024-04-01 16:37:47
#
# Scraped 98 users this round
# Got 187 reivews
# 417541 reviews are now in the bag, so to speak
# 2024-04-01 16:41:03
#
# Scraped 120 users this round
# Got 169 reivews
# 417710 reviews are now in the bag, so to speak
# 2024-04-01 16:45:28
#
# Unable to parse review blocks.
# Unable to parse review blocks.
# Scraped 122 users this round
# Got 182 reivews
# 417892 reviews are now in the bag, so to speak
# 2024-04-01 16:50:15
#
# Scraped 105 users this round
# Got 195 reivews
# 418087 reviews are now in the bag, so to speak
# 2024-04-01 16:53:50
#
# Scraped 113 users this round
# Got 231 reivews
# 418318 reviews are now in the bag, so to speak
# 2024-04-01 16:57:59
#
# Scraped 103 users this round
# Got 156 reivews
# 418474 reviews are now in the bag, so to speak
# 2024-04-01 17:01:44
#
# Scraped 98 users this round
# Got 173 reivews
# 418647 reviews are now in the bag, so to speak
# 2024-04-01 17:05:02
#
# Scraped 107 users this round
# Got 203 reivews
# 418850 reviews are now in the bag, so to speak
# 2024-04-01 17:08:53
#
# Scraped 94 users this round
# Got 204 reivews
# 419054 reviews are now in the bag, so to speak
# 2024-04-01 17:11:57
#
# Scraped 107 users this round
# Got 118 reivews
# 419172 reviews are now in the bag, so to speak
# 2024-04-01 17:15:39
#
# Scraped 121 users this round
# Got 160 reivews
# 419332 reviews are now in the bag, so to speak
# 2024-04-01 17:19:52
#
# Scraped 112 users this round
# Got 184 reivews
# 419516 reviews are now in the bag, so to speak
# 2024-04-01 17:24:16
#
# Scraped 111 users this round
# Got 198 reivews
# 419714 reviews are now in the bag, so to speak
# 2024-04-01 17:28:29
#
# Scraped 130 users this round
# Got 179 reivews
# 419893 reviews are now in the bag, so to speak
# 2024-04-01 17:33:14
#
# Scraped 100 users this round
# Got 186 reivews
# 420079 reviews are now in the bag, so to speak
# 2024-04-01 17:36:41
#
# Scraped 104 users this round
# Got 164 reivews
# 420243 reviews are now in the bag, so to speak
# 2024-04-01 17:40:25
#
# Scraped 98 users this round
# Got 184 reivews
# 420427 reviews are now in the bag, so to speak
# 2024-04-01 17:43:37
#
# Scraped 98 users this round
# Got 201 reivews
# 420628 reviews are now in the bag, so to speak
# 2024-04-01 17:47:09
#
# Scraped 113 users this round
# Got 187 reivews
# 420815 reviews are now in the bag, so to speak
# 2024-04-01 17:51:00
#
# Scraped 95 users this round
# Got 169 reivews
# 420984 reviews are now in the bag, so to speak
# 2024-04-01 17:54:07
#
# Scraped 122 users this round
# Got 167 reivews
# 421151 reviews are now in the bag, so to speak
# 2024-04-01 17:58:25
#
# Scraped 103 users this round
# Got 216 reivews
# 421367 reviews are now in the bag, so to speak
# 2024-04-01 18:01:54
#
# Scraped 104 users this round
# Got 184 reivews
# 421551 reviews are now in the bag, so to speak
# 2024-04-01 18:05:29
#
# Scraped 117 users this round
# Got 189 reivews
# 421740 reviews are now in the bag, so to speak
# 2024-04-01 18:09:38
#
# Scraped 103 users this round
# Got 203 reivews
# 421943 reviews are now in the bag, so to speak
# 2024-04-01 18:13:14
#
# Scraped 111 users this round
# Got 210 reivews
# 422153 reviews are now in the bag, so to speak
# 2024-04-01 18:17:09
#
# Scraped 111 users this round
# Got 214 reivews
# 422367 reviews are now in the bag, so to speak
# 2024-04-01 18:21:06
#
# Scraped 103 users this round
# Got 166 reivews
# 422533 reviews are now in the bag, so to speak
# 2024-04-01 18:24:39
#
# Scraped 124 users this round
# Got 178 reivews
# 422711 reviews are now in the bag, so to speak
# 2024-04-01 18:29:12
#
# Scraped 95 users this round
# Got 218 reivews
# 422929 reviews are now in the bag, so to speak
# 2024-04-01 18:32:27
#
# Scraped 81 users this round
# Got 183 reivews
# 423112 reviews are now in the bag, so to speak
# 2024-04-01 18:35:08
#
# Scraped 125 users this round
# Got 226 reivews
# 423338 reviews are now in the bag, so to speak
# 2024-04-01 18:39:42
#
# Scraped 110 users this round
# Got 166 reivews
# 423504 reviews are now in the bag, so to speak
# 2024-04-01 18:43:29
#
# Scraped 96 users this round
# Got 185 reivews
# 423689 reviews are now in the bag, so to speak
# 2024-04-01 18:46:46
#
# Scraped 109 users this round
# Got 161 reivews
# 423850 reviews are now in the bag, so to speak
# 2024-04-01 18:50:32
#
# Scraped 87 users this round
# Got 154 reivews
# 424004 reviews are now in the bag, so to speak
# 2024-04-01 18:53:25
#
# Scraped 101 users this round
# Got 147 reivews
# 424151 reviews are now in the bag, so to speak
# 2024-04-01 18:56:56
#
# Scraped 114 users this round
# Got 190 reivews
# 424341 reviews are now in the bag, so to speak
# 2024-04-01 19:00:56
#
# Scraped 102 users this round
# Got 189 reivews
# 424530 reviews are now in the bag, so to speak
# 2024-04-01 19:04:34
#
# Scraped 115 users this round
# Got 224 reivews
# 424754 reviews are now in the bag, so to speak
# 2024-04-01 19:08:53
#
# Scraped 96 users this round
# Got 180 reivews
# 424934 reviews are now in the bag, so to speak
# 2024-04-01 19:12:00
#
# Scraped 117 users this round
# Got 171 reivews
# 425105 reviews are now in the bag, so to speak
# 2024-04-01 19:16:11
#
# Scraped 116 users this round
# Got 221 reivews
# 425326 reviews are now in the bag, so to speak
# 2024-04-01 19:20:19
#
# Scraped 122 users this round
# Got 220 reivews
# 425546 reviews are now in the bag, so to speak
# 2024-04-01 19:24:54
#
# Scraped 125 users this round
# Got 201 reivews
# 425747 reviews are now in the bag, so to speak
# 2024-04-01 19:29:33
#
# Scraped 100 users this round
# Got 170 reivews
# 425917 reviews are now in the bag, so to speak
# 2024-04-01 19:32:57
#
# Scraped 119 users this round
# Got 201 reivews
# 426118 reviews are now in the bag, so to speak
# 2024-04-01 19:37:07
#
# Scraped 123 users this round
# Got 189 reivews
# 426307 reviews are now in the bag, so to speak
# 2024-04-01 19:41:28
#
# Scraped 96 users this round
# Got 184 reivews
# 426491 reviews are now in the bag, so to speak
# 2024-04-01 19:44:55
#
# Scraped 109 users this round
# Got 203 reivews
# 426694 reviews are now in the bag, so to speak
# 2024-04-01 19:48:42
#
# Scraped 122 users this round
# Got 184 reivews
# 426878 reviews are now in the bag, so to speak
# 2024-04-01 19:52:56
#
# Scraped 114 users this round
# Got 208 reivews
# 427086 reviews are now in the bag, so to speak
# 2024-04-01 19:57:08
#
# Scraped 104 users this round
# Got 196 reivews
# 427282 reviews are now in the bag, so to speak
# 2024-04-01 20:00:49
#
# Scraped 114 users this round
# Got 200 reivews
# 427482 reviews are now in the bag, so to speak
# 2024-04-01 20:05:21
#
# Scraped 100 users this round
# Got 197 reivews
# 427679 reviews are now in the bag, so to speak
# 2024-04-01 20:09:56
#
# Scraped 99 users this round
# Got 205 reivews
# 427884 reviews are now in the bag, so to speak
# 2024-04-01 20:16:32
#
# Scraped 112 users this round
# Got 194 reivews
# 428078 reviews are now in the bag, so to speak
# 2024-04-01 20:24:20
#
# Scraped 111 users this round
# Got 174 reivews
# 428252 reviews are now in the bag, so to speak
# 2024-04-01 20:31:39
#
# Scraped 120 users this round
# Got 175 reivews
# 428427 reviews are now in the bag, so to speak
# 2024-04-01 20:38:38
#
# Scraped 112 users this round
# Got 183 reivews
# 428610 reviews are now in the bag, so to speak
# 2024-04-01 20:44:54
#
# Scraped 132 users this round
# Got 147 reivews
# 428757 reviews are now in the bag, so to speak
# 2024-04-01 20:52:12
#
# Scraped 110 users this round
# Got 162 reivews
# 428919 reviews are now in the bag, so to speak
# 2024-04-01 20:59:29
#
# Scraped 102 users this round
# Got 200 reivews
# 429119 reviews are now in the bag, so to speak
# 2024-04-01 21:05:34
#
# Scraped 103 users this round
# Got 205 reivews
# 429324 reviews are now in the bag, so to speak
# 2024-04-01 21:11:25
#
# Scraped 116 users this round
# Got 180 reivews
# 429504 reviews are now in the bag, so to speak
# 2024-04-01 21:18:50
#
# Scraped 109 users this round
# Got 227 reivews
# 429731 reviews are now in the bag, so to speak
# 2024-04-01 21:25:12
#
# Scraped 100 users this round
# Got 209 reivews
# 429940 reviews are now in the bag, so to speak
# 2024-04-01 21:31:19
#
# Scraped 122 users this round
# Got 168 reivews
# 430108 reviews are now in the bag, so to speak
# 2024-04-01 21:38:34
#
# Scraped 112 users this round
# Got 196 reivews
# 430304 reviews are now in the bag, so to speak
# 2024-04-01 21:45:11
#
# Scraped 112 users this round
# Got 189 reivews
# 430493 reviews are now in the bag, so to speak
# 2024-04-01 21:51:27
#
# Scraped 120 users this round
# Got 134 reivews
# 430627 reviews are now in the bag, so to speak
# 2024-04-01 21:58:38
#
# Scraped 103 users this round
# Got 164 reivews
# 430791 reviews are now in the bag, so to speak
# 2024-04-01 22:05:53
#
# Scraped 105 users this round
# Got 166 reivews
# 430957 reviews are now in the bag, so to speak
# 2024-04-01 22:12:19
#
# Scraped 95 users this round
# Got 194 reivews
# 431151 reviews are now in the bag, so to speak
# 2024-04-01 22:17:39
#
# Scraped 101 users this round
# Got 171 reivews
# 431322 reviews are now in the bag, so to speak
# 2024-04-01 22:23:20
#
# Scraped 106 users this round
# Got 190 reivews
# 431512 reviews are now in the bag, so to speak
# 2024-04-01 22:30:00
#
# Scraped 117 users this round
# Got 208 reivews
# 431720 reviews are now in the bag, so to speak
# 2024-04-01 22:36:39
#
# Scraped 107 users this round
# Got 178 reivews
# 431898 reviews are now in the bag, so to speak
# 2024-04-01 22:42:45
#
# Scraped 125 users this round
# Got 178 reivews
# 432076 reviews are now in the bag, so to speak
# 2024-04-01 22:49:09
#
# Scraped 99 users this round
# Got 185 reivews
# 432261 reviews are now in the bag, so to speak
# 2024-04-01 22:54:17
#
# Scraped 97 users this round
# Got 186 reivews
# 432447 reviews are now in the bag, so to speak
# 2024-04-01 22:59:07
#
# Scraped 108 users this round
# Got 189 reivews
# 432636 reviews are now in the bag, so to speak
# 2024-04-01 23:04:47
#
# Scraped 113 users this round
# Got 213 reivews
# 432849 reviews are now in the bag, so to speak
# 2024-04-01 23:10:29
#
# Scraped 113 users this round
# Got 198 reivews
# 433047 reviews are now in the bag, so to speak
# 2024-04-01 23:14:52
#
# Scraped 96 users this round
# Got 203 reivews
# 433250 reviews are now in the bag, so to speak
# 2024-04-01 23:18:20
#
# Scraped 117 users this round
# Got 184 reivews
# 433434 reviews are now in the bag, so to speak
# 2024-04-01 23:22:33
#
# Scraped 106 users this round
# Got 203 reivews
# 433637 reviews are now in the bag, so to speak
# 2024-04-01 23:26:20
#
# Scraped 96 users this round
# Got 176 reivews
# 433813 reviews are now in the bag, so to speak
# 2024-04-01 23:29:44
#
# Scraped 117 users this round
# Got 213 reivews
# 434026 reviews are now in the bag, so to speak
# 2024-04-01 23:33:58
#
# Scraped 111 users this round
# Got 164 reivews
# 434190 reviews are now in the bag, so to speak
# 2024-04-01 23:37:54
#
# Scraped 116 users this round
# Got 175 reivews
# 434365 reviews are now in the bag, so to speak
# 2024-04-01 23:42:03
#
# Scraped 104 users this round
# Got 204 reivews
# 434569 reviews are now in the bag, so to speak
# 2024-04-01 23:45:53
#
# Scraped 120 users this round
# Got 206 reivews
# 434775 reviews are now in the bag, so to speak
# 2024-04-01 23:50:36
#
# Scraped 106 users this round
# Got 184 reivews
# 434959 reviews are now in the bag, so to speak
# 2024-04-01 23:54:27
#
# Scraped 100 users this round
# Got 200 reivews
# 435159 reviews are now in the bag, so to speak
# 2024-04-01 23:57:55
#
# Scraped 112 users this round
# Got 187 reivews
# 435346 reviews are now in the bag, so to speak
# 2024-04-02 00:01:54
#
# Scraped 107 users this round
# Got 185 reivews
# 435531 reviews are now in the bag, so to speak
# 2024-04-02 00:05:42
#
# Scraped 111 users this round
# Got 175 reivews
# 435706 reviews are now in the bag, so to speak
# 2024-04-02 00:09:51
#
# Scraped 114 users this round
# Got 217 reivews
# 435923 reviews are now in the bag, so to speak
# 2024-04-02 00:14:12
#
# Scraped 116 users this round
# Got 218 reivews
# 436141 reviews are now in the bag, so to speak
# 2024-04-02 00:18:28
#
# Scraped 103 users this round
# Got 199 reivews
# 436340 reviews are now in the bag, so to speak
# 2024-04-02 00:22:04
#
# Scraped 141 users this round
# Got 206 reivews
# 436546 reviews are now in the bag, so to speak
# 2024-04-02 00:27:14
#
# Scraped 100 users this round
# Got 162 reivews
# 436708 reviews are now in the bag, so to speak
# 2024-04-02 00:30:37
#
# Scraped 100 users this round
# Got 202 reivews
# 436910 reviews are now in the bag, so to speak
# 2024-04-02 00:34:11
#
# Scraped 107 users this round
# Got 182 reivews
# 437092 reviews are now in the bag, so to speak
# 2024-04-02 00:37:53
#
# Scraped 96 users this round
# Got 186 reivews
# 437278 reviews are now in the bag, so to speak
# 2024-04-02 00:41:04
#
# Scraped 120 users this round
# Got 175 reivews
# 437453 reviews are now in the bag, so to speak
# 2024-04-02 00:45:26
#
# Scraped 111 users this round
# Got 216 reivews
# 437669 reviews are now in the bag, so to speak
# 2024-04-02 00:49:29
#
# Scraped 113 users this round
# Got 190 reivews
# 437859 reviews are now in the bag, so to speak
# 2024-04-02 00:53:22
#
# Scraped 99 users this round
# Got 152 reivews
# 438011 reviews are now in the bag, so to speak
# 2024-04-02 00:56:51
#
# Scraped 110 users this round
# Got 182 reivews
# 438193 reviews are now in the bag, so to speak
# 2024-04-02 01:00:48
#
# Scraped 108 users this round
# Got 177 reivews
# 438370 reviews are now in the bag, so to speak
# 2024-04-02 01:04:49
#
# Scraped 111 users this round
# Got 179 reivews
# 438549 reviews are now in the bag, so to speak
# 2024-04-02 01:08:48
#
# Scraped 110 users this round
# Got 189 reivews
# 438738 reviews are now in the bag, so to speak
# 2024-04-02 01:12:49
#
# Scraped 108 users this round
# Got 212 reivews
# ...
# 500986 reviews are now in the bag, so to speak
# 2024-04-02 23:26:28
#
# Scraped 99 users this round
# Got 170 reivews
# 501156 reviews are now in the bag, so to speak
# 2024-04-02 23:33:12
#
# Scraped 120 users this round
# Got 165 reivews
# 501321 reviews are now in the bag, so to speak
# 2024-04-02 23:40:45
#
# Scraped 144 users this round
# Got 170 reivews
# 501491 reviews are now in the bag, so to speak
# 2024-04-02 23:46:00
#
# Scraped 121 users this round
# Got 163 reivews
# 501654 reviews are now in the bag, so to speak
# 2024-04-02 23:50:21
#
# Scraped 118 users this round
# Got 178 reivews
# 501832 reviews are now in the bag, so to speak
# 2024-04-02 23:54:41
#
# Scraped 120 users this round
# Got 189 reivews
# 502021 reviews are now in the bag, so to speak
# 2024-04-02 23:58:55
#
# Scraped 96 users this round
# Got 197 reivews
# 502218 reviews are now in the bag, so to speak
# 2024-04-03 00:02:18
#
# Scraped 125 users this round
# Got 179 reivews
# 502397 reviews are now in the bag, so to speak
# 2024-04-03 00:06:38
#
# Scraped 112 users this round
# Got 217 reivews
# 502614 reviews are now in the bag, so to speak
# 2024-04-03 00:10:34
#
# Scraped 110 users this round
# Got 193 reivews
# 502807 reviews are now in the bag, so to speak
# 2024-04-03 00:14:37
#
# Scraped 117 users this round
# Got 187 reivews
# 502994 reviews are now in the bag, so to speak
# 2024-04-03 00:18:47
#
# Scraped 92 users this round
# Got 193 reivews
# 503187 reviews are now in the bag, so to speak
# 2024-04-03 00:21:42
#
# Scraped 132 users this round
# Got 216 reivews
# 503403 reviews are now in the bag, so to speak
# 2024-04-03 00:26:30
#
# Scraped 113 users this round
# Got 225 reivews
# 503628 reviews are now in the bag, so to speak
# 2024-04-03 00:30:30
#
# Scraped 113 users this round
# Got 185 reivews
# 503813 reviews are now in the bag, so to speak
# 2024-04-03 00:34:24
#
# Scraped 105 users this round
# Got 228 reivews
# 504041 reviews are now in the bag, so to speak
# 2024-04-03 00:38:01
#
# Scraped 109 users this round
# Got 208 reivews
# 504249 reviews are now in the bag, so to speak
# 2024-04-03 00:41:44
#
# Scraped 117 users this round
# Got 176 reivews
# 504425 reviews are now in the bag, so to speak
# 2024-04-03 00:45:41
#
# Scraped 107 users this round
# Got 200 reivews
# 504625 reviews are now in the bag, so to speak
# 2024-04-03 00:49:24
#
# Scraped 108 users this round
# Got 177 reivews
# 504802 reviews are now in the bag, so to speak
# 2024-04-03 00:53:05
#
# Scraped 103 users this round
# Got 168 reivews
# 504970 reviews are now in the bag, so to speak
# 2024-04-03 00:56:46
#
# Scraped 111 users this round
# Got 189 reivews
# 505159 reviews are now in the bag, so to speak
# 2024-04-03 01:00:44
#
# Scraped 111 users this round
# Got 184 reivews
# 505343 reviews are now in the bag, so to speak
# 2024-04-03 01:04:28
#
# Scraped 103 users this round
# Got 187 reivews
# 505530 reviews are now in the bag, so to speak
# 2024-04-03 01:08:05
#
# Scraped 89 users this round
# Got 196 reivews
# 505726 reviews are now in the bag, so to speak
# 2024-04-03 01:10:59
#
# Scraped 139 users this round
# Got 164 reivews
# 505890 reviews are now in the bag, so to speak
# 2024-04-03 01:15:55
#
# Scraped 128 users this round
# Got 223 reivews
# 506113 reviews are now in the bag, so to speak
# 2024-04-03 01:20:28
#
# Scraped 129 users this round
# Got 221 reivews
# 506334 reviews are now in the bag, so to speak
# 2024-04-03 01:24:49
#
# Scraped 97 users this round
# Got 202 reivews
# 506536 reviews are now in the bag, so to speak
# 2024-04-03 01:27:59
#
# Scraped 111 users this round
# Got 175 reivews
# 506711 reviews are now in the bag, so to speak
# 2024-04-03 01:31:39
#
# Scraped 107 users this round
# Got 145 reivews
# 506856 reviews are now in the bag, so to speak
# 2024-04-03 01:35:07
#
# Scraped 107 users this round
# Got 156 reivews
# 507012 reviews are now in the bag, so to speak
# 2024-04-03 01:38:32
#
# Scraped 129 users this round
# Got 167 reivews
# 507179 reviews are now in the bag, so to speak
# 2024-04-03 01:42:50
#
# Scraped 110 users this round
# Got 184 reivews
# 507363 reviews are now in the bag, so to speak
# 2024-04-03 01:46:26
#
# Scraped 133 users this round
# Got 143 reivews
# 507506 reviews are now in the bag, so to speak
# 2024-04-03 01:50:54
#
# Scraped 104 users this round
# Got 175 reivews
# 507681 reviews are now in the bag, so to speak
# 2024-04-03 01:54:25
#
# Scraped 109 users this round
# Got 183 reivews
# 507864 reviews are now in the bag, so to speak
# 2024-04-03 01:57:57
#
# Scraped 118 users this round
# Got 211 reivews
# 508075 reviews are now in the bag, so to speak
# 2024-04-03 02:01:45
#
# Scraped 129 users this round
# Got 171 reivews
# 508246 reviews are now in the bag, so to speak
# 2024-04-03 02:06:17
#
# Scraped 103 users this round
# Got 157 reivews
# 508403 reviews are now in the bag, so to speak
# 2024-04-03 02:09:29
#
# Scraped 87 users this round
# Got 121 reivews
# 508524 reviews are now in the bag, so to speak
# 2024-04-03 02:12:15
#
# Scraped 107 users this round
# Got 198 reivews
# 508722 reviews are now in the bag, so to speak
# 2024-04-03 02:15:55
#
# Scraped 123 users this round
# Got 227 reivews
# 508949 reviews are now in the bag, so to speak
# 2024-04-03 02:20:13
#
# Scraped 95 users this round
# Got 168 reivews
# 509117 reviews are now in the bag, so to speak
# 2024-04-03 02:23:11
#
# Scraped 119 users this round
# Got 180 reivews
# 509297 reviews are now in the bag, so to speak
# 2024-04-03 02:27:14
#
# Scraped 113 users this round
# Got 145 reivews
# 509442 reviews are now in the bag, so to speak
# 2024-04-03 02:30:57
#
# Scraped 99 users this round
# Got 149 reivews
# 509591 reviews are now in the bag, so to speak
# 2024-04-03 02:34:23
#
# Scraped 105 users this round
# Got 157 reivews
# 509748 reviews are now in the bag, so to speak
# 2024-04-03 02:37:48
#
# Scraped 104 users this round
# Got 199 reivews
# 509947 reviews are now in the bag, so to speak
# 2024-04-03 02:41:15
#
# Scraped 108 users this round
# Got 191 reivews
# 510138 reviews are now in the bag, so to speak
# 2024-04-03 02:44:36
#
# Scraped 110 users this round
# Got 192 reivews
# 510330 reviews are now in the bag, so to speak
# 2024-04-03 02:48:36
#
# Scraped 113 users this round
# Got 177 reivews
# 510507 reviews are now in the bag, so to speak
# 2024-04-03 02:52:23
#
# Scraped 91 users this round
# Got 199 reivews
# 510706 reviews are now in the bag, so to speak
# 2024-04-03 02:55:16
#
# Scraped 96 users this round
# Got 189 reivews
# 510895 reviews are now in the bag, so to speak
# 2024-04-03 02:58:24
#
# Scraped 118 users this round
# Got 190 reivews
# 511085 reviews are now in the bag, so to speak
# 2024-04-03 03:02:38
#
# Scraped 110 users this round
# Got 207 reivews
# 511292 reviews are now in the bag, so to speak
# 2024-04-03 03:06:12
#
# Scraped 112 users this round
# Got 213 reivews
# 511505 reviews are now in the bag, so to speak
# 2024-04-03 03:09:55
#
# Scraped 91 users this round
# Got 171 reivews
# 511676 reviews are now in the bag, so to speak
# 2024-04-03 03:12:55
#
# Scraped 113 users this round
# Got 226 reivews
# 511902 reviews are now in the bag, so to speak
# 2024-04-03 03:16:41
#
# Scraped 103 users this round
# Got 191 reivews
# 512093 reviews are now in the bag, so to speak
# 2024-04-03 03:19:57
#
# Scraped 122 users this round
# Got 193 reivews
# 512286 reviews are now in the bag, so to speak
# 2024-04-03 03:24:16
#
# Scraped 105 users this round
# Got 171 reivews
# 512457 reviews are now in the bag, so to speak
# 2024-04-03 03:28:08
#
# Scraped 118 users this round
# Got 240 reivews
# 512697 reviews are now in the bag, so to speak
# 2024-04-03 03:32:07
#
# Scraped 87 users this round
# Got 182 reivews
# 512879 reviews are now in the bag, so to speak
# 2024-04-03 03:34:48
#
# Scraped 114 users this round
# Got 190 reivews
# 513069 reviews are now in the bag, so to speak
# 2024-04-03 03:38:25
#
# Scraped 110 users this round
# Got 183 reivews
# 513252 reviews are now in the bag, so to speak
# 2024-04-03 03:42:14
#
# Scraped 111 users this round
# Got 126 reivews
# 513378 reviews are now in the bag, so to speak
# 2024-04-03 03:45:50
#
# Scraped 104 users this round
# Got 160 reivews
# 513538 reviews are now in the bag, so to speak
# 2024-04-03 03:48:55
#
# Scraped 93 users this round
# Got 197 reivews
# 513735 reviews are now in the bag, so to speak
# 2024-04-03 03:51:55
#
# Scraped 98 users this round
# Got 177 reivews
# 513912 reviews are now in the bag, so to speak
# 2024-04-03 03:55:07
#
# Scraped 105 users this round
# Got 207 reivews
# 514119 reviews are now in the bag, so to speak
# 2024-04-03 03:58:25
#
# Scraped 110 users this round
# Got 180 reivews
# 514299 reviews are now in the bag, so to speak
# 2024-04-03 04:01:58
#
# Scraped 113 users this round
# Got 193 reivews
# 514492 reviews are now in the bag, so to speak
# 2024-04-03 04:05:49
#
# Scraped 106 users this round
# Got 201 reivews
# 514693 reviews are now in the bag, so to speak
# 2024-04-03 04:09:16
#
# Scraped 118 users this round
# Got 183 reivews
# 514876 reviews are now in the bag, so to speak
# 2024-04-03 04:13:06
#
# Scraped 92 users this round
# Got 201 reivews
# 515077 reviews are now in the bag, so to speak
# 2024-04-03 04:16:07
#
# Scraped 99 users this round
# Got 180 reivews
# 515257 reviews are now in the bag, so to speak
# 2024-04-03 04:19:34
#
# Scraped 117 users this round
# Got 255 reivews
# 515512 reviews are now in the bag, so to speak
# 2024-04-03 04:24:20
#
# Scraped 117 users this round
# Got 188 reivews
# 515700 reviews are now in the bag, so to speak
# 2024-04-03 04:28:26
#
# Scraped 129 users this round
# Got 186 reivews
# 515886 reviews are now in the bag, so to speak
# 2024-04-03 04:32:34
#
# Scraped 91 users this round
# Got 194 reivews
# 516080 reviews are now in the bag, so to speak
# 2024-04-03 04:35:29
#
# Scraped 97 users this round
# Got 191 reivews
# 516271 reviews are now in the bag, so to speak
# 2024-04-03 04:38:45
#
# Scraped 101 users this round
# Got 207 reivews
# 516478 reviews are now in the bag, so to speak
# 2024-04-03 04:42:21
#
# Scraped 92 users this round
# Got 224 reivews
# 516702 reviews are now in the bag, so to speak
# 2024-04-03 04:45:18
#
# Scraped 128 users this round
# Got 233 reivews
# 516935 reviews are now in the bag, so to speak
# 2024-04-03 04:49:37
#
# Scraped 114 users this round
# Got 214 reivews
# 517149 reviews are now in the bag, so to speak
# 2024-04-03 04:53:20
#
# Scraped 131 users this round
# Got 167 reivews
# 517316 reviews are now in the bag, so to speak
# 2024-04-03 04:57:45
#
# Scraped 80 users this round
# Got 143 reivews
# 517459 reviews are now in the bag, so to speak
# 2024-04-03 05:00:19
#
# Scraped 120 users this round
# Got 168 reivews
# 517627 reviews are now in the bag, so to speak
# 2024-04-03 05:04:18
#
# Scraped 116 users this round
# Got 219 reivews
# 517846 reviews are now in the bag, so to speak
# 2024-04-03 05:08:15
#
# Scraped 120 users this round
# Got 221 reivews
# 518067 reviews are now in the bag, so to speak
# 2024-04-03 05:12:34
#
# Scraped 107 users this round
# Got 207 reivews
# 518274 reviews are now in the bag, so to speak
# 2024-04-03 05:16:09
#
# Scraped 120 users this round
# Got 176 reivews
# 518450 reviews are now in the bag, so to speak
# 2024-04-03 05:20:07
#
# Scraped 93 users this round
# Got 153 reivews
# 518603 reviews are now in the bag, so to speak
# 2024-04-03 05:23:16
#
# Scraped 105 users this round
# Got 221 reivews
# 518824 reviews are now in the bag, so to speak
# 2024-04-03 05:26:46
#
# Scraped 93 users this round
# Got 175 reivews
# 518999 reviews are now in the bag, so to speak
# 2024-04-03 05:29:45
#
# Scraped 99 users this round
# Got 188 reivews
# 519187 reviews are now in the bag, so to speak
# 2024-04-03 05:32:54
#
# Scraped 131 users this round
# Got 188 reivews
# 519375 reviews are now in the bag, so to speak
# 2024-04-03 05:37:35
#
# Scraped 114 users this round
# Got 156 reivews
# 519531 reviews are now in the bag, so to speak
# 2024-04-03 05:41:19
#
# Scraped 106 users this round
# Got 159 reivews
# 519690 reviews are now in the bag, so to speak
# 2024-04-03 05:44:41
#
# Scraped 113 users this round
# Got 150 reivews
# 519840 reviews are now in the bag, so to speak
# 2024-04-03 05:48:22
#
# Scraped 88 users this round
# Got 196 reivews
# 520036 reviews are now in the bag, so to speak
# 2024-04-03 05:51:13
#
# Scraped 106 users this round
# Got 197 reivews
# 520233 reviews are now in the bag, so to speak
# 2024-04-03 05:54:42
#
# Scraped 122 users this round
# Got 183 reivews
# 520416 reviews are now in the bag, so to speak
# 2024-04-03 05:58:47
#
# Scraped 97 users this round
# Got 155 reivews
# 520571 reviews are now in the bag, so to speak
# 2024-04-03 06:02:25
#
# Scraped 123 users this round
# Got 188 reivews
# 520759 reviews are now in the bag, so to speak
# 2024-04-03 06:06:26
#
# Scraped 114 users this round
# Got 170 reivews
# 520929 reviews are now in the bag, so to speak
# 2024-04-03 06:10:19
#
# Scraped 121 users this round
# Got 208 reivews
# 521137 reviews are now in the bag, so to speak
# 2024-04-03 06:14:25
#
# Scraped 104 users this round
# Got 186 reivews
# 521323 reviews are now in the bag, so to speak
# 2024-04-03 06:18:36
#
# Scraped 98 users this round
# Got 174 reivews
# 521497 reviews are now in the bag, so to speak
# 2024-04-03 06:21:56
#
# Scraped 126 users this round
# Got 217 reivews
# 521714 reviews are now in the bag, so to speak
# 2024-04-03 06:26:12
#
# Scraped 96 users this round
# Got 175 reivews
# 521889 reviews are now in the bag, so to speak
# 2024-04-03 06:29:21
#
# Scraped 94 users this round
# Got 187 reivews
# 522076 reviews are now in the bag, so to speak
# 2024-04-03 06:32:56
#
# Scraped 107 users this round
# Got 151 reivews
# 522227 reviews are now in the bag, so to speak
# 2024-04-03 06:36:40
#
# Scraped 119 users this round
# Got 183 reivews
# 522410 reviews are now in the bag, so to speak
# 2024-04-03 06:40:57
#
# Scraped 115 users this round
# Got 229 reivews
# 522639 reviews are now in the bag, so to speak
# 2024-04-03 06:44:45
#
# Scraped 115 users this round
# Got 206 reivews
# 522845 reviews are now in the bag, so to speak
# 2024-04-03 06:48:36
#
# Scraped 98 users this round
# Got 183 reivews
# 523028 reviews are now in the bag, so to speak
# 2024-04-03 06:51:45
#
# Scraped 109 users this round
# Got 164 reivews
# 523192 reviews are now in the bag, so to speak
# 2024-04-03 06:55:17
#
# Scraped 103 users this round
# Got 192 reivews
# 523384 reviews are now in the bag, so to speak
# 2024-04-03 06:58:36
#
# Scraped 94 users this round
# Got 158 reivews
# 523542 reviews are now in the bag, so to speak
# 2024-04-03 07:01:47
#
# Scraped 107 users this round
# Got 196 reivews
# 523738 reviews are now in the bag, so to speak
# 2024-04-03 07:05:23
#
# Scraped 90 users this round
# Got 193 reivews
# 523931 reviews are now in the bag, so to speak
# 2024-04-03 07:08:22
#
# Scraped 118 users this round
# Got 210 reivews
# 524141 reviews are now in the bag, so to speak
# 2024-04-03 07:12:32
#
# Scraped 97 users this round
# Got 190 reivews
# 524331 reviews are now in the bag, so to speak
# 2024-04-03 07:15:38
#
# Scraped 113 users this round
# Got 191 reivews
# 524522 reviews are now in the bag, so to speak
# 2024-04-03 07:19:18
#
# Scraped 114 users this round
# Got 171 reivews
# 524693 reviews are now in the bag, so to speak
# 2024-04-03 07:23:37
#
# Scraped 112 users this round
# Got 198 reivews
# 524891 reviews are now in the bag, so to speak
# 2024-04-03 07:27:34
#
# Scraped 111 users this round
# Got 197 reivews
# 525088 reviews are now in the bag, so to speak
# 2024-04-03 07:32:12
#
# Scraped 114 users this round
# Got 168 reivews
# 525256 reviews are now in the bag, so to speak
# 2024-04-03 07:36:15
#
# Scraped 98 users this round
# Got 184 reivews
# 525440 reviews are now in the bag, so to speak
# 2024-04-03 07:39:35
#
# Scraped 113 users this round
# Got 213 reivews
# 525653 reviews are now in the bag, so to speak
# 2024-04-03 07:43:25
#
# Scraped 114 users this round
# Got 202 reivews
# 525855 reviews are now in the bag, so to speak
# 2024-04-03 07:47:30
#
# Scraped 106 users this round
# Got 180 reivews
# 526035 reviews are now in the bag, so to speak
# 2024-04-03 07:51:13
#
# Scraped 107 users this round
# Got 168 reivews
# 526203 reviews are now in the bag, so to speak
# 2024-04-03 07:54:49
#
# Scraped 107 users this round
# Got 170 reivews
# 526373 reviews are now in the bag, so to speak
# 2024-04-03 07:58:34
#
# Scraped 89 users this round
# Got 151 reivews
# 526524 reviews are now in the bag, so to speak
# 2024-04-03 08:01:55
#
# Scraped 109 users this round
# Got 189 reivews
# 526713 reviews are now in the bag, so to speak
# 2024-04-03 08:05:38
#
# Scraped 133 users this round
# Got 195 reivews
# 526908 reviews are now in the bag, so to speak
# 2024-04-03 08:10:39
#
# Scraped 101 users this round
# Got 205 reivews
# 527113 reviews are now in the bag, so to speak
# 2024-04-03 08:14:34
#
# Scraped 130 users this round
# Got 221 reivews
# 527334 reviews are now in the bag, so to speak
# 2024-04-03 08:20:40
#
# Unable to parse review blocks.
