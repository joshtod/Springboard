# %% [markdown]
# Steam Scraper Wrapper
# ---
# This notebook calls the scraper notebook again and again until a certain target number of records is stored on disk.
#
# We need over 20,000 records for our analysis.
#
# As each record requires quite a few URL calls with manual delays in between, this scraping is quite slow. The only way to finish this in our lifetime is to run the notebook at all times.
#
# The scraper notebook itself is vulnerable to network errors that are out of our control, and this blasted Windows machine just decides to restart itself from time to time (known issue, no fix; "feature not a bug", etc). Because of this, we can't just tell the scraper to scrape a bunch of games and then go on about our business.
#
# This notebook aims to provide the desired set-it-and-forget-it functionality by calling the scraper notebook in a 'while' loop with a try/except block that logs process & errors, then builds in a delay after a failed scraping attempt. The loop is written to try f_o_r_e_v_e_r until the desired number of records are scraped, but since I live here, I'll check it periodically to make sure it isn't broken.
#
# Each loop only attempts to scrape a certain number of games (as defined by {interval}), merges the results into the existing main file, then begins the loop again until {target_records} is reached.
#
# Because the game records are added to the main file within each iteration, the maximum number of partially-scraped records that can be lost due to a crash is limited by the {interval} variable.

# %%
import pandas as pd
import time
import datetime

# %%
with open('../data/raw/0 - Scraped Games DF.pkl', 'rb') as file:
    existing_records = pd.read_pickle(file)

starting_records = len(existing_records)
print(starting_records)
# Out:
# 95916

# %%
# This notebook will run until this many records exist in the data/raw directory.
target_records = 120000
current_records = starting_records

# This variable is fed to the other notebook to determine how many games should be scraped
# per notebook run.
interval = 10
# %store interval
# Out:
# Stored 'interval' (int)

# %%
# Set up your tracker variables.
successful_iterations = 0
failed_iterations = 0
successive_failed_iterations = 0
start_time = time.time()

# Loop over the scraper notebook until {target_records} exist in the directory.
# Each call of the notebook aims to add {interval} records.
while current_records < target_records :
    loop_start_time = time.time()
    try :
        # %run "0.0-jod-steam-scraper.ipynb"
        successful_iterations += 1
        successive_failed_iterations = 0
    except Exception as e :
        print(f"This exception printed from the wrapper: {e}")
        failed_iterations += 1
        successive_failed_iterations += 1
        print(f"Successive failed iterations: {successive_failed_iterations}")
        print("Pausing for 2 minutes...")
        time.sleep(120)
        print("OK, GO!")

    # The scraped records are added to the main file from inside the other notebook.
    # Thus, we have to read it here to see what our current total count is.
    # (For a variety of reasons, each notebook run might not scrape exactly the number
    # of games that it was supposed to.)
    with open('../data/raw/0 - Scraped Games DF.pkl', 'rb') as file:
        existing_records = pd.read_pickle(file)
    new_record_count = len(existing_records)

    # Final record.
    loop_end_time = time.time()
    loop_final_time = loop_end_time - loop_start_time
    total_time_so_far = loop_end_time - start_time
    print("-----------------------------")
    print(f"Loop complete at {datetime.now()}")
    print(f"Games scraped this loop: {new_record_count - current_records}")
    print(f"Time spent on this loop: {int(loop_final_time/60)}m {int(loop_final_time%60)}s")
    print(f"Games scraped so far: {new_record_count - starting_records}")
    print(f"Time spent so far: {int((loop_end_time-start_time)/60)}m")
    print(f"Current record count/target: {new_record_count}/{target_records}")
    print(f"Successful loops: {successful_iterations}")
    print(f"Failed loops: {failed_iterations}")
    print("-----------------------------")
    print("")
    current_records = new_record_count

finish_time = time.time()
total_runtime = finish_time - start_time

hours = int(total_runtime / (60**2))
minutes = int(total_runtime / 60)
seconds = int(total_runtime % 60)

# print(f"{hours}h, {minutes}m, {seconds}s")
print("******************************************************")
print("******************************************************")
print(f"Completed. Started at {starting_records}, added {current_records-starting_records}, ended at {current_records}.")
print(f"{successful_iterations} successful iterations, {failed_iterations} failed iterations.")
print(f"Total runtime: {hours}h {minutes}m {seconds}s")
print("******************************************************")
print("******************************************************")
# Out:
# Identified 95916 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5588
# -----------------------------
# Loop complete at 2024-03-24 18:58:18.630402
# Games scraped this loop: 10
# Time spent on this loop: 4m 0s
# Games scraped so far: 10
# Time spent so far: 3m
# Current record count/target: 95926/120000
# Successful loops: 1
# Failed loops: 0
# -----------------------------
#
# Identified 95926 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5588
# -----------------------------
# Loop complete at 2024-03-24 19:01:27.823259
# Games scraped this loop: 10
# Time spent on this loop: 3m 9s
# Games scraped so far: 20
# Time spent so far: 3m
# Current record count/target: 95936/120000
# Successful loops: 2
# Failed loops: 0
# -----------------------------
#
# Identified 95936 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5590
# -----------------------------
# Loop complete at 2024-03-24 19:04:19.763652
# Games scraped this loop: 10
# Time spent on this loop: 2m 51s
# Games scraped so far: 30
# Time spent so far: 2m
# Current record count/target: 95946/120000
# Successful loops: 3
# Failed loops: 0
# -----------------------------
#
# Identified 95946 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5592
# -----------------------------
# Loop complete at 2024-03-24 19:07:19.788068
# Games scraped this loop: 10
# Time spent on this loop: 3m 0s
# Games scraped so far: 40
# Time spent so far: 3m
# Current record count/target: 95956/120000
# Successful loops: 4
# Failed loops: 0
# -----------------------------
#
# Identified 95956 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5594
# -----------------------------
# Loop complete at 2024-03-24 19:10:48.652296
# Games scraped this loop: 10
# Time spent on this loop: 3m 28s
# Games scraped so far: 50
# Time spent so far: 3m
# Current record count/target: 95966/120000
# Successful loops: 5
# Failed loops: 0
# -----------------------------
#
# Identified 95966 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5597
# -----------------------------
# Loop complete at 2024-03-24 19:14:08.090944
# Games scraped this loop: 10
# Time spent on this loop: 3m 19s
# Games scraped so far: 60
# Time spent so far: 3m
# Current record count/target: 95976/120000
# Successful loops: 6
# Failed loops: 0
# -----------------------------
#
# Identified 95976 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5597
# -----------------------------
# Loop complete at 2024-03-24 19:16:52.377180
# Games scraped this loop: 10
# Time spent on this loop: 2m 44s
# Games scraped so far: 70
# Time spent so far: 2m
# Current record count/target: 95986/120000
# Successful loops: 7
# Failed loops: 0
# -----------------------------
#
# Identified 95986 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5598
# -----------------------------
# Loop complete at 2024-03-24 19:19:51.063562
# Games scraped this loop: 10
# Time spent on this loop: 2m 58s
# Games scraped so far: 80
# Time spent so far: 2m
# Current record count/target: 95996/120000
# Successful loops: 8
# Failed loops: 0
# -----------------------------
#
# Identified 95996 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5598
# -----------------------------
# Loop complete at 2024-03-24 19:23:04.969707
# Games scraped this loop: 10
# Time spent on this loop: 3m 13s
# Games scraped so far: 90
# Time spent so far: 3m
# Current record count/target: 96006/120000
# Successful loops: 9
# Failed loops: 0
# -----------------------------
#
# Identified 96006 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5601
# -----------------------------
# Loop complete at 2024-03-24 19:25:51.180464
# Games scraped this loop: 10
# Time spent on this loop: 2m 46s
# Games scraped so far: 100
# Time spent so far: 2m
# Current record count/target: 96016/120000
# Successful loops: 10
# Failed loops: 0
# -----------------------------
#
# Identified 96016 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5604
# -----------------------------
# Loop complete at 2024-03-24 19:28:46.004598
# Games scraped this loop: 10
# Time spent on this loop: 2m 54s
# Games scraped so far: 110
# Time spent so far: 2m
# Current record count/target: 96026/120000
# Successful loops: 11
# Failed loops: 0
# -----------------------------
#
# Identified 96026 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5606
# -----------------------------
# Loop complete at 2024-03-24 19:31:10.619135
# Games scraped this loop: 10
# Time spent on this loop: 2m 24s
# Games scraped so far: 120
# Time spent so far: 2m
# Current record count/target: 96036/120000
# Successful loops: 12
# Failed loops: 0
# -----------------------------
#
# Identified 96036 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5607
# -----------------------------
# Loop complete at 2024-03-24 19:33:47.849894
# Games scraped this loop: 10
# Time spent on this loop: 2m 37s
# Games scraped so far: 130
# Time spent so far: 2m
# Current record count/target: 96046/120000
# Successful loops: 13
# Failed loops: 0
# -----------------------------
#
# Identified 96046 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5610
# -----------------------------
# Loop complete at 2024-03-24 19:36:59.165192
# Games scraped this loop: 10
# Time spent on this loop: 3m 11s
# Games scraped so far: 140
# Time spent so far: 3m
# Current record count/target: 96056/120000
# Successful loops: 14
# Failed loops: 0
# -----------------------------
#
# Identified 96056 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5612
# -----------------------------
# Loop complete at 2024-03-24 19:40:37.125733
# Games scraped this loop: 10
# Time spent on this loop: 3m 37s
# Games scraped so far: 150
# Time spent so far: 3m
# Current record count/target: 96066/120000
# Successful loops: 15
# Failed loops: 0
# -----------------------------
#
# Identified 96066 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5616
# -----------------------------
# Loop complete at 2024-03-24 19:43:52.271057
# Games scraped this loop: 10
# Time spent on this loop: 3m 15s
# Games scraped so far: 160
# Time spent so far: 3m
# Current record count/target: 96076/120000
# Successful loops: 16
# Failed loops: 0
# -----------------------------
#
# Identified 96076 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5619
# -----------------------------
# Loop complete at 2024-03-24 19:47:12.018854
# Games scraped this loop: 10
# Time spent on this loop: 3m 19s
# Games scraped so far: 170
# Time spent so far: 3m
# Current record count/target: 96086/120000
# Successful loops: 17
# Failed loops: 0
# -----------------------------
#
# Identified 96086 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5621
# -----------------------------
# Loop complete at 2024-03-24 19:50:32.732771
# Games scraped this loop: 10
# Time spent on this loop: 3m 20s
# Games scraped so far: 180
# Time spent so far: 3m
# Current record count/target: 96096/120000
# Successful loops: 18
# Failed loops: 0
# -----------------------------
#
# Identified 96096 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5624
# -----------------------------
# Loop complete at 2024-03-24 19:53:35.527019
# Games scraped this loop: 10
# Time spent on this loop: 3m 2s
# Games scraped so far: 190
# Time spent so far: 3m
# Current record count/target: 96106/120000
# Successful loops: 19
# Failed loops: 0
# -----------------------------
#
# Identified 96106 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5626
# -----------------------------
# Loop complete at 2024-03-24 19:56:26.516239
# Games scraped this loop: 10
# Time spent on this loop: 2m 50s
# Games scraped so far: 200
# Time spent so far: 2m
# Current record count/target: 96116/120000
# Successful loops: 20
# Failed loops: 0
# -----------------------------
#
# Identified 96116 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5626
# -----------------------------
# Loop complete at 2024-03-24 19:59:33.224846
# Games scraped this loop: 10
# Time spent on this loop: 3m 6s
# Games scraped so far: 210
# Time spent so far: 3m
# Current record count/target: 96126/120000
# Successful loops: 21
# Failed loops: 0
# -----------------------------
#
# Identified 96126 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5628
# -----------------------------
# Loop complete at 2024-03-24 20:02:32.318018
# Games scraped this loop: 10
# Time spent on this loop: 2m 59s
# Games scraped so far: 220
# Time spent so far: 2m
# Current record count/target: 96136/120000
# Successful loops: 22
# Failed loops: 0
# -----------------------------
#
# Identified 96136 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5630
# -----------------------------
# Loop complete at 2024-03-24 20:05:18.389760
# Games scraped this loop: 10
# Time spent on this loop: 2m 46s
# Games scraped so far: 230
# Time spent so far: 2m
# Current record count/target: 96146/120000
# Successful loops: 23
# Failed loops: 0
# -----------------------------
#
# Identified 96146 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5633
# -----------------------------
# Loop complete at 2024-03-24 20:08:15.898282
# Games scraped this loop: 10
# Time spent on this loop: 2m 57s
# Games scraped so far: 240
# Time spent so far: 2m
# Current record count/target: 96156/120000
# Successful loops: 24
# Failed loops: 0
# -----------------------------
#
# Identified 96156 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5634
# -----------------------------
# Loop complete at 2024-03-24 20:11:10.247008
# Games scraped this loop: 10
# Time spent on this loop: 2m 54s
# Games scraped so far: 250
# Time spent so far: 2m
# Current record count/target: 96166/120000
# Successful loops: 25
# Failed loops: 0
# -----------------------------
#
# Identified 96166 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5635
# -----------------------------
# Loop complete at 2024-03-24 20:13:57.758333
# Games scraped this loop: 10
# Time spent on this loop: 2m 47s
# Games scraped so far: 260
# Time spent so far: 2m
# Current record count/target: 96176/120000
# Successful loops: 26
# Failed loops: 0
# -----------------------------
#
# Identified 96176 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5636
# -----------------------------
# Loop complete at 2024-03-24 20:17:29.715466
# Games scraped this loop: 10
# Time spent on this loop: 3m 31s
# Games scraped so far: 270
# Time spent so far: 3m
# Current record count/target: 96186/120000
# Successful loops: 27
# Failed loops: 0
# -----------------------------
#
# Identified 96186 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5638
# -----------------------------
# Loop complete at 2024-03-24 20:20:36.901807
# Games scraped this loop: 10
# Time spent on this loop: 3m 7s
# Games scraped so far: 280
# Time spent so far: 3m
# Current record count/target: 96196/120000
# Successful loops: 28
# Failed loops: 0
# -----------------------------
#
# Identified 96196 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5640
# -----------------------------
# Loop complete at 2024-03-24 20:23:20.913818
# Games scraped this loop: 10
# Time spent on this loop: 2m 44s
# Games scraped so far: 290
# Time spent so far: 2m
# Current record count/target: 96206/120000
# Successful loops: 29
# Failed loops: 0
# -----------------------------
#
# Identified 96206 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5643
# -----------------------------
# Loop complete at 2024-03-24 20:26:23.716250
# Games scraped this loop: 10
# Time spent on this loop: 3m 2s
# Games scraped so far: 300
# Time spent so far: 3m
# Current record count/target: 96216/120000
# Successful loops: 30
# Failed loops: 0
# -----------------------------
#
# Identified 96216 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5644
# -----------------------------
# Loop complete at 2024-03-24 20:29:31.331600
# Games scraped this loop: 10
# Time spent on this loop: 3m 7s
# Games scraped so far: 310
# Time spent so far: 3m
# Current record count/target: 96226/120000
# Successful loops: 31
# Failed loops: 0
# -----------------------------
#
# Identified 96226 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5648
# -----------------------------
# Loop complete at 2024-03-24 20:32:51.616297
# Games scraped this loop: 10
# Time spent on this loop: 3m 20s
# Games scraped so far: 320
# Time spent so far: 3m
# Current record count/target: 96236/120000
# Successful loops: 32
# Failed loops: 0
# -----------------------------
#
# Identified 96236 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5649
# -----------------------------
# Loop complete at 2024-03-24 20:36:09.339488
# Games scraped this loop: 10
# Time spent on this loop: 3m 17s
# Games scraped so far: 330
# Time spent so far: 3m
# Current record count/target: 96246/120000
# Successful loops: 33
# Failed loops: 0
# -----------------------------
#
# Identified 96246 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5652
# -----------------------------
# Loop complete at 2024-03-24 20:38:53.186795
# Games scraped this loop: 10
# Time spent on this loop: 2m 43s
# Games scraped so far: 340
# Time spent so far: 2m
# Current record count/target: 96256/120000
# Successful loops: 34
# Failed loops: 0
# -----------------------------
#
# Identified 96256 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5655
# -----------------------------
# Loop complete at 2024-03-24 20:42:12.482669
# Games scraped this loop: 10
# Time spent on this loop: 3m 19s
# Games scraped so far: 350
# Time spent so far: 3m
# Current record count/target: 96266/120000
# Successful loops: 35
# Failed loops: 0
# -----------------------------
#
# Identified 96266 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5656
# -----------------------------
# Loop complete at 2024-03-24 20:45:31.162226
# Games scraped this loop: 10
# Time spent on this loop: 3m 18s
# Games scraped so far: 360
# Time spent so far: 3m
# Current record count/target: 96276/120000
# Successful loops: 36
# Failed loops: 0
# -----------------------------
#
# Identified 96276 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5658
# -----------------------------
# Loop complete at 2024-03-24 20:48:26.786532
# Games scraped this loop: 10
# Time spent on this loop: 2m 55s
# Games scraped so far: 370
# Time spent so far: 2m
# Current record count/target: 96286/120000
# Successful loops: 37
# Failed loops: 0
# -----------------------------
#
# Identified 96286 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5659
# -----------------------------
# Loop complete at 2024-03-24 20:51:22.406210
# Games scraped this loop: 10
# Time spent on this loop: 2m 55s
# Games scraped so far: 380
# Time spent so far: 2m
# Current record count/target: 96296/120000
# Successful loops: 38
# Failed loops: 0
# -----------------------------
#
# Identified 96296 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5660
# -----------------------------
# Loop complete at 2024-03-24 20:54:02.130310
# Games scraped this loop: 10
# Time spent on this loop: 2m 39s
# Games scraped so far: 390
# Time spent so far: 2m
# Current record count/target: 96306/120000
# Successful loops: 39
# Failed loops: 0
# -----------------------------
#
# Identified 96306 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5663
# -----------------------------
# Loop complete at 2024-03-24 20:56:46.523644
# Games scraped this loop: 10
# Time spent on this loop: 2m 44s
# Games scraped so far: 400
# Time spent so far: 2m
# Current record count/target: 96316/120000
# Successful loops: 40
# Failed loops: 0
# -----------------------------
#
# Identified 96316 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5665
# -----------------------------
# Loop complete at 2024-03-24 20:59:58.368761
# Games scraped this loop: 10
# Time spent on this loop: 3m 11s
# Games scraped so far: 410
# Time spent so far: 3m
# Current record count/target: 96326/120000
# Successful loops: 41
# Failed loops: 0
# -----------------------------
#
# Identified 96326 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5669
# -----------------------------
# Loop complete at 2024-03-24 21:03:22.989220
# Games scraped this loop: 10
# Time spent on this loop: 3m 24s
# Games scraped so far: 420
# Time spent so far: 3m
# Current record count/target: 96336/120000
# Successful loops: 42
# Failed loops: 0
# -----------------------------
#
# Identified 96336 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5670
# -----------------------------
# Loop complete at 2024-03-24 21:06:19.124120
# Games scraped this loop: 10
# Time spent on this loop: 2m 56s
# Games scraped so far: 430
# Time spent so far: 2m
# Current record count/target: 96346/120000
# Successful loops: 43
# Failed loops: 0
# -----------------------------
#
# Identified 96346 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5670
# -----------------------------
# Loop complete at 2024-03-24 21:08:59.986728
# Games scraped this loop: 10
# Time spent on this loop: 2m 40s
# Games scraped so far: 440
# Time spent so far: 2m
# Current record count/target: 96356/120000
# Successful loops: 44
# Failed loops: 0
# -----------------------------
#
# Identified 96356 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5671
# -----------------------------
# Loop complete at 2024-03-24 21:11:54.807850
# Games scraped this loop: 10
# Time spent on this loop: 2m 54s
# Games scraped so far: 450
# Time spent so far: 2m
# Current record count/target: 96366/120000
# Successful loops: 45
# Failed loops: 0
# -----------------------------
#
# Identified 96366 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5671
# -----------------------------
# Loop complete at 2024-03-24 21:15:14.271348
# Games scraped this loop: 10
# Time spent on this loop: 3m 19s
# Games scraped so far: 460
# Time spent so far: 3m
# Current record count/target: 96376/120000
# Successful loops: 46
# Failed loops: 0
# -----------------------------
#
# Identified 96376 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5672
# -----------------------------
# Loop complete at 2024-03-24 21:17:51.405902
# Games scraped this loop: 10
# Time spent on this loop: 2m 37s
# Games scraped so far: 470
# Time spent so far: 2m
# Current record count/target: 96386/120000
# Successful loops: 47
# Failed loops: 0
# -----------------------------
#
# Identified 96386 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5674
# -----------------------------
# Loop complete at 2024-03-24 21:20:54.943847
# Games scraped this loop: 10
# Time spent on this loop: 3m 3s
# Games scraped so far: 480
# Time spent so far: 3m
# Current record count/target: 96396/120000
# Successful loops: 48
# Failed loops: 0
# -----------------------------
#
# Identified 96396 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5676
# -----------------------------
# Loop complete at 2024-03-24 21:23:49.947541
# Games scraped this loop: 10
# Time spent on this loop: 2m 55s
# Games scraped so far: 490
# Time spent so far: 2m
# Current record count/target: 96406/120000
# Successful loops: 49
# Failed loops: 0
# -----------------------------
#
# Identified 96406 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5677
# -----------------------------
# Loop complete at 2024-03-24 21:26:50.367674
# Games scraped this loop: 10
# Time spent on this loop: 3m 0s
# Games scraped so far: 500
# Time spent so far: 3m
# Current record count/target: 96416/120000
# Successful loops: 50
# Failed loops: 0
# -----------------------------
#
# Identified 96416 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5680
# -----------------------------
# Loop complete at 2024-03-24 21:29:41.249729
# Games scraped this loop: 10
# Time spent on this loop: 2m 50s
# Games scraped so far: 510
# Time spent so far: 2m
# Current record count/target: 96426/120000
# Successful loops: 51
# Failed loops: 0
# -----------------------------
#
# Identified 96426 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5681
# -----------------------------
# Loop complete at 2024-03-24 21:32:44.792655
# Games scraped this loop: 10
# Time spent on this loop: 3m 3s
# Games scraped so far: 520
# Time spent so far: 3m
# Current record count/target: 96436/120000
# Successful loops: 52
# Failed loops: 0
# -----------------------------
#
# Identified 96436 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5681
# -----------------------------
# Loop complete at 2024-03-24 21:35:55.171452
# Games scraped this loop: 10
# Time spent on this loop: 3m 10s
# Games scraped so far: 530
# Time spent so far: 3m
# Current record count/target: 96446/120000
# Successful loops: 53
# Failed loops: 0
# -----------------------------
#
# Identified 96446 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5681
# -----------------------------
# Loop complete at 2024-03-24 21:38:43.816811
# Games scraped this loop: 10
# Time spent on this loop: 2m 48s
# Games scraped so far: 540
# Time spent so far: 2m
# Current record count/target: 96456/120000
# Successful loops: 54
# Failed loops: 0
# -----------------------------
#
# Identified 96456 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5686
# -----------------------------
# Loop complete at 2024-03-24 21:41:45.337344
# Games scraped this loop: 10
# Time spent on this loop: 3m 1s
# Games scraped so far: 550
# Time spent so far: 3m
# Current record count/target: 96466/120000
# Successful loops: 55
# Failed loops: 0
# -----------------------------
#
# Identified 96466 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5688
# -----------------------------
# Loop complete at 2024-03-24 21:44:48.119033
# Games scraped this loop: 10
# Time spent on this loop: 3m 2s
# Games scraped so far: 560
# Time spent so far: 3m
# Current record count/target: 96476/120000
# Successful loops: 56
# Failed loops: 0
# -----------------------------
#
# Identified 96476 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5688
# -----------------------------
# Loop complete at 2024-03-24 21:47:44.497883
# Games scraped this loop: 10
# Time spent on this loop: 2m 56s
# Games scraped so far: 570
# Time spent so far: 2m
# Current record count/target: 96486/120000
# Successful loops: 57
# Failed loops: 0
# -----------------------------
#
# Identified 96486 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5692
# -----------------------------
# Loop complete at 2024-03-24 21:50:26.266077
# Games scraped this loop: 10
# Time spent on this loop: 2m 41s
# Games scraped so far: 580
# Time spent so far: 2m
# Current record count/target: 96496/120000
# Successful loops: 58
# Failed loops: 0
# -----------------------------
#
# Identified 96496 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5692
# -----------------------------
# Loop complete at 2024-03-24 21:53:16.927369
# Games scraped this loop: 10
# Time spent on this loop: 2m 50s
# Games scraped so far: 590
# Time spent so far: 2m
# Current record count/target: 96506/120000
# Successful loops: 59
# Failed loops: 0
# -----------------------------
#
# Identified 96506 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5693
# -----------------------------
# Loop complete at 2024-03-24 21:56:39.638356
# Games scraped this loop: 10
# Time spent on this loop: 3m 22s
# Games scraped so far: 600
# Time spent so far: 3m
# Current record count/target: 96516/120000
# Successful loops: 60
# Failed loops: 0
# -----------------------------
#
# Identified 96516 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5695
# -----------------------------
# Loop complete at 2024-03-24 21:59:32.988482
# Games scraped this loop: 10
# Time spent on this loop: 2m 53s
# Games scraped so far: 610
# Time spent so far: 2m
# Current record count/target: 96526/120000
# Successful loops: 61
# Failed loops: 0
# -----------------------------
#
# Identified 96526 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5697
# -----------------------------
# Loop complete at 2024-03-24 22:02:44.501013
# Games scraped this loop: 10
# Time spent on this loop: 3m 11s
# Games scraped so far: 620
# Time spent so far: 3m
# Current record count/target: 96536/120000
# Successful loops: 62
# Failed loops: 0
# -----------------------------
#
# Identified 96536 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5699
# -----------------------------
# Loop complete at 2024-03-24 22:05:56.349507
# Games scraped this loop: 10
# Time spent on this loop: 3m 11s
# Games scraped so far: 630
# Time spent so far: 3m
# Current record count/target: 96546/120000
# Successful loops: 63
# Failed loops: 0
# -----------------------------
#
# Identified 96546 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5700
# -----------------------------
# Loop complete at 2024-03-24 22:09:00.205180
# Games scraped this loop: 10
# Time spent on this loop: 3m 3s
# Games scraped so far: 640
# Time spent so far: 3m
# Current record count/target: 96556/120000
# Successful loops: 64
# Failed loops: 0
# -----------------------------
#
# Identified 96556 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=5703
# -----------------------------
# Loop complete at 2024-03-24 22:11:58.470607
# Games scraped this loop: 10
# Time spent on this loop: 2m 58s
# Games scraped so far: 650
# Time spent so far: 2m
# Current record count/target: 96566/120000
# Successful loops: 65
# Failed loops: 0
# -----------------------------
#
# Identified 96566 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# ...
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6418
# -----------------------------
# Loop complete at 2024-03-25 18:53:24.723547
# Games scraped this loop: 10
# Time spent on this loop: 2m 55s
# Games scraped so far: 4808
# Time spent so far: 2m
# Current record count/target: 100724/120000
# Successful loops: 482
# Failed loops: 0
# -----------------------------
#
# Identified 100724 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6423
# -----------------------------
# Loop complete at 2024-03-25 18:56:45.337542
# Games scraped this loop: 10
# Time spent on this loop: 3m 20s
# Games scraped so far: 4818
# Time spent so far: 3m
# Current record count/target: 100734/120000
# Successful loops: 483
# Failed loops: 0
# -----------------------------
#
# Identified 100734 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6426
# -----------------------------
# Loop complete at 2024-03-25 18:59:58.167648
# Games scraped this loop: 10
# Time spent on this loop: 3m 12s
# Games scraped so far: 4828
# Time spent so far: 3m
# Current record count/target: 100744/120000
# Successful loops: 484
# Failed loops: 0
# -----------------------------
#
# Identified 100744 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6428
# -----------------------------
# Loop complete at 2024-03-25 19:03:04.067309
# Games scraped this loop: 10
# Time spent on this loop: 3m 5s
# Games scraped so far: 4838
# Time spent so far: 3m
# Current record count/target: 100754/120000
# Successful loops: 485
# Failed loops: 0
# -----------------------------
#
# Identified 100754 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6431
# -----------------------------
# Loop complete at 2024-03-25 19:07:21.927448
# Games scraped this loop: 10
# Time spent on this loop: 4m 17s
# Games scraped so far: 4848
# Time spent so far: 4m
# Current record count/target: 100764/120000
# Successful loops: 486
# Failed loops: 0
# -----------------------------
#
# Identified 100764 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6432
# -----------------------------
# Loop complete at 2024-03-25 19:10:59.216036
# Games scraped this loop: 10
# Time spent on this loop: 3m 37s
# Games scraped so far: 4858
# Time spent so far: 3m
# Current record count/target: 100774/120000
# Successful loops: 487
# Failed loops: 0
# -----------------------------
#
# Identified 100774 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6436
# -----------------------------
# Loop complete at 2024-03-25 19:14:29.363334
# Games scraped this loop: 10
# Time spent on this loop: 3m 30s
# Games scraped so far: 4868
# Time spent so far: 3m
# Current record count/target: 100784/120000
# Successful loops: 488
# Failed loops: 0
# -----------------------------
#
# Identified 100784 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6436
# -----------------------------
# Loop complete at 2024-03-25 19:18:22.280593
# Games scraped this loop: 10
# Time spent on this loop: 3m 52s
# Games scraped so far: 4878
# Time spent so far: 3m
# Current record count/target: 100794/120000
# Successful loops: 489
# Failed loops: 0
# -----------------------------
#
# Identified 100794 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6436
# -----------------------------
# Loop complete at 2024-03-25 19:21:24.196507
# Games scraped this loop: 10
# Time spent on this loop: 3m 1s
# Games scraped so far: 4888
# Time spent so far: 3m
# Current record count/target: 100804/120000
# Successful loops: 490
# Failed loops: 0
# -----------------------------
#
# Identified 100804 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6436
# -----------------------------
# Loop complete at 2024-03-25 19:25:14.468658
# Games scraped this loop: 10
# Time spent on this loop: 3m 50s
# Games scraped so far: 4898
# Time spent so far: 3m
# Current record count/target: 100814/120000
# Successful loops: 491
# Failed loops: 0
# -----------------------------
#
# Identified 100814 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6438
# -----------------------------
# Loop complete at 2024-03-25 19:28:33.671206
# Games scraped this loop: 10
# Time spent on this loop: 3m 19s
# Games scraped so far: 4908
# Time spent so far: 3m
# Current record count/target: 100824/120000
# Successful loops: 492
# Failed loops: 0
# -----------------------------
#
# Identified 100824 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6438
# -----------------------------
# Loop complete at 2024-03-25 19:31:47.776199
# Games scraped this loop: 10
# Time spent on this loop: 3m 14s
# Games scraped so far: 4918
# Time spent so far: 3m
# Current record count/target: 100834/120000
# Successful loops: 493
# Failed loops: 0
# -----------------------------
#
# Identified 100834 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6442
# -----------------------------
# Loop complete at 2024-03-25 19:34:56.292567
# Games scraped this loop: 10
# Time spent on this loop: 3m 8s
# Games scraped so far: 4928
# Time spent so far: 3m
# Current record count/target: 100844/120000
# Successful loops: 494
# Failed loops: 0
# -----------------------------
#
# Identified 100844 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6443
# -----------------------------
# Loop complete at 2024-03-25 19:38:38.010647
# Games scraped this loop: 10
# Time spent on this loop: 3m 41s
# Games scraped so far: 4938
# Time spent so far: 3m
# Current record count/target: 100854/120000
# Successful loops: 495
# Failed loops: 0
# -----------------------------
#
# Identified 100854 existing game records.
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# C:\Users\Josh\AppData\Local\Temp\ipykernel_34272\755497478.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   scraped_search_results_df = pd.DataFrame(games)
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6443
# -----------------------------
# Loop complete at 2024-03-25 19:41:34.671908
# Games scraped this loop: 10
# Time spent on this loop: 2m 56s
# Games scraped so far: 4948
# Time spent so far: 2m
# Current record count/target: 100864/120000
# Successful loops: 496
# Failed loops: 0
# -----------------------------
#
# Identified 100864 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6446
# -----------------------------
# Loop complete at 2024-03-25 19:44:31.625521
# Games scraped this loop: 10
# Time spent on this loop: 2m 56s
# Games scraped so far: 4958
# Time spent so far: 2m
# Current record count/target: 100874/120000
# Successful loops: 497
# Failed loops: 0
# -----------------------------
#
# Identified 100874 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6448
# -----------------------------
# Loop complete at 2024-03-25 19:47:52.143709
# Games scraped this loop: 10
# Time spent on this loop: 3m 20s
# Games scraped so far: 4968
# Time spent so far: 3m
# Current record count/target: 100884/120000
# Successful loops: 498
# Failed loops: 0
# -----------------------------
#
# Identified 100884 existing game records.
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# Stored 'next_link' (str)
# 10 games scraped from search page.
# Scraping individual game page data...
# Scraped 10 game pages.
# Scraping comment counts. This might take a while...
# Scraped 10 games' comment counts.
# Next scrape starts from https://store.steampowered.com/search/?sort_by=&sort_order=0&supportedlang=english&page=6451
# -----------------------------
# Loop complete at 2024-03-25 19:51:04.277182
# Games scraped this loop: 10
# Time spent on this loop: 3m 12s
# Games scraped so far: 4978
# Time spent so far: 3m
# Current record count/target: 100894/120000
# Successful loops: 499
# Failed loops: 0
# -----------------------------
#
# Identified 100894 existing game records.
# Stored 'next_link' (str)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_34272\227278714.py:68
#      66 # Include a random delay to prevent getting IP blocked.
#      67 interval = 0.5 + random.random() * 0.3
# ---> 68 time.sleep(interval)
#      70 if next_link == False :
#      71     print('Fewer than '+str(games_to_scrape)+' games in the available search results.')
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#      10 loop_start_time = time.time()
#      11 try :
# ---> 12     get_ipython().run_line_magic('run', '"0.0-jod-steam-scraper.ipynb"')
#      13     successful_iterations += 1
#      14     successive_failed_iterations = 0
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\execution.py:722, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     720     with preserve_keys(self.shell.user_ns, '__file__'):
#     721         self.shell.user_ns['__file__'] = filename
# --> 722         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     723     return
#     725 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:2939, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2937 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2938 if raise_exceptions:
# -> 2939     result.raise_error()
#    2940 elif not result.success:
#    2941     break
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:268, in ExecutionResult.raise_error(self)
#     266     raise self.error_before_exec
#     267 if self.error_in_exec is not None:
# --> 268     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_34272\227278714.py:68
#      66 # Include a random delay to prevent getting IP blocked.
#      67 interval = 0.5 + random.random() * 0.3
# ---> 68 time.sleep(interval)
#      70 if next_link == False :
#      71     print('Fewer than '+str(games_to_scrape)+' games in the available search results.')
#
# KeyboardInterrupt:

# %%
# LINK RESETTER

# next_link = 'https://store.steampowered.com/search/?sort_by=&sort_order=0&page=3665'

# %store next_link
# Out:
# Stored 'next_link' (str)
